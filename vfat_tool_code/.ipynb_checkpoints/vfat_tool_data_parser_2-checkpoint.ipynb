# %%
import re
import os
import pandas as pd
import numpy as np
import traceback2
from datetime import datetime
import pymysql
import numpy as np

# %%
sm = {
    "WBTC" : "BTC",
    "WETH" : "ETH",
    "WBNB" : "BNB",
    "WFTM" : "FTM",
    "WAVAX" : "AVAX",
    "cvxCRV" : "CRV"
}

# %%
def __connect__():
    db_user = 'coin'
    db_password = 'dragonstone#123'
    db_name = 'master_data'
    db_host = 'localhost'
    return pymysql.connect(
        unix_socket=None,
        host=db_host,
        user=db_user,
        password=db_password,
        db=db_name,
        charset='latin1',
        cursorclass=pymysql.cursors.DictCursor)


def get_cursor(connection):
    if connection is None:
        connection = __connect__()
    connection.ping(reconnect=True)
    return connection.cursor()

# %%
def get_raydium_data(date):
    sql = f'select * from raydium_farm_pool_data where timestamp_dt = FROM_UNIXTIME({date});'
    data = pd.read_sql_query(sql, __connect__())
    data['apr'] = data['pool_rate']
    data['network'] = 'SOL'
    data['type_of_agriculture'] = data['farm_payment'].apply(lambda x : 'FARM' if x is not None else 'POOL')
    return data[['pair1', 'pair2', 'apr', 'tvl', 'where', 'network', 'type_of_agriculture']]

def get_liquidityfolio_pool_data(date):
    sql = f'select * from liquidityfolio_pool where timestamp_dt = FROM_UNIXTIME({date}) and `where` != "balancer";'
    data = pd.read_sql_query(sql, __connect__())
    data['apr'] = data['pool_rate'] * 100 * 12
    data['tvl'] = data['tvl'] * 1000
    data['type_of_agriculture'] = data['farm_payment'].apply(lambda x : 'FARM' if x is not None else 'POOL')
    data['network'] = 'ETH'
    return data[['pair1', 'pair2', 'apr', 'tvl', 'where', 'network', 'type_of_agriculture']]

# %%
date = datetime(2021, 8, 10)
dt = date.timestamp()
df = get_raydium_data(dt)
df = df.append(get_liquidityfolio_pool_data(dt))
df[df['where'] == 'Sushi']
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, apr, tvl, where, network, type_of_agriculture]
# Index: []

# %%
df
# Out:
#      pair1 pair2   apr           tvl    where network type_of_agriculture
# 0    ALEPH  USDC  2.21  6.330781e+06  Raydium     SOL                POOL
# 1     APEX  USDC  0.00  2.930430e+02  Raydium     SOL                POOL
# 2     APYS  USDC  2.62  6.872245e+04  Raydium     SOL                POOL
# 3     AUSS  USDC  0.00  4.256466e+00  Raydium     SOL                POOL
# 4      BLD  USDC  0.00  5.874780e+00  Raydium     SOL                POOL
# ..     ...   ...   ...           ...      ...     ...                 ...
# 119   WOOF  USDC  0.07  1.466740e-01  Raydium     SOL                POOL
# 120  xCOPE  USDC  0.00  2.960129e+06  Raydium     SOL                POOL
# 121    YFI   SRM  3.02  6.973069e+04  Raydium     SOL                POOL
# 122    YFI  USDC  4.61  1.287470e+07  Raydium     SOL                POOL
# 123    YFI  USDT  4.41  1.081699e+06  Raydium     SOL                POOL
#
# [124 rows x 7 columns]

# %%
import os
import re
import pandas as pd

# %%
def matched(regex, line):
    matched = re.search(regex, line)
    return bool(matched)

# %%
def get_info(block):
    pass

# %%
def clean_block(block):
    regexs = ['[\d]+ [\-]$', 'Total [s,S]taked:', 'NOTE: Once rewards', 'Each time you', "Staking Contract", "Found ", "Showing incentivized"
             ,"Finished reading smart", "The following farms have", "------------------", "{"]
    if len(block) > 0:
        for regex in regexs:
            if matched(regex, block[0]):
                return block[1:]
    return block

# %%
def get_fee(block):
    fee_regexs = ["fee [\d.]+%", "Fee [\d.]+%", "[\d.]+% fee", "[\d.]+% Fee"]
    fee_regex = "((fee|Fee) [\d.]+%)|([\d.]+% (Fee|fee))"
    for line in block:
        if matched(fee_regex, line):
            for regex in fee_regexs:
                if matched(regex, line):
                    x = re.findall(regex, line)
                    return x[0].replace("Fee", "").replace("fee", "").replace("%", "").replace(" ","").strip()
    return 0

# %%
block = ['[WAVAX]-[PEFI] PGL', '[+]', '[-]', '[<=>]', 'Price: $5.98 TVL: $941,883.25', 'WAVAX Price: $16.55', 'PEFI Price: $0.36', 'Staked: 143314.2957 PGL ($857,165.68)', 'PEFI Per Week: 17695.11 ($6,290.27)', 'APR: Day 0.10% Week 0.73% Year 38.16%', 'You are staking 0.00 [WAVAX]-[PEFI] PGL ($0.00), 0.00% of the pool.', 'Stake 0.00 [WAVAX]-[PEFI] PGL', 'Unstake 0.00 [WAVAX]-[PEFI] PGL - Fee 2.56%', 'Claim 0.00 PEFI ($0.00)', 'Staking or unstaking also claims rewards.']
# block = ["qweqwerlkqer", "afa 23.5% Fee adsfas"]
get_fee(block)
# Out:
# '2.56'

# %%
def get_single_pair1(line):
    if " " not in line:
        return [line, ""]

def get_single_pair2(line):
    if matched("[\d]+ [\-] ", line):
        return [line.split(" ")[2], ""]
    return ["", ""]

# %%
def get_pair2(line):
    if "-" in line:
        return line.split("-")
    return ["", ""]

# %%
def pair1(line):
#     print(line)
    try:
        is_3_pairs = line.split("]-[")
        if len(is_3_pairs) > 2:
            return ""
        s_index = line.index("[") + 1
        s = line[s_index: line.index("]", s_index)]
        return s
#         if all(ord(c) < 128 for c in s):
#             return s
#         else:
#             print(line)
#             return None
    except:
        return ''

def pair2(line):
#     print(line)
    if "-[" not in line:
        return ""
    s_index = line.index("-[") + 2
    s = line[s_index: line.index("]", s_index)]
    return s
#     print(s)
#     if all(ord(c) < 128 for c in s):
#         return s
#     else:
#         print(line)
#         return ''

# %%
def tvl(line):
    tvl = "TVL: \$[0-9\.\,]+"
    x = re.findall(tvl, line)
    return x[0].replace("TVL: $", "").replace("%", "").replace(",","").strip()

def get_single_tvl(line):
    exp = "\(*[0-9\,\.$]+\)*"
    x = re.findall(exp, line)
    return x[-1].replace("(", "").replace(")", "").replace("$", "").replace(",","").strip()

def where(line):
    if 'INFO' in line:
        return line.replace("INFO", "").replace('\n', '').replace(":", "").replace("//", "://").replace('*', '').strip()
    return None

def apr(line):
    apr = "Year [0-9\,\.]+\%"
    x = re.findall(apr, line)
    return x[0].replace("Year ", "").replace("%", "").strip() if len(x) else 0

# %%
def get_pair(block):
    return [pair1(block[0]) , pair2(block[0])]

def get_apr(block):
    for line in block:
        if matched("APR *:", line):
            return apr(line)
    return 0

def get_tvl(block, network=None):
    if network != 'BSC':
        for line in block:
            if "TVL: " in line:
                return tvl(line)
    for line in block:
        if "Staked:" in line:
            return get_single_tvl(line)
    return None

        
def get_where(block):
    return where(block[0])

# %%
def get_pair_info(block, where, network=None):
    if len(block)> 0:
        if matched('[\d]+ [\-]$', block[0]):
            if len(block) > 1:
                print(len(block), "\t", block[1], "Z#####################")
            else:
                print(len(block), "\t", block[0], "\t-------------------------")
        else:
            print(len(block), "\t", block[0])
    pair = get_pair(block)
    if pair is None or len(pair[0]) == 0:
        pair = get_pair(block[0])
    if pair is None or len(pair[0]) == 0:
        pair = get_single_pair1(block[0])
    if pair is None or len(pair[0]) == 0:
        pair = get_single_pair2(block[0])
    return [pair[0].replace("τ", "T", -1), pair[1].replace("τ", "T", -1), get_apr(block), get_tvl(block, network=network), where, get_fee(block)]

# %%
def get_pair_from_blocks(blocks, network=None):
    where = None
    pairs = []
    for block in blocks:
        block2 = block
        correction_loop = 0
        while correction_loop < 10:
            block = clean_block(block)
            correction_loop = correction_loop + 1
        if len(block) == 1:
            where_tmp = get_where(block)
            where = where_tmp
#             print(where)
        elif len(block) > 0 and len(block) < 25:
            pair = get_pair_info(block, where, network=network)
#             print("pair: ", pair)
            if pair is None or len(pair[0]) == 0:
                print('No Pair')
            else:
                pairs.append(pair)
        else:
            if(len(block)) > 0:
                print("Bigger Block as Test")
    return pairs

# %%
def convert_to_pair_blocks2(data_lines):
#     print(data_lines)
    blocks = []
    block = []
    index = 0
    while index < len(data_lines):
        line = data_lines[index]
        if "[%]" in line :
            tmp_block = block[:-3]
            if len(tmp_block):
                blocks.append(tmp_block)
            block = []
            block.append(data_lines[index - 2])
            block.append(data_lines[index - 1])
            block.append(line)
        elif "Exit" in line:
            tmp_block = block[:]
            if len(tmp_block):
                tmp_block.append(line)
                blocks.append(tmp_block)
            block = []
        elif "INFO" in line:
            blocks.append([line.strip()])
            block = []
        elif matched("[\d]+ [\-] *", line):
            blocks.append(block)
            block = []
        elif "Staking or unstaking also" in line:
            block.append(line)
            blocks.append(block)
            block = []
        else:
            block.append(line)
        index = index + 1
    if len(block):
        blocks.append(block)
#     print(blocks)
    return blocks

# %%
def extract_single_pairs(blocks):
    all_blocks = []
    for block in blocks:
        all_blocks.extend(convert_to_pair_blocks2(block))
    return all_blocks

# %%
def convert_to_pair_blocks(data_lines):
#     print(data_lines)
    blocks = []
    block = []
    index = 0
    while index < len(data_lines):
        line = data_lines[index]
        if "INFO" in line:
            blocks.append([line])
            block = []
        elif "[+]" in line:
            tmp_block = block[:-1]
            if len(tmp_block):
                blocks.append(tmp_block)
            block = []
            block.append(data_lines[index - 1])
            block.append(line)
        else:
            block.append(line)
            
        index = index + 1
    blocks.append(block)
    return extract_single_pairs(blocks)

# %%
def read_data_rows_from_files(file):
    f = open(file)
    lines = f.readlines()
    start_index = 0
    data_lines = []
    while start_index < len(lines):
        line = lines[start_index]
        start_index = start_index + 1
        if "INFO" in line:
#             print(line.strip())
            data_lines.append(line)
        if "Reading smart contracts" in line:
            while start_index < len(lines):
                line = lines[start_index].strip()
                start_index = start_index + 1
                if len(line):
#                     print(line)
                    data_lines.append(line)
    return convert_to_pair_blocks(data_lines)

# %%
def convert_file_to_blocks(file_name):
    if ".DS_Store" not in file_name:
#         print(file_name)
        file_blocks = read_data_rows_from_files(file_name)
        return file_blocks
    return []

# %%
def conver_files_to_one_df(data_dir, network=None):
    files = os.listdir(data_dir)
    dfs = pd.DataFrame([])
    for file_name in files:
        file = f"{data_dir}/{file_name}"
#         print(file)
#         print(dfs.shape)
        if os.path.isdir(file):
            network = file_name.upper()
            if "ALL" == network:
                network = 'ETH'
            df = conver_files_to_one_df(file, network)
#             print("Dir:", network, "Total Pairs: ", df.shape)
            dfs = dfs.append(df)
#             print("Dir Return, Dfs: ", dfs.shape)
        else:
            file_blocks = convert_file_to_blocks(file)
            pairs = get_pair_from_blocks(file_blocks, network=network)
            df = pd.DataFrame(pairs, columns=['pair1', 'pair2', 'apr', 'tvl', 'where', 'fee'])
            df['network'] = network
#             print(df.shape)
            dfs = dfs.append(df)
#             print("After File Apend, Dfs: ", dfs.shape)
    return dfs.reset_index(drop=True)

# %%
data_dir = './out'
pair_df = conver_files_to_one_df(data_dir)
# Out:
# 17 	 [MAHA]-[WETH] Uni LP
# 17 	 [ARTH]-[DAI] Uni LP
# 13 	 ARTH
# 8 	 Boardroom
# 8 	 Boardroom
# 8 	 Boardroom
# Bigger Block as Test
# 17 	 [TORN]-[WETH] Uni LP
# 15 	 [DAI]-[DEBASE] Uni LP
# 11 	 DAI
# 15 	 [DAI]-[DEBASE] Uni LP
# 15 	 [DAI]-[DEBASE] Uni LP
# Bigger Block as Test
# 12 	 [MARK 80%]-[WETH 20%]
# 12 	 [MARK 80%]-[USDC 20%]
# 15 	 [MARK]-[WETH] Uni LP
# 15 	 [MARK]-[USDC] Uni LP
# 12 	 alUSD
# 12 	 ALCX
# 16 	 [WETH]-[ALCX] SLP
# 11 	 alUSD3CRV-f
# 11 	 POOL
# 11 	 saddlealETH
# 16 	 [WETH]-[ALCX] SLP
# 16 	 [PLAY]-[DOUGH] SLP
# 16 	 [DOUGH]-[WETH] SLP
# 13 	 [WETH 20%]-[DOUGH 80%]
# 13 	 [DEFI+S 70%]-[WETH 30%]
# 13 	 [DEFI+L 70%]-[WETH 30%]
# 12 	 BCP
# 14 	 "reason": "cannot estimate gas; transaction may fail or may require manual gas limit",
# No Pair
# 17 	 [LEV]-[WETH] SLP
# 13 	 LEV
# 14 	 Current Epoch: 297
# No Pair
# Bigger Block as Test
# 15 	 [WETH]-[ICE] Uni LP
# 15 	 [WETH]-[ICE] SLP
# 11 	 ICE
# 15 	 [WETH]-[ICE] Uni LP
# 8 	 Staked: 73.7780 yUSDT ($81.32)
# No Pair
# 10 	 yvUSDT
# 11 	 ICE
# 11 	 USDT
# 14 	 Current Epoch: 198
# No Pair
# Bigger Block as Test
# 4 	 User DsProxy found at 0x0000000000000000000000000000000000000000
# No Pair
# 8 	 BTCx5-USDC-1Jun21-LP
# 8 	 BTCx5-USDC-1Jun21-UP
# 8 	 BTCx5-USDC-1Jun21-DOWN
# 8 	 ETHx5-USDC-1Jun21-LP
# 8 	 ETHx5-USDC-1Jun21-UP
# 8 	 ETHx5-USDC-1Jun21-DOWN
# 8 	 LINKx5-USDC-1Jun21-LP
# 8 	 LINKx5-USDC-1Jun21-UP
# 8 	 LINKx5-USDC-1Jun21-DOWN
# 8 	 UNIx5-USDC-1Jun21-LP
# 8 	 UNIx5-USDC-1Jun21-UP
# 9 	 UNIx5-USDC-1Jun21-DOWN
# 16 	 [COMFI]-[WETH] Uni LP
# 12 	 DOLA-3CRV3CRV-f
# 17 	 [INV]-[WETH] Uni LP
# 17 	 [DOLA]-[WETH] Uni LP
# 17 	 [WETH]-[UBI] Uni LP
# 17 	 [DAI]-[UBI] Uni LP
# 3 	 *** Participant Rewards ***
# No Pair
# 15 	 [USE]-[DAI] Uni LP
# 11 	 ELENA
# 11 	 MM
# 8 	 Staked: 50783.0784 m3Crv ($55,000.19)
# No Pair
# 15 	 [USDC]-[MM] Uni LP
# 8 	 Staked: 1.0278 mcrvRenWBTC ($49,468.61)
# No Pair
# 8 	 Staked: 97845.7597 mDAI ($105,228.51)
# No Pair
# 8 	 Staked: 103103.2879 mUSDC ($112,380.36)
# No Pair
# 10 	 [MIR]-[UST] Uni LP
# 15 	 [MM]-[WETH] SLP
# 15 	 [KP3R]-[MM] SLP
# 8 	 Staked: 197.3627 mWETH ($653,570.06)
# No Pair
# 8 	 Staked: 6399.9780 mUNI ($198,155.06)
# No Pair
# 8 	 Staked: 57.5220 mWBTC ($2,719,469.31)
# No Pair
# 8 	 Staked: 8359.1825 mLINK ($227,025.42)
# No Pair
# 8 	 Staked: 149397.7493 mZRX ($151,390.37)
# No Pair
# 8 	 Staked: 132.2681 mALCX ($93,541.37)
# No Pair
# 8 	 Staked: 128401.9612 malUSD ($144,603.09)
# No Pair
# 8 	 Staked: 52048.5995 musdp3CRV ($55,545.52)
# No Pair
# 8 	 Staked: 1.1381 mrenBTC ($53,504.10)
# No Pair
# 15 	 [MM]-[WETH] Uni LP
# 8 	 Staked: 8783.2705 myveCRV-DAO ($14,608.84)
# No Pair
# 8 	 Staked: 15913.7187 mTUSD ($16,244.03)
# No Pair
# 8 	 Staked: 5566.1951 mCVX ($28,817.74)
# No Pair
# 17 	 [KEEP]-[WETH] Uni LP
# 17 	 [TBTC]-[WETH] Uni LP
# 12 	 saddleTWRenSBTC
# 6 	 KEEP Price: $0.389576 TVL: $16,447,763.12
# No Pair
# 8 	 Staked: 10726465.0965 sd3Crv ($11,506,559.09)
# No Pair
# 8 	 Staked: 17534383.6733 sdeursCRV ($23,189,311.62)
# No Pair
# 8 	 Staked: 41.3439 sdcrvRenWSBTC ($1,515,814.76)
# No Pair
# 15 	 [SDT]-[WETH] Uni LP
# 15 	 [SDT]-[WETH] SLP
# 10 	 DUMMY
# 10 	 sdveCRV90-CRV10
# 8 	 Staked: 1943.5084 sdeCRV ($0.00)
# No Pair
# 8 	 Staked: 1065741.2834 sdFRAX3CRV-f ($1,065,784.21)
# No Pair
# 5 	 SDT
# 17 	 [ONS]-[DAI] Uni LP
# 17 	 [DAI]-[ONC] Uni LP
# 10 	 Boardroom
# 10 	 Boardroom
# 15 	 [NAWA]-[USDC] Uni LP
# 12 	 AAVE
# 12 	 BOND
# 12 	 COMP
# 12 	 SNX
# 12 	 SUSHI
# 12 	 LINK
# 12 	 ILV
# 16 	 [XYZ]-[USDC] SLP
# 15 	 [DEX]-[WETH] Uni LP
# 11 	 DEX
# 11 	 KIF
# 15 	 [KIF]-[WETH] Uni LP
# 15 	 [kBASEv0]-[USDC] Uni LP
# 11 	 kBASEv0
# 17 	 [GME]-[WETH] Uni LP
# 13 	 YFI
# 13 	 LINK
# 13 	 CREAM
# 13 	 renDOGE
# 13 	 USDT
# 13 	 BUSD
# 13 	 USDC
# 13 	 CRV
# 13 	 COMP
# 13 	 SUSHI
# 13 	 BADGER
# 13 	 DSD
# 13 	 ESD
# 13 	 FRAX
# 12 	 MIC
# 13 	 OGN
# 13 	 OUSD
# 13 	 CVP
# 13 	 ALBT
# 13 	 SPDR
# 15 	 [WETH]-[UPDOWN] Uni LP
# 11 	 UPDOWN
# 17 	 [PICKLE]-[WETH] Uni LP
# 13 	 Wrapped
# 11 	 p3Crv Price: $1.10 TVL: $670,592.21
# No Pair
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 11 	 psteCRV Price: $0.00 TVL: $0.00
# No Pair
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 13 	 Wrapped
# 11 	 pUSDC Price: $0.96 TVL: $6,455,708.87
# No Pair
# 11 	 pLUSD3CRV-f Price: $1.04 TVL: $663,126.43
# No Pair
# 13 	 Wrapped
# 11 	 pLQTY Price: $7.29 TVL: $4,620,325.11
# No Pair
# 16 	 [WBTC]-[LFBTC] SLP
# 16 	 [WETH]-[LFETH] SLP
# 16 	 [LFBTC]-[LIFT] SLP
# 15 	 [BAO]-[WETH] Uni LP
# 15 	 [WBTC]-[WETH] Uni LP
# 15 	 [WETH]-[USDT] Uni LP
# 15 	 [LINK]-[WETH] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [cDAI]-[WETH] Uni LP
# 15 	 [OKB]-[WETH] Uni LP
# 15 	 [LEO]-[WETH] Uni LP
# 15 	 [DAI]-[WETH] Uni LP
# 15 	 [UNI]-[WETH] Uni LP
# 15 	 [HT]-[WETH] Uni LP
# 15 	 [AAVE]-[WETH] Uni LP
# 15 	 [CEL]-[WETH] Uni LP
# 15 	 [SNX]-[WETH] Uni LP
# 15 	 [WETH]-[CRV] Uni LP
# 15 	 [YFI]-[WETH] Uni LP
# 15 	 [COMP]-[WETH] Uni LP
# 15 	 [MKR]-[WETH] Uni LP
# 15 	 [UMA]-[WETH] Uni LP
# 15 	 [FTX Token]-[WETH] Uni LP
# 15 	 [WETH]-[renBTC] Uni LP
# 15 	 [BAT]-[WETH] Uni LP
# 15 	 [TUSD]-[WETH] Uni LP
# 15 	 [WETH]-[HUSD] Uni LP
# 15 	 [WETH]-[ZRX] Uni LP
# 15 	 [aETH]-[WETH] Uni LP
# 15 	 [OCEAN]-[WETH] Uni LP
# 15 	 [WETH]-[KNC] Uni LP
# 15 	 [WETH]-[AMPL] Uni LP
# 15 	 [wNXM]-[WETH] Uni LP
# 15 	 [RSR]-[WETH] Uni LP
# 15 	 [WETH]-[ENJ] Uni LP
# 15 	 [BAND]-[WETH] Uni LP
# 15 	 [NMR]-[WETH] Uni LP
# 15 	 [BAL]-[WETH] Uni LP
# 15 	 [NEXO]-[WETH] Uni LP
# 15 	 [ANT]-[WETH] Uni LP
# 15 	 [MANA]-[WETH] Uni LP
# 15 	 [SNT]-[WETH] Uni LP
# 15 	 [ESD]-[USDC] Uni LP
# 15 	 [yyDAI+yUSDC+yUSDT+yTUSD]-[WETH] Uni LP
# 15 	 [MATIC]-[WETH] Uni LP
# 15 	 [PAXG]-[WETH] Uni LP
# 15 	 [WETH]-[GT] Uni LP
# 15 	 [SXP]-[WETH] Uni LP
# 15 	 [REP]-[WETH] Uni LP
# 15 	 [CVC]-[WETH] Uni LP
# 15 	 [HEGIC]-[WETH] Uni LP
# 15 	 [WFIL]-[USDC] Uni LP
# 15 	 [HBTC]-[WETH] Uni LP
# 15 	 [cUNI]-[WETH] Uni LP
# 15 	 [WETH]-[UOS] Uni LP
# 15 	 [WETH]-[UTK] Uni LP
# 15 	 [WETH]-[SHR] Uni LP
# 15 	 [Titan]-[WETH] Uni LP
# 15 	 [MPH]-[WETH] Uni LP
# 15 	 [sUSD]-[WETH] Uni LP
# 15 	 [MATH]-[WETH] Uni LP
# 15 	 [SRM]-[WETH] Uni LP
# 15 	 [cZRX]-[WETH] Uni LP
# 15 	 [RPL]-[WETH] Uni LP
# 15 	 [STORJ]-[WETH] Uni LP
# 15 	 [BNT]-[WETH] Uni LP
# 15 	 [ANKR]-[WETH] Uni LP
# 15 	 [UBT]-[WETH] Uni LP
# 15 	 [FTM]-[WETH] Uni LP
# 15 	 [AGI]-[WETH] Uni LP
# 15 	 [POLY]-[WETH] Uni LP
# 15 	 [ELF]-[WETH] Uni LP
# 15 	 [DNT]-[WETH] Uni LP
# 15 	 [PNK]-[WETH] Uni LP
# 15 	 [HXRO]-[WETH] Uni LP
# 15 	 [NPXS]-[WETH] Uni LP
# 15 	 [WZEC]-[USDC] Uni LP
# 15 	 [CORE]-[WETH] Uni LP
# 15 	 [WETH]-[mUSD] Uni LP
# 15 	 [WETH]-[EURS] Uni LP
# 15 	 [WETH]-[AXS] Uni LP
# 15 	 [WETH]-[BTMX] Uni LP
# 15 	 [LPT]-[WETH] Uni LP
# 15 	 [WETH]-[DGTX] Uni LP
# 15 	 [WETH]-[ENG] Uni LP
# 15 	 [FET]-[WETH] Uni LP
# 15 	 [FARM]-[USDC] Uni LP
# 15 	 [ADX]-[WETH] Uni LP
# 15 	 [STAKE]-[WETH] Uni LP
# 15 	 [BZRX]-[WETH] Uni LP
# 15 	 [IDEX]-[WETH] Uni LP
# 15 	 [WETH]-[NEC] Uni LP
# 15 	 [SAND]-[WETH] Uni LP
# 15 	 [WETH]-[MLN] Uni LP
# 15 	 [CREAM]-[WETH] Uni LP
# 15 	 [DPI]-[WETH] Uni LP
# 15 	 [TBTC]-[WETH] Uni LP
# 15 	 [LOOM]-[WETH] Uni LP
# 15 	 [MX]-[WETH] Uni LP
# 15 	 [KP3R]-[WETH] Uni LP
# 15 	 [AKRO]-[WETH] Uni LP
# 15 	 [REQ]-[WETH] Uni LP
# 15 	 [QSP]-[WETH] Uni LP
# 15 	 [MTA]-[WETH] Uni LP
# 15 	 [AST]-[WETH] Uni LP
# 15 	 [DUSD]-[WETH] Uni LP
# 15 	 [BTSE]-[WETH] Uni LP
# 15 	 [DF]-[WETH] Uni LP
# 15 	 [WETH]-[DMG] Uni LP
# 15 	 [WETH]-[KARMA] Uni LP
# 15 	 [TKN]-[WETH] Uni LP
# 15 	 [PNT]-[WETH] Uni LP
# 15 	 [YAM]-[WETH] Uni LP
# 15 	 [AUDIO]-[WETH] Uni LP
# 15 	 [GHST]-[WETH] Uni LP
# 15 	 [SWRV]-[WETH] Uni LP
# 15 	 [FOAM]-[WETH] Uni LP
# 15 	 [LIEN]-[WETH] Uni LP
# 15 	 [WETH]-[PRE] Uni LP
# 15 	 [GEN]-[WETH] Uni LP
# 15 	 [JRT]-[WETH] Uni LP
# 15 	 [WETH]-[MEME] Uni LP
# 15 	 [BOND]-[USDC] Uni LP
# 15 	 [APY]-[WETH] Uni LP
# 15 	 [INDEX]-[WETH] Uni LP
# 15 	 [USDC]-[DHT] Uni LP
# 15 	 [DOUGH]-[WETH] Uni LP
# 15 	 [HGET]-[WETH] Uni LP
# 15 	 [BFT]-[WETH] Uni LP
# 15 	 [WETH]-[ROOK] Uni LP
# 15 	 [YAMv2]-[WETH] Uni LP
# 15 	 [DFD]-[WETH] Uni LP
# 15 	 [BLT]-[WETH] Uni LP
# 15 	 [SLP]-[WETH] Uni LP
# 15 	 [WETH]-[HYDRO] Uni LP
# 15 	 [KRL]-[WETH] Uni LP
# 15 	 [RSV]-[WETH] Uni LP
# 15 	 [HOT]-[WETH] Uni LP
# 15 	 [ADEL]-[WETH] Uni LP
# 15 	 [SOCKS]-[WETH] Uni LP
# 15 	 [WETH]-[WAR] Uni LP
# 15 	 [0xBTC]-[WETH] Uni LP
# 15 	 [WETH]-[DONUT] Uni LP
# 15 	 [TTT]-[WETH] Uni LP
# 15 	 [REPv2]-[WETH] Uni LP
# 15 	 [GNO]-[WETH] Uni LP
# 15 	 [WETH]-[AUC] Uni LP
# 15 	 [YAX]-[WETH] Uni LP
# 15 	 [OCTO]-[WETH] Uni LP
# 15 	 [VALUE]-[WETH] Uni LP
# 15 	 [WETH]-[SHROOM] Uni LP
# 15 	 [WETH]-[RGT] Uni LP
# 15 	 [SEED]-[WETH] Uni LP
# 15 	 [WG0]-[WETH] Uni LP
# 15 	 [WETH]-[WOA] Uni LP
# 15 	 [UBXT]-[WETH] Uni LP
# 15 	 [BEST]-[WETH] Uni LP
# 15 	 [TOMOE]-[WETH] Uni LP
# 15 	 [WETH]-[HEZ] Uni LP
# 15 	 [PICKLE]-[WETH] Uni LP
# 15 	 [WETH]-[ENCORE] Uni LP
# 15 	 [YFIM]-[WETH] Uni LP
# 15 	 [WETH]-[ORO] Uni LP
# 15 	 [XOR]-[WETH] Uni LP
# 15 	 [REN]-[WETH] Uni LP
# 15 	 [LRC]-[WETH] Uni LP
# 15 	 [CVP]-[WETH] Uni LP
# 15 	 [JUL]-[WETH] Uni LP
# 15 	 [KEEP]-[WETH] Uni LP
# 15 	 [WETH]-[RMPL] Uni LP
# 15 	 [OWL]-[WETH] Uni LP
# 15 	 [WETH]-[RARI] Uni LP
# 15 	 [SUSHI]-[WETH] Uni LP
# 15 	 [ORN]-[WETH] Uni LP
# 15 	 [CHART]-[WETH] Uni LP
# 15 	 [XIO]-[WETH] Uni LP
# 15 	 [YFL]-[WETH] Uni LP
# 15 	 [WETH]-[SWAP] Uni LP
# 15 	 [BUSD]-[USDC] Uni LP
# 15 	 [POLS]-[WETH] Uni LP
# 15 	 [HAUT]-[WETH] Uni LP
# 15 	 [ALMX]-[WETH] Uni LP
# 15 	 [CANDY]-[WETH] Uni LP
# 15 	 [COKE]-[WETH] Uni LP
# 15 	 [BUGS]-[WETH] Uni LP
# 15 	 [WETH]-[sDEFI] Uni LP
# 15 	 [ALPHA]-[WETH] Uni LP
# 15 	 [WVG0]-[WETH] Uni LP
# 15 	 [KP4R]-[WETH] Uni LP
# 15 	 [IDLE]-[WETH] Uni LP
# 15 	 [PERP]-[WETH] Uni LP
# 15 	 [ZAP]-[WETH] Uni LP
# 15 	 [COVER]-[WETH] Uni LP
# 15 	 [CRE]-[WETH] Uni LP
# 15 	 [L2]-[WETH] Uni LP
# 15 	 [DODO]-[WETH] Uni LP
# 15 	 [API3]-[WETH] Uni LP
# 15 	 [WETH]-[FRONT] Uni LP
# 15 	 [SKL]-[WETH] Uni LP
# 15 	 [TRU]-[WETH] Uni LP
# 15 	 [DEXT]-[WETH] Uni LP
# 15 	 [eXRD]-[WETH] Uni LP
# 15 	 [BAO]-[WETH] SLP
# 15 	 [BAO]-[USDC] SLP
# 15 	 [YFI]-[BAO] SLP
# 15 	 [BAO]-[SUSHI] SLP
# 15 	 [BAO]-[DAI] SLP
# 11 	 xSUSHI
# 15 	 [SUSHI]-[xSUSHI] SLP
# 15 	 [xSUSHI]-[WETH] SLP
# 15 	 [WETH]-[GRT] Uni LP
# 15 	 [RUNE]-[WETH] SLP
# 15 	 [1INCH]-[WETH] Uni LP
# 15 	 [WETH]-[FIDA] Uni LP
# 15 	 [NFTX]-[WETH] SLP
# 15 	 [sETH]-[WETH] Uni LP
# 15 	 [WETH]-[aETHc] Uni LP
# 15 	 [stETH]-[WETH] Uni LP
# 15 	 [WETH]-[INJ] Uni LP
# 15 	 [GRO]-[WETH] Uni LP
# 15 	 [WETH]-[TVK] Uni LP
# 15 	 [FRAX]-[USDC] Uni LP
# 15 	 [DAI]-[USDC] Uni LP
# 15 	 [LDO]-[WETH] Uni LP
# 15 	 [BADGER]-[WETH] Uni LP
# 15 	 [BOR]-[WETH] SLP
# 17 	 [FEI]-[TRIBE] Uni LP
# 10 	 SIG-LP
# 15 	 [SIG]-[WETH] Uni LP
# 10 	 mock-lp
# 11 	 SIG
# 15 	 [UNIC]-[WETH] Unic Swap LP
# 15 	 [uGOTCHI]-[WETH] Unic Swap LP
# 15 	 [uDOKI]-[WETH] Unic Swap LP
# 15 	 [uPUNK]-[WETH] Unic Swap LP
# 15 	 [uMASK]-[WETH] Unic Swap LP
# 15 	 [uAXIE]-[WETH] Unic Swap LP
# 15 	 [uCM]-[WETH] Unic Swap LP
# 15 	 [uWAIFU]-[WETH] Unic Swap LP
# 15 	 [uUNICLY]-[WETH] Unic Swap LP
# 15 	 [uMOON]-[WETH] Unic Swap LP
# 15 	 [uJORDAN]-[WETH] Unic Swap LP
# 15 	 [WETH]-[uGONE] Unic Swap LP
# 15 	 [WETH]-[uGLYPH] Unic Swap LP
# 15 	 [uPAK]-[WETH] Unic Swap LP
# 15 	 [WETH]-[uARTBLOCKS] Unic Swap LP
# 15 	 [uREVV]-[WETH] Unic Swap LP
# 15 	 [uARC]-[WETH] Unic Swap LP
# 15 	 [uJENNY]-[WETH] Unic Swap LP
# 15 	 [WETH]-[uFEWO] Unic Swap LP
# 10 	 FAUCETPROXY
# 15 	 [uPMON]-[WETH] Unic Swap LP
# 15 	 [WETH]-[uGMC] Unic Swap LP
# 15 	 [UNIC]-[uJENNY] Unic Swap LP
# 15 	 [uUNICLY]-[UNIC] Unic Swap LP
# 15 	 [uCM]-[UNIC] Unic Swap LP
# 15 	 [uAXIE]-[UNIC] Unic Swap LP
# 15 	 [uMOON]-[UNIC] Unic Swap LP
# 15 	 [uDOKI]-[UNIC] Unic Swap LP
# 10 	 XUNICPROXY2
# 15 	 [uAAH]-[WETH] Unic Swap LP
# 8 	 [UNIC]-[WETH] Unic Swap LP
# 8 	 [uGOTCHI]-[WETH] Unic Swap LP
# 8 	 [uDOKI]-[WETH] Unic Swap LP
# 8 	 [uPUNK]-[WETH] Unic Swap LP
# 8 	 [uMASK]-[WETH] Unic Swap LP
# 8 	 [uAXIE]-[WETH] Unic Swap LP
# 8 	 [uCM]-[WETH] Unic Swap LP
# 8 	 [uWAIFU]-[WETH] Unic Swap LP
# 8 	 [uUNICLY]-[WETH] Unic Swap LP
# 8 	 [WETH]-[uBEEPLE] Unic Swap LP
# 8 	 [uMOON]-[WETH] Unic Swap LP
# 8 	 [uJORDAN]-[WETH] Unic Swap LP
# 8 	 [WETH]-[uGONE] Unic Swap LP
# 8 	 [WETH]-[uGLYPH] Unic Swap LP
# 8 	 [uPAK]-[WETH] Unic Swap LP
# 8 	 [WETH]-[uARTBLOCKS] Unic Swap LP
# 8 	 [uREVV]-[WETH] Unic Swap LP
# 8 	 [uARC]-[WETH] Unic Swap LP
# 8 	 [uJENNY]-[WETH] Unic Swap LP
# 8 	 [WETH]-[uAPE] Unic Swap LP
# 8 	 [WETH]-[uFEWO] Unic Swap LP
# 8 	 [uAPE]-[WETH] Unic Swap LP
# 3 	 XUNICPROXY
# 3 	 FAUCETPROXY
# 8 	 [uPMON]-[WETH] Unic Swap LP
# 8 	 [WETH]-[uGMC] Unic Swap LP
# 8 	 [UNIC]-[uJENNY] Unic Swap LP
# 8 	 [uUNICLY]-[UNIC] Unic Swap LP
# 8 	 [uCM]-[UNIC] Unic Swap LP
# 8 	 [uAXIE]-[UNIC] Unic Swap LP
# 8 	 [uMOON]-[UNIC] Unic Swap LP
# 8 	 [uDOKI]-[UNIC] Unic Swap LP
# 3 	 XUNICPROXY2
# 8 	 [uAAH]-[WETH] Unic Swap LP
# 17 	 [FXS]-[WETH] Uni LP
# 17 	 [FRAX]-[WETH] Uni LP
# 17 	 [FRAX]-[USDC] Uni LP
# 17 	 [FXS]-[FRAX] Uni LP
# 14 	 FRAX3CRV-f
# 15 	 [SHIB]-[WETH] SLP
# 15 	 [LEASH]-[WETH] SLP
# 15 	 [WBTC]-[WETH] SLP
# 15 	 [USDC]-[WETH] SLP
# 15 	 [SUSHI]-[WETH] SLP
# 15 	 [UNI]-[WETH] SLP
# 15 	 [LINK]-[WETH] SLP
# 15 	 [DAI]-[WETH] SLP
# 15 	 [xFUND]-[WETH] SLP
# 15 	 [SNX]-[WETH] SLP
# 15 	 [WETH]-[MEME] SLP
# 15 	 [WETH]-[GRT] SLP
# 15 	 [DUCK]-[WETH] SLP
# 15 	 [ELON]-[WETH] SLP
# 15 	 [VXV]-[WETH] SLP
# 15 	 [BONE]-[WETH] SLP
# 15 	 [LEASH]-[BONE] SLP
# 15 	 [WETH]-[USDT] SLP
# 15 	 [SHIB]-[BONE] SLP
# 15 	 [F9]-[WETH] SLP
# 15 	 [UFO]-[WETH] SLP
# 15 	 [STARL]-[WETH] SLP
# 15 	 [ZIG]-[WETH] SLP
# 15 	 [RYOSHI]-[WETH] SLP
# 15 	 [WETH]-[PERL] SLP
# 11 	 WHEY
# 15 	 [WETH]-[WHEY] SLP
# 15 	 [CNTR]-[WETH] Uni LP
# 11 	 CS-WETH
# 11 	 CS-DAI
# 11 	 CS-USDT
# 17 	 [WOWS]-[WETH] Uni LP
# 14 	 [Gelato Uniswap V3 INST/ETH LP 1]
# 15 	 [renDOGE]-[WETH] Uni LP
# 15 	 [SHIB]-[WETH] Uni LP
# 15 	 [AKITA]-[WETH] Uni LP
# 15 	 [WETH]-[HOKK] Uni LP
# 15 	 [KISHU]-[WETH] Uni LP
# 15 	 [SNOGE]-[WETH] Uni LP
# 15 	 [WETH]-[HUSKY] Uni LP
# 15 	 [WOGE]-[WETH] Uni LP
# 15 	 [DOGEN]-[WETH] Uni LP
# 15 	 [DOGEN]-[renDOGE] Uni LP
# 15 	 [POODL]-[WETH] Uni LP
# 15 	 [CHONK]-[WETH] Uni LP
# 15 	 [ROGE]-[WETH] Uni LP
# 15 	 [CoShi]-[WETH] Uni LP
# 15 	 [DOGEFI]-[WETH] Uni LP
# 15 	 [PUP]-[WETH] Uni LP
# 15 	 [ELON]-[WETH] Uni LP
# 15 	 [STOGE]-[WETH] Uni LP
# 15 	 [SHIBAKEN]-[WETH] Uni LP
# 15 	 [Tosa]-[WETH] Uni LP
# 15 	 [WETH]-[HOGE] Uni LP
# 15 	 [DOGEN]-[MUSKY] Uni LP
# 15 	 [JSHIBA]-[DOGEN] Uni LP
# 15 	 [DOGEN]-[BDOG] Uni LP
# 15 	 [MUSKY]-[WETH] Uni LP
# 15 	 [DOGEN]-[HACHIKO] Uni LP
# 15 	 [DOGEN]-[POODL] Uni LP
# 15 	 [DOGEN]-[WDOGE] Uni LP
# 15 	 [DOGEN]-[PUP] Uni LP
# 15 	 [DOGEN]-[SOGE] Uni LP
# 15 	 [DOGEN]-[Tosa] Uni LP
# 15 	 [WETH]-[DIASPORA] Uni LP
# 10 	 dUSD
# 15 	 [DOGEN]-[dUSD] SLP
# 10 	 DOG5
# 16 	 [FORCE]-[WETH] SLP
# 10 	 Current Epoch: 573
# No Pair
# 21 	 [VSD]-[USDT] Uni LP
# 21 	 [VSD]-[DAI] Uni LP
# 21 	 [VSD]-[USDC] Uni LP
# Bigger Block as Test
# 13 	 [XDEX 36%]-[DAI 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[ZKS 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[UNI 32%]-[DAI 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[ZRX 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[CRV 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[BAL 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[SUSHI 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[USDT 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[MEME 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[USDC 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[MKR 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[WBTC 32%]-[DAI 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[COMP 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[YFI 32%]-[DAI 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[CELR 32%]-[DAI 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[REN 32%]-[DAI 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[MFT 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[CRO 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[ANKR 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[SAND 32%]-[DAI 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[WETH 32%]-[AXS 32%]
# No Pair
# 14 	 [XDEX 4%]-[DAI 32%]-[TVK 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[FXS 32%]-[FRAX 32%]-[WETH 32%]
# No Pair
# 14 	 [XDEX 4%]-[sUSD 32%]-[SNX 32%]-[WETH 32%]
# No Pair
# 13 	 [XDEX 4%]-[USDC 48%]-[DORA 48%]
# No Pair
# 13 	 [XDEX 4%]-[DAI 32%]-[WETH 64%]
# No Pair
# 15 	 [DFX]-[WETH] SLP
# 14 	 [EURS 50%]-[USDC 50%]
# 14 	 [CADC 50%]-[USDC 50%]
# 14 	 [XSGD 50%]-[USDC 50%]
# 12 	 dfx-cadc-a
# 12 	 dfx-eurs-a
# 12 	 dfx-xsgd-a
# Bigger Block as Test
# 17 	 [WETH]-[KINE] Uni LP
# 17 	 [WETH]-[kUSD] Uni LP
# 17 	 [kUSD]-[USDT] Uni LP
# 17 	 [FST]-[WETH] Uni LP
# 13 	 B26
# 13 	 B26
# 13 	 B26
# 5 	 Rewards start at block 12213000 and end at block 12293639
# No Pair
# 11 	 WETH
# 11 	 WBTC
# 11 	 USDC
# 11 	 DAI
# 15 	 [WETH]-[BAG] Uni LP
# 15 	 There is a locking period for the pools, for more information please visit the website
# No Pair
# 10 	 BAG
# 10 	 BAG
# 15 	 [WETH]-[BAG] Uni LP
# 19 	 [rDPX]-[WETH] Uni LP
# 19 	 [WETH]-[DPX] Uni LP
# 15 	 DPX
# 14 	 [sUSD 80%]-[sAAPL 20%]
# 14 	 [sUSD 80%]-[sAMZN 20%]
# 14 	 [sUSD 80%]-[sCOIN 20%]
# 14 	 [sUSD 80%]-[sFB 20%]
# 14 	 [sUSD 80%]-[sGOOG 20%]
# 14 	 [sUSD 80%]-[sMSFT 20%]
# 14 	 [sUSD 80%]-[sNFLX 20%]
# 13 	 crvPlain3andSUSD
# 8 	 sBTC
# 10 	 sETH
# 12 	 ROOM
# 17 	 [ROOM]-[WETH] Uni LP
# 13 	 HT
# 12 	 MATTER
# 11 	 LPOOL
# 11 	 LPOOL
# 11 	 LPOOL
# 11 	 LPOOL
# 15 	 [LPOOL]-[WETH] Uni LP
# 17 	 [KLTR]-[WETH] Uni LP
# 17 	 [BLZ]-[WETH] Uni LP
# 17 	 [PFARM]-[WETH] Uni LP
# 15 	 [SPELL]-[WETH] SLP
# 10 	 MIM-3LP3CRV-f
# 15 	 [MIM]-[WETH] SLP
# 23 	 Portfolio
# 15 	 [LINK]-[WETH] SLP
# 15 	 [COMP]-[WETH] SLP
# 15 	 [SAKE]-[WETH] SLP
# 15 	 [DAI]-[WETH] SLP
# 15 	 [LINK]-[USDT] SLP
# 15 	 [WBTC]-[WETH] SLP
# 15 	 [WETH]-[USDT] SLP
# 15 	 [USDC]-[WETH] SLP
# 15 	 [BIKI]-[USDT] SLP
# 15 	 [WETH]-[vETH] SLP
# 15 	 [WETH]-[FOTO] SLP
# 15 	 [ECAT]-[WETH] SLP
# 15 	 [USDC]-[USDT] SLP
# 15 	 [WBTC]-[USDT] SLP
# 10 	 SakeLock
# 15 	 [WETH]-[FANS] SLP
# 17 	 [MINT]-[WETH] Uni LP
# 17 	 [XBE]-[USDT] Uni LP
# 17 	 [XBE]-[USDT] SLP
# 5 	 Rewards start at block 12341940
# No Pair
# 15 	 [USDC]-[Gaia] Uni LP
# 15 	 [USDf]-[USDC] Uni LP
# 15 	 [SHARE]-[WETH] Uni LP
# 15 	 [WETH]-[Gaia] Uni LP
# 15 	 [oneETH]-[WETH] Uni LP
# 15 	 [ICHI]-[WETH] Uni LP
# 15 	 [oneETH]-[ICHI] Uni LP
# 15 	 [ICHI]-[oneBTC] Uni LP
# 15 	 [WBTC]-[oneBTC] Uni LP
# 15 	 [ICHI]-[WETH] Uni LP
# 15 	 [oneLINK]-[LINK] Uni LP
# 15 	 [WBTC]-[oneBTC] SLP
# 15 	 [oneLINK]-[LINK] SLP
# 15 	 [ICHI]-[WETH] SLP
# 15 	 [ERN]-[WETH] Uni LP
# 20 	 [USDC]-[USDT] DMM-LP USDC-USDT
# 20 	 [WETH]-[USDT] DMM-LP WETH-USDT
# 20 	 [WBTC]-[USDT] DMM-LP WBTC-USDT
# 20 	 [WBTC]-[WETH] DMM-LP WBTC-WETH
# 20 	 [WETH]-[KNC] DMM-LP WETH-KNC
# 17 	 [ARMOR]-[WETH] Uni LP
# 17 	 [ARMOR]-[DAI] Uni LP
# 17 	 [ARMOR]-[WBTC] Uni LP
# 17 	 [ARMOR]-[WETH] SLP
# 17 	 [ARMOR]-[DAI] SLP
# 17 	 [ARMOR]-[WBTC] SLP
# 14 	 [ETH]-[ARMOR] 1INCH LP
# 14 	 [ARMOR]-[DAI] 1INCH LP
# 14 	 [ARMOR]-[WBTC] 1INCH LP
# 14 	 [ARMOR 98%]-[WETH 2%]
# 14 	 [DAI 98%]-[ARMOR 2%]
# 17 	 [ARMOR]-[arNXM] Uni LP
# 17 	 [arNXM]-[WETH] Uni LP
# 17 	 [arNXM]-[WETH] SLP
# 14 	 [ETH]-[arNXM] 1INCH LP
# 14 	 [arNXM 98%]-[WETH 2%]
# 17 	 [wNXM]-[arNXM] Uni LP
# 17 	 [wNXM]-[arNXM] SLP
# 17 	 [DAI]-[BSGS] Uni LP
# 17 	 [DAI]-[BSG] Uni LP
# 8 	 Boardroom
# 17 	 saddleD4
# 16 	 [TRU]-[WETH] Uni LP
# 14 	 [DAI 40%]-[BAL 57.99999999999999%]-[TRU 2%]
# No Pair
# 16 	 [TUSD]-[tfTUSD] Uni LP
# 11 	 tfTUSD
# 13 	 DAIQ
# 17 	 Initialized 0xbd106eeb1f0ed1528bc631e1616ea8aea59ad0fd
# No Pair
# Bigger Block as Test
# 15 	 [KKO]-[WETH] SLP
# 11 	 KKO
# 11 	 USDC
# 11 	 USDT
# 11 	 DAI
# 10 	 FAKEVOL
# 14 	 ALPHR Address: 0xaa99199d1e9644b588796F3215089878440D58e0
# No Pair
# 15 	 [YAX]-[WETH] Uni LP
# 11 	 MVLT Price: $1.11 TVL: $5,519,255.46
# No Pair
# 13 	 YAXIS
# 17 	 [YAXIS]-[WETH] Uni LP
# 17 	 [USDap]-[USDC] Uni LP
# 17 	 [BAG]-[USDT] Uni LP
# 17 	 [BAG]-[USDN] Uni LP
# 17 	 [BAG]-[USDC] Uni LP
# 17 	 [BAG]-[USDap] Uni LP
# 17 	 [WETH]-[SI] Uni LP
# 6 	 WBTC
# 6 	 USDC
# 6 	 SUSHI
# 7 	 USDC
# 17 	 [WETH]-[SI] SLP
# 19 	 USDC/OIL Uniswap Pool
# No Pair
# 15 	 [UMBR]-[WETH] Uni LP
# Bigger Block as Test
# 17 	 [LUDUS]-[WETH] Uni LP
# 13 	 LUDUS
# 15 	 [MUSE]-[WETH] Uni LP
# 15 	 [MEME20]-[WETH] Uni LP
# 15 	 [WETH]-[MASK20] Uni LP
# 15 	 [DUDES20]-[WETH] Uni LP
# 15 	 [WETH]-[GPUNKS20] Uni LP
# 15 	 [WETH]-[MCAT20] Uni LP
# 15 	 [CHUBBIES20]-[WETH] Uni LP
# 15 	 [BAYC20]-[WETH] Uni LP
# 15 	 [MEEBITS20]-[WETH] Uni LP
# 15 	 [CAT20]-[WETH] Uni LP
# 15 	 [WETH]-[GCG] Uni LP
# 15 	 [WETH]-[TABOY20] Uni LP
# 15 	 [KONGZ20]-[WETH] Uni LP
# 15 	 [COOL20]-[WETH] Uni LP
# 15 	 [WILD]-[WETH] Uni LP
# 5 	 *** Old pool, please unstake ***
# No Pair
# 15 	 [WILD]-[WETH] Uni LP
# 15 	 [CYC]-[WETH] Uni LP
# 17 	 [🐟]-[WETH] Uni LP
# 17 	 [UNI]-[🐟] Uni LP
# 17 	 [🐟]-[USDC] Uni LP
# 17 	 [⛩️]-[🐟] Uni LP
# 17 	 [FUSE]-[USDC] Uni LP
# 17 	 [FUSE]-[WETH] Uni LP
# 17 	 [SGT]-[WETH] Uni LP
# 13 	 SGT
# 13 	 vETH2
# 17 	 [SGT]-[vETH2] Uni LP
# 12 	 saddleVETH2
# 17 	 [SGT]-[WETH] Uni LP
# 13 	 SGT
# 13 	 vETH2
# 15 	 [SXP]-[USDT] SLP
# 15 	 [SXP]-[WETH] SLP
# 15 	 [WBTC]-[SXP] SLP
# 15 	 [USDC]-[WETH] SLP
# 15 	 [DAI]-[WETH] SLP
# 15 	 [WETH]-[USDT] SLP
# 15 	 [WBTC]-[WETH] SLP
# 15 	 [USDC]-[USDT] SLP
# 15 	 [DAI]-[USDC] SLP
# 17 	 [SAND]-[WETH] Uni LP
# 10 	 D-MINTER
# 22 	 BASK
# 12 	 WASABI
# 12 	 waUSD
# 16 	 [WASABI]-[WETH] SLP
# 11 	 waUSD3CRV-f
# 12 	 waBTC
# 12 	 waLUSD
# 12 	 waETH
# 8 	 Badger/wBTC Sushi-LP -
# No Pair
# Bigger Block as Test
# Bigger Block as Test
# 24 	 [WBTC]-[DIGG] Uni LP
# 23 	 [WBTC]-[DIGG] SLP
# 19 	 BADGER
# 14 	 DIGG
# Bigger Block as Test
# Bigger Block as Test
# 20 	 crvRenWBTC
# 15 	 [WBTC]-[ibBTC] SLP
# Bigger Block as Test
# 11 	 cvxCRV
# 6 	 CVX
# 13 	 [STBZ]-[WETH] Uni LP
# 9 	 DAI
# 9 	 USDC
# 9 	 USDT
# Bigger Block as Test
# 17 	 [LUSD]-[WETH] Uni LP
# 12 	 FARM
# 16 	 [FARM]-[WETH] Uni LP
# 16 	 [FARM]-[USDC] Uni LP
# 16 	 [GRAIN]-[FARM] Uni LP
# 10 	 fWETH Price: $3,249.64 TVL: $32,109,414.82
# No Pair
# 12 	 Wrapped
# 12 	 Wrapped
# 12 	 Wrapped
# 10 	 fBAC Price: $0.05 TVL: $58.62
# No Pair
# 10 	 fESD Price: $0.06 TVL: $13,908.26
# No Pair
# 10 	 fDSD Price: $0.02 TVL: $1,330.92
# No Pair
# 10 	 fyDAI+yUSDC+yUSDT+yTUSD Price: $1.15 TVL: $640,758.56
# No Pair
# 10 	 fhusd3CRV Price: $0.00 TVL: $0.00
# No Pair
# 10 	 fcDAI+cUSDC Price: $1.11 TVL: $1,051,743.09
# No Pair
# 10 	 fyDAI+yUSDC+yUSDT+yBUSD Price: $1.14 TVL: $2,084,620.51
# No Pair
# 10 	 fusdn3CRV Price: $0.00 TVL: $0.00
# No Pair
# 10 	 fUSDC Price: $0.91 TVL: $28,496,236.82
# No Pair
# 10 	 fUSDT Price: $0.92 TVL: $21,581,308.03
# No Pair
# 10 	 fTUSD Price: $1.06 TVL: $24,882.63
# No Pair
# 10 	 fDAI Price: $1.06 TVL: $31,201,144.23
# No Pair
# 12 	 Wrapped
# 12 	 Wrapped
# 12 	 Wrapped
# 12 	 Wrapped
# 10 	 fhCRV Price: $0.00 TVL: $0.00
# No Pair
# 10 	 foBTC/sbtcCRV Price: $49,210.63 TVL: $8,200,045.36
# No Pair
# 10 	 ftbtc/sbtcCrv Price: $48,839.16 TVL: $96,799.94
# No Pair
# 10 	 fcrvRenWBTC Price: $47,792.36 TVL: $29,745,991.62
# No Pair
# 10 	 fWBTC Price: $46,866.50 TVL: $535,972.01
# No Pair
# 10 	 frenBTC Price: $46,438.89 TVL: $114,063.70
# No Pair
# 12 	 Wrapped
# 12 	 Wrapped
# 12 	 Wrapped
# 12 	 Wrapped
# 15 	 [MOMA]-[WETH] Uni LP
# 17 	 [ALN]-[WETH] Uni LP
# 14 	 [OHM]-[DAI] SLP
# 14 	 Current Epoch: 382
# No Pair
# Bigger Block as Test
# 17 	 [WBTC]-[KBTC] Uni LP
# 17 	 [WBTC]-[KlonX] Uni LP
# 17 	 [KXUSD]-[DAI] Uni LP
# 12 	 EMI LP
# No Pair
# 13 	 ESW
# 12 	 EMI LP
# No Pair
# 12 	 EMI LP
# No Pair
# 12 	 EMI LP
# No Pair
# 12 	 EMI LP
# No Pair
# 11 	 YEL
# 15 	 [YEL]-[WETH] SLP
# 17 	 [DAI]-[BAS] Uni LP
# 17 	 [BAC]-[DAI] Uni LP
# 8 	 Boardroom
# 13 	 GDAO
# Bigger Block as Test
# Bigger Block as Test
# 13 	 Current Epoch: 3125
# No Pair
# 24 	 [USDC]-[DSD] Uni LP
# 15 	 [WETH]-[VBTC] Uni LP
# 15 	 [$TRDL]-[WETH] SLP
# 16 	 [UNI-V2 16.69114701562267%]-[WETH 16.69114701562267%]-[$TRDL 16.68447055681667%]-[VBTC 16.68447055681667%]-[vBCH 16.624382427560665%]-[oneVBTC 16.624382427560665%]
# No Pair
# 15 	 [vBCH]-[WETH] Uni LP
# 14 	 [VBTC 25%]-[PUNK 25%]-[BAYC 25%]-[COOL 25%]
# No Pair
# 17 	 [XTK]-[WETH] Uni LP
# 15 	 [SNX 25%]-[WETH 25%]-[xSNXa 50%]
# No Pair
# 15 	 [WETH 25%]-[AAVE 25%]-[xAAVEa 50%]
# No Pair
# 15 	 [AAVE 25%]-[WETH 25%]-[xAAVEb 50%]
# No Pair
# 17 	 [xKNCa]-[WETH] Uni LP
# 17 	 [xKNCb]-[WETH] Uni LP
# 14 	 [ETH]-[xINCHa] 1INCH LP
# 14 	 [ETH]-[xINCHb] 1INCH LP
# 12 	 xBNTBNT
# 21 	 "reason": "cannot estimate gas; transaction may fail or may require manual gas limit",
# No Pair
# 11 	 DEFI5
# 11 	 CC10
# 11 	 DEGEN
# 15 	 [WETH]-[DEFI5] Uni LP
# 15 	 [CC10]-[WETH] Uni LP
# 15 	 [WETH]-[ORCL5] Uni LP
# 15 	 [DEGEN]-[WETH] Uni LP
# 15 	 [FFF]-[WETH] Uni LP
# 15 	 [NFTP]-[WETH] Uni LP
# 17 	 [DEGEN]-[WETH] Uni LP
# 17 	 [WETH]-[ORCL5] Uni LP
# 17 	 [WETH]-[DEFI5] Uni LP
# 17 	 [CC10]-[WETH] Uni LP
# 13 	 DEFI5
# 13 	 CC10
# 8 	 Staked: 5400386.3212 bUSDT ($5,516,278.33)
# No Pair
# 8 	 Staked: 3844660.2966 bUSDC ($3,923,434.39)
# No Pair
# 8 	 Staked: 85103876.7784 bARPA ($5,407,232.49)
# No Pair
# 8 	 Staked: 205.5216 bWBTC ($9,644,383.12)
# No Pair
# 8 	 Staked: 22.9841 bHBTC ($1,076,454.57)
# No Pair
# 17 	 [DAI]-[MORT] Uni LP
# 17 	 [MORC]-[DAI] Uni LP
# 10 	 Boardroom
# 17 	 [POS]-[USDC] Uni LP
# 17 	 [POC]-[USDC] Uni LP
# 8 	 Boardroom
# Bigger Block as Test
# 11 	 syUSD
# 15 	 [SMTY]-[WETH] Uni LP
# 15 	 [bALPHA]-[WETH] Uni LP
# 11 	 WBTC
# 11 	 WETH
# 11 	 USDT
# 11 	 USDC
# 11 	 OCEAN
# 11 	 LINK
# 11 	 SUSHI
# 11 	 UNI
# 11 	 YFI
# 11 	 AAVE
# 11 	 SRM
# 11 	 TOMOE
# 15 	 [bALPHA]-[WETH] Uni LP
# 15 	 [WETH]-[BDP] Uni LP
# 15 	 [bBETA]-[WETH] Uni LP
# 22 	 [WETH 50%]-[PAR 50%]
# 7 	 PAR
# 7 	 PAR
# 8 	 PAR
# 17 	 [ALCH]-[WETH] Uni LP
# 13 	 ALCH
# 13 	 BANK
# 17 	 [BANK]-[WETH] SLP
# 17 	 [FLOAT]-[WETH] SLP
# 13 	 FLOAT
# 17 	 [BANK]-[WETH] SLP
# 13 	 DAI
# 13 	 USDC
# 13 	 USDT
# 13 	 SUSHI
# 13 	 WBTC
# 13 	 YAM
# 13 	 YFI
# 12 	 ETH
# 12 	 [WETH]-[USF] Uni LP
# 3 	 [USDT Platform] Price: $1.00 TVL: $827,564.18
# 3 	 Your Position: 0.0000 USDT [0]
# 8 	 Your Liquidity: 0.0000 USDT-LP [$0.00]
# 3 	 Your Position: 0.0000 ETH [0]
# 14 	 Your Liquidity: 0.0000 ETH-LP-V2 [$0.00]
# 13 	 USDT-LP
# 13 	 ETH-LP-V2
# 17 	 [WETH]-[COTI] Uni LP
# 17 	 [WETH]-[GOVI] Uni LP
# 17 	 [WETH]-[COTI] SLP
# 17 	 [WETH]-[GOVI] SLP
# 17 	 [XUS]-[WETH] Uni LP
# 17 	 [XUSD]-[XUS] Uni LP
# 17 	 [XUSD]-[DAI] Uni LP
# 17 	 [XUSD]-[WETH] Uni LP
# 17 	 [XUSD]-[LINK] Uni LP
# 17 	 [ISLA]-[WETH] Uni LP
# Bigger Block as Test
# 16 	 [RULER]-[WETH] SLP
# 16 	 [RC_WBTC_25000_DAI_2021_3_31]-[DAI] SLP
# 16 	 [DAI]-[RC_WETH_750_DAI_2021_3_31] SLP
# 16 	 [DAI]-[RC_COVER_250_DAI_2021_3_31] SLP
# 11 	 RC_INV3CRV-f
# 14 	 RC_vETH23CRV-f
# 14 	 RC_PICKLE3CRV-f
# 11 	 RC_WBTC3CRV-f
# 11 	 RC_WETH3CRV-f
# 11 	 RC_xCOVER3CRV-f
# 11 	 RC_xRULER3CRV-f
# 11 	 RC_xSUSHI3CRV-f
# 11 	 RC_bBADGER3CRV-f
# 11 	 RC_RGT3CRV-f
# 11 	 RC_MASK3CRV-f
# 11 	 RC_PUNK-B3CRV-f
# 14 	 RC_INV3CRV-f
# 14 	 RC_BOR3CRV-f
# 14 	 RC_DEFI53CRV-f
# 11 	 SifuDegen3CRV-f
# 11 	 SifuETH3CRV-f
# 16 	 [RC_DAI_0.25_TRIBE_2021_4_30]-[TRIBE] SLP
# 11 	 sifuxruler3CRV-f
# 11 	 RC_AAVE3CRV-f
# 11 	 RC_COMP3CRV-f
# 14 	 RC_xPREMIA3CRV-f
# 14 	 RC_ALCX3CRV-f
# 11 	 RC_WBTC3CRV-f
# 11 	 RC_WETH3CRV-f
# 11 	 RC_xCOVER3CRV-f
# 11 	 RC_xRULER3CRV-f
# 11 	 RC_xSUSHI3CRV-f
# 11 	 SifuETH3CRV-f
# 11 	 RC_INV3CRV-f
# 14 	 RC_oLTC3CRV-f
# 14 	 RC_BOR3CRV-f
# 14 	 RC_DEFI53CRV-f
# 14 	 RC_bBADGER3CRV-f
# 14 	 RC_vETH23CRV-f
# 11 	 RC_vVSP3CRV-f
# 11 	 RC_iFARM3CRV-f
# 11 	 RC_yvYFI3CRV-f
# 14 	 RC_RAI3CRV-f
# 14 	 RC_bDPI3CRV-f
# 11 	 RC_PICKLE3CRV-f
# 14 	 RC_eXRD3CRV-f
# 14 	 RC_ARMOR3CRV-f
# 11 	 RC_WBTC3CRV-f
# 11 	 RC_WETH3CRV-f
# 11 	 SifuETH3CRV-f
# 11 	 RC_xRULER3CRV-f
# 11 	 RC_xCOVER3CRV-f
# 14 	 RC_eXRD3CRV-f
# 14 	 RC_bBADGER3CRV-f
# 14 	 RC_ibBTC3CRV-f
# 14 	 RC_vETH23CRV-f
# 14 	 RC_iFARM3CRV-f
# 14 	 RC_ARMOR3CRV-f
# 14 	 RC_ALCX3CRV-f
# 14 	 RC_BDI3CRV-f
# 14 	 RC_NEAR3CRV-f
# 14 	 RC_vVSP3CRV-f
# 14 	 RC_INV3CRV-f
# 11 	 RC_xRULER3CRV-f
# 11 	 RC_xCOVER3CRV-f
# 14 	 RC_AMP3CRV-f
# 11 	 RC_iFARM3CRV-f
# 14 	 RC_ARMOR3CRV-f
# 10 	 RULER
# 17 	 [WETH]-[FOX] Uni LP
# 17 	 [TCAP]-[WETH] SLP
# 17 	 [CTX]-[WETH] SLP
# 13 	 WETH
# 13 	 DAI
# 15 	 [WETH]-[CONV] Uni LP
# 15 	 [CONV]-[USDT] Uni LP
# 15 	 [WETH]-[USDT] Uni LP
# 11 	 CONV
# 17 	 [MIS]-[USDT] SLP
# 17 	 [MIC]-[USDT] SLP
# 8 	 Boardroom
# 18 	 [CVX]-[WETH] SLP
# 18 	 [cvxCRV]-[CRV] SLP
# 13 	 cvxCRV
# 13 	 CVX
# 13 	 3Crv
# 12 	 hCRV
# 12 	 3Crv
# 12 	 gusd3CRV
# 12 	 husd3CRV
# 12 	 usdk3CRV
# 12 	 usdn3CRV
# 12 	 musd3CRV
# 12 	 rsv3CRV
# 12 	 tbtc/sbtcCrv
# 12 	 dusd3CRV
# 12 	 pBTC/sbtcCRV
# 12 	 bBTC/sbtcCRV
# 12 	 oBTC/sbtcCRV
# 12 	 ust3CRV
# 12 	 eursCRV
# 12 	 a3CRV
# 12 	 saCRV
# 12 	 usdp3CRV
# 12 	 ib3CRV
# 12 	 linkCRV
# 12 	 TUSD3CRV-f
# 12 	 FRAX3CRV-f
# 12 	 LUSD3CRV-f
# 12 	 BUSD3CRV-f
# 12 	 alUSD3CRV-f
# 12 	 crvTricrypto
# 12 	 crv3crypto
# 12 	 EURT-f
# 17 	 [sYFL]-[WETH] LSLP
# 17 	 [LINK]-[YFLUSD] LSLP
# 17 	 [YFLUSD]-[WETH] LSLP
# 8 	 Boardroom
# 17 	 [PUSD]-[PEGS] Uni LP
# 17 	 [PUSD]-[USDC] Uni LP
# 16 	 [WETH]-[PUSH] Uni LP
# 12 	 PUSH
# 17 	 [DON]-[USDT] Uni LP
# 15 	 [WFTM]-[CHAD] BRUSH LP
# 15 	 [BRUSH]-[CHAD] BRUSH LP
# 15 	 [USDC]-[CHAD] BRUSH LP
# 10 	 CHAD
# 15 	 [BOMB]-[CHAD] SPOOKY LP
# 15 	 [STEAK]-[CHAD] SPIRIT LP
# 15 	 [TOMB]-[CHAD] BRUSH LP
# 15 	 [CzTears]-[CHAD] BRUSH LP
# 15 	 [Shiba]-[CHAD] BRUSH LP
# 15 	 [WFTM]-[Shiba] BRUSH LP
# 15 	 [ATRI]-[CHAD] BRUSH LP
# 15 	 [PHANT]-[CHAD] BRUSH LP
# 15 	 [CHAD]-[OPERA] Opera Swap LP
# 15 	 [JUST]-[CHAD] ZooDex LP
# 15 	 [iFUSD]-[CHAD] BRUSH LP
# 15 	 [SafePapillonShitCumRocketDogeElonMoonATHonlyNOdipFOMOHodlBullFUDHentaiWaifuNFTDiamondHandsApe]-[CHAD] BRUSH LP
# 15 	 [CHAD]-[YORO] BRUSH LP
# 15 	 [xSTEAK]-[CHAD] BRUSH LP
# 15 	 [SBRW]-[CHAD] BRUSH LP
# 15 	 [WFTM]-[HODL] BRUSH LP
# 15 	 [GRIM]-[CHAD] BRUSH LP
# 15 	 [CASPER]-[CHAD] SPIRIT LP
# 15 	 [Nova]-[CHAD] BRUSH LP
# 17 	 [WFTM]-[ELITE] SLP
# Bigger Block as Test
# Bigger Block as Test
# 10 	 ORI
# 15 	 [ORI]-[WFTM] Uni LP
# 15 	 [WFTM]-[AURORA] Uni LP
# 15 	 [USDC]-[WFTM] Uni LP
# 15 	 [WFTM]-[ETH] Uni LP
# 15 	 [WFTM]-[BTC] Uni LP
# 15 	 [WFTM]-[LINK] Uni LP
# 15 	 [WFTM]-[DAI] Uni LP
# 15 	 [USDC]-[ORI] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 15 	 [ORI]-[ETH] Uni LP
# 15 	 [ORI]-[BTC] Uni LP
# 15 	 [ORI]-[LINK] Uni LP
# 15 	 [WFTM]-[SUSHI] Uni LP
# 15 	 [WFTM]-[YFI] Uni LP
# 15 	 [WFTM]-[SNX] Uni LP
# 15 	 [WFTM]-[BNB] Uni LP
# 15 	 [ZOO]-[WFTM] Uni LP
# 15 	 [WFTM]-[ICE] Uni LP
# 15 	 [WFTM]-[ESWAP] Uni LP
# 15 	 [ORI]-[ESWAP] Uni LP
# 15 	 [WFTM]-[renBTC] Uni LP
# 15 	 [ORI]-[renBTC] Uni LP
# 15 	 [WFTM]-[renZEC] Uni LP
# 15 	 [ORI]-[renZEC] Uni LP
# 15 	 [WFTM]-[renBCH] Uni LP
# 15 	 [ORI]-[renBCH] Uni LP
# 15 	 [CRV]-[WFTM] Uni LP
# 15 	 [ORI]-[CRV] Uni LP
# 15 	 [WFTM]-[ICE] SLP
# 15 	 [WFTM]-[ICE] SPOOKY LP
# 10 	 ICE
# 15 	 [WFTM]-[ICE] SLP
# 10 	 fUSDT+DAI+USDC
# 15 	 [USDC]-[RDT] SPOOKY LP
# 15 	 [WFTM]-[RDT] SPOOKY LP
# 10 	 RDT
# 10 	 USDC
# 10 	 WFTM
# 10 	 ETH
# 10 	 BTC
# 10 	 DAI
# 10 	 fUSDT
# 10 	 BNB
# 10 	 BOO
# 15 	 [USDC]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[BOO] SPOOKY LP
# 15 	 [WFTM]-[ETH] SPOOKY LP
# 15 	 [WFTM]-[BTC] SPOOKY LP
# 15 	 [WFTM]-[DAI] SPOOKY LP
# 15 	 [WFTM]-[SHRAP] BLP
# 15 	 [WFTM]-[BOMB] BLP
# 15 	 [BOMB]-[SHRAP] BLP
# 15 	 [USDC]-[BOMB] BLP
# 15 	 [USDC]-[SHRAP] BLP
# 10 	 BLP
# 15 	 [WFTM]-[BTC] BLP
# 15 	 [WFTM]-[ETH] BLP
# 15 	 [WFTM]-[SHADOW] SPOOKY LP
# 15 	 [USDC]-[SHADOW] SPOOKY LP
# 10 	 SHADOW
# 15 	 [WFTM]-[BOO] SPOOKY LP
# 15 	 [WFTM]-[ETH] SPOOKY LP
# 15 	 [USDC]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[DAI] SPOOKY LP
# 15 	 [fUSDT]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[BTC] SPOOKY LP
# 15 	 [WFTM]-[SUSHI] SPOOKY LP
# 15 	 [WFTM]-[BNB] SPOOKY LP
# 15 	 [WFTM]-[YFI] SLP
# 15 	 [WFTM]-[DAI] SLP
# 15 	 [WFTM]-[LINK] SLP
# 15 	 [WFTM]-[ETH] SLP
# 15 	 [fUSDT]-[WFTM] SLP
# 15 	 [WFTM]-[BTC] SLP
# 15 	 [WFTM]-[SUSHI] SLP
# 15 	 [WFTM]-[CREAM] SLP
# 15 	 [FXS]-[FRAX] SLP
# 15 	 [USDC]-[AAVE] SLP
# 15 	 [WFTM]-[SNX] SLP
# 15 	 [WFTM]-[ICE] SLP
# 15 	 [WFTM]-[COVER] SLP
# 15 	 [ZOO]-[WFTM] SLP
# 15 	 [CRV]-[WFTM] SLP
# 15 	 [fUSDT]-[FRAX] SLP
# 15 	 [fUSDT]-[LQDR] SLP
# 15 	 [LQDR]-[WFTM] SLP
# 10 	 NTOKEN
# 10 	 BRUSH
# 15 	 [WFTM]-[BRUSH] BRUSH LP
# 15 	 [USDC]-[WFTM] BRUSH LP
# 15 	 [WFTM]-[BNB] BRUSH LP
# 15 	 [WFTM]-[ETH] BRUSH LP
# 15 	 [WFTM]-[BTC] BRUSH LP
# 15 	 [ZOO]-[BRUSH] BRUSH LP
# 15 	 [WFTM]-[HODL] BRUSH LP
# 10 	 SEED
# 15 	 [SEED]-[WFTM] SPOOKY LP
# 15 	 [USDC]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[BTC] SPOOKY LP
# 15 	 [WFTM]-[ETH] SPOOKY LP
# 15 	 [WFTM]-[LINK] SPOOKY LP
# 15 	 [fUSDT]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[BNB] SPOOKY LP
# 10 	 USDC
# 10 	 WFTM
# 10 	 BTC
# 10 	 ETH
# 10 	 SPIRIT
# 15 	 [WFTM]-[SPIRIT] SPIRIT LP
# 15 	 [WFTM]-[BTC] SPIRIT LP
# 15 	 [WFTM]-[ETH] SPIRIT LP
# 15 	 [USDC]-[WFTM] SPIRIT LP
# 15 	 [ZOO]-[WFTM] SPIRIT LP
# 15 	 [WFTM]-[ICE] SPIRIT LP
# 15 	 [WFTM]-[SUSHI] SPIRIT LP
# 15 	 [WFTM]-[CREAM] SPIRIT LP
# 15 	 [CRV]-[WFTM] SPIRIT LP
# 15 	 [WFTM]-[LINK] SPIRIT LP
# 15 	 [WFTM]-[COVER] SPIRIT LP
# 15 	 [WFTM]-[YFI] SPIRIT LP
# 15 	 [WFTM]-[FRAX] SPIRIT LP
# 15 	 [FXS]-[FRAX] SPIRIT LP
# 15 	 [fUSDT]-[WFTM] SPIRIT LP
# 15 	 [WFTM]-[ANY] SPIRIT LP
# 15 	 [WFTM]-[BNB] SPIRIT LP
# 15 	 [SPIRIT]-[BNB] SPIRIT LP
# 15 	 [YFI]-[WOOFY] SPIRIT LP
# 15 	 [SPIRIT]-[DAI] SPIRIT LP
# 15 	 [fUSDT]-[BUSD] SPIRIT LP
# 15 	 [USDC]-[GTON] SPIRIT LP
# 15 	 [WFTM]-[MIM] SPIRIT LP
# 15 	 [DIS]-[WFTM] SPIRIT LP
# 15 	 [LQDR]-[SPIRIT] SPIRIT LP
# 15 	 [SPIRIT]-[GRIM] SPIRIT LP
# 15 	 [SPIRIT]-[xSTEAK] SPIRIT LP
# 15 	 [UNIDX]-[SPIRIT] SPIRIT LP
# 15 	 [WFTM]-[JUST] SPIRIT LP
# 15 	 [WFTM]-[RAI] SPIRIT LP
# Bigger Block as Test
# 10 	 SBRW
# 15 	 [WFTM]-[SBRW] Uni LP
# 15 	 [USDC]-[SBRW] Uni LP
# 15 	 [WFTM]-[BEERMONEY] Uni LP
# 10 	 MM
# 15 	 [WFTM]-[MM] SPOOKY LP
# 10 	 mBOO
# 10 	 mSPIRIT
# 10 	 mspLP
# 10 	 [WFTM]-[BOO] SPOOKY LP
# 10 	 [WFTM]-[SPIRIT] SPIRIT LP
# 15 	 [WFTM]-[MM] SPIRIT LP
# 10 	 mUSDC
# 8 	 Staked: 2.3940 mBTC ($0.00)
# No Pair
# 15 	 [WFTM]-[FROYO] SLP
# 10 	 3FROYO
# 10 	 FRANK
# 15 	 [WFTM]-[FRANK] SPIRIT LP
# 15 	 [WFTM]-[SPIRIT] SPIRIT LP
# 15 	 [WFTM]-[BTC] SPIRIT LP
# 15 	 [WFTM]-[ETH] SPIRIT LP
# 15 	 [USDC]-[WFTM] SPIRIT LP
# 15 	 [ZOO]-[WFTM] SPIRIT LP
# 15 	 [WFTM]-[ICE] SPIRIT LP
# 15 	 [WFTM]-[SUSHI] SPIRIT LP
# 15 	 [WFTM]-[CREAM] SPIRIT LP
# 15 	 [CRV]-[WFTM] SPIRIT LP
# 15 	 [WFTM]-[LINK] SPIRIT LP
# 15 	 [WFTM]-[COVER] SPIRIT LP
# 15 	 [WFTM]-[YFI] SPIRIT LP
# 15 	 [WFTM]-[FRAX] SPIRIT LP
# 15 	 [fUSDT]-[WFTM] SPIRIT LP
# 15 	 [WFTM]-[ANY] SPIRIT LP
# 10 	 SPIRIT
# 15 	 [fUSDT]-[FRANK] SPIRIT LP
# 15 	 [WFTM]-[BOO] SPOOKY LP
# 15 	 [fUSDT]-[WFTM] SPOOKY LP
# 15 	 [USDC]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[DAI] SPOOKY LP
# 15 	 [WFTM]-[BTC] SPOOKY LP
# 15 	 [WFTM]-[ETH] SPOOKY LP
# 15 	 [WFTM]-[LINK] SPOOKY LP
# 15 	 [WFTM]-[AAVE] SPOOKY LP
# 15 	 [WFTM]-[SNX] SPOOKY LP
# 15 	 [WFTM]-[YFI] SPOOKY LP
# 15 	 [WFTM]-[SUSHI] SPOOKY LP
# 15 	 [WFTM]-[BNB] SPOOKY LP
# 15 	 [WFTM]-[ICE] SPOOKY LP
# 10 	 BOO
# 15 	 [LQDR]-[WFTM] SLP
# 15 	 [fUSDT]-[LQDR] SLP
# 10 	 LQDR
# 17 	 [WFTM]-[NIPS] ZooDex LP
# 10 	 UNIRON
# 15 	 [USDC]-[WFTM] SPOOKY LP
# 15 	 [UNIRON]-[WFTM] SPOOKY LP
# 15 	 [USDC]-[UNIRON] SPOOKY LP
# 15 	 [UNIRON]-[ETH] SPOOKY LP
# 15 	 [USDC]-[fUSDT] SPOOKY LP
# 10 	 WFTM
# 10 	 BTC
# 10 	 ETH
# 10 	 fUSDT
# 10 	 LINK
# 10 	 BNB
# 10 	 AAVE
# 15 	 [WFTM]-[GHOST] SPIRIT LP
# 15 	 [WFTM]-[GHOST] SLP
# 15 	 [WFTM]-[GHOST] SPOOKY LP
# 15 	 [WFTM]-[GHOST] Uni LP
# 15 	 [WFTM]-[KLING] SLP
# 15 	 [fUSDT]-[KLING] SLP
# 10 	 KLING
# 15 	 [WFTM]-[BORG] SLP
# 15 	 [fUSDT]-[BORG] SLP
# 15 	 [WFTM]-[BORGDAI] SLP
# 15 	 [fUSDT]-[BORGDAI] SLP
# 15 	 [WFTM]-[YFI] SLP
# 15 	 [WFTM]-[DAI] SLP
# 15 	 [WFTM]-[LINK] SLP
# 15 	 [WFTM]-[ETH] SLP
# 15 	 [fUSDT]-[WFTM] SLP
# 15 	 [WFTM]-[SUSHI] SLP
# 15 	 [WFTM]-[CREAM] SLP
# 15 	 [USDC]-[AAVE] SLP
# 15 	 [WFTM]-[SNX] SLP
# 15 	 [WFTM]-[ICE] SLP
# 15 	 [WFTM]-[COVER] SLP
# 15 	 [ZOO]-[WFTM] SLP
# 15 	 [CRV]-[WFTM] SLP
# 10 	 WFTM
# 10 	 FUSD
# 10 	 DAI
# 10 	 USDC
# 10 	 fUSDT
# 10 	 BTC
# 10 	 ETH
# 10 	 YFI
# 10 	 BNB
# 10 	 ICE
# 10 	 LINK
# 10 	 CREAM
# 10 	 ORI
# 10 	 SON
# 10 	 BOO
# 10 	 SPIRIT
# 10 	 SNX
# 10 	 SUSHI
# 10 	 FRANK
# 10 	 EST
# 10 	 CzTears
# 10 	 OPE
# 10 	 GHOST
# 10 	 LQDR
# 10 	 WAKA
# 10 	 BRUSH
# 15 	 [WFTM]-[BTC] SLP
# 15 	 [BTC]-[KLING] SLP
# 10 	 AAVE
# 10 	 CRV
# 10 	 GBONE
# 15 	 [WFTM]-[Shiba] Uni LP
# 15 	 [GBONE]-[Shiba] Uni LP
# 15 	 [GBONE]-[WFTM] Uni LP
# Bigger Block as Test
# 15 	 [WFTM]-[SHADE] SPOOKY LP
# 10 	 SHADE
# 10 	 OPERA
# 15 	 [WFTM]-[OPERA] Opera Swap LP
# 15 	 [WFTM]-[FUSD] Opera Swap LP
# 15 	 [WFTM]-[BTC] Opera Swap LP
# 15 	 [WFTM]-[ETH] Opera Swap LP
# 15 	 [USDC]-[WFTM] Opera Swap LP
# 15 	 [WFTM]-[BNB] Opera Swap LP
# 15 	 [WFTM]-[LINK] Opera Swap LP
# 15 	 [WFTM]-[SUSHI] Opera Swap LP
# 15 	 [WFTM]-[YFI] Opera Swap LP
# 15 	 [WFTM]-[ANY] Opera Swap LP
# 15 	 [CRV]-[WFTM] Opera Swap LP
# 15 	 [WFTM]-[DAI] Opera Swap LP
# 15 	 [WFTM]-[AAVE] Opera Swap LP
# 15 	 [fUSDT]-[WFTM] Opera Swap LP
# 15 	 [EST]-[WFTM] SPIRIT LP
# 10 	 EST
# 17 	 [WFTM]-[Nova] SPOOKY LP
# 15 	 [WFTM]-[HODLCC] SPOOKY LP
# 15 	 [WFTM]-[beHODL] SPOOKY LP
# 15 	 [NIPS]-[beHODL] SPOOKY LP
# 15 	 [REAPER]-[beHODL] SPOOKY LP
# 15 	 [beHODL]-[BUTT] SPOOKY LP
# 15 	 [beHODL]-[Shiba] SPOOKY LP
# 15 	 [WFTM]-[SPOON] SPIRIT LP
# 10 	 ibSPOON
# 10 	 ibFTM
# 10 	 ibUSDC
# 10 	 ibfUSDT
# 10 	 ibDAI
# 10 	 [WFTM]-[SPIRIT] SPIRIT LP
# 10 	 [WFTM]-[BOO] SPOOKY LP
# 10 	 [USDC]-[WFTM] SPOOKY LP
# 10 	 [fUSDT]-[WFTM] SPOOKY LP
# 10 	 [WFTM]-[DAI] SPOOKY LP
# 15 	 [WFTM]-[WAKA] Uni LP
# 15 	 [fUSDT]-[WFTM] Uni LP
# 15 	 [USDC]-[WFTM] Uni LP
# 15 	 [WFTM]-[BTC] Uni LP
# 15 	 [WFTM]-[ETH] Uni LP
# 15 	 [WFTM]-[ATRI] Uni LP
# 15 	 [WFTM]-[DAI] Uni LP
# 15 	 [WFTM]-[YFI] Uni LP
# 15 	 [WFTM]-[SUSHI] Uni LP
# 15 	 [ZOO]-[WFTM] Uni LP
# 15 	 [WFTM]-[BADGER] Uni LP
# 15 	 [WFTM]-[AAVE] Uni LP
# 15 	 [WFTM]-[ICE] Uni LP
# 15 	 [WFTM]-[SNX] Uni LP
# 15 	 [WFTM]-[CREAM] Uni LP
# 15 	 [WFTM]-[COVER] Uni LP
# 15 	 [WFTM]-[LINK] Uni LP
# 15 	 [CRV]-[WFTM] Uni LP
# 15 	 [WFTM]-[BAND] Uni LP
# 10 	 pWaka
# 15 	 [WFTM]-[BOMB] Uni LP
# 15 	 [WFTM]-[Shiba] Uni LP
# 10 	 bWaka
# 15 	 [WFTM]-[GRIM] Uni LP
# 10 	 BONE
# 15 	 [WFTM]-[BONE] Uni LP
# 15 	 [USDC]-[WFTM] Uni LP
# 15 	 [WFTM]-[BOO] Uni LP
# 15 	 [WFTM]-[WAKA] Uni LP
# 15 	 [WFTM]-[DAI] Uni LP
# 15 	 [fUSDT]-[WFTM] Uni LP
# 15 	 [WFTM]-[ETH] Uni LP
# 15 	 [WFTM]-[BTC] Uni LP
# 15 	 [WFTM]-[BNB] Uni LP
# 15 	 [LQDR]-[WFTM] Uni LP
# 15 	 [WFTM]-[NIPS] Uni LP
# 15 	 [BONE]-[Shiba] Uni LP
# 15 	 [WFTM]-[LAIKA] Uni LP
# 15 	 [REAPER]-[WFTM] Uni LP
# 15 	 [BabyBONE]-[BONE] Uni LP
# 15 	 [WFTM]-[BOO] SPOOKY LP
# 15 	 [fUSDT]-[WFTM] SPOOKY LP
# 15 	 [USDC]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[DAI] SPOOKY LP
# 15 	 [WFTM]-[BTC] SPOOKY LP
# 15 	 [WFTM]-[ETH] SPOOKY LP
# 15 	 [WFTM]-[LINK] SPOOKY LP
# 15 	 [WFTM]-[AAVE] SPOOKY LP
# 15 	 [WFTM]-[SNX] SPOOKY LP
# 15 	 [WFTM]-[SUSHI] SPOOKY LP
# 15 	 [WFTM]-[BAND] SPOOKY LP
# 15 	 [WFTM]-[CREAM] SPOOKY LP
# 15 	 [CRV]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[BADGER] SPOOKY LP
# 15 	 [WFTM]-[ICE] SPOOKY LP
# 15 	 [ZOO]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[BNB] SPOOKY LP
# 15 	 [WFTM]-[WOOFY] SPOOKY LP
# 15 	 [WFTM]-[ANY] SPOOKY LP
# 15 	 [WFTM]-[BIFI] SPOOKY LP
# 15 	 [WFTM]-[MIM] SPOOKY LP
# 15 	 [WFTM]-[KEK] SPOOKY LP
# 15 	 [YFI]-[ETH] SPOOKY LP
# 10 	 BOO
# 15 	 [DAI]-[SON] Uni LP
# 15 	 [USDC]-[SON] Uni LP
# 15 	 [WFTM]-[SON] Uni LP
# 15 	 [BTC]-[SON] Uni LP
# 15 	 [ETH]-[SON] Uni LP
# 15 	 [BORGDAI]-[SON] Uni LP
# 15 	 [SON]-[BORG] Uni LP
# 15 	 [SON]-[AURORA] Uni LP
# 10 	 SON
# 15 	 [WFTM]-[DAI] Uni LP
# 15 	 [USDC]-[WFTM] Uni LP
# 15 	 [WFTM]-[BTC] Uni LP
# 15 	 [WFTM]-[ETH] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 10 	 WFTM
# 10 	 ETH
# 10 	 YFI
# 10 	 FUSD
# 10 	 ICE
# 10 	 LINK
# 10 	 CREAM
# 10 	 DAI
# 10 	 OPE
# 10 	 AURORA
# 15 	 [YFI]-[SON] Uni LP
# 15 	 [WFTM]-[BORG] Uni LP
# 15 	 [WFTM]-[BORGDAI] Uni LP
# 10 	 BOO
# 10 	 SPIRIT
# 15 	 [SON]-[FUSD] Uni LP
# 15 	 [ZOO]-[SON] Uni LP
# 15 	 [fUSDT]-[SON] Uni LP
# 15 	 [SON]-[ICE] Uni LP
# 15 	 [SON]-[OPE] Uni LP
# 15 	 [BORGDAI]-[AURORA] Uni LP
# 15 	 [BORGDAI]-[DAI] Uni LP
# 15 	 [fUSDT]-[BORGDAI] Uni LP
# 10 	 SNX
# 15 	 [SON]-[LINK] Uni LP
# 15 	 [CREAM]-[SON] Uni LP
# 15 	 [SON]-[SUSHI] Uni LP
# 15 	 [SON]-[UBI] Uni LP
# 15 	 [AURORA]-[BORG] Uni LP
# 10 	 SUSHI
# 15 	 [WFTM]-[AURORA] Uni LP
# 15 	 [ORI]-[SON] Uni LP
# 10 	 iFUSD
# 15 	 [STEAK]-[FUSD] SPIRIT LP
# 15 	 [USDC]-[FUSD] SPIRIT LP
# 15 	 [WFTM]-[FUSD] SPIRIT LP
# 18 	 FUSD
# 10 	 YEL
# 15 	 [WFTM]-[YEL] SPOOKY LP
# 10 	 xBOO
# 10 	 BUTT
# 15 	 [WFTM]-[BUTT] ZooDex LP
# 15 	 [WFTM]-[SHIT] ZooDex LP
# 15 	 [SHIT]-[BUTT] ZooDex LP
# 15 	 [ZOO]-[BUTT] ZooDex LP
# 15 	 [REAPER]-[BUTT] ZooDex LP
# 15 	 [REAPER]-[SHIT] ZooDex LP
# 15 	 [TOTEM]-[SHIT] ZooDex LP
# 15 	 [HODL]-[BUTT] ZooDex LP
# 15 	 [SHIT]-[HODL] ZooDex LP
# 15 	 [BABYBOO]-[SHIT] SPOOKY LP
# 15 	 [SHIT]-[WILD] ZooDex LP
# 17 	 [WFTM]-[ELK] ELK LP
# 17 	 [DAI]-[ELK] ELK LP
# 17 	 [BTC]-[ELK] ELK LP
# 17 	 [ETH]-[ELK] ELK LP
# 17 	 [LINK]-[ELK] ELK LP
# 17 	 [fUSDT]-[ELK] ELK LP
# 17 	 [USDC]-[ELK] ELK LP
# 17 	 [SPIRIT]-[ELK] ELK LP
# 17 	 [BOO]-[ELK] ELK LP
# 17 	 [CREAM]-[ELK] ELK LP
# 17 	 [SUSHI]-[ELK] ELK LP
# 17 	 [AAVE]-[ELK] ELK LP
# 17 	 [BNB]-[ELK] ELK LP
# 17 	 [ELK]-[ICE] ELK LP
# 17 	 [ZOO]-[ELK] ELK LP
# 17 	 [YFI]-[ELK] ELK LP
# 15 	 [WFTM]-[YORO] ZooDex LP
# 15 	 [WFTM]-[CATNIP] ZooDex LP
# 10 	 CATNIP
# 15 	 [ZOO]-[YORO] ZooDex LP
# 15 	 [GRIM]-[YORO] ZooDex LP
# 15 	 [REAPER]-[CATNIP] ZooDex LP
# 15 	 [ZOO]-[ATRI] ZooDex LP
# 15 	 [WFTM]-[ECHO] ZooDex LP
# 15 	 [BABYBOO]-[YORO] ZooDex LP
# 15 	 [ZOO]-[WFTM] ZooDex LP
# 15 	 [WFTM]-[YORO] SPIRIT LP
# 15 	 [WFTM]-[CATNIP] SPIRIT LP
# 15 	 [USDC]-[WFTM] SPIRIT LP
# 15 	 [WFTM]-[SPIRIT] SPIRIT LP
# 15 	 [WFTM]-[CATNIP] Uni LP
# 15 	 [WFTM]-[Shiba] Uni LP
# 15 	 [WFTM]-[YORO] Uni LP
# 15 	 [WFTM]-[DAI] Uni LP
# 11 	 Masonry Contract
# No Pair
# 15 	 [WFTM]-[TOMB] SPOOKY LP
# 15 	 [WFTM]-[TSHARE] SPOOKY LP
# 2 	 Below pools are now closed, please unstake your funds. There are no more rewards to be received.
# No Pair
# 15 	 [WFTM]-[TOMB] SPOOKY LP
# 10 	 RYUINU
# 15 	 [WFTM]-[RYUINU] SPIRIT LP
# 15 	 [USDC]-[WFTM] SPIRIT LP
# 15 	 [USDC]-[RYUINU] SPIRIT LP
# 15 	 [BTC]-[RYUINU] SPIRIT LP
# 15 	 [RYUINU]-[ETH] SPIRIT LP
# 15 	 [RYUINU]-[BNB] SPIRIT LP
# 15 	 [WFTM]-[RYUINU] SPOOKY LP
# 10 	 TRITON
# 15 	 [fUSDT]-[TRITON] Galaxy LP
# 15 	 [DAI]-[TRITON] Galaxy LP
# 15 	 [USDC]-[fUSDT] Galaxy LP
# 15 	 [fUSDT]-[DAI] Galaxy LP
# 15 	 [USDC]-[DAI] Galaxy LP
# 13 	 Wrapped
# 15 	 [WFTM]-[AURA] Uni LP
# 15 	 [WFTM]-[DAI] Uni LP
# 15 	 [USDC]-[WFTM] Uni LP
# 15 	 [WFTM]-[LINK] Uni LP
# 15 	 [WFTM]-[BTC] Uni LP
# 15 	 [WFTM]-[ETH] Uni LP
# 15 	 [WFTM]-[BNB] Uni LP
# 15 	 [WFTM]-[SUSHI] Uni LP
# 15 	 [CRV]-[WFTM] Uni LP
# 10 	 KF
# 15 	 [fUSDT]-[WFTM] SPOOKY LP
# 15 	 [KF]-[WFTM] SPOOKY LP
# 15 	 [fUSDT]-[KF] SPOOKY LP
# 15 	 [KF]-[ETH] SPOOKY LP
# 15 	 [USDC]-[fUSDT] SPOOKY LP
# 15 	 [KF]-[BTC] SPOOKY LP
# 15 	 [KF]-[LINK] SPOOKY LP
# 10 	 WFTM
# 10 	 BTC
# 10 	 ETH
# 10 	 fUSDT
# 10 	 LINK
# 10 	 BNB
# 10 	 AAVE
# 10 	 SUSHI
# 10 	 USDC
# 10 	 BULL
# 10 	 WFTM
# 10 	 BOO
# 10 	 BTC
# 10 	 ETH
# 10 	 USDC
# 15 	 [WFTM]-[BULL] SPOOKY LP
# 15 	 [USDC]-[BULL] SPOOKY LP
# 15 	 [BOO]-[BULL] SPOOKY LP
# 15 	 [USDC]-[WFTM] SPOOKY LP
# 15 	 [fUSDT]-[WFTM] SPOOKY LP
# 15 	 [WFTM]-[ETH] SPOOKY LP
# 15 	 [WFTM]-[BTC] SPOOKY LP
# 15 	 [xSAT]-[WBNB] Cake LP
# 15 	 [WBNB]-[BUSD] Cake LP
# 15 	 [BTCB]-[WBNB] Cake LP
# 15 	 [ETH]-[WBNB] Cake LP
# 15 	 [USDT]-[BUSD] Cake LP
# 15 	 [Cake]-[WBNB] Cake LP
# 15 	 [DOT]-[WBNB] Cake LP
# 15 	 [USDC]-[BUSD] Cake LP
# 15 	 [BTCB]-[BUSD] Cake LP
# 15 	 [XRP]-[WBNB] Cake LP
# 15 	 [DAI]-[BUSD] Cake LP
# 15 	 [USDT]-[WBNB] Cake LP
# 11 	 Cake
# 11 	 WBNB
# 11 	 BTCB
# 11 	 ETH
# 15 	 [BUSD]-[LAZY] Cake LP
# 15 	 [WBNB]-[LAZY] Cake LP
# 11 	 LAZY
# 15 	 [USDT]-[LAZY] Cake LP
# 15 	 [WBNB]-[BELT] Cake LP
# 15 	 [Cake]-[BUSD] Cake LP
# 15 	 [SZOO]-[WBNB] Cake LP
# 15 	 [Cake]-[LAZY] Cake LP
# 15 	 [Cake]-[USDT] Cake LP
# 11 	 BUSD
# 11 	 USDT
# 11 	 USDC
# 10 	 4Belt
# 9 	 beltBTC Price: $0.00 TVL: $0.00
# No Pair
# 9 	 beltETH Price: $0.00 TVL: $0.00
# No Pair
# 9 	 beltBNB Price: $0.00 TVL: $0.00
# No Pair
# 15 	 [WBNB]-[BELT] Cake LP
# 10 	 OWANT
# 10 	 R4BELTPOOL
# 15 	 [VENUS]-[BUSD] Cake LP
# 15 	 [VENUS]-[WBNB] Cake LP
# 15 	 [WBNB]-[BUSD] Cake LP
# 11 	 VENUS
# 11 	 BUSD
# 11 	 WBNB
# 11 	 USDT
# 11 	 BTCB
# 11 	 ETH
# 11 	 DAI
# 11 	 USDC
# 11 	 DOT
# 11 	 LINK
# 11 	 Cake
# 15 	 [USDT]-[BUSD] Cake LP
# 15 	 [ETH]-[WBNB] Cake LP
# 15 	 [VENUS]-[MARS] Cake LP
# 11 	 MARS
# 15 	 [APE]-[WBNB] Cake LP
# 15 	 [MFRM]-[WBNB] Cake LP
# 15 	 [SOAK]-[WBNB] Cake LP
# 15 	 [BUST]-[WBNB] Cake LP
# 15 	 [WBNB]-[BIFI] Cake LP
# 15 	 [MFRM]-[APE] Cake LP
# 15 	 [BUST]-[APE] Cake LP
# 15 	 [APE]-[BIFI] Cake LP
# 15 	 [TEST]-[APE] Cake LP
# 13 	 [MAGIC]-[WBNB] Cake LP
# 13 	 [WBNB]-[MYTHIC] Cake LP
# 11 	 MAGIC
# 11 	 MAGIC
# 11 	 MAGIC
# 15 	 [MASH]-[BUSD] Cake LP
# 15 	 [MASH]-[WBNB] Cake LP
# 15 	 [WBNB]-[BUSD] Cake LP
# 15 	 [BTCB]-[WBNB] Cake LP
# 11 	 MASH
# 11 	 Cake
# 11 	 BUNNY
# 11 	 BUNNY
# 11 	 XVS
# 10 	 VAULT
# 11 	 WBNB
# 11 	 BUSD
# 11 	 BTCB
# 15 	 [BTCB]-[MASH] Cake LP
# 15 	 [MASH]-[VAULT] Cake LP
# 15 	 [Cake]-[MASH] Cake LP
# 10 	 ENV
# 15 	 [USDC]-[BUSD] Cake LP
# 15 	 [USDT]-[BUSD] Cake LP
# 15 	 [DOGE]-[BUSD] Cake LP
# 15 	 [MASH]-[PLUM] Cake LP
# 15 	 [SLIME]-[MASH] Uni LP
# 15 	 [TAKO]-[MASH] APE LP
# 15 	 [ETH]-[BUSD] Cake LP
# 15 	 [DOT]-[WBNB] Cake LP
# 15 	 [TOFY]-[BUSD] Cake LP
# 15 	 [WBNB]-[TOFY] Cake LP
# 11 	 TOFY
# 15 	 [MASH]-[SAFEMOON] Cake LP
# 15 	 [SAFEMARS]-[MASH] Cake LP
# 15 	 [ElonGate]-[MASH] Cake LP
# 15 	 [SAFEGALAXY]-[MASH] Cake LP
# 15 	 [SAFESTAR]-[MASH] Cake LP
# 11 	 SAFEMOON
# 11 	 SAFEMARS
# 11 	 ElonGate
# 11 	 SAFESTAR
# 15 	 [MASH]-[TOFY] Cake LP
# 11 	 MASH
# 15 	 [MASH]-[DOGE] Cake LP
# 15 	 [WBNB]-[BUSD] Cake LP
# 15 	 [BTCB]-[WBNB] Cake LP
# 15 	 [ETH]-[WBNB] Cake LP
# 15 	 [DOT]-[WBNB] Cake LP
# 15 	 [USDT]-[WBNB] Cake LP
# 15 	 [Cake]-[WBNB] Cake LP
# 10 	 GARUDA
# 11 	 BUSD
# 11 	 WBNB
# 11 	 BTCB
# 11 	 ETH
# 11 	 Cake
# 15 	 [USDC]-[BUSD] Cake LP
# 15 	 [GARUDA]-[WBNB] Cake LP
# 15 	 [GARUDA]-[BUSD] Cake LP
# 15 	 [ADA]-[WBNB] Cake LP
# 15 	 [XRP]-[WBNB] Cake LP
# 15 	 [WBNB]-[LINK] Cake LP
# 15 	 [WBNB]-[UNI] Cake LP
# 15 	 [USDT]-[GARUDA] Cake LP
# 11 	 DOT
# 11 	 ADA
# 11 	 XRP
# 11 	 LINK
# 11 	 UNI
# 11 	 DOGE
# 15 	 [GARUDA]-[xSAT] Cake LP
# 11 	 XVS
# 15 	 [LTC]-[WBNB] Cake LP
# 11 	 LTC
# 15 	 [DOGE]-[WBNB] Cake LP
# 15 	 [WBNB]-[XVS] Cake LP
# 15 	 [GARUDA]-[USDC] Cake LP
# 10 	 CERBERUS
# 11 	 USDC
# 11 	 USDT
# 15 	 [DAI]-[GARUDA] Cake LP
# 11 	 UST
# 15 	 [UST]-[GARUDA] Cake LP
# 10 	 TUSD
# 15 	 [TUSD]-[GARUDA] Cake LP
# 11 	 DAI
# 15 	 [VAI]-[GARUDA] Cake LP
# 15 	 [USDT]-[BUSD] Cake LP
# 15 	 [Cake]-[GARUDA] Cake LP
# 15 	 [ETH]-[GARUDA] Cake LP
# 15 	 [TUSD]-[BUSD] Cake LP
# 15 	 [UST]-[BUSD] Cake LP
# 15 	 [DOT]-[GARUDA] Cake LP
# 15 	 [USDT]-[USDC] Cake LP
# 15 	 [BETH]-[GARUDA] Cake LP
# 15 	 [TUSD]-[USDT] Cake LP
# 15 	 [UNOWN]-[WBNB] Cake LP
# 15 	 [UNOWN]-[BUSD] Cake LP
# 11 	 UNOWN
# 15 	 [WBNB]-[BUSD] Cake LP
# 11 	 ETH
# 15 	 [UNOWN]-[BTCB] Cake LP
# 11 	 BTCB
# 15 	 [Cake]-[UNOWN] Cake LP
# 11 	 Cake
# 15 	 [UNOWN]-[USDT] Cake LP
# 15 	 [UNOWN]-[ADA] Cake LP
# 11 	 USDT
# 15 	 [UNOWN]-[BAKE] Cake LP
# 15 	 [UNOWN]-[BUNNY] Cake LP
# 11 	 BAKE
# 15 	 [BLAZE]-[BUSD] Uni LP
# 15 	 [BLAZE]-[WBNB] Uni LP
# 15 	 [WBNB]-[BUSD] Uni LP
# 11 	 BLAZE
# 11 	 BUSD
# 11 	 WBNB
# 15 	 [USDT]-[BUSD] Uni LP
# 10 	 0XC
# 15 	 [0XC]-[WBNB] Uni LP
# 15 	 [BLAZE]-[0XC] Uni LP
# 10 	 RX
# 15 	 [RX]-[WBNB] Uni LP
# 10 	 OVEN
# 15 	 [OVEN]-[WBNB] Uni LP
# 15 	 [MINTv2]-[WBNB] Cake LP
# 15 	 [MINTv2]-[BUSD] Cake LP
# 15 	 [WBNB]-[BUSD] Cake LP
# 11 	 MINTv2
# 15 	 [Cake]-[BUSD] Cake LP
# 15 	 [WBNB]-[BUSD] Cake LP
# 15 	 [SUGAR]-[BUSD] Cake LP
# 11 	 BUSD
# 11 	 Cake
# 11 	 BUSD
# 11 	 WBNB
# 15 	 [MINTv2]-[SUGAR] Cake LP
# 15 	 [SUGAR]-[WBNB] Cake LP
# 15 	 [SUGAR]-[BUSD] Cake LP
# 15 	 [WBNB]-[BUSD] Cake LP
# 11 	 SUGAR
# 11 	 Cake
# 11 	 WBNB
# 11 	 BUSD
# 15 	 [Cake]-[WBNB] Cake LP
# 11 	 BTCB
# 11 	 ETH
# 15 	 [MINTv2]-[SUGAR] Cake LP
# 15 	 [MINTv2]-[WBNB] Cake LP
# 15 	 [MINTv2]-[BUSD] Cake LP
# 11 	 MINTv2
# 10 	 TeaSportV1
# 15 	 [WBNB]-[TeaSportV1] Cake LP
# 15 	 [BUSD]-[TeaSportV1] Cake LP
# 11 	 LINK
# 15 	 [WBNB]-[TeaSportV1] Cake LP
# 15 	 [BUSD]-[TeaSportV1] Cake LP
# 15 	 [WBNB]-[BUSD] Cake LP
# 15 	 [MINTv2]-[WBNB] Cake LP
# 15 	 [MINTv2]-[BUSD] Cake LP
# 15 	 [SUGAR]-[WBNB] Cake LP
# 15 	 [SUGAR]-[BUSD] Cake LP
# 15 	 [Cake]-[BUSD] Cake LP
# 11 	 WBNB
# 11 	 BUSD
# 11 	 TeaSportV1
# 15 	 [MINTv2]-[SUGAR] Cake LP
# 11 	 Cake
# 15 	 [AUTO]-[WBNB] Cake LP
# 11 	 Cake
# 15 	 [AUTO]-[WBNB] BLP
# 15 	 [WBNB]-[BAKE] BLP
# 15 	 [BTCB]-[WBNB] BLP
# 15 	 [MDX]-[WBNB] Uni LP
# 15 	 [USDT]-[MDX] Uni LP
# 15 	 [USDT]-[BTCB] Uni LP
# 15 	 [ETH]-[USDT] Uni LP
# 15 	 [USDT]-[USDC] Uni LP
# 15 	 [USDT]-[BUSD] Uni LP
# 15 	 [ETH]-[BTCB] Uni LP
# 15 	 [MDX]-[BUSD] Uni LP
# 15 	 [USDT]-[WBNB] Uni LP
# 15 	 [WBNB]-[BUSD] Uni LP
# 15 	 [BTCB]-[WBNB] Uni LP
# 15 	 [ETH]-[WBNB] Uni LP
# 15 	 [FIL]-[USDT] Uni LP
# 15 	 [ADA]-[USDT] Uni LP
# 15 	 [DAI]-[USDT] Uni LP
# 15 	 [USDT]-[DOT] Uni LP
# 15 	 [LTC]-[USDT] Uni LP
# 15 	 [ETH]-[BETH] Uni LP
# 15 	 [XRP]-[USDT] Uni LP
# 15 	 [Cake]-[WBNB] Cake LP
# 15 	 [WBNB]-[BUSD] Cake LP
# 15 	 [USDT]-[WBNB] Cake LP
# 15 	 [BTCB]-[WBNB] Cake LP
# 15 	 [ETH]-[WBNB] Cake LP
# 15 	 [USDT]-[BUSD] Cake LP
# 15 	 [VAI]-[BUSD] Cake LP
# 15 	 [DOT]-[WBNB] Cake LP
# 15 	 [WBNB]-[LINK] Cake LP
# 15 	 [WBNB]-[UNI] Cake LP
# 15 	 [DODO]-[WBNB] Cake LP
# 15 	 [ETH]-[COMP] Cake LP
# 15 	 [ALPHA]-[WBNB] Cake LP
# 15 	 [XRP]-[WBNB] Cake LP
# 15 	 [ADA]-[WBNB] Cake LP
# 15 	 [BAND]-[WBNB] Cake LP
# 15 	 [ATOM]-[WBNB] Cake LP
# 15 	 [WBNB]-[XVS] Cake LP
# 15 	 [WBNB]-[SFP] Cake LP
# 15 	 [TWT]-[WBNB] Cake LP
# 15 	 [SXP]-[WBNB] Cake LP
# 15 	 [UST]-[BUSD] Cake LP
# 15 	 [INJ]-[WBNB] Cake LP
# 15 	 [WBNB]-[REEF] Cake LP
# 15 	 [BTCST]-[WBNB] Cake LP
# 15 	 [FRONT]-[WBNB] Cake LP
# 15 	 [LIT]-[WBNB] Cake LP
# 15 	 [LINA]-[BUSD] Cake LP
# 15 	 [BEL]-[WBNB] Cake LP
# 15 	 [ALICE]-[WBNB] Cake LP
# 15 	 [WBNB]-[pCWS] Cake LP
# 15 	 [ZIL]-[WBNB] Cake LP
# 15 	 [WBNB]-[pBTC] Cake LP
# 15 	 [WBNB]-[GUM] Cake LP
# 15 	 [DEGO]-[WBNB] Cake LP
# 15 	 [BUSD]-[TPT] Cake LP
# 15 	 [DEXE]-[BUSD] Cake LP
# 15 	 [RAMP]-[BUSD] Cake LP
# 15 	 [NULS]-[BUSD] Cake LP
# 15 	 [NRV]-[WBNB] Cake LP
# 15 	 [WBNB]-[ODDZ] Cake LP
# 15 	 [TKO]-[WBNB] Cake LP
# 15 	 [ITAM]-[WBNB] Cake LP
# 15 	 [EPS]-[WBNB] Cake LP
# 15 	 [WBNB]-[JGN] Cake LP
# 15 	 [TLM]-[WBNB] Cake LP
# 8 	 Staked: 153396.9671 beltBNB ($0.00)
# No Pair
# 8 	 Staked: 2580.6982 beltBTC ($0.00)
# No Pair
# 8 	 Staked: 30272.6648 beltETH ($0.00)
# No Pair
# 10 	 4Belt
# 15 	 [WBNB]-[BELT] Cake LP
# 15 	 [AUTO]-[BUSD] Uni LP
# 15 	 [BANANA]-[WBNB] APE LP
# 15 	 [BANANA]-[BUSD] APE LP
# 11 	 BANANA
# 15 	 [LMT]-[WBNB] Cake LP
# 15 	 [BTCB]-[BUSD] Cake LP
# 15 	 [WEX]-[WBNB] Uni LP
# 15 	 [WAULTx]-[WBNB] Uni LP
# 15 	 [WBNB]-[BUSD] Uni LP
# 15 	 [BTCB]-[WBNB] Uni LP
# 15 	 [ETH]-[WBNB] Uni LP
# 15 	 [USDT]-[WBNB] Uni LP
# 15 	 [DOT]-[WBNB] Uni LP
# 15 	 [USDT]-[BUSD] Uni LP
# 15 	 [BTCB]-[BUSD] Uni LP
# 15 	 [DAI]-[BUSD] Uni LP
# 15 	 [ETH]-[BUSD] Uni LP
# 11 	 WEX
# 15 	 [BUSD]-[MATH] Cake LP
# 15 	 [KUN]-[BUSD] Cake LP
# 15 	 [AUTO]-[WBNB] Uni LP
# 11 	 WBNB
# 15 	 [Cake]-[BUSD] Cake LP
# 15 	 [WINGS]-[WBNB] Uni LP
# 15 	 [WINGS]-[BUSD] Uni LP
# 15 	 [USDC]-[BUSD] Uni LP
# 11 	 WINGS
# 15 	 [WBNB]-[BUSD] Uni LP
# 15 	 [SUSHI]-[BUSD] Uni LP
# 15 	 [USDT]-[DOGE] Uni LP
# 15 	 [BCH]-[WBNB] Uni LP
# 15 	 [Cake]-[WBNB] Uni LP
# 15 	 [HOTCROSS]-[WBNB] Cake LP
# 15 	 [RFOX]-[WBNB] Cake LP
# 15 	 [BUSD]-[CHR] Cake LP
# 15 	 [VRT]-[WBNB] Cake LP
# 15 	 [TUSD]-[BUSD] Cake LP
# 15 	 [QKC]-[BUSD] Cake LP
# 15 	 [bCFX]-[BUSD] Cake LP
# 15 	 [ETH]-[BTCB] Cake LP
# ...
# 15 	 [MONO]-[PolyDoge] Uni LP
# 15 	 [MONO]-[DFYN] DFYN LP
# 15 	 [MONO]-[QUICK] Uni LP
# 15 	 [MONO]-[PZAP] Uni LP
# 15 	 [MONO]-[UNI] Uni LP
# 15 	 [MONO]-[miMATIC] Uni LP
# 15 	 [UFT]-[MONO] Uni LP
# 11 	 UFT
# 15 	 [WMATIC]-[PepeFarm] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 11 	 PepeFarm
# 11 	 WMATIC
# 15 	 [USDC]-[IRON] SLP
# 15 	 [WBTC]-[WETH] Uni LP
# 11 	 IRON
# 11 	 WBTC
# 11 	 WETH
# 11 	 USDC
# 10 	 DMND
# 15 	 [USDC]-[PepeFarm] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 11 	 WMATIC
# 11 	 WBTC
# 11 	 WETH
# 11 	 QUICK
# 11 	 YLD
# 11 	 USDT
# 11 	 USDC
# 11 	 PolyZeus
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [WBTC]-[USDC] Uni LP
# 15 	 [WMATIC]-[QUICK] Uni LP
# 15 	 [WMATIC]-[PolyZeus] Uni LP
# 15 	 [USDC]-[PolyZeus] Uni LP
# 15 	 [USDC]-[GLOCK] Uni LP
# 11 	 GLOCK
# 11 	 WMATIC
# 15 	 [USDC]-[USDT] Uni LP
# 11 	 WETH
# 11 	 DAI
# 11 	 QUICK
# 11 	 WBTC
# 11 	 USDT
# 11 	 Zero
# 15 	 [WMATIC]-[Zero] Uni LP
# 11 	 USDC
# 11 	 WMATIC
# 11 	 WETH
# 15 	 [WMATIC]-[MAPLE] Uni LP
# 15 	 [WBTC]-[WETH] Uni LP
# 15 	 [USDC]-[ELECTRON] SLP
# 15 	 [WMATIC]-[ELECTRON] SLP
# 11 	 ELECTRON
# 15 	 [WMATIC]-[USDC] SLP
# 11 	 USDC
# 11 	 WMATIC
# 11 	 WETH
# 11 	 USDT
# 11 	 WBTC
# 11 	 AAVE
# 11 	 SUSHI
# 11 	 QUICK
# 11 	 DAI
# 15 	 [USDC]-[SWAN] Uni LP
# 15 	 [WMATIC]-[SWAN] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 11 	 SWAN
# 11 	 WMATIC
# 11 	 QUICK
# 11 	 WETH
# 11 	 WBTC
# 11 	 AAVE
# 11 	 USDT
# 11 	 DAI
# 10 	 FISH
# 17 	 [WMATIC]-[ALCH] Uni LP
# 13 	 ALCH
# 15 	 [TAIL]-[USDC] Uni LP
# 15 	 [TAIL]-[WMATIC] Uni LP
# 11 	 TAIL
# 15 	 [WMATIC]-[USDC] Uni LP
# 11 	 WMATIC
# 11 	 QUICK
# 11 	 WETH
# 11 	 WBTC
# 11 	 AAVE
# 11 	 DAI
# 11 	 USDT
# 11 	 USDC
# 11 	 SUSHI
# 10 	 FISH
# 10 	 DOLPH
# 15 	 [WMATIC]-[DOLPH] Uni LP
# 15 	 [USDC]-[DOLPH] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 11 	 USDC
# 11 	 USDT
# 11 	 WMATIC
# 11 	 WETH
# 11 	 WBTC
# 11 	 GIVE
# 15 	 [USDC]-[GIVE] Uni LP
# 15 	 [WMATIC]-[GIVE] Uni LP
# 15 	 [QUICK]-[GIVE] Uni LP
# 11 	 WMATIC
# 11 	 USDC
# 11 	 DAI
# 11 	 WBTC
# 11 	 WETH
# 11 	 QUICK
# 11 	 CRV
# 11 	 AAVE
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[GIVE] SLP
# 15 	 [USDC]-[GIVE] APE LP
# 11 	 SUSHI
# 10 	 BANANA
# 10 	 SPADE
# 11 	 PolyDoge
# 15 	 [PolyDoge]-[GIVE] Uni LP
# 15 	 [PolyDoge]-[GIVE] SLP
# 15 	 [PolyDoge]-[GIVE] APE LP
# 15 	 [GIVE]-[SPADE] SLP
# 15 	 [WETH]-[GIVE] Uni LP
# 15 	 [WETH]-[GIVE] SLP
# 15 	 [WETH]-[GIVE] APE LP
# 15 	 [WBTC]-[GIVE] Uni LP
# 15 	 [WBTC]-[GIVE] SLP
# 15 	 [WBTC]-[GIVE] APE LP
# 15 	 [WMATIC]-[GIVE] SLP
# 15 	 [SUSHI]-[GIVE] SLP
# 15 	 [COVAL]-[GIVE] Uni LP
# 15 	 [WMATIC]-[GIVE] APE LP
# 15 	 [BANANA]-[GIVE] APE LP
# 11 	 COVAL
# 15 	 [WMATIC]-[PolyDoge] Uni LP
# 15 	 [WETH]-[PolyDoge] Uni LP
# 11 	 PZAP
# 15 	 [USDC]-[PZAP] Uni LP
# 15 	 [WMATIC]-[PZAP] Uni LP
# 15 	 [USDT]-[PZAP] Uni LP
# 15 	 [WETH]-[PZAP] Uni LP
# 15 	 [QUICK]-[PZAP] Uni LP
# 15 	 [WBTC]-[PZAP] Uni LP
# 15 	 [WMATIC]-[WETH] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 15 	 [WMATIC]-[LINK] Uni LP
# 15 	 [WMATIC]-[AAVE] Uni LP
# 15 	 [WMATIC]-[UNI] Uni LP
# 15 	 [WMATIC]-[WBTC] Uni LP
# 15 	 [WMATIC]-[QUICK] Uni LP
# 15 	 [WMATIC]-[PAUTO] Uni LP
# 15 	 [AURORA]-[WMATIC] Uni LP
# 15 	 [WMATIC]-[FISH] Uni LP
# 15 	 [SUSHI]-[WMATIC] Uni LP
# 15 	 [WMATIC]-[PBNB] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [WMATIC]-[PolyDoge] Uni LP
# 15 	 [WMATIC]-[BSIT] Uni LP
# 15 	 [USDC]-[BSIT] Uni LP
# 15 	 [USDC]-[JAVA] Uni LP
# 11 	 JAVA
# 11 	 WMATIC
# 11 	 WBTC
# 11 	 WETH
# 11 	 DAI
# 11 	 USDT
# 11 	 USDC
# 11 	 LINK
# 11 	 QUICK
# 11 	 AAVE
# 15 	 [WMATIC]-[JAVA] Uni LP
# 15 	 [WMATIC]-[PolyDoge] Uni LP
# 11 	 PolyDoge
# 15 	 [WMATIC]-[ROLL] SLP
# 11 	 ROLL
# 15 	 [WMATIC]-[ROLL] APE LP
# 10 	 TXNMINE
# 10 	 TRITON
# 15 	 [USDC]-[HAN] Uni LP
# 15 	 [WMATIC]-[HAN] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 15 	 [WMATIC]-[WETH] Uni LP
# 15 	 [WMATIC]-[WBTC] Uni LP
# 15 	 [WBTC]-[WETH] Uni LP
# 15 	 [WMATIC]-[QuickChart] Uni LP
# 15 	 [WMATIC]-[DPS] Uni LP
# 15 	 [WMATIC]-[MORDOR] Uni LP
# 15 	 [WMATIC]-[SIN] Uni LP
# 15 	 [WMATIC]-[HND] Uni LP
# 11 	 HAN
# 11 	 WMATIC
# 11 	 USDC
# 11 	 WBTC
# 11 	 WETH
# 11 	 USDT
# 11 	 DAI
# 15 	 [USDC]-[YETI] Uni LP
# 15 	 [WMATIC]-[YETI] Uni LP
# 11 	 YETI
# 15 	 [WMATIC]-[USDC] Uni LP
# 11 	 WMATIC
# 11 	 DAI
# 11 	 USDT
# 11 	 USDC
# 11 	 QUICK
# 11 	 WETH
# 11 	 WBTC
# 11 	 AAVE
# 11 	 SUSHI
# 10 	 FISH
# 11 	 LINK
# 15 	 [USDC]-[STONK] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 11 	 WMATIC
# 11 	 WBTC
# 11 	 WETH
# 11 	 QUICK
# 11 	 YLD
# 11 	 USDT
# 11 	 USDC
# 11 	 STONK
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [WBTC]-[USDC] Uni LP
# 15 	 [WMATIC]-[QUICK] Uni LP
# 15 	 [WMATIC]-[CNT] Uni LP
# 15 	 [USDC]-[CNT] Uni LP
# 15 	 [WETH]-[CNT] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [WMATIC]-[WETH] Uni LP
# 15 	 [WBTC]-[USDC] Uni LP
# 15 	 [WBTC]-[WETH] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 15 	 [WETH]-[USDT] Uni LP
# 15 	 [WETH]-[DAI] Uni LP
# 15 	 [WETH]-[AAVE] Uni LP
# 8 	 "code": -32603,
# No Pair
# 15 	 [USDC]-[HAWK] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [DAI]-[USDT] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 11 	 HAWK
# 11 	 PolyDoge
# 11 	 WMATIC
# 11 	 USDC
# 11 	 DAI
# 11 	 USDT
# 11 	 LINK
# 11 	 WBTC
# 11 	 WETH
# 11 	 QUICK
# 11 	 AAVE
# 10 	 RGEM
# 10 	 BLACKBRY
# 15 	 [WMATIC]-[CRAB] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [WMATIC]-[QUICK] Uni LP
# 15 	 [USDC]-[QUICK] Uni LP
# 15 	 [WBTC]-[WETH] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [WETH]-[USDT] Uni LP
# 15 	 [WETH]-[AAVE] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 11 	 USDC
# 11 	 USDT
# 11 	 AAVE
# 11 	 QUICK
# 10 	 miFARM
# 11 	 DAI
# 10 	 SUN
# 11 	 WETH
# 10 	 CAP
# 11 	 WBTC
# 11 	 SUSHI
# 11 	 QUICK
# 11 	 AAVE
# 11 	 USDC
# 11 	 DAI
# 15 	 [WBTC]-[WETH] Uni LP
# 15 	 [USDC]-[SUN] Uni LP
# 15 	 [WMATIC]-[SUN] Uni LP
# 15 	 [USDC]-[FOX] SLP
# 15 	 [WMATIC]-[FOX] SLP
# 11 	 FOX
# 15 	 [WMATIC]-[USDC] SLP
# 11 	 WMATIC
# 11 	 USDT
# 15 	 [USDC]-[WETH] SLP
# 11 	 WETH
# 15 	 [WMATIC]-[WETH] SLP
# 15 	 [USDC]-[DAI] SLP
# 11 	 DAI
# 11 	 WBTC
# 15 	 [AURORA]-[USDC] Uni LP
# 11 	 AURORA
# 11 	 WMATIC
# 11 	 WBTC
# 11 	 WETH
# 11 	 USDT
# 11 	 USDC
# 11 	 DAI
# 15 	 [AURORA]-[WMATIC] Uni LP
# 15 	 [AURORA]-[WMATIC] DFYN LP
# 15 	 [AURORA]-[USDC] DFYN LP
# 15 	 [USDC]-[NEBULA] DFYN LP
# 10 	 IRON
# 15 	 [AURORA]-[WMATIC] Uni LP
# 15 	 [WMATIC]-[PZAP] Uni LP
# 15 	 [WMATIC]-[SOLAR] Uni LP
# 11 	 SOLAR
# 15 	 [AURORA]-[WMATIC] Uni LP
# 11 	 NEBULA
# 11 	 WMATIC
# 11 	 WBTC
# 11 	 WETH
# 11 	 USDT
# 11 	 USDC
# 11 	 DAI
# 15 	 [WMATIC]-[SOLAR] DFYN LP
# 15 	 [USDC]-[NEBULA] DFYN LP
# 11 	 WMATIC
# 11 	 WBTC
# 11 	 WETH
# 11 	 USDC
# 11 	 SUSHI
# 10 	 ACORN
# 11 	 DAI
# 15 	 [USDC]-[ACORN] Uni LP
# 17 	 [USDC]-[NIOX] Uni LP
# 17 	 [WMATIC]-[USDC] Uni LP
# 17 	 [USDC]-[WETH] Uni LP
# 17 	 [USDC]-[pBTC] Uni LP
# 17 	 [USDC]-[DAI] Uni LP
# 17 	 [USDC]-[USDT] Uni LP
# 17 	 [NIOX]-[renBTC] Uni LP
# 17 	 [AGIX]-[NIOX] Uni LP
# 17 	 [SDAO]-[NIOX] Uni LP
# 10 	 FUNK
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [FUNK]-[USDC] Uni LP
# 15 	 [WMATIC]-[FUNK] Uni LP
# 11 	 USDC
# 15 	 [USDC]-[USDT] Uni LP
# 11 	 USDT
# 11 	 WMATIC
# 11 	 QUICK
# 11 	 DAI
# 11 	 WBTC
# 11 	 AAVE
# 11 	 WETH
# 11 	 LINK
# 10 	 YELD
# 10 	 BONE
# 10 	 pWINGS
# 15 	 [USDC]-[WETH] Uni LP
# 10 	 miMATIC
# 15 	 [WMATIC]-[MAX] Uni LP
# 11 	 MAX
# 11 	 WMATIC
# 11 	 USDC
# 11 	 USDT
# 15 	 [USDC]-[MAX] Uni LP
# 11 	 WBTC
# 11 	 WETH
# 11 	 DAI
# 11 	 QUICK
# 15 	 [USDC]-[BEAR] Uni LP
# 15 	 [WMATIC]-[BEAR] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 11 	 BEAR
# 11 	 WETH
# 11 	 DAI
# 11 	 AAVE
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [WMATIC]-[WETH] Uni LP
# 15 	 [WMATIC]-[QUICK] Uni LP
# 15 	 [USDC]-[QUICK] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 15 	 [WBTC]-[USDC] Uni LP
# 11 	 WMATIC
# 11 	 QUICK
# 11 	 PolyGame
# 15 	 [WMATIC]-[PolyGame] Uni LP
# 15 	 [WBTC]-[WETH] Uni LP
# 15 	 [WMATIC]-[WETH] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [WMATIC]-[QUICK] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [SUSHI]-[WMATIC] SLP
# 15 	 [USDC]-[IRON] SLP
# 15 	 [WETH]-[AAVE] SLP
# 11 	 POLYTOKEN
# 11 	 WMATIC
# 11 	 WBTC
# 11 	 WETH
# 11 	 QUICK
# 11 	 USDT
# 11 	 USDC
# 11 	 LINK
# 11 	 DAI
# 15 	 [USDC]-[POLYTOKEN] SLP
# 15 	 [WMATIC]-[POLYTOKEN] SLP
# 15 	 [WMATIC]-[USDC] SLP
# 15 	 [USDC]-[POLYTOKEN] Uni LP
# 15 	 [WMATIC]-[POLYTOKEN] Uni LP
# 10 	 BONE
# 15 	 [WMATIC]-[BONE] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[BONE] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [WMATIC]-[WETH] Uni LP
# 15 	 [USDC]-[miMATIC] Uni LP
# 15 	 [WBTC]-[USDC] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 15 	 [DAI]-[USDT] Uni LP
# 11 	 WMATIC
# 11 	 WETH
# 11 	 WBTC
# 11 	 QUICK
# 11 	 USDC
# 11 	 USDT
# 11 	 DAI
# 11 	 AAVE
# 11 	 LINK
# 11 	 miMATIC
# 15 	 [WMATIC]-[BONE] SLP
# 15 	 [WMATIC]-[BONE] APE LP
# 15 	 [polyBUNNY]-[WETH] Uni LP
# 11 	 polyBUNNY
# 10 	 FISH
# 11 	 PolyDoge
# 15 	 [WMATIC]-[BPUL] Uni LP
# 15 	 [WMATIC]-[BNT] Uni LP
# 15 	 [BONE]-[SPADE] SLP
# 15 	 [WMATIC]-[BONE] Uni LP
# 15 	 [USDC]-[BONE] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 15 	 [USDC]-[miMATIC] Uni LP
# 15 	 [DAI]-[USDT] Uni LP
# 15 	 [CAKE]-[USDC] Uni LP
# 15 	 [USDC]-[BAKE] Uni LP
# 15 	 [WMATIC]-[BAKE] Uni LP
# 15 	 [CREAM]-[USDC] Uni LP
# 15 	 [BISCUIT]-[USDC] Uni LP
# 11 	 CAKE
# 10 	 BREAD
# 11 	 WMATIC
# 11 	 USDC
# 11 	 WBTC
# 11 	 WETH
# 11 	 QUICK
# 11 	 USDT
# 11 	 DAI
# 15 	 [USDC]-[ABUNNY] Uni LP
# 15 	 [WMATIC]-[ABUNNY] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 11 	 ABUNNY
# 11 	 WBTC
# 15 	 [WBTC]-[WETH] Uni LP
# 11 	 AAVE
# 11 	 QUICK
# 15 	 [Falcon]-[USDC] Uni LP
# 15 	 [Falcon]-[WMATIC] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [WBTC]-[USDC] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 11 	 Falcon
# 11 	 WMATIC
# 11 	 DAI
# 11 	 WETH
# 11 	 QUICK
# 11 	 WBTC
# 11 	 LINK
# 11 	 PolyDoge
# 11 	 AAVE
# 15 	 [WMATIC]-[PolyDoge] Uni LP
# 15 	 [WMATIC]-[WETH] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 10 	 GOON
# 11 	 PolyDoge
# 11 	 WMATIC
# 11 	 WETH
# 11 	 USDT
# 11 	 USDC
# 11 	 DAI
# 15 	 [WMATIC]-[GOON] Uni LP
# 15 	 [WMATIC]-[Shield] Uni LP
# 11 	 Shield
# 11 	 WMATIC
# 11 	 USDC
# 11 	 USDT
# 15 	 [USDC]-[Shield] Uni LP
# 11 	 WBTC
# 11 	 WETH
# 11 	 DAI
# 11 	 QUICK
# 10 	 MAX
# 15 	 [USDC]-[MAX] Uni LP
# 10 	 pWINGS
# 15 	 [WMATIC]-[pWINGS] Uni LP
# 15 	 [WMATIC]-[WETH] Uni LP
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [WETH]-[USDT] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [WMATIC]-[USDT] Uni LP
# 15 	 [WBTC]-[USDT] Uni LP
# 15 	 [WMATIC]-[PAUTO] Uni LP
# 15 	 [WBTC]-[WETH] Uni LP
# 15 	 [USDC]-[USDT] Uni LP
# 15 	 [USDC]-[DAI] Uni LP
# 15 	 [WMATIC]-[PFORCE] Uni LP
# 15 	 [USDC]-[pSWAMP] Uni LP
# 11 	 PFORCE
# 11 	 Snake
# 11 	 WETH
# 11 	 WBTC
# 11 	 WMATIC
# 15 	 [USDC]-[Snake] Uni LP
# 10 	 USDT
# 11 	 QUICK
# 11 	 USDT
# 11 	 Krill
# 11 	 DAI
# 10 	 CAVE
# 11 	 WMATIC
# 11 	 USDC
# 11 	 USDT
# 15 	 [CAVE]-[USDC] Uni LP
# 11 	 WBTC
# 11 	 WETH
# 11 	 DAI
# 11 	 QUICK
# 10 	 MAX
# 15 	 [WMATIC]-[CAVE] Uni LP
# 15 	 [USDC]-[MICE] Uni LP
# 15 	 [WMATIC]-[MICE] Uni LP
# 11 	 MICE
# 11 	 WMATIC
# 11 	 QUICK
# 11 	 USDC
# 11 	 WETH
# 11 	 LINK
# 11 	 AAVE
# 11 	 SUSHI
# 15 	 [QUICK]-[MICE] Uni LP
# 11 	 BULL
# 11 	 WMATIC
# 11 	 WBTC
# 11 	 WETH
# 11 	 QUICK
# 11 	 USDC
# 15 	 [WMATIC]-[BULL] Uni LP
# 15 	 [USDC]-[BULL] Uni LP
# 15 	 [QUICK]-[BULL] Uni LP
# 15 	 [WMATIC]-[WETH] Uni LP
# 15 	 [WETH]-[USDT] Uni LP
# 15 	 [USDC]-[GBULL] Uni LP
# 11 	 WBTC
# 11 	 WETH
# 11 	 QUICK
# 11 	 WMATIC
# 11 	 USDC
# 11 	 USDT
# 11 	 DAI
# 11 	 GBULL
# 15 	 [USDC]-[WETH] Uni LP
# 15 	 [WMATIC]-[USDC] Uni LP
# 15 	 [WMATIC]-[GBULL] Uni LP
# 15 	 [GBULL]-[QUICK] Uni LP
# 15 	 [GBULL]-[WETH] Uni LP
# 15 	 [BULL]-[USDC] Uni LP
# 15 	 [WMATIC]-[BULL] Uni LP
# 15 	 [GBULL]-[miMATIC] Uni LP
# 15 	 [USDC]-[GBULL] Uni LP
# 15 	 [WMATIC]-[GBULL] Uni LP
# 15 	 [GBULL]-[QUICK] Uni LP
# 15 	 [GBULL]-[WETH] Uni LP
# 15 	 [BULL]-[USDC] Uni LP
# 15 	 [WMATIC]-[BULL] Uni LP
# 15 	 [BULL]-[TITAN] Uni LP
# 15 	 [GBULL]-[TITAN] Uni LP
# 15 	 [USDC]-[TITAN] Uni LP
# 15 	 [WMATIC]-[TITAN] Uni LP
# 12 	 BAG
# 12 	 WAVAX
# 17 	 [BAG]-[WAVAX] Uni LP
# 17 	 [BAG]-[DAI] Uni LP
# 17 	 [BAG]-[ETH] Uni LP
# 17 	 [BAG]-[LINK] Uni LP
# 17 	 [BAG]-[USDT] Uni LP
# 17 	 [WBTC]-[BAG] Uni LP
# 17 	 [WAVAX]-[LINK] Uni LP
# 17 	 [WAVAX]-[USDT] Uni LP
# 17 	 [WAVAX]-[DAI] Uni LP
# 17 	 [WAVAX]-[ETH] Uni LP
# 17 	 [WBTC]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[USDT] PGL
# 15 	 [WAVAX]-[PEFI] PGL
# 15 	 [PNG]-[PEFI] PGL
# 15 	 [BIRD]-[WAVAX] PGL
# 15 	 [BIRD]-[USDT] PGL
# 15 	 [PNG]-[WAVAX] PGL
# 17 	 [ZERO]-[zUSDC] Uni LP
# 17 	 [ZERO]-[WAVAX] Uni LP
# 17 	 [ZERO]-[zETH] Uni LP
# 17 	 [ZERO]-[zUSDT] Uni LP
# 17 	 [ZERO]-[zBTC] Uni LP
# 17 	 [ZERO]-[zUNI] Uni LP
# 17 	 [ZERO]-[zSUSHI] Uni LP
# 17 	 [ZERO]-[zDAI] Uni LP
# 10 	 sBAMBOO-V2
# 15 	 [BAMBOO-V2]-[WAVAX] PGL
# 15 	 [BAMBOO-V2]-[WAVAX] Pure Swap LP
# 15 	 [BAMBOO-V2]-[ETH] Pure Swap LP
# 15 	 [WBTC]-[BAMBOO-V2] Pure Swap LP
# 15 	 [BAMBOO-V2]-[LINK] Pure Swap LP
# 15 	 [SUSHI]-[BAMBOO-V2] Pure Swap LP
# 15 	 [BAMBOO-V2]-[SNOB] Pure Swap LP
# 15 	 [WAVAX]-[ETH] Pure Swap LP
# 15 	 [WAVAX]-[USDT] Pure Swap LP
# 15 	 [WBTC]-[WAVAX] Pure Swap LP
# 15 	 [BAMBOO-V2]-[USDT] Pure Swap LP
# 15 	 [BAMBOO-V2]-[DAI] Pure Swap LP
# 10 	 BURN
# 17 	 [WAVAX]-[ETH] PGL
# 17 	 [WBTC]-[WAVAX] PGL
# 17 	 [WAVAX]-[LINK] PGL
# 17 	 [PNG]-[WAVAX] PGL
# 17 	 [WAVAX]-[USDT] PGL
# 17 	 [SUSHI]-[WAVAX] PGL
# 17 	 [WAVAX]-[DAI] PGL
# 17 	 [AAVE]-[WAVAX] PGL
# 17 	 [WAVAX]-[UNI] PGL
# 17 	 [YFI]-[WAVAX] PGL
# 17 	 [PNG]-[ETH] PGL
# 17 	 [WBTC]-[PNG] PGL
# 17 	 [PNG]-[LINK] PGL
# 17 	 [PNG]-[USDT] PGL
# 17 	 [SUSHI]-[PNG] PGL
# 17 	 [PNG]-[DAI] PGL
# 17 	 [PNG]-[AAVE] PGL
# 17 	 [PNG]-[UNI] PGL
# 17 	 [PNG]-[YFI] PGL
# 17 	 [PNG]-[SPORE] PGL
# 17 	 [SPORE]-[WAVAX] PGL
# 9 	 "code": -32603,
# No Pair
# 15 	 [WAVAX]-[USDT] Uni LP
# 15 	 [WAVAX]-[ETH] Uni LP
# 15 	 [WAVAX]-[DAI] Uni LP
# 15 	 [COM]-[WAVAX] Uni LP
# 15 	 [WBTC]-[WAVAX] Uni LP
# 15 	 [xCOM]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[COM+] Uni LP
# 15 	 [COM+]-[USDT] Uni LP
# 15 	 [BNB]-[COM+] Uni LP
# 15 	 [COM+]-[HT] Uni LP
# 15 	 [AVAX+]-[COM+] Uni LP
# 10 	 GDL
# 15 	 [WAVAX]-[GDL] PGL
# 10 	 gondolaRenBtc
# 10 	 gondolaWETHe
# 10 	 gondolaUSDTe
# 10 	 gondolaDAIe
# 10 	 gondolaDAIeUSDTe
# 10 	 gondolaWBTCe
# 17 	 [WAVAX]-[ETH] Uni LP
# 17 	 [CNR]-[WAVAX] Uni LP
# 17 	 [WAVAX]-[USDT] Uni LP
# 17 	 [WAVAX]-[LINK] Uni LP
# 17 	 [PNG]-[WAVAX] Uni LP
# 17 	 [CNR]-[USDT] Uni LP
# 17 	 [CNR]-[ETH] Uni LP
# 17 	 [CNR]-[LINK] Uni LP
# 17 	 [PNG]-[CNR] Uni LP
# 12 	 CNR
# 12 	 WAVAX
# 17 	 [YTS]-[WAVAX] Uni LP
# 17 	 [WAVAX]-[ETH] Uni LP
# 17 	 [WAVAX]-[USDT] Uni LP
# 17 	 [YTS]-[ETH] Uni LP
# 17 	 [YTS]-[USDT] Uni LP
# 17 	 [YTS]-[PNG] Uni LP
# 17 	 [WAVAX]-[ELK] ELK LP
# 17 	 [DAI]-[ELK] ELK LP
# 17 	 [WBTC]-[ELK] ELK LP
# 17 	 [ELK]-[ETH] ELK LP
# 17 	 [LINK]-[ELK] ELK LP
# 17 	 [USDT]-[ELK] ELK LP
# 17 	 [SPORE]-[ELK] ELK LP
# 17 	 [PNG]-[ELK] ELK LP
# 17 	 [JOE]-[ELK] ELK LP
# 17 	 [AVE]-[ELK] ELK LP
# 17 	 [SUSHI]-[ELK] ELK LP
# 17 	 [AAVE]-[ELK] ELK LP
# 17 	 [XAVA]-[ELK] ELK LP
# 17 	 [VSO]-[ELK] ELK LP
# 17 	 [SNOB]-[ELK] ELK LP
# 15 	 [JOE]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[ETH] Uni LP
# 15 	 [WAVAX]-[USDT] Uni LP
# 15 	 [WBTC]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[LINK] Uni LP
# 15 	 [PNG]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[XAVA] Uni LP
# 15 	 [WAVAX]-[SNOB] Uni LP
# 15 	 [WAVAX]-[PEFI] Uni LP
# 15 	 [SPORE]-[WAVAX] Uni LP
# 15 	 [VSO]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[ELK] Uni LP
# 15 	 [JOE]-[USDT] Uni LP
# 15 	 [HUSKY]-[WAVAX] Uni LP
# 15 	 [DAI]-[USDT] Uni LP
# 15 	 [LYD]-[WAVAX] Uni LP
# 15 	 [WBTC]-[USDT] Uni LP
# 15 	 [USDT]-[ETH] Uni LP
# 15 	 [LINK]-[USDT] Uni LP
# 15 	 [WET]-[WAVAX] Uni LP
# 15 	 [SHERPA]-[WAVAX] Uni LP
# 10 	 xJOE
# 15 	 [YAK]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[PEFI] PGL
# 15 	 [WAVAX]-[ETH] PGL
# 15 	 [PNG]-[PEFI] PGL
# 15 	 [SNOB]-[PEFI] PGL
# 15 	 [SUSHI]-[PEFI] PGL
# 15 	 [DAI]-[PEFI] PGL
# 15 	 [LINK]-[PEFI] PGL
# 8 	 xPEFI Price: $2.37 Total Supply: 1527395.0564 TVL: $3,626,024.87
# No Pair
# 9 	 [DAI]-[PEFI] PGL
# 9 	 [PNG]-[WAVAX] PGL
# 9 	 [WAVAX]-[PEFI] PGL
# 9 	 [SUSHI]-[PEFI] PGL
# 9 	 [PNG]-[PEFI] PGL
# 9 	 [LINK]-[PEFI] PGL
# 9 	 [WAVAX]-[ETH] PGL
# 13 	 [SNOB]-[PEFI] PGL
# 9 	 [WAVAX]-[ETH] Uni LP
# 9 	 [LYD]-[USDT] Uni LP
# 9 	 [LYD]-[PNG] Uni LP
# 9 	 [WAVAX]-[ETH] PGL
# 9 	 [WAVAX]-[LINK] PGL
# 10 	 OLIVE
# 15 	 [OLIVE]-[WAVAX] Uni LP
# 15 	 [OLIVE]-[USDT] Uni LP
# 15 	 [WAVAX]-[USDT] Uni LP
# 15 	 [SUSHI]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[ETH] Uni LP
# 15 	 [WBTC]-[WAVAX] Uni LP
# 15 	 [PNG]-[WAVAX] Uni LP
# 15 	 [DAI]-[USDT] Uni LP
# 15 	 [SPORE]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[MKC] Uni LP
# 15 	 [HUSKY]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[NEKO] Uni LP
# 15 	 [WAVAX]-[XAVA] Uni LP
# 15 	 [WAVAX]-[🐆] Uni LP
# 15 	 [AVE]-[WAVAX] Uni LP
# 15 	 [LAIKA]-[WAVAX] Uni LP
# 15 	 [BUSD]-[USDT] Uni LP
# 15 	 [CYCLE]-[WAVAX] Uni LP
# 15 	 [YAK]-[WAVAX] Uni LP
# 10 	 LYD
# 15 	 [WAVAX]-[USDT] Uni LP
# 15 	 [WAVAX]-[ETH] Uni LP
# 15 	 [LYD]-[USDT] Uni LP
# 15 	 [LYD]-[WAVAX] Uni LP
# 15 	 [SUSHI]-[WAVAX] Uni LP
# 15 	 [LYD]-[PNG] Uni LP
# 15 	 [WBTC]-[WAVAX] Uni LP
# 15 	 [LYD]-[ETH] Uni LP
# 15 	 [LYD]-[SNOB] Uni LP
# 15 	 [DAI]-[USDT] Uni LP
# 15 	 [YAK]-[WAVAX] Uni LP
# 15 	 [WAVAX]-[LINK] Uni LP
# 17 	 [AVME]-[WAVAX] PGL
# 10 	 mSNOWCONES

# %%
pair_df[pair_df['network']=='BSC']
# Out:
#         pair1 pair2     apr        tvl                                where  \
# 1486     xSAT  WBNB  195.24     272.51             https://lazymint.finance
# 1487     WBNB  BUSD   47.46    4484.46             https://lazymint.finance
# 1488     BTCB  WBNB   38.02    5597.71             https://lazymint.finance
# 1489      ETH  WBNB  301.85     528.78             https://lazymint.finance
# 1490     USDT  BUSD    9.36   11369.72             https://lazymint.finance
# ...       ...   ...     ...        ...                                  ...
# 10193     BBQ  BUSD  264.19   34511.43  https://app.barbecueswapfinance.com
# 10194    USDC  BUSD   21.05  108280.37  https://app.barbecueswapfinance.com
# 10195  BANANA        202.92   11233.20  https://app.barbecueswapfinance.com
# 10196    BTCB         49.91   60891.67  https://app.barbecueswapfinance.com
# 10197     BFT  WBNB  385.53    5912.36  https://app.barbecueswapfinance.com
#
#       fee network
# 1486    0     BSC
# 1487    0     BSC
# 1488    0     BSC
# 1489    0     BSC
# 1490    0     BSC
# ...    ..     ...
# 10193   0     BSC
# 10194   3     BSC
# 10195   3     BSC
# 10196   3     BSC
# 10197   3     BSC
#
# [8712 rows x 7 columns]

# %%
pair_df[pair_df['fee'].notna()]
# Out:
#             pair1  pair2     apr        tvl                           where  \
# 0            MAHA   WETH    0.00  850318.83        https://www.arthcoin.com
# 1            ARTH    DAI    0.00   13351.36        https://www.arthcoin.com
# 2            ARTH           0.00     642.97        https://www.arthcoin.com
# 3       Boardroom              0       None        https://www.arthcoin.com
# 4       Boardroom              0       None        https://www.arthcoin.com
# ...           ...    ...     ...        ...                             ...
# 13879         DAI   USDT   40.60   13253.56       https://www.lydia.finance
# 13880         YAK  WAVAX   81.47   78736.95       https://www.lydia.finance
# 13881       WAVAX   LINK  533.11   12028.14       https://www.lydia.finance
# 13882        AVME  WAVAX  194.53  346703.53                 https://avme.io
# 13883  mSNOWCONES              0       0.00  https://snowball.network/earn/
#
#       fee network
# 0       0     ETH
# 1       0     ETH
# 2       0     ETH
# 3       0     ETH
# 4       0     ETH
# ...    ..     ...
# 13879   0    AVAX
# 13880   0    AVAX
# 13881   0    AVAX
# 13882   0    AVAX
# 13883   0    AVAX
#
# [13884 rows x 7 columns]

# %%
pair_df['apy'] = np.nan

# %%
def get_symbol_mapping(pair):
    if pair is not None:
        return sm[pair.strip()] if pair.strip() in sm else pair.strip()
    else:
        return ""

def update_apr(apr):
    apr = f"{apr}".replace("%", "")
    if len(apr) == 0 or "nan" == apr:
        return np.nan
    else:
        return apr

# %%
pair_df['type_of_agriculture'] = 'FARM'
pair_df = pair_df.append(df).reset_index(drop=True)

# %% [markdown]
# Addidtional Pairs

# %%
ext_grades = pd.DataFrame([])

# %%
ap_sh1_df = pd.read_excel("Addition_Yield_Scrape_8_13_formatted.xlsx", "Additional Staking Yields")
ext_farm_grades1 = ap_sh1_df[['Website', 'network', 'Grade']]
ext_farm_grades1.columns = ['Website', 'Network', 'Grade']
ap_sh1_df = ap_sh1_df[['pair1', 'pair2', 'APR', 'APY', 'fee', 'network', 'type_of_agriculture', 'dex', 'tvl']]
ap_sh1_df.columns = ['pair1', 'pair2', 'apr', 'apy', 'fee', 'network', 'type_of_agriculture', 'where', 'tvl']
ap_sh1_df['pair1'] = ap_sh1_df['pair1'].fillna('')
ap_sh1_df['pair2'] = ap_sh1_df['pair2'].fillna('')
ap_sh1_df['apy'] = np.nan
ap_sh2_df = pd.read_excel("Addition_Yield_Scrape_8_13_formatted.xlsx", "Visor Manual Scrub")
ext_farm_grades2 = ap_sh2_df[['dex', 'network.1', 'Grade']]
ext_farm_grades2.columns = ['Website', 'Network', 'Grade']
ap_sh2_df = ap_sh2_df[['pair1', 'pair2', 'apr', 'fee', 'network', 'tvl', 'type_of_agriculture', 'dex']]
ap_sh2_df.columns = ['pair1', 'pair2', 'apr', 'fee', 'network', 'tvl', 'type_of_agriculture', 'where']
ap_sh2_df['apy'] = np.nan
ap_sh2_df['pair1'] = ap_sh2_df['pair1'].fillna('')
ap_sh2_df['pair2'] = ap_sh2_df['pair2'].fillna('')
ext_pair_df = ap_sh1_df.append(ap_sh2_df).reset_index(drop=True)
ext_pair_df['network'] = ext_pair_df['network'].fillna('')
ext_grades = ext_farm_grades1.append(ext_farm_grades2).drop_duplicates().reset_index(drop=True)

# %%
# pair_df = ext_pair_df
pair_df = pair_df.append(ext_grades)

# %%
ext_grades
# Out:
#                                          Website  Network Grade
# 0                      https://88mph.app/rewards      NaN     B
# 1                    https://account.aleph.im/#/      NaN     B
# 2            https://app.alpacafinance.org/stake      NaN     B
# 3        https://homora-bsc.alphafinance.io/earn      NaN     B
# 4            https://app.anchorprotocol.com/earn      NaN     B
# 5              https://stakefi.ankr.com/features      NaN     B
# 6       https://app.barnbridge.com/yield-farming      NaN     B
# 7                            https://belt.fi/bsc      NaN     B
# 8            https://www.convexfinance.com/stake      NaN     B
# 9                https://app.cream.finance/stake      NaN     B
# 10             https://ellipsis.finance/stakeeps      NaN     B
# 11            https://staking.equalizer.finance/      NaN     B
# 12                   https://app.fei.money/stake      NaN     B
# 13                    https://defi.instadapp.io/      NaN     B
# 14             https://www.inverse.finance/stake      NaN     B
# 15                     https://lido.fi/#networks      NaN     B
# 16                    https://mercurial.finance/      NaN     B
# 17                   https://eth.mirror.finance/      NaN     B
# 18               https://mstable.app/#/musd/save      NaN     B
# 19                    https://app.nerve.fi/stake      NaN     B
# 20                    https://nominex.io/my/nmx/      NaN     B
# 21             https://www.olympusdao.finance/#/      NaN     B
# 22          https://trade.orionprotocol.io/pools      NaN     B
# 23                        https://perp.exchange/      NaN     B
# 24          https://app.pooltogether.com/rewards      NaN     B
# 25                   https://raydium.io/staking/      NaN     B
# 26       https://staking.synthetix.io/earn/claim      NaN     B
# 27               https://tokenlon.im/lon/staking      NaN     B
# 28  https://liquidity.wing.finance/pwing-eth-slp      NaN     B
# 29                    https://www.visor.finance/      NaN     B

# %%
pair_df['apr'] = pair_df['apr'].apply(lambda x: update_apr(x))
pair_df['pair1'] = pair_df['pair1'].apply(lambda x: sm[x.strip()] if x.strip() in sm else x.strip())
pair_df['pair2'] = pair_df['pair2'].apply(lambda x: get_symbol_mapping(x))

# %%
pair_df = pair_df.drop(pair_df[(pair_df['pair1'] == '') & (pair_df['pair2'] == '')].index)
pair_df[pair_df['pair1'] == '']
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, apr, apy, fee, network, type_of_agriculture, where, tvl]
# Index: []

# %%
def convert_apr_to_apy(pair_df):
    tmp_df = pair_df[pair_df['apy'].isna()]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apr = row['apr']
        if pd.isnull( apr):
            return
        if apr is not None and len(apr.strip()):
            apr = float(apr.replace(',',''))
        else:
            apr = 0
        try:
            pair_df.loc[index, 'apy'] = ((1+(apr/100)/365)**365-1)*100
        except:
            pair_df.loc[index, 'apy'] = np.nan
    return
            
def convert_apy_to_apr(pair_df):
    tmp_df = pair_df[(pair_df['apr'].isnull())]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apy = row['apy']
        if pd.isnull( apy):
            return
        if apy is not None and len(apy.strip()):
            apy = float(apy.replace(',',''))
        else:
            apy = 0
        try:
            pair_df.loc[index, 'apr'] = (((1+(apy/100))**(1/365)-1)*365)*100
        except:
            pair_df.loc[index, 'apr'] = np.nan
    return


convert_apr_to_apy(pair_df)
convert_apy_to_apr(pair_df)
# Out:
# (47, 9)
# (13, 9)

# %%
pair_df[pair_df['apy'].isna()]
# Out:
#      pair1 pair2     apr  apy  fee network type_of_agriculture  \
# 1    ALEPH           NaN  NaN    0                     Staking
# 2   ALPACA        0.2002  NaN    0                     Staking
# 3    ALPHA        0.0987  NaN    0                     Staking
# 4      ANC           NaN  NaN    0                     Staking
# 5     ANKR        0.0519  NaN    0                     Staking
# 6     BOND        1.0204  NaN    0                     Staking
# 7     BELT        0.8984  NaN    0                     Staking
# 8      CRV        0.6093  NaN    0                     Staking
# 9    CREAM           NaN  NaN    0                     Staking
# 10     EPS           NaN  NaN    0                     Staking
# 11     EQZ           NaN  NaN    0                     Staking
# 12     FEI        0.8824  NaN    0                     Staking
# 13    INST         0.035  NaN    0                     Staking
# 14     INV           NaN  NaN    0                     Staking
# 15     LDO         0.055  NaN    0                     Staking
# 16     MER           NaN  NaN    0                     Staking
# 17     MIR        0.6073  NaN    0                     Staking
# 18     MTA           NaN  NaN    0                     Staking
# 19     NRV           NaN  NaN    0                     Staking
# 20     NMX           NaN  NaN    0                     Staking
# 21     OHM           NaN  NaN    0                     Staking
# 22     ORN        0.4775  NaN    0                     Staking
# 23    PERP         0.336  NaN    0                     Staking
# 24    POOL        0.1899  NaN    0                     Staking
# 25     RAY        0.2943  NaN    0                     Staking
# 26     SNX        0.2409  NaN    0                     Staking
# 27     LON           NaN  NaN    0                     Staking
# 28    WING           NaN  NaN    0                     Staking
# 29    VISR          0.09  NaN    0                        FARM
# 30     OHM   ETH  9.9077  NaN    0                        FARM
# 31      MM   ETH  5.0732  NaN    0                        FARM
# 32    AAVE   ETH  0.4442  NaN    0                        FARM
# 33    COMP   ETH  0.4565  NaN    0                        FARM
# 34     MKR   ETH   0.365  NaN    0                        FARM
# 35     UNI   ETH  0.3022  NaN    0                        FARM
# 36    PERP   ETH  0.4326  NaN    0                        FARM
# 37   FORTH   ETH  0.5481  NaN    0                        FARM
# 38   MATIC   ETH   1.234  NaN    0                        FARM
# 39     ETH   TRU  0.2622  NaN    0                        FARM
# 40     ETH   CRV    3.34  NaN    0                        FARM
# 41     ETH   GTC  1.4819  NaN    0                        FARM
# 42    LINK   ETH  0.5618  NaN    0                        FARM
# 43     BTC   ETH   0.115  NaN    0                        FARM
# 44     DAI   ETH  0.5061  NaN    0                        FARM
# 45    USDC   ETH  0.6072  NaN    0                        FARM
# 46     ETH  USDT  0.3285  NaN    0                        FARM
#
#                                            where  tvl
# 1                    https://account.aleph.im/#/  NaN
# 2            https://app.alpacafinance.org/stake  NaN
# 3        https://homora-bsc.alphafinance.io/earn  NaN
# 4            https://app.anchorprotocol.com/earn  NaN
# 5              https://stakefi.ankr.com/features  NaN
# 6       https://app.barnbridge.com/yield-farming  NaN
# 7                            https://belt.fi/bsc  NaN
# 8            https://www.convexfinance.com/stake  NaN
# 9                https://app.cream.finance/stake  NaN
# 10             https://ellipsis.finance/stakeeps  NaN
# 11            https://staking.equalizer.finance/  NaN
# 12                   https://app.fei.money/stake  NaN
# 13                    https://defi.instadapp.io/  NaN
# 14             https://www.inverse.finance/stake  NaN
# 15                     https://lido.fi/#networks  NaN
# 16                    https://mercurial.finance/  NaN
# 17                   https://eth.mirror.finance/  NaN
# 18               https://mstable.app/#/musd/save  NaN
# 19                    https://app.nerve.fi/stake  NaN
# 20                    https://nominex.io/my/nmx/  NaN
# 21             https://www.olympusdao.finance/#/  NaN
# 22          https://trade.orionprotocol.io/pools  NaN
# 23                        https://perp.exchange/  NaN
# 24          https://app.pooltogether.com/rewards  NaN
# 25                   https://raydium.io/staking/  NaN
# 26       https://staking.synthetix.io/earn/claim  NaN
# 27               https://tokenlon.im/lon/staking  NaN
# 28  https://liquidity.wing.finance/pwing-eth-slp  NaN
# 29                    https://www.visor.finance/  NaN
# 30                    https://www.visor.finance/  NaN
# 31                    https://www.visor.finance/  NaN
# 32                    https://www.visor.finance/  NaN
# 33                    https://www.visor.finance/  NaN
# 34                    https://www.visor.finance/  NaN
# 35                    https://www.visor.finance/  NaN
# 36                    https://www.visor.finance/  NaN
# 37                    https://www.visor.finance/  NaN
# 38                    https://www.visor.finance/  NaN
# 39                    https://www.visor.finance/  NaN
# 40                    https://www.visor.finance/  NaN
# 41                    https://www.visor.finance/  NaN
# 42                    https://www.visor.finance/  NaN
# 43                    https://www.visor.finance/  NaN
# 44                    https://www.visor.finance/  NaN
# 45                    https://www.visor.finance/  NaN
# 46                    https://www.visor.finance/  NaN

# %%
pair_df[pair_df['apr'].isna()]
# Out:
#     pair1 pair2  apr  apy  fee network type_of_agriculture  \
# 1   ALEPH        NaN  NaN    0                     Staking
# 4     ANC        NaN  NaN    0                     Staking
# 9   CREAM        NaN  NaN    0                     Staking
# 10    EPS        NaN  NaN    0                     Staking
# 11    EQZ        NaN  NaN    0                     Staking
# 14    INV        NaN  NaN    0                     Staking
# 16    MER        NaN  NaN    0                     Staking
# 18    MTA        NaN  NaN    0                     Staking
# 19    NRV        NaN  NaN    0                     Staking
# 20    NMX        NaN  NaN    0                     Staking
# 21    OHM        NaN  NaN    0                     Staking
# 27    LON        NaN  NaN    0                     Staking
# 28   WING        NaN  NaN    0                     Staking
#
#                                            where  tvl
# 1                    https://account.aleph.im/#/  NaN
# 4            https://app.anchorprotocol.com/earn  NaN
# 9                https://app.cream.finance/stake  NaN
# 10             https://ellipsis.finance/stakeeps  NaN
# 11            https://staking.equalizer.finance/  NaN
# 14             https://www.inverse.finance/stake  NaN
# 16                    https://mercurial.finance/  NaN
# 18               https://mstable.app/#/musd/save  NaN
# 19                    https://app.nerve.fi/stake  NaN
# 20                    https://nominex.io/my/nmx/  NaN
# 21             https://www.olympusdao.finance/#/  NaN
# 27               https://tokenlon.im/lon/staking  NaN
# 28  https://liquidity.wing.finance/pwing-eth-slp  NaN

# %%
pair_df = pair_df.drop_duplicates()
pair_df
# Out:
#      pair1 pair2       apr       apy  fee network type_of_agriculture  \
# 0      MPH        0.064828  0.064849    0                     Staking
# 1    ALEPH             NaN       NaN    0                     Staking
# 2   ALPACA          0.2002       NaN    0                     Staking
# 3    ALPHA          0.0987       NaN    0                     Staking
# 4      ANC             NaN       NaN    0                     Staking
# 5     ANKR          0.0519       NaN    0                     Staking
# 6     BOND          1.0204       NaN    0                     Staking
# 7     BELT          0.8984       NaN    0                     Staking
# 8      CRV          0.6093       NaN    0                     Staking
# 9    CREAM             NaN       NaN    0                     Staking
# 10     EPS             NaN       NaN    0                     Staking
# 11     EQZ             NaN       NaN    0                     Staking
# 12     FEI          0.8824       NaN    0                     Staking
# 13    INST           0.035       NaN    0                     Staking
# 14     INV             NaN       NaN    0                     Staking
# 15     LDO           0.055       NaN    0                     Staking
# 16     MER             NaN       NaN    0                     Staking
# 17     MIR          0.6073       NaN    0                     Staking
# 18     MTA             NaN       NaN    0                     Staking
# 19     NRV             NaN       NaN    0                     Staking
# 20     NMX             NaN       NaN    0                     Staking
# 21     OHM             NaN       NaN    0                     Staking
# 22     ORN          0.4775       NaN    0                     Staking
# 23    PERP           0.336       NaN    0                     Staking
# 24    POOL          0.1899       NaN    0                     Staking
# 25     RAY          0.2943       NaN    0                     Staking
# 26     SNX          0.2409       NaN    0                     Staking
# 27     LON             NaN       NaN    0                     Staking
# 28    WING             NaN       NaN    0                     Staking
# 29    VISR            0.09       NaN    0                        FARM
# 30     OHM   ETH    9.9077       NaN    0                        FARM
# 31      MM   ETH    5.0732       NaN    0                        FARM
# 32    AAVE   ETH    0.4442       NaN    0                        FARM
# 33    COMP   ETH    0.4565       NaN    0                        FARM
# 34     MKR   ETH     0.365       NaN    0                        FARM
# 35     UNI   ETH    0.3022       NaN    0                        FARM
# 36    PERP   ETH    0.4326       NaN    0                        FARM
# 37   FORTH   ETH    0.5481       NaN    0                        FARM
# 38   MATIC   ETH     1.234       NaN    0                        FARM
# 39     ETH   TRU    0.2622       NaN    0                        FARM
# 40     ETH   CRV      3.34       NaN    0                        FARM
# 41     ETH   GTC    1.4819       NaN    0                        FARM
# 42    LINK   ETH    0.5618       NaN    0                        FARM
# 43     BTC   ETH     0.115       NaN    0                        FARM
# 44     DAI   ETH    0.5061       NaN    0                        FARM
# 45    USDC   ETH    0.6072       NaN    0                        FARM
# 46     ETH  USDT    0.3285       NaN    0                        FARM
#
#                                            where  tvl
# 0                      https://88mph.app/rewards  NaN
# 1                    https://account.aleph.im/#/  NaN
# 2            https://app.alpacafinance.org/stake  NaN
# 3        https://homora-bsc.alphafinance.io/earn  NaN
# 4            https://app.anchorprotocol.com/earn  NaN
# 5              https://stakefi.ankr.com/features  NaN
# 6       https://app.barnbridge.com/yield-farming  NaN
# 7                            https://belt.fi/bsc  NaN
# 8            https://www.convexfinance.com/stake  NaN
# 9                https://app.cream.finance/stake  NaN
# 10             https://ellipsis.finance/stakeeps  NaN
# 11            https://staking.equalizer.finance/  NaN
# 12                   https://app.fei.money/stake  NaN
# 13                    https://defi.instadapp.io/  NaN
# 14             https://www.inverse.finance/stake  NaN
# 15                     https://lido.fi/#networks  NaN
# 16                    https://mercurial.finance/  NaN
# 17                   https://eth.mirror.finance/  NaN
# 18               https://mstable.app/#/musd/save  NaN
# 19                    https://app.nerve.fi/stake  NaN
# 20                    https://nominex.io/my/nmx/  NaN
# 21             https://www.olympusdao.finance/#/  NaN
# 22          https://trade.orionprotocol.io/pools  NaN
# 23                        https://perp.exchange/  NaN
# 24          https://app.pooltogether.com/rewards  NaN
# 25                   https://raydium.io/staking/  NaN
# 26       https://staking.synthetix.io/earn/claim  NaN
# 27               https://tokenlon.im/lon/staking  NaN
# 28  https://liquidity.wing.finance/pwing-eth-slp  NaN
# 29                    https://www.visor.finance/  NaN
# 30                    https://www.visor.finance/  NaN
# 31                    https://www.visor.finance/  NaN
# 32                    https://www.visor.finance/  NaN
# 33                    https://www.visor.finance/  NaN
# 34                    https://www.visor.finance/  NaN
# 35                    https://www.visor.finance/  NaN
# 36                    https://www.visor.finance/  NaN
# 37                    https://www.visor.finance/  NaN
# 38                    https://www.visor.finance/  NaN
# 39                    https://www.visor.finance/  NaN
# 40                    https://www.visor.finance/  NaN
# 41                    https://www.visor.finance/  NaN
# 42                    https://www.visor.finance/  NaN
# 43                    https://www.visor.finance/  NaN
# 44                    https://www.visor.finance/  NaN
# 45                    https://www.visor.finance/  NaN
# 46                    https://www.visor.finance/  NaN

# %%
pair_df[pair_df['pair1'] == '']
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, apr, apy, fee, network, type_of_agriculture, where, tvl]
# Index: []

# %%
single_piar_df = pair_df[pair_df['pair2'] == ""].copy()
double_coin_pair_df = pair_df[pair_df['pair2'] != ""].copy()
tmp_df = double_coin_pair_df.copy()

# %%
tmp_df['tmp'] = tmp_df['pair1']
tmp_df['pair1'] = tmp_df['pair2']
tmp_df['pair2'] = tmp_df['tmp']
del tmp_df['tmp']

# %%
double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
# Out:
#     pair1  pair2     apr  apy  fee network type_of_agriculture  \
# 0    AAVE    ETH  0.4442  NaN    0                        FARM
# 1     BTC    ETH   0.115  NaN    0                        FARM
# 2    COMP    ETH  0.4565  NaN    0                        FARM
# 3     CRV    ETH    3.34  NaN    0                        FARM
# 4     DAI    ETH  0.5061  NaN    0                        FARM
# 5     ETH   AAVE  0.4442  NaN    0                        FARM
# 6     ETH    BTC   0.115  NaN    0                        FARM
# 7     ETH   COMP  0.4565  NaN    0                        FARM
# 8     ETH    CRV    3.34  NaN    0                        FARM
# 9     ETH    DAI  0.5061  NaN    0                        FARM
# 10    ETH  FORTH  0.5481  NaN    0                        FARM
# 11    ETH    GTC  1.4819  NaN    0                        FARM
# 12    ETH   LINK  0.5618  NaN    0                        FARM
# 13    ETH  MATIC   1.234  NaN    0                        FARM
# 14    ETH    MKR   0.365  NaN    0                        FARM
# 15    ETH     MM  5.0732  NaN    0                        FARM
# 16    ETH    OHM  9.9077  NaN    0                        FARM
# 17    ETH   PERP  0.4326  NaN    0                        FARM
# 18    ETH    TRU  0.2622  NaN    0                        FARM
# 19    ETH    UNI  0.3022  NaN    0                        FARM
# 20    ETH   USDC  0.6072  NaN    0                        FARM
# 21    ETH   USDT  0.3285  NaN    0                        FARM
# 22  FORTH    ETH  0.5481  NaN    0                        FARM
# 23    GTC    ETH  1.4819  NaN    0                        FARM
# 24   LINK    ETH  0.5618  NaN    0                        FARM
# 25  MATIC    ETH   1.234  NaN    0                        FARM
# 26    MKR    ETH   0.365  NaN    0                        FARM
# 27     MM    ETH  5.0732  NaN    0                        FARM
# 28    OHM    ETH  9.9077  NaN    0                        FARM
# 29   PERP    ETH  0.4326  NaN    0                        FARM
# 30    TRU    ETH  0.2622  NaN    0                        FARM
# 31    UNI    ETH  0.3022  NaN    0                        FARM
# 32   USDC    ETH  0.6072  NaN    0                        FARM
# 33   USDT    ETH  0.3285  NaN    0                        FARM
#
#                          where  tvl
# 0   https://www.visor.finance/  NaN
# 1   https://www.visor.finance/  NaN
# 2   https://www.visor.finance/  NaN
# 3   https://www.visor.finance/  NaN
# 4   https://www.visor.finance/  NaN
# 5   https://www.visor.finance/  NaN
# 6   https://www.visor.finance/  NaN
# 7   https://www.visor.finance/  NaN
# 8   https://www.visor.finance/  NaN
# 9   https://www.visor.finance/  NaN
# 10  https://www.visor.finance/  NaN
# 11  https://www.visor.finance/  NaN
# 12  https://www.visor.finance/  NaN
# 13  https://www.visor.finance/  NaN
# 14  https://www.visor.finance/  NaN
# 15  https://www.visor.finance/  NaN
# 16  https://www.visor.finance/  NaN
# 17  https://www.visor.finance/  NaN
# 18  https://www.visor.finance/  NaN
# 19  https://www.visor.finance/  NaN
# 20  https://www.visor.finance/  NaN
# 21  https://www.visor.finance/  NaN
# 22  https://www.visor.finance/  NaN
# 23  https://www.visor.finance/  NaN
# 24  https://www.visor.finance/  NaN
# 25  https://www.visor.finance/  NaN
# 26  https://www.visor.finance/  NaN
# 27  https://www.visor.finance/  NaN
# 28  https://www.visor.finance/  NaN
# 29  https://www.visor.finance/  NaN
# 30  https://www.visor.finance/  NaN
# 31  https://www.visor.finance/  NaN
# 32  https://www.visor.finance/  NaN
# 33  https://www.visor.finance/  NaN

# %%
summary = {
    "total_pairs": pair_df.shape[0],
"single_coin_pairs": single_piar_df.shape[0],
"double_coin_piars": double_coin_pair_df.shape[0],
"after_switching_coins_total_double_coin_pairs": double_coin_pair_df.shape[0] * 2,
"total_pairs_in_sheet": double_coin_pair_df.shape[0] * 2 + single_piar_df.shape[0]
}

# %%
summary
# Out:
# {'total_pairs': 47,
#  'single_coin_pairs': 30,
#  'double_coin_piars': 17,
#  'after_switching_coins_total_double_coin_pairs': 34,
#  'total_pairs_in_sheet': 64}

# %%
pair_df = double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
pair_df = single_piar_df.append(pair_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
pair_df = pair_df.drop(pair_df[pair_df['pair1'] == ''].index)
pair_df = pair_df.drop(pair_df[pair_df['pair1'] == '$0.00'].index)

# %%
pair_df
# Out:
#      pair1 pair2     apr  apy  fee network type_of_agriculture  \
# 0     AAVE   ETH  0.4442  NaN    0                        FARM
# 1    ALEPH           NaN  NaN    0                     Staking
# 2   ALPACA        0.2002  NaN    0                     Staking
# 3    ALPHA        0.0987  NaN    0                     Staking
# 4      ANC           NaN  NaN    0                     Staking
# ..     ...   ...     ...  ...  ...     ...                 ...
# 59     UNI   ETH  0.3022  NaN    0                        FARM
# 60    USDC   ETH  0.6072  NaN    0                        FARM
# 61    USDT   ETH  0.3285  NaN    0                        FARM
# 62    VISR          0.09  NaN    0                        FARM
# 63    WING           NaN  NaN    0                     Staking
#
#                                            where  tvl
# 0                     https://www.visor.finance/  NaN
# 1                    https://account.aleph.im/#/  NaN
# 2            https://app.alpacafinance.org/stake  NaN
# 3        https://homora-bsc.alphafinance.io/earn  NaN
# 4            https://app.anchorprotocol.com/earn  NaN
# ..                                           ...  ...
# 59                    https://www.visor.finance/  NaN
# 60                    https://www.visor.finance/  NaN
# 61                    https://www.visor.finance/  NaN
# 62                    https://www.visor.finance/  NaN
# 63  https://liquidity.wing.finance/pwing-eth-slp  NaN
#
# [64 rows x 9 columns]

# %%
pair_df['dex'] = pair_df['where']
pair_df['date'] = date 
del pair_df['where']

# %%
pair_df['dex'].unique().tolist()
# Out:
# ['https://www.visor.finance/',
#  'https://account.aleph.im/#/',
#  'https://app.alpacafinance.org/stake',
#  'https://homora-bsc.alphafinance.io/earn',
#  'https://app.anchorprotocol.com/earn',
#  'https://stakefi.ankr.com/features',
#  'https://belt.fi/bsc',
#  'https://app.barnbridge.com/yield-farming',
#  'https://app.cream.finance/stake',
#  'https://www.convexfinance.com/stake',
#  'https://ellipsis.finance/stakeeps',
#  'https://staking.equalizer.finance/',
#  'https://app.fei.money/stake',
#  'https://defi.instadapp.io/',
#  'https://www.inverse.finance/stake',
#  'https://lido.fi/#networks',
#  'https://tokenlon.im/lon/staking',
#  'https://mercurial.finance/',
#  'https://eth.mirror.finance/',
#  'https://88mph.app/rewards',
#  'https://mstable.app/#/musd/save',
#  'https://nominex.io/my/nmx/',
#  'https://app.nerve.fi/stake',
#  'https://www.olympusdao.finance/#/',
#  'https://trade.orionprotocol.io/pools',
#  'https://perp.exchange/',
#  'https://app.pooltogether.com/rewards',
#  'https://raydium.io/staking/',
#  'https://staking.synthetix.io/earn/claim',
#  'https://liquidity.wing.finance/pwing-eth-slp']

# %%
pair_df[pair_df['pair1'] == 'ETH']
# Out:
#    pair1  pair2     apr  apy  fee network type_of_agriculture  tvl  \
# 16   ETH   AAVE  0.4442  NaN    0                        FARM  NaN
# 17   ETH    BTC   0.115  NaN    0                        FARM  NaN
# 18   ETH   COMP  0.4565  NaN    0                        FARM  NaN
# 19   ETH    CRV    3.34  NaN    0                        FARM  NaN
# 20   ETH    DAI  0.5061  NaN    0                        FARM  NaN
# 21   ETH  FORTH  0.5481  NaN    0                        FARM  NaN
# 22   ETH    GTC  1.4819  NaN    0                        FARM  NaN
# 23   ETH   LINK  0.5618  NaN    0                        FARM  NaN
# 24   ETH  MATIC   1.234  NaN    0                        FARM  NaN
# 25   ETH    MKR   0.365  NaN    0                        FARM  NaN
# 26   ETH     MM  5.0732  NaN    0                        FARM  NaN
# 27   ETH    OHM  9.9077  NaN    0                        FARM  NaN
# 28   ETH   PERP  0.4326  NaN    0                        FARM  NaN
# 29   ETH    TRU  0.2622  NaN    0                        FARM  NaN
# 30   ETH    UNI  0.3022  NaN    0                        FARM  NaN
# 31   ETH   USDC  0.6072  NaN    0                        FARM  NaN
# 32   ETH   USDT  0.3285  NaN    0                        FARM  NaN
#
#                            dex       date
# 16  https://www.visor.finance/ 2021-08-10
# 17  https://www.visor.finance/ 2021-08-10
# 18  https://www.visor.finance/ 2021-08-10
# 19  https://www.visor.finance/ 2021-08-10
# 20  https://www.visor.finance/ 2021-08-10
# 21  https://www.visor.finance/ 2021-08-10
# 22  https://www.visor.finance/ 2021-08-10
# 23  https://www.visor.finance/ 2021-08-10
# 24  https://www.visor.finance/ 2021-08-10
# 25  https://www.visor.finance/ 2021-08-10
# 26  https://www.visor.finance/ 2021-08-10
# 27  https://www.visor.finance/ 2021-08-10
# 28  https://www.visor.finance/ 2021-08-10
# 29  https://www.visor.finance/ 2021-08-10
# 30  https://www.visor.finance/ 2021-08-10
# 31  https://www.visor.finance/ 2021-08-10
# 32  https://www.visor.finance/ 2021-08-10

# %%
farm_grades = pd.read_csv('Yield_grades.csv')
farm_grades
# Out:
#                Farm                      Website Network RugDoc / Indv. Grade
# 0              Aave             https://aave.com     ETH            NaN     A
# 1             Armor             https://armor.fi     ETH            NaN     A
# 2    UniSwap (Pool)                  uniswap.org     ETH            NaN     A
# 3              Aave             https://aave.com   MATIC            NaN     A
# 4             Sushi        https://app.sushi.com   MATIC            NaN     A
# ..              ...                          ...     ...            ...   ...
# 762             NaN  https://app.pickle.finance/   MATIC            NaN     D
# 763             NaN       https://polyfunky.com/   MATIC            NaN     F
# 764             NaN    https://www.helmet.insure     ETH            NaN     C
# 765             NaN  https://app.pendle.finance/     ETH            NaN     D
# 766             NaN        https://shibaswap.com     ETH            NaN     B
#
# [767 rows x 5 columns]

# %%
farm_grades = farm_grades[['Website', 'Network', 'Grade']]
farm_grades = farm_grades.append(ext_grades).reset_index(drop=True)
farm_grades = farm_grades.append({'Website': 'Sushi', 'Network': 'ETH', 'Grade': 'A'}, ignore_index=True)
farm_grades = farm_grades.append({'Website': 'https://app.sushi.com/farms/', 'Network': 'ETH', 'Grade': 'A'}, ignore_index=True)
farm_grades = farm_grades.append({'Website': 'Uniswap', 'Network': 'ETH', 'Grade': 'A'}, ignore_index=True)

# %%
pairs_farm_risk_df = pd.merge(pair_df, farm_grades, how='left', left_on=['dex'], right_on=['Website'])
pairs_farm_risk_df.to_csv('inhouse_farm_risk_yeild_report.csv')
pairs_farm_risk_df
# Out:
#      pair1 pair2     apr  apy  fee network type_of_agriculture  tvl  \
# 0     AAVE   ETH  0.4442  NaN    0                        FARM  NaN
# 1    ALEPH           NaN  NaN    0                     Staking  NaN
# 2   ALPACA        0.2002  NaN    0                     Staking  NaN
# 3    ALPHA        0.0987  NaN    0                     Staking  NaN
# 4      ANC           NaN  NaN    0                     Staking  NaN
# ..     ...   ...     ...  ...  ...     ...                 ...  ...
# 59     UNI   ETH  0.3022  NaN    0                        FARM  NaN
# 60    USDC   ETH  0.6072  NaN    0                        FARM  NaN
# 61    USDT   ETH  0.3285  NaN    0                        FARM  NaN
# 62    VISR          0.09  NaN    0                        FARM  NaN
# 63    WING           NaN  NaN    0                     Staking  NaN
#
#                                              dex       date  \
# 0                     https://www.visor.finance/ 2021-08-10
# 1                    https://account.aleph.im/#/ 2021-08-10
# 2            https://app.alpacafinance.org/stake 2021-08-10
# 3        https://homora-bsc.alphafinance.io/earn 2021-08-10
# 4            https://app.anchorprotocol.com/earn 2021-08-10
# ..                                           ...        ...
# 59                    https://www.visor.finance/ 2021-08-10
# 60                    https://www.visor.finance/ 2021-08-10
# 61                    https://www.visor.finance/ 2021-08-10
# 62                    https://www.visor.finance/ 2021-08-10
# 63  https://liquidity.wing.finance/pwing-eth-slp 2021-08-10
#
#                                          Website Network Grade
# 0                     https://www.visor.finance/     NaN     B
# 1                    https://account.aleph.im/#/     NaN     B
# 2            https://app.alpacafinance.org/stake     NaN     B
# 3        https://homora-bsc.alphafinance.io/earn     NaN     B
# 4            https://app.anchorprotocol.com/earn     NaN     B
# ..                                           ...     ...   ...
# 59                    https://www.visor.finance/     NaN     B
# 60                    https://www.visor.finance/     NaN     B
# 61                    https://www.visor.finance/     NaN     B
# 62                    https://www.visor.finance/     NaN     B
# 63  https://liquidity.wing.finance/pwing-eth-slp     NaN     B
#
# [64 rows x 13 columns]

# %%
pairs_farm_risk_df[(pairs_farm_risk_df['Website'].isna()) & (pairs_farm_risk_df['type_of_agriculture'] == 'POOL')]
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, apr, apy, fee, network, type_of_agriculture, tvl, dex, date, Website, Network, Grade]
# Index: []

# %%
unmapped_dexs_df = pairs_farm_risk_df[pairs_farm_risk_df['Website'].isna()][['dex', 'network']]
unmapped_dexs_df = unmapped_dexs_df.drop_duplicates().reset_index(drop=True)
if unmapped_dexs_df.shape[0] > 1:
    unmapped_dexs_df.to_csv('unmapped_dex.csv')
unmapped_dexs_df
# Out:
# Empty DataFrame
# Columns: [dex, network]
# Index: []

# %%
pairs_farm_risk_df[pairs_farm_risk_df['pair1'] == '']
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, apr, apy, fee, network, type_of_agriculture, tvl, dex, date, Website, Network, Grade]
# Index: []

# %%
pairs_farm_risk_df[pairs_farm_risk_df['dex'] =='https://polycat.finance']
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, apr, apy, fee, network, type_of_agriculture, tvl, dex, date, Website, Network, Grade]
# Index: []
