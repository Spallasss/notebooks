# %%
import requests
import pandas as pd
import pymysql
from datetime import datetime, timedelta
import traceback2
import time
import urllib.parse

# %%
def get_host_url(url):
    parsed_url = urllib.parse.urlparse(url)
    host_breakup = parsed_url.netloc.split('.')
#     print([url, f'{parsed_url.scheme}://{host_breakup[-2]}.{host_breakup[-1]}'])
    url = f'{parsed_url.scheme}://{host_breakup[-2]}.{host_breakup[-1]}'
    return url

# %% [markdown]
# ## CMC Symbols Info

# %%
api_key = "a86e3326-8c8d-434e-897a-5d6becbf1f35"

# %% [markdown]
# ### pull all symbols and id at CMC

# %%
def get_cmc_symbols_ids(url):
    payload = {
        'limit':5000,
#         'listing_status': 'active,inactive,untracked',
#         'start':7406
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': api_key
    }
    
    response = requests.get(url, params=payload, headers=headers).json()
    return response

def pull_cmc_cryptocurrency_meta_info(url, cryptocurrency_id):
    payload = {
        'aux':'urls,tags,status',
        'id': cryptocurrency_id
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': api_key
    }
    
    response = requests.get(url, params=payload, headers=headers).json()
    return response

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/map'
response = get_cmc_symbols_ids(url)

# %%
len(response['data'])
# Out:
# 4618

# %%
def parse_cmc_symbol_ids_response(json_response):
    parsed_cmc_symbol_ids_data = {}
    json_data = response['data']
    for json_obj in json_data:
        parsed_cmc_symbol_ids_data[json_obj['id']] = [json_obj['id'], json_obj['name'], json_obj['symbol'], json_obj['slug'], json_obj['is_active']]
    return parsed_cmc_symbol_ids_data

# %%
parsed_cmc_symbol_ids_data = parse_cmc_symbol_ids_response(response)

# %%
parsed_cmc_symbol_ids_data
# Out:
# {1: [1, 'Bitcoin', 'BTC', 'bitcoin', 1],
#  2: [2, 'Litecoin', 'LTC', 'litecoin', 1],
#  3: [3, 'Namecoin', 'NMC', 'namecoin', 1],
#  4: [4, 'Terracoin', 'TRC', 'terracoin', 1],
#  5: [5, 'Peercoin', 'PPC', 'peercoin', 1],
#  8: [8, 'Feathercoin', 'FTC', 'feathercoin', 1],
#  10: [10, 'Freicoin', 'FRC', 'freicoin', 1],
#  13: [13, 'Ixcoin', 'IXC', 'ixcoin', 1],
#  16: [16, 'WorldCoin', 'WDC', 'worldcoin', 1],
#  18: [18, 'Digitalcoin', 'DGC', 'digitalcoin', 1],
#  25: [25, 'Goldcoin', 'GLC', 'goldcoin', 1],
#  35: [35, 'Phoenixcoin', 'PXC', 'phoenixcoin', 1],
#  37: [37, 'Megacoin', 'MEC', 'megacoin', 1],
#  41: [41, 'Infinitecoin', 'IFC', 'infinitecoin', 1],
#  42: [42, 'Primecoin', 'XPM', 'primecoin', 1],
#  43: [43, 'Anoncoin', 'ANC', 'anoncoin', 1],
#  45: [45, 'CasinoCoin', 'CSC', 'casinocoin', 1],
#  50: [50, 'Emerald Crypto', 'EMD', 'emerald', 1],
#  52: [52, 'XRP', 'XRP', 'xrp', 1],
#  53: [53, 'Quark', 'QRK', 'quark', 1],
#  56: [56, 'Zetacoin', 'ZET', 'zetacoin', 1],
#  61: [61, 'TagCoin', 'TAG', 'tagcoin', 1],
#  64: [64, 'FLO', 'FLO', 'flo', 1],
#  66: [66, 'Nxt', 'NXT', 'nxt', 1],
#  67: [67, 'Unobtanium', 'UNO', 'unobtanium', 1],
#  69: [69, 'Datacoin', 'DTC', 'datacoin', 1],
#  72: [72, 'Deutsche eMark', 'DEM', 'deutsche-emark', 1],
#  74: [74, 'Dogecoin', 'DOGE', 'dogecoin', 1],
#  77: [77, 'Diamond', 'DMD', 'diamond', 1],
#  78: [78, 'HoboNickels', 'HBN', 'hobonickels', 1],
#  80: [80, 'Orbitcoin', 'ORB', 'orbitcoin', 1],
#  83: [83, 'Omni', 'OMNI', 'omni', 1],
#  87: [87, 'FedoraCoin', 'TIPS', 'fedoracoin', 1],
#  90: [90, 'Dimecoin', 'DIME', 'dimecoin', 1],
#  93: [93, '42-coin', '42', '42-coin', 1],
#  99: [99, 'Vertcoin', 'VTC', 'vertcoin', 1],
#  109: [109, 'DigiByte', 'DGB', 'digibyte', 1],
#  113: [113, 'SmartCoin', 'SMC', 'smartcoin', 1],
#  118: [118, 'ReddCoin', 'RDD', 'redd', 1],
#  122: [122, 'PotCoin', 'POT', 'potcoin', 1],
#  125: [125, 'Blakecoin', 'BLC', 'blakecoin', 1],
#  128: [128, 'Maxcoin', 'MAX', 'maxcoin', 1],
#  131: [131, 'Dash', 'DASH', 'dash', 1],
#  132: [132, 'Counterparty', 'XCP', 'counterparty', 1],
#  141: [141, 'MintCoin', 'MINT', 'mintcoin', 1],
#  145: [145, 'DopeCoin', 'DOPE', 'dopecoin', 1],
#  148: [148, 'Auroracoin', 'AUR', 'auroracoin', 1],
#  151: [151, 'Pesetacoin', 'PTC', 'pesetacoin', 1],
#  154: [154, 'Marscoin', 'MARS', 'marscoin', 1],
#  168: [168, 'Uniform Fiscal Object', 'UFO', 'uniform-fiscal-object', 1],
#  170: [170, 'BlackCoin', 'BLK', 'blackcoin', 1],
#  175: [175, 'Photon', 'PHO', 'photon', 1],
#  182: [182, 'Myriad', 'XMY', 'myriad', 1],
#  184: [184, 'DNotes', 'NOTE', 'dnotes', 1],
#  201: [201, 'Einsteinium', 'EMC2', 'einsteinium', 1],
#  212: [212, 'ECC', 'ECC', 'eccoin', 1],
#  213: [213, 'MonaCoin', 'MONA', 'monacoin', 1],
#  215: [215, 'Rubycoin', 'RBY', 'rubycoin', 1],
#  217: [217, 'Bela', 'BELA', 'belacoin', 1],
#  224: [224, 'FairCoin', 'FAIR', 'faircoin', 1],
#  233: [233, 'SolarCoin', 'SLR', 'solarcoin', 1],
#  234: [234, 'e-Gulden', 'EFL', 'e-gulden', 1],
#  254: [254, 'Gulden', 'NLG', 'gulden', 1],
#  258: [258, 'Groestlcoin', 'GRS', 'groestlcoin', 1],
#  260: [260, 'PetroDollar', 'XPD', 'petrodollar', 1],
#  263: [263, 'PLNcoin', 'PLNC', 'plncoin', 1],
#  268: [268, 'WhiteCoin', 'XWC', 'whitecoin', 1],
#  275: [275, 'PopularCoin', 'POP', 'popularcoin', 1],
#  276: [276, 'Bitstar', 'BITS', 'bitstar', 1],
#  278: [278, 'Quebecoin', 'QBC', 'quebecoin', 1],
#  290: [290, 'BlueCoin', 'BLU', 'bluecoin', 1],
#  291: [291, 'MaidSafeCoin', 'MAID', 'maidsafecoin', 1],
#  293: [293, 'Bitcoin Plus', 'XBC', 'bitcoin-plus', 1],
#  298: [298, 'NewYorkCoin', 'NYC', 'newyorkcoin', 1],
#  313: [313, 'Pinkcoin', 'PINK', 'pinkcoin', 1],
#  316: [316, 'Dreamcoin', 'DRM', 'dreamcoin', 1],
#  322: [322, 'Energycoin', 'ENRG', 'energycoin', 1],
#  323: [323, 'VeriCoin', 'VRC', 'vericoin', 1],
#  328: [328, 'Monero', 'XMR', 'monero', 1],
#  331: [331, 'Litecoin Plus', 'LCP', 'litecoin-plus', 1],
#  333: [333, 'Curecoin', 'CURE', 'curecoin', 1],
#  341: [341, 'SuperCoin', 'SUPER', 'supercoin', 1],
#  360: [360, 'Motocoin', 'MOTO', 'motocoin', 1],
#  362: [362, 'CloakCoin', 'CLOAK', 'cloakcoin', 1],
#  366: [366, 'BitSend', 'BSD', 'bitsend', 1],
#  367: [367, 'Coin2.1', 'C2', 'coin2-1', 1],
#  372: [372, 'Bytecoin', 'BCN', 'bytecoin-bcn', 1],
#  377: [377, 'Navcoin', 'NAV', 'nav-coin', 1],
#  389: [389, 'Startcoin', 'START', 'startcoin', 1],
#  405: [405, 'DigitalNote', 'XDN', 'digitalnote', 1],
#  406: [406, 'Boolberry', 'BBR', 'boolberry', 1],
#  416: [416, 'HempCoin', 'THC', 'hempcoin', 1],
#  448: [448, 'Stealth', 'XST', 'stealth', 1],
#  460: [460, 'Clams', 'CLAM', 'clams', 1],
#  463: [463, 'BitShares', 'BTS', 'bitshares', 1],
#  470: [470, 'Viacoin', 'VIA', 'viacoin', 1],
#  495: [495, 'I/O Coin', 'IOC', 'iocoin', 1],
#  501: [501, 'Cryptonite', 'XCN', 'cryptonite', 1],
#  502: [502, 'Carboncoin', 'CARBON', 'carboncoin', 1],
#  506: [506, 'CannabisCoin', 'CANN', 'cannabiscoin', 1],
#  512: [512, 'Stellar', 'XLM', 'stellar', 1],
#  541: [541, 'Syscoin', 'SYS', 'syscoin', 1],
#  551: [551, 'Donu', 'DONU', 'donu', 1],
#  558: [558, 'Emercoin', 'EMC', 'emercoin', 1],
#  572: [572, 'RabbitCoin', 'RBBT', 'rabbitcoin', 1],
#  573: [573, 'Burst', 'BURST', 'burst', 1],
#  576: [576, 'GameCredits', 'GAME', 'gamecredits', 1],
#  584: [584, 'NativeCoin', 'N8V', 'native-coin', 1],
#  588: [588, 'Ubiq', 'UBQ', 'ubiq', 1],
#  597: [597, 'Opal', 'OPAL', 'opal', 1],
#  601: [601, 'Acoin', 'ACOIN', 'acoin', 1],
#  624: [624, 'bitCNY', 'BITCNY', 'bitcny', 1],
#  626: [626, 'NuBits', 'USNBT', 'nubits', 1],
#  633: [633, 'ExclusiveCoin', 'EXCL', 'exclusivecoin', 1],
#  638: [638, 'Trollcoin', 'TROLL', 'trollcoin', 1],
#  644: [644, 'GlobalBoost-Y', 'BSTY', 'globalboost-y', 1],
#  656: [656, 'Prime-XI', 'PXI', 'prime-xi', 1],
#  659: [659, 'Bitswift', 'BITS', 'bitswift', 1],
#  693: [693, 'Verge', 'XVG', 'verge', 1],
#  699: [699, 'NuShares', 'NSR', 'nushares', 1],
#  702: [702, 'SpreadCoin', 'SPR', 'spreadcoin', 1],
#  703: [703, 'Rimbit', 'RBT', 'rimbit', 1],
#  706: [706, 'MonetaryUnit', 'MUE', 'monetaryunit', 1],
#  707: [707, 'Blocknet', 'BLOCK', 'blocknet', 1],
#  719: [719, 'Limitless VIP', 'VIP', 'limitless-vip', 1],
#  720: [720, 'Crown', 'CRW', 'crown', 1],
#  730: [730, 'GCN Coin', 'GCN', 'gcn-coin', 1],
#  733: [733, 'Quotient', 'XQN', 'quotient', 1],
#  760: [760, 'OKCash', 'OK', 'okcash', 1],
#  764: [764, 'PayCoin', 'XPY', 'paycoin2', 1],
#  788: [788, 'Circuits of Value', 'COVAL', 'circuits-of-value', 1],
#  789: [789, 'Nexus', 'NXS', 'nexus', 1],
#  799: [799, 'SmileyCoin', 'SMLY', 'smileycoin', 1],
#  815: [815, 'Kobocoin', 'KOBO', 'kobocoin', 1],
#  819: [819, 'Bean Cash', 'BITB', 'bean-cash', 1],
#  823: [823, 'GeoCoin', 'GEO', 'geocoin', 1],
#  825: [825, 'Tether', 'USDT', 'tether', 1],
#  831: [831, 'Wild Beast Block', 'WBB', 'wild-beast-block', 1],
#  833: [833, 'Gridcoin', 'GRC', 'gridcoin', 1],
#  837: [837, 'X-Coin', 'XCO', 'x-coin', 1],
#  857: [857, 'SongCoin', 'SONG', 'songcoin', 1],
#  859: [859, 'Woodcoin', 'LOG', 'woodcoin', 1],
#  873: [873, 'NEM', 'XEM', 'nem', 1],
#  894: [894, 'Neutron', 'NTRN', 'neutron', 1],
#  895: [895, 'Xaurum', 'XAUR', 'xaurum', 1],
#  898: [898, 'Californium', 'CF', 'californium', 1],
#  911: [911, 'Advanced Internet Blocks', 'AIB', 'advanced-internet-blocks', 1],
#  914: [914, 'Sphere', 'SPHR', 'sphere', 1],
#  916: [916, 'MedicCoin', 'MEDIC', 'mediccoin', 1],
#  918: [918, 'Bubble', 'BUB', 'bubble', 1],
#  921: [921, 'Universal Currency', 'UNIT', 'universal-currency', 1],
#  934: [934, 'ParkByte', 'PKB', 'parkbyte', 1],
#  938: [938, 'ARbit', 'ARB', 'arbit', 1],
#  945: [945, 'Bata', 'BTA', 'bata', 1],
#  948: [948, 'AudioCoin', 'ADC', 'audiocoin', 1],
#  951: [951, 'Synergy', 'SNRG', 'synergy', 1],
#  960: [960, 'FujiCoin', 'FJC', 'fujicoin', 1],
#  977: [977, 'GravityCoin', 'GXX', 'gravitycoin', 1],
#  978: [978, 'Ratecoin', 'XRA', 'ratecoin', 1],
#  986: [986, 'CrevaCoin', 'CREVA', 'crevacoin', 1],
#  990: [990, 'Bitzeny', 'ZNY', 'bitzeny', 1],
#  993: [993, 'BowsCoin', 'BSC', 'bowscoin', 1],
#  1004: [1004, 'Hellenic Coin', 'HNC', 'helleniccoin', 1],
#  1019: [1019, 'Manna', 'MANNA', 'manna', 1],
#  1020: [1020, 'Axiom', 'AXIOM', 'axiom', 1],
#  1022: [1022, 'BITTUP', 'BTU', 'bittup', 1],
#  1026: [1026, 'Aeon', 'AEON', 'aeon', 1],
#  1027: [1027, 'Ethereum', 'ETH', 'ethereum', 1],
#  1032: [1032, 'TransferCoin', 'TX', 'transfercoin', 1],
#  1033: [1033, 'GuccioneCoin', 'GCC', 'guccionecoin', 1],
#  1035: [1035, 'AmsterdamCoin', 'AMS', 'amsterdamcoin', 1],
#  1037: [1037, 'Agoras Tokens', 'AGRS', 'agoras-tokens', 1],
#  1038: [1038, 'Eurocoin', 'EUC', 'eurocoin', 1],
#  1042: [1042, 'Siacoin', 'SC', 'siacoin', 1],
#  1044: [1044, 'Global Currency Reserve', 'GCR', 'global-currency-reserve', 1],
#  1050: [1050, 'Shift', 'SHIFT', 'shift', 1],
#  1052: [1052, 'VectorAI', 'VEC2', 'vector', 1],
#  1053: [1053, 'Bolivarcoin', 'BOLI', 'bolivarcoin', 1],
#  1066: [1066, 'Pakcoin', 'PAK', 'pakcoin', 1],
#  1070: [1070, 'Expanse', 'EXP', 'expanse', 1],
#  1082: [1082, 'SIBCoin', 'SIB', 'sibcoin', 1],
#  1085: [1085, 'Swing', 'SWING', 'swing', 1],
#  1087: [1087, 'Factom', 'FCT', 'factom', 1],
#  1089: [1089, 'ParallelCoin', 'DUO', 'parallelcoin', 1],
#  1090: [1090, 'Save and Gain', 'SANDG', 'save-and-gain', 1],
#  1104: [1104, 'Augur', 'REP', 'augur', 1],
#  1106: [1106, 'StrongHands', 'SHND', 'stronghands', 1],
#  1107: [1107, 'PAC Protocol', 'PAC', 'pac-protocol', 1],
#  1120: [1120, 'DraftCoin', 'DFT', 'draftcoin', 1],
#  1135: [1135, 'ClubCoin', 'CLUB', 'clubcoin', 1],
#  1136: [1136, 'Adzcoin', 'ADZ', 'adzcoin', 1],
#  1146: [1146, 'AvatarCoin', 'AV', 'avatarcoin', 1],
#  1154: [1154, 'Validity', 'VAL', 'validity', 1],
#  1155: [1155, 'Litecred', 'LTCR', 'litecred', 1],
#  1156: [1156, 'Yocoin', 'YOC', 'yocoin', 1],
#  1159: [1159, 'SaluS', 'SLS', 'salus', 1],
#  1164: [1164, 'Francs', 'FRN', 'francs', 1],
#  1165: [1165, 'Evil Coin', 'EVIL', 'evil-coin', 1],
#  1168: [1168, 'Decred', 'DCR', 'decred', 1],
#  1169: [1169, 'PIVX', 'PIVX', 'pivx', 1],
#  1172: [1172, 'Safex Token', 'SFT', 'safex-token', 1],
#  1175: [1175, 'Rubies', 'RBIES', 'rubies', 1],
#  1185: [1185, 'TrumpCoin', 'TRUMP', 'trumpcoin', 1],
#  1191: [1191, 'Memetic / PepeCoin', 'MEME', 'memetic', 1],
#  1194: [1194,
#   'Independent Money System',
#   'IMS',
#   'independent-money-system',
#   1],
#  1200: [1200, 'NevaCoin', 'NEVA', 'nevacoin', 1],
#  1209: [1209, 'PosEx', 'PEX', 'posex', 1],
#  1210: [1210, 'Cabbage', 'CAB', 'cabbage', 1],
#  1212: [1212, 'MojoCoin', 'MOJO', 'mojocoin', 1],
#  1214: [1214, 'Lisk', 'LSK', 'lisk', 1],
#  1216: [1216, 'EDRCoin', 'EDRC', 'edrcoin', 1],
#  1218: [1218, 'PostCoin', 'POST', 'postcoin', 1],
#  1223: [1223, 'BERNcash', 'BERN', 'berncash', 1],
#  1229: [1229, 'DigixDAO', 'DGD', 'digixdao', 1],
#  1230: [1230, 'Steem', 'STEEM', 'steem', 1],
#  1241: [1241, 'FuzzBalls', 'FUZZ', 'fuzzballs', 1],
#  1244: [1244, 'HiCoin', 'XHI', 'hicoin', 1],
#  1247: [1247, 'AquariusCoin', 'ARCO', 'aquariuscoin', 1],
#  1248: [1248, 'Bitcoin 21', 'XBTC21', 'bitcoin-21', 1],
#  1250: [1250, 'Zurcoin', 'ZUR', 'zurcoin', 1],
#  1252: [1252, '2GIVE', '2GIVE', '2give', 1],
#  1254: [1254, 'PlatinumBAR', 'XPTX', 'platinumbar', 1],
#  1257: [1257, 'LanaCoin', 'LANA', 'lanacoin', 1],
#  1259: [1259, 'PonziCoin', 'PONZI', 'ponzicoin', 1],
#  1266: [1266, 'MarteXcoin', 'MXT', 'martexcoin', 1],
#  1273: [1273, 'Citadel', 'CTL', 'citadel', 1],
#  1274: [1274, 'Waves', 'WAVES', 'waves', 1],
#  1279: [1279, 'PWR Coin', 'PWR', 'powercoin', 1],
#  1281: [1281, 'ION', 'ION', 'ion', 1],
#  1282: [1282, 'High Voltage', 'HVCO', 'high-voltage', 1],
#  1285: [1285, 'GoldBlocks', 'GB', 'goldblocks', 1],
#  1291: [1291, 'Comet', 'CMT', 'comet', 1],
#  1294: [1294, 'Rise', 'RISE', 'rise', 1],
#  1297: [1297, 'ChessCoin', 'CHESS', 'chesscoin', 1],
#  1298: [1298, 'LBRY Credits', 'LBC', 'library-credit', 1],
#  1299: [1299, 'PutinCoin', 'PUT', 'putincoin', 1],
#  1306: [1306, 'Cryptojacks', 'CJ', 'cryptojacks', 1],
#  1308: [1308, 'HEAT', 'HEAT', 'heat-ledger', 1],
#  1312: [1312, 'Steem Dollars', 'SBD', 'steem-dollars', 1],
#  1320: [1320, 'Ardor', 'ARDR', 'ardor', 1],
#  1321: [1321, 'Ethereum Classic', 'ETC', 'ethereum-classic', 1],
#  1340: [1340, 'Karbo', 'KRB', 'karbo', 1],
#  1343: [1343, 'Stratis', 'STRAX', 'stratis', 1],
#  1351: [1351, 'Aces', 'ACES', 'aces', 1],
#  1353: [1353, 'TajCoin', 'TAJ', 'tajcoin', 1],
#  1368: [1368, 'Veltor', 'VLT', 'veltor', 1],
#  1376: [1376, 'Neo', 'NEO', 'neo', 1],
#  1381: [1381, 'Bitcloud', 'BTDX', 'bitcloud', 1],
#  1382: [1382, 'NoLimitCoin', 'NLC2', 'nolimitcoin', 1],
#  1389: [1389, 'Zayedcoin', 'ZYD', 'zayedcoin', 1],
#  1392: [1392, 'Pluton', 'PLU', 'pluton', 1],
#  1395: [1395, 'Dollarcoin', 'DLC', 'dollarcoin', 1],
#  1396: [1396, 'MustangCoin', 'MST', 'mustangcoin', 1],
#  1398: [1398, 'PROUD Money', 'PROUD', 'proud-money', 1],
#  1403: [1403, 'FirstBlood', '1ST', 'firstblood', 1],
#  1409: [1409, 'SingularDTV', 'SNGLS', 'singulardtv', 1],
#  1414: [1414, 'Firo', 'FIRO', 'firo', 1],
#  1434: [1434, 'Advanced Technology Coin', 'ARC', 'arcticcoin', 1],
#  1437: [1437, 'Zcash', 'ZEC', 'zcash', 1],
#  1439: [1439, 'AllSafe', 'ASAFE', 'allsafe', 1],
#  1447: [1447, 'ZClassic', 'ZCL', 'zclassic', 1],
#  1454: [1454, 'Lykke', 'LKK', 'lykke', 1],
#  1455: [1455, 'Golem', 'GLM', 'golem-network-tokens', 1],
#  1464: [1464, 'Internet of People', 'IOP', 'internet-of-people', 1],
#  1465: [1465, 'Veros', 'VRS', 'veros', 1],
#  1466: [1466, 'Hush', 'HUSH', 'hush', 1],
#  1468: [1468, 'Kurrent', 'KURT', 'kurrent', 1],
#  1473: [1473, 'Pascal', 'PASC', 'pascal', 1],
#  1474: [1474, 'Eternity', 'ENT', 'eternity', 1],
#  1475: [1475, 'Incent', 'INCNT', 'incent', 1],
#  1478: [1478, 'DECENT', 'DCT', 'decent', 1],
#  1483: [1483, 'vSlice', 'VSL', 'vslice', 1],
#  1492: [1492, 'Obyte', 'GBYTE', 'obyte', 1],
#  1495: [1495, 'PoSW Coin', 'POSW', 'posw-coin', 1],
#  1496: [1496, 'Luna Coin', 'LUNA', 'luna-coin', 1],
#  1500: [1500, 'Wings', 'WINGS', 'wings', 1],
#  1503: [1503, 'Jupiter', 'JUP', 'jupiter', 1],
#  1504: [1504, 'InflationCoin', 'IFLT', 'inflationcoin', 1],
#  1505: [1505, 'Alias', 'ALIAS', 'alias', 1],
#  1510: [1510, 'CryptoCarbon', 'CCRB', 'cryptocarbon', 1],
#  1511: [1511, 'PureVidz', 'VIDZ', 'purevidz', 1],
#  1514: [1514, 'ICOBID', 'ICOB', 'icobid', 1],
#  1515: [1515, 'iBank', 'IBANK', 'ibank', 1],
#  1518: [1518, 'Maker', 'MKR', 'maker', 1],
#  1521: [1521, 'Komodo', 'KMD', 'komodo', 1],
#  1522: [1522, 'FirstCoin', 'FRST', 'firstcoin', 1],
#  1527: [1527, 'Waves Community Token', 'WCT', 'waves-community-token', 1],
#  1528: [1528, 'Iconic', 'ICON', 'iconic', 1],
#  1531: [1531, 'Global Cryptocurrency', 'GCC', 'global-cryptocurrency', 1],
#  1546: [1546, 'Centurion', 'CNT', 'centurion', 1],
#  1552: [1552, 'Enzyme', 'MLN', 'enzyme', 1],
#  1556: [1556, 'Chrono.tech', 'TIME', 'chrono-tech', 1],
#  1558: [1558, 'Argus', 'ARGUS', 'argus', 1],
#  1562: [1562, 'Swarm City', 'SWT', 'swarm-city', 1],
#  1567: [1567, 'Nano', 'NANO', 'nano', 1],
#  1576: [1576, 'MiloCoin', 'MILO', 'milocoin', 1],
#  1578: [1578, 'Zero', 'ZER', 'zero', 1],
#  1582: [1582, 'Netko', 'NETKO', 'netko', 1],
#  1586: [1586, 'Ark', 'ARK', 'ark', 1],
#  1587: [1587, 'Dynamic', 'DYN', 'dynamic', 1],
#  1588: [1588, 'Tokes', 'TKS', 'tokes', 1],
#  1590: [1590, 'Mercury', 'MER', 'mercury', 1],
#  1596: [1596, 'Edgeless', 'EDG', 'edgeless', 1],
#  1599: [1599, 'Mavro', 'MAVRO', 'mavro', 1],
#  1605: [1605, 'Universe', 'UNI', 'universe', 1],
#  1606: [1606, 'Solaris', 'XLR', 'solaris', 1],
#  1609: [1609, 'Asch', 'XAS', 'asch', 1],
#  1611: [1611, 'DubaiCoin', 'DBIX', 'dubaicoin-dbix', 1],
#  1619: [1619, 'Skycoin', 'SKY', 'skycoin', 1],
#  1623: [1623, 'BlazerCoin', 'BLAZR', 'blazercoin', 1],
#  1624: [1624, 'Atmos', 'ATMOS', 'atmos', 1],
#  1629: [1629, 'Zennies', 'ZENI', 'zennies', 1],
#  1630: [1630, 'Coinonat', 'CXT', 'coinonat', 1],
#  1632: [1632, 'Concoin', 'CONX', 'concoin', 1],
#  1636: [1636, 'XTRABYTES', 'XBY', 'xtrabytes', 1],
#  1637: [1637, 'iExec RLC', 'RLC', 'rlc', 1],
#  1638: [1638, 'WeTrust', 'TRST', 'trust', 1],
#  1651: [1651, 'SpeedCash', 'SCS', 'speedcash', 1],
#  1654: [1654, 'BitCore', 'BTX', 'bitcore', 1],
#  1657: [1657, 'Bitvolt', 'VOLT', 'bitvolt', 1],
#  1658: [1658, 'Lunyr', 'LUN', 'lunyr', 1],
#  1659: [1659, 'Gnosis', 'GNO', 'gnosis-gno', 1],
#  1660: [1660, 'Monolith', 'TKN', 'monolith', 1],
#  1669: [1669, 'Humaniq', 'HMQ', 'humaniq', 1],
#  1673: [1673, 'Minereum', 'MNE', 'minereum', 1],
#  1674: [1674, 'Cannation', 'CNNC', 'cannation', 1],
#  1676: [1676, 'CREA', 'CREA', 'crea', 1],
#  1677: [1677, 'Etheroll', 'DICE', 'etheroll', 1],
#  1678: [1678, 'InsaneCoin', 'INSN', 'insanecoin-insn', 1],
#  1680: [1680, 'Aragon', 'ANT', 'aragon', 1],
#  1681: [1681, 'PRIZM', 'PZM', 'prizm', 1],
#  1684: [1684, 'Qtum', 'QTUM', 'qtum', 1],
#  1687: [1687, 'Digital Money Bits', 'DMB', 'digital-money-bits', 1],
#  1691: [1691, 'Project-X', 'NANOX', 'project-x', 1],
#  1693: [1693, 'Theresa May Coin', 'MAY', 'theresa-may-coin', 1],
#  1694: [1694, 'Sumokoin', 'SUMO', 'sumokoin', 1],
#  1697: [1697, 'Basic Attention Token', 'BAT', 'basic-attention-token', 1],
#  1698: [1698, 'Horizen', 'ZEN', 'horizen', 1],
#  1700: [1700, 'Aeternity', 'AE', 'aeternity', 1],
#  1703: [1703, 'Metaverse ETP', 'ETP', 'metaverse', 1],
#  1704: [1704, 'eBoost', 'EBST', 'eboostcoin', 1],
#  1706: [1706, 'Aidos Kuneen', 'ADK', 'aidos-kuneen', 1],
#  1708: [1708, 'Patientory', 'PTOY', 'patientory', 1],
#  1710: [1710, 'Veritaseum', 'VERI', 'veritaseum', 1],
#  1711: [1711, 'Electra', 'ECA', 'electra', 1],
#  1712: [1712,
#   'Quantum Resistant Ledger',
#   'QRL',
#   'quantum-resistant-ledger',
#   1],
#  1715: [1715, 'MobileGo', 'MGO', 'mobilego', 1],
#  1719: [1719, 'Peerplays', 'PPY', 'peerplays-ppy', 1],
#  1720: [1720, 'IOTA', 'MIOTA', 'iota', 1],
#  1721: [1721, 'Mysterium', 'MYST', 'mysterium', 1],
#  1722: [1722, 'More Coin', 'MORE', 'more-coin', 1],
#  1723: [1723, 'SONM', 'SNM', 'sonm', 1],
#  1725: [1725, 'Adelphoi', 'ADL', 'adelphoi', 1],
#  1726: [1726, 'ZrCoin', 'ZRC', 'zrcoin', 1],
#  1727: [1727, 'Bancor', 'BNT', 'bancor', 1],
#  1731: [1731, 'GlobalToken', 'GLT', 'globaltoken', 1],
#  1732: [1732, 'Numeraire', 'NMR', 'numeraire', 1],
#  1736: [1736, 'Unify', 'UNIFY', 'unify', 1],
#  1745: [1745, 'Dinastycoin', 'DCY', 'dinastycoin', 1],
#  1747: [1747, 'Onix', 'ONX', 'onix', 1],
#  1750: [1750, 'GXChain', 'GXC', 'gxchain', 1],
#  1751: [1751, 'ATC Coin', 'ATCC', 'atc-coin', 1],
#  1754: [1754, 'Bitradio', 'BRO', 'bitradio', 1],
#  1755: [1755, 'Flash', 'FLASH', 'flash', 1],
#  1757: [1757, 'FUNToken', 'FUN', 'funtoken', 1],
#  1758: [1758, 'TenX', 'PAY', 'tenx', 1],
#  1759: [1759, 'Status', 'SNT', 'status', 1],
#  1762: [1762, 'Ergo', 'ERG', 'ergo', 1],
#  1763: [1763, 'BriaCoin', 'BRIA', 'briacoin', 1],
#  1765: [1765, 'EOS', 'EOS', 'eos', 1],
#  1768: [1768, 'AdEx Network', 'ADX', 'adx-net', 1],
#  1769: [1769, 'Denarius', 'D', 'denarius-d', 1],
#  1771: [1771, 'DAOBet', 'BET', 'daobet', 1],
#  1772: [1772, 'Storj', 'STORJ', 'storj', 1],
#  1774: [1774, 'SocialCoin', 'SOCC', 'socialcoin-socc', 1],
#  1775: [1775, 'adToken', 'ADT', 'adtoken', 1],
#  1776: [1776, 'MCO', 'MCO', 'crypto-com', 1],
#  1777: [1777, 'CryptoPing', 'PING', 'cryptoping', 1],
#  1779: [1779, 'Wagerr', 'WGR', 'wagerr', 1],
#  1784: [1784, 'Polybius', 'PLBT', 'polybius', 1],
#  1785: [1785, 'Gas', 'GAS', 'gas', 1],
#  1786: [1786, 'SunContract', 'SNC', 'suncontract', 1],
#  1787: [1787, 'Jetcoin', 'JET', 'jetcoin', 1],
#  1788: [1788, 'Metal', 'MTL', 'metal', 1],
#  1789: [1789, 'Populous', 'PPT', 'populous', 1],
#  1799: [1799, 'Rupee', 'RUP', 'rupee', 1],
#  1803: [1803, 'PeepCoin', 'PCN', 'peepcoin', 1],
#  1807: [1807, 'Santiment Network Token', 'SAN', 'santiment', 1],
#  1808: [1808, 'OMG Network', 'OMG', 'omg', 1],
#  1810: [1810, 'CVCoin', 'CVN', 'cvcoin', 1],
#  1814: [1814, 'Metrix Coin', 'MRX', 'metrix-coin', 1],
#  1816: [1816, 'Civic', 'CVC', 'civic', 1],
#  1817: [1817, 'Voyager Token', 'VGX', 'voyager-token', 1],
#  1824: [1824, 'BitCoal', 'COAL', 'bitcoal', 1],
#  1826: [1826, 'Particl', 'PART', 'particl', 1],
#  1828: [1828, 'SmartCash', 'SMART', 'smartcash', 1],
#  1830: [1830, 'SkinCoin', 'SKIN', 'skincoin', 1],
#  1831: [1831, 'Bitcoin Cash', 'BCH', 'bitcoin-cash', 1],
#  1834: [1834, 'Pillar', 'PLR', 'pillar', 1],
#  1838: [1838, 'OracleChain', 'OCT', 'oraclechain', 1],
#  1839: [1839, 'Binance Coin', 'BNB', 'binance-coin', 1],
#  1841: [1841, 'Primalbase Token', 'PBT', 'primalbase', 1],
#  1845: [1845, 'IXT', 'IXT', 'ixledger', 1],
#  1846: [1846, 'GeyserCoin', 'GSR', 'geysercoin', 1],
#  1850: [1850, 'Cream', 'CRM', 'cream', 1],
#  1853: [1853, 'OAX', 'OAX', 'oax', 1],
#  1856: [1856, 'district0x', 'DNT', 'district0x', 1],
#  1861: [1861, 'Stox', 'STX', 'stox', 1],
#  1864: [1864, 'Blox', 'CDT', 'blox', 1],
#  1866: [1866, 'Bytom', 'BTM', 'bytom', 1],
#  1873: [1873, 'Blocktix', 'TIX', 'blocktix', 1],
#  1876: [1876, 'Dentacoin', 'DCN', 'dentacoin', 1],
#  1878: [1878, 'Shadow Token', 'SHDW', 'shadow-token', 1],
#  1881: [1881, 'DeepOnion', 'ONION', 'deeponion', 1],
#  1883: [1883, 'Adshares', 'ADS', 'adshares', 1],
#  1886: [1886, 'Dent', 'DENT', 'dent', 1],
#  1888: [1888, 'InvestFeed', 'IFT', 'investfeed', 1],
#  1894: [1894, 'The ChampCoin', 'TCC', 'the-champcoin', 1],
#  1896: [1896, '0x', 'ZRX', '0x', 1],
#  1899: [1899, 'YOYOW', 'YOYOW', 'yoyow', 1],
#  1902: [1902, 'MyBit', 'MYB', 'mybit', 1],
#  1903: [1903, 'HyperCash', 'HC', 'hypercash', 1],
#  1905: [1905, 'TrueFlip', 'TFL', 'trueflip', 1],
#  1908: [1908, 'Nebulas', 'NAS', 'nebulas-token', 1],
#  1916: [1916, 'BiblePay', 'BBP', 'biblepay', 1],
#  1918: [1918, 'Achain', 'ACT', 'achain', 1],
#  1923: [1923, 'Tierion', 'TNT', 'tierion', 1],
#  1925: [1925, 'Waltonchain', 'WTC', 'waltonchain', 1],
#  1930: [1930, 'Primas', 'PST', 'primas', 1],
#  1931: [1931, 'Opus', 'OPT', 'opus', 1],
#  1933: [1933, 'Suretly', 'SUR', 'suretly', 1],
#  1934: [1934, 'Loopring', 'LRC', 'loopring', 1],
#  1935: [1935, 'LiteCoin Ultra', 'LTCU', 'litecoin-ultra', 1],
#  1937: [1937, 'Po.et', 'POE', 'poet', 1],
#  1944: [1944, 'Moving Cloud Coin', 'MCC', 'moving-cloud-coin', 1],
#  1947: [1947, 'Monetha', 'MTH', 'monetha', 1],
#  1948: [1948, 'Aventus', 'AVT', 'aventus', 1],
#  1949: [1949, 'Agrello', 'DLT', 'agrello-delta', 1],
#  1950: [1950, 'Hiveterminal Token', 'HVN', 'hiveterminal-token', 1],
#  1954: [1954, 'Moeda Loyalty Points', 'MDA', 'moeda-loyalty-points', 1],
#  1955: [1955, 'Neblio', 'NEBL', 'neblio', 1],
#  1958: [1958, 'TRON', 'TRX', 'tron', 1],
#  1961: [1961, 'imbrex', 'REX', 'imbrex', 1],
#  1962: [1962, 'BUZZCoin', 'BUZZ', 'buzzcoin', 1],
#  1966: [1966, 'Decentraland', 'MANA', 'decentraland', 1],
#  1967: [1967, 'Indorse Token', 'IND', 'indorse-token', 1],
#  1968: [1968, 'XPA', 'XPA', 'xpa', 1],
#  1969: [1969, 'Sociall', 'SCL', 'sociall', 1],
#  1970: [1970, 'ATBCoin', 'ATB', 'atbcoin', 1],
#  1974: [1974, 'Propy', 'PRO', 'propy', 1],
#  1975: [1975, 'Chainlink', 'LINK', 'chainlink', 1],
#  1976: [1976, 'Blackmoon', 'BMC', 'blackmoon', 1],
#  1982: [1982, 'Kyber Network', 'KNC', 'kyber-network', 1],
#  1983: [1983, 'VIBE', 'VIBE', 'vibe', 1],
#  1984: [1984, 'Substratum', 'SUB', 'substratum', 1],
#  1985: [1985, 'Chronologic', 'DAY', 'chronologic', 1],
#  1991: [1991, 'Rivetz', 'RVT', 'rivetz', 1],
#  1993: [1993, 'Kin', 'KIN', 'kin', 1],
#  1996: [1996, 'SALT', 'SALT', 'salt', 1],
#  1998: [1998, 'Ormeus Coin', 'ORMEUS', 'ormeus-coin', 1],
#  2001: [2001, 'ColossusXT', 'COLX', 'colossusxt', 1],
#  2002: [2002, 'TrezarCoin', 'TZC', 'trezarcoin', 1],
#  2006: [2006, 'Cobinhood', 'COB', 'cobinhood', 1],
#  2008: [2008, 'MSD', 'MSD', 'msd', 1],
#  2009: [2009, 'Bismuth', 'BIS', 'bismuth', 1],
#  2010: [2010, 'Cardano', 'ADA', 'cardano', 1],
#  2011: [2011, 'Tezos', 'XTZ', 'tezos', 1],
#  2013: [2013, 'Infinity Economics', 'XIN', 'infinity-economics', 1],
#  2017: [2017, 'KickToken', 'KICK', 'kick-token', 1],
#  2019: [2019, 'Viberate', 'VIB', 'viberate', 1],
#  2021: [2021, 'RChain', 'REV', 'rchain', 1],
#  2022: [2022, 'Internxt', 'INXT', 'internxt', 1],
#  2030: [2030, 'REAL', 'REAL', 'real', 1],
#  2031: [2031, 'Hubii Network', 'HBT', 'hubii-network', 1],
#  2034: [2034, 'Everex', 'EVX', 'everex', 1],
#  2036: [2036, 'PayPie', 'PPP', 'paypie', 1],
#  2041: [2041, 'BitcoinZ', 'BTCZ', 'bitcoinz', 1],
#  2042: [2042, 'HelloGold', 'HGT', 'hellogold', 1],
#  2043: [2043, 'Cindicator', 'CND', 'cindicator', 1],
#  2044: [2044, 'Enigma', 'ENG', 'enigma', 1],
#  2047: [2047, 'Zeusshield', 'ZSC', 'zeusshield', 1],
#  2056: [2056, 'PiplCoin', 'PIPL', 'piplcoin', 1],
#  2058: [2058, 'AirSwap', 'AST', 'airswap', 1],
#  2061: [2061, 'Blockmason Credit Protocol', 'BCPT', 'blockmason', 1],
#  2062: [2062, 'Aion', 'AION', 'aion', 1],
#  2064: [2064, 'Maecenas', 'ART', 'maecenas', 1],
#  2066: [2066, 'Everus', 'EVR', 'everus', 1],
#  2070: [2070, 'DomRaider', 'DRT', 'domraider', 1],
#  2071: [2071, 'Request', 'REQ', 'request', 1],
#  2074: [2074, 'Ethereum Gold', 'ETG', 'ethereum-gold', 1],
#  2076: [2076, 'Blue Protocol', 'BLUE', 'ethereum-blue', 1],
#  2081: [2081, 'Ambrosus', 'AMB', 'amber', 1],
#  2083: [2083, 'Bitcoin Gold', 'BTG', 'bitcoin-gold', 1],
#  2087: [2087, 'KuCoin Token', 'KCS', 'kucoin-token', 1],
#  2088: [2088, 'EXRNchain', 'EXRN', 'exrnchain', 1],
#  2090: [2090, 'LATOKEN', 'LA', 'latoken', 1],
#  2091: [2091, 'Exchange Union', 'XUC', 'exchange-union', 1],
#  2092: [2092, 'NULS', 'NULS', 'nuls', 1],
#  2095: [2095, 'BOScoin', 'BOS', 'boscoin', 1],
#  2096: [2096, 'Ripio Credit Network', 'RCN', 'ripio-credit-network', 1],
#  2099: [2099, 'ICON', 'ICX', 'icon', 1],
#  2100: [2100, 'JavaScript Token', 'JS', 'javascript-token', 1],
#  2103: [2103,
#   'Intelligent Trading Foundation',
#   'ITT',
#   'intelligent-trading-foundation',
#   1],
#  2104: [2104, 'iEthereum', 'IETH', 'iethereum', 1],
#  2105: [2105, 'Pirl', 'PIRL', 'pirl', 1],
#  2107: [2107, 'LUXCoin', 'LUX', 'luxcoin', 1],
#  2110: [2110, 'Dovu', 'DOV', 'dovu', 1],
#  2112: [2112, 'Phoenix Global', 'PHB', 'phoenix-global', 1],
#  2120: [2120, 'Etherparty', 'FUEL', 'etherparty', 1],
#  2122: [2122, 'Ellaism', 'ELLA', 'ellaism', 1],
#  2126: [2126, 'FlypMe', 'FYP', 'flypme', 1],
#  2130: [2130, 'Enjin Coin', 'ENJ', 'enjin-coin', 1],
#  2131: [2131, 'iBTC', 'IBTC', 'ibtc', 1],
#  2132: [2132, 'Power Ledger', 'POWR', 'power-ledger', 1],
#  2134: [2134, 'Grid+', 'GRID', 'grid', 1],
#  2135: [2135, 'Revain', 'REV', 'revain', 1],
#  2136: [2136, 'ATLANT', 'ATL', 'atlant', 1],
#  2137: [2137, 'Electroneum', 'ETN', 'electroneum', 1],
#  2140: [2140, 'SONO', 'SONO', 'altcommunity-coin', 1],
#  2143: [2143, 'Streamr', 'DATA', 'streamr', 1],
#  2144: [2144, 'SHIELD', 'XSH', 'shield-xsh', 1],
#  2147: [2147, 'ELTCOIN', 'ELTCOIN', 'eltcoin', 1],
#  2148: [2148, 'Desire', 'DSR', 'desire', 1],
#  2151: [2151, 'Autonio', 'NIOX', 'autonio', 1],
#  2153: [2153, 'Aeron', 'ARNX', 'aeron', 1],
#  2158: [2158, 'Phore', 'PHR', 'phore', 1],
#  2160: [2160, 'Innova', 'INN', 'innova', 1],
#  2161: [2161, 'Raiden Network Token', 'RDN', 'raiden-network-token', 1],
#  2162: [2162, 'Delphy', 'DPY', 'delphy', 1],
#  2165: [2165, 'ERC20', 'ERC20', 'erc20', 1],
#  2175: [2175, 'DecentBet', 'DBET', 'decent-bet', 1],
#  2178: [2178, 'Upfiring', 'UFR', 'upfiring', 1],
#  2181: [2181, 'Genesis Vision', 'GVT', 'genesis-vision', 1],
#  2184: [2184, 'Privatix', 'PRIX', 'privatix', 1],
#  2185: [2185, 'Lethean', 'LTHN', 'lethean', 1],
#  2191: [2191, 'Paypex', 'PAYX', 'paypex', 1],
#  2199: [2199, 'EONS', 'EONS', 'eons', 1],
#  2200: [2200, 'GoByte', 'GBX', 'gobyte', 1],
#  2205: [2205, 'Phantomx', 'PNX', 'phantomx', 1],
#  2208: [2208, 'EncrypGen', 'DNA', 'encrypgen', 1],
#  2209: [2209, 'Ink', 'INK', 'ink', 1],
#  2212: [2212, 'Quantstamp', 'QSP', 'quantstamp', 1],
#  2213: [2213, 'QASH', 'QASH', 'qash', 1],
#  2215: [2215, 'Energo', 'TSL', 'energo', 1],
#  2219: [2219, 'SpankChain', 'SPANK', 'spankchain', 1],
#  2221: [2221, 'VoteCoin', 'VOT', 'votecoin', 1],
#  2222: [2222, 'Bitcoin Diamond', 'BCD', 'bitcoin-diamond', 1],
#  2223: [2223, 'BLOCKv', 'VEE', 'blockv', 1],
#  2230: [2230, 'Monkey Project', 'MONK', 'monkey-project', 1],
#  2231: [2231, 'Flixxo', 'FLIXX', 'flixxo', 1],
#  2235: [2235, 'Time New Bank', 'TNB', 'time-new-bank', 1],
#  2236: [2236, 'MyWish', 'WISH', 'mywish', 1],
#  2237: [2237, 'EventChain', 'EVC', 'eventchain', 1],
#  2240: [2240, 'SoMee.Social', 'ONG', 'ongsocial', 1],
#  2241: [2241, 'Ccore', 'CCO', 'ccore', 1],
#  2242: [2242, 'Qbao', 'QBT', 'qbao', 1],
#  2243: [2243, 'Dragonchain', 'DRGN', 'dragonchain', 1],
#  2244: [2244, 'Payfair', 'PFR', 'payfair', 1],
#  2245: [2245, 'Presearch', 'PRE', 'presearch', 1],
#  2246: [2246, 'CyberMiles', 'CMT', 'cybermiles', 1],
#  2247: [2247, 'BlockCDN', 'BCDN', 'blockcdn', 1],
#  2248: [2248, 'Cappasity', 'CAPP', 'cappasity', 1],
#  2249: [2249, 'Eroscoin', 'ERO', 'eroscoin', 1],
#  2251: [2251, 'IoT Chain', 'ITC', 'iot-chain', 1],
#  2255: [2255, 'Social Send', 'SEND', 'social-send', 1],
#  2256: [2256, 'Bonpay', 'BON', 'bonpay', 1],
#  2257: [2257, 'Nekonium', 'NUKO', 'nekonium', 1],
#  2260: [2260, 'Datamine', 'DAM', 'datamine', 1],
#  2267: [2267, 'Wabi', 'WABI', 'wabi', 1],
#  2269: [2269, 'WandX', 'WAND', 'wandx', 1],
#  2273: [2273, 'Uquid Coin', 'UQC', 'uquid-coin', 1],
#  2274: [2274, 'MediShares', 'MDS', 'medishares', 1],
#  2276: [2276, 'Ignis', 'IGNIS', 'ignis', 1],
#  2277: [2277, 'SmartMesh', 'SMT', 'smartmesh', 1],
#  2278: [2278, 'HollyWoodCoin', 'HWC', 'hollywoodcoin', 1],
#  2279: [2279, 'Playkey', 'PKT', 'playkey', 1],
#  2280: [2280, 'Filecoin', 'FIL', 'filecoin', 1],
#  2281: [2281, 'BitcoinX', 'BCX', 'bitcoinx', 1],
#  2282: [2282, 'Super Bitcoin', 'SBTC', 'super-bitcoin', 1],
#  2283: [2283, 'Datum', 'DAT', 'datum', 1],
#  2286: [2286, 'MicroMoney', 'AMM', 'micromoney', 1],
#  2287: [2287, 'LockTrip', 'LOC', 'lockchain', 1],
#  2288: [2288, 'Worldcore', 'WRC', 'worldcore', 1],
#  2289: [2289, 'Gifto', 'GTO', 'gifto', 1],
#  2290: [2290, 'YENTEN', 'YTN', 'yenten', 1],
#  2291: [2291, 'Genaro Network', 'GNX', 'genaro-network', 1],
#  2293: [2293, 'United Bitcoin', 'UBTC', 'united-bitcoin', 1],
#  2295: [2295, 'Starbase', 'STAR', 'starbase', 1],
#  2296: [2296, 'OST', 'OST', 'ost', 1],
#  2297: [2297, 'StormX', 'STMX', 'stormx', 1],
#  2299: [2299, 'aelf', 'ELF', 'aelf', 1],
#  2300: [2300, 'WAX', 'WAXP', 'wax', 1],
#  2303: [2303, 'MediBloc', 'MED', 'medibloc', 1],
#  2305: [2305, 'NAGA', 'NGC', 'naga', 1],
#  2306: [2306, 'Bread', 'BRD', 'bread', 1],
#  2307: [2307, 'Bibox Token', 'BIX', 'bibox-token', 1],
#  2309: [2309, 'SophiaTX', 'SPHTX', 'sophiatx', 1],
#  2310: [2310, 'Bounty0x', 'BNTY', 'bounty0x', 1],
#  2311: [2311, 'ACE (TokenStars)', 'ACE', 'ace', 1],
#  2313: [2313, 'SIRIN LABS Token', 'SRN', 'sirin-labs-token', 1],
#  2314: [2314, 'Cryptopay', 'CPAY', 'cryptopay', 1],
#  2315: [2315, 'HTMLCOIN', 'HTML', 'html-coin', 1],
#  2316: [2316, 'DeepBrain Chain', 'DBC', 'deepbrain-chain', 1],
#  2318: [2318, 'Neumark', 'NEU', 'neumark', 1],
#  2319: [2319, 'Qcash', 'QC', 'qcash', 1],
#  2320: [2320, 'Utrust', 'UTK', 'utrust', 1],
#  2321: [2321, 'QLC Chain', 'QLC', 'qlink', 1],
#  2323: [2323, 'HEROcoin', 'PLAY', 'herocoin', 1],
#  2324: [2324, 'BigONE Token', 'ONE', 'bigone-token', 1],
#  2325: [2325, 'Matryx', 'MTX', 'matryx', 1],
#  2329: [2329, 'Hyper Pay', 'HPY', 'hyper-pay', 1],
#  2330: [2330, 'Pylon Network', 'PYLNT', 'pylon-network', 1],
#  2332: [2332, 'STRAKS', 'STAK', 'straks', 1],
#  2335: [2335, 'Lightning Bitcoin', 'LBTC', 'lightning-bitcoin', 1],
#  2336: [2336, 'Game.com', 'GTC', 'game', 1],
#  2337: [2337, 'Lamden', 'TAU', 'lamden', 1],
#  2341: [2341, 'SwftCoin', 'SWFTC', 'swftcoin', 1],
#  2342: [2342, 'Covesting', 'COV', 'covesting', 1],
#  2343: [2343, 'CanYaCoin', 'CAN', 'canyacoin', 1],
#  2344: [2344, 'AppCoins', 'APPC', 'appcoins', 1],
#  2345: [2345,
#   'High Performance Blockchain',
#   'HPB',
#   'high-performance-blockchain',
#   1],
#  2346: [2346, 'WaykiChain', 'WICC', 'waykichain', 1],
#  2348: [2348, 'Measurable Data Token', 'MDT', 'measurable-data-token', 1],
#  2349: [2349, 'Mixin', 'XIN', 'mixin', 1],
#  2352: [2352, 'Coinlancer', 'CL', 'coinlancer', 1],
#  2354: [2354, 'GET Protocol', 'GET', 'get-protocol', 1],
#  2356: [2356, 'CFun', 'CFUN', 'cfun', 1],
#  2357: [2357, 'AI Doctor', 'AIDOC', 'aidoc', 1],
#  2359: [2359, 'Polis', 'POLIS', 'polis', 1],
#  2363: [2363, 'Zap', 'ZAP', 'zap', 1],
#  2364: [2364, 'TokenClub', 'TCT', 'tokenclub', 1],
#  2366: [2366, 'FairGame', 'FAIR', 'fairgame', 1],
#  2367: [2367, 'Aigang', 'AIX', 'aigang', 1],
#  2370: [2370, 'Bitcoin God', 'GOD', 'bitcoin-god', 1],
#  2371: [2371, 'United Traders Token', 'UTT', 'uttoken', 1],
#  2374: [2374, 'BitDegree', 'BDG', 'bitdegree', 1],
#  2375: [2375, 'QunQun', 'QUN', 'qunqun', 1],
#  2376: [2376, 'TopChain', 'TOPC', 'topchain', 1],
#  2379: [2379, 'Kcash', 'KCASH', 'kcash', 1],
#  2380: [2380, 'ATN', 'ATN', 'atn', 1],
#  2382: [2382, 'Spectre.ai Utility Token', 'SXUT', 'spectre-utility', 1],
#  2386: [2386, 'KZ Cash', 'KZC', 'kz-cash', 1],
#  2387: [2387, 'Bitcoin Atom', 'BCA', 'bitcoin-atom', 1],
#  2391: [2391, 'EchoLink', 'EKO', 'echolink', 1],
#  2392: [2392, 'Bottos', 'BTO', 'bottos', 1],
#  2394: [2394, 'Telcoin', 'TEL', 'telcoin', 1],
#  2395: [2395, 'Ignition', 'IC', 'ignition', 1],
#  2396: [2396, 'WETH', 'WETH', 'weth', 1],
#  2398: [2398, 'Selfkey', 'KEY', 'selfkey', 1],
#  2399: [2399, 'INT', 'INT', 'int-chain', 1],
#  2400: [2400, 'OneRoot Network', 'RNT', 'oneroot-network', 1],
#  2402: [2402, 'Sense', 'SENSE', 'sense', 1],
#  2403: [2403, 'MOAC', 'MOAC', 'moac', 1],
#  2405: [2405, 'IOST', 'IOST', 'iostoken', 1],
#  2406: [2406, 'InvestDigital', 'IDT', 'investdigital', 1],
#  2407: [2407, 'AICHAIN', 'AIT', 'aichain', 1],
#  2410: [2410, 'SpaceChain', 'SPC', 'spacechain', 1],
#  2411: [2411, 'Galactrum', 'ORE', 'galactrum', 1],
#  2415: [2415, 'ArbitrageCT', 'ARCT', 'arbitragect', 1],
#  2416: [2416, 'THETA', 'THETA', 'theta', 1],
#  2418: [2418, 'Maverick Chain', 'MVC', 'maverick-chain', 1],
#  2419: [2419, 'Profile Utility Token', 'PUT', 'profile-utility-token', 1],
#  2421: [2421, 'VouchForMe', 'IPL', 'insurepal', 1],
#  2422: [2422, 'IDEX Membership', 'IDXM', 'idex-membership', 1],
#  2424: [2424, 'SingularityNET', 'AGI', 'singularitynet', 1],
#  2427: [2427, 'ChatCoin', 'CHAT', 'chatcoin', 1],
#  2428: [2428, 'Scry.info', 'DDD', 'scryinfo', 1],
#  2429: [2429, 'Mobius', 'MOBI', 'mobius', 1],
#  2430: [2430, 'Hydro Protocol', 'HOT', 'hydro-protocol', 1],
#  2434: [2434, 'Maggie', 'MAG', 'maggie', 1],
#  2437: [2437, 'YEE', 'YEE', 'yee', 1],
#  2438: [2438, 'Acute Angle Cloud', 'AAC', 'acute-angle-cloud', 1],
#  2441: [2441, 'Molecular Future', 'MOF', 'molecular-future', 1],
#  2443: [2443, 'Trinity Network Credit', 'TNC', 'trinity-network-credit', 1],
#  2444: [2444, 'CRYPTO20', 'C20', 'c20', 1],
#  2446: [2446, 'DATA', 'DTA', 'data', 1],
#  2447: [2447, 'Crypterium', 'CRPT', 'crpt', 1],
#  2448: [2448, 'SparksPay', 'SPK', 'sparkspay', 1],
#  2450: [2450, 'carVertical', 'CV', 'carvertical', 1],
#  2452: [2452, 'Tokenbox', 'TBX', 'tokenbox', 1],
#  2453: [2453, 'EDUCare', 'EKT', 'educare', 1],
#  2454: [2454, 'UnlimitedIP', 'UIP', 'unlimitedip', 1],
#  2455: [2455, 'PressOne', 'PRS', 'pressone', 1],
#  2457: [2457, 'TrueChain', 'TRUE', 'truechain', 1],
#  2458: [2458, 'Odyssey', 'OCN', 'odyssey', 1],
#  2459: [2459, 'indaHash', 'IDH', 'indahash', 1],
#  2460: [2460, 'Qbic', 'QBIC', 'qbic', 1],
#  2462: [2462, 'AidCoin', 'AID', 'aidcoin', 1],
#  2464: [2464, 'Devery', 'EVE', 'devery', 1],
#  2465: [2465, 'BUX Token', 'BUX', 'bux-token', 1],
#  2466: [2466, 'AXPR', 'AXPR', 'axpr-token', 1],
#  2467: [2467, 'OriginTrail', 'TRAC', 'origintrail', 1],
#  2468: [2468, 'LinkEye', 'LET', 'linkeye', 1],
#  2469: [2469, 'Zilliqa', 'ZIL', 'zilliqa', 1],
#  2470: [2470, 'CoinMeet', 'MEET', 'coinmeet', 1],
#  2471: [2471, 'Smartlands Network', 'SLT', 'smartlands-network', 1],
#  2472: [2472, 'Fortuna', 'FOTA', 'fortuna', 1],
#  2473: [2473, 'All Sports', 'SOC', 'all-sports', 1],
#  2474: [2474, 'Matrix AI Network', 'MAN', 'matrix-ai-network', 1],
#  2475: [2475, 'Garlicoin', 'GRLC', 'garlicoin', 1],
#  2476: [2476, 'Ruff', 'RUFF', 'ruff', 1],
#  2477: [2477, 'Nework', 'NKC', 'nework', 1],
#  2478: [2478, 'CoinFi', 'COFI', 'coinfi', 1],
#  2479: [2479, 'Equal', 'EQL', 'equal', 1],
#  2480: [2480, 'HalalChain', 'HLC', 'halalchain', 1],
#  2481: [2481, 'Zeepin', 'ZPT', 'zeepin', 1],
#  2482: [2482, 'CPChain', 'CPC', 'cpchain', 1],
#  2483: [2483, 'OceanChain', 'OC', 'oceanchain', 1],
#  2488: [2488, 'ValueChain', 'VLC', 'valuechain', 1],
#  2489: [2489, 'BitWhite', 'BTW', 'bitwhite', 1],
#  2490: [2490, 'CargoX', 'CXO', 'cargox', 1],
#  2492: [2492, 'Elastos', 'ELA', 'elastos', 1],
#  2493: [2493, 'STK', 'STK', 'stk', 1],
#  2496: [2496, 'Polymath', 'POLY', 'polymath-network', 1],
#  2497: [2497, 'Medicalchain', 'MTN', 'medical-chain', 1],
#  2499: [2499, 'SwissBorg', 'CHSB', 'swissborg', 1],
#  2500: [2500, 'Zilla', 'ZLA', 'zilla', 1],
#  2501: [2501, 'adbank', 'ADB', 'adbank', 1],
#  2502: [2502, 'Huobi Token', 'HT', 'huobi-token', 1],
#  2503: [2503, 'DMarket', 'DMT', 'dmarket', 1],
#  2505: [2505, 'Bluzelle', 'BLZ', 'bluzelle', 1],
#  2506: [2506, 'Swarm', 'SWM', 'swarm-network', 1],
#  2507: [2507, 'THEKEY', 'TKY', 'thekey', 1],
#  2510: [2510, 'Datawallet', 'DXT', 'datawallet', 1],
#  2511: [2511, 'WePower', 'WPR', 'wepower', 1],
#  2513: [2513, 'GoldMint', 'MNTP', 'goldmint', 1],
#  2516: [2516, 'MktCoin', 'MLM', 'mktcoin', 1],
#  2524: [2524, 'Universa', 'UTNP', 'universa', 1],
#  2525: [2525, 'Alphacat', 'ACAT', 'alphacat', 1],
#  2527: [2527, 'SureRemit', 'RMT', 'sureremit', 1],
#  2528: [2528, 'Dether', 'DTH', 'dether', 1],
#  2529: [2529, 'Cashaa', 'CAS', 'cashaa', 1],
#  2530: [2530, 'Fusion', 'FSN', 'fusion', 1],
#  2533: [2533, 'Restart Energy MWAT', 'MWAT', 'restart-energy-mwat', 1],
#  2536: [2536, 'Neurotoken', 'NTK', 'neurotoken', 1],
#  2537: [2537, 'Gems ', 'GEM', 'gems-protocol', 1],
#  2538: [2538, 'Nectar', 'NEC', 'nectar', 1],
#  2539: [2539, 'Ren', 'REN', 'ren', 1],
#  2540: [2540, 'Litecoin Cash', 'LCC', 'litecoin-cash', 1],
#  2541: [2541, 'Storiqa', 'STQ', 'storiqa', 1],
#  2542: [2542, 'Tidex Token', 'TDX', 'tidex-token', 1],
#  2544: [2544, 'Nucleus Vision', 'NCASH', 'nucleus-vision', 1],
#  2545: [2545, 'Arcblock', 'ABT', 'arcblock', 1],
#  2546: [2546, 'Remme', 'REM', 'remme', 1],
#  2547: [2547, 'Experty', 'EXY', 'experty', 1],
#  2548: [2548, 'POA', 'POA', 'poa', 1],
#  2549: [2549, 'Ink Protocol', 'XNK', 'ink-protocol', 1],
#  2551: [2551, 'Bezop', 'BEZ', 'bezop', 1],
#  2552: [2552,
#   'IHT Real Estate Protocol',
#   'IHT',
#   'iht-real-estate-protocol',
#   1],
#  2553: [2553, 'Refereum', 'RFR', 'refereum', 1],
#  2554: [2554, 'Lympo', 'LYM', 'lympo', 1],
#  2556: [2556, 'Credits', 'CS', 'credits', 1],
#  2558: [2558, 'Insights Network', 'INSTAR', 'insights-network', 1],
#  2559: [2559, 'Cube', 'AUTO', 'cube', 1],
#  2561: [2561, 'BitTube', 'TUBE', 'bit-tube', 1],
#  2562: [2562, 'Education Ecosystem', 'LEDU', 'education-ecosystem', 1],
#  2563: [2563, 'TrueUSD', 'TUSD', 'trueusd', 1],
#  2564: [2564, 'HOQU', 'HQX', 'hoqu', 1],
#  2565: [2565, 'StarterCoin', 'STAC', 'startercoin', 1],
#  2566: [2566, 'Ontology', 'ONT', 'ontology', 1],
#  2567: [2567, 'DATx', 'DATX', 'datx', 1],
#  2568: [2568, 'JET8', 'J8T', 'jet8', 1],
#  2569: [2569, 'CoinPoker', 'CHP', 'coinpoker', 1],
#  2570: [2570, 'TomoChain', 'TOMO', 'tomochain', 1],
#  2571: [2571, 'Graft', 'GRFT', 'graft', 1],
#  2572: [2572, 'BABB', 'BAX', 'babb', 1],
#  2573: [2573, 'Electrify.Asia', 'ELEC', 'electrifyasia', 1],
#  2575: [2575, 'Bitcoin Private', 'BTCP', 'bitcoin-private', 1],
#  2576: [2576, 'Tokenomy', 'TEN', 'tokenomy', 1],
#  2577: [2577, 'Ravencoin', 'RVN', 'ravencoin', 1],
#  2578: [2578, 'TE-FOOD', 'TONE', 'te-food', 1],
#  2579: [2579, 'ShipChain', 'SHIP', 'shipchain', 1],
#  2580: [2580, 'Leadcoin', 'LDC', 'leadcoin', 1],
#  2584: [2584, 'Debitum', 'DEB', 'debitum-network', 1],
#  2585: [2585, 'Centrality', 'CENNZ', 'centrality', 1],
#  2586: [2586, 'Synthetix', 'SNX', 'synthetix-network-token', 1],
#  2588: [2588, 'Loom Network', 'LOOM', 'loom-network', 1],
#  2592: [2592, 'Banca', 'BANCA', 'banca', 1],
#  2593: [2593, 'Dragon Coins', 'DRG', 'dragon-coins', 1],
#  2595: [2595, 'NANJCOIN', 'NANJ', 'nanjcoin', 1],
#  2597: [2597, 'UpToken', 'UP', 'uptoken', 1],
#  2600: [2600, 'LGO Token', 'LGO', 'lgo-token', 1],
#  2601: [2601, '1World', '1WO', '1world', 1],
#  2602: [2602, 'NaPoleonX', 'NPX', 'napoleonx', 1],
#  2603: [2603, 'Pundi X[old]', 'NPXS', 'pundi-x', 1],
#  2604: [2604, 'BitGreen', 'BITG', 'bitgreen', 1],
#  2605: [2605, 'BnkToTheFuture', 'BFT', 'bnktothefuture', 1],
#  2606: [2606, 'Wanchain', 'WAN', 'wanchain', 1],
#  2607: [2607, 'AMLT', 'AMLT', 'amlt', 1],
#  2608: [2608, 'Mithril', 'MITH', 'mithril', 1],
#  2610: [2610, 'Peculium', 'PCL', 'peculium', 1],
#  2614: [2614, 'BlitzPredict', 'XBP', 'blitzpredict', 1],
#  2615: [2615, 'Blocklancer', 'LNC', 'blocklancer', 1],
#  2616: [2616, 'Stipend', 'SPD', 'stipend', 1],
#  2618: [2618, 'StockChain', 'SCC', 'stockchain', 1],
#  2620: [2620, 'Switcheo', 'SWTH', 'switcheo', 1],
#  2624: [2624, 'Sentinel Chain', 'SENC', 'sentinel-chain', 1],
#  2626: [2626, 'Friendz', 'FDZ', 'friends', 1],
#  2627: [2627, 'TokenPay', 'TPAY', 'tokenpay', 1],
#  2628: [2628, 'Rentberry', 'BERRY', 'rentberry', 1],
#  2629: [2629, 'Scala', 'XLA', 'scala', 1],
#  2630: [2630, 'PolySwarm', 'NCT', 'polyswarm', 1],
#  2631: [2631, 'ODEM', 'ODE', 'odem', 1],
#  2633: [2633, 'Stakenet', 'XSN', 'stakenet', 1],
#  2634: [2634, 'XinFin Network', 'XDC', 'xinfin-network', 1],
#  2638: [2638, 'Cortex', 'CTXC', 'cortex', 1],
#  2642: [2642, 'CyberVein', 'CVT', 'cybervein', 1],
#  2643: [2643, 'Sentinel', 'DVPN', 'sentinel', 1],
#  2644: [2644, 'eosDAC', 'EOSDAC', 'eosdac', 1],
#  2645: [2645, 'U Network', 'UUU', 'u-network', 1],
#  2653: [2653, 'Auctus', 'AUC', 'auctus', 1],
#  2655: [2655, 'Monero Classic', 'XMC', 'monero-classic', 1],
#  2658: [2658, 'Smart MFG', 'MFG', 'smart-mfg', 1],
#  2660: [2660, 'Aditus', 'ADI', 'aditus', 1],
#  2661: [2661, 'Tripio', 'TRIO', 'tripio', 1],
#  2662: [2662, 'Haven Protocol', 'XHV', 'haven-protocol', 1],
#  2665: [2665, 'Dero', 'DERO', 'dero', 1],
#  2666: [2666, 'Effect.AI', 'EFX', 'effect-ai', 1],
#  2667: [2667, 'FintruX Network', 'FTX', 'fintrux-network', 1],
#  2669: [2669, 'MARK.SPACE', 'MRK', 'mark-space', 1],
#  2670: [2670, 'Pixie Coin', 'PXC', 'pixie-coin', 1],
#  2673: [2673, 'WeOwn', 'CHX', 'we-own', 1],
#  2674: [2674, 'Masari', 'MSR', 'masari', 1],
#  2675: [2675, 'Dock', 'DOCK', 'dock', 1],
#  2676: [2676, 'PHI Token', 'PHI', 'phi-token', 1],
#  2677: [2677, 'Linker Coin', 'LNC', 'linker-coin', 1],
#  2678: [2678, 'TraDove B2BCoin', 'BBC', 'b2bcoin', 1],
#  2679: [2679,
#   'Decentralized Machine Learning',
#   'DML',
#   'decentralized-machine-learning',
#   1],
#  2682: [2682, 'Holo', 'HOT', 'holo', 1],
#  2685: [2685, 'Zebi Token', 'ZEBI', 'zebi-token', 1],
#  2686: [2686, 'Lendingblock', 'LND', 'lendingblock', 1],
#  2688: [2688, 'Vipstar Coin', 'VIPS', 'vipstar-coin', 1],
#  2689: [2689, 'Rublix', 'RBLX', 'rublix', 1],
#  2690: [2690, 'Biotron', 'BTRN', 'biotron', 1],
#  2691: [2691, 'Penta', 'PNT', 'penta', 1],
#  2694: [2694, 'Nexo', 'NEXO', 'nexo', 1],
#  2696: [2696, 'DAEX', 'DAX', 'daex', 1],
#  2698: [2698, 'Hydro', 'HYDRO', 'hydro', 1],
#  2699: [2699, 'Sharder', 'SS', 'sharder', 1],
#  2700: [2700, 'Celsius', 'CEL', 'celsius', 1],
#  2702: [2702, 'Bitcoin Interest', 'BCI', 'bitcoin-interest', 1],
#  2704: [2704, 'Transcodium', 'TNS', 'transcodium', 1],
#  2705: [2705, 'Amon', 'AMN', 'amon', 1],
#  2707: [2707, 'FLIP', 'FLP', 'flip', 1],
#  2708: [2708, 'Crowd Machine', 'CMCT', 'crowd-machine', 1],
#  2709: [2709, 'Morpheus Labs', 'MITX', 'morpheus-labs', 1],
#  2711: [2711, 'DOC.COM', 'MTC', 'doc-com', 1],
#  2712: [2712, 'MyToken', 'MT', 'mytoken', 1],
#  2713: [2713, 'KEY', 'KEY', 'key', 1],
#  2714: [2714, 'Nexty', 'NTY', 'nexty', 1],
#  2717: [2717, 'BoutsPro', 'BOUTS', 'boutspro', 1],
#  2719: [2719, 'Cybereits', 'CRE', 'cybereits', 1],
#  2720: [2720, 'Parkgene', 'GENE', 'parkgene', 1],
#  2721: [2721, 'APR Coin', 'APR', 'apr-coin', 1],
#  2722: [2722, 'AC3', 'AC3', 'ac3', 1],
#  2723: [2723, 'FuzeX', 'FXT', 'fuzex', 1],
#  2724: [2724, 'Zippie', 'ZIPT', 'zippie', 1],
#  2725: [2725, 'Skrumble Network', 'SKM', 'skrumble-network', 1],
#  2726: [2726, 'DAOstack', 'GEN', 'daostack', 1],
#  2727: [2727, 'Bezant', 'BZNT', 'bezant', 1],
#  2729: [2729, 'TEAM (TokenStars)', 'TEAM', 'tokenstars', 1],
#  2731: [2731, 'Utrum', 'OOT', 'utrum', 1],
#  2733: [2733, 'Freyrchain', 'FREC', 'freyrchain', 1],
#  2734: [2734, 'EduCoin', 'EDU', 'edu-coin', 1],
#  2735: [2735,
#   'Content Neutrality Network',
#   'CNN',
#   'content-neutrality-network',
#   1],
#  2737: [2737, 'Global Social Chain', 'GSC', 'global-social-chain', 1],
#  2739: [2739, 'Digix Gold Token', 'DGX', 'digix-gold-token', 1],
#  2741: [2741,
#   'Intelligent Investment Chain',
#   'IIC',
#   'intelligent-investment-chain',
#   1],
#  2742: [2742, 'Sakura Bloom', 'SKB', 'sakura-bloom', 1],
#  2745: [2745, 'Joint Ventures', 'JOINT', 'joint-ventures', 1],
#  2746: [2746, 'GreenPower', 'GRN', 'greenpower', 1],
#  2747: [2747, 'BlockMesh', 'BMH', 'blockmesh', 1],
#  2748: [2748, 'Oxen', 'OXEN', 'oxen', 1],
#  2752: [2752, 'Datarius Credit', 'DTRC', 'datarius-credit', 1],
#  2754: [2754, 'HeroNode', 'HER', 'heronode', 1],
#  2755: [2755, 'Raise', 'RAISE', 'raise', 1],
#  2757: [2757, 'Callisto Network', 'CLO', 'callisto-network', 1],
#  2758: [2758, 'Unibright', 'UBT', 'unibright', 1],
#  2759: [2759, 'Patron', 'PAT', 'patron', 1],
#  2760: [2760, 'Cred', 'LBA', 'libra-credit', 1],
#  2762: [2762, 'Open Platform', 'OPEN', 'open-platform', 1],
#  2763: [2763, 'Morpheus.Network', 'MRPH', 'morpheus-network', 1],
#  2765: [2765, 'XYO', 'XYO', 'xyo', 1],
#  2766: [2766, 'Cryptaur', 'CPT', 'cryptaur', 1],
#  2771: [2771, 'RED', 'RED', 'red', 1],
#  2772: [2772, 'Digitex', 'DGTX', 'digitex', 1],
#  2773: [2773, 'GINcoin', 'GIN', 'gincoin', 1],
#  2775: [2775, 'Faceter', 'FACE', 'faceter', 1],
#  2776: [2776, 'Travala.com', 'AVA', 'travala', 1],
#  2777: [2777, 'IoTeX', 'IOTX', 'iotex', 1],
#  2780: [2780, 'NKN', 'NKN', 'nkn', 1],
#  2827: [2827, 'Phantasma', 'SOUL', 'phantasma', 1],
#  2828: [2828, 'SPINDLE', 'SPD', 'spindle', 1],
#  2829: [2829, 'REPO', 'REPO', 'repo', 1],
#  2830: [2830, 'Seele-N', 'SEELE', 'seele', 1],
#  2835: [2835, 'Endor Protocol', 'EDR', 'endor-protocol', 1],
#  2836: [2836, 'Bigbom', 'BBO', 'bigbom', 1],
#  2837: [2837, '0xBitcoin', '0xBTC', '0xbtc', 1],
#  2838: [2838, 'Plian', 'PI', 'pchain', 1],
#  2840: [2840, 'QuarkChain', 'QKC', 'quarkchain', 1],
#  2842: [2842, 'Bankera', 'BNK', 'bankera', 1],
#  2843: [2843, 'Ether Zero', 'ETZ', 'ether-zero', 1],
#  2846: [2846, 'FuturoCoin', 'FTO', 'futurocoin', 1],
#  2847: [2847, 'Abyss', 'ABYSS', 'abyss', 1],
#  2850: [2850, 'TRAXIA', 'TM2', 'traxia', 1],
#  2852: [2852, 'Engine', 'EGCC', 'engine', 1],
#  2855: [2855, 'Casino Betting Coin', 'CBC', 'casino-betting-coin', 1],
#  2856: [2856, 'CEEK VR', 'CEEK', 'ceek-vr', 1],
#  2859: [2859, 'XMax', 'XMX', 'xmax', 1],
#  2861: [2861, 'GoChain', 'GO', 'gochain', 1],
#  2862: [2862, 'Smartshare', 'SSP', 'smartshare', 1],
#  2865: [2865, 'Trittium', 'TRTT', 'trittium', 1],
#  2866: [2866, 'Sentinel Protocol', 'UPP', 'sentinel-protocol', 1],
#  2867: [2867, 'Bittwatt', 'BWT', 'bittwatt', 1],
#  2868: [2868, 'Constellation', 'DAG', 'constellation', 1],
#  2869: [2869, 'Merculet', 'MVP', 'merculet', 1],
#  2870: [2870, 'FantasyGold', 'FGC', 'fantasygold', 1],
#  2871: [2871, 'Ubique Chain Of Things', 'UCT', 'ubique-chain-of-things', 1],
#  2873: [2873, 'Metronome', 'MET', 'metronome', 1],
#  2874: [2874, 'Aurora', 'AOA', 'aurora', 1],
#  2876: [2876, 'Ternio', 'TERN', 'ternio', 1],
#  2878: [2878, 'DigiFinexToken', 'DFT', 'digifinextoken', 1],
#  2879: [2879, 'Origin Sport', 'ORS', 'origin-sport', 1],
#  2880: [2880, 'Rate3', 'RTE', 'rate3', 1],
#  2882: [2882, '0Chain', 'ZCN', '0chain', 1],
#  2883: [2883, 'ZINC', 'ZINC', 'zinc', 1],
#  2884: [2884, 'FSBT API Token', 'FSBT', 'fsbt-api-token', 1],
#  2885: [2885, 'Egretia', 'EGT', 'egretia', 1],
#  2889: [2889, "Bob's Repair", 'BOB', 'bobs-repair', 1],
#  2890: [2890, 'KanadeCoin', 'KNDC', 'kanadecoin', 1],
#  2891: [2891, 'Cardstack', 'CARD', 'cardstack', 1],
#  2893: [2893, 'On.Live', 'ONL', 'on-live', 1],
#  2894: [2894, 'OTCBTC Token', 'OTB', 'otcbtc-token', 1],
#  2895: [2895, 'Coni', 'CONI', 'coni', 1],
#  2896: [2896, 'Hifi Finance', 'MFT', 'mainframe', 1],
#  2898: [2898, 'GoNetwork', 'GOT', 'gonetwork', 1],
#  2899: [2899, 'Thrive Token', 'THRT', 'thrive-token', 1],
#  2900: [2900, 'Project Pai', 'PAI', 'project-pai', 1],
#  2901: [2901, 'FansTime', 'FTI', 'fanstime', 1],
#  2902: [2902, 'POPCHAIN', 'PCH', 'popchain', 1],
#  2906: [2906, 'Essentia', 'ESS', 'essentia', 1],
#  2907: [2907, 'Karatgold Coin', 'KBC', 'karatgold-coin', 1],
#  2908: [2908, 'HashCoin', 'HSC', 'hashcoin', 1],
#  2909: [2909, 'LikeCoin', 'LIKE', 'likecoin', 1],
#  2911: [2911, 'ORS Group', 'ORS', 'ors-group', 1],
#  2912: [2912, 'TENT', 'TENT', 'tent', 1],
#  2913: [2913, 'Databroker', 'DTX', 'databroker', 1],
#  2914: [2914, 'BeeKan', 'BKBT', 'beekan', 1],
#  2915: [2915, 'Moss Coin', 'MOC', 'moss-coin', 1],
#  2916: [2916, 'Nimiq', 'NIM', 'nimiq', 1],
#  2918: [2918, 'BitZ Token', 'BZ', 'bit-z-token', 1],
#  2919: [2919, 'DWS', 'DWS', 'dws', 1],
#  2920: [2920, '0xcert', 'ZXC', '0xcert', 1],
#  2921: [2921, 'OneLedger', 'OLT', 'oneledger', 1],
#  2923: [2923, 'XMCT', 'XMCT', 'xmct', 1],
#  2927: [2927, 'sUSD', 'SUSD', 'susd', 1],
#  2929: [2929, 'Truegame', 'TGAME', 'tgame', 1],
#  2930: [2930, 'Everipedia', 'IQ', 'everipedia', 1],
#  2933: [2933, 'BitMart Token', 'BMX', 'bitmart-token', 1],
#  2934: [2934, 'BitKan', 'KAN', 'bitkan', 1],
#  2937: [2937, 'VITE', 'VITE', 'vite', 1],
#  2938: [2938, 'Hashgard', 'GARD', 'hashgard', 1],
#  2941: [2941, 'CoinEx Token', 'CET', 'coinex-token', 1],
#  2943: [2943, 'Rocket Pool', 'RPL', 'rocket-pool', 1],
#  2944: [2944, 'Elysian', 'ELY', 'elysian', 1],
#  2945: [2945, 'ContentBox', 'BOX', 'contentbox', 1],
#  2947: [2947, 'SoPay', 'SOP', 'sopay', 1],
#  2949: [2949, 'Kryll', 'KRL', 'kryll', 1],
#  2950: [2950, 'LemoChain', 'LEMO', 'lemochain', 1],
#  2953: [2953, 'Blue Whale EXchange', 'BWX', 'blue-whale-exchange', 1],
#  2955: [2955, 'Cosmo Coin', 'COSM', 'cosmo-coin', 1],
#  2956: [2956, 'Narrative', 'NRVE', 'narrative', 1],
#  2958: [2958, 'TurtleCoin', 'TRTL', 'turtlecoin', 1],
#  2960: [2960, 'Tourist Token', 'TOTO', 'tourist-token', 1],
#  2965: [2965, 'VikkyToken', 'VIKKY', 'vikkytoken', 1],
#  2966: [2966, 'Fox Trading', 'FOXT', 'fox-trading', 1],
#  2968: [2968, 'Bridge Protocol', 'BRDG', 'bridge-protocol', 1],
#  2969: [2969, 'Globalvillage Ecosystem', 'GVE', 'globalvillage-ecosystem', 1],
#  2970: [2970, 'LocalCoinSwap', 'LCS', 'local-coin-swap', 1],
#  2972: [2972, 'ZPER', 'ZPR', 'zper', 1],
#  2976: [2976, 'Ryo Currency', 'RYO', 'ryo-currency', 1],
#  2977: [2977, 'BitRewards', 'BIT', 'bitrewards', 1],
#  2978: [2978, 'AceD', 'ACED', 'aced', 1],
#  2980: [2980, 'WABnetwork', 'WAB', 'wabnetwork', 1],
#  2981: [2981, 'Consentium', 'CSM', 'consentium', 1],
#  2982: [2982, 'MVL', 'MVL', 'mvl', 1],
#  2984: [2984, 'Newton Coin Project', 'NCP', 'newton-coin-project', 1],
#  2986: [2986, 'DACC', 'DACC', 'dacc', 1],
#  2987: [2987, 'ThingsOperatingSystem', 'TOS', 'thingsoperatingsystem', 1],
#  2988: [2988, 'Pigeoncoin', 'PGN', 'pigeoncoin', 1],
#  2989: [2989, 'STASIS EURO', 'EURS', 'stasis-euro', 1],
#  2990: [2990, 'EXMR FDN', 'EXMR', 'exmr-fdn', 1],
#  2991: [2991, 'NIX', 'NIX', 'nix', 1],
#  2992: [2992, 'Apollo Currency', 'APL', 'apollo-currency', 1],
#  2993: [2993, 'HorusPay', 'HORUS', 'horuspay', 1],
#  2994: [2994, 'Bitcoin File', 'BIFI', 'bitcoin-file', 1],
#  2998: [2998, 'Vexanium', 'VEX', 'vexanium', 1],
#  2999: [2999, 'Hdac', 'HDAC', 'hdac', 1],
#  3001: [3001, 'KWHCoin', 'KWH', 'kwhcoin', 1],
#  3002: [3002, 'Master Contract Token', 'MCT', 'master-contract-token', 1],
#  ...}

# %%
def get_cmc_cryptocurrency_meta_info_by_id(id):
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/info'
    response = pull_cmc_cryptocurrency_meta_info(url, id)
    ids_json_data = response['data']
    ids_meta_info = {}
    for cmc_id in ids_json_data:
        json_data = ids_json_data[cmc_id]
        meta_info = []
        meta_info.append(json_data['category'])
        meta_info.append(get_host_url(json_data['urls']['website'][0]) if json_data['urls']['website'] else '')
        meta_info.append(','.join(json_data['tags']) if json_data['tags'] else '')
        ids_meta_info[f'{cmc_id}'] = meta_info
    print(len(ids_meta_info))
    return ids_meta_info

# %%
cmc_cryptocurrency_data = []
cryptocurrency_count = len(parsed_cmc_symbol_ids_data)
start_index = 0
batch_size = 100
cryptocurrency_ids = list(parsed_cmc_symbol_ids_data.keys())
cryptocurrency_ids = [str(cryptocurrency_id) for cryptocurrency_id in cryptocurrency_ids]
while start_index < cryptocurrency_count:
    end_index = start_index + batch_size
    cryptocurrency_ids_subset = cryptocurrency_ids[start_index : end_index]
    cryptocurrency_ids_meta_info = get_cmc_cryptocurrency_meta_info_by_id(','.join(cryptocurrency_ids_subset))
    for cryptocurrency_id in cryptocurrency_ids_subset:
        cryptocurrency_data = []
        cryptocurrency_data.extend(parsed_cmc_symbol_ids_data[int(cryptocurrency_id)])
        cryptocurrency_data.extend(cryptocurrency_ids_meta_info[(cryptocurrency_id)])
        cmc_cryptocurrency_data.append(cryptocurrency_data)
    time.sleep(1)
    start_index = end_index
# Out:
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 100
# 18

# %%
cmc_cryptocurrency_data
# Out:
# [[1,
#   'Bitcoin',
#   'BTC',
#   'bitcoin',
#   1,
#   'coin',
#   'https://bitcoin.org',
#   'mineable,pow,sha-256,store-of-value,state-channels,coinbase-ventures-portfolio,three-arrows-capital-portfolio,polychain-capital-portfolio,binance-labs-portfolio,arrington-xrp-capital,blockchain-capital-portfolio,boostvc-portfolio,cms-holdings-portfolio,dcg-portfolio,dragonfly-capital-portfolio,electric-capital-portfolio,fabric-ventures-portfolio,framework-ventures,galaxy-digital-portfolio,huobi-capital,alameda-research-portfolio,a16z-portfolio,1confirmation-portfolio,winklevoss-capital,usv-portfolio,placeholder-ventures-portfolio,pantera-capital-portfolio,multicoin-capital-portfolio,paradigm-xzy-screener'],
#  [2,
#   'Litecoin',
#   'LTC',
#   'litecoin',
#   1,
#   'coin',
#   'https://litecoin.org',
#   'mineable,pow,scrypt,medium-of-exchange,binance-chain'],
#  [3,
#   'Namecoin',
#   'NMC',
#   'namecoin',
#   1,
#   'coin',
#   'https://namecoin.org',
#   'mineable,pow,sha-256,platform'],
#  [4,
#   'Terracoin',
#   'TRC',
#   'terracoin',
#   1,
#   'coin',
#   'http://terracoin.io',
#   'mineable,pow,sha-256,masternodes'],
#  [5,
#   'Peercoin',
#   'PPC',
#   'peercoin',
#   1,
#   'coin',
#   'http://peercoin.net',
#   'mineable,hybrid-pow-pos,sha-256,medium-of-exchange,payments'],
#  [8,
#   'Feathercoin',
#   'FTC',
#   'feathercoin',
#   1,
#   'coin',
#   'http://feathercoin.com',
#   'mineable,pow,neoscrypt,medium-of-exchange,payments'],
#  [10,
#   'Freicoin',
#   'FRC',
#   'freicoin',
#   1,
#   'coin',
#   'http://freico.in',
#   'mineable,pow,sha-256'],
#  [13,
#   'Ixcoin',
#   'IXC',
#   'ixcoin',
#   1,
#   'coin',
#   'https://ixcoin.net',
#   'pow,sha-256'],
#  [16,
#   'WorldCoin',
#   'WDC',
#   'worldcoin',
#   1,
#   'coin',
#   'http://worldcoin.global',
#   'mineable,pow,scrypt'],
#  [18,
#   'Digitalcoin',
#   'DGC',
#   'digitalcoin',
#   1,
#   'coin',
#   'http://digitalcoin.co',
#   'mineable,pow,scrypt'],
#  [25,
#   'Goldcoin',
#   'GLC',
#   'goldcoin',
#   1,
#   'coin',
#   'https://goldcoinproject.org',
#   'mineable,pow,scrypt'],
#  [35,
#   'Phoenixcoin',
#   'PXC',
#   'phoenixcoin',
#   1,
#   'coin',
#   'http://phoenixcoin.org',
#   'mineable,neoscrypt'],
#  [37,
#   'Megacoin',
#   'MEC',
#   'megacoin',
#   1,
#   'coin',
#   'https://megacoin-mec.cc',
#   'mineable,pow,scrypt'],
#  [41,
#   'Infinitecoin',
#   'IFC',
#   'infinitecoin',
#   1,
#   'coin',
#   'http://infiniteco.in',
#   'mineable,pow,scrypt'],
#  [42,
#   'Primecoin',
#   'XPM',
#   'primecoin',
#   1,
#   'coin',
#   'http://primecoin.io',
#   'mineable,pow,multiple-algorithms'],
#  [43,
#   'Anoncoin',
#   'ANC',
#   'anoncoin',
#   1,
#   'coin',
#   'https://anoncoin.net',
#   'mineable,pow,privacy'],
#  [45,
#   'CasinoCoin',
#   'CSC',
#   'casinocoin',
#   1,
#   'coin',
#   'http://casinocoin.org',
#   'poc,gambling,gaming'],
#  [50,
#   'Emerald Crypto',
#   'EMD',
#   'emerald',
#   1,
#   'coin',
#   'http://emeraldcrypto.de',
#   'mineable,pow,scrypt'],
#  [52,
#   'XRP',
#   'XRP',
#   'xrp',
#   1,
#   'coin',
#   'https://xrpl.org',
#   'medium-of-exchange,enterprise-solutions,binance-chain,arrington-xrp-capital,galaxy-digital-portfolio,a16z-portfolio,pantera-capital-portfolio'],
#  [53,
#   'Quark',
#   'QRK',
#   'quark',
#   1,
#   'coin',
#   'http://qrknet.info',
#   'mineable,pow,multiple-algorithms'],
#  [56,
#   'Zetacoin',
#   'ZET',
#   'zetacoin',
#   1,
#   'coin',
#   'http://zetac.org',
#   'mineable,pow,sha-256'],
#  [61,
#   'TagCoin',
#   'TAG',
#   'tagcoin',
#   1,
#   'coin',
#   'http://tagcoin.org',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [64,
#   'FLO',
#   'FLO',
#   'flo',
#   1,
#   'coin',
#   'http://flo.cash',
#   'mineable,pow,scrypt'],
#  [66,
#   'Nxt',
#   'NXT',
#   'nxt',
#   1,
#   'coin',
#   'https://jelurida.com',
#   'hybrid-pos-lpos,pos,platform,enterprise-solutions,state-channels'],
#  [67,
#   'Unobtanium',
#   'UNO',
#   'unobtanium',
#   1,
#   'coin',
#   'http://unobtanium.uno',
#   'mineable,pow,sha-256,medium-of-exchange,payments'],
#  [69,
#   'Datacoin',
#   'DTC',
#   'datacoin',
#   1,
#   'coin',
#   'http://datacoin.info',
#   'mineable,pow,multiple-algorithms'],
#  [72,
#   'Deutsche eMark',
#   'DEM',
#   'deutsche-emark',
#   1,
#   'coin',
#   'https://deutsche-emark.org',
#   'mineable,hybrid-pow-pos,sha-256'],
#  [74,
#   'Dogecoin',
#   'DOGE',
#   'dogecoin',
#   1,
#   'coin',
#   'http://dogecoin.com',
#   'mineable,pow,scrypt,medium-of-exchange,memes,payments'],
#  [77,
#   'Diamond',
#   'DMD',
#   'diamond',
#   1,
#   'coin',
#   'http://bit.diamonds',
#   'masternodes,staking'],
#  [78,
#   'HoboNickels',
#   'HBN',
#   'hobonickels',
#   1,
#   'coin',
#   'http://hobonickels.info',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [80,
#   'Orbitcoin',
#   'ORB',
#   'orbitcoin',
#   1,
#   'coin',
#   'http://orbitcoin.org',
#   'mineable,hybrid-pow-pos,neoscrypt'],
#  [83, 'Omni', 'OMNI', 'omni', 1, 'coin', 'http://omnilayer.org', 'pow,scrypt'],
#  [87,
#   'FedoraCoin',
#   'TIPS',
#   'fedoracoin',
#   1,
#   'coin',
#   'https://tipsco.in',
#   'mineable'],
#  [90,
#   'Dimecoin',
#   'DIME',
#   'dimecoin',
#   1,
#   'coin',
#   'https://dimecoinnetwork.com',
#   'mineable,pow,quark'],
#  [93,
#   '42-coin',
#   '42',
#   '42-coin',
#   1,
#   'coin',
#   'http://42-coin.org',
#   'mineable,hybrid-pow-pos,scrypt,store-of-value'],
#  [99,
#   'Vertcoin',
#   'VTC',
#   'vertcoin',
#   1,
#   'coin',
#   'http://vertcoin.org',
#   'mineable,pow,medium-of-exchange,privacy,payments'],
#  [109,
#   'DigiByte',
#   'DGB',
#   'digibyte',
#   1,
#   'coin',
#   'https://digibyte.org',
#   'mineable,pow,multiple-algorithms,medium-of-exchange,privacy,iot,payments'],
#  [113,
#   'SmartCoin',
#   'SMC',
#   'smartcoin',
#   1,
#   'coin',
#   'http://smartcoin.cc',
#   'mineable,pow,scrypt,coinbase-ventures-portfolio'],
#  [118,
#   'ReddCoin',
#   'RDD',
#   'redd',
#   1,
#   'coin',
#   'http://reddcoin.com',
#   'hybrid-pow-pos,scrypt,media,content-creation'],
#  [122,
#   'PotCoin',
#   'POT',
#   'potcoin',
#   1,
#   'coin',
#   'http://potcoin.com',
#   'mineable,pow,scrypt'],
#  [125,
#   'Blakecoin',
#   'BLC',
#   'blakecoin',
#   1,
#   'coin',
#   'http://blakecoin.org',
#   'mineable,pow,blake'],
#  [128,
#   'Maxcoin',
#   'MAX',
#   'maxcoin',
#   1,
#   'coin',
#   'https://maxcoinproject.org',
#   'mineable,hybrid-pow-pos'],
#  [131,
#   'Dash',
#   'DASH',
#   'dash',
#   1,
#   'coin',
#   'https://dash.org',
#   'mineable,hybrid-pow-pos,x11,medium-of-exchange,privacy,masternodes,dao'],
#  [132,
#   'Counterparty',
#   'XCP',
#   'counterparty',
#   1,
#   'coin',
#   'http://counterparty.io',
#   'pow'],
#  [141,
#   'MintCoin',
#   'MINT',
#   'mintcoin',
#   1,
#   'coin',
#   'http://mintcoinofficial.eu',
#   'pos,scrypt'],
#  [145,
#   'DopeCoin',
#   'DOPE',
#   'dopecoin',
#   1,
#   'coin',
#   'http://dopecoin.com',
#   'pow,scrypt'],
#  [148,
#   'Auroracoin',
#   'AUR',
#   'auroracoin',
#   1,
#   'coin',
#   'http://auroracoin.is',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [151,
#   'Pesetacoin',
#   'PTC',
#   'pesetacoin',
#   1,
#   'coin',
#   'http://pesetacoin.info',
#   'mineable,pow,scrypt'],
#  [154,
#   'Marscoin',
#   'MARS',
#   'marscoin',
#   1,
#   'coin',
#   'http://marscoin.org',
#   'mineable,pow,x11'],
#  [168,
#   'Uniform Fiscal Object',
#   'UFO',
#   'uniform-fiscal-object',
#   1,
#   'coin',
#   'https://ufocoin.net',
#   'mineable,pow,neoscrypt'],
#  [170,
#   'BlackCoin',
#   'BLK',
#   'blackcoin',
#   1,
#   'coin',
#   'https://blackcoin.org',
#   'pos,scrypt'],
#  [175,
#   'Photon',
#   'PHO',
#   'photon',
#   1,
#   'coin',
#   'http://photoncc.com',
#   'mineable,pow,blake256'],
#  [182,
#   'Myriad',
#   'XMY',
#   'myriad',
#   1,
#   'coin',
#   'http://myriadcoin.org',
#   'mineable,pow,multiple-algorithms'],
#  [184,
#   'DNotes',
#   'NOTE',
#   'dnotes',
#   1,
#   'coin',
#   'http://dnotescoin.com',
#   'mineable,pow,scrypt'],
#  [201,
#   'Einsteinium',
#   'EMC2',
#   'einsteinium',
#   1,
#   'coin',
#   'https://emc2.foundation',
#   'mineable,crowdfunding,research'],
#  [212, 'ECC', 'ECC', 'eccoin', 1, 'coin', 'https://ecc.network', 'pos,scrypt'],
#  [213,
#   'MonaCoin',
#   'MONA',
#   'monacoin',
#   1,
#   'coin',
#   'http://monacoin.org',
#   'mineable,pow,lyra2rev2,medium-of-exchange,memes,payments'],
#  [215,
#   'Rubycoin',
#   'RBY',
#   'rubycoin',
#   1,
#   'coin',
#   'http://rubycoin.org',
#   'pos,scrypt'],
#  [217,
#   'Bela',
#   'BELA',
#   'belacoin',
#   1,
#   'token',
#   'http://livebela.com',
#   'pow,scrypt'],
#  [224, 'FairCoin', 'FAIR', 'faircoin', 1, 'coin', 'http://fair-coin.org', ''],
#  [233,
#   'SolarCoin',
#   'SLR',
#   'solarcoin',
#   1,
#   'coin',
#   'http://solarcoin.org',
#   'pow,scrypt'],
#  [234,
#   'e-Gulden',
#   'EFL',
#   'e-gulden',
#   1,
#   'coin',
#   'http://e-gulden.org',
#   'mineable,pow,scrypt'],
#  [254,
#   'Gulden',
#   'NLG',
#   'gulden',
#   1,
#   'coin',
#   'https://gulden.com',
#   'mineable,pow,scrypt,sigma'],
#  [258,
#   'Groestlcoin',
#   'GRS',
#   'groestlcoin',
#   1,
#   'coin',
#   'http://groestlcoin.org',
#   'mineable,pow,groestl,medium-of-exchange,privacy'],
#  [260, 'PetroDollar', 'XPD', 'petrodollar', 1, 'coin', '', 'mineable'],
#  [263,
#   'PLNcoin',
#   'PLNC',
#   'plncoin',
#   1,
#   'coin',
#   'http://plncoin.org',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [268,
#   'WhiteCoin',
#   'XWC',
#   'whitecoin',
#   1,
#   'coin',
#   'http://whitecoin.info',
#   'platform,interoperability,staking,rpos'],
#  [275,
#   'PopularCoin',
#   'POP',
#   'popularcoin',
#   1,
#   'coin',
#   'https://popularcoin.com',
#   'mineable,pow,scrypt'],
#  [276,
#   'Bitstar',
#   'BITS',
#   'bitstar',
#   1,
#   'coin',
#   'https://bitstarcoin.com',
#   'hybrid-pow-pos,scrypt'],
#  [278,
#   'Quebecoin',
#   'QBC',
#   'quebecoin',
#   1,
#   'coin',
#   'https://quebecoin.ca',
#   'mineable,x11'],
#  [290,
#   'BlueCoin',
#   'BLU',
#   'bluecoin',
#   1,
#   'coin',
#   'http://bluecoin.org',
#   'mineable,hybrid-pow-pos,x11'],
#  [291,
#   'MaidSafeCoin',
#   'MAID',
#   'maidsafecoin',
#   1,
#   'token',
#   'https://safenetwork.tech',
#   'platform,distributed-computing,filesharing,storage'],
#  [293,
#   'Bitcoin Plus',
#   'XBC',
#   'bitcoin-plus',
#   1,
#   'coin',
#   'https://bitcoinplus.org',
#   'pos,medium-of-exchange,store-of-value,payments,scaling,staking'],
#  [298,
#   'NewYorkCoin',
#   'NYC',
#   'newyorkcoin',
#   1,
#   'coin',
#   'https://nycoin.net',
#   'mineable,pow,scrypt,payments'],
#  [313,
#   'Pinkcoin',
#   'PINK',
#   'pinkcoin',
#   1,
#   'coin',
#   'http://with.pink',
#   'mineable,hybrid-pow-pos,x11'],
#  [316, 'Dreamcoin', 'DRM', 'dreamcoin', 1, 'coin', 'http://dreamcoin.fi', ''],
#  [322,
#   'Energycoin',
#   'ENRG',
#   'energycoin',
#   1,
#   'coin',
#   'https://energycoin.eu',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [323,
#   'VeriCoin',
#   'VRC',
#   'vericoin',
#   1,
#   'coin',
#   'http://vericoin.info',
#   'mineable,post,scrypt'],
#  [328,
#   'Monero',
#   'XMR',
#   'monero',
#   1,
#   'coin',
#   'https://getmonero.org',
#   'mineable,pow,medium-of-exchange,privacy,ringct,boostvc-portfolio,electric-capital-portfolio,galaxy-digital-portfolio'],
#  [331,
#   'Litecoin Plus',
#   'LCP',
#   'litecoin-plus',
#   1,
#   'coin',
#   'http://litecoinplus.co',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [333,
#   'Curecoin',
#   'CURE',
#   'curecoin',
#   1,
#   'coin',
#   'https://curecoin.net',
#   'mineable,pow,scrypt,education,distributed-computing,research'],
#  [341,
#   'SuperCoin',
#   'SUPER',
#   'supercoin',
#   1,
#   'coin',
#   'https://supercoin.nl',
#   'mineable,hybrid-pow-pos,x11'],
#  [360,
#   'Motocoin',
#   'MOTO',
#   'motocoin',
#   1,
#   'coin',
#   'http://motocoin.org',
#   'mineable,pop'],
#  [362,
#   'CloakCoin',
#   'CLOAK',
#   'cloakcoin',
#   1,
#   'coin',
#   'https://cloakcoin.com',
#   'hybrid-pow-pos,x13'],
#  [366,
#   'BitSend',
#   'BSD',
#   'bitsend',
#   1,
#   'coin',
#   'https://bitsend.cc',
#   'mineable,hybrid-pow-pos,x11,masternodes'],
#  [367,
#   'Coin2.1',
#   'C2',
#   'coin2-1',
#   1,
#   'coin',
#   'http://coin2.us',
#   'hybrid-pow-pos,scrypt'],
#  [372,
#   'Bytecoin',
#   'BCN',
#   'bytecoin-bcn',
#   1,
#   'coin',
#   'https://bytecoin.org',
#   'mineable,pow,cryptonight,medium-of-exchange,privacy,payments'],
#  [377,
#   'Navcoin',
#   'NAV',
#   'nav-coin',
#   1,
#   'coin',
#   'http://navcoin.org',
#   'pos,medium-of-exchange,privacy,payments,staking,dao'],
#  [389,
#   'Startcoin',
#   'START',
#   'startcoin',
#   1,
#   'coin',
#   'https://startcoin.org',
#   'mineable,pow,x11'],
#  [405,
#   'DigitalNote',
#   'XDN',
#   'digitalnote',
#   1,
#   'coin',
#   'https://digitalnote.org',
#   'mineable,pow,cryptonight,privacy,payments'],
#  [406,
#   'Boolberry',
#   'BBR',
#   'boolberry',
#   1,
#   'coin',
#   'http://boolberry.com',
#   'mineable,pow,x11'],
#  [416,
#   'HempCoin',
#   'THC',
#   'hempcoin',
#   1,
#   'coin',
#   'http://hempcoin.org',
#   'mineable,hybrid-pow-pos,scrypt,masternodes'],
#  [448,
#   'Stealth',
#   'XST',
#   'stealth',
#   1,
#   'coin',
#   'https://stealth.org',
#   'mineable,hybrid-pow-pos,x13,medium-of-exchange,privacy'],
#  [460,
#   'Clams',
#   'CLAM',
#   'clams',
#   1,
#   'coin',
#   'http://clamcoin.org',
#   'pow,medium-of-exchange'],
#  [463,
#   'BitShares',
#   'BTS',
#   'bitshares',
#   1,
#   'coin',
#   'https://bitshares.org',
#   'pos,sha-512,marketplace,decentralized-exchange,defi'],
#  [470,
#   'Viacoin',
#   'VIA',
#   'viacoin',
#   1,
#   'coin',
#   'http://viacoin.org',
#   'mineable,pow,scrypt'],
#  [495,
#   'I/O Coin',
#   'IOC',
#   'iocoin',
#   1,
#   'coin',
#   'http://iocoin.io',
#   'hybrid-pow-pos,x11,filesharing'],
#  [501,
#   'Cryptonite',
#   'XCN',
#   'cryptonite',
#   1,
#   'coin',
#   'http://cryptonite.info',
#   'mineable,pow,m7-pow'],
#  [502,
#   'Carboncoin',
#   'CARBON',
#   'carboncoin',
#   1,
#   'coin',
#   'http://carboncoin.cc',
#   'mineable,pow,scrypt'],
#  [506,
#   'CannabisCoin',
#   'CANN',
#   'cannabiscoin',
#   1,
#   'coin',
#   'http://cannabiscoin.net',
#   'mineable,pow'],
#  [512,
#   'Stellar',
#   'XLM',
#   'stellar',
#   1,
#   'coin',
#   'https://stellar.org',
#   'medium-of-exchange,enterprise-solutions,decentralized-exchange,smart-contracts,hashkey-capital-portfolio'],
#  [541,
#   'Syscoin',
#   'SYS',
#   'syscoin',
#   1,
#   'coin',
#   'http://syscoin.org',
#   'mineable,pow,platform,enterprise-solutions,masternodes,scaling'],
#  [551,
#   'Donu',
#   'DONU',
#   'donu',
#   1,
#   'coin',
#   'https://neos.sh',
#   'mineable,pos,sha-256'],
#  [558,
#   'Emercoin',
#   'EMC',
#   'emercoin',
#   1,
#   'coin',
#   'http://emercoin.com',
#   'mineable,hybrid-pow-pos,sha-256'],
#  [572,
#   'RabbitCoin',
#   'RBBT',
#   'rabbitcoin',
#   1,
#   'coin',
#   'http://rabbitcoin.co',
#   'mineable'],
#  [573,
#   'Burst',
#   'BURST',
#   'burst',
#   1,
#   'coin',
#   'https://burst-coin.org',
#   'mineable,poc'],
#  [576,
#   'GameCredits',
#   'GAME',
#   'gamecredits',
#   1,
#   'token',
#   'https://gamecredits.org',
#   'collectibles-nfts,gaming'],
#  [584,
#   'NativeCoin',
#   'N8V',
#   'native-coin',
#   1,
#   'coin',
#   'https://native-coin.com',
#   'mineable,hybrid-pow-pos,x11'],
#  [588,
#   'Ubiq',
#   'UBQ',
#   'ubiq',
#   1,
#   'coin',
#   'http://ubiqsmart.com',
#   'mineable,pow,ethash,platform,dapp'],
#  [597,
#   'Opal',
#   'OPAL',
#   'opal',
#   1,
#   'coin',
#   'http://opal-coin.com',
#   'hybrid-pow-pos,x13'],
#  [601,
#   'Acoin',
#   'ACOIN',
#   'acoin',
#   1,
#   'coin',
#   'https://acoin.info',
#   'mineable,pow,sha-256'],
#  [624,
#   'bitCNY',
#   'BITCNY',
#   'bitcny',
#   1,
#   'token',
#   '',
#   'store-of-value,defi,stablecoin'],
#  [626,
#   'NuBits',
#   'USNBT',
#   'nubits',
#   1,
#   'coin',
#   'https://nubits.com',
#   'pos,sha-256,stablecoin,stablecoin-algorithmically-stabilized'],
#  [633,
#   'ExclusiveCoin',
#   'EXCL',
#   'exclusivecoin',
#   1,
#   'coin',
#   'https://exclusivecoin.pw',
#   'mineable,pos,masternodes'],
#  [638,
#   'Trollcoin',
#   'TROLL',
#   'trollcoin',
#   1,
#   'coin',
#   'http://trollcoin.com',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [644,
#   'GlobalBoost-Y',
#   'BSTY',
#   'globalboost-y',
#   1,
#   'coin',
#   'http://globalboost-y.com',
#   'mineable,pow,yescript'],
#  [656,
#   'Prime-XI',
#   'PXI',
#   'prime-xi',
#   1,
#   'coin',
#   'https://primexi.com',
#   'mineable,pow,x11'],
#  [659,
#   'Bitswift',
#   'BITS',
#   'bitswift',
#   1,
#   'token',
#   'http://bitswift.io',
#   'platform,enterprise-solutions'],
#  [693,
#   'Verge',
#   'XVG',
#   'verge',
#   1,
#   'coin',
#   'http://vergecurrency.com',
#   'mineable,multiple-algorithms,medium-of-exchange,privacy'],
#  [699,
#   'NuShares',
#   'NSR',
#   'nushares',
#   1,
#   'token',
#   'https://nubits.com',
#   'medium-of-exchange'],
#  [702,
#   'SpreadCoin',
#   'SPR',
#   'spreadcoin',
#   1,
#   'coin',
#   'http://spreadcoin.info',
#   'mineable,pow,x11'],
#  [703, 'Rimbit', 'RBT', 'rimbit', 1, 'coin', 'http://rimbit.com', ''],
#  [706,
#   'MonetaryUnit',
#   'MUE',
#   'monetaryunit',
#   1,
#   'coin',
#   'http://monetaryunit.org',
#   'mineable,pow,sha-256,masternodes'],
#  [707,
#   'Blocknet',
#   'BLOCK',
#   'blocknet',
#   1,
#   'coin',
#   'http://blocknet.co',
#   'hybrid-pow-pos,marketplace,masternodes'],
#  [719,
#   'Limitless VIP',
#   'VIP',
#   'limitless-vip',
#   1,
#   'coin',
#   'http://tittiecoin.com',
#   'pow,scrypt'],
#  [720,
#   'Crown',
#   'CRW',
#   'crown',
#   1,
#   'coin',
#   'https://crownplatform.com',
#   'mineable,pos,sha-256,collectibles-nfts,masternodes'],
#  [730,
#   'GCN Coin',
#   'GCN',
#   'gcn-coin',
#   1,
#   'coin',
#   'https://gcn.zone',
#   'mineable,pow,scrypt'],
#  [733, 'Quotient', 'XQN', 'quotient', 1, 'coin', '', 'hybrid-pow-pos,scrypt'],
#  [760,
#   'OKCash',
#   'OK',
#   'okcash',
#   1,
#   'coin',
#   'http://okcash.co',
#   'hybrid-pow-pos'],
#  [764,
#   'PayCoin',
#   'XPY',
#   'paycoin2',
#   1,
#   'coin',
#   'http://paycoin.com',
#   'mineable,pos,sha-256'],
#  [788,
#   'Circuits of Value',
#   'COVAL',
#   'circuits-of-value',
#   1,
#   'token',
#   'https://circuitsofvalue.com',
#   'collectibles-nfts'],
#  [789,
#   'Nexus',
#   'NXS',
#   'nexus',
#   1,
#   'coin',
#   'http://nexus.io',
#   'mineable,hybrid-pow-npos,platform,staking'],
#  [799,
#   'SmileyCoin',
#   'SMLY',
#   'smileycoin',
#   1,
#   'coin',
#   'https://smileyco.in',
#   'mineable,scrypt,marketplace'],
#  [815,
#   'Kobocoin',
#   'KOBO',
#   'kobocoin',
#   1,
#   'coin',
#   'http://kobocoin.com',
#   'hybrid-pow-pos,x15'],
#  [819,
#   'Bean Cash',
#   'BITB',
#   'bean-cash',
#   1,
#   'coin',
#   'http://beancash.org',
#   'mineable,hybrid-pow-pos,sha-256'],
#  [823, 'GeoCoin', 'GEO', 'geocoin', 1, 'token', 'http://geocoin.cash', ''],
#  [825,
#   'Tether',
#   'USDT',
#   'tether',
#   1,
#   'token',
#   'https://tether.to',
#   'store-of-value,payments,stablecoin,stablecoin-asset-backed,solana-ecosystem'],
#  [831,
#   'Wild Beast Block',
#   'WBB',
#   'wild-beast-block',
#   1,
#   'coin',
#   'http://wbbos.com',
#   'mineable,pow,scrypt'],
#  [833,
#   'Gridcoin',
#   'GRC',
#   'gridcoin',
#   1,
#   'coin',
#   'http://gridcoin.us',
#   'mineable,pos,sha-256'],
#  [837,
#   'X-Coin',
#   'XCO',
#   'x-coin',
#   1,
#   'coin',
#   'http://x-coin.info',
#   'hybrid-pow-pos,sha-256'],
#  [857,
#   'SongCoin',
#   'SONG',
#   'songcoin',
#   1,
#   'coin',
#   'http://songcoin.org',
#   'mineable,pow,scrypt'],
#  [859,
#   'Woodcoin',
#   'LOG',
#   'woodcoin',
#   1,
#   'coin',
#   'http://woodcoin.org',
#   'mineable,pow'],
#  [873,
#   'NEM',
#   'XEM',
#   'nem',
#   1,
#   'coin',
#   'http://nem.io',
#   'poi,medium-of-exchange,payments,smart-contracts'],
#  [894,
#   'Neutron',
#   'NTRN',
#   'neutron',
#   1,
#   'coin',
#   'http://neutroncoin.com',
#   'hybrid-pow-pos,sha-256,masternodes'],
#  [895,
#   'Xaurum',
#   'XAUR',
#   'xaurum',
#   1,
#   'token',
#   'http://xaurum.org',
#   'asset-management,stablecoin,stablecoin-asset-backed'],
#  [898,
#   'Californium',
#   'CF',
#   'californium',
#   1,
#   'coin',
#   'http://californium.info',
#   'mineable,pow,sha-256'],
#  [911,
#   'Advanced Internet Blocks',
#   'AIB',
#   'advanced-internet-blocks',
#   1,
#   'coin',
#   'http://iobond.com',
#   'mineable,pow,scrypt'],
#  [914,
#   'Sphere',
#   'SPHR',
#   'sphere',
#   1,
#   'coin',
#   'https://sphrpay.io',
#   'hybrid-pow-pos,scrypt'],
#  [916,
#   'MedicCoin',
#   'MEDIC',
#   'mediccoin',
#   1,
#   'coin',
#   'https://mediccoin.com',
#   'mineable,hybrid-pow-pos,scrypt,masternodes'],
#  [918, 'Bubble', 'BUB', 'bubble', 1, 'coin', '', ''],
#  [921,
#   'Universal Currency',
#   'UNIT',
#   'universal-currency',
#   1,
#   'coin',
#   'http://u-currency.com',
#   'mineable,hybrid-pow-pos,sha-256'],
#  [934,
#   'ParkByte',
#   'PKB',
#   'parkbyte',
#   1,
#   'coin',
#   'http://parkbyte.com',
#   'hybrid-pow-pos,sha-256'],
#  [938, 'ARbit', 'ARB', 'arbit', 1, 'coin', '', 'mineable,hybrid-pow-pos'],
#  [945,
#   'Bata',
#   'BTA',
#   'bata',
#   1,
#   'coin',
#   'https://bata.io',
#   'mineable,pow,scrypt'],
#  [948,
#   'AudioCoin',
#   'ADC',
#   'audiocoin',
#   1,
#   'coin',
#   'http://audiocoin.eu',
#   'mineable,hybrid-pow-pos,scrypt,music'],
#  [951,
#   'Synergy',
#   'SNRG',
#   'synergy',
#   1,
#   'coin',
#   'http://synergycoin.com',
#   'hybrid-pow-pos,x11'],
#  [960,
#   'FujiCoin',
#   'FJC',
#   'fujicoin',
#   1,
#   'coin',
#   'https://fujicoin.org',
#   'mineable,pow,scrypt-n'],
#  [977,
#   'GravityCoin',
#   'GXX',
#   'gravitycoin',
#   1,
#   'coin',
#   'http://specialcoins.ovh',
#   'mineable,pow,lyra2re'],
#  [978,
#   'Ratecoin',
#   'XRA',
#   'ratecoin',
#   1,
#   'coin',
#   'https://stakeminers.com',
#   'hybrid-pow-pos,x11'],
#  [986,
#   'CrevaCoin',
#   'CREVA',
#   'crevacoin',
#   1,
#   'coin',
#   'http://crevacoin.com',
#   'mineable'],
#  [990,
#   'Bitzeny',
#   'ZNY',
#   'bitzeny',
#   1,
#   'coin',
#   'http://bitzeny.org',
#   'mineable,pow,scrypt'],
#  [993,
#   'BowsCoin',
#   'BSC',
#   'bowscoin',
#   1,
#   'coin',
#   'https://bowscoin.info',
#   'mineable,pow,x11'],
#  [1004,
#   'Hellenic Coin',
#   'HNC',
#   'helleniccoin',
#   1,
#   'coin',
#   'http://helleniccoin.com',
#   'mineable,pow,scrypt'],
#  [1019, 'Manna', 'MANNA', 'manna', 1, 'coin', 'https://mannabase.com', ''],
#  [1020,
#   'Axiom',
#   'AXIOM',
#   'axiom',
#   1,
#   'coin',
#   'http://axiomcrypto.org',
#   'mineable,hybrid-pow-pos'],
#  [1022, 'BITTUP', 'BTU', 'bittup', 1, 'token', 'https://bittup.com', ''],
#  [1026,
#   'Aeon',
#   'AEON',
#   'aeon',
#   1,
#   'coin',
#   'http://aeon.cash',
#   'mineable,pow,cryptonight-lite,privacy'],
#  [1027,
#   'Ethereum',
#   'ETH',
#   'ethereum',
#   1,
#   'coin',
#   'https://ethereum.org',
#   'mineable,pow,smart-contracts,ethereum,coinbase-ventures-portfolio,three-arrows-capital-portfolio,polychain-capital-portfolio,binance-labs-portfolio,arrington-xrp-capital,blockchain-capital-portfolio,boostvc-portfolio,cms-holdings-portfolio,dcg-portfolio,dragonfly-capital-portfolio,electric-capital-portfolio,fabric-ventures-portfolio,framework-ventures,hashkey-capital-portfolio,kinetic-capital,huobi-capital,alameda-research-portfolio,a16z-portfolio,1confirmation-portfolio,winklevoss-capital,usv-portfolio,placeholder-ventures-portfolio,pantera-capital-portfolio,multicoin-capital-portfolio,paradigm-xzy-screener'],
#  [1032,
#   'TransferCoin',
#   'TX',
#   'transfercoin',
#   1,
#   'coin',
#   'http://txproject.io',
#   'hybrid-pow-pos,x11,masternodes'],
#  [1033,
#   'GuccioneCoin',
#   'GCC',
#   'guccionecoin',
#   1,
#   'coin',
#   'https://wordpress.com',
#   'pow,scrypt'],
#  [1035,
#   'AmsterdamCoin',
#   'AMS',
#   'amsterdamcoin',
#   1,
#   'coin',
#   'http://amsterdamcoin.com',
#   'mineable,hybrid-pow-pos,quark'],
#  [1037,
#   'Agoras Tokens',
#   'AGRS',
#   'agoras-tokens',
#   1,
#   'token',
#   'http://idni.org',
#   ''],
#  [1038,
#   'Eurocoin',
#   'EUC',
#   'eurocoin',
#   1,
#   'coin',
#   'http://eurocoin-euc.com',
#   'mineable,hybrid-pow-pos,sha-256'],
#  [1042,
#   'Siacoin',
#   'SC',
#   'siacoin',
#   1,
#   'coin',
#   'https://sia.tech',
#   'mineable,pow,blake2b,platform,distributed-computing,filesharing,storage,dragonfly-capital-portfolio,fenbushi-capital-portfolio,paradigm-xzy-screener'],
#  [1044,
#   'Global Currency Reserve',
#   'GCR',
#   'global-currency-reserve',
#   1,
#   'coin',
#   'http://gcrcoin.com',
#   'pos'],
#  [1050,
#   'Shift',
#   'SHIFT',
#   'shift',
#   1,
#   'coin',
#   'https://shiftnrg.org',
#   'dpos,distributed-computing,filesharing,substrate,storage,polkadot-ecosystem'],
#  [1052,
#   'VectorAI',
#   'VEC2',
#   'vector',
#   1,
#   'coin',
#   'http://vector-blockchain.com',
#   'mineable,pow,dagger-hashimoto'],
#  [1053,
#   'Bolivarcoin',
#   'BOLI',
#   'bolivarcoin',
#   1,
#   'coin',
#   'https://bolis.info',
#   'mineable,pow,x11,masternodes'],
#  [1066,
#   'Pakcoin',
#   'PAK',
#   'pakcoin',
#   1,
#   'coin',
#   'http://pakcoin.io',
#   'mineable,pow,scrypt'],
#  [1070,
#   'Expanse',
#   'EXP',
#   'expanse',
#   1,
#   'coin',
#   'http://expanse.tech',
#   'mineable,pow,ethash'],
#  [1082,
#   'SIBCoin',
#   'SIB',
#   'sibcoin',
#   1,
#   'coin',
#   'https://sibcoin.com',
#   'mineable,pow,x11gost,masternodes'],
#  [1085,
#   'Swing',
#   'SWING',
#   'swing',
#   1,
#   'coin',
#   '',
#   'mineable,hybrid-pow-pos,sha-256'],
#  [1087,
#   'Factom',
#   'FCT',
#   'factom',
#   1,
#   'coin',
#   'https://factomprotocol.org',
#   'services,enterprise-solutions,data-provenance,fenbushi-capital-portfolio,hashkey-capital-portfolio'],
#  [1089,
#   'ParallelCoin',
#   'DUO',
#   'parallelcoin',
#   1,
#   'coin',
#   'http://parallelcoin.info',
#   'mineable,pow,scrypt'],
#  [1090,
#   'Save and Gain',
#   'SANDG',
#   'save-and-gain',
#   1,
#   'coin',
#   'http://co.uk',
#   'mineable,pow,sha-256'],
#  [1104,
#   'Augur',
#   'REP',
#   'augur',
#   1,
#   'token',
#   'http://augur.net',
#   'platform,defi,oracles,prediction-markets,reputation,storage,1confirmation-portfolio,pantera-capital-portfolio,multicoin-capital-portfolio'],
#  [1106,
#   'StrongHands',
#   'SHND',
#   'stronghands',
#   1,
#   'coin',
#   'https://stronghands.info',
#   'mineable,hybrid-pow-pos,medium-of-exchange,staking'],
#  [1107,
#   'PAC Protocol',
#   'PAC',
#   'pac-protocol',
#   1,
#   'coin',
#   'https://pacglobal.io',
#   'mineable,pos,pos-30,decentralized-exchange,filesharing,masternodes,storage'],
#  [1120,
#   'DraftCoin',
#   'DFT',
#   'draftcoin',
#   1,
#   'coin',
#   'http://btcdraft.com',
#   'pos,scrypt'],
#  [1135,
#   'ClubCoin',
#   'CLUB',
#   'clubcoin',
#   1,
#   'coin',
#   'http://clubcoin.co',
#   'hybrid-pow-pos,scrypt'],
#  [1136,
#   'Adzcoin',
#   'ADZ',
#   'adzcoin',
#   1,
#   'coin',
#   'https://adzcoin.org',
#   'mineable,pow,x11'],
#  [1146, 'AvatarCoin', 'AV', 'avatarcoin', 1, 'coin', '', 'pos'],
#  [1154,
#   'Validity',
#   'VAL',
#   'validity',
#   1,
#   'coin',
#   'https://validitytech.com',
#   'pos'],
#  [1155,
#   'Litecred',
#   'LTCR',
#   'litecred',
#   1,
#   'coin',
#   '',
#   'mineable,hybrid-pow-pos,qubit'],
#  [1156,
#   'Yocoin',
#   'YOC',
#   'yocoin',
#   1,
#   'coin',
#   'http://yocoin.org',
#   'mineable,pow,scrypt'],
#  [1159,
#   'SaluS',
#   'SLS',
#   'salus',
#   1,
#   'coin',
#   'http://saluscoin.info',
#   'hybrid-pow-pos,scrypt,marketplace,staking'],
#  [1164,
#   'Francs',
#   'FRN',
#   'francs',
#   1,
#   'coin',
#   'http://francs.paris',
#   'mineable,pow,scrypt'],
#  [1165,
#   'Evil Coin',
#   'EVIL',
#   'evil-coin',
#   1,
#   'coin',
#   'http://evilcoin.xyz',
#   'mineable,hybrid-pow-pos,x11'],
#  [1168,
#   'Decred',
#   'DCR',
#   'decred',
#   1,
#   'coin',
#   'https://decred.org',
#   'mineable,hybrid-pow-pos,blake256,medium-of-exchange,store-of-value,privacy,dao,placeholder-ventures-portfolio'],
#  [1169,
#   'PIVX',
#   'PIVX',
#   'pivx',
#   1,
#   'coin',
#   'https://pivx.org',
#   'pos,medium-of-exchange,store-of-value,privacy,zero-knowledge-proofs,masternodes,staking,dao'],
#  [1172,
#   'Safex Token',
#   'SFT',
#   'safex-token',
#   1,
#   'coin',
#   'http://safex.org',
#   ''],
#  [1175, 'Rubies', 'RBIES', 'rubies', 1, 'coin', 'http://rbies.org', 'pos'],
#  [1185,
#   'TrumpCoin',
#   'TRUMP',
#   'trumpcoin',
#   1,
#   'coin',
#   'http://trumpcoin.com',
#   'mineable,pos,blake'],
#  [1191,
#   'Memetic / PepeCoin',
#   'MEME',
#   'memetic',
#   1,
#   'coin',
#   'https://memetic.ai',
#   'mineable,hybrid-pow-pos,x11,masternodes'],
#  [1194,
#   'Independent Money System',
#   'IMS',
#   'independent-money-system',
#   1,
#   'coin',
#   'http://independentmoneysystem.com',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [1200,
#   'NevaCoin',
#   'NEVA',
#   'nevacoin',
#   1,
#   'coin',
#   'https://nevacoin.net',
#   'mineable,hybrid-pow-pos'],
#  [1209, 'PosEx', 'PEX', 'posex', 1, 'coin', '', 'mineable'],
#  [1210, 'Cabbage', 'CAB', 'cabbage', 1, 'coin', 'http://cabbage.tech', 'pos'],
#  [1212,
#   'MojoCoin',
#   'MOJO',
#   'mojocoin',
#   1,
#   'coin',
#   'https://mojocoin.org',
#   'pos'],
#  [1214,
#   'Lisk',
#   'LSK',
#   'lisk',
#   1,
#   'coin',
#   'https://lisk.io',
#   'dpos,platform,enterprise-solutions,smart-contracts'],
#  [1216,
#   'EDRCoin',
#   'EDRC',
#   'edrcoin',
#   1,
#   'coin',
#   'https://edrcoin.cash',
#   'hybrid-pow-pos,sha-256'],
#  [1218,
#   'PostCoin',
#   'POST',
#   'postcoin',
#   1,
#   'coin',
#   'https://postcoin.top',
#   'pos'],
#  [1223,
#   'BERNcash',
#   'BERN',
#   'berncash',
#   1,
#   'coin',
#   'http://berncoin.org',
#   'mineable,hybrid-pow-pos,x14'],
#  [1229,
#   'DigixDAO',
#   'DGD',
#   'digixdao',
#   1,
#   'token',
#   'https://digix.global',
#   'platform,stablecoin,stablecoin-asset-backed'],
#  [1230,
#   'Steem',
#   'STEEM',
#   'steem',
#   1,
#   'coin',
#   'https://steem.com',
#   'media,content-creation'],
#  [1241,
#   'FuzzBalls',
#   'FUZZ',
#   'fuzzballs',
#   1,
#   'coin',
#   'http://fyi-koerier.nl',
#   'mineable,pow,scrypt'],
#  [1244,
#   'HiCoin',
#   'XHI',
#   'hicoin',
#   1,
#   'coin',
#   'http://xhicoin.io',
#   'mineable,pos,scrypt'],
#  [1247,
#   'AquariusCoin',
#   'ARCO',
#   'aquariuscoin',
#   1,
#   'coin',
#   'http://aquariuscoin.com',
#   'hybrid-pow-pos,scrypt'],
#  [1248,
#   'Bitcoin 21',
#   'XBTC21',
#   'bitcoin-21',
#   1,
#   'coin',
#   'http://bitcoin-21.com',
#   ''],
#  [1250,
#   'Zurcoin',
#   'ZUR',
#   'zurcoin',
#   1,
#   'coin',
#   'http://zurcoin.org',
#   'mineable,pow,quark'],
#  [1252,
#   '2GIVE',
#   '2GIVE',
#   '2give',
#   1,
#   'coin',
#   'https://2give.info',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [1254,
#   'PlatinumBAR',
#   'XPTX',
#   'platinumbar',
#   1,
#   'coin',
#   'http://platinumbar.io',
#   'mineable,hybrid-pow-pos,quark'],
#  [1257,
#   'LanaCoin',
#   'LANA',
#   'lanacoin',
#   1,
#   'coin',
#   'https://lanacoin.com',
#   'mineable,hybrid-pow-pos'],
#  [1259, 'PonziCoin', 'PONZI', 'ponzicoin', 1, 'coin', '', 'mineable'],
#  [1266,
#   'MarteXcoin',
#   'MXT',
#   'martexcoin',
#   1,
#   'coin',
#   'http://martexcoin.org',
#   'mineable,hybrid-pow-pos,x13'],
#  [1273,
#   'Citadel',
#   'CTL',
#   'citadel',
#   1,
#   'coin',
#   'https://citadelplatform.org',
#   'mineable,pow,cryptonight'],
#  [1274,
#   'Waves',
#   'WAVES',
#   'waves',
#   1,
#   'coin',
#   'https://waves.tech',
#   'lpos,platform,smart-contracts,solana-ecosystem'],
#  [1279,
#   'PWR Coin',
#   'PWR',
#   'powercoin',
#   1,
#   'coin',
#   'https://pwr-coin.com',
#   'mineable'],
#  [1281,
#   'ION',
#   'ION',
#   'ion',
#   1,
#   'coin',
#   'https://ionomy.com',
#   'pos,masternodes'],
#  [1282,
#   'High Voltage',
#   'HVCO',
#   'high-voltage',
#   1,
#   'coin',
#   'http://highvoltagecoin.tech',
#   'hybrid-pow-pos,sha-256'],
#  [1285,
#   'GoldBlocks',
#   'GB',
#   'goldblocks',
#   1,
#   'coin',
#   'http://goldblocks.eu',
#   'mineable,hybrid-pow-pos,x11'],
#  [1291,
#   'Comet',
#   'CMT',
#   'comet',
#   1,
#   'coin',
#   'https://cometcoin.com',
#   'mineable,pow,scrypt'],
#  [1294,
#   'Rise',
#   'RISE',
#   'rise',
#   1,
#   'coin',
#   'https://rise.vision',
#   'dpos,platform,dapp'],
#  [1297,
#   'ChessCoin',
#   'CHESS',
#   'chesscoin',
#   1,
#   'coin',
#   'https://github.io',
#   'hybrid-pow-pos,scrypt'],
#  [1298,
#   'LBRY Credits',
#   'LBC',
#   'library-credit',
#   1,
#   'coin',
#   'https://lbry.com',
#   'mineable,marketplace,content-creation'],
#  [1299,
#   'PutinCoin',
#   'PUT',
#   'putincoin',
#   1,
#   'coin',
#   'https://putincoin.org',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [1306,
#   'Cryptojacks',
#   'CJ',
#   'cryptojacks',
#   1,
#   'coin',
#   'http://cryptojacks.com',
#   'mineable,hybrid-pow-pos,x13'],
#  [1308,
#   'HEAT',
#   'HEAT',
#   'heat-ledger',
#   1,
#   'coin',
#   'http://heatledger.com',
#   'hybrid-pos-pop'],
#  [1312,
#   'Steem Dollars',
#   'SBD',
#   'steem-dollars',
#   1,
#   'coin',
#   'https://steem.io',
#   'media,content-creation,stablecoin'],
#  [1320,
#   'Ardor',
#   'ARDR',
#   'ardor',
#   1,
#   'coin',
#   'https://jelurida.com',
#   'platform,enterprise-solutions,state-channels'],
#  [1321,
#   'Ethereum Classic',
#   'ETC',
#   'ethereum-classic',
#   1,
#   'coin',
#   'https://ethereumclassic.org',
#   'mineable,pow,ethash,platform,smart-contracts,dcg-portfolio'],
#  [1340,
#   'Karbo',
#   'KRB',
#   'karbo',
#   1,
#   'coin',
#   'http://karbowanec.com',
#   'mineable,pow,cryptonight,marketplace,privacy'],
#  [1343,
#   'Stratis',
#   'STRAX',
#   'stratis',
#   1,
#   'coin',
#   'http://stratisplatform.com',
#   'hybrid-pow-pos,x13,platform,enterprise-solutions'],
#  [1351, 'Aces', 'ACES', 'aces', 1, 'coin', '', 'pos'],
#  [1353,
#   'TajCoin',
#   'TAJ',
#   'tajcoin',
#   1,
#   'coin',
#   'http://tajcoin.tech',
#   'mineable,hybrid-pow-pos,blake2s'],
#  [1368, 'Veltor', 'VLT', 'veltor', 1, 'coin', '', 'mineable,pow'],
#  [1376,
#   'Neo',
#   'NEO',
#   'neo',
#   1,
#   'coin',
#   'https://neo.org',
#   'platform,enterprise-solutions,smart-contracts'],
#  [1381,
#   'Bitcloud',
#   'BTDX',
#   'bitcloud',
#   1,
#   'coin',
#   'https://bit-cloud.cc',
#   'hybrid-pow-pos,quark,masternodes'],
#  [1382,
#   'NoLimitCoin',
#   'NLC2',
#   'nolimitcoin',
#   1,
#   'coin',
#   'https://nolimitcoin.org',
#   'pos'],
#  [1389,
#   'Zayedcoin',
#   'ZYD',
#   'zayedcoin',
#   1,
#   'coin',
#   'http://zayedcoin.net',
#   'mineable,pow,sha-256'],
#  [1392,
#   'Pluton',
#   'PLU',
#   'pluton',
#   1,
#   'token',
#   'https://plutus.it',
#   'services,payments'],
#  [1395,
#   'Dollarcoin',
#   'DLC',
#   'dollarcoin',
#   1,
#   'coin',
#   '',
#   'mineable,pow,sha-256'],
#  [1396,
#   'MustangCoin',
#   'MST',
#   'mustangcoin',
#   1,
#   'coin',
#   'http://mustangcoin.xyz',
#   'mineable,hybrid-pow-pos,x11'],
#  [1398,
#   'PROUD Money',
#   'PROUD',
#   'proud-money',
#   1,
#   'coin',
#   'http://proud.money',
#   'mineable,hybrid-pow-pos,x11'],
#  [1403,
#   'FirstBlood',
#   '1ST',
#   'firstblood',
#   1,
#   'token',
#   'https://firstblood.io',
#   'media,loyalty,gaming,kinetic-capital'],
#  [1409,
#   'SingularDTV',
#   'SNGLS',
#   'singulardtv',
#   1,
#   'token',
#   'https://breaker.io',
#   'media,content-creation'],
#  [1414,
#   'Firo',
#   'FIRO',
#   'firo',
#   1,
#   'coin',
#   'https://firo.org',
#   'mineable,pow,medium-of-exchange,privacy,masternodes'],
#  [1434,
#   'Advanced Technology Coin',
#   'ARC',
#   'arcticcoin',
#   1,
#   'coin',
#   'https://advtech.group',
#   'mineable,pow'],
#  [1437,
#   'Zcash',
#   'ZEC',
#   'zcash',
#   1,
#   'coin',
#   'https://z.cash',
#   'mineable,pow,equihash,medium-of-exchange,privacy,zero-knowledge-proofs,binance-chain,boostvc-portfolio,dcg-portfolio,electric-capital-portfolio,fenbushi-capital-portfolio,hashkey-capital-portfolio,winklevoss-capital,placeholder-ventures-portfolio,pantera-capital-portfolio'],
#  [1439,
#   'AllSafe',
#   'ASAFE',
#   'allsafe',
#   1,
#   'coin',
#   'https://allsafecoin.org',
#   'pos,scrypt'],
#  [1447,
#   'ZClassic',
#   'ZCL',
#   'zclassic',
#   1,
#   'coin',
#   'http://zclassic-ce.com',
#   'mineable,pow,equihash,marketplace,privacy,zero-knowledge-proofs'],
#  [1454,
#   'Lykke',
#   'LKK',
#   'lykke',
#   1,
#   'coin',
#   'https://lykke.com',
#   'marketplace,centralized-exchange,payments'],
#  [1455,
#   'Golem',
#   'GLM',
#   'golem-network-tokens',
#   1,
#   'token',
#   'https://golem.network',
#   'platform,distributed-computing,payments'],
#  [1464,
#   'Internet of People',
#   'IOP',
#   'internet-of-people',
#   1,
#   'coin',
#   'http://iop.global',
#   'mineable,hybrid-pow-pos,sha-256'],
#  [1465, 'Veros', 'VRS', 'veros', 1, 'token', 'http://vedh.io', ''],
#  [1466,
#   'Hush',
#   'HUSH',
#   'hush',
#   1,
#   'coin',
#   'https://hush.is',
#   'mineable,pow,equihash,privacy'],
#  [1468,
#   'Kurrent',
#   'KURT',
#   'kurrent',
#   1,
#   'coin',
#   'http://kurrentproject.com',
#   'mineable,pow,x11,privacy'],
#  [1473,
#   'Pascal',
#   'PASC',
#   'pascal',
#   1,
#   'coin',
#   'http://pascalcoin.org',
#   'mineable'],
#  [1474,
#   'Eternity',
#   'ENT',
#   'eternity',
#   1,
#   'coin',
#   'http://eternity-group.org',
#   'mineable,hybrid-pow-pos,x11,masternodes'],
#  [1475,
#   'Incent',
#   'INCNT',
#   'incent',
#   1,
#   'token',
#   'https://incent.com',
#   'platform,loyalty'],
#  [1478,
#   'DECENT',
#   'DCT',
#   'decent',
#   1,
#   'coin',
#   'https://decent.ch',
#   'pos,dcg-portfolio'],
#  [1483, 'vSlice', 'VSL', 'vslice', 1, 'token', 'http://vslice.io', 'gambling'],
#  [1492, 'Obyte', 'GBYTE', 'obyte', 1, 'coin', 'https://obyte.org', ''],
#  [1495, 'PoSW Coin', 'POSW', 'posw-coin', 1, 'coin', 'https://posw.io', ''],
#  [1496,
#   'Luna Coin',
#   'LUNA',
#   'luna-coin',
#   1,
#   'coin',
#   'https://bitluna.org',
#   'mineable'],
#  [1500,
#   'Wings',
#   'WINGS',
#   'wings',
#   1,
#   'token',
#   'https://wings.ai',
#   'asset-management,crowdfunding'],
#  [1503,
#   'Jupiter',
#   'JUP',
#   'jupiter',
#   1,
#   'coin',
#   'https://gojupiter.tech',
#   'platform,enterprise-solutions'],
#  [1504,
#   'InflationCoin',
#   'IFLT',
#   'inflationcoin',
#   1,
#   'coin',
#   'http://inflationcoin.org',
#   'hybrid-pow-pos,x11'],
#  [1505,
#   'Alias',
#   'ALIAS',
#   'alias',
#   1,
#   'coin',
#   'https://alias.cash',
#   'pos,pos-30,privacy'],
#  [1510,
#   'CryptoCarbon',
#   'CCRB',
#   'cryptocarbon',
#   1,
#   'coin',
#   'https://co.uk',
#   ''],
#  [1511,
#   'PureVidz',
#   'VIDZ',
#   'purevidz',
#   1,
#   'coin',
#   'http://purevidz.net',
#   'pos'],
#  [1514,
#   'ICOBID',
#   'ICOB',
#   'icobid',
#   1,
#   'coin',
#   'http://icobidplatform.net',
#   'hybrid-pow-pos,scrypt'],
#  [1515,
#   'iBank',
#   'IBANK',
#   'ibank',
#   1,
#   'coin',
#   '',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [1518,
#   'Maker',
#   'MKR',
#   'maker',
#   1,
#   'token',
#   'https://makerdao.com',
#   'store-of-value,defi,dao,polychain-capital-portfolio,governance,lending-borowing,dragonfly-capital-portfolio,electric-capital-portfolio,a16z-portfolio,1confirmation-portfolio,placeholder-ventures-portfolio,pantera-capital-portfolio,paradigm-xzy-screener'],
#  [1521,
#   'Komodo',
#   'KMD',
#   'komodo',
#   1,
#   'coin',
#   'https://komodoplatform.com',
#   'mineable,hybrid-dpow-pow,equihash,platform,atomic-swaps,enterprise-solutions'],
#  [1522,
#   'FirstCoin',
#   'FRST',
#   'firstcoin',
#   1,
#   'coin',
#   'http://firstcoinproject.com',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [1527,
#   'Waves Community Token',
#   'WCT',
#   'waves-community-token',
#   1,
#   'token',
#   'https://wavesplatform.com',
#   'platform,enterprise-solutions'],
#  [1528,
#   'Iconic',
#   'ICON',
#   'iconic',
#   1,
#   'coin',
#   'http://iconicproject.com',
#   'pos'],
#  [1531,
#   'Global Cryptocurrency',
#   'GCC',
#   'global-cryptocurrency',
#   1,
#   'coin',
#   'https://thegcccoin.com',
#   'pow,scrypt'],
#  [1546,
#   'Centurion',
#   'CNT',
#   'centurion',
#   1,
#   'coin',
#   'http://centurionlab.org',
#   'mineable,hybrid-pow-pos,x11'],
#  [1552,
#   'Enzyme',
#   'MLN',
#   'enzyme',
#   1,
#   'token',
#   'https://enzyme.finance',
#   'asset-management,defi,kinetic-capital,placeholder-ventures-portfolio'],
#  [1556,
#   'Chrono.tech',
#   'TIME',
#   'chrono-tech',
#   1,
#   'token',
#   'https://chrono.tech',
#   ''],
#  [1558,
#   'Argus',
#   'ARGUS',
#   'argus',
#   1,
#   'coin',
#   'https://argusnetwork.co',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [1562,
#   'Swarm City',
#   'SWT',
#   'swarm-city',
#   1,
#   'token',
#   'http://swarm.city',
#   'marketplace'],
#  [1567,
#   'Nano',
#   'NANO',
#   'nano',
#   1,
#   'coin',
#   'http://nano.org',
#   'pow,blake2b,medium-of-exchange,payments'],
#  [1576,
#   'MiloCoin',
#   'MILO',
#   'milocoin',
#   1,
#   'coin',
#   'http://milocoin.info',
#   'mineable,hybrid-pow-pos,scrypt'],
#  [1578,
#   'Zero',
#   'ZER',
#   'zero',
#   1,
#   'coin',
#   'https://zerocurrency.io',
#   'mineable,pow,equihash,privacy'],
#  [1582, 'Netko', 'NETKO', 'netko', 1, 'coin', 'http://netko.tech', 'mineable'],
#  [1586,
#   'Ark',
#   'ARK',
#   'ark',
#   1,
#   'coin',
#   'http://ark.io',
#   'dpos,marketplace,payments,state-channels'],
#  [1587,
#   'Dynamic',
#   'DYN',
#   'dynamic',
#   1,
#   'coin',
#   'https://duality.solutions',
#   'mineable,pow,argon2,masternodes'],
#  [1588,
#   'Tokes',
#   'TKS',
#   'tokes',
#   1,
#   'token',
#   'https://multichain.ventures',
#   'health,payments'],
#  [1590,
#   'Mercury',
#   'MER',
#   'mercury',
#   1,
#   'token',
#   'https://gojupiter.tech',
#   'platform,dapp'],
#  [1596,
#   'Edgeless',
#   'EDG',
#   'edgeless',
#   1,
#   'token',
#   'https://edgeless.io',
#   'gambling,coinbase-ventures-portfolio,framework-ventures,hashkey-capital-portfolio,ledgerprime-portfolio'],
#  [1599, 'Mavro', 'MAVRO', 'mavro', 1, 'coin', 'http://mavro.org', 'mineable'],
#  [1605,
#   'Universe',
#   'UNI',
#   'universe',
#   1,
#   'coin',
#   'http://universe-project.com',
#   'pos,scrypt'],
#  [1606,
#   'Solaris',
#   'XLR',
#   'solaris',
#   1,
#   'coin',
#   'https://solarisplatform.com',
#   'hybrid-pow-pos,pos,sha-256d,xevan,masternodes'],
#  [1609,
#   'Asch',
#   'XAS',
#   'asch',
#   1,
#   'coin',
#   'https://asch.io',
#   'dpos,platform,scaling,dapp'],
#  [1611,
#   'DubaiCoin',
#   'DBIX',
#   'dubaicoin-dbix',
#   1,
#   'coin',
#   'http://arabianchain.org',
#   'mineable,pow,dagger-hashimoto'],
#  [1619,
#   'Skycoin',
#   'SKY',
#   'skycoin',
#   1,
#   'coin',
#   'https://skycoin.com',
#   'platform,distributed-computing'],
#  [1623,
#   'BlazerCoin',
#   'BLAZR',
#   'blazercoin',
#   1,
#   'coin',
#   'http://blazercoin.cf',
#   'mineable,pow,scrypt'],
#  [1624, 'Atmos', 'ATMOS', 'atmos', 1, 'token', 'https://novusphere.io', 'pos'],
#  [1629,
#   'Zennies',
#   'ZENI',
#   'zennies',
#   1,
#   'coin',
#   'http://zeni.zone',
#   'pos,scrypt'],
#  [1630,
#   'Coinonat',
#   'CXT',
#   'coinonat',
#   1,
#   'coin',
#   'http://coinonat.org',
#   'mineable,pow,nist5'],
#  [1632,
#   'Concoin',
#   'CONX',
#   'concoin',
#   1,
#   'coin',
#   'http://concoin.com',
#   'mineable'],
#  [1636,
#   'XTRABYTES',
#   'XBY',
#   'xtrabytes',
#   1,
#   'coin',
#   'https://xtrabytes.global',
#   'posign'],
#  [1637,
#   'iExec RLC',
#   'RLC',
#   'rlc',
#   1,
#   'token',
#   'https://iex.ec',
#   'marketplace,ai-big-data,distributed-computing,defi,privacy,oracles,scaling,substrate,polkadot,polkadot-ecosystem'],
#  [1638,
#   'WeTrust',
#   'TRST',
#   'trust',
#   1,
#   'token',
#   'https://wetrust.io',
#   'platform,smart-contracts'],
#  [1651,
#   'SpeedCash',
#   'SCS',
#   'speedcash',
#   1,
#   'coin',
#   'http://scash.ml',
#   'store-of-value,ethereum'],
#  [1654,
#   'BitCore',
#   'BTX',
#   'bitcore',
#   1,
#   'coin',
#   'http://bitcore.cc',
#   'mineable,masternodes'],
#  [1657, 'Bitvolt', 'VOLT', 'bitvolt', 1, 'coin', 'http://bitvolt.co', ''],
#  [1658,
#   'Lunyr',
#   'LUN',
#   'lunyr',
#   1,
#   'token',
#   'https://lunyr.com',
#   'media,content-creation,crowdsourcing'],
#  [1659,
#   'Gnosis',
#   'GNO',
#   'gnosis-gno',
#   1,
#   'token',
#   'https://gnosis.io',
#   'services,decentralized-exchange,defi,prediction-markets,kinetic-capital'],
#  [1660,
#   'Monolith',
#   'TKN',
#   'monolith',
#   1,
#   'token',
#   'https://monolith.xyz',
#   'services,defi'],
#  [1669,
#   'Humaniq',
#   'HMQ',
#   'humaniq',
#   1,
#   'token',
#   'https://humaniq.com',
#   'asset-management'],
#  [1673, 'Minereum', 'MNE', 'minereum', 1, 'token', 'https://minereum.com', ''],
#  [1674,
#   'Cannation',
#   'CNNC',
#   'cannation',
#   1,
#   'coin',
#   'http://cannationcoin.com',
#   'mineable'],
#  [1676, 'CREA', 'CREA', 'crea', 1, 'coin', 'https://creaproject.io', 'media'],
#  [1677,
#   'Etheroll',
#   'DICE',
#   'etheroll',
#   1,
#   'token',
#   'https://etheroll.com',
#   'gambling'],
#  [1678,
#   'InsaneCoin',
#   'INSN',
#   'insanecoin-insn',
#   1,
#   'coin',
#   'https://insane.network',
#   'mineable,masternodes'],
#  [1680,
#   'Aragon',
#   'ANT',
#   'aragon',
#   1,
#   'token',
#   'https://aragon.org',
#   'platform,cosmos-ecosystem,enterprise-solutions,dao,substrate,polkadot,governance,boostvc-portfolio,placeholder-ventures-portfolio'],
#  [1681, 'PRIZM', 'PZM', 'prizm', 1, 'coin', '', 'marketplace,iot'],
#  [1684,
#   'Qtum',
#   'QTUM',
#   'qtum',
#   1,
#   'coin',
#   'https://qtum.org',
#   'platform,smart-contracts,kinetic-capital'],
#  [1687,
#   'Digital Money Bits',
#   'DMB',
#   'digital-money-bits',
#   1,
#   'coin',
#   'https://digitalmoneybits.org',
#   'mineable'],
#  [1691, 'Project-X', 'NANOX', 'project-x', 1, 'coin', '', ''],
#  [1693,
#   'Theresa May Coin',
#   'MAY',
#   'theresa-may-coin',
#   1,
#   'coin',
#   'http://theresamaycoin.com',
#   'mineable'],
#  [1694,
#   'Sumokoin',
#   'SUMO',
#   'sumokoin',
#   1,
#   'coin',
#   'https://sumokoin.org',
#   'mineable,privacy'],
#  [1697,
#   'Basic Attention Token',
#   'BAT',
#   'basic-attention-token',
#   1,
#   'token',
#   'https://basicattentiontoken.org',
#   'marketing,content-creation,payments,dcg-portfolio,1confirmation-portfolio,pantera-capital-portfolio'],
#  [1698,
#   'Horizen',
#   'ZEN',
#   'horizen',
#   1,
#   'coin',
#   'https://horizen.global',
#   'mineable,medium-of-exchange,content-creation,privacy,masternodes,dcg-portfolio'],
#  [1700,
#   'Aeternity',
#   'AE',
#   'aeternity',
#   1,
#   'coin',
#   'https://aeternity.com',
#   'mineable,medium-of-exchange,privacy'],
#  [1703,
#   'Metaverse ETP',
#   'ETP',
#   'metaverse',
#   1,
#   'coin',
#   'https://mvs.org',
#   'mineable,asset-management,smart-contracts'],
#  [1704, 'eBoost', 'EBST', 'eboostcoin', 1, 'coin', 'http://eboost.fun', ''],
#  [1706,
#   'Aidos Kuneen',
#   'ADK',
#   'aidos-kuneen',
#   1,
#   'coin',
#   'http://aidoskuneen.com',
#   ''],
#  [1708,
#   'Patientory',
#   'PTOY',
#   'patientory',
#   1,
#   'token',
#   'https://patientory.com',
#   'health,data-provenance'],
#  [1710,
#   'Veritaseum',
#   'VERI',
#   'veritaseum',
#   1,
#   'token',
#   'http://veritaseum.com',
#   'services'],
#  [1711,
#   'Electra',
#   'ECA',
#   'electra',
#   1,
#   'coin',
#   'http://weebly.com',
#   'mineable,medium-of-exchange,atomic-swaps,payments'],
#  [1712,
#   'Quantum Resistant Ledger',
#   'QRL',
#   'quantum-resistant-ledger',
#   1,
#   'coin',
#   'https://theqrl.org',
#   'mineable,pow,platform,distributed-computing,quantum-resistant'],
#  [1715,
#   'MobileGo',
#   'MGO',
#   'mobilego',
#   1,
#   'token',
#   'https://mobilego.io',
#   'media,gaming,entertainment'],
#  [1719,
#   'Peerplays',
#   'PPY',
#   'peerplays-ppy',
#   1,
#   'coin',
#   'http://peerplays.com',
#   ''],
#  [1720,
#   'IOTA',
#   'MIOTA',
#   'iota',
#   1,
#   'coin',
#   'https://iota.org',
#   'dag,medium-of-exchange,iot,sharing-economy'],
#  [1721,
#   'Mysterium',
#   'MYST',
#   'mysterium',
#   1,
#   'token',
#   'https://mysterium.network',
#   'platform,distributed-computing'],
#  [1722,
#   'More Coin',
#   'MORE',
#   'more-coin',
#   1,
#   'token',
#   'http://mre.live',
#   'events,loyalty,entertainment'],
#  [1723,
#   'SONM',
#   'SNM',
#   'sonm',
#   1,
#   'token',
#   'https://sonm.com',
#   'platform,distributed-computing,filesharing,payments,storage'],
#  [1725, 'Adelphoi', 'ADL', 'adelphoi', 1, 'token', 'https://adel.io', ''],
#  [1726,
#   'ZrCoin',
#   'ZRC',
#   'zrcoin',
#   1,
#   'token',
#   'https://zrcoin.io',
#   'services'],
#  [1727,
#   'Bancor',
#   'BNT',
#   'bancor',
#   1,
#   'token',
#   'https://bancor.network',
#   'marketplace,decentralized-exchange,defi,payments,amm,kinetic-capital'],
#  [1731,
#   'GlobalToken',
#   'GLT',
#   'globaltoken',
#   1,
#   'coin',
#   'http://globaltoken.org',
#   'mineable'],
#  [1732,
#   'Numeraire',
#   'NMR',
#   'numeraire',
#   1,
#   'token',
#   'https://numer.ai',
#   'asset-management,ai-big-data,defi,payments,research,coinfund-portfolio,usv-portfolio,placeholder-ventures-portfolio,paradigm-xzy-screener'],
#  [1736, 'Unify', 'UNIFY', 'unify', 1, 'coin', 'https://unify.cyou', ''],
#  [1745,
#   'Dinastycoin',
#   'DCY',
#   'dinastycoin',
#   1,
#   'coin',
#   'http://dinastycoin.com',
#   'mineable'],
#  [1747, 'Onix', 'ONX', 'onix', 1, 'coin', 'http://onixcoin.com', 'mineable'],
#  [1750,
#   'GXChain',
#   'GXC',
#   'gxchain',
#   1,
#   'coin',
#   'https://gxb.io',
#   'platform,decentralized-exchange'],
#  [1751, 'ATC Coin', 'ATCC', 'atc-coin', 1, 'token', 'http://atccoin.com', ''],
#  [1754,
#   'Bitradio',
#   'BRO',
#   'bitradio',
#   1,
#   'coin',
#   'http://bitrad.io',
#   'masternodes'],
#  [1755, 'Flash', 'FLASH', 'flash', 1, 'coin', 'https://flashcoin.io', ''],
#  [1757,
#   'FUNToken',
#   'FUN',
#   'funtoken',
#   1,
#   'token',
#   'https://funtoken.io',
#   'gambling,marketplace,payments,pantera-capital-portfolio'],
#  [1758,
#   'TenX',
#   'PAY',
#   'tenx',
#   1,
#   'token',
#   'https://tenx.tech',
#   'medium-of-exchange,fenbushi-capital-portfolio,kinetic-capital'],
#  [1759,
#   'Status',
#   'SNT',
#   'status',
#   1,
#   'token',
#   'http://status.im',
#   'media,content-creation,privacy,fabric-ventures-portfolio,kinetic-capital'],
#  [1762,
#   'Ergo',
#   'ERG',
#   'ergo',
#   1,
#   'coin',
#   'https://ergoplatform.org',
#   'mineable,pow,platform,dapp'],
#  [1763, 'BriaCoin', 'BRIA', 'briacoin', 1, 'coin', 'https://briacoin.com', ''],
#  [1765,
#   'EOS',
#   'EOS',
#   'eos',
#   1,
#   'coin',
#   'https://eos.io',
#   'medium-of-exchange,enterprise-solutions,smart-contracts,binance-chain,fenbushi-capital-portfolio,galaxy-digital-portfolio'],
#  [1768,
#   'AdEx Network',
#   'ADX',
#   'adx-net',
#   1,
#   'token',
#   'https://adex.network',
#   'marketing,smart-contracts,substrate,polkadot,polkadot-ecosystem'],
#  [1769,
#   'Denarius',
#   'D',
#   'denarius-d',
#   1,
#   'coin',
#   'https://denarius.io',
#   'mineable,masternodes'],
#  [1771,
#   'DAOBet',
#   'BET',
#   'daobet',
#   1,
#   'coin',
#   'https://daobet.org',
#   'gambling'],
#  [1772,
#   'Storj',
#   'STORJ',
#   'storj',
#   1,
#   'token',
#   'https://storj.io',
#   'platform,distributed-computing,filesharing,storage'],
#  [1774,
#   'SocialCoin',
#   'SOCC',
#   'socialcoin-socc',
#   1,
#   'coin',
#   'https://socc.network',
#   'mineable'],
#  [1775,
#   'adToken',
#   'ADT',
#   'adtoken',
#   1,
#   'token',
#   'https://adtoken.com',
#   'marketing'],
#  [1776,
#   'MCO',
#   'MCO',
#   'crypto-com',
#   1,
#   'token',
#   'https://crypto.com',
#   'medium-of-exchange'],
#  [1777,
#   'CryptoPing',
#   'PING',
#   'cryptoping',
#   1,
#   'token',
#   'https://cryptoping.tech',
#   'asset-management,ai-big-data'],
#  [1779,
#   'Wagerr',
#   'WGR',
#   'wagerr',
#   1,
#   'coin',
#   'https://wagerr.com',
#   'gambling,masternodes'],
#  [1784,
#   'Polybius',
#   'PLBT',
#   'polybius',
#   1,
#   'token',
#   'https://polybius.io',
#   'asset-management'],
#  [1785,
#   'Gas',
#   'GAS',
#   'gas',
#   1,
#   'token',
#   'https://neo.org',
#   'medium-of-exchange,payments,smart-contracts'],
#  [1786,
#   'SunContract',
#   'SNC',
#   'suncontract',
#   1,
#   'token',
#   'https://suncontract.org',
#   'energy'],
#  [1787,
#   'Jetcoin',
#   'JET',
#   'jetcoin',
#   1,
#   'token',
#   'https://jetcoin.io',
#   'marketing,entertainment'],
#  [1788,
#   'Metal',
#   'MTL',
#   'metal',
#   1,
#   'token',
#   'https://metalpay.com',
#   'medium-of-exchange,payments'],
#  [1789,
#   'Populous',
#   'PPT',
#   'populous',
#   1,
#   'token',
#   'https://populous.world',
#   'logistics'],
#  [1799,
#   'Rupee',
#   'RUP',
#   'rupee',
#   1,
#   'coin',
#   'https://rupeeblockchain.org',
#   'mineable,masternodes'],
#  [1803, 'PeepCoin', 'PCN', 'peepcoin', 1, 'coin', 'http://peepcoin.io', ''],
#  [1807,
#   'Santiment Network Token',
#   'SAN',
#   'santiment',
#   1,
#   'token',
#   'https://santiment.net',
#   'asset-management,ai-big-data,crowdsourcing'],
#  [1808,
# ...
#   'health,marketplace,ai-big-data,payments'],
#  [2712, 'MyToken', 'MT', 'mytoken', 1, 'token', 'https://mytoken.io', ''],
#  [2713, 'KEY', 'KEY', 'key', 1, 'token', 'https://bihu.com', ''],
#  [2714, 'Nexty', 'NTY', 'nexty', 1, 'coin', 'https://nexty.io', 'mineable'],
#  [2717, 'BoutsPro', 'BOUTS', 'boutspro', 1, 'token', 'https://bouts.pro', ''],
#  [2719,
#   'Cybereits',
#   'CRE',
#   'cybereits',
#   1,
#   'token',
#   'https://cybereits.com',
#   ''],
#  [2720,
#   'Parkgene',
#   'GENE',
#   'parkgene',
#   1,
#   'token',
#   'https://parkgene.io',
#   'iot'],
#  [2721,
#   'APR Coin',
#   'APR',
#   'apr-coin',
#   1,
#   'coin',
#   'https://apr-coin.com',
#   'mineable,masternodes'],
#  [2722, 'AC3', 'AC3', 'ac3', 1, 'token', 'https://ac3.io', ''],
#  [2723, 'FuzeX', 'FXT', 'fuzex', 1, 'token', 'https://fuzex.co', ''],
#  [2724, 'Zippie', 'ZIPT', 'zippie', 1, 'token', 'https://zippie.org', ''],
#  [2725,
#   'Skrumble Network',
#   'SKM',
#   'skrumble-network',
#   1,
#   'token',
#   'https://skrumble.network',
#   ''],
#  [2726,
#   'DAOstack',
#   'GEN',
#   'daostack',
#   1,
#   'token',
#   'https://daostack.io',
#   'platform,dao'],
#  [2727, 'Bezant', 'BZNT', 'bezant', 1, 'token', 'https://bezant.io', ''],
#  [2729,
#   'TEAM (TokenStars)',
#   'TEAM',
#   'tokenstars',
#   1,
#   'token',
#   'https://tokenstars.com',
#   'sports'],
#  [2731, 'Utrum', 'OOT', 'utrum', 1, 'coin', 'https://utrum.io', ''],
#  [2733,
#   'Freyrchain',
#   'FREC',
#   'freyrchain',
#   1,
#   'token',
#   'http://freyrchain.org',
#   ''],
#  [2734, 'EduCoin', 'EDU', 'edu-coin', 1, 'token', 'http://edu.one', ''],
#  [2735,
#   'Content Neutrality Network',
#   'CNN',
#   'content-neutrality-network',
#   1,
#   'token',
#   'https://cnntoken.io',
#   ''],
#  [2737,
#   'Global Social Chain',
#   'GSC',
#   'global-social-chain',
#   1,
#   'token',
#   'https://gsc.social',
#   ''],
#  [2739,
#   'Digix Gold Token',
#   'DGX',
#   'digix-gold-token',
#   1,
#   'token',
#   'https://digix.global',
#   'store-of-value,stablecoin,stablecoin-asset-backed,dao,substrate,polkadot'],
#  [2741,
#   'Intelligent Investment Chain',
#   'IIC',
#   'intelligent-investment-chain',
#   1,
#   'token',
#   'http://iichain.io',
#   ''],
#  [2742,
#   'Sakura Bloom',
#   'SKB',
#   'sakura-bloom',
#   1,
#   'token',
#   'https://skb-coin.jp',
#   ''],
#  [2745,
#   'Joint Ventures',
#   'JOINT',
#   'joint-ventures',
#   1,
#   'token',
#   'https://jointventures.io',
#   'iot'],
#  [2746,
#   'GreenPower',
#   'GRN',
#   'greenpower',
#   1,
#   'coin',
#   'https://grnpower.io',
#   ''],
#  [2747,
#   'BlockMesh',
#   'BMH',
#   'blockmesh',
#   1,
#   'token',
#   'https://blockmesh.io',
#   ''],
#  [2748,
#   'Oxen',
#   'OXEN',
#   'oxen',
#   1,
#   'coin',
#   'https://oxen.io',
#   'pos,defi,privacy,masternodes'],
#  [2752,
#   'Datarius Credit',
#   'DTRC',
#   'datarius-credit',
#   1,
#   'token',
#   'https://datarius.io',
#   ''],
#  [2754, 'HeroNode', 'HER', 'heronode', 1, 'token', 'https://heronode.io', ''],
#  [2755, 'Raise', 'RAISE', 'raise', 1, 'token', 'https://raise.it', ''],
#  [2757,
#   'Callisto Network',
#   'CLO',
#   'callisto-network',
#   1,
#   'coin',
#   'https://callisto.network',
#   'mineable,services'],
#  [2758,
#   'Unibright',
#   'UBT',
#   'unibright',
#   1,
#   'token',
#   'https://unibright.io',
#   ''],
#  [2759,
#   'Patron',
#   'PAT',
#   'patron',
#   1,
#   'token',
#   'https://patron-influencers.com',
#   ''],
#  [2760,
#   'Cred',
#   'LBA',
#   'libra-credit',
#   1,
#   'token',
#   'https://mycred.io',
#   'payments,binance-labs-portfolio'],
#  [2762,
#   'Open Platform',
#   'OPEN',
#   'open-platform',
#   1,
#   'token',
#   'https://openfuture.io',
#   ''],
#  [2763,
#   'Morpheus.Network',
#   'MRPH',
#   'morpheus-network',
#   1,
#   'token',
#   'https://morpheus.network',
#   'logistics,payments'],
#  [2765, 'XYO', 'XYO', 'xyo', 1, 'token', 'https://xyo.network', ''],
#  [2766, 'Cryptaur', 'CPT', 'cryptaur', 1, 'token', 'https://cryptaur.com', ''],
#  [2771,
#   'RED',
#   'RED',
#   'red',
#   1,
#   'token',
#   'https://red-lang.org',
#   'marketplace'],
#  [2772,
#   'Digitex',
#   'DGTX',
#   'digitex',
#   1,
#   'token',
#   'https://digitexfutures.com',
#   'asset-management,centralized-exchange,derivatives'],
#  [2773,
#   'GINcoin',
#   'GIN',
#   'gincoin',
#   1,
#   'coin',
#   'https://gincoin.io',
#   'mineable,masternodes'],
#  [2775, 'Faceter', 'FACE', 'faceter', 1, 'token', 'https://faceter.io', ''],
#  [2776,
#   'Travala.com',
#   'AVA',
#   'travala',
#   1,
#   'token',
#   'https://travala.com',
#   'hospitality,marketplace,medium-of-exchange,payments,tourism'],
#  [2777,
#   'IoTeX',
#   'IOTX',
#   'iotex',
#   1,
#   'coin',
#   'https://iotex.io',
#   'platform,iot,hashkey-capital-portfolio,kinetic-capital'],
#  [2780,
#   'NKN',
#   'NKN',
#   'nkn',
#   1,
#   'coin',
#   'https://nkn.org',
#   'mineable,platform,enterprise-solutions,distributed-computing,iot'],
#  [2827,
#   'Phantasma',
#   'SOUL',
#   'phantasma',
#   1,
#   'token',
#   'https://phantasma.io',
#   'platform,enterprise-solutions,distributed-computing,collectibles-nfts,content-creation,filesharing'],
#  [2828, 'SPINDLE', 'SPD', 'spindle', 1, 'token', 'https://spindle.zone', ''],
#  [2829, 'REPO', 'REPO', 'repo', 1, 'token', 'https://repocoin.io', ''],
#  [2830,
#   'Seele-N',
#   'SEELE',
#   'seele',
#   1,
#   'token',
#   'https://seelen.pro',
#   'platform,ai-big-data'],
#  [2835,
#   'Endor Protocol',
#   'EDR',
#   'endor-protocol',
#   1,
#   'token',
#   'https://endor.com',
#   ''],
#  [2836, 'Bigbom', 'BBO', 'bigbom', 1, 'token', 'https://bigbom.com', ''],
#  [2837,
#   '0xBitcoin',
#   '0xBTC',
#   '0xbtc',
#   1,
#   'token',
#   'https://0xbitcoin.org',
#   'mineable'],
#  [2838,
#   'Plian',
#   'PI',
#   'pchain',
#   1,
#   'coin',
#   'https://plian.org',
#   'platform,interoperability,smart-contracts'],
#  [2840,
#   'QuarkChain',
#   'QKC',
#   'quarkchain',
#   1,
#   'token',
#   'https://quarkchain.io',
#   'marketplace,payments'],
#  [2842,
#   'Bankera',
#   'BNK',
#   'bankera',
#   1,
#   'token',
#   'https://bankera.com',
#   'marketplace,centralized-exchange,payments,smart-contracts'],
#  [2843,
#   'Ether Zero',
#   'ETZ',
#   'ether-zero',
#   1,
#   'coin',
#   'https://etherzero.org',
#   'mineable'],
#  [2846,
#   'FuturoCoin',
#   'FTO',
#   'futurocoin',
#   1,
#   'coin',
#   'https://futurocoin.com',
#   'mineable'],
#  [2847,
#   'Abyss',
#   'ABYSS',
#   'abyss',
#   1,
#   'token',
#   'https://abyss.finance',
#   'marketplace,collectibles-nfts'],
#  [2850, 'TRAXIA', 'TM2', 'traxia', 1, 'token', 'http://traxia.co', ''],
#  [2852, 'Engine', 'EGCC', 'engine', 1, 'token', 'https://egcchain.com', ''],
#  [2855,
#   'Casino Betting Coin',
#   'CBC',
#   'casino-betting-coin',
#   1,
#   'token',
#   'http://casinobettingcoin.com',
#   ''],
#  [2856, 'CEEK VR', 'CEEK', 'ceek-vr', 1, 'token', 'https://ceek.io', ''],
#  [2859,
#   'XMax',
#   'XMX',
#   'xmax',
#   1,
#   'token',
#   'https://xmx.com',
#   'media,content-creation,gaming'],
#  [2861, 'GoChain', 'GO', 'gochain', 1, 'coin', 'https://gochain.io', ''],
#  [2862,
#   'Smartshare',
#   'SSP',
#   'smartshare',
#   1,
#   'token',
#   'https://smartshare.vip',
#   ''],
#  [2865,
#   'Trittium',
#   'TRTT',
#   'trittium',
#   1,
#   'coin',
#   'https://trittium.cc',
#   'masternodes'],
#  [2866,
#   'Sentinel Protocol',
#   'UPP',
#   'sentinel-protocol',
#   1,
#   'token',
#   'https://sentinelprotocol.io',
#   ''],
#  [2867, 'Bittwatt', 'BWT', 'bittwatt', 1, 'token', 'https://bittwatt.com', ''],
#  [2868,
#   'Constellation',
#   'DAG',
#   'constellation',
#   1,
#   'coin',
#   'https://constellationlabs.io',
#   'dag,platform,payments,smart-contracts'],
#  [2869, 'Merculet', 'MVP', 'merculet', 1, 'token', 'https://merculet.io', ''],
#  [2870,
#   'FantasyGold',
#   'FGC',
#   'fantasygold',
#   1,
#   'coin',
#   'https://fantasygold.io',
#   'sports,staking'],
#  [2871,
#   'Ubique Chain Of Things',
#   'UCT',
#   'ubique-chain-of-things',
#   1,
#   'token',
#   'http://uct.foundation',
#   ''],
#  [2873,
#   'Metronome',
#   'MET',
#   'metronome',
#   1,
#   'token',
#   'https://metronome.io',
#   'platform,defi,payments,wallet'],
#  [2874,
#   'Aurora',
#   'AOA',
#   'aurora',
#   1,
#   'token',
#   'https://aurorachain.io',
#   'platform,smart-contracts'],
#  [2876, 'Ternio', 'TERN', 'ternio', 1, 'token', 'https://ternio.io', ''],
#  [2878,
#   'DigiFinexToken',
#   'DFT',
#   'digifinextoken',
#   1,
#   'token',
#   'https://digifinex.com',
#   'centralized-exchange'],
#  [2879,
#   'Origin Sport',
#   'ORS',
#   'origin-sport',
#   1,
#   'token',
#   'https://originsport.io',
#   ''],
#  [2880, 'Rate3', 'RTE', 'rate3', 1, 'token', 'https://rate3.network', ''],
#  [2882,
#   '0Chain',
#   'ZCN',
#   '0chain',
#   1,
#   'token',
#   'https://0chain.net',
#   'platform,ai-big-data,distributed-computing,filesharing,iot,storage'],
#  [2883, 'ZINC', 'ZINC', 'zinc', 1, 'token', 'https://zinc.work', ''],
#  [2884,
#   'FSBT API Token',
#   'FSBT',
#   'fsbt-api-token',
#   1,
#   'token',
#   'https://fsbt.tech',
#   ''],
#  [2885, 'Egretia', 'EGT', 'egretia', 1, 'token', 'http://egretia.io', ''],
#  [2889,
#   "Bob's Repair",
#   'BOB',
#   'bobs-repair',
#   1,
#   'token',
#   'https://bobsrepair.com',
#   ''],
#  [2890,
#   'KanadeCoin',
#   'KNDC',
#   'kanadecoin',
#   1,
#   'token',
#   'https://kanadecoin.com',
#   ''],
#  [2891,
#   'Cardstack',
#   'CARD',
#   'cardstack',
#   1,
#   'token',
#   'https://cardstack.com',
#   ''],
#  [2893, 'On.Live', 'ONL', 'on-live', 1, 'token', 'https://on.live', ''],
#  [2894,
#   'OTCBTC Token',
#   'OTB',
#   'otcbtc-token',
#   1,
#   'token',
#   'https://otcbtc.com',
#   ''],
#  [2895, 'Coni', 'CONI', 'coni', 1, 'token', 'https://coinbene.com', ''],
#  [2896,
#   'Hifi Finance',
#   'MFT',
#   'mainframe',
#   1,
#   'token',
#   'https://hifi.finance',
#   'platform,content-creation,smart-contracts,arrington-xrp-capital,kinetic-capital'],
#  [2898,
#   'GoNetwork',
#   'GOT',
#   'gonetwork',
#   1,
#   'token',
#   'https://gonetwork.co',
#   'marketplace'],
#  [2899,
#   'Thrive Token',
#   'THRT',
#   'thrive-token',
#   1,
#   'token',
#   'https://thrivelabs.io',
#   ''],
#  [2900,
#   'Project Pai',
#   'PAI',
#   'project-pai',
#   1,
#   'coin',
#   'https://projectpai.com',
#   'services,ai-big-data,identity'],
#  [2901, 'FansTime', 'FTI', 'fanstime', 1, 'token', 'https://fanstime.org', ''],
#  [2902, 'POPCHAIN', 'PCH', 'popchain', 1, 'token', 'https://popchain.co', ''],
#  [2906,
#   'Essentia',
#   'ESS',
#   'essentia',
#   1,
#   'token',
#   'https://essentia.one',
#   'masternodes'],
#  [2907,
#   'Karatgold Coin',
#   'KBC',
#   'karatgold-coin',
#   1,
#   'token',
#   'https://karatgold.io',
#   'store-of-value,stablecoin,stablecoin-asset-backed'],
#  [2908,
#   'HashCoin',
#   'HSC',
#   'hashcoin',
#   1,
#   'token',
#   'https://hashfuture.io',
#   ''],
#  [2909,
#   'LikeCoin',
#   'LIKE',
#   'likecoin',
#   1,
#   'token',
#   'https://like.co',
#   'cosmos-ecosystem'],
#  [2911,
#   'ORS Group',
#   'ORS',
#   'ors-group',
#   1,
#   'token',
#   'https://orsgroup.io',
#   ''],
#  [2912,
#   'TENT',
#   'TENT',
#   'tent',
#   1,
#   'coin',
#   'https://tent.app',
#   'mineable,pow,masternodes,mobile,payments,staking'],
#  [2913,
#   'Databroker',
#   'DTX',
#   'databroker',
#   1,
#   'token',
#   'http://databrokerdao.com',
#   ''],
#  [2914, 'BeeKan', 'BKBT', 'beekan', 1, 'token', 'https://beekan.org', ''],
#  [2915, 'Moss Coin', 'MOC', 'moss-coin', 1, 'token', 'https://moss.land', ''],
#  [2916, 'Nimiq', 'NIM', 'nimiq', 1, 'coin', 'https://nimiq.com', 'mineable'],
#  [2918,
#   'BitZ Token',
#   'BZ',
#   'bit-z-token',
#   1,
#   'token',
#   'https://bitz.top',
#   'marketplace,discount-token,payments'],
#  [2919, 'DWS', 'DWS', 'dws', 1, 'token', 'https://dwswifi.com', ''],
#  [2920,
#   '0xcert',
#   'ZXC',
#   '0xcert',
#   1,
#   'token',
#   'https://0xcert.org',
#   'collectibles-nfts'],
#  [2921,
#   'OneLedger',
#   'OLT',
#   'oneledger',
#   1,
#   'token',
#   'https://oneledger.io',
#   ''],
#  [2923, 'XMCT', 'XMCT', 'xmct', 1, 'token', 'http://xmedchain.com', ''],
#  [2927,
#   'sUSD',
#   'SUSD',
#   'susd',
#   1,
#   'token',
#   'https://synthetix.io',
#   'store-of-value,defi,stablecoin,stablecoin-algorithmically-stabilized,synthetics'],
#  [2929, 'Truegame', 'TGAME', 'tgame', 1, 'token', 'https://truegame.io', ''],
#  [2930,
#   'Everipedia',
#   'IQ',
#   'everipedia',
#   1,
#   'token',
#   'https://everipedia.org',
#   'media,loyalty,content-creation'],
#  [2933,
#   'BitMart Token',
#   'BMX',
#   'bitmart-token',
#   1,
#   'token',
#   'https://bitmart.com',
#   'marketplace'],
#  [2934,
#   'BitKan',
#   'KAN',
#   'bitkan',
#   1,
#   'token',
#   'https://bitkan.com',
#   'services,content-creation'],
#  [2937,
#   'VITE',
#   'VITE',
#   'vite',
#   1,
#   'coin',
#   'https://vite.org',
#   'platform,enterprise-solutions,decentralized-exchange,scaling'],
#  [2938,
#   'Hashgard',
#   'GARD',
#   'hashgard',
#   1,
#   'token',
#   'https://hashgard.com',
#   'cosmos-ecosystem'],
#  [2941,
#   'CoinEx Token',
#   'CET',
#   'coinex-token',
#   1,
#   'coin',
#   'https://coinex.org',
#   'cosmos-ecosystem,decentralized-exchange'],
#  [2943,
#   'Rocket Pool',
#   'RPL',
#   'rocket-pool',
#   1,
#   'token',
#   'https://rocketpool.net',
#   ''],
#  [2944, 'Elysian', 'ELY', 'elysian', 1, 'token', 'https://elycoin.io', ''],
#  [2945,
#   'ContentBox',
#   'BOX',
#   'contentbox',
#   1,
#   'token',
#   'https://contentbox.one',
#   ''],
#  [2947, 'SoPay', 'SOP', 'sopay', 1, 'token', 'https://sopay.org', ''],
#  [2949, 'Kryll', 'KRL', 'kryll', 1, 'token', 'https://kryll.io', ''],
#  [2950,
#   'LemoChain',
#   'LEMO',
#   'lemochain',
#   1,
#   'token',
#   'https://lemochain.com',
#   ''],
#  [2953,
#   'Blue Whale EXchange',
#   'BWX',
#   'blue-whale-exchange',
#   1,
#   'token',
#   'https://bluewhale.foundation',
#   'marketplace,sharing-economy,smart-contracts'],
#  [2955,
#   'Cosmo Coin',
#   'COSM',
#   'cosmo-coin',
#   1,
#   'token',
#   'https://cosmochain.io',
#   ''],
#  [2956,
#   'Narrative',
#   'NRVE',
#   'narrative',
#   1,
#   'token',
#   'https://narrative.org',
#   ''],
#  [2958,
#   'TurtleCoin',
#   'TRTL',
#   'turtlecoin',
#   1,
#   'coin',
#   'https://turtlecoin.lol',
#   'mineable,privacy'],
#  [2960,
#   'Tourist Token',
#   'TOTO',
#   'tourist-token',
#   1,
#   'token',
#   'https://globaltourist.io',
#   ''],
#  [2965,
#   'VikkyToken',
#   'VIKKY',
#   'vikkytoken',
#   1,
#   'token',
#   'https://vikky.io',
#   ''],
#  [2966,
#   'Fox Trading',
#   'FOXT',
#   'fox-trading',
#   1,
#   'token',
#   'https://foxtrading.io',
#   ''],
#  [2968,
#   'Bridge Protocol',
#   'BRDG',
#   'bridge-protocol',
#   1,
#   'token',
#   'https://bridgeprotocol.io',
#   ''],
#  [2969,
#   'Globalvillage Ecosystem',
#   'GVE',
#   'globalvillage-ecosystem',
#   1,
#   'token',
#   'http://gve.io',
#   ''],
#  [2970,
#   'LocalCoinSwap',
#   'LCS',
#   'local-coin-swap',
#   1,
#   'token',
#   'https://localcoinswap.com',
#   'polkadot-ecosystem'],
#  [2972, 'ZPER', 'ZPR', 'zper', 1, 'token', 'https://zper.io', 'payments'],
#  [2976,
#   'Ryo Currency',
#   'RYO',
#   'ryo-currency',
#   1,
#   'coin',
#   'https://ryo-currency.com',
#   'mineable'],
#  [2977,
#   'BitRewards',
#   'BIT',
#   'bitrewards',
#   1,
#   'token',
#   'https://bitrewards.network',
#   ''],
#  [2978,
#   'AceD',
#   'ACED',
#   'aced',
#   1,
#   'token',
#   'https://acedcoin.com',
#   'defi,entertainment'],
#  [2980,
#   'WABnetwork',
#   'WAB',
#   'wabnetwork',
#   1,
#   'token',
#   'https://wab.network',
#   ''],
#  [2981,
#   'Consentium',
#   'CSM',
#   'consentium',
#   1,
#   'token',
#   'https://consentium.net',
#   ''],
#  [2982, 'MVL', 'MVL', 'mvl', 1, 'token', 'http://mvlchain.io', ''],
#  [2984,
#   'Newton Coin Project',
#   'NCP',
#   'newton-coin-project',
#   1,
#   'token',
#   'https://newtoncoin.site',
#   'mineable'],
#  [2986, 'DACC', 'DACC', 'dacc', 1, 'token', 'http://dacc.co', ''],
#  [2987,
#   'ThingsOperatingSystem',
#   'TOS',
#   'thingsoperatingsystem',
#   1,
#   'token',
#   '',
#   ''],
#  [2988,
#   'Pigeoncoin',
#   'PGN',
#   'pigeoncoin',
#   1,
#   'coin',
#   'https://pigeoncoin.org',
#   'mineable'],
#  [2989,
#   'STASIS EURO',
#   'EURS',
#   'stasis-euro',
#   1,
#   'token',
#   'https://stasis.net',
#   'marketplace,stablecoin,stablecoin-asset-backed,wallet'],
#  [2990,
#   'EXMR FDN',
#   'EXMR',
#   'exmr-fdn',
#   1,
#   'token',
#   'https://exmr.foundation',
#   'marketplace,platform,payments,staking,dapp'],
#  [2991,
#   'NIX',
#   'NIX',
#   'nix',
#   1,
#   'coin',
#   'https://nixplatform.io',
#   'mineable,privacy,masternodes'],
#  [2992,
#   'Apollo Currency',
#   'APL',
#   'apollo-currency',
#   1,
#   'coin',
#   'https://aplfintech.com',
#   'medium-of-exchange,privacy,payments'],
#  [2993,
#   'HorusPay',
#   'HORUS',
#   'horuspay',
#   1,
#   'token',
#   'https://horuspay.io',
#   ''],
#  [2994,
#   'Bitcoin File',
#   'BIFI',
#   'bitcoin-file',
#   1,
#   'coin',
#   'https://bitcoinfile.org',
#   ''],
#  [2998, 'Vexanium', 'VEX', 'vexanium', 1, 'coin', 'https://vexanium.com', ''],
#  [2999,
#   'Hdac',
#   'HDAC',
#   'hdac',
#   1,
#   'coin',
#   'https://hdactech.com',
#   'mineable,iot'],
#  [3001, 'KWHCoin', 'KWH', 'kwhcoin', 1, 'token', 'https://kwhcoin.com', ''],
#  [3002,
#   'Master Contract Token',
#   'MCT',
#   'master-contract-token',
#   1,
#   'token',
#   'https://splyse.tech',
#   ''],
#  ...]

# %%
coins_info_df = pd.DataFrame(cmc_cryptocurrency_data, columns=['id', 'name', 'symbol', 'slug', 'is_active', 'category', 'url', 'tags'])

# %%
coins_info_df['current_name'] = coins_info_df['name']

# %%
coins_info_df
# Out:
#         id                 name    symbol                 slug  is_active  \
# 0        1              Bitcoin       BTC              bitcoin          1
# 1        2             Litecoin       LTC             litecoin          1
# 2        3             Namecoin       NMC             namecoin          1
# 3        4            Terracoin       TRC            terracoin          1
# 4        5             Peercoin       PPC             peercoin          1
# ...    ...                  ...       ...                  ...        ...
# 4613  9137       UNITi Protocol      UNIT       uniti-protocol          1
# 4614  9138  PhoenixDefi.Finance      PNIX  phoenixdefi-finance          1
# 4615  9140             Moonshot  MOONSHOT             moonshot          1
# 4616  9144          RAI Finance       RAI          rai-finance          1
# 4617  9148           Drep [new]      DREP             drep-new          1
#
#      category                          url  \
# 0        coin          https://bitcoin.org
# 1        coin         https://litecoin.org
# 2        coin         https://namecoin.org
# 3        coin          http://terracoin.io
# 4        coin          http://peercoin.net
# ...       ...                          ...
# 4613    token    https://unitiprotocol.com
# 4614    token  https://phoenixdefi.finance
# 4615    token  https://project-moonshot.me
# 4616    token
# 4617    token             https://drep.org
#
#                                                    tags         current_name
# 0     mineable,pow,sha-256,store-of-value,state-chan...              Bitcoin
# 1     mineable,pow,scrypt,medium-of-exchange,binance...             Litecoin
# 2                         mineable,pow,sha-256,platform             Namecoin
# 3                      mineable,pow,sha-256,masternodes            Terracoin
# 4     mineable,hybrid-pow-pos,sha-256,medium-of-exch...             Peercoin
# ...                                                 ...                  ...
# 4613                                                          UNITi Protocol
# 4614                                                     PhoenixDefi.Finance
# 4615                                                                Moonshot
# 4616                                 polkadot-ecosystem          RAI Finance
# 4617                                                              Drep [new]
#
# [4618 rows x 9 columns]

# %%
def __connect__():
    db_user = 'coin'
    db_password = 'dragonstone#123'
    db_name = 'master_data'
    db_host = 'localhost'
    return pymysql.connect(
        unix_socket=None,
        host=db_host,
        user=db_user,
        password=db_password,
        db=db_name,
        charset='latin1',
        cursorclass=pymysql.cursors.DictCursor)


def get_cursor(connection):
    if connection is None:
        connection = __connect__()
    connection.ping(reconnect=True)
    return connection.cursor()

def insert_symbols_meta_info(df):
    connection = __connect__()
    cursor = get_cursor(connection)
    for i, row in df.iterrows():
        try:
            print(row["id"], row["name"], row["current_name"], row["symbol"], row["slug"], row["is_active"], row["category"], row["url"], row["tags"])
            sql = "INSERT INTO `cmc_coin_metainfo` (`cmc_id`, `name`, `current_name`, `symbol`, `slug`, `is_active`, `category`, `url`, `tags`) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"
            cursor.execute(sql, (row["id"], row["name"], row["current_name"], row["symbol"], row["slug"], row["is_active"], row["category"], row["url"], row["tags"]))
        except Exception:
            print(traceback2.format_exc())
    connection.commit()
    cursor.close()
    connection.close()

# %%
insert_symbols_meta_info(coins_info_df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-17-06af231409e3> in <module>
# ----> 1 insert_symbols_meta_info(coins_info_df)
#
# <ipython-input-16-1d8a1c721ed6> in insert_symbols_meta_info(df)
#      21
#      22 def insert_symbols_meta_info(df):
# ---> 23     connection = __connect__()
#      24     cursor = get_cursor(connection)
#      25     for i, row in df.iterrows():
#
# <ipython-input-16-1d8a1c721ed6> in __connect__()
#       4     db_name = 'master_data'
#       5     db_host = 'localhost'
# ----> 6     return pymysql.connect(
#       7         unix_socket=None,
#       8         host=db_host,
#
# ~/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# ~/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py in connect(self, sock)
#     630             self._next_seq_id = 0
#     631
# --> 632             self._get_server_information()
#     633             self._request_authentication()
#     634
#
# ~/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py in _get_server_information(self)
#    1053     def _get_server_information(self):
#    1054         i = 0
# -> 1055         packet = self._read_packet()
#    1056         data = packet.get_all_data()
#    1057
#
# ~/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     690         buff = bytearray()
#     691         while True:
# --> 692             packet_header = self._read_bytes(4)
#     693             # if DEBUG: dump_packet(packet_header)
#     694
#
# ~/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#     746         if len(data) < num_bytes:
#     747             self._force_close()
# --> 748             raise err.OperationalError(
#     749                 CR.CR_SERVER_LOST, "Lost connection to MySQL server during query"
#     750             )
#
# OperationalError: (2013, 'Lost connection to MySQL server during query')

# %%
coins_info_df[coins_info_df['symbol']== 'JUL']
# Out:
#         id           name symbol           slug  is_active category  \
# 2964  6937  JustLiquidity    JUL  justliquidity          1    token
#
#                             url                          tags   current_name
# 2964  https://justliquidity.org  ethereum,binance-smart-chain  JustLiquidity

# %%
coins_info_df.to_csv('cmc_cryptocurrency_meta_info.csv')

# %%
df = coins_info_df.groupby([ 'symbol']).count()

# %%
df = df[df['id'] > 1]

# %%
symbols = list(df.index.values)
symbols
# Out:
# ['AAPL',
#  'ACE',
#  'ACM',
#  'ACOIN',
#  'ACU',
#  'AIN',
#  'ALG',
#  'AMZN',
#  'ANC',
#  'ANK',
#  'APE',
#  'APL',
#  'AST',
#  'AT',
#  'ATP',
#  'AUR',
#  'AUTO',
#  'BABA',
#  'BANANA',
#  'BANK',
#  'BBC',
#  'BBP',
#  'BCA',
#  'BCP',
#  'BCZ',
#  'BDP',
#  'BDT',
#  'BEAR',
#  'BEE',
#  'BERRY',
#  'BET',
#  'BFC',
#  'BFI',
#  'BID',
#  'BIFI',
#  'BILI',
#  'BIRD',
#  'BIT',
#  'BITS',
#  'BLINK',
#  'BLOC',
#  'BNTX',
#  'BOND',
#  'BOS',
#  'BOX',
#  'BPT',
#  'BSC',
#  'BSD',
#  'BST',
#  'BTA',
#  'BTCT',
#  'BTCV',
#  'BTR',
#  'BTS',
#  'BTU',
#  'BULL',
#  'BUNNY',
#  'BUX',
#  'BXC',
#  'BYND',
#  'CAN',
#  'CAP',
#  'CBC',
#  'CEN',
#  'CGT',
#  'CHESS',
#  'CHI',
#  'CMCT',
#  'CMT',
#  'CNT',
#  'COFI',
#  'COMB',
#  'COMP',
#  'CON',
#  'CORN',
#  'CPAY',
#  'CPC',
#  'CPU',
#  'CRE',
#  'CREDIT',
#  'CRP',
#  'CTC',
#  'CTT',
#  'CUB',
#  'CURE',
#  'CVR',
#  'CVT',
#  'DAPP',
#  'DEC',
#  'DFS',
#  'DFT',
#  'DFX',
#  'DG',
#  'DGN',
#  'DICE',
#  'DIP',
#  'DMD',
#  'DNA',
#  'DON',
#  'DOS',
#  'DRAGON',
#  'DRC',
#  'DRM',
#  'DSD',
#  'DT',
#  'DUCK',
#  'DUO',
#  'DVS',
#  'EC',
#  'ECU',
#  'EDC',
#  'EDG',
#  'EGG',
#  'EM',
#  'EMC',
#  'EPS',
#  'ETHV',
#  'EVC',
#  'EXP',
#  'FAIR',
#  'FAT',
#  'FB',
#  'FCH',
#  'FCT',
#  'FEX',
#  'FIRE',
#  'FIT',
#  'FLASH',
#  'FLO',
#  'FLUX',
#  'FNB',
#  'FNK',
#  'FST',
#  'FUEL',
#  'FXT',
#  'GBX',
#  'GC',
#  'GCC',
#  'GCR',
#  'GENE',
#  'GEO',
#  'GET',
#  'GHOST',
#  'GMB',
#  'GOLD',
#  'GOOGL',
#  'GOT',
#  'GRT',
#  'GST',
#  'GXT',
#  'HBC',
#  'HBT',
#  'HELP',
#  'HOT',
#  'HP',
#  'HUB',
#  'IBTC',
#  'ICH',
#  'IETH',
#  'IFT',
#  'IMT',
#  'IOV',
#  'IQ',
#  'KARMA',
#  'KEY',
#  'KIND',
#  'KNT',
#  'KUN',
#  'LBK',
#  'LINA',
#  'LIT',
#  'LNC',
#  'LOCK',
#  'LOL',
#  'LST',
#  'LTK',
#  'LUNA',
#  'MARS',
#  'MASK',
#  'MAX',
#  'MBC',
#  'MBN',
#  'MCC',
#  'MCH',
#  'MCT',
#  'MDS',
#  'MDX',
#  'MEME',
#  'MINT',
#  'MIR',
#  'MIS',
#  'MM',
#  'MNC',
#  'MONA',
#  'MPH',
#  'MPT',
#  'MTC',
#  'MVC',
#  'MXT',
#  'MYFI',
#  'NCT',
#  'NFLX',
#  'NODE',
#  'NTK',
#  'NYAN',
#  'OCT',
#  'ODE',
#  'OKS',
#  'ONE',
#  'ONG',
#  'ONX',
#  'OPEN',
#  'OPT',
#  'ORC',
#  'ORE',
#  'ORS',
#  'OWL',
#  'PAR',
#  'PFE',
#  'PFI',
#  'PHO',
#  'PHT',
#  'PIS',
#  'PIZZA',
#  'PLA',
#  'PLAY',
#  'PNT',
#  'POP',
#  'PPC',
#  'PUSD',
#  'PUT',
#  'PXC',
#  'QUSD',
#  'RAI',
#  'REL',
#  'REV',
#  'RFR',
#  'RISE',
#  'ROCKS',
#  'RUNE',
#  'SAFE',
#  'SALT',
#  'SAPP',
#  'SBTC',
#  'SCC',
#  'SDT',
#  'SGT',
#  'SOC',
#  'SONO',
#  'SOUL',
#  'SPD',
#  'SPICE',
#  'SPORE',
#  'SPY',
#  'SSS',
#  'STA',
#  'STAR',
#  'START',
#  'STETH',
#  'STK',
#  'STN',
#  'STR',
#  'STV',
#  'STX',
#  'SUPER',
#  'TACO',
#  'TCH',
#  'TEN',
#  'TERN',
#  'TFT',
#  'TNC',
#  'TON',
#  'TOP',
#  'TRY',
#  'TSLA',
#  'TTN',
#  'UBU',
#  'UFO',
#  'ULT',
#  'UNI',
#  'UNIT',
#  'UP',
#  'USDF',
#  'USDX',
#  'VAL',
#  'VLT',
#  'VSN',
#  'WAR',
#  'WDC',
#  'WEC',
#  'WING',
#  'WOW',
#  'WRC',
#  'XDNA',
#  'XFI',
#  'XIN',
#  'XLA',
#  'XOR',
#  'XPT',
#  'XRA',
#  'XST',
#  'XT',
#  'YAM',
#  'YFIII',
#  'YFT',
#  'YLD',
#  'ZOM',
#  'ZUM',
#  'ZUSD']

# %%
coins_info_df[(coins_info_df['symbol'].isin(symbols))]
# Out:
#         id            name symbol            slug  is_active category  \
# 4        5        Peercoin    PPC        peercoin          1     coin
# 8       16       WorldCoin    WDC       worldcoin          1     coin
# 11      35     Phoenixcoin    PXC     phoenixcoin          1     coin
# 15      43        Anoncoin    ANC        anoncoin          1     coin
# 22      64             FLO    FLO             flo          1     coin
# ...    ...             ...    ...             ...        ...      ...
# 4581  9086      Minter HUB    HUB      minter-hub          1    token
# 4586  9091          CPCoin    CPC          cpcoin          1     coin
# 4590  9097     Try.Finance    TRY     try-finance          1    token
# 4613  9137  UNITi Protocol   UNIT  uniti-protocol          1    token
# 4616  9144     RAI Finance    RAI     rai-finance          1    token
#
#                             url  \
# 4           http://peercoin.net
# 8       http://worldcoin.global
# 11       http://phoenixcoin.org
# 15         https://anoncoin.net
# 22              http://flo.cash
# ...                         ...
# 4581      http://minter.network
# 4586          https://cpcoin.io
# 4590        https://try.finance
# 4613  https://unitiprotocol.com
# 4616
#
#                                                    tags    current_name
# 4     mineable,hybrid-pow-pos,sha-256,medium-of-exch...        Peercoin
# 8                                   mineable,pow,scrypt       WorldCoin
# 11                                   mineable,neoscrypt     Phoenixcoin
# 15                                 mineable,pow,privacy        Anoncoin
# 22                                  mineable,pow,scrypt             FLO
# ...                                                 ...             ...
# 4581                                                         Minter HUB
# 4586                                                             CPCoin
# 4590                                                        Try.Finance
# 4613                                                     UNITi Protocol
# 4616                                 polkadot-ecosystem     RAI Finance
#
# [665 rows x 9 columns]

# %%
coins_info_df[(coins_info_df['symbol'] == 'PPC')]
# Out:
#         id               name symbol              slug  is_active category  \
# 4        5           Peercoin    PPC          peercoin          1     coin
# 2652  6253  PHILLIPS PAY COIN    PPC  philips-pay-coin          1    token
#
#                       url                                               tags  \
# 4     http://peercoin.net  mineable,hybrid-pow-pos,sha-256,medium-of-exch...
# 2652      http://p-pay.io
#
#            current_name
# 4              Peercoin
# 2652  PHILLIPS PAY COIN

# %% [markdown]
# ## Debank Cryptocurrency Meta Info

# %%
import requests
import pandas as pd

# %%
def get_data_from_host(url):
    r = requests.get(url)
    return r.json()

# %%
project_list_url = 'https://api.debank.com/project/v2/list'
project_list_response = get_data_from_host(project_list_url)

# %%
project_list_response['data'][0]
# Out:
# {'active_user_count_24h': 1067,
#  'chain': 'eth',
#  'chain_info_dict': {'id': 'eth',
#   'logo_url': 'https://static.debank.com/image/chain/logo_url/eth/6e0cd1f895af9836ee8c32cfc03bc279.png',
#   'name': {'ch': '以太坊', 'en': 'Ethereum'},
#   'token_id': 'eth'},
#  'contract_call_count_24h': 9993,
#  'create_at': 1588847817540.0,
#  'id': '0x',
#  'is_stable': False,
#  'is_tvl': False,
#  'is_visible': True,
#  'lock_underlying_usd': None,
#  'lock_usd': None,
#  'logo_url': 'https://static.debank.com/image/project/logo_url/0x/a97d06e29468082e0859f3cd48d5a2ec.png',
#  'name': {'ch': '0x', 'en': '0x'},
#  'platform_token_chain': 'eth',
#  'platform_token_id': '0xe41d2489571d322189246dafa5ebde1f4699f498',
#  'priority': 9,
#  'publish_at': 1502809252.0,
#  'site_url': 'https://0x.org',
#  'tag_ids': ['dex'],
#  'total_contract_count': 7,
#  'total_user_count': 52200,
#  'tvl': 0,
#  'update_at': 1613718897246.0}

# %%
debank_projects_info = []
for project_response in project_list_response['data']:
    debank_projects_info.append([project_response['id'], project_response['name']['en'], get_host_url(project_response['site_url'])])

# %%
debank_projects_info_df = pd.DataFrame(debank_projects_info, columns=['id', 'name', 'url'])

# %%
debank_projects_info_df
# Out:
#           id             name                      url
# 0         0x               0x           https://0x.org
# 1      1inch         1inch V1   https://1inch.exchange
# 2     1inch2            1inch   https://1inch.exchange
# 3        1sd              1sd      https://1sd.finance
# 4      88mph         88mph V1        https://88mph.app
# ..       ...              ...                      ...
# 307      zai           ZAI V1      https://zai.finance
# 308     zai2           ZAI V2           https://zai.fi
# 309    zelda            Zelda       https://zelda.cash
# 310  zeroset  Zero Set Dollar  https://zeroset.finance
# 311   zkswap           ZKSwap          https://zks.app
#
# [312 rows x 3 columns]

# %%
debank_unique_urls = list(debank_projects_info_df.url.unique())

# %%
len(debank_unique_urls)
# Out:
# 282

# %% [markdown]
# ### debank's cryptocurrencies available at CMC : Count

# %%
def insert_debank_coin_cmc_symbol(df):
    connection = __connect__()
    cursor = get_cursor(connection)
    for i, row in df.iterrows():
        try:
            print([row['symbol'], row['name_in_cmc'], row['name_in_debank']])
            sql = "INSERT INTO `debank_symbols2` (`symbol`, `name_in_cmc`, `name_in_debank`) VALUES (%s, %s, %s)"
            cursor.execute(sql, (row['symbol'], row['name_in_cmc'], row['name_in_debank']))
        except Exception:
            print(traceback2.format_exc())
    connection.commit()
    cursor.close()
    connection.close()

# %%
len(coins_info_df[(coins_info_df['url'].isin(debank_unique_urls))]['url'].unique())
# Out:
# 188

# %%
coins_info_df[(coins_info_df['url'].isin(debank_unique_urls))]
# Out:
#         id        name   symbol         slug  is_active category  \
# 290   1552      Enzyme      MLN       enzyme          1    token
# 321   1659      Gnosis      GNO   gnosis-gno          1    token
# 329   1680      Aragon      ANT       aragon          1    token
# 354   1727      Bancor      BNT       bancor          1    token
# 376   1776         MCO      MCO   crypto-com          1    token
# ...    ...         ...      ...          ...        ...      ...
# 4537  9025       Tribe    TRIBE        tribe          1    token
# 4545  9034     pETH18C  pETH18C      peth18c          1    token
# 4553  9043  Stone DeFi      STN  stone-token          1    token
# 4568  9067     Olympus      OHM      olympus          1    token
# 4582  9087       xDeFi     XDEX        xdefi          1    token
#
#                          url  \
# 290   https://enzyme.finance
# 321        https://gnosis.io
# 329       https://aragon.org
# 354   https://bancor.network
# 376       https://crypto.com
# ...                      ...
# 4537       https://fei.money
# 4545       https://poolin.fi
# 4553    https://stonedefi.io
# 4568        https://eth.link
# 4582       https://xdefi.com
#
#                                                    tags current_name
# 290   asset-management,defi,kinetic-capital,placehol...       Enzyme
# 321   services,decentralized-exchange,defi,predictio...       Gnosis
# 329   platform,cosmos-ecosystem,enterprise-solutions...       Aragon
# 354   marketplace,decentralized-exchange,defi,paymen...       Bancor
# 376                                  medium-of-exchange          MCO
# ...                                                 ...          ...
# 4537                                    defi,governance        Tribe
# 4545                                                         pETH18C
# 4553                                                      Stone DeFi
# 4568                                                         Olympus
# 4582                                                           xDeFi
#
# [335 rows x 9 columns]

# %%
sql = "select * from master_symbols where name_in_debank != ''"
maaster_symbol_df = pd.read_sql_query(sql, __connect__())

# %%
maaster_symbol_df
# Out:
#    symbol name_in_cmc    name_in_debank     name_in_tt  \
# 0   1INCH       1inch             1inch          1inch
# 1   1INCH       1inch            1inch2          1inch
# 2    AAVE        Aave              aave           Aave
# 3    AAVE        Aave           Aave V1           Aave
# 4    AAVE        Aave           Aave V2           Aave
# ..    ...         ...               ...            ...
# 90    YFI       Yearn             Yearn  yearn.finance
# 91    YFI       Yearn          Yearn V2  yearn.finance
# 92   YFII   DFI.money  DFI.Money (YFII)
# 93    YLD       Yield  YIELD (yield.is)
# 94    YLD   YIELD App  YIELD (yield.is)
#
#                 name_in_defi name_in_duneanalytics
# 0   1inch-Liquidity-Protocol                 1inch
# 1   1inch-Liquidity-Protocol                 1inch
# 2                       Aave                  Aave
# 3                       Aave                  Aave
# 4                       Aave                  Aave
# ..                       ...                   ...
# 90             yearn.finance         yearn.finance
# 91             yearn.finance         yearn.finance
# 92                 DFI.money
# 93
# 94
#
# [95 rows x 6 columns]

# %%
def get_symbol_and_name_for_url(cmc_df, url, name, master_symbol_df):
    cmc_df = cmc_df[cmc_df['url'] == url]
    if cmc_df.shape[0] == 1:
        return [cmc_df.iloc[0]['name'], cmc_df.iloc[0]['symbol']]
    elif name in master_symbol_df['name_in_debank'].values:
        master_symbol_df = master_symbol_df[master_symbol_df['name_in_debank'] == name]
        if master_symbol_df.shape[0] == 1:
            return [master_symbol_df.iloc[0]['name_in_cmc'], master_symbol_df.iloc[0]['symbol']]
        else:
            return ['']*2
    else:
        return ['', '']

# %%
deban_cmc_symbol_map = []
for index, row in debank_projects_info_df.iterrows():
    name = row['name']
    url = row['url']
    debank_mapping = [name]
    debank_mapping.extend(get_symbol_and_name_for_url(coins_info_df, url, name, maaster_symbol_df))
    deban_cmc_symbol_map.append(debank_mapping)

# %%
deban_cmc_symbol_map
# Out:
# [['0x', '0x', 'ZRX'],
#  ['1inch V1', '', ''],
#  ['1inch', '1inch', '1INCH'],
#  ['1sd', '', ''],
#  ['88mph V1', '88mph', 'MPH'],
#  ['88mph V2', '88mph', 'MPH'],
#  ['Aave V1', 'Aave', 'AAVE'],
#  ['Aave V2', 'Aave', 'AAVE'],
#  ['Aavegotchi', '', ''],
#  ['Aave AMM', '', ''],
#  ['acBTC', '', ''],
#  ['ACO', '', ''],
#  ['Airswap', 'AirSwap', 'AST'],
#  ['Alchemix', 'Alchemix', 'ALCX'],
#  ['Alpaca City', 'Alpaca City', 'ALPA'],
#  ['Alpha Homora', 'Alpha Homora', 'ALPHA'],
#  ['Alpha Homora V2', '', ''],
#  ['Ampleforth', 'Ampleforth', 'AMPL'],
#  ['AnySwap', 'Anyswap', 'ANY'],
#  ['APWine', '', ''],
#  ['APY.Finance', 'APY.Finance', 'APY'],
#  ['Aragon', '', ''],
#  ['ARCx', '', ''],
#  ['Armor', 'Armor', 'ARMOR'],
#  ['Artem', '', ''],
#  ['Augur', '', ''],
#  ['Badger DAO', 'Badger', 'BADGER'],
#  ['Balancer', '', ''],
#  ['Bancor', '', ''],
#  ['Band', 'Band Protocol', 'BAND'],
#  ['BarnBridge', 'BarnBridge', 'BOND'],
#  ['Base', 'Base Protocol', 'BASE'],
#  ['Basis Cash', 'Basis Cash', 'BAC'],
#  ['Basis Coin', '', ''],
#  ['Basis Dollar', '', ''],
#  ['Basis Gold', '', ''],
#  ['Big Data Protocol', '', ''],
#  ['Bella', 'Bella Protocol', 'BEL'],
#  ['Pendle', '', ''],
#  ['Bonded', 'Bonded Finance', 'BOND'],
#  ['BoringDAO', 'BoringDAO', 'BOR'],
#  ['Bounce', '', ''],
#  ['B.Protocol', '', ''],
#  ['1inch', '1inch', '1INCH'],
#  ['Acryptos', 'ACryptoS', 'ACS'],
#  ['Alpaca Finance', 'Alpaca Finance', 'ALPACA'],
#  ['Alpha Homora', 'Alpha Homora', 'ALPHA'],
#  ['AutoFarm', 'Auto', 'AUTO'],
#  ['BakerySwap', 'BakeryToken', 'BAKE'],
#  ['bDollar', '', ''],
#  ['Belt.fi', 'Belt', 'BELT'],
#  ['BnEX', '', ''],
#  ['BSCswap', 'BSCswap', 'BSWAP'],
#  ['Cream', '', ''],
#  ['dfuture', 'dFuture', 'DFT'],
#  ['DODO', 'DODO', 'DODO'],
#  ['Ellipsis', 'Ellipsis', 'EPS'],
#  ['ForTube Bank', 'ForTube', 'FOR'],
#  ['Goose Finance', 'Goose Finance', 'EGG'],
#  ['Helmet', 'Helmet.insure', 'HELMET'],
#  ['JulSwap', 'JulSwap', 'JULD'],
#  ['Nerve', 'Nerve Finance', 'NRV'],
#  ['OpenOcean', '', ''],
#  ['Bunny', 'PancakeBunny', 'BUNNY'],
#  ['PancakeSwap', '', ''],
#  ['PureSwap', '', ''],
#  ['QIAN', '', ''],
#  ['Smoothy', '', ''],
#  ['Venus', '', ''],
#  ['BT.Finance', 'BT.Finance', 'BT'],
#  ['bZx V1', 'bZx', 'BZRX'],
#  ['bZx', 'bZx', 'BZRX'],
#  ['ChainLink', 'Chainlink', 'LINK'],
#  ['Charm', '', ''],
#  ['ChickenSwap', '', ''],
#  ['CoFiX', 'CoFiX', 'COFI'],
#  ['Compound', '', ''],
#  ['Connext', '', ''],
#  ['CoreVault', 'cVault.finance', 'CORE'],
#  ['COVER', 'COVER Protocol', 'COVER'],
#  ['Cream', '', ''],
#  ['Cream V2', '', ''],
#  ['Curve', '', ''],
#  ['Daiq', 'Daiquilibrium', 'DAIQ'],
#  ['DDEX', '', ''],
#  ['Debaseonomics', '', ''],
#  ['Deerfi', '', ''],
#  ['DeFiDollar', '', ''],
#  ['DeFiner', 'DeFiner', 'FIN'],
#  ['DeFi Saver', '', ''],
#  ['DeFi Swap', '', ''],
#  ['DeFlast', '', ''],
#  ['Dego', 'Dego Finance', 'DEGO'],
#  ['DerivaDEX', 'DerivaDAO', 'DDX'],
#  ['DeversiFi', '', ''],
#  ['DEX.AG', '', ''],
#  ['dex.blue', '', ''],
#  ['DeXe', 'DeXe', 'DEXE'],
#  ['Dextf', 'DEXTF Protocol', 'DEXTF'],
#  ['dForce Lending', 'dForce', 'DF'],
#  ['dForce Trade', '', ''],
#  ['dHEDGE', 'dHedge DAO', 'DHT'],
#  ['DiFy', 'DiFy.Finance', 'YFIII'],
#  ['DefiMoneyMarket', 'DMM: Governance', 'DMG'],
#  ['dmm.exchange', '', ''],
#  ['DODO', 'DODO', 'DODO'],
#  ['Doki Doki', '', ''],
#  ['Dollar', '', ''],
#  ['DOS Network', 'DOS Network', 'DOS'],
#  ['Dracula', 'Dracula Token', 'DRC'],
#  ['DSD', 'Dynamic Set Dollar', 'DSD'],
#  ['dForce Yield Markets', 'dForce', 'DF'],
#  ['DuckDao', '', ''],
#  ['dYdX', '', ''],
#  ['Emoon', '', ''],
#  ['Emporium', '', ''],
#  ['Empty Set Dollar', 'Empty Set Dollar', 'ESD'],
#  ['Enzyme', 'Enzyme', 'MLN'],
#  ['Equalizer', '', ''],
#  ['Empty Set Gold', '', ''],
#  ['FairSwap', 'Lien', 'LIEN'],
#  ['Fei Protocol', '', ''],
#  ['Ferrum', '', ''],
#  ['FinNexus', 'FinNexus', 'FNX'],
#  ['FIREDAO', '', ''],
#  ['Float', 'Float Protocol', 'BANK'],
#  ['ForTube Bank', 'ForTube', 'FOR'],
#  ['ForTube Bond', 'ForTube', 'FOR'],
#  ['ForTube Bank V1', 'ForTube', 'FOR'],
#  ['Frax', 'Frax', 'FRAX'],
#  ['Freeliquid', '', ''],
#  ['Furucombo', 'Furucombo', 'COMBO'],
#  ['Gnosis', 'Gnosis', 'GNO'],
#  ['Golff', 'Golff', 'GOF'],
#  ['GrowthDeFi', 'Growth DeFi', 'GRO'],
#  ['GYSR', 'GYSR', 'GYSR'],
#  ['HAKKA', 'Hakka.Finance', 'HAKKA'],
#  ['Harvest', 'Harvest', 'FARM'],
#  ['Tax Heaven', '', ''],
#  ['Hedget', 'Hedget', 'HGET'],
#  ['Hegic', 'Hegic', 'HEGIC'],
#  ['HubrisOne X', '', ''],
#  ['HyperBC Farm', '', ''],
#  ['ichi.farm', 'ICHI', 'ICHI'],
#  ['IDEX', '', ''],
#  ['Idle', 'Idle', 'IDLE'],
#  ['Yearn', 'Yearn', 'YFI'],
#  ['Incognito', '', ''],
#  ['Index Coop', 'Index Cooperative', 'INDEX'],
#  ['Indexed', '', ''],
#  ['InstaDapp', '', ''],
#  ['Inverse', 'Inverse Finance', 'INV'],
#  ['Jarvis Network', 'Jarvis Network', 'JRT'],
#  ['Keep', 'Keep Network', 'KEEP'],
#  ['Keep3r', 'Keep3rV1', 'KP3R'],
#  ['KeeperDAO', 'KeeperDAO', 'ROOK'],
#  ['KIMCHI', 'KIMCHI.finance', 'KIMCHI'],
#  ['Kine', '', ''],
#  ['Kwenta', '', ''],
#  ['Kyber', '', ''],
#  ['Leverj', 'Leverj Gluon', 'L2'],
#  ['LIDO', 'LIDO', 'LDO'],
#  ['Lien', 'Lien', 'LIEN'],
#  ['Linear', 'Linear', 'LINA'],
#  ['Loopring V1', 'Loopring', 'LRC'],
#  ['Loopring', 'Loopring', 'LRC'],
#  ['LuaSwap', 'Lua Token', 'LUA'],
#  ['Maker', 'Maker', 'MKR'],
#  ['Benchmark(MARK)', 'Benchmark', 'MARK'],
#  ['Mars', '', ''],
#  ['Matcha', '', ''],
#  ['MCDEX', 'MCDEX', 'MCB'],
#  ['Melon', 'Enzyme', 'MLN'],
#  ['Meme', 'Meme', 'MEME'],
#  ['Mercurity', 'Mercurity Swap Protocol', 'MEE'],
#  ['Mesa', '', ''],
#  ['MetaMask Swaps', '', ''],
#  ['M.finance', '', ''],
#  ['MiniSwap', '', ''],
#  ['Mirror', '', ''],
#  ['MITH.CASH', '', ''],
#  ['Mona', '', ''],
#  ['Mooniswap', '', ''],
#  ['mStable', '', ''],
#  ['Mushrooms', 'MM Token', 'MM'],
#  ['N3rd', 'N3RD Finance', 'N3RDz'],
#  ['Nest', '', ''],
#  ['Nexus Mutual', 'NXM', 'NXM'],
#  ['NFTfi', '', ''],
#  ['Notional', '', ''],
#  ['Nsure Network', 'Nsure.Network', 'NSURE'],
#  ['Nuo', '', ''],
#  ['Oasis', '', ''],
#  ['One Cash', '', ''],
#  ['OneSwap', 'OneSwap DAO Token', 'ONES'],
#  ['OpenDAO', 'Open Governance Token', 'OPEN'],
#  ['OpenOcean', '', ''],
#  ['OpenPredict', 'Open Predict Token', 'OPT'],
#  ['OpenSea', '', ''],
#  ['Opium', 'Opium', 'OPIUM'],
#  ['Opyn V1', '', ''],
#  ['Opyn', '', ''],
#  ['Orai', 'Oraichain Token', 'ORAI'],
#  ['Orion Protocol', 'Orion Protocol', 'ORN'],
#  ['ParaSwap', '', ''],
#  ['pBTC', 'pTokens BTC', 'PBTC'],
#  ['PEAKDEFI', 'PEAKDEFI', 'PEAK'],
#  ['Pegscash', '', ''],
#  ['Percent', '', ''],
#  ['PerlinX', '', ''],
#  ['Perpetual', 'Perpetual', 'PERP'],
#  ['Pickle', 'Pickle Finance', 'PICKLE'],
#  ['PieDAO', '', ''],
#  ['PlotX', 'PlotX', 'PLOT'],
#  ['ADD.XYZ', 'Add.xyz', 'ADD'],
#  ['pNetwork', 'pTokens BTC', 'PBTC'],
#  ['Polymarket', '', ''],
#  ['PoolTogether', 'PoolTogether', 'POOL'],
#  ['PowerPool', '', ''],
#  ['QIAN', '', ''],
#  ['RabbitHole', '', ''],
#  ['Radix', 'Radix', 'EXRD'],
#  ['RAMP DEFI', 'RAMP', 'RAMP'],
#  ['Rari Capital', '', ''],
#  ['RAY', '', ''],
#  ['Reflect', 'reflect.finance', 'RFI'],
#  ['Reflexer', 'Rai Reflex Index', 'RAI'],
#  ['Ren', 'Ren', 'REN'],
#  ['Reserve', '', ''],
#  ['Rootkit', 'Rootkit Finance', 'ROOT'],
#  ['Sablier', '', ''],
#  ['Saddle', '', ''],
#  ['SAFE', '', ''],
#  ['Saffron', 'saffron.finance', 'SFI'],
#  ['SakeSwap', 'SakeToken', 'SAKE'],
#  ['SashimiSwap', 'Sashimi', 'SASHIMI'],
#  ['Saturn', '', ''],
#  ['S.Finance', 'S.Finance', 'SFG'],
#  ['Shell', '', ''],
#  ['Siren', 'Siren', 'SI'],
#  ['Smoothy', '', ''],
#  ['SnowSwap', 'SnowSwap', 'SNOW'],
#  ['Stabilize', 'Stabilize', 'STBZ'],
#  ['Stake DAO', 'Stake DAO', 'SDT'],
#  ['Stand Cash', '', ''],
#  ['STEROIDS', '', ''],
#  ['Stkr', 'ankrETH', 'aEth'],
#  ['STONE', 'Stone DeFi', 'STN'],
#  ['Sunflower Swap', '', ''],
#  ['SushiSwap', '', ''],
#  ['Swerve', 'Swerve', 'SWRV'],
#  ['Swingby', 'Swingby', 'SWINGBY'],
#  ['SWISS', 'swiss.finance', 'SWISS'],
#  ['Switcheo', 'Switcheo', 'SWTH'],
#  ['SynLev', 'SynLev', 'SYN'],
#  ['Synthetix', 'Synthetix', 'SNX'],
#  ['tBTC', 'tBTC', 'TBTC'],
#  ['Team Finance', '', ''],
#  ['Tellor', 'Tellor', 'TRB'],
#  ['Themis', 'Themis', 'MIS'],
#  ['Tokenlon', '', ''],
#  ['TokenSets', '', ''],
#  ['Tornado', 'Tornado Cash', 'TORN'],
#  ['Totle', '', ''],
#  ['TRAMS', '', ''],
#  ['TrueFi', 'TrueFi', 'TRU'],
#  ['TrustSwap', 'TrustSwap', 'SWAP'],
#  ['TyphoonCash', 'Typhoon Cash', 'PHOON'],
#  ['UMA', 'UMA', 'UMA'],
#  ['Umbrella', 'YAM v3', 'YAM'],
#  ['Unagii', '', ''],
#  ['Unicrypt', '', ''],
#  ['Unimex', '', ''],
#  ['Unipower', 'UniPower', 'POWER'],
#  ['Unisave', '', ''],
#  ['Uniswap V1', 'Uniswap', 'UNI'],
#  ['Uniswap', 'Uniswap', 'UNI'],
#  ['unit protocol', '', ''],
#  ['unn', 'UNION Protocol Governance Token', 'UNN'],
#  ['Unslashed', 'Unslashed Finance', 'USF'],
#  ['Vesper', 'Vesper', 'VSP'],
#  ['Volmex', '', ''],
#  ['Warp', 'Warp Finance', 'WARP'],
#  ['WePiggy', '', ''],
#  ['xBTC', 'xBTC', 'xBTC'],
#  ['xDai', 'Wrapped XDAI', 'wxDai'],
#  ['Agave', '', ''],
#  ['Bao.Finance', '', ''],
#  ['component', '', ''],
#  ['Honeyswap', '', ''],
#  ['Perpetual', 'Perpetual', 'PERP'],
#  ['XDEFI', 'xDeFi', 'XDEX'],
#  ['X SIGMA', '', ''],
#  ['xToken', 'xToken', 'XTK'],
#  ['XUSD', 'XUSD Stable', 'XUSD'],
#  ['xvix', 'XVIX', 'XVIX'],
#  ['Y3D', '', ''],
#  ['YAM V1', 'YAM v3', 'YAM'],
#  ['YAM V3', 'YAM v3', 'YAM'],
#  ['yAxis', 'yAxis', 'YAX'],
#  ['Yearn V2', 'Yearn', 'YFI'],
#  ['YfDAI', 'YFDAI.FINANCE', 'YF-DAI'],
#  ['DFI.Money (YFII)', 'DFI.Money', 'YFII'],
#  ['YFLink', '', ''],
#  ['Value DeFi', '', ''],
#  ['YIELD (yield.is)', '', ''],
#  ['YVS', 'YVS.Finance', 'YVS'],
#  ['ZAI V1', 'Zero Collateral Dai', 'ZAI'],
#  ['ZAI V2', '', ''],
#  ['Zelda', '', ''],
#  ['Zero Set Dollar', '', ''],
#  ['ZKSwap', '', '']]

# %%
df = pd.DataFrame(deban_cmc_symbol_map, columns=['name_in_debank', 'name_in_cmc', 'symbol'])

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#       name_in_debank          name_in_cmc symbol
# 0                 0x                   0x    ZRX
# 1           1inch V1
# 2              1inch                1inch  1INCH
# 3                1sd
# 4           88mph V1                88mph    MPH
# ..               ...                  ...    ...
# 307           ZAI V1  Zero Collateral Dai    ZAI
# 308           ZAI V2
# 309            Zelda
# 310  Zero Set Dollar
# 311           ZKSwap
#
# [303 rows x 3 columns]

# %%
sql = "select * from debank_symbols where name_in_cmc != ''"
debank_symbol_df = pd.read_sql_query(sql, __connect__())

# %%
debank_symbol_df
# Out:
#     symbol          name_in_cmc       name_in_debank
# 0    1INCH                1inch                1inch
# 1    1INCH                1inch          1INCH Token
# 2    1INCH                1inch             1inch V1
# 3     AAVE                 Aave           Aave Token
# 4     AAVE                 Aave              Aave V1
# ..     ...                  ...                  ...
# 244    ZAI  Zero Collateral Dai  Zero Collateral Dai
# 245    ZKS               ZKSwap                  Zks
# 246    ZKS               ZKSwap               ZKSwap
# 247    ZRX                   0x                   0x
# 248    ZRX                   0x    0x Protocol Token
#
# [249 rows x 3 columns]

# %%
df3 = debank_symbol_df.append(df)

# %%
df3 = df3.drop_duplicates()
# Out:
#     symbol          name_in_cmc   name_in_debank
# 0    1INCH                1inch            1inch
# 1    1INCH                1inch      1INCH Token
# 2    1INCH                1inch         1inch V1
# 3     AAVE                 Aave       Aave Token
# 4     AAVE                 Aave          Aave V1
# ..     ...                  ...              ...
# 307    ZAI  Zero Collateral Dai           ZAI V1
# 308                                       ZAI V2
# 309                                        Zelda
# 310                              Zero Set Dollar
# 311                                       ZKSwap
#
# [482 rows x 3 columns]

# %%
insert_debank_coin_cmc_symbol(df3)
# Out:
# ['1INCH', '1inch', '1inch']
# ['1INCH', '1inch', '1INCH Token']
# ['1INCH', '1inch', '1inch V1']
# ['AAVE', 'Aave', 'Aave Token']
# ['AAVE', 'Aave', 'Aave V1']
# ['AAVE', 'Aave', 'Aave V2']
# ['ALCX', 'Alchemix', 'Alchemix']
# ['ALPA', 'Alpaca City', 'Alpaca City']
# ['ALPA', 'Alpaca City', 'AlpaToken']
# ['ALPACA', 'Alpaca Finance', 'Alpaca Finance']
# ['ALPHA', 'Alpha Finance Lab', 'AlphaToken']
# ['AMP', 'Amp', 'Amp']
# ['AMPL', 'Ampleforth', 'Ampleforth']
# ['ANT', 'Aragon', 'Aragon']
# ['ANT', 'Aragon', 'Aragon Network Token']
# ['ANY', 'Anyswap', 'Anyswap']
# ['APY', 'APY.Finance', 'APY Governance Token']
# ['APY', 'APY.Finance', 'APY.Finance']
# ['ARMOR', 'ARMOR', 'Armor']
# ['AST', 'AirSwap', 'AirSwap Token']
# ['AST', 'AntiscamToken', 'AirSwap Token']
# ['BAC', 'Basis Cash', 'Basis Cash']
# ['BADGER', 'Badger DAO', 'Badger DAO']
# ['BAG', 'Basis Gold', 'Basis Gold']
# ['BAL', 'Balancer', 'Balancer']
# ['BAND', 'Band Protocol', 'BandToken']
# ['BAS', 'Basis Share', 'BAS']
# ['BASE', 'Base Protocol', 'Base Protocol']
# ['BCS', 'Basiscoin Share', 'BCS']
# ['BDO', 'bDollar', 'bDollar']
# ['BDP', 'BidiPass', 'BDPToken']
# ['BDP', 'Big Data Protocol', 'BDPToken']
# ['BDP', 'Big Data Protocol', 'Big Data Protocol']
# ['BEL', 'Bella Protocol', 'Bella']
# ['BNT', 'Bancor', 'Bancor']
# ['BNT', 'Bancor', 'Bancor Network Token']
# ['BOND', 'BarnBridge', 'BarnBridge']
# ['BOND', 'BarnBridge', 'BarnBridge Governance Token']
# ['BOND', 'Bonded Finance', 'BarnBridge Governance Token']
# ['BOR', 'BoringDAO', 'BoringDAO']
# ['BSD', 'Basis Dollar', 'Basis Dollar']
# ['BSDS', 'Basis Dollar Share', 'Basis Dollar Share']
# ['BSWAP', 'BSCswap', 'BSCswap']
# ['BT', 'BT.Finance', 'BT.Finance']
# ['BZRX', 'bZx Protocol', 'bZx Protocol Token']
# ['CAKE', 'PancakeSwap', 'PancakeSwap']
# ['COFI', 'CoFiX', 'CoFiX']
# ['COMBO', 'Furucombo', 'Furucombo']
# ['COMP', 'Compound', 'Compound']
# ['COMP', 'Compound Coin', 'Compound']
# ['CORE', 'cVault.finance', 'cVault.finance']
# ['COVER', 'COVER Protocol', 'Cover Protocol Governance Token']
# ['CREAM', 'Cream Finance', 'Cream']
# ['CRM', 'Cream', 'Cream']
# ['CRV', 'Curve DAO Token', 'Curve DAO Token']
# ['CVP', 'PowerPool', 'Concentrated Voting Power']
# ['CVP', 'PowerPool', 'PowerPool']
# ['DAIQ', 'Daiquilibrium', 'Daiquilibrium']
# ['DDIM', 'DuckDaoDime', 'DuckDaoDime']
# ['DDX', 'DerivaDAO', 'DerivaDAO']
# ['DEGO', 'Dego Finance', 'dego.finance']
# ['DEGOV', 'Degov', 'Degov']
# ['DEXE', 'DeXe', 'DeXe']
# ['DEXTF', 'DEXTF Protocol', 'DEXTF Token']
# ['DF', 'dForce', 'dForce']
# ['DFD', 'DefiDollar DAO', 'DefiDollar DAO']
# ['DHT', 'dHedge DAO', 'dHedge DAO Token']
# ['DMG', 'DMM: Governance', 'DMM: Governance']
# ['DODO', 'DODO', 'DODO']
# ['DODO', 'DODO', 'DODO bird']
# ['DOKI', 'Doki Doki Finance', 'DokiDokiFinance']
# ['DOS', 'DEMOS', 'DOS Network Token']
# ['DOS', 'DOS Network', 'DOS Network']
# ['DOS', 'DOS Network', 'DOS Network Token']
# ['DOUGH', 'PieDAO DOUGH v2', 'PieDAO DOUGH v2']
# ['DRC', 'Digital Reserve Currency', 'Dracula Token']
# ['DRC', 'Dracula Token', 'Dracula Token']
# ['DRC', 'DRC mobility', 'Dracula Token']
# ['EGG', 'Goose Finance', 'Goose Finance']
# ['ESD', 'Empty Set Dollar', 'Empty Set Dollar']
# ['EXRD', 'Radix', 'Radix']
# ['FARM', 'Harvest Finance', 'FARM Reward Token']
# ['FIN', 'DeFiner', 'DeFiner']
# ['FL', 'Freeliquid', 'FL']
# ['FL', 'Freeliquid', 'Freeliquid']
# ['FNX', 'FinNexus', 'FinNexus']
# ['FOR', 'ForTube', 'The Force Token']
# ['FRAX', 'Frax', 'Frax']
# ['FRM', 'Ferrum Network', 'Ferrum Network Token']
# ['FXS', 'Frax Share', 'Frax Share']
# ['GET', 'Themis', 'Themis']
# ['GHST', 'Aavegotchi', 'Aavegotchi']
# ['GHST', 'Aavegotchi', 'Aavegotchi GHST Token']
# ['GNO', 'Gnosis', 'Gnosis']
# ['GNO', 'Gnosis', 'Gnosis Token']
# ['GOF', 'Golff', 'Golff']
# ['GOF', 'Golff', 'Golff.finance']
# ['GRO', 'Growth DeFi', 'Growth']
# ['GYSR', 'GYSR', 'Geyser']
# ['GYSR', 'GYSR', 'GYSR']
# ['HAKKA', 'Hakka.Finance', 'Hakka Finance']
# ['HEGIC', 'Hegic', 'Hegic']
# ['HGET', 'Hedget', 'Hedget']
# ['HOT', 'Holo', 'Hydro Protocol Token']
# ['HOT', 'Hydro Protocol', 'Hydro Protocol Token']
# ['ICHI', 'ICHI', 'ichi.farm']
# ['IDEX', 'IDEX', 'IDEX']
# ['IDEX', 'IDEX', 'IDEX Token']
# ['IDLE', 'Idle', 'Idle']
# ['INDEX', 'Index Cooperative', 'Index']
# ['JULD', 'JulSwap', 'JulSwap']
# ['KEEP', 'Keep Network', 'KEEP Token']
# ['KFC', 'Chicken', 'Chicken']
# ['KIMCHI', 'KIMCHI.finance', 'KIMCHI.finance']
# ['KNC', 'Kyber Network', 'Kyber']
# ['KNC', 'Kyber Network', 'Kyber Network Crystal']
# ['KP3R', 'Keep3rV1', 'Keep3rV1']
# ['L2', 'Leverj Gluon', 'Leverj Gluon']
# ['LDO', 'Lido DAO Token', 'Lido DAO Token']
# ['LIEN', 'Lien', 'lien']
# ['LINA', 'LINA', 'Linear Token']
# ['LINA', 'Linear', 'Linear']
# ['LINA', 'Linear', 'Linear Token']
# ['LINK', 'Chainlink', 'ChainLink Token']
# ['LON', 'Tokenlon Network Token', 'Tokenlon']
# ['LRC', 'Loopring', 'Loopring']
# ['LRC', 'Loopring', 'LoopringCoin V2']
# ['LUA', 'Lua Token', 'LuaToken']
# ['MARK', 'Benchmark Protocol', 'Benchmark']
# ['Mars', 'Mars', 'Mars']
# ['Mars', 'Mars', 'MarsToken']
# ['MCB', 'MCDEX', 'MCDEX']
# ['MCB', 'MCDEX', 'MCDEX Token']
# ['MEME', 'Meme', 'MEME']
# ['MEME', 'Memetic / PepeCoin', 'MEME']
# ['MINI', 'MiniSwap', 'MINISWAP']
# ['MIR', 'MIR COIN', 'Wrapped MIR Token']
# ['MIR', 'Mirror Protocol', 'Wrapped MIR Token']
# ['MIS', 'Mithril Share', 'ThemisToken']
# ['MIS', 'Themis', 'Themis']
# ['MIS', 'Themis', 'ThemisToken']
# ['MKR', 'Maker', 'Maker']
# ['MLN', 'Enzyme', 'Enzyme']
# ['MLN', 'Enzyme', 'Melon Token']
# ['MM', 'MilliMeter', 'MMToken']
# ['MM', 'MM Token', 'MMToken']
# ['MPH\n', '88mph\n', '88mph V1']
# ['MPH', '88mph', '88mph V2']
# ['MPH', '88mph', '88mph.app']
# ['MPH', 'Morpher', '88mph.app']
# ['MTA', 'Meta', 'Meta']
# ['N3RDz', 'N3RD Finance', 'N3RD.FINANCE']
# ['NEC', 'Nectar', 'Ethfinex Nectar Token']
# ['NEST', 'NEST Protocol', 'NEST']
# ['ONC', 'One Cash', 'One Cash']
# ['ONES', 'OneSwap DAO Token', 'OneSwap']
# ['ONS', 'One Share', 'ONS']
# ['OPEN', 'Open Governance Token', 'OPEN Governance Token']
# ['OPEN', 'Open Platform', 'OPEN Governance Token']
# ['OPIUM', 'Opium', 'Opium']
# ['OPIUM', 'Opium', 'Opium Governance Token']
# ['OPT', 'Open Predict Token', 'Open Predict Token']
# ['OPT', 'Opus', 'Open Predict Token']
# ['ORAI', 'Oraichain Token', 'Oraichain Token']
# ['ORN', 'Orion Protocol', 'Orion Protocol']
# ['PEAK', 'PEAKDEFI', 'PEAKDEFI']
# ['PERL', 'Perlin', 'Perlin']
# ['PERP', 'Perpetual Protocol', 'Perpetual']
# ['PHOON', 'Typhoon Cash', 'Typhoon']
# ['PICKLE', 'Pickle Finance', 'PickleToken']
# ['PLOT', 'PlotX', 'PLOT']
# ['PLOT', 'PlotX', 'PlotX']
# ['PNT', 'Penta', 'pNetwork Token']
# ['PNT', 'pNetwork', 'pNetwork']
# ['PNT', 'pNetwork', 'pNetwork Token']
# ['POOL', 'PoolTogether', 'PoolTogether']
# ['POWER', 'UniPower', 'UniPower']
# ['RAMP', 'RAMP', 'RAMP DEFI']
# ['REN', 'Ren', 'Ren']
# ['REN', 'Ren', 'Republic Token']
# ['REP', 'Augur', 'Augur']
# ['RFI', 'reflect.finance', 'reflect.finance']
# ['RGT', 'Rari Governance Token', 'Rari Governance Token']
# ['ROOK', 'KeeperDAO', 'KeeperDAO']
# ['ROOK', 'KeeperDAO', 'ROOK']
# ['ROOT', 'Rootkit Finance', 'RootKit']
# ['RSR', 'Reserve Rights', 'Reserve Rights']
# ['RSV', 'Reserve', 'Reserve']
# ['SAKE', 'SakeToken', 'SakeToken']
# ['SASHIMI', 'Sashimi', 'SashimiToken']
# ['SDT', 'Stake DAO', 'Stake DAO']
# ['SDT', 'Stake DAO', 'Stake DAO Token']
# ['SDT', 'Terra SDT', 'Stake DAO Token']
# ['SFG', 'S.Finance', 'S.Finance']
# ['SFI', 'saffron.finance', 'Spice']
# ['SI', 'Siren', 'Siren']
# ['SIG', 'xSigma', 'xSigma']
# ['SNOW', 'SnowSwap', 'SnowSwap']
# ['SNX', 'Synthetix', 'Synthetix']
# ['SNX', 'Synthetix', 'Synthetix Network Token']
# ['STAKE', 'xDai', 'xDai']
# ['STBZ', 'Stabilize', 'Stabilize']
# ['STBZ', 'Stabilize', 'Stabilize Token']
# ['SUSHI', 'SushiSwap', 'SushiSwap']
# ['SUSHI', 'SushiSwap', 'SushiToken']
# ['SWAP', 'TrustSwap', 'TrustSwap']
# ['SWAP', 'TrustSwap', 'TrustSwap Token']
# ['SWINGBY', 'Swingby', 'Swingby']
# ['SWISS', 'swiss.finance', 'Swiss Token']
# ['SWRV', 'Swerve', 'Swerve']
# ['SWRV', 'Swerve', 'Swerve DAO Token']
# ['SWTH', 'Switcheo', 'Switcheo']
# ['SYN', 'SynLev', 'SynLev']
# ['TBTC', 'tBTC', 'tBTC']
# ['TCORE', 'Tornado', 'Tornado']
# ['TORN', 'Tornado Cash', 'TornadoCash']
# ['TRB', 'Tellor', 'Tellor']
# ['TRU', 'TrueFi', 'TrueFi']
# ['TRU', 'TrueFi', 'TrustToken']
# ['UMA', 'UMA', 'UMA']
# ['UMA', 'UMA', 'UMA Voting Token v1']
# ['UMB', 'Umbrella Network', 'Umbrella']
# ['UNC', 'Unicrypt', 'Unicrypt']
# ['UNCX', 'UniCrypt', 'UniCrypt']
# ['UNI', 'UNICORN Token', 'Uniswap']
# ['UNI', 'Uniswap', 'Uniswap']
# ['UNI', 'Universe', 'Uniswap']
# ['UNN', 'UNION Protocol Governance Token', 'UNION Protocol Governance Token']
# ['VALUE', 'Value Liquidity', 'Value Liquidity']
# ['VSP', 'Vesper', 'Vesper']
# ['xBTC', 'xBTC', 'xBTC']
# ['XTK', 'xToken', 'xToken']
# ['XVIX', 'XVIX', 'XVIX']
# ['XVS', 'Venus', 'Venus']
# ['YAM', 'YAM v1', 'YAM']
# ['YAM', 'YAM v3', 'YAM']
# ['YAX', 'yAxis', 'yAxis']
# ['Yf-DAI', 'YFDAI.FINANCE', 'YfDAI.finance']
# ['YFI', 'yearn.finance', 'yearn.finance']
# ['YFII', 'DFI.Money', 'YFII.finance']
# ['YFIII', 'DiFy.Finance', 'DiFy.Finance']
# ['YFIII', 'YFIII', 'DiFy.Finance']
# ['YFL', 'YF Link', 'YFLink']
# ['YVS', 'YVS.Finance', 'YVS.Finance']
# ['ZAI', 'Zero Collateral Dai', 'Zero Collateral Dai']
# ['ZKS', 'ZKSwap', 'Zks']
# ['ZKS', 'ZKSwap', 'ZKSwap']
# ['ZRX', '0x', '0x']
# ['ZRX', '0x', '0x Protocol Token']
# ['ZRX', '0x', '0x']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'ZRX-0x-0x' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', '1inch V1']
# ['1INCH', '1inch', '1inch']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry '1INCH-1inch-1inch' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', '1sd']
# ['MPH', '88mph', '88mph V1']
# ['MPH', '88mph', '88mph V2']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'MPH-88mph-88mph V2' for key 'debank_symbols2.PRIMARY'")
#
# ['AAVE', 'Aave', 'Aave V1']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'AAVE-Aave-Aave V1' for key 'debank_symbols2.PRIMARY'")
#
# ['AAVE', 'Aave', 'Aave V2']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'AAVE-Aave-Aave V2' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Aavegotchi']
# ['', '', 'Aave AMM']
# ['', '', 'acBTC']
# ['', '', 'ACO']
# ['AST', 'AirSwap', 'Airswap']
# ['ALCX', 'Alchemix', 'Alchemix']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'ALCX-Alchemix-Alchemix' for key 'debank_symbols2.PRIMARY'")
#
# ['ALPA', 'Alpaca City', 'Alpaca City']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'ALPA-Alpaca City-Alpaca City' for key 'debank_symbols2.PRIMARY'")
#
# ['ALPHA', 'Alpha Homora', 'Alpha Homora']
# ['', '', 'Alpha Homora V2']
# ['AMPL', 'Ampleforth', 'Ampleforth']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'AMPL-Ampleforth-Ampleforth' for key 'debank_symbols2.PRIMARY'")
#
# ['ANY', 'Anyswap', 'AnySwap']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'ANY-Anyswap-AnySwap' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'APWine']
# ['APY', 'APY.Finance', 'APY.Finance']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'APY-APY.Finance-APY.Finance' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Aragon']
# ['', '', 'ARCx']
# ['ARMOR', 'Armor', 'Armor']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'ARMOR-Armor-Armor' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Artem']
# ['', '', 'Augur']
# ['BADGER', 'Badger', 'Badger DAO']
# ['', '', 'Balancer']
# ['', '', 'Bancor']
# ['BAND', 'Band Protocol', 'Band']
# ['BOND', 'BarnBridge', 'BarnBridge']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'BOND-BarnBridge-BarnBridge' for key 'debank_symbols2.PRIMARY'")
#
# ['BASE', 'Base Protocol', 'Base']
# ['BAC', 'Basis Cash', 'Basis Cash']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'BAC-Basis Cash-Basis Cash' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Basis Coin']
# ['', '', 'Basis Dollar']
# ['', '', 'Basis Gold']
# ['', '', 'Big Data Protocol']
# ['BEL', 'Bella Protocol', 'Bella']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'BEL-Bella Protocol-Bella' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Pendle']
# ['BOND', 'Bonded Finance', 'Bonded']
# ['BOR', 'BoringDAO', 'BoringDAO']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'BOR-BoringDAO-BoringDAO' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Bounce']
# ['', '', 'B.Protocol']
# ['ACS', 'ACryptoS', 'Acryptos']
# ['ALPACA', 'Alpaca Finance', 'Alpaca Finance']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'ALPACA-Alpaca Finance-Alpaca Finance' for key 'debank_symbols2.PRIMARY'")
#
# ['AUTO', 'Auto', 'AutoFarm']
# ['BAKE', 'BakeryToken', 'BakerySwap']
# ['', '', 'bDollar']
# ['BELT', 'Belt', 'Belt.fi']
# ['', '', 'BnEX']
# ['BSWAP', 'BSCswap', 'BSCswap']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'BSWAP-BSCswap-BSCswap' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Cream']
# ['DFT', 'dFuture', 'dfuture']
# ['DODO', 'DODO', 'DODO']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'DODO-DODO-DODO' for key 'debank_symbols2.PRIMARY'")
#
# ['EPS', 'Ellipsis', 'Ellipsis']
# ['FOR', 'ForTube', 'ForTube Bank']
# ['EGG', 'Goose Finance', 'Goose Finance']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'EGG-Goose Finance-Goose Finance' for key 'debank_symbols2.PRIMARY'")
#
# ['HELMET', 'Helmet.insure', 'Helmet']
# ['JULD', 'JulSwap', 'JulSwap']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'JULD-JulSwap-JulSwap' for key 'debank_symbols2.PRIMARY'")
#
# ['NRV', 'Nerve Finance', 'Nerve']
# ['', '', 'OpenOcean']
# ['BUNNY', 'PancakeBunny', 'Bunny']
# ['', '', 'PancakeSwap']
# ['', '', 'PureSwap']
# ['', '', 'QIAN']
# ['', '', 'Smoothy']
# ['', '', 'Venus']
# ['BT', 'BT.Finance', 'BT.Finance']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'BT-BT.Finance-BT.Finance' for key 'debank_symbols2.PRIMARY'")
#
# ['BZRX', 'bZx', 'bZx V1']
# ['BZRX', 'bZx', 'bZx']
# ['LINK', 'Chainlink', 'ChainLink']
# ['', '', 'Charm']
# ['', '', 'ChickenSwap']
# ['COFI', 'CoFiX', 'CoFiX']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'COFI-CoFiX-CoFiX' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Compound']
# ['', '', 'Connext']
# ['CORE', 'cVault.finance', 'CoreVault']
# ['COVER', 'COVER Protocol', 'COVER']
# ['', '', 'Cream V2']
# ['', '', 'Curve']
# ['DAIQ', 'Daiquilibrium', 'Daiq']
# ['', '', 'DDEX']
# ['', '', 'Debaseonomics']
# ['', '', 'Deerfi']
# ['', '', 'DeFiDollar']
# ['FIN', 'DeFiner', 'DeFiner']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'FIN-DeFiner-DeFiner' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'DeFi Saver']
# ['', '', 'DeFi Swap']
# ['', '', 'DeFlast']
# ['DEGO', 'Dego Finance', 'Dego']
# ['DDX', 'DerivaDAO', 'DerivaDEX']
# ['', '', 'DeversiFi']
# ['', '', 'DEX.AG']
# ['', '', 'dex.blue']
# ['DEXE', 'DeXe', 'DeXe']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
# ...
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'TRU-TrueFi-TrueFi' for key 'debank_symbols2.PRIMARY'")
#
# ['SWAP', 'TrustSwap', 'TrustSwap']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'SWAP-TrustSwap-TrustSwap' for key 'debank_symbols2.PRIMARY'")
#
# ['PHOON', 'Typhoon Cash', 'TyphoonCash']
# ['UMA', 'UMA', 'UMA']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'UMA-UMA-UMA' for key 'debank_symbols2.PRIMARY'")
#
# ['YAM', 'YAM v3', 'Umbrella']
# ['', '', 'Unagii']
# ['', '', 'Unicrypt']
# ['', '', 'Unimex']
# ['POWER', 'UniPower', 'Unipower']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'POWER-UniPower-Unipower' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Unisave']
# ['UNI', 'Uniswap', 'Uniswap V1']
# ['UNI', 'Uniswap', 'Uniswap']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'UNI-Uniswap-Uniswap' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'unit protocol']
# ['UNN', 'UNION Protocol Governance Token', 'unn']
# ['USF', 'Unslashed Finance', 'Unslashed']
# ['VSP', 'Vesper', 'Vesper']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'VSP-Vesper-Vesper' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Volmex']
# ['WARP', 'Warp Finance', 'Warp']
# ['', '', 'WePiggy']
# ['xBTC', 'xBTC', 'xBTC']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'xBTC-xBTC-xBTC' for key 'debank_symbols2.PRIMARY'")
#
# ['wxDai', 'Wrapped XDAI', 'xDai']
# ['', '', 'Agave']
# ['', '', 'Bao.Finance']
# ['', '', 'component']
# ['', '', 'Honeyswap']
# ['XDEX', 'xDeFi', 'XDEFI']
# ['', '', 'X SIGMA']
# ['XTK', 'xToken', 'xToken']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'XTK-xToken-xToken' for key 'debank_symbols2.PRIMARY'")
#
# ['XUSD', 'XUSD Stable', 'XUSD']
# ['XVIX', 'XVIX', 'xvix']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'XVIX-XVIX-xvix' for key 'debank_symbols2.PRIMARY'")
#
# ['', '', 'Y3D']
# ['YAM', 'YAM v3', 'YAM V1']
# ['YAM', 'YAM v3', 'YAM V3']
# ['YAX', 'yAxis', 'yAxis']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'YAX-yAxis-yAxis' for key 'debank_symbols2.PRIMARY'")
#
# ['YFI', 'Yearn', 'Yearn V2']
# ['YF-DAI', 'YFDAI.FINANCE', 'YfDAI']
# ['YFII', 'DFI.Money', 'DFI.Money (YFII)']
# ['', '', 'YFLink']
# ['', '', 'Value DeFi']
# ['', '', 'YIELD (yield.is)']
# ['YVS', 'YVS.Finance', 'YVS']
# ['ZAI', 'Zero Collateral Dai', 'ZAI V1']
# ['', '', 'ZAI V2']
# ['', '', 'Zelda']
# ['', '', 'Zero Set Dollar']
# ['', '', 'ZKSwap']

# %%
not_in_df = debank_symbol_df[~debank_symbol_df['name_in_debank'].isin(df['name_in_debank'].values)]

# %%
df[df['symbol'] == '1INCH']
# Out:
#    name_in_debank name_in_cmc symbol
# 2           1inch       1inch  1INCH
# 43          1inch       1inch  1INCH

# %%
not_in_df
# Out:
#     symbol          name_in_cmc       name_in_debank
# 1    1INCH                1inch          1INCH Token
# 3     AAVE                 Aave           Aave Token
# 8     ALPA          Alpaca City            AlpaToken
# 10   ALPHA    Alpha Finance Lab           AlphaToken
# 11     AMP                  Amp                  Amp
# ..     ...                  ...                  ...
# 241  YFIII                YFIII         DiFy.Finance
# 243    YVS          YVS.Finance          YVS.Finance
# 244    ZAI  Zero Collateral Dai  Zero Collateral Dai
# 245    ZKS               ZKSwap                  Zks
# 248    ZRX                   0x    0x Protocol Token
#
# [140 rows x 3 columns]

# %%
debank_symbol_df.sort_values(['name_in_debank'])
# Out:
#     symbol    name_in_cmc     name_in_debank
# 247    ZRX             0x                 0x
# 248    ZRX             0x  0x Protocol Token
# 1    1INCH          1inch        1INCH Token
# 0    1INCH          1inch              1inch
# 2    1INCH          1inch           1inch V1
# ..     ...            ...                ...
# 200  STAKE           xDai               xDai
# 196    SIG         xSigma             xSigma
# 231    XTK         xToken             xToken
# 236    YAX          yAxis              yAxis
# 238    YFI  yearn.finance      yearn.finance
#
# [249 rows x 3 columns]

# %%
debank_valid_values_df = df[df['name_in_cmc'] != ''].sort_values(['name_in_debank'])
debank_valid_values_df
# Out:
#     name_in_debank   name_in_cmc symbol
# 0               0x            0x    ZRX
# 2            1inch         1inch  1INCH
# 4         88mph V1         88mph    MPH
# 5         88mph V2         88mph    MPH
# 214        ADD.XYZ       Add.xyz    ADD
# ..             ...           ...    ...
# 284           xBTC          xBTC   xBTC
# 285           xDai  Wrapped XDAI  wxDai
# 293         xToken        xToken    XTK
# 295           xvix          XVIX   XVIX
# 299          yAxis         yAxis    YAX
#
# [168 rows x 3 columns]

# %%
not_in_df.sort_values(['name_in_debank'])
# Out:
#     symbol      name_in_cmc        name_in_debank
# 248    ZRX               0x     0x Protocol Token
# 1    1INCH            1inch           1INCH Token
# 148    MPH            88mph             88mph.app
# 149    MPH          Morpher             88mph.app
# 16     APY      APY.Finance  APY Governance Token
# ..     ...              ...                   ...
# 174    PNT         pNetwork        pNetwork Token
# 172    PNT            Penta        pNetwork Token
# 181    RFI  reflect.finance       reflect.finance
# 196    SIG           xSigma                xSigma
# 238    YFI    yearn.finance         yearn.finance
#
# [140 rows x 3 columns]

# %%
df2 = debank_valid_values_df.append(not_in_df)

# %%
df2 = df2.drop_duplicates()
df2.sort_values(['name_in_debank'])
# Out:
#         name_in_debank    name_in_cmc symbol
# 0                   0x             0x    ZRX
# 248  0x Protocol Token             0x    ZRX
# 1          1INCH Token          1inch  1INCH
# 2                1inch          1inch  1INCH
# 4             88mph V1          88mph    MPH
# ..                 ...            ...    ...
# 196             xSigma         xSigma    SIG
# 293             xToken         xToken    XTK
# 295               xvix           XVIX   XVIX
# 299              yAxis          yAxis    YAX
# 238      yearn.finance  yearn.finance    YFI
#
# [308 rows x 3 columns]

# %%
insert_debank_coin_cmc_symbol(df2)
# Out:
# ['ZRX', '0x', '0x']
# ['1INCH', '1inch', '1inch']
# ['MPH', '88mph', '88mph V1']
# ['MPH', '88mph', '88mph V2']
# ['ADD', 'Add.xyz', 'ADD.XYZ']
# ['APY', 'APY.Finance', 'APY.Finance']
# ['AAVE', 'Aave', 'Aave V1']
# ['AAVE', 'Aave', 'Aave V2']
# ['ACS', 'ACryptoS', 'Acryptos']
# ['AST', 'AirSwap', 'Airswap']
# ['ALCX', 'Alchemix', 'Alchemix']
# ['ALPA', 'Alpaca City', 'Alpaca City']
# ['ALPACA', 'Alpaca Finance', 'Alpaca Finance']
# ['ALPHA', 'Alpha Homora', 'Alpha Homora']
# ['AMPL', 'Ampleforth', 'Ampleforth']
# ['ANY', 'Anyswap', 'AnySwap']
# ['ARMOR', 'Armor', 'Armor']
# ['AUTO', 'Auto', 'AutoFarm']
# ['BSWAP', 'BSCswap', 'BSCswap']
# ['BT', 'BT.Finance', 'BT.Finance']
# ['BADGER', 'Badger', 'Badger DAO']
# ['BAKE', 'BakeryToken', 'BakerySwap']
# ['BAND', 'Band Protocol', 'Band']
# ['BOND', 'BarnBridge', 'BarnBridge']
# ['BASE', 'Base Protocol', 'Base']
# ['BAC', 'Basis Cash', 'Basis Cash']
# ['BEL', 'Bella Protocol', 'Bella']
# ['BELT', 'Belt', 'Belt.fi']
# ['MARK', 'Benchmark', 'Benchmark(MARK)']
# ['BOND', 'Bonded Finance', 'Bonded']
# ['BOR', 'BoringDAO', 'BoringDAO']
# ['BUNNY', 'PancakeBunny', 'Bunny']
# ['COVER', 'COVER Protocol', 'COVER']
# ['LINK', 'Chainlink', 'ChainLink']
# ['COFI', 'CoFiX', 'CoFiX']
# ['CORE', 'cVault.finance', 'CoreVault']
# ['YFII', 'DFI.Money', 'DFI.Money (YFII)']
# ['DODO', 'DODO', 'DODO']
# ['DOS', 'DOS Network', 'DOS Network']
# ['DSD', 'Dynamic Set Dollar', 'DSD']
# ['DAIQ', 'Daiquilibrium', 'Daiq']
# ['FIN', 'DeFiner', 'DeFiner']
# ['DEXE', 'DeXe', 'DeXe']
# ['DMG', 'DMM: Governance', 'DefiMoneyMarket']
# ['DEGO', 'Dego Finance', 'Dego']
# ['DDX', 'DerivaDAO', 'DerivaDEX']
# ['DEXTF', 'DEXTF Protocol', 'Dextf']
# ['YFIII', 'DiFy.Finance', 'DiFy']
# ['DRC', 'Dracula Token', 'Dracula']
# ['EPS', 'Ellipsis', 'Ellipsis']
# ['ESD', 'Empty Set Dollar', 'Empty Set Dollar']
# ['MLN', 'Enzyme', 'Enzyme']
# ['LIEN', 'Lien', 'FairSwap']
# ['FNX', 'FinNexus', 'FinNexus']
# ['BANK', 'Float Protocol', 'Float']
# ['FOR', 'ForTube', 'ForTube Bank']
# ['FOR', 'ForTube', 'ForTube Bank V1']
# ['FOR', 'ForTube', 'ForTube Bond']
# ['FRAX', 'Frax', 'Frax']
# ['COMBO', 'Furucombo', 'Furucombo']
# ['GYSR', 'GYSR', 'GYSR']
# ['GNO', 'Gnosis', 'Gnosis']
# ['GOF', 'Golff', 'Golff']
# ['EGG', 'Goose Finance', 'Goose Finance']
# ['GRO', 'Growth DeFi', 'GrowthDeFi']
# ['HAKKA', 'Hakka.Finance', 'HAKKA']
# ['FARM', 'Harvest', 'Harvest']
# ['HGET', 'Hedget', 'Hedget']
# ['HEGIC', 'Hegic', 'Hegic']
# ['HELMET', 'Helmet.insure', 'Helmet']
# ['IDLE', 'Idle', 'Idle']
# ['INDEX', 'Index Cooperative', 'Index Coop']
# ['INV', 'Inverse Finance', 'Inverse']
# ['JRT', 'Jarvis Network', 'Jarvis Network']
# ['JULD', 'JulSwap', 'JulSwap']
# ['KIMCHI', 'KIMCHI.finance', 'KIMCHI']
# ['KEEP', 'Keep Network', 'Keep']
# ['KP3R', 'Keep3rV1', 'Keep3r']
# ['ROOK', 'KeeperDAO', 'KeeperDAO']
# ['LDO', 'LIDO', 'LIDO']
# ['L2', 'Leverj Gluon', 'Leverj']
# ['LIEN', 'Lien', 'Lien']
# ['LINA', 'Linear', 'Linear']
# ['LRC', 'Loopring', 'Loopring']
# ['LRC', 'Loopring', 'Loopring V1']
# ['LUA', 'Lua Token', 'LuaSwap']
# ['MCB', 'MCDEX', 'MCDEX']
# ['MKR', 'Maker', 'Maker']
# ['MLN', 'Enzyme', 'Melon']
# ['MEME', 'Meme', 'Meme']
# ['MEE', 'Mercurity Swap Protocol', 'Mercurity']
# ['MM', 'MM Token', 'Mushrooms']
# ['N3RDz', 'N3RD Finance', 'N3rd']
# ['NRV', 'Nerve Finance', 'Nerve']
# ['NXM', 'NXM', 'Nexus Mutual']
# ['NSURE', 'Nsure.Network', 'Nsure Network']
# ['ONES', 'OneSwap DAO Token', 'OneSwap']
# ['OPEN', 'Open Governance Token', 'OpenDAO']
# ['OPT', 'Open Predict Token', 'OpenPredict']
# ['OPIUM', 'Opium', 'Opium']
# ['ORAI', 'Oraichain Token', 'Orai']
# ['ORN', 'Orion Protocol', 'Orion Protocol']
# ['PEAK', 'PEAKDEFI', 'PEAKDEFI']
# ['PERP', 'Perpetual', 'Perpetual']
# ['PICKLE', 'Pickle Finance', 'Pickle']
# ['PLOT', 'PlotX', 'PlotX']
# ['POOL', 'PoolTogether', 'PoolTogether']
# ['RAMP', 'RAMP', 'RAMP DEFI']
# ['EXRD', 'Radix', 'Radix']
# ['RFI', 'reflect.finance', 'Reflect']
# ['RAI', 'Rai Reflex Index', 'Reflexer']
# ['REN', 'Ren', 'Ren']
# ['ROOT', 'Rootkit Finance', 'Rootkit']
# ['SFG', 'S.Finance', 'S.Finance']
# ['STN', 'Stone DeFi', 'STONE']
# ['SWISS', 'swiss.finance', 'SWISS']
# ['SFI', 'saffron.finance', 'Saffron']
# ['SAKE', 'SakeToken', 'SakeSwap']
# ['SASHIMI', 'Sashimi', 'SashimiSwap']
# ['SI', 'Siren', 'Siren']
# ['SNOW', 'SnowSwap', 'SnowSwap']
# ['STBZ', 'Stabilize', 'Stabilize']
# ['SDT', 'Stake DAO', 'Stake DAO']
# ['aEth', 'ankrETH', 'Stkr']
# ['SWRV', 'Swerve', 'Swerve']
# ['SWINGBY', 'Swingby', 'Swingby']
# ['SWTH', 'Switcheo', 'Switcheo']
# ['SYN', 'SynLev', 'SynLev']
# ['SNX', 'Synthetix', 'Synthetix']
# ['TRB', 'Tellor', 'Tellor']
# ['MIS', 'Themis', 'Themis']
# ['TORN', 'Tornado Cash', 'Tornado']
# ['TRU', 'TrueFi', 'TrueFi']
# ['SWAP', 'TrustSwap', 'TrustSwap']
# ['PHOON', 'Typhoon Cash', 'TyphoonCash']
# ['UMA', 'UMA', 'UMA']
# ['YAM', 'YAM v3', 'Umbrella']
# ['POWER', 'UniPower', 'Unipower']
# ['UNI', 'Uniswap', 'Uniswap']
# ['UNI', 'Uniswap', 'Uniswap V1']
# ['USF', 'Unslashed Finance', 'Unslashed']
# ['VSP', 'Vesper', 'Vesper']
# ['WARP', 'Warp Finance', 'Warp']
# ['XDEX', 'xDeFi', 'XDEFI']
# ['XUSD', 'XUSD Stable', 'XUSD']
# ['YAM', 'YAM v3', 'YAM V1']
# ['YAM', 'YAM v3', 'YAM V3']
# ['YVS', 'YVS.Finance', 'YVS']
# ['YFI', 'Yearn', 'Yearn']
# ['YFI', 'Yearn', 'Yearn V2']
# ['YF-DAI', 'YFDAI.FINANCE', 'YfDAI']
# ['ZAI', 'Zero Collateral Dai', 'ZAI V1']
# ['BZRX', 'bZx', 'bZx']
# ['BZRX', 'bZx', 'bZx V1']
# ['DF', 'dForce', 'dForce Lending']
# ['DF', 'dForce', 'dForce Yield Markets']
# ['DHT', 'dHedge DAO', 'dHEDGE']
# ['DFT', 'dFuture', 'dfuture']
# ['ICHI', 'ICHI', 'ichi.farm']
# ['PBTC', 'pTokens BTC', 'pBTC']
# ['PBTC', 'pTokens BTC', 'pNetwork']
# ['TBTC', 'tBTC', 'tBTC']
# ['UNN', 'UNION Protocol Governance Token', 'unn']
# ['xBTC', 'xBTC', 'xBTC']
# ['wxDai', 'Wrapped XDAI', 'xDai']
# ['XTK', 'xToken', 'xToken']
# ['XVIX', 'XVIX', 'xvix']
# ['YAX', 'yAxis', 'yAxis']
# ['1INCH', '1inch', '1INCH Token']
# ['AAVE', 'Aave', 'Aave Token']
# ['ALPA', 'Alpaca City', 'AlpaToken']
# ['ALPHA', 'Alpha Finance Lab', 'AlphaToken']
# ['AMP', 'Amp', 'Amp']
# ['ANT', 'Aragon', 'Aragon Network Token']
# ['ANY', 'Anyswap', 'Anyswap']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'ANY-Anyswap-Anyswap' for key 'debank_symbols2.PRIMARY'")
#
# ['APY', 'APY.Finance', 'APY Governance Token']
# ['AST', 'AirSwap', 'AirSwap Token']
# ['AST', 'AntiscamToken', 'AirSwap Token']
# ['BAND', 'Band Protocol', 'BandToken']
# ['BAS', 'Basis Share', 'BAS']
# ['BASE', 'Base Protocol', 'Base Protocol']
# ['BCS', 'Basiscoin Share', 'BCS']
# ['BDP', 'BidiPass', 'BDPToken']
# ['BDP', 'Big Data Protocol', 'BDPToken']
# ['BNT', 'Bancor', 'Bancor Network Token']
# ['BOND', 'BarnBridge', 'BarnBridge Governance Token']
# ['BOND', 'Bonded Finance', 'BarnBridge Governance Token']
# ['BSDS', 'Basis Dollar Share', 'Basis Dollar Share']
# ['BZRX', 'bZx Protocol', 'bZx Protocol Token']
# ['CORE', 'cVault.finance', 'cVault.finance']
# ['COVER', 'COVER Protocol', 'Cover Protocol Governance Token']
# ['CRV', 'Curve DAO Token', 'Curve DAO Token']
# ['CVP', 'PowerPool', 'Concentrated Voting Power']
# ['DAIQ', 'Daiquilibrium', 'Daiquilibrium']
# ['DDIM', 'DuckDaoDime', 'DuckDaoDime']
# ['DDX', 'DerivaDAO', 'DerivaDAO']
# ['DEGO', 'Dego Finance', 'dego.finance']
# ['DEGOV', 'Degov', 'Degov']
# ['DEXTF', 'DEXTF Protocol', 'DEXTF Token']
# ['DF', 'dForce', 'dForce']
# ['DFD', 'DefiDollar DAO', 'DefiDollar DAO']
# ['DHT', 'dHedge DAO', 'dHedge DAO Token']
# ['DMG', 'DMM: Governance', 'DMM: Governance']
# ['DODO', 'DODO', 'DODO bird']
# ['DOKI', 'Doki Doki Finance', 'DokiDokiFinance']
# ['DOS', 'DEMOS', 'DOS Network Token']
# ['DOS', 'DOS Network', 'DOS Network Token']
# ['DOUGH', 'PieDAO DOUGH v2', 'PieDAO DOUGH v2']
# ['DRC', 'Digital Reserve Currency', 'Dracula Token']
# ['DRC', 'Dracula Token', 'Dracula Token']
# ['DRC', 'DRC mobility', 'Dracula Token']
# ['FARM', 'Harvest Finance', 'FARM Reward Token']
# ['FL', 'Freeliquid', 'FL']
# ['FOR', 'ForTube', 'The Force Token']
# ['FRM', 'Ferrum Network', 'Ferrum Network Token']
# ['FXS', 'Frax Share', 'Frax Share']
# ['GHST', 'Aavegotchi', 'Aavegotchi GHST Token']
# ['GNO', 'Gnosis', 'Gnosis Token']
# ['GOF', 'Golff', 'Golff.finance']
# ['GRO', 'Growth DeFi', 'Growth']
# ['GYSR', 'GYSR', 'Geyser']
# ['HAKKA', 'Hakka.Finance', 'Hakka Finance']
# ['HOT', 'Holo', 'Hydro Protocol Token']
# ['HOT', 'Hydro Protocol', 'Hydro Protocol Token']
# ['IDEX', 'IDEX', 'IDEX Token']
# ['INDEX', 'Index Cooperative', 'Index']
# ['KEEP', 'Keep Network', 'KEEP Token']
# ['KFC', 'Chicken', 'Chicken']
# ['KIMCHI', 'KIMCHI.finance', 'KIMCHI.finance']
# ['KNC', 'Kyber Network', 'Kyber Network Crystal']
# ['KP3R', 'Keep3rV1', 'Keep3rV1']
# ['L2', 'Leverj Gluon', 'Leverj Gluon']
# ['LDO', 'Lido DAO Token', 'Lido DAO Token']
# ['LIEN', 'Lien', 'lien']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'LIEN-Lien-lien' for key 'debank_symbols2.PRIMARY'")
#
# ['LINA', 'LINA', 'Linear Token']
# ['LINA', 'Linear', 'Linear Token']
# ['LINK', 'Chainlink', 'ChainLink Token']
# ['LRC', 'Loopring', 'LoopringCoin V2']
# ['LUA', 'Lua Token', 'LuaToken']
# ['MARK', 'Benchmark Protocol', 'Benchmark']
# ['Mars', 'Mars', 'MarsToken']
# ['MCB', 'MCDEX', 'MCDEX Token']
# ['MEME', 'Meme', 'MEME']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'MEME-Meme-MEME' for key 'debank_symbols2.PRIMARY'")
#
# ['MEME', 'Memetic / PepeCoin', 'MEME']
# ['MINI', 'MiniSwap', 'MINISWAP']
# ['MIR', 'MIR COIN', 'Wrapped MIR Token']
# ['MIR', 'Mirror Protocol', 'Wrapped MIR Token']
# ['MIS', 'Mithril Share', 'ThemisToken']
# ['MIS', 'Themis', 'ThemisToken']
# ['MLN', 'Enzyme', 'Melon Token']
# ['MM', 'MilliMeter', 'MMToken']
# ['MM', 'MM Token', 'MMToken']
# ['MPH', '88mph', '88mph.app']
# ['MPH', 'Morpher', '88mph.app']
# ['MTA', 'Meta', 'Meta']
# ['N3RDz', 'N3RD Finance', 'N3RD.FINANCE']
# ['NEC', 'Nectar', 'Ethfinex Nectar Token']
# ['NEST', 'NEST Protocol', 'NEST']
# ['ONS', 'One Share', 'ONS']
# ['OPEN', 'Open Governance Token', 'OPEN Governance Token']
# ['OPEN', 'Open Platform', 'OPEN Governance Token']
# ['OPIUM', 'Opium', 'Opium Governance Token']
# ['OPT', 'Open Predict Token', 'Open Predict Token']
# ['OPT', 'Opus', 'Open Predict Token']
# ['ORAI', 'Oraichain Token', 'Oraichain Token']
# ['PERL', 'Perlin', 'Perlin']
# ['PHOON', 'Typhoon Cash', 'Typhoon']
# ['PICKLE', 'Pickle Finance', 'PickleToken']
# ['PLOT', 'PlotX', 'PLOT']
# ['PNT', 'Penta', 'pNetwork Token']
# ['PNT', 'pNetwork', 'pNetwork Token']
# ['POWER', 'UniPower', 'UniPower']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'POWER-UniPower-UniPower' for key 'debank_symbols2.PRIMARY'")
#
# ['REN', 'Ren', 'Republic Token']
# ['RFI', 'reflect.finance', 'reflect.finance']
# ['RGT', 'Rari Governance Token', 'Rari Governance Token']
# ['ROOK', 'KeeperDAO', 'ROOK']
# ['ROOT', 'Rootkit Finance', 'RootKit']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'ROOT-Rootkit Finance-RootKit' for key 'debank_symbols2.PRIMARY'")
#
# ['RSR', 'Reserve Rights', 'Reserve Rights']
# ['SAKE', 'SakeToken', 'SakeToken']
# ['SASHIMI', 'Sashimi', 'SashimiToken']
# ['SDT', 'Stake DAO', 'Stake DAO Token']
# ['SDT', 'Terra SDT', 'Stake DAO Token']
# ['SFI', 'saffron.finance', 'Spice']
# ['SIG', 'xSigma', 'xSigma']
# ['SNX', 'Synthetix', 'Synthetix Network Token']
# ['STBZ', 'Stabilize', 'Stabilize Token']
# ['SUSHI', 'SushiSwap', 'SushiToken']
# ['SWAP', 'TrustSwap', 'TrustSwap Token']
# ['SWISS', 'swiss.finance', 'Swiss Token']
# ['SWRV', 'Swerve', 'Swerve DAO Token']
# ['TORN', 'Tornado Cash', 'TornadoCash']
# ['TRU', 'TrueFi', 'TrustToken']
# ['UMA', 'UMA', 'UMA Voting Token v1']
# ['UNCX', 'UniCrypt', 'UniCrypt']
# ['UNN', 'UNION Protocol Governance Token', 'UNION Protocol Governance Token']
# ['VALUE', 'Value Liquidity', 'Value Liquidity']
# ['XVIX', 'XVIX', 'XVIX']
# Traceback (most recent call last):
#   File "<ipython-input-110-3675578a49a3>", line 8, in insert_debank_coin_cmc_symbol
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 148, in execute
#     result = self._query(query)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/cursors.py", line 310, in _query
#     conn.query(q)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 548, in query
#     self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 775, in _read_query_result
#     result.read()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 1156, in read
#     first_packet = self.connection._read_packet()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "/Users/aarush/project/cripto_backtest/.venv/lib/python3.9/site-packages/pymysql/err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.IntegrityError: (1062, "Duplicate entry 'XVIX-XVIX-XVIX' for key 'debank_symbols2.PRIMARY'")
#
# ['YAM', 'YAM v1', 'YAM']
# ['YAM', 'YAM v3', 'YAM']
# ['Yf-DAI', 'YFDAI.FINANCE', 'YfDAI.finance']
# ['YFI', 'yearn.finance', 'yearn.finance']
# ['YFII', 'DFI.Money', 'YFII.finance']
# ['YFIII', 'DiFy.Finance', 'DiFy.Finance']
# ['YFIII', 'YFIII', 'DiFy.Finance']
# ['YVS', 'YVS.Finance', 'YVS.Finance']
# ['ZAI', 'Zero Collateral Dai', 'Zero Collateral Dai']
# ['ZKS', 'ZKSwap', 'Zks']
# ['ZRX', '0x', '0x Protocol Token']

# %%
df2[df2['symbol'] == 'ZRX']
# Out:
#         name_in_debank name_in_cmc symbol
# 0                   0x          0x    ZRX
# 248  0x Protocol Token          0x    ZRX
