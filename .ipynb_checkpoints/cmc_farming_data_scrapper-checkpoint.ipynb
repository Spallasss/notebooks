# %%
from lxml import html
import requests
import json
import pandas as pd

# %%
stable_coins = "USDT, USDC, DAI, BUSD, SUSD, UST, TUSD".split(",")
stable_coins
# Out:
# ['USDT', 'USDC', 'DAI', 'BUSD', 'SUSD', 'UST', 'TUSD']

# %%
url = "https://coinmarketcap.com/yield-farming/"
page = requests.get(url)
tree = html.fromstring(page.content)

# %%
data = tree.xpath('//script[@id="__NEXT_DATA__"]/text()')

# %%
json_obj = json.loads(data[0])['props']['initialProps']['pageProps']
farming_list = json_obj['yieldFarmingList']

# %%
farming_list
# Out:
# [{'id': '5fcf5b00c5adb439ad44e3d3',
#   'name': 'Venus',
#   'platform': 'Binance Smart Chain',
#   'webSite': 'https://venus.io/',
#   'totalValueLocked': 8244634935.67,
#   'poolList': [{'id': 196,
#     'name': 'vBTC-BTCB Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vBTC-BTCB',
#     'totalStake': 2299680246.57,
#     'totalStakeRatio': 0.27893051,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00846575342466,
#     'weeklyROI': 0.05926027397262,
#     'monthlyROI': 0.2575,
#     'yearlyROI': 3.09,
#     'updateTime': '2021-04-29T09:31:26.000Z'},
#    {'id': 194,
#     'name': 'vETH-ETH Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vETH-ETH',
#     'totalStake': 1637433472.87,
#     'totalStakeRatio': 0.19860594,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.0061095890411,
#     'weeklyROI': 0.0427671232877,
#     'monthlyROI': 0.18583333333333,
#     'yearlyROI': 2.23,
#     'updateTime': '2021-04-29T09:31:26.000Z'},
#    {'id': 197,
#     'name': 'vBNB-BNB Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vBNB-BNB',
#     'totalStake': 1582313625.1,
#     'totalStakeRatio': 0.1919204,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.01723287671233,
#     'weeklyROI': 0.12063013698631,
#     'monthlyROI': 0.52416666666667,
#     'yearlyROI': 6.29,
#     'updateTime': '2021-04-29T09:31:26.000Z'},
#    {'id': 200,
#     'name': 'vUSDT-USDT Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vUSDT-USDT',
#     'totalStake': 541625580.22,
#     'totalStakeRatio': 0.06569431,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.02109589041096,
#     'weeklyROI': 0.14767123287672,
#     'monthlyROI': 0.64166666666667,
#     'yearlyROI': 7.7,
#     'updateTime': '2021-04-29T09:31:27.000Z'},
#    {'id': 193,
#     'name': 'vXVS-XVS Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vXVS-XVS',
#     'totalStake': 529349123.29,
#     'totalStakeRatio': 0.06420528,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.02635616438356,
#     'weeklyROI': 0.18449315068492,
#     'monthlyROI': 0.80166666666667,
#     'yearlyROI': 9.62,
#     'updateTime': '2021-04-29T09:31:25.000Z'},
#    {'id': 195,
#     'name': 'vBUSD-BUSD Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vBUSD-BUSD',
#     'totalStake': 457933516.54,
#     'totalStakeRatio': 0.05554321,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.02978082191781,
#     'weeklyROI': 0.20846575342467,
#     'monthlyROI': 0.90583333333333,
#     'yearlyROI': 10.87,
#     'updateTime': '2021-04-29T09:31:26.000Z'},
#    {'id': 202,
#     'name': 'vSXP-SXP Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vSXP-SXP',
#     'totalStake': 369193581.72,
#     'totalStakeRatio': 0.04477986,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.01712328767123,
#     'weeklyROI': 0.11986301369861,
#     'monthlyROI': 0.52083333333333,
#     'yearlyROI': 6.25,
#     'updateTime': '2021-04-29T09:31:28.000Z'},
#    {'id': 206,
#     'name': 'VAI Mint',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'VAI',
#     'totalStake': 205690780.48,
#     'totalStakeRatio': 0.02494844,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.29901369863014,
#     'weeklyROI': 2.09309589041098,
#     'monthlyROI': 9.095,
#     'yearlyROI': 109.14,
#     'updateTime': '2021-04-29T09:31:29.000Z'},
#    {'id': 201,
#     'name': 'vUSDC-USDC Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vUSDC-USDC',
#     'totalStake': 196040931.36,
#     'totalStakeRatio': 0.023778,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.04706849315068,
#     'weeklyROI': 0.32947945205476,
#     'monthlyROI': 1.43166666666667,
#     'yearlyROI': 17.18,
#     'updateTime': '2021-04-29T09:31:27.000Z'},
#    {'id': 198,
#     'name': 'vXRP-XRP Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vXRP-XRP',
#     'totalStake': 132888394.41,
#     'totalStakeRatio': 0.01611817,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00380821917808,
#     'weeklyROI': 0.02665753424656,
#     'monthlyROI': 0.11583333333333,
#     'yearlyROI': 1.39,
#     'updateTime': '2021-04-29T09:31:27.000Z'},
#    {'id': 205,
#     'name': 'vLINK-LINK Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vLINK-LINK',
#     'totalStake': 111560651.64,
#     'totalStakeRatio': 0.0135313,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'},
#      {'cryptoId': 1975,
#       'name': 'Chainlink',
#       'symbol': 'LINK',
#       'slug': 'chainlink'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00457534246575,
#     'weeklyROI': 0.03202739726025,
#     'monthlyROI': 0.13916666666667,
#     'yearlyROI': 1.67,
#     'updateTime': '2021-04-29T09:31:29.000Z'},
#    {'id': 204,
#     'name': 'vDOT-DOT Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vDOT-DOT',
#     'totalStake': 77900320.62,
#     'totalStakeRatio': 0.00944861,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'},
#      {'cryptoId': 6636,
#       'name': 'Polkadot',
#       'symbol': 'DOT',
#       'slug': 'polkadot-new'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00972602739726,
#     'weeklyROI': 0.06808219178082,
#     'monthlyROI': 0.29583333333333,
#     'yearlyROI': 3.55,
#     'updateTime': '2021-04-29T09:31:28.000Z'},
#    {'id': 199,
#     'name': 'vLTC-LTC Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vLTC-LTC',
#     'totalStake': 63540571.41,
#     'totalStakeRatio': 0.0077069,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00786301369863,
#     'weeklyROI': 0.05504109589041,
#     'monthlyROI': 0.23916666666667,
#     'yearlyROI': 2.87,
#     'updateTime': '2021-04-29T09:31:27.000Z'},
#    {'id': 203,
#     'name': 'vBCH-BCH Lending',
#     'link': 'https://app.venus.io/dashboard',
#     'pair': 'vBCH-BCH',
#     'totalStake': 39484139.44,
#     'totalStakeRatio': 0.00478907,
#     'rewards': [{'cryptoId': 7288,
#       'name': 'Venus',
#       'symbol': 'XVS',
#       'slug': 'venus'},
#      {'cryptoId': 1831,
#       'name': 'Bitcoin Cash',
#       'symbol': 'BCH',
#       'slug': 'bitcoin-cash'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00224657534247,
#     'weeklyROI': 0.01572602739729,
#     'monthlyROI': 0.06833333333333,
#     'yearlyROI': 0.82,
#     'updateTime': '2021-04-29T09:31:28.000Z'}],
#   'auditList': [{'url': 'https://certik.foundation/projects/swipe',
#     'auditFirm': 'Certik'}],
#   'hasNew': True},
#  {'id': '5f86b154cc06881662044a5a',
#   'name': 'PancakeSwap',
#   'platform': 'Binance Smart Chain',
#   'webSite': 'https://pancakeswap.finance/',
#   'totalValueLocked': 5192515093.088451,
#   'poolList': [{'id': 126,
#     'name': 'CAKE',
#     'link': 'https://pancakeswap.finance/staking',
#     'pair': 'CAKE',
#     'totalStake': 5064157278.444463,
#     'totalStakeRatio': 0.97528022,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.2361898630137,
#     'weeklyROI': 1.6533290410959,
#     'monthlyROI': 7.18410833333333,
#     'yearlyROI': 86.2093,
#     'updateTime': '2021-04-29T09:31:05.000Z'},
#    {'id': 128,
#     'name': 'PancakeSWAP BUSD-BNB',
#     'link': 'https://pancakeswap.finance/farms/BUSD-BNB%20FLIP',
#     'pair': 'BUSD-WBNB',
#     'totalStake': 40090525.4532061,
#     'totalStakeRatio': 0.00772083,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 4.74046630136986,
#     'weeklyROI': 33.18326410958902,
#     'monthlyROI': 144.18918333333332,
#     'yearlyROI': 1730.2702,
#     'updateTime': '2021-04-29T09:31:05.000Z'},
#    {'id': 127,
#     'name': 'PancakeSWAP CAKE-BNB',
#     'link': 'https://pancakeswap.finance/farms/CAKE-BNB%20FLIP',
#     'pair': 'CAKE-WBNB',
#     'totalStake': 28191954.96494473,
#     'totalStakeRatio': 0.00542934,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 25.27952356164384,
#     'weeklyROI': 176.95666493150688,
#     'monthlyROI': 768.9188416666667,
#     'yearlyROI': 9227.0261,
#     'updateTime': '2021-04-29T09:31:05.000Z'},
#    {'id': 170,
#     'name': 'PancakeSWAP ETH-BNB',
#     'link': 'https://pancakeswap.finance/farms/ETH-BNB%20FLP',
#     'pair': 'ETH-BNB',
#     'totalStake': 15254501.05682646,
#     'totalStakeRatio': 0.00293779,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 3.11461808219178,
#     'weeklyROI': 21.80232657534246,
#     'monthlyROI': 94.7363,
#     'yearlyROI': 1136.8356,
#     'updateTime': '2021-04-29T09:31:18.000Z'},
#    {'id': 168,
#     'name': 'PancakeSWAP USDT-BUSD',
#     'link': 'https://pancakeswap.finance/farms/USDT-BUSD%20FLIP',
#     'pair': 'USDT-BUSD',
#     'totalStake': 12964481.586011996,
#     'totalStakeRatio': 0.00249676,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 1.83238904109589,
#     'weeklyROI': 12.82672328767123,
#     'monthlyROI': 55.73516666666667,
#     'yearlyROI': 668.822,
#     'updateTime': '2021-04-29T09:31:17.000Z'},
#    {'id': 171,
#     'name': 'PancakeSWAP BTC-BNB',
#     'link': 'https://pancakeswap.finance/farms/BTCB-BNB%20FLP',
#     'pair': 'BTC-BNB',
#     'totalStake': 12572746.928955115,
#     'totalStakeRatio': 0.00242132,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 3.77896301369863,
#     'weeklyROI': 26.45274109589041,
#     'monthlyROI': 114.94345833333333,
#     'yearlyROI': 1379.3215,
#     'updateTime': '2021-04-29T09:31:18.000Z'},
#    {'id': 131,
#     'name': 'PancakeSWAP DOT-BNB',
#     'link': 'https://pancakeswap.finance/farms/DOT-BNB%20FLIP',
#     'pair': 'DOT-WBNB',
#     'totalStake': 8551632.798232889,
#     'totalStakeRatio': 0.00164692,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 5.55589178082192,
#     'weeklyROI': 38.89124246575344,
#     'monthlyROI': 168.99170833333332,
#     'yearlyROI': 2027.9005,
#     'updateTime': '2021-04-29T09:31:06.000Z'},
#    {'id': 129,
#     'name': 'PancakeSWAP ADA-BNB',
#     'link': 'https://pancakeswap.finance/farms/ADA-BNB%20FLIP',
#     'pair': 'ADA-WBNB',
#     'totalStake': 2827958.779740503,
#     'totalStakeRatio': 0.00054462,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 8.40039561643836,
#     'weeklyROI': 58.80276931506852,
#     'monthlyROI': 255.51203333333333,
#     'yearlyROI': 3066.1444,
#     'updateTime': '2021-04-29T09:31:05.000Z'},
#    {'id': 173,
#     'name': 'PancakeSWAP USDT-BNB',
#     'link': 'https://pancakeswap.finance/farms/USDT-BNB%20FLP',
#     'pair': 'USDT-BNB',
#     'totalStake': 2615753.115131901,
#     'totalStakeRatio': 0.00050375,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 18.16377287671233,
#     'weeklyROI': 127.1464101369863,
#     'monthlyROI': 552.481425,
#     'yearlyROI': 6629.7771,
#     'updateTime': '2021-04-29T09:31:18.000Z'},
#    {'id': 169,
#     'name': 'PancakeSWAP TWT-BNB',
#     'link': 'https://pancakeswap.finance/farms/TWT-BNB%20FLP',
#     'pair': 'TWT-BNB',
#     'totalStake': 1961499.0650279375,
#     'totalStakeRatio': 0.00037776,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 24.22226273972603,
#     'weeklyROI': 169.5558391780822,
#     'monthlyROI': 736.7604916666667,
#     'yearlyROI': 8841.1259,
#     'updateTime': '2021-04-29T09:31:17.000Z'},
#    {'id': 133,
#     'name': 'PancakeSWAP LINK-BNB',
#     'link': 'https://pancakeswap.finance/farms/LINK-BNB%20FLIP',
#     'pair': 'LINK-WBNB',
#     'totalStake': 1571880.1895434228,
#     'totalStakeRatio': 0.00030272,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 30.22618767123288,
#     'weeklyROI': 211.58331369863015,
#     'monthlyROI': 919.379875,
#     'yearlyROI': 11032.5585,
#     'updateTime': '2021-04-29T09:31:06.000Z'},
#    {'id': 130,
#     'name': 'PancakeSWAP BAND-BNB',
#     'link': 'https://pancakeswap.finance/farms/BAND-BNB%20FLIP',
#     'pair': 'BAND-WBNB',
#     'totalStake': 588105.826271808,
#     'totalStakeRatio': 0.00011326,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 80.78808876712328,
#     'weeklyROI': 565.5166213698631,
#     'monthlyROI': 2457.3043666666667,
#     'yearlyROI': 29487.6524,
#     'updateTime': '2021-04-29T09:31:06.000Z'},
#    {'id': 174,
#     'name': 'PancakeSWAP XRP-BNB',
#     'link': 'https://pancakeswap.finance/farms/XRP-BNB%20FLP',
#     'pair': 'XRP-BNB',
#     'totalStake': 300389.33834103646,
#     'totalStakeRatio': 5.785e-05,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 79.08394164383562,
#     'weeklyROI': 553.5875915068493,
#     'monthlyROI': 2405.4698916666666,
#     'yearlyROI': 28865.6387,
#     'updateTime': '2021-04-29T09:31:19.000Z'},
#    {'id': 172,
#     'name': 'PancakeSWAP ALPHA-BNB',
#     'link': 'https://pancakeswap.finance/farms/ALPHA-BNB%20FLP',
#     'pair': 'ALPHA-BNB',
#     'totalStake': 298454.8315944105,
#     'totalStakeRatio': 5.748e-05,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 79.59654301369864,
#     'weeklyROI': 557.1758010958904,
#     'monthlyROI': 2421.0615166666666,
#     'yearlyROI': 29052.7382,
#     'updateTime': '2021-04-29T09:31:18.000Z'},
#    {'id': 175,
#     'name': 'PancakeSWAP ATOM-BNB',
#     'link': 'https://pancakeswap.finance/farms/ATOM-BNB%20FLP',
#     'pair': 'ATOM-BNB',
#     'totalStake': 260082.4372669074,
#     'totalStakeRatio': 5.009e-05,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 91.34016547945205,
#     'weeklyROI': 639.3811583561644,
#     'monthlyROI': 2778.2633666666666,
#     'yearlyROI': 33339.1604,
#     'updateTime': '2021-04-29T09:31:19.000Z'},
#    {'id': 177,
#     'name': 'PancakeSWAP DAI-BNB',
#     'link': 'https://pancakeswap.finance/farms/DAI-BNB%20FLP',
#     'pair': 'DAI-BNB',
#     'totalStake': 104845.45907752967,
#     'totalStakeRatio': 2.019e-05,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 226.58084657534246,
#     'weeklyROI': 1586.0659260273974,
#     'monthlyROI': 6891.834083333333,
#     'yearlyROI': 82702.009,
#     'updateTime': '2021-04-29T09:31:20.000Z'},
#    {'id': 132,
#     'name': 'PancakeSWAP EOS-BNB',
#     'link': 'https://pancakeswap.finance/farms/EOS-BNB%20FLIP',
#     'pair': 'EOS-WBNB',
#     'totalStake': 85941.82438226299,
#     'totalStakeRatio': 1.655e-05,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 276.4192295890411,
#     'weeklyROI': 1934.9346071232876,
#     'monthlyROI': 8407.751566666666,
#     'yearlyROI': 100893.0188,
#     'updateTime': '2021-04-29T09:31:06.000Z'},
#    {'id': 178,
#     'name': 'PancakeSWAP XTZ-BNB',
#     'link': 'https://pancakeswap.finance/farms/XTZ-BNB%20FLP',
#     'pair': 'XTZ-BNB',
#     'totalStake': 83791.71722524207,
#     'totalStakeRatio': 1.614e-05,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 283.51218547945206,
#     'weeklyROI': 1984.5852983561645,
#     'monthlyROI': 8623.495641666666,
#     'yearlyROI': 103481.9477,
#     'updateTime': '2021-04-29T09:31:20.000Z'},
#    {'id': 179,
#     'name': 'PancakeSWAP BCH-BNB',
#     'link': 'https://pancakeswap.finance/farms/BCH-BNB%20FLP',
#     'pair': 'BCH-BNB',
#     'totalStake': 19284.696212083774,
#     'totalStakeRatio': 3.71e-06,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 1231.8562147945206,
#     'weeklyROI': 8622.993503561644,
#     'monthlyROI': 37468.959866666664,
#     'yearlyROI': 449627.5184,
#     'updateTime': '2021-04-29T09:31:20.000Z'},
#    {'id': 176,
#     'name': 'PancakeSWAP YFII-BNB',
#     'link': 'https://pancakeswap.finance/farms/YFII-BNB%20FLP',
#     'pair': 'YFII-BNB',
#     'totalStake': 13984.57599641017,
#     'totalStakeRatio': 2.69e-06,
#     'rewards': [{'cryptoId': 7186,
#       'name': 'PancakeSwap',
#       'symbol': 'CAKE',
#       'slug': 'pancakeswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 1698.7267175342465,
#     'weeklyROI': 11891.087022739726,
#     'monthlyROI': 51669.604325,
#     'yearlyROI': 620035.2519,
#     'updateTime': '2021-04-29T09:31:19.000Z'}],
#   'auditList': [{'url': 'https://github.com/certikfoundation-shared/CertiK-Audits/blob/master/reports/REP-PancakeSwap-16_10_2020.pdf',
#     'auditFirm': 'CertiK'}],
#   'hasNew': False},
#  {'id': '5f5b5b9cb761c05513d8356f',
#   'name': 'Sushi',
#   'platform': 'Ethereum',
#   'webSite': 'https://sushiswap.org/',
#   'totalValueLocked': 2043756305.5284464,
#   'poolList': [{'id': 52,
#     'name': 'Sushi Party!',
#     'link': 'https://sushiswapclassic.org/farms/SUSHI-ETH%20SLP',
#     'pair': 'SUSHI-ETH',
#     'totalStake': 625392866.1311141,
#     'totalStakeRatio': 0.30600168,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.08614273972603,
#     'weeklyROI': 0.60299917808221,
#     'monthlyROI': 2.620175,
#     'yearlyROI': 31.4421,
#     'updateTime': '2021-04-29T09:30:38.000Z'},
#    {'id': 58,
#     'name': 'Circle Snail',
#     'link': 'https://sushiswapclassic.org/farms/USDC-ETH%20SLP',
#     'pair': 'USDC-ETH',
#     'totalStake': 352221274.09740114,
#     'totalStakeRatio': 0.17234015,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.09148465753425,
#     'weeklyROI': 0.64039260273975,
#     'monthlyROI': 2.78265833333333,
#     'yearlyROI': 33.3919,
#     'updateTime': '2021-04-29T09:30:40.000Z'},
#    {'id': 57,
#     'name': 'Donald DAI',
#     'link': 'https://sushiswapclassic.org/farms/DAI-ETH%20SLP',
#     'pair': 'DAI-ETH',
#     'totalStake': 318025173.7724368,
#     'totalStakeRatio': 0.15560817,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.10636849315068,
#     'weeklyROI': 0.74457945205476,
#     'monthlyROI': 3.235375,
#     'yearlyROI': 38.8245,
#     'updateTime': '2021-04-29T09:30:40.000Z'},
#    {'id': 55,
#     'name': 'Tether Turtle',
#     'link': 'https://sushiswapclassic.org/farms/USDT-ETH%20SLP',
#     'pair': 'USDT-ETH',
#     'totalStake': 277607441.9381259,
#     'totalStakeRatio': 0.13583197,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.10208493150685,
#     'weeklyROI': 0.71459452054795,
#     'monthlyROI': 3.10508333333333,
#     'yearlyROI': 37.261,
#     'updateTime': '2021-04-29T09:30:39.000Z'},
#    {'id': 54,
#     'name': 'YFI Whale',
#     'link': 'https://sushiswapclassic.org/farms/YFI-ETH%20SLP',
#     'pair': 'YFI-ETH',
#     'totalStake': 173766660.96597272,
#     'totalStakeRatio': 0.08502318,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.13047150684932,
#     'weeklyROI': 0.91330054794524,
#     'monthlyROI': 3.96850833333333,
#     'yearlyROI': 47.6221,
#     'updateTime': '2021-04-29T09:30:39.000Z'},
#    {'id': 59,
#     'name': 'Toadie Marine',
#     'link': 'https://sushiswapclassic.org/farms/LINK-ETH%20SLP',
#     'pair': 'LINK-ETH',
#     'totalStake': 119803080.31143084,
#     'totalStakeRatio': 0.05861906,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.08637616438356,
#     'weeklyROI': 0.60463315068492,
#     'monthlyROI': 2.627275,
#     'yearlyROI': 31.5273,
#     'updateTime': '2021-04-29T09:30:40.000Z'},
#    {'id': 51,
#     'name': 'Synthetic Snake',
#     'link': 'https://sushiswapclassic.org/farms/SNX-ETH%20SLP',
#     'pair': 'SNX-ETH',
#     'totalStake': 62577353.1528561,
#     'totalStakeRatio': 0.03061879,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.09469945205479,
#     'weeklyROI': 0.66289616438353,
#     'monthlyROI': 2.88044166666667,
#     'yearlyROI': 34.5653,
#     'updateTime': '2021-04-29T09:30:38.000Z'},
#    {'id': 61,
#     'name': 'Spartan Dollar',
#     'link': 'https://sushiswapclassic.org/farms/SUSD-ETH%20SLP',
#     'pair': 'SUSD-ETH',
#     'totalStake': 26932432.59886989,
#     'totalStakeRatio': 0.01317791,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.11376739726027,
#     'weeklyROI': 0.79637178082189,
#     'monthlyROI': 3.460425,
#     'yearlyROI': 41.5251,
#     'updateTime': '2021-04-29T09:30:41.000Z'},
#    {'id': 60,
#     'name': 'Compound Truffle',
#     'link': 'https://sushiswapclassic.org/farms/COMP-ETH%20SLP',
#     'pair': 'COMP-ETH',
#     'totalStake': 24931025.006551124,
#     'totalStakeRatio': 0.01219863,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.06707753424658,
#     'weeklyROI': 0.46954273972606,
#     'monthlyROI': 2.040275,
#     'yearlyROI': 24.4833,
#     'updateTime': '2021-04-29T09:30:40.000Z'},
#    {'id': 65,
#     'name': 'CRV Crocodile',
#     'link': 'https://sushiswapclassic.org/farms/CRV-ETH%20SLP',
#     'pair': 'CRV-ETH',
#     'totalStake': 20212869.11113016,
#     'totalStakeRatio': 0.00989006,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.05552684931507,
#     'weeklyROI': 0.38868794520549,
#     'monthlyROI': 1.68894166666667,
#     'yearlyROI': 20.2673,
#     'updateTime': '2021-04-29T09:30:42.000Z'},
#    {'id': 50,
#     'name': 'Band-osaurus',
#     'link': 'https://sushiswapclassic.org/farms/BAND-ETH%20SLP',
#     'pair': 'BAND-ETH',
#     'totalStake': 15313972.217636935,
#     'totalStakeRatio': 0.00749305,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.10407150684932,
#     'weeklyROI': 0.72850054794524,
#     'monthlyROI': 3.16550833333333,
#     'yearlyROI': 37.9861,
#     'updateTime': '2021-04-29T09:30:38.000Z'},
#    {'id': 49,
#     'name': 'Umami Squid',
#     'link': 'https://sushiswapclassic.org/farms/UMA-ETH%20SLP',
#     'pair': 'UMA-ETH',
#     'totalStake': 14566366.379109293,
#     'totalStakeRatio': 0.00712725,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.07705123287671,
#     'weeklyROI': 0.53935863013697,
#     'monthlyROI': 2.34364166666667,
#     'yearlyROI': 28.1237,
#     'updateTime': '2021-04-29T09:30:37.000Z'},
#    {'id': 64,
#     'name': 'REN Rhino',
#     'link': 'https://sushiswapclassic.org/farms/REN-ETH%20SLP',
#     'pair': 'ren-ETH',
#     'totalStake': 12405789.845811544,
#     'totalStakeRatio': 0.00607009,
#     'rewards': [{'cryptoId': 6758,
#       'name': 'SushiSwap',
#       'symbol': 'SUSHI',
#       'slug': 'sushiswap'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.0904704109589,
#     'weeklyROI': 0.6332928767123,
#     'monthlyROI': 2.75180833333333,
#     'yearlyROI': 33.0217,
#     'updateTime': '2021-04-29T09:30:42.000Z'}],
#   'auditList': [{'url': 'https://github.com/quantstamp/sushiswap-security-review',
#     'auditFirm': 'Quantstamp'},
#    {'url': 'https://github.com/peckshield/publications/blob/master/audit_reports/PeckShield-Audit-Report-SushiSwap-v1.0.pdf',
#     'auditFirm': 'Peckshield'}],
#   'hasNew': False},
#  {'id': '5f5b5b9cb761c05513d8356d',
#   'name': 'Curve',
#   'platform': 'Ethereum',
#   'webSite': 'https://www.curve.fi/',
#   'totalValueLocked': 1854776987.4432564,
#   'poolList': [{'id': 39,
#     'name': 'renBTC',
#     'link': 'https://www.curve.fi/ren',
#     'pair': 'renBTC-wBTC',
#     'totalStake': 517522019.25426126,
#     'totalStakeRatio': 0.27902116,
#     'rewards': [{'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.00483287671233,
#     'weeklyROI': 0.03383013698631,
#     'monthlyROI': 0.147,
#     'yearlyROI': 1.764,
#     'updateTime': '2021-04-15T10:00:46.000Z'},
#    {'id': 41,
#     'name': 'hBTC',
#     'link': 'https://www.curve.fi/hbtc',
#     'pair': 'hBTC-wBTC',
#     'totalStake': 480045188.0476562,
#     'totalStakeRatio': 0.25881558,
#     'rewards': [{'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.01870383561644,
#     'weeklyROI': 0.13092684931508,
#     'monthlyROI': 0.56890833333333,
#     'yearlyROI': 6.8269,
#     'updateTime': '2021-04-15T10:00:46.000Z'},
#    {'id': 40,
#     'name': 'sBTC',
#     'link': 'https://www.curve.fi/sbtc',
#     'pair': 'renBTC-wBTC-sBTC',
#     'totalStake': 425205110.03057575,
#     'totalStakeRatio': 0.22924864,
#     'rewards': [{'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.00577726027397,
#     'weeklyROI': 0.04044082191779,
#     'monthlyROI': 0.175725,
#     'yearlyROI': 2.1087,
#     'updateTime': '2021-04-15T10:00:46.000Z'},
#    {'id': 38,
#     'name': 'sUSD',
#     'link': 'https://www.curve.fi/susdv2',
#     'pair': 'DAI-USDC-USDT-sUSD',
#     'totalStake': 199434597.04514995,
#     'totalStakeRatio': 0.10752484,
#     'rewards': [{'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.04020493150685,
#     'weeklyROI': 0.28143452054795,
#     'monthlyROI': 1.2229,
#     'yearlyROI': 14.6748,
#     'updateTime': '2021-04-15T10:00:45.000Z'},
#    {'id': 34,
#     'name': 'Compound',
#     'link': 'https://www.curve.fi/compound',
#     'pair': 'DAI-USDC',
#     'totalStake': 142911560.83606184,
#     'totalStakeRatio': 0.07705054,
#     'rewards': [{'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.03104602739726,
#     'weeklyROI': 0.21732219178082,
#     'monthlyROI': 0.94431666666667,
#     'yearlyROI': 11.3318,
#     'updateTime': '2021-04-15T10:00:44.000Z'},
#    {'id': 37,
#     'name': 'bUSD',
#     'link': 'https://www.curve.fi/busd',
#     'pair': 'DAI-USDC-USDT-BUSD',
#     'totalStake': 89658512.22955135,
#     'totalStakeRatio': 0.04833924,
#     'rewards': [{'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.01985287671233,
#     'weeklyROI': 0.13897013698631,
#     'monthlyROI': 0.60385833333333,
#     'yearlyROI': 7.2463,
#     'updateTime': '2021-04-15T10:00:45.000Z'}],
#   'auditList': [{'url': 'https://www.curve.fi/curve_audits/00-ToB.pdf',
#     'auditFirm': 'Trail of Bits'},
#    {'url': 'https://www.curve.fi/curve_audits/curve-dao-quantstamp.pdf',
#     'auditFirm': 'Quantstamp'}],
#   'hasNew': False},
#  {'id': '5f685b38fcdfe7080cdd0fbb',
#   'name': 'BakerySwap',
#   'platform': 'Binance Smart Chain',
#   'webSite': 'https://www.bakeryswap.org/',
#   'totalValueLocked': 425774746.64,
#   'poolList': [{'id': 103,
#     'name': 'Bread',
#     'link': 'https://www.bakeryswap.org/#/bakery/BAKE',
#     'pair': 'BAKE',
#     'totalStake': 286929760.31,
#     'totalStakeRatio': 0.67390037,
#     'rewards': [{'cryptoId': 7064,
#       'name': 'BakeryToken',
#       'symbol': 'BAKE',
#       'slug': 'bakerytoken'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.03265753424658,
#     'weeklyROI': 0.22860273972606,
#     'monthlyROI': 0.99333333333333,
#     'yearlyROI': 11.92,
#     'updateTime': '2021-04-29T09:31:15.000Z'},
#    {'id': 104,
#     'name': 'Doughnut',
#     'link': 'https://www.bakeryswap.org/#/bakery/BAKE-BNB%20BLP',
#     'pair': 'BAKE-BNB',
#     'totalStake': 72870082.43,
#     'totalStakeRatio': 0.17114703,
#     'rewards': [{'cryptoId': 7064,
#       'name': 'BakeryToken',
#       'symbol': 'BAKE',
#       'slug': 'bakerytoken'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.18364383561644,
#     'weeklyROI': 1.28550684931508,
#     'monthlyROI': 5.58583333333333,
#     'yearlyROI': 67.03,
#     'updateTime': '2021-04-29T09:31:14.000Z'},
#    {'id': 109,
#     'name': 'Cake',
#     'link': 'https://www.bakeryswap.org/#/bakery/BTC-BNB%20BLP',
#     'pair': 'BTC-BNB',
#     'totalStake': 52678797.03,
#     'totalStakeRatio': 0.12372457,
#     'rewards': [{'cryptoId': 7064,
#       'name': 'BakeryToken',
#       'symbol': 'BAKE',
#       'slug': 'bakerytoken'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.29638356164384,
#     'weeklyROI': 2.07468493150688,
#     'monthlyROI': 9.015,
#     'yearlyROI': 108.18,
#     'updateTime': '2021-04-29T09:31:15.000Z'},
#    {'id': 105,
#     'name': 'Waffle',
#     'link': 'https://www.bakeryswap.org/#/bakery/BAKE-BUSD%20BLP',
#     'pair': 'BAKE-BUSD',
#     'totalStake': 7412055.63,
#     'totalStakeRatio': 0.0174084,
#     'rewards': [{'cryptoId': 7064,
#       'name': 'BakeryToken',
#       'symbol': 'BAKE',
#       'slug': 'bakerytoken'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.48147945205479,
#     'weeklyROI': 3.37035616438353,
#     'monthlyROI': 14.645,
#     'yearlyROI': 175.74,
#     'updateTime': '2021-04-29T09:31:15.000Z'},
#    {'id': 107,
#     'name': 'Croissant',
#     'link': 'https://www.bakeryswap.org/#/bakery/BUSD-BNB%20BLP',
#     'pair': 'BUSD-BNB',
#     'totalStake': 4000602.7,
#     'totalStakeRatio': 0.00939605,
#     'rewards': [{'cryptoId': 7064,
#       'name': 'BakeryToken',
#       'symbol': 'BAKE',
#       'slug': 'bakerytoken'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.33452054794521,
#     'weeklyROI': 2.34164383561647,
#     'monthlyROI': 10.175,
#     'yearlyROI': 122.1,
#     'updateTime': '2021-04-29T09:31:15.000Z'},
#    {'id': 108,
#     'name': 'Toast',
#     'link': 'https://www.bakeryswap.org/#/bakery/ETH-BNB%20BLP',
#     'pair': 'ETH-BNB',
#     'totalStake': 1883448.54,
#     'totalStakeRatio': 0.00442358,
#     'rewards': [{'cryptoId': 7064,
#       'name': 'BakeryToken',
#       'symbol': 'BAKE',
#       'slug': 'bakerytoken'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.23684931506849,
#     'weeklyROI': 1.65794520547943,
#     'monthlyROI': 7.20416666666667,
#     'yearlyROI': 86.45,
#     'updateTime': '2021-04-29T09:31:15.000Z'}],
#   'hasNew': False},
#  {'id': '5f71c830edcba010f8a365b4',
#   'name': 'Harvest',
#   'platform': 'Ethereum',
#   'webSite': 'https://harvest.finance/',
#   'totalValueLocked': 265443502.41074225,
#   'poolList': [{'id': 142,
#     'name': 'CRVRENWBTC Vault',
#     'link': 'https://harvest.finance/',
#     'pair': 'CRV-RENBTC',
#     'totalStake': 117997318.50083295,
#     'totalStakeRatio': 0.44452894,
#     'rewards': [{'cryptoId': 6859,
#       'name': 'Harvest Finance',
#       'symbol': 'FARM',
#       'slug': 'harvest-finance'},
#      {'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.00920547945205,
#     'weeklyROI': 0.06443835616435,
#     'monthlyROI': 0.28,
#     'yearlyROI': 3.36,
#     'updateTime': '2021-04-29T09:31:09.000Z'},
#    {'id': 147,
#     'name': 'FARM Profit Sharing',
#     'link': 'https://harvest.finance/',
#     'pair': 'FARM',
#     'totalStake': 64799563.646852136,
#     'totalStakeRatio': 0.2441181,
#     'rewards': [{'cryptoId': 6859,
#       'name': 'Harvest Finance',
#       'symbol': 'FARM',
#       'slug': 'harvest-finance'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.13008219178082,
#     'weeklyROI': 0.91057534246574,
#     'monthlyROI': 3.95666666666667,
#     'yearlyROI': 47.48,
#     'updateTime': '2021-04-29T09:31:11.000Z'},
#    {'id': 138,
#     'name': 'USDC Vault',
#     'link': 'https://harvest.finance/',
#     'pair': 'USDC',
#     'totalStake': 45636653.85762993,
#     'totalStakeRatio': 0.17192605,
#     'rewards': [{'cryptoId': 6859,
#       'name': 'Harvest Finance',
#       'symbol': 'FARM',
#       'slug': 'harvest-finance'},
#      {'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.03816438356164,
#     'weeklyROI': 0.26715068493148,
#     'monthlyROI': 1.16083333333333,
#     'yearlyROI': 13.93,
#     'updateTime': '2021-04-29T09:31:08.000Z'},
#    {'id': 136,
#     'name': 'WETH Vault',
#     'link': 'https://harvest.finance/',
#     'pair': 'WETH',
#     'totalStake': 18128140.129510045,
#     'totalStakeRatio': 0.06829378,
#     'rewards': [{'cryptoId': 6859,
#       'name': 'Harvest Finance',
#       'symbol': 'FARM',
#       'slug': 'harvest-finance'},
#      {'cryptoId': 6193,
#       'name': 'Cream Finance',
#       'symbol': 'CREAM',
#       'slug': 'cream-finance'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.01087671232877,
#     'weeklyROI': 0.07613698630139,
#     'monthlyROI': 0.33083333333333,
#     'yearlyROI': 3.97,
#     'updateTime': '2021-04-29T09:31:07.000Z'},
#    {'id': 137,
#     'name': 'DAI Vault',
#     'link': 'https://harvest.finance/',
#     'pair': 'DAI',
#     'totalStake': 13991538.178642528,
#     'totalStakeRatio': 0.05271004,
#     'rewards': [{'cryptoId': 6859,
#       'name': 'Harvest Finance',
#       'symbol': 'FARM',
#       'slug': 'harvest-finance'},
#      {'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.05057534246575,
#     'weeklyROI': 0.35402739726025,
#     'monthlyROI': 1.53833333333333,
#     'yearlyROI': 18.46,
#     'updateTime': '2021-04-29T09:31:08.000Z'},
#    {'id': 139,
#     'name': 'USDT Vault',
#     'link': 'https://harvest.finance/',
#     'pair': 'USDT',
#     'totalStake': 3071116.5716935103,
#     'totalStakeRatio': 0.01156976,
#     'rewards': [{'cryptoId': 6859,
#       'name': 'Harvest Finance',
#       'symbol': 'FARM',
#       'slug': 'harvest-finance'},
#      {'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.06049315068493,
#     'weeklyROI': 0.42345205479451,
#     'monthlyROI': 1.84,
#     'yearlyROI': 22.08,
#     'updateTime': '2021-04-29T09:31:08.000Z'},
#    {'id': 141,
#     'name': 'WBTC Vault',
#     'link': 'https://harvest.finance/',
#     'pair': 'WBTC',
#     'totalStake': 1819171.52558116,
#     'totalStakeRatio': 0.00685333,
#     'rewards': [{'cryptoId': 6859,
#       'name': 'Harvest Finance',
#       'symbol': 'FARM',
#       'slug': 'harvest-finance'},
#      {'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.00380821917808,
#     'weeklyROI': 0.02665753424656,
#     'monthlyROI': 0.11583333333333,
#     'yearlyROI': 1.39,
#     'updateTime': '2021-04-29T09:31:09.000Z'}],
#   'hasNew': False},
#  {'id': '5f5b5b9cb761c05513d83568',
#   'name': 'Synthetix',
#   'platform': 'Ethereum',
#   'webSite': 'https://mintr.synthetix.io/',
#   'totalValueLocked': 192146030.16113365,
#   'poolList': [{'id': 18,
#     'name': 'Curve sUSD',
#     'link': 'https://mintr.synthetix.io/',
#     'pair': 'sUSD',
#     'totalStake': 192146030.16113365,
#     'totalStakeRatio': 1,
#     'rewards': [{'cryptoId': 2586,
#       'name': 'Synthetix',
#       'symbol': 'SNX',
#       'slug': 'synthetix-network-token'},
#      {'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.01129369863014,
#     'weeklyROI': 0.07905589041098,
#     'monthlyROI': 0.34351666666667,
#     'yearlyROI': 4.1222,
#     'updateTime': '2021-04-15T10:00:22.000Z'}],
#   'auditList': [{'url': 'https://docs.synthetix.io/contracts/audits/',
#     'auditFirm': 'Iosiro'}],
#   'hasNew': False},
#  {'id': '5f787c8daba1f33645724c99',
#   'name': 'SUN',
#   'platform': 'Tron',
#   'webSite': 'https://sun.io/',
#   'totalValueLocked': 181926764,
#   'poolList': [{'id': 155,
#     'name': 'USDT/TRX LP Pool',
#     'link': 'https://sun.io/#/sun',
#     'pair': 'USDT-TRX',
#     'totalStake': 53329235,
#     'totalStakeRatio': 0.29313573,
#     'rewards': [{'cryptoId': 6990,
#       'name': 'SUN',
#       'symbol': 'SUN',
#       'slug': 'sun'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.06135123287671,
#     'weeklyROI': 0.42945863013697,
#     'monthlyROI': 1.8661,
#     'yearlyROI': 22.3932,
#     'updateTime': '2020-11-18T15:31:13.000Z'},
#    {'id': 150,
#     'name': 'HT Pool',
#     'link': 'https://sun.io/#/sun',
#     'pair': 'HT',
#     'totalStake': 42604805,
#     'totalStakeRatio': 0.23418657,
#     'rewards': [{'cryptoId': 6990,
#       'name': 'SUN',
#       'symbol': 'SUN',
#       'slug': 'sun'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.04730684931507,
#     'weeklyROI': 0.33114794520549,
#     'monthlyROI': 1.43891666666667,
#     'yearlyROI': 17.267,
#     'updateTime': '2020-10-08T06:01:12.000Z'},
#    {'id': 153,
#     'name': 'SUN/TRX LP Pool',
#     'link': 'https://sun.io/#/sun',
#     'pair': 'SUN-TRX',
#     'totalStake': 28208478,
#     'totalStakeRatio': 0.15505403,
#     'rewards': [{'cryptoId': 6990,
#       'name': 'SUN',
#       'symbol': 'SUN',
#       'slug': 'sun'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.11598712328767,
#     'weeklyROI': 0.81190986301369,
#     'monthlyROI': 3.52794166666667,
#     'yearlyROI': 42.3353,
#     'updateTime': '2020-11-18T15:31:12.000Z'},
#    {'id': 154,
#     'name': 'JST/TRX LP Pool',
#     'link': 'https://sun.io/#/sun',
#     'pair': 'JST-TRX',
#     'totalStake': 19554433,
#     'totalStakeRatio': 0.10748519,
#     'rewards': [{'cryptoId': 6990,
#       'name': 'SUN',
#       'symbol': 'SUN',
#       'slug': 'sun'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.07436383561644,
#     'weeklyROI': 0.52054684931508,
#     'monthlyROI': 2.2619,
#     'yearlyROI': 27.1428,
#     'updateTime': '2020-11-18T15:31:13.000Z'},
#    {'id': 156,
#     'name': 'SUN Pool',
#     'link': 'https://sun.io/#/sun',
#     'pair': 'SUN-TRX',
#     'totalStake': 14941255,
#     'totalStakeRatio': 0.08212786,
#     'rewards': [{'cryptoId': 6990,
#       'name': 'SUN',
#       'symbol': 'SUN',
#       'slug': 'sun'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.07299287671233,
#     'weeklyROI': 0.51095013698631,
#     'monthlyROI': 2.2202,
#     'yearlyROI': 26.6424,
#     'updateTime': '2020-11-18T15:31:13.000Z'},
#    {'id': 163,
#     'name': 'USDJ/TRX LP Pool',
#     'link': 'https://sun.io/#/sun',
#     'pair': 'USDJ-TRX',
#     'totalStake': 10905012,
#     'totalStakeRatio': 0.05994177,
#     'rewards': [{'cryptoId': 6990,
#       'name': 'SUN',
#       'symbol': 'SUN',
#       'slug': 'sun'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.1000095890411,
#     'weeklyROI': 0.7000671232877,
#     'monthlyROI': 3.04195833333333,
#     'yearlyROI': 36.5035,
#     'updateTime': '2020-11-18T15:31:15.000Z'},
#    {'id': 151,
#     'name': 'HT/TRX LP Pool',
#     'link': 'https://sun.io/#/sun',
#     'pair': 'HT-TRX',
#     'totalStake': 9594999,
#     'totalStakeRatio': 0.052741,
#     'rewards': [{'cryptoId': 6990,
#       'name': 'SUN',
#       'symbol': 'SUN',
#       'slug': 'sun'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.09002465753425,
#     'weeklyROI': 0.63017260273975,
#     'monthlyROI': 2.73825,
#     'yearlyROI': 32.859,
#     'updateTime': '2020-10-08T06:01:12.000Z'},
#    {'id': 161,
#     'name': 'WIN/TRX LP Pool',
#     'link': 'https://sun.io/#/sun',
#     'pair': 'WIN-TRX',
#     'totalStake': 2788547,
#     'totalStakeRatio': 0.01532785,
#     'rewards': [{'cryptoId': 6990,
#       'name': 'SUN',
#       'symbol': 'SUN',
#       'slug': 'sun'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.13036739726027,
#     'weeklyROI': 0.91257178082189,
#     'monthlyROI': 3.96534166666667,
#     'yearlyROI': 47.5841,
#     'updateTime': '2020-11-18T15:31:15.000Z'}],
#   'hasNew': False},
#  {'id': '5f86b154cc06881662044a5c',
#   'name': 'Flamincome',
#   'platform': 'Ethereum',
#   'webSite': 'https://flamincome.finance/',
#   'totalValueLocked': 102436324.81345797,
#   'poolList': [{'id': 184,
#     'name': 'WBTC VAULT',
#     'link': 'https://app.flamincome.finance/',
#     'pair': 'WBTC',
#     'totalStake': 47152065.97592938,
#     'totalStakeRatio': 0.46030611,
#     'rewards': [{'cryptoId': 3717,
#       'name': 'Wrapped Bitcoin',
#       'symbol': 'WBTC',
#       'slug': 'wrapped-bitcoin'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.01076712328767,
#     'weeklyROI': 0.07536986301369,
#     'monthlyROI': 0.3275,
#     'yearlyROI': 3.93,
#     'updateTime': '2021-04-29T09:31:22.000Z'},
#    {'id': 183,
#     'name': 'USDT VAULT',
#     'link': 'https://app.flamincome.finance/',
#     'pair': 'USDT',
#     'totalStake': 33057976.21681692,
#     'totalStakeRatio': 0.32271732,
#     'rewards': [{'cryptoId': 825,
#       'name': 'Tether',
#       'symbol': 'USDT',
#       'slug': 'tether'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00950684931507,
#     'weeklyROI': 0.06654794520549,
#     'monthlyROI': 0.28916666666667,
#     'yearlyROI': 3.47,
#     'updateTime': '2021-04-29T09:31:21.000Z'},
#    {'id': 185,
#     'name': 'WETH VAULT',
#     'link': 'https://app.flamincome.finance/',
#     'pair': 'WETH',
#     'totalStake': 22226282.620711666,
#     'totalStakeRatio': 0.21697657,
#     'rewards': [{'cryptoId': 2396,
#       'name': 'WETH',
#       'symbol': 'WETH',
#       'slug': 'weth'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00090410958904,
#     'weeklyROI': 0.00632876712328,
#     'monthlyROI': 0.0275,
#     'yearlyROI': 0.33,
#     'updateTime': '2021-04-29T09:31:22.000Z'}],
#   'hasNew': False},
#  {'id': '5f5b5b9cb761c05513d8356a',
#   'name': 'Yearn',
#   'platform': 'Ethereum',
#   'webSite': 'https://yearn.finance/vaults',
#   'totalValueLocked': 91331021.76725766,
#   'poolList': [{'id': 26,
#     'name': 'yCRV Vault',
#     'link': 'https://yearn.finance/vaults',
#     'pair': 'yCRV',
#     'totalStake': 41620315.981046066,
#     'totalStakeRatio': 0.45570842,
#     'rewards': [{'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'}],
#     'impermanentLoss': 'NONE',
#     'dailyROI': 0.04553452054795,
#     'weeklyROI': 0.31874164383565,
#     'monthlyROI': 1.38500833333333,
#     'yearlyROI': 16.6201,
#     'updateTime': '2021-04-29T09:30:27.000Z'},
#    {'id': 24,
#     'name': 'USDC Vault',
#     'link': 'https://yearn.finance/vaults',
#     'pair': 'USDC',
#     'totalStake': 15719355.12214,
#     'totalStakeRatio': 0.17211408,
#     'rewards': [{'cryptoId': 3408,
#       'name': 'USD Coin',
#       'symbol': 'USDC',
#       'slug': 'usd-coin'}],
#     'impermanentLoss': 'NONE',
#     'dailyROI': 0.1127402739726,
#     'weeklyROI': 0.7891819178082,
#     'monthlyROI': 3.42918333333333,
#     'yearlyROI': 41.1502,
#     'updateTime': '2021-04-29T09:30:28.000Z'},
#    {'id': 21,
#     'name': 'aLINK Vault',
#     'link': 'https://yearn.finance/vaults',
#     'pair': 'aLINK',
#     'totalStake': 11943638.254435511,
#     'totalStakeRatio': 0.13077307,
#     'rewards': [{'cryptoId': 5751,
#       'name': 'Aave LINK',
#       'symbol': 'ALINK',
#       'slug': 'aave-link'}],
#     'impermanentLoss': 'NONE',
#     'dailyROI': 1.561643836e-05,
#     'weeklyROI': 0.00010931506852,
#     'monthlyROI': 0.000475,
#     'yearlyROI': 0.0057,
#     'updateTime': '2021-04-29T09:30:29.000Z'},
#    {'id': 25,
#     'name': 'USDT Vault',
#     'link': 'https://yearn.finance/vaults',
#     'pair': 'USDT',
#     'totalStake': 10901052.86844,
#     'totalStakeRatio': 0.11935761,
#     'rewards': [{'cryptoId': 825,
#       'name': 'Tether',
#       'symbol': 'USDT',
#       'slug': 'tether'}],
#     'impermanentLoss': 'NONE',
#     'dailyROI': 0.11013315068493,
#     'weeklyROI': 0.77093205479451,
#     'monthlyROI': 3.34988333333333,
#     'yearlyROI': 40.1986,
#     'updateTime': '2021-04-29T09:30:28.000Z'},
#    {'id': 22,
#     'name': 'DAI Vault',
#     'link': 'https://yearn.finance/vaults',
#     'pair': 'DAI',
#     'totalStake': 7289989.090530373,
#     'totalStakeRatio': 0.07981942,
#     'rewards': [{'cryptoId': 4943,
#       'name': 'Dai',
#       'symbol': 'DAI',
#       'slug': 'multi-collateral-dai'}],
#     'impermanentLoss': 'NONE',
#     'dailyROI': 0.11154136986301,
#     'weeklyROI': 0.78078958904107,
#     'monthlyROI': 3.39271666666667,
#     'yearlyROI': 40.7126,
#     'updateTime': '2021-04-29T09:30:29.000Z'},
#    {'id': 23,
#     'name': 'TUSD Vault',
#     'link': 'https://yearn.finance/vaults',
#     'pair': 'TUSD',
#     'totalStake': 3856670.450665706,
#     'totalStakeRatio': 0.04222739,
#     'rewards': [{'cryptoId': 2563,
#       'name': 'TrueUSD',
#       'symbol': 'TUSD',
#       'slug': 'trueusd'}],
#     'impermanentLoss': 'NONE',
#     'dailyROI': 0.11583780821918,
#     'weeklyROI': 0.81086465753426,
#     'monthlyROI': 3.5234,
#     'yearlyROI': 42.2808,
#     'updateTime': '2021-04-29T09:30:28.000Z'}],
#   'auditList': [{'url': 'https://github.com/iearn-finance/audits/blob/master/Certik%20-%20itoken-finance-audit-report-1.1.0.pdf',
#     'auditFirm': 'Certik'},
#    {'url': 'https://github.com/iearn-finance/audits/blob/master/CryptoManiacs%20%20-%20Audit%20of%20iearn.finance%20by%20CryptoManiacs%20-%20HackMD.pdf',
#     'auditFirm': 'CryptoManiacs'},
#    {'url': 'https://github.com/iearn-finance/audits/blob/master/Quantstamp%20-%20Yearn.Finance%20Security%20Review.pdf',
#     'auditFirm': 'Quantstamp'},
#    {'url': 'https://github.com/iearn-finance/audits/blob/master/StrategyCurveYCRV.sol%20-%20HackMD.pdf',
#     'auditFirm': 'HackMD'}],
#   'hasNew': False},
#  {'id': '5f5b5b9cb761c05513d83566',
#   'name': 'dForce',
#   'platform': 'Ethereum',
#   'webSite': 'https://staking.dforce.network/dapp',
#   'totalValueLocked': 85948729.4766219,
#   'poolList': [{'id': 6,
#     'name': 'dUSDT/dUSDC/dDAI',
#     'link': 'https://markets.dforce.network/',
#     'pair': 'dUSDT-dUSDC-dDAI',
#     'totalStake': 85374034.78,
#     'totalStakeRatio': 0.99331352,
#     'rewards': [{'cryptoId': 4758,
#       'name': 'dForce',
#       'symbol': 'DF',
# ...
#     'weeklyROI': 1.78989616438353,
#     'monthlyROI': 7.777525,
#     'yearlyROI': 93.3303,
#     'updateTime': '2021-04-29T09:31:31.000Z'}],
#   'hasNew': True},
#  {'id': '5f685b27fcdfe7080cdd0fba',
#   'name': 'Fortube',
#   'platform': 'Ethereum',
#   'webSite': 'https://for.tube',
#   'totalValueLocked': 22788623,
#   'poolList': [{'id': 78,
#     'name': 'USDT Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'USDT',
#     'totalStake': 9588306,
#     'totalStakeRatio': 0.42074969,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00948191780822,
#     'weeklyROI': 0.06637342465754,
#     'monthlyROI': 0.28840833333333,
#     'yearlyROI': 3.4609,
#     'updateTime': '2020-11-17T04:33:53.000Z'},
#    {'id': 82,
#     'name': 'FOR Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'FOR',
#     'totalStake': 5097528,
#     'totalStakeRatio': 0.22368741,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.01422273972603,
#     'weeklyROI': 0.09955917808221,
#     'monthlyROI': 0.43260833333333,
#     'yearlyROI': 5.1913,
#     'updateTime': '2020-11-17T04:33:54.000Z'},
#    {'id': 83,
#     'name': 'ETH Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'ETH',
#     'totalStake': 3176820,
#     'totalStakeRatio': 0.13940377,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00355561643836,
#     'weeklyROI': 0.02488931506852,
#     'monthlyROI': 0.10815,
#     'yearlyROI': 1.2978,
#     'updateTime': '2020-11-17T04:33:54.000Z'},
#    {'id': 84,
#     'name': 'HBTC Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'HBTC',
#     'totalStake': 1938891,
#     'totalStakeRatio': 0.08508153,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00355561643836,
#     'weeklyROI': 0.02488931506852,
#     'monthlyROI': 0.10815,
#     'yearlyROI': 1.2978,
#     'updateTime': '2020-11-17T04:33:54.000Z'},
#    {'id': 79,
#     'name': 'USDC Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'USDC',
#     'totalStake': 1367397,
#     'totalStakeRatio': 0.06000349,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00948191780822,
#     'weeklyROI': 0.06637342465754,
#     'monthlyROI': 0.28840833333333,
#     'yearlyROI': 3.4609,
#     'updateTime': '2020-11-17T04:33:53.000Z'},
#    {'id': 80,
#     'name': 'BUSD Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'BUSD',
#     'totalStake': 1100342,
#     'totalStakeRatio': 0.04828471,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00948191780822,
#     'weeklyROI': 0.06637342465754,
#     'monthlyROI': 0.28840833333333,
#     'yearlyROI': 3.4609,
#     'updateTime': '2020-11-17T04:33:53.000Z'},
#    {'id': 77,
#     'name': 'WBTC Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'WBTC',
#     'totalStake': 218726,
#     'totalStakeRatio': 0.00959803,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00355561643836,
#     'weeklyROI': 0.02488931506852,
#     'monthlyROI': 0.10815,
#     'yearlyROI': 1.2978,
#     'updateTime': '2020-11-17T04:33:53.000Z'},
#    {'id': 81,
#     'name': 'DAI Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'DAI',
#     'totalStake': 152322,
#     'totalStakeRatio': 0.00668412,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00948191780822,
#     'weeklyROI': 0.06637342465754,
#     'monthlyROI': 0.28840833333333,
#     'yearlyROI': 3.4609,
#     'updateTime': '2020-11-17T04:33:53.000Z'},
#    {'id': 87,
#     'name': 'YFII Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'YFII',
#     'totalStake': 99696,
#     'totalStakeRatio': 0.00437481,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00071123287671,
#     'weeklyROI': 0.00497863013697,
#     'monthlyROI': 0.02163333333333,
#     'yearlyROI': 0.2596,
#     'updateTime': '2020-11-17T04:33:55.000Z'},
#    {'id': 85,
#     'name': 'YYDAI+YUSDC+YUSDT+YTUSD Vault',
#     'link': 'https://for.tube/bank/home',
#     'pair': 'yyDAI+yUSDC+yUSDT+yTUSD',
#     'totalStake': 48595,
#     'totalStakeRatio': 0.00213242,
#     'rewards': [{'cryptoId': 4118,
#       'name': 'ForTube',
#       'symbol': 'FOR',
#       'slug': 'the-force-protocol'}],
#     'impermanentLoss': 'None',
#     'dailyROI': 0.00948191780822,
#     'weeklyROI': 0.06637342465754,
#     'monthlyROI': 0.28840833333333,
#     'yearlyROI': 3.4609,
#     'updateTime': '2020-11-17T04:33:55.000Z'}],
#   'hasNew': False},
#  {'id': '5f5b5b9cb761c05513d83567',
#   'name': 'mStable',
#   'platform': 'Ethereum',
#   'webSite': 'https://app.mstable.org/earn',
#   'totalValueLocked': 6001245.220436543,
#   'poolList': [{'id': 8,
#     'name': 'Uniswap MTA/WETH 50/50',
#     'link': 'https://app.mstable.org/earn/uniswap-mta-50-weth-50',
#     'pair': 'MTA-wETH',
#     'totalStake': 6001245.220436543,
#     'totalStakeRatio': 1,
#     'rewards': [{'cryptoId': 5748,
#       'name': 'mStable Governance Token: Meta (MTA)',
#       'symbol': 'MTA',
#       'slug': 'meta'},
#      {'cryptoId': 5728,
#       'name': 'Balancer',
#       'symbol': 'BAL',
#       'slug': 'balancer'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.16686219178082,
#     'weeklyROI': 1.16803534246574,
#     'monthlyROI': 5.07539166666667,
#     'yearlyROI': 60.9047,
#     'updateTime': '2021-04-29T09:30:21.000Z'}],
#   'auditList': [{'url': 'https://diligence.consensys.net/audits/2020/07/mstable-1.1/',
#     'auditFirm': 'Consensys Diligence'},
#    {'url': 'https://docs.mstable.org/protocol/security',
#     'auditFirm': 'Bramah Systems'}],
#   'hasNew': False},
#  {'id': '5f86b154cc06881662044a5b',
#   'name': 'Bella Protocol',
#   'platform': 'Ethereum',
#   'webSite': 'https://bella.fi/',
#   'totalValueLocked': 3537465.2867459026,
#   'poolList': [{'id': 181,
#     'name': 'BEL-ETH',
#     'link': 'https://liquidity.bella.fi/',
#     'pair': 'BEL-ETH',
#     'totalStake': 1949097.0793866178,
#     'totalStakeRatio': 0.55098691,
#     'rewards': [{'cryptoId': 6928,
#       'name': 'Bella Protocol',
#       'symbol': 'BEL',
#       'slug': 'bella-protocol'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.35342465753425,
#     'weeklyROI': 2.47397260273975,
#     'monthlyROI': 10.75,
#     'yearlyROI': 129,
#     'updateTime': '2021-04-29T09:31:26.000Z'},
#    {'id': 180,
#     'name': 'BEL-USDT',
#     'link': 'https://liquidity.bella.fi/',
#     'pair': 'BEL-USDT',
#     'totalStake': 1003032.4880320563,
#     'totalStakeRatio': 0.28354554,
#     'rewards': [{'cryptoId': 6928,
#       'name': 'Bella Protocol',
#       'symbol': 'BEL',
#       'slug': 'bella-protocol'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 1.37260273972603,
#     'weeklyROI': 9.60821917808221,
#     'monthlyROI': 41.75,
#     'yearlyROI': 501,
#     'updateTime': '2021-04-29T09:31:26.000Z'},
#    {'id': 182,
#     'name': 'ARPA-USDT',
#     'link': 'https://liquidity.bella.fi/',
#     'pair': 'ARPA-USDT',
#     'totalStake': 585335.7193272285,
#     'totalStakeRatio': 0.16546755,
#     'rewards': [{'cryptoId': 6928,
#       'name': 'Bella Protocol',
#       'symbol': 'BEL',
#       'slug': 'bella-protocol'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 1.17808219178082,
#     'weeklyROI': 8.24657534246574,
#     'monthlyROI': 35.83333333333333,
#     'yearlyROI': 430,
#     'updateTime': '2021-04-29T09:31:27.000Z'}],
#   'hasNew': False},
#  {'id': '5f71c840edcba010f8a365b5',
#   'name': 'HodlTree',
#   'platform': 'Ethereum',
#   'webSite': 'https://hodltree.io',
#   'totalValueLocked': 1820692.0890921436,
#   'poolList': [{'id': 149,
#     'name': 'HodlTree balancer',
#     'link': 'https://pools.balancer.exchange/#/pool/0x02b77ad79e27ad80a0a0868cc7528520e8442c9b/',
#     'pair': 'HTRE-USDC',
#     'totalStake': 1791237.1005000002,
#     'totalStakeRatio': 0.98382209,
#     'rewards': [{'cryptoId': 7100,
#       'name': 'HodlTree',
#       'symbol': 'HTRE',
#       'slug': 'hodltree'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.30496383561644,
#     'weeklyROI': 2.13474684931508,
#     'monthlyROI': 9.27598333333333,
#     'yearlyROI': 111.3118,
#     'updateTime': '2021-04-29T09:31:12.000Z'},
#    {'id': 148,
#     'name': 'HodlTree uniswap',
#     'link': 'https://uniswap.info/pair/0x57e69e4385896fa4511f958e88d8775fd6a8c6c0',
#     'pair': 'HTRE-USDC',
#     'totalStake': 29454.988592143403,
#     'totalStakeRatio': 0.01617791,
#     'rewards': [{'cryptoId': 7100,
#       'name': 'HodlTree',
#       'symbol': 'HTRE',
#       'slug': 'hodltree'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.30496383561644,
#     'weeklyROI': 2.13474684931508,
#     'monthlyROI': 9.27598333333333,
#     'yearlyROI': 111.3118,
#     'updateTime': '2021-04-29T09:31:12.000Z'}],
#   'hasNew': False},
#  {'id': '5f6b21051a3d2007bc5ea1bb',
#   'name': 'PerlinX',
#   'platform': 'Ethereum',
#   'webSite': 'https://perlinx.finance/',
#   'totalValueLocked': 1017462.378677196,
#   'poolList': [{'id': 121,
#     'name': 'Balancer WETH-PERL 50/50',
#     'link': 'https://app.perlinx.finance/pools/0x8C7769F9F1E5042C0809b8702e4b9947b1Bcb3f3',
#     'pair': 'WETH-PERL',
#     'totalStake': 653907.5691423632,
#     'totalStakeRatio': 0.64268476,
#     'rewards': [{'cryptoId': 4293,
#       'name': 'Perlin',
#       'symbol': 'PERL',
#       'slug': 'perlin'},
#      {'cryptoId': 5728,
#       'name': 'Balancer',
#       'symbol': 'BAL',
#       'slug': 'balancer'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.34463342465753,
#     'weeklyROI': 2.41243397260271,
#     'monthlyROI': 10.4826,
#     'yearlyROI': 125.7912,
#     'updateTime': '2020-10-06T23:49:08.000Z'},
#    {'id': 122,
#     'name': 'Balancer TUSD-PERL 50/50',
#     'link': 'https://app.perlinx.finance/pools/0x0BdF7EFEf728308B6F55b1dD8D0c714f0d5d233f',
#     'pair': 'TUSD-PERL',
#     'totalStake': 154035.40062250657,
#     'totalStakeRatio': 0.15139174,
#     'rewards': [{'cryptoId': 4293,
#       'name': 'Perlin',
#       'symbol': 'PERL',
#       'slug': 'perlin'},
#      {'cryptoId': 5728,
#       'name': 'Balancer',
#       'symbol': 'BAL',
#       'slug': 'balancer'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.29445835616438,
#     'weeklyROI': 2.06120849315066,
#     'monthlyROI': 8.95644166666667,
#     'yearlyROI': 107.4773,
#     'updateTime': '2020-10-06T22:34:08.000Z'},
#    {'id': 123,
#     'name': 'Balancer BUSD-PERL 50/50',
#     'link': 'https://app.perlinx.finance/pools/0x19F4611C61e2eE6D2FaDFccBde1e95cFcfd1E210',
#     'pair': 'BUSD-PERL',
#     'totalStake': 108925.26551513521,
#     'totalStakeRatio': 0.10705582,
#     'rewards': [{'cryptoId': 4293,
#       'name': 'Perlin',
#       'symbol': 'PERL',
#       'slug': 'perlin'},
#      {'cryptoId': 5728,
#       'name': 'Balancer',
#       'symbol': 'BAL',
#       'slug': 'balancer'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.44221917808219,
#     'weeklyROI': 3.09553424657533,
#     'monthlyROI': 13.45083333333333,
#     'yearlyROI': 161.41,
#     'updateTime': '2020-10-06T23:52:09.000Z'},
#    {'id': 124,
#     'name': 'Balancer DAI-PERL 50/50"',
#     'link': 'https://app.perlinx.finance/pools/0x0B0Dea284a07d60d026691476b130f160e48BD0A',
#     'pair': 'DAI-PERL',
#     'totalStake': 87350.24405015854,
#     'totalStakeRatio': 0.08585108,
#     'rewards': [{'cryptoId': 4293,
#       'name': 'Perlin',
#       'symbol': 'PERL',
#       'slug': 'perlin'},
#      {'cryptoId': 5728,
#       'name': 'Balancer',
#       'symbol': 'BAL',
#       'slug': 'balancer'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.38915835616438,
#     'weeklyROI': 2.72410849315066,
#     'monthlyROI': 11.8369,
#     'yearlyROI': 142.0428,
#     'updateTime': '2020-10-06T22:28:09.000Z'},
#    {'id': 125,
#     'name': 'Balancer BAL-PERL 50/50',
#     'link': 'https://app.perlinx.finance/pools/0x2C1cB70Cccf250B35Ca2CB021E2F624aBa76e3e8',
#     'pair': 'BAL-PERL',
#     'totalStake': 13243.899347032466,
#     'totalStakeRatio': 0.0130166,
#     'rewards': [{'cryptoId': 4293,
#       'name': 'Perlin',
#       'symbol': 'PERL',
#       'slug': 'perlin'},
#      {'cryptoId': 5728,
#       'name': 'Balancer',
#       'symbol': 'BAL',
#       'slug': 'balancer'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.31130739726027,
#     'weeklyROI': 2.17915178082189,
#     'monthlyROI': 9.46893333333333,
#     'yearlyROI': 113.6272,
#     'updateTime': '2020-10-06T22:37:09.000Z'}],
#   'hasNew': False},
#  {'id': '600004163c1b4b4fdf0bb037',
#   'name': 'Mithril Cash',
#   'platform': 'Ethereum',
#   'webSite': 'https://mith.cash/',
#   'totalValueLocked': 907457,
#   'poolList': [{'id': 208,
#     'name': 'MIC_USDT-SUSHI-LPV2',
#     'link': 'https://mith.cash/',
#     'pair': 'MIC-USDT',
#     'totalStake': 684331,
#     'totalStakeRatio': 0.75411948,
#     'rewards': [{'cryptoId': 8141,
#       'name': 'Mithril Share',
#       'symbol': 'MIS',
#       'slug': 'mithril-share'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.01768684931507,
#     'weeklyROI': 0.12380794520549,
#     'monthlyROI': 0.537975,
#     'yearlyROI': 6.4557,
#     'updateTime': '2021-04-29T09:31:30.000Z'},
#    {'id': 207,
#     'name': 'MIS_USDT-SUSHI-LPV2',
#     'link': 'https://mith.cash/',
#     'pair': 'MIS-USDT',
#     'totalStake': 223126,
#     'totalStakeRatio': 0.24588052,
#     'rewards': [{'cryptoId': 8141,
#       'name': 'Mithril Share',
#       'symbol': 'MIS',
#       'slug': 'mithril-share'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 0.01906301369863,
#     'weeklyROI': 0.13344109589041,
#     'monthlyROI': 0.57983333333333,
#     'yearlyROI': 6.958,
#     'updateTime': '2021-04-29T09:31:30.000Z'}],
#   'hasNew': True},
#  {'id': '5f86b154cc06881662044a5d',
#   'name': 'S.Finance',
#   'platform': 'Ethereum',
#   'webSite': 'https://s.finance',
#   'totalValueLocked': 235360.51479170384,
#   'poolList': [{'id': 164,
#     'name': 'sUSD liquidity gauge',
#     'link': 'https://s.finance/dao',
#     'pair': 'DAI-USDT-USDC-sUSD',
#     'totalStake': 116621.56291937767,
#     'totalStakeRatio': 0.49550182,
#     'rewards': [{'cryptoId': 7187,
#       'name': 'S.Finance',
#       'symbol': 'SFG',
#       'slug': 's-finance'},
#      {'cryptoId': 6538,
#       'name': 'Curve DAO Token',
#       'symbol': 'CRV',
#       'slug': 'curve-dao-token'},
#      {'cryptoId': 2586,
#       'name': 'Synthetix',
#       'symbol': 'SNX',
#       'slug': 'synthetix-network-token'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.17663561643836,
#     'weeklyROI': 1.23644931506852,
#     'monthlyROI': 5.37266666666667,
#     'yearlyROI': 64.472,
#     'updateTime': '2021-04-29T09:31:30.000Z'},
#    {'id': 167,
#     'name': 'dfi liquidity gauge',
#     'link': 'https://s.finance/dao',
#     'pair': 'DAI-USDC-USDT',
#     'totalStake': 103886.31555852525,
#     'totalStakeRatio': 0.44139229,
#     'rewards': [{'cryptoId': 7187,
#       'name': 'S.Finance',
#       'symbol': 'SFG',
#       'slug': 's-finance'}],
#     'impermanentLoss': 'Low',
#     'dailyROI': 0.7274301369863,
#     'weeklyROI': 5.0920109589041,
#     'monthlyROI': 22.126,
#     'yearlyROI': 265.512,
#     'updateTime': '2021-04-29T09:31:30.000Z'},
#    {'id': 165,
#     'name': 'SFG liquidity gauge',
#     'link': 'https://s.finance/dao',
#     'pair': 'SFG-DAI',
#     'totalStake': 14852.63631380093,
#     'totalStakeRatio': 0.0631059,
#     'rewards': [{'cryptoId': 7187,
#       'name': 'S.Finance',
#       'symbol': 'SFG',
#       'slug': 's-finance'}],
#     'impermanentLoss': 'High',
#     'dailyROI': 1.38047698630137,
#     'weeklyROI': 9.66333890410959,
#     'monthlyROI': 41.98950833333333,
#     'yearlyROI': 503.8741,
#     'updateTime': '2021-04-29T09:31:30.000Z'}],
#   'hasNew': False}]

# %%
farming_data = []
for item in farming_list:
    pool_list = item['poolList']
    for pool_item in pool_list:
        rewards = [f"{reward['symbol']}/{reward['name']}" for reward in pool_item['rewards']]
        farming_data.append([pool_item['name'], pool_item['pair'], pool_item['totalStake'], pool_item['yearlyROI'], pool_item['monthlyROI'], pool_item['dailyROI'], pool_item['impermanentLoss'], ",".join(rewards)])

# %%
farming_data
# Out:
# [['vBTC-BTCB Lending',
#   'vBTC-BTCB',
#   2299680246.57,
#   3.09,
#   0.2575,
#   0.00846575342466,
#   'None',
#   'XVS/Venus'],
#  ['vETH-ETH Lending',
#   'vETH-ETH',
#   1637433472.87,
#   2.23,
#   0.18583333333333,
#   0.0061095890411,
#   'None',
#   'XVS/Venus'],
#  ['vBNB-BNB Lending',
#   'vBNB-BNB',
#   1582313625.1,
#   6.29,
#   0.52416666666667,
#   0.01723287671233,
#   'None',
#   'XVS/Venus'],
#  ['vUSDT-USDT Lending',
#   'vUSDT-USDT',
#   541625580.22,
#   7.7,
#   0.64166666666667,
#   0.02109589041096,
#   'None',
#   'XVS/Venus'],
#  ['vXVS-XVS Lending',
#   'vXVS-XVS',
#   529349123.29,
#   9.62,
#   0.80166666666667,
#   0.02635616438356,
#   'None',
#   'XVS/Venus'],
#  ['vBUSD-BUSD Lending',
#   'vBUSD-BUSD',
#   457933516.54,
#   10.87,
#   0.90583333333333,
#   0.02978082191781,
#   'None',
#   'XVS/Venus'],
#  ['vSXP-SXP Lending',
#   'vSXP-SXP',
#   369193581.72,
#   6.25,
#   0.52083333333333,
#   0.01712328767123,
#   'None',
#   'XVS/Venus'],
#  ['VAI Mint',
#   'VAI',
#   205690780.48,
#   109.14,
#   9.095,
#   0.29901369863014,
#   'None',
#   'XVS/Venus'],
#  ['vUSDC-USDC Lending',
#   'vUSDC-USDC',
#   196040931.36,
#   17.18,
#   1.43166666666667,
#   0.04706849315068,
#   'None',
#   'XVS/Venus'],
#  ['vXRP-XRP Lending',
#   'vXRP-XRP',
#   132888394.41,
#   1.39,
#   0.11583333333333,
#   0.00380821917808,
#   'None',
#   'XVS/Venus'],
#  ['vLINK-LINK Lending',
#   'vLINK-LINK',
#   111560651.64,
#   1.67,
#   0.13916666666667,
#   0.00457534246575,
#   'None',
#   'XVS/Venus,LINK/Chainlink'],
#  ['vDOT-DOT Lending',
#   'vDOT-DOT',
#   77900320.62,
#   3.55,
#   0.29583333333333,
#   0.00972602739726,
#   'None',
#   'XVS/Venus,DOT/Polkadot'],
#  ['vLTC-LTC Lending',
#   'vLTC-LTC',
#   63540571.41,
#   2.87,
#   0.23916666666667,
#   0.00786301369863,
#   'None',
#   'XVS/Venus'],
#  ['vBCH-BCH Lending',
#   'vBCH-BCH',
#   39484139.44,
#   0.82,
#   0.06833333333333,
#   0.00224657534247,
#   'None',
#   'XVS/Venus,BCH/Bitcoin Cash'],
#  ['CAKE',
#   'CAKE',
#   5064157278.444463,
#   86.2093,
#   7.18410833333333,
#   0.2361898630137,
#   'None',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP BUSD-BNB',
#   'BUSD-WBNB',
#   40090525.4532061,
#   1730.2702,
#   144.18918333333332,
#   4.74046630136986,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP CAKE-BNB',
#   'CAKE-WBNB',
#   28191954.96494473,
#   9227.0261,
#   768.9188416666667,
#   25.27952356164384,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP ETH-BNB',
#   'ETH-BNB',
#   15254501.05682646,
#   1136.8356,
#   94.7363,
#   3.11461808219178,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP USDT-BUSD',
#   'USDT-BUSD',
#   12964481.586011996,
#   668.822,
#   55.73516666666667,
#   1.83238904109589,
#   'Low',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP BTC-BNB',
#   'BTC-BNB',
#   12572746.928955115,
#   1379.3215,
#   114.94345833333333,
#   3.77896301369863,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP DOT-BNB',
#   'DOT-WBNB',
#   8551632.798232889,
#   2027.9005,
#   168.99170833333332,
#   5.55589178082192,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP ADA-BNB',
#   'ADA-WBNB',
#   2827958.779740503,
#   3066.1444,
#   255.51203333333333,
#   8.40039561643836,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP USDT-BNB',
#   'USDT-BNB',
#   2615753.115131901,
#   6629.7771,
#   552.481425,
#   18.16377287671233,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP TWT-BNB',
#   'TWT-BNB',
#   1961499.0650279375,
#   8841.1259,
#   736.7604916666667,
#   24.22226273972603,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP LINK-BNB',
#   'LINK-WBNB',
#   1571880.1895434228,
#   11032.5585,
#   919.379875,
#   30.22618767123288,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP BAND-BNB',
#   'BAND-WBNB',
#   588105.826271808,
#   29487.6524,
#   2457.3043666666667,
#   80.78808876712328,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP XRP-BNB',
#   'XRP-BNB',
#   300389.33834103646,
#   28865.6387,
#   2405.4698916666666,
#   79.08394164383562,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP ALPHA-BNB',
#   'ALPHA-BNB',
#   298454.8315944105,
#   29052.7382,
#   2421.0615166666666,
#   79.59654301369864,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP ATOM-BNB',
#   'ATOM-BNB',
#   260082.4372669074,
#   33339.1604,
#   2778.2633666666666,
#   91.34016547945205,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP DAI-BNB',
#   'DAI-BNB',
#   104845.45907752967,
#   82702.009,
#   6891.834083333333,
#   226.58084657534246,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP EOS-BNB',
#   'EOS-WBNB',
#   85941.82438226299,
#   100893.0188,
#   8407.751566666666,
#   276.4192295890411,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP XTZ-BNB',
#   'XTZ-BNB',
#   83791.71722524207,
#   103481.9477,
#   8623.495641666666,
#   283.51218547945206,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP BCH-BNB',
#   'BCH-BNB',
#   19284.696212083774,
#   449627.5184,
#   37468.959866666664,
#   1231.8562147945206,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['PancakeSWAP YFII-BNB',
#   'YFII-BNB',
#   13984.57599641017,
#   620035.2519,
#   51669.604325,
#   1698.7267175342465,
#   'High',
#   'CAKE/PancakeSwap'],
#  ['Sushi Party!',
#   'SUSHI-ETH',
#   625392866.1311141,
#   31.4421,
#   2.620175,
#   0.08614273972603,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['Circle Snail',
#   'USDC-ETH',
#   352221274.09740114,
#   33.3919,
#   2.78265833333333,
#   0.09148465753425,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['Donald DAI',
#   'DAI-ETH',
#   318025173.7724368,
#   38.8245,
#   3.235375,
#   0.10636849315068,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['Tether Turtle',
#   'USDT-ETH',
#   277607441.9381259,
#   37.261,
#   3.10508333333333,
#   0.10208493150685,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['YFI Whale',
#   'YFI-ETH',
#   173766660.96597272,
#   47.6221,
#   3.96850833333333,
#   0.13047150684932,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['Toadie Marine',
#   'LINK-ETH',
#   119803080.31143084,
#   31.5273,
#   2.627275,
#   0.08637616438356,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['Synthetic Snake',
#   'SNX-ETH',
#   62577353.1528561,
#   34.5653,
#   2.88044166666667,
#   0.09469945205479,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['Spartan Dollar',
#   'SUSD-ETH',
#   26932432.59886989,
#   41.5251,
#   3.460425,
#   0.11376739726027,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['Compound Truffle',
#   'COMP-ETH',
#   24931025.006551124,
#   24.4833,
#   2.040275,
#   0.06707753424658,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['CRV Crocodile',
#   'CRV-ETH',
#   20212869.11113016,
#   20.2673,
#   1.68894166666667,
#   0.05552684931507,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['Band-osaurus',
#   'BAND-ETH',
#   15313972.217636935,
#   37.9861,
#   3.16550833333333,
#   0.10407150684932,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['Umami Squid',
#   'UMA-ETH',
#   14566366.379109293,
#   28.1237,
#   2.34364166666667,
#   0.07705123287671,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['REN Rhino',
#   'ren-ETH',
#   12405789.845811544,
#   33.0217,
#   2.75180833333333,
#   0.0904704109589,
#   'High',
#   'SUSHI/SushiSwap'],
#  ['renBTC',
#   'renBTC-wBTC',
#   517522019.25426126,
#   1.764,
#   0.147,
#   0.00483287671233,
#   'Low',
#   'CRV/Curve DAO Token'],
#  ['hBTC',
#   'hBTC-wBTC',
#   480045188.0476562,
#   6.8269,
#   0.56890833333333,
#   0.01870383561644,
#   'Low',
#   'CRV/Curve DAO Token'],
#  ['sBTC',
#   'renBTC-wBTC-sBTC',
#   425205110.03057575,
#   2.1087,
#   0.175725,
#   0.00577726027397,
#   'Low',
#   'CRV/Curve DAO Token'],
#  ['sUSD',
#   'DAI-USDC-USDT-sUSD',
#   199434597.04514995,
#   14.6748,
#   1.2229,
#   0.04020493150685,
#   'Low',
#   'CRV/Curve DAO Token'],
#  ['Compound',
#   'DAI-USDC',
#   142911560.83606184,
#   11.3318,
#   0.94431666666667,
#   0.03104602739726,
#   'Low',
#   'CRV/Curve DAO Token'],
#  ['bUSD',
#   'DAI-USDC-USDT-BUSD',
#   89658512.22955135,
#   7.2463,
#   0.60385833333333,
#   0.01985287671233,
#   'Low',
#   'CRV/Curve DAO Token'],
#  ['Bread',
#   'BAKE',
#   286929760.31,
#   11.92,
#   0.99333333333333,
#   0.03265753424658,
#   'High',
#   'BAKE/BakeryToken'],
#  ['Doughnut',
#   'BAKE-BNB',
#   72870082.43,
#   67.03,
#   5.58583333333333,
#   0.18364383561644,
#   'High',
#   'BAKE/BakeryToken'],
#  ['Cake',
#   'BTC-BNB',
#   52678797.03,
#   108.18,
#   9.015,
#   0.29638356164384,
#   'High',
#   'BAKE/BakeryToken'],
#  ['Waffle',
#   'BAKE-BUSD',
#   7412055.63,
#   175.74,
#   14.645,
#   0.48147945205479,
#   'High',
#   'BAKE/BakeryToken'],
#  ['Croissant',
#   'BUSD-BNB',
#   4000602.7,
#   122.1,
#   10.175,
#   0.33452054794521,
#   'High',
#   'BAKE/BakeryToken'],
#  ['Toast',
#   'ETH-BNB',
#   1883448.54,
#   86.45,
#   7.20416666666667,
#   0.23684931506849,
#   'High',
#   'BAKE/BakeryToken'],
#  ['CRVRENWBTC Vault',
#   'CRV-RENBTC',
#   117997318.50083295,
#   3.36,
#   0.28,
#   0.00920547945205,
#   'Low',
#   'FARM/Harvest Finance,CRV/Curve DAO Token'],
#  ['FARM Profit Sharing',
#   'FARM',
#   64799563.646852136,
#   47.48,
#   3.95666666666667,
#   0.13008219178082,
#   'None',
#   'FARM/Harvest Finance'],
#  ['USDC Vault',
#   'USDC',
#   45636653.85762993,
#   13.93,
#   1.16083333333333,
#   0.03816438356164,
#   'Low',
#   'FARM/Harvest Finance,CRV/Curve DAO Token'],
#  ['WETH Vault',
#   'WETH',
#   18128140.129510045,
#   3.97,
#   0.33083333333333,
#   0.01087671232877,
#   'None',
#   'FARM/Harvest Finance,CREAM/Cream Finance'],
#  ['DAI Vault',
#   'DAI',
#   13991538.178642528,
#   18.46,
#   1.53833333333333,
#   0.05057534246575,
#   'High',
#   'FARM/Harvest Finance,CRV/Curve DAO Token'],
#  ['USDT Vault',
#   'USDT',
#   3071116.5716935103,
#   22.08,
#   1.84,
#   0.06049315068493,
#   'Low',
#   'FARM/Harvest Finance,CRV/Curve DAO Token'],
#  ['WBTC Vault',
#   'WBTC',
#   1819171.52558116,
#   1.39,
#   0.11583333333333,
#   0.00380821917808,
#   'Low',
#   'FARM/Harvest Finance,CRV/Curve DAO Token'],
#  ['Curve sUSD',
#   'sUSD',
#   192146030.16113365,
#   4.1222,
#   0.34351666666667,
#   0.01129369863014,
#   'None',
#   'SNX/Synthetix,CRV/Curve DAO Token'],
#  ['USDT/TRX LP Pool',
#   'USDT-TRX',
#   53329235,
#   22.3932,
#   1.8661,
#   0.06135123287671,
#   'High',
#   'SUN/SUN'],
#  ['HT Pool',
#   'HT',
#   42604805,
#   17.267,
#   1.43891666666667,
#   0.04730684931507,
#   'None',
#   'SUN/SUN'],
#  ['SUN/TRX LP Pool',
#   'SUN-TRX',
#   28208478,
#   42.3353,
#   3.52794166666667,
#   0.11598712328767,
#   'High',
#   'SUN/SUN'],
#  ['JST/TRX LP Pool',
#   'JST-TRX',
#   19554433,
#   27.1428,
#   2.2619,
#   0.07436383561644,
#   'High',
#   'SUN/SUN'],
#  ['SUN Pool',
#   'SUN-TRX',
#   14941255,
#   26.6424,
#   2.2202,
#   0.07299287671233,
#   'High',
#   'SUN/SUN'],
#  ['USDJ/TRX LP Pool',
#   'USDJ-TRX',
#   10905012,
#   36.5035,
#   3.04195833333333,
#   0.1000095890411,
#   'High',
#   'SUN/SUN'],
#  ['HT/TRX LP Pool',
#   'HT-TRX',
#   9594999,
#   32.859,
#   2.73825,
#   0.09002465753425,
#   'High',
#   'SUN/SUN'],
#  ['WIN/TRX LP Pool',
#   'WIN-TRX',
#   2788547,
#   47.5841,
#   3.96534166666667,
#   0.13036739726027,
#   'High',
#   'SUN/SUN'],
#  ['WBTC VAULT',
#   'WBTC',
#   47152065.97592938,
#   3.93,
#   0.3275,
#   0.01076712328767,
#   'None',
#   'WBTC/Wrapped Bitcoin'],
#  ['USDT VAULT',
#   'USDT',
#   33057976.21681692,
#   3.47,
#   0.28916666666667,
#   0.00950684931507,
#   'None',
#   'USDT/Tether'],
#  ['WETH VAULT',
#   'WETH',
#   22226282.620711666,
#   0.33,
#   0.0275,
#   0.00090410958904,
#   'None',
#   'WETH/WETH'],
#  ['yCRV Vault',
#   'yCRV',
#   41620315.981046066,
#   16.6201,
#   1.38500833333333,
#   0.04553452054795,
#   'NONE',
#   'CRV/Curve DAO Token'],
#  ['USDC Vault',
#   'USDC',
#   15719355.12214,
#   41.1502,
#   3.42918333333333,
#   0.1127402739726,
#   'NONE',
#   'USDC/USD Coin'],
#  ['aLINK Vault',
#   'aLINK',
#   11943638.254435511,
#   0.0057,
#   0.000475,
#   1.561643836e-05,
#   'NONE',
#   'ALINK/Aave LINK'],
#  ['USDT Vault',
#   'USDT',
#   10901052.86844,
#   40.1986,
#   3.34988333333333,
#   0.11013315068493,
#   'NONE',
#   'USDT/Tether'],
#  ['DAI Vault',
#   'DAI',
#   7289989.090530373,
#   40.7126,
#   3.39271666666667,
#   0.11154136986301,
#   'NONE',
#   'DAI/Dai'],
#  ['TUSD Vault',
#   'TUSD',
#   3856670.450665706,
#   42.2808,
#   3.5234,
#   0.11583780821918,
#   'NONE',
#   'TUSD/TrueUSD'],
#  ['dUSDT/dUSDC/dDAI',
#   'dUSDT-dUSDC-dDAI',
#   85374034.78,
#   1.1708,
#   0.09756666666667,
#   0.00320767123288,
#   'None',
#   'DF/dForce'],
#  ['Uniswap DF-USDx',
#   'DF-USDx',
#   494905.42852765915,
#   20.4803,
#   1.70669166666667,
#   0.0561104109589,
#   'None',
#   'DF/dForce'],
#  ['Uniswap GOLDx-USDx',
#   'GOLDx-USDx',
#   79789.26809423916,
#   29.7915,
#   2.482625,
#   0.08162054794521,
#   'None',
#   'DF/dForce'],
#  ['swUSD',
#   'DAI-USDC-USDT-TUSD',
#   25852843.680346794,
#   62.473,
#   5.20608333333333,
#   0.17115890410959,
#   'Low',
#   'SWRV/Swerve'],
#  ['SFI Staking Pool',
#   'SFI',
#   15059721.48,
#   10.1935,
#   0.84945833333333,
#   0.02792739726027,
#   'None',
#   'SFI/saffron.finance'],
#  ['SFI/ETH Uniswap LP Pool',
#   'SFI-ETH',
#   3232412.0332,
#   43.3973,
#   3.61644166666667,
#   0.11889671232877,
#   'High',
#   'SFI/saffron.finance'],
#  ['SFI/ETH SushiSwap Pool',
#   'SFI-ETH',
#   3149958.497,
#   43.858,
#   3.65483333333333,
#   0.12015890410959,
#   'High',
#   'SFI/saffron.finance'],
#  ['rSFI Staking Pool',
#   'rSFI',
#   2947294.6965,
#   61.6467,
#   5.137225,
#   0.16889506849315,
#   'None',
#   'SFI/saffron.finance'],
#  ['SFI/ESD Uniswap Pool',
#   'SFI-ESD',
#   109910.88235805,
#   97.908,
#   8.159,
#   0.26824109589041,
#   'High',
#   'SFI/saffron.finance'],
#  ['SFI/BTSE Pool',
#   'SFI-BTSE',
#   100483.17739999999,
#   58.264,
#   4.85533333333333,
#   0.15962739726027,
#   'High',
#   'SFI/saffron.finance'],
#  ['SFI/GEEQ Uniswap Pool',
#   'SFI-GEEQ',
#   69622.77620000001,
#   93.3303,
#   7.777525,
#   0.25569945205479,
#   'High',
#   'SFI/saffron.finance'],
#  ['USDT Vault',
#   'USDT',
#   9588306,
#   3.4609,
#   0.28840833333333,
#   0.00948191780822,
#   'None',
#   'FOR/ForTube'],
#  ['FOR Vault',
#   'FOR',
#   5097528,
#   5.1913,
#   0.43260833333333,
#   0.01422273972603,
#   'None',
#   'FOR/ForTube'],
#  ['ETH Vault',
#   'ETH',
#   3176820,
#   1.2978,
#   0.10815,
#   0.00355561643836,
#   'None',
#   'FOR/ForTube'],
#  ['HBTC Vault',
#   'HBTC',
#   1938891,
#   1.2978,
#   0.10815,
#   0.00355561643836,
#   'None',
#   'FOR/ForTube'],
#  ['USDC Vault',
#   'USDC',
#   1367397,
#   3.4609,
#   0.28840833333333,
#   0.00948191780822,
#   'None',
#   'FOR/ForTube'],
#  ['BUSD Vault',
#   'BUSD',
#   1100342,
#   3.4609,
#   0.28840833333333,
#   0.00948191780822,
#   'None',
#   'FOR/ForTube'],
#  ['WBTC Vault',
#   'WBTC',
#   218726,
#   1.2978,
#   0.10815,
#   0.00355561643836,
#   'None',
#   'FOR/ForTube'],
#  ['DAI Vault',
#   'DAI',
#   152322,
#   3.4609,
#   0.28840833333333,
#   0.00948191780822,
#   'None',
#   'FOR/ForTube'],
#  ['YFII Vault',
#   'YFII',
#   99696,
#   0.2596,
#   0.02163333333333,
#   0.00071123287671,
#   'None',
#   'FOR/ForTube'],
#  ['YYDAI+YUSDC+YUSDT+YTUSD Vault',
#   'yyDAI+yUSDC+yUSDT+yTUSD',
#   48595,
#   3.4609,
#   0.28840833333333,
#   0.00948191780822,
#   'None',
#   'FOR/ForTube'],
#  ['Uniswap MTA/WETH 50/50',
#   'MTA-wETH',
#   6001245.220436543,
#   60.9047,
#   5.07539166666667,
#   0.16686219178082,
#   'High',
#   'MTA/mStable Governance Token: Meta (MTA),BAL/Balancer'],
#  ['BEL-ETH',
#   'BEL-ETH',
#   1949097.0793866178,
#   129,
#   10.75,
#   0.35342465753425,
#   'High',
#   'BEL/Bella Protocol'],
#  ['BEL-USDT',
#   'BEL-USDT',
#   1003032.4880320563,
#   501,
#   41.75,
#   1.37260273972603,
#   'High',
#   'BEL/Bella Protocol'],
#  ['ARPA-USDT',
#   'ARPA-USDT',
#   585335.7193272285,
#   430,
#   35.83333333333333,
#   1.17808219178082,
#   'High',
#   'BEL/Bella Protocol'],
#  ['HodlTree balancer',
#   'HTRE-USDC',
#   1791237.1005000002,
#   111.3118,
#   9.27598333333333,
#   0.30496383561644,
#   'High',
#   'HTRE/HodlTree'],
#  ['HodlTree uniswap',
#   'HTRE-USDC',
#   29454.988592143403,
#   111.3118,
#   9.27598333333333,
#   0.30496383561644,
#   'High',
#   'HTRE/HodlTree'],
#  ['Balancer WETH-PERL 50/50',
#   'WETH-PERL',
#   653907.5691423632,
#   125.7912,
#   10.4826,
#   0.34463342465753,
#   'High',
#   'PERL/Perlin,BAL/Balancer'],
#  ['Balancer TUSD-PERL 50/50',
#   'TUSD-PERL',
#   154035.40062250657,
#   107.4773,
#   8.95644166666667,
#   0.29445835616438,
#   'High',
#   'PERL/Perlin,BAL/Balancer'],
#  ['Balancer BUSD-PERL 50/50',
#   'BUSD-PERL',
#   108925.26551513521,
#   161.41,
#   13.45083333333333,
#   0.44221917808219,
#   'High',
#   'PERL/Perlin,BAL/Balancer'],
#  ['Balancer DAI-PERL 50/50"',
#   'DAI-PERL',
#   87350.24405015854,
#   142.0428,
#   11.8369,
#   0.38915835616438,
#   'High',
#   'PERL/Perlin,BAL/Balancer'],
#  ['Balancer BAL-PERL 50/50',
#   'BAL-PERL',
#   13243.899347032466,
#   113.6272,
#   9.46893333333333,
#   0.31130739726027,
#   'High',
#   'PERL/Perlin,BAL/Balancer'],
#  ['MIC_USDT-SUSHI-LPV2',
#   'MIC-USDT',
#   684331,
#   6.4557,
#   0.537975,
#   0.01768684931507,
#   'High',
#   'MIS/Mithril Share'],
#  ['MIS_USDT-SUSHI-LPV2',
#   'MIS-USDT',
#   223126,
#   6.958,
#   0.57983333333333,
#   0.01906301369863,
#   'High',
#   'MIS/Mithril Share'],
#  ['sUSD liquidity gauge',
#   'DAI-USDT-USDC-sUSD',
#   116621.56291937767,
#   64.472,
#   5.37266666666667,
#   0.17663561643836,
#   'Low',
#   'SFG/S.Finance,CRV/Curve DAO Token,SNX/Synthetix'],
#  ['dfi liquidity gauge',
#   'DAI-USDC-USDT',
#   103886.31555852525,
#   265.512,
#   22.126,
#   0.7274301369863,
#   'Low',
#   'SFG/S.Finance'],
#  ['SFG liquidity gauge',
#   'SFG-DAI',
#   14852.63631380093,
#   503.8741,
#   41.98950833333333,
#   1.38047698630137,
#   'High',
#   'SFG/S.Finance']]

# %%
df = pd.DataFrame(farming_data, columns=['name','pair', 'tvl', 'APY_Yearly', 'APY_Monthly', 'APY_Daily', 'impermanent loass', 'rewards'])

# %%
df
# Out:
#                      name                pair           tvl  APY_Yearly  \
# 0       vBTC-BTCB Lending           vBTC-BTCB  2.299680e+09      3.0900
# 1        vETH-ETH Lending            vETH-ETH  1.637433e+09      2.2300
# 2        vBNB-BNB Lending            vBNB-BNB  1.582314e+09      6.2900
# 3      vUSDT-USDT Lending          vUSDT-USDT  5.416256e+08      7.7000
# 4        vXVS-XVS Lending            vXVS-XVS  5.293491e+08      9.6200
# ..                    ...                 ...           ...         ...
# 116   MIC_USDT-SUSHI-LPV2            MIC-USDT  6.843310e+05      6.4557
# 117   MIS_USDT-SUSHI-LPV2            MIS-USDT  2.231260e+05      6.9580
# 118  sUSD liquidity gauge  DAI-USDT-USDC-sUSD  1.166216e+05     64.4720
# 119   dfi liquidity gauge       DAI-USDC-USDT  1.038863e+05    265.5120
# 120   SFG liquidity gauge             SFG-DAI  1.485264e+04    503.8741
#
#      APY_Monthly impermanent loass  \
# 0       0.257500              None
# 1       0.185833              None
# 2       0.524167              None
# 3       0.641667              None
# 4       0.801667              None
# ..           ...               ...
# 116     0.537975              High
# 117     0.579833              High
# 118     5.372667               Low
# 119    22.126000               Low
# 120    41.989508              High
#
#                                              rewards
# 0                                          XVS/Venus
# 1                                          XVS/Venus
# 2                                          XVS/Venus
# 3                                          XVS/Venus
# 4                                          XVS/Venus
# ..                                               ...
# 116                                MIS/Mithril Share
# 117                                MIS/Mithril Share
# 118  SFG/S.Finance,CRV/Curve DAO Token,SNX/Synthetix
# 119                                    SFG/S.Finance
# 120                                    SFG/S.Finance
#
# [121 rows x 7 columns]

# %%
df
# Out:
#                      name                pair           tvl       APY  \
# 0       vBTC-BTCB Lending           vBTC-BTCB  2.299680e+09    3.0900
# 1        vETH-ETH Lending            vETH-ETH  1.637433e+09    2.2300
# 2        vBNB-BNB Lending            vBNB-BNB  1.582314e+09    6.2900
# 3      vUSDT-USDT Lending          vUSDT-USDT  5.416256e+08    7.7000
# 4        vXVS-XVS Lending            vXVS-XVS  5.293491e+08    9.6200
# ..                    ...                 ...           ...       ...
# 116   MIC_USDT-SUSHI-LPV2            MIC-USDT  6.843310e+05    6.4557
# 117   MIS_USDT-SUSHI-LPV2            MIS-USDT  2.231260e+05    6.9580
# 118  sUSD liquidity gauge  DAI-USDT-USDC-sUSD  1.166216e+05   64.4720
# 119   dfi liquidity gauge       DAI-USDC-USDT  1.038863e+05  265.5120
# 120   SFG liquidity gauge             SFG-DAI  1.485264e+04  503.8741
#
#     impermanent loass                                          rewards
# 0                None                                        XVS/Venus
# 1                None                                        XVS/Venus
# 2                None                                        XVS/Venus
# 3                None                                        XVS/Venus
# 4                None                                        XVS/Venus
# ..                ...                                              ...
# 116              High                                MIS/Mithril Share
# 117              High                                MIS/Mithril Share
# 118               Low  SFG/S.Finance,CRV/Curve DAO Token,SNX/Synthetix
# 119               Low                                    SFG/S.Finance
# 120              High                                    SFG/S.Finance
#
# [121 rows x 6 columns]

# %%
df['pair_size'] = df['pair'].str.split("-").apply(lambda x: len(x))

# %%
df = df[df['pair_size'] <=2 ]

# %%
df
# Out:
#                          name        pair           tvl       APY  \
# 0           vBTC-BTCB Lending   vBTC-BTCB  2.299680e+09    3.0900
# 1            vETH-ETH Lending    vETH-ETH  1.637433e+09    2.2300
# 2            vBNB-BNB Lending    vBNB-BNB  1.582314e+09    6.2900
# 3          vUSDT-USDT Lending  vUSDT-USDT  5.416256e+08    7.7000
# 4            vXVS-XVS Lending    vXVS-XVS  5.293491e+08    9.6200
# ..                        ...         ...           ...       ...
# 114  Balancer DAI-PERL 50/50"    DAI-PERL  8.735024e+04  142.0428
# 115   Balancer BAL-PERL 50/50    BAL-PERL  1.324390e+04  113.6272
# 116       MIC_USDT-SUSHI-LPV2    MIC-USDT  6.843310e+05    6.4557
# 117       MIS_USDT-SUSHI-LPV2    MIS-USDT  2.231260e+05    6.9580
# 120       SFG liquidity gauge     SFG-DAI  1.485264e+04  503.8741
#
#     impermanent loass                   rewards  pair_size
# 0                None                 XVS/Venus          2
# 1                None                 XVS/Venus          2
# 2                None                 XVS/Venus          2
# 3                None                 XVS/Venus          2
# 4                None                 XVS/Venus          2
# ..                ...                       ...        ...
# 114              High  PERL/Perlin,BAL/Balancer          2
# 115              High  PERL/Perlin,BAL/Balancer          2
# 116              High         MIS/Mithril Share          2
# 117              High         MIS/Mithril Share          2
# 120              High             SFG/S.Finance          2
#
# [114 rows x 7 columns]

# %%
df[['pair1', 'pair2']] = df['pair'].str.split("-", expand=True)[[0,1]]
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/frame.py:3188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %% [markdown]
# ### cmc Farming symbols to modify (WBNB = BNB, vBNB = BNB, vETH = ETH, vUSDT = USDT, vBUSD = BUSD, vXVS = XVS, vSXP = SXP, vUSDC = USDC, vXRP = XRP, lowercase V followed by anything letters can remove the v and it’s the same)

# %%
symbol_mappings = {}
symbol_mappings['WBNB'] = 'BNB'
symbol_mappings['vBNB'] = 'BNB'
symbol_mappings['vETH'] = 'ETH'
symbol_mappings['vUSDT'] = 'USDT'
symbol_mappings['vBUSD'] = 'BUSD'
symbol_mappings['vXVS'] = 'XVS'
symbol_mappings['vSXP'] = 'SXP'
symbol_mappings['vUSDC'] = 'USDC'
symbol_mappings['vXRP'] = 'XRP'

# %%
for index, row in df.iterrows():
    if row['pair1'] in symbol_mappings:
        print(row['pair1'])
        df.loc[index, 'pair1'] = symbol_mappings[row['pair1']]
        row['pair1'] = 'AAAAAA'
    if row['pair2'] in symbol_mappings:
        print(row['pair2'])
        row['pair2'] = symbol_mappings[row['pair1']]

# %%
df[df['pair2'] == 'BNB']
# Out:
#                      name       pair           tvl          APY  \
# 2        vBNB-BNB Lending   vBNB-BNB  1.582314e+09       6.2900
# 15   PancakeSWAP BUSD-BNB  BUSD-WBNB  4.009053e+07    1730.2702
# 16   PancakeSWAP CAKE-BNB  CAKE-WBNB  2.819195e+07    9227.0261
# 17    PancakeSWAP ETH-BNB    ETH-BNB  1.525450e+07    1136.8356
# 19    PancakeSWAP BTC-BNB    BTC-BNB  1.257275e+07    1379.3215
# 20    PancakeSWAP DOT-BNB   DOT-WBNB  8.551633e+06    2027.9005
# 21    PancakeSWAP ADA-BNB   ADA-WBNB  2.827959e+06    3066.1444
# 22   PancakeSWAP USDT-BNB   USDT-BNB  2.615753e+06    6629.7771
# 23    PancakeSWAP TWT-BNB    TWT-BNB  1.961499e+06    8841.1259
# 24   PancakeSWAP LINK-BNB  LINK-WBNB  1.571880e+06   11032.5585
# 25   PancakeSWAP BAND-BNB  BAND-WBNB  5.881058e+05   29487.6524
# 26    PancakeSWAP XRP-BNB    XRP-BNB  3.003893e+05   28865.6387
# 27  PancakeSWAP ALPHA-BNB  ALPHA-BNB  2.984548e+05   29052.7382
# 28   PancakeSWAP ATOM-BNB   ATOM-BNB  2.600824e+05   33339.1604
# 29    PancakeSWAP DAI-BNB    DAI-BNB  1.048455e+05   82702.0090
# 30    PancakeSWAP EOS-BNB   EOS-WBNB  8.594182e+04  100893.0188
# 31    PancakeSWAP XTZ-BNB    XTZ-BNB  8.379172e+04  103481.9477
# 32    PancakeSWAP BCH-BNB    BCH-BNB  1.928470e+04  449627.5184
# 33   PancakeSWAP YFII-BNB   YFII-BNB  1.398458e+04  620035.2519
# 51               Doughnut   BAKE-BNB  7.287008e+07      67.0300
# 52                   Cake    BTC-BNB  5.267880e+07     108.1800
# 54              Croissant   BUSD-BNB  4.000603e+06     122.1000
# 55                  Toast    ETH-BNB  1.883449e+06      86.4500
#
#    impermanent loass           rewards  pair_size  pair1 pair2    Pool_rate  \
# 2               None         XVS/Venus          2    BNB   BNB       6.2900
# 15              High  CAKE/PancakeSwap          2   BUSD   BNB    1730.2702
# 16              High  CAKE/PancakeSwap          2   CAKE   BNB    9227.0261
# 17              High  CAKE/PancakeSwap          2    ETH   BNB    1136.8356
# 19              High  CAKE/PancakeSwap          2    BTC   BNB    1379.3215
# 20              High  CAKE/PancakeSwap          2    DOT   BNB    2027.9005
# 21              High  CAKE/PancakeSwap          2    ADA   BNB    3066.1444
# 22              High  CAKE/PancakeSwap          2   USDT   BNB    6629.7771
# 23              High  CAKE/PancakeSwap          2    TWT   BNB    8841.1259
# 24              High  CAKE/PancakeSwap          2   LINK   BNB   11032.5585
# 25              High  CAKE/PancakeSwap          2   BAND   BNB   29487.6524
# 26              High  CAKE/PancakeSwap          2    XRP   BNB   28865.6387
# 27              High  CAKE/PancakeSwap          2  ALPHA   BNB   29052.7382
# 28              High  CAKE/PancakeSwap          2   ATOM   BNB   33339.1604
# 29              High  CAKE/PancakeSwap          2    DAI   BNB   82702.0090
# 30              High  CAKE/PancakeSwap          2    EOS   BNB  100893.0188
# 31              High  CAKE/PancakeSwap          2    XTZ   BNB  103481.9477
# 32              High  CAKE/PancakeSwap          2    BCH   BNB  449627.5184
# 33              High  CAKE/PancakeSwap          2   YFII   BNB  620035.2519
# 51              High  BAKE/BakeryToken          2   BAKE   BNB      67.0300
# 52              High  BAKE/BakeryToken          2    BTC   BNB     108.1800
# 54              High  BAKE/BakeryToken          2   BUSD   BNB     122.1000
# 55              High  BAKE/BakeryToken          2    ETH   BNB      86.4500
#
#        Pool_size  includes_stablecoin Farm payment        Where
# 2   1.582314e+09                False          XVS        Venus
# 15  4.009053e+07                 True         CAKE  PancakeSwap
# 16  2.819195e+07                False         CAKE  PancakeSwap
# 17  1.525450e+07                False         CAKE  PancakeSwap
# 19  1.257275e+07                False         CAKE  PancakeSwap
# 20  8.551633e+06                False         CAKE  PancakeSwap
# 21  2.827959e+06                False         CAKE  PancakeSwap
# 22  2.615753e+06                 True         CAKE  PancakeSwap
# 23  1.961499e+06                False         CAKE  PancakeSwap
# 24  1.571880e+06                False         CAKE  PancakeSwap
# 25  5.881058e+05                False         CAKE  PancakeSwap
# 26  3.003893e+05                False         CAKE  PancakeSwap
# 27  2.984548e+05                False         CAKE  PancakeSwap
# 28  2.600824e+05                False         CAKE  PancakeSwap
# 29  1.048455e+05                 True         CAKE  PancakeSwap
# 30  8.594182e+04                False         CAKE  PancakeSwap
# 31  8.379172e+04                False         CAKE  PancakeSwap
# 32  1.928470e+04                False         CAKE  PancakeSwap
# 33  1.398458e+04                False         CAKE  PancakeSwap
# 51  7.287008e+07                False         BAKE  BakeryToken
# 52  5.267880e+07                False         BAKE  BakeryToken
# 54  4.000603e+06                 True         BAKE  BakeryToken
# 55  1.883449e+06                False         BAKE  BakeryToken

# %%
df['Pool_rate'] = df['APY']
df['Pool_size'] = df['tvl']
# Out:
# <ipython-input-18-0ada91f6eca8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pool_rate'] = df['APY']
# <ipython-input-18-0ada91f6eca8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Pool_size'] = df['tvl']

# %%
df['includes_stablecoin'] = (df['pair1'].isin(stable_coins)) | (df['pair2'].isin(stable_coins))
# Out:
# <ipython-input-19-51d2910a5f37>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['includes_stablecoin'] = (df['pair1'].isin(stable_coins)) | (df['pair2'].isin(stable_coins))

# %%
df['Farm payment'] = df['rewards'].str.split("/", expand=True)[0]
# Out:
# <ipython-input-20-06b6ad36b2f2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Farm payment'] = df['rewards'].str.split("/", expand=True)[0]

# %%
df['Where'] = df['rewards'].str.split("/", expand=True)[1]
# Out:
# <ipython-input-21-e99b077bec5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Where'] = df['rewards'].str.split("/", expand=True)[1]

# %%
df = df.reset_index(drop = True)
df
# Out:
#                          name        pair           tvl       APY  \
# 0           vBTC-BTCB Lending   vBTC-BTCB  2.299680e+09    3.0900
# 1            vETH-ETH Lending    vETH-ETH  1.637433e+09    2.2300
# 2            vBNB-BNB Lending    vBNB-BNB  1.582314e+09    6.2900
# 3          vUSDT-USDT Lending  vUSDT-USDT  5.416256e+08    7.7000
# 4            vXVS-XVS Lending    vXVS-XVS  5.293491e+08    9.6200
# ..                        ...         ...           ...       ...
# 109  Balancer DAI-PERL 50/50"    DAI-PERL  8.735024e+04  142.0428
# 110   Balancer BAL-PERL 50/50    BAL-PERL  1.324390e+04  113.6272
# 111       MIC_USDT-SUSHI-LPV2    MIC-USDT  6.843310e+05    6.4557
# 112       MIS_USDT-SUSHI-LPV2    MIS-USDT  2.231260e+05    6.9580
# 113       SFG liquidity gauge     SFG-DAI  1.485264e+04  503.8741
#
#     impermanent loass                   rewards  pair_size  pair1 pair2  \
# 0                None                 XVS/Venus          2   vBTC  BTCB
# 1                None                 XVS/Venus          2   vETH   ETH
# 2                None                 XVS/Venus          2   vBNB   BNB
# 3                None                 XVS/Venus          2  vUSDT  USDT
# 4                None                 XVS/Venus          2   vXVS   XVS
# ..                ...                       ...        ...    ...   ...
# 109              High  PERL/Perlin,BAL/Balancer          2    DAI  PERL
# 110              High  PERL/Perlin,BAL/Balancer          2    BAL  PERL
# 111              High         MIS/Mithril Share          2    MIC  USDT
# 112              High         MIS/Mithril Share          2    MIS  USDT
# 113              High             SFG/S.Finance          2    SFG   DAI
#
#      Pool_rate     Pool_size  includes_stablecoin Farm payment          Where
# 0       3.0900  2.299680e+09                False          XVS          Venus
# 1       2.2300  1.637433e+09                False          XVS          Venus
# 2       6.2900  1.582314e+09                False          XVS          Venus
# 3       7.7000  5.416256e+08                 True          XVS          Venus
# 4       9.6200  5.293491e+08                False          XVS          Venus
# ..         ...           ...                  ...          ...            ...
# 109   142.0428  8.735024e+04                 True         PERL     Perlin,BAL
# 110   113.6272  1.324390e+04                False         PERL     Perlin,BAL
# 111     6.4557  6.843310e+05                 True          MIS  Mithril Share
# 112     6.9580  2.231260e+05                 True          MIS  Mithril Share
# 113   503.8741  1.485264e+04                 True          SFG      S.Finance
#
# [114 rows x 14 columns]

# %% [markdown]
# ###  where = [pancakeswap, sushiswap, bakery, sun]

# %%
df[df['Where'].isin(['PancakeSwap', 'SushiSwap', 'BakeryToken', 'SUN'])]
# Out:
#                      name       pair           tvl          APY  \
# 14                   CAKE       CAKE  5.064157e+09      86.2093
# 15   PancakeSWAP BUSD-BNB  BUSD-WBNB  4.009053e+07    1730.2702
# 16   PancakeSWAP CAKE-BNB  CAKE-WBNB  2.819195e+07    9227.0261
# 17    PancakeSWAP ETH-BNB    ETH-BNB  1.525450e+07    1136.8356
# 18  PancakeSWAP USDT-BUSD  USDT-BUSD  1.296448e+07     668.8220
# 19    PancakeSWAP BTC-BNB    BTC-BNB  1.257275e+07    1379.3215
# 20    PancakeSWAP DOT-BNB   DOT-WBNB  8.551633e+06    2027.9005
# 21    PancakeSWAP ADA-BNB   ADA-WBNB  2.827959e+06    3066.1444
# 22   PancakeSWAP USDT-BNB   USDT-BNB  2.615753e+06    6629.7771
# 23    PancakeSWAP TWT-BNB    TWT-BNB  1.961499e+06    8841.1259
# 24   PancakeSWAP LINK-BNB  LINK-WBNB  1.571880e+06   11032.5585
# 25   PancakeSWAP BAND-BNB  BAND-WBNB  5.881058e+05   29487.6524
# 26    PancakeSWAP XRP-BNB    XRP-BNB  3.003893e+05   28865.6387
# 27  PancakeSWAP ALPHA-BNB  ALPHA-BNB  2.984548e+05   29052.7382
# 28   PancakeSWAP ATOM-BNB   ATOM-BNB  2.600824e+05   33339.1604
# 29    PancakeSWAP DAI-BNB    DAI-BNB  1.048455e+05   82702.0090
# 30    PancakeSWAP EOS-BNB   EOS-WBNB  8.594182e+04  100893.0188
# 31    PancakeSWAP XTZ-BNB    XTZ-BNB  8.379172e+04  103481.9477
# 32    PancakeSWAP BCH-BNB    BCH-BNB  1.928470e+04  449627.5184
# 33   PancakeSWAP YFII-BNB   YFII-BNB  1.398458e+04  620035.2519
# 34           Sushi Party!  SUSHI-ETH  6.253929e+08      31.4421
# 35           Circle Snail   USDC-ETH  3.522213e+08      33.3919
# 36             Donald DAI    DAI-ETH  3.180252e+08      38.8245
# 37          Tether Turtle   USDT-ETH  2.776074e+08      37.2610
# 38              YFI Whale    YFI-ETH  1.737667e+08      47.6221
# 39          Toadie Marine   LINK-ETH  1.198031e+08      31.5273
# 40        Synthetic Snake    SNX-ETH  6.257735e+07      34.5653
# 41         Spartan Dollar   SUSD-ETH  2.693243e+07      41.5251
# 42       Compound Truffle   COMP-ETH  2.493103e+07      24.4833
# 43          CRV Crocodile    CRV-ETH  2.021287e+07      20.2673
# 44           Band-osaurus   BAND-ETH  1.531397e+07      37.9861
# 45            Umami Squid    UMA-ETH  1.456637e+07      28.1237
# 46              REN Rhino    ren-ETH  1.240579e+07      33.0217
# 50                  Bread       BAKE  2.869298e+08      11.9200
# 51               Doughnut   BAKE-BNB  7.287008e+07      67.0300
# 52                   Cake    BTC-BNB  5.267880e+07     108.1800
# 53                 Waffle  BAKE-BUSD  7.412056e+06     175.7400
# 54              Croissant   BUSD-BNB  4.000603e+06     122.1000
# 55                  Toast    ETH-BNB  1.883449e+06      86.4500
# 64       USDT/TRX LP Pool   USDT-TRX  5.332924e+07      22.3932
# 65                HT Pool         HT  4.260480e+07      17.2670
# 66        SUN/TRX LP Pool    SUN-TRX  2.820848e+07      42.3353
# 67        JST/TRX LP Pool    JST-TRX  1.955443e+07      27.1428
# 68               SUN Pool    SUN-TRX  1.494126e+07      26.6424
# 69       USDJ/TRX LP Pool   USDJ-TRX  1.090501e+07      36.5035
# 70         HT/TRX LP Pool     HT-TRX  9.594999e+06      32.8590
# 71        WIN/TRX LP Pool    WIN-TRX  2.788547e+06      47.5841
#
#    impermanent loass           rewards  pair_size  pair1 pair2    Pool_rate  \
# 14              None  CAKE/PancakeSwap          1   CAKE  None      86.2093
# 15              High  CAKE/PancakeSwap          2   BUSD  WBNB    1730.2702
# 16              High  CAKE/PancakeSwap          2   CAKE  WBNB    9227.0261
# 17              High  CAKE/PancakeSwap          2    ETH   BNB    1136.8356
# 18               Low  CAKE/PancakeSwap          2   USDT  BUSD     668.8220
# 19              High  CAKE/PancakeSwap          2    BTC   BNB    1379.3215
# 20              High  CAKE/PancakeSwap          2    DOT  WBNB    2027.9005
# 21              High  CAKE/PancakeSwap          2    ADA  WBNB    3066.1444
# 22              High  CAKE/PancakeSwap          2   USDT   BNB    6629.7771
# 23              High  CAKE/PancakeSwap          2    TWT   BNB    8841.1259
# 24              High  CAKE/PancakeSwap          2   LINK  WBNB   11032.5585
# 25              High  CAKE/PancakeSwap          2   BAND  WBNB   29487.6524
# 26              High  CAKE/PancakeSwap          2    XRP   BNB   28865.6387
# 27              High  CAKE/PancakeSwap          2  ALPHA   BNB   29052.7382
# 28              High  CAKE/PancakeSwap          2   ATOM   BNB   33339.1604
# 29              High  CAKE/PancakeSwap          2    DAI   BNB   82702.0090
# 30              High  CAKE/PancakeSwap          2    EOS  WBNB  100893.0188
# 31              High  CAKE/PancakeSwap          2    XTZ   BNB  103481.9477
# 32              High  CAKE/PancakeSwap          2    BCH   BNB  449627.5184
# 33              High  CAKE/PancakeSwap          2   YFII   BNB  620035.2519
# 34              High   SUSHI/SushiSwap          2  SUSHI   ETH      31.4421
# 35              High   SUSHI/SushiSwap          2   USDC   ETH      33.3919
# 36              High   SUSHI/SushiSwap          2    DAI   ETH      38.8245
# 37              High   SUSHI/SushiSwap          2   USDT   ETH      37.2610
# 38              High   SUSHI/SushiSwap          2    YFI   ETH      47.6221
# 39              High   SUSHI/SushiSwap          2   LINK   ETH      31.5273
# 40              High   SUSHI/SushiSwap          2    SNX   ETH      34.5653
# 41              High   SUSHI/SushiSwap          2   SUSD   ETH      41.5251
# 42              High   SUSHI/SushiSwap          2   COMP   ETH      24.4833
# 43              High   SUSHI/SushiSwap          2    CRV   ETH      20.2673
# 44              High   SUSHI/SushiSwap          2   BAND   ETH      37.9861
# 45              High   SUSHI/SushiSwap          2    UMA   ETH      28.1237
# 46              High   SUSHI/SushiSwap          2    ren   ETH      33.0217
# 50              High  BAKE/BakeryToken          1   BAKE  None      11.9200
# 51              High  BAKE/BakeryToken          2   BAKE   BNB      67.0300
# 52              High  BAKE/BakeryToken          2    BTC   BNB     108.1800
# 53              High  BAKE/BakeryToken          2   BAKE  BUSD     175.7400
# 54              High  BAKE/BakeryToken          2   BUSD   BNB     122.1000
# 55              High  BAKE/BakeryToken          2    ETH   BNB      86.4500
# 64              High           SUN/SUN          2   USDT   TRX      22.3932
# 65              None           SUN/SUN          1     HT  None      17.2670
# 66              High           SUN/SUN          2    SUN   TRX      42.3353
# 67              High           SUN/SUN          2    JST   TRX      27.1428
# 68              High           SUN/SUN          2    SUN   TRX      26.6424
# 69              High           SUN/SUN          2   USDJ   TRX      36.5035
# 70              High           SUN/SUN          2     HT   TRX      32.8590
# 71              High           SUN/SUN          2    WIN   TRX      47.5841
#
#        Pool_size  includes_stablecoin Farm payment        Where
# 14  5.064157e+09                False         CAKE  PancakeSwap
# 15  4.009053e+07                 True         CAKE  PancakeSwap
# 16  2.819195e+07                False         CAKE  PancakeSwap
# 17  1.525450e+07                False         CAKE  PancakeSwap
# 18  1.296448e+07                 True         CAKE  PancakeSwap
# 19  1.257275e+07                False         CAKE  PancakeSwap
# 20  8.551633e+06                False         CAKE  PancakeSwap
# 21  2.827959e+06                False         CAKE  PancakeSwap
# 22  2.615753e+06                 True         CAKE  PancakeSwap
# 23  1.961499e+06                False         CAKE  PancakeSwap
# 24  1.571880e+06                False         CAKE  PancakeSwap
# 25  5.881058e+05                False         CAKE  PancakeSwap
# 26  3.003893e+05                False         CAKE  PancakeSwap
# 27  2.984548e+05                False         CAKE  PancakeSwap
# 28  2.600824e+05                False         CAKE  PancakeSwap
# 29  1.048455e+05                 True         CAKE  PancakeSwap
# 30  8.594182e+04                False         CAKE  PancakeSwap
# 31  8.379172e+04                False         CAKE  PancakeSwap
# 32  1.928470e+04                False         CAKE  PancakeSwap
# 33  1.398458e+04                False         CAKE  PancakeSwap
# 34  6.253929e+08                False        SUSHI    SushiSwap
# 35  3.522213e+08                 True        SUSHI    SushiSwap
# 36  3.180252e+08                 True        SUSHI    SushiSwap
# 37  2.776074e+08                 True        SUSHI    SushiSwap
# 38  1.737667e+08                False        SUSHI    SushiSwap
# 39  1.198031e+08                False        SUSHI    SushiSwap
# 40  6.257735e+07                False        SUSHI    SushiSwap
# 41  2.693243e+07                 True        SUSHI    SushiSwap
# 42  2.493103e+07                False        SUSHI    SushiSwap
# 43  2.021287e+07                False        SUSHI    SushiSwap
# 44  1.531397e+07                False        SUSHI    SushiSwap
# 45  1.456637e+07                False        SUSHI    SushiSwap
# 46  1.240579e+07                False        SUSHI    SushiSwap
# 50  2.869298e+08                False         BAKE  BakeryToken
# 51  7.287008e+07                False         BAKE  BakeryToken
# 52  5.267880e+07                False         BAKE  BakeryToken
# 53  7.412056e+06                 True         BAKE  BakeryToken
# 54  4.000603e+06                 True         BAKE  BakeryToken
# 55  1.883449e+06                False         BAKE  BakeryToken
# 64  5.332924e+07                 True          SUN          SUN
# 65  4.260480e+07                False          SUN          SUN
# 66  2.820848e+07                False          SUN          SUN
# 67  1.955443e+07                False          SUN          SUN
# 68  1.494126e+07                False          SUN          SUN
# 69  1.090501e+07                False          SUN          SUN
# 70  9.594999e+06                False          SUN          SUN
# 71  2.788547e+06                False          SUN          SUN

# %%
df['Where'].unique()
# Out:
# array(['Venus', 'Venus,LINK', 'Venus,DOT', 'Venus,BCH', 'PancakeSwap',
#        'SushiSwap', 'Curve DAO Token', 'BakeryToken',
#        'Harvest Finance,CRV', 'Harvest Finance', 'Harvest Finance,CREAM',
#        'Synthetix,CRV', 'SUN', 'Wrapped Bitcoin', 'Tether', 'WETH',
#        'USD Coin', 'Aave LINK', 'Dai', 'TrueUSD', 'dForce',
#        'saffron.finance', 'ForTube',
#        'mStable Governance Token: Meta (MTA),BAL', 'Bella Protocol',
#        'HodlTree', 'Perlin,BAL', 'Mithril Share', 'S.Finance'],
#       dtype=object)

# %%
df.to_csv('farming_data_cmc_new.csv')
