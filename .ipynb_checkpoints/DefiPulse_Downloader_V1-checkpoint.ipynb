# %%
import requests
import pandas as pd
import time

# %%
api_key = "3a2957dbae161d9aac23aadb136880f304a1653c2003ca11cc478e2f30f8"

# %%
payload_projects = {'api-key': api_key} 
url_projects = 'https://data-api.defipulse.com/api/v1/defipulse/api/GetProjects'

# %%
res_proj = requests.get(url_projects,params= payload_projects).json()

# %%
res_proj
# Out:
# [{'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 0,
#   'name': 'Maker',
#   'value': {'tvl': {'USD': {'value': 6897687750, 'relative_1d': -3.98},
#     'ETH': {'value': 3886721.9724119278, 'relative_1d': 0.84},
#     'BTC': {'value': 122881.7219683201, 'relative_1d': 2.51}},
#    'total': {'USD': {'value': 6897687750, 'relative_1d': -3.98},
#     'ETH': {'value': 2999897.51387, 'relative_1d': 0.17},
#     'BTC': {'value': 13905.280677, 'relative_1d': 0.65}},
#    'balance': {'ERC20': {'DAI': {'value': 19481897.218611,
#       'relative_1d': 26.67}}}},
#   'contributesTo': None,
#   'relative_1d': -3.98,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'permissioning': 'Open',
#   'variability': 'Medium',
#   'website': 'https://compound.finance',
#   'chain': 'Ethereum',
#   'id': 1,
#   'name': 'Compound',
#   'value': {'tvl': {'USD': {'value': 6359608556, 'relative_1d': -4.62},
#     'ETH': {'value': 3583524.1035003494, 'relative_1d': 0.17},
#     'BTC': {'value': 113295.88678550166, 'relative_1d': 1.83}},
#    'total': {'USD': {'value': 6359608556, 'relative_1d': -4.62},
#     'ETH': {'value': 1255642.045734, 'relative_1d': -0.05},
#     'BTC': {'value': 41822.129672, 'relative_1d': 0.35}},
#    'balance': {'ERC20': {'DAI': {'value': 428551521.54652405,
#       'relative_1d': 1.19}}}},
#   'contributesTo': None,
#   'relative_1d': -4.62,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'variability': 'medium',
#   'website': 'https://aave.com',
#   'chain': 'Ethereum',
#   'id': 22,
#   'name': 'Aave',
#   'value': {'tvl': {'USD': {'value': 4972439748, 'relative_1d': -3.7},
#     'ETH': {'value': 2801879.6335113933, 'relative_1d': 1.14},
#     'BTC': {'value': 88583.5921781121, 'relative_1d': 2.82}},
#    'total': {'USD': {'value': 4972439748, 'relative_1d': -3.7},
#     'ETH': {'value': 585019.486306, 'relative_1d': -0.68},
#     'BTC': {'value': 9455.191334, 'relative_1d': 0.78}},
#    'balance': {'ERC20': {'DAI': {'value': 13924728.955735,
#       'relative_1d': -19.13}}}},
#   'contributesTo': None,
#   'relative_1d': -3.7,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 43,
#   'name': 'SushiSwap',
#   'value': {'tvl': {'USD': {'value': 4520025116, 'relative_1d': -4.73},
#     'ETH': {'value': 2546952.191944463, 'relative_1d': 0.06},
#     'BTC': {'value': 80523.86389832386, 'relative_1d': 1.72}},
#    'total': {'USD': {'value': 4520025116, 'relative_1d': -4.73},
#     'ETH': {'value': 1259043.402902, 'relative_1d': -0.48},
#     'BTC': {'value': 12381.40361, 'relative_1d': 0.06}},
#    'balance': {'ERC20': {'DAI': {'value': 251830220.844715,
#       'relative_1d': -0.01}}}},
#   'contributesTo': None,
#   'relative_1d': -4.73,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 2,
#   'name': 'Uniswap',
#   'value': {'tvl': {'USD': {'value': 4139393595, 'relative_1d': -2.33},
#     'ETH': {'value': 2332473.231793901, 'relative_1d': 2.58},
#     'BTC': {'value': 73742.94564990058, 'relative_1d': 4.28}},
#    'total': {'USD': {'value': 4139393595, 'relative_1d': -2.33},
#     'ETH': {'value': 1156016.088751, 'relative_1d': 1.78},
#     'BTC': {'value': 4436.706322, 'relative_1d': 0.58}},
#    'balance': {'ERC20': {'DAI': {'value': 136316973.97095326,
#       'relative_1d': -1.33}}}},
#   'contributesTo': None,
#   'relative_1d': -2.33,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 33,
#   'name': 'Curve Finance',
#   'value': {'tvl': {'USD': {'value': 4113000286, 'relative_1d': -1.88},
#     'ETH': {'value': 2317601.080758221, 'relative_1d': 3.05},
#     'BTC': {'value': 73272.75108964929, 'relative_1d': 4.75}},
#    'total': {'USD': {'value': 4113000286, 'relative_1d': -1.88},
#     'ETH': {'value': 234311.408447, 'relative_1d': 5.84},
#     'BTC': {'value': 19249.033923, 'relative_1d': -0.59}},
#    'balance': {'ERC20': {'DAI': {'value': 349409183.6474167,
#       'relative_1d': -1.85}}}},
#   'contributesTo': None,
#   'relative_1d': -1.88,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 12,
#   'name': 'Synthetix',
#   'value': {'tvl': {'USD': {'value': 2196983051, 'relative_1d': -2.32},
#     'ETH': {'value': 1237960.111682106, 'relative_1d': 2.59},
#     'BTC': {'value': 39139.066630276735, 'relative_1d': 4.29}},
#    'total': {'USD': {'value': 2196983051, 'relative_1d': -2.32},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -2.32,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 28,
#   'name': 'Balancer',
#   'value': {'tvl': {'USD': {'value': 1754125255, 'relative_1d': -0.73},
#     'ETH': {'value': 988417.7739085356, 'relative_1d': 4.26},
#     'BTC': {'value': 31249.59257289062, 'relative_1d': 5.99}},
#    'total': {'USD': {'value': 1754125255, 'relative_1d': -0.73},
#     'ETH': {'value': 308035.321773, 'relative_1d': 2.87},
#     'BTC': {'value': 3773.954401, 'relative_1d': 3.73}},
#    'balance': {'ERC20': {'DAI': {'value': 47668410.67289967,
#       'relative_1d': -1.9}}}},
#   'contributesTo': None,
#   'relative_1d': -0.73,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 14,
#   'name': 'Bancor',
#   'value': {'tvl': {'USD': {'value': 1553259372, 'relative_1d': -1.09},
#     'ETH': {'value': 875233.4911082562, 'relative_1d': 3.88},
#     'BTC': {'value': 27671.183911563912, 'relative_1d': 5.6}},
#    'total': {'USD': {'value': 1553259372, 'relative_1d': -1.09},
#     'ETH': {'value': 85956.32159, 'relative_1d': 2.99},
#     'BTC': {'value': 2577.2022220000003, 'relative_1d': 7.13}},
#    'balance': {'ERC20': {'DAI': {'value': 37097379.884297,
#       'relative_1d': -1.64}}}},
#   'contributesTo': None,
#   'relative_1d': -1.09,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 63,
#   'name': 'Badger DAO',
#   'value': {'tvl': {'USD': {'value': 1385284428, 'relative_1d': 9.48},
#     'ETH': {'value': 780582.656028129, 'relative_1d': 14.98},
#     'BTC': {'value': 24678.724537587157, 'relative_1d': 16.89}},
#    'total': {'USD': {'value': 1385284428, 'relative_1d': 9.48},
#     'ETH': {'value': 76987.228561, 'relative_1d': 0.09},
#     'BTC': {'value': 12150.889466999999, 'relative_1d': 5.07}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': 9.48,
#   'timestamp': 1615640400},
#  {'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 13,
#   'name': 'InstaDApp',
#   'value': {'tvl': {'USD': {'value': 1038330883, 'relative_1d': -1.04},
#     'ETH': {'value': 585080.6246759979, 'relative_1d': 3.93},
#     'BTC': {'value': 18497.776573885403, 'relative_1d': 5.66}},
#    'total': {'USD': {'value': 1038330883, 'relative_1d': -1.04},
#     'ETH': {'value': 60350.664748, 'relative_1d': -0.42},
#     'BTC': {'value': 215.716651, 'relative_1d': 5.58}},
#    'balance': {'ERC20': {'DAI': {'value': 860300918.1760601,
#       'relative_1d': -1.3}}}},
#   'contributesTo': ['Maker', 'Compound'],
#   'relative_1d': -1.04,
#   'timestamp': 1614697200},
#  {'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 49,
#   'name': 'Alpha Homora',
#   'value': {'tvl': {'USD': {'value': 847194204, 'relative_1d': -3.08},
#     'ETH': {'value': 477378.5719115559, 'relative_1d': 1.8},
#     'BTC': {'value': 15092.692856254656, 'relative_1d': 3.48}},
#    'total': {'USD': {'value': 847194204, 'relative_1d': -3.08},
#     'ETH': {'value': 475514.983684, 'relative_1d': 0.98},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': ['Uniswap', 'Sushiswap'],
#   'relative_1d': -3.08,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 30,
#   'name': 'RenVM',
#   'value': {'tvl': {'USD': {'value': 742172738, 'relative_1d': -5.53},
#     'ETH': {'value': 418200.8801586765, 'relative_1d': -0.78},
#     'BTC': {'value': 13221.744350979483, 'relative_1d': 0.86}},
#    'total': {'USD': {'value': 742172738, 'relative_1d': -5.53},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': 13221.802069, 'relative_1d': 0.74}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -5.53,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'website': 'https://vesper.finance',
#   'chain': 'Ethereum',
#   'id': 71,
#   'name': 'Vesper',
#   'value': {'tvl': {'USD': {'value': 700656819, 'relative_1d': -2.89},
#     'ETH': {'value': 394807.4126039624, 'relative_1d': 1.99},
#     'BTC': {'value': 12482.141776795503, 'relative_1d': 3.68}},
#    'total': {'USD': {'value': 700656819, 'relative_1d': -2.89},
#     'ETH': {'value': 133527.524454, 'relative_1d': 0.11},
#     'BTC': {'value': 4717.235085, 'relative_1d': 0.41}},
#    'balance': {'ERC20': {'DAI': {'value': 132408.947765,
#       'relative_1d': -6.9}}}},
#   'contributesTo': ['Aave', 'Maker', 'Compound'],
#   'relative_1d': -2.89,
#   'timestamp': 1615824000},
#  {'category': 'Payments',
#   'website': 'https://flexa.network',
#   'chain': 'Ethereum',
#   'id': 31,
#   'name': 'Flexa',
#   'value': {'tvl': {'USD': {'value': 465650391, 'relative_1d': -2.06},
#     'ETH': {'value': 262385.5517614443, 'relative_1d': 2.86},
#     'BTC': {'value': 8295.522203263194, 'relative_1d': 4.57}},
#    'total': {'USD': {'value': 465650391, 'relative_1d': -2.06},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -2.06,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'website': 'https://harvest.finance',
#   'chain': 'Ethereum',
#   'id': 45,
#   'name': 'Harvest Finance',
#   'value': {'tvl': {'USD': {'value': 415737430, 'relative_1d': -5.79},
#     'ETH': {'value': 234260.50330200372, 'relative_1d': -1.05},
#     'BTC': {'value': 7406.3270383736835, 'relative_1d': 0.59}},
#    'total': {'USD': {'value': 415737430, 'relative_1d': -5.79},
#     'ETH': {'value': 31144.445667, 'relative_1d': 0.69},
#     'BTC': {'value': 3915.486064, 'relative_1d': 0.06}},
#    'balance': {'ERC20': {'DAI': {'value': 18767769.178186,
#       'relative_1d': -0.58}}}},
#   'contributesTo': None,
#   'relative_1d': -5.79,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 82,
#   'name': 'Reflexer',
#   'value': {'tvl': {'USD': {'value': 369454817, 'relative_1d': -3.97},
#     'ETH': {'value': 208181.09011202017, 'relative_1d': 0.86},
#     'BTC': {'value': 6581.806215053817, 'relative_1d': 2.53}},
#    'total': {'USD': {'value': 369454817, 'relative_1d': -3.97},
#     'ETH': {'value': 208066.769759, 'relative_1d': 0.37},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -3.97,
#   'timestamp': 1615824000},
#  {'category': 'Payments',
#   'chain': 'Ethereum',
#   'id': 83,
#   'name': 'Tornado Cash',
#   'value': {'tvl': {'USD': {'value': 317518204, 'relative_1d': -4.05},
#     'ETH': {'value': 178915.75044515068, 'relative_1d': 0.78},
#     'BTC': {'value': 5656.559861499724, 'relative_1d': 2.45}},
#    'total': {'USD': {'value': 317518204, 'relative_1d': -4.05},
#     'ETH': {'value': 178217.3, 'relative_1d': -0.03},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -4.05,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 17,
#   'name': 'Nexus Mutual',
#   'value': {'tvl': {'USD': {'value': 289373163, 'relative_1d': -4.02},
#     'ETH': {'value': 163056.53019135844, 'relative_1d': 0.8},
#     'BTC': {'value': 5155.15834431029, 'relative_1d': 2.47}},
#    'total': {'USD': {'value': 289373163, 'relative_1d': -4.02},
#     'ETH': {'value': 162115.919033, 'relative_1d': -0.01},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 540984.825134,
#       'relative_1d': 0.25}}}},
#   'contributesTo': None,
#   'relative_1d': -4.02,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 36,
#   'name': 'yearn.finance',
#   'value': {'tvl': {'USD': {'value': 268025856, 'relative_1d': -1.29},
#     'ETH': {'value': 151027.70978429914, 'relative_1d': 3.67},
#     'BTC': {'value': 4774.857881514425, 'relative_1d': 5.39}},
#    'total': {'USD': {'value': 268025856, 'relative_1d': -1.29},
#     'ETH': {'value': 10533.54541, 'relative_1d': -0.29},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 7142983.838017,
#       'relative_1d': -2.22}}}},
#   'contributesTo': ['Curve', 'Aave'],
#   'relative_1d': -1.29,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'permissioning': 'Open',
#   'variability': 'Medium',
#   'website': 'https://dydx.exchange/',
#   'chain': 'Ethereum',
#   'id': 11,
#   'name': 'dYdX',
#   'value': {'tvl': {'USD': {'value': 245003702, 'relative_1d': 0.63},
#     'ETH': {'value': 138055.14346248336, 'relative_1d': 5.69},
#     'BTC': {'value': 4364.720161531399, 'relative_1d': 7.44}},
#    'total': {'USD': {'value': 245003702, 'relative_1d': 0.63},
#     'ETH': {'value': 117378.4798636083, 'relative_1d': 6.83},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 18288375.53608092,
#       'relative_1d': -16.01}}}},
#   'contributesTo': None,
#   'relative_1d': 0.63,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 78,
#   'name': 'KEEP Network',
#   'value': {'tvl': {'USD': {'value': 239798412, 'relative_1d': -4.66},
#     'ETH': {'value': 135122.05693420785, 'relative_1d': 0.13},
#     'BTC': {'value': 4271.988361872233, 'relative_1d': 1.79}},
#    'total': {'USD': {'value': 239798412, 'relative_1d': -4.66},
#     'ETH': {'value': 87751.714732, 'relative_1d': -0.12},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -4.66,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 18,
#   'name': 'Set Protocol',
#   'value': {'tvl': {'USD': {'value': 194559291, 'relative_1d': -45.86},
#     'ETH': {'value': 109630.63256474407, 'relative_1d': -43.14},
#     'BTC': {'value': 3466.057259987665, 'relative_1d': -42.19}},
#    'total': {'USD': {'value': 194559291, 'relative_1d': -45.86},
#     'ETH': {'value': 15955.017675, 'relative_1d': -28.07},
#     'BTC': {'value': 331.531835, 'relative_1d': -21.48}},
#    'balance': {'ERC20': {'DAI': {'value': 100475.844449,
#       'relative_1d': 243}}}},
#   'contributesTo': None,
#   'relative_1d': -45.86,
#   'timestamp': 1615752000},
#  {'category': 'Lending',
#   'permissioning': 'Open',
#   'variability': 'Medium',
#   'website': 'https://cream.finance',
#   'chain': 'Ethereum',
#   'id': 42,
#   'name': 'C.R.E.A.M. Finance',
#   'value': {'tvl': {'USD': {'value': 193750533, 'relative_1d': -1.88},
#     'ETH': {'value': 109174.91209682872, 'relative_1d': 3.05},
#     'BTC': {'value': 3451.649304844196, 'relative_1d': 4.76}},
#    'total': {'USD': {'value': 193750533, 'relative_1d': -1.88},
#     'ETH': {'value': 38902.548873, 'relative_1d': 0.65},
#     'BTC': {'value': 69.783028, 'relative_1d': -13.94}},
#    'balance': {'ERC20': {'DAI': {'value': 6964140.488241,
#       'relative_1d': -0.17}}}},
#   'contributesTo': None,
#   'relative_1d': -1.88,
#   'timestamp': 1615824000},
#  {'category': 'Payments',
#   'website': 'https://polygon.technology/',
#   'chain': 'Ethereum',
#   'id': 61,
#   'name': 'Polygon',
#   'value': {'tvl': {'USD': {'value': 174110445, 'relative_1d': 2.42},
#     'ETH': {'value': 98108.07863952938, 'relative_1d': 7.57},
#     'BTC': {'value': 3101.76280366859, 'relative_1d': 9.35}},
#    'total': {'USD': {'value': 174110445, 'relative_1d': 2.42},
#     'ETH': {'value': 17335.670459, 'relative_1d': 5.18},
#     'BTC': {'value': 118.987763, 'relative_1d': -1.7}},
#    'balance': {'ERC20': {'DAI': {'value': 3970535.981777,
#       'relative_1d': -0.6}}}},
#   'contributesTo': None,
#   'relative_1d': 2.42,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 26,
#   'name': 'Loopring',
#   'value': {'tvl': {'USD': {'value': 173962126, 'relative_1d': -3.8},
#     'ETH': {'value': 98024.50357247503, 'relative_1d': 1.04},
#     'BTC': {'value': 3099.1205132690834, 'relative_1d': 2.71}},
#    'total': {'USD': {'value': 173962126, 'relative_1d': -3.8},
#     'ETH': {'value': 45312.898973, 'relative_1d': 0.49},
#     'BTC': {'value': 50.745584, 'relative_1d': -0.33}},
#    'balance': {'ERC20': {'DAI': {'value': 1673651.880558,
#       'relative_1d': 0.3}}}},
#   'contributesTo': None,
#   'relative_1d': -3.8,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 69,
#   'name': 'Index Coop',
#   'value': {'tvl': {'USD': {'value': 129686547, 'relative_1d': -3.25},
#     'ETH': {'value': 73076.01764825208, 'relative_1d': 1.62},
#     'BTC': {'value': 2310.354830353908, 'relative_1d': 3.3}},
#    'total': {'USD': {'value': 129686547, 'relative_1d': -3.25},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': 3.726794, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -3.25,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'website': 'https://idle.finance',
#   'chain': 'Ethereum',
#   'id': 54,
#   'name': 'Idle Finance',
#   'value': {'tvl': {'USD': {'value': 105517640, 'relative_1d': -0.44},
#     'ETH': {'value': 59457.27680483242, 'relative_1d': 4.56},
#     'BTC': {'value': 1879.7878029827157, 'relative_1d': 6.3}},
#    'total': {'USD': {'value': 105517640, 'relative_1d': -0.44},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': 69.376249, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 20194003.90308,
#       'relative_1d': 0.19}}}},
#   'contributesTo': None,
#   'relative_1d': -0.44,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 80,
#   'name': '1inch Liquidity Protocol',
#   'value': {'tvl': {'USD': {'value': 102689825, 'relative_1d': -4.12},
#     'ETH': {'value': 57863.8543286677, 'relative_1d': 0.7},
#     'BTC': {'value': 1829.4105187097584, 'relative_1d': 2.37}},
#    'total': {'USD': {'value': 102689825, 'relative_1d': -4.12},
#     'ETH': {'value': 25802.33989, 'relative_1d': 0.19},
#     'BTC': {'value': 72.931121, 'relative_1d': -13.66}},
#    'balance': {'ERC20': {'DAI': {'value': 1075246.285763,
#       'relative_1d': -3.24}}}},
#   'contributesTo': None,
#   'relative_1d': -4.12,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 59,
#   'name': 'cvault.finance',
#   'value': {'tvl': {'USD': {'value': 79443035, 'relative_1d': -4.78},
#     'ETH': {'value': 44764.70969414204, 'relative_1d': 0},
#     'BTC': {'value': 1415.2709274480455, 'relative_1d': 1.66}},
#    'total': {'USD': {'value': 79443035, 'relative_1d': -4.78},
#     'ETH': {'value': 18345.887788, 'relative_1d': 0.05},
#     'BTC': {'value': 100.745371, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 1996534.275647,
#       'relative_1d': -3.29}}}},
#   'contributesTo': None,
#   'relative_1d': -4.78,
#   'timestamp': 1615824000},
#  {'category': 'Payments',
#   'chain': 'Bitcoin',
#   'id': 3,
#   'name': 'Lightning Network',
#   'value': {'tvl': {'USD': {'value': 64250747, 'relative_1d': -5.6},
#     'ETH': {'value': 36204.1308855681, 'relative_1d': -0.86},
#     'BTC': {'value': 1144.621605857829, 'relative_1d': 0.79}},
#    'total': {'USD': {'value': 64250747, 'relative_1d': -5.6},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': 1140.91, 'relative_1d': 0.22}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -5.6,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 47,
#   'name': 'HEGIC',
#   'value': {'tvl': {'USD': {'value': 62139143, 'relative_1d': -5.95},
#     'ETH': {'value': 35014.28032095927, 'relative_1d': -1.22},
#     'BTC': {'value': 1107.0035597763444, 'relative_1d': 0.42}},
#    'total': {'USD': {'value': 62139143, 'relative_1d': -5.95},
#     'ETH': {'value': 15521.516128, 'relative_1d': -1.78},
#     'BTC': {'value': 612.363475, 'relative_1d': -0.34}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -5.95,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 34,
#   'name': 'mStable',
#   'value': {'tvl': {'USD': {'value': 58286578, 'relative_1d': -4.48},
#     'ETH': {'value': 32843.42980142899, 'relative_1d': 0.32},
#     'BTC': {'value': 1038.3704412077516, 'relative_1d': 1.98}},
#    'total': {'USD': {'value': 58286578, 'relative_1d': -4.48},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': 185.485663, 'relative_1d': 1.23}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -4.48,
#   'timestamp': 1615824000},
#  {'category': 'Payments',
#   'chain': 'Ethereum',
#   'id': 9,
#   'name': 'xDai',
#   'value': {'tvl': {'USD': {'value': 55636290, 'relative_1d': 1.94},
#     'ETH': {'value': 31350.040570694433, 'relative_1d': 7.06},
#     'BTC': {'value': 991.1557853758787, 'relative_1d': 8.84}},
#    'total': {'USD': {'value': 55636290, 'relative_1d': 1.94},
#     'ETH': {'value': 3136.724059, 'relative_1d': 10.96},
#     'BTC': {'value': 28.391645, 'relative_1d': -1.05}},
#    'balance': {'ERC20': {'DAI': {'value': 23546799.038727,
#       'relative_1d': 7.4}}}},
#   'contributesTo': None,
#   'relative_1d': 1.94,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 44,
#   'name': 'DODO',
#   'value': {'tvl': {'USD': {'value': 53644656, 'relative_1d': -4.54},
#     'ETH': {'value': 30227.790925688012, 'relative_1d': 0.25},
#     'BTC': {'value': 955.6749946644329, 'relative_1d': 1.91}},
#    'total': {'USD': {'value': 53644656, 'relative_1d': -4.54},
#     'ETH': {'value': 8311.074782, 'relative_1d': 3.55},
#     'BTC': {'value': 272.58436, 'relative_1d': -3.3}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -4.54,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'website': 'https://app.truefi.com',
#   'chain': 'Ethereum',
#   'id': 64,
#   'name': 'TrueFi',
#   'value': {'tvl': {'USD': {'value': 51684171, 'relative_1d': 0.02},
#     'ETH': {'value': 29123.093177361552, 'relative_1d': 5.05},
#     'BTC': {'value': 920.749120744863, 'relative_1d': 6.79}},
#    'total': {'USD': {'value': 51684171, 'relative_1d': 0.02},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': 0.02,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 25,
#   'name': 'dForce',
#   'value': {'tvl': {'USD': {'value': 50814743, 'relative_1d': -1.19},
#     'ETH': {'value': 28633.186264566004, 'relative_1d': 3.78},
#     'BTC': {'value': 905.2603346994998, 'relative_1d': 5.5}},
#    'total': {'USD': {'value': 50814743, 'relative_1d': -1.19},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 3105909.178077,
#       'relative_1d': 0.02}}}},
#   'contributesTo': None,
#   'relative_1d': -1.19,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 68,
#   'name': 'Futureswap',
#   'value': {'tvl': {'USD': {'value': 50528933, 'relative_1d': -1.45},
#     'ETH': {'value': 28472.13751211486, 'relative_1d': 3.51},
#     'BTC': {'value': 900.1686538016851, 'relative_1d': 5.22}},
#    'total': {'USD': {'value': 50528933, 'relative_1d': -1.45},
#     'ETH': {'value': 12859.010105, 'relative_1d': 0.33},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -1.45,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 55,
#   'name': 'DeFi Swap',
#   'value': {'tvl': {'USD': {'value': 48068486, 'relative_1d': -3.81},
#     'ETH': {'value': 27085.720242522595, 'relative_1d': 1.02},
#     'BTC': {'value': 856.3359992760019, 'relative_1d': 2.7}},
#    'total': {'USD': {'value': 48068486, 'relative_1d': -3.81},
#     'ETH': {'value': 12072.414187, 'relative_1d': 0.16},
#     'BTC': {'value': 82.143303, 'relative_1d': 0.76}},
#    'balance': {'ERC20': {'DAI': {'value': 1249050.030613,
#       'relative_1d': -2.57}}}},
#   'contributesTo': None,
#   'relative_1d': -3.81,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'website': 'https://metronome.io',
#   'chain': 'Ethereum',
#   'id': 37,
#   'name': 'Metronome',
#   'value': {'tvl': {'USD': {'value': 44852006, 'relative_1d': -3.44},
#     'ETH': {'value': 25273.292086460657, 'relative_1d': 1.41},
#     'BTC': {'value': 799.0346810079109, 'relative_1d': 3.09}},
#    'total': {'USD': {'value': 44852006, 'relative_1d': -3.44},
#     'ETH': {'value': 15202.085986, 'relative_1d': -0.01},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -3.44,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 57,
#   'name': 'B.Protocol',
#   'value': {'tvl': {'USD': {'value': 35348597, 'relative_1d': -3.72},
#     'ETH': {'value': 19918.293438817138, 'relative_1d': 1.12},
#     'BTC': {'value': 629.7322560772911, 'relative_1d': 2.8}},
#    'total': {'USD': {'value': 35348597, 'relative_1d': -3.72},
#     'ETH': {'value': 19840.53651, 'relative_1d': 0.31},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': ['Maker'],
#   'relative_1d': -3.72,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 65,
#   'name': 'DerivaDEX',
#   'value': {'tvl': {'USD': {'value': 33620475, 'relative_1d': 0.53},
#     'ETH': {'value': 18944.528027588072, 'relative_1d': 5.58},
#     'BTC': {'value': 598.9459092857395, 'relative_1d': 7.34}},
#    'total': {'USD': {'value': 33620475, 'relative_1d': 0.53},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': 0.53,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'variability': 'medium',
#   'website': 'https://bzx.network',
#   'chain': 'Ethereum',
#   'id': 19,
#   'name': 'bZx',
#   'value': {'tvl': {'USD': {'value': 26317379, 'relative_1d': -2.41},
#     'ETH': {'value': 14829.365857506706, 'relative_1d': 2.49},
#     'BTC': {'value': 468.8418737442712, 'relative_1d': 4.19}},
#    'total': {'USD': {'value': 26317379, 'relative_1d': -2.41},
#     'ETH': {'value': 2862.766031, 'relative_1d': 14.21},
#     'BTC': {'value': 71.149431, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 2372848.607390574,
#       'relative_1d': -5.64}}}},
#   'contributesTo': None,
#   'relative_1d': -2.41,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 77,
#   'name': '88mph',
#   'value': {'tvl': {'USD': {'value': 23903868, 'relative_1d': -1.56},
#     'ETH': {'value': 13469.396172831157, 'relative_1d': 3.39},
#     'BTC': {'value': 425.8453800758702, 'relative_1d': 5.1}},
#    'total': {'USD': {'value': 23903868, 'relative_1d': -1.56},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 1701899.19578, 'relative_1d': 0}}}},
#   'contributesTo': ['Aave', 'Compound', 'yearn.finance', 'Harvest Finance'],
#   'relative_1d': -1.56,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 75,
#   'name': 'Siren',
#   'value': {'tvl': {'USD': {'value': 21687092, 'relative_1d': -3.26},
#     'ETH': {'value': 12220.283093290058, 'relative_1d': 1.6},
#     'BTC': {'value': 386.35370373867374, 'relative_1d': 3.29}},
#    'total': {'USD': {'value': 21687092, 'relative_1d': -3.26},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': 18.164533, 'relative_1d': 1.17}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -3.26,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'website': 'https://pickle.finance',
#   'chain': 'Ethereum',
#   'id': 56,
#   'name': 'Pickle Finance',
#   'value': {'tvl': {'USD': {'value': 21606066, 'relative_1d': -0.92},
#     'ETH': {'value': 12174.626411522077, 'relative_1d': 4.06},
#     'BTC': {'value': 384.910232424072, 'relative_1d': 5.78}},
#    'total': {'USD': {'value': 21606066, 'relative_1d': -0.92},
#     'ETH': {'value': 4980.678937, 'relative_1d': 3.86},
#     'BTC': {'value': 33.530127, 'relative_1d': -16.67}},
#    'balance': {'ERC20': {'DAI': {'value': 4804518.735724,
#       'relative_1d': 0.79}}}},
#   'contributesTo': None,
#   'relative_1d': -0.92,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 76,
#   'name': 'dHEDGE',
#   'value': {'tvl': {'USD': {'value': 20943259, 'relative_1d': -4.75},
#     'ETH': {'value': 11801.146685599657, 'relative_1d': 0.03},
#     'BTC': {'value': 373.1023819610445, 'relative_1d': 1.69}},
#    'total': {'USD': {'value': 20943259, 'relative_1d': -4.75},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -4.75,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 39,
#   'name': 'Gnosis',
#   'value': {'tvl': {'USD': {'value': 20192528, 'relative_1d': -4.05},
#     'ETH': {'value': 11378.12337998963, 'relative_1d': 0.77},
#     'BTC': {'value': 359.7281728987397, 'relative_1d': 2.44}},
#    'total': {'USD': {'value': 20192528, 'relative_1d': -4.05},
#     'ETH': {'value': 7218.049929, 'relative_1d': 0},
#     'BTC': {'value': 0.12234400000000001, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 521690.5663940927,
#       'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -4.05,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 85,
#   'name': 'IDEX',
#   'value': {'tvl': {'USD': {'value': 18691826, 'relative_1d': -2.59},
#     'ETH': {'value': 10532.505014988617, 'relative_1d': 2.3},
#     'BTC': {'value': 332.99329410964083, 'relative_1d': 4}},
#    'total': {'USD': {'value': 18691826, 'relative_1d': -2.59},
#     'ETH': {'value': 4517.379396, 'relative_1d': 0.06},
#     'BTC': {'value': 0.070023, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 16976.243341, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -2.59,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 74,
#   'name': 'LINKSWAP',
#   'value': {'tvl': {'USD': {'value': 18283957, 'relative_1d': -13.75},
#     'ETH': {'value': 10302.67822931458, 'relative_1d': -9.42},
#     'BTC': {'value': 325.72714248404765, 'relative_1d': -7.92}},
#    'total': {'USD': {'value': 18283957, 'relative_1d': -13.75},
#     'ETH': {'value': 2080.800269, 'relative_1d': -16.72},
#     'BTC': {'value': 0.000112, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 37.797293, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -13.75,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 72,
#   'name': 'PowerIndex',
#   'value': {'tvl': {'USD': {'value': 18116738, 'relative_1d': -3.52},
#     'ETH': {'value': 10208.453354971036, 'relative_1d': 1.33},
#     'BTC': {'value': 322.7481501882859, 'relative_1d': 3.01}},
#    'total': {'USD': {'value': 18116738, 'relative_1d': -3.52},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -3.52,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 67,
#   'name': 'Notional',
#   'value': {'tvl': {'USD': {'value': 17484603, 'relative_1d': -2.4},
#     'ETH': {'value': 9852.25674487795, 'relative_1d': 2.51},
#     'BTC': {'value': 311.4867188026097, 'relative_1d': 4.21}},
#    'total': {'USD': {'value': 17484603, 'relative_1d': -2.4},
#     'ETH': {'value': 4466.354143, 'relative_1d': 0.48},
#     'BTC': {'value': 28.703871, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 581486.529336,
#       'relative_1d': -3.29}}}},
#   'contributesTo': None,
#   'relative_1d': -2.4,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 6,
#   'name': 'Kyber',
#   'value': {'tvl': {'USD': {'value': 14744619, 'relative_1d': -2.52},
#     'ETH': {'value': 8308.325444587193, 'relative_1d': 2.38},
#     'BTC': {'value': 262.6741363418212, 'relative_1d': 4.08}},
#    'total': {'USD': {'value': 14744619, 'relative_1d': -2.52},
#     'ETH': {'value': 3184.177505, 'relative_1d': 2.6},
#     'BTC': {'value': 42.691704, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -2.52,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 66,
#   'name': 'Cover Protocol',
#   'value': {'tvl': {'USD': {'value': 14512962, 'relative_1d': 1.39},
#     'ETH': {'value': 8177.790925688011, 'relative_1d': 6.48},
#     'BTC': {'value': 258.5471865438958, 'relative_1d': 8.25}},
#    'total': {'USD': {'value': 14512962, 'relative_1d': 1.39},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 14492586.738904,
#       'relative_1d': 1.38}}}},
#   'contributesTo': None,
#   'relative_1d': 1.39,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 52,
#   'name': 'Swerve Finance',
#   'value': {'tvl': {'USD': {'value': 14302163, 'relative_1d': 3.7},
#     'ETH': {'value': 8059.009511573917, 'relative_1d': 8.91},
#     'BTC': {'value': 254.791820246081, 'relative_1d': 10.72}},
#    'total': {'USD': {'value': 14302163, 'relative_1d': 3.7},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 3123638.309917,
#       'relative_1d': 1.18}}}},
#   'contributesTo': None,
#   'relative_1d': 3.7,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 29,
#   'name': 'DeversiFi',
#   'value': {'tvl': {'USD': {'value': 13958970, 'relative_1d': -2.59},
#     'ETH': {'value': 7865.626479139901, 'relative_1d': 2.3},
#     'BTC': {'value': 248.6778660724561, 'relative_1d': 4}},
#    'total': {'USD': {'value': 13958970, 'relative_1d': -2.59},
#     'ETH': {'value': 2189.234866, 'relative_1d': 2.68},
#     'BTC': {'value': 42.101964, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 132753.190114,
#       'relative_1d': 3.21}}}},
#   'contributesTo': None,
#   'relative_1d': -2.59,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 16,
#   'name': 'Enzyme Finance',
#   'value': {'tvl': {'USD': {'value': 12934169, 'relative_1d': 0.33},
#     'ETH': {'value': 7288.169698199112, 'relative_1d': 5.37},
#     'BTC': {'value': 230.421123216148, 'relative_1d': 7.12}},
#    'total': {'USD': {'value': 12934169, 'relative_1d': 0.33},
#     'ETH': {'value': 1559.110398, 'relative_1d': -8.95},
#     'BTC': {'value': 42.058745, 'relative_1d': 0.45}},
#    'balance': {'ERC20': {'DAI': {'value': 784889.736145,
#       'relative_1d': -1.02}}}},
#   'contributesTo': None,
#   'relative_1d': 0.33,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 48,
#   'name': 'Value DeFi',
#   'value': {'tvl': {'USD': {'value': 10990000, 'relative_1d': -6.09},
#     'ETH': {'value': 6192.665720017129, 'relative_1d': -1.37},
#     'BTC': {'value': 195.78591745209658, 'relative_1d': 0.27}},
#    'total': {'USD': {'value': 10990000, 'relative_1d': -6.09},
#     'ETH': {'value': 2740.600305, 'relative_1d': -2.65},
#     'BTC': {'value': 79.652664, 'relative_1d': -1.45}},
#    'balance': {'ERC20': {'DAI': {'value': 67572.343127, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -6.09,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 58,
#   'name': 'QIAN',
#   'value': {'tvl': {'USD': {'value': 10044966, 'relative_1d': -4.24},
#     'ETH': {'value': 5660.156197173575, 'relative_1d': 0.57},
#     'BTC': {'value': 178.95021693222174, 'relative_1d': 2.24}},
#    'total': {'USD': {'value': 10044966, 'relative_1d': -4.24},
#     'ETH': {'value': 2435.488071, 'relative_1d': 0},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -4.24,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 23,
#   'name': 'Erasure',
#   'value': {'tvl': {'USD': {'value': 8879334, 'relative_1d': -1.66},
#     'ETH': {'value': 5003.343701399689, 'relative_1d': 3.28},
#     'BTC': {'value': 158.18458176101862, 'relative_1d': 5}},
#    'total': {'USD': {'value': 8879334, 'relative_1d': -1.66},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 5696.22101, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -1.66,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 27,
#   'name': 'Opyn',
#   'value': {'tvl': {'USD': {'value': 8692700, 'relative_1d': -2.73},
#     'ETH': {'value': 4898.17882660536, 'relative_1d': 2.15},
#     'BTC': {'value': 154.85971288770156, 'relative_1d': 3.85}},
#    'total': {'USD': {'value': 8692700, 'relative_1d': -2.73},
#     'ETH': {'value': 3186.55982, 'relative_1d': 0},
#     'BTC': {'value': 2.7125, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 1.801998, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -2.73,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'permissioning': 'Open',
#   'variability': 'Medium',
#   'website': 'https://for.tube',
#   'chain': 'Ethereum',
#   'id': 40,
#   'name': 'ForTube',
#   'value': {'tvl': {'USD': {'value': 8187129, 'relative_1d': -2.18},
#     'ETH': {'value': 4613.29873554669, 'relative_1d': 2.74},
#     'BTC': {'value': 145.8530084225356, 'relative_1d': 4.44}},
#    'total': {'USD': {'value': 8187129, 'relative_1d': -2.18},
#     'ETH': {'value': 535.084643, 'relative_1d': 0},
#     'BTC': {'value': 2.840329, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 46320.039199, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -2.18,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 21,
#   'name': 'DDEX',
#   'value': {'tvl': {'USD': {'value': 7720242, 'relative_1d': -3.8},
#     'ETH': {'value': 4350.216377036987, 'relative_1d': 1.03},
#     'BTC': {'value': 137.5354561348689, 'relative_1d': 2.71}},
#    'total': {'USD': {'value': 7720242, 'relative_1d': -3.8},
#     'ETH': {'value': 2981.786127, 'relative_1d': -0.37},
#     'BTC': {'value': 16.867132, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 15516.527267, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -3.8,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 41,
#   'name': 'Opium Network',
#   'value': {'tvl': {'USD': {'value': 6630319, 'relative_1d': -0.27},
#     'ETH': {'value': 3736.0645299434264, 'relative_1d': 4.75},
#     'BTC': {'value': 118.11857037443745, 'relative_1d': 6.48}},
#    'total': {'USD': {'value': 6630319, 'relative_1d': -0.27},
#     'ETH': {'value': 0.008563, 'relative_1d': 0},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 13.299079, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -0.27,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'website': 'https://snowswap.org/',
#   'chain': 'Ethereum',
#   'id': 81,
#   'name': 'Snowswap',
#   'value': {'tvl': {'USD': {'value': 5709878, 'relative_1d': -2.93},
#     'ETH': {'value': 3217.4127166587778, 'relative_1d': 1.95},
#     'BTC': {'value': 101.72099206274271, 'relative_1d': 3.64}},
#    'total': {'USD': {'value': 5709878, 'relative_1d': -2.93},
#     'ETH': {'value': 1976.219087, 'relative_1d': -0.74},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 149770.066717,
#       'relative_1d': 0.07}}}},
#   'contributesTo': None,
#   'relative_1d': -2.93,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 51,
#   'name': 'PerlinX',
#   'value': {'tvl': {'USD': {'value': 4580766, 'relative_1d': 20.47},
#     'ETH': {'value': 2581.178578673338, 'relative_1d': 26.52},
#     'BTC': {'value': 81.60595759266339, 'relative_1d': 28.62}},
#    'total': {'USD': {'value': 4580766, 'relative_1d': 20.47},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': 20.47,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 62,
#   'name': 'S Finance',
#   'value': {'tvl': {'USD': {'value': 4054980, 'relative_1d': -0.02},
#     'ETH': {'value': 2284.9077016701603, 'relative_1d': 5.01},
#     'BTC': {'value': 72.23912461782554, 'relative_1d': 6.75}},
#    'total': {'USD': {'value': 4054980, 'relative_1d': -0.02},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 658537.323441,
#       'relative_1d': 1.67}}}},
#   'contributesTo': None,
#   'relative_1d': -0.02,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'website': 'https://dextf.com',
#   'chain': 'Ethereum',
#   'id': 73,
#   'name': 'DEXTF',
#   'value': {'tvl': {'USD': {'value': 3723436, 'relative_1d': -3.36},
#     'ETH': {'value': 2098.088669506615, 'relative_1d': 1.49},
#     'BTC': {'value': 66.33269639073383, 'relative_1d': 3.18}},
#    'total': {'USD': {'value': 3723436, 'relative_1d': -3.36},
#     'ETH': {'value': 213.903652, 'relative_1d': -0.81},
#     'BTC': {'value': 7.186299, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 136969.301863,
#       'relative_1d': -2.14}}}},
#   'contributesTo': None,
#   'relative_1d': -3.36,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 35,
#   'name': 'PieDAO',
#   'value': {'tvl': {'USD': {'value': 3439354, 'relative_1d': -1.11},
#     'ETH': {'value': 1938.0136137219104, 'relative_1d': 3.86},
#     'BTC': {'value': 61.27179966629101, 'relative_1d': 5.58}},
#    'total': {'USD': {'value': 3439354, 'relative_1d': -1.11},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': 16.957554000000002, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -1.11,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 86,
#   'name': 'yAxis',
#   'value': {'tvl': {'USD': {'value': 3148450, 'relative_1d': 0.37},
#     'ETH': {'value': 1774.0944846394843, 'relative_1d': 5.41},
#     'BTC': {'value': 56.089369590723706, 'relative_1d': 7.16}},
#    'total': {'USD': {'value': 3148450, 'relative_1d': 0.37},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': 0.37,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 4,
#   'name': 'Augur',
#   'value': {'tvl': {'USD': {'value': 2600071, 'relative_1d': -4.78},
#     'ETH': {'value': 1465.0928618117068, 'relative_1d': 0.01},
#     'BTC': {'value': 46.320044237997294, 'relative_1d': 1.66}},
#    'total': {'USD': {'value': 2600071, 'relative_1d': -4.78},
#     'ETH': {'value': 1469.3238911564, 'relative_1d': 0},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -4.78,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 60,
#   'name': 'Value Liquid',
#   'value': {'tvl': {'USD': {'value': 2459090, 'relative_1d': -29.29},
#     'ETH': {'value': 1385.6526246985372, 'relative_1d': -25.74},
#     'BTC': {'value': 43.80847968583041, 'relative_1d': -24.5}},
#    'total': {'USD': {'value': 2459090, 'relative_1d': -29.29},
#     'ETH': {'value': 85.128697, 'relative_1d': -1.54},
#     'BTC': {'value': 0.344588, 'relative_1d': -2.82}},
#    'balance': {'ERC20': {'DAI': {'value': 63517.143909,
#       'relative_1d': -24.78}}}},
#   'contributesTo': None,
#   'relative_1d': -29.29,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'website': 'https://mcdex.io',
#   'chain': 'Ethereum',
#   'id': 32,
#   'name': 'MCDEX',
#   'value': {'tvl': {'USD': {'value': 2441253, 'relative_1d': -4.58},
#     'ETH': {'value': 1375.6017986341199, 'relative_1d': 0.22},
#     'BTC': {'value': 43.49071504437517, 'relative_1d': 1.88}},
#    'total': {'USD': {'value': 2441253, 'relative_1d': -4.58},
#     'ETH': {'value': 1367.462682, 'relative_1d': -0.58},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -4.58,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'chain': 'Ethereum',
#   'id': 24,
#   'name': 'Robo-Advisor for Yield',
#   'shortName': 'RAY',
#   'value': {'tvl': {'USD': {'value': 2427964, 'relative_1d': 0.04},
#     'ETH': {'value': 1368.1136881015168, 'relative_1d': 5.07},
#     'BTC': {'value': 43.25397263700293, 'relative_1d': 6.81}},
#    'total': {'USD': {'value': 2427964, 'relative_1d': 0.04},
#     'ETH': {'value': 0.770687, 'relative_1d': 0},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 1515746.949213,
#       'relative_1d': 0.03}}}},
#   'contributesTo': None,
#   'relative_1d': 0.04,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'website': 'https://cream.finance',
#   'chain': 'Ethereum',
#   'id': 53,
#   'name': 'C.R.E.A.M. Swap',
#   'value': {'tvl': {'USD': {'value': 1900588, 'relative_1d': -5.01},
#     'ETH': {'value': 1070.9468749295647, 'relative_1d': -0.24},
#     'BTC': {'value': 33.85881394708329, 'relative_1d': 1.42}},
#    'total': {'USD': {'value': 1900588, 'relative_1d': -5.01},
#     'ETH': {'value': 856.011024, 'relative_1d': -1.18},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -5.01,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 84,
#   'name': 'Primitive',
#   'value': {'tvl': {'USD': {'value': 1241429, 'relative_1d': -1.46},
#     'ETH': {'value': 699.522730858521, 'relative_1d': 3.49},
#     'BTC': {'value': 22.115952294507625, 'relative_1d': 5.21}},
#    'total': {'USD': {'value': 1241429, 'relative_1d': -1.46},
#     'ETH': {'value': 125.362573, 'relative_1d': 0},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 719017.661679, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -1.46,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 46,
#   'name': 'DFI.money',
#   'value': {'tvl': {'USD': {'value': 1194585, 'relative_1d': -0.57},
#     'ETH': {'value': 673.1269862735817, 'relative_1d': 4.43},
#     'BTC': {'value': 21.281430409418817, 'relative_1d': 6.16}},
#    'total': {'USD': {'value': 1194585, 'relative_1d': -0.57},
#     'ETH': {'value': 45.760465, 'relative_1d': 0},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 247866.723763,
#       'relative_1d': 0.02}}}},
#   'contributesTo': None,
#   'relative_1d': -0.57,
#   'timestamp': 1615824000},
#  {'category': 'Assets',
#   'chain': 'Ethereum',
#   'id': 79,
#   'name': 'PEAKDEFI',
#   'value': {'tvl': {'USD': {'value': 548796, 'relative_1d': -3.28},
#     'ETH': {'value': 309.2365947663804, 'relative_1d': 1.58},
#     'BTC': {'value': 9.776754172342201, 'relative_1d': 3.26}},
#    'total': {'USD': {'value': 548796, 'relative_1d': -3.28},
#     'ETH': {'value': 73.266746, 'relative_1d': 0},
#     'BTC': {'value': 3.815316, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -3.28,
#   'timestamp': 1615824000},
#  {'category': 'Lending',
#   'permissioning': 'Open',
#   'variability': 'Medium',
#   'website': 'https://definer.org/',
#   'chain': 'Ethereum',
#   'id': 50,
#   'name': 'DeFiner',
#   'value': {'tvl': {'USD': {'value': 450519, 'relative_1d': -3.98},
#     'ETH': {'value': 253.8592873081344, 'relative_1d': 0.84},
#     'BTC': {'value': 8.02595775656061, 'relative_1d': 2.51}},
#    'total': {'USD': {'value': 450519, 'relative_1d': -3.98},
#     'ETH': {'value': 0.055634, 'relative_1d': 0},
#     'BTC': {'value': 0.001226, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': 69247.145816, 'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': -3.98,
#   'timestamp': 1615824000},
#  {'category': 'Derivatives',
#   'chain': 'Ethereum',
#   'id': 38,
#   'name': 'Auctus',
#   'value': {'tvl': {'USD': {'value': 251464, 'relative_1d': -4.2},
#     'ETH': {'value': 141.69540424189148, 'relative_1d': 0.61},
#     'BTC': {'value': 4.4798098222178355, 'relative_1d': 2.28}},
#    'total': {'USD': {'value': 251464, 'relative_1d': -4.2},
#     'ETH': {'value': 101.864309, 'relative_1d': 0},
#     'BTC': {'value': 1, 'relative_1d': 0}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': -4.2,
#   'timestamp': 1615824000},
#  {'category': 'DEXes',
#   'chain': 'Ethereum',
#   'id': 70,
#   'name': 'UniTrade',
#   'value': {'tvl': {'USD': {'value': 109416, 'relative_1d': 5.13},
#     'ETH': {'value': 61.653931976468996, 'relative_1d': 10.41},
#     'BTC': {'value': 1.9492367555904095, 'relative_1d': 12.24}},
#    'total': {'USD': {'value': 109416, 'relative_1d': 5.13},
#     'ETH': {'value': 25.421479, 'relative_1d': 0.63},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': None, 'relative_1d': None}}}},
#   'contributesTo': None,
#   'relative_1d': 5.13,
#   'timestamp': 1615824000},
#  {'category': 'Payments',
#   'chain': 'Ethereum',
#   'id': 15,
#   'name': 'Connext',
#   'value': {'tvl': {'USD': {'value': 12798, 'relative_1d': 0.05},
#     'ETH': {'value': 7.211440935830685, 'relative_1d': 5.08},
#     'BTC': {'value': 0.2279952840356626, 'relative_1d': 6.83}},
#    'total': {'USD': {'value': 12798, 'relative_1d': 0.05},
#     'ETH': {'value': None, 'relative_1d': None},
#     'BTC': {'value': None, 'relative_1d': None}},
#    'balance': {'ERC20': {'DAI': {'value': 12768.9525837232,
#       'relative_1d': 0}}}},
#   'contributesTo': None,
#   'relative_1d': 0.05,
#   'timestamp': 1615824000}]

# %%
#1. project - Project name. Corresponds to the slug of a project when clicking on it on defipulse.com
#2. period - 1w, 1m, 3m, 1y or all . 
#            (The 1w period will return to hourly values, all other periods will return daily values. Default all)
#3. lenght - Desired length of data set in hours or days. 
#           (Can be used as an alternative to period for a more granular control over the returned data set.)
#4. resolution -  Desired resolution hours or history(=days),
#                 (used together with length for a more granular control over the returned data set)
#5. category - Return data for a specific category only. For historical reasons, project=all is required for this to work.
#              (Current categories: lending, dexes, derivatives, payments, assets)
url = f"https://data-api.defipulse.com/api/v1/defipulse/api/GetHistory"
def get_historical_tvl_by_project_name(pname,retry=0):
    pname = pname.replace(" ","-")
    payload = {'api-key': api_key
                ,'project': pname
    #            ,'period':''
                ,'length':'90'
                ,'resolution':'days'
    #            ,'category':'all'
              }
    res = requests.get(url,params= payload)
    if len(res.text)<100 and retry<3:
        retry = retry+1
        print(f'Retrying for {pname} : {retry}')
        time.sleep(3)
        return get_historical_tvl_by_project_name(pname,retry)
    elif retry>3:
        return None
    df_res = pd.read_json(res.text)
    new_cns = []
    for cn in df_res.columns:
        if cn == 'timestamp':
            new_cn = cn
        else:
            new_cn = f'{pname}_{cn}'
        new_cns.append(new_cn)
    df_res.columns = new_cns
    #display(df_res)
    return  df_res

# %%
df_parent = None 
for index, row in df_proj.iterrows():
    pname = row['name']
    df_child =  get_historical_tvl_by_project_name(pname)
    if len(df_child)==0:
        continue
    if index == 0:
        df_parent = df_child.copy()
    else:
        df_parent = pd.merge(df_parent,df_child,on='timestamp',how='outer',indicator=False)
        #display(df_parent)
        #break

# %%
df_parent.sort_values(by=['timestamp'],inplace=True)
df_parent.reset_index(drop=True,inplace=True)
df_parent.to_csv('HistoricalDailyTVL.csv',index=None)
df_parent
# Out:
#              timestamp  Maker_tvlUSD  Maker_tvlETH     Maker_BTC  \
# 0  2020-11-20 00:00:00           NaN           NaN           NaN
# 1  2020-11-21 00:00:00           NaN           NaN           NaN
# 2  2020-11-22 00:00:00           NaN           NaN           NaN
# 3  2020-11-23 00:00:00  2.646823e+09  4.725288e+06      0.000000
# 4  2020-11-24 00:00:00  2.768471e+09  4.572432e+06  14899.598316
# ..                 ...           ...           ...           ...
# 93 2021-02-20 00:00:00  7.139396e+09  3.646698e+06  13701.768639
# 94 2021-02-21 00:00:00  7.054215e+09  3.673630e+06  13836.880361
# 95 2021-02-22 00:00:00  7.159530e+09  3.695489e+06  13937.296425
# 96 2021-02-22 15:00:00           NaN           NaN           NaN
# 97 2021-02-22 16:00:00  6.536703e+09  3.769333e+06  13914.114816
#
#        Maker_ETH     Maker_DAI   Aave_tvlUSD   Aave_tvlETH      Aave_BTC  \
# 0            NaN           NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN           NaN
# 3   2.683540e+06  3.288758e+08  1.628763e+09  2.907779e+06  15404.128288
# 4   2.670361e+06  3.310137e+08  1.682207e+09  2.778349e+06  15514.524367
# ..           ...           ...           ...           ...           ...
# 93  2.832263e+06  9.042741e+06  5.605657e+09  2.863287e+06   9694.338876
# 94  2.853782e+06  8.528125e+06  5.680520e+09  2.958250e+06   9504.549051
# 95  2.860040e+06  9.250082e+06  5.660620e+09  2.921807e+06   9491.582277
# 96           NaN           NaN           NaN           NaN           NaN
# 97  2.878483e+06  9.790433e+06  5.146440e+09  2.967651e+06   9594.776055
#
#          Aave_ETH  ...  Auctus_ETH  UniTrade_tvlUSD  UniTrade_tvlETH  \
# 0             NaN  ...         NaN              NaN              NaN
# 1             NaN  ...         NaN              NaN              NaN
# 2             NaN  ...         NaN              NaN              NaN
# 3   396068.475796  ...  122.440908          75235.0       134.314636
# 4   393091.604811  ...  122.440908          59852.0        98.852131
# ..            ...  ...         ...              ...              ...
# 93  466637.198922  ...  188.841066          97192.0        49.644238
# 94  472875.825472  ...   98.841066          86091.0        44.833692
# 95  459794.447375  ...  103.435370          92212.0        47.596484
# 96            NaN  ...         NaN              NaN              NaN
# 97  460963.603571  ...  103.435370          76041.0        43.848389
#
#     UniTrade_BTC  UniTrade_ETH  UniTrade_DAI  Connext_tvlUSD  Connext_tvlETH  \
# 0            NaN           NaN           NaN             NaN             NaN
# 1            NaN           NaN           NaN             NaN             NaN
# 2            NaN           NaN           NaN             NaN             NaN
# 3            0.0     52.021607           NaN         12796.0       22.844289
# 4            0.0     33.997634           NaN         12785.0       21.115827
# ..           ...           ...           ...             ...             ...
# 93           0.0     15.466924           NaN         12781.0        6.528346
# 94           0.0     13.772336           NaN         12779.0        6.654932
# 95           0.0     15.232484           NaN         12777.0        6.595023
# 96           NaN           NaN           NaN             NaN             NaN
# 97           0.0     13.320280           NaN         12775.0        7.366594
#
#     Connext_BTC   Connext_DAI
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           0.0  12768.952584
# 4           0.0  12768.952584
# ..          ...           ...
# 93          0.0  12768.952584
# 94          0.0  12768.952584
# 95          0.0  12768.952584
# 96          NaN           NaN
# 97          0.0  12768.952584
#
# [98 rows x 318 columns]
