# %%
import requests
import pandas as pd
import pymysql
import numpy as np
from datetime import datetime
import traceback2

from selenium import webdriver
import time
from bs4 import BeautifulSoup as soup
from selenium.webdriver.common.keys import Keys
import  re



stable_coins = "USDT, USDC, DAI, BUSD, SUSD, UST, TUSD".split(",")

frams_url = "https://pancakeswap.finance/farms"

# %%
def __connect__():
    db_user = 'coin'
    db_password = 'dragonstone#123'
    db_name = 'master_data'
    db_host = 'localhost'
    return pymysql.connect(
        unix_socket=None,
        host=db_host,
        user=db_user,
        password=db_password,
        db=db_name,
        charset='latin1',
        cursorclass=pymysql.cursors.DictCursor)


def get_cursor(connection):
    if connection is None:
        connection = __connect__()
    connection.ping(reconnect=True)
    return connection.cursor()


def insert_pancakswap_data_df(df):
    df = df.astype(object).where(pd.notnull(df), None)
    connection = __connect__()
    cursor = get_cursor(connection)
    for i, row in df.iterrows():
        dt = row["Date"].timestamp()
        try:
            pair2 = row["Pair_2"] if row["Pair_2"] else ' '
            print(row["Date"], row["Pair_1"], pair2, row["Pool_rate"], row["pool_tvl"], row["Farm_payment"], row["Where"], row["includes_stablecoin"])
            sql = "INSERT INTO `pancakswap_farm_pool_data` (`timestamp_dt`, `pair1`,`pair2`,`pool_rate`,`pool_size`,`farm_payment`,`where`,`includes_stablecoin`) VALUES (FROM_UNIXTIME(%s), %s, %s, %s, %s, %s, %s, %s)"
            cursor.execute(sql, (dt, row["Pair_1"], pair2, row["Pool_rate"], row["pool_tvl"], row["Farm_payment"], row["Where"], row["includes_stablecoin"]))
        except Exception as e:
            print(e)
    connection.commit()
    cursor.close()
    connection.close()

# %%
def get_selenium_browser():
    options = webdriver.ChromeOptions()
    options.add_argument('--ignore-certificate-errors')
    options.add_argument('--incognito')
    options.add_argument("no-sandbox")
    options.add_argument("--disable-gpu")
    options.add_argument("--window-size=1200,900")
    options.add_argument("--disable-dev-shm-usage")
    options.add_argument('--headless')
    options.add_argument("start-maximized")
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_experimental_option('useAutomationExtension', False)
    options.add_argument("--disable-blink-features")
    options.add_argument("--disable-blink-features=AutomationControlled")
    options.add_argument("--enable-javascript")
    browser = webdriver.Chrome("chromedriver", options=options)
    return browser


def extract_data(page_source):
    df_c =  pd.DataFrame(columns = ['name','earned', 'apr', 'liquidity', 'multiplier'])
    
    page_soup = soup(page_source, "html.parser")
    table = page_soup.findAll("table")#, {"class": "sc-hRMXGO hbbpxV"})
    #heads = table[0].thead.tr.findAll("th")
    rows =  table[0].tbody.findAll("tr")
    for row in rows: 
#         print(row)
        divs = row.findAll("div", {"color": "text"})
        name = divs[0].text
        #name
        earned = row.find_all("span")[0].text
        #earned
        apr = row.find_all(text=re.compile('%'))[0]
        #apr
        liq = divs[1].text
        #liq
        mul = row.find_all(text=re.compile('x'))[0]
        #mul
        #print(f'{name} {earned} {apr} {liq} {mul}')
        df_c.at[len(df_c)] = [name,earned,apr,liq,mul]
    return df_c


def crawl_page(browser, url):
    browser.get(url)
#     time.sleep(5)
    prev_len = 0
    curr_len = 100
    count = 0
    page_source = None
    while count<5:
        print(curr_len)
#         time.sleep(3)
        page_source = browser.page_source
        #df = extract_data(page_source)
#         time.sleep(3)
        #print(df)
        body = browser.find_element_by_css_selector('body')
        body.send_keys(Keys.PAGE_DOWN)
#         time.sleep(1)
        body.send_keys(Keys.PAGE_DOWN)
        curr_len = len(page_source)
        if curr_len == prev_len:
            count = count+1
        else:
            count = 0
        prev_len = curr_len
    return browser.page_source

def get_page_as_df():
    browser = get_selenium_browser()
    page_source = crawl_page(browser, frams_url)
    df = extract_data(page_source)
    
    return df

# %%
df = get_page_as_df()
# Out:
# 100
# 126362
# 126401
# 126401
# 180893
# 235476
# 235628
# 290336
# 344668
# 399269
# 399534
# 453896
# 508469
# 508584
# 563122
# 617733
# 617882
# 617882
# 617882
# 617882
# 617882

# %%
def add_columns():
    df[['Pair_1', 'Pair_2']] = df['name'].str.split("-", expand=True)[[0,1]]
    df['Farm_payment'] = 'CAKE'
    df['Where'] = 'PancakeSwap'
    df['includes_stablecoin'] = (df['Pair_1'].isin(stable_coins)) | (df['Pair_2'].isin(stable_coins))
    df['pool_tvl'] = df['liquidity'].apply(lambda x: x.strip('$').replace(',','',-1))
    df['Pool_rate'] = df['apr'].apply(lambda x: x.strip('%').replace(',','',-1))
    now = datetime.now()
    now = datetime(now.year, now.month, now.day)
    df['Date'] = now

# %%
df
# Out:
#           name earned      apr       liquidity multiplier Pair_1 Pair_2  \
# 0     CAKE-BNB      0    60.5%  $1,590,506,850        40x   CAKE    BNB
# 1     BUSD-BNB      0   20.92%    $919,835,619         8x   BUSD    BNB
# 2    MCOIN-UST      0  520.42%      $4,622,350         1x  MCOIN    UST
# 3      WIN-BNB      0   147.7%     $16,286,877         1x    WIN    BNB
# 4      TRX-BNB      0   60.57%     $39,716,218         1x    TRX    BNB
# ..         ...    ...      ...             ...        ...    ...    ...
# 115   LINK-BNB      0   33.52%     $71,765,617         1x   LINK    BNB
# 116    EOS-BNB      0   19.02%     $12,644,868       0.1x    EOS    BNB
# 117    DOT-BNB      0   25.54%     $94,192,066         1x    DOT    BNB
# 118   BAND-BNB      0   64.55%     $37,266,349         1x   BAND    BNB
# 119    ADA-BNB      0    27.9%     $43,107,387       0.5x    ADA    BNB
#
#     Farm_payment        Where  includes_stablecoin       Date      pool_size  \
# 0           CAKE  PancakeSwap                False 2021-05-10  1,590,506,850
# 1           CAKE  PancakeSwap                False 2021-05-10    919,835,619
# 2           CAKE  PancakeSwap                False 2021-05-10      4,622,350
# 3           CAKE  PancakeSwap                False 2021-05-10     16,286,877
# 4           CAKE  PancakeSwap                False 2021-05-10     39,716,218
# ..           ...          ...                  ...        ...            ...
# 115         CAKE  PancakeSwap                False 2021-05-10     71,765,617
# 116         CAKE  PancakeSwap                False 2021-05-10     12,644,868
# 117         CAKE  PancakeSwap                False 2021-05-10     94,192,066
# 118         CAKE  PancakeSwap                False 2021-05-10     37,266,349
# 119         CAKE  PancakeSwap                False 2021-05-10     43,107,387
#
#     pool_rate    pool_tvl Pool_rate
# 0        60.5  1590506850      60.5
# 1       20.92   919835619     20.92
# 2      520.42     4622350    520.42
# 3       147.7    16286877     147.7
# 4       60.57    39716218     60.57
# ..        ...         ...       ...
# 115     33.52    71765617     33.52
# 116     19.02    12644868     19.02
# 117     25.54    94192066     25.54
# 118     64.55    37266349     64.55
# 119      27.9    43107387      27.9
#
# [120 rows x 15 columns]

# %%
insert_pancakswap_data_df(df)
# Out:
# 2021-05-10 00:00:00 CAKE BNB 60.5 1590506850 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BUSD BNB 20.92 919835619 CAKE PancakeSwap False
# 2021-05-10 00:00:00 MCOIN UST 520.42 4622350 CAKE PancakeSwap False
# 2021-05-10 00:00:00 WIN BNB 147.7 16286877 CAKE PancakeSwap False
# 2021-05-10 00:00:00 TRX BNB 60.57 39716218 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BTT BNB 92 26146381 CAKE PancakeSwap False
# 2021-05-10 00:00:00 PNT PBTC 303.96 7914165 CAKE PancakeSwap False
# 2021-05-10 00:00:00 XMARK BUSD 143.49 16764539 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BTCB BUSD 17.81 135067787 CAKE PancakeSwap False
# 2021-05-10 00:00:00 LMT BNB 242.1 9936413 CAKE PancakeSwap False
# 2021-05-10 00:00:00 DFD BUSD 238.67 10079103 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ALPACA BUSD 40.28 59723428 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ΤBTC BTCB 48.87 49224953 CAKE PancakeSwap False
# 'charmap' codec can't encode character '\u03a4' in position 183: character maps to <undefined>
# 2021-05-10 00:00:00 SWINGBY BNB 191.22 12579956 CAKE PancakeSwap False
# 2021-05-10 00:00:00 XED BNB 223.72 10752514 CAKE PancakeSwap False
# 2021-05-10 00:00:00 HAKKA BUSD 216.13 11130148 CAKE PancakeSwap False
# 2021-05-10 00:00:00 CGG BNB 227.74 10562938 CAKE PancakeSwap False
# 2021-05-10 00:00:00 SUTER BNB 209.88 11461643 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BROOBEE BNB 235.36 10220816 CAKE PancakeSwap False
# 2021-05-10 00:00:00 HZN BNB 222.36 10818177 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ALPA BNB 243.62 9874163 CAKE PancakeSwap False
# 2021-05-10 00:00:00 PERL BNB 206.93 11624806 CAKE PancakeSwap False
# 2021-05-10 00:00:00 TLM BNB 115.02 10457013 CAKE PancakeSwap False
# 2021-05-10 00:00:00 JGN BNB 177.17 13577570 CAKE PancakeSwap False
# 2021-05-10 00:00:00 EPS BNB 207.74 11579570 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ARPA BNB 154 15620714 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ITAM BNB 199.42 12062568 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BONDLY BNB 156.94 15328475 CAKE PancakeSwap False
# 2021-05-10 00:00:00 TKO BNB 78.71 30560754 CAKE PancakeSwap False
# 2021-05-10 00:00:00 APYS BNB 229.25 10493165 CAKE PancakeSwap False
# 2021-05-10 00:00:00 HOO BUSD 231.68 10383241 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ODDZ BNB 228.12 10545157 CAKE PancakeSwap False
# 2021-05-10 00:00:00 EASY BNB 308.49 7798027 CAKE PancakeSwap False
# 2021-05-10 00:00:00 NRV BNB 139.61 17231002 CAKE PancakeSwap False
# 2021-05-10 00:00:00 DEGO BNB 125.14 9611418 CAKE PancakeSwap False
# 2021-05-10 00:00:00 GUM BNB 222.75 10799505 CAKE PancakeSwap False
# 2021-05-10 00:00:00 PBTC BNB 64.02 37573323 CAKE PancakeSwap False
# 2021-05-10 00:00:00 DFT BNB 240.23 10013693 CAKE PancakeSwap False
# 2021-05-10 00:00:00 SWTH BNB 195.76 12288247 CAKE PancakeSwap False
# 2021-05-10 00:00:00 LIEN BNB 226.75 10608912 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ZIL BNB 74.22 32410750 CAKE PancakeSwap False
# 2021-05-10 00:00:00 PCWS BNB 210.35 11436133 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BBADGER BTCB 105.19 22868134 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BDIGG BTCB 134.32 17908666 CAKE PancakeSwap False
# 2021-05-10 00:00:00 LTO BNB 112.7 10672786 CAKE PancakeSwap False
# 2021-05-10 00:00:00 MIR UST 93.31 12890408 CAKE PancakeSwap False
# 2021-05-10 00:00:00 TRADE BNB 238.74 5038143 CAKE PancakeSwap False
# 2021-05-10 00:00:00 DUSK BNB 171.78 7002011 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BIFI BNB 75.68 15893608 CAKE PancakeSwap False
# 2021-05-10 00:00:00 TXL BUSD 198.49 6059648 CAKE PancakeSwap False
# 2021-05-10 00:00:00 COS BNB 156.64 7678902 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BUNNY BNB 21.14 113789349 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ALICE BNB 76.4 15742449 CAKE PancakeSwap False
# 2021-05-10 00:00:00 FOR BUSD 149.46 16095047 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BUX BNB 176.4 6818401 CAKE PancakeSwap False
# 2021-05-10 00:00:00 NULS BUSD 99.41 12099321 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BELT BNB 178.09 13507472 CAKE PancakeSwap False
# 2021-05-10 00:00:00 RAMP BUSD 92.29 13032513 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BFI BNB 235.49 3064587 CAKE PancakeSwap False
# 2021-05-10 00:00:00 DEXE BUSD 172.97 6953564 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BEL BNB 82.11 14649106 CAKE PancakeSwap False
# 2021-05-10 00:00:00 TPT BUSD 110.26 21816785 CAKE PancakeSwap False
# 2021-05-10 00:00:00 WATCH BNB 153.16 15705915 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BMXX BNB 162.18 7416528 CAKE PancakeSwap False
# 2021-05-10 00:00:00 IOTX BUSD 109.17 11017831 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BOR BNB 147.27 8167270 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BOPEN BNB 136.2 8831333 CAKE PancakeSwap False
# 2021-05-10 00:00:00 SUSHI ETH 20.83 34638653 CAKE PancakeSwap False
# 2021-05-10 00:00:00 DODO BNB 64.14 18753736 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BRY BNB 102.62 11720922 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ZEE BNB 154.86 7767113 CAKE PancakeSwap False
# 2021-05-10 00:00:00 SWGB BNB 222.82 5397987 CAKE PancakeSwap False
# 2021-05-10 00:00:00 COMP ETH 5.57 43200024 CAKE PancakeSwap False
# 2021-05-10 00:00:00 SFP BNB 55.09 43662664 CAKE PancakeSwap False
# 2021-05-10 00:00:00 LINA BUSD 101.43 11857816 CAKE PancakeSwap False
# 2021-05-10 00:00:00 LIT BNB 73.02 16472878 CAKE PancakeSwap False
# 2021-05-10 00:00:00 HGET BNB 75.54 3184480 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BDO BNB 231.8 5188884 CAKE PancakeSwap False
# 2021-05-10 00:00:00 EGLD BNB 40.1 5998998 CAKE PancakeSwap False
# 2021-05-10 00:00:00 UST BUSD 18.65 64480526 CAKE PancakeSwap False
# 2021-05-10 00:00:00 MAMZN UST 61.25 3927235 CAKE PancakeSwap False
# 2021-05-10 00:00:00 MGOOGL UST 60.64 3967036 CAKE PancakeSwap False
# 2021-05-10 00:00:00 MNFLX UST 72.13 3334991 CAKE PancakeSwap False
# 2021-05-10 00:00:00 MTSLA UST 70.1 3431821 CAKE PancakeSwap False
# 2021-05-10 00:00:00 WSOTE BNB 77.39 15541405 CAKE PancakeSwap False
# 2021-05-10 00:00:00 FRONT BNB 119.61 10055613 CAKE PancakeSwap False
# 2021-05-10 00:00:00 HELMET BNB 36.32 33112019 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BTCST BNB 104.64 22988577 CAKE PancakeSwap False
# 2021-05-10 00:00:00 LTC BNB 13.09 18372362 CAKE PancakeSwap False
# 2021-05-10 00:00:00 USDC BUSD 11.79 102057846 CAKE PancakeSwap False
# 2021-05-10 00:00:00 DAI BUSD 13.46 89375475 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BSCX BNB 170.54 14105768 CAKE PancakeSwap False
# 2021-05-10 00:00:00 TEN BNB 187.1 6428587 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BALBT BNB 181.15 6639788 CAKE PancakeSwap False
# 2021-05-10 00:00:00 REEF BNB 84.53 28457251 CAKE PancakeSwap False
# 2021-05-10 00:00:00 DITTO BNB 185.9 6470129 CAKE PancakeSwap False
# 2021-05-10 00:00:00 VAI BUSD 14.97 80362838 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BLK BNB 148.09 1624358 CAKE PancakeSwap False
# 2021-05-10 00:00:00 UNFI BNB 49.91 4819360 CAKE PancakeSwap False
# 2021-05-10 00:00:00 HARD BNB 48.89 4920672 CAKE PancakeSwap False
# 2021-05-10 00:00:00 CTK BNB 46 5229849 CAKE PancakeSwap False
# 2021-05-10 00:00:00 SXP BNB 47.75 25188520 CAKE PancakeSwap False
# 2021-05-10 00:00:00 INJ BNB 69.95 17195319 CAKE PancakeSwap False
# 2021-05-10 00:00:00 FIL BNB 38.46 6255325 CAKE PancakeSwap False
# 2021-05-10 00:00:00 UNI BNB 25.6 93982191 CAKE PancakeSwap False
# 2021-05-10 00:00:00 YFI BNB 20.8 11565614 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ATOM BNB 20.95 11482341 CAKE PancakeSwap False
# 2021-05-10 00:00:00 XRP BNB 33.29 72257371 CAKE PancakeSwap False
# 2021-05-10 00:00:00 USDT BNB 22.06 218083789 CAKE PancakeSwap True
# 2021-05-10 00:00:00 ALPHA BNB 60.32 39882887 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BTCB BNB 11.87 405347702 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ETH BNB 9.36 513747797 CAKE PancakeSwap False
# 2021-05-10 00:00:00 XVS BNB 45.95 52356081 CAKE PancakeSwap False
# 2021-05-10 00:00:00 TWT BNB 92.54 25994902 CAKE PancakeSwap False
# 2021-05-10 00:00:00 USDT BUSD 11.87 405161117 CAKE PancakeSwap True
# 2021-05-10 00:00:00 LINK BNB 33.52 71765617 CAKE PancakeSwap False
# 2021-05-10 00:00:00 EOS BNB 19.02 12644868 CAKE PancakeSwap False
# 2021-05-10 00:00:00 DOT BNB 25.54 94192066 CAKE PancakeSwap False
# 2021-05-10 00:00:00 BAND BNB 64.55 37266349 CAKE PancakeSwap False
# 2021-05-10 00:00:00 ADA BNB 27.9 43107387 CAKE PancakeSwap False
