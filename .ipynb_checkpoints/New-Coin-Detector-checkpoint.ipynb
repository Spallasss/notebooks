# %%
import pymysql
import pandas as pd
from datetime import datetime, timedelta

# %%
def __connect__():
    db_user = 'coin'
    db_password = 'dragonstone#123'
    db_name = 'master_data'
    db_host = 'localhost'
    return pymysql.connect(
        unix_socket=None,
        host=db_host,
        user=db_user,
        password=db_password,
        db=db_name,
        charset='latin1',
        cursorclass=pymysql.cursors.DictCursor)

def get_cursor(connection):
    if connection is None:
        connection = __connect__()
    connection.ping(reconnect=True)
    return connection.cursor()

# %%
def get_unmapped_coins():
    now = datetime.now()
    today = datetime(now.year, now.month, now.day)
    sql = "select * from notebook_missing_symbols;"
    df = pd.read_sql(sql, __connect__())
    df['reported_on'] = today
    return df

# %%
df = get_unmapped_coins()

# %%
def insert_new_coins(df):
    connection = __connect__()
    cursor = get_cursor(connection)
    df = df.astype(object).where(pd.notnull(df), None)
    for i, row in df.iterrows():
        dt = row["reported_on"].timestamp()
        print(row["reported_on"], row["data_source"], row["missing_project"])
        try:
            sql = """INSERT INTO `new_symbols_reporting` (`reported_on`, `data_source`, `missing_project`) VALUES (FROM_UNIXTIME(%s), %s, %s)
                """
            cursor.execute(sql, (dt, row["data_source"], row["missing_project"]))
        except Exception as e:
            print(e)
    connection.commit()
    cursor.close()
    connection.close()
    
def update_new_coins(df, data_source):
    connection = __connect__()
    cursor = get_cursor(connection)
    df = df.astype(object).where(pd.notnull(df), None)
    for i, row in df.iterrows():
        dt = row["mapped_on"].timestamp()
        print(row["mapped_on"], row["missing_project"], data_source)
        try:
            sql = f'update new_symbols_reporting set mapped_on = FROM_UNIXTIME({dt}) where missing_project = "{row["missing_project"]}" and data_source = "{data_source}";'
            cursor.execute(sql)
            print(sql)
        except Exception as e:
            print(e)
    connection.commit()
    cursor.close()
    connection.close()

# %%
insert_new_coins(df)
# Out:
# 2021-08-02 00:00:00 tt Binance Smart Chain
# 2021-08-02 00:00:00 tt dYdX
# 2021-08-02 00:00:00 tt Polymarket
# 2021-08-02 00:00:00 tt MetaMask
# 2021-08-02 00:00:00 tt Rari Capital
# 2021-08-02 00:00:00 tt Instadapp
# 2021-08-02 00:00:00 tt Saddle Finance
# 2021-08-02 00:00:00 tt Autofarm
# 2021-08-02 00:00:00 tt Visor Finance
# 2021-08-02 00:00:00 tt Notional Finance
# 2021-08-02 00:00:00 tt Ribbon Finance
# 2021-08-02 00:00:00 tt Set Protocol
# 2021-08-02 00:00:00 tt Integral Protocol
# 2021-08-02 00:00:00 tt Optimism
# 2021-08-02 00:00:00 solanaprojects Anchor
# 2021-08-02 00:00:00 solanaprojects Mango
# 2021-08-02 00:00:00 solanaprojects MATH Wallet
# 2021-08-02 00:00:00 solanaprojects Orca
# 2021-08-02 00:00:00 solanaprojects unlimitedcope
# 2021-08-02 00:00:00 solanaprojects Parrot
# 2021-08-02 00:00:00 solanaprojects Mercurial
# 2021-08-02 00:00:00 solanaprojects SolFarm
# 2021-08-02 00:00:00 defistation bscSwap
# 2021-08-02 00:00:00 defistation Narwhalswap
# 2021-08-02 00:00:00 defistation Stakecow
# 2021-08-02 00:00:00 defistation STORMSWAP
# 2021-08-02 00:00:00 defistation ARIES FINANCIAL
# 2021-08-02 00:00:00 defistation bDollar Protocol
# 2021-08-02 00:00:00 defistation Belt Finance
# 2021-08-02 00:00:00 defistation BlackHoleSwap
# 2021-08-02 00:00:00 defistation bStable.finance
# 2021-08-02 00:00:00 Debank Incognito
# 2021-08-02 00:00:00 Debank Kwenta
# 2021-08-02 00:00:00 Debank Mesa
# 2021-08-02 00:00:00 Debank NFTfi
# 2021-08-02 00:00:00 Debank Polymarket
# 2021-08-02 00:00:00 Debank Ribbon
# 2021-08-02 00:00:00 Debank Tax Heaven
# 2021-08-02 00:00:00 Debank Tinlake
# 2021-08-02 00:00:00 Debank TRAMS
# 2021-08-02 00:00:00 Debank Volmex
# 2021-08-02 00:00:00 Debank Y3D
# 2021-08-02 00:00:00 Debank Zelda
# 2021-08-02 00:00:00 Debank ShibaSwap
# 2021-08-02 00:00:00 Debank ShapeShift
# 2021-08-02 00:00:00 Debank Bunicorn
# 2021-08-02 00:00:00 Debank PolygonFarm
# 2021-08-02 00:00:00 Debank DinoSwap
# 2021-08-02 00:00:00 Debank PolyCrystal
# 2021-08-02 00:00:00 Debank HOGT
# 2021-08-02 00:00:00 Debank XSwap
# 2021-08-02 00:00:00 Debank BACK
# 2021-08-02 00:00:00 Debank Kalmar
# 2021-08-02 00:00:00 Debank PolyQuity
# 2021-08-02 00:00:00 Debank KSwap

# %% [markdown]
# ## Insert Mappings

# %%
mapping_df = pd.read_csv("missing_symbols_mappings.csv")
mapping_df = mapping_df[~mapping_df['symbol'].isna()]
now = datetime.now()
today = datetime(now.year, now.month, now.day)
mapping_df['mapped_on'] = today

# %%
mapping_df
# Out:
#          missing_project     data_source symbol                   name  \
# 0    Binance Smart Chain              tt    BNB           Binance Coin
# 4           Rari Capital              tt    RGT  Rari Governance Token
# 5              Instadapp              tt   INST              Instadapp
# 8          Visor Finance              tt   VISR                  Visor
# 14                Anchor  solanaprojects    ANC        Anchor Protocol
# ..                   ...             ...    ...                    ...
# 126              o3-swap        DefiPlus     O3                O3 Swap
# 129       ruler-protocol        DefiPlus  RULER         Ruler Protocol
# 130        Nsure-Network        DefiPlus  NSURE          Nsure Network
# 131       convex-finance        DefiPlus    CVX         Convex Finance
# 132          dfx-finance        DefiPlus    DFX            DFX Finance
#
#      mapped_on
# 0   2021-08-02
# 4   2021-08-02
# 5   2021-08-02
# 8   2021-08-02
# 14  2021-08-02
# ..         ...
# 126 2021-08-02
# 129 2021-08-02
# 130 2021-08-02
# 131 2021-08-02
# 132 2021-08-02
#
# [82 rows x 5 columns]

# %%
def insert_tt_coin_cgk_symbol(df):
    connection = __connect__()
    cursor = get_cursor(connection)
    for i, row in df.iterrows():
        try:
            print([row['symbol'], row['name'], row['missing_project']])
            sql = "INSERT INTO `tt_symbols_cgk` (`symbol`, `name_in_coingecko`, `name_in_tt`) VALUES (%s, %s, %s)"
            cursor.execute(sql, (row['symbol'], row['name'], row['missing_project']))
        except Exception:
            print(traceback2.format_exc())
    connection.commit()
    cursor.close()
    connection.close()
    return

def insert_debank_coin_cmc_symbol(df):
    connection = __connect__()
    cursor = get_cursor(connection)
    for i, row in df.iterrows():
        try:
            print([row['symbol'], row['name'], row['missing_project']])
            sql = "INSERT INTO `debank_symbols_cgk` (`symbol`, `name_in_coingecko`, `name_in_debank`) VALUES (%s, %s, %s)"
            cursor.execute(sql, (row['symbol'], row['name'], row['missing_project']))
        except Exception:
            print(traceback2.format_exc())
    connection.commit()
    cursor.close()
    connection.close()
    return

def insert_defi_coin_cmc_symbol(df):
    connection = __connect__()
    cursor = get_cursor(connection)
    for i, row in df.iterrows():
        try:
            print([row['symbol'], row['name'], row['missing_project']])
            sql = "INSERT INTO `defi_symbols_cgk` (`symbol`, `name_in_coingecko`, `name_in_defi`) VALUES (%s, %s, %s)"
            cursor.execute(sql, (row['symbol'], row['name'], row['missing_project']))
        except Exception:
            print(traceback2.format_exc())
    connection.commit()
    cursor.close()
    connection.close()
    return

def insert_defistation_coin_cmc_symbol(df):
    connection = __connect__()
    cursor = get_cursor(connection)
    for i, row in df.iterrows():
        try:
            print([row['symbol'], row['name'], row['missing_project']])
            sql = "INSERT INTO `defistation_symbols_cgk` (`symbol`, `name_in_coingecko`, `name_in_defistation`) VALUES (%s, %s, %s)"
            cursor.execute(sql, (row['symbol'], row['name'], row['missing_project']))
        except Exception:
            print(traceback2.format_exc())
    connection.commit()
    cursor.close()
    connection.close()
    return

def insert_solana_coin_cmc_symbol(df):
    connection = __connect__()
    cursor = get_cursor(connection)
    for i, row in df.iterrows():
        try:
            print([row['symbol'], row['name'], row['missing_project']])
            sql = "INSERT INTO `solana_symbols_cgk` (`symbol`, `name_in_coingecko`, `name_in_solana`) VALUES (%s, %s, %s)"
            cursor.execute(sql, (row['symbol'], row['name'], row['missing_project']))
        except Exception:
            print(traceback2.format_exc())
    connection.commit()
    cursor.close()
    connection.close()
    return

# %%
tample_mapping = {
    "tt" : insert_tt_coin_cgk_symbol,
    "solanaprojects" : insert_solana_coin_cmc_symbol,
    "defistation" : insert_defistation_coin_cmc_symbol,
    "DefiPlus" : insert_defi_coin_cmc_symbol,
    "Debank" : insert_debank_coin_cmc_symbol,
}

# %%
# Out:
#          missing_project data_source reported_on
# 0    Binance Smart Chain          tt  2021-08-02
# 1                   dYdX          tt  2021-08-02
# 2             Polymarket          tt  2021-08-02
# 3               MetaMask          tt  2021-08-02
# 4           Rari Capital          tt  2021-08-02
# ..                   ...         ...         ...
# 227                XSwap      Debank  2021-08-02
# 228                 BACK      Debank  2021-08-02
# 229               Kalmar      Debank  2021-08-02
# 230            PolyQuity      Debank  2021-08-02
# 231                KSwap      Debank  2021-08-02
#
# [232 rows x 3 columns]

# %%
update_new_coins(mapping_df, 'tt')
# Out:
# 2021-08-02 00:00:00 Binance Smart Chain tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Binance Smart Chain" and data_source = "tt";
# 2021-08-02 00:00:00 Rari Capital tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Rari Capital" and data_source = "tt";
# 2021-08-02 00:00:00 Instadapp tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Instadapp" and data_source = "tt";
# 2021-08-02 00:00:00 Visor Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Visor Finance" and data_source = "tt";
# 2021-08-02 00:00:00 Anchor tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Anchor" and data_source = "tt";
# 2021-08-02 00:00:00 Mango tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Mango" and data_source = "tt";
# 2021-08-02 00:00:00 MATH Wallet tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "MATH Wallet" and data_source = "tt";
# 2021-08-02 00:00:00 Orca tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Orca" and data_source = "tt";
# 2021-08-02 00:00:00 unlimitedcope tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "unlimitedcope" and data_source = "tt";
# 2021-08-02 00:00:00 Mercurial tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Mercurial" and data_source = "tt";
# 2021-08-02 00:00:00 SolFarm tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "SolFarm" and data_source = "tt";
# 2021-08-02 00:00:00 Narwhalswap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Narwhalswap" and data_source = "tt";
# 2021-08-02 00:00:00 STORMSWAP tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "STORMSWAP" and data_source = "tt";
# 2021-08-02 00:00:00 ARIES FINANCIAL tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "ARIES FINANCIAL" and data_source = "tt";
# 2021-08-02 00:00:00 bDollar Protocol tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "bDollar Protocol" and data_source = "tt";
# 2021-08-02 00:00:00 Belt Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Belt Finance" and data_source = "tt";
# 2021-08-02 00:00:00 BlackHoleSwap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "BlackHoleSwap" and data_source = "tt";
# 2021-08-02 00:00:00 bStable.finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "bStable.finance" and data_source = "tt";
# 2021-08-02 00:00:00 BTC Standard Hashrate Token tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "BTC Standard Hashrate Token" and data_source = "tt";
# 2021-08-02 00:00:00 BTcoin.Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "BTcoin.Finance" and data_source = "tt";
# 2021-08-02 00:00:00 CBerry tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "CBerry" and data_source = "tt";
# 2021-08-02 00:00:00 CheesecakeSwap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "CheesecakeSwap" and data_source = "tt";
# 2021-08-02 00:00:00 DeFireX tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "DeFireX" and data_source = "tt";
# 2021-08-02 00:00:00 Elephant Money tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Elephant Money" and data_source = "tt";
# 2021-08-02 00:00:00 HyruleSwap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "HyruleSwap" and data_source = "tt";
# 2021-08-02 00:00:00 Iron Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Iron Finance" and data_source = "tt";
# 2021-08-02 00:00:00 PancakeBunny tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "PancakeBunny" and data_source = "tt";
# 2021-08-02 00:00:00 Pumpy tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Pumpy" and data_source = "tt";
# 2021-08-02 00:00:00 SwampFinance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "SwampFinance" and data_source = "tt";
# 2021-08-02 00:00:00 TreeDefi tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "TreeDefi" and data_source = "tt";
# 2021-08-02 00:00:00 Unifi Protocol tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Unifi Protocol" and data_source = "tt";
# 2021-08-02 00:00:00 Value DeFi tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Value DeFi" and data_source = "tt";
# 2021-08-02 00:00:00 DungeonSwap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "DungeonSwap" and data_source = "tt";
# 2021-08-02 00:00:00 Nominex tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Nominex" and data_source = "tt";
# 2021-08-02 00:00:00 Alpaca Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Alpaca Finance" and data_source = "tt";
# 2021-08-02 00:00:00 Dopple Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Dopple Finance" and data_source = "tt";
# 2021-08-02 00:00:00 Growing Farm tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Growing Farm" and data_source = "tt";
# 2021-08-02 00:00:00 Wault.Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Wault.Finance" and data_source = "tt";
# 2021-08-02 00:00:00 ZCore Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "ZCore Finance" and data_source = "tt";
# 2021-08-02 00:00:00 Hakka Harvester tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Hakka Harvester" and data_source = "tt";
# 2021-08-02 00:00:00 RAMP DEFI tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "RAMP DEFI" and data_source = "tt";
# 2021-08-02 00:00:00 O3 Swap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "O3 Swap" and data_source = "tt";
# 2021-08-02 00:00:00 Definix tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Definix" and data_source = "tt";
# 2021-08-02 00:00:00 Infinity Crypto tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Infinity Crypto" and data_source = "tt";
# 2021-08-02 00:00:00 Lever Network tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Lever Network" and data_source = "tt";
# 2021-08-02 00:00:00 dFuture tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "dFuture" and data_source = "tt";
# 2021-08-02 00:00:00 BunnyPark tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "BunnyPark" and data_source = "tt";
# 2021-08-02 00:00:00 ToolApe tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "ToolApe" and data_source = "tt";
# 2021-08-02 00:00:00 KokomoSwap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "KokomoSwap" and data_source = "tt";
# 2021-08-02 00:00:00 Xpool tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Xpool" and data_source = "tt";
# 2021-08-02 00:00:00 MacaronSwap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "MacaronSwap" and data_source = "tt";
# 2021-08-02 00:00:00 Merlin Lab tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Merlin Lab" and data_source = "tt";
# 2021-08-02 00:00:00 Rabbit Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Rabbit Finance" and data_source = "tt";
# 2021-08-02 00:00:00 CyberTime Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "CyberTime Finance" and data_source = "tt";
# 2021-08-02 00:00:00 Biswap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Biswap" and data_source = "tt";
# 2021-08-02 00:00:00 InsurAce Protocol tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "InsurAce Protocol" and data_source = "tt";
# 2021-08-02 00:00:00 dForce tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "dForce" and data_source = "tt";
# 2021-08-02 00:00:00 MoonFarm Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "MoonFarm Finance" and data_source = "tt";
# 2021-08-02 00:00:00 Hepa Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Hepa Finance" and data_source = "tt";
# 2021-08-02 00:00:00 TEN tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "TEN" and data_source = "tt";
# 2021-08-02 00:00:00 CafeSwap Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "CafeSwap Finance" and data_source = "tt";
# 2021-08-02 00:00:00 InstaDApp tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "InstaDApp" and data_source = "tt";
# 2021-08-02 00:00:00 B.Protocol tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "B.Protocol" and data_source = "tt";
# 2021-08-02 00:00:00 Flexa tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Flexa" and data_source = "tt";
# 2021-08-02 00:00:00 Lightning-Network tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Lightning-Network" and data_source = "tt";
# 2021-08-02 00:00:00 LINKSWAP tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "LINKSWAP" and data_source = "tt";
# 2021-08-02 00:00:00 QIAN tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "QIAN" and data_source = "tt";
# 2021-08-02 00:00:00 yAxis tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "yAxis" and data_source = "tt";
# 2021-08-02 00:00:00 Mushrooms-Finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Mushrooms-Finance" and data_source = "tt";
# 2021-08-02 00:00:00 BiFi tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "BiFi" and data_source = "tt";
# 2021-08-02 00:00:00 UMA tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "UMA" and data_source = "tt";
# 2021-08-02 00:00:00 defirex tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "defirex" and data_source = "tt";
# 2021-08-02 00:00:00 Bella-Flex-Saving tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Bella-Flex-Saving" and data_source = "tt";
# 2021-08-02 00:00:00 Olympus tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Olympus" and data_source = "tt";
# 2021-08-02 00:00:00 premia tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "premia" and data_source = "tt";
# 2021-08-02 00:00:00 fei-protocol tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "fei-protocol" and data_source = "tt";
# 2021-08-02 00:00:00 wing-finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "wing-finance" and data_source = "tt";
# 2021-08-02 00:00:00 o3-swap tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "o3-swap" and data_source = "tt";
# 2021-08-02 00:00:00 ruler-protocol tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "ruler-protocol" and data_source = "tt";
# 2021-08-02 00:00:00 Nsure-Network tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "Nsure-Network" and data_source = "tt";
# 2021-08-02 00:00:00 convex-finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "convex-finance" and data_source = "tt";
# 2021-08-02 00:00:00 dfx-finance tt
# update new_symbols_reporting set mapped_on = FROM_UNIXTIME(1627862400.0) where missing_project = "dfx-finance" and data_source = "tt";
