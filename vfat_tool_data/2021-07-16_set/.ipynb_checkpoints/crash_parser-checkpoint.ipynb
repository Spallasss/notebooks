# %%
import re
import os
import pandas as pd
import numpy as np
import traceback2
from datetime import datetime
import pymysql
import numpy as np

where_map = {}
# pairs regexp: "\[([a-zA-z0-9$\-+τ\.%]*)\]-", "-\[([a-zA-z0-9$\-+τ]*)\]",  or ( c in ['τ'] for c in s)
ignorable_files = ["farm-yield_7_16.csv", "Alternate Yields 7:16.xlsx", "farm_risk_yield_data_2021_07_16.csv", "unmapped_dex.csv", '.ipynb_checkpoints', "crash_parser.ipynb"]

# %%
def __connect__():
    db_user = 'coin'
    db_password = 'dragonstone#123'
    db_name = 'master_data'
    db_host = 'localhost'
    return pymysql.connect(
        unix_socket=None,
        host=db_host,
        user=db_user,
        password=db_password,
        db=db_name,
        charset='latin1',
        cursorclass=pymysql.cursors.DictCursor)


def get_cursor(connection):
    if connection is None:
        connection = __connect__()
    connection.ping(reconnect=True)
    return connection.cursor()

# %%
def get_raydium_data(date):
    sql = f'select * from raydium_farm_pool_data where timestamp_dt = FROM_UNIXTIME({date});'
    data = pd.read_sql_query(sql, __connect__())
    data['apr'] = data['pool_rate']
    data['network'] = 'SOL'
    data['type_of_agriculture'] = data['farm_payment'].apply(lambda x : 'FARM' if x is not None else 'POOL')
    return data[['pair1', 'pair2', 'apr', 'tvl', 'where', 'network', 'type_of_agriculture']]

def get_liquidityfolio_pool_data(date):
    sql = f'select * from liquidityfolio_pool where timestamp_dt = FROM_UNIXTIME({date}) and `where` != "balancer";'
    data = pd.read_sql_query(sql, __connect__())
    data['apr'] = data['pool_rate'] * 100 * 12
    data['tvl'] = data['tvl'] * 1000
    data['type_of_agriculture'] = data['farm_payment'].apply(lambda x : 'FARM' if x is not None else 'POOL')
    data['network'] = 'ETH'
    return data[['pair1', 'pair2', 'apr', 'tvl', 'where', 'network', 'type_of_agriculture']]

# %%
date = datetime(2021, 7, 12)
dt = date.timestamp()

# %%
df = get_raydium_data(dt)
df = df.append(get_liquidityfolio_pool_data(dt))
df[df['where'] == 'Sushi']
# Out:
#       pair1  pair2         apr           tvl  where network  \
# 0       ETH    BEL  155.122558  7.547389e+03  Sushi     ETH
# 1       ETH    UMA    3.767084  4.305553e+06  Sushi     ETH
# 2       ETH    UWL    0.264113  5.270969e+04  Sushi     ETH
# 4     stXYM  stETH    0.000000  0.000000e+00  Sushi     ETH
# 5       ETH  LIGHT    0.134295  1.960001e+03  Sushi     ETH
# ...     ...    ...         ...           ...    ...     ...
# 1803   AMIS   USDC    0.375174  9.974114e+01  Sushi     ETH
# 1804    ETH   SAK3  364.236329  1.856205e+03  Sushi     ETH
# 1809    ETH   89SA    0.000000  3.998762e+03  Sushi     ETH
# 1810    ETH    SEC    1.525689  6.920176e+04  Sushi     ETH
# 1811    ETH    OHM    4.621980  5.027084e+03  Sushi     ETH
#
#      type_of_agriculture
# 0                   POOL
# 1                   POOL
# 2                   POOL
# 4                   POOL
# 5                   POOL
# ...                  ...
# 1803                POOL
# 1804                POOL
# 1809                POOL
# 1810                POOL
# 1811                POOL
#
# [923 rows x 7 columns]

# %%
get_liquidityfolio_pool_data(dt)
# Out:
#       pair1  pair2         apr           tvl    where network  \
# 0       ETH    BEL  155.122558  7.547389e+03    Sushi     ETH
# 1       ETH    UMA    3.767084  4.305553e+06    Sushi     ETH
# 2       ETH    UWL    0.264113  5.270969e+04    Sushi     ETH
# 3      WBTC   USDC    5.161059  1.029026e+06  Uniswap     ETH
# 4     stXYM  stETH    0.000000  0.000000e+00    Sushi     ETH
# ...     ...    ...         ...           ...      ...     ...
# 1807    ETH    CHZ    8.838859  4.913366e+04  Uniswap     ETH
# 1808    ETH   POLS    3.309331  4.662414e+06  Uniswap     ETH
# 1809    ETH   89SA    0.000000  3.998762e+03    Sushi     ETH
# 1810    ETH    SEC    1.525689  6.920176e+04    Sushi     ETH
# 1811    ETH    OHM    4.621980  5.027084e+03    Sushi     ETH
#
#      type_of_agriculture
# 0                   POOL
# 1                   POOL
# 2                   POOL
# 3                   POOL
# 4                   POOL
# ...                  ...
# 1807                POOL
# 1808                POOL
# 1809                POOL
# 1810                POOL
# 1811                POOL
#
# [1812 rows x 7 columns]

# %%
sm = {
    "WBTC" : "BTC",
    "WETH" : "ETH",
    "WBNB" : "BNB",
    "WFTM" : "FTM",
    "WAVAX" : "AVAX",
    "cvxCRV" : "CRV"
}

# %%
dex_map = {
    "SUSHI" : "https://app.sushi.com"
    
}

# %%
def get_alternate_pairs(line):
    spl = line.split("/")
    print(spl)
    if spl and len(spl) > 1:
        pair1 = spl[0].strip()
        print(pair1)
        pair2 = spl[1].strip()
        print(pair2)
        pair2 = pair2[0 : pair2.index(' ')]
        return [pair1, pair2]
    return None

# %%
def pair1(line):
#     print(line)
    try:
        is_3_pairs = line.split("]-[")
        if len(is_3_pairs) > 2:
            return None
        s_index = line.index("[") + 1
        s = line[s_index: line.index("]", s_index)]
        if all(ord(c) < 128 for c in s):
            return s
        else:
            print(line)
            return None
    except:
        return ''

def pair2(line):
#     print(line)
    s_index = line.index("-[") + 2
    s = line[s_index: line.index("]", s_index)]
#     print(s)
    if all(ord(c) < 128 for c in s):
        return s
    else:
        print(line)
        return ''

# %%
def apr(line):
    apr = "Year [0-9\,\.]+\%"
    x = re.findall(apr, line)
    return x[0].replace("Year ", "").replace("%", "").strip() if len(x) else 0

# %%
def tvl(line):
    tvl = "TVL: \$[0-9\.\,]+"
    x = re.findall(tvl, line)
    return x[0].replace("TVL: $", "").replace("%", "").replace(",","").strip()

# %%
def where(line):
    if 'INFO' in line:
        return line.replace("INFO", "").replace('\n', '').replace(":", "").replace("//", "://").replace('*', '').strip()
    return None

# %%
def get_single_pair(line): 
    exp = "\d* *.*Price:"
    x = re.findall(exp, line)
    if not len(x) or "TVL:" in line:
#         print(">>>>>>>>>>>",line)
        return
    pair = x[0].replace(" Price:", "")
    return pair[pair.rindex(" "):].strip() if " " in pair else pair

def get_single_tvl(line):
    exp = "\(*[0-9\,\.$]+\)*"
    x = re.findall(exp, line)
    return x[-1].replace("(", "").replace(")", "").replace("$", "").replace(",","").strip()

# %%
tvl("[WBTC]-[WAVAX] PGL [+] [-] [<=>] Price: $160,706,376.77 TVL: $12,218,373.64\n")
# Out:
# '12218373.64'

# %%
def is_end_of_block(line):
#     print(line, line == "" or len(re.findall("INFO[ ]+: ", line)))
    return line.strip() == "" or len(re.findall("INFO[ ]+: ", line)) or "******" in line

def read_block(lines, start_index):
    block = []
#     print("Block Start Line No.: ", start_index + 1)
    while start_index < len(lines):
        line = lines[start_index]
        start_index = start_index + 1
        if not is_end_of_block(line):
            block.append(line.strip())
        else:
            break
    return [block, start_index]

def read_blocks_from_files(file):
    f = open(file)
    lines = f.readlines()
    blocks = []
    block = []
    block_start_line_no = []
    line_no = 0
    start_index = 0
    while start_index < len(lines):
        line = lines[start_index]
        if not is_end_of_block(lines[start_index]):
            block_and_index = read_block(lines, start_index)
#             print(block_and_index[0])
            if block_and_index is not None:
                block_start_line_no.append(start_index + 1)
                start_index = block_and_index[1]
                blocks.append(block_and_index[0])
            else:
                start_index = start_index + 1
        elif len(re.findall("INFO[ ]+: ", line)):
            block_start_line_no.append(start_index + 1)
            blocks.append([line])
            start_index = start_index + 1
        else:
            start_index = start_index + 1
    return [blocks, block_start_line_no]

def read_blocks_from_files_as(file):
    f = open(file)
    lines = f.readlines()
    blocks = []
    block = []
    block_start_line_no = []
    line_no = 0
    for line in lines:
        line_no = line_no + 1
        line = line.strip()
        if line == "" or len(re.findall("INFO[ ]+: ", line)):
            blocks.append(block)
            block_start_line_no.append(line_no)
            if len(line):
                blocks.append([line])
                block_start_line_no.append(line_no + 1)
            block = []
        else:
            block.append(line)
            
    blocks.append(block)
    return [blocks, block_start_line_no]

def get_pair_info_from_block(block, wh, network):
    tvl_index = 0
    if network == 'BSC':
        tvl_index = 3
    if len(block) == 1:
        if 'INFO' in block[0]:
            return [where(block[0])]
        else:
            return [wh] if len(wh) else None
    if len(block) and pair1(block[0]) and not get_single_pair(block[0]):
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        return [pair1(block[0]), pair2(block[0]), get_single_tvl(block[tvl_index]) if tvl_index > 0 else tvl(block[tvl_index]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
    elif len(block) > 2 and get_alternate_pairs(block[0]):
        print(get_alternate_pairs(block[0]))
        tvl_index = 0
        for index in range(1, len(block)):
            if 'Staked: ' in block[index]:
                tvl_index = index
                break
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        pairs = get_alternate_pairs(block[0])
        return [pairs[0], pairs[1], get_single_tvl(block[tvl_index]), apr(block[apr_index]), where_map[wh] if wh in where_map else wh, network]
    elif len(block) > 2 and get_single_pair(block[0]):
#         print('singel')
        if network == 'BSC':
            tvl_index = 1
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        tvl_index = 0
        if "TVL:" not in block[0]:
            for index in range(1, len(block)):
                if 'Stacked: ' in block[index]:
                    tvl_index = index
                    break
        return [get_single_pair(block[0]), "", get_single_tvl(block[tvl_index]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
    return None


def get_pairs(blocks, network, block_start_line_no):
    where = ""
    pairs = []
    index = -1
    for block in blocks:
#         print('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
        index = index + 1
        try:
            pair = get_pair_info_from_block(block, where, network)
            if pair == None:
                print('no Pair....\n',block)
                print("Block Start Line No.: ", block_start_line_no[index] if index < len(block_start_line_no) else -1)
#             if len(where) == 0 and pair and len(pair) > 2:
#                 print(block, network)
            if pair is not None and len(pair) > 0:
                if len(pair) == 1 and pair[0] and len(pair[0]):
                    where = pair[0]
                else:
                    pairs.append(pair)
        except Exception as e:
            print("Exception", traceback2.format_exc())
            print(block[0])
    return pairs

# %%
block = [['17 - mrenBTC Price: $33,923.83 TVL: $75,675.25', 'Staked: 2.2015 mrenBTC ($74,682.95)', 'MM Per Week: 58.02 ($193.79)', 'APR: Day 0.04% Week 0.26% Year 13.49%', 'You are staking 0.00 mrenBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mrenBTC', 'Unstake 0.00 mrenBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']]
get_pairs(block, "AVAX", [1])
# Out:
# ['17 - mrenBTC Price: $33,923.83 TVL: $75,675.25']
# no Pair....
#  ['17 - mrenBTC Price: $33,923.83 TVL: $75,675.25', 'Staked: 2.2015 mrenBTC ($74,682.95)', 'MM Per Week: 58.02 ($193.79)', 'APR: Day 0.04% Week 0.26% Year 13.49%', 'You are staking 0.00 mrenBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mrenBTC', 'Unstake 0.00 mrenBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1
# []

# %%
# def get_single_tvl(line):
#     exp = "\(*[0-9\,\.$]+\)*"
#     x = re.findall(exp, line)
#     print(x)
#     return x[-1].replace("(", "").replace(")", "").replace("$", "").replace(",","").strip()

# %%
get_single_pair(block[0][0])

# %%
data_dir = './'
def conver_files_to_one_df(data_dir):
    all_pairs = []
    files = os.listdir(data_dir)
    for file_name in files:
        print(file_name)
        if file_name in ignorable_files:
            continue
        network = file_name[0:file_name.index(" ")]
        if 'Alternate' == network:
            network = 'ETH'
#         if 'MATIC' != network:
#             continue
        print(file_name)
        blocks = read_blocks_from_files(f"{data_dir}{file_name}")
        block_start_line_no = blocks[1]
        blocks = blocks[0]
        pairs = get_pairs(blocks, network, block_start_line_no)
        all_pairs.extend(pairs)
    return all_pairs

# %%
pairs = conver_files_to_one_df(data_dir)
# Out:
# .ipynb_checkpoints
# FANTOM 7:16 Yields.uu
# FANTOM 7:16 Yields.uu
# no Pair....
#  ['FANTOM 7/16 Yields']
# Block Start Line No.:  1
# no Pair....
#  ['Total Staked: $36,493,534.18', 'Found 1 pools.']
# Block Start Line No.:  287
# ['0 - BOO Price: $2.67 Market Cap: $13,249,568.26']
# ['0 - SPIRIT Price: $0.02 Market Cap: $6,012,696.06']
# ['30 - SPIRIT-LP Price: $0.00 Market Cap: $0.00']
# ['8 - SON Price: $104.51 Market Cap: $7,995.31']
# ['14 - WFTM Price: $0.20 Market Cap: $50,492,947.51']
# ['15 - ETH Price: $1,920.60 Market Cap: $5,207,194.12']
# ['16 - YFI Price: $29,040.00 Market Cap: $1,049,477.52']
# ['17 - FUSD Price: $1.00 Market Cap: $24,684,823.40']
# ['19 - ICE Price: $2.08 Market Cap: $6,399,053.78']
# ['20 - LINK Price: $15.68 Market Cap: $1,256,503.80']
# ['21 - CREAM Price: $0.000642 Market Cap: $2.72']
# ['22 - DAI Price: $1.00 Market Cap: $37,054,979.95']
# ['23 - OPE Price: $0.00 Market Cap: $0.00']
# ['24 - AURORA Price: $0.13 Market Cap: $1,276,050.37']
# ['28 - BOO Price: $2.67 Market Cap: $13,249,612.68']
# ['29 - SPIRIT Price: $0.00 Market Cap: $0.00']
# ['38 - SNX Price: $0.00 Market Cap: $0.00']
# ['44 - SUSHI Price: $6.61 Market Cap: $1,551,304.96']
# ['0 - ORI Price: $0.03 Market Cap: $716,125.11']
# ['2 - EST Price: $0.06 Market Cap: $78,595.57']
# ['1 - 3FROYO Price: $1.00 Market Cap: $291,584.52']
# ['20 - NTOKEN Price: $0.00 Market Cap: $0.00']
# ['0 - MM Price: $2.53 Market Cap: $37,043.98']
# ['2 - mBOO Price: $3.25 TVL: $16,170.82']
# no Pair....
#  ['2 - mBOO Price: $3.25 TVL: $16,170.82', 'Staked: 4080.0064 mBOO ($13,263.66)', 'MM Per Week: 29.68 ($75.01)', 'APR: Day 0.08% Week 0.57% Year 29.41%', 'You are staking 0.00 mBOO ($0.00), 0.00% of the pool.', 'Stake 0.00 mBOO', 'Unstake 0.00 mBOO', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1844
# ['3 - mSPIRIT Price: $0.00 TVL: $0.00']
# no Pair....
#  ['3 - mSPIRIT Price: $0.00 TVL: $0.00', 'Staked: 312670.5088 mSPIRIT ($0.00)', 'MM Per Week: 14.84 ($37.50)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 mSPIRIT ($0.00), NaN% of the pool.', 'Stake 0.00 mSPIRIT', 'Unstake 0.00 mSPIRIT', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1854
# ['8 - mUSDC Price: $1.00 TVL: $10,004.17']
# no Pair....
#  ['8 - mUSDC Price: $1.00 TVL: $10,004.17', 'Staked: 9991.3359 mUSDC ($9,997.25)', 'MM Per Week: 7.42 ($18.75)', 'APR: Day 0.03% Week 0.19% Year 9.75%', 'You are staking 0.00 mUSDC ($0.00), 0.00% of the pool.', 'Stake 0.00 mUSDC', 'Unstake 0.00 mUSDC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1906
# ['0 - SEED Price: $0.000513 Market Cap: $5,745.28']
# ['11 - USDC Price: $1.00 Market Cap: $57,826,484.62']
# ['12 - WFTM Price: $0.20 Market Cap: $50,493,016.36']
# ['13 - BTC Price: $32,000.29 Market Cap: $9,078,708.73']
# ['14 - ETH Price: $1,920.72 Market Cap: $5,207,519.47']
# ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.']
# no Pair....
#  ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.', '0 - iFUSD Price: $0.35 Market Cap: $4,030,790.17', 'Staked: 219930.8952 iFUSD ($76,600.53)', 'STEAK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 iFUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 iFUSD - Fee 0.005%', 'Unstake 0.00 iFUSD', 'Claim 0.00 STEAK ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2062
# ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.']
# no Pair....
#  ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.', '1 - [STEAK]-[FUSD] SPIRIT LP [+] [-] [<=>] Price: $1.10 TVL: $18,184.12', 'STEAK Price: $0.85', 'FUSD Price: $0.34', 'Staked: 5910.2051 SPIRIT-LP ($6,514.02)', 'STEAK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 [STEAK]-[FUSD] SPIRIT LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [STEAK]-[FUSD] SPIRIT LP - Fee 0.005%', 'Unstake 0.00 [STEAK]-[FUSD] SPIRIT LP', 'Claim 0.00 STEAK ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2073
# ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.']
# no Pair....
#  ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.', '2 - [USDC]-[FUSD] SPIRIT LP [+] [-] [<=>] Price: $1,307,039.52 TVL: $6,792.43', 'USDC Price: $1.00', 'FUSD Price: $0.34', 'Staked: 0.0010 SPIRIT-LP ($1,325.10)', 'STEAK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 [USDC]-[FUSD] SPIRIT LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [USDC]-[FUSD] SPIRIT LP - Fee 0.005%', 'Unstake 0.00 [USDC]-[FUSD] SPIRIT LP', 'Claim 0.00 STEAK ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2086
# ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.']
# no Pair....
#  ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.', '5 - [WFTM]-[FUSD] SPIRIT LP [+] [-] [<=>] Price: $0.72 TVL: $11,558.98', 'WFTM Price: $0.20', 'FUSD Price: $0.34', 'Staked: 14382.8154 SPIRIT-LP ($10,368.49)', 'STEAK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 [WFTM]-[FUSD] SPIRIT LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [WFTM]-[FUSD] SPIRIT LP - Fee 0.005%', 'Unstake 0.00 [WFTM]-[FUSD] SPIRIT LP', 'Claim 0.00 STEAK ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2099
# ['Total Staked: $94,808.14']
# no Pair....
#  ['Total Staked: $94,808.14', 'FUSD Price: $0.34 Market Cap: $8,508,447.57', 'Staked: 11694183.0744 FUSD ($4,030,790.17)', 'FUSD Per Week: 14000.00 ($4,825.57)', 'APR: Day 0.02% Week 0.12% Year 6.23%', 'You are staking 0.00 FUSD ($0.00), 0.00% of the pool.', 'iFUSD Contract', 'Deposit 0.00 FUSD', 'Withdraw 0.00 iFUSD']
# Block Start Line No.:  2112
# ['STEAK Price: $0.85 Market Cap: $4,264,082.36']
# ['FRANK Price: $0.10 Market Cap: $36,876.23']
# ['SPIRIT Price: $0.02 Market Cap: $6,011,466.58']
# ['BOO Price: $2.67 Market Cap: $13,249,780.65']
# ['LQDR Price: $0.44 Market Cap: $461,231.93']
# ['19 - pWaka Price: $0.00 Market Cap: $0.00']
# ['22 - bWaka Price: $0.00 Market Cap: $0.00']
# ['0 - BRUSH Price: $0.001691 Market Cap: $240,809.15']
# ['2 - KLING Price: $12.07 Market Cap: $513.93']
# ['20 - WFTM Price: $0.20 Market Cap: $50,468,085.08']
# ['21 - FUSD Price: $0.00 Market Cap: $0.00']
# ['22 - DAI Price: $1.00 Market Cap: $37,054,979.95']
# ['23 - USDC Price: $1.00 Market Cap: $57,826,484.62']
# ['24 - fUSDT Price: $1.00 Market Cap: $51,353,725.03']
# ['25 - BTC Price: $0.00 Market Cap: $0.00']
# ['26 - ETH Price: $1,919.69 Market Cap: $5,204,726.90']
# ['27 - YFI Price: $29,032.00 Market Cap: $1,049,188.41']
# ['28 - BNB Price: $309.74 Market Cap: $1,741,041.94']
# ['29 - ICE Price: $2.08 Market Cap: $6,399,053.78']
# ['30 - LINK Price: $15.66 Market Cap: $1,254,901.12']
# ['31 - CREAM Price: $0.000642 Market Cap: $2.72']
# ['32 - ORI Price: $0.00 Market Cap: $0.00']
# ['33 - SON Price: $0.00 Market Cap: $0.00']
# ['34 - BOO Price: $2.67 Market Cap: $13,249,896.58']
# ['35 - SPIRIT Price: $0.00 Market Cap: $0.00']
# ['36 - SNX Price: $9.49 Market Cap: $751,679.47']
# ['37 - SUSHI Price: $6.60 Market Cap: $1,548,958.05']
# ['38 - FRANK Price: $0.00 Market Cap: $0.00']
# ['39 - EST Price: $0.00 Market Cap: $0.00']
# ['40 - CzTears Price: $0.00 Market Cap: $0.00']
# ['41 - OPE Price: $0.00 Market Cap: $0.00']
# ['42 - GHOST Price: $0.00 Market Cap: $0.00']
# ['43 - LQDR Price: $0.00 Market Cap: $0.00']
# ['44 - WAKA Price: $0.00 Market Cap: $0.00']
# ['45 - BRUSH Price: $0.00 Market Cap: $0.00']
# ['48 - AAVE Price: $267.96 Market Cap: $857,887.42']
# ['49 - CRV Price: $1.48 Market Cap: $1,519,844.02']
# ['0 - OPERA Price: $0.008879 Market Cap: $14,867.89']
# ['3 - CHAD Price: $0.01 Market Cap: $28,933.08']
# ['2 - RDT Price: $0.009683 Market Cap: $3,729.53']
# ['3 - USDC Price: $1.00 Market Cap: $57,826,484.62']
# ['4 - WFTM Price: $0.20 Market Cap: $50,417,666.16']
# ['5 - ETH Price: $1,919.97 Market Cap: $5,205,486.05']
# ['6 - BTC Price: $0.00 Market Cap: $0.00']
# ['7 - DAI Price: $1.00 Market Cap: $37,054,979.95']
# ['8 - fUSDT Price: $1.00 Market Cap: $51,353,725.03']
# ['9 - BNB Price: $309.82 Market Cap: $1,741,491.62']
# ['10 - BOO Price: $2.67 Market Cap: $13,250,032.48']
# ['3 - CATNIP Price: $2.19 Market Cap: $22,400.26']
# ['1 - ibSPOON Price: $0.00 Market Cap: $0.00']
# ['2 - ibFTM Price: $0.20 Market Cap: $12,424.74']
# ['3 - ibUSDC Price: $1.00 Market Cap: $11,252.90']
# ['4 - ibfUSDT Price: $1.00 Market Cap: $6,620.27']
# ['5 - ibDAI Price: $1.00 Market Cap: $10,141.80']
# ['0 - BULL Price: $0.000747 Market Cap: $3,156.86']
# ['1 - WFTM Price: $0.20 Market Cap: $50,417,776.29']
# ['2 - BOO Price: $2.67 Market Cap: $13,250,073.59']
# ['3 - BTC Price: $0.00 Market Cap: $0.00']
# ['4 - ETH Price: $1,920.53 Market Cap: $5,207,004.34']
# ['5 - USDC Price: $1.00 Market Cap: $57,826,484.62']
# ['Total Staked: $429,827.06']
# no Pair....
#  ['Total Staked: $429,827.06', 'Staking Contract', 'Found 1 pools.']
# Block Start Line No.:  4768
# ['0 - SHADE Price: $1.69 Market Cap: $4,430,254.58']
# farm-yield_7_16.csv
# ETH 7:16 Yields.uu
# ETH 7:16 Yields.uu
# no Pair....
#  ['ETH 7/16 Yields']
# Block Start Line No.:  1
# ['DEX Price: $1.11 Market Cap: $466,200.00 [%]']
# ['KIF Price: $30.60 Market Cap: $1,254,599.90 [%]']
# ['kBASEv0 Price: $0.20 Market Cap: $34,946.01 [%]']
# ['Boardroom']
# no Pair....
#  ['Boardroom', 'There is a total 1619.93 BAS ($57.25) staked in the Boardroom.', 'You are staking 0 BAS ($0.00), 0.00% of the pool.', 'Stake 0.00 BAS', 'Unstake 0.00 BAS', 'Claim 0.00 BAC ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  503
# ['Boardroom']
# no Pair....
#  ['Boardroom', 'There is a total 30319.19 BSGS ($1,870.42) staked in the Boardroom.', 'You are staking 0 BSGS ($0.00), 0.00% of the pool.', 'Stake 0.0000 BSGS', 'Unstake 0.0000 BSGS', 'Claim 0.0000 BSG', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  547
# ['DAIQ Price: $0.000526 Market Cap: $5,977.59 [%]']
# ['DAI Price: $1.00 Market Cap: $5,246,262,093.47 [%]']
# ['DPX Price: $103.89 Market Cap: $51,945,000.00 [%]']
# ['YFI Price: $27,854.00 Market Cap: $1,021,294,764.00 [%]']
# ['LINK Price: $15.56 Market Cap: $15,560,000,000.00 [%]']
# ['CREAM Price: $178.64 Market Cap: $1,607,760,000.00 [%]']
# ['renDOGE Price: $0.18 Market Cap: $3,502,828.94 [%]']
# ['USDT Price: $1.00 Market Cap: $30,910,401,959.98 [%]']
# ['BUSD Price: $1.00 Market Cap: $11,188,613,530.54 [%]']
# ['USDC Price: $1.00 Market Cap: $25,603,380,061.54 [%]']
# ['CRV Price: $1.46 Market Cap: $2,260,916,871.51 [%]']
# ['COMP Price: $381.77 Market Cap: $3,817,700,000.00 [%]']
# ['SUSHI Price: $6.54 Market Cap: $1,492,476,659.26 [%]']
# ['BADGER Price: $7.83 Market Cap: $164,430,000.00 [%]']
# ['DSD Price: $0.02 Market Cap: $2,914,884.53 [%]']
# ['ESD Price: $0.12 Market Cap: $61,207,523.07 [%]']
# ['FRAX Price: $1.00 Market Cap: $233,319,365.98 [%]']
# ['MIC Price: $0.00 Market Cap: $0.00']
# ['OGN Price: $0.77 Market Cap: $771,302,000.00 [%]']
# ['OUSD Price: $1.00 Market Cap: $19,117,663.05 [%]']
# ['CVP Price: $0.87 Market Cap: $86,695,600.00 [%]']
# ['ALBT Price: $0.34 Market Cap: $335,560,000.00 [%]']
# ['SPDR Price: $0.009043 Market Cap: $9,043,070.00 [%]']
# ['FARM Price: $75.08 Market Cap: $47,065,784.01 [%]']
# ['fWETH Price: $1,916.09 TVL: $14,314,480.61']
# no Pair....
#  ['fWETH Price: $1,916.09 TVL: $14,314,480.61', 'Staked: 7415.2642 fWETH ($14,208,310.95)', 'FARM Per Week: 101.73 ($7,637.94)', 'APR: Day 0.01% Week 0.05% Year 2.80%', 'You are staking 0.00 fWETH ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fWETH', 'Unstake 0.000000 fWETH', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1000
# ['fBAC Price: $0.08 TVL: $93.47']
# no Pair....
#  ['fBAC Price: $0.08 TVL: $93.47', 'Staked: 802.2039 fBAC ($65.91)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fBAC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fBAC', 'Unstake 0.000000 fBAC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1048
# ['fESD Price: $0.12 TVL: $26,598.13']
# no Pair....
#  ['fESD Price: $0.12 TVL: $26,598.13', 'Staked: 211750.8008 fESD ($25,093.31)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fESD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fESD', 'Unstake 0.000000 fESD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1060
# ['fDSD Price: $0.02 TVL: $1,521.46']
# no Pair....
#  ['fDSD Price: $0.02 TVL: $1,521.46', 'Staked: 60247.9388 fDSD ($1,419.21)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fDSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fDSD', 'Unstake 0.000000 fDSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1072
# ['fyDAI+yUSDC+yUSDT+yTUSD Price: $1.15 TVL: $640,472.38']
# no Pair....
#  ['fyDAI+yUSDC+yUSDT+yTUSD Price: $1.15 TVL: $640,472.38', 'Staked: 452106.5006 fyDAI+yUSDC+yUSDT+yTUSD ($521,015.36)', 'FARM Per Week: 1.27 ($95.48)', 'APR: Day 0.00% Week 0.02% Year 0.95%', 'You are staking 0.00 fyDAI+yUSDC+yUSDT+yTUSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fyDAI+yUSDC+yUSDT+yTUSD', 'Unstake 0.000000 fyDAI+yUSDC+yUSDT+yTUSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1084
# ['fhusd3CRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['fhusd3CRV Price: $0.00 TVL: $0.00', 'Staked: 1600925.6950 fhusd3CRV ($0.00)', 'FARM Per Week: 6.36 ($477.36)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fhusd3CRV ($0.00), NaN% of the pool.', 'Staking Contract', 'Stake 0.000000 fhusd3CRV', 'Unstake 0.000000 fhusd3CRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1096
# ['fcDAI+cUSDC Price: $1.11 TVL: $1,047,266.75']
# no Pair....
#  ['fcDAI+cUSDC Price: $1.11 TVL: $1,047,266.75', 'Staked: 897605.5621 fcDAI+cUSDC ($993,313.65)', 'FARM Per Week: 6.36 ($477.38)', 'APR: Day 0.01% Week 0.05% Year 2.50%', 'You are staking 0.00 fcDAI+cUSDC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fcDAI+cUSDC', 'Unstake 0.000000 fcDAI+cUSDC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1108
# ['fyDAI+yUSDC+yUSDT+yBUSD Price: $1.13 TVL: $1,317,640.19']
# no Pair....
#  ['fyDAI+yUSDC+yUSDT+yBUSD Price: $1.13 TVL: $1,317,640.19', 'Staked: 939845.1221 fyDAI+yUSDC+yUSDT+yBUSD ($1,066,365.57)', 'FARM Per Week: 9.16 ($687.43)', 'APR: Day 0.01% Week 0.06% Year 3.35%', 'You are staking 0.00 fyDAI+yUSDC+yUSDT+yBUSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fyDAI+yUSDC+yUSDT+yBUSD', 'Unstake 0.000000 fyDAI+yUSDC+yUSDT+yBUSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1120
# ['fusdn3CRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['fusdn3CRV Price: $0.00 TVL: $0.00', 'Staked: 1824971.8129 fusdn3CRV ($0.00)', 'FARM Per Week: 33.06 ($2,482.38)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fusdn3CRV ($0.00), NaN% of the pool.', 'Staking Contract', 'Stake 0.000000 fusdn3CRV', 'Unstake 0.000000 fusdn3CRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1132
# ['fUSDC Price: $0.91 TVL: $31,101,878.74']
# no Pair....
#  ['fUSDC Price: $0.91 TVL: $31,101,878.74', 'Staked: 36998219.5164 fUSDC ($33,704,280.79)', 'FARM Per Week: 38.43 ($2,885.28)', 'APR: Day 0.00% Week 0.01% Year 0.45%', 'You are staking 0.00 fUSDC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fUSDC', 'Unstake 0.000000 fUSDC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1144
# ['fUSDT Price: $0.92 TVL: $21,609,321.35']
# no Pair....
#  ['fUSDT Price: $0.92 TVL: $21,609,321.35', 'Staked: 25642348.4495 fUSDT ($23,488,070.52)', 'FARM Per Week: 22.82 ($1,713.06)', 'APR: Day 0.00% Week 0.01% Year 0.38%', 'You are staking 0.00 fUSDT ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fUSDT', 'Unstake 0.000000 fUSDT', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1156
# ['fTUSD Price: $1.05 TVL: $24,944.56']
# no Pair....
#  ['fTUSD Price: $1.05 TVL: $24,944.56', 'Staked: 2390.8356 fTUSD ($2,522.28)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fTUSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fTUSD', 'Unstake 0.000000 fTUSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1168
# ['fDAI Price: $1.05 TVL: $22,582,625.28']
# no Pair....
#  ['fDAI Price: $1.05 TVL: $22,582,625.28', 'Staked: 20308611.8088 fDAI ($21,394,962.01)', 'FARM Per Week: 25.22 ($1,893.51)', 'APR: Day 0.00% Week 0.01% Year 0.46%', 'You are staking 0.00 fDAI ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fDAI', 'Unstake 0.000000 fDAI', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1180
# ['fhCRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['fhCRV Price: $0.00 TVL: $0.00', 'Staked: 214.1772 fhCRV ($0.00)', 'FARM Per Week: 17.80 ($1,336.62)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fhCRV ($0.00), NaN% of the pool.', 'Staking Contract', 'Stake 0.000000 fhCRV', 'Unstake 0.000000 fhCRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1240
# ['foBTC', 'sbtcCRV Price: $35,590.29 TVL: $6,819,846.09']
# foBTC
# sbtcCRV Price: $35,590.29 TVL: $6,819,846.09
# ['foBTC', 'sbtcCRV Price: $35,590.29 TVL: $6,819,846.09']
# foBTC
# sbtcCRV Price: $35,590.29 TVL: $6,819,846.09
# ['foBTC', 'sbtcCRV']
# ['foBTC', 'sbtcCRV Price: $35,590.29 TVL: $6,819,846.09']
# foBTC
# sbtcCRV Price: $35,590.29 TVL: $6,819,846.09
# ['ftbtc', 'sbtcCrv Price: $32,857.28 TVL: $398,502.61']
# ftbtc
# sbtcCrv Price: $32,857.28 TVL: $398,502.61
# ['ftbtc', 'sbtcCrv Price: $32,857.28 TVL: $398,502.61']
# ftbtc
# sbtcCrv Price: $32,857.28 TVL: $398,502.61
# ['ftbtc', 'sbtcCrv']
# ['ftbtc', 'sbtcCrv Price: $32,857.28 TVL: $398,502.61']
# ftbtc
# sbtcCrv Price: $32,857.28 TVL: $398,502.61
# ['fcrvRenWBTC Price: $32,899.23 TVL: $19,097,853.94']
# no Pair....
#  ['fcrvRenWBTC Price: $32,899.23 TVL: $19,097,853.94', 'Staked: 569.1363 fcrvRenWBTC ($18,724,145.43)', 'FARM Per Week: 30.52 ($2,291.34)', 'APR: Day 0.00% Week 0.01% Year 0.64%', 'You are staking 0.00 fcrvRenWBTC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fcrvRenWBTC', 'Unstake 0.000000 fcrvRenWBTC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1276
# ['fWBTC Price: $32,253.49 TVL: $264,540.86']
# no Pair....
#  ['fWBTC Price: $32,253.49 TVL: $264,540.86', 'Staked: 7.9612 fWBTC ($256,776.07)', 'FARM Per Week: 1.27 ($95.47)', 'APR: Day 0.01% Week 0.04% Year 1.93%', 'You are staking 0.00 fWBTC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fWBTC', 'Unstake 0.000000 fWBTC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1288
# ['frenBTC Price: $32,005.24 TVL: $78,611.60']
# no Pair....
#  ['frenBTC Price: $32,005.24 TVL: $78,611.60', 'Staked: 2.3888 frenBTC ($76,452.74)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 frenBTC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 frenBTC', 'Unstake 0.000000 frenBTC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1300
# ['0 - DEFI5 Price: $67.56 Market Cap: $7,864,545.80 [%]']
# ['1 - CC10 Price: $47.20 Market Cap: $3,837,005.19 [%]']
# ['2 - DEGEN Price: $2.80 Market Cap: $7,435,304.29 [%]']
# ['Total Staked: $11,922,532.90']
# no Pair....
#  ['Total Staked: $11,922,532.90', '[DEGEN]-[WETH] Uni LP [+] [-] [<=>] Price: $165.14 TVL: $1,318,052.19', 'DEGEN Price: $2.80', 'WETH Price: $1,912.08', 'Staked: 1281.1005 UNI-V2 ($211,557.95)', 'NDX Per Week: 0.00 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.000000 [DEGEN]-[WETH] Uni LP $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [DEGEN]-[WETH] Uni LP', 'Unstake 0.000000 [DEGEN]-[WETH] Uni LP', 'Claim 0.000000 NDX ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1599
# ['DEFI5 Price: $67.56 Market Cap: $7,864,545.80 [%]']
# ['CC10 Price: $47.20 Market Cap: $3,837,005.19 [%]']
# ['MICv2_3CRV3CRV-f Price: $0.26 Market Cap: $39,967.51']
# no Pair....
#  ['Initialized 0xf42122af352885352e26e5a6253cb20ad9f727ec', 'Reading smart contracts...']
# Block Start Line No.:  1728
# ['Boardroom']
# no Pair....
#  ['Boardroom', 'There is a total 6512.33 MIS ($9,417.71) staked in the Boardroom.', 'You are staking 0 MIS ($0.00), 0.00% of the pool.', 'Stake 0.00 MIS', 'Unstake 0.00 MIS', 'Claim 0.00 MIC ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1759
# ['Boardroom']
# no Pair....
#  ['Boardroom', 'There is a total 99863.25 MORT ($5,805.95) staked in the Boardroom.', 'You are staking 0 MORT ($0.00), 0.00% of the pool.', 'There will be 22440.16 MORC issued at next expansion.', 'Boardroom APR: Day 62.41% Week 436.90% Year 22781.21%', 'Stake 0.00 MORT', 'Unstake 0.00 MORT', 'Claim 0.00 MORC ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1803
# ['0 - MM Price: $2.68 Market Cap: $1,602,024.12 [%]']
# ['1 - m3Crv Price: $1.08 TVL: $58,035.65']
# no Pair....
#  ['1 - m3Crv Price: $1.08 TVL: $58,035.65', 'Staked: 50783.0784 m3Crv ($54,825.88)', 'MM Per Week: 27.77 ($74.41)', 'APR: Day 0.02% Week 0.14% Year 7.06%', 'You are staking 0.00 m3Crv ($0.00), 0.00% of the pool.', 'Stake 0.00 m3Crv', 'Unstake 0.00 m3Crv', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1831
# ['3 - mcrvRenWBTC Price: $33,145.39 TVL: $34,742.41']
# no Pair....
#  ['3 - mcrvRenWBTC Price: $33,145.39 TVL: $34,742.41', 'Staked: 1.0278 mcrvRenWBTC ($34,065.92)', 'MM Per Week: 27.77 ($74.41)', 'APR: Day 0.03% Week 0.22% Year 11.36%', 'You are staking 0.00 mcrvRenWBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mcrvRenWBTC', 'Unstake 0.00 mcrvRenWBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1853
# ['4 - mDAI Price: $1.07 TVL: $112,055.87']
# no Pair....
#  ['4 - mDAI Price: $1.07 TVL: $112,055.87', 'Staked: 97845.7597 mDAI ($104,710.00)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.02% Week 0.14% Year 7.39%', 'You are staking 0.00 mDAI ($0.00), 0.00% of the pool.', 'Stake 0.00 mDAI', 'Unstake 0.00 mDAI', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1863
# ['5 - mUSDC Price: $1.08 TVL: $155,478.24']
# no Pair....
#  ['5 - mUSDC Price: $1.08 TVL: $155,478.24', 'Staked: 131587.0773 mUSDC ($142,514.88)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.01% Week 0.10% Year 5.43%', 'You are staking 0.00 mUSDC ($0.00), 0.00% of the pool.', 'Stake 0.00 mUSDC', 'Unstake 0.00 mUSDC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1873
# ['9 - mWETH Price: $1,958.25 TVL: $401,734.02']
# no Pair....
#  ['9 - mWETH Price: $1,958.25 TVL: $401,734.02', 'Staked: 188.6877 mWETH ($369,496.89)', 'MM Per Week: 111.06 ($297.64)', 'APR: Day 0.01% Week 0.08% Year 4.19%', 'You are staking 0.00 mWETH ($0.00), 0.00% of the pool.', 'Stake 0.00 mWETH', 'Unstake 0.00 mWETH', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1917
# ['10 - mUNI Price: $17.23 TVL: $127,979.77']
# no Pair....
#  ['10 - mUNI Price: $17.23 TVL: $127,979.77', 'Staked: 6399.9780 mUNI ($110,278.23)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.02% Week 0.13% Year 7.02%', 'You are staking 0.00 mUNI ($0.00), 0.00% of the pool.', 'Stake 0.00 mUNI', 'Unstake 0.00 mUNI', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1927
# ['11 - mWBTC Price: $32,489.84 TVL: $4,879,442.29']
# no Pair....
#  ['11 - mWBTC Price: $32,489.84 TVL: $4,879,442.29', 'Staked: 146.7196 mWBTC ($4,766,896.10)', 'MM Per Week: 277.65 ($744.11)', 'APR: Day 0.00% Week 0.02% Year 0.81%', 'You are staking 0.00 mWBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mWBTC', 'Unstake 0.00 mWBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1937
# ['12 - mLINK Price: $15.82 TVL: $229,496.35']
# no Pair....
#  ['12 - mLINK Price: $15.82 TVL: $229,496.35', 'Staked: 8126.7346 mLINK ($128,569.79)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.02% Week 0.12% Year 6.02%', 'You are staking 0.00 mLINK ($0.00), 0.00% of the pool.', 'Stake 0.00 mLINK', 'Unstake 0.00 mLINK', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1947
# ['13 - mZRX Price: $0.64 TVL: $99,769.81']
# no Pair....
#  ['13 - mZRX Price: $0.64 TVL: $99,769.81', 'Staked: 152977.0146 mZRX ($98,346.59)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.02% Week 0.15% Year 7.87%', 'You are staking 0.00 mZRX ($0.00), 0.00% of the pool.', 'Stake 0.00 mZRX', 'Unstake 0.00 mZRX', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1957
# ['14 - mALCX Price: $455.43 TVL: $193,928.59']
# no Pair....
#  ['14 - mALCX Price: $455.43 TVL: $193,928.59', 'Staked: 127.6666 mALCX ($58,143.05)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.04% Week 0.26% Year 13.31%', 'You are staking 0.00 mALCX ($0.00), 0.00% of the pool.', 'Stake 0.00 mALCX', 'Unstake 0.00 mALCX', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1967
# ['15 - malUSD Price: $1.11 TVL: $157,341.92']
# no Pair....
#  ['15 - malUSD Price: $1.11 TVL: $157,341.92', 'Staked: 128401.9612 malUSD ($142,137.30)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.01% Week 0.10% Year 5.44%', 'You are staking 0.00 malUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 malUSD', 'Unstake 0.00 malUSD', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1977
# ['16 - musdp3CRV Price: $1.05 TVL: $57,250.56']
# no Pair....
#  ['16 - musdp3CRV Price: $1.05 TVL: $57,250.56', 'Staked: 52048.5995 musdp3CRV ($54,458.10)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.04% Week 0.27% Year 14.21%', 'You are staking 0.00 musdp3CRV ($0.00), 0.00% of the pool.', 'Stake 0.00 musdp3CRV', 'Unstake 0.00 musdp3CRV', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1987
# ['17 - mrenBTC Price: $32,340.59 TVL: $72,171.75']
# no Pair....
#  ['17 - mrenBTC Price: $32,340.59 TVL: $72,171.75', 'Staked: 2.2015 mrenBTC ($71,197.45)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.03% Week 0.21% Year 10.87%', 'You are staking 0.00 mrenBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mrenBTC', 'Unstake 0.00 mrenBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1997
# ['19 - myveCRV-DAO Price: $1.36 TVL: $10,969.67']
# no Pair....
#  ['19 - myveCRV-DAO Price: $1.36 TVL: $10,969.67', 'Staked: 6985.0646 myveCRV-DAO ($9,468.37)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.22% Week 1.57% Year 81.73%', 'You are staking 0.00 myveCRV-DAO ($0.00), 0.00% of the pool.', 'Stake 0.00 myveCRV-DAO', 'Unstake 0.00 myveCRV-DAO', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2019
# ['20 - mTUSD Price: $1.01 TVL: $10,125.14']
# no Pair....
#  ['20 - mTUSD Price: $1.01 TVL: $10,125.14', 'Staked: 9995.7107 mTUSD ($10,058.61)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.21% Week 1.48% Year 76.94%', 'You are staking 0.00 mTUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 mTUSD', 'Unstake 0.00 mTUSD', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2029
# ['21 - mCVX Price: $2.17 TVL: $4,931.18']
# no Pair....
#  ['21 - mCVX Price: $2.17 TVL: $4,931.18', 'Staked: 2269.9560 mCVX ($4,917.12)', 'MM Per Week: 55.53 ($148.82)', 'APR: Day 0.43% Week 3.03% Year 157.38%', 'You are staking 0.00 mCVX ($0.00), 0.00% of the pool.', 'Stake 0.00 mCVX', 'Unstake 0.00 mCVX', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2039
# ['Boardroom']
# no Pair....
#  ['Boardroom', 'There is a total 3788.52 ONS ($39,400.60) staked in the Boardroom.', 'You are staking 0 ONS ($0.00), 0.00% of the pool.', 'There will be 91916.83 ONC issued at next expansion.', 'Boardroom APR: Day 241.37% Week 1689.56% Year 88098.40%', 'Stake 0.00 ONS', 'Unstake 0.00 ONS', 'Claim 0.00 ONC ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2101
# ['Boardroom']
# no Pair....
#  ['Boardroom', 'There is a total 202.12 ONS ($1,629.41) staked in the Boardroom.', 'You are staking 0 ONS ($0.00), 0.00% of the pool.', 'There will be 61277.89 ONC issued at next expansion.', 'Boardroom APR: Day 3890.95% Week 27236.63% Year 1420195.92%', 'Stake 0.00 ONS', 'Unstake 0.00 ONS', 'Claim 0.00 ONC ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2113
# ['p3Crv Price: $1.10 TVL: $948,067.48']
# no Pair....
#  ['p3Crv Price: $1.10 TVL: $948,067.48', 'Staked: 772307.4651 p3Crv ($846,945.95)', 'PICKLE Per Week: 243.34 ($1,666.85)', 'APR: Day 0.03% Week 0.20% Year 10.23%', 'You are staking 0.000000 p3Crv $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 p3Crv', 'Unstake 0.000000 p3Crv', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2190
# ['psteCRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['psteCRV Price: $0.00 TVL: $0.00', 'Staked: 4863.7188 psteCRV ($0.00)', 'PICKLE Per Week: 1555.52 ($10,655.34)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.000000 psteCRV $0.00 (NaN% of the pool).', 'Etherscan', 'Stake 0.000000 psteCRV', 'Unstake 0.000000 psteCRV', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2262
# ['pUSDC Price: $0.95 TVL: $6,581,928.31']
# no Pair....
#  ['pUSDC Price: $0.95 TVL: $6,581,928.31', 'Staked: 7234643.9909 pUSDC ($6,894,890.01)', 'PICKLE Per Week: 2095.13 ($14,351.62)', 'APR: Day 0.03% Week 0.21% Year 10.82%', 'You are staking 0.000000 pUSDC $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 pUSDC', 'Unstake 0.000000 pUSDC', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2394
# ['pLUSD3CRV-f Price: $1.04 TVL: $2,910,154.78']
# no Pair....
#  ['pLUSD3CRV-f Price: $1.04 TVL: $2,910,154.78', 'Staked: 2734459.2626 pLUSD3CRV-f ($2,834,953.91)', 'PICKLE Per Week: 46.03 ($315.29)', 'APR: Day 0.00% Week 0.01% Year 0.58%', 'You are staking 0.000000 pLUSD3CRV-f $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 pLUSD3CRV-f', 'Unstake 0.000000 pLUSD3CRV-f', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2406
# ['pLQTY Price: $4.51 TVL: $2,173,963.57']
# no Pair....
#  ['pLQTY Price: $4.51 TVL: $2,173,963.57', 'Staked: 464024.4548 pLQTY ($2,090,589.91)', 'PICKLE Per Week: 688.03 ($4,713.03)', 'APR: Day 0.03% Week 0.23% Year 11.72%', 'You are staking 0.000000 pLQTY $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 pLQTY', 'Unstake 0.000000 pLQTY', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2430
# ['DAI Price: $1.00 Market Cap: $5,245,677,515.47 [%]']
# ['USDC Price: $1.00 Market Cap: $25,598,380,483.84 [%]']
# ['USDT Price: $1.00 Market Cap: $30,910,401,959.98 [%]']
# ['sUSD Price: $1.00 Market Cap: $243,638,763.76 [%]']
# ['za-USDC Price: $0.00 Market Cap: $0.00']
# ['za-USDT Price: $0.00 Market Cap: $0.00']
# ['za-sUSD Price: $0.00 Market Cap: $0.00']
# ['za-DAI Price: $0.00 Market Cap: $0.00']
# ['zs-DAI Price: $0.00 Market Cap: $0.00']
# ['zpa-USDC Price: $0.00 Market Cap: $0.00']
# ['zpa-USDT Price: $0.00 Market Cap: $0.00']
# ['zpa-sUSD Price: $0.00 Market Cap: $0.00']
# ['zpa-DAI Price: $0.00 Market Cap: $0.00']
# ['zs-USD Price: $0.00 Market Cap: $0.00']
# ['zs-BTC Price: $0.00 Market Cap: $0.00']
# ['zs-SGR Price: $0.00 Market Cap: $0.00']
# ['zs-BMSGR Price: $0.00 Market Cap: $0.00']
# ['zs-FRAX Price: $0.00 Market Cap: $0.00']
# ['zs-UST Price: $0.00 Market Cap: $0.00']
# ['zs-ETH Price: $0.00 Market Cap: $0.00']
# ['zs-XUSD Price: $0.00 Market Cap: $0.00']
# ['zs-XUSD2 Price: $0.00 Market Cap: $0.00']
# ['zs-tsBTC Price: $0.00 Market Cap: $0.00']
# ['zs-AMPL Price: $0.00 Market Cap: $0.00']
# ['zs-FEI Price: $0.00 Market Cap: $0.00']
# ['1 - sd3Crv Price: $1.07 TVL: $12,314,339.92']
# no Pair....
#  ['1 - sd3Crv Price: $1.07 TVL: $12,314,339.92', 'Staked: 10879180.0516 sd3Crv ($11,624,148.07)', 'SDT Per Week: 6952.96 ($8,621.67)', 'APR: Day 0.01% Week 0.07% Year 3.86%', 'You are staking 0.00 sd3Crv ($0.00), 0.00% of the pool.', 'Stake 0.00 sd3Crv', 'Unstake 0.00 sd3Crv', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2714
# ['2 - sdeursCRV Price: $1.31 TVL: $27,746,742.00']
# no Pair....
#  ['2 - sdeursCRV Price: $1.31 TVL: $27,746,742.00', 'Staked: 18913652.1461 sdeursCRV ($24,749,919.29)', 'SDT Per Week: 36180.48 ($44,863.80)', 'APR: Day 0.03% Week 0.18% Year 9.43%', 'You are staking 0.00 sdeursCRV ($0.00), 0.00% of the pool.', 'Stake 0.00 sdeursCRV', 'Unstake 0.00 sdeursCRV', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2724
# ['3 - sdcrvRenWSBTC Price: $36,373.92 TVL: $1,426,257.69']
# no Pair....
#  ['3 - sdcrvRenWSBTC Price: $36,373.92 TVL: $1,426,257.69', 'Staked: 36.2625 sdcrvRenWSBTC ($1,319,010.89)', 'SDT Per Week: 448.00 ($555.52)', 'APR: Day 0.01% Week 0.04% Year 2.19%', 'You are staking 0.00 sdcrvRenWSBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 sdcrvRenWSBTC', 'Unstake 0.00 sdcrvRenWSBTC', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2734
# ['7 - DUMMY Price: $0.00 Market Cap: $0.00']
# ['8 - sdveCRV90-CRV10 Price: $0.00 Market Cap: $0.00']
# ['9 - sdeCRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['9 - sdeCRV Price: $0.00 TVL: $0.00', 'Staked: 2110.2590 sdeCRV ($0.00)', 'SDT Per Week: 2114.56 ($2,622.05)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 sdeCRV ($0.00), NaN% of the pool.', 'Stake 0.00 sdeCRV', 'Unstake 0.00 sdeCRV', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2788
# ['10 - sdFRAX3CRV-f Price: $1.00 TVL: $1,742,265.26']
# no Pair....
#  ['10 - sdFRAX3CRV-f Price: $1.00 TVL: $1,742,265.26', 'Staked: 1283487.0032 sdFRAX3CRV-f ($1,283,538.70)', 'SDT Per Week: 1075.20 ($1,333.25)', 'APR: Day 0.01% Week 0.10% Year 5.40%', 'You are staking 0.00 sdFRAX3CRV-f ($0.00), 0.00% of the pool.', 'Stake 0.00 sdFRAX3CRV-f', 'Unstake 0.00 sdFRAX3CRV-f', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2798
# ['[DAI 40%]-[BAL 57.99999999999999%]-[TRU 2%] BPT Price: $1.17 TVL: $12,707.38']
# no Pair....
#  ['[DAI 40%]-[BAL 57.99999999999999%]-[TRU 2%] BPT Price: $1.17 TVL: $12,707.38', 'DAI Price: $1.00', 'BAL Price: $18.02', 'TRU Price: $0.15', 'Staked: 9297.9796 [DAI 40%]-[BAL 57.99999999999999%]-[TRU 2%] ($10,841.04)', 'TRU Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 undefined $0.00 (0.00% of the pool).', 'Your LP tokens comprise of 0.0000 DAI + 0.0000 BAL + 0.0000 TRU', 'Stake 0.000000 undefined', 'Unstake 0.000000 undefined', 'Claim 0.000000 TRU', 'Exit']
# Block Start Line No.:  2829
# ['tfTUSD Price: $1.00 Market Cap: $46,312,181.56 [%]']
# ['UPDOWN Price: $0.08 Market Cap: $79,980.35 [%]']
# ['Boardroom']
# no Pair....
#  ['Boardroom', 'There is a total 49826.65 sYFL ($170.17) staked in the Boardroom.', 'You are staking 0 sYFL ($0.00), 0.00% of the pool.', 'Stake 0.00 sYFL', 'Unstake 0.00 sYFL', 'Claim 0.00 YFLUSD ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  3017
# ['Total Staked: $118,605.45']
# no Pair....
#  ['Total Staked: $118,605.45', 'MVLT Price: $1.11 TVL: $22,603,642.45', 'Staked: 18691831.7498 MVLT ($20,747,063.76)', 'YAXIS Per Week: 41666.67 ($132,916.67)', 'APR: Day 0.09% Week 0.64% Year 33.31%', 'You are staking 0.000000 MVLT $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 MVLT', 'Unstake 0.000000 MVLT', 'Claim 0.000000 YAXIS ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  3045
# ['YAXIS Price: $3.19 Market Cap: $35,090,000.00 [%]']
# ['SGT Price: $0.02 Market Cap: $181,859.20 [%]']
# ['vETH2 Price: $1,907.14 Market Cap: $30,491,153.18 [%]']
# ['saddleVETH2 Price: $1,915.46 Market Cap: $176,813.16']
# ['SGT Price: $0.02 Market Cap: $181,859.20 [%]']
# ['vETH2 Price: $1,907.14 Market Cap: $30,491,153.18 [%]']
# ['Staking Contract']
# no Pair....
#  ['Staking Contract', '0 - LPOOL Price: $1.15 Market Cap: $11,500,000.00 [%]', 'Staked: 323.0636 LPOOL ($371.52)', 'YLD Per Week: 106870.23 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 LPOOL ($0.00), 0.00% of the pool.', 'Stake 0.00 LPOOL', 'Unstake 0.00 LPOOL', 'Claim 0.00 YLD ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  3198
# ['Staking Contract']
# no Pair....
#  ['Staking Contract', '0 - LPOOL Price: $1.15 Market Cap: $11,500,000.00 [%]', 'Staked: 1248.3772 LPOOL ($1,435.63)', 'YLD Per Week: 106870.23 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 LPOOL ($0.00), 0.00% of the pool.', 'Stake 0.00 LPOOL', 'Unstake 0.00 LPOOL', 'Claim 0.00 YLD ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  3209
# ['Staking Contract']
# no Pair....
#  ['Staking Contract', '0 - LPOOL Price: $1.15 Market Cap: $11,500,000.00 [%]', 'Staked: 2748.2155 LPOOL ($3,160.45)', 'YLD Per Week: 106870.23 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 LPOOL ($0.00), 0.00% of the pool.', 'Stake 0.00 LPOOL', 'Unstake 0.00 LPOOL', 'Claim 0.00 YLD ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  3220
# ['Staking Contract']
# no Pair....
#  ['Staking Contract', '0 - LPOOL Price: $1.15 Market Cap: $11,500,000.00 [%]', 'Staked: 233857.4190 LPOOL ($268,936.03)', 'YLD Per Week: 18868.37 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 LPOOL ($0.00), 0.00% of the pool.', 'Stake 0.00 LPOOL', 'Unstake 0.00 LPOOL', 'Claim 0.00 YLD ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  3231
# ['9 - [UNI-V2 16.69114701562267%]-[WETH 16.69114701562267%]-[$TRDL 16.68447055681667%]-[VBTC 16.68447055681667%]-[vBCH 16.624382427560665%]-[oneVBTC 16.624382427560665%] BPT Price: $115.09 TVL: $141,372.23']
# no Pair....
#  ['9 - [UNI-V2 16.69114701562267%]-[WETH 16.69114701562267%]-[$TRDL 16.68447055681667%]-[VBTC 16.68447055681667%]-[vBCH 16.624382427560665%]-[oneVBTC 16.624382427560665%] BPT Price: $115.09 TVL: $141,372.23', 'UNI-V2 Price: $21.88', 'WETH Price: $1,907.14', '$TRDL Price: $0.12', 'VBTC Price: $11,119.54', 'vBCH Price: $313.57', 'oneVBTC Price: $0.98', 'Staked: 1191.1905 [UNI-V2 16.69114701562267%]-[WETH 16.69114701562267%]-[$TRDL 16.68447055681667%]-[VBTC 16.68447055681667%]-[vBCH 16.624382427560665%]-[oneVBTC 16.624382427560665%] ($137,098.58)', '$TRDL Per Week: 17920.00 ($2,209.27)', 'APR: Day 0.23% Week 1.61% Year 83.80%', 'You are staking 0.00 [UNI-V2 16.69114701562267%]-[WETH 16.69114701562267%]-[$TRDL 16.68447055681667%]-[VBTC 16.68447055681667%]-[vBCH 16.624382427560665%]-[oneVBTC 16.624382427560665%] ($0.00), 0.00% of the pool.', 'Stake 0.00 [UNI-V2 16.69114701562267%]-[WETH 16.69114701562267%]-[$TRDL 16.68447055681667%]-[VBTC 16.68447055681667%]-[vBCH 16.624382427560665%]-[oneVBTC 16.624382427560665%]', 'Unstake 0.00 [UNI-V2 16.69114701562267%]-[WETH 16.69114701562267%]-[$TRDL 16.68447055681667%]-[VBTC 16.68447055681667%]-[vBCH 16.624382427560665%]-[oneVBTC 16.624382427560665%]', 'Claim 0.00 $TRDL ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  3304
# ['0 - SIG-LP Price: $1.00 Market Cap: $5,815,326.49']
# ['2 - mock-lp Price: $0.00 Market Cap: $0.00']
# ['3 - SIG Price: $0.19 Market Cap: $2,267,968.51 [%]']
# ['alUSD Price: $1.00 Market Cap: $218,921,983.07 [%]']
# ['ALCX Price: $268.88 Market Cap: $338,382,744.00 [%]']
# ['alUSD3CRV-f Price: $1.01 Market Cap: $414,080,479.44']
# ['POOL Price: $0.00 Market Cap: $0.00']
# ['saddlealETH Price: $0.00 Market Cap: $0.00']
# ['Total Staked: $57,425,866.97']
# no Pair....
#  ['Total Staked: $57,425,866.97', 'Staking Contract', 'Found 1 pools.']
# Block Start Line No.:  3460
# ['dfx-cadc-a Price: $0.00 Market Cap: $0.00']
# ['dfx-eurs-a Price: $0.00 Market Cap: $0.00']
# ['dfx-xsgd-a Price: $0.00 Market Cap: $0.00']
# ['[SNX 25%]-[WETH 25%]-[xSNXa 50%] BPT Price: $0.01 TVL: $52,796.99']
# no Pair....
#  ['[SNX 25%]-[WETH 25%]-[xSNXa 50%] BPT Price: $0.01 TVL: $52,796.99', 'SNX Price: $9.24', 'WETH Price: $1,907.14', 'xSNXa Price: $0.00', 'Staked: 2022079.7605 [SNX 25%]-[WETH 25%]-[xSNXa 50%] ($23,624.97)', 'XTK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 [SNX 25%]-[WETH 25%]-[xSNXa 50%] $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [SNX 25%]-[WETH 25%]-[xSNXa 50%]', 'Unstake 0.000000 [SNX 25%]-[WETH 25%]-[xSNXa 50%]', 'Claim 0.000000 XTK ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  3597
# ['[WETH 25%]-[AAVE 25%]-[xAAVEa 50%] BPT Price: $2.47 TVL: $789,157.88']
# no Pair....
#  ['[WETH 25%]-[AAVE 25%]-[xAAVEa 50%] BPT Price: $2.47 TVL: $789,157.88', 'WETH Price: $1,907.14', 'AAVE Price: $261.76', 'xAAVEa Price: $2.71', 'Staked: 195695.9524 [WETH 25%]-[AAVE 25%]-[xAAVEa 50%] ($483,203.30)', 'XTK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 [WETH 25%]-[AAVE 25%]-[xAAVEa 50%] $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [WETH 25%]-[AAVE 25%]-[xAAVEa 50%]', 'Unstake 0.000000 [WETH 25%]-[AAVE 25%]-[xAAVEa 50%]', 'Claim 0.000000 XTK ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  3612
# ['[AAVE 25%]-[WETH 25%]-[xAAVEb 50%] BPT Price: $2.84 TVL: $1,166,072.05']
# no Pair....
#  ['[AAVE 25%]-[WETH 25%]-[xAAVEb 50%] BPT Price: $2.84 TVL: $1,166,072.05', 'AAVE Price: $261.76', 'WETH Price: $1,907.14', 'xAAVEb Price: $3.21', 'Staked: 217055.4823 [AAVE 25%]-[WETH 25%]-[xAAVEb 50%] ($615,586.18)', 'XTK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 [AAVE 25%]-[WETH 25%]-[xAAVEb 50%] $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [AAVE 25%]-[WETH 25%]-[xAAVEb 50%]', 'Unstake 0.000000 [AAVE 25%]-[WETH 25%]-[xAAVEb 50%]', 'Claim 0.000000 XTK ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  3627
# ['xBNTBNT Price: $0.00 Market Cap: $0.00']
# ['DOLA-3CRV3CRV-f Price: $0.99 Market Cap: $5,317,965.38']
# ['Badger', 'wBTC Sushi-LP - Underlying - Sett - Geyser']
# Badger
# wBTC Sushi-LP - Underlying - Sett - Geyser
# ['Badger', 'wBTC Sushi-LP - Underlying - Sett - Geyser']
# Badger
# wBTC Sushi-LP - Underlying - Sett - Geyser
# ['Badger', 'wBTC']
# ['Badger', 'wBTC Sushi-LP - Underlying - Sett - Geyser']
# Badger
# wBTC Sushi-LP - Underlying - Sett - Geyser
# ['Badger', 'wBTC Uni-LP - Underlying - Sett - Geyser']
# Badger
# wBTC Uni-LP - Underlying - Sett - Geyser
# ['Badger', 'wBTC Uni-LP - Underlying - Sett - Geyser']
# Badger
# wBTC Uni-LP - Underlying - Sett - Geyser
# ['Badger', 'wBTC']
# ['Badger', 'wBTC Uni-LP - Underlying - Sett - Geyser']
# Badger
# wBTC Uni-LP - Underlying - Sett - Geyser
# ['DIGG', 'wBTC Uni-LP - Underlying - Sett - Geyser']
# DIGG
# wBTC Uni-LP - Underlying - Sett - Geyser
# ['DIGG', 'wBTC Uni-LP - Underlying - Sett - Geyser']
# DIGG
# wBTC Uni-LP - Underlying - Sett - Geyser
# ['DIGG', 'wBTC']
# ['DIGG', 'wBTC Uni-LP - Underlying - Sett - Geyser']
# DIGG
# wBTC Uni-LP - Underlying - Sett - Geyser
# ['DIGG', 'wBTC Sushi-LP - Underlying - Sett - Geyser']
# DIGG
# wBTC Sushi-LP - Underlying - Sett - Geyser
# ['DIGG', 'wBTC Sushi-LP - Underlying - Sett - Geyser']
# DIGG
# wBTC Sushi-LP - Underlying - Sett - Geyser
# ['DIGG', 'wBTC']
# ['DIGG', 'wBTC Sushi-LP - Underlying - Sett - Geyser']
# DIGG
# wBTC Sushi-LP - Underlying - Sett - Geyser
# ['Badger - Underlying - Sett - Geyser']
# no Pair....
#  ['Badger - Underlying - Sett - Geyser', 'You have 0 BADGER', 'You have 0 bBADGER', 'BADGER Price: $7.82 Market Cap: $164,220,000.00 [%]', 'Staked: 79402.9438 BADGER ($620,931.02)', 'Staked in Geyser: $7,003,938.44', 'BADGER Per Week: 2035.82 ($15,920.11)', 'APR: Day 0.03% Week 0.23% Year 11.82%', 'DIGG Per Week: 0.08 ($2,761.52)', 'APR: Day 0.01% Week 0.04% Year 2.05%', 'Stake 0.000000000000 BADGER', 'Unstake 0.000000000000 BADGER', 'Stake 0.000000000000 bBADGER', 'Unstake 0.000000000000 bBADGER', 'Revoke (set approval to 0)']
# Block Start Line No.:  3854
# ['DIGG - Underlying - Sett']
# no Pair....
#  ['DIGG - Underlying - Sett', 'You have 0 DIGG', 'You have 0 bDIGG', 'DIGG Price: $34,373.00 Market Cap: $15,173,163.88 [%]', 'Staked: 88.9161 DIGG ($3,056,311.79)', 'Stake 0.000000000000 DIGG', 'Unstake 0.000000000000 DIGG']
# Block Start Line No.:  3871
# ['ETH', 'wBTC Sushi-LP - Underlying - Sett - Geyser']
# ETH
# wBTC Sushi-LP - Underlying - Sett - Geyser
# ['ETH', 'wBTC Sushi-LP - Underlying - Sett - Geyser']
# ETH
# wBTC Sushi-LP - Underlying - Sett - Geyser
# ['ETH', 'wBTC']
# ['ETH', 'wBTC Sushi-LP - Underlying - Sett - Geyser']
# ETH
# wBTC Sushi-LP - Underlying - Sett - Geyser
# ['curve.fi ', ' renBTC - Underlying - Sett - Geyser']
# curve.fi
# renBTC - Underlying - Sett - Geyser
# ['curve.fi ', ' renBTC - Underlying - Sett - Geyser']
# curve.fi
# renBTC - Underlying - Sett - Geyser
# ['curve.fi', 'renBTC']
# ['curve.fi ', ' renBTC - Underlying - Sett - Geyser']
# curve.fi
# renBTC - Underlying - Sett - Geyser
# ['curve.fi ', ' sBTC - Underlying - Sett - Geyser']
# curve.fi
# sBTC - Underlying - Sett - Geyser
# ['curve.fi ', ' sBTC - Underlying - Sett - Geyser']
# curve.fi
# sBTC - Underlying - Sett - Geyser
# ['curve.fi', 'sBTC']
# ['curve.fi ', ' sBTC - Underlying - Sett - Geyser']
# curve.fi
# sBTC - Underlying - Sett - Geyser
# ['curve.fi ', ' tBTC - Underlying - Sett - Geyser']
# curve.fi
# tBTC - Underlying - Sett - Geyser
# ['curve.fi ', ' tBTC - Underlying - Sett - Geyser']
# curve.fi
# tBTC - Underlying - Sett - Geyser
# ['curve.fi', 'tBTC']
# ['curve.fi ', ' tBTC - Underlying - Sett - Geyser']
# curve.fi
# tBTC - Underlying - Sett - Geyser
# ['harvest.finance ', ' renBTC - Underlying - Sett - Geyser']
# harvest.finance
# renBTC - Underlying - Sett - Geyser
# ['harvest.finance ', ' renBTC - Underlying - Sett - Geyser']
# harvest.finance
# renBTC - Underlying - Sett - Geyser
# ['harvest.finance', 'renBTC']
# ['harvest.finance ', ' renBTC - Underlying - Sett - Geyser']
# harvest.finance
# renBTC - Underlying - Sett - Geyser
# ['Total Staked: $83,053.22']
# no Pair....
#  ['Total Staked: $83,053.22', 'Staking Contract', 'Found 12 pools.']
# Block Start Line No.:  3983
# ['0 - WBTC Price: $31,886.00 Market Cap: $6,242,484,347.06 [%]']
# ['1 - WETH Price: $1,907.14 Market Cap: $14,240,979,332.92 [%]']
# ['2 - USDT Price: $1.00 Market Cap: $30,910,401,959.98 [%]']
# ['3 - USDC Price: $1.00 Market Cap: $25,580,262,087.34 [%]']
# ['4 - OCEAN Price: $0.39 Market Cap: $238,615,120.18 [%]']
# ['5 - LINK Price: $15.49 Market Cap: $15,490,000,000.00 [%]']
# ['6 - SUSHI Price: $6.52 Market Cap: $1,487,917,802.68 [%]']
# ['7 - UNI Price: $16.66 Market Cap: $16,660,000,000.00 [%]']
# ['8 - YFI Price: $27,840.00 Market Cap: $1,020,781,440.00 [%]']
# ['9 - AAVE Price: $261.76 Market Cap: $4,188,160,000.00 [%]']
# ['10 - SRM Price: $2.74 Market Cap: $441,140,002.74 [%]']
# ['11 - TOMOE Price: $2.66 Market Cap: $23,418,723.63 [%]']
# ['Total Staked: $3,581,493.73']
# no Pair....
#  ['Total Staked: $3,581,493.73', 'Staking Contract', 'Found 3 pools.']
# Block Start Line No.:  4111
# ['WBTC Price: $31,886.00 Market Cap: $6,242,484,347.06 [%]']
# ['USDC Price: $1.00 Market Cap: $25,580,210,867.30 [%]']
# ['SUSHI Price: $6.52 Market Cap: $1,487,917,802.68 [%]']
# ['USDC Price: $1.00 Market Cap: $25,580,210,867.30 [%]']
# ['BANK Price: $62.86 Market Cap: $7,153,288.99 [%]']
# ['FLOAT Price: $1.46 Market Cap: $5,151,484.95 [%]']
# ['DAI Price: $1.00 Market Cap: $5,239,734,162.85 [%]']
# ['USDC Price: $1.00 Market Cap: $25,580,210,867.30 [%]']
# ['USDT Price: $1.00 Market Cap: $30,910,401,959.98 [%]']
# ['SUSHI Price: $6.52 Market Cap: $1,487,917,802.68 [%]']
# ['WBTC Price: $31,886.00 Market Cap: $6,242,484,347.06 [%]']
# ['YAM Price: $0.67 Market Cap: $9,327,013.31 [%]']
# ['YFI Price: $27,840.00 Market Cap: $1,020,781,440.00 [%]']
# ['ETH Price: $1,907.14 Market Cap: $0.00 [%]']
# ...
# ['2 - WBTC Price: $31,825.00 Market Cap: $555,298,108.93 [%]']
# ['3 - WETH Price: $1,900.80 Market Cap: $1,421,785,739.72 [%]']
# ['4 - USDC Price: $1.00 Market Cap: $1,311,911,067.03 [%]']
# ['5 - DAI Price: $1.00 Market Cap: $560,543,580.34 [%]']
# ['6 - USDT Price: $1.00 Market Cap: $667,759,247.69 [%]']
# ['7 - QUICK Price: $295.95 Market Cap: $288,354,442.21 [%]']
# ['8 - LINK Price: $15.43 Market Cap: $44,362,925.74 [%]']
# ['0 - APPLE Price: $0.004888 Market Cap: $3,006.54 [%]']
# ['4 - WMATIC Price: $0.82 Market Cap: $302,748,862.25 [%]']
# ['5 - AAVE Price: $259.88 Market Cap: $120,149,903.67 [%]']
# ['6 - WETH Price: $1,900.80 Market Cap: $1,421,785,739.72 [%]']
# ['7 - WBTC Price: $31,825.00 Market Cap: $555,298,108.93 [%]']
# ['8 - QUICK Price: $295.95 Market Cap: $288,354,442.21 [%]']
# ['9 - USDC Price: $1.00 Market Cap: $1,311,911,067.03 [%]']
# ['10 - LINK Price: $15.43 Market Cap: $44,362,925.74 [%]']
# ['2 - DOJO Price: $0.16 Market Cap: $19,718.84 [%]']
# ['3 - WMATIC Price: $0.82 Market Cap: $302,748,862.25 [%]']
# ['4 - USDC Price: $1.00 Market Cap: $1,311,911,067.03 [%]']
# ['5 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['6 - WBTC Price: $31,823.00 Market Cap: $555,263,211.95 [%]']
# ['7 - WETH Price: $1,900.72 Market Cap: $1,421,725,900.25 [%]']
# ['8 - USDT Price: $1.00 Market Cap: $667,759,247.69 [%]']
# ['9 - DAI Price: $1.00 Market Cap: $560,543,580.34 [%]']
# ['10 - QUICK Price: $295.95 Market Cap: $288,354,442.21 [%]']
# ['11 - LINK Price: $15.43 Market Cap: $44,362,925.74 [%]']
# ['12 - AAVE Price: $259.84 Market Cap: $120,131,410.53 [%]']
# ['13 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['14 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['15 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['16 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['Features']
# no Pair....
#  ['Features', '- New Boost Feature earn 2x more rewards Medium', '- Pools & Tokennomics (Capped. Low Emissions) Medium']
# Block Start Line No.:  18263
# ['Launch Dates']
# no Pair....
#  ['Launch Dates', '- Medium', '- Syrup Token Launch - Fair Launch - Launch time will be random between blocks 16655000 to 16663000', 'or Thur. Jul 08 2021, 9:00 PM to 2:00 AM UTC (Approx.)', '- Farm Launch - Monday , July 12, 4pm UTC (Approx.)  - Block 16804000']
# Block Start Line No.:  18268
# no Pair....
#  ['Telegram', 'Twitter']
# Block Start Line No.:  18275
# no Pair....
#  ['Special thanks to the vfat team for getting us started when we launched our first', 'farm.']
# Block Start Line No.:  18279
# ['🍁🍁🍁 Please visit our website to view APR details. 🍁🍁🍁']
# no Pair....
#  ['🍁🍁🍁 Please visit our website to view APR details. 🍁🍁🍁', 'VFAT is the secondary source for  utilizing our farms. Due to the boost feature', 'APR calculations are different and so we have not displayed them here.']
# Block Start Line No.:  18284
# ['3 - SYRUP Price: $0.28 Market Cap: $3,355.64 [%]']
# ['4 - MAPLE Price: $0.03 Market Cap: $21,739.11 [%]']
# ['5 - WMATIC Price: $0.82 Market Cap: $302,731,179.29 [%]']
# ['6 - WETH Price: $1,900.72 Market Cap: $1,421,725,900.25 [%]']
# ['7 - WBTC Price: $31,823.00 Market Cap: $555,263,211.95 [%]']
# ['8 - AAVE Price: $259.84 Market Cap: $120,131,410.53 [%]']
# ['9 - SUSHI Price: $6.50 Market Cap: $8,455,742.83 [%]']
# ['10 - QUICK Price: $295.95 Market Cap: $288,354,442.21 [%]']
# ['11 - USDC Price: $1.00 Market Cap: $1,311,911,067.03 [%]']
# ['12 - DAI Price: $1.00 Market Cap: $560,543,580.34 [%]']
# ['2 - UTOPIA Price: $5.70 Market Cap: $24,230.61 [%]']
# ['3 - WMATIC Price: $0.82 Market Cap: $302,731,522.87 [%]']
# ['4 - WETH Price: $1,900.72 Market Cap: $1,421,725,900.25 [%]']
# ['5 - USDC Price: $1.00 Market Cap: $1,311,911,067.03 [%]']
# ['6 - miMATIC Price: $0.00 Market Cap: $0.00']
# ['7 - DAI Price: $1.00 Market Cap: $560,543,580.34 [%]']
# ['8 - QUICK Price: $295.95 Market Cap: $288,354,442.21 [%]']
# ['9 - AAVE Price: $259.84 Market Cap: $120,131,410.53 [%]']
# ['10 - LINK Price: $15.43 Market Cap: $44,362,925.74 [%]']
# ['11 - QI Price: $0.00 Market Cap: $0.00']
# ['12 - USDT Price: $1.00 Market Cap: $667,759,247.69 [%]']
# ['13 - xUSD Price: $0.00 Market Cap: $0.00']
# ['2 - B-POLYBASE Price: $0.00 Market Cap: $0.00']
# ['3 - B-POLYDEFI Price: $0.00 Market Cap: $0.00']
# ['4 - B-POLYDEFI Price: $0.00 Market Cap: $0.00']
# ['5 - B-QIPOOL Price: $0.00 Market Cap: $0.00']
# ['6 - B-POLYIDX Price: $0.00 Market Cap: $0.00']
# ['7 - WBTC Price: $31,823.00 Market Cap: $555,263,211.95 [%]']
# ['8 - WETH Price: $1,900.72 Market Cap: $1,421,725,900.25 [%]']
# ['9 - miMATIC Price: $0.00 Market Cap: $0.00']
# ['10 - USDT Price: $1.00 Market Cap: $667,759,247.69 [%]']
# ['11 - USDC Price: $1.00 Market Cap: $1,311,911,067.03 [%]']
# ['12 - DAI Price: $1.00 Market Cap: $560,543,580.34 [%]']
# ['14 - BPTC Price: $0.00 Market Cap: $0.00']
# ['15 - BPSG Price: $0.00 Market Cap: $0.00']
# ['1 - Shield Price: $0.01 Market Cap: $352.24 [%]']
# ['2 - WMATIC Price: $0.82 Market Cap: $302,683,694.04 [%]']
# ['3 - USDC Price: $1.00 Market Cap: $1,311,080,801.88 [%]']
# ['4 - USDT Price: $1.00 Market Cap: $667,759,247.69 [%]']
# ['6 - WBTC Price: $31,801.00 Market Cap: $554,879,345.23 [%]']
# ['7 - WETH Price: $1,900.09 Market Cap: $1,421,260,646.54 [%]']
# ['8 - DAI Price: $1.00 Market Cap: $560,543,580.34 [%]']
# ['9 - QUICK Price: $296.30 Market Cap: $288,695,459.46 [%]']
# ['10 - MAX Price: $0.00 Market Cap: $0.00']
# ['3 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['4 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['5 - PLATIN Price: $23.10 Market Cap: $31,408.00 [%]']
# ['6 - WMATIC Price: $0.82 Market Cap: $302,763,745.87 [%]']
# ['7 - AAVE Price: $260.08 Market Cap: $120,242,369.34 [%]']
# ['8 - WETH Price: $1,901.59 Market Cap: $1,422,382,641.27 [%]']
# ['9 - WBTC Price: $31,814.00 Market Cap: $555,106,175.57 [%]']
# ['10 - QUICK Price: $296.30 Market Cap: $288,695,459.46 [%]']
# ['11 - USDC Price: $1.00 Market Cap: $1,311,080,801.88 [%]']
# ['12 - PolyDoge Price: $0.0000000049 Market Cap: $4,928,000.00 [%]']
# ['0 - MILK Price: $0.00 Market Cap: $0.00']
# ['1 - WMATIC Price: $0.82 Market Cap: $302,762,676.83 [%]']
# ['2 - QUICK Price: $296.30 Market Cap: $288,695,459.46 [%]']
# ['3 - WETH Price: $1,901.59 Market Cap: $1,422,382,641.27 [%]']
# ['4 - WBTC Price: $31,814.00 Market Cap: $555,106,175.57 [%]']
# ['5 - AAVE Price: $260.08 Market Cap: $120,242,369.34 [%]']
# ['6 - USDC Price: $1.00 Market Cap: $1,311,080,801.88 [%]']
# ['7 - USDT Price: $1.00 Market Cap: $667,759,247.69 [%]']
# ['8 - SUSHI Price: $6.51 Market Cap: $8,468,751.67 [%]']
# ['9 - DAI Price: $1.00 Market Cap: $560,543,580.34 [%]']
# ['10 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['13 - xUSD Price: $0.00 Market Cap: $0.00']
# ['1 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['2 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['3 - USDC Price: $1.00 Market Cap: $1,311,082,100.31 [%]']
# ['4 - WBTC Price: $31,814.00 Market Cap: $555,106,175.57 [%]']
# ['5 - WETH Price: $1,901.59 Market Cap: $1,422,384,675.97 [%]']
# ['6 - WMATIC Price: $0.82 Market Cap: $302,760,129.83 [%]']
# ['7 - BONE Price: $0.00 Market Cap: $0.00']
# ['8 - USDT Price: $1.00 Market Cap: $667,759,247.69 [%]']
# ['9 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['10 - QUICK Price: $296.30 Market Cap: $288,695,459.46 [%]']
# ['11 - BALLZ Price: $0.002598 Market Cap: $911.31 [%]']
# ['12 - AAVE Price: $260.08 Market Cap: $120,242,369.34 [%]']
# ['13 - LINK Price: $15.43 Market Cap: $44,362,925.74 [%]']
# ['0 - pWINGS Price: $0.00 Market Cap: $0.00']
# ['0 - POLYTOKEN Price: $2.43 Market Cap: $12,852.96 [%]']
# ['1 - WMATIC Price: $0.82 Market Cap: $302,760,259.48 [%]']
# ['2 - WBTC Price: $31,788.00 Market Cap: $554,652,514.90 [%]']
# ['3 - WETH Price: $1,900.07 Market Cap: $1,421,246,855.32 [%]']
# ['4 - QUICK Price: $296.30 Market Cap: $288,695,459.46 [%]']
# ['5 - USDT Price: $1.00 Market Cap: $667,716,558.33 [%]']
# ['6 - USDC Price: $1.00 Market Cap: $1,310,538,001.23 [%]']
# ['7 - LINK Price: $15.42 Market Cap: $44,334,174.65 [%]']
# ['8 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['2 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['3 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['4 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['7 - USDC Price: $1.00 Market Cap: $1,310,538,001.23 [%]']
# ['8 - WMATIC Price: $0.82 Market Cap: $302,760,716.45 [%]']
# ['9 - WETH Price: $1,900.07 Market Cap: $1,421,246,855.32 [%]']
# ['10 - WBTC Price: $31,788.00 Market Cap: $554,652,514.90 [%]']
# ['11 - AAVE Price: $259.88 Market Cap: $120,149,903.67 [%]']
# ['12 - LINK Price: $15.42 Market Cap: $44,334,174.65 [%]']
# ['13 - FISH Price: $5.17 Market Cap: $13,559,053.25 [%]']
# ['14 - USDT Price: $1.00 Market Cap: $667,716,558.33 [%]']
# ['15 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['16 - PolyDoge Price: $0.0000000049 Market Cap: $4,928,000.00 [%]']
# ['17 - xUSD Price: $0.00 Market Cap: $0.00']
# ['1 - GHOST Price: $0.85 Market Cap: $1,118.21 [%]']
# ['2 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['3 - WMATIC Price: $0.82 Market Cap: $302,760,396.03 [%]']
# ['4 - WBTC Price: $31,815.00 Market Cap: $555,123,624.05 [%]']
# ['5 - USDT Price: $1.00 Market Cap: $667,716,558.33 [%]']
# ['6 - SUSHI Price: $6.51 Market Cap: $8,468,751.67 [%]']
# ['7 - USDC Price: $1.00 Market Cap: $1,311,082,100.31 [%]']
# ['8 - WETH Price: $1,901.74 Market Cap: $1,422,496,010.48 [%]']
# ['11 - xUSD Price: $0.00 Market Cap: $0.00']
# ['2 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['3 - SCR Price: $10.83 Market Cap: $108,315.80 [%]']
# ['4 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['5 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['6 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['8 - WMATIC Price: $0.82 Market Cap: $302,760,396.03 [%]']
# ['9 - WETH Price: $1,901.74 Market Cap: $1,422,496,010.48 [%]']
# ['10 - WBTC Price: $31,815.00 Market Cap: $555,123,624.05 [%]']
# ['11 - QUICK Price: $296.39 Market Cap: $288,783,149.61 [%]']
# ['12 - USDC Price: $1.00 Market Cap: $1,311,082,100.31 [%]']
# ['13 - USDT Price: $1.00 Market Cap: $667,716,558.33 [%]']
# ['14 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['15 - AAVE Price: $260.15 Market Cap: $120,274,732.33 [%]']
# ['16 - LINK Price: $15.44 Market Cap: $44,391,676.82 [%]']
# ['2 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['3 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['5 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['7 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['14 - COMMUNITY Price: $0.01 Market Cap: $1,360.84 [%]']
# ['15 - WMATIC Price: $0.82 Market Cap: $302,763,382.25 [%]']
# ['16 - USDC Price: $1.00 Market Cap: $1,311,082,100.31 [%]']
# ['17 - WBTC Price: $31,815.00 Market Cap: $555,123,624.05 [%]']
# ['18 - WETH Price: $1,901.74 Market Cap: $1,422,496,010.48 [%]']
# ['19 - USDT Price: $1.00 Market Cap: $667,716,558.33 [%]']
# ['20 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['0 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['1 - WMATIC Price: $0.82 Market Cap: $302,763,994.70 [%]']
# ['2 - WBTC Price: $31,816.00 Market Cap: $555,141,072.54 [%]']
# ['3 - WETH Price: $1,901.76 Market Cap: $1,422,510,970.42 [%]']
# ['4 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['5 - USDT Price: $1.00 Market Cap: $667,716,558.33 [%]']
# ['6 - USDC Price: $1.00 Market Cap: $1,311,082,100.31 [%]']
# ['0 - FISH Price: $0.08 Market Cap: $10,840.13 [%]']
# ['1 - WMATIC Price: $0.82 Market Cap: $302,763,201.04 [%]']
# ['2 - WBTC Price: $31,817.00 Market Cap: $555,158,521.03 [%]']
# ['3 - WETH Price: $1,903.80 Market Cap: $1,424,036,884.51 [%]']
# ['4 - QUICK Price: $296.39 Market Cap: $288,783,149.61 [%]']
# ['5 - USDT Price: $1.00 Market Cap: $667,716,558.33 [%]']
# ['6 - USDC Price: $1.00 Market Cap: $1,310,611,421.83 [%]']
# ['7 - LINK Price: $15.45 Market Cap: $44,420,427.91 [%]']
# ['8 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['11 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['14 - POLYTOKEN Price: $0.00 Market Cap: $0.00']
# ['1 - pCAKECRYPT Price: $0.16 Market Cap: $380,403.78 [%]']
# ['4 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['5 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['6 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['7 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['8 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['9 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['10 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['11 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['13 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['0 - TBULL Price: $0.00 Market Cap: $0.00']
# ['3 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['4 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['5 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['6 - WMATIC Price: $0.82 Market Cap: $302,756,705.24 [%]']
# ['7 - WETH Price: $1,903.80 Market Cap: $1,424,039,055.94 [%]']
# ['8 - WBTC Price: $31,817.00 Market Cap: $555,158,521.03 [%]']
# ['9 - QUICK Price: $296.39 Market Cap: $288,783,149.61 [%]']
# ['10 - USDC Price: $1.00 Market Cap: $1,310,611,421.83 [%]']
# ['11 - USDT Price: $1.00 Market Cap: $667,718,755.70 [%]']
# ['12 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['13 - AAVE Price: $260.20 Market Cap: $120,297,848.75 [%]']
# ['14 - LINK Price: $15.45 Market Cap: $44,420,427.91 [%]']
# ['21 - polyBUNNY Price: $0.00 Market Cap: $0.00']
# ['22 - FISH Price: $0.00 Market Cap: $0.00']
# ['23 - PolyDoge Price: $0.0000000049 Market Cap: $4,928,000.00 [%]']
# ['24 - miMATIC Price: $0.00 Market Cap: $0.00']
# ['2 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['3 - LION Price: $0.01 Market Cap: $531.75 [%]']
# ['4 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['7 - WMATIC Price: $0.82 Market Cap: $302,683,263.98 [%]']
# ['8 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['9 - WETH Price: $1,903.80 Market Cap: $1,424,039,055.94 [%]']
# ['10 - WBTC Price: $31,817.00 Market Cap: $555,158,521.03 [%]']
# ['11 - AAVE Price: $260.20 Market Cap: $120,297,848.75 [%]']
# ['12 - QUICK Price: $296.39 Market Cap: $288,783,149.61 [%]']
# ['13 - USDT Price: $1.00 Market Cap: $667,718,755.70 [%]']
# ['14 - miMATIC Price: $1.00 Market Cap: $88,319,698.57 [%]']
# ['5 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['6 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['7 - LITHIUM Price: $0.00 Market Cap: $0.00']
# ['8 - WMATIC Price: $0.82 Market Cap: $302,787,247.90 [%]']
# ['9 - QUICK Price: $296.38 Market Cap: $288,773,406.26 [%]']
# ['10 - WETH Price: $1,902.46 Market Cap: $1,423,036,738.29 [%]']
# ['11 - WBTC Price: $31,817.00 Market Cap: $555,158,521.03 [%]']
# ['12 - PUP Price: $0.00 Market Cap: $0.00']
# ['13 - BIFI Price: $0.00 Market Cap: $0.00']
# ['14 - ADDY Price: $0.00 Market Cap: $0.00']
# ['15 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['16 - USDT Price: $1.00 Market Cap: $667,718,755.70 [%]']
# ['17 - USDC Price: $1.00 Market Cap: $1,311,082,100.31 [%]']
# ['0 - SPADE Price: $10.64 Market Cap: $40,058.26 [%]']
# ['1 - WMATIC Price: $0.82 Market Cap: $302,785,216.61 [%]']
# ['2 - WETH Price: $1,902.46 Market Cap: $1,423,036,738.29 [%]']
# ['3 - USDC Price: $1.00 Market Cap: $1,311,082,100.31 [%]']
# ['4 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['5 - USDT Price: $1.00 Market Cap: $667,718,755.70 [%]']
# ['6 - WBTC Price: $31,817.00 Market Cap: $555,158,521.03 [%]']
# ['7 - LINK Price: $15.44 Market Cap: $44,391,676.82 [%]']
# ['8 - SUSHI Price: $6.51 Market Cap: $8,468,751.67 [%]']
# ['9 - AAVE Price: $260.31 Market Cap: $120,348,704.88 [%]']
# ['10 - QUICK Price: $296.38 Market Cap: $288,773,406.26 [%]']
# ['7 - ELYSM Price: $17.71 Market Cap: $177,056.64 [%]']
# ['8 - UTOPIA Price: $5.70 Market Cap: $24,243.98 [%]']
# ['9 - xUSD Price: $1.06 Market Cap: $2,153,683.32 [%]']
# ['10 - ICE Price: $0.00 Market Cap: $0.00']
# ['11 - DFYNLP Price: $0.00 Market Cap: $0.00']
# ['0 - STAR Price: $0.24 Market Cap: $2,145.53 [%]']
# ['1 - WMATIC Price: $0.82 Market Cap: $302,753,958.91 [%]']
# ['2 - WBTC Price: $31,827.00 Market Cap: $555,333,005.90 [%]']
# ['3 - WETH Price: $1,904.23 Market Cap: $1,424,367,415.83 [%]']
# ['4 - QUICK Price: $296.38 Market Cap: $288,773,406.26 [%]']
# ['5 - USDT Price: $1.00 Market Cap: $667,718,755.70 [%]']
# ['6 - USDC Price: $1.00 Market Cap: $1,311,082,900.31 [%]']
# ['7 - LINK Price: $15.47 Market Cap: $44,477,930.08 [%]']
# ['8 - DAI Price: $1.00 Market Cap: $560,541,378.01 [%]']
# ['11 - UNI-V2 Price: $0.00 Market Cap: $0.00']
# ['14 - POLYTOKEN Price: $0.00 Market Cap: $0.00']
# ['17 - FISH Price: $0.00 Market Cap: $0.00']
# ['9 - KWIL Price: $198.66 Market Cap: $198,657.56 [%]']

# %%
pair_df = pd.DataFrame(pairs, columns=['pair1', 'pair2', 'tvl', 'apr', 'where', 'network'])
pair_df['apy'] = np.nan

# %%
pairs
# Out:
# [['WFTM', 'ICE', '3306577.84', '175.59', 'https://popsicle.finance', 'FANTOM'],
#  ['WFTM', 'ICE', '3210722.55', '189.47', 'https://popsicle.finance', 'FANTOM'],
#  ['WFTM',
#   'BOO',
#   '8495107.84',
#   '116.99',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'WFTM',
#   '2923586.22',
#   '54.56',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['USDC',
#   'WFTM',
#   '4351275.25',
#   '36.66',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'DAI',
#   '2827882.69',
#   '56.54',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '3444758.75',
#   '37.02',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '3475985.90',
#   '36.91',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'LINK',
#   '1213269.03',
#   '52.25',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'AAVE',
#   '1199460.54',
#   '52.84',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM', 'SNX', '923093.51', '61.80', 'https://spookyswap.finance', 'FANTOM'],
#  ['WFTM',
#   'SUSHI',
#   '1319441.44',
#   '48.61',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BAND',
#   '269515.61',
#   '47.03',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'CREAM',
#   '412174.10',
#   '76.88',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['CRV', 'WFTM', '674672.47', '46.97', 'https://spookyswap.finance', 'FANTOM'],
#  ['WFTM',
#   'BADGER',
#   '308383.15',
#   '74.40',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ICE',
#   '3210722.55',
#   '111.84',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['ZOO', 'WFTM', '861790.93', '36.79', 'https://spookyswap.finance', 'FANTOM'],
#  ['WFTM',
#   'BNB',
#   '1630383.03',
#   '48.61',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'WOOFY',
#   '1099807.62',
#   '51.91',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM', 'ANY', '707135.76', '44.83', 'https://spookyswap.finance', 'FANTOM'],
#  ['WFTM',
#   'BIFI',
#   '259082.06',
#   '85.62',
#   'https://spookyswap.finance',
#   'FANTOM'],
#  ['WFTM', 'MIM', '349940.12', '90.67', 'https://spookyswap.finance', 'FANTOM'],
#  ['BOO', '', '13249568.26', '78.16', 'https://spookyswap.finance', 'FANTOM'],
#  ['SPIRIT',
#   '',
#   '6012696.06',
#   '51.30',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'SPIRIT',
#   '3300160.15',
#   '102.96',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '1366849.24',
#   '40.80',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '2447731.38',
#   '22.98',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['USDC',
#   'WFTM',
#   '2290950.94',
#   '37.78',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['ZOO',
#   'WFTM',
#   '1530726.83',
#   '18.16',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ICE',
#   '408084.38',
#   '34.39',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'SUSHI',
#   '1303908.25',
#   '21.29',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'CREAM',
#   '112676.74',
#   '50.16',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['CRV',
#   'WFTM',
#   '820681.62',
#   '33.85',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'LINK',
#   '517790.06',
#   '53.94',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'COVER',
#   '167454.12',
#   '17.23',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'YFI',
#   '674146.80',
#   '41.30',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'FRAX',
#   '605650.99',
#   '46.58',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['FXS',
#   'FRAX',
#   '901009.52',
#   '30.76',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'WFTM',
#   '562077.34',
#   '50.26',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ANY',
#   '548561.05',
#   '50.50',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BNB',
#   '1062073.51',
#   '52.34',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['SPIRIT',
#   'BNB',
#   '102888.72',
#   '135.04',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['YFI',
#   'WOOFY',
#   '572140.90',
#   '24.20',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['SPIRIT',
#   'DAI',
#   '450732.45',
#   '123.74',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'BUSD',
#   '919608.12',
#   '15.06',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['USDC',
#   'GTON',
#   '266033.64',
#   '19.88',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['SPIRIT-LP', '', '0.00', 0, 'https://app.spiritswap.finance', 'FANTOM'],
#  ['DIS',
#   'WFTM',
#   '193951.69',
#   '180.16',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['SPIRIT',
#   'GRIM',
#   '9687.12',
#   '285.50',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['SPIRIT',
#   'xSTEAK',
#   '6939.89',
#   '398.58',
#   'https://app.spiritswap.finance',
#   'FANTOM'],
#  ['DAI', 'SON', '231.87', '527.67', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['USDC',
#   'SON',
#   '606.84',
#   '262.30',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'SON',
#   '468.72',
#   '445.38',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['BTC', 'SON', '781.90', '332.39', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['ETH',
#   'SON',
#   '171.60',
#   '1048.77',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['BORGDAI',
#   'SON',
#   '140.49',
#   '965.58',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['SON',
#   'BORG',
#   '249.23',
#   '334.40',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['SON',
#   'AURORA',
#   '57.52',
#   '1421.71',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['SON', '', '7995.31', '115.10', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['WFTM',
#   'DAI',
#   '79390.95',
#   '202.86',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['USDC',
#   'WFTM',
#   '211930.27',
#   '2221.26',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '49911.28',
#   '25.64',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '73836.08',
#   '72.25',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['USDC',
#   'DAI',
#   '364859.25',
#   '226.96',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   '',
#   '50492947.51',
#   '21.77',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['ETH', '', '5207194.12', '25.70', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['YFI',
#   '',
#   '1049477.52',
#   '136.37',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['FUSD',
#   '',
#   '24684823.40',
#   '7.26',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['ICE',
#   '',
#   '6399053.78',
#   '107.49',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['LINK',
#   '',
#   '1256503.80',
#   '47.24',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['CREAM',
#   '',
#   '2.72',
#   '3565427.79',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['DAI',
#   '',
#   '37054979.95',
#   '151.65',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['OPE', '', '0.00', 0, 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['AURORA',
#   '',
#   '1276050.37',
#   '13.71',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['YFI', 'SON', '677.84', '663.13', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['WFTM',
#   'BORG',
#   '629.33',
#   '109.51',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'BORGDAI',
#   '385.87',
#   '176.02',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['BOO',
#   '',
#   '13249612.68',
#   '77.80',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['SPIRIT', '', '0.00', 0, 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['SON',
#   'FUSD',
#   '247.43',
#   '498.61',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['ZOO', 'SON', '245.32', '338.84', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['fUSDT',
#   'SON',
#   '203.69',
#   '626.81',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['SON', 'ICE', '33.71', '2441.58', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['SON', 'OPE', '10.07', '8113.50', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['BORGDAI',
#   'AURORA',
#   '139.99',
#   '738.04',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['BORGDAI',
#   'DAI',
#   '627.58',
#   '152.01',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['fUSDT',
#   'BORGDAI',
#   '1611.73',
#   '59.30',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['SNX', '', '0.00', 0, 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['SON',
#   'LINK',
#   '178.21',
#   '1007.87',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['CREAM',
#   'SON',
#   '302.97',
#   '403.72',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['SON',
#   'SUSHI',
#   '55.98',
#   '2181.42',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['SON', 'UBI', '9.50', '4500.13', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['AURORA',
#   'BORG',
#   '23.30',
#   '3042.43',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['SUSHI',
#   '',
#   '1551304.96',
#   '141.26',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'AURORA',
#   '447906.73',
#   '309.31',
#   'https://ftm.borgswap.exchange',
#   'FANTOM'],
#  ['ORI', 'SON', '63.06', '1010.37', 'https://ftm.borgswap.exchange', 'FANTOM'],
#  ['ORI', '', '716125.11', '172.60', 'https://hyperjump.fi', 'FANTOM'],
#  ['ORI', 'WFTM', '386801.72', '324.73', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'AURORA', '442979.28', '87.16', 'https://hyperjump.fi', 'FANTOM'],
#  ['USDC', 'WFTM', '211930.27', '31.87', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'ETH', '73836.08', '42.83', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'BTC', '50357.38', '63.47', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'LINK', '103006.32', '30.36', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'DAI', '79390.95', '41.43', 'https://hyperjump.fi', 'FANTOM'],
#  ['USDC', 'ORI', '45916.25', '281.88', 'https://hyperjump.fi', 'FANTOM'],
#  ['USDC', 'DAI', '364859.25', '9.49', 'https://hyperjump.fi', 'FANTOM'],
#  ['ORI', 'ETH', '18497.36', '344.40', 'https://hyperjump.fi', 'FANTOM'],
#  ['ORI', 'BTC', '26038.73', '245.26', 'https://hyperjump.fi', 'FANTOM'],
#  ['ORI', 'LINK', '18150.61', '350.64', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'SUSHI', '43393.29', '74.59', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'YFI', '78686.86', '39.72', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'SNX', '260820.11', '78.05', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'BNB', '61448.48', '104.51', 'https://hyperjump.fi', 'FANTOM'],
#  ['ZOO', 'WFTM', '85264.49', '47.71', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'ICE', '23426.79', '143.24', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'ESWAP', '12965.24', '318.39', 'https://hyperjump.fi', 'FANTOM'],
#  ['ORI', 'ESWAP', '17359.46', '392.03', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'renBTC', '23210.23', '139.30', 'https://hyperjump.fi', 'FANTOM'],
#  ['ORI', 'renBTC', '19319.67', '336.56', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'renZEC', '24661.08', '130.01', 'https://hyperjump.fi', 'FANTOM'],
#  ['ORI', 'renZEC', '17356.72', '365.11', 'https://hyperjump.fi', 'FANTOM'],
#  ['WFTM', 'renBCH', '26309.76', '121.99', 'https://hyperjump.fi', 'FANTOM'],
#  ['ORI', 'renBCH', '18963.46', '334.94', 'https://hyperjump.fi', 'FANTOM'],
#  ['EST', 'WFTM', '48002.89', '147.98', 'https://ester.finance', 'FANTOM'],
#  ['EST', '', '78595.57', '67.47', 'https://ester.finance', 'FANTOM'],
#  ['WFTM',
#   'FROYO',
#   '8001.07',
#   '132.60',
#   'https://frozenyogurt.finance',
#   'FANTOM'],
#  ['3FROYO',
#   '',
#   '291584.52',
#   '19.07',
#   'https://frozenyogurt.finance',
#   'FANTOM'],
#  ['WFTM',
#   'GHOST',
#   '5372.99',
#   '5222.40',
#   'https://www.theghost.finance',
#   'FANTOM'],
#  ['WFTM',
#   'GHOST',
#   '4425.11',
#   '7415.38',
#   'https://www.theghost.finance',
#   'FANTOM'],
#  ['WFTM',
#   'GHOST',
#   '4351.68',
#   '8179.42',
#   'https://www.theghost.finance',
#   'FANTOM'],
#  ['WFTM',
#   'GHOST',
#   '2025.05',
#   '9571.01',
#   'https://www.theghost.finance',
#   'FANTOM'],
#  ['WFTM',
#   'YFI',
#   '141350.61',
#   '69.80',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['WFTM',
#   'DAI',
#   '117786.33',
#   '88.93',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['WFTM',
#   'LINK',
#   '114325.77',
#   '88.04',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '189782.54',
#   '52.88',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'WFTM',
#   '148868.07',
#   '70.29',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '148930.26',
#   '67.30',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['WFTM',
#   'SUSHI',
#   '180373.48',
#   '55.76',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['WFTM',
#   'CREAM',
#   '63198.21',
#   '125.60',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['USDC',
#   'AAVE',
#   '77592.37',
#   '52.17',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['WFTM',
#   'SNX',
#   '72907.53',
#   '54.65',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ICE',
#   '3306216.02',
#   '211.14',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['WFTM',
#   'COVER',
#   '53168.34',
#   '74.98',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['ZOO',
#   'WFTM',
#   '144280.55',
#   '39.92',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['CRV',
#   'WFTM',
#   '26396.09',
#   '77.19',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'FRAX',
#   '188954.56',
#   '22.48',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'LQDR',
#   '102942.66',
#   '354.55',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['LQDR',
#   'WFTM',
#   '155984.69',
#   '229.03',
#   'https://www.liquiddriver.finance',
#   'FANTOM'],
#  ['NTOKEN', '', '0.00', 0, 'https://www.liquiddriver.finance', 'FANTOM'],
#  ['MM', '', '37043.98', '7.95', 'https://mushrooms.finance/farms', 'FANTOM'],
#  ['WFTM',
#   'MM',
#   '10542.98',
#   '82.32',
#   'https://mushrooms.finance/farms',
#   'FANTOM'],
#  ['WFTM',
#   'ICE',
#   '22129.79',
#   '4.94',
#   'https://mushrooms.finance/farms',
#   'FANTOM'],
#  ['WFTM',
#   'BOO',
#   '10398.83',
#   '50.39',
#   'https://mushrooms.finance/farms',
#   'FANTOM'],
#  ['WFTM',
#   'SPIRIT',
#   '8870.21',
#   '25.56',
#   'https://mushrooms.finance/farms',
#   'FANTOM'],
#  ['WFTM',
#   'MM',
#   '8879.06',
#   '135.38',
#   'https://mushrooms.finance/farms',
#   'FANTOM'],
#  ['SEED', '', '5745.28', '82.57', 'https://thegreenhouse.finance', 'FANTOM'],
#  ['SEED',
#   'WFTM',
#   '4692.03',
#   '249.09',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['USDC',
#   'WFTM',
#   '4350827.66',
#   '48.07',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '3444065.77',
#   '176.86',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '3475376.81',
#   '244.94',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['WFTM',
#   'LINK',
#   '1212757.88',
#   '270.60',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'WFTM',
#   '2923285.80',
#   '256.32',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BNB',
#   '1630057.83',
#   '146.88',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['USDC',
#   '',
#   '57826484.62',
#   '77.19',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['WFTM',
#   '',
#   '50493016.36',
#   '107.52',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['BTC',
#   '',
#   '9078708.73',
#   '134.34',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['ETH',
#   '',
#   '5207519.47',
#   '274.94',
#   'https://thegreenhouse.finance',
#   'FANTOM'],
#  ['STEAK', '', '4264082.36', '361.44', 'https://stakesteak.com', 'FANTOM'],
#  ['FRANK', '', '36876.23', '45.84', 'https://frankenstein.finance', 'FANTOM'],
#  ['WFTM',
#   'FRANK',
#   '16413.84',
#   '99.07',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'SPIRIT',
#   '3299469.54',
#   '3.52',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '1366568.49',
#   '2.15',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '2447301.59',
#   '18.47',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['USDC',
#   'WFTM',
#   '2290719.21',
#   '1.67',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['ZOO',
#   'WFTM',
#   '1530412.43',
#   '11.36',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ICE',
#   '408042.30',
#   '31.08',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'SUSHI',
#   '1303773.92',
#   '2.20',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'CREAM',
#   '112653.60',
#   '35.82',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['CRV',
#   'WFTM',
#   '820513.06',
#   '0.85',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'LINK',
#   '517572.16',
#   '2.97',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'COVER',
#   '167419.73',
#   '5.89',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'YFI',
#   '674193.25',
#   '10.65',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'FRAX',
#   '605526.59',
#   '47.83',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'WFTM',
#   '562019.63',
#   '6.79',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ANY',
#   '548448.37',
#   '1.04',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['SPIRIT',
#   '',
#   '6011466.58',
#   '9.04',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'FRANK',
#   '14303.57',
#   '113.21',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BOO',
#   '8494260.67',
#   '2.01',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'WFTM',
#   '2923288.80',
#   '10.63',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['USDC',
#   'WFTM',
#   '4350830.49',
#   '5.10',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'DAI',
#   '2827594.25',
#   '6.61',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '3446380.44',
#   '9.34',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '3475377.06',
#   '1.79',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'LINK',
#   '1212757.88',
#   '40.23',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'AAVE',
#   '1199214.18',
#   '3.52',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'SNX',
#   '922903.91',
#   '3.55',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM', 'YFI', '7085.70', '11.03', 'https://frankenstein.finance', 'FANTOM'],
#  ['WFTM',
#   'SUSHI',
#   '1319308.22',
#   '5.79',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BNB',
#   '1630057.83',
#   '3.03',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ICE',
#   '3210406.74',
#   '17.70',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['BOO', '', '13249780.65', '3.39', 'https://frankenstein.finance', 'FANTOM'],
#  ['LQDR',
#   'WFTM',
#   '156071.39',
#   '18.55',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'LQDR',
#   '102999.15',
#   '19.68',
#   'https://frankenstein.finance',
#   'FANTOM'],
#  ['LQDR', '', '461231.93', '73.82', 'https://frankenstein.finance', 'FANTOM'],
#  ['WFTM', 'WAKA', '558222.60', '126.41', 'https://waka.finance', 'FANTOM'],
#  ['fUSDT', 'WFTM', '571809.06', '9.02', 'https://waka.finance', 'FANTOM'],
#  ['USDC', 'WFTM', '146928.17', '40.91', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'BTC', '83676.57', '46.24', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'ETH', '110694.07', '41.13', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'ATRI', '2520205.83', '1.91', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'DAI', '36049.51', '39.13', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'YFI', '28525.49', '43.63', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'SUSHI', '22841.83', '54.70', 'https://waka.finance', 'FANTOM'],
#  ['ZOO', 'WFTM', '27188.75', '45.97', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'BADGER', '54396.26', '22.88', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'AAVE', '137763.42', '9.03', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'ICE', '37330.85', '40.50', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'SNX', '116210.66', '10.71', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'CREAM', '23476.06', '53.01', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'COVER', '25685.05', '48.52', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'LINK', '19984.82', '62.28', 'https://waka.finance', 'FANTOM'],
#  ['CRV', 'WFTM', '23641.94', '52.70', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'BAND', '155659.42', '8.00', 'https://waka.finance', 'FANTOM'],
#  ['pWaka', '', '0.00', 0, 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'BOMB', '23858.68', '54.89', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'Shiba', '39820.94', '31.37', 'https://waka.finance', 'FANTOM'],
#  ['bWaka', '', '0.00', 0, 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'GRIM', '1380.92', '90.60', 'https://waka.finance', 'FANTOM'],
#  ['WFTM', 'ELK', '59555.91', '101.21', 'https://app.elk.finance', 'FANTOM'],
#  ['fUSDT', 'ELK', '14286.58', '140.72', 'https://app.elk.finance', 'FANTOM'],
#  ['USDC', 'ELK', '14790.83', '135.84', 'https://app.elk.finance', 'FANTOM'],
#  ['DAI', 'ELK', '11618.49', '172.93', 'https://app.elk.finance', 'FANTOM'],
#  ['ETH', 'ELK', '8698.09', '232.49', 'https://app.elk.finance', 'FANTOM'],
#  ['BTC', 'ELK', '8382.63', '159.82', 'https://app.elk.finance', 'FANTOM'],
#  ['BOO', 'ELK', '2963.11', '226.12', 'https://app.elk.finance', 'FANTOM'],
#  ['SPIRIT', 'ELK', '2569.80', '260.61', 'https://app.elk.finance', 'FANTOM'],
#  ['BNB', 'ELK', '2869.92', '233.36', 'https://app.elk.finance', 'FANTOM'],
#  ['LINK', 'ELK', '4304.06', '155.60', 'https://app.elk.finance', 'FANTOM'],
#  ['ZOO', 'ELK', '3897.06', '171.85', 'https://app.elk.finance', 'FANTOM'],
#  ['CREAM', 'ELK', '2419.23', '276.83', 'https://app.elk.finance', 'FANTOM'],
#  ['ELK', 'ICE', '2417.86', '276.99', 'https://app.elk.finance', 'FANTOM'],
#  ['YFI', 'ELK', '2998.40', '223.36', 'https://app.elk.finance', 'FANTOM'],
#  ['AAVE', 'ELK', '2883.06', '232.30', 'https://app.elk.finance', 'FANTOM'],
#  ['SUSHI', 'ELK', '2662.99', '251.49', 'https://app.elk.finance', 'FANTOM'],
#  ['ELK', 'DSTEIN', '1484.37', '451.18', 'https://app.elk.finance', 'FANTOM'],
#  ['Shiba', 'ELK', '3004.62', '222.90', 'https://app.elk.finance', 'FANTOM'],
#  ['BRUSH', '', '240809.15', '52.82', 'https://paintswap.finance', 'FANTOM'],
#  ['WFTM',
#   'BRUSH',
#   '57710.62',
#   '158.93',
#   'https://paintswap.finance',
#   'FANTOM'],
#  ['USDC', 'WFTM', '34545.02', '128.65', 'https://paintswap.finance', 'FANTOM'],
#  ['WFTM', 'BNB', '21487.84', '66.75', 'https://paintswap.finance', 'FANTOM'],
#  ['WFTM', 'ETH', '46699.67', '54.53', 'https://paintswap.finance', 'FANTOM'],
#  ['WFTM', 'BTC', '58758.35', '64.61', 'https://paintswap.finance', 'FANTOM'],
#  ['ZOO', 'BRUSH', '8876.65', '180.91', 'https://paintswap.finance', 'FANTOM'],
#  ['BRUSH', 'CHAD', '3717.85', '172.87', 'https://paintswap.finance', 'FANTOM'],
#  ['WFTM', 'HODL', '55081.42', '19.45', 'https://paintswap.finance', 'FANTOM'],
#  ['WFTM', 'TOMB', '3517706.63', '644.14', 'https://tomb.finance', 'FANTOM'],
#  ['WFTM', 'TSHARE', '2111179.80', '725.09', 'https://tomb.finance', 'FANTOM'],
#  ['WFTM',
#   'KLING',
#   '309.26',
#   '294.94',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['fUSDT',
#   'KLING',
#   '33.20',
#   '1319.30',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['KLING',
#   '',
#   '513.93',
#   '68.67',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'BORG',
#   '935.96',
#   '11.86',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['fUSDT',
#   'BORG',
#   '395.07',
#   '27.57',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'BORGDAI',
#   '424.18',
#   '27.31',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['fUSDT',
#   'BORGDAI',
#   '142.38',
#   '92.51',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'YFI',
#   '141297.40',
#   '69.24',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'DAI',
#   '117759.16',
#   '264.50',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'LINK',
#   '114228.23',
#   '40.79',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '189689.62',
#   '130.43',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['fUSDT',
#   'WFTM',
#   '148832.40',
#   '145.00',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'SUSHI',
#   '180193.92',
#   '46.28',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'CREAM',
#   '63167.92',
#   '70.25',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['USDC',
#   'AAVE',
#   '77592.37',
#   '36.01',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'SNX',
#   '72872.58',
#   '63.53',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'ICE',
#   '3305429.45',
#   '15.34',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   'COVER',
#   '53142.85',
#   '51.40',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['ZOO',
#   'WFTM',
#   '144211.39',
#   '14.65',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['CRV',
#   'WFTM',
#   '26383.44',
#   '41.61',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['WFTM',
#   '',
#   '50468085.08',
#   '30.34',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['FUSD', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['DAI',
#   '',
#   '37054979.95',
#   '108.66',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['USDC',
#   '',
#   '57826484.62',
#   '22.01',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['fUSDT',
#   '',
#   '51353725.03',
#   '33.86',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['BTC', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['ETH',
#   '',
#   '5204726.90',
#   '3307.96',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['YFI',
#   '',
#   '1049188.41',
#   '4.64',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['BNB',
#   '',
#   '1741041.94',
#   '6.96',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['ICE',
#   '',
#   '6399053.78',
#   '41.11',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['LINK',
#   '',
#   '1254901.12',
#   '4.41',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['CREAM',
#   '',
#   '2.72',
#   '5531567.56',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['ORI', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['SON', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['BOO',
#   '',
#   '13249896.58',
#   '17.97',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['SPIRIT', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['SNX',
#   '',
#   '751679.47',
#   '15.76',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['SUSHI',
#   '',
#   '1548958.05',
#   '5.96',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['FRANK', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['EST', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['CzTears', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['OPE', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['GHOST', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['LQDR', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['WAKA', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['BRUSH', '', '0.00', 0, 'https://klingftm.borgswap.exchange', 'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '148858.87',
#   '4.47',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['BTC',
#   'KLING',
#   '211.53',
#   '411.91',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['AAVE',
#   '',
#   '857887.42',
#   '34.94',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['CRV',
#   '',
#   '1519844.02',
#   '50.05',
#   'https://klingftm.borgswap.exchange',
#   'FANTOM'],
#  ['OPERA',
#   '',
#   '14867.89',
#   '572.87',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'OPERA',
#   '11023.77',
#   '681.33',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'FUSD',
#   '5872.26',
#   '62.80',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '4982.75',
#   '123.03',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '4680.25',
#   '131.20',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['USDC',
#   'WFTM',
#   '9819.25',
#   '37.46',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BNB',
#   '12714.43',
#   '28.91',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'LINK',
#   '7400.53',
#   '33.12',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'SUSHI',
#   '4861.18',
#   '51.47',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'YFI',
#   '3210.04',
#   '76.40',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ANY',
#   '5004.28',
#   '48.95',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['CRV',
#   'WFTM',
#   '2641.71',
#   '139.28',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'DAI',
#   '11620.29',
#   '31.64',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM',
#   'AAVE',
#   '25429.77',
#   '14.45',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'WFTM',
#   '2826.62',
#   '129.99',
#   'https://www.operaswap.finance',
#   'FANTOM'],
#  ['WFTM', 'CHAD', '6971.58', '518.42', 'CHAD', 'FANTOM'],
#  ['BRUSH', 'CHAD', '3743.02', '516.54', 'CHAD', 'FANTOM'],
#  ['USDC', 'CHAD', '3139.82', '575.71', 'CHAD', 'FANTOM'],
#  ['CHAD', '', '28933.08', '93.17', 'CHAD', 'FANTOM'],
#  ['BOMB', 'CHAD', '2386.79', '812.96', 'CHAD', 'FANTOM'],
#  ['STEAK', 'CHAD', '29.63', '0.00', 'CHAD', 'FANTOM'],
#  ['TOMB', 'CHAD', '476.44', '768.60', 'CHAD', 'FANTOM'],
#  ['CzTears', 'CHAD', '1036.16', '356.60', 'CHAD', 'FANTOM'],
#  ['Shiba', 'CHAD', '1029.97', '355.69', 'CHAD', 'FANTOM'],
#  ['WFTM', 'Shiba', '2259.95', '95.80', 'CHAD', 'FANTOM'],
#  ['ATRI', 'CHAD', '597.76', '611.96', 'CHAD', 'FANTOM'],
#  ['PHANT', 'CHAD', '377.27', '786.26', 'CHAD', 'FANTOM'],
#  ['CHAD', 'OPERA', '5.51', '0.00', 'CHAD', 'FANTOM'],
#  ['JUST', 'CHAD', '1430.98', '359.04', 'CHAD', 'FANTOM'],
#  ['iFUSD', 'CHAD', '648.94', '874.81', 'CHAD', 'FANTOM'],
#  ['CHAD', 'YORO', '332.84', '925.74', 'CHAD', 'FANTOM'],
#  ['xSTEAK', 'CHAD', '1474.84', '242.44', 'CHAD', 'FANTOM'],
#  ['SBRW', 'CHAD', '194.69', '1924.04', 'CHAD', 'FANTOM'],
#  ['WFTM', 'HODL', '55004.09', '459.76', 'CHAD', 'FANTOM'],
#  ['GRIM', 'CHAD', '432.73', '1817.88', 'CHAD', 'FANTOM'],
#  ['USDC', 'RDT', '837.15', '4113.16', 'https://rediant.finance', 'FANTOM'],
#  ['WFTM', 'RDT', '962.24', '5748.33', 'https://rediant.finance', 'FANTOM'],
#  ['RDT', '', '3729.53', '202.66', 'https://rediant.finance', 'FANTOM'],
#  ['USDC', '', '57826484.62', '28.32', 'https://rediant.finance', 'FANTOM'],
#  ['WFTM', '', '50417666.16', '40.47', 'https://rediant.finance', 'FANTOM'],
#  ['ETH', '', '5205486.05', '16914.16', 'https://rediant.finance', 'FANTOM'],
#  ['BTC', '', '0.00', 0, 'https://rediant.finance', 'FANTOM'],
#  ['DAI', '', '37054979.95', '8.58', 'https://rediant.finance', 'FANTOM'],
#  ['fUSDT', '', '51353725.03', '13056.23', 'https://rediant.finance', 'FANTOM'],
#  ['BNB', '', '1741491.62', '34.01', 'https://rediant.finance', 'FANTOM'],
#  ['BOO', '', '13250032.48', '669.24', 'https://rediant.finance', 'FANTOM'],
#  ['USDC', 'WFTM', '4347608.54', '845.59', 'https://rediant.finance', 'FANTOM'],
#  ['WFTM', 'BOO', '8488323.37', '38.81', 'https://rediant.finance', 'FANTOM'],
#  ['WFTM', 'ETH', '3472126.94', 0, 'https://rediant.finance', 'FANTOM'],
#  ['WFTM', 'BTC', '3440971.18', '118.16', 'https://rediant.finance', 'FANTOM'],
#  ['WFTM', 'DAI', '2825498.56', '82.08', 'https://rediant.finance', 'FANTOM'],
#  ['WFTM', 'YORO', '12724.84', '461.91', 'https://yorocoon.com', 'FANTOM'],
#  ['WFTM', 'CATNIP', '9640.66', '2477.07', 'https://yorocoon.com', 'FANTOM'],
#  ['CATNIP', 'YORO', '13076.34', '1313.74', 'https://yorocoon.com', 'FANTOM'],
#  ['CATNIP', '', '22400.26', '3197.02', 'https://yorocoon.com', 'FANTOM'],
#  ['ZOO', 'YORO', '6573.63', '902.87', 'https://yorocoon.com', 'FANTOM'],
#  ['ZOO', 'CATNIP', '2805.49', '4048.61', 'https://yorocoon.com', 'FANTOM'],
#  ['WFTM', 'SPOON', '5487.72', '830.72', 'https://app.spoon.finance', 'FANTOM'],
#  ['ibSPOON', '', '0.00', 0, 'https://app.spoon.finance', 'FANTOM'],
#  ['ibFTM', '', '12424.74', '19.82', 'https://app.spoon.finance', 'FANTOM'],
#  ['ibUSDC', '', '11252.90', '24.02', 'https://app.spoon.finance', 'FANTOM'],
#  ['ibfUSDT', '', '6620.27', '37.24', 'https://app.spoon.finance', 'FANTOM'],
#  ['ibDAI', '', '10141.80', '24.29', 'https://app.spoon.finance', 'FANTOM'],
#  ['WFTM',
#   'SPIRIT',
#   '1970.52',
#   '276.16',
#   'https://app.spoon.finance',
#   'FANTOM'],
#  ['WFTM', 'BOO', '14802.68', '129.45', 'https://app.spoon.finance', 'FANTOM'],
#  ['USDC', 'WFTM', '1311.88', '456.06', 'https://app.spoon.finance', 'FANTOM'],
#  ['fUSDT', 'WFTM', '8169.70', '106.55', 'https://app.spoon.finance', 'FANTOM'],
#  ['WFTM', 'DAI', '2290.65', '273.73', 'https://app.spoon.finance', 'FANTOM'],
#  ['BULL',
#   '',
#   '3156.86',
#   '1148.67',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['WFTM',
#   '',
#   '50417776.29',
#   '103.45',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['BOO',
#   '',
#   '13250073.59',
#   '672.64',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['BTC', '', '0.00', 0, 'https://fantom.bullrun.finance', 'FANTOM'],
#  ['ETH',
#   '',
#   '5207004.34',
#   '104.22',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['USDC',
#   '',
#   '57826484.62',
#   '17.94',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BULL',
#   '2883.58',
#   '2908.22',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['USDC',
#   'BULL',
#   '250.63',
#   '5108.57',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['BOO',
#   'BULL',
#   '471.00',
#   '2485.65',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['USDC',
#   'WFTM',
#   '4347609.15',
#   '698.42',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['fUSDT',
#   'WFTM',
#   '2921121.85',
#   '118.71',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['WFTM',
#   'ETH',
#   '3472636.09',
#   '59.75',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['WFTM',
#   'BTC',
#   '3441000.31',
#   '86.73',
#   'https://fantom.bullrun.finance',
#   'FANTOM'],
#  ['WFTM', 'SHADE', '431222.89', '1346.76', 'https://shade.cash', 'FANTOM'],
#  ['SHADE', '', '4430254.58', '73.82', 'https://shade.cash', 'FANTOM'],
#  ['ETH',
#   '1INCH',
#   '7828350.43',
#   '0.00',
#   'https://1inch.exchange/#/dao/farming',
#   'ETH'],
#  ['1INCH',
#   'VSP',
#   '2993612.96',
#   '0.00',
#   'https://1inch.exchange/#/dao/farming',
#   'ETH'],
#  ['ETH',
#   'TORN',
#   '304449.07',
#   '0.00',
#   'https://1inch.exchange/#/dao/farming',
#   'ETH'],
#  ['ETH',
#   'OPIUM',
#   '1219882.98',
#   '0.00',
#   'https://1inch.exchange/#/dao/farming',
#   'ETH'],
#  ['LDO',
#   'stETH',
#   '3167501.02',
#   '0.00',
#   'https://1inch.exchange/#/dao/farming',
#   'ETH'],
#  ['ETH',
#   'WBTC',
#   '936457.97',
#   '0.00',
#   'https://1inch.exchange/#/dao/farming',
#   'ETH'],
#  ['ETH',
#   'USDC',
#   '586412.46',
#   '0.00',
#   'https://1inch.exchange/#/dao/farming',
#   'ETH'],
#  ['ETH',
#   'DAI',
#   '242082.92',
#   '0.00',
#   'https://1inch.exchange/#/dao/farming',
#   'ETH'],
#  ['ETH',
#   'USDT',
#   '350449.89',
#   '0.00',
#   'https://1inch.exchange/#/dao/farming',
#   'ETH'],
#  ['DEX', 'WETH', '85447.28', '8.08', 'https://kitten.finance/', 'ETH'],
#  ['DEX', '', '466200.00', '0.00', 'https://kitten.finance/', 'ETH'],
#  ['KIF', '', '1254599.90', '0.87', 'https://kitten.finance/', 'ETH'],
#  ['KIF', 'WETH', '174233.52', '4.12', 'https://kitten.finance/', 'ETH'],
#  ['kBASEv0', 'USDC', '20525.72', '34.60', 'https://kitten.finance/', 'ETH'],
#  ['kBASEv0', '', '34946.01', '16.55', 'https://kitten.finance/', 'ETH'],
#  ['ARMOR', 'WETH', '1837977.30', '74.69', 'https://armor.fi', 'ETH'],
#  ['ARMOR', 'DAI', '587870.82', '62.12', 'https://armor.fi', 'ETH'],
#  ['ARMOR', 'WBTC', '473236.75', '76.75', 'https://armor.fi', 'ETH'],
#  ['ARMOR', 'WETH', '709981.95', '83.18', 'https://armor.fi', 'ETH'],
#  ['ARMOR', 'DAI', '196742.33', '62.14', 'https://armor.fi', 'ETH'],
#  ['ARMOR', 'WBTC', '351031.21', '69.25', 'https://armor.fi', 'ETH'],
#  ['ETH', 'ARMOR', '299735.78', '81.87', 'https://armor.fi', 'ETH'],
#  ['ARMOR', 'DAI', '151165.69', '80.11', 'https://armor.fi', 'ETH'],
#  ['ARMOR', 'WBTC', '177294.18', '68.07', 'https://armor.fi', 'ETH'],
#  ['ARMOR 98%', 'WETH 2%', '2787164.81', '43.39', 'https://armor.fi', 'ETH'],
#  ['DAI 98%', 'ARMOR 2%', '580620.20', '20.73', 'https://armor.fi', 'ETH'],
#  ['ARMOR', 'arNXM', '6713.94', '0.00', 'https://armor.fi', 'ETH'],
#  ['arNXM', 'WETH', '3549895.20', '14.02', 'https://armor.fi', 'ETH'],
#  ['arNXM', 'WETH', '1856434.83', '12.97', 'https://armor.fi', 'ETH'],
#  ['ETH', 'arNXM', '878152.57', '13.71', 'https://armor.fi', 'ETH'],
#  ['arNXM 98%', 'WETH 2%', '6245235.46', '11.57', 'https://armor.fi', 'ETH'],
#  ['wNXM', 'arNXM', '1700.60', '0.00', 'https://armor.fi', 'ETH'],
#  ['wNXM', 'arNXM', '577.26', 0, 'https://armor.fi', 'ETH'],
#  ['DAI', 'BAS', '728.36', '1407.70', 'https://basis.cash', 'ETH'],
#  ['BAC', 'DAI', '1817683.35', '0.00', 'https://basis.cash', 'ETH'],
#  ['DAI', 'BSGS', '7181.70', '273.25', 'https://basis.gold', 'ETH'],
#  ['DAI', 'BSG', '6102.35', '848.77', 'https://basis.gold', 'ETH'],
#  ['DAIQ', '', '5977.59', 0, 'https://daiq.io', 'ETH'],
#  ['DAI', 'DEBASE', '36894.94', '0.00', 'https://debaseonomics.io/', 'ETH'],
#  ['DAI', '', '5246262093.47', '0.00', 'https://debaseonomics.io/', 'ETH'],
#  ['DAI', 'DEBASE', '36894.94', '0.00', 'https://debaseonomics.io/', 'ETH'],
#  ['DAI', 'DEBASE', '36894.94', '0.00', 'https://debaseonomics.io/', 'ETH'],
#  ['DPX', '', '51945000.00', '16.24', 'https://app.dopex.io/farms', 'ETH'],
#  ['rDPX', 'WETH', '607669.23', '264.06', 'https://app.dopex.io/farms', 'ETH'],
#  ['WETH', 'DPX', '3910845.03', '117.19', 'https://app.dopex.io/farms', 'ETH'],
#  ['GME', 'WETH', '33962.75', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['YFI', '', '1021294764.00', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['LINK', '', '15560000000.00', 0, 'https://gamestop.finance', 'ETH'],
#  ['CREAM', '', '1607760000.00', 0, 'https://gamestop.finance', 'ETH'],
#  ['renDOGE', '', '3502828.94', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['USDT', '', '30910401959.98', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['BUSD', '', '11188613530.54', 0, 'https://gamestop.finance', 'ETH'],
#  ['USDC', '', '25603380061.54', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['CRV', '', '2260916871.51', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['COMP', '', '3817700000.00', 0, 'https://gamestop.finance', 'ETH'],
#  ['SUSHI', '', '1492476659.26', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['BADGER', '', '164430000.00', 0, 'https://gamestop.finance', 'ETH'],
#  ['DSD', '', '2914884.53', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['ESD', '', '61207523.07', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['FRAX', '', '233319365.98', 0, 'https://gamestop.finance', 'ETH'],
#  ['MIC', '', '0.00', 0, 'https://gamestop.finance', 'ETH'],
#  ['OGN', '', '771302000.00', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['OUSD', '', '19117663.05', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['CVP', '', '86695600.00', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['ALBT', '', '335560000.00', 0, 'https://gamestop.finance', 'ETH'],
#  ['SPDR', '', '9043070.00', '0.00', 'https://gamestop.finance', 'ETH'],
#  ['FARM', '', '47065784.01', '23.33', 'https://harvest.finance/', 'ETH'],
#  ['FARM', 'WETH', '5533068.02', '34.17', 'https://harvest.finance/', 'ETH'],
#  ['FARM', 'USDC', '127469.79', '0.00', 'https://harvest.finance/', 'ETH'],
#  ['GRAIN', 'FARM', '54192.25', '41.96', 'https://harvest.finance/', 'ETH'],
#  ['DPI', 'WETH', '1895102.34', '1.28', 'https://harvest.finance/', 'ETH'],
#  ['DAI', 'BSG', '1076.41', '0.00', 'https://harvest.finance/', 'ETH'],
#  ['DAI', 'BSGS', '3505.60', '0.00', 'https://harvest.finance/', 'ETH'],
#  ['BAC', 'DAI', '533575.20', '19.46', 'https://harvest.finance/', 'ETH'],
#  ['BASv2', 'DAI', '52961.52', '27.23', 'https://harvest.finance/', 'ETH'],
#  ['MIC', 'USDT', '610007.70', '73.69', 'https://harvest.finance/', 'ETH'],
#  ['MIS', 'USDT', '61661.74', '330.41', 'https://harvest.finance/', 'ETH'],
#  ['foBTC', 'sbtcCRV', '6339205.56', '1.57', 'https://harvest.finance/', 'ETH'],
#  ['ftbtc', 'sbtcCrv', '388894.81', '0.00', 'https://harvest.finance/', 'ETH'],
#  ['DAI', 'WETH', '14125635.98', '1.06', 'https://harvest.finance/', 'ETH'],
#  ['USDC', 'WETH', '6647786.28', '1.86', 'https://harvest.finance/', 'ETH'],
#  ['WETH', 'USDT', '17309672.69', '1.38', 'https://harvest.finance/', 'ETH'],
#  ['WBTC', 'WETH', '5879686.33', '1.12', 'https://harvest.finance/', 'ETH'],
#  ['oneETH', 'WETH', '254514.08', '0.00', 'https://ichi.farm/', 'ETH'],
#  ['ICHI', 'WETH', '2749.89', '0.00', 'https://ichi.farm/', 'ETH'],
#  ['oneETH', 'ICHI', '6721.29', '0.00', 'https://ichi.farm/', 'ETH'],
#  ['ICHI', 'oneBTC', '143.58', '0.00', 'https://ichi.farm/', 'ETH'],
#  ['WBTC', 'oneBTC', '17705.73', 0, 'https://ichi.farm/', 'ETH'],
#  ['ICHI', 'WETH', '43526.52', '0.00', 'https://ichi.farm/', 'ETH'],
#  ['oneLINK', 'LINK', '27.95', 0, 'https://ichi.farm/', 'ETH'],
#  ['WBTC', 'oneBTC', '768868.83', '7.26', 'https://ichi.farm/', 'ETH'],
#  ['oneLINK', 'LINK', '466.95', '0.00', 'https://ichi.farm/', 'ETH'],
#  ['ICHI', 'WETH', '2230120.17', '0.00', 'https://ichi.farm/', 'ETH'],
#  ['DEFI5', '', '7864545.80', '19.23', 'https://indexed.finance', 'ETH'],
#  ['CC10', '', '3837005.19', '18.09', 'https://indexed.finance', 'ETH'],
#  ['DEGEN', '', '7435304.29', '10.83', 'https://indexed.finance', 'ETH'],
#  ['WETH', 'DEFI5', '4013455.88', '25.97', 'https://indexed.finance', 'ETH'],
#  ['CC10', 'WETH', '1875204.82', '45.76', 'https://indexed.finance', 'ETH'],
#  ['WETH', 'ORCL5', '188927.75', '42.28', 'https://indexed.finance', 'ETH'],
#  ['DEGEN', 'WETH', '1318052.19', '52.86', 'https://indexed.finance', 'ETH'],
#  ['WETH', 'ERROR', '24043.14', '74.13', 'https://indexed.finance', 'ETH'],
#  ['FFF', 'WETH', '1487554.95', '32.96', 'https://indexed.finance', 'ETH'],
#  ['WETH', 'ORCL5', '188927.75', 0, 'https://indexed.finance', 'ETH'],
#  ['WETH', 'DEFI5', '4013455.88', 0, 'https://indexed.finance', 'ETH'],
#  ['CC10', 'WETH', '1875204.82', 0, 'https://indexed.finance', 'ETH'],
#  ['DEFI5', '', '7864545.80', 0, 'https://indexed.finance', 'ETH'],
#  ['CC10', '', '3837005.19', 0, 'https://indexed.finance', 'ETH'],
#  ['MICv2_3CRV3CRV-f', '', '39967.51', 0, 'https://mith.cash', 'ETH'],
#  ['MIS2', 'USDT', '1333.92', '146.06', 'https://mith.cash', 'ETH'],
#  ['MIS2', 'USDT', '1333.92', '0.00', 'https://mith.cash', 'ETH'],
#  ['MIS', 'USDT', '91145.49', '420.84', 'https://mith.cash', 'ETH'],
#  ['MIC', 'USDT', '621876.68', '96.66', 'https://mith.cash', 'ETH'],
#  ['DAI', 'MORT', '3393.23', '0.00', 'https://morph.finance/', 'ETH'],
#  ['MORC', 'DAI', '2112.50', '0.00', 'https://morph.finance/', 'ETH'],
#  ['MM', '', '1602024.12', '6.89', 'https://mushrooms.finance/farms', 'ETH'],
#  ['USDC',
#   'MM',
#   '653036.39',
#   '41.49',
#   'https://mushrooms.finance/farms',
#   'ETH'],
#  ['MIR', 'UST', '702017.03', '1.94', 'https://mushrooms.finance/farms', 'ETH'],
#  ['MM',
#   'WETH',
#   '245348.22',
#   '97.15',
#   'https://mushrooms.finance/farms',
#   'ETH'],
#  ['KP3R', 'MM', '28487.80', '63.14', 'https://mushrooms.finance/farms', 'ETH'],
#  ['MM',
#   'WETH',
#   '162083.76',
#   '104.97',
#   'https://mushrooms.finance/farms',
#   'ETH'],
#  ['NAWA', 'USDC', '16639.04', '240.69', 'https://narwhale.finance', 'ETH'],
#  ['ONS', 'DAI', '25653.85', '0.00', 'https://onecash.finance', 'ETH'],
#  ['DAI', 'ONC', '66860.63', '0.00', 'https://onecash.finance', 'ETH'],
#  ['PUSD', 'PEGS', '735492.55', '688.64', 'https://pegs.cash', 'ETH'],
#  ['PUSD', 'USDC', '3832.37', '135420.39', 'https://pegs.cash', 'ETH'],
#  ['PICKLE',
#   'WETH',
#   '2052074.24',
#   '32.32',
#   'https://pickle.finance/farms',
#   'ETH'],
#  ['WETH',
#   'yveCRV-DAO',
#   '821238.03',
#   '1.24',
#   'https://pickle.finance/farms',
#   'ETH'],
#  ['DAI', 'WETH', '2153665.23', '10.19', 'https://pickle.finance/farms', 'ETH'],
#  ['USDC', 'WETH', '618623.29', '0.05', 'https://pickle.finance/farms', 'ETH'],
#  ['WETH',
#   'USDT',
#   '3219561.82',
#   '14.62',
#   'https://pickle.finance/farms',
#   'ETH'],
#  ['WBTC', 'WETH', '662832.41', '0.04', 'https://pickle.finance/farms', 'ETH'],
#  ['YFI', 'WETH', '570972.92', '0.06', 'https://pickle.finance/farms', 'ETH'],
#  ['MIR', 'UST', '471893.64', '5.51', 'https://pickle.finance/farms', 'ETH'],
#  ['mTSLA', 'UST', '39374.91', '0.17', 'https://pickle.finance/farms', 'ETH'],
#  ['UST',
#   'mAAPL',
#   '1035530.01',
#   '16.22',
#   'https://pickle.finance/farms',
#   'ETH'],
#  ['mQQQ', 'UST', '344932.91', '49.44', 'https://pickle.finance/farms', 'ETH'],
#  ['mSLV', 'UST', '334721.14', '40.05', 'https://pickle.finance/farms', 'ETH'],
#  ['mBABA', 'UST', '813368.86', '22.73', 'https://pickle.finance/farms', 'ETH'],
#  ['SUSHI', 'WETH', '600749.91', '2.12', 'https://pickle.finance/farms', 'ETH'],
#  ['FEI',
#   'TRIBE',
#   '4437976.65',
#   '11.43',
#   'https://pickle.finance/farms',
#   'ETH'],
#  ['yvBOOST',
#   'WETH',
#   '10353690.38',
#   '5.36',
#   'https://pickle.finance/farms',
#   'ETH'],
#  ['WETH',
#   'ALCX',
#   '18941807.46',
#   '3.52',
#   'https://pickle.finance/farms',
#   'ETH'],
#  ['CVX', 'WETH', '955738.43', '20.73', 'https://pickle.finance/farms', 'ETH'],
#  ['STBZ',
#   'WETH',
#   '547171.36',
#   '85.91',
#   'https://www.stabilize.finance/app/',
#   'ETH'],
#  ['DAI',
#   '',
#   '5245677515.47',
#   '0.00',
#   'https://www.stabilize.finance/app/',
#   'ETH'],
#  ['USDC',
#   '',
#   '25598380483.84',
#   0,
#   'https://www.stabilize.finance/app/',
#   'ETH'],
#  ['USDT',
#   '',
#   '30910401959.98',
#   0,
#   'https://www.stabilize.finance/app/',
#   'ETH'],
#  ['sUSD',
#   '',
#   '243638763.76',
#   '0.00',
#   'https://www.stabilize.finance/app/',
#   'ETH'],
#  ['za-USDC', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['za-USDT', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['za-sUSD', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['za-DAI', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-DAI', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zpa-USDC', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zpa-USDT', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zpa-sUSD', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zpa-DAI', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-USD', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-BTC', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-SGR', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-BMSGR', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-FRAX', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-UST', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-ETH', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-XUSD', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-XUSD2', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-tsBTC', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-AMPL', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['zs-FEI', '', '0.00', 0, 'https://www.stabilize.finance/app/', 'ETH'],
#  ['SDT', 'WETH', '2490981.04', '119.24', 'https://stakedao.org', 'ETH'],
#  ['SDT', 'WETH', '1086934.56', '110.06', 'https://stakedao.org', 'ETH'],
#  ['DUMMY', '', '0.00', 0, 'https://stakedao.org', 'ETH'],
#  ['sdveCRV90-CRV10', '', '0.00', 0, 'https://stakedao.org', 'ETH'],
#  ['TRU', 'WETH', '188802.95', '3547.82', 'https://app.truefi.io/farm', 'ETH'],
#  ['TUSD',
#   'tfTUSD',
#   '43467.13',
#   '1568.69',
#   'https://app.truefi.io/farm',
#   'ETH'],
#  ['tfTUSD', '', '46312181.56', '5.84', 'https://app.truefi.io/farm', 'ETH'],
#  ['WETH', 'UPDOWN', '243.04', '0.00', 'https://updown.finance', 'ETH'],
#  ['UPDOWN', '', '79980.35', '0.00', 'https://updown.finance', 'ETH'],
#  ['XUS', 'WETH', '37681.31', '0.00', 'https://xusd.money/', 'ETH'],
#  ['XUSD', 'XUS', '31676.63', '0.00', 'https://xusd.money/', 'ETH'],
#  ['XUSD', 'DAI', '4361.39', '0.00', 'https://xusd.money/', 'ETH'],
#  ['XUSD', 'WETH', '47958.77', '0.00', 'https://xusd.money/', 'ETH'],
#  ['XUSD', 'LINK', '0.01', '18661518.63', 'https://xusd.money/', 'ETH'],
#  ['sYFL', 'WETH', '1753.91', '71.81', 'https://yflusd.linkswap.app', 'ETH'],
#  ['LINK', 'YFLUSD', '3947.64', '47.58', 'https://yflusd.linkswap.app', 'ETH'],
#  ['YFLUSD', 'WETH', '10924.32', '16.91', 'https://yflusd.linkswap.app', 'ETH'],
#  ['YAX', 'WETH', '132979.51', '941.32', 'https://yaxis.io/farms', 'ETH'],
#  ['YAXIS', '', '35090000.00', '141.14', 'https://yaxis.io/farms', 'ETH'],
#  ['YAXIS', 'WETH', '1785202.43', '179.72', 'https://yaxis.io/farms', 'ETH'],
#  ['SGT',
#   'WETH',
#   '24256.57',
#   '31.31',
#   'https://www.sharedstake.org/earn',
#   'ETH'],
#  ['SGT', '', '181859.20', '77.87', 'https://www.sharedstake.org/earn', 'ETH'],
#  ['vETH2',
#   '',
#   '30491153.18',
#   '0.28',
#   'https://www.sharedstake.org/earn',
#   'ETH'],
#  ['SGT',
#   'vETH2',
#   '15633.26',
#   '41.45',
#   'https://www.sharedstake.org/earn',
#   'ETH'],
#  ['saddleVETH2',
#   '',
#   '176813.16',
#   '0.00',
#   'https://www.sharedstake.org/earn',
#   'ETH'],
#  ['SGT',
#   'WETH',
#   '24256.57',
#   '0.00',
#   'https://www.sharedstake.org/earn',
#   'ETH'],
# ...
#  ['AKRO', 'WETH', '341503.70', '3.62', 'https://www.bao.finance', 'ETH'],
#  ['REQ', 'WETH', '1433049.05', '0.05', 'https://www.bao.finance', 'ETH'],
#  ['QSP', 'WETH', '58292.74', '2.20', 'https://www.bao.finance', 'ETH'],
#  ['MTA', 'WETH', '1557400.88', '6.82', 'https://www.bao.finance', 'ETH'],
#  ['AST', 'WETH', '147175.43', '13.40', 'https://www.bao.finance', 'ETH'],
#  ['DUSD', 'WETH', '16778.29', '4.86', 'https://www.bao.finance', 'ETH'],
#  ['BTSE', 'WETH', '434350.10', '2.16', 'https://www.bao.finance', 'ETH'],
#  ['DF', 'WETH', '1407071.67', '5.57', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'DMG', '23016.46', '0.20', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'KARMA', '27225.46', '7.15', 'https://www.bao.finance', 'ETH'],
#  ['TKN', 'WETH', '1196163.00', '6.51', 'https://www.bao.finance', 'ETH'],
#  ['PNT', 'WETH', '1061393.96', '0.16', 'https://www.bao.finance', 'ETH'],
#  ['YAM', 'WETH', '53315.79', '2.04', 'https://www.bao.finance', 'ETH'],
#  ['AUDIO', 'WETH', '4194383.52', '7.06', 'https://www.bao.finance', 'ETH'],
#  ['GHST', 'WETH', '97091.18', '3.36', 'https://www.bao.finance', 'ETH'],
#  ['SWRV', 'WETH', '35875.52', '11.91', 'https://www.bao.finance', 'ETH'],
#  ['FOAM', 'WETH', '462083.95', '0.13', 'https://www.bao.finance', 'ETH'],
#  ['LIEN', 'WETH', '138433.71', '17.89', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'PRE', '114517.75', '0.75', 'https://www.bao.finance', 'ETH'],
#  ['GEN', 'WETH', '87779.60', '5.86', 'https://www.bao.finance', 'ETH'],
#  ['JRT', 'WETH', '241602.82', '50.96', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'MEME', '1140646.79', '10.11', 'https://www.bao.finance', 'ETH'],
#  ['BOND', 'USDC', '27144477.22', '7.82', 'https://www.bao.finance', 'ETH'],
#  ['APY', 'WETH', '3255961.43', '14.96', 'https://www.bao.finance', 'ETH'],
#  ['INDEX', 'WETH', '684337.24', '3.96', 'https://www.bao.finance', 'ETH'],
#  ['USDC', 'DHT', '14473.92', '22.51', 'https://www.bao.finance', 'ETH'],
#  ['DOUGH', 'WETH', '281895.90', '18.27', 'https://www.bao.finance', 'ETH'],
#  ['HGET', 'WETH', '73351.57', '7.35', 'https://www.bao.finance', 'ETH'],
#  ['BFT', 'WETH', '179407.27', '0.13', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'ROOK', '2303913.89', '7.09', 'https://www.bao.finance', 'ETH'],
#  ['YAMv2', 'WETH', '4662.48', '0.07', 'https://www.bao.finance', 'ETH'],
#  ['DFD', 'WETH', '51315.70', '3.04', 'https://www.bao.finance', 'ETH'],
#  ['BLT', 'WETH', '31370.58', '5.47', 'https://www.bao.finance', 'ETH'],
#  ['SLP', 'WETH', '213652.84', '3.00', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'HYDRO', '481.51', '0.69', 'https://www.bao.finance', 'ETH'],
#  ['KRL', 'WETH', '55020.24', '2.40', 'https://www.bao.finance', 'ETH'],
#  ['RSV', 'WETH', '51166.32', '4.27', 'https://www.bao.finance', 'ETH'],
#  ['HOT', 'WETH', '306018.84', '0.02', 'https://www.bao.finance', 'ETH'],
#  ['ADEL', 'WETH', '11540.72', '12.71', 'https://www.bao.finance', 'ETH'],
#  ['SOCKS', 'WETH', '126610.11', '4.14', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'WAR', '42977.74', '2.29', 'https://www.bao.finance', 'ETH'],
#  ['0xBTC', 'WETH', '39546.24', '11.05', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'DONUT', '160875.88', '4.63', 'https://www.bao.finance', 'ETH'],
#  ['TTT', 'WETH', '13200.29', '0.28', 'https://www.bao.finance', 'ETH'],
#  ['REPv2', 'WETH', '1031406.75', '4.35', 'https://www.bao.finance', 'ETH'],
#  ['GNO', 'WETH', '153669.82', '7.96', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'AUC', '228657.78', '6.28', 'https://www.bao.finance', 'ETH'],
#  ['YAX', 'WETH', '132945.35', '18.95', 'https://www.bao.finance', 'ETH'],
#  ['OCTO', 'WETH', '199793.46', '19.64', 'https://www.bao.finance', 'ETH'],
#  ['VALUE', 'WETH', '3198.63', '0.11', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'SHROOM', '385263.18', '2.98', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'RGT', '1261245.11', '4.01', 'https://www.bao.finance', 'ETH'],
#  ['SEED', 'WETH', '553.56', '1.56', 'https://www.bao.finance', 'ETH'],
#  ['WG0', 'WETH', '351500.27', '8.16', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'WOA', '23661.84', '4.54', 'https://www.bao.finance', 'ETH'],
#  ['UBXT', 'WETH', '229365.51', '6.12', 'https://www.bao.finance', 'ETH'],
#  ['BEST', 'WETH', '1927.81', '0.15', 'https://www.bao.finance', 'ETH'],
#  ['TOMOE', 'WETH', '65195.72', '0.16', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'HEZ', '25771679.87', '2.10', 'https://www.bao.finance', 'ETH'],
#  ['PICKLE', 'WETH', '2053771.16', '0.10', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'ENCORE', '53948.42', '3.91', 'https://www.bao.finance', 'ETH'],
#  ['YFIM', 'WETH', '981916.44', '1.51', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'ORO', '878.88', '0.41', 'https://www.bao.finance', 'ETH'],
#  ['XOR', 'WETH', '971904.12', '2.17', 'https://www.bao.finance', 'ETH'],
#  ['REN', 'WETH', '2117910.23', '3.58', 'https://www.bao.finance', 'ETH'],
#  ['LRC', 'WETH', '1298739.89', '5.65', 'https://www.bao.finance', 'ETH'],
#  ['CVP', 'WETH', '3351769.37', '0.02', 'https://www.bao.finance', 'ETH'],
#  ['JUL', 'WETH', '19364.21', '0.28', 'https://www.bao.finance', 'ETH'],
#  ['KEEP', 'WETH', '5682263.47', '4.27', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'RMPL', '401064.02', '0.12', 'https://www.bao.finance', 'ETH'],
#  ['OWL', 'WETH', '1186182.46', '0.36', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'RARI', '1356306.17', '1.25', 'https://www.bao.finance', 'ETH'],
#  ['SUSHI', 'WETH', '1369543.28', '4.40', 'https://www.bao.finance', 'ETH'],
#  ['ORN', 'WETH', '925216.61', '5.33', 'https://www.bao.finance', 'ETH'],
#  ['CHART', 'WETH', '171899.80', '15.75', 'https://www.bao.finance', 'ETH'],
#  ['XIO', 'WETH', '2796928.63', '7.53', 'https://www.bao.finance', 'ETH'],
#  ['YFL', 'WETH', '177600.07', '3.78', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'SWAP', '3273753.48', '7.91', 'https://www.bao.finance', 'ETH'],
#  ['BUSD', 'USDC', '1963691.64', '0.15', 'https://www.bao.finance', 'ETH'],
#  ['POLS', 'WETH', '8635876.98', '1.61', 'https://www.bao.finance', 'ETH'],
#  ['HAUT', 'WETH', '2366.70', '13.71', 'https://www.bao.finance', 'ETH'],
#  ['ALMX', 'WETH', '35930.90', '7.89', 'https://www.bao.finance', 'ETH'],
#  ['CANDY', 'WETH', '9039.79', '2.28', 'https://www.bao.finance', 'ETH'],
#  ['COKE', 'WETH', '3913.12', '4.43', 'https://www.bao.finance', 'ETH'],
#  ['BUGS', 'WETH', '3604.37', '3.36', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'sDEFI', '18160.52', '2.89', 'https://www.bao.finance', 'ETH'],
#  ['ALPHA', 'WETH', '181542.22', '1.91', 'https://www.bao.finance', 'ETH'],
#  ['WVG0', 'WETH', '46702.85', '9.24', 'https://www.bao.finance', 'ETH'],
#  ['KP4R', 'WETH', '197768.55', '5.33', 'https://www.bao.finance', 'ETH'],
#  ['IDLE', 'WETH', '80537.51', '5.22', 'https://www.bao.finance', 'ETH'],
#  ['PERP', 'WETH', '5390129.46', '13.39', 'https://www.bao.finance', 'ETH'],
#  ['ZAP', 'WETH', '98023.69', '5.91', 'https://www.bao.finance', 'ETH'],
#  ['COVER', 'WETH', '3752.52', '0.09', 'https://www.bao.finance', 'ETH'],
#  ['CRE', 'WETH', '32945.34', '2.04', 'https://www.bao.finance', 'ETH'],
#  ['L2', 'WETH', '188009.10', '9.16', 'https://www.bao.finance', 'ETH'],
#  ['DODO', 'WETH', '317986.79', '36.20', 'https://www.bao.finance', 'ETH'],
#  ['API3', 'WETH', '946378.30', '5.14', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'FRONT', '21702.59', '7.48', 'https://www.bao.finance', 'ETH'],
#  ['SKL', 'WETH', '2333573.14', '16.93', 'https://www.bao.finance', 'ETH'],
#  ['TRU', 'WETH', '187585.90', '11.96', 'https://www.bao.finance', 'ETH'],
#  ['DEXT', 'WETH', '15801.06', '17.34', 'https://www.bao.finance', 'ETH'],
#  ['eXRD', 'WETH', '34192.11', '6.35', 'https://www.bao.finance', 'ETH'],
#  ['BAO', 'WETH', '2204788.03', '2.72', 'https://www.bao.finance', 'ETH'],
#  ['BAO', 'USDC', '208502.92', '18.02', 'https://www.bao.finance', 'ETH'],
#  ['YFI', 'BAO', '136574.96', '5.05', 'https://www.bao.finance', 'ETH'],
#  ['BAO', 'SUSHI', '200333.99', '3.22', 'https://www.bao.finance', 'ETH'],
#  ['BAO', 'DAI', '116711.40', '12.64', 'https://www.bao.finance', 'ETH'],
#  ['xSUSHI', '', '488270020.51', '1.04', 'https://www.bao.finance', 'ETH'],
#  ['SUSHI', 'xSUSHI', '127191.12', '3.73', 'https://www.bao.finance', 'ETH'],
#  ['xSUSHI', 'WETH', '25414309.73', '4.73', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'GRT', '1266614.06', '1.39', 'https://www.bao.finance', 'ETH'],
#  ['RUNE', 'WETH', '2362110.74', '1.28', 'https://www.bao.finance', 'ETH'],
#  ['1INCH', 'WETH', '1146940.52', '0.41', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'FIDA', '44734.12', '2.74', 'https://www.bao.finance', 'ETH'],
#  ['NFTX', 'WETH', '7644656.76', '4.89', 'https://www.bao.finance', 'ETH'],
#  ['sETH', 'WETH', '332009.95', '1.23', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'aETHc', '2724453.05', '2.52', 'https://www.bao.finance', 'ETH'],
#  ['stETH', 'WETH', '138348.03', '1.78', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'INJ', '1449334.95', '1.56', 'https://www.bao.finance', 'ETH'],
#  ['GRO', 'WETH', '170582.72', '10.83', 'https://www.bao.finance', 'ETH'],
#  ['WETH', 'TVK', '1529605.57', '3.00', 'https://www.bao.finance', 'ETH'],
#  ['FRAX', 'USDC', '76068734.15', '7.35', 'https://www.bao.finance', 'ETH'],
#  ['DAI', 'USDC', '17277824.85', '6.83', 'https://www.bao.finance', 'ETH'],
#  ['LDO', 'WETH', '246550.51', '1.79', 'https://www.bao.finance', 'ETH'],
#  ['BADGER', 'WETH', '121978.23', '1.55', 'https://www.bao.finance', 'ETH'],
#  ['BOR', 'WETH', '304906.13', '6.30', 'https://www.bao.finance', 'ETH'],
#  ['FORCE', 'WETH', '305112.04', '186.37', 'https://forcedao.com/', 'ETH'],
#  ['USDC',
#   'Gaia',
#   '5357.22',
#   '247.17',
#   'https://www.dollarprotocol.com/#/stake',
#   'ETH'],
#  ['USDf',
#   'USDC',
#   '5565.56',
#   '225.32',
#   'https://www.dollarprotocol.com/#/stake',
#   'ETH'],
#  ['SHARE',
#   'WETH',
#   '136075.51',
#   '10.82',
#   'https://www.dollarprotocol.com/#/stake',
#   'ETH'],
#  ['WETH',
#   'Gaia',
#   '1008.81',
#   '323.46',
#   'https://www.dollarprotocol.com/#/stake',
#   'ETH'],
#  ['LUDUS', 'WETH', '25451.11', '0.00', 'https://app.playludus.io', 'ETH'],
#  ['LUDUS', '', '162248.44', '0.00', 'https://app.playludus.io', 'ETH'],
#  ['WASABI',
#   '',
#   '3627028.68',
#   '0.00',
#   'https://wasabix.finance/#/app/pool',
#   'ETH'],
#  ['waUSD',
#   '',
#   '1035305.98',
#   '17.79',
#   'https://wasabix.finance/#/app/pool',
#   'ETH'],
#  ['WASABI',
#   'WETH',
#   '4099516.88',
#   '170.97',
#   'https://wasabix.finance/#/app/pool',
#   'ETH'],
#  ['waUSD3CRV-f',
#   '',
#   '552373.06',
#   '24.38',
#   'https://wasabix.finance/#/app/pool',
#   'ETH'],
#  ['waBTC',
#   '',
#   '887507.48',
#   '15.25',
#   'https://wasabix.finance/#/app/pool',
#   'ETH'],
#  ['waLUSD',
#   '',
#   '1088659.90',
#   '27.35',
#   'https://wasabix.finance/#/app/pool',
#   'ETH'],
#  ['waETH',
#   '',
#   '891465.49',
#   '15.12',
#   'https://wasabix.finance/#/app/pool',
#   'ETH'],
#  ['ALN', 'WETH', '131876.65', '0.00', 'https://aluna.social/farm', 'ETH'],
#  ['WETH', 'KINE', '2048065.63', '116.46', 'https://kine.finance', 'ETH'],
#  ['WETH', 'kUSD', '232.61', '0.00', 'https://kine.finance', 'ETH'],
#  ['kUSD', 'USDT', '964.18', 0, 'https://kine.finance', 'ETH'],
#  ['UMBR', 'WETH', '394037.85', '181.07', 'https://farm.umbria.network', 'ETH'],
#  ['ERN', 'WETH', '5073474.39', '90.61', 'https://ethernity.io', 'ETH'],
#  ['MUSE', 'WETH', '3522544.70', '101.32', 'https://nft20.io', 'ETH'],
#  ['MEME20', 'WETH', '86979.48', '206.95', 'https://nft20.io', 'ETH'],
#  ['WETH', 'MASK20', '198557.24', '180.80', 'https://nft20.io', 'ETH'],
#  ['DUDES20', 'WETH', '70752.51', '254.57', 'https://nft20.io', 'ETH'],
#  ['WETH', 'GPUNKS20', '148874.99', '240.49', 'https://nft20.io', 'ETH'],
#  ['WETH', 'MCAT20', '173408.63', '205.72', 'https://nft20.io', 'ETH'],
#  ['CHUBBIES20', 'WETH', '82234.53', '255.46', 'https://nft20.io', 'ETH'],
#  ['BAYC20', 'WETH', '205231.40', '85.47', 'https://nft20.io', 'ETH'],
#  ['MEEBITS20', 'WETH', '95216.55', '188.99', 'https://nft20.io', 'ETH'],
#  ['CAT20', 'WETH', '72076.22', '248.74', 'https://nft20.io', 'ETH'],
#  ['WETH', 'GCG', '41626.63', '428.46', 'https://nft20.io', 'ETH'],
#  ['WETH', 'TABOY20', '51240.72', '348.29', 'https://nft20.io', 'ETH'],
#  ['KONGZ20', 'WETH', '100164.47', '175.08', 'https://nft20.io', 'ETH'],
#  ['COOL20', 'WETH', '45725.56', '383.52', 'https://nft20.io', 'ETH'],
#  ['WETH', 'ICE', '2174923.45', '0.00', 'https://popsicle.finance', 'ETH'],
#  ['WETH', 'ICE', '2084150.08', '0.00', 'https://popsicle.finance', 'ETH'],
#  ['WBTC', 'KBTC', '753943.49', 0, 'https://klondike.finance', 'ETH'],
#  ['WBTC', 'KlonX', '813237.79', '45.68', 'https://klondike.finance', 'ETH'],
#  ['KXUSD', 'DAI', '287335.57', 0, 'https://klondike.finance', 'ETH'],
#  ['KEEP',
#   'WETH',
#   '5680928.74',
#   '56.22',
#   'https://dashboard.keep.network/liquidity',
#   'ETH'],
#  ['TBTC',
#   'WETH',
#   '1666926.43',
#   '30.96',
#   'https://dashboard.keep.network/liquidity',
#   'ETH'],
#  ['saddleTWRenSBTC',
#   '',
#   '31531869.91',
#   '12.28',
#   'https://dashboard.keep.network/liquidity',
#   'ETH'],
#  ['USDT-LP', '', '853650.38', 0, 'https://cvi.finance', 'ETH'],
#  ['ETH-LP-V2', '', '1293679.08', 0, 'https://cvi.finance', 'ETH'],
#  ['WETH', 'COTI', '1637465.77', '44.53', 'https://cvi.finance', 'ETH'],
#  ['WETH', 'GOVI', '8151022.83', '56.18', 'https://cvi.finance', 'ETH'],
#  ['WETH', 'COTI', '267174.93', '43.81', 'https://cvi.finance', 'ETH'],
#  ['WETH', 'GOVI', '940721.54', '58.86', 'https://cvi.finance', 'ETH'],
#  ['FST',
#   'WETH',
#   '4738550.36',
#   '40.28',
#   'https://exchange.futureswap.com',
#   'ETH'],
#  ['XBE', 'USDT', '924481.33', '0.00', 'http://app.eurxb.finance', 'ETH'],
#  ['XBE', 'USDT', '208323.52', 0, 'http://app.eurxb.finance', 'ETH'],
#  ['USDap', 'USDC', '1674262.97', '133.93', 'https://bondappetit.io', 'ETH'],
#  ['BAG', 'USDT', '69846.27', '203.69', 'https://bondappetit.io', 'ETH'],
#  ['BAG', 'USDN', '393476.95', '0.00', 'https://bondappetit.io', 'ETH'],
#  ['BAG', 'USDC', '35919.10', '0.00', 'https://bondappetit.io', 'ETH'],
#  ['BAG', 'USDap', '754386.38', '316.18', 'https://bondappetit.io', 'ETH'],
#  ['UNI', '', '31299.09', '0.00', 'https://penguinswap.eth.link', 'ETH'],
#  ['WETH 50%',
#   'PAR 50%',
#   '18227.62',
#   '42164.72',
#   'https://mimo.capital/mining',
#   'ETH'],
#  ['PAR 50%',
#   'USDC 50%',
#   '104037.05',
#   '7387.39',
#   'https://mimo.capital/mining',
#   'ETH'],
#  ['FEI', 'TRIBE', '316200127.15', '101.83', 'https://fei.money', 'ETH'],
#  ['WETH',
#   '',
#   '14233534765.80',
#   '0.00',
#   'https://app.thisistheway.finance/#/stake',
#   'ETH'],
#  ['WBTC',
#   '',
#   '6237394194.86',
#   '0.00',
#   'https://app.thisistheway.finance/#/stake',
#   'ETH'],
#  ['USDC',
#   '',
#   '25582209402.89',
#   '0.00',
#   'https://app.thisistheway.finance/#/stake',
#   'ETH'],
#  ['DAI',
#   '',
#   '5239314508.65',
#   '0.00',
#   'https://app.thisistheway.finance/#/stake',
#   'ETH'],
#  ['WETH',
#   'BAG',
#   '706821.51',
#   '0.00',
#   'https://app.thisistheway.finance/#/stake',
#   'ETH'],
#  ['BAG',
#   '',
#   '5797864.30',
#   0,
#   'https://app.thisistheway.finance/#/stake',
#   'ETH'],
#  ['BAG',
#   '',
#   '5797864.30',
#   0,
#   'https://app.thisistheway.finance/#/stake',
#   'ETH'],
#  ['BAG',
#   '',
#   '5797864.30',
#   0,
#   'https://app.thisistheway.finance/#/stake',
#   'ETH'],
#  ['WETH',
#   'BAG',
#   '706834.62',
#   0,
#   'https://app.thisistheway.finance/#/stake',
#   'ETH'],
#  ['PLAY', 'DOUGH', '1794398.34', '185.96', 'https://www.piedao.org', 'ETH'],
#  ['DOUGH', 'WETH', '1687059.24', '218.13', 'https://www.piedao.org', 'ETH'],
#  ['WETH 20%',
#   'DOUGH 80%',
#   '1763656.98',
#   '115.34',
#   'https://www.piedao.org',
#   'ETH'],
#  ['DEFI+S 70%',
#   'WETH 30%',
#   '406553.55',
#   '72.72',
#   'https://www.piedao.org',
#   'ETH'],
#  ['DEFI+L 70%',
#   'WETH 30%',
#   '999758.87',
#   '26.86',
#   'https://www.piedao.org',
#   'ETH'],
#  ['BCP', '', '2656244.51', '28.54', 'https://www.piedao.org', 'ETH'],
#  ['TCAP',
#   'WETH',
#   '4171235.40',
#   '145.06',
#   'https://app.cryptex.finance',
#   'ETH'],
#  ['CTX', 'WETH', '1637575.87', '371.95', 'https://app.cryptex.finance', 'ETH'],
#  ['WETH', '', '14234040274.57', '0.00', 'https://app.cryptex.finance', 'ETH'],
#  ['DAI', '', '5239314508.65', '0.00', 'https://app.cryptex.finance', 'ETH'],
#  ['LOTTO',
#   'WETH',
#   '108363.83',
#   '341.28',
#   'https://farm.unicrypt.network',
#   'ETH'],
#  ['KLTR', 'WETH', '35717.45', '73.64', 'https://farm.unicrypt.network', 'ETH'],
#  ...]

# %%
pair_df
# Out:
#        pair1 pair2         tvl         apr                       where  \
# 0       WFTM   ICE  3306577.84      175.59    https://popsicle.finance
# 1       WFTM   ICE  3210722.55      189.47    https://popsicle.finance
# 2       WFTM   BOO  8495107.84      116.99  https://spookyswap.finance
# 3      fUSDT  WFTM  2923586.22       54.56  https://spookyswap.finance
# 4       USDC  WFTM  4351275.25       36.66  https://spookyswap.finance
# ...      ...   ...         ...         ...                         ...
# 8840    USDC  FISH     2545.18     3782.19     https://poolsar.finance
# 8841  WMATIC  FISH     2375.00     9090.82     https://poolsar.finance
# 8842    KWIL  USDC    11789.30  9550647.76     https://poolsar.finance
# 8843  WMATIC  KWIL    10161.06  4778969.02     https://poolsar.finance
# 8844    KWIL         198657.56   440010.30     https://poolsar.finance
#
#      network  apy
# 0     FANTOM  NaN
# 1     FANTOM  NaN
# 2     FANTOM  NaN
# 3     FANTOM  NaN
# 4     FANTOM  NaN
# ...      ...  ...
# 8840   MATIC  NaN
# 8841   MATIC  NaN
# 8842   MATIC  NaN
# 8843   MATIC  NaN
# 8844   MATIC  NaN
#
# [8845 rows x 7 columns]

# %%
pair_df = pair_df.drop(pair_df[pair_df['pair1'] == ''].index)

# %%
pair_df[pair_df['pair1'] == '']
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, tvl, apr, where, network, apy]
# Index: []

# %%
pair_df[pair_df['network'] == 'Alternate']['network'] = 'ETH'

# %%
sheet_pairs_df = pd.DataFrame([])
eth_sheet_pairs_df = pd.read_csv('farm-yield_7_16.csv')
# eth_sheet_pairs_df.columns=['pair1', 'pair2', 'tvl', 'where', 'apr']
eth_sheet_pairs_df['apy'] = np.nan
eth_sheet_pairs_df['network'] = 'ETH'
sheet_pairs_df = sheet_pairs_df.append(eth_sheet_pairs_df)
sheet_pairs_df['pair2'] = sheet_pairs_df['pair2'].fillna('')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-95a6bbbd5fcc> in <module>
#       1 sheet_pairs_df = pd.DataFrame([])
# ----> 2 eth_sheet_pairs_df = pd.read_csv('yieldFarm_7-9.csv')
#       3 # eth_sheet_pairs_df.columns=['pair1', 'pair2', 'tvl', 'where', 'apr']
#       4 eth_sheet_pairs_df['apy'] = np.nan
#       5 eth_sheet_pairs_df['network'] = 'ETH'
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/.local/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/.local/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'yieldFarm_7-9.csv'

# %%
sheet_pairs_df

# %%
def update_apr(apr):
    apr = f"{apr}".replace("%", "")
    if len(apr) == 0 or "nan" == apr:
        return np.nan
    else:
        return apr

# %%
def get_symbol_mapping(pair):
    if pair is not None:
        return sm[pair.strip()] if pair.strip() in sm else pair.strip()
    else:
        return ""

# %%
pair_df = pair_df.append(sheet_pairs_df).reset_index(drop=True)
pair_df['type_of_agriculture'] = 'FARM'
pair_df = pair_df.append(df).reset_index(drop=True)

# %%
pair_df['apr'] = pair_df['apr'].apply(lambda x: update_apr(x))
pair_df['pair1'] = pair_df['pair1'].apply(lambda x: sm[x.strip()] if x.strip() in sm else x.strip())
pair_df['pair2'] = pair_df['pair2'].apply(lambda x: get_symbol_mapping(x))

# %%
pair_df['pair2'].unique()

# %%
pair_df

# %%
# pair_df['apr'].unique().tolist()

# %%
def convert_apr_to_apy(pair_df):
    tmp_df = pair_df[pair_df['apy'].isna()]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apr = row['apr']
        if pd.isnull( apr):
            return
        if apr is not None and len(apr.strip()):
            apr = float(apr.replace(',',''))
        else:
            apr = 0
        try:
            pair_df.loc[index, 'apy'] = ((1+(apr/100)/365)**365-1)*100
        except:
            pair_df.loc[index, 'apy'] = np.nan
    return
            
def convert_apy_to_apr(pair_df):
    tmp_df = pair_df[(pair_df['apr'].isnull())]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apy = row['apy']
        if pd.isnull( apy):
            return
        if apy is not None and len(apy.strip()):
            apy = float(apy.replace(',',''))
        else:
            apy = 0
        try:
            pair_df.loc[index, 'apr'] = (((1+(apy/100))**(1/365)-1)*365)*100
        except:
            pair_df.loc[index, 'apr'] = np.nan
    return


convert_apr_to_apy(pair_df)
convert_apy_to_apr(pair_df)

# %%
pair_df[pair_df['apy'].isna()]

# %%
pair_df[pair_df['apr'].isna()]

# %%
pair_df = pair_df.drop_duplicates()

# %%
single_piar_df = pair_df[pair_df['pair2'] == ""].copy()
double_coin_pair_df = pair_df[pair_df['pair2'] != ""].copy()
tmp_df = double_coin_pair_df.copy()

# %%
single_piar_df

# %%
double_coin_pair_df

# %%
tmp_df

# %%
tmp_df['tmp'] = tmp_df['pair1']
tmp_df['pair1'] = tmp_df['pair2']
tmp_df['pair2'] = tmp_df['tmp']
del tmp_df['tmp']

# %%
double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)

# %%
summary = {
    "total_pairs": pair_df.shape[0],
"single_coin_pairs": single_piar_df.shape[0],
"double_coin_piars": double_coin_pair_df.shape[0],
"after_switching_coins_total_double_coin_pairs": double_coin_pair_df.shape[0] * 2,
"total_pairs_in_sheet": double_coin_pair_df.shape[0] * 2 + single_piar_df.shape[0]
}

# %%
summary

# %%
pair_df = double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
pair_df = single_piar_df.append(pair_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)

# %%
pair_df

# %%
pair_df['dex'] = pair_df['where']
pair_df['date'] = date 
del pair_df['where']

# %%
# pair_df.to_csv('yield_data_2021_06_21.csv')

# %%
pair_df['dex'].unique().tolist()

# %%
pair_df[pair_df['pair1'] == 'ETH']

# %%
pair_df['apr'].unique().tolist()

# %%
pair_df

# %%
pair_df[pair_df['pair1'] == 'CRV']

# %%
pair_df = pair_df.drop_duplicates()

# %% [markdown]
# ## Farm Risk

# %%
farm_grades = pd.read_csv('~/notebooks/vfat_tool_data/Yield_grades.csv')
farm_grades

# %%
farm_grades = farm_grades[['Website', 'Network', 'Grade']]
farm_grades = farm_grades.append({'Website': 'Sushi', 'Network': 'ETH', 'Grade': 'A'}, ignore_index=True)
farm_grades = farm_grades.append({'Website': 'https://app.sushi.com/farms/', 'Network': 'ETH', 'Grade': 'A'}, ignore_index=True)
farm_grades = farm_grades.append({'Website': 'Uniswap', 'Network': 'ETH', 'Grade': 'A'}, ignore_index=True)

# %%
farm_grades

# %%
pairs_farm_risk_df = pd.merge(pair_df, farm_grades, how='left', left_on=['dex', 'network'], right_on=['Website', 'Network'])
pairs_farm_risk_df.to_csv('farm_risk_yield_data_2021_07_09.csv')
pairs_farm_risk_df

# %%
pairs_farm_risk_df[(pairs_farm_risk_df['Website'].isna()) & (pairs_farm_risk_df['type_of_agriculture'] == 'POOL')]

# %%
unmapped_dexs_df = pairs_farm_risk_df[pairs_farm_risk_df['Website'].isna()][['dex', 'network']].reset_index(drop=True)
unmapped_dexs_df = unmapped_dexs_df.drop_duplicates()
if unmapped_dexs_df.shape[0] > 1:
    unmapped_dexs_df.to_csv('unmapped_dex.csv')
unmapped_dexs_df
