# %%
import re
import os
import pandas as pd
import numpy as np
import traceback2
from datetime import datetime
import pymysql
import numpy as np

where_map = {}
# pairs regexp: "\[([a-zA-z0-9$\-+τ\.%]*)\]-", "-\[([a-zA-z0-9$\-+τ]*)\]",  or ( c in ['τ'] for c in s)
ignorable_files = ["farm_risk_yield_data_2021_07_01.csv", "Farm_risk_07_01.csv", "yield_data_2021_07_01.csv","Alternate.csv","vfat_tools_data_2021_07_01.csv",'.ipynb_checkpoints', "crash_parser.ipynb", "yieldFarm_07_01.csv", "Alternate Yields 7-1.xlsx", "Alternate Yields 7-1.csv"]

# %%
def __connect__():
    db_user = 'coin'
    db_password = 'dragonstone#123'
    db_name = 'master_data'
    db_host = 'localhost'
    return pymysql.connect(
        unix_socket=None,
        host=db_host,
        user=db_user,
        password=db_password,
        db=db_name,
        charset='latin1',
        cursorclass=pymysql.cursors.DictCursor)


def get_cursor(connection):
    if connection is None:
        connection = __connect__()
    connection.ping(reconnect=True)
    return connection.cursor()

# %%
def get_raydium_data(date):
    sql = f'select * from raydium_farm_pool_data where timestamp_dt = FROM_UNIXTIME({date});'
    data = pd.read_sql_query(sql, __connect__())
    data['apr'] = data['pool_rate']
    data['network'] = 'SOL'
    data['type_of_agriculture'] = data['farm_payment'].apply(lambda x : 'FARM' if x is not None else 'POOL')
    return data[['pair1', 'pair2', 'apr', 'tvl', 'where', 'network', 'type_of_agriculture']]

def get_liquidityfolio_pool_data(date):
    sql = f'select * from liquidityfolio_pool where timestamp_dt = FROM_UNIXTIME({date}) and `where` != "balancer";'
    data = pd.read_sql_query(sql, __connect__())
    data['apr'] = data['pool_rate'] * 100 * 12
    data['tvl'] = data['tvl'] * 1000
    data['type_of_agriculture'] = data['farm_payment'].apply(lambda x : 'FARM' if x is not None else 'POOL')
    data['network'] = 'ETH'
    return data[['pair1', 'pair2', 'apr', 'tvl', 'where', 'network', 'type_of_agriculture']]

# %%
date = datetime(2021, 6, 28)
dt = date.timestamp()

# %%
df = get_raydium_data(dt)
df = df.append(get_liquidityfolio_pool_data(dt))
df[df['where'] == 'Sushi']
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, apr, tvl, where, network, type_of_agriculture]
# Index: []

# %%
sm = {
    "WBTC" : "BTC",
    "WETH" : "ETH",
    "WBNB" : "BNB",
    "WFTM" : "FTM",
    "WAVAX" : "AVAX",
    "cvxCRV" : "CRV"
}

# %%
dex_map = {
    "SUSHI" : "https://app.sushi.com"
    
}

# %%
def get_alternate_pairs(line):
    spl = line.split("/")
    print(spl)
    if spl and len(spl) > 1:
        pair1 = spl[0].strip()
        print(pair1)
        pair2 = spl[1].strip()
        print(pair2)
        pair2 = pair2[0 : pair2.index(' ')]
        return [pair1, pair2]
    return None

# %%
def pair1(line):
#     print(line)
    try:
        is_3_pairs = line.split("]-[")
        if len(is_3_pairs) > 2:
            return None
        s_index = line.index("[") + 1
        s = line[s_index: line.index("]", s_index)]
        if all(ord(c) < 128 for c in s):
            return s
        else:
            print(line)
            return None
    except:
        return ''

def pair2(line):
#     print(line)
    s_index = line.index("-[") + 2
    s = line[s_index: line.index("]", s_index)]
#     print(s)
    if all(ord(c) < 128 for c in s):
        return s
    else:
        print(line)
        return ''

# %%
def apr(line):
    apr = "Year [0-9\,\.]+\%"
    x = re.findall(apr, line)
    return x[0].replace("Year ", "").replace("%", "").strip() if len(x) else 0

# %%
def tvl(line):
    tvl = "TVL: \$[0-9\.\,]+"
    x = re.findall(tvl, line)
    return x[0].replace("TVL: $", "").replace("%", "").replace(",","").strip()

# %%
def where(line):
    if 'INFO' in line:
        return line.replace("INFO", "").replace('\n', '').replace(":", "").replace("//", "://").replace('*', '').strip()
    return None

# %%
def get_single_pair(line):
    exp = "\d* *.*Price:"
    x = re.findall(exp, line)
    if not len(x) or "TVL:" in line:
#         print(">>>>>>>>>>>",line)
        return
    pair = x[0].replace(" Price:", "")
    return pair[pair.rindex(" "):].strip() if " " in pair else pair

def get_single_tvl(line):
    exp = "\([0-9\,\.$]+\)"
    x = re.findall(exp, line)
    return x[0].replace("(", "").replace(")", "").replace("$", "").replace(",","").strip()

# %%
tvl("[WBTC]-[WAVAX] PGL [+] [-] [<=>] Price: $160,706,376.77 TVL: $12,218,373.64\n")
# Out:
# '12218373.64'

# %%
def is_end_of_block(line):
#     print(line, line == "" or len(re.findall("INFO[ ]+: ", line)))
    return line.strip() == "" or len(re.findall("INFO[ ]+: ", line)) or "******" in line

def read_block(lines, start_index):
    block = []
#     print("Block Start Line No.: ", start_index + 1)
    while start_index < len(lines):
        line = lines[start_index]
        start_index = start_index + 1
        if not is_end_of_block(line):
            block.append(line.strip())
        else:
            break
    return [block, start_index]

def read_blocks_from_files(file):
    f = open(file)
    lines = f.readlines()
    blocks = []
    block = []
    block_start_line_no = []
    line_no = 0
    start_index = 0
    while start_index < len(lines):
        line = lines[start_index]
        if not is_end_of_block(lines[start_index]):
            block_and_index = read_block(lines, start_index)
#             print(block_and_index[0])
            if block_and_index is not None:
                block_start_line_no.append(start_index + 1)
                start_index = block_and_index[1]
                blocks.append(block_and_index[0])
            else:
                start_index = start_index + 1
        elif len(re.findall("INFO[ ]+: ", line)):
            block_start_line_no.append(start_index + 1)
            blocks.append([line])
            start_index = start_index + 1
        else:
            start_index = start_index + 1
    return [blocks, block_start_line_no]

def read_blocks_from_files_as(file):
    f = open(file)
    lines = f.readlines()
    blocks = []
    block = []
    block_start_line_no = []
    line_no = 0
    for line in lines:
        line_no = line_no + 1
        line = line.strip()
        if line == "" or len(re.findall("INFO[ ]+: ", line)):
            blocks.append(block)
            block_start_line_no.append(line_no)
            if len(line):
                blocks.append([line])
                block_start_line_no.append(line_no + 1)
            block = []
        else:
            block.append(line)
            
    blocks.append(block)
    return [blocks, block_start_line_no]

def get_pair_info_from_block(block, wh, network):
    tvl_index = 0
    if network == 'BSC':
        tvl_index = 3
    if len(block) == 1:
        if 'INFO' in block[0]:
            return [where(block[0])]
        else:
            return [wh] if len(wh) else None
    if len(block) and pair1(block[0]) and not get_single_pair(block[0]):
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        return [pair1(block[0]), pair2(block[0]), get_single_tvl(block[tvl_index]) if tvl_index > 0 else tvl(block[tvl_index]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
    elif len(block) > 2 and get_single_pair(block[0]):
#         print('singel')
        if network == 'BSC':
            tvl_index = 1
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        return [get_single_pair(block[0]), "", get_single_tvl(block[1]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
    elif len(block) > 2 and get_alternate_pairs(block[0]):
        print(get_alternate_pairs(block[0]))
        tvl_index = 0
        for index in range(1, len(block)):
            if 'Staked: ' in block[index]:
                tvl_index = index
                break
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        pairs = get_alternate_pairs(block[0])
        return [pairs[0], pairs[1], get_single_tvl(block[tvl_index]), apr(block[apr_index]), where_map[wh] if wh in where_map else wh, network]
    return None


def get_pairs(blocks, network, block_start_line_no):
    where = ""
    pairs = []
    index = -1
    for block in blocks:
#         print('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
        index = index + 1
        try:
            pair = get_pair_info_from_block(block, where, network)
            if pair == None:
                print('no Pair....\n',block)
                print("Block Start Line No.: ", block_start_line_no[index] if index < len(block_start_line_no) else -1)
#             if len(where) == 0 and pair and len(pair) > 2:
#                 print(block, network)
            if pair is not None and len(pair) > 0:
                if len(pair) == 1 and pair[0] and len(pair[0]):
                    where = pair[0]
                else:
                    pairs.append(pair)
        except Exception as e:
            print("Exception", traceback2.format_exc())
            print(block[0])
    return pairs

# %%
block = [['334 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,875,027,502.08 TVL: $15,943,098.17', 'τBTC Price: $26,860.23', 'BTCB Price: $32,310.00', 'Staked: 0.0008 Cake-LP ($1,494,384.52)', 'AUTO Per Week: 3.22 ($3,410.84)', 'APR: Day 0.03% Week 0.23% Year 11.87%', 'You are staking 0.00 [τBTC]-[BTCB] Cake LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [τBTC]-[BTCB] Cake LP', 'Unstake 0.00 [τBTC]-[BTCB] Cake LP', 'Claim 0.00 AUTO ($0.00)', 'Staking or unstaking also claims rewards.']]
get_pairs(block, "AVAX", [1])
# Out:
# 334 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,875,027,502.08 TVL: $15,943,098.17
# ['334 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,875,027,502.08 TVL: $15,943,098.17']
# no Pair....
#  ['334 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,875,027,502.08 TVL: $15,943,098.17', 'τBTC Price: $26,860.23', 'BTCB Price: $32,310.00', 'Staked: 0.0008 Cake-LP ($1,494,384.52)', 'AUTO Per Week: 3.22 ($3,410.84)', 'APR: Day 0.03% Week 0.23% Year 11.87%', 'You are staking 0.00 [τBTC]-[BTCB] Cake LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [τBTC]-[BTCB] Cake LP', 'Unstake 0.00 [τBTC]-[BTCB] Cake LP', 'Claim 0.00 AUTO ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1
# []

# %%
data_dir = './'
def conver_files_to_one_df(data_dir):
    all_pairs = []
    files = os.listdir(data_dir)
    for file_name in files:
        if file_name in ignorable_files:
            continue
        network = file_name[0:file_name.index(" ")]
        if 'Alternate' == network:
            network = 'ETH'
#         if 'MATIC' != network:
#             continue
        print(file_name)
        blocks = read_blocks_from_files(f"{data_dir}{file_name}")
        block_start_line_no = blocks[1]
        blocks = blocks[0]
        pairs = get_pairs(blocks, network, block_start_line_no)
        all_pairs.extend(pairs)
    return all_pairs

# %%
pairs = conver_files_to_one_df(data_dir)
# Out:
# MATIC Yields 7:1.uu
# no Pair....
#  ['MATIC Yields 7/1']
# Block Start Line No.:  1
# 0 - [USDC]-[🚜] Uni LP [+] [-] [<=>] Price: $913,397.04 TVL: $2,979.76
# 2 - [WMATIC]-[🚜] Uni LP [+] [-] [<=>] Price: $0.66 TVL: $14,137.51
# 9 - [🚜]-[miMATIC] Uni LP [+] [-] [<=>] Price: $0.59 TVL: $488.89
# ['9 - [🚜]-[miMATIC] Uni LP [+] [-] [<=>] Price: $0.59 TVL: $488.89']
# no Pair....
#  ['9 - [🚜]-[miMATIC] Uni LP [+] [-] [<=>] Price: $0.59 TVL: $488.89', '🚜 Price: $0.09', 'miMATIC Price: $1.00', 'Staked: 825.2039 UNI-V2 ($488.87)', 'HONEST Per Week: 461.88 ($40.06)', 'APR: Day 1.17% Week 8.19% Year 426.06%', 'You are staking 0.00 [🚜]-[miMATIC] Uni LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [🚜]-[miMATIC] Uni LP', 'Unstake 0.00 [🚜]-[miMATIC] Uni LP', 'Claim 0.00 HONEST ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  14875
# ['9 - vaultWETHWBTC Price: $0.00 TVL: $0.00']
# no Pair....
#  ['9 - vaultWETHWBTC Price: $0.00 TVL: $0.00', 'Staked: 0.0006 vaultWETHWBTC ($0.00)', 'HOPE Per Week: 53030.30 ($4,793.51)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultWETHWBTC ($0.00), NaN% of the pool.', 'Stake 0.00 vaultWETHWBTC', 'Unstake 0.00 vaultWETHWBTC', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15695
# ['10 - vaultWETHWBTC Price: $0.00 TVL: $0.00']
# no Pair....
#  ['10 - vaultWETHWBTC Price: $0.00 TVL: $0.00', 'Staked: 0.0000 vaultWETHWBTC ($0.00)', 'HOPE Per Week: 53030.30 ($4,793.51)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultWETHWBTC ($0.00), NaN% of the pool.', 'Stake 0.00 vaultWETHWBTC', 'Unstake 0.00 vaultWETHWBTC', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15705
# ['15 - vaultKNCWETH Price: $0.00 TVL: $0.00']
# no Pair....
#  ['15 - vaultKNCWETH Price: $0.00 TVL: $0.00', 'Staked: 2869.5251 vaultKNCWETH ($0.00)', 'HOPE Per Week: 21212.12 ($1,917.41)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultKNCWETH ($0.00), NaN% of the pool.', 'Stake 0.00 vaultKNCWETH', 'Unstake 0.00 vaultKNCWETH', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15739
# ['16 - vaultUSDCWETH Price: $0.00 TVL: $0.00']
# no Pair....
#  ['16 - vaultUSDCWETH Price: $0.00 TVL: $0.00', 'Staked: 0.0076 vaultUSDCWETH ($0.00)', 'HOPE Per Week: 21212.12 ($1,917.41)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultUSDCWETH ($0.00), NaN% of the pool.', 'Stake 0.00 vaultUSDCWETH', 'Unstake 0.00 vaultUSDCWETH', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15749
# ['17 - vaultUSDCDAI Price: $0.00 TVL: $0.00']
# no Pair....
#  ['17 - vaultUSDCDAI Price: $0.00 TVL: $0.00', 'Staked: 0.2882 vaultUSDCDAI ($0.00)', 'HOPE Per Week: 21212.12 ($1,917.41)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultUSDCDAI ($0.00), NaN% of the pool.', 'Stake 0.00 vaultUSDCDAI', 'Unstake 0.00 vaultUSDCDAI', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15759
# ['18 - vaultUSDCUSDT Price: $0.00 TVL: $0.00']
# no Pair....
#  ['18 - vaultUSDCUSDT Price: $0.00 TVL: $0.00', 'Staked: 0.0000 vaultUSDCUSDT ($0.00)', 'HOPE Per Week: 21212.12 ($1,917.41)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultUSDCUSDT ($0.00), NaN% of the pool.', 'Stake 0.00 vaultUSDCUSDT', 'Unstake 0.00 vaultUSDCUSDT', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15769
# ['19 - vaultWMATICKNC Price: $0.00 TVL: $0.00']
# no Pair....
#  ['19 - vaultWMATICKNC Price: $0.00 TVL: $0.00', 'Staked: 63313.6353 vaultWMATICKNC ($0.00)', 'HOPE Per Week: 21212.12 ($1,917.41)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultWMATICKNC ($0.00), NaN% of the pool.', 'Stake 0.00 vaultWMATICKNC', 'Unstake 0.00 vaultWMATICKNC', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15779
# ['20 - vaultWMATICDAI Price: $0.00 TVL: $0.00']
# no Pair....
#  ['20 - vaultWMATICDAI Price: $0.00 TVL: $0.00', 'Staked: 101387.0252 vaultWMATICDAI ($0.00)', 'HOPE Per Week: 21212.12 ($1,917.41)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultWMATICDAI ($0.00), NaN% of the pool.', 'Stake 0.00 vaultWMATICDAI', 'Unstake 0.00 vaultWMATICDAI', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15789
# 0 - [🌾]-[WETH] SLP [+] [-] [<=>] Price: $169.53 TVL: $322,620.94
# ['0 - [🌾]-[WETH] SLP [+] [-] [<=>] Price: $169.53 TVL: $322,620.94']
# no Pair....
#  ['0 - [🌾]-[WETH] SLP [+] [-] [<=>] Price: $169.53 TVL: $322,620.94', '🌾 Price: $3.17', 'WETH Price: $2,118.32', 'Staked: 1675.4567 SLP ($284,038.31)', '🌾 Per Week: 95206.61 ($301,795.08)', 'APR: Day 15.18% Week 106.25% Year 5525.08%', 'You are staking 0.00 [🌾]-[WETH] SLP ($0.00), 0.00% of the pool.', 'Stake 0.00 [🌾]-[WETH] SLP', 'Unstake 0.00 [🌾]-[WETH] SLP & Claim 0.00 🌾 ($0.00) - Fee 4%', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  16947
# ['pDAI Price: $1.00 TVL: $3,098,669.32']
# no Pair....
#  ['pDAI Price: $1.00 TVL: $3,098,669.32', 'Staked: 3083688.4920 pDAI ($3,090,017.79)', 'PICKLE Per Week: 581.54 ($4,989.60)', 'MATIC Per Week: 1425.00 ($1,539.00)', 'APR PICKLE: Day 0.02% Week 0.16% Year 8.40%', 'APR MATIC: Day 0.01% Week 0.05% Year 2.59%', 'Total Per Week: $6,528.60', 'Total APR: Day 0.0302% Week 0.21% Year 10.99%', 'You are staking 0.00 pDAI ($0.00), 0.00% of the pool.']
# Block Start Line No.:  17794
# BSC Yields 7:1.uu
# no Pair....
#  ['BSC Yields 7/1']
# Block Start Line No.:  1
# 361 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,430,136,560.61 TVL: $7,821,961.69
# ['361 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,430,136,560.61 TVL: $7,821,961.69']
# no Pair....
#  ['361 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,430,136,560.61 TVL: $7,821,961.69', 'τBTC Price: $15,048.51', 'BTCB Price: $33,528.00', 'Staked: 0.0054 Cake-LP ($7,744,435.49)', 'CAKE Per Week: 5501.21 ($71,075.60)', 'APR: Day 0.13% Week 0.92% Year 47.72%', 'You are staking 0.00 [τBTC]-[BTCB] Cake LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [τBTC]-[BTCB] Cake LP', 'Unstake 0.00 [τBTC]-[BTCB] Cake LP', 'Claim 0.00 CAKE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1153
# 380 - [WBNB]-[τDOGE] Cake LP [+] [-] [<=>] Price: $1,330,423.04 TVL: $1,424,747.90
# 334 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,430,136,560.61 TVL: $7,821,961.69
# ['334 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,430,136,560.61 TVL: $7,821,961.69']
# no Pair....
#  ['334 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,430,136,560.61 TVL: $7,821,961.69', 'τBTC Price: $15,048.51', 'BTCB Price: $33,528.00', 'Staked: 0.0005 Cake-LP ($741,718.04)', 'AUTO Per Week: 3.23 ($2,730.83)', 'APR: Day 0.05% Week 0.37% Year 19.15%', 'You are staking 0.00 [τBTC]-[BTCB] Cake LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [τBTC]-[BTCB] Cake LP', 'Unstake 0.00 [τBTC]-[BTCB] Cake LP', 'Claim 0.00 AUTO ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  4053
# ['338 - beltBNB Price: $0.00 TVL: $0.00']
# no Pair....
#  ['338 - beltBNB Price: $0.00 TVL: $0.00', 'Staked: 181850.5966 beltBNB ($0.00)', 'AUTO Per Week: 64.51 ($54,616.50)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 AUTO ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  4101
# ['339 - beltBTC Price: $0.00 TVL: $0.00']
# no Pair....
#  ['339 - beltBTC Price: $0.00 TVL: $0.00', 'Staked: 2731.0170 beltBTC ($0.00)', 'AUTO Per Week: 64.51 ($54,616.50)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 AUTO ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  4111
# ['340 - beltETH Price: $0.00 TVL: $0.00']
# no Pair....
#  ['340 - beltETH Price: $0.00 TVL: $0.00', 'Staked: 31451.8772 beltETH ($0.00)', 'AUTO Per Week: 64.51 ($54,616.50)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 AUTO ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  4121
# ['Total Staked: $413,483,388.94']
# no Pair....
#  ['Total Staked: $413,483,388.94', '[WAULT]-[WBNB] Cake LP [+] [-] [<=>] Price: $253.29 TVL: $469,071.58', 'WAULT Price: $43.12', 'WBNB Price: $289.71', 'Staked: 272.2288 Cake-LP ($68,954.10)', 'WAULT Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 [WAULT]-[WBNB] Cake LP ($0.00), 0.00% of the pool.']
# Block Start Line No.:  8911
# ['1 - acsCake Price: $41.33 TVL: $46,480,035.14']
# no Pair....
#  ['1 - acsCake Price: $41.33 TVL: $46,480,035.14', 'Staked: 1297.1077 acsCake ($53,609.76)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsCake ($0.00), 0.00% of the pool.', 'Stake 0.00 acsCake', 'Unstake 0.00 acsCake', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  8975
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 2 - Wrapped [BTCB]-[WBNB] Cake LP Price: $7,734.95 TVL: $65.87
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 3 - Wrapped [ETH]-[WBNB] Cake LP Price: $2,005.48 TVL: $6,500.51
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 4 - Wrapped [WBNB]-[XVS] Cake LP Price: $273.76 TVL: $1,781.53
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 5 - Wrapped [SXP]-[WBNB] Cake LP Price: $68.04 TVL: $31,391.72
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 6 - Wrapped [WBNB]-[BUSD] Cake LP Price: $59.33 TVL: $490,901.34
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 7 - Wrapped [Cake]-[WBNB] Cake LP Price: $288.38 TVL: $14,894.23
# ['9 - acsBUSD Price: $1.15 TVL: $6,713,262.48']
# no Pair....
#  ['9 - acsBUSD Price: $1.15 TVL: $6,713,262.48', 'Staked: 112158.6662 acsBUSD ($129,361.92)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsBUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 acsBUSD', 'Unstake 0.00 acsBUSD', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9045
# ['10 - acsWBNB Price: $323.89 TVL: $13,939,271.17']
# no Pair....
#  ['10 - acsWBNB Price: $323.89 TVL: $13,939,271.17', 'Staked: 252.3715 acsWBNB ($81,740.20)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsWBNB ($0.00), 0.00% of the pool.', 'Stake 0.00 acsWBNB', 'Unstake 0.00 acsWBNB', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9055
# ['11 - acsUSDT Price: $1.14 TVL: $4,866,268.39']
# no Pair....
#  ['11 - acsUSDT Price: $1.14 TVL: $4,866,268.39', 'Staked: 451.0413 acsUSDT ($515.45)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsUSDT ($0.00), 0.00% of the pool.', 'Stake 0.00 acsUSDT', 'Unstake 0.00 acsUSDT', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9065
# ['12 - acsXVS Price: $21.86 TVL: $12,215,164.74']
# no Pair....
#  ['12 - acsXVS Price: $21.86 TVL: $12,215,164.74', 'Staked: 1701.8300 acsXVS ($37,202.17)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsXVS ($0.00), 0.00% of the pool.', 'Stake 0.00 acsXVS', 'Unstake 0.00 acsXVS', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9075
# ['13 - acsUSDC Price: $1.14 TVL: $7,236,352.89']
# no Pair....
#  ['13 - acsUSDC Price: $1.14 TVL: $7,236,352.89', 'Staked: 6058.9964 acsUSDC ($6,913.55)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsUSDC ($0.00), 0.00% of the pool.', 'Stake 0.00 acsUSDC', 'Unstake 0.00 acsUSDC', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9085
# ['14 - acsSXP Price: $2.15 TVL: $16,510,424.49']
# no Pair....
#  ['14 - acsSXP Price: $2.15 TVL: $16,510,424.49', 'Staked: 3624.1778 acsSXP ($7,795.34)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsSXP ($0.00), 0.00% of the pool.', 'Stake 0.00 acsSXP', 'Unstake 0.00 acsSXP', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9095
# ['15 - acsBTCB Price: $36,047.17 TVL: $16,357,275.24']
# no Pair....
#  ['15 - acsBTCB Price: $36,047.17 TVL: $16,357,275.24', 'Staked: 0.0913 acsBTCB ($3,289.59)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsBTCB ($0.00), 0.00% of the pool.', 'Stake 0.00 acsBTCB', 'Unstake 0.00 acsBTCB', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9105
# ['16 - acsETH Price: $2,258.56 TVL: $11,548,215.58']
# no Pair....
#  ['16 - acsETH Price: $2,258.56 TVL: $11,548,215.58', 'Staked: 1957.3555 acsETH ($4,420,800.01)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsETH ($0.00), 0.00% of the pool.', 'Stake 0.00 acsETH', 'Unstake 0.00 acsETH', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9115
# ['17 - acsVAI Price: $1.00 TVL: $335,968.52']
# no Pair....
#  ['17 - acsVAI Price: $1.00 TVL: $335,968.52', 'Staked: 6945.7167 acsVAI ($6,927.39)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsVAI ($0.00), 0.00% of the pool.', 'Stake 0.00 acsVAI', 'Unstake 0.00 acsVAI', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9125
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 18 - Wrapped [TWT]-[WBNB] Cake LP Price: $30.96 TVL: $110,836.83
# ['19 - acsDAI Price: $1.07 TVL: $245,899.57']
# no Pair....
#  ['19 - acsDAI Price: $1.07 TVL: $245,899.57', 'Staked: 3198.3976 acsDAI ($3,430.06)', 'ACS Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 acsDAI ($0.00), 0.00% of the pool.', 'Stake 0.00 acsDAI', 'Unstake 0.00 acsDAI', 'Claim 0.00 ACS ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  9145
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 20 - Wrapped [BTCST]-[WBNB] Cake LP Price: $897.98 TVL: $2,760.58
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 21 - Wrapped [LTC]-[WBNB] Cake LP Price: $502.00 TVL: $12,133.47
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 23 - Wrapped [ADA]-[WBNB] Cake LP Price: $49.09 TVL: $21,001.84
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 24 - Wrapped [YFI]-[WBNB] Cake LP Price: $7,665.35 TVL: $1,483.34
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 25 - Wrapped [ETH]-[BETH] Cake LP Price: $4,326.13 TVL: $1,955.37
# ['beltBTC Price: $0.00 TVL: $0.00']
# no Pair....
#  ['beltBTC Price: $0.00 TVL: $0.00', 'Staked: 5401.2572 beltBTC ($0.00)', 'BELT Per Week: 12096.00 ($154,862.31)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 BELT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  11013
# ['beltETH Price: $0.00 TVL: $0.00']
# no Pair....
#  ['beltETH Price: $0.00 TVL: $0.00', 'Staked: 72110.7813 beltETH ($0.00)', 'BELT Per Week: 6048.00 ($77,431.15)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 BELT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  11023
# ['beltBNB Price: $0.00 TVL: $0.00']
# no Pair....
#  ['beltBNB Price: $0.00 TVL: $0.00', 'Staked: 281243.9763 beltBNB ($0.00)', 'BELT Per Week: 6048.00 ($77,431.15)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 BELT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  11033
# ['beltBNB Price: $0.00 TVL: $0.00']
# no Pair....
#  ['beltBNB Price: $0.00 TVL: $0.00', 'Staked: 2664.7124 beltBNB ($0.00)', 'SWAMP Per Week: 156.98 ($1,340.63)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 SWAMP ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  14631
# ['beltBTC Price: $0.00 TVL: $0.00']
# no Pair....
#  ['beltBTC Price: $0.00 TVL: $0.00', 'Staked: 28.3573 beltBTC ($0.00)', 'SWAMP Per Week: 156.98 ($1,340.63)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 SWAMP ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  14641
# ['beltETH Price: $0.00 TVL: $0.00']
# no Pair....
#  ['beltETH Price: $0.00 TVL: $0.00', 'Staked: 439.5913 beltETH ($0.00)', 'SWAMP Per Week: 156.98 ($1,340.63)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 SWAMP ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  14651
# [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,433,037,100.05 TVL: $7,837,825.85
# ['[τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,433,037,100.05 TVL: $7,837,825.85']
# no Pair....
#  ['[τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,433,037,100.05 TVL: $7,837,825.85', 'τBTC Price: $15,079.03', 'BTCB Price: $33,596.00', 'Staked: 0.0000 Cake-LP ($61,036.91)', 'SWAMP Per Week: 31.40 ($268.13)', 'APR: Day 0.06% Week 0.44% Year 22.84%', 'You are staking 0.00 [τBTC]-[BTCB] Cake LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [τBTC]-[BTCB] Cake LP', 'Unstake 0.00 [τBTC]-[BTCB] Cake LP', 'Claim 0.00 SWAMP ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15095
# ['0 - fWBNB Price: $296.81 TVL: $850,711.55']
# no Pair....
#  ['0 - fWBNB Price: $296.81 TVL: $850,711.55', 'Staked: 2730.3241 fWBNB ($810,398.52)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fWBNB ($0.00), 0.00% of the pool.', 'Stake 0.00 fWBNB', 'Unstake 0.00 fWBNB', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28677
# ['1 - fUSDT Price: $1.02 TVL: $1,930,825.35']
# no Pair....
#  ['1 - fUSDT Price: $1.02 TVL: $1,930,825.35', 'Staked: 1853466.1318 fUSDT ($1,889,633.48)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fUSDT ($0.00), 0.00% of the pool.', 'Stake 0.00 fUSDT', 'Unstake 0.00 fUSDT', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28687
# ['2 - fUSDC Price: $1.03 TVL: $183,686.36']
# no Pair....
#  ['2 - fUSDC Price: $1.03 TVL: $183,686.36', 'Staked: 175000.5201 fUSDC ($180,174.03)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fUSDC ($0.00), 0.00% of the pool.', 'Stake 0.00 fUSDC', 'Unstake 0.00 fUSDC', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28697
# ['3 - fBUSD Price: $1.03 TVL: $784,191.43']
# no Pair....
#  ['3 - fBUSD Price: $1.03 TVL: $784,191.43', 'Staked: 695730.5022 fBUSD ($716,662.78)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fBUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 fBUSD', 'Unstake 0.00 fBUSD', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28707
# ['4 - fDAI Price: $1.01 TVL: $105,827.66']
# no Pair....
#  ['4 - fDAI Price: $1.01 TVL: $105,827.66', 'Staked: 103569.2297 fDAI ($104,681.82)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fDAI ($0.00), 0.00% of the pool.', 'Stake 0.00 fDAI', 'Unstake 0.00 fDAI', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28717
# ['5 - fBTCB Price: $34,005.92 TVL: $3,636,157.51']
# no Pair....
#  ['5 - fBTCB Price: $34,005.92 TVL: $3,636,157.51', 'Staked: 106.3493 fBTCB ($3,616,506.73)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fBTCB ($0.00), 0.00% of the pool.', 'Stake 0.00 fBTCB', 'Unstake 0.00 fBTCB', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28727
# ['6 - fETH Price: $2,155.77 TVL: $606,163.91']
# no Pair....
#  ['6 - fETH Price: $2,155.77 TVL: $606,163.91', 'Staked: 265.7449 fETH ($572,885.68)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fETH ($0.00), 0.00% of the pool.', 'Stake 0.00 fETH', 'Unstake 0.00 fETH', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28737
# ['13 - f3EPS Price: $1.04 TVL: $1,170,884.21']
# no Pair....
#  ['13 - f3EPS Price: $1.04 TVL: $1,170,884.21', 'Staked: 1097431.6401 f3EPS ($1,139,216.85)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 f3EPS ($0.00), 0.00% of the pool.', 'Stake 0.00 f3EPS', 'Unstake 0.00 f3EPS', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28757
# ['14 - fCake Price: $15.88 TVL: $2,080,111.83']
# no Pair....
#  ['14 - fCake Price: $15.88 TVL: $2,080,111.83', 'Staked: 97057.9398 fCake ($1,540,954.68)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fCake ($0.00), 0.00% of the pool.', 'Stake 0.00 fCake', 'Unstake 0.00 fCake', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28767
# ['16 - fHMDX Price: $0.00 TVL: $0.00']
# no Pair....
#  ['16 - fHMDX Price: $0.00 TVL: $0.00', 'Staked: 3500.5629 fHMDX ($0.00)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fHMDX ($0.00), NaN% of the pool.', 'Stake 0.00 fHMDX', 'Unstake 0.00 fHMDX', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28777
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 21 - Wrapped [USDT]-[WBNB] Uni LP Price: $37.07 TVL: $19,800.97
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 22 - Wrapped [USDT]-[BTCB] Uni LP Price: $386.10 TVL: $38,940.20
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 23 - Wrapped [ETH]-[USDT] Uni LP Price: $98.67 TVL: $33,534.80
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 24 - Wrapped [USDT]-[BUSD] Uni LP Price: $2.06 TVL: $57,171.63
# ['26 - fBUNNY Price: $19.29 TVL: $95,490.27']
# no Pair....
#  ['26 - fBUNNY Price: $19.29 TVL: $95,490.27', 'Staked: 3865.4157 fBUNNY ($74,553.38)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fBUNNY ($0.00), 0.00% of the pool.', 'Stake 0.00 fBUNNY', 'Unstake 0.00 fBUNNY', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28877
# ['27 - f4Belt Price: $0.00 TVL: $0.00']
# no Pair....
#  ['27 - f4Belt Price: $0.00 TVL: $0.00', 'Staked: 623117.8613 f4Belt ($0.00)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 f4Belt ($0.00), NaN% of the pool.', 'Stake 0.00 f4Belt', 'Unstake 0.00 f4Belt', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  28887
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 28 - Wrapped [Cake]-[WBNB] Cake LP Price: $136.05 TVL: $323,373.30
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 29 - Wrapped [WBNB]-[BUSD] Cake LP Price: $39.37 TVL: $35,321.44
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 30 - Wrapped [BTCB]-[WBNB] Cake LP Price: $6,627.11 TVL: $55,297.26
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 31 - Wrapped [BUSD]-[TPT] Cake LP Price: $3,632,295.83 TVL: $43,121.64
# ['48 - beltBNB Price: $0.00 TVL: $0.00']
# no Pair....
#  ['48 - beltBNB Price: $0.00 TVL: $0.00', 'Staked: 10.2219 beltBNB ($0.00)', 'aDGNZ Per Week: 52.88 ($11.41)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 aDGNZ ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  35823
# ['49 - beltBTC Price: $0.00 TVL: $0.00']
# no Pair....
#  ['49 - beltBTC Price: $0.00 TVL: $0.00', 'Staked: 0.2084 beltBTC ($0.00)', 'aDGNZ Per Week: 39.66 ($8.56)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 aDGNZ ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  35833
# ['50 - beltETH Price: $0.00 TVL: $0.00']
# no Pair....
#  ['50 - beltETH Price: $0.00 TVL: $0.00', 'Staked: 3.6292 beltETH ($0.00)', 'aDGNZ Per Week: 39.66 ($8.56)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 aDGNZ ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  35843
# ['6 - beltBNB Price: $0.00 TVL: $0.00']
# no Pair....
#  ['6 - beltBNB Price: $0.00 TVL: $0.00', 'Staked: 0.0000 beltBNB ($0.00)', 'AQUA Per Week: 38.46 ($5,595.83)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 AQUA ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  37453
# ['7 - beltBTC Price: $0.00 TVL: $0.00']
# no Pair....
#  ['7 - beltBTC Price: $0.00 TVL: $0.00', 'Staked: 0.0000 beltBTC ($0.00)', 'AQUA Per Week: 38.46 ($5,595.83)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 AQUA ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  37463
# ['8 - beltETH Price: $0.00 TVL: $0.00']
# no Pair....
#  ['8 - beltETH Price: $0.00 TVL: $0.00', 'Staked: 0.0000 beltETH ($0.00)', 'AQUA Per Week: 38.46 ($5,595.83)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 AQUA ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  37473
# 22 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,444,681,912.77 TVL: $7,901,515.76
# ['22 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,444,681,912.77 TVL: $7,901,515.76']
# no Pair....
#  ['22 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,444,681,912.77 TVL: $7,901,515.76', 'τBTC Price: $15,201.56', 'BTCB Price: $33,869.00', 'Staked: 0.0000 Cake-LP ($15.56)', 'ELXR Per Week: 2473.62 ($13.36)', 'APR: Day 12.26% Week 85.82% Year 4462.85%', 'You are staking 0.00 [τBTC]-[BTCB] Cake LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [τBTC]-[BTCB] Cake LP - Fee 4%', 'Unstake 0.00 [τBTC]-[BTCB] Cake LP', 'Claim 0.00 ELXR ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  39401
# ['3 - mBUSD Price: $1.04 TVL: $18,146.79']
# no Pair....
#  ['3 - mBUSD Price: $1.04 TVL: $18,146.79', 'Staked: 15435.1017 mBUSD ($16,059.83)', 'MM Per Week: 15.50 ($43.96)', 'APR: Day 0.04% Week 0.27% Year 14.23%', 'You are staking 0.00 mBUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 mBUSD', 'Unstake 0.00 mBUSD', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  40580
# ['4 - mEPS Price: $0.39 TVL: $3,456.17']
# no Pair....
#  ['4 - mEPS Price: $0.39 TVL: $3,456.17', 'Staked: 4080.1025 mEPS ($1,583.38)', 'MM Per Week: 15.50 ($43.96)', 'APR: Day 0.40% Week 2.78% Year 144.36%', 'You are staking 0.00 mEPS ($0.00), 0.00% of the pool.', 'Stake 0.00 mEPS', 'Unstake 0.00 mEPS', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  40590
# ['5 - mlowb Price: $0.00 TVL: $0.00']
# no Pair....
#  ['5 - mlowb Price: $0.00 TVL: $0.00', 'Staked: 224584809.0831 mlowb ($0.00)', 'MM Per Week: 15.50 ($43.96)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 mlowb ($0.00), NaN% of the pool.', 'Stake 0.00 mlowb', 'Unstake 0.00 mlowb', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  40600
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-13-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 6 - Wrapped [USDT]-[lowb] Cake LP Price: $0.03 TVL: $38,504.32
# [WBNB]-[τDOGE] Cake LP [+] [-] [<=>] Price: $1,339,444.08 TVL: $1,434,408.52
# 32 - [WBNB]-[τDOGE] Cake LP [+] [-] [<=>] Price: $1,339,398.13 TVL: $1,434,359.30
# no Pair....
#  ['Initialized 0xf42122af352885352e26e5a6253cb20ad9f727ec', 'Reading smart contracts...']
# Block Start Line No.:  58076
# ['4 - [USDC 33.%]-[BUSD 33.%]-[USDT 33.%] BPT Price: $29.95 TVL: $140,153.54']
# no Pair....
#  ['4 - [USDC 33.%]-[BUSD 33.%]-[USDT 33.%] BPT Price: $29.95 TVL: $140,153.54', 'USDC Price: $1.00', 'BUSD Price: $1.00', 'USDT Price: $1.00', 'Staked: 4679.9927 [USDC 33.%]-[BUSD 33.%]-[USDT 33.%] ($140,153.54)', 'YOGI Per Week: 16016.00 ($1,958.74)', 'APR: Day 0.20% Week 1.40% Year 72.67%', 'You are staking 0.00 [USDC 33.%]-[BUSD 33.%]-[USDT 33.%] ($0.00), 0.00% of the pool.', 'Stake 0.00 [USDC 33.%]-[BUSD 33.%]-[USDT 33.%]', 'Unstake 0.00 [USDC 33.%]-[BUSD 33.%]-[USDT 33.%]', 'Claim 0.00 YOGI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  58353
# ['beltBNB Price: $0.00 TVL: $0.00']
# no Pair....
#  ['beltBNB Price: $0.00 TVL: $0.00', 'Staked: 488.8881 beltBNB ($0.00)', 'LORY Per Week: 681.46 ($3,583.26)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 LORY ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  60817
# ['beltBTC Price: $0.00 TVL: $0.00']
# no Pair....
#  ['beltBTC Price: $0.00 TVL: $0.00', 'Staked: 4.5316 beltBTC ($0.00)', 'LORY Per Week: 681.46 ($3,583.26)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 LORY ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  60827
# ['beltETH Price: $0.00 TVL: $0.00']
# no Pair....
#  ['beltETH Price: $0.00 TVL: $0.00', 'Staked: 47.9811 beltETH ($0.00)', 'LORY Per Week: 681.46 ($3,583.26)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 LORY ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  60837
# AVAX Yields 7:1.uu
# no Pair....
#  ['AVAX Yields 7/1']
# Block Start Line No.:  1
# 33 - [WAVAX]-[🐆] Uni LP [+] [-] [<=>] Price: $26.38 TVL: $914.40
# ETH Yields 7:1.uu
# no Pair....
#  ['ETH Yields 7/1']
# Block Start Line No.:  1
# no Pair....
#  ['Initialized 0xf42122af352885352e26e5a6253cb20ad9f727ec', 'Reading smart contracts...']
# Block Start Line No.:  11
# ['Total Staked: $11,595,637.18']
# no Pair....
#  ['Total Staked: $11,595,637.18', '[DEGEN]-[WETH] Uni LP [+] [-] [<=>] Price: $184.46 TVL: $1,431,974.07', 'DEGEN Price: $3.15', 'WETH Price: $2,134.51', 'Staked: 1364.2877 UNI-V2 ($251,654.29)', 'NDX Per Week: 0.00 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.000000 [DEGEN]-[WETH] Uni LP $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [DEGEN]-[WETH] Uni LP', 'Unstake 0.000000 [DEGEN]-[WETH] Uni LP', 'Claim 0.000000 NDX ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1220
# ['1 - m3Crv Price: $1.08 TVL: $58,035.65']
# no Pair....
#  ['1 - m3Crv Price: $1.08 TVL: $58,035.65', 'Staked: 50783.0784 m3Crv ($54,825.88)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.04% Week 0.31% Year 15.87%', 'You are staking 0.00 m3Crv ($0.00), 0.00% of the pool.', 'Stake 0.00 m3Crv', 'Unstake 0.00 m3Crv', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1427
# ['3 - mcrvRenWBTC Price: $35,056.60 TVL: $44,694.49']
# no Pair....
#  ['3 - mcrvRenWBTC Price: $35,056.60 TVL: $44,694.49', 'Staked: 1.2501 mcrvRenWBTC ($43,824.23)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.05% Week 0.38% Year 19.85%', 'You are staking 0.00 mcrvRenWBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mcrvRenWBTC', 'Unstake 0.00 mcrvRenWBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1449
# ['4 - mDAI Price: $1.06 TVL: $148,989.73']
# no Pair....
#  ['4 - mDAI Price: $1.06 TVL: $148,989.73', 'Staked: 97845.7597 mDAI ($104,140.96)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.02% Week 0.16% Year 8.35%', 'You are staking 0.00 mDAI ($0.00), 0.00% of the pool.', 'Stake 0.00 mDAI', 'Unstake 0.00 mDAI', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1459
# ['5 - mUSDC Price: $1.08 TVL: $154,863.62']
# no Pair....
#  ['5 - mUSDC Price: $1.08 TVL: $154,863.62', 'Staked: 131587.0773 mUSDC ($142,250.13)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.02% Week 0.12% Year 6.12%', 'You are staking 0.00 mUSDC ($0.00), 0.00% of the pool.', 'Stake 0.00 mUSDC', 'Unstake 0.00 mUSDC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1469
# ['9 - mWETH Price: $2,179.82 TVL: $447,813.52']
# no Pair....
#  ['9 - mWETH Price: $2,179.82 TVL: $447,813.52', 'Staked: 188.6877 mWETH ($411,305.63)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.01% Week 0.04% Year 2.12%', 'You are staking 0.00 mWETH ($0.00), 0.00% of the pool.', 'Stake 0.00 mWETH', 'Unstake 0.00 mWETH', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1513
# ['10 - mUNI Price: $18.63 TVL: $234,119.38']
# no Pair....
#  ['10 - mUNI Price: $18.63 TVL: $234,119.38', 'Staked: 11535.8144 mUNI ($214,889.38)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.01% Week 0.08% Year 4.05%', 'You are staking 0.00 mUNI ($0.00), 0.00% of the pool.', 'Stake 0.00 mUNI', 'Unstake 0.00 mUNI', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1523
# ['11 - mWBTC Price: $34,296.34 TVL: $5,200,304.90']
# no Pair....
#  ['11 - mWBTC Price: $34,296.34 TVL: $5,200,304.90', 'Staked: 148.4591 mWBTC ($5,091,605.13)', 'MM Per Week: 303.12 ($836.62)', 'APR: Day 0.00% Week 0.02% Year 0.85%', 'You are staking 0.00 mWBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mWBTC', 'Unstake 0.00 mWBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1533
# ['12 - mLINK Price: $18.72 TVL: $245,656.06']
# no Pair....
#  ['12 - mLINK Price: $18.72 TVL: $245,656.06', 'Staked: 8126.7346 mLINK ($152,108.03)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.02% Week 0.11% Year 5.72%', 'You are staking 0.00 mLINK ($0.00), 0.00% of the pool.', 'Stake 0.00 mLINK', 'Unstake 0.00 mLINK', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1543
# ['13 - mZRX Price: $0.70 TVL: $109,197.37']
# no Pair....
#  ['13 - mZRX Price: $0.70 TVL: $109,197.37', 'Staked: 152977.0146 mZRX ($107,775.10)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.02% Week 0.16% Year 8.07%', 'You are staking 0.00 mZRX ($0.00), 0.00% of the pool.', 'Stake 0.00 mZRX', 'Unstake 0.00 mZRX', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1553
# ['14 - mALCX Price: $549.65 TVL: $225,649.47']
# no Pair....
#  ['14 - mALCX Price: $549.65 TVL: $225,649.47', 'Staked: 123.7239 mALCX ($68,005.42)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.04% Week 0.25% Year 12.79%', 'You are staking 0.00 mALCX ($0.00), 0.00% of the pool.', 'Stake 0.00 mALCX', 'Unstake 0.00 mALCX', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1563
# ['15 - malUSD Price: $1.11 TVL: $156,800.70']
# no Pair....
#  ['15 - malUSD Price: $1.11 TVL: $156,800.70', 'Staked: 128401.9612 malUSD ($141,892.63)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.02% Week 0.12% Year 6.13%', 'You are staking 0.00 malUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 malUSD', 'Unstake 0.00 malUSD', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1573
# ['16 - musdp3CRV Price: $1.06 TVL: $59,079.26']
# no Pair....
#  ['16 - musdp3CRV Price: $1.06 TVL: $59,079.26', 'Staked: 52048.5995 musdp3CRV ($55,264.69)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.04% Week 0.30% Year 15.74%', 'You are staking 0.00 musdp3CRV ($0.00), 0.00% of the pool.', 'Stake 0.00 musdp3CRV', 'Unstake 0.00 musdp3CRV', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1583
# ['17 - mrenBTC Price: $34,152.25 TVL: $76,158.63']
# no Pair....
#  ['17 - mrenBTC Price: $34,152.25 TVL: $76,158.63', 'Staked: 2.2015 mrenBTC ($75,185.80)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.03% Week 0.22% Year 11.57%', 'You are staking 0.00 mrenBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mrenBTC', 'Unstake 0.00 mrenBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1593
# ['19 - myveCRV-DAO Price: $1.51 TVL: $21,525.35']
# no Pair....
#  ['19 - myveCRV-DAO Price: $1.51 TVL: $21,525.35', 'Staked: 12763.0625 myveCRV-DAO ($19,329.56)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.12% Week 0.87% Year 45.01%', 'You are staking 0.00 myveCRV-DAO ($0.00), 0.00% of the pool.', 'Stake 0.00 myveCRV-DAO', 'Unstake 0.00 myveCRV-DAO', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1615
# ['20 - mTUSD Price: $1.00 TVL: $47,950.55']
# no Pair....
#  ['20 - mTUSD Price: $1.00 TVL: $47,950.55', 'Staked: 47695.7248 mTUSD ($47,822.97)', 'MM Per Week: 60.62 ($167.32)', 'APR: Day 0.05% Week 0.35% Year 18.19%', 'You are staking 0.00 mTUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 mTUSD', 'Unstake 0.00 mTUSD', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1625
# ['p3Crv Price: $1.10 TVL: $448,839.31']
# no Pair....
#  ['p3Crv Price: $1.10 TVL: $448,839.31', 'Staked: 349729.0264 p3Crv ($383,528.06)', 'PICKLE Per Week: 233.22 ($1,989.38)', 'APR: Day 0.07% Week 0.52% Year 26.97%', 'You are staking 0.000000 p3Crv $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 p3Crv', 'Unstake 0.000000 p3Crv', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1866
# ['psteCRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['psteCRV Price: $0.00 TVL: $0.00', 'Staked: 4769.0973 psteCRV ($0.00)', 'PICKLE Per Week: 1687.69 ($14,395.97)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.000000 psteCRV $0.00 (NaN% of the pool).', 'Etherscan', 'Stake 0.000000 psteCRV', 'Unstake 0.000000 psteCRV', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1938
# ['pUSDC Price: $0.95 TVL: $5,045,673.58']
# no Pair....
#  ['pUSDC Price: $0.95 TVL: $5,045,673.58', 'Staked: 5559191.5226 pUSDC ($5,291,896.87)', 'PICKLE Per Week: 2361.96 ($20,147.51)', 'APR: Day 0.05% Week 0.38% Year 19.80%', 'You are staking 0.000000 pUSDC $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 pUSDC', 'Unstake 0.000000 pUSDC', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2070
# ['pLUSD3CRV-f Price: $1.04 TVL: $3,679,291.76']
# no Pair....
#  ['pLUSD3CRV-f Price: $1.04 TVL: $3,679,291.76', 'Staked: 3150968.6784 pLUSD3CRV-f ($3,288,542.17)', 'PICKLE Per Week: 184.32 ($1,572.25)', 'APR: Day 0.01% Week 0.05% Year 2.49%', 'You are staking 0.000000 pLUSD3CRV-f $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 pLUSD3CRV-f', 'Unstake 0.000000 pLUSD3CRV-f', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2082
# ['pLQTY Price: $5.60 TVL: $2,273,967.79']
# no Pair....
#  ['pLQTY Price: $5.60 TVL: $2,273,967.79', 'Staked: 386646.1675 pLQTY ($2,166,891.49)', 'PICKLE Per Week: 763.88 ($6,515.90)', 'APR: Day 0.04% Week 0.30% Year 15.64%', 'You are staking 0.000000 pLQTY $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 pLQTY', 'Unstake 0.000000 pLQTY', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2106
# ['1 - sd3Crv Price: $1.07 TVL: $12,174,637.29']
# no Pair....
#  ['1 - sd3Crv Price: $1.07 TVL: $12,174,637.29', 'Staked: 10799146.9515 sd3Crv ($11,515,700.78)', 'SDT Per Week: 11200.00 ($11,312.00)', 'APR: Day 0.01% Week 0.10% Year 5.11%', 'You are staking 0.00 sd3Crv ($0.00), 0.00% of the pool.', 'Stake 0.00 sd3Crv', 'Unstake 0.00 sd3Crv', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2424
# ['2 - sdeursCRV Price: $1.33 TVL: $27,040,607.20']
# no Pair....
#  ['2 - sdeursCRV Price: $1.33 TVL: $27,040,607.20', 'Staked: 17711827.1391 sdeursCRV ($23,629,897.05)', 'SDT Per Week: 35840.00 ($36,198.40)', 'APR: Day 0.02% Week 0.15% Year 7.97%', 'You are staking 0.00 sdeursCRV ($0.00), 0.00% of the pool.', 'Stake 0.00 sdeursCRV', 'Unstake 0.00 sdeursCRV', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2434
# ['3 - sdcrvRenWSBTC Price: $36,373.92 TVL: $1,428,571.47']
# no Pair....
#  ['3 - sdcrvRenWSBTC Price: $36,373.92 TVL: $1,428,571.47', 'Staked: 36.2953 sdcrvRenWSBTC ($1,320,202.19)', 'SDT Per Week: 4480.00 ($4,524.80)', 'APR: Day 0.05% Week 0.34% Year 17.82%', 'You are staking 0.00 sdcrvRenWSBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 sdcrvRenWSBTC', 'Unstake 0.00 sdcrvRenWSBTC', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2444
# ['9 - sdeCRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['9 - sdeCRV Price: $0.00 TVL: $0.00', 'Staked: 1312.6596 sdeCRV ($0.00)', 'SDT Per Week: 4480.00 ($4,524.80)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 sdeCRV ($0.00), NaN% of the pool.', 'Stake 0.00 sdeCRV', 'Unstake 0.00 sdeCRV', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2498
# ['[DAI 40%]-[BAL 57.99999999999999%]-[TRU 2%] BPT Price: $1.25 TVL: $13,604.32']
# no Pair....
#  ['[DAI 40%]-[BAL 57.99999999999999%]-[TRU 2%] BPT Price: $1.25 TVL: $13,604.32', 'DAI Price: $1.00', 'BAL Price: $20.29', 'TRU Price: $0.16', 'Staked: 9297.9796 [DAI 40%]-[BAL 57.99999999999999%]-[TRU 2%] ($11,606.25)', 'TRU Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 undefined $0.00 (0.00% of the pool).', 'Your LP tokens comprise of 0.0000 DAI + 0.0000 BAL + 0.0000 TRU', 'Stake 0.000000 undefined', 'Unstake 0.000000 undefined', 'Claim 0.000000 TRU', 'Exit']
# Block Start Line No.:  2528
# ['Total Staked: $139,441.40']
# no Pair....
# ...
# Block Start Line No.:  5485
# [🐟]-[WETH] Uni LP [+] [-] [<=>] Price: $332.84 TVL: $104,370.88
# ['[🐟]-[WETH] Uni LP [+] [-] [<=>] Price: $332.84 TVL: $104,370.88']
# no Pair....
#  ['[🐟]-[WETH] Uni LP [+] [-] [<=>] Price: $332.84 TVL: $104,370.88', '🐟 Price: $4.48', 'WETH Price: $2,127.23', 'Staked: 299.9189 UNI-V2 ($99,823.83)', '🐟 Per Week: 194.44 ($871.11)', 'APR: Day 0.12% Week 0.87% Year 45.38%', 'You are staking 0.000000 [🐟]-[WETH] Uni LP $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [🐟]-[WETH] Uni LP', 'Unstake 0.000000 [🐟]-[WETH] Uni LP', 'Claim 0.000000 🐟 ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  5602
# [UNI]-[🐟] Uni LP [+] [-] [<=>] Price: $19.64 TVL: $29,014.24
# [🐟]-[USDC] Uni LP [+] [-] [<=>] Price: $113,913,903.63 TVL: $16,344.57
# ['[🐟]-[USDC] Uni LP [+] [-] [<=>] Price: $113,913,903.63 TVL: $16,344.57']
# no Pair....
#  ['[🐟]-[USDC] Uni LP [+] [-] [<=>] Price: $113,913,903.63 TVL: $16,344.57', '🐟 Price: $4.48', 'USDC Price: $1.00', 'Staked: 0.0001 UNI-V2 ($15,655.94)', '🐟 Per Week: 194.44 ($871.11)', 'APR: Day 0.79% Week 5.56% Year 289.33%', 'You are staking 0.000000 [🐟]-[USDC] Uni LP $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [🐟]-[USDC] Uni LP', 'Unstake 0.000000 [🐟]-[USDC] Uni LP', 'Claim 0.000000 🐟 ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  5630
# [⛩️]-[🐟] Uni LP [+] [-] [<=>] Price: $4.34 TVL: $24,872.61
# ['[⛩️]-[🐟] Uni LP [+] [-] [<=>] Price: $4.34 TVL: $24,872.61']
# no Pair....
#  ['[⛩️]-[🐟] Uni LP [+] [-] [<=>] Price: $4.34 TVL: $24,872.61', '⛩️ Price: $1.00', '🐟 Price: $4.48', 'Staked: 3224.8556 UNI-V2 ($13,982.95)', '🐟 Per Week: 194.44 ($871.11)', 'APR: Day 0.89% Week 6.23% Year 323.95%', 'You are staking 0.000000 [⛩️]-[🐟] Uni LP $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [⛩️]-[🐟] Uni LP', 'Unstake 0.000000 [⛩️]-[🐟] Uni LP', 'Claim 0.000000 🐟 ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  5644
# ['WETH Pool']
# no Pair....
#  ['WETH Pool', 'PAR Price: $1.22 Market Cap: $18,013,486.22 [%]', 'Staked: 9487506.8158 PAR ($11,574,758.32)', 'MIMO Per Week: 5256133.05 ($230,575.36)', 'APR: Day 0.28% Week 1.99% Year 103.59%', 'You are staking 0.00 PAR ($0.00), 0.00% of the pool.']
# Block Start Line No.:  5686
# ['WBTC Pool']
# no Pair....
#  ['WBTC Pool', 'PAR Price: $1.22 Market Cap: $18,013,486.22 [%]', 'Staked: 2524348.4183 PAR ($3,079,705.07)', 'MIMO Per Week: 4204906.44 ($184,460.29)', 'APR: Day 0.86% Week 5.99% Year 311.46%', 'You are staking 0.00 PAR ($0.00), 0.00% of the pool.']
# Block Start Line No.:  5693
# ['USDC Pool']
# no Pair....
#  ['USDC Pool', 'PAR Price: $1.22 Market Cap: $18,013,486.22 [%]', 'Staked: 2627614.2485 PAR ($3,205,689.38)', 'MIMO Per Week: 1051226.61 ($46,115.07)', 'APR: Day 0.21% Week 1.44% Year 74.80%', 'You are staking 0.00 PAR ($0.00), 0.00% of the pool.']
# Block Start Line No.:  5700
# ['There is a locking period for the pools, for more information please visit the website']
# no Pair....
#  ['There is a locking period for the pools, for more information please visit the website', 'Staking Contract', 'Found 4 pools.']
# Block Start Line No.:  5788
# Exception Traceback (most recent call last):
#   File "<ipython-input-15-8a8db9f60c5c>", line 118, in get_pairs
#   File "<ipython-input-15-8a8db9f60c5c>", line 82, in get_pair_info_from_block
#   File "<ipython-input-9-6396f5945b4a>", line 19, in pair2
# ValueError: substring not found
#
# [Gelato Uniswap V3 INST/ETH LP 1] Price: $6.65 TVL: $2,720,500.60
# ['PENDLE SINGLE STAKING POOL TVL: $2,685,243.95']
# no Pair....
#  ['PENDLE SINGLE STAKING POOL TVL: $2,685,243.95', 'PENDLE Price: $0.58', 'PENDLE Per Block: 0.66209 ($0.38)', 'APR: Day 0.09% Week 0.66% Year 34.20%', 'Total Staked: 4,660,490.18 PENDLE ($2,685,243.95)', 'You are staking 0.00 PENDLE $0.00 (0.00000% of the pool).', 'Etherscan', 'Stake 0.00 PENDLE', 'Unstake 0.00 PENDLE', 'Revoke (set approval to 0)']
# Block Start Line No.:  7610
# ['fWETH Price: $2,139.65 TVL: $15,570,714.29']
# no Pair....
#  ['fWETH Price: $2,139.65 TVL: $15,570,714.29', 'Staked: 7222.5127 fWETH ($15,453,677.89)', 'FARM Per Week: 109.76 ($6,157.38)', 'APR: Day 0.01% Week 0.04% Year 2.07%', 'You are staking 0.00 fWETH ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fWETH', 'Unstake 0.000000 fWETH', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7767
# ['fBAC Price: $0.08 TVL: $115.37']
# no Pair....
#  ['fBAC Price: $0.08 TVL: $115.37', 'Staked: 1198.2196 fBAC ($89.98)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fBAC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fBAC', 'Unstake 0.000000 fBAC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7811
# ['fESD Price: $0.04 TVL: $9,621.56']
# no Pair....
#  ['fESD Price: $0.04 TVL: $9,621.56', 'Staked: 211750.8008 fESD ($9,077.22)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fESD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fESD', 'Unstake 0.000000 fESD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7822
# ['fDSD Price: $0.02 TVL: $1,234.48']
# no Pair....
#  ['fDSD Price: $0.02 TVL: $1,234.48', 'Staked: 60247.9388 fDSD ($1,151.52)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fDSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fDSD', 'Unstake 0.000000 fDSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7833
# ['fyDAI+yUSDC+yUSDT+yTUSD Price: $1.15 TVL: $694,928.01']
# no Pair....
#  ['fyDAI+yUSDC+yUSDT+yTUSD Price: $1.15 TVL: $694,928.01', 'Staked: 497812.1127 fyDAI+yUSDC+yUSDT+yTUSD ($573,592.75)', 'FARM Per Week: 2.24 ($125.51)', 'APR: Day 0.00% Week 0.02% Year 1.14%', 'You are staking 0.00 fyDAI+yUSDC+yUSDT+yTUSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fyDAI+yUSDC+yUSDT+yTUSD', 'Unstake 0.000000 fyDAI+yUSDC+yUSDT+yTUSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7844
# ['fhusd3CRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['fhusd3CRV Price: $0.00 TVL: $0.00', 'Staked: 1609864.8146 fhusd3CRV ($0.00)', 'FARM Per Week: 6.99 ($391.89)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fhusd3CRV ($0.00), NaN% of the pool.', 'Staking Contract', 'Stake 0.000000 fhusd3CRV', 'Unstake 0.000000 fhusd3CRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7855
# ['fcDAI+cUSDC Price: $1.11 TVL: $1,056,289.83']
# no Pair....
#  ['fcDAI+cUSDC Price: $1.11 TVL: $1,056,289.83', 'Staked: 906917.9669 fcDAI+cUSDC ($1,002,746.95)', 'FARM Per Week: 7.83 ($439.02)', 'APR: Day 0.01% Week 0.04% Year 2.28%', 'You are staking 0.00 fcDAI+cUSDC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fcDAI+cUSDC', 'Unstake 0.000000 fcDAI+cUSDC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7866
# ['fyDAI+yUSDC+yUSDT+yBUSD Price: $1.13 TVL: $1,316,678.93']
# no Pair....
#  ['fyDAI+yUSDC+yUSDT+yBUSD Price: $1.13 TVL: $1,316,678.93', 'Staked: 941719.5398 fyDAI+yUSDC+yUSDT+yBUSD ($1,067,198.06)', 'FARM Per Week: 11.46 ($642.91)', 'APR: Day 0.01% Week 0.06% Year 3.13%', 'You are staking 0.00 fyDAI+yUSDC+yUSDT+yBUSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fyDAI+yUSDC+yUSDT+yBUSD', 'Unstake 0.000000 fyDAI+yUSDC+yUSDT+yBUSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7877
# ['fusdn3CRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['fusdn3CRV Price: $0.00 TVL: $0.00', 'Staked: 1741820.0270 fusdn3CRV ($0.00)', 'FARM Per Week: 47.53 ($2,666.46)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fusdn3CRV ($0.00), NaN% of the pool.', 'Staking Contract', 'Stake 0.000000 fusdn3CRV', 'Unstake 0.000000 fusdn3CRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7888
# ['fUSDC Price: $0.91 TVL: $13,927,092.89']
# no Pair....
#  ['fUSDC Price: $0.91 TVL: $13,927,092.89', 'Staked: 16396851.0623 fUSDC ($14,920,378.79)', 'FARM Per Week: 33.82 ($1,897.48)', 'APR: Day 0.00% Week 0.01% Year 0.66%', 'You are staking 0.00 fUSDC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fUSDC', 'Unstake 0.000000 fUSDC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7899
# ['fUSDT Price: $0.91 TVL: $6,476,653.70']
# no Pair....
#  ['fUSDT Price: $0.91 TVL: $6,476,653.70', 'Staked: 7648901.5638 fUSDT ($6,995,083.87)', 'FARM Per Week: 11.83 ($663.86)', 'APR: Day 0.00% Week 0.01% Year 0.49%', 'You are staking 0.00 fUSDT ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fUSDT', 'Unstake 0.000000 fUSDT', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7910
# ['fTUSD Price: $1.06 TVL: $25,069.60']
# no Pair....
#  ['fTUSD Price: $1.06 TVL: $25,069.60', 'Staked: 2491.7610 fTUSD ($2,630.08)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fTUSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fTUSD', 'Unstake 0.000000 fTUSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7921
# ['fDAI Price: $1.05 TVL: $13,643,131.21']
# no Pair....
#  ['fDAI Price: $1.05 TVL: $13,643,131.21', 'Staked: 12301691.3724 fDAI ($12,935,205.05)', 'FARM Per Week: 27.03 ($1,516.48)', 'APR: Day 0.00% Week 0.01% Year 0.61%', 'You are staking 0.00 fDAI ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fDAI', 'Unstake 0.000000 fDAI', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7932
# ['fhCRV Price: $0.00 TVL: $0.00']
# no Pair....
#  ['fhCRV Price: $0.00 TVL: $0.00', 'Staked: 214.1772 fhCRV ($0.00)', 'FARM Per Week: 19.56 ($1,097.29)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fhCRV ($0.00), NaN% of the pool.', 'Staking Contract', 'Stake 0.000000 fhCRV', 'Unstake 0.000000 fhCRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  7987
# ['foBTC', 'sbtcCRV Price: $36,242.93 TVL: $6,082,199.53']
# foBTC
# sbtcCRV Price: $36,242.93 TVL: $6,082,199.53
# ['foBTC', 'sbtcCRV Price: $36,242.93 TVL: $6,082,199.53']
# foBTC
# sbtcCRV Price: $36,242.93 TVL: $6,082,199.53
# ['foBTC', 'sbtcCRV']
# ['foBTC', 'sbtcCRV Price: $36,242.93 TVL: $6,082,199.53']
# foBTC
# sbtcCRV Price: $36,242.93 TVL: $6,082,199.53
# ['ftbtc', 'sbtcCrv Price: $34,638.17 TVL: $420,101.73']
# ftbtc
# sbtcCrv Price: $34,638.17 TVL: $420,101.73
# ['ftbtc', 'sbtcCrv Price: $34,638.17 TVL: $420,101.73']
# ftbtc
# sbtcCrv Price: $34,638.17 TVL: $420,101.73
# ['ftbtc', 'sbtcCrv']
# ['ftbtc', 'sbtcCrv Price: $34,638.17 TVL: $420,101.73']
# ftbtc
# sbtcCrv Price: $34,638.17 TVL: $420,101.73
# ['fcrvRenWBTC Price: $34,765.91 TVL: $20,365,540.91']
# no Pair....
#  ['fcrvRenWBTC Price: $34,765.91 TVL: $20,365,540.91', 'Staked: 574.8720 fcrvRenWBTC ($19,985,948.28)', 'FARM Per Week: 33.53 ($1,881.08)', 'APR: Day 0.00% Week 0.01% Year 0.49%', 'You are staking 0.00 fcrvRenWBTC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fcrvRenWBTC', 'Unstake 0.000000 fcrvRenWBTC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  8020
# ['fWBTC Price: $34,159.66 TVL: $269,908.48']
# no Pair....
#  ['fWBTC Price: $34,159.66 TVL: $269,908.48', 'Staked: 7.6660 fWBTC ($261,869.06)', 'FARM Per Week: 1.40 ($78.38)', 'APR: Day 0.00% Week 0.03% Year 1.56%', 'You are staking 0.00 fWBTC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fWBTC', 'Unstake 0.000000 fWBTC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  8031
# ['frenBTC Price: $33,794.90 TVL: $83,007.39']
# no Pair....
#  ['frenBTC Price: $33,794.90 TVL: $83,007.39', 'Staked: 2.3888 frenBTC ($80,729.43)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 frenBTC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 frenBTC', 'Unstake 0.000000 frenBTC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  8042
# FANTOM Yields 7:1.uu
# no Pair....
#  ['FANTOM Yields 7/1']
# Block Start Line No.:  1
# ['2 - mBOO Price: $4.01 TVL: $23,089.44']
# no Pair....
#  ['2 - mBOO Price: $4.01 TVL: $23,089.44', 'Staked: 4849.2044 mBOO ($19,442.74)', 'MM Per Week: 17.36 ($50.21)', 'APR: Day 0.04% Week 0.26% Year 13.43%', 'You are staking 0.00 mBOO ($0.00), 0.00% of the pool.', 'Stake 0.00 mBOO', 'Unstake 0.00 mBOO', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1820
# ['3 - mSPIRIT Price: $0.00 TVL: $0.00']
# no Pair....
#  ['3 - mSPIRIT Price: $0.00 TVL: $0.00', 'Staked: 218531.0891 mSPIRIT ($0.00)', 'MM Per Week: 17.36 ($50.21)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 mSPIRIT ($0.00), NaN% of the pool.', 'Stake 0.00 mSPIRIT', 'Unstake 0.00 mSPIRIT', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1830
# ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.']
# no Pair....
#  ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.', '0 - iFUSD Price: $0.32 Market Cap: $3,686,921.16', 'Staked: 1266685.7835 iFUSD ($407,094.40)', 'STEAK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 iFUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 iFUSD - Fee 0.005%', 'Unstake 0.00 iFUSD', 'Claim 0.00 STEAK ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2028
# ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.']
# no Pair....
#  ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.', '1 - [STEAK]-[FUSD] SPIRIT LP [+] [-] [<=>] Price: $1.07 TVL: $84,904.03', 'STEAK Price: $0.87', 'FUSD Price: $0.32', 'Staked: 6832.0952 SPIRIT-LP ($7,299.21)', 'STEAK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 [STEAK]-[FUSD] SPIRIT LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [STEAK]-[FUSD] SPIRIT LP - Fee 0.005%', 'Unstake 0.00 [STEAK]-[FUSD] SPIRIT LP', 'Claim 0.00 STEAK ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2039
# ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.']
# no Pair....
#  ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.', '2 - [USDC]-[FUSD] SPIRIT LP [+] [-] [<=>] Price: $1,256,108.90 TVL: $6,703.48', 'USDC Price: $1.01', 'FUSD Price: $0.32', 'Staked: 0.0011 SPIRIT-LP ($1,346.47)', 'STEAK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 [USDC]-[FUSD] SPIRIT LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [USDC]-[FUSD] SPIRIT LP - Fee 0.005%', 'Unstake 0.00 [USDC]-[FUSD] SPIRIT LP', 'Claim 0.00 STEAK ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2052
# ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.']
# no Pair....
#  ['Note: There is a 0.05% deposit fee into farms that is returned to iFUSD holders, and 10% claim fee that is returned to xSTEAK holders.', '5 - [WFTM]-[FUSD] SPIRIT LP [+] [-] [<=>] Price: $0.72 TVL: $11,551.81', 'WFTM Price: $0.23', 'FUSD Price: $0.32', 'Staked: 14382.8154 SPIRIT-LP ($10,373.16)', 'STEAK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 [WFTM]-[FUSD] SPIRIT LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [WFTM]-[FUSD] SPIRIT LP - Fee 0.005%', 'Unstake 0.00 [WFTM]-[FUSD] SPIRIT LP', 'Claim 0.00 STEAK ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2065
# ['Total Staked: $426,113.25']
# no Pair....
#  ['Total Staked: $426,113.25', 'FUSD Price: $0.32 Market Cap: $7,899,483.90', 'Staked: 11588634.0781 FUSD ($3,686,921.16)', 'FUSD Per Week: 14000.00 ($4,454.10)', 'APR: Day 0.02% Week 0.12% Year 6.28%', 'You are staking 0.00 FUSD ($0.00), 0.00% of the pool.', 'iFUSD Contract', 'Deposit 0.00 FUSD', 'Withdraw 0.00 iFUSD']
# Block Start Line No.:  2078

# %%
pair_df = pd.DataFrame(pairs, columns=['pair1', 'pair2', 'tvl', 'apr', 'where', 'network'])
pair_df['apy'] = np.nan

# %%
pairs
# Out:
# [['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['USDC',
#   'QUICK',
#   '8629368.06',
#   '49.06',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'QUICK',
#   '12803446.21',
#   '53.42',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['USDC',
#   'DAI',
#   '52530360.75',
#   '4.21',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'TEL',
#   '2592305.66',
#   '72.27',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['stkGHST-QUICK',
#   '',
#   '0.00',
#   0,
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'WISE',
#   '3334388.59',
#   '20.06',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'CEL',
#   '4949292.89',
#   '30.09',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'TEL',
#   '4467094.56',
#   '38.02',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['DEFI5',
#   'WETH',
#   '4306340.29',
#   '7.71',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['Krill',
#   'QUICK',
#   '52775.84',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'WISE',
#   '1493550.59',
#   '55.64',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'PolyDoge',
#   '747225.49',
#   '90.30',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['QUICK',
#   'EMON',
#   '79816.96',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'SX',
#   '1893797.62',
#   '20.01',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['stkGHST-USDC',
#   '',
#   '0.00',
#   0,
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC',
#   'WOLF',
#   '651416.95',
#   '7.64',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['LINK',
#   'QUICK',
#   '1353292.98',
#   '49.30',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['AGA',
#   'AGAr',
#   '91188.60',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'UNI',
#   '1979439.07',
#   '59.40',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['DAI',
#   'USDT',
#   '13734954.43',
#   '4.86',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC',
#   'PolyDoge',
#   '411780.96',
#   '101.80',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC',
#   'EMON',
#   '103053.62',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['FRAX',
#   'FXS',
#   '407906.19',
#   '4.17',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'DEGEN',
#   '531288.22',
#   '62.55',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'GAME',
#   '513816.16',
#   '48.29',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'DEGEN',
#   '568048.37',
#   '60.17',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['ARIA20',
#   'WETH',
#   '285014.84',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'CC10',
#   '1104799.43',
#   '37.98',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['VISION',
#   'WETH',
#   '584239.59',
#   '14.40',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['DEFI5',
#   'QUICK',
#   '608141.09',
#   '68.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['$DG',
#   'WETH',
#   '573615.99',
#   '86.51',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'CEL',
#   '587837.54',
#   '56.43',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'CC10',
#   '505890.36',
#   '65.37',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'UBT',
#   '1867219.48',
#   '17.81',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC',
#   'mOCEAN',
#   '1483261.38',
#   '15.93',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['SWAP',
#   'QUICK',
#   '202996.74',
#   '41.08',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['SX',
#   'DAI',
#   '556282.04',
#   '3.04',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'miFARM',
#   '235368.91',
#   '35.27',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['UBT',
#   'QUICK',
#   '205023.32',
#   '80.69',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'SUPER',
#   '150958.93',
#   '55.28',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'AGAr',
#   '2697.43',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['ANY',
#   'QUICK',
#   '340919.27',
#   '72.97',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'SUPER',
#   '207540.81',
#   '42.99',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['FRAX',
#   'QUICK',
#   '291272.33',
#   '58.10',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['VISION',
#   'QUICK',
#   '50284.92',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['HEX',
#   'QUICK',
#   '322678.92',
#   '60.29',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'xMARK',
#   '11516.69',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['$DG',
#   'QUICK',
#   '173485.21',
#   '71.51',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['AGA',
#   'QUICK',
#   '3341.84',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'IGG',
#   '163929.72',
#   '50.76',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'BTU',
#   '25.37',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['FSN',
#   'QUICK',
#   '134.98',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['ARIA20',
#   'QUICK',
#   '78100.85',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'NFTP',
#   '11552.92',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'PLOT',
#   '91829.78',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'DRC',
#   '6768.18',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK', 'SX', '553.38', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['mOCEAN',
#   'QUICK',
#   '1406.07',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['CTSI',
#   'QUICK',
#   '11869.68',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'WOLF',
#   '5162.66',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['GFARM2',
#   'QUICK',
#   '2.29',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['ELET',
#   'QUICK',
#   '1693.04',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'DMT',
#   '13512.27',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'DSLA',
#   '125626.68',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC',
#   'WETH',
#   '513716.82',
#   '35.54',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['LADZ',
#   'WETH',
#   '24398.07',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['LADZ', 'MUST', '13855.80', 0, 'https://swap.cometh.io/#/stake', 'MATIC'],
#  ['MUST',
#   'pBTC',
#   '15943.37',
#   '49.83',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WBTC',
#   'pBTC',
#   '31289.43',
#   '12.63',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['BND',
#   'WETH',
#   '362900.07',
#   '10.98',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'pBTC',
#   '1782.27',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['BND',
#   'MUST',
#   '38054.92',
#   '124.50',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['KIF',
#   'MUST',
#   '10080.97',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['DAI',
#   'USDT',
#   '33375.10',
#   '11.92',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'DAI',
#   '32674.92',
#   '12.10',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'USDT',
#   '28034.85',
#   '14.10',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['PICKLE',
#   'MUST',
#   '237722.40',
#   '33.23',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WBTC',
#   'WETH',
#   '1055734.95',
#   '18.73',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['bBADGER',
#   'MUST',
#   '5777.62',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'bDIGG',
#   '7540.21',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'xSDT',
#   '46979.94',
#   '17.04',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['SDT',
#   'xSDT',
#   '263357.46',
#   '3.04',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['sd3Crv', 'xSDT', '46.55', 0, 'https://swap.cometh.io/#/stake', 'MATIC'],
#  ['xSDT',
#   'sdcrvRenWSBTC',
#   '961.65',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'MUST',
#   '129323.03',
#   '92.03',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WBTC',
#   'MUST',
#   '36385.38',
#   '163.34',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['JULIEN',
#   'MUST',
#   '305522.23',
#   '1.31',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['SDT',
#   'MUST',
#   '37354.53',
#   '30.34',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WBTC',
#   'sdcrvRenWSBTC',
#   '752.09',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['maUSDC',
#   'MUST',
#   '547.57',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['GHST',
#   'MUST',
#   '105672.37',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'AAVE',
#   '8076.04',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['SUSHI',
#   'MUST',
#   '7076.44',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'WETH',
#   '949888.31',
#   '10.46',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WETH',
#   'MUST',
#   '424067.67',
#   '133.44',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WMATIC',
#   'MUST',
#   '839248.47',
#   '94.54',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['DOKI',
#   'WETH',
#   '288272.82',
#   '69.68',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['DOKI',
#   'MUST',
#   '90517.61',
#   '44.15',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['AZUKI',
#   'MUST',
#   '101801.30',
#   '199.65',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['AZUKI',
#   'WETH',
#   '239739.54',
#   '185.29',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'STR',
#   '12588.32',
#   '98.50',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'NDR',
#   '32318.49',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['ELET',
#   'MUST',
#   '10433.15',
#   '75.87',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['VBTC',
#   'WETH',
#   '5425.66',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['VBTC',
#   'MUST',
#   '7443.12',
#   '53.39',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['VBTC',
#   'WBTC',
#   '14458.08',
#   '27.38',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['ELET',
#   'WMATIC',
#   '35139.17',
#   '22.58',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   '$TRDL',
#   '5192.44',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['SDT',
#   'WETH',
#   '265959.14',
#   '45.27',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MM',
#   'MUST',
#   '65293.91',
#   '85.01',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'mWETH',
#   '49200.67',
#   '96.68',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['mWBTC',
#   'MUST',
#   '42974.00',
#   '110.89',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WETH',
#   'RAZOR',
#   '68140.54',
#   '55.82',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'RAZOR',
#   '22181.33',
#   '72.33',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC', 'NIOX', '545169.19', '101.26', 'https://swap.smartdex.app', 'MATIC'],
#  ['WMATIC',
#   'USDC',
#   '148900.05',
#   '104.95',
#   'https://swap.smartdex.app',
#   'MATIC'],
#  ['USDC', 'WETH', '222543.25', '71.95', 'https://swap.smartdex.app', 'MATIC'],
#  ['AGI', 'NIOX', '2369.23', '0.00', 'https://swap.smartdex.app', 'MATIC'],
#  ['GLQ', 'WETH', '2.04', '0.00', 'https://swap.smartdex.app', 'MATIC'],
#  ['ALOHA', 'NIOX', '21522.15', '0.00', 'https://swap.smartdex.app', 'MATIC'],
#  ['USDC', 'pBTC', '124347.49', '88.16', 'https://swap.smartdex.app', 'MATIC'],
#  ['WMATIC', 'ELK', '359237.61', '123.63', 'https://app.elk.finance', 'MATIC'],
#  ['USDT', 'ELK', '111085.62', '99.70', 'https://app.elk.finance', 'MATIC'],
#  ['USDC', 'ELK', '100557.24', '109.91', 'https://app.elk.finance', 'MATIC'],
#  ['WETH', 'ELK', '52639.45', '157.67', 'https://app.elk.finance', 'MATIC'],
#  ['WBTC', 'ELK', '20514.14', '215.47', 'https://app.elk.finance', 'MATIC'],
#  ['LINK', 'ELK', '25840.79', '171.02', 'https://app.elk.finance', 'MATIC'],
#  ['DAI', 'ELK', '46570.33', '142.77', 'https://app.elk.finance', 'MATIC'],
#  ['QUICK', 'ELK', '13068.40', '211.46', 'https://app.elk.finance', 'MATIC'],
#  ['AAVE', 'ELK', '17615.49', '250.95', 'https://app.elk.finance', 'MATIC'],
#  ['GHST', 'ELK', '3806.16', '291.33', 'https://app.elk.finance', 'MATIC'],
#  ['MUST', 'ELK', '11799.19', '376.14', 'https://app.elk.finance', 'MATIC'],
#  ['DEFI5', 'ELK', '4782.34', '237.94', 'https://app.elk.finance', 'MATIC'],
#  ['CC10', 'ELK', '5740.43', '192.87', 'https://app.elk.finance', 'MATIC'],
#  ['Krill', 'ELK', '4379.16', '506.36', 'https://app.elk.finance', 'MATIC'],
#  ['MANA', 'ELK', '9077.36', '243.69', 'https://app.elk.finance', 'MATIC'],
#  ['ELK', 'CXO', '14133.15', '78.20', 'https://app.elk.finance', 'MATIC'],
#  ['AZUKI', 'ELK', '7324.13', '151.06', 'https://app.elk.finance', 'MATIC'],
#  ['Krill', '', '83804.46', '0.00', 'https://polywhale.finance', 'MATIC'],
#  ['Mint', '', '0.00', 0, 'https://polywhale.finance', 'MATIC'],
#  ['USDC', 'FOX', '8848.93', '687.50', 'https://polyfox.finance', 'MATIC'],
#  ['WMATIC', '', '9862.59', '60.05', 'https://polyfox.finance', 'MATIC'],
#  ['WBTC', '', '13196.29', '44.88', 'https://polyfox.finance', 'MATIC'],
#  ['WETH', '', '3199.52', '370.21', 'https://polyfox.finance', 'MATIC'],
#  ['QUICK', '', '4373.53', '270.83', 'https://polyfox.finance', 'MATIC'],
#  ['Krill', '', '92.87', '3188.69', 'https://polyfox.finance', 'MATIC'],
#  ['USDT', '', '19796.67', '35.90', 'https://polyfox.finance', 'MATIC'],
#  ['USDC', '', '17501.93', '40.61', 'https://polyfox.finance', 'MATIC'],
#  ['DAI', '', '3952.31', '179.82', 'https://polyfox.finance', 'MATIC'],
#  ['FOX', '', '12505.09', '118.40', 'https://polyfox.finance', 'MATIC'],
#  ['HAWK', 'WETH', '6785.05', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['WMATIC', '', '19969.06', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['WETH', '', '1366.92', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['WBTC', '', '78.68', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['DAI', '', '10457.07', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['USDC', '', '32292.21', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['USDT', '', '4350.08', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['USDC', 'FIRE', '155214.35', '232.22', 'https://polydragon.io', 'MATIC'],
#  ['FIRE', '', '194479.49', '176.70', 'https://polydragon.io', 'MATIC'],
#  ['WMATIC', 'FIRE', '287586.41', '219.84', 'https://polydragon.io', 'MATIC'],
#  ['WETH', 'FIRE', '26588.62', '180.55', 'https://polydragon.io', 'MATIC'],
#  ['miMATIC', 'FIRE', '1728.44', '231.41', 'https://polydragon.io', 'MATIC'],
#  ['HEX', 'FIRE', '5146.58', '93.18', 'https://polydragon.io', 'MATIC'],
#  ['BTT', 'WMATIC', '872.93', '0.00', 'https://farm.BoughtThe.top', 'MATIC'],
#  ['DAI', '', '3.56', '0.00', 'https://farm.BoughtThe.top', 'MATIC'],
#  ['USDC', '', '75.96', '0.00', 'https://farm.BoughtThe.top', 'MATIC'],
#  ['USDT', '', '80.00', '0.00', 'https://farm.BoughtThe.top', 'MATIC'],
#  ['WBTC', '', '9.59', '0.00', 'https://farm.BoughtThe.top', 'MATIC'],
#  ['WETH', '', '0.04', '0.00', 'https://farm.BoughtThe.top', 'MATIC'],
#  ['WMATIC', '', '381.62', '0.00', 'https://farm.BoughtThe.top', 'MATIC'],
#  ['STARTER',
#   'WMATIC',
#   '1323.96',
#   '947.83',
#   'https://www.polystarter.fi',
#   'MATIC'],
#  ['WMATIC', '', '14681.33', '8.01', 'https://www.polystarter.fi', 'MATIC'],
#  ['QUICK', '', '1011.00', '116.27', 'https://www.polystarter.fi', 'MATIC'],
#  ['MUST', '', '2217.82', '53.00', 'https://www.polystarter.fi', 'MATIC'],
#  ['Krill', '', '60.92', '643.14', 'https://www.polystarter.fi', 'MATIC'],
#  ['WBTC', '', '338.93', '115.61', 'https://www.polystarter.fi', 'MATIC'],
#  ['WETH', '', '632.72', '61.93', 'https://www.polystarter.fi', 'MATIC'],
#  ['DAI', '', '1080.49', '36.26', 'https://www.polystarter.fi', 'MATIC'],
#  ['USDC', '', '7042.20', '5.56', 'https://www.polystarter.fi', 'MATIC'],
#  ['USDT', '', '506.83', '77.31', 'https://www.polystarter.fi', 'MATIC'],
#  ['USDC', 'SPR', '22.50', '3160.25', 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['SPR', '', '160.02', '156.47', 'https://polyvolve.finance', 'MATIC'],
#  ['WMATIC', '', '581.55', '17.22', 'https://polyvolve.finance', 'MATIC'],
#  ['WETH', '', '134.64', '74.39', 'https://polyvolve.finance', 'MATIC'],
#  ['WBTC', '', '27.95', '125.43', 'https://polyvolve.finance', 'MATIC'],
#  ['QUICK', '', '126.75', '79.02', 'https://polyvolve.finance', 'MATIC'],
#  ['LINK', '', '46.86', '160.32', 'https://polyvolve.finance', 'MATIC'],
#  ['USDC', '', '1301.03', '3.85', 'https://polyvolve.finance', 'MATIC'],
#  ['AAVE', '', '31.60', '206.00', 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['QUICK', 'SPR', '15.43', '1344.12', 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['Krill', 'SPR', '18.24', '3523.16', 'https://polyvolve.finance', 'MATIC'],
#  ['USDC', 'GAJ', '103937.66', '425.42', 'https://polygaj.finance', 'MATIC'],
#  ['GAJ', '', '153992.80', '235.41', 'https://polygaj.finance', 'MATIC'],
#  ['WMATIC', '', '45378.47', '79.89', 'https://polygaj.finance', 'MATIC'],
#  ['WBTC', '', '80841.28', '22.42', 'https://polygaj.finance', 'MATIC'],
#  ['WETH', '', '104787.21', '34.60', 'https://polygaj.finance', 'MATIC'],
#  ['USDC', '', '43246.36', '20.96', 'https://polygaj.finance', 'MATIC'],
#  ['USDT', '', '20973.78', '43.21', 'https://polygaj.finance', 'MATIC'],
#  ['AAVE', '', '15032.55', '60.29', 'https://polygaj.finance', 'MATIC'],
#  ['WMATIC', 'GAJ', '63406.81', '590.27', 'https://polygaj.finance', 'MATIC'],
#  ['SLP', '', '0.00', 0, 'https://polygaj.finance', 'MATIC'],
#  ['SLP', '', '0.00', 0, 'https://polygaj.finance', 'MATIC'],
#  ['WMATIC', 'GAJ', '51790.61', '807.43', 'https://polygaj.finance', 'MATIC'],
#  ['USDC',
#   'STONK',
#   '318.92',
#   '286.91',
#   'https://gameswap.netlify.app/',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://gameswap.netlify.app/', 'MATIC'],
#  ['WMATIC', '', '262.22', '31.09', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['WBTC', '', '209.45', '19.46', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['WETH', '', '15.96', '1021.50', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['QUICK', '', '35.05', '534.98', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['YLD', '', '3.57', '1141.85', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['USDT', '', '86.52', '141.36', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['USDC', '', '1546.68', '7.91', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['STONK', '', '150.47', '162.56', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://gameswap.netlify.app/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://gameswap.netlify.app/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://gameswap.netlify.app/', 'MATIC'],
#  ['AURORA',
#   'USDC',
#   '37821.72',
#   '241.94',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['AURORA',
#   '',
#   '30666.52',
#   '148.83',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['WMATIC',
#   '',
#   '151333.61',
#   '24.13',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['WBTC', '', '147849.05', '6.17', 'https://www.blackswap.finance', 'MATIC'],
#  ['WETH', '', '169149.38', '21.59', 'https://www.blackswap.finance', 'MATIC'],
#  ['USDT', '', '127179.59', '21.53', 'https://www.blackswap.finance', 'MATIC'],
#  ['USDC', '', '108880.69', '25.15', 'https://www.blackswap.finance', 'MATIC'],
#  ['DAI', '', '185572.69', '9.84', 'https://www.blackswap.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.blackswap.finance', 'MATIC'],
#  ['AURORA',
#   'WMATIC',
#   '17302.89',
#   '322.49',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['AURORA',
#   'USDC',
#   '13294.73',
#   '418.74',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['USDC',
#   'NEBULA',
#   '9061.87',
#   '1328.09',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['IRON', '', '0.00', 0, 'https://www.blackswap.finance', 'MATIC'],
#  ['AURORA',
#   'WMATIC',
#   '8299.18',
#   '590.20',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['PolyZap-LP', '', '0.00', 0, 'https://www.blackswap.finance', 'MATIC'],
#  ['WMATIC',
#   'SOLAR',
#   '16046.84',
#   '480.38',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['SOLAR', '', '8229.03', '288.69', 'https://www.blackswap.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.blackswap.finance', 'MATIC'],
#  ['NEBULA', '', '1566.07', '606.77', 'https://www.blackswap.finance', 'MATIC'],
#  ['WMATIC', '', '21295.70', '66.93', 'https://www.blackswap.finance', 'MATIC'],
#  ['WBTC', '', '49196.98', '11.27', 'https://www.blackswap.finance', 'MATIC'],
#  ['WETH', '', '22769.73', '34.78', 'https://www.blackswap.finance', 'MATIC'],
#  ['USDT', '', '45186.21', '17.52', 'https://www.blackswap.finance', 'MATIC'],
#  ['USDC', '', '48463.21', '16.34', 'https://www.blackswap.finance', 'MATIC'],
#  ['DAI', '', '21043.92', '30.10', 'https://www.blackswap.finance', 'MATIC'],
#  ['WMATIC',
#   'SOLAR',
#   '6011.12',
#   '662.56',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['USDC',
#   'NEBULA',
#   '9061.87',
#   '646.47',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['PCAKE', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['WMATIC', '', '8610.57', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['WBTC', '', '7633.25', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['WETH', '', '2653.51', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['USDC', '', '6908.52', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['USDT', '', '2998.83', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['DAI', '', '11032.79', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['QUICK', '', '1033.02', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['LINK', '', '7490.42', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['AAVE', '', '3181.51', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['PolyMoon', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['ELK', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['miMATIC', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['gNFT', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['RANGER', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['WMATIC', '', '212.59', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['WETH', '', '116.90', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['WBTC', '', '38.21', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['QUICK', '', '84.56', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['LINK', '', '47.88', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['USDC', '', '215.49', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['AAVE', '', '35.45', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['FOX', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['WMATIC', 'WETH', '55708106.43', '27.17', 'https://app.sushi.com', 'MATIC'],
#  ['USDC', 'WETH', '85376732.16', '14.14', 'https://app.sushi.com', 'MATIC'],
#  ['WETH', 'USDT', '52028567.49', '20.52', 'https://app.sushi.com', 'MATIC'],
#  ['SLP', '', '0.00', 0, 'https://app.sushi.com', 'MATIC'],
#  ['SLP', '', '0.00', 0, 'https://app.sushi.com', 'MATIC'],
#  ['SLP', '', '0.00', 0, 'https://app.sushi.com', 'MATIC'],
#  ['LINK', 'WETH', '28373320.23', '13.92', 'https://app.sushi.com', 'MATIC'],
#  ['USDC', 'USDT', '80301978.38', '4.54', 'https://app.sushi.com', 'MATIC'],
#  ['CRV', 'WETH', '2884561.12', '27.53', 'https://app.sushi.com', 'MATIC'],
#  ['SNX', 'WETH', '2015120.76', '19.65', 'https://app.sushi.com', 'MATIC'],
#  ['USDC', 'DAI', '38342773.16', '5.36', 'https://app.sushi.com', 'MATIC'],
#  ['WMATIC', 'WOOFY', '805656.17', '30.64', 'https://app.sushi.com', 'MATIC'],
#  ['FRAX', 'USDC', '12651873.85', '11.25', 'https://app.sushi.com', 'MATIC'],
#  ['FRAX', 'FXS', '3179866.89', '10.04', 'https://app.sushi.com', 'MATIC'],
#  ['GRT', 'WETH', '1117250.32', '7.10', 'https://app.sushi.com', 'MATIC'],
#  ['WETH', 'ADDY', '313961.53', '101.46', 'https://app.sushi.com', 'MATIC'],
#  ['WETH', 'WFIL', '856136.05', '36.90', 'https://app.sushi.com', 'MATIC'],
#  ['WETH', 'DHT', '1792935.42', '25.38', 'https://app.sushi.com', 'MATIC'],
#  ['USDC', 'PAUTO', '423749.27', '93.56', 'https://app.sushi.com', 'MATIC'],
#  ['dTOP', 'WETH', '2644406.90', '15.91', 'https://app.sushi.com', 'MATIC'],
#  ['USDC', 'BIFI', '749722.05', '52.73', 'https://app.sushi.com', 'MATIC'],
#  ['WBTC', 'ibBTC', '16222404.82', '14.60', 'https://app.sushi.com', 'MATIC'],
#  ['USDC',
#   'miMATIC',
#   '97961368.69',
#   '30.18',
#   'https://www.mai.finance',
#   'MATIC'],
#  ['QI',
#   'miMATIC',
#   '11932433.47',
#   '390.63',
#   'https://www.mai.finance',
#   'MATIC'],
#  ['USDC',
#   'Shark',
#   '1647.25',
#   '354.09',
#   'https://www.polyshark.finance',
#   'MATIC'],
#  ['WMATIC', '', '3072.03', '88.11', 'https://www.polyshark.finance', 'MATIC'],
#  ['WETH', '', '64.25', '2808.73', 'https://www.polyshark.finance', 'MATIC'],
#  ['Shark', '', '2002.09', '270.40', 'https://www.polyshark.finance', 'MATIC'],
#  ['WBTC', '', '4824.18', '37.41', 'https://www.polyshark.finance', 'MATIC'],
#  ['USDT', '', '2773.70', '65.06', 'https://www.polyshark.finance', 'MATIC'],
#  ['QUICK', '', '739.94', '243.88', 'https://www.polyshark.finance', 'MATIC'],
#  ['MUST', '', '14.76', '6113.55', 'https://www.polyshark.finance', 'MATIC'],
#  ['WMATIC',
#   'Shark',
#   '612.00',
#   '997.45',
#   'https://www.polyshark.finance',
#   'MATIC'],
#  ['DAI', '', '3869.48', '46.63', 'https://www.polyshark.finance', 'MATIC'],
#  ['WMATIC',
#   'Shark',
#   '795.41',
#   '1137.18',
#   'https://www.polyshark.finance',
#   'MATIC'],
#  ['USDC',
#   'ELECTRON',
#   '1684.10',
#   '2364.50',
#   'https://polyvalent.finance',
#   'MATIC'],
#  ['WMATIC',
#   'ELECTRON',
#   '675.11',
#   '5621.99',
#   'https://polyvalent.finance',
#   'MATIC'],
#  ['ELECTRON', '', '1917.59', '433.13', 'https://polyvalent.finance', 'MATIC'],
#  ['WMATIC',
#   'USDC',
#   '10702247.45',
#   '201.87',
#   'https://polyvalent.finance',
#   'MATIC'],
#  ['USDC', '', '2104.66', '169.13', 'https://polyvalent.finance', 'MATIC'],
#  ['WMATIC', '', '2105.78', '169.04', 'https://polyvalent.finance', 'MATIC'],
#  ['WETH', '', '3793.13', '93.84', 'https://polyvalent.finance', 'MATIC'],
#  ['USDT', '', '4190.72', '84.94', 'https://polyvalent.finance', 'MATIC'],
#  ['WBTC', '', '847.16', '420.17', 'https://polyvalent.finance', 'MATIC'],
#  ['AAVE', '', '1979.05', '179.86', 'https://polyvalent.finance', 'MATIC'],
#  ['SUSHI', '', '793.83', '448.40', 'https://polyvalent.finance', 'MATIC'],
#  ['QUICK', '', '891.05', '399.48', 'https://polyvalent.finance', 'MATIC'],
#  ['DAI', '', '4800.00', '74.16', 'https://polyvalent.finance', 'MATIC'],
#  ['WMATIC', 'PolyFi', '3011.62', '389.67', 'https://polyfi.io', 'MATIC'],
#  ['WMATIC', '', '10503.72', '10.14', 'https://polyfi.io', 'MATIC'],
#  ['USDT', '', '3362.64', '38.00', 'https://polyfi.io', 'MATIC'],
#  ['USDC', '', '6375.67', '20.04', 'https://polyfi.io', 'MATIC'],
#  ['DAI', '', '3423.40', '37.33', 'https://polyfi.io', 'MATIC'],
#  ['WBTC', '', '3652.44', '29.15', 'https://polyfi.io', 'MATIC'],
#  ['WETH', '', '500.48', '212.77', 'https://polyfi.io', 'MATIC'],
#  ['QUICK', '', '569.53', '186.97', 'https://polyfi.io', 'MATIC'],
#  ['AAVE', '', '1158.72', '91.90', 'https://polyfi.io', 'MATIC'],
#  ['USDC', '', '12.08', '320.13', 'https://www.polyape.online/', 'MATIC'],
#  ['USDT', '', '2.51', '1543.14', 'https://www.polyape.online/', 'MATIC'],
#  ['WMATIC', '', '0.37', '10491.95', 'https://www.polyape.online/', 'MATIC'],
#  ['WETH', '', '5.72', '675.50', 'https://www.polyape.online/', 'MATIC'],
#  ['WBTC', '', '70.42', '54.89', 'https://www.polyape.online/', 'MATIC'],
#  ['QUICK', '', '505.76', '7.64', 'https://www.polyape.online/', 'MATIC'],
#  ['WMATIC', 'APE', '42.54', '1148.22', 'https://www.polyape.online/', 'MATIC'],
#  ['DAI', '', '94.05', '41.10', 'https://www.polyape.online/', 'MATIC'],
#  ['PZAP', '', '306108.21', '118.62', 'https://farm.polyzap.finance', 'MATIC'],
#  ['USDC',
#   'PZAP',
#   '330490.06',
#   '377.99',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['PolyZap-LP', '', '0.00', 0, 'https://farm.polyzap.finance', 'MATIC'],
#  ['USDT',
#   'PZAP',
#   '90432.54',
#   '425.51',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['WETH',
#   'PZAP',
#   '80833.26',
#   '464.97',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['QUICK',
#   'PZAP',
#   '53410.63',
#   '462.69',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['WBTC',
#   'PZAP',
#   '60329.38',
#   '408.44',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['WMATIC',
#   'WETH',
#   '120693.23',
#   '103.26',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['PolyZap-LP', '', '0.00', 0, 'https://farm.polyzap.finance', 'MATIC'],
#  ['WMATIC',
#   'USDC',
#   '129937.65',
#   '100.35',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['USDC',
#   'DAI',
#   '208131.28',
#   '59.12',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['PolyZap-LP', '', '0.00', 0, 'https://farm.polyzap.finance', 'MATIC'],
#  ['WMATIC',
#   'LINK',
#   '137388.48',
#   '90.69',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['WMATIC',
#   'AAVE',
#   '159309.69',
#   '76.02',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['WMATIC',
#   'UNI',
#   '136954.27',
#   '88.42',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['WMATIC',
#   'WBTC',
#   '193815.10',
#   '62.50',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['WMATIC',
#   'QUICK',
#   '254811.09',
#   '47.58',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['WMATIC',
#   'PAUTO',
#   '15598.84',
#   '155.27',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['AURORA',
#   'WMATIC',
#   '8362.83',
#   '475.58',
#   'https://farm.polyzap.finance',
#   'MATIC'],
#  ['GMS', '', '0.00', 0, 'https://gemstones.finance', 'MATIC'],
#  ['WMATIC',
#   'USDC',
#   '10702245.15',
#   '280.35',
#   'https://gemstones.finance',
#   'MATIC'],
#  ['WMATIC',
#   'WETH',
#   '55709269.45',
#   '199.72',
#   'https://gemstones.finance',
#   'MATIC'],
#  ['USDC',
#   'WETH',
#   '85378693.57',
#   '343.32',
#   'https://gemstones.finance',
#   'MATIC'],
#  ['SLP', '', '0.00', 0, 'https://gemstones.finance', 'MATIC'],
#  ['WMATIC',
#   'WOOFY',
#   '805656.17',
#   '319.80',
#   'https://gemstones.finance',
#   'MATIC'],
#  ['SUSHI',
#   'WETH',
#   '859903.59',
#   '166.01',
#   'https://gemstones.finance',
#   'MATIC'],
#  ['GMS', 'USDC', '162912.59', '1242.86', 'https://gemstones.finance', 'MATIC'],
#  ['WMATIC',
#   'GMS',
#   '161150.33',
#   '1100.85',
#   'https://gemstones.finance',
#   'MATIC'],
#  ['kmWMATIC/USDC-LINK', '', '0.00', 0, 'https://gemstones.finance', 'MATIC'],
#  ['kmWETH/WMATIC-LINK', '', '0.00', 0, 'https://gemstones.finance', 'MATIC'],
#  ['kmWETH/USDT-LINK', '', '0.00', 0, 'https://gemstones.finance', 'MATIC'],
#  ['kmAAVE/USDC-LINK', '', '0.00', 0, 'https://gemstones.finance', 'MATIC'],
#  ['kmWBTC/DAI-LINK', '', '0.00', 0, 'https://gemstones.finance', 'MATIC'],
#  ['USDC', '', '96.23', 0, 'https://polypanda.finance', 'MATIC'],
#  ['USDT', '', '97.62', 0, 'https://polypanda.finance', 'MATIC'],
#  ['DAI', '', '46.65', 0, 'https://polypanda.finance', 'MATIC'],
#  ['WETH', '', '161.84', 0, 'https://polypanda.finance', 'MATIC'],
#  ['WBTC', '', '193.33', 0, 'https://polypanda.finance', 'MATIC'],
#  ['QUICK', '', '158.24', 0, 'https://polypanda.finance', 'MATIC'],
#  ['WMATIC', '', '138.49', 0, 'https://polypanda.finance', 'MATIC'],
#  ['Bamboo', '', '0.00', 0, 'https://polypanda.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polypanda.finance', 'MATIC'],
#  ['USDC', 'DAI', '52341189.27', 0, 'https://polypanda.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polypanda.finance', 'MATIC'],
#  ['PolyDoge', '', '173.37', 0, 'https://polypanda.finance', 'MATIC'],
#  ['SURF', '', '0.00', 0, 'https://polypanda.finance', 'MATIC'],
#  ['USDC',
#   'DFYN',
#   '3060362.95',
#   '356.72',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['DFYNLP', '', '0.00', 0, 'https://exchange.dfyn.network', 'MATIC'],
#  ['DFYNLP', '', '0.00', 0, 'https://exchange.dfyn.network', 'MATIC'],
#  ['USDC',
#   'USDT',
#   '45923805.67',
#   '40.62',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['DAI',
#   'USDT',
#   '27930730.04',
#   '46.25',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['USDC',
#   'DAI',
#   '25995840.14',
#   '47.31',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['USDC',
#   'WETH',
#   '11395599.90',
#   '86.23',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['ROUTE (PoS)',
#   'USDC',
#   '890037.94',
#   '548.47',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['ROUTE (PoS)',
#   'WETH',
#   '3188772.36',
#   '194.26',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['DFYNLP', '', '0.00', 0, 'https://exchange.dfyn.network', 'MATIC'],
#  ['CRV',
#   'WETH',
#   '1642574.80',
#   '186.36',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['DFYNLP', '', '0.00', 0, 'https://exchange.dfyn.network', 'MATIC'],
#  ['USDC',
#   'UNI',
#   '1483858.16',
#   '154.61',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['WMATIC',
#   'QUICK',
#   '1387075.02',
#   '220.91',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['DFYNLP', '', '0.00', 0, 'https://exchange.dfyn.network', 'MATIC'],
#  ['USDC',
#   'AAVE',
#   '1386728.15',
#   '165.43',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['USDC',
#   'LINK',
#   '1841381.12',
#   '166.62',
#   'https://exchange.dfyn.network',
#   'MATIC'],
#  ['RAPTOR', '', '0.00', 0, 'https://www.jurassicfarm.app', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.jurassicfarm.app', 'MATIC'],
#  ['WMATIC', '', '1527.77', '29.14', 'https://www.jurassicfarm.app', 'MATIC'],
#  ['WBTC', '', '692.78', '64.26', 'https://www.jurassicfarm.app', 'MATIC'],
#  ['WBTC', '', '692.78', '64.26', 'https://www.jurassicfarm.app', 'MATIC'],
#  ['QUICK', '', '204.31', '217.89', 'https://www.jurassicfarm.app', 'MATIC'],
#  ['USDT', '', '221.00', '201.43', 'https://www.jurassicfarm.app', 'MATIC'],
#  ['USDC', '', '233.44', '190.69', 'https://www.jurassicfarm.app', 'MATIC'],
#  ['RAPTOR',
#   'QUICK',
#   '526.79',
#   '972.04',
#   'https://www.jurassicfarm.app',
#   'MATIC'],
#  ['WMATIC',
#   'RAPTOR',
#   '467.38',
#   '1134.27',
#   'https://www.jurassicfarm.app',
#   'MATIC'],
#  ['Krill',
#   'RAPTOR',
#   '582.79',
#   '783.87',
#   'https://www.jurassicfarm.app',
#   'MATIC'],
#  ['USDC', 'MONO', '1992.23', '779.55', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['MONO', '', '7237.21', '105.43', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['WMATIC', '', '19874.18', '6.40', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['QUICK', '', '2987.41', '42.57', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['WETH', '', '130604.98', '0.97', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['USDC', '', '4523.12', '28.11', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['WMATIC',
#   'MONO',
#   '3280.66',
#   '232.76',
#   'https://monopolyfinance.xyz',
#   'MATIC'],
#  ['MONO',
#   'PolyDoge',
#   '982.27',
#   '274.21',
#   'https://monopolyfinance.xyz',
#   'MATIC'],
#  ['MONO', 'DFYN', '1559.88', '555.14', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['MONO',
#   'QUICK',
#   '519.28',
#   '1668.64',
#   'https://monopolyfinance.xyz',
#   'MATIC'],
#  ['MONO', 'PZAP', '719.72', '1280.54', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['MONO', 'UNI', '733.97', '1039.54', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['MONO',
#   'miMATIC',
#   '1428.32',
#   '534.19',
#   'https://monopolyfinance.xyz',
#   'MATIC'],
#  ['UFT', 'MONO', '927.66', '876.02', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['UFT', '', '4104.43', '61.96', 'https://monopolyfinance.xyz', 'MATIC'],
#  ['WMATIC', 'CSI', '38.53', '574.79', 'https://polyce.io', 'MATIC'],
#  ['USDC', 'CSI', '25.08', '600.67', 'https://polyce.io', 'MATIC'],
#  ['WMATIC', '', '197.44', '22.37', 'https://polyce.io', 'MATIC'],
#  ['WBTC', '', '36.97', '119.48', 'https://polyce.io', 'MATIC'],
#  ['WETH', '', '2029.67', '2.18', 'https://polyce.io', 'MATIC'],
#  ['USDT', '', '481.64', '4.59', 'https://polyce.io', 'MATIC'],
#  ['USDC', '', '86.40', '25.56', 'https://polyce.io', 'MATIC'],
#  ['DAI', '', '1.92', '1150.31', 'https://polyce.io', 'MATIC'],
#  ['QUICK', '', '1.97', '745.92', 'https://polyce.io', 'MATIC'],
#  ['SUSHI', '', '32.34', '45.53', 'https://polyce.io', 'MATIC'],
#  ['LINK', '', '4.24', '347.01', 'https://polyce.io', 'MATIC'],
#  ['CSI', '', '32.44', '340.38', 'https://polyce.io', 'MATIC'],
#  ['PolyDoge', '', '69.22', '10.64', 'https://polyce.io', 'MATIC'],
#  ['WMATIC', '', '33.44', '357.02', 'https://lumberjack.finance', 'MATIC'],
#  ['WBTC', '', '35.50', '336.30', 'https://lumberjack.finance', 'MATIC'],
#  ['WETH', '', '17.26', '691.71', 'https://lumberjack.finance', 'MATIC'],
#  ['USDC', '', '53.07', '224.95', 'https://lumberjack.finance', 'MATIC'],
#  ['SUSHI', '', '37.08', '322.03', 'https://lumberjack.finance', 'MATIC'],
#  ['ACORN', '', '0.00', 0, 'https://lumberjack.finance', 'MATIC'],
#  ['DAI', '', '15.49', '770.59', 'https://lumberjack.finance', 'MATIC'],
#  ['USDC', 'ACORN', '145.12', '670.89', 'https://lumberjack.finance', 'MATIC'],
#  ['USDC', 'PPNK', '100.55', '1055.70', 'https://polypunk.finance', 'MATIC'],
#  ['WETH', '', '180.08', '115.74', 'https://polypunk.finance', 'MATIC'],
#  ['USDC', '', '817.63', '25.49', 'https://polypunk.finance', 'MATIC'],
#  ['QUICK', '', '41.60', '375.73', 'https://polypunk.finance', 'MATIC'],
#  ['WMATIC', '', '1099.09', '18.96', 'https://polypunk.finance', 'MATIC'],
#  ['DAI', '', '970.29', '16.11', 'https://polypunk.finance', 'MATIC'],
#  ['Steak', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['WMATIC',
#   'Steak',
#   '188.07',
#   '1190.92',
#   'https://steakhouse.finance',
#   'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['MONKE',
#   'USDC',
#   '145.17',
#   '687.74',
#   'https://www.monkefarm.finance',
#   'MATIC'],
#  ['MONKE', '', '143.13', '176.75', 'https://www.monkefarm.finance', 'MATIC'],
#  ['WMATIC', '', '26.51', '477.16', 'https://www.monkefarm.finance', 'MATIC'],
#  ['WETH', '', '53.26', '475.03', 'https://www.monkefarm.finance', 'MATIC'],
#  ['WBTC', '', '31.75', '796.82', 'https://www.monkefarm.finance', 'MATIC'],
#  ['USDC', '', '97.41', '259.70', 'https://www.monkefarm.finance', 'MATIC'],
#  ['USDT', '', '75.88', '333.38', 'https://www.monkefarm.finance', 'MATIC'],
#  ['QUICK', '', '15.37', '822.80', 'https://www.monkefarm.finance', 'MATIC'],
#  ['NAN', '', '0.00', 0, 'https://www.monkefarm.finance', 'MATIC'],
#  ['USDC', 'NAN', '119.40', '427.27', 'https://www.monkefarm.finance', 'MATIC'],
#  ['LION', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['WETH', '', '22567.67', 0, 'https://polylion.exchange', 'MATIC'],
#  ['USDC', '', '11079.30', 0, 'https://polylion.exchange', 'MATIC'],
#  ['WMATIC', '', '24326.43', 0, 'https://polylion.exchange', 'MATIC'],
#  ['QUICK', '', '5840.25', 0, 'https://polylion.exchange', 'MATIC'],
#  ['USDT', '', '6286.49', 0, 'https://polylion.exchange', 'MATIC'],
#  ['WBTC', '', '5906.62', 0, 'https://polylion.exchange', 'MATIC'],
#  ['DAI', '', '5240.91', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['USDC', 'QUICK', '8719299.73', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['AAVE', '', '2606.64', 0, 'https://polylion.exchange', 'MATIC'],
#  ['LINK', '', '6888.92', 0, 'https://polylion.exchange', 'MATIC'],
#  ['PolyDoge', '', '6388.18', 0, 'https://polylion.exchange', 'MATIC'],
#  ['SUSHI', '', '4888.92', 0, 'https://polylion.exchange', 'MATIC'],
#  ['DAI', 'USDT', '12823177.99', 0, 'https://polylion.exchange', 'MATIC'],
#  ['BULL', 'USDC', '8443.94', '1285.81', 'https://polybull.finance', 'MATIC'],
#  ['WBTC', '', '11289.73', '86.85', 'https://polybull.finance', 'MATIC'],
#  ['WETH', '', '2261.71', '433.53', 'https://polybull.finance', 'MATIC'],
#  ['QUICK', '', '3670.91', '267.10', 'https://polybull.finance', 'MATIC'],
#  ['WMATIC', '', '54546.03', '50.33', 'https://polybull.finance', 'MATIC'],
#  ['USDC', '', '8275.56', '118.48', 'https://polybull.finance', 'MATIC'],
#  ['USDT', '', '3772.64', '259.90', 'https://polybull.finance', 'MATIC'],
#  ['DAI', '', '11796.62', '83.12', 'https://polybull.finance', 'MATIC'],
#  ['BULL', '', '9780.23', '401.02', 'https://polybull.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybull.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybull.finance', 'MATIC'],
#  ['WMATIC', 'BULL', '6731.58', '1586.26', 'https://polybull.finance', 'MATIC'],
#  ['BULL', 'QUICK', '2265.94', '1737.01', 'https://polybull.finance', 'MATIC'],
#  ['WMATIC',
#   'ORCA',
#   '1111.81',
#   '236.95',
#   'https://www.orcinuslabs.ca',
#   'MATIC'],
#  ['USDC', 'ORCA', '1152.07', '228.13', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['USDT', 'ORCA', '959.39', '285.85', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['ORCA', '', '2732.81', '90.76', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['USDC', '', '1302.77', '47.60', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['WMATIC', '', '804.06', '77.12', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['USDT', '', '1960.06', '22.15', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['WBTC', '', '1837.02', '33.76', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['WETH', '', '541.78', '114.46', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['SUSHI', '', '697.75', '106.65', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['LINK', '', '1069.65', '69.57', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['AAVE', '', '1682.44', '44.23', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['FISH', '', '0.00', 0, 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['Krill', '', '113.24', '657.14', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['ZERO', 'ORCA', '262.16', '976.38', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['APE',
#   'USDC',
#   '22.84',
#   '5657.69',
#   'https://www.polyapefinance.com',
#   'MATIC'],
#  ['WMATIC',
#   '',
#   '0.00',
#   '422370189.75',
#   'https://www.polyapefinance.com',
#   'MATIC'],
#  ['WETH',
#   '',
#   '0.00',
#   '17193377.16',
#   'https://www.polyapefinance.com',
#   'MATIC'],
#  ['APE', '', '11.59', '552.77', 'https://www.polyapefinance.com', 'MATIC'],
#  ['WBTC', '', '0.00', 0, 'https://www.polyapefinance.com', 'MATIC'],
#  ['USDT', '', '10.56', '151.64', 'https://www.polyapefinance.com', 'MATIC'],
#  ['QUICK',
#   '',
#   '0.00',
#   '352678079178222144.00',
#   'https://www.polyapefinance.com',
#   'MATIC'],
#  ['USDC', '', '19.74', '81.11', 'https://www.polyapefinance.com', 'MATIC'],
#  ['DAI', '', '0.96', '1668.06', 'https://www.polyapefinance.com', 'MATIC'],
#  ['WMATIC', '', '403.89', '122.55', 'https://polywolf.finance', 'MATIC'],
#  ['WBTC', '', '181.44', '272.78', 'https://polywolf.finance', 'MATIC'],
#  ['WETH', '', '139.83', '353.97', 'https://polywolf.finance', 'MATIC'],
#  ['USDT', '', '920.18', '53.79', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', '', '821.48', '60.25', 'https://polywolf.finance', 'MATIC'],
#  ['DAI', '', '1149.64', '43.05', 'https://polywolf.finance', 'MATIC'],
#  ['AAVE', '', '1175.10', '8.42', 'https://polywolf.finance', 'MATIC'],
#  ['QUICK', '', '487.09', '20.32', 'https://polywolf.finance', 'MATIC'],
#  ['Krill', '', '20.77', '476.64', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'WOLF', '1246.46', '1503.37', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'WOLF', '717.60', '1557.44', 'https://polywolf.finance', 'MATIC'],
#  ['WBTC', 'WOLF', '119.48', '2093.22', 'https://polywolf.finance', 'MATIC'],
#  ['WETH', 'WOLF', '152.60', '1646.63', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'USDC', '17641.27', '25.26', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'WETH', '13254.92', '22.42', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'QUICK', '1249.41', '39.86', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'DAI', '20700.41', '5.16', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'USDT', '1679.81', '370.78', 'https://polywolf.finance', 'MATIC'],
#  ['SUSHI', 'WETH', '96.06', '1249.99', 'https://polywolf.finance', 'MATIC'],
#  ['SUSHI', 'USDC', '840.29', '177.15', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'WETH', '917.35', '165.26', 'https://polywolf.finance', 'MATIC'],
#  ['WETH', 'USDT', '1565.12', '895.32', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'WBTC', '487.10', '305.16', 'https://polywolf.finance', 'MATIC'],
#  ['WOLF', '', '2410.92', '246.35', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'STACK', '90390.64', '135.76', 'https://stacker.vc', 'MATIC'],
#  ['USDC', 'Goat', '15.21', '1484.44', 'https://www.polygoat.finance', 'MATIC'],
#  ['WMATIC',
#   'Goat',
#   '11.15',
#   '3035.68',
#   'https://www.polygoat.finance',
#   'MATIC'],
#  ['Goat', '', '63.03', '421.65', 'https://www.polygoat.finance', 'MATIC'],
#  ['WMATIC', '', '976.84', '18.14', 'https://www.polygoat.finance', 'MATIC'],
#  ['QUICK', '', '31.87', '277.95', 'https://www.polygoat.finance', 'MATIC'],
#  ['WETH', '', '20.42', '433.87', 'https://www.polygoat.finance', 'MATIC'],
#  ['WBTC', '', '9.27', '955.34', 'https://www.polygoat.finance', 'MATIC'],
#  ['USDT', '', '39.04', '226.89', 'https://www.polygoat.finance', 'MATIC'],
#  ['AAVE', '', '50.08', '176.88', 'https://www.polygoat.finance', 'MATIC'],
#  ['LINK', '', '18.86', '469.62', 'https://www.polygoat.finance', 'MATIC'],
#  ['Krill', '', '0.88', '10018.10', 'https://www.polygoat.finance', 'MATIC'],
#  ['Snake', '', '0.56', '3250.09', 'https://www.polysnake.finance', 'MATIC'],
#  ['WETH', '', '6.98', '97.93', 'https://www.polysnake.finance', 'MATIC'],
#  ['WBTC', '', '17.91', '25.43', 'https://www.polysnake.finance', 'MATIC'],
#  ['WMATIC', '', '45.47', '10.02', 'https://www.polysnake.finance', 'MATIC'],
#  ['USDC',
#   'Snake',
#   '10.49',
#   '334.85',
#   'https://www.polysnake.finance',
#   'MATIC'],
#  ['USDT', '', '0.00', 0, 'https://www.polysnake.finance', 'MATIC'],
#  ['QUICK', '', '0.00', 0, 'https://www.polysnake.finance', 'MATIC'],
#  ['USDT', '', '22.41', '20.32', 'https://www.polysnake.finance', 'MATIC'],
#  ['Krill', '', '0.35', '1303.18', 'https://www.polysnake.finance', 'MATIC'],
#  ['DAI', '', '6.45', '70.66', 'https://www.polysnake.finance', 'MATIC'],
#  ['WOLF', '', '644684.88', '125.76', 'https://www.moonwolf.io', 'MATIC'],
# ...
#   '1295.14',
#   'https://polygon.prismfinance.net',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polygon.prismfinance.net', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polygon.prismfinance.net', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polygon.prismfinance.net', 'MATIC'],
#  ['PRISM',
#   '',
#   '449.27',
#   '230.53',
#   'https://polygon.prismfinance.net',
#   'MATIC'],
#  ['USDC', '', '17689.07', '4.10', 'https://polygon.prismfinance.net', 'MATIC'],
#  ['WMATIC',
#   '',
#   '1217.09',
#   '63.82',
#   'https://polygon.prismfinance.net',
#   'MATIC'],
#  ['USDT', '', '8693.23', '7.15', 'https://polygon.prismfinance.net', 'MATIC'],
#  ['WBTC', '', '91.22', '681.24', 'https://polygon.prismfinance.net', 'MATIC'],
#  ['WETH', '', '113.54', '547.31', 'https://polygon.prismfinance.net', 'MATIC'],
#  ['QUICK',
#   '',
#   '190.25',
#   '408.30',
#   'https://polygon.prismfinance.net',
#   'MATIC'],
#  ['AAVE', '', '1938.84', '40.06', 'https://polygon.prismfinance.net', 'MATIC'],
#  ['USDC',
#   'POLLEN',
#   '9.62',
#   '3638489.63',
#   'https://polybutterfly.finance',
#   'MATIC'],
#  ['POLLEN', '', '543.45', '562.05', 'https://polybutterfly.finance', 'MATIC'],
#  ['WMATIC',
#   '',
#   '0.01',
#   '22047059.97',
#   'https://polybutterfly.finance',
#   'MATIC'],
#  ['WETH',
#   '',
#   '0.00',
#   '1292159765.36',
#   'https://polybutterfly.finance',
#   'MATIC'],
#  ['WBTC', '', '5.33', '9543.98', 'https://polybutterfly.finance', 'MATIC'],
#  ['USDT', '', '0.98', '51788.50', 'https://polybutterfly.finance', 'MATIC'],
#  ['USDC',
#   '',
#   '0.00',
#   '1156982217.49',
#   'https://polybutterfly.finance',
#   'MATIC'],
#  ['DAI', '', '0.56', '91511.00', 'https://polybutterfly.finance', 'MATIC'],
#  ['QUICK', '', '0.82', '38854.92', 'https://polybutterfly.finance', 'MATIC'],
#  ['GEN', '', '0.00', 0, 'https://polybutterfly.finance', 'MATIC'],
#  ['KENNY', '', '1059.38', '276.35', 'https://southpark.finance/', 'MATIC'],
#  ['KENNY', '', '1059.38', '276.35', 'https://southpark.finance/', 'MATIC'],
#  ['USDC', 'KENNY', '895.67', '717.01', 'https://southpark.finance/', 'MATIC'],
#  ['WMATIC',
#   'KENNY',
#   '171.84',
#   '3012.96',
#   'https://southpark.finance/',
#   'MATIC'],
#  ['GEN', 'KENNY', '85.90', '4529.99', 'https://southpark.finance/', 'MATIC'],
#  ['WMATIC',
#   'WBTC',
#   '175670.83',
#   '1229.45',
#   'https://southpark.finance/',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://southpark.finance/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://southpark.finance/', 'MATIC'],
#  ['USDC',
#   'DAI',
#   '50925289.24',
#   '126.07',
#   'https://southpark.finance/',
#   'MATIC'],
#  ['USDC', '', '288.85', '168.93', 'https://southpark.finance/', 'MATIC'],
#  ['USDT', '', '233.21', '209.23', 'https://southpark.finance/', 'MATIC'],
#  ['DAI', '', '260.95', '186.99', 'https://southpark.finance/', 'MATIC'],
#  ['GEN', '', '305.25', '191.82', 'https://southpark.finance/', 'MATIC'],
#  ['WMATIC', '', '493.63', '197.69', 'https://southpark.finance/', 'MATIC'],
#  ['WBTC', '', '173.77', '561.61', 'https://southpark.finance/', 'MATIC'],
#  ['WETH', '', '370.35', '210.80', 'https://southpark.finance/', 'MATIC'],
#  ['WMATIC', 'CASH', '935.71', '1919.03', 'https://polycash.finance', 'MATIC'],
#  ['CASH', '', '591.25', '585.53', 'https://polycash.finance', 'MATIC'],
#  ['WMATIC', '', '1304.29', '106.17', 'https://polycash.finance', 'MATIC'],
#  ['DAI', '', '699.95', '197.84', 'https://polycash.finance', 'MATIC'],
#  ['WETH', '', '11960.03', '11.58', 'https://polycash.finance', 'MATIC'],
#  ['WBTC', '', '1187.56', '116.61', 'https://polycash.finance', 'MATIC'],
#  ['USDT', '', '1173.66', '117.99', 'https://polycash.finance', 'MATIC'],
#  ['SUSHI', '', '927.41', '149.32', 'https://polycash.finance', 'MATIC'],
#  ['USDC', '', '1618.25', '85.57', 'https://polycash.finance', 'MATIC'],
#  ['FISH', '', '0.00', 0, 'https://polycash.finance', 'MATIC'],
#  ['miMATIC', 'CASH', '380.57', '2099.66', 'https://polycash.finance', 'MATIC'],
#  ['miMATIC', '', '1481.24', '93.49', 'https://polycash.finance', 'MATIC'],
#  ['USDC',
#   'DINO',
#   '1971.49',
#   '4715.27',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['WMATIC',
#   'DINO',
#   '859.91',
#   '9766.31',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['DINO',
#   '',
#   '12664.70',
#   '324.94',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['WMATIC',
#   '',
#   '7809.06',
#   '210.80',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['AAVE',
#   '',
#   '3190.78',
#   '180.57',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['WBTC',
#   '',
#   '4205.32',
#   '234.86',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['QUICK',
#   '',
#   '435.22',
#   '2269.36',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['WETH',
#   '',
#   '1732.40',
#   '712.65',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['DAI',
#   '',
#   '3728.34',
#   '220.76',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['LINK',
#   '',
#   '1301.15',
#   '442.80',
#   'https://dinosaurfinance.vercel.app',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://dinosaurfinance.vercel.app', 'MATIC'],
#  ['DRAX', '', '53552.03', '0.00', 'https://defimagic.io', 'MATIC'],
#  ['USDC', 'MICE', '15.94', '1819.34', 'https://polymouse.finance', 'MATIC'],
#  ['WMATIC', 'MICE', '23.61', '611.96', 'https://polymouse.finance', 'MATIC'],
#  ['MICE', '', '32.12', '356.67', 'https://polymouse.finance', 'MATIC'],
#  ['WMATIC', '', '1.40', '4676.52', 'https://polymouse.finance', 'MATIC'],
#  ['QUICK', '', '17.35', '377.27', 'https://polymouse.finance', 'MATIC'],
#  ['USDC', '', '55.05', '118.92', 'https://polymouse.finance', 'MATIC'],
#  ['WETH', '', '3.14', '2087.71', 'https://polymouse.finance', 'MATIC'],
#  ['LINK', '', '4.05', '1616.63', 'https://polymouse.finance', 'MATIC'],
#  ['AAVE', '', '10.60', '617.83', 'https://polymouse.finance', 'MATIC'],
#  ['SUSHI', '', '3.13', '2093.51', 'https://polymouse.finance', 'MATIC'],
#  ['QUICK', 'MICE', '8.22', '1604.71', 'https://polymouse.finance', 'MATIC'],
#  ['WMATIC',
#   'TIGON',
#   '104.68',
#   '6092.78',
#   'https://www.polytiger.com/',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polytiger.com/', 'MATIC'],
#  ['WMATIC', '', '110.63', '95.52', 'https://www.polytiger.com/', 'MATIC'],
#  ['USDT', '', '162.48', '65.04', 'https://www.polytiger.com/', 'MATIC'],
#  ['DAI', '', '72.96', '144.85', 'https://www.polytiger.com/', 'MATIC'],
#  ['USDC', '', '247.04', '42.78', 'https://www.polytiger.com/', 'MATIC'],
#  ['WBTC', '', '21.76', '485.65', 'https://www.polytiger.com/', 'MATIC'],
#  ['WETH', '', '40.59', '260.35', 'https://www.polytiger.com/', 'MATIC'],
#  ['QUICK', '', '7.49', '1411.86', 'https://www.polytiger.com/', 'MATIC'],
#  ['AAVE', '', '67.43', '156.73', 'https://www.polytiger.com/', 'MATIC'],
#  ['SUSHI', '', '104.15', '101.47', 'https://www.polytiger.com/', 'MATIC'],
#  ['LINK', '', '40.55', '260.58', 'https://www.polytiger.com/', 'MATIC'],
#  ['FISH', '', '0.00', 0, 'https://www.polytiger.com/', 'MATIC'],
#  ['TIGON', 'USDT', '24.82', '3865.31', 'https://www.polytiger.com/', 'MATIC'],
#  ['USDC', 'DEER', '44.37', '1201.39', 'https://polydeer.finance', 'MATIC'],
#  ['USDC', 'DEER', '44.37', '3003.47', 'https://polydeer.finance', 'MATIC'],
#  ['USDC', 'DEER', '44.37', '6006.95', 'https://polydeer.finance', 'MATIC'],
#  ['WMATIC', 'DEER', '89.65', '291.38', 'https://polydeer.finance', 'MATIC'],
#  ['WMATIC', 'DEER', '89.65', '728.46', 'https://polydeer.finance', 'MATIC'],
#  ['WMATIC', 'DEER', '89.65', '1456.92', 'https://polydeer.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polydeer.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polydeer.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polydeer.finance', 'MATIC'],
#  ['QUICK', '', '83.70', '59.07', 'https://polydeer.finance', 'MATIC'],
#  ['QUICK', '', '83.70', '184.59', 'https://polydeer.finance', 'MATIC'],
#  ['QUICK', '', '83.70', '516.84', 'https://polydeer.finance', 'MATIC'],
#  ['WETH', '', '3172.09', '0.97', 'https://polydeer.finance', 'MATIC'],
#  ['WETH', '', '3172.09', '2.92', 'https://polydeer.finance', 'MATIC'],
#  ['WETH', '', '3172.09', '8.77', 'https://polydeer.finance', 'MATIC'],
#  ['DAI', '', '24.01', '128.67', 'https://polydeer.finance', 'MATIC'],
#  ['DAI', '', '24.01', '386.01', 'https://polydeer.finance', 'MATIC'],
#  ['DAI', '', '24.01', '1029.37', 'https://polydeer.finance', 'MATIC'],
#  ['WBTC', '', '2.37', '1304.56', 'https://polydeer.finance', 'MATIC'],
#  ['WBTC', '', '2.37', '3913.67', 'https://polydeer.finance', 'MATIC'],
#  ['WBTC', '', '2.37', '10436.45', 'https://polydeer.finance', 'MATIC'],
#  ['AAVE', '', '4.64', '665.75', 'https://polydeer.finance', 'MATIC'],
#  ['AAVE', '', '4.64', '1997.25', 'https://polydeer.finance', 'MATIC'],
#  ['AAVE', '', '4.64', '5325.99', 'https://polydeer.finance', 'MATIC'],
#  ['DEER', '', '409.77', '22.62', 'https://polydeer.finance', 'MATIC'],
#  ['DEER', '', '409.77', '75.41', 'https://polydeer.finance', 'MATIC'],
#  ['DEER', '', '409.77', '150.82', 'https://polydeer.finance', 'MATIC'],
#  ['WMATIC', '', '840.98', '5.88', 'https://polydeer.finance', 'MATIC'],
#  ['WMATIC', '', '840.98', '18.37', 'https://polydeer.finance', 'MATIC'],
#  ['WMATIC', '', '840.98', '55.11', 'https://polydeer.finance', 'MATIC'],
#  ['USDT', '', '189.77', '26.05', 'https://polydeer.finance', 'MATIC'],
#  ['USDT', '', '189.77', '81.41', 'https://polydeer.finance', 'MATIC'],
#  ['USDT', '', '189.77', '244.24', 'https://polydeer.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polydeer.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polydeer.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polydeer.finance', 'MATIC'],
#  ['Shield', '', '22.82', '1056.82', 'https://avengers.exchange', 'MATIC'],
#  ['USDC', 'Shield', '13.56', '2044.29', 'https://avengers.exchange', 'MATIC'],
#  ['WBTC', '', '0.98', '1542.09', 'https://avengers.exchange', 'MATIC'],
#  ['WMATIC', '', '5.66', '266.29', 'https://avengers.exchange', 'MATIC'],
#  ['USDT', '', '0.05', '31477.80', 'https://avengers.exchange', 'MATIC'],
#  ['QUICK', '', '0.05', '27623.04', 'https://avengers.exchange', 'MATIC'],
#  ['Krill', '', '0.18', '169.21', 'https://avengers.exchange', 'MATIC'],
#  ['DAI', '', '4.78', '315.44', 'https://avengers.exchange', 'MATIC'],
#  ['WETH', '', '2.73', '552.42', 'https://avengers.exchange', 'MATIC'],
#  ['USDC', '', '22.26', '67.72', 'https://avengers.exchange', 'MATIC'],
#  ['SUSHI', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['LINK', '', '211.66', '7.12', 'https://avengers.exchange', 'MATIC'],
#  ['AAVE', '', '6.26', '240.60', 'https://avengers.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['DAI', 'USDT', '12820844.41', '34.39', 'https://avengers.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['USDC',
#   'QUICK',
#   '8709168.06',
#   '12.31',
#   'https://avengers.exchange',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['WETH', 'QUICK', '12745812.55', 0, 'https://avengers.exchange', 'MATIC'],
#  ['WETH', 'UNI', '59992.10', '329.04', 'https://avengers.exchange', 'MATIC'],
#  ['IRON', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['FISH', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['WMATIC', 'Shield', '4.69', '9407.01', 'https://avengers.exchange', 'MATIC'],
#  ['USDT', 'Shield', '3.97', '18603.27', 'https://avengers.exchange', 'MATIC'],
#  ['MALT', '', '0.00', 0, 'https://avengers.exchange', 'MATIC'],
#  ['USDC', 'BRSK', '5132.99', '467.06', 'https://berserkfinance.com', 'MATIC'],
#  ['WMATIC',
#   'BRSK',
#   '4562.54',
#   '696.86',
#   'https://berserkfinance.com',
#   'MATIC'],
#  ['BRSK', '', '5624.29', '54.17', 'https://berserkfinance.com', 'MATIC'],
#  ['WMATIC', '', '380.99', '279.87', 'https://berserkfinance.com', 'MATIC'],
#  ['USDC', '', '2146.54', '49.67', 'https://berserkfinance.com', 'MATIC'],
#  ['WETH', '', '306.56', '347.82', 'https://berserkfinance.com', 'MATIC'],
#  ['WBTC', '', '233.79', '456.09', 'https://berserkfinance.com', 'MATIC'],
#  ['USDT', '', '323.52', '329.58', 'https://berserkfinance.com', 'MATIC'],
#  ['BRSK', 'WETH', '178.88', '4308.79', 'https://berserkfinance.com', 'MATIC'],
#  ['WBTC', 'BRSK', '1649.95', '466.69', 'https://berserkfinance.com', 'MATIC'],
#  ['BRSK', 'DAI', '317.73', '2417.60', 'https://berserkfinance.com', 'MATIC'],
#  ['BRSK', 'LINK', '289.90', '4074.27', 'https://berserkfinance.com', 'MATIC'],
#  ['BRSK', 'QUICK', '287.09', '2670.99', 'https://berserkfinance.com', 'MATIC'],
#  ['BRSK', 'AAVE', '230.02', '3336.91', 'https://berserkfinance.com', 'MATIC'],
#  ['MOCA', '', '167692.26', '427.67', 'https://museumofcryptoart.com', 'MATIC'],
#  ['WETH',
#   'MOCA',
#   '520123.57',
#   '738.16',
#   'https://museumofcryptoart.com',
#   'MATIC'],
#  ['USDC',
#   'MOCA',
#   '552925.06',
#   '772.39',
#   'https://museumofcryptoart.com',
#   'MATIC'],
#  ['USDC',
#   'SPACE',
#   '170.87',
#   '991.18',
#   'https://polygon.space-defi.com/',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polygon.space-defi.com/', 'MATIC'],
#  ['SPACE', '', '87.19', '767.20', 'https://polygon.space-defi.com/', 'MATIC'],
#  ['WMATIC',
#   '',
#   '199.04',
#   '252.05',
#   'https://polygon.space-defi.com/',
#   'MATIC'],
#  ['WMATIC',
#   'SPACE',
#   '295.03',
#   '689.91',
#   'https://polygon.space-defi.com/',
#   'MATIC'],
#  ['WETH', '', '412.48', '97.30', 'https://polygon.space-defi.com/', 'MATIC'],
#  ['USDC', '', '134.69', '372.47', 'https://polygon.space-defi.com/', 'MATIC'],
#  ['USDT', '', '220.03', '182.40', 'https://polygon.space-defi.com/', 'MATIC'],
#  ['QUICK', '', '89.11', '525.46', 'https://polygon.space-defi.com/', 'MATIC'],
#  ['WBTC', '', '1613.90', '24.87', 'https://polygon.space-defi.com/', 'MATIC'],
#  ['AAVE', '', '2128.85', '21.99', 'https://polygon.space-defi.com/', 'MATIC'],
#  ['DAI', '', '249.51', '160.85', 'https://polygon.space-defi.com/', 'MATIC'],
#  ['Krill', '', '15.68', '2132.87', 'https://polygon.space-defi.com/', 'MATIC'],
#  ['SPCT', '', '0.00', 0, 'https://polygon.space-defi.com/', 'MATIC'],
#  ['USDC', 'GLOCK', '4.22', '71591.45', 'https://www.glockswap.com', 'MATIC'],
#  ['GLOCK', '', '77.50', '7233.72', 'https://www.glockswap.com', 'MATIC'],
#  ['WMATIC', '', '434.93', '483.35', 'https://www.glockswap.com', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.glockswap.com', 'MATIC'],
#  ['WETH', '', '271.79', '515.65', 'https://www.glockswap.com', 'MATIC'],
#  ['DAI', '', '1.06', '132774.77', 'https://www.glockswap.com', 'MATIC'],
#  ['QUICK', '', '71.65', '1955.90', 'https://www.glockswap.com', 'MATIC'],
#  ['WBTC', '', '17.35', '8077.83', 'https://www.glockswap.com', 'MATIC'],
#  ['USDT', '', '16.46', '8516.50', 'https://www.glockswap.com', 'MATIC'],
#  ['WMATIC',
#   'xUSD',
#   '77877.99',
#   '256.83',
#   'https://xdollar.mcn.ventures',
#   'MATIC'],
#  ['xUSD', '', '2019458.36', '156.52', 'https://xdollar.mcn.ventures', 'MATIC'],
#  ['XDO', '', '253478.19', 0, 'https://xdollar.mcn.ventures', 'MATIC'],
#  ['USDC',
#   'Carrot',
#   '78.19',
#   '4619.98',
#   'https://www.polycarrot.finance',
#   'MATIC'],
#  ['Carrot',
#   '',
#   '156.86',
#   '1087.08',
#   'https://www.polycarrot.finance',
#   'MATIC'],
#  ['WMATIC',
#   'Bunny',
#   '843.77',
#   '124.69',
#   'https://www.polycarrot.finance',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycarrot.finance', 'MATIC'],
#  ['Bunny', '', '1123.69', '12.65', 'https://www.polycarrot.finance', 'MATIC'],
#  ['WMATIC', '', '261.52', '217.35', 'https://www.polycarrot.finance', 'MATIC'],
#  ['DAI', '', '96.96', '205.18', 'https://www.polycarrot.finance', 'MATIC'],
#  ['WETH', '', '98.80', '201.37', 'https://www.polycarrot.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycarrot.finance', 'MATIC'],
#  ['USDC',
#   'DAI',
#   '50925397.15',
#   '493.72',
#   'https://www.polycarrot.finance',
#   'MATIC'],
#  ['WMATIC', '8BALL', '995.26', '2681.93', 'https://8ballfinance.io', 'MATIC'],
#  ['USDC', '8BALL', '845.17', '2535.98', 'https://8ballfinance.io', 'MATIC'],
#  ['8BALL', '', '709.53', '976.35', 'https://8ballfinance.io', 'MATIC'],
#  ...]

# %%
pair_df = pair_df.drop(pair_df[pair_df['pair1'] == ''].index)

# %%
pair_df[pair_df['pair1'] == '']
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, tvl, apr, where, network, apy]
# Index: []

# %%
pair_df[pair_df['network'] == 'Alternate']['network'] = 'ETH'

# %%
sheet_pairs_df = pd.DataFrame([])
eth_sheet_pairs_df = pd.read_csv('Alternate Yields 7-1.csv')
# eth_sheet_pairs_df.columns=['pair1', 'pair2', 'tvl', 'where', 'apr']
eth_sheet_pairs_df['apy'] = np.nan
eth_sheet_pairs_df['network'] = 'ETH'
sheet_pairs_df = sheet_pairs_df.append(eth_sheet_pairs_df)
sheet_pairs_df['pair2'] = sheet_pairs_df['pair2'].fillna('')

# %%
sheet_pairs_df
# Out:
#      pair1 pair2           tvl       apr                         where  \
# 0     WETH  USDT  2.741531e+08     11.73  https://app.sushi.com/farms/
# 1     USDC  WETH  3.345186e+08     12.16  https://app.sushi.com/farms/
# 2      DAI  WETH  2.260552e+08     13.93  https://app.sushi.com/farms/
# 3     sUSD  WETH  9.648626e+06     17.68  https://app.sushi.com/farms/
# 4     COMP  WETH  2.393832e+07      8.77  https://app.sushi.com/farms/
# ..     ...   ...           ...       ...                           ...
# 262   LINK  USDC  0.000000e+00        --         https://app.compli.fi
# 263    UNI  USDC  0.000000e+00        --         https://app.compli.fi
# 264    UNI  USDC  1.088958e+04   9841.67         https://app.compli.fi
# 265    UNI  USDC  5.616700e+03   19080.9         https://app.compli.fi
# 266  COMFI  WETH  6.895975e+05  25635.31         https://app.compli.fi
#
#     network  apy
# 0       ETH  NaN
# 1       ETH  NaN
# 2       ETH  NaN
# 3       ETH  NaN
# 4       ETH  NaN
# ..      ...  ...
# 262     ETH  NaN
# 263     ETH  NaN
# 264     ETH  NaN
# 265     ETH  NaN
# 266     ETH  NaN
#
# [267 rows x 7 columns]

# %%
def update_apr(apr):
    apr = f"{apr}".replace("%", "")
    if len(apr) == 0 or "nan" == apr:
        return np.nan
    else:
        return apr

# %%
def get_symbol_mapping(pair):
    if pair is not None:
        return sm[pair.strip()] if pair.strip() in sm else pair.strip()
    else:
        return ""

# %%
pair_df = pair_df.append(sheet_pairs_df).reset_index(drop=True)
pair_df['type_of_agriculture'] = 'FARM'
pair_df = pair_df.append(df).reset_index(drop=True)

# %%
pair_df['apr'] = pair_df['apr'].apply(lambda x: update_apr(x))
pair_df['pair1'] = pair_df['pair1'].apply(lambda x: sm[x.strip()] if x.strip() in sm else x.strip())
pair_df['pair2'] = pair_df['pair2'].apply(lambda x: get_symbol_mapping(x))

# %%
pair_df['pair2'].unique()
# Out:
# array(['', 'QUICK', 'DAI', 'TEL', 'WISE', 'CEL', 'ETH', 'PolyDoge',
#        'EMON', 'SX', 'WOLF', 'AGAr', 'UNI', 'USDT', 'FXS', 'DEGEN',
#        'GAME', 'CC10', 'UBT', 'mOCEAN', 'miFARM', 'SUPER', 'xMARK', 'IGG',
#        'BTU', 'NFTP', 'PLOT', 'DRC', 'DMT', 'DSLA', 'MUST', 'pBTC',
#        'bDIGG', 'xSDT', 'sdcrvRenWSBTC', 'AAVE', 'STR', 'NDR', 'BTC',
#        'WMATIC', '$TRDL', 'mWETH', 'RAZOR', 'NIOX', 'USDC', 'ELK', 'CXO',
#        'FOX', 'FIRE', 'SPR', 'GAJ', 'STONK', 'NEBULA', 'SOLAR', 'WOOFY',
#        'ADDY', 'WFIL', 'DHT', 'PAUTO', 'BIFI', 'ibBTC', 'miMATIC',
#        'Shark', 'ELECTRON', 'PolyFi', 'APE', 'PZAP', 'LINK', 'GMS',
#        'DFYN', 'RAPTOR', 'MONO', 'CSI', 'ACORN', 'PPNK', 'Steak', 'NAN',
#        'BULL', 'ORCA', 'STACK', 'Goat', 'Snake', 'MOON', 'TITAN', 'IRON',
#        'ALCH', 'CRAB', 'BEAR', 'STONKX', 'PLX', 'SDS', 'MAPLE', 'PUSSY',
#        'SWAN', 'Lion', 'BOOTY', 'PINGU', 'GBULL', 'HACHI', 'POLYAKITA',
#        'PRISM', 'POLLEN', 'KENNY', 'CASH', 'DINO', 'MICE', 'TIGON',
#        'DEER', 'Shield', 'BRSK', 'MOCA', 'SPACE', 'GLOCK', 'xUSD',
#        'Carrot', 'Bunny', '8BALL', 'MORDOR', 'VERT', 'Zero', 'MAX',
#        'SN0W', 'YELD', 'DUFF', 'WEXpoly', 'ELE', 'WAULTx', 'FISH',
#        'HONOR', 'Wheat', 'TREAT', 'PWOOF', 'COSMIC', 'Stonky', 'JAVA',
#        'SLOWPOKE', 'Rocket', 'Comet', 'KOGECOIN', 'PGOV', 'XBULL', 'OMEN',
#        'MEME', 'DPS', 'SIN', 'HND', 'QuickChart', 'FUNK', 'CUBAN',
#        'PolyGame', 'CRS', 'CRYSTL', 'CRV', 'JDI', 'SNX', 'TAPE', 'pSPACE',
#        'TAKO', 'HOPE', 'ROLL', 'HERO', 'BPUL', 'BNT', 'LEGO', 'RDT',
#        'PYQ', 'PUSD', 'OIL', 'BREW', 'DMND', 'GRASS', 'HIPPO', 'PepeFarm',
#        'BONE', 'PUP', 'RUBY', 'PolyZeus', 'BNB', 'BUSD', 'XVS', 'REEF',
#        'HGET', 'SFP', 'COMP', 'BRY', 'SUSHI', 'TPT', 'BELT', 'BUNNY',
#        'MIR', 'BTCB', 'pCWS', 'GUM', 'ODDZ', 'JGN', 'ALPA', 'HZN',
#        'bROOBEE', 'mCOIN', 'MATH', 'CHR', 'WELL', 'SWG', 'KTN', 'BORING',
#        'O3', 'ORBS', 'ADA', 'IOTA', 'BAKE', 'SWAMP', 'ONT', 'MATIC',
#        'GRAND', 'LORY', 'SOUL', 'EGG', 'MDX', 'DOT', 'BETH', 'BGOV',
#        'AUTO', 'DOGE', 'BARK', 'TOKAU', 'KEBAB', 'NYAN', 'EOS', 'NYAS',
#        'NYAC', 'APESOX', 'FLP', 'SLME', 'ALICE', 'TREE', 'RUNE', 'STAKD',
#        'ICE', '888', 'BLIQ', 'MYTHIC', 'WEX', 'ALPACA', 'ACSI', 'SASHIMI',
#        'ELF', 'TOAD', 'LYPTUS', 'TACO', 'CRL', 'STEEL', 'dETH', 'dADA',
#        'NAR', 'xBLZD', 'WATCH', 'ALLOY', 'SPHN', 'DVT', 'KEIF', 'renBTC',
#        'renZEC', 'renBCH', 'JulD', 'VOXb', 'OBRb', 'SWGb', 'ETHb', 'SBS',
#        'BANANA', 'BLUE', 'GREEN', 'BRICK', 'gRUPEE', 'COM+', 'HT', 'BNB+',
#        'HMDX', 'SXP', 'ALIFE', 'ZBO', 'BCU', 'PMP', 'TABLE', 'LEGEND',
#        'MIST', 'PSI', 'PALM', 'ABS', 'MCAKE', 'yumcha', 'ycVT', 'bBDO',
#        'cCAKE', 'BSCDOG', 'PIANO', 'MELODY', 'SEED', 'NIU', 'BBOO',
#        'ABRA', 'CCAKE', 'ZEX', 'DBALL', 'SENZU', 'MANY', 'BSCX', 'DODO',
#        'Helmet', 'TKO', 'SAFEMOON', 'BTT', 'TRX', 'MASH', 'VAULT', 'PLUM',
#        'TOFY', 'XWIN', 'SDO', 'SSO', 'HARD', 'PASTA', 'TRIP', 'CHS',
#        'PIZZA', 'Cake-LP', 'MOUSE', 'LAMA', 'CHAR', 'KLING', 'BORG-LP',
#        'SOJU', 'SAKE', 'BBKFI', 'WXDN', 'CBRL', 'VEGAN', 'FSXU', 'BRRL',
#        'WPEPS', 'EMBY', 'WCMG', 'PEPR', 'Latte', 'sLKM', 'gROOT', 'NEON',
#        'JAZZ', 'YOLO', 'wGOLD', 'wGRUNT', 'wARCHER', 'wORC-ARCHER',
#        'wARMORED-WARRIOR', 'wCROSSBOW-MAN', 'wSKELETON-WARRIOR', 'GENX',
#        'GMEv3', 'GEN', 'LIME', 'UNFT', 'TeamTrees', 'TRUCK', 'ToUranus',
#        'NMX', 'DSL', 'yBEAR', 'MOONSTAR', 'sBEAR', 'APACHE', 'MANGO',
#        'KIWI', 'BAMI', 'VNDC', 'PNDA', 'ANKR', 'CREAM', 'vUSDC', 'SPARTA',
#        'vUSDT', 'ANY', 'UBXT', 'BAMBOO', 'RHINO', 'JAWS', 'MEL', 'JAGUAR',
#        'Zombie', 'Phantom', 'aDGNZ', 'BSC', 'BULLDOGE', 'POODL', 'bPUP',
#        'AUSSIE', 'FLOOFY', 'VB-DOGEKILLER', 'KaiInu', 'LAIKA', 'dUSD',
#        'BBQ', 'SOAK', 'AQUA', 'GOAL', 'PUL', 'GARUDA', 'xSAT', 'SMTY',
#        'ELXR', 'mAMZN', 'mGOOGL', 'mNFLX', 'mTSLA', 'MX', 'GMT', 'xGMT',
#        'EGGP', 'GRZ', 'TENFI', 'Field', 'wBBP', 'wTROLL', 'FRANK',
#        'TINVS', 'TINV', 'BSW', 'BFG', 'CERBERUS', 'UST', 'LAZY', 'TNDR',
#        'KETCHUP', 'SKUNK', 'BEV', 'GBEN', 'MARS', 'CAKF', 'KSF', 'SUGAR',
#        'TeaSportV1', 'GSSIT', 'WEREWOLF', 'LAVA', 'MAYO', 'SIBERIAN',
#        'MARMEL', 'ANT', 'SAFEANT', 'ADR', 'TBIRD', 'VENOM', 'RICE', 'MU',
#        'Qi', 'DY', 'BRU', 'DUB', 'UNOWN', 'RBH', 'DEK', 'HGT', 'CARNAGE',
#        'HALVAR', 'FAXE', 'WHALE', 'FROZEN', 'YOGI 80%', 'WBNB 50%',
#        'BTCB 50%', 'BUSD 50%', 'TOMAHAWK', 'BER', 'U235', 'RASTA',
#        'MRASTA', 'AVAX', 'PNG', 'YFI', 'SPORE', 'zUSDC', 'zETH', 'zUSDT',
#        'zBTC', 'zUNI', 'zSUSHI', 'zDAI', 'BAMBOO-V2', 'SNOB', 'PEFI',
#        'MKC', 'NEKO', 'XAVA', 'BAG', 'GDL', 'CNR', '1INCH', 'VSP', 'TORN',
#        'OPIUM', 'stETH', 'ARMOR', 'WETH 2%', 'ARMOR 2%', 'arNXM', 'BAS',
#        'BSGS', 'BSG', 'DEBASE', 'DPX', 'ICHI', 'oneBTC', 'DEFI5', 'ORCL5',
#        'ERROR', 'MORT', 'MM', 'ONC', 'PEGS', 'BAL', 'yveCRV-DAO', 'mAAPL',
#        'TRIBE', 'ALCX', 'tfTUSD', 'UPDOWN', 'XUS', 'YFLUSD', 'vETH2',
#        'VBTC', 'xINCHa', 'xINCHb', 'USDC 50%', 'wBTC', 'tBTC', 'BDP',
#        'USF', 'SI', 'vETH', 'FOTO', 'FANS', 'WETH 20%', 'USDC 20%',
#        'Gaia', 'KINE', 'kUSD', 'MASK20', 'GPUNKS20', 'MCAT20', 'GCG',
#        'TABOY20', 'KBTC', 'KlonX', 'COTI', 'GOVI', 'USDN', 'PAR 50%',
#        'DOUGH', 'DOUGH 80%', 'WETH 30%', 'WHEY', 'PUSH', 'HOKK', 'HUSKY',
#        'renDOGE', 'HOGE', 'MUSKY', 'DOGEN', 'BDOG', 'HACHIKO', 'WDOGE',
#        'SOGE', 'Tosa', 'DIASPORA', 'sAAPL 20%', 'sAMZN 20%', 'sCOIN 20%',
#        'sFB 20%', 'sGOOG 20%', 'sMSFT 20%', 'sNFLX 20%', 'LFBTC', 'LFETH',
#        'LIFT', 'uBEEPLE', 'uGONE', 'uGLYPH', 'uARTBLOCKS', 'uFEWO',
#        'CONV', 'KNC', 'FARM', 'sbtcCRV', 'sbtcCrv', 'BOO', 'FTM', 'BAND',
#        'COVER', 'BADGER', 'SPIRIT', 'FRAX', 'BITB', 'GTON', 'SON', 'BORG',
#        'AURORA', 'BORGDAI', 'FUSD', 'OPE', 'UBI', 'ORI', 'ESWAP', 'FROYO',
#        'GHOST', 'LQDR', 'WAKA', 'ATRI', 'BOMB', 'Shiba', 'DSTEIN',
#        'BRUSH', 'CHAD', 'TOMB', 'TSHARE', 'SHADOW', 'OPERA', 'YORO',
#        'HODL', 'CATNIP', 'SPOON', 'OMG', 'AMP', 'RARI', 'SEEN', 'INJ',
#        'BCP', 'CRETH2', 'DIGG', 'pWING', 'RGT', 'ibETHv2', 'YLD', 'GRT',
#        'FEMALE', 'ATTR', 'PUNK', 'ZRX', 'DUCK', 'BASIC', 'ROOK', 'FLI',
#        'DG', 'MLN', 'SAK3', 'FOLD', '1ONE', 'WBNB (Cake)', 'WBNB (Uni)',
#        'SRM', 'RAY', 'SOL', 'oDOP', 'SDC', 'unknown'], dtype=object)

# %%
pair_df
# Out:
#        pair1 pair2             tvl   apr                               where  \
# 0     UNI-V2                  0.00     0  https://quickswap.exchange/#/quick
# 1     UNI-V2                  0.00     0  https://quickswap.exchange/#/quick
# 2     UNI-V2                  0.00     0  https://quickswap.exchange/#/quick
# 3     UNI-V2                  0.00     0  https://quickswap.exchange/#/quick
# 4     UNI-V2                  0.00     0  https://quickswap.exchange/#/quick
# ...      ...   ...             ...   ...                                 ...
# 8300    WOOF  USDC        0.695141   0.0                             Raydium
# 8301   xCOPE  USDC  2172500.326824  0.02                             Raydium
# 8302     YFI   SRM    55320.900733  0.52                             Raydium
# 8303     YFI  USDC   110579.366739  9.25                             Raydium
# 8304     YFI  USDT    96631.990083  9.26                             Raydium
#
#      network  apy type_of_agriculture
# 0      MATIC  NaN                FARM
# 1      MATIC  NaN                FARM
# 2      MATIC  NaN                FARM
# 3      MATIC  NaN                FARM
# 4      MATIC  NaN                FARM
# ...      ...  ...                 ...
# 8300     SOL  NaN                POOL
# 8301     SOL  NaN                POOL
# 8302     SOL  NaN                POOL
# 8303     SOL  NaN                POOL
# 8304     SOL  NaN                POOL
#
# [8305 rows x 8 columns]

# %%
# pair_df['apr'].unique().tolist()

# %%
def convert_apr_to_apy(pair_df):
    tmp_df = pair_df[pair_df['apy'].isna()]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apr = row['apr']
        if pd.isnull( apr):
            return
        if apr is not None and len(apr.strip()):
            apr = float(apr.replace(',',''))
        else:
            apr = 0
        try:
            pair_df.loc[index, 'apy'] = ((1+(apr/100)/365)**365-1)*100
        except:
            pair_df.loc[index, 'apy'] = np.nan
    return
            
def convert_apy_to_apr(pair_df):
    tmp_df = pair_df[(pair_df['apr'].isnull())]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apy = row['apy']
        if pd.isnull( apy):
            return
        if apy is not None and len(apy.strip()):
            apy = float(apy.replace(',',''))
        else:
            apy = 0
        try:
            pair_df.loc[index, 'apr'] = (((1+(apy/100))**(1/365)-1)*365)*100
        except:
            pair_df.loc[index, 'apr'] = np.nan
    return


convert_apr_to_apy(pair_df)
convert_apy_to_apr(pair_df)
# Out:
# (8305, 8)
# (52, 8)

# %%
pair_df[pair_df['apy'].isna()]
# Out:
#        pair1   pair2             tvl                    apr  \
# 550   WMATIC                    0.00           422370189.75
# 551      ETH                    0.00            17193377.16
# 555    QUICK                    0.00  352678079178222144.00
# 716     AAVE                    0.00  189848690299186688.00
# 803     USDC  POLLEN            9.62             3638489.63
# ...      ...     ...             ...                    ...
# 8300    WOOF    USDC        0.695141                    0.0
# 8301   xCOPE    USDC  2172500.326824                   0.02
# 8302     YFI     SRM    55320.900733                   0.52
# 8303     YFI    USDC   110579.366739                   9.25
# 8304     YFI    USDT    96631.990083                   9.26
#
#                                where network  apy type_of_agriculture
# 550   https://www.polyapefinance.com   MATIC  NaN                FARM
# 551   https://www.polyapefinance.com   MATIC  NaN                FARM
# 555   https://www.polyapefinance.com   MATIC  NaN                FARM
# 716     https://www.polyswan.finance   MATIC  NaN                FARM
# 803    https://polybutterfly.finance   MATIC  NaN                FARM
# ...                              ...     ...  ...                 ...
# 8300                         Raydium     SOL  NaN                POOL
# 8301                         Raydium     SOL  NaN                POOL
# 8302                         Raydium     SOL  NaN                POOL
# 8303                         Raydium     SOL  NaN                POOL
# 8304                         Raydium     SOL  NaN                POOL
#
# [320 rows x 8 columns]

# %%
pair_df[pair_df['apr'].isna()]
# Out:
#               pair1 pair2  tvl  apr                         where network  \
# 8057    kmWETH/USDT  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8058    kmWETH/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8059     kmWETH/DAI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8060    kmWBTC/USDT  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8061     kmWBTC/DAI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8062    kmWBTC/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8063    kmLINK/USDT  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8064     kmLINK/DAI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8065    kmLINK/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8066   kmUSDC/1INCH  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8067    kmUSDC/AAVE  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8068  kmUSDC/BADGER  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8069   kmUSDC/ALPHA  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8070    kmUSDC/BZRX  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8071    kmUSDC/COMP  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8072   kmUSDC/COVER  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8073   kmUSDC/CREAM  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8074     kmUSDC/GRT  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8075   kmUSDC/HEGIC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8076    kmUSDC/LINK  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8077     kmUSDC/REN  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8078     kmUSDC/SRM  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8079   kmUSDC/SUSHI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8080     kmUSDC/UNI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8081    kmUSDC/wNXM  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8082     kmUSDC/YFI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8083    kmSUSHI/UNI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8084    kmUNI/SUSHI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8085   kmSUSHI/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8086   kmSUSHI/USDT  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8087    kmSUSHI/DAI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8088   kmWETH/1INCH  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8089     kmYFI/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8090    kmAAVE/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8091   kmALPHA/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8092  kmBADGER/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8093    kmRUNE/USDT  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8094      kmUMA/DAI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8095      kmDAI/CRV  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8096     kmDPI/sUSD  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8112   kmxSUSHI/UST  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8113   kmxSUSHI/DAI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8114  kmxSUSHI/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8115  kmxSUSHI/TUSD  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8116  kmxSUSHI/USDT  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8127    kmCOMP/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8128     kmFTM/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8129     kmSNX/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8130    kmRUNE/sUSD  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8131     kmREN/USDC  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8132     kmAAVE/DAI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
# 8133      kmUNI/DAI  LINK  0.0  NaN  https://app.sushi.com/farms/     ETH
#
#       apy type_of_agriculture
# 8057  NaN                FARM
# 8058  NaN                FARM
# 8059  NaN                FARM
# 8060  NaN                FARM
# 8061  NaN                FARM
# 8062  NaN                FARM
# 8063  NaN                FARM
# 8064  NaN                FARM
# 8065  NaN                FARM
# 8066  NaN                FARM
# 8067  NaN                FARM
# 8068  NaN                FARM
# 8069  NaN                FARM
# 8070  NaN                FARM
# 8071  NaN                FARM
# 8072  NaN                FARM
# 8073  NaN                FARM
# 8074  NaN                FARM
# 8075  NaN                FARM
# 8076  NaN                FARM
# 8077  NaN                FARM
# 8078  NaN                FARM
# 8079  NaN                FARM
# 8080  NaN                FARM
# 8081  NaN                FARM
# 8082  NaN                FARM
# 8083  NaN                FARM
# 8084  NaN                FARM
# 8085  NaN                FARM
# 8086  NaN                FARM
# 8087  NaN                FARM
# 8088  NaN                FARM
# 8089  NaN                FARM
# 8090  NaN                FARM
# 8091  NaN                FARM
# 8092  NaN                FARM
# 8093  NaN                FARM
# 8094  NaN                FARM
# 8095  NaN                FARM
# 8096  NaN                FARM
# 8112  NaN                FARM
# 8113  NaN                FARM
# 8114  NaN                FARM
# 8115  NaN                FARM
# 8116  NaN                FARM
# 8127  NaN                FARM
# 8128  NaN                FARM
# 8129  NaN                FARM
# 8130  NaN                FARM
# 8131  NaN                FARM
# 8132  NaN                FARM
# 8133  NaN                FARM

# %%
pair_df = pair_df.drop_duplicates()

# %%
single_piar_df = pair_df[pair_df['pair2'] == ""].copy()
double_coin_pair_df = pair_df[pair_df['pair2'] != ""].copy()
tmp_df = double_coin_pair_df.copy()

# %%
single_piar_df
# Out:
#               pair1 pair2            tvl   apr  \
# 0            UNI-V2                 0.00     0
# 14    stkGHST-QUICK                 0.00     0
# 25     stkGHST-USDC                 0.00     0
# 150           Krill             83804.46  0.00
# 151            Mint                 0.00     0
# ...             ...   ...            ...   ...
# 8192            BTC         1386940498.0  0.03
# 8193            ETH        2614091673.98  0.05
# 8194         xSUSHI         165092534.03     0
# 8195            YFI          61496804.29  0.07
# 8196            ZRX           2000614.07   0.1
#
#                                    where network  apy type_of_agriculture
# 0     https://quickswap.exchange/#/quick   MATIC  0.0                FARM
# 14    https://quickswap.exchange/#/quick   MATIC  0.0                FARM
# 25    https://quickswap.exchange/#/quick   MATIC  0.0                FARM
# 150            https://polywhale.finance   MATIC  0.0                FARM
# 151            https://polywhale.finance   MATIC  0.0                FARM
# ...                                  ...     ...  ...                 ...
# 8192                    https://aave.com     ETH  NaN                FARM
# 8193                    https://aave.com     ETH  NaN                FARM
# 8194                    https://aave.com     ETH  NaN                FARM
# 8195                    https://aave.com     ETH  NaN                FARM
# 8196                    https://aave.com     ETH  NaN                FARM
#
# [2884 rows x 8 columns]

# %%
double_coin_pair_df
# Out:
#       pair1  pair2             tvl    apr                               where  \
# 9      USDC  QUICK      8629368.06  49.06  https://quickswap.exchange/#/quick
# 10      ETH  QUICK     12803446.21  53.42  https://quickswap.exchange/#/quick
# 12     USDC    DAI     52530360.75   4.21  https://quickswap.exchange/#/quick
# 13    QUICK    TEL      2592305.66  72.27  https://quickswap.exchange/#/quick
# 15      ETH   WISE      3334388.59  20.06  https://quickswap.exchange/#/quick
# ...     ...    ...             ...    ...                                 ...
# 8300   WOOF   USDC        0.695141    0.0                             Raydium
# 8301  xCOPE   USDC  2172500.326824   0.02                             Raydium
# 8302    YFI    SRM    55320.900733   0.52                             Raydium
# 8303    YFI   USDC   110579.366739   9.25                             Raydium
# 8304    YFI   USDT    96631.990083   9.26                             Raydium
#
#      network         apy type_of_agriculture
# 9      MATIC   63.275796                FARM
# 10     MATIC   70.541667                FARM
# 12     MATIC    4.299624                FARM
# 13     MATIC  105.851628                FARM
# 15     MATIC   22.206848                FARM
# ...      ...         ...                 ...
# 8300     SOL         NaN                POOL
# 8301     SOL         NaN                POOL
# 8302     SOL         NaN                POOL
# 8303     SOL         NaN                POOL
# 8304     SOL         NaN                POOL
#
# [5211 rows x 8 columns]

# %%
tmp_df
# Out:
#       pair1  pair2             tvl    apr                               where  \
# 9      USDC  QUICK      8629368.06  49.06  https://quickswap.exchange/#/quick
# 10      ETH  QUICK     12803446.21  53.42  https://quickswap.exchange/#/quick
# 12     USDC    DAI     52530360.75   4.21  https://quickswap.exchange/#/quick
# 13    QUICK    TEL      2592305.66  72.27  https://quickswap.exchange/#/quick
# 15      ETH   WISE      3334388.59  20.06  https://quickswap.exchange/#/quick
# ...     ...    ...             ...    ...                                 ...
# 8300   WOOF   USDC        0.695141    0.0                             Raydium
# 8301  xCOPE   USDC  2172500.326824   0.02                             Raydium
# 8302    YFI    SRM    55320.900733   0.52                             Raydium
# 8303    YFI   USDC   110579.366739   9.25                             Raydium
# 8304    YFI   USDT    96631.990083   9.26                             Raydium
#
#      network         apy type_of_agriculture
# 9      MATIC   63.275796                FARM
# 10     MATIC   70.541667                FARM
# 12     MATIC    4.299624                FARM
# 13     MATIC  105.851628                FARM
# 15     MATIC   22.206848                FARM
# ...      ...         ...                 ...
# 8300     SOL         NaN                POOL
# 8301     SOL         NaN                POOL
# 8302     SOL         NaN                POOL
# 8303     SOL         NaN                POOL
# 8304     SOL         NaN                POOL
#
# [5211 rows x 8 columns]

# %%
tmp_df['tmp'] = tmp_df['pair1']
tmp_df['pair1'] = tmp_df['pair2']
tmp_df['pair2'] = tmp_df['tmp']
del tmp_df['tmp']

# %%
double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
# Out:
#         pair1  pair2         tvl     apr                               where  \
# 0         $DG    BNB  1817147.28  203.39         https://pancakeswap.finance
# 1         $DG    ETH   573615.99   86.51  https://quickswap.exchange/#/quick
# 2         $DG  QUICK   173485.21   71.51  https://quickswap.exchange/#/quick
# 3       $TRDL    ETH   148319.28  162.47             https://strudel.finance
# 4       $TRDL   MUST     5192.44    0.00      https://swap.cometh.io/#/stake
# ...       ...    ...         ...     ...                                 ...
# 10417    zETH   ZERO   105941.60    0.00              https://app.0.exchange
# 10418  zSUSHI   ZERO    33667.61    0.00              https://app.0.exchange
# 10419    zUNI   ZERO    11370.02    0.00              https://app.0.exchange
# 10420   zUSDC   ZERO    23370.71    0.00              https://app.0.exchange
# 10421   zUSDT   ZERO    36828.54    0.00              https://app.0.exchange
#
#       network         apy type_of_agriculture
# 0         BSC  660.080516                FARM
# 1       MATIC  137.281358                FARM
# 2       MATIC  104.296137                FARM
# 3         ETH  405.862514                FARM
# 4       MATIC    0.000000                FARM
# ...       ...         ...                 ...
# 10417    AVAX    0.000000                FARM
# 10418    AVAX    0.000000                FARM
# 10419    AVAX    0.000000                FARM
# 10420    AVAX    0.000000                FARM
# 10421    AVAX    0.000000                FARM
#
# [10422 rows x 8 columns]

# %%
summary = {
    "total_pairs": pair_df.shape[0],
"single_coin_pairs": single_piar_df.shape[0],
"double_coin_piars": double_coin_pair_df.shape[0],
"after_switching_coins_total_double_coin_pairs": double_coin_pair_df.shape[0] * 2,
"total_pairs_in_sheet": double_coin_pair_df.shape[0] * 2 + single_piar_df.shape[0]
}

# %%
summary
# Out:
# {'total_pairs': 8095,
#  'single_coin_pairs': 2884,
#  'double_coin_piars': 5211,
#  'after_switching_coins_total_double_coin_pairs': 10422,
#  'total_pairs_in_sheet': 13306}

# %%
pair_df = double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
pair_df = single_piar_df.append(pair_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)

# %%
pair_df
# Out:
#           pair1  pair2         tvl      apr  \
# 0           $DG    BNB  1817147.28   203.39
# 1           $DG    ETH   573615.99    86.51
# 2           $DG  QUICK   173485.21    71.51
# 3         $TRDL    ETH   148319.28   162.47
# 4         $TRDL   MUST     5192.44     0.00
# ...         ...    ...         ...      ...
# 13301  zs-XUSD2               0.00        0
# 13302  zs-tsBTC               0.00        0
# 13303      τBTC             107.45   323.19
# 13304         🌾          113115.97  3468.42
# 13305         🚜           18383.78    18.30
#
#                                     where network           apy  \
# 0             https://pancakeswap.finance     BSC  6.600805e+02
# 1      https://quickswap.exchange/#/quick   MATIC  1.372814e+02
# 2      https://quickswap.exchange/#/quick   MATIC  1.042961e+02
# 3                 https://strudel.finance     ETH  4.058625e+02
# 4          https://swap.cometh.io/#/stake   MATIC  0.000000e+00
# ...                                   ...     ...           ...
# 13301  https://www.stabilize.finance/app/     ETH  0.000000e+00
# 13302  https://www.stabilize.finance/app/     ETH  0.000000e+00
# 13303          https://www.elixir-swap.io     BSC  2.397001e+03
# 13304               https://harvester.app   MATIC  2.453592e+16
# 13305        https://www.honestwork.farm/   MATIC  2.007593e+01
#
#       type_of_agriculture
# 0                    FARM
# 1                    FARM
# 2                    FARM
# 3                    FARM
# 4                    FARM
# ...                   ...
# 13301                FARM
# 13302                FARM
# 13303                FARM
# 13304                FARM
# 13305                FARM
#
# [13306 rows x 8 columns]

# %%
pair_df['dex'] = pair_df['where']
pair_df['date'] = date 
del pair_df['where']

# %%
# pair_df.to_csv('yield_data_2021_06_21.csv')

# %%
pair_df['dex'].unique().tolist()
# Out:
# ['https://pancakeswap.finance',
#  'https://quickswap.exchange/#/quick',
#  'https://strudel.finance',
#  'https://swap.cometh.io/#/stake',
#  'https://caramelswap.finance',
#  'https://absorber.finance',
#  'https://icecreamswap.finance',
#  'http://mangofarm.finance',
#  'https://brussels.worldswap.finance',
#  'https://berlin.worldswap.finance',
#  'https://1inch.exchange/#/dao/farming',
#  'https://app.sushi.com/farms/',
#  'https://app.swamp.finance',
#  'https://ellipsis.finance',
#  'https://app.firebird.finance',
#  'https://frozenyogurt.finance',
#  'https://autofarm.network',
#  'https://beta.belt.fi',
#  'https://blue.planetfinance.io',
#  'https://app.yieldparrot.finance',
#  'https://50cent.network',
#  'https://glacierswap.org/farms/',
#  'https://8ballfinance.io',
#  'https://dollar.supra.finance',
#  'https://polyvolve.finance',
#  'https://polygaj.finance',
#  'https://www.polycake.finance',
#  'https://polyrangers.finance',
#  'https://polyvalent.finance',
#  'https://polyfi.io',
#  'https://polylion.exchange',
#  'https://www.orcinuslabs.ca',
#  'https://polywolf.finance',
#  'https://www.polygoat.finance',
#  'https://www.moonwolf.io',
#  'https://polycrab.finance',
#  'https://polybear.exchange',
#  'https://www.smellycat.finance',
#  'https://www.polyswan.finance',
#  'https://polypingu.finance',
#  'https://polygon.prismfinance.net',
#  'https://dinosaurfinance.vercel.app',
#  'https://polymouse.finance',
#  'https://www.polytiger.com/',
#  'https://polydeer.finance',
#  'https://avengers.exchange',
#  'https://polygon.space-defi.com/',
#  'https://polysnow.farm',
#  'https://polycafe.finance',
#  'https://polycomet.com',
#  'https://bali.worldswap.finance',
#  'https://polycuban.finance',
#  'https://harvester.app',
#  'https://polybrew.finance',
#  'PolyDiamond',
#  'https://bone.polypup.finance',
#  'https://www.bigdataprotocol.com/datavault',
#  'https://klingftm.borgswap.exchange',
#  'https://aave.com',
#  'https://app.pangolin.exchange/#/png',
#  'https://apeswap.finance',
#  'https://app.gametoken.finance',
#  'https://berserkfinance.com',
#  'https://app.elk.finance',
#  'https://app.wault.finance/polygon',
#  'https://polycrystal.finance',
#  'https://spookyswap.finance',
#  'https://frankenstein.finance',
#  'https://waka.finance',
#  'https://www.operaswap.finance',
#  'https://exchange.dfyn.network',
#  'https://www.liquiddriver.finance',
#  'https://farm.polyzap.finance',
#  'https://abrakadabra.tech',
#  'https://lumberjack.finance',
#  'https://app.acryptos.com',
#  'https://mdex.com',
#  'https://swipe.org/farm',
#  'https://iron.finance/',
#  'https://xwin.finance',
#  'https://www.goosedefi.com',
#  'http://slime.finance',
#  'https://koaladefi.finance/',
#  'https://brickchain.finance',
#  'https://app.hyruleswap.com',
#  'https://www.jiggly.finance',
#  'http://shitz.lol',
#  'https://mooncakeswap.finance',
#  'https://app.comos.finance/',
#  'https://farm.borgswap.exchange',
#  'https://bitblocks.finance',
#  'https://lokum.finance',
#  'https://limeswap.io',
#  'https://tapswap.finance',
#  'https://app.barbecueswapfinance.com',
#  'https://vanillacake.farm',
#  'https://garudaswap.finance',
#  'https://www.elixir-swap.io',
#  'https://www.grizzlyswap.com',
#  'https://gocerberus.finance',
#  'https://ketchupfinance.com',
#  'https://mayoswap.com',
#  'https://www.andromedadefi.com',
#  'https://thunderbird.finance/',
#  'https://www.venomswap.net',
#  'https://www.blacksheepdefi.com',
#  'https://krustykrab.finance',
#  'https://www.meatchfinance.com/',
#  'https://www.carnageswap.net',
#  'https://thoreum.finance',
#  'https://app.seedmoneyfinance.com',
#  'https://whalefarm.finance',
#  'https://fusionfinance.farm/',
#  'https://www.blueballs.finance',
#  'https://seleniumswap.com',
#  'https://pandayield.com',
#  'https://pool.mochiswap.io',
#  'https://pumpy.farm',
#  'https://mouse.farm',
#  'https://thelab.finance',
#  'https://app.apache.finance/',
#  'https://farms.pandaswap.xyz',
#  'https://pantherswap.com',
#  'https://jaguarswap.com',
#  'https://zombie-farm.com',
#  'https://degentoken.finance',
#  'https://coinswap.space/',
#  'https://gatorswap.xyz',
#  'https://dumplingdefi.finance',
#  'https://satis.finance',
#  'https://dinopark.finance',
#  'https://ten.finance',
#  'https://biswap.org',
#  'https://antswap.fi',
#  'https://lavacake.finance',
#  'https://qiswap.finance',
#  'https://zeusfarmsdefi.com',
#  'https://www.faxe.farmwiki.xyz',
#  'https://www.halvar.farmwiki.xyz',
#  'https://tomahawk.farm/',
#  'https://supermanion.com',
#  'https://triton.farm/',
#  'https://magicbeans.finance/',
#  'https://app.wault.finance',
#  'https://money-pocket.dollaremon.fi',
#  'https://kesef.finance',
#  'https://manyswap.io',
#  'https://mozartfinance.io',
#  'https://app.treedefi.com',
#  'https://www.unownswap.com',
#  'https://app.sushi.com',
#  'https://augury.finance',
#  'https://polycat.finance',
#  'https://swap.smartdex.app',
#  'https://dogen.finance',
#  'https://gamestop.finance',
#  'https://polygon.alchemydao.com',
#  'https://alchemydao.com',
#  'https://app.alchemix.fi/farms',
#  'https://pickle.finance/farms',
#  'Raydium',
#  'https://www.bakeryswap.org',
#  'https://aliendefi.com',
#  'https://app.vlad.finance',
#  'https://farm.hyperjump.fi',
#  'https://app.sponge.finance',
#  'https://apoyield.com',
#  'https://aloeswap.com',
#  'https://hyfi.pro',
#  'https://longdrink.finance',
#  'https://app.alpacafinance.org',
#  'hhttps://taco.finance/',
#  'https://alpha.parthenon.finance',
#  'https://antdefi.io',
#  'https://app.spiritswap.finance',
#  'https://www.polyapefinance.com',
#  'https://memefarm.io',
#  'https://www.polyape.online/',
#  'https://olive.cash/farms',
#  'https://farm.unicrypt.network',
#  'https://elk.finance',
#  'https://armor.fi',
#  'https://www.arthcoin.com',
#  'https://fanaticsfinance.com',
#  'CHAD',
#  'https://www.blackswap.finance',
#  'https://ftm.borgswap.exchange',
#  'https://hyperjump.fi',
#  'https://www.alchemistdefi.com',
#  'https://bobadefi.com',
#  'https://toad.farm',
#  'https://fullsail.finance',
#  'https://muscle.finance',
#  'https://snek.farm',
#  'https://tripswap.finance',
#  'https://www.coralfarm.finance/',
#  'https://avax.olive.cash',
#  'https://app.baguette.exchange',
#  'https://app.canary.exchange/',
#  'https://avme.io',
#  'https://pandaswap.exchange',
#  'https://birdy.finance',
#  'https://avax.complus.exchange',
#  'https://www.lydia.finance',
#  'https://bsc.complus.exchange',
#  'https://exchange.yetiswap.app',
#  'https://penguinfinance.org',
#  'https://app.gondola.finance',
#  'https://farm.avalaunch.app',
#  'https://app.0.exchange',
#  'https://b2xtoken.io/farm',
#  'https://basis.cash',
#  'https://harvest.finance/',
#  'https://app.thisistheway.finance/#/stake',
#  'https://bondappetit.io',
#  'https://cheesecakeswap.com',
#  'https://neonic.finance',
#  'https://www.ybearswap.finance',
#  'https://mars.cosmos.farm',
#  'https://pastafinance.com',
#  'https://pegs.cash',
#  'https://app.bami.money',
#  'https://polyyeld.finance',
#  'https://www.zexswap.finance',
#  'https://app.blueswap.finance',
#  'https://farmhero.io',
#  'https://yieldfields.finance',
#  'https://takodefi.com',
#  'https://bscrunner.com',
#  'https://floatprotocol.com/#/stake',
#  'https://basketdao.org',
#  'https://nft20.io',
#  'https://benswap.finance/',
#  'https://www.piedao.org',
#  'https://biscuitfarm.finance',
#  'https://carrotcake.fi',
#  'https://lazymint.finance',
#  'https://kimochi.finance',
#  'https://www.saltswap.finance/',
#  'https://pizzafinance.app',
#  'https://shrimpswap.finance',
#  'https://marmelade.finance',
#  'https://fulcrum.trade',
#  'https://julswap.com',
#  'https://www.wardenswap.finance',
#  'https://kebabfinance.com',
#  'https://veganswap.finance',
#  'https://sakeswap.finance',
#  'https://www.billhwangdefi.co',
#  'https://nu.parthenon.finance',
#  'https://biopset.com',
#  'https://blizzard.money',
#  'https://donutdefi.com',
#  'https://app.polarisdefi.io',
#  'https://finance.zcore.network',
#  'https://farm.space',
#  'https://app.uranium.finance',
#  'https://dragonballfinance.org',
#  'https://marshmallowdefi.com',
#  'https://sojudefi.com',
#  'https://thefarmingden.com',
#  'https://thunderswap.finance',
#  'https://bourbondefi.com',
#  'https://evodefi.com',
#  'https://www.gengarfinance.com',
#  'https://dungeonswap.app',
#  'https://plumcake.finance',
#  'https://www.pulsar.farm',
#  'https://farms.tinville.finance',
#  'https://app.pancakefork.finance',
#  'https://bsc.prismfinance.net',
#  'https://app.tea-swap.finance/',
#  'https://werewolf.farm',
#  'https://siberianswap.finance',
#  'https://app.elephantswap.finance',
#  'https://mu.parthenon.finance',
#  'https://cottonfarm.app',
#  'https://www.bsc.space-defi.com',
#  'https://legofarming.club',
#  'https://rediant.finance',
#  'https://www.frozencake.finance',
#  'https://app.rasta.finance',
#  'https://venus.cosmos.farm',
#  'https://tsuki.finance',
#  'https://berrydata.co/',
#  'https://yieldbay.finance',
#  'https://goatswap.finance',
#  'https://oni.exchange',
#  'https://ramenswap.finance',
#  'https://yieldnyan.com',
#  'https://app.stakd.finance',
#  'https://llamaswap.finance',
#  'https://jazzdefi.com',
#  'https://www.pureswap.finance',
#  'https://friction.finance',
#  'https://www.robinhoodswap.finance',
#  'https://cookiebake.finance',
#  'https://cdo.finance',
#  'https://cubdefi.com',
#  'http://djinn.gold',
#  'https://eggplant.fi',
#  'https://eleven.finance',
#  'https://app.feeder.finance',
#  'https://fishswap.app',
#  'https://fluity.finance',
#  'https://thegreenhouse.finance',
#  'https://paintswap.finance',
#  'https://shadowswap.app',
#  'https://wheat.growthdefi.com',
#  'https://guessit.app',
#  'https://popsicle.finance',
#  'https://www.knightsdefi.com',
#  'https://www.mythic.finance',
#  'https://mushrooms.finance',
#  'https://pearldefi.com',
#  'https://farms.polispay.org',
#  'https://privacyswap.finance',
#  'https://ricefarm.fi',
#  'https://bsc.sashimi.cool/',
#  'https://smoothy.finance',
#  'https://soups.finance',
#  'https://swirl.cash/mining',
#  'https://bsc.wasabix.finance/#/app/pool',
#  'https://farm.wsbdapp.com',
#  'https://farms.apwars.farm',
#  'https://yumcha.finance',
#  'https://www.polypulsar.farm',
#  'https://mushrooms.finance/farms',
#  'https://app.spoon.finance',
#  'https://piratedice.xyz',
#  'https://basis.gold',
#  'https://polyfox.finance',
#  'https://hawkdex.com',
#  'https://farm.BoughtThe.top',
#  'https://www.polystarter.fi',
#  'https://gameswap.netlify.app/',
#  'https://www.polyshark.finance',
#  'https://polypanda.finance',
#  'https://www.jurassicfarm.app',
#  'https://polyce.io',
#  'https://www.monkefarm.finance',
#  'https://polybull.finance',
#  'https://www.polysnake.finance',
#  'https://stonk.farm/',
#  'https://www.polymaple.com/',
#  'https://www.polyion.net',
#  'https://farms.goldenbull.finance',
#  'https://defi.polyakita.com',
#  'https://polybutterfly.finance',
#  'https://southpark.finance/',
#  'https://polycash.finance',
#  'https://www.glockswap.com',
#  'https://polyvertex.finance/farms',
#  'https://polymax.club',
#  'https://polywoof.finance',
#  'https://stonky.farm/',
#  'PolyMemeV2',
#  'https://carouselswap.com',
#  'https://stonkz.farm/',
#  'https://polymeryield.finance',
#  'https://polygrass.online',
#  'https://foxfarming.us',
#  'https://hippolygon.com',
#  'https://pepefarm.finance',
#  'https://www.polyruby.finance',
#  'https://polyzeus.finance',
#  'https://app.sirenmarkets.com/stake',
#  'https://polydex.fi',
#  'https://dmm.exchange/',
#  'https://klondike.finance',
#  'https://app.lift.kitchen - Seigniorage + Product Development Fund creating consumer blockchain products to bolster the investment fund',
#  'https://mordorswap.finance',
#  'https://app.compli.fi',
#  'https://ichi.farm/',
#  'https://bsc.farms.yogi.fi',
#  'https://docs.xbull.finance',
#  'https://bsc.lever.network/Staking',
#  'https://app.badger.finance',
#  'https://www.polycarrot.finance',
#  'https://polycactus.com',
#  'https://v0.dfx.finance',
#  'https://yorocoon.com',
#  'https://indexed.finance',
#  'https://cntr.finance',
#  'https://convx.conv.finance',
#  'https://polygon.cosmicswap.finance',
#  'https://cvi.finance',
#  'https://app.cryptex.finance',
#  'https://cyclone.xyz/eth',
#  'https://polypunk.finance',
#  'https://www.polysa.finance',
#  'https://www.polyharvest.finance',
#  'https://www.rocketfarming.finance',
#  'https://fairyfarming.world/',
#  'https://debaseonomics.io/',
#  'https://www.stabilize.finance/app/',
#  'http://stake.kineko.io',
#  'https://morph.finance/',
#  'https://onecash.finance',
#  'https://slowpoke.space',
#  'https://www.honestwork.farm/',
#  'https://legofarming-polygon.club',
#  'https://app.elena.finance',
#  'https://xusd.money/',
#  'https://daiq.io',
#  'https://kitten.finance/',
#  'https://monopolyfinance.xyz',
#  'https://inverse.finance',
#  'https://don-key.finance',
#  'https://app.dopex.io/farms',
#  'https://defimagic.io',
#  'https://stakedao.org',
#  'https://ester.finance',
#  'PolyZero',
#  'https://polyroll.org',
#  'https://pop.town',
#  'https://polydragon.io',
#  'https://forcedao.com/',
#  'https://exchange.futureswap.com',
#  'https://fuse.io',
#  'https://gravityfinance.io/app/#farms',
#  'https://www.dollarprotocol.com/#/stake',
#  'https://defiville.finance/',
#  'https://dashboard.keep.network/liquidity',
#  'https://kine.finance',
#  'https://lever.network',
#  'https://staking.launchpool.xyz',
#  'https://app.playludus.io',
#  'https://launchpad.benchmarkprotocol.finance/pools',
#  'https://stake.publicmint.com',
#  'https://museumofcryptoart.com',
#  'https://mochi.market',
#  'https://incentives.epns.io',
#  'https://app.optionroom.finance',
#  'https://staking.sandbox.game',
#  'https://www.sharedstake.org/earn',
#  'https://app.xsigma.fi',
#  'https://abracadabra.money',
#  'https://gemstones.finance',
#  'https://app.tornado.cash',
#  'https://app.truefi.io/farm',
#  'https://farm.umbria.network',
#  'https://www.app.unic.ly/#/farm',
#  'https://updown.finance',
#  'https://app.pickle.finance/',
#  'https://app.unslashed.finance/',
#  'https://wasabix.finance/#/app/pool',
#  'https://wild.credit',
#  'https://app.wolvesofwallstreet.finance',
#  'https://xtoken.cafe/app/dashboard',
#  'https://yaxis.io/farms',
#  'https://yflusd.linkswap.app',
#  'https://fei.money',
#  'https://www.theghost.finance',
#  'https://tomb.finance',
#  'https://polyfunky.com/',
#  'https://governordao.org',
#  'https://gambit.financial/earn',
#  'https://www.helmet.insure',
#  'https://polygon.iron.finance',
#  'https://polygame.finance',
#  'https://kogefarm.io',
#  'https://polywhale.finance',
#  'https://steakhouse.finance',
#  'https://mith.cash',
#  'https://narwhale.finance',
#  'https://nya.cash',
#  'https://mimo.capital/mining',
#  'https://polygon.fulcrum.trade',
#  'https://polkacash.finance',
#  'https://app.polyquity.org',
#  'https://www.mai.finance',
#  'https://stacker.vc',
#  'https://stakesteak.com',
#  'https://penguinswap.eth.link',
#  'https://app.pendle.finance/',
#  'http://app.eurxb.finance',
#  'https://xdollar.mcn.ventures',
#  'https://staking.synthetix.io',
#  'https://app.rulerprotocol.com/app/farms']

# %%
pair_df[pair_df['pair1'] == 'ETH']
# Out:
#      pair1       pair2          tvl     apr network          apy  \
# 6513   ETH                  3199.52  370.21   MATIC  3878.346108
# 6514   ETH                  1366.92    0.00   MATIC     0.000000
# 6515   ETH                     0.04    0.00   MATIC     0.000000
# 6516   ETH                   632.72   61.93   MATIC    85.665263
# 6517   ETH                   134.64   74.39   MATIC   110.253333
# ...    ...         ...          ...     ...     ...          ...
# 7445   ETH       xKNCb      5169.08    0.00     ETH     0.000000
# 7446   ETH      xSUSHI   25323771.0   16.84     ETH    18.336392
# 7447   ETH     yvBOOST  11606533.93    5.97     ETH     6.151286
# 7448   ETH     yvBOOST   17990552.0   21.88     ETH          NaN
# 7449   ETH  yveCRV-DAO    969373.28    1.53     ETH     1.541732
#
#      type_of_agriculture                                dex       date
# 6513                FARM            https://polyfox.finance 2021-06-30
# 6514                FARM                https://hawkdex.com 2021-06-30
# 6515                FARM         https://farm.BoughtThe.top 2021-06-30
# 6516                FARM         https://www.polystarter.fi 2021-06-30
# 6517                FARM          https://polyvolve.finance 2021-06-30
# ...                  ...                                ...        ...
# 7445                FARM  https://xtoken.cafe/app/dashboard 2021-06-30
# 7446                FARM       https://app.sushi.com/farms/ 2021-06-30
# 7447                FARM       https://pickle.finance/farms 2021-06-30
# 7448                FARM       https://app.sushi.com/farms/ 2021-06-30
# 7449                FARM       https://pickle.finance/farms 2021-06-30
#
# [937 rows x 9 columns]

# %%
pair_df['apr'].unique().tolist()
# Out:
# ['203.39',
#  '86.51',
#  '71.51',
#  '162.47',
#  '0.00',
#  '0',
#  '257.29',
#  '651.27',
#  '410.24',
#  '8.98',
#  '228',
#  '15.39',
#  '5.55',
#  '22.06',
#  '7372.33',
#  '1037.37',
#  '976.35',
#  '2535.98',
#  '2681.93',
#  '2.61',
#  '206.00',
#  '60.29',
#  '179.86',
#  '91.90',
#  '44.23',
#  '8.42',
#  '176.88',
#  '195.81',
#  '79.65',
#  '165.24',
#  '189848690299186688.00',
#  '66.93',
#  '40.06',
#  '180.57',
#  '617.83',
#  '156.73',
#  '665.75',
#  '1997.25',
#  '5325.99',
#  '240.60',
#  '21.99',
#  '14.01',
#  '125.00',
#  '265.69',
#  '15815811688809592832.00',
#  '158.63',
#  '2000.80',
#  '1928.91',
#  '164.25',
#  '579.79',
#  '78.67',
#  '12.69',
#  '27.91',
#  '150.70',
#  '3336.91',
#  '250.95',
#  '268.90',
#  '10.76',
#  '12.58',
#  '207.49',
#  '54.08',
#  '8.33',
#  '14.93',
#  '75.33',
#  '39.36',
#  '165.43',
#  '73.40',
#  '76.69',
#  '76.02',
#  '198.58',
#  '209.36',
#  '304.92',
#  '622.05',
#  '670.89',
#  '68.05',
#  '0.47',
#  '60.61',
#  '18.81',
#  '220.24',
#  '33.12',
#  '162.73',
#  '6.31',
#  '40.27',
#  '326.07',
#  '29.70',
#  '60.32',
#  '15.32',
#  '23.18',
#  '40.40',
#  '22.98',
#  '1.39',
#  '101.00',
#  '45.64',
#  '117.78',
#  '1367.37',
#  '19.00',
#  '213.75',
#  '104.74',
#  '2.77',
#  '2.64',
#  '27.10',
#  '119.18',
#  '7287.50',
#  '147.08',
#  '2176608.53',
#  '101.44',
#  '680.37',
#  '163.76',
#  '219.38',
#  '17.25',
#  '25.25',
#  '6.34',
#  '223.50',
#  '83.06',
#  '454.47',
#  '8.96',
#  '1.16',
#  '6.81',
#  '25.97',
#  '204.28',
#  '61.17',
#  '104.89',
#  '161.69',
#  '47.22',
#  '48.64',
#  '11.02',
#  '136.54',
#  '134.57',
#  '38.46',
#  '94.49',
#  '79.61',
#  '84.47',
#  '142.61',
#  '92.34',
#  '105.00',
#  '159.40',
#  '3678.80',
#  '149.05',
#  '22.88',
#  '8.99',
#  '19.48',
#  '45.60',
#  '286.71',
#  '204.11',
#  '1559.63',
#  '1.15',
#  '187.56',
#  '113.90',
#  '348.70',
#  '216.52',
#  '296.42',
#  '64.99',
#  '54.75',
#  '15.56',
#  '20.20',
#  '91.03',
#  '396.23',
#  '12717.26',
#  '47.73',
#  '171.34',
#  '22144647.67',
#  '1392.18',
#  '185.24',
#  '20.77',
#  '1111.48',
#  '840218.91',
#  '33.07',
#  '13.33',
#  '63.55',
#  '132.71',
#  '127.77',
#  '14.29',
#  '2.80',
#  '6.53',
#  '638.73',
#  '646.61',
#  '86.97',
#  '278.33',
#  '289.65',
#  '26.96',
#  '1953.55',
#  '215.72',
#  '1538.94',
#  '5.91',
#  '14.92',
#  '7.49',
#  '43.62',
#  '101.46',
#  '127.36',
#  '837.35',
#  '2561.99',
#  '4341.04',
#  '263.26',
#  '63.34',
#  '30.25',
#  '474.05',
#  '303.20',
#  '103.55',
#  '3.87',
#  '129.79',
#  '49.4',
#  '2.5',
#  '48.97',
#  '61.74',
#  '2.24',
#  '16.84',
#  '8.37',
#  '395.05',
#  '2150.50',
#  '27365.05',
#  '17925.23',
#  '96.50',
#  '193.00',
#  '241.25',
#  '86.34',
#  '377.48',
#  '192.71',
#  '349.29',
#  '260.45',
#  '147.80',
#  '242.16',
#  '150.32',
#  '192.79',
#  '383.72',
#  '214.98',
#  '219.47',
#  '131.11',
#  '69.60',
#  '669.48',
#  '170.09',
#  '188.53',
#  '213.02',
#  '127.99',
#  '359.74',
#  '663.33',
#  '456.62',
#  '617.76',
#  '112.46',
#  '96.52',
#  '84713774344.18',
#  '408.98',
#  '20048639.94',
#  '153.79',
#  '294.09',
#  '15.30',
#  '43.94',
#  '266.86',
#  '222.83',
#  '60.45',
#  '22.87',
#  '276.39',
#  '48.89',
#  '16.87',
#  '10.05',
#  '209.33',
#  '147.54',
#  '129.07',
#  '144.95',
#  '55.15',
#  '206.11',
#  '56.78',
#  '20.27',
#  '7.27',
#  '597.22',
#  '472.54',
#  '55.41',
#  '163.94',
#  '100.38',
#  '474.19',
#  '44.66',
#  '18.76',
#  '22.48',
#  '135.57',
#  '3908.23',
#  '120.08',
#  '49.54',
#  '240.54',
#  '259.77',
#  '717.23',
#  '1991.81',
#  '848.20',
#  '973.02',
#  '3346.19',
#  '2.37',
#  '1252.24',
#  '5433.79',
#  '1952.56',
#  '383.43',
#  '10.06',
#  '57.95',
#  '61.26',
#  '2.09',
#  '119.85',
#  '72.97',
#  '114.78',
#  '475.65',
#  '350.40',
#  '439.11',
#  '552.77',
#  '28.13',
#  '41.73',
#  '15.74',
#  '11.70',
#  '13.90',
#  '510.53',
#  '5657.69',
#  '1148.22',
#  '270.15',
#  '347.53',
#  '18.96',
#  '97.59',
#  '34.35',
#  '31.96',
#  '25.74',
#  '374.29',
#  '388.72',
#  '84.93',
#  '16.91',
#  '39.46',
#  '302.09',
#  '99.46',
#  '78.61',
#  '79.29',
#  '85.61',
#  '82.77',
#  '103.33',
#  '85.93',
#  '90.65',
#  '45.17',
#  '92.42',
#  '25.12',
#  '45.91',
#  '121.19',
#  '16.00',
#  '111.08',
#  '131.17',
#  '772.66',
#  '236.07',
#  '816.82',
#  '144.80',
#  '273.96',
#  '627.16',
#  '206.03',
#  '29.54',
#  '3.48',
#  '51.19',
#  '68.29',
#  '62.31',
#  '494.29',
#  '5.26',
#  '8.81',
#  '10.01',
#  '148.83',
#  '15.93',
#  '3557.65',
#  '829.21',
#  '285.11',
#  '124.57',
#  '1820.57',
#  '241.94',
#  '418.74',
#  '322.49',
#  '590.20',
#  '475.58',
#  '233.72',
#  '121.38',
#  '391.12',
#  '375.07',
#  '356.28',
#  '387.67',
#  '5.72',
#  '4.84',
#  '2.29',
#  '1253.18',
#  '285.35',
#  '171.51',
#  '47.15',
#  '538.16',
#  '461.74',
#  '89.26',
#  '1531.40',
#  '351.72',
#  '339.23',
#  '197.62',
#  '1005.42',
#  '73.85',
#  '150.13',
#  '160.72',
#  '405.49',
#  '89.99',
#  '66.35',
#  '87.60',
#  '22.39',
#  '76.89',
#  '173.69',
#  '19.43',
#  '128.69',
#  '550.98',
#  '11.99',
#  '31.82',
#  '97.96',
#  '28.50',
#  '11.01',
#  '48.17',
#  '72.33',
#  '1911.41',
#  '479.97',
#  '281.16',
#  '52.73',
#  '130.03',
#  '198.23',
#  '241.37',
#  '224.28',
#  '67.91',
#  '2483.04',
#  '43.50',
#  '93.04',
#  '41.28',
#  '42.66',
#  '36.68',
#  '25.09',
#  '24.19',
#  '419.62',
#  '23.47',
#  '251.76',
#  '114.77',
#  '12.72',
#  '11.22',
#  '125.87',
#  '14.37',
#  '9.37',
#  '33.05',
#  '23.57',
#  '10.13',
#  '35.09',
#  '16.82',
#  '17.09',
#  '235.11',
#  '59.61',
#  '12.64',
#  '28.18',
#  '268.20',
#  '158.18',
#  '61.15',
#  '159.69',
#  '75.50',
#  '4896.39',
#  '127.42',
#  '31.50',
#  '266.51',
#  '120.52',
#  '20.29',
#  '41.21',
#  '12.71',
#  '31.74',
#  '25.93',
#  '12.84',
#  '12.75',
#  '7.53',
#  '42.08',
#  '49.27',
#  '15.83',
#  '25.00',
#  '163.71',
#  '123.52',
#  '80.58',
#  '170.93',
#  '81.84',
#  '136.43',
#  '178.59',
#  '151.06',
#  '185.29',
#  '199.65',
#  '58.72',
#  '666.96',
#  '679.00',
#  '32.51',
#  '373.57',
#  '18.16',
#  '52.12',
#  '30.04',
#  '17.64',
#  '7.15',
#  '99.84',
#  '45.65',
#  '91.35',
#  '373.85',
#  '41.14',
#  '402.57',
#  '451.86',
#  '532.76',
#  '32.41',
#  '1007.24',
#  '76.67',
#  '48.86',
#  '16.81',
#  '72.50',
#  '158.38',
#  '2.95',
#  '191.43',
#  '4.11',
#  '100.06',
#  '374.72',
#  '1726.29',
#  '90.93',
#  '164.55',
#  '57.03',
#  '222.03',
#  '305.91',
#  '305.54',
#  '797.07',
#  '125.03',
#  '259.67',
#  '3216.04',
#  '17.57',
#  '182.31',
#  '322.88',
#  '154.42',
#  '319.84',
#  '57.99',
#  '61.28',
#  '341.73',
#  '173.72',
#  '121.05',
#  '9.00',
#  '26.08',
#  '851.70',
#  '2.85',
#  '154.58',
#  '10.73',
#  '369.34',
#  '9.24',
#  '918.52',
#  '258.30',
#  '137.44',
#  '18.56',
#  '14.24',
#  '486.04',
#  '0.31',
#  '261.51',
#  '426.12',
#  '294.98',
#  '674.34',
#  '493.27',
#  '187.73',
#  '530.86',
#  '77.74',
#  '861.45',
#  '51.20',
#  '13.74',
#  '11.89',
#  '71.64',
#  '25.85',
#  '13.04',
#  '22.31',
#  '80.87',
#  '12.32',
#  '41.60',
#  '39.87',
#  '126.83',
#  '33.41',
#  '219.86',
#  '175.77',
#  '2022.93',
#  '233.09',
#  '104.83',
#  '93.32',
#  '53.84',
#  '0.7',
#  '61.02',
#  '15.96',
#  '125.77',
#  '20.70',
#  '35.84',
#  '3.16',
#  '18.50',
#  '409.01',
#  '251.15',
#  '216.23',
#  '226.46',
#  '204.47',
#  '205.29',
#  '157.59',
#  '186.45',
#  '205.06',
#  '131.45',
#  '200.06',
#  '111.71',
#  '179.62',
#  '117.19',
#  '365.56',
#  '99.31',
#  '406.55',
#  '345.37',
#  '119.60',
#  '266.47',
#  '305.30',
#  '281.64',
#  '362.04',
#  '336.59',
#  '39.23',
#  '450.32',
#  '179.08',
#  '13.28',
#  '33.49',
#  '54.18',
#  '33.14',
#  '14.69',
#  '5802.29',
#  '2314.31',
#  '8.13',
#  '19.07',
#  '25.84',
#  '37.79',
#  '102.73',
#  '420.22',
#  '288.77',
#  '27.21',
#  '1811010.02',
#  '257547.58',
#  '105.67',
#  '95.53',
#  '67.50',
#  '61.23',
#  '119.16',
#  '7.30',
#  '115.10',
#  '17.37',
#  '50.99',
#  '171.23',
#  '7.18',
#  '404.44',
#  '116.42',
#  '373.99',
#  '2935.54',
#  '4683.99',
#  '5771.14',
#  '153.72',
#  '54.04',
#  '33.33',
#  '53.07',
#  '1.30',
#  '37.68',
#  '3.90',
#  '10.88',
#  '0.42',
#  '108.39',
#  '222.29',
#  '215.09',
#  '13.59',
#  '370.02',
#  '207.20',
#  '168.27',
#  '230.45',
#  '193.60',
#  '278.76',
#  '421.03',
#  '11.44',
#  '1196.86',
#  '14.38',
#  '15.26',
#  '18.40',
#  '102.78',
#  '31.60',
#  '108.64',
#  '95.43',
#  '18.60',
#  '47.11',
#  '62.65',
#  '36.38',
#  '20.17',
#  '347.46',
#  '140.28',
#  '73.25',
#  '111.66',
#  '53.15',
#  '763.80',
#  '84.53',
#  '445.41',
#  '184.16',
#  '257.26',
#  '46.05',
#  '7.63',
#  '290.20',
#  '738.00',
#  '713.19',
#  '753.10',
#  '716.10',
#  '308.58',
#  '2690.29',
#  '189.74',
#  '982.03',
#  '1705.20',
#  '1887.02',
#  '14.64',
#  '403.38',
#  '79.73',
#  '13821.63',
#  '20761.63',
#  '32837.32',
#  '84.77',
#  '391.74',
#  '52.45',
#  '7355130519771405312.00',
#  '29.96',
#  '31.71',
#  '3019.56',
#  '148.01',
#  '27.13',
#  '193.49',
#  '16.26',
#  '286.91',
#  '24.49',
#  '363.29',
#  '9876.73',
#  '18.89',
#  '32.21',
#  '14.70',
#  '72.79',
#  '47.02',
#  '72.11',
#  '138.86',
#  '63.87',
#  '2937.29',
#  '29.27',
#  '607.95',
#  '294.74',
#  '27.57',
#  '23.87',
#  '0.38',
#  '311.20',
#  '3.64',
#  '187.77',
#  '104.08',
#  '62.87',
#  '249.68',
#  '630.06',
#  '19.35',
#  '52.97',
#  '62.59',
#  '375.40',
#  '57.60',
#  '58.31',
#  '559.51',
#  '13.71',
#  '198.92',
#  '39.21',
#  '17.20',
#  '45.74',
#  '10.66',
#  '12.79',
#  '76.55',
#  '7.41',
#  '170.78',
#  '23.68',
#  '94.86',
#  '138.62',
#  '64.80',
#  '84.99',
#  '41.44',
#  '15.29',
#  '140.70',
#  '575.30',
#  '223.74',
#  '46.52',
#  '109.09',
#  '16.80',
#  '9.56',
#  '11.82',
#  '103.57',
#  '142.89',
#  '22.42',
#  '9.28',
#  '27.46',
#  '18.10',
#  '4261.67',
#  '97.92',
#  '43.91',
#  '44.65',
#  '46.31',
#  '67.20',
#  '37.65',
#  '38.48',
#  '449.35',
#  '42.58',
#  '193.62',
#  '71.07',
#  '2.91',
#  '12.12',
#  '249.01',
#  '21.88',
#  '31.93',
#  '307.16',
#  '101.52',
#  '197.35',
#  '7390.41',
#  '1308.00',
#  '80.59',
#  '166.18',
#  '38.55',
#  '196.29',
#  '132.99',
#  '6605041.11',
#  '48.47',
#  '71.56',
#  '504.22',
#  '2723.44',
#  '36.77',
#  '440.54',
#  '107237.38',
#  '15.87',
#  '198366.01',
#  '384.05',
#  '370.38',
#  '249.38',
#  '121.32',
#  '3.24',
#  '284.97',
#  '25.40',
#  '94.41',
#  '191.36',
#  '357.99',
#  '161.53',
#  '366.61',
#  '230.46',
#  '3758.85',
#  '47.47',
#  '5.10',
#  '1432.29',
#  '72.35',
#  '180.69',
#  '315.21',
#  '8.91',
#  '51.24',
#  '11.20',
#  '2019.91',
#  '265.56',
#  '43.29',
#  '4.86',
#  '51.61',
#  '13.41',
#  '218.35',
#  '484.85',
#  '11.19',
#  '14.43',
#  '1.26',
#  '0.37',
#  '8.65',
#  '50.11',
#  '105.75',
#  '21.39',
#  '107.97',
#  '77.06',
#  '298.50',
#  '14.35',
#  '154.89',
#  '99.30',
#  '1566.39',
#  '49.62',
#  '65.57',
#  '236.23',
#  '68.95',
#  '246.47',
#  '28.43',
#  '3.02',
#  '21.47',
#  '294.30',
#  '18.59',
#  '140.80',
#  '89.28',
#  '136.33',
#  '325.43',
#  '40.46',
#  '137.72',
#  '79.42',
#  '531.12',
#  '74.58',
#  '49.51',
#  '10.96',
#  '134.39',
#  '311.42',
#  '94.57',
#  '177.59',
#  '114.14',
#  '6591.14',
#  '79.32',
#  '165.44',
#  '96.12',
#  '305.53',
#  '130.63',
#  '101.81',
#  '53.12',
#  '50.42',
#  '17.19',
#  '208.53',
#  '57.07',
#  '71.66',
#  '14.42',
#  '286.60',
#  '127.56',
#  '641.67',
#  '37.17',
#  '302.77',
#  '40.22',
#  '29.58',
#  '2022.51',
#  '740.37',
#  '26.95',
#  '98.05',
#  '40.08',
#  '114.50',
#  '762.05',
#  '154.33',
#  '21.32',
#  '214.19',
#  '168.71',
#  '141.67',
#  '304.82',
#  '101.19',
#  '83.60',
#  '3581.49',
#  '340.58',
#  '30.50',
#  '1908.10',
#  '256.45',
#  '158.11',
#  '118.37',
#  '18441258193895.80',
#  '13.21',
#  '47.94',
#  '47.74',
#  '7.40',
#  '3878.54',
#  '1870.53',
#  '600.94',
#  '78.98',
#  '130.75',
#  '8405.38',
#  '343.59',
#  '17.44',
#  '117.91',
#  '267.27',
#  '67168042.11',
#  '88.55',
#  '224.29',
#  '477.04',
#  '31.97',
#  '774.05',
#  '1710349.56',
#  '103.07',
#  '5.88',
#  '13.12',
#  '157.71',
#  '0.78',
#  '343.71',
#  '58.73',
#  '1.47',
#  '20.14',
#  '9.63',
#  '100.72',
#  '558.03',
#  '0.67',
#  '47.35',
#  '411.76',
#  '42.21',
#  '79.91',
#  '2605.03',
#  '88.15',
#  '172.15',
#  '16.14',
#  '30.68',
#  '10.82',
#  '4.83',
#  '15.60',
#  '3.94',
#  '62.45',
#  '178.11',
#  '35.96',
#  '7.83',
#  '81.51',
#  '1620.08',
#  '99.37',
#  '47.75',
#  '44.31',
#  '16082.40',
#  '18.44',
#  '30.64',
#  '32.63',
#  '10046.23',
#  '476.64',
#  '67.71',
#  '114.32',
#  '30.70',
#  '459.15',
#  '12.29',
#  '13.00',
#  '90.05',
#  '8247.24',
#  '246.66',
#  '30.42',
#  ...]

# %%
pair_df
# Out:
#           pair1  pair2         tvl      apr network           apy  \
# 0           $DG    BNB  1817147.28   203.39     BSC  6.600805e+02
# 1           $DG    ETH   573615.99    86.51   MATIC  1.372814e+02
# 2           $DG  QUICK   173485.21    71.51   MATIC  1.042961e+02
# 3         $TRDL    ETH   148319.28   162.47     ETH  4.058625e+02
# 4         $TRDL   MUST     5192.44     0.00   MATIC  0.000000e+00
# ...         ...    ...         ...      ...     ...           ...
# 13301  zs-XUSD2               0.00        0     ETH  0.000000e+00
# 13302  zs-tsBTC               0.00        0     ETH  0.000000e+00
# 13303      τBTC             107.45   323.19     BSC  2.397001e+03
# 13304         🌾          113115.97  3468.42   MATIC  2.453592e+16
# 13305         🚜           18383.78    18.30   MATIC  2.007593e+01
#
#       type_of_agriculture                                 dex       date
# 0                    FARM         https://pancakeswap.finance 2021-06-30
# 1                    FARM  https://quickswap.exchange/#/quick 2021-06-30
# 2                    FARM  https://quickswap.exchange/#/quick 2021-06-30
# 3                    FARM             https://strudel.finance 2021-06-30
# 4                    FARM      https://swap.cometh.io/#/stake 2021-06-30
# ...                   ...                                 ...        ...
# 13301                FARM  https://www.stabilize.finance/app/ 2021-06-30
# 13302                FARM  https://www.stabilize.finance/app/ 2021-06-30
# 13303                FARM          https://www.elixir-swap.io 2021-06-30
# 13304                FARM               https://harvester.app 2021-06-30
# 13305                FARM        https://www.honestwork.farm/ 2021-06-30
#
# [13306 rows x 9 columns]

# %%
pair_df[pair_df['pair1'] == 'CRV']
# Out:
#      pair1   pair2          tvl      apr network           apy  \
# 5133   CRV             93892.99  2089.26   MATIC  6.658232e+10
# 5134   CRV              5722.10        0     ETH  0.000000e+00
# 5135   CRV                74.63    88.35  FANTOM  1.416771e+02
# 5136   CRV          18444141.25    10.76     ETH           NaN
# 5137   CRV     ETH   2884561.12    27.53   MATIC  3.167890e+01
# 5138   CRV     ETH   1642574.80   186.36   MATIC  5.416409e+02
# 5139   CRV     ETH    803279.21   236.43   MATIC  9.555800e+02
# 5140   CRV     ETH   19219369.0    10.24     ETH  1.078106e+01
# 5141   CRV     FTM    657552.49    59.95  FANTOM  8.203125e+01
# 5142   CRV     FTM   1095133.81    50.71  FANTOM  6.598846e+01
# 5143   CRV     FTM     32730.24    80.19  FANTOM  1.227813e+02
# 5144   CRV     FTM   1096170.85     1.74  FANTOM  1.755184e+00
# 5145   CRV     FTM     37513.23    54.49  FANTOM  7.237354e+01
# 5146   CRV     FTM     32691.59    74.95  FANTOM  1.114316e+02
# 5147   CRV     FTM     20157.53   168.31  FANTOM  4.361433e+02
# 5148   CRV  WMATIC    789975.31   242.41   MATIC  1.020193e+03
#
#      type_of_agriculture                                 dex       date
# 5133                FARM               https://harvester.app 2021-06-30
# 5134                FARM            https://gamestop.finance 2021-06-30
# 5135                FARM  https://klingftm.borgswap.exchange 2021-06-30
# 5136                FARM                    https://aave.com 2021-06-30
# 5137                FARM               https://app.sushi.com 2021-06-30
# 5138                FARM       https://exchange.dfyn.network 2021-06-30
# 5139                FARM         https://polycrystal.finance 2021-06-30
# 5140                FARM        https://app.sushi.com/farms/ 2021-06-30
# 5141                FARM          https://spookyswap.finance 2021-06-30
# 5142                FARM      https://app.spiritswap.finance 2021-06-30
# 5143                FARM    https://www.liquiddriver.finance 2021-06-30
# 5144                FARM        https://frankenstein.finance 2021-06-30
# 5145                FARM                https://waka.finance 2021-06-30
# 5146                FARM  https://klingftm.borgswap.exchange 2021-06-30
# 5147                FARM       https://www.operaswap.finance 2021-06-30
# 5148                FARM         https://polycrystal.finance 2021-06-30

# %%
pair_df = pair_df.drop_duplicates()

# %%
df['pair1'].unique().tolist()
# Out:
# ['ALEPH',
#  'APYS',
#  'BLD',
#  'BOLE',
#  'BOP',
#  'BTC',
#  'CATO',
#  'CCAI',
#  'CHAD',
#  'CHEEMS',
#  'COPE',
#  'ETH',
#  'FAB',
#  'FIDA',
#  'FROG',
#  'FTR',
#  'FTT',
#  'GÜ',
#  'JOKE',
#  'KEEP',
#  'KEKW',
#  'KERMIT',
#  'KIN',
#  'LINK',
#  'LIQ',
#  'LUA',
#  'MAPS',
#  'MEDIA',
#  'MER',
#  'MOLA',
#  'OXS',
#  'OXY',
#  'PARTI',
#  'RAY',
#  'ROPE',
#  'SAIL',
#  'SAMO',
#  'SBFC',
#  'SDOGE',
#  'SHBL',
#  'SKEM',
#  'SLIM',
#  'SNY',
#  'SOL',
#  'SOLAPE',
#  'SOLPAD',
#  'SRM',
#  'STEP',
#  'SUSHI',
#  'TOMO',
#  'TULIP',
#  'TYNA',
#  'unknown',
#  'USDC',
#  'USDT',
#  'VCC',
#  'WOO',
#  'WOOF',
#  'xCOPE',
#  'YFI']

# %% [markdown]
# ## Farm Risk

# %%
# # farms_risks_df = pd.read_excel("~/notebooks/vfat_tool_data/Farm_risk.xlsx", sheet_name='BSC')
# farm_risk_df = pd.read_csv('~/notebooks/vfat_tool_data/farm_risks_analysis.csv')

# %%
# farm_risk_df.columns = ['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', 'rugdoc_url', 'network']
# farm_risk_df

# %%
# pairs_farm_risk_df = pd.merge(pair_df, farm_risk_df, how='left', left_on=['dex', 'network'], right_on=['Farm Url', 'network'])
# pairs_farm_risk_df.to_csv('farm_risk_yield_data_2021_06_14.csv')
# pairs_farm_risk_df

# %%
# farms_df = pair_df[['dex', 'network']].drop_duplicates().reset_index(drop=True)

# %%
# farms_df

# %%
# new_farm_risk_df = pd.merge(farms_df, farm_risk_df, how='left', left_on=['dex', 'network'], right_on=['Farm Url', 'network'])
# new_farm_risk_df['Farm Url'] = new_farm_risk_df['dex']
# del new_farm_risk_df['dex']
# new_farm_risk_df = new_farm_risk_df[['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', 'rugdoc_url', 'network']]

# # new_farm_risk_df.columns = ['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', 'rugdoc_url', 'network']

# %%
# new_farm_risk_df.to_csv('Farm_risk_06_14.csv', index=False)

# %%
excel_file = '~/notebooks/vfat_tool_data/Farm_risk_20210616.xlsx'

# %%
bsc_risks_df = pd.read_excel(excel_file, sheet_name='BSC')
bsc_risks_df.columns = ['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2', '3']
bsc_risks_df['rugdoc_url'] = bsc_risks_df['1'].fillna('') + bsc_risks_df['2'].fillna('') + bsc_risks_df['3'].fillna('')
del bsc_risks_df['1']
del bsc_risks_df['2']
del bsc_risks_df['3']
bsc_risks_df['network'] = 'BSC'
bsc_risks_df
# Out:
#           #  Indiv. Assesment  Audit Score RugDoc   Farm Name Farm Symbol  \
# 0         x               NaN          NaN  least     Pancake        CAKE
# 1       NaN               NaN          NaN   some     Apeswap      BANANA
# 2       NaN               NaN          NaN    NaN    Autofarm    AUTOFARM
# 3         x               9.0          NaN    NaN        Bake        BAKE
# 4         x               NaN         86.0    NaN        Brew        BREW
# ..      ...               ...          ...    ...         ...         ...
# 324     NaN               NaN          NaN    low   VenomSwap       VENOM
# 325     NaN               NaN          NaN    low    Elephant    ELEPHANT
# 326  No TLV               NaN          NaN    NaN   Bloodmoon   BLOODMOON
# 327     NaN               NaN          NaN    low  Blacksheep  BLACKSHEEP
# 328     NaN               NaN          NaN    NaN        Rice        RICE
#
#                              Farm Url  \
# 0         https://pancakeswap.finance
# 1             https://apeswap.finance
# 2            https://autofarm.network
# 3          https://www.bakeryswap.org
# 4            https://cafeswap.finance
# ..                                ...
# 324         https://www.venomswap.net
# 325  https://app.elephantswap.finance
# 326   https://bloodmoon.werewolf.farm
# 327    https://www.blacksheepdefi.com
# 328               https://ricefarm.fi
#
#                                         rugdoc_url network
# 0           https://rugdoc.io/project/pancakeswap/     BSC
# 1               https://rugdoc.io/project/apeswap/     BSC
# 2                                                      BSC
# 3                                                      BSC
# 4         https://www.certik.org/projects/cafeswap     BSC
# ..                                             ...     ...
# 324          https://rugdoc.io/project/venom-swap/     BSC
# 325       https://rugdoc.io/project/elephant-swap/     BSC
# 326                                                    BSC
# 327  https://rugdoc.io/project/blacksheep-finance/     BSC
# 328                                                    BSC
#
# [329 rows x 9 columns]

# %%
matic_risks_df = pd.read_excel(excel_file, sheet_name='MATIC')
matic_risks_df.columns = ['#', 'Indiv. Assesment', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2']
matic_risks_df['Audit Score'] = np.nan
matic_risks_df['rugdoc_url'] = matic_risks_df['1'].fillna('') + matic_risks_df['2'].fillna('')
del matic_risks_df['1']
del matic_risks_df['2']
matic_risks_df['network'] = 'MATIC'
matic_risks_df
# Out:
#          # Indiv. Assesment RugDoc     Farm Name Farm Symbol  \
# 0        x              low    NaN   Quickswap *       QUICK
# 1        x             some    NaN        Cometh        MUST
# 2   No TLV              NaN    NaN          Dark          DB
# 3      NaN              NaN    NaN      Smartdex        NIOX
# 4        x             high    NaN           Elk         ELK
# ..     ...              ...    ...           ...         ...
# 85  No TLV              NaN    NaN      PolyZero        ZERO
# 86     NaN              NaN    low       PolyMax         MAX
# 87     NaN              NaN    low  PolySnowFarm        SNOW
# 88     NaN              NaN    low      Polyyeld        YELD
# 89     NaN              NaN    low        Polysa        DUFF
#
#                               Farm Url  Audit Score  \
# 0   https://quickswap.exchange/#/quick          NaN
# 1       https://swap.cometh.io/#/stake          NaN
# 2               https://www.dark.build          NaN
# 3            https://swap.smartdex.app          NaN
# 4              https://app.elk.finance          NaN
# ..                                 ...          ...
# 85                                 NaN          NaN
# 86                https://polymax.club          NaN
# 87               https://polysnow.farm          NaN
# 88            https://polyyeld.finance          NaN
# 89          https://www.polysa.finance          NaN
#
#                                      rugdoc_url network
# 0                                                 MATIC
# 1                                                 MATIC
# 2                                                 MATIC
# 3                                                 MATIC
# 4                                                 MATIC
# ..                                          ...     ...
# 85                                                MATIC
# 86           https://rugdoc.io/project/polymax/   MATIC
# 87     https://rugdoc.io/project/polysnow-farm/   MATIC
# 88  https://rugdoc.io/project/polyyeld-finance/   MATIC
# 89    https://rugdoc.io/project/polysa-finance/   MATIC
#
# [90 rows x 9 columns]

# %%
avax_risks_df = pd.read_excel(excel_file, sheet_name='AVAX')
avax_risks_df.columns = ['#', 'Indiv. Assesment', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2']
avax_risks_df['Audit Score'] = np.nan
avax_risks_df['rugdoc_url'] = avax_risks_df['1'].fillna('') + avax_risks_df['2'].fillna('')
del avax_risks_df['1']
del avax_risks_df['2']
avax_risks_df['network'] = 'AVAX'
avax_risks_df
# Out:
#          # Indiv. Assesment RugDoc  Farm Name Farm Symbol  \
# 0        x              low    NaN   Pangolin         PNG
# 1        x              low    NaN    Complus         COM
# 2      NaN              NaN    NaN       Zero        ZERO
# 3      NaN              NaN    NaN       Yeti         YTS
# 4        x              NaN    low  Pandaswap      BAMBOO
# 5        x             some    NaN       Pefi        PEFI
# 6        x             high    NaN      Elk *         ELK
# 7   No TLV              NaN    NaN   Snowball        SNOB
# 8        x             some    NaN      Olive       OLIVE
# 9        x              NaN   some      Lydia         LYD
# 10     NaN              NaN    NaN   Baguette         BAG
# 11     NaN              NaN    NaN    Gondola         GDL
# 12       x              NaN   HIGH      Birdy        BIRD
# 13       x             some    NaN     Canary         CNR
# 14     NaN              NaN    NaN  Avalaunch        XAVA
# 15       x             some    NaN       Avme        AVME
#
#                                Farm Url  Audit Score  \
# 0   https://app.pangolin.exchange/#/png          NaN
# 1         https://avax.complus.exchange          NaN
# 2                https://app.0.exchange          NaN
# 3         https://exchange.yetiswap.app          NaN
# 4            https://pandaswap.exchange          NaN
# 5            https://penguinfinance.org          NaN
# 6                   https://elk.finance          NaN
# 7         https://snowball.network/earn          NaN
# 8               https://avax.olive.cash          NaN
# 9             https://www.lydia.finance          NaN
# 10        https://app.baguette.exchange          NaN
# 11          https://app.gondola.finance          NaN
# 12                https://birdy.finance          NaN
# 13          https://app.canary.exchange          NaN
# 14           https://farm.avalaunch.app          NaN
# 15                      https://avme.io          NaN
#
#                                     rugdoc_url network
# 0                                                 AVAX
# 1                                                 AVAX
# 2                                                 AVAX
# 3                                                 AVAX
# 4   https://rugdoc.io/project/panda-swap-defi/    AVAX
# 5                                                 AVAX
# 6                                                 AVAX
# 7                                                 AVAX
# 8                                                 AVAX
# 9        https://rugdoc.io/project/lydia-avax/    AVAX
# 10                                                AVAX
# 11                                                AVAX
# 12  https://rugdoc.io/project/birdy-avalanche/    AVAX
# 13                                                AVAX
# 14                                                AVAX
# 15                                                AVAX

# %%
fantom_risks_df = pd.read_excel(excel_file, sheet_name='FANTOM')
fantom_risks_df.columns = ['#', 'Indiv. Assesment', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2']
fantom_risks_df['Audit Score'] = np.nan
fantom_risks_df['rugdoc_url'] = fantom_risks_df['1'].fillna('') + fantom_risks_df['2'].fillna('')
del fantom_risks_df['1']
del fantom_risks_df['2']
fantom_risks_df['network'] = 'FANTOM'
fantom_risks_df
# Out:
#          # Indiv. Assesment RugDoc      Farm Name Farm Symbol  \
# 0      NaN              NaN    NaN       Popsicle         ICE
# 1        x              NaN    low         Spooky         boo
# 2        x              NaN   some         Spirit      SPIRIT
# 3        x              NaN    low           Borg         SON
# 4        x              NaN    low      Hyperjump         ORI
# 5        x              NaN    low          Ester         EST
# 6        x             high    NaN          Froyo       FROYO
# 7      NaN              NaN    NaN          Ghost       GHOST
# 8   No TLV              NaN    low          Beefy     Various
# 9        x             some    NaN  Liquid Driver        LQDR
# 10     NaN              NaN    NaN     Standard *        STRD
# 11     NaN              NaN    NaN      Mushrooms          MM
# 12       x             high    NaN     Greenhouse        SEED
# 13     NaN              NaN   high    Stake Steak       STEAK
# 14     NaN              NaN   high   Frankenstein       FRANK
# 15       x              NaN   high           Waka        WAKA
# 16       x             some    NaN            Elk         ELK
# 17      xx              NaN   high      Paintswap       BRUSH
# 18      xx              NaN    low           Tomb     Various
# 19     NaN              NaN   high         Shadow     Various
# 20     NaN              NaN    low       Borgswap       KLING
# 21     NaN              NaN   some          Opera       OPERA
#
#                               Farm Url  Audit Score  \
# 0             https://popsicle.finance          NaN
# 1           https://spookyswap.finance          NaN
# 2       https://app.spiritswap.finance          NaN
# 3        https://ftm.borgswap.exchange          NaN
# 4                 https://hyperjump.fi          NaN
# 5                https://ester.finance          NaN
# 6         https://frozenyogurt.finance          NaN
# 7         https://www.theghost.finance          NaN
# 8         https://fantom.beefy.finance          NaN
# 9     https://www.liquiddriver.finance          NaN
# 10                https://strd.finance          NaN
# 11     https://mushrooms.finance/farms          NaN
# 12       https://thegreenhouse.finance          NaN
# 13              https://stakesteak.com          NaN
# 14        https://frankenstein.finance          NaN
# 15                https://waka.finance          NaN
# 16             https://app.elk.finance          NaN
# 17           https://paintswap.finance          NaN
# 18                https://tomb.finance          NaN
# 19              https://shadowswap.app          NaN
# 20  https://klingftm.borgswap.exchange          NaN
# 21       https://www.operaswap.finance          NaN
#
#                                        rugdoc_url network
# 0                                                  FANTOM
# 1           https://rugdoc.io/project/spookyswap/  FANTOM
# 2           https://rugdoc.io/project/spiritswap/  FANTOM
# 3       https://rugdoc.io/project/borgswap-kling/  FANTOM
# 4         https://rugdoc.io/project/hyperjump-fi/  FANTOM
# 5        https://rugdoc.io/project/ester-finance/  FANTOM
# 6                                                  FANTOM
# 7                                                  FANTOM
# 8        https://rugdoc.io/project/beefy-finance/  FANTOM
# 9                                                  FANTOM
# 10                                                 FANTOM
# 11                                                 FANTOM
# 12                                                 FANTOM
# 13          https://rugdoc.io/project/stakesteak/  FANTOM
# 14        https://rugdoc.io/project/frankenstein/  FANTOM
# 15            https://rugdoc.io/project/waka-ftm/  FANTOM
# 16                                                 FANTOM
# 17           https://rugdoc.io/project/paintswap/  FANTOM
# 18        https://rugdoc.io/project/tomb-finance/  FANTOM
# 19  https://rugdoc.io/project/shadowswap-finance/  FANTOM
# 20      https://rugdoc.io/project/borgswap-kling/  FANTOM
# 21   https://rugdoc.io/project/operaswap-finance/  FANTOM

# %%
risk_df = bsc_risks_df.append(matic_risks_df)
risk_df = risk_df.append(avax_risks_df)
risk_df = risk_df.append(fantom_risks_df)
risk_df = risk_df[risk_df['rugdoc_url'] != '']
risk_df
# Out:
#       # Indiv. Assesment  Audit Score RugDoc  Farm Name Farm Symbol  \
# 0     x              NaN          NaN  least    Pancake        CAKE
# 1   NaN              NaN          NaN   some    Apeswap      BANANA
# 4     x              NaN         86.0    NaN       Brew        BREW
# 5   NaN              NaN          NaN   some      Donut       DONUT
# 7   NaN              NaN          NaN    NaN      Goose       GOOSE
# ..  ...              ...          ...    ...        ...         ...
# 17   xx              NaN          NaN   high  Paintswap       BRUSH
# 18   xx              NaN          NaN    low       Tomb     Various
# 19  NaN              NaN          NaN   high     Shadow     Various
# 20  NaN              NaN          NaN    low   Borgswap       KLING
# 21  NaN              NaN          NaN   some      Opera       OPERA
#
#                               Farm Url  \
# 0          https://pancakeswap.finance
# 1              https://apeswap.finance
# 4             https://cafeswap.finance
# 5                https://donutdefi.com
# 7            https://www.goosedefi.com
# ..                                 ...
# 17           https://paintswap.finance
# 18                https://tomb.finance
# 19              https://shadowswap.app
# 20  https://klingftm.borgswap.exchange
# 21       https://www.operaswap.finance
#
#                                        rugdoc_url network
# 0          https://rugdoc.io/project/pancakeswap/     BSC
# 1              https://rugdoc.io/project/apeswap/     BSC
# 4        https://www.certik.org/projects/cafeswap     BSC
# 5           https://rugdoc.io/project/donutswapp/     BSC
# 7       https://www.certik.org/projects/ramenswap     BSC
# ..                                            ...     ...
# 17           https://rugdoc.io/project/paintswap/  FANTOM
# 18        https://rugdoc.io/project/tomb-finance/  FANTOM
# 19  https://rugdoc.io/project/shadowswap-finance/  FANTOM
# 20      https://rugdoc.io/project/borgswap-kling/  FANTOM
# 21   https://rugdoc.io/project/operaswap-finance/  FANTOM
#
# [218 rows x 9 columns]

# %%
pairs_farm_risk_df = pd.merge(pair_df, risk_df, how='left', left_on=['dex', 'network'], right_on=['Farm Url', 'network'])
pairs_farm_risk_df.to_csv('farm_risk_yield_data_2021_07_01.csv')
pairs_farm_risk_df
# Out:
#           pair1  pair2         tvl      apr network           apy  \
# 0           $DG    BNB  1817147.28   203.39     BSC  6.600805e+02
# 1           $DG    ETH   573615.99    86.51   MATIC  1.372814e+02
# 2           $DG  QUICK   173485.21    71.51   MATIC  1.042961e+02
# 3         $TRDL    ETH   148319.28   162.47     ETH  4.058625e+02
# 4         $TRDL   MUST     5192.44     0.00   MATIC  0.000000e+00
# ...         ...    ...         ...      ...     ...           ...
# 13298  zs-XUSD2               0.00        0     ETH  0.000000e+00
# 13299  zs-tsBTC               0.00        0     ETH  0.000000e+00
# 13300      τBTC             107.45   323.19     BSC  2.397001e+03
# 13301         🌾          113115.97  3468.42   MATIC  2.453592e+16
# 13302         🚜           18383.78    18.30   MATIC  2.007593e+01
#
#       type_of_agriculture                                 dex       date    #  \
# 0                    FARM         https://pancakeswap.finance 2021-06-30    x
# 1                    FARM  https://quickswap.exchange/#/quick 2021-06-30  NaN
# 2                    FARM  https://quickswap.exchange/#/quick 2021-06-30  NaN
# 3                    FARM             https://strudel.finance 2021-06-30  NaN
# 4                    FARM      https://swap.cometh.io/#/stake 2021-06-30  NaN
# ...                   ...                                 ...        ...  ...
# 13298                FARM  https://www.stabilize.finance/app/ 2021-06-30  NaN
# 13299                FARM  https://www.stabilize.finance/app/ 2021-06-30  NaN
# 13300                FARM          https://www.elixir-swap.io 2021-06-30  NaN
# 13301                FARM               https://harvester.app 2021-06-30  NaN
# 13302                FARM        https://www.honestwork.farm/ 2021-06-30  NaN
#
#       Indiv. Assesment  Audit Score RugDoc Farm Name Farm Symbol  \
# 0                  NaN          NaN  least   Pancake        CAKE
# 1                  NaN          NaN    NaN       NaN         NaN
# 2                  NaN          NaN    NaN       NaN         NaN
# 3                  NaN          NaN    NaN       NaN         NaN
# 4                  NaN          NaN    NaN       NaN         NaN
# ...                ...          ...    ...       ...         ...
# 13298              NaN          NaN    NaN       NaN         NaN
# 13299              NaN          NaN    NaN       NaN         NaN
# 13300              NaN          NaN   high    Elixir        ELXR
# 13301              NaN          NaN    NaN       NaN         NaN
# 13302              NaN          NaN    NaN       NaN         NaN
#
#                           Farm Url                              rugdoc_url
# 0      https://pancakeswap.finance  https://rugdoc.io/project/pancakeswap/
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                              NaN                                     NaN
# ...                            ...                                     ...
# 13298                          NaN                                     NaN
# 13299                          NaN                                     NaN
# 13300   https://www.elixir-swap.io  https://rugdoc.io/project/elixir-swap/
# 13301                          NaN                                     NaN
# 13302                          NaN                                     NaN
#
# [13303 rows x 17 columns]
