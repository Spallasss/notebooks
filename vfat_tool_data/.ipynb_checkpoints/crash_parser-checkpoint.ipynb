# %%
import re
import os
import pandas as pd
import numpy as np
import traceback2
from datetime import datetime
import pymysql
import numpy as np

where_map = {}
# pairs regexp: "\[([a-zA-z0-9$\-+τ\.%]*)\]-", "-\[([a-zA-z0-9$\-+τ]*)\]",  or ( c in ['τ'] for c in s)

# %%
def pair1(line):
#     print(line)
    try:
        is_3_pairs = line.split("]-[")
        if len(is_3_pairs) > 2:
            return None
        s_index = line.index("[") + 1
        s = line[s_index: line.index("]", s_index)]
        if all(ord(c) < 128 for c in s):
            return s
        else:
            print(line)
            return None
    except:
        return ''

def pair2(line):
#     print(line)
    s_index = line.index("-[") + 2
    s = line[s_index: line.index("]", s_index)]
#     print(s)
    if all(ord(c) < 128 for c in s):
        return s
    else:
        print(line)
        return ''

# %%
def apr(line):
    apr = "Year [0-9\,\.]+\%"
    x = re.findall(apr, line)
    return x[0].replace("Year ", "").replace("%", "").strip() if len(x) else 0

# %%
def tvl(line):
    tvl = "TVL: \$[0-9\.\,]+"
    x = re.findall(tvl, line)
    return x[0].replace("TVL: $", "").replace("%", "").replace(",","").strip()

# %%
def where(line):
    if 'INFO' in line:
        return line.replace("INFO", "").replace('\n', '').replace(":", "").replace("//", "://").replace('*', '').strip()
    return None

# %%
def get_single_pair(line):
    exp = "\d* *.*Price:"
    x = re.findall(exp, line)
    if not len(x) or "TVL:" in line:
#         print(">>>>>>>>>>>",line)
        return
    pair = x[0].replace(" Price:", "")
    return pair[pair.rindex(" "):].strip() if " " in pair else pair

def get_single_tvl(line):
    exp = "\([0-9\,\.$]+\)"
    x = re.findall(exp, line)
    return x[0].replace("(", "").replace(")", "").replace("$", "").replace(",","").strip()

# %%
def is_end_of_block(line):
#     print(line, line == "" or len(re.findall("INFO[ ]+: ", line)))
    return line.strip() == "" or len(re.findall("INFO[ ]+: ", line)) or "******" in line

def read_block(lines, start_index):
    block = []
#     print("Block Start Line No.: ", start_index + 1)
    while start_index < len(lines):
        line = lines[start_index]
        start_index = start_index + 1
        if not is_end_of_block(line):
            block.append(line.strip())
        else:
            break
    return [block, start_index]

def read_blocks_from_files(file):
    f = open(file)
    lines = f.readlines()
    blocks = []
    block = []
    block_start_line_no = []
    line_no = 0
    start_index = 0
    while start_index < len(lines):
        line = lines[start_index]
        if not is_end_of_block(lines[start_index]):
            block_and_index = read_block(lines, start_index)
#             print(block_and_index[0])
            if block_and_index is not None:
                block_start_line_no.append(start_index + 1)
                start_index = block_and_index[1]
                blocks.append(block_and_index[0])
            else:
                start_index = start_index + 1
        elif len(re.findall("INFO[ ]+: ", line)):
            block_start_line_no.append(start_index + 1)
            blocks.append([line])
            start_index = start_index + 1
        else:
            start_index = start_index + 1
    return [blocks, block_start_line_no]

def read_blocks_from_files_as(file):
    f = open(file)
    lines = f.readlines()
    blocks = []
    block = []
    block_start_line_no = []
    line_no = 0
    for line in lines:
        line_no = line_no + 1
        line = line.strip()
        if line == "" or len(re.findall("INFO[ ]+: ", line)):
            blocks.append(block)
            block_start_line_no.append(line_no)
            if len(line):
                blocks.append([line])
                block_start_line_no.append(line_no + 1)
            block = []
        else:
            block.append(line)
            
    blocks.append(block)
    return [blocks, block_start_line_no]

def get_pair_info_from_block(block, wh, network):
    tvl_index = 0
    if network == 'BSC':
        tvl_index = 3
    if len(block) == 1:
        if 'INFO' in block[0]:
            return [where(block[0])]
        else:
            return [wh] if len(wh) else None
    if len(block) and pair1(block[0]) and not get_single_pair(block[0]):
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        return [pair1(block[0]), pair2(block[0]), get_single_tvl(block[tvl_index]) if tvl_index > 0 else tvl(block[tvl_index]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
    elif len(block) > 2 and get_single_pair(block[0]):
#         print('singel')
        if network == 'BSC':
            tvl_index = 1
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        return [get_single_pair(block[0]), "", get_single_tvl(block[1]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
    return None


def get_pairs(blocks, network, block_start_line_no):
    where = ""
    pairs = []
    index = -1
    for block in blocks:
#         print('!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!')
        index = index + 1
        try:
            pair = get_pair_info_from_block(block, where, network)
            if pair == None:
                print('no Pair....\n',block)
                print("Block Start Line No.: ", block_start_line_no[index] if index < len(block_start_line_no) else -1)
#             if len(where) == 0 and pair and len(pair) > 2:
#                 print(block, network)
            if pair is not None and len(pair) > 0:
                if len(pair) == 1 and pair[0] and len(pair[0]):
                    where = pair[0]
                else:
                    pairs.append(pair)
        except Exception as e:
            print("Exception", traceback2.format_exc())
            print(block[0])
    return pairs

# %%
data_dir = './'
def conver_files_to_one_df(data_dir):
    all_pairs = []
    files = os.listdir(data_dir)
    for file_name in files:
        if file_name in ignorable_files:
            continue
        network = file_name[0:file_name.index(" ")]
        if 'Alternate' == network:
            network = 'ETH'
#         if 'MATIC' != network:
#             continue
        print(file_name)
        blocks = read_blocks_from_files(f"{data_dir}{file_name}")
        block_start_line_no = blocks[1]
        blocks = blocks[0]
        pairs = get_pairs(blocks, network, block_start_line_no)
        all_pairs.extend(pairs)
    return all_pairs

# %%
pairs = conver_files_to_one_df(data_dir)
# Out:
# AVAX 6:28 Yields.uu
# no Pair....
#  ['AVAX 6/28 Yields']
# Block Start Line No.:  1
# 33 - [WAVAX]-[🐆] Uni LP [+] [-] [<=>] Price: $23.73 TVL: $822.35
# Alternate Yield Format 6:28.uu
# no Pair....
#  ['Alternate Yield Format 6/28']
# Block Start Line No.:  1
# no Pair....
#  ['___________________________________________________________________________']
# Block Start Line No.:  4
# no Pair....
#  ['MATIC', '___________________________________________________________________________']
# Block Start Line No.:  6
# no Pair....
#  ['DAI ($1.00)', 'Supplied : 1,036,988,170.35 ($1,036,988,170.35) at 2.56% APR', 'Borrowed : 781,734,522.07 ($781,734,522.07) at 3.77% APR', 'Reserves : 255,253,648.67 ($255,253,648.67)', 'Farming APR Supply 1.22% Borrow 2.44%', 'Net APR Supply 3.78% Borrow -1.33%']
# Block Start Line No.:  12
# no Pair....
#  ['USDC ($1.00)', 'Supplied : 1,206,248,858.41 ($1,206,248,858.41) at 2.18% APR', 'Borrowed : 890,088,173.12 ($890,088,173.12) at 3.28% APR', 'Reserves : 316,160,690.31 ($316,160,690.31)', 'Farming APR Supply 0.96% Borrow 1.94%', 'Net APR Supply 3.13% Borrow -1.33%']
# Block Start Line No.:  19
# no Pair....
#  ['USDT ($1.00)', 'Supplied : 288,420,001.56 ($288,420,001.56) at 2.40% APR', 'Borrowed : 223,374,359.18 ($223,374,359.18) at 3.44% APR', 'Reserves : 65,045,642.85 ($65,045,642.85)', 'Farming APR Supply 1.60% Borrow 3.10%', 'Net APR Supply 4.00% Borrow -0.34%']
# Block Start Line No.:  26
# no Pair....
#  ['WBTC ($34,486.00)', 'Supplied : 10,723.97 ($369,826,979.60) at 0.06% APR', 'Borrowed : 823.65 ($28,404,350.49) at 0.95% APR', 'Reserves : 9,900.33 ($341,422,629.31)', 'Farming APR Supply 0.35% Borrow 0.51%', 'Net APR Supply 0.41% Borrow -0.44%']
# Block Start Line No.:  33
# no Pair....
#  ['WETH ($2,036.24)', 'Supplied : 480,431.58 ($978,273,990.31) at 0.26% APR', 'Borrowed : 73,641.75 ($149,952,285.00) at 1.89% APR', 'Reserves : 406,789.82 ($828,321,705.62)', 'Farming APR Supply 1.33% Borrow 0.96%', 'Net APR Supply 1.59% Borrow -0.92%']
# Block Start Line No.:  40
# no Pair....
#  ['WMATIC ($1.11)', 'Supplied : 206,673,631.46 ($229,407,730.92) at 1.40% APR', 'Borrowed : 69,310,532.38 ($76,934,690.94) at 5.22% APR', 'Reserves : 137,363,099.21 ($152,473,040.12)', 'Farming APR Supply 3.02% Borrow 1.00%', 'Net APR Supply 4.42% Borrow -4.22%']
# Block Start Line No.:  47
# no Pair....
#  ['AAVE ($217.87)', 'Supplied : 348,956.73 ($76,027,201.95) at 0.00% APR', 'Borrowed : 0.00 ($0.00) at 0.00% APR', 'Reserves : 348,956.73 ($76,027,201.95)', 'Farming APR Supply 0.63% Borrow NaN%', 'Net APR Supply 0.63% Borrow NaN%']
# Block Start Line No.:  54
# no Pair....
#  ['Total Staked: $82,883,124.38', 'Found 100 pools.']
# Block Start Line No.:  247
# no Pair....
#  ['-------------------------------------------------', 'TOKEN INFORMATION', '-------------------------------------------------']
# Block Start Line No.:  789
# no Pair....
#  ['50C price $0.80', '50C Circulating 197,632', '50C totalSupply 197,632', 'Fully diluted marketcap: $158,461']
# Block Start Line No.:  793
# no Pair....
#  ['50K price $72.97', '50K Circulating 1,322.39', '50K totalSupply 200,001.00', 'Fully diluted marketcap: $14,594,073']
# Block Start Line No.:  798
# no Pair....
#  ['-------------------------------------------------', 'POOLS INFORMATION', '-------------------------------------------------']
# Block Start Line No.:  804
# no Pair....
#  ['WMATIC Pool:', '--Reward: 50C', '--APR: 20.32%', '--TVL: $1,444,230', '--Your deposit: $0.00']
# Block Start Line No.:  812
# no Pair....
#  ['WETH Pool:', '--Reward: 50C', '--APR: 41.12%', '--TVL: $713,618', '--Your deposit: $0.00']
# Block Start Line No.:  818
# no Pair....
#  ['USDC Pool:', '--Reward: 50C', '--APR: 15.54%', '--TVL: $1,888,201', '--Your deposit: $0.00']
# Block Start Line No.:  824
# no Pair....
#  ['50C-USDC Pool:', '--Reward: 50C', '--APR: 18,019.86%', '--TVL: $16,285', '--Your deposit: $0.00']
# Block Start Line No.:  830
# no Pair....
#  ['50C-WMatic Pool:', '--Reward: 50K', '--APR: 14,706.89%', '--TVL: $59,539', '--Your deposit: $0.00']
# Block Start Line No.:  836
# no Pair....
#  ['50K-USDC Pool:', '--Reward: 50K', '--APR: 11,407.20%', '--TVL: $31,984', '--Your deposit: $0.00']
# Block Start Line No.:  842
# no Pair....
#  ['50C Pool:', '--Reward: 50K', '--APR: 10,713.86%', '--TVL: $20,432', '--Your deposit: $0.00']
# Block Start Line No.:  848
# 0 - [🌾]-[WETH] SLP [+] [-] [<=>] Price: $301.90 TVL: $62,953.20
# no Pair....
#  ['0 - [🌾]-[WETH] SLP [+] [-] [<=>] Price: $301.90 TVL: $62,953.20', '🌾 Price: $10.45', 'WETH Price: $2,081.40', 'Staked: 201.8257 SLP ($60,930.57)', '🌾 Per Week: 95206.61 ($995,137.20)', 'APR: Day 233.32% Week 1633.23% Year 84928.04%', 'You are staking 0.00 [🌾]-[WETH] SLP ($0.00), 0.00% of the pool.', 'Stake 0.00 [🌾]-[WETH] SLP', 'Unstake 0.00 [🌾]-[WETH] SLP', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  858
# no Pair....
#  ['ETH', '___________________________________________________________________________']
# Block Start Line No.:  992
# no Pair....
#  ['fWETH Price: $2,100.96 TVL: $15,717,381.90', 'Staked: 7425.9617 fWETH ($15,601,658.57)', 'FARM Per Week: 116.41 ($5,701.72)', 'APR: Day 0.01% Week 0.04% Year 1.90%', 'You are staking 0.00 fWETH ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fWETH', 'Unstake 0.000000 fWETH', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1053
# no Pair....
#  ['fBAC Price: $0.07 TVL: $111.00', 'Staked: 1198.2196 fBAC ($86.57)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fBAC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fBAC', 'Unstake 0.000000 fBAC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1101
# no Pair....
#  ['fESD Price: $0.04 TVL: $9,544.69', 'Staked: 211750.8008 fESD ($9,004.69)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fESD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fESD', 'Unstake 0.000000 fESD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1113
# no Pair....
#  ['fDSD Price: $0.02 TVL: $1,205.62', 'Staked: 60247.9388 fDSD ($1,124.59)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fDSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fDSD', 'Unstake 0.000000 fDSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1125
# no Pair....
#  ['fyDAI+yUSDC+yUSDT+yTUSD Price: $1.15 TVL: $694,407.20', 'Staked: 497812.1127 fyDAI+yUSDC+yUSDT+yTUSD ($573,377.77)', 'FARM Per Week: 2.91 ($142.74)', 'APR: Day 0.00% Week 0.02% Year 1.29%', 'You are staking 0.00 fyDAI+yUSDC+yUSDT+yTUSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fyDAI+yUSDC+yUSDT+yTUSD', 'Unstake 0.000000 fyDAI+yUSDC+yUSDT+yTUSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1137
# no Pair....
#  ['fhusd3CRV Price: $0.00 TVL: $0.00', 'Staked: 1609864.8146 fhusd3CRV ($0.00)', 'FARM Per Week: 7.29 ($356.85)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fhusd3CRV ($0.00), NaN% of the pool.', 'Staking Contract', 'Stake 0.000000 fhusd3CRV', 'Unstake 0.000000 fhusd3CRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1149
# no Pair....
#  ['fcDAI+cUSDC Price: $1.10 TVL: $1,054,688.03', 'Staked: 906917.9669 fcDAI+cUSDC ($1,001,986.36)', 'FARM Per Week: 8.74 ($428.22)', 'APR: Day 0.01% Week 0.04% Year 2.22%', 'You are staking 0.00 fcDAI+cUSDC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fcDAI+cUSDC', 'Unstake 0.000000 fcDAI+cUSDC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1161
# no Pair....
#  ['fyDAI+yUSDC+yUSDT+yBUSD Price: $1.13 TVL: $1,315,019.18', 'Staked: 893890.0171 fyDAI+yUSDC+yUSDT+yBUSD ($1,012,356.87)', 'FARM Per Week: 13.11 ($642.33)', 'APR: Day 0.01% Week 0.06% Year 3.30%', 'You are staking 0.00 fyDAI+yUSDC+yUSDT+yBUSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fyDAI+yUSDC+yUSDT+yBUSD', 'Unstake 0.000000 fyDAI+yUSDC+yUSDT+yBUSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1173
# no Pair....
#  ['fusdn3CRV Price: $0.00 TVL: $0.00', 'Staked: 1781803.5863 fusdn3CRV ($0.00)', 'FARM Per Week: 58.28 ($2,854.79)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fusdn3CRV ($0.00), NaN% of the pool.', 'Staking Contract', 'Stake 0.000000 fusdn3CRV', 'Unstake 0.000000 fusdn3CRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1185
# no Pair....
#  ['fUSDC Price: $0.91 TVL: $9,458,486.14', 'Staked: 10985350.1643 fUSDC ($9,991,053.89)', 'FARM Per Week: 45.15 ($2,211.46)', 'APR: Day 0.00% Week 0.02% Year 1.15%', 'You are staking 0.00 fUSDC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fUSDC', 'Unstake 0.000000 fUSDC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1197
# no Pair....
#  ['fUSDT Price: $0.91 TVL: $2,119,977.32', 'Staked: 2442888.9565 fUSDT ($2,232,688.98)', 'FARM Per Week: 14.37 ($703.65)', 'APR: Day 0.00% Week 0.03% Year 1.64%', 'You are staking 0.00 fUSDT ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fUSDT', 'Unstake 0.000000 fUSDT', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1209
# no Pair....
#  ['fTUSD Price: $1.05 TVL: $25,026.48', 'Staked: 2491.7610 fTUSD ($2,625.56)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fTUSD ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fTUSD', 'Unstake 0.000000 fTUSD', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1221
# no Pair....
#  ['fDAI Price: $1.05 TVL: $8,578,067.06', 'Staked: 7726176.5957 fDAI ($8,121,175.86)', 'FARM Per Week: 27.91 ($1,367.09)', 'APR: Day 0.00% Week 0.02% Year 0.88%', 'You are staking 0.00 fDAI ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fDAI', 'Unstake 0.000000 fDAI', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1233
# no Pair....
#  ['fhCRV Price: $0.00 TVL: $0.00', 'Staked: 196.6380 fhCRV ($0.00)', 'FARM Per Week: 20.40 ($999.18)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fhCRV ($0.00), NaN% of the pool.', 'Staking Contract', 'Stake 0.000000 fhCRV', 'Unstake 0.000000 fhCRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1293
# no Pair....
#  ['foBTC/sbtcCRV Price: $36,206.72 TVL: $5,878,588.16', 'Staked: 151.8950 foBTC/sbtcCRV ($5,499,622.05)', 'FARM Per Week: 26.23 ($1,284.66)', 'APR: Day 0.00% Week 0.02% Year 1.21%', 'You are staking 0.00 foBTC/sbtcCRV ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 foBTC/sbtcCRV', 'Unstake 0.000000 foBTC/sbtcCRV', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1305
# no Pair....
#  ['ftbtc/sbtcCrv Price: $35,452.78 TVL: $431,154.50', 'Staked: 11.8359 ftbtc/sbtcCrv ($419,614.90)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 ftbtc/sbtcCrv ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 ftbtc/sbtcCrv', 'Unstake 0.000000 ftbtc/sbtcCrv', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1317
# no Pair....
#  ['fcrvRenWBTC Price: $35,645.55 TVL: $20,872,365.39', 'Staked: 574.8720 fcrvRenWBTC ($20,491,625.93)', 'FARM Per Week: 34.97 ($1,712.88)', 'APR: Day 0.00% Week 0.01% Year 0.43%', 'You are staking 0.00 fcrvRenWBTC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fcrvRenWBTC', 'Unstake 0.000000 fcrvRenWBTC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1329
# no Pair....
#  ['fWBTC Price: $34,812.23 TVL: $275,331.83', 'Staked: 7.6660 fWBTC ($266,871.64)', 'FARM Per Week: 1.46 ($71.37)', 'APR: Day 0.00% Week 0.03% Year 1.39%', 'You are staking 0.00 fWBTC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 fWBTC', 'Unstake 0.000000 fWBTC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1341
# no Pair....
#  ['frenBTC Price: $34,538.25 TVL: $84,833.21', 'Staked: 2.3888 frenBTC ($82,505.15)', 'FARM Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 frenBTC ($0.00), 0.00% of the pool.', 'Staking Contract', 'Stake 0.000000 frenBTC', 'Unstake 0.000000 frenBTC', 'Claim 0.000000 FARM', 'Exit']
# Block Start Line No.:  1353
# no Pair....
#  ['.------------------------------------------------------------------------------------------------------.', '|                                                Sushi                                                 |', '|------------------------------------------------------------------------------------------------------|', '|  #  |         Pair         | Total Staked | Total $ Staked  | Reward |   APR   |      My Stake       |', '|-----|----------------------|--------------|-----------------|--------|---------|---------------------|', '|   0 | [WETH]-[USDT] SLP    |       2.0172 | $256,102,490.45 | SUSHI  |  12.77% | 0.00 ($0.00), 0.00% |', '|   1 | [USDC]-[WETH] SLP    |       2.7318 | $352,425,256.26 | SUSHI  |  11.60% | 0.00 ($0.00), 0.00% |', '|   2 | [DAI]-[WETH] SLP     | 1787021.1937 | $212,935,570.64 | SUSHI  |  17.03% | 0.00 ($0.00), 0.00% |', '|   3 | [sUSD]-[WETH] SLP    |   70145.1676 |   $9,492,397.29 | SUSHI  |  18.06% | 0.00 ($0.00), 0.00% |', '|   4 | [COMP]-[WETH] SLP    |   10470.6358 |  $22,151,051.62 | SUSHI  |   8.81% | 0.00 ($0.00), 0.00% |', '|   6 | [SNX]-[WETH] SLP     |   69872.2588 |  $21,968,724.56 | SUSHI  |  18.01% | 0.00 ($0.00), 0.00% |', '|   7 | [UMA]-[WETH] SLP     |   24651.2773 |   $7,575,340.39 | SUSHI  |   7.83% | 0.00 ($0.00), 0.00% |', '|   8 | [LINK]-[WETH] SLP    |  167332.4441 |  $83,326,536.06 | SUSHI  |  15.82% | 0.00 ($0.00), 0.00% |', '|   9 | [BAND]-[WETH] SLP    |    7649.4793 |   $2,276,553.01 | SUSHI  |  28.96% | 0.00 ($0.00), 0.00% |', '|  11 | [YFI]-[WETH] SLP     |    5994.7643 | $165,604,081.42 | SUSHI  |  14.81% | 0.00 ($0.00), 0.00% |', '|  12 | [SUSHI]-[WETH] SLP   |  984439.4895 | $290,579,155.44 | SUSHI  |  21.78% | 0.00 ($0.00), 0.00% |', '|  13 | [REN]-[WETH] SLP     |   86338.7127 |   $6,452,506.40 | SUSHI  |  20.44% | 0.00 ($0.00), 0.00% |', '|  17 | [WETH]-[CRV] SLP     |   32880.1756 |  $13,763,283.34 | SUSHI  |  14.37% | 0.00 ($0.00), 0.00% |', '|  18 | [UNI]-[WETH] SLP     |    5567.3725 |   $2,378,153.76 | SUSHI  |   5.54% | 0.00 ($0.00), 0.00% |', '|  19 | [xSUSHI]-[WETH] SLP  |   91252.1523 |  $27,155,785.48 | SUSHI  |  17.00% | 0.00 ($0.00), 0.00% |', '|  21 | [WBTC]-[WETH] SLP    |       0.0096 | $393,282,295.52 | SUSHI  |   9.22% | 0.00 ($0.00), 0.00% |', '|  22 | [CREAM]-[WETH] SLP   |    1174.9875 |   $1,710,624.27 | SUSHI  |  23.13% | 0.00 ($0.00), 0.00% |', '|  25 | [yyDAI+yUSDC+yUSD... |   32109.8114 |   $3,492,903.03 | SUSHI  |  26.43% | 0.00 ($0.00), 0.00% |', '|  31 | [HEGIC]-[WETH] SLP   |   27172.5728 |     $806,285.83 | SUSHI  |   8.18% | 0.00 ($0.00), 0.00% |', '|  33 | [MKR]-[WETH] SLP     |    5601.3114 |  $25,374,448.52 | SUSHI  |  10.39% | 0.00 ($0.00), 0.00% |', '|  35 | [PICKLE]-[WETH] SLP  |    1003.1559 |     $284,513.53 | SUSHI  |  23.17% | 0.00 ($0.00), 0.00% |', '|  36 | [WETH]-[OMG] SLP     |   13438.1008 |   $2,531,829.10 | SUSHI  |  15.62% | 0.00 ($0.00), 0.00% |', '|  37 | [AAVE]-[WETH] SLP    |   65822.3942 |  $97,454,796.63 | SUSHI  |  11.16% | 0.00 ($0.00), 0.00% |', '|  38 | [WETH]-[AMP] SLP     |  140713.2854 |   $3,545,115.58 | SUSHI  |  13.02% | 0.00 ($0.00), 0.00% |', '|  41 | [WETH]-[RARI] SLP    |    4766.7287 |   $1,601,467.74 | SUSHI  |  16.47% | 0.00 ($0.00), 0.00% |', '|  42 | [DPI]-[WETH] SLP     |    2140.7019 |   $3,214,224.19 | SUSHI  |  12.31% | 0.00 ($0.00), 0.00% |', '|  44 | [YAM]-[WETH] SLP     |       0.0024 |   $1,747,870.66 | SUSHI  |  22.63% | 0.00 ($0.00), 0.00% |', '|  45 | REDUCE               |       0.0000 |           $0.00 | SUSHI  |    NaN% | 0.00 ($0.00), NaN%  |', '|  46 | [FARM]-[WETH] SLP    |     147.6555 |      $99,486.35 | SUSHI  |  66.27% | 0.00 ($0.00), 0.00% |', '|  48 | [DOUGH]-[WETH] SLP   |    1054.4365 |      $66,829.64 | SUSHI  |  98.66% | 0.00 ($0.00), 0.00% |', '|  49 | [STAKE]-[WETH] SLP   |    2375.4854 |     $683,918.71 | SUSHI  |  48.20% | 0.00 ($0.00), 0.00% |', '|  53 | [AKRO]-[WETH] SLP    |   16559.0110 |     $213,233.67 | SUSHI  |  30.92% | 0.00 ($0.00), 0.00% |', '| ...
# Block Start Line No.:  1415
# no Pair....
#  ['Badger/wBTC Sushi-LP - Underlying - Sett - Geyser', 'You have 0 SLP', 'You have 0 bSLP', '[WBTC]-[BADGER] SLP [+] [-] [<=>] Price: $111,354,817.25 TVL: $10,566,085.41', 'WBTC Price: $34,343.00', 'BADGER Price: $8.15', 'Staked: 0.0003 SLP ($29,201.95)', 'Staked in Geyser: $3,980,002.13', 'BADGER Per Week: 4071.63 ($33,183.83)', 'APR: Day 0.12% Week 0.83% Year 43.36%', 'DIGG Per Week: 0.17 ($4,991.03)', 'APR: Day 0.02% Week 0.13% Year 6.52%', 'Stake 0.000000000000 SLP', 'Unstake 0.000000000000 SLP', 'Stake 0.000000000000 bSLP', 'Unstake 0.000000000000 bSLP', 'Revoke (set approval to 0)']
# Block Start Line No.:  1638
# no Pair....
#  ['Badger/wBTC Uni-LP - Underlying - Sett - Geyser', 'You have 0 UNI-V2', 'You have 0 bUNI-V2', '[WBTC]-[BADGER] Uni LP [+] [-] [<=>] Price: $120,098,861.01 TVL: $5,205,580.75', 'WBTC Price: $34,343.00', 'BADGER Price: $8.15', 'Staked: 0.0002 UNI-V2 ($25,129.90)', 'Staked in Geyser: $4,611,438.83', 'BADGER Per Week: 4071.63 ($33,183.83)', 'APR: Day 0.10% Week 0.72% Year 37.42%', 'DIGG Per Week: 0.17 ($4,991.03)', 'APR: Day 0.02% Week 0.11% Year 5.63%', 'Stake 0.000000000000 UNI-V2', 'Unstake 0.000000000000 UNI-V2', 'Stake 0.000000000000 bUNI-V2', 'Unstake 0.000000000000 bUNI-V2', 'Revoke (set approval to 0)']
# Block Start Line No.:  1657
# no Pair....
#  ['DIGG/wBTC Uni-LP - Underlying - Sett - Geyser', 'You have 0 UNI-V2', 'You have 0 bUNI-V2', '[WBTC]-[DIGG] Uni LP [+] [-] [<=>] Price: $72,587,593,912,450.38 TVL: $3,755,033.65', 'WBTC Price: $34,343.00', 'DIGG Price: $30,088.00', 'Staked: 0.0000 UNI-V2 ($438,683.35)', 'Staked in Geyser: $1,709,151.66', 'DIGG Per Week: 1.10 ($33,199.77)', 'APR: Day 0.28% Week 1.94% Year 101.01%', 'Stake 0.000000000000 UNI-V2', 'Unstake 0.000000000000 UNI-V2', 'Stake 0.000000000000 bUNI-V2', 'Unstake 0.000000000000 bUNI-V2', 'Revoke (set approval to 0)']
# Block Start Line No.:  1676
# no Pair....
#  ['DIGG/wBTC Sushi-LP - Underlying - Sett - Geyser', 'You have 0 SLP', 'You have 0 bSLP', '[WBTC]-[DIGG] SLP [+] [-] [<=>] Price: $66,512,578,353,577.66 TVL: $4,250,432.77', 'WBTC Price: $34,343.00', 'DIGG Price: $30,088.00', 'Staked: 0.0000 SLP ($137,436.54)', 'Staked in Geyser: $2,134,677.96', 'DIGG Per Week: 1.10 ($33,199.77)', 'APR: Day 0.22% Week 1.56% Year 80.87%', 'Stake 0.000000000000 SLP', 'Unstake 0.000000000000 SLP', 'Stake 0.000000000000 bSLP', 'Unstake 0.000000000000 bSLP', 'Revoke (set approval to 0)']
# Block Start Line No.:  1693
# no Pair....
#  ['Badger - Underlying - Sett - Geyser', 'You have 0 BADGER', 'You have 0 bBADGER', 'BADGER Price: $8.15 Market Cap: $171,150,000.00 [%]', 'Staked: 11096.0986 BADGER ($90,433.20)', 'Staked in Geyser: $7,510,550.81', 'BADGER Per Week: 2035.82 ($16,591.93)', 'APR: Day 0.03% Week 0.22% Year 11.49%', 'DIGG Per Week: 0.08 ($2,497.23)', 'APR: Day 0.00% Week 0.03% Year 1.73%', 'Stake 0.000000000000 BADGER', 'Unstake 0.000000000000 BADGER', 'Stake 0.000000000000 bBADGER', 'Unstake 0.000000000000 bBADGER', 'Revoke (set approval to 0)']
# Block Start Line No.:  1710
# no Pair....
#  ['DIGG - Underlying - Sett', 'You have 0 DIGG', 'You have 0 bDIGG', 'DIGG Price: $30,088.00 Market Cap: $13,721,038.55 [%]', 'Staked: 90.2868 DIGG ($2,716,547.88)', 'Stake 0.000000000000 DIGG', 'Unstake 0.000000000000 DIGG']
# Block Start Line No.:  1727
# no Pair....
#  ['ETH/wBTC Sushi-LP - Underlying - Sett - Geyser', 'You have 0 SLP', 'You have 0 bSLP', '[WBTC]-[WETH] SLP [+] [-] [<=>] Price: $41,061,292,730.72 TVL: $404,017,346.96', 'WBTC Price: $34,343.00', 'WETH Price: $2,086.97', 'Staked: 0.0000 SLP ($0.00)', 'Staked in Geyser: $15,745,652.80', 'BADGER Per Week: 6368.46 ($51,902.95)', 'APR: Day 0.05% Week 0.33% Year 17.14%', 'DIGG Per Week: 0.13 ($3,903.64)', 'APR: Day 0.00% Week 0.02% Year 1.29%', 'Stake 0.000000000000 SLP', 'Unstake 0.000000000000 SLP', 'Stake 0.000000000000 bSLP', 'Unstake 0.000000000000 bSLP', 'Revoke (set approval to 0)']
# Block Start Line No.:  1736
# no Pair....
#  ['curve.fi / renBTC - Underlying - Sett - Geyser', 'You have 0 crvRenWBTC', 'You have 0 bcrvRenWBTC', 'crvRenWBTC Price: $35,258.00 Market Cap: $186,604,749.45 [%]', 'Staked: 0.9972 crvRenWBTC ($35,158.02)', 'Staked in Geyser: $11,003,478.32', 'BADGER Per Week: 6368.46 ($51,902.95)', 'APR: Day 0.07% Week 0.47% Year 24.53%', 'DIGG Per Week: 0.13 ($3,903.64)', 'APR: Day 0.01% Week 0.04% Year 1.84%', 'Stake 0.000000000000 crvRenWBTC', 'Unstake 0.000000000000 crvRenWBTC', 'Stake 0.000000000000 bcrvRenWBTC', 'Unstake 0.000000000000 bcrvRenWBTC', 'Revoke (set approval to 0)']
# Block Start Line No.:  1755
# no Pair....
#  ['curve.fi / sBTC - Underlying - Sett - Geyser', 'You have 0 crvRenWSBTC', 'You have 0 bcrvRenWSBTC', 'crvRenWSBTC Price: $34,633.99 TVL: $246,265,795.44', 'Staked: $0.00', 'Staked in Geyser: $8,022,072.55', 'BADGER Per Week: 6368.46 ($51,902.95)', 'APR: Day 0.09% Week 0.65% Year 33.64%', 'DIGG Per Week: 0.13 ($3,903.64)', 'APR: Day 0.01% Week 0.05% Year 2.53%', 'Stake 0.000000000000 crvRenWSBTC', 'Unstake 0.000000000000 crvRenWSBTC', 'Stake 0.000000000000 bcrvRenWSBTC', 'Unstake 0.000000000000 bcrvRenWSBTC', 'Revoke (set approval to 0)']
# Block Start Line No.:  1772
# no Pair....
#  ['curve.fi / tBTC - Underlying - Sett - Geyser', 'You have 0 tbtc/sbtcCrv', 'You have 0 btbtc/sbtcCrv', 'tbtc/sbtcCrv Price: $34,627.04 Market Cap: $48,903,421.24', 'Staked: 0.3667 tbtc/sbtcCrv ($12,698.84)', 'Staked in Geyser: $4,124,269.85', 'BADGER Per Week: 6368.46 ($51,902.95)', 'APR: Day 0.18% Week 1.26% Year 65.44%', 'DIGG Per Week: 0.13 ($3,903.64)', 'APR: Day 0.01% Week 0.09% Year 4.92%', 'Stake 0.000000000000 tbtc/sbtcCrv', 'Unstake 0.000000000000 tbtc/sbtcCrv', 'Stake 0.000000000000 btbtc/sbtcCrv', 'Unstake 0.000000000000 btbtc/sbtcCrv', 'Revoke (set approval to 0)']
# Block Start Line No.:  1789
# no Pair....
#  ['harvest.finance / renBTC - Underlying - Sett - Geyser', 'You have 0 crvRenWBTC', 'You have 0 bSupercrvRenWBTC', 'crvRenWBTC Price: $35,258.00 Market Cap: $186,604,749.45 [%]', 'Staked: 0.0408 crvRenWBTC ($1,438.37)', 'Staked in Geyser: $559,107.55', 'BADGER Per Week: 6368.46 ($51,902.95)', 'APR: Day 1.33% Week 9.28% Year 482.73%', 'DIGG Per Week: 0.13 ($3,903.64)', 'APR: Day 0.10% Week 0.70% Year 36.31%', 'Stake 0.000000000000 crvRenWBTC', 'Unstake 0.000000000000 crvRenWBTC', 'Stake 0.000000000000 bSupercrvRenWBTC', 'Unstake 0.000000000000 bSupercrvRenWBTC', 'Revoke (set approval to 0)']
# Block Start Line No.:  1806
# no Pair....
#  ['VSD Total Supply: 132909.08, $93,453.10', 'VSD Total Staged: 4.10, $2.89', 'VSD Total Bonded: 12356.47, $8,688.27', 'You have 0.00 unstaked VSD, $0.00', 'You have 0.00 staged VSD, $0.00, 0.0000% of the pool', 'You have 0.00 bonded VSD, $0.00, 0.0000% of the pool', 'Redeem 0.00 VSD']
# Block Start Line No.:  1826
# no Pair....
#  ['Locking period for 7 days', 'B26 Price: $10.20 Market Cap: $265,200.00 [%]', 'Staked: 1415.2955 B26 ($14,436.01)', 'B26 Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 B26 $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 B26', 'Unstake 0.000000 B26', 'Claim 0.000000 B26 ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1911
# no Pair....
#  ['Locking period for 30 days', 'B26 Price: $10.20 Market Cap: $265,200.00 [%]', 'Staked: 8671.1737 B26 ($88,445.97)', 'B26 Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 B26 $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 B26', 'Unstake 0.000000 B26', 'Claim 0.000000 B26 ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1924
# no Pair....
#  ['Locking period for 90 days', 'B26 Price: $10.20 Market Cap: $265,200.00 [%]', 'Staked: 0.3877 B26 ($3.95)', 'B26 Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 B26 $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 B26', 'Unstake 0.000000 B26', 'Claim 0.000000 B26 ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1937
# [🐟]-[WETH] Uni LP [+] [-] [<=>] Price: $348.72 TVL: $120,418.28
# no Pair....
#  ['[🐟]-[WETH] Uni LP [+] [-] [<=>] Price: $348.72 TVL: $120,418.28', '🐟 Price: $5.01', 'WETH Price: $2,090.53', 'Staked: 332.9308 UNI-V2 ($116,098.74)', '🐟 Per Week: 194.44 ($974.17)', 'APR: Day 0.12% Week 0.84% Year 43.63%', 'You are staking 0.000000 [🐟]-[WETH] Uni LP $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [🐟]-[WETH] Uni LP', 'Unstake 0.000000 [🐟]-[WETH] Uni LP', 'Claim 0.000000 🐟 ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1956
# [UNI]-[🐟] Uni LP [+] [-] [<=>] Price: $20.65 TVL: $32,524.54
# [🐟]-[USDC] Uni LP [+] [-] [<=>] Price: $120,394,899.97 TVL: $35,677.76
# no Pair....
#  ['[🐟]-[USDC] Uni LP [+] [-] [<=>] Price: $120,394,899.97 TVL: $35,677.76', '🐟 Price: $5.01', 'USDC Price: $1.00', 'Staked: 0.0003 UNI-V2 ($34,949.96)', '🐟 Per Week: 194.44 ($974.17)', 'APR: Day 0.40% Week 2.79% Year 144.94%', 'You are staking 0.000000 [🐟]-[USDC] Uni LP $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [🐟]-[USDC] Uni LP', 'Unstake 0.000000 [🐟]-[USDC] Uni LP', 'Claim 0.000000 🐟 ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1984
# [⛩️]-[🐟] Uni LP [+] [-] [<=>] Price: $4.73 TVL: $33,247.23
# no Pair....
#  ['[⛩️]-[🐟] Uni LP [+] [-] [<=>] Price: $4.73 TVL: $33,247.23', '⛩️ Price: $1.07', '🐟 Price: $5.01', 'Staked: 4511.8129 UNI-V2 ($21,358.33)', '🐟 Per Week: 194.44 ($974.17)', 'APR: Day 0.65% Week 4.56% Year 237.18%', 'You are staking 0.000000 [⛩️]-[🐟] Uni LP $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [⛩️]-[🐟] Uni LP', 'Unstake 0.000000 [⛩️]-[🐟] Uni LP', 'Claim 0.000000 🐟 ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1998
# no Pair....
#  ['AAVE ($223.89)', 'Supplied : 1,853,211.05 ($414,915,422.43) at 0.00% APR', 'Borrowed : 0.00 ($0.00) at 0.00% APR', 'Reserves : 1,853,211.05 ($414,915,422.43)', 'Farming APR Supply 0.00% Borrow NaN%', 'Net APR Supply 0.00% Borrow NaN%']
# Block Start Line No.:  2018
# no Pair....
#  ['BAL ($18.44)', 'Supplied : 184,544.85 ($3,403,007.04) at 2.41% APR', 'Borrowed : 81,232.74 ($1,497,931.75) at 6.85% APR', 'Reserves : 103,312.16 ($1,905,076.14)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 2.41% Borrow -6.85%']
# Block Start Line No.:  2025
# no Pair....
#  ['BAT ($0.56)', 'Supplied : 3,777,470.81 ($2,122,194.43) at 0.40% APR', 'Borrowed : 597,677.32 ($335,776.91) at 2.66% APR', 'Reserves : 3,131,952.27 ($1,759,540.18)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.40% Borrow -2.66%']
# Block Start Line No.:  2032
# no Pair....
#  ['BUSD ($1.00)', 'Supplied : 12,216,902.62 ($12,216,902.62) at 1.97% APR', 'Borrowed : 8,088,759.02 ($8,088,759.02) at 3.31% APR', 'Reserves : 4,128,165.12 ($4,128,165.12)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 1.97% Borrow -3.31%']
# Block Start Line No.:  2039
# no Pair....
#  ['CRV ($1.62)', 'Supplied : 10,896,099.82 ($17,651,681.71) at 8.06% APR', 'Borrowed : 5,186,330.12 ($8,401,854.79) at 21.17% APR', 'Reserves : 5,709,787.33 ($9,249,855.48)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 8.06% Borrow -21.17%']
# Block Start Line No.:  2046
# no Pair....
#  ['DAI ($1.00)', 'Supplied : 1,641,043,422.33 ($1,641,043,422.33) at 2.39% APR', 'Borrowed : 1,172,755,788.30 ($1,172,755,788.30) at 3.61% APR', 'Reserves : 456,874,077.28 ($456,874,077.28)', 'Farming APR Supply 0.73% Borrow 1.02%', 'Net APR Supply 3.12% Borrow -2.58%']
# Block Start Line No.:  2053
# no Pair....
#  ['ENJ ($1.01)', 'Supplied : 10,704,492.37 ($10,811,537.29) at 2.31% APR', 'Borrowed : 4,478,454.81 ($4,523,239.35) at 6.88% APR', 'Reserves : 5,967,184.40 ($6,026,856.24)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 2.31% Borrow -6.88%']
# Block Start Line No.:  2060
# no Pair....
#  ['GUSD ($0.99)', 'Supplied : 21,941,308.14 ($21,768,893.34) at 2.48% APR', 'Borrowed : 16,304,080.86 ($16,175,963.39) at 3.72% APR', 'Reserves : 5,637,232.06 ($5,592,934.69)', 'Farming APR Supply 3.01% Borrow 4.05%', 'Net APR Supply 5.49% Borrow 0.33%']
# Block Start Line No.:  2067
# no Pair....
#  ['KNC ($1.38)', 'Supplied : 1,240,338.28 ($1,711,666.82) at 0.04% APR', 'Borrowed : 2,574.19 ($3,552.38) at 0.18% APR', 'Reserves : 1,221,760.40 ($1,686,029.35)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.04% Borrow -0.18%']
# Block Start Line No.:  2074
# no Pair....
#  ['LINK ($18.82)', 'Supplied : 19,847,553.57 ($373,530,958.09) at 0.05% APR', 'Borrowed : 311,603.75 ($5,864,382.63) at 0.48% APR', 'Reserves : 19,230,927.33 ($361,926,052.30)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.05% Borrow -0.48%']
# Block Start Line No.:  2081
# no Pair....
#  ['MANA ($0.50)', 'Supplied : 7,254,795.02 ($3,660,196.44) at 0.07% APR', 'Borrowed : 392,424.04 ($197,986.17) at 1.02% APR', 'Reserves : 6,777,553.03 ($3,419,417.83)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.07% Borrow -1.02%']
# Block Start Line No.:  2088
# no Pair....
#  ['MKR ($2,221.03)', 'Supplied : 45,341.07 ($100,703,878.87) at 0.00% APR', 'Borrowed : 223.51 ($496,411.46) at 0.08% APR', 'Reserves : 45,110.50 ($100,191,775.63)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.00% Borrow -0.08%']
# Block Start Line No.:  2095
# no Pair....
#  ['REN ($0.36)', 'Supplied : 42,739,810.67 ($15,319,486.78) at 0.28% APR', 'Borrowed : 4,539,983.51 ($1,627,293.53) at 2.36% APR', 'Reserves : 36,246,542.67 ($12,992,065.77)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.28% Borrow -2.36%']
# Block Start Line No.:  2102
# no Pair....
#  ['SNX ($6.72)', 'Supplied : 1,204,947.07 ($8,097,244.31) at 3.95% APR', 'Borrowed : 656,175.68 ($4,409,500.54) at 11.17% APR', 'Reserves : 548,774.45 ($3,687,764.30)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 3.95% Borrow -11.17%']
# Block Start Line No.:  2109
# no Pair....
#  ['sUSD ($1.02)', 'Supplied : 47,949,903.45 ($48,908,901.52) at 3.25% APR', 'Borrowed : 38,461,782.05 ($39,231,017.69) at 5.06% APR', 'Reserves : 9,488,147.80 ($9,677,910.76)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 3.25% Borrow -5.06%']
# Block Start Line No.:  2116
# no Pair....
#  ['TUSD ($1.00)', 'Supplied : 175,728,416.63 ($175,728,416.63) at 1.09% APR', 'Borrowed : 84,263,836.16 ($84,263,836.16) at 2.43% APR', 'Reserves : 90,448,387.42 ($90,448,387.42)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 1.09% Borrow -2.43%']
# Block Start Line No.:  2123
# no Pair....
#  ['UNI ($17.65)', 'Supplied : 3,689,581.23 ($65,121,108.68) at 0.01% APR', 'Borrowed : 121,739.71 ($2,148,705.80) at 0.51% APR', 'Reserves : 3,567,840.02 ($62,972,376.32)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.01% Borrow -0.51%']
# Block Start Line No.:  2130
# no Pair....
#  ['USDC ($1.00)', 'Supplied : 4,097,580,048.15 ($4,097,580,048.15) at 2.01% APR', 'Borrowed : 2,826,496,020.17 ($2,826,496,020.17) at 3.11% APR', 'Reserves : 1,234,730,733.89 ($1,234,730,733.89)', 'Farming APR Supply 0.91% Borrow 1.32%', 'Net APR Supply 2.92% Borrow -1.79%']
# Block Start Line No.:  2137
# no Pair....
#  ['USDT ($1.00)', 'Supplied : 912,952,932.31 ($909,607,872.77) at 2.97% APR', 'Borrowed : 759,388,347.51 ($756,605,948.61) at 3.77% APR', 'Reserves : 139,209,527.26 ($138,699,463.55)', 'Farming APR Supply 2.55% Borrow 3.07%', 'Net APR Supply 5.52% Borrow -0.70%']
# Block Start Line No.:  2144
# no Pair....
#  ['WBTC ($34,301.00)', 'Supplied : 41,927.56 ($1,438,157,129.98) at 0.03% APR', 'Borrowed : 2,267.37 ($77,772,939.40) at 0.67% APR', 'Reserves : 39,649.61 ($1,360,021,168.34)', 'Farming APR Supply 0.98% Borrow 0.95%', 'Net APR Supply 1.01% Borrow 0.28%']
# Block Start Line No.:  2151
# no Pair....
#  ['WETH ($2,088.33)', 'Supplied : 1,256,833.17 ($2,624,682,422.42) at 0.05% APR', 'Borrowed : 83,061.68 ($173,460,196.18) at 0.82% APR', 'Reserves : 1,173,229.92 ($2,450,091,236.92)', 'Farming APR Supply 0.66% Borrow 0.53%', 'Net APR Supply 0.71% Borrow -0.29%']
# Block Start Line No.:  2158
# no Pair....
#  ['xSUSHI ($8.75)', 'Supplied : 18,752,372.81 ($164,083,262.08) at 0.00% APR', 'Borrowed : 52,732.82 ($461,412.18) at 0.04% APR', 'Reserves : 18,699,639.99 ($163,621,849.92)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.00% Borrow -0.04%']
# Block Start Line No.:  2165
# no Pair....
#  ['YFI ($31,347.00)', 'Supplied : 2,036.18 ($63,828,161.11) at 0.06% APR', 'Borrowed : 143.99 ($4,513,591.52) at 1.10% APR', 'Reserves : 1,892.19 ($59,314,575.22)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.06% Borrow -1.10%']
# Block Start Line No.:  2172
# no Pair....
#  ['ZRX ($0.69)', 'Supplied : 2,845,360.30 ($1,959,096.01) at 0.11% APR', 'Borrowed : 100,010.76 ($68,859.71) at 0.96% APR', 'Reserves : 2,669,251.13 ($1,837,840.80)', 'Farming APR Supply 0.00% Borrow 0.00%', 'Net APR Supply 0.11% Borrow -0.96%']
# Block Start Line No.:  2179
# no Pair....
#  ['You have 0.00 unlocked and 0.00 locked rewards (0.00 total).', 'Claim 0.00 COMFI ($0.00)']
# Block Start Line No.:  2295
# no Pair....
#  ['PENDLE SINGLE STAKING POOL TVL: $3,019,108.44', 'PENDLE Price: $0.67', 'PENDLE Per Block: 0.66209 ($0.44)', 'APR: Day 0.10% Week 0.68% Year 35.25%', 'Total Staked: 4,521,010.84 PENDLE ($3,019,108.44)', 'You are staking 0.00 PENDLE $0.00 (0.00000% of the pool).', 'Etherscan', 'Stake 0.00 PENDLE', 'Unstake 0.00 PENDLE', 'Revoke (set approval to 0)']
# Block Start Line No.:  2340
# MATIC 6:28 Yields.uu
# no Pair....
#  ['MATIC 6/28 Yields']
# Block Start Line No.:  1
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-8-6396f5945b4a>", line 19, in pair2
# ValueError: substring not found
#
# GFI-USDC Quick LP [+] [-] [<=>] Price: $160,154.28 TVL: $557,070.69
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-8-6396f5945b4a>", line 19, in pair2
# ValueError: substring not found
#
# GFI-WETH Quick LP [+] [-] [<=>] Price: $7.26 TVL: $586,889.03
# 0 - [USDC]-[🚜] Uni LP [+] [-] [<=>] Price: $1,725,091.70 TVL: $15,639.94
# 2 - [WMATIC]-[🚜] Uni LP [+] [-] [<=>] Price: $1.27 TVL: $27,061.33
# no Pair....
#  ['9 - vaultWETHWBTC Price: $0.00 TVL: $0.00', 'Staked: 0.0012 vaultWETHWBTC ($0.00)', 'HOPE Per Week: 58333.33 ($5,432.40)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultWETHWBTC ($0.00), NaN% of the pool.', 'Stake 0.00 vaultWETHWBTC', 'Unstake 0.00 vaultWETHWBTC', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  16239
# no Pair....
#  ['10 - vaultWETHWBTC Price: $0.00 TVL: $0.00', 'Staked: 0.0000 vaultWETHWBTC ($0.00)', 'HOPE Per Week: 58333.33 ($5,432.40)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 vaultWETHWBTC ($0.00), NaN% of the pool.', 'Stake 0.00 vaultWETHWBTC', 'Unstake 0.00 vaultWETHWBTC', 'Claim 0.00 HOPE ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  16249
# ETH 6:28 Yields.uu
# no Pair....
#  ['ETH 6/28 Yields']
# Block Start Line No.:  1
# no Pair....
#  ['Boardroom', 'There is a total 30323.65 BSGS ($1,870.70) staked in the Boardroom.', 'You are staking 0 BSGS ($0.00), 0.00% of the pool.', 'Stake 0.0000 BSGS', 'Unstake 0.0000 BSGS', 'Claim 0.0000 BSG', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  581
# no Pair....
#  ['Total Staked: $11,291,738.59', '[DEGEN]-[WETH] Uni LP [+] [-] [<=>] Price: $182.82 TVL: $1,429,490.87', 'DEGEN Price: $3.16', 'WETH Price: $2,095.28', 'Staked: 1364.2877 UNI-V2 ($249,424.27)', 'NDX Per Week: 0.00 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.000000 [DEGEN]-[WETH] Uni LP $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [DEGEN]-[WETH] Uni LP', 'Unstake 0.000000 [DEGEN]-[WETH] Uni LP', 'Claim 0.000000 NDX ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1141
# no Pair....
#  ['1 - m3Crv Price: $1.08 TVL: $58,035.65', 'Staked: 50783.0784 m3Crv ($54,825.88)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.04% Week 0.31% Year 16.16%', 'You are staking 0.00 m3Crv ($0.00), 0.00% of the pool.', 'Stake 0.00 m3Crv', 'Unstake 0.00 m3Crv', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1349
# no Pair....
#  ['3 - mcrvRenWBTC Price: $35,958.16 TVL: $45,843.90', 'Staked: 1.2501 mcrvRenWBTC ($44,951.26)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.05% Week 0.38% Year 19.71%', 'You are staking 0.00 mcrvRenWBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mcrvRenWBTC', 'Unstake 0.00 mcrvRenWBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1371
# no Pair....
#  ['4 - mDAI Price: $1.06 TVL: $122,237.48', 'Staked: 74194.9806 mDAI ($78,981.37)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.03% Week 0.22% Year 11.22%', 'You are staking 0.00 mDAI ($0.00), 0.00% of the pool.', 'Stake 0.00 mDAI', 'Unstake 0.00 mDAI', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1381
# no Pair....
#  ['5 - mUSDC Price: $1.08 TVL: $154,082.14', 'Staked: 131587.0773 mUSDC ($141,890.76)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.02% Week 0.12% Year 6.24%', 'You are staking 0.00 mUSDC ($0.00), 0.00% of the pool.', 'Stake 0.00 mUSDC', 'Unstake 0.00 mUSDC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1391
# no Pair....
#  ['9 - mWETH Price: $2,138.75 TVL: $439,168.21', 'Staked: 188.6877 mWETH ($403,555.65)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.01% Week 0.04% Year 2.20%', 'You are staking 0.00 mWETH ($0.00), 0.00% of the pool.', 'Stake 0.00 mWETH', 'Unstake 0.00 mWETH', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1435
# no Pair....
#  ['10 - mUNI Price: $18.22 TVL: $228,792.55', 'Staked: 11535.8144 mUNI ($210,127.03)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.01% Week 0.08% Year 4.22%', 'You are staking 0.00 mUNI ($0.00), 0.00% of the pool.', 'Stake 0.00 mUNI', 'Unstake 0.00 mUNI', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1445
# no Pair....
#  ['11 - mWBTC Price: $34,900.69 TVL: $5,292,317.40', 'Staked: 148.4591 mWBTC ($5,181,326.13)', 'MM Per Week: 316.72 ($851.99)', 'APR: Day 0.00% Week 0.02% Year 0.86%', 'You are staking 0.00 mWBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mWBTC', 'Unstake 0.00 mWBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1455
# no Pair....
#  ['12 - mLINK Price: $19.09 TVL: $250,510.08', 'Staked: 8126.7346 mLINK ($155,178.07)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.02% Week 0.11% Year 5.71%', 'You are staking 0.00 mLINK ($0.00), 0.00% of the pool.', 'Stake 0.00 mLINK', 'Unstake 0.00 mLINK', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1465
# no Pair....
#  ['13 - mZRX Price: $0.69 TVL: $107,672.87', 'Staked: 152977.0146 mZRX ($106,308.08)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.02% Week 0.16% Year 8.33%', 'You are staking 0.00 mZRX ($0.00), 0.00% of the pool.', 'Stake 0.00 mZRX', 'Unstake 0.00 mZRX', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1475
# no Pair....
#  ['14 - mALCX Price: $523.09 TVL: $202,895.44', 'Staked: 123.7239 mALCX ($64,718.41)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.04% Week 0.26% Year 13.69%', 'You are staking 0.00 mALCX ($0.00), 0.00% of the pool.', 'Stake 0.00 mALCX', 'Unstake 0.00 mALCX', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1485
# no Pair....
#  ['15 - malUSD Price: $1.12 TVL: $158,368.71', 'Staked: 128401.9612 malUSD ($143,311.55)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.02% Week 0.12% Year 6.18%', 'You are staking 0.00 malUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 malUSD', 'Unstake 0.00 malUSD', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1495
# no Pair....
#  ['16 - musdp3CRV Price: $1.06 TVL: $59,079.26', 'Staked: 52048.5995 musdp3CRV ($55,264.69)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.04% Week 0.31% Year 16.03%', 'You are staking 0.00 musdp3CRV ($0.00), 0.00% of the pool.', 'Stake 0.00 musdp3CRV', 'Unstake 0.00 musdp3CRV', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1505
# no Pair....
#  ['17 - mrenBTC Price: $34,870.56 TVL: $77,751.73', 'Staked: 2.2015 mrenBTC ($76,767.16)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.03% Week 0.22% Year 11.54%', 'You are staking 0.00 mrenBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 mrenBTC', 'Unstake 0.00 mrenBTC', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1515
# no Pair....
#  ['19 - myveCRV-DAO Price: $1.51 TVL: $21,453.44', 'Staked: 10957.3627 myveCRV-DAO ($16,567.10)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.15% Week 1.03% Year 53.48%', 'You are staking 0.00 myveCRV-DAO ($0.00), 0.00% of the pool.', 'Stake 0.00 myveCRV-DAO', 'Unstake 0.00 myveCRV-DAO', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1537
# no Pair....
#  ['20 - mTUSD Price: $1.00 TVL: $10,029.52', 'Staked: 9995.7107 mTUSD ($10,002.13)', 'MM Per Week: 63.34 ($170.40)', 'APR: Day 0.24% Week 1.70% Year 88.59%', 'You are staking 0.00 mTUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 mTUSD', 'Unstake 0.00 mTUSD', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  1547
# no Pair....
#  ['p3Crv Price: $1.10 TVL: $576,826.51', 'Staked: 458280.5216 p3Crv ($502,570.35)', 'PICKLE Per Week: 223.36 ($1,918.63)', 'APR: Day 0.05% Week 0.38% Year 19.85%', 'You are staking 0.000000 p3Crv $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 p3Crv', 'Unstake 0.000000 p3Crv', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1788
# no Pair....
#  ['psteCRV Price: $0.00 TVL: $0.00', 'Staked: 4976.8206 psteCRV ($0.00)', 'PICKLE Per Week: 1758.85 ($15,108.55)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.000000 psteCRV $0.00 (NaN% of the pool).', 'Etherscan', 'Stake 0.000000 psteCRV', 'Unstake 0.000000 psteCRV', 'Claim 0.000000 PICKLE ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  1860
# no Pair....
#  ['1 - sd3Crv Price: $1.07 TVL: $11,462,814.76', 'Staked: 10228060.7104 sd3Crv ($10,894,424.00)', 'SDT Per Week: 11200.00 ($10,219.64)', 'APR: Day 0.01% Week 0.09% Year 4.88%', 'You are staking 0.00 sd3Crv ($0.00), 0.00% of the pool.', 'Stake 0.00 sd3Crv', 'Unstake 0.00 sd3Crv', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2308
# no Pair....
#  ['2 - sdeursCRV Price: $1.33 TVL: $25,791,400.52', 'Staked: 16943708.3212 sdeursCRV ($22,540,868.15)', 'SDT Per Week: 35840.00 ($32,702.85)', 'APR: Day 0.02% Week 0.15% Year 7.54%', 'You are staking 0.00 sdeursCRV ($0.00), 0.00% of the pool.', 'Stake 0.00 sdeursCRV', 'Unstake 0.00 sdeursCRV', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2318
# no Pair....
#  ['3 - sdcrvRenWSBTC Price: $36,373.92 TVL: $8,779,362.79', 'Staked: 236.2953 sdcrvRenWSBTC ($8,594,985.92)', 'SDT Per Week: 4480.00 ($4,087.86)', 'APR: Day 0.01% Week 0.05% Year 2.47%', 'You are staking 0.00 sdcrvRenWSBTC ($0.00), 0.00% of the pool.', 'Stake 0.00 sdcrvRenWSBTC', 'Unstake 0.00 sdcrvRenWSBTC', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2328
# no Pair....
#  ['9 - sdeCRV Price: $0.00 TVL: $0.00', 'Staked: 1283.1892 sdeCRV ($0.00)', 'SDT Per Week: 4480.00 ($4,087.86)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 sdeCRV ($0.00), NaN% of the pool.', 'Stake 0.00 sdeCRV', 'Unstake 0.00 sdeCRV', 'Claim 0.00 SDT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2382
# no Pair....
#  ['[DAI 40%]-[BAL]-[TRU 2%] BPT Price: $1.18 TVL: $12,821.32', 'DAI Price: $1.00', 'BAL Price: $18.40', 'TRU Price: $0.15', 'Staked: 9297.9796 [DAI 40%]-[BAL]-[TRU 2%] ($10,938.24)', 'TRU Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 undefined $0.00 (0.00% of the pool).', 'Your LP tokens comprise of 0.0000 DAI + 0.0000 BAL + 0.0000 TRU', 'Stake 0.000000 undefined', 'Unstake 0.000000 undefined', 'Claim 0.000000 TRU', 'Exit']
# Block Start Line No.:  2412
# no Pair....
#  ['Total Staked: $142,810.04', 'MVLT Price: $1.11 TVL: $39,178,382.33', 'Staked: 32481300.6562 MVLT ($36,010,395.43)', 'YAXIS Per Week: 41666.67 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.000000 MVLT $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 MVLT', 'Unstake 0.000000 MVLT', 'Claim 0.000000 YAXIS ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  2543
# no Pair....
#  ['Staking Contract', '0 - LPOOL Price: $1.25 Market Cap: $12,500,000.00 [%]', 'Staked: 323.0636 LPOOL ($403.83)', 'YLD Per Week: 106870.23 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 LPOOL ($0.00), 0.00% of the pool.', 'Stake 0.00 LPOOL', 'Unstake 0.00 LPOOL', 'Claim 0.00 YLD ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2744
# no Pair....
#  ['Staking Contract', '0 - LPOOL Price: $1.25 Market Cap: $12,500,000.00 [%]', 'Staked: 1248.3772 LPOOL ($1,560.47)', 'YLD Per Week: 106870.23 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 LPOOL ($0.00), 0.00% of the pool.', 'Stake 0.00 LPOOL', 'Unstake 0.00 LPOOL', 'Claim 0.00 YLD ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2755
# no Pair....
#  ['Staking Contract', '0 - LPOOL Price: $1.25 Market Cap: $12,500,000.00 [%]', 'Staked: 2809.4220 LPOOL ($3,511.78)', 'YLD Per Week: 106870.23 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 LPOOL ($0.00), 0.00% of the pool.', 'Stake 0.00 LPOOL', 'Unstake 0.00 LPOOL', 'Claim 0.00 YLD ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2766
# no Pair....
#  ['Staking Contract', '0 - LPOOL Price: $1.25 Market Cap: $12,500,000.00 [%]', 'Staked: 569981.2616 LPOOL ($712,476.58)', 'YLD Per Week: 18868.37 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 LPOOL ($0.00), 0.00% of the pool.', 'Stake 0.00 LPOOL', 'Unstake 0.00 LPOOL', 'Claim 0.00 YLD ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2777
# no Pair....
#  ['9 - [UNI-V2]-[WETH]-[$TRDL]-[VBTC]-[vBCH]-[oneVBTC] BPT Price: $138.30 TVL: $152,955.33', 'UNI-V2 Price: $27.76', 'WETH Price: $2,095.28', '$TRDL Price: $0.21', 'VBTC Price: $12,329.97', 'vBCH Price: $346.03', 'oneVBTC Price: $1.04', 'Staked: 1040.4280 [UNI-V2 ]-[WETH ]-[$TRDL ]-[VBTC ]-[vBCH ]-[oneVBTC ] ($143,888.95)', '$TRDL Per Week: 17920.00 ($3,723.02)', 'APR: Day 0.37% Week 2.59% Year 134.55%', 'You are staking 0.00 [UNI-V2 ]-[WETH ]-[$TRDL]-[VBTC]-[vBCH]-[oneVBTC] ($0.00), 0.00% of the pool.', 'Stake 0.00 [UNI-V2 ]-[WETH ]-[$TRDL ]-[VBTC]-[vBCH ]-[oneVBTC ]', 'Unstake 0.00 [UNI-V2 ]-[WETH ]-[$TRDL ]-[VBTC]-[vBCH]-[oneVBTC]', 'Claim 0.00 $TRDL ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  2850
# no Pair....
#  ['[SNX 25%]-[WETH 25%]-[xSNXa 50%] BPT Price: $0.01 TVL: $45,569.39', 'SNX Price: $6.70', 'WETH Price: $2,087.13', 'xSNXa Price: $0.00', 'Staked: 2024637.2229 [SNX 25%]-[WETH 25%]-[xSNXa 50%] ($20,091.71)', 'XTK Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.000000 [SNX 25%]-[WETH 25%]-[xSNXa 50%] $0.00 (0.00% of the pool).', 'Etherscan', 'Stake 0.000000 [SNX 25%]-[WETH 25%]-[xSNXa 50%]', 'Unstake 0.000000 [SNX 25%]-[WETH 25%]-[xSNXa 50%]', 'Claim 0.000000 XTK ($0.00)', 'Revoke (set approval to 0)', 'Exit']
# Block Start Line No.:  3135
# no Pair....
# ...
#
# 25 - Wrapped [ETH]-[BETH] Cake LP Price: $4,309.48 TVL: $1,947.85
# no Pair....
#  ['beltBTC Price: $0.00 TVL: $0.00', 'Staked: 5662.1961 beltBTC ($0.00)', 'BELT Per Week: 12096.00 ($165,086.31)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 BELT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  11814
# no Pair....
#  ['beltETH Price: $0.00 TVL: $0.00', 'Staked: 73543.5224 beltETH ($0.00)', 'BELT Per Week: 6048.00 ($82,543.15)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 BELT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  11825
# no Pair....
#  ['beltBNB Price: $0.00 TVL: $0.00', 'Staked: 272711.1433 beltBNB ($0.00)', 'BELT Per Week: 6048.00 ($82,543.15)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 BELT ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  11836
# no Pair....
#  ['beltBNB Price: $0.00 TVL: $0.00', 'Staked: 3355.6258 beltBNB ($0.00)', 'SWAMP Per Week: 157.41 ($1,448.19)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 SWAMP ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15440
# no Pair....
#  ['beltBTC Price: $0.00 TVL: $0.00', 'Staked: 32.4343 beltBTC ($0.00)', 'SWAMP Per Week: 157.41 ($1,448.19)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 SWAMP ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15450
# no Pair....
#  ['beltETH Price: $0.00 TVL: $0.00', 'Staked: 470.0737 beltETH ($0.00)', 'SWAMP Per Week: 157.41 ($1,448.19)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 SWAMP ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15460
# [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,616,391,463.13 TVL: $9,996,507.26
# no Pair....
#  ['[τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,616,391,463.13 TVL: $9,996,507.26', 'τBTC Price: $18,509.33', 'BTCB Price: $34,827.00', 'Staked: 0.0000 Cake-LP ($68,846.47)', 'SWAMP Per Week: 31.48 ($289.64)', 'APR: Day 0.06% Week 0.42% Year 21.88%', 'You are staking 0.00 [τBTC]-[BTCB] Cake LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [τBTC]-[BTCB] Cake LP', 'Unstake 0.00 [τBTC]-[BTCB] Cake LP', 'Claim 0.00 SWAMP ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  15904
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 92, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# Cake Price: $13.58 Market Cap: $4,774,817,280.00 [%]
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 92, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# BANANA Price: $1.85 Market Cap: $84,614,624.54 [%]
# no Pair....
#  ['NUTS Per Week: 2500.00 ($4,400.00)', 'APR: ~80% TLM + 17524.80% NUTS', 'You are staking 0.00 Cake ($0.00), 0.00% of the pool.', 'Stake 0.00 Cake', 'Unstake 0.00 Cake', 'Harvest 0.00 TLM + 0.00 NUTS', 'Unstaking also harvests rewards.']
# Block Start Line No.:  22396
# no Pair....
#  ['0 - fWBNB Price: $300.96 TVL: $829,808.71', 'Staked: 2624.4869 fWBNB ($789,853.48)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fWBNB ($0.00), 0.00% of the pool.', 'Stake 0.00 fWBNB', 'Unstake 0.00 fWBNB', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29504
# no Pair....
#  ['1 - fUSDT Price: $1.03 TVL: $1,940,550.51', 'Staked: 1841903.4526 fUSDT ($1,896,274.15)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fUSDT ($0.00), 0.00% of the pool.', 'Stake 0.00 fUSDT', 'Unstake 0.00 fUSDT', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29514
# no Pair....
#  ['2 - fUSDC Price: $1.02 TVL: $901,444.53', 'Staked: 867705.1180 fUSDC ($884,403.01)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fUSDC ($0.00), 0.00% of the pool.', 'Stake 0.00 fUSDC', 'Unstake 0.00 fUSDC', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29524
# no Pair....
#  ['3 - fBUSD Price: $1.03 TVL: $783,682.24', 'Staked: 695530.5400 fBUSD ($716,329.60)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fBUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 fBUSD', 'Unstake 0.00 fBUSD', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29534
# no Pair....
#  ['4 - fDAI Price: $1.02 TVL: $119,187.72', 'Staked: 115520.2329 fDAI ($117,914.25)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fDAI ($0.00), 0.00% of the pool.', 'Stake 0.00 fDAI', 'Unstake 0.00 fDAI', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29544
# no Pair....
#  ['5 - fBTCB Price: $35,122.10 TVL: $3,981,147.14', 'Staked: 112.7523 fBTCB ($3,960,097.27)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fBTCB ($0.00), 0.00% of the pool.', 'Stake 0.00 fBTCB', 'Unstake 0.00 fBTCB', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29554
# no Pair....
#  ['6 - fETH Price: $2,129.07 TVL: $974,175.76', 'Staked: 440.0473 fETH ($936,889.40)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fETH ($0.00), 0.00% of the pool.', 'Stake 0.00 fETH', 'Unstake 0.00 fETH', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29564
# no Pair....
#  ['13 - f3EPS Price: $1.04 TVL: $1,170,552.90', 'Staked: 1097431.6401 f3EPS ($1,139,055.66)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 f3EPS ($0.00), 0.00% of the pool.', 'Stake 0.00 f3EPS', 'Unstake 0.00 f3EPS', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29584
# no Pair....
#  ['14 - fCake Price: $16.39 TVL: $2,011,004.00', 'Staked: 89831.8234 fCake ($1,472,127.39)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fCake ($0.00), 0.00% of the pool.', 'Stake 0.00 fCake', 'Unstake 0.00 fCake', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29594
# no Pair....
#  ['16 - fHMDX Price: $0.00 TVL: $0.00', 'Staked: 3500.5629 fHMDX ($0.00)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 fHMDX ($0.00), NaN% of the pool.', 'Stake 0.00 fHMDX', 'Unstake 0.00 fHMDX', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29604
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 21 - Wrapped [USDT]-[WBNB] Uni LP Price: $37.43 TVL: $15,608.77
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 22 - Wrapped [USDT]-[BTCB] Uni LP Price: $393.59 TVL: $39,619.55
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 23 - Wrapped [ETH]-[USDT] Uni LP Price: $98.34 TVL: $33,353.06
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 24 - Wrapped [USDT]-[BUSD] Uni LP Price: $2.06 TVL: $57,408.25
# no Pair....
#  ['26 - fBUNNY Price: $18.83 TVL: $115,343.58', 'Staked: 4821.6638 fBUNNY ($90,812.72)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day 0.00% Week 0.00% Year 0.00%', 'You are staking 0.00 fBUNNY ($0.00), 0.00% of the pool.', 'Stake 0.00 fBUNNY', 'Unstake 0.00 fBUNNY', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29704
# no Pair....
#  ['27 - f4Belt Price: $0.00 TVL: $0.00', 'Staked: 652536.5996 f4Belt ($0.00)', 'HYFI Per Week: 0.00 ($0.00)', 'APR: Day NaN% Week NaN% Year NaN%', 'You are staking 0.00 f4Belt ($0.00), NaN% of the pool.', 'Stake 0.00 f4Belt', 'Unstake 0.00 f4Belt', 'Claim 0.00 HYFI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  29714
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 28 - Wrapped [Cake]-[WBNB] Cake LP Price: $139.20 TVL: $328,966.33
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 29 - Wrapped [WBNB]-[BUSD] Cake LP Price: $39.56 TVL: $35,456.12
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 30 - Wrapped [BTCB]-[WBNB] Cake LP Price: $6,777.42 TVL: $56,513.74
# Exception Traceback (most recent call last):
#   File "<ipython-input-14-33b151aaa9ee>", line 104, in get_pairs
#   File "<ipython-input-14-33b151aaa9ee>", line 82, in get_pair_info_from_block
#   File "<ipython-input-12-beeab1256670>", line 13, in get_single_tvl
# IndexError: list index out of range
#
# 31 - Wrapped [BUSD]-[TPT] Cake LP Price: $3,742,859.32 TVL: $44,332.99
# no Pair....
#  ['48 - beltBNB Price: $0.00 TVL: $0.00', 'Staked: 14.7219 beltBNB ($0.00)', 'aDGNZ Per Week: 52.88 ($34.93)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 aDGNZ ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  36652
# no Pair....
#  ['49 - beltBTC Price: $0.00 TVL: $0.00', 'Staked: 0.2084 beltBTC ($0.00)', 'aDGNZ Per Week: 39.66 ($26.20)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 aDGNZ ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  36662
# no Pair....
#  ['50 - beltETH Price: $0.00 TVL: $0.00', 'Staked: 3.6292 beltETH ($0.00)', 'aDGNZ Per Week: 39.66 ($26.20)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 aDGNZ ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  36672
# no Pair....
#  ['6 - beltBNB Price: $0.00 TVL: $0.00', 'Staked: 0.0000 beltBNB ($0.00)', 'AQUA Per Week: 41.18 ($6,274.04)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBNB ($0.00), NaN% of the pool.', 'Stake 0.00 beltBNB', 'Unstake 0.00 beltBNB', 'Claim 0.00 AQUA ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  38388
# no Pair....
#  ['7 - beltBTC Price: $0.00 TVL: $0.00', 'Staked: 0.0000 beltBTC ($0.00)', 'AQUA Per Week: 41.18 ($6,274.04)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltBTC ($0.00), NaN% of the pool.', 'Stake 0.00 beltBTC', 'Unstake 0.00 beltBTC', 'Claim 0.00 AQUA ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  38398
# no Pair....
#  ['8 - beltETH Price: $0.00 TVL: $0.00', 'Staked: 0.0000 beltETH ($0.00)', 'AQUA Per Week: 41.18 ($6,274.04)', 'APR: Day Infinity% Week Infinity% Year Infinity%', 'You are staking 0.00 beltETH ($0.00), NaN% of the pool.', 'Stake 0.00 beltETH', 'Unstake 0.00 beltETH', 'Claim 0.00 AQUA ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  38408
# 22 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,620,519,738.60 TVL: $10,022,038.41
# no Pair....
#  ['22 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $1,620,519,738.60 TVL: $10,022,038.41', 'τBTC Price: $18,556.57', 'BTCB Price: $34,916.00', 'Staked: 0.0000 Cake-LP ($0.87)', 'ELXR Per Week: 2473.62 ($13.04)', 'APR: Day 214.11% Week 1498.78% Year 77936.52%', 'You are staking 0.00 [τBTC]-[BTCB] Cake LP ($0.00), 0.00% of the pool.', 'Stake 0.00 [τBTC]-[BTCB] Cake LP - Fee 4%', 'Unstake 0.00 [τBTC]-[BTCB] Cake LP', 'Claim 0.00 ELXR ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  40280
# no Pair....
#  ['3 - mBUSD Price: $1.04 TVL: $17,703.68', 'Staked: 15434.1407 mBUSD ($16,056.60)', 'MM Per Week: 8.10 ($22.47)', 'APR: Day 0.02% Week 0.14% Year 7.28%', 'You are staking 0.00 mBUSD ($0.00), 0.00% of the pool.', 'Stake 0.00 mBUSD', 'Unstake 0.00 mBUSD', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  41463
# no Pair....
#  ['4 - mEPS Price: $0.41 TVL: $3,661.47', 'Staked: 4080.1025 mEPS ($1,677.74)', 'MM Per Week: 8.10 ($22.47)', 'APR: Day 0.19% Week 1.34% Year 69.63%', 'You are staking 0.00 mEPS ($0.00), 0.00% of the pool.', 'Stake 0.00 mEPS', 'Unstake 0.00 mEPS', 'Claim 0.00 MM ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  41473
# [WBNB]-[τDOGE] Cake LP [+] [-] [<=>] Price: $1,381,492.48 TVL: $1,499,805.64
# 32 - [WBNB]-[τDOGE] Cake LP [+] [-] [<=>] Price: $1,381,492.48 TVL: $1,499,805.64
# no Pair....
#  ['Total Staked: $113,827.15', 'Staking Contract', 'Found 7 pools.']
# Block Start Line No.:  47645
# no Pair....
#  ['Staking Contract', 'Found 6 pools.']
# Block Start Line No.:  52857
# no Pair....
#  ['Initialized 0xf42122af352885352e26e5a6253cb20ad9f727ec', 'Reading smart contracts...']
# Block Start Line No.:  59433
# no Pair....
#  ['Staking Contract', 'Found 6 pools.']
# Block Start Line No.:  59712
# no Pair....
#  ['4 - [USDC ]-[BUSD]-[USDT] BPT Price: $29.95 TVL: $168,749.10', 'USDC Price: $1.00', 'BUSD Price: $1.00', 'USDT Price: $1.00', 'Staked: 5634.8528 [USDC]-[BUSD]-[USDT] ($168,749.10)', 'YOGI Per Week: 16016.00 ($2,119.00)', 'APR: Day 0.18% Week 1.26% Year 65.30%', 'You are staking 0.00 [USDC]-[BUSD]-[USDT ] ($0.00), 0.00% of the pool.', 'Stake 0.00 [USDC ]-[BUSD]-[USDT ]', 'Unstake 0.00 [USDC]-[BUSD]-[USDT]', 'Claim 0.00 YOGI ($0.00)', 'Staking or unstaking also claims rewards.']
# Block Start Line No.:  59767

# %%
pair_df = pd.DataFrame(pairs, columns=['pair1', 'pair2', 'tvl', 'apr', 'where', 'network'])
pair_df['apy'] = np.nan

# %%
pairs
# Out:
# [['WAVAX',
#   'ETH',
#   '46841802.37',
#   '14.74',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WBTC',
#   'WAVAX',
#   '9766912.08',
#   '44.25',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WAVAX',
#   'LINK',
#   '10475554.12',
#   '13.04',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'WAVAX',
#   '45373170.50',
#   '130.55',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WAVAX',
#   'USDT',
#   '3783645.05',
#   '13.32',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['SUSHI',
#   'WAVAX',
#   '4840201.86',
#   '13.01',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WAVAX',
#   'DAI',
#   '4310768.52',
#   '13.11',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['AAVE',
#   'WAVAX',
#   '1937503.04',
#   '12.98',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WAVAX',
#   'UNI',
#   '858936.33',
#   '13.13',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['YFI',
#   'WAVAX',
#   '316762.94',
#   '13.04',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'ETH',
#   '4298600.76',
#   '39.31',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WBTC',
#   'PNG',
#   '184926.45',
#   '43.62',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'LINK',
#   '2001358.58',
#   '38.97',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'USDT',
#   '577789.20',
#   '44.17',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['SUSHI',
#   'PNG',
#   '85884.17',
#   '39.63',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'DAI',
#   '152737.03',
#   '40.46',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'AAVE',
#   '136312.74',
#   '38.96',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'UNI',
#   '73299.18',
#   '41.98',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'YFI',
#   '23660.76',
#   '39.50',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'SPORE',
#   '150919.93',
#   '65.88',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['SPORE',
#   'WAVAX',
#   '202783.00',
#   '21.00',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WAVAX',
#   'USDT',
#   '168449.04',
#   '10.38',
#   'https://avax.complus.exchange',
#   'AVAX'],
#  ['WAVAX',
#   'ETH',
#   '58619.34',
#   '13.24',
#   'https://avax.complus.exchange',
#   'AVAX'],
#  ['WAVAX',
#   'DAI',
#   '75823.39',
#   '15.43',
#   'https://avax.complus.exchange',
#   'AVAX'],
#  ['COM',
#   'WAVAX',
#   '21152.65',
#   '30.48',
#   'https://avax.complus.exchange',
#   'AVAX'],
#  ['WBTC',
#   'WAVAX',
#   '13530.86',
#   '57.51',
#   'https://avax.complus.exchange',
#   'AVAX'],
#  ['xCOM',
#   'WAVAX',
#   '1500.21',
#   '107.43',
#   'https://avax.complus.exchange',
#   'AVAX'],
#  ['WAVAX',
#   'COM+',
#   '20588.69',
#   '150.96',
#   'https://avax.complus.exchange',
#   'AVAX'],
#  ['COM+',
#   'USDT',
#   '16216.76',
#   '191.81',
#   'https://avax.complus.exchange',
#   'AVAX'],
#  ['BNB', 'COM+', '7048.93', '219.65', 'https://avax.complus.exchange', 'AVAX'],
#  ['COM+', 'HT', '7970.13', '194.34', 'https://avax.complus.exchange', 'AVAX'],
#  ['AVAX+',
#   'COM+',
#   '9497.80',
#   '165.79',
#   'https://avax.complus.exchange',
#   'AVAX'],
#  ['ZERO', 'zUSDC', '22295.57', '0.00', 'https://app.0.exchange', 'AVAX'],
#  ['ZERO', 'WAVAX', '521509.31', '0.00', 'https://app.0.exchange', 'AVAX'],
#  ['ZERO', 'zETH', '144415.31', '0.00', 'https://app.0.exchange', 'AVAX'],
#  ['ZERO', 'zUSDT', '40639.52', '0.00', 'https://app.0.exchange', 'AVAX'],
#  ['ZERO', 'zBTC', '27339.24', '0.00', 'https://app.0.exchange', 'AVAX'],
#  ['ZERO', 'zUNI', '10661.79', '0.00', 'https://app.0.exchange', 'AVAX'],
#  ['ZERO', 'zSUSHI', '29324.30', '0.00', 'https://app.0.exchange', 'AVAX'],
#  ['ZERO', 'zDAI', '12692.71', '0.00', 'https://app.0.exchange', 'AVAX'],
#  ['YTS',
#   'WAVAX',
#   '43873.76',
#   '175.52',
#   'https://exchange.yetiswap.app',
#   'AVAX'],
#  ['WAVAX',
#   'ETH',
#   '78982.97',
#   '34.55',
#   'https://exchange.yetiswap.app',
#   'AVAX'],
#  ['WAVAX',
#   'USDT',
#   '87607.32',
#   '43.14',
#   'https://exchange.yetiswap.app',
#   'AVAX'],
#  ['YTS', 'ETH', '285.49', '156.56', 'https://exchange.yetiswap.app', 'AVAX'],
#  ['YTS', 'USDT', '898.57', '115.06', 'https://exchange.yetiswap.app', 'AVAX'],
#  ['YTS', 'PNG', '19460.35', '203.00', 'https://exchange.yetiswap.app', 'AVAX'],
#  ['sBAMBOO-V2', '', '0.00', 0, 'https://pandaswap.exchange', 'AVAX'],
#  ['BAMBOO-V2',
#   'WAVAX',
#   '1997.37',
#   '237.22',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'WAVAX',
#   '9637.08',
#   '81.09',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'ETH',
#   '2402.69',
#   '389.05',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['WBTC',
#   'BAMBOO-V2',
#   '1251.38',
#   '380.83',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'LINK',
#   '6915.32',
#   '68.74',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['SUSHI',
#   'BAMBOO-V2',
#   '1444.00',
#   '412.46',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'SNOB',
#   '11952.40',
#   '39.73',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['WAVAX', 'ETH', '20447.87', '28.46', 'https://pandaswap.exchange', 'AVAX'],
#  ['WAVAX', 'USDT', '1586.34', '58.50', 'https://pandaswap.exchange', 'AVAX'],
#  ['WBTC', 'WAVAX', '1585.22', '43.42', 'https://pandaswap.exchange', 'AVAX'],
#  ['BAMBOO-V2',
#   'USDT',
#   '4697.68',
#   '207.75',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'DAI',
#   '2816.01',
#   '179.13',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BURN', '', '0.00', 0, 'https://pandaswap.exchange', 'AVAX'],
#  ['WAVAX',
#   'PEFI',
#   '1017308.55',
#   '91.65',
#   'https://penguinfinance.org',
#   'AVAX'],
#  ['WAVAX',
#   'ETH',
#   '46884502.28',
#   '12.69',
#   'https://penguinfinance.org',
#   'AVAX'],
#  ['PNG', 'PEFI', '658452.47', '115.12', 'https://penguinfinance.org', 'AVAX'],
#  ['SNOB', 'PEFI', '587209.62', '133.24', 'https://penguinfinance.org', 'AVAX'],
#  ['SUSHI',
#   'PEFI',
#   '561776.12',
#   '136.76',
#   'https://penguinfinance.org',
#   'AVAX'],
#  ['DAI', 'PEFI', '727963.20', '103.96', 'https://penguinfinance.org', 'AVAX'],
#  ['LINK', 'PEFI', '499188.28', '156.13', 'https://penguinfinance.org', 'AVAX'],
#  ['WAVAX', 'ELK', '118333.29', '122.35', 'https://elk.finance', 'AVAX'],
#  ['USDT', 'ELK', '26497.83', '135.70', 'https://elk.finance', 'AVAX'],
#  ['ELK', 'ETH', '23853.14', '62.81', 'https://elk.finance', 'AVAX'],
#  ['WBTC', 'ELK', '16488.77', '72.69', 'https://elk.finance', 'AVAX'],
#  ['LINK', 'ELK', '11348.39', '105.61', 'https://elk.finance', 'AVAX'],
#  ['DAI', 'ELK', '17823.16', '134.49', 'https://elk.finance', 'AVAX'],
#  ['PNG', 'ELK', '5140.98', '116.57', 'https://elk.finance', 'AVAX'],
#  ['YTS', 'ELK', '2104.37', '142.39', 'https://elk.finance', 'AVAX'],
#  ['OLIVE', 'ELK', '1721.61', '174.04', 'https://elk.finance', 'AVAX'],
#  ['ELK', 'PEFI', '2953.17', '202.92', 'https://elk.finance', 'AVAX'],
#  ['SPORE', 'ELK', '13253.20', '311.66', 'https://elk.finance', 'AVAX'],
#  ['SUSHI', 'ELK', '4711.97', '63.59', 'https://elk.finance', 'AVAX'],
#  ['SNOB', 'ELK', '2882.29', '103.96', 'https://elk.finance', 'AVAX'],
#  ['SFI', 'ELK', '1476.44', '204.20', 'https://elk.finance', 'AVAX'],
#  ['SL3', 'ELK', '1444.21', '207.47', 'https://elk.finance', 'AVAX'],
#  ['ARFV2', 'ELK', '1983.72', '302.09', 'https://elk.finance', 'AVAX'],
#  ['AVE', 'ELK', '6705.38', '106.13', 'https://elk.finance', 'AVAX'],
#  ['HUSKY', 'ELK', '6335.61', '94.59', 'https://elk.finance', 'AVAX'],
#  ['OLIVE', '', '88583.54', '77.73', 'https://avax.olive.cash', 'AVAX'],
#  ['OLIVE', 'WAVAX', '148469.93', '193.82', 'https://avax.olive.cash', 'AVAX'],
#  ['OLIVE', 'USDT', '71725.02', '77.03', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'USDT', '73719.24', '18.70', 'https://avax.olive.cash', 'AVAX'],
#  ['SUSHI', 'WAVAX', '36023.09', '38.24', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'ETH', '31791.75', '43.33', 'https://avax.olive.cash', 'AVAX'],
#  ['WBTC', 'WAVAX', '81404.17', '16.92', 'https://avax.olive.cash', 'AVAX'],
#  ['PNG', 'WAVAX', '8687.84', '39.69', 'https://avax.olive.cash', 'AVAX'],
#  ['DAI', 'USDT', '342044.68', '2.01', 'https://avax.olive.cash', 'AVAX'],
#  ['SPORE', 'WAVAX', '58231.15', '47.37', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'MKC', '2021.29', '186.07', 'https://avax.olive.cash', 'AVAX'],
#  ['HUSKY', 'WAVAX', '37104.13', '74.71', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'NEKO', '4803.27', '71.69', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'XAVA', '4611.51', '149.33', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', '', '822.35', '167.47', 'https://avax.olive.cash', 'AVAX'],
#  ['AVE', 'WAVAX', '576.44', '239.02', 'https://avax.olive.cash', 'AVAX'],
#  ['BAG', '', '168593.07', '72.19', 'https://app.baguette.exchange', 'AVAX'],
#  ['WAVAX', '', '969469.01', '6.28', 'https://app.baguette.exchange', 'AVAX'],
#  ['BAG',
#   'WAVAX',
#   '69409.26',
#   '115.08',
#   'https://app.baguette.exchange',
#   'AVAX'],
#  ['BAG', 'DAI', '5610.01', '0.00', 'https://app.baguette.exchange', 'AVAX'],
#  ['BAG', 'ETH', '29741.20', '258.25', 'https://app.baguette.exchange', 'AVAX'],
#  ['BAG',
#   'LINK',
#   '31400.43',
#   '243.04',
#   'https://app.baguette.exchange',
#   'AVAX'],
#  ['BAG',
#   'USDT',
#   '43322.88',
#   '178.25',
#   'https://app.baguette.exchange',
#   'AVAX'],
#  ['WBTC',
#   'BAG',
#   '27757.75',
#   '283.16',
#   'https://app.baguette.exchange',
#   'AVAX'],
#  ['WAVAX',
#   'LINK',
#   '95941.58',
#   '26.39',
#   'https://app.baguette.exchange',
#   'AVAX'],
#  ['WAVAX',
#   'USDT',
#   '93476.82',
#   '27.10',
#   'https://app.baguette.exchange',
#   'AVAX'],
#  ['WAVAX', 'DAI', '204.09', '0.00', 'https://app.baguette.exchange', 'AVAX'],
#  ['WAVAX',
#   'ETH',
#   '154394.95',
#   '16.40',
#   'https://app.baguette.exchange',
#   'AVAX'],
#  ['WBTC',
#   'WAVAX',
#   '132342.56',
#   '19.13',
#   'https://app.baguette.exchange',
#   'AVAX'],
#  ['LYD', '', '407203.16', '320.50', 'https://www.lydia.finance', 'AVAX'],
#  ['WAVAX', 'USDT', '339549.21', '24.63', 'https://www.lydia.finance', 'AVAX'],
#  ['WAVAX', 'ETH', '544772.47', '20.47', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'USDT', '318853.80', '360.26', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'WAVAX', '385584.51', '289.93', 'https://www.lydia.finance', 'AVAX'],
#  ['SUSHI', 'WAVAX', '107241.05', '25.99', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'PNG', '186632.41', '299.71', 'https://www.lydia.finance', 'AVAX'],
#  ['WBTC', 'WAVAX', '238256.56', '23.39', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'ETH', '185491.56', '300.51', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'SNOB', '43242.85', '323.85', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'XAVA', '40866.00', '349.84', 'https://www.lydia.finance', 'AVAX'],
#  ['DAI', 'USDT', '178968.70', '7.79', 'https://www.lydia.finance', 'AVAX'],
#  ['WAVAX', 'USDT', '3791055.33', '172.41', 'https://birdy.finance', 'AVAX'],
#  ['WAVAX', 'PEFI', '1017308.55', '4353.52', 'https://birdy.finance', 'AVAX'],
#  ['PNG', 'PEFI', '658452.47', '16321.72', 'https://birdy.finance', 'AVAX'],
#  ['BIRD', 'WAVAX', '9399.48', '2456.95', 'https://birdy.finance', 'AVAX'],
#  ['BIRD', 'USDT', '16175.68', '2753.73', 'https://birdy.finance', 'AVAX'],
#  ['PNG', 'WAVAX', '45395062.81', '285.86', 'https://birdy.finance', 'AVAX'],
#  ['gondolaETHPool',
#   '',
#   '1609971.16',
#   '7.97',
#   'https://app.gondola.finance',
#   'AVAX'],
#  ['gondolaUSDTPool',
#   '',
#   '1569443.78',
#   '4.46',
#   'https://app.gondola.finance',
#   'AVAX'],
#  ['ZERO', 'GDL', '92905.12', '408.29', 'https://app.gondola.finance', 'AVAX'],
#  ['GDL', '', '161799.34', '144.10', 'https://app.gondola.finance', 'AVAX'],
#  ['WAVAX',
#   'GDL',
#   '143030.30',
#   '244.87',
#   'https://app.gondola.finance',
#   'AVAX'],
#  ['gondolaRenBtc', '', '0.00', 0, 'https://app.gondola.finance', 'AVAX'],
#  ['WAVAX',
#   'ETH',
#   '594210.40',
#   '16.22',
#   'https://app.canary.exchange/',
#   'AVAX'],
#  ['CNR',
#   'WAVAX',
#   '63702.81',
#   '455.61',
#   'https://app.canary.exchange/',
#   'AVAX'],
#  ['WAVAX', 'USDT', '300207.03', 0, 'https://app.canary.exchange/', 'AVAX'],
#  ['WAVAX',
#   'LINK',
#   '342896.43',
#   '28.12',
#   'https://app.canary.exchange/',
#   'AVAX'],
#  ['PNG',
#   'WAVAX',
#   '82139.88',
#   '125.17',
#   'https://app.canary.exchange/',
#   'AVAX'],
#  ['CNR', 'USDT', '77661.46', '375.36', 'https://app.canary.exchange/', 'AVAX'],
#  ['CNR', 'ETH', '51377.66', '562.94', 'https://app.canary.exchange/', 'AVAX'],
#  ['CNR', 'LINK', '51862.47', '558.57', 'https://app.canary.exchange/', 'AVAX'],
#  ['PNG', 'CNR', '52512.12', '556.72', 'https://app.canary.exchange/', 'AVAX'],
#  ['CNR', '', '0.00', 0, 'https://app.canary.exchange/', 'AVAX'],
#  ['WAVAX', '', '1089482.59', 0, 'https://app.canary.exchange/', 'AVAX'],
#  ['WAVAX',
#   'XAVA',
#   '2311896.48',
#   '81.02',
#   'https://farm.avalaunch.app',
#   'AVAX'],
#  ['XAVA', '', '2639648.62', '24.25', 'https://farm.avalaunch.app', 'AVAX'],
#  ['XavaDT', '', '0.00', 0, 'https://farm.avalaunch.app', 'AVAX'],
#  ['AVME', 'WAVAX', '223294.01', '276.68', 'https://avme.io', 'AVAX'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['FISH', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', '', '10105692.32', '81.72', 'https://polycat.finance', 'ETH'],
#  ['WBTC', '', '11116810.10', '49.53', 'https://polycat.finance', 'ETH'],
#  ['WETH', '', '16598724.64', '49.75', 'https://polycat.finance', 'ETH'],
#  ['QUICK', '', '2515890.57', '218.84', 'https://polycat.finance', 'ETH'],
#  ['USDT', '', '9120322.80', '60.37', 'https://polycat.finance', 'ETH'],
#  ['USDC', '', '10696787.82', '51.47', 'https://polycat.finance', 'ETH'],
#  ['DAI', '', '9032138.46', '60.96', 'https://polycat.finance', 'ETH'],
#  ['LINK', '', '3750925.00', '73.39', 'https://polycat.finance', 'ETH'],
#  ['PolyDoge', '', '2093156.74', '157.82', 'https://polycat.finance', 'ETH'],
#  ['SUSHI', '', '5275029.26', '104.37', 'https://polycat.finance', 'ETH'],
#  ['SLP', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['AGA', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['AGAr', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['DFYN', '', '1751772.43', '314.29', 'https://polycat.finance', 'ETH'],
#  ['BANANA', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'FISH', '827218.73', '333.32', 'https://polycat.finance', 'ETH'],
#  ['FISH', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'QUICK', '8351689.14', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['DAI', 'USDT', '12886102.83', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', 'QUICK', '11480926.90', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'WETH', '66314633.63', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'WETH', '82284535.47', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', 'USDT', '52918679.66', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'WETH', '66314633.63', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'WETH', '82284535.47', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', 'USDT', '52918679.66', 0, 'https://polycat.finance', 'ETH'],
#  ['SLP', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['SLP', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['SLP', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['LINK', 'WETH', '27927621.87', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'USDT', '89729889.10', 0, 'https://polycat.finance', 'ETH'],
#  ['CRV', 'WETH', '7504222.50', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'IRON', '910527.16', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', '', '63278.17', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'FISH', '678711.53', 0, 'https://polycat.finance', 'ETH'],
#  ['FISH', 'QUICK', '704468.33', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'DAI', '54641983.61', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'DAI', '46241864.71', 0, 'https://polycat.finance', 'ETH'],
#  ['USDT', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['USDT', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['USDT', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['USDT', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['DAI', '', '576355.75', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', '', '482122.36', 0, 'https://polycat.finance', 'ETH'],
#  ['WBTC', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['AAVE', '', '0.00', 0, 'https://polycat.finance', 'ETH'],
#  ['QUICK', 'PolyDoge', '704782.40', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'PolyDoge', '363346.16', 0, 'https://polycat.finance', 'ETH'],
#  ['FISH', 'WMATIC', '7929751.52', 0, 'https://polycat.finance', 'ETH'],
#  ['FISH', 'DFYN', '593535.20', 0, 'https://polycat.finance', 'ETH'],
#  ['FISH', 'DFYN', '593535.20', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'IRON', '910527.16', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'IRON', '910527.16', 0, 'https://polycat.finance', 'ETH'],
#  ['FRAX', 'USDC', '12544738.28', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'IRON', '525713.87', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', 'TITAN', '410685.21', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'TITAN', '20672.68', 0, 'https://polycat.finance', 'ETH'],
#  ['TITAN', 'IRON', '2237.94', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', 'IRON', '13654.49', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'USDT', '68251730.19', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'USDT', '68251730.19', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'WEXpoly', '12196411.20', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'WEXpoly', '3124920.08', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'WETH', '27436032.80', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'USDC', '32285167.64', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'WETH', '80153878.18', 0, 'https://polycat.finance', 'ETH'],
#  ['WBTC', 'WETH', '38106232.37', 0, 'https://polycat.finance', 'ETH'],
#  ['WBTC', 'USDC', '68050753.03', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'DAI', '22829066.16', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', 'DAI', '17438245.70', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', 'AAVE', '5063463.69', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'WEXpoly', '12196411.20', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'WEXpoly', '3124920.08', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'WETH', '27436032.80', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'USDC', '32285167.64', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'WETH', '80153878.18', 0, 'https://polycat.finance', 'ETH'],
#  ['WBTC', 'WETH', '38106232.37', 0, 'https://polycat.finance', 'ETH'],
#  ['WBTC', 'USDC', '68050753.03', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'DAI', '22829066.16', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', 'DAI', '17438245.70', 0, 'https://polycat.finance', 'ETH'],
#  ['WETH', 'AAVE', '5063463.69', 0, 'https://polycat.finance', 'ETH'],
#  ['LINK', 'WETH', '7091390.06', 0, 'https://polycat.finance', 'ETH'],
#  ['SNX', 'WETH', '2834252.54', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'PAUTO', '1263820.56', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'BIFI', '1274899.91', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'ELE', '568978.01', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'PolyDoge', '634469.37', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'WAULTx', '1578912.97', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'USDC', '32285167.64', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', '', '678684.33', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'FISH', '365856.83', 0, 'https://polycat.finance', 'ETH'],
#  ['USDC', 'DAI', '10079873.83', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'BANANA', '4398433.60', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'WETH', '12843882.53', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'DAI', '2788373.47', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'USDT', '6821239.21', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'WBTC', '3828834.48', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'BNB', '1163142.66', 0, 'https://polycat.finance', 'ETH'],
#  ['WMATIC', 'USDC', '1024734.11', 0, 'https://polycat.finance', 'ETH'],
#  ['🌾', '', '49549.51', '26108.80', 'https://harvester.app', 'ETH'],
#  ['WETH', '', '114447.52', '11303.68', 'https://harvester.app', 'ETH'],
#  ['WMATIC', '', '102388.80', '10107.97', 'https://harvester.app', 'ETH'],
#  ['DAI', '', '127628.98', '5068.12', 'https://harvester.app', 'ETH'],
#  ['SUSHI', '', '44470.91', '17454.26', 'https://harvester.app', 'ETH'],
#  ['LINK', '', '80341.94', '9661.29', 'https://harvester.app', 'ETH'],
#  ['AAVE', '', '36643.86', '21182.46', 'https://harvester.app', 'ETH'],
#  ['SNX', '', '32019.75', '24241.51', 'https://harvester.app', 'ETH'],
#  ['USDC', '', '97683.05', '6621.82', 'https://harvester.app', 'ETH'],
#  ['CRV', '', '59324.78', '10903.36', 'https://harvester.app', 'ETH'],
#  ['GRT', '', '25690.52', '25178.13', 'https://harvester.app', 'ETH'],
#  ['WBTC', '', '28656.57', '18057.69', 'https://harvester.app', 'ETH'],
#  ['USDT', '', '75579.42', '8558.40', 'https://harvester.app', 'ETH'],
#  ['FARM', '', '17370414.42', '39.86', 'https://harvest.finance/', 'ETH'],
#  ['FARM', 'WETH', '4637017.67', '31.71', 'https://harvest.finance/', 'ETH'],
#  ['FARM', 'USDC', '102794.23', '0.00', 'https://harvest.finance/', 'ETH'],
#  ['GRAIN', 'FARM', '42942.21', '39.65', 'https://harvest.finance/', 'ETH'],
#  ['DPI', 'WETH', '1882047.36', '1.17', 'https://harvest.finance/', 'ETH'],
#  ['DAI', 'BSG', '1206.25', '0.00', 'https://harvest.finance/', 'ETH'],
#  ['DAI', 'BSGS', '3556.58', '0.00', 'https://harvest.finance/', 'ETH'],
#  ['BAC', 'DAI', '500780.04', '0.00', 'https://harvest.finance/', 'ETH'],
#  ['BASv2', 'DAI', '46462.64', '0.00', 'https://harvest.finance/', 'ETH'],
#  ['MIC', 'USDT', '638850.11', '96.46', 'https://harvest.finance/', 'ETH'],
#  ['MIS', 'USDT', '63223.08', '339.52', 'https://harvest.finance/', 'ETH'],
#  ['DAI', 'WETH', '16751441.10', '0.59', 'https://harvest.finance/', 'ETH'],
#  ['USDC', 'WETH', '11628485.25', '0.76', 'https://harvest.finance/', 'ETH'],
#  ['WETH', 'USDT', '33589294.05', '0.48', 'https://harvest.finance/', 'ETH'],
#  ['WBTC', 'WETH', '11747586.53', '0.39', 'https://harvest.finance/', 'ETH'],
#  ['VSD', 'USDT', '0.00', 0, 'https://valueset.finance/', 'ETH'],
#  ['VSD', 'USDC', '121771.44', 0, 'https://valueset.finance/', 'ETH'],
#  ['VSD', 'WETH', '3600.89', 0, 'https://valueset.finance/', 'ETH'],
#  ['VSD', 'DAI', '21506.55', 0, 'https://valueset.finance/', 'ETH'],
#  ['UNI', '', '32524.54', '155.75', 'https://penguinswap.eth.link', 'ETH'],
#  ['BTCx5-USDC-1Jun21-LP',
#   '',
#   '852291.43',
#   '244.92',
#   'https://app.compli.fi',
#   'ETH'],
#  ['BTCx5-USDC-1Jun21-UP',
#   '',
#   '17908.78',
#   '5827.86',
#   'https://app.compli.fi',
#   'ETH'],
#  ['BTCx5-USDC-1Jun21-DOWN',
#   '',
#   '54131.76',
#   '1928.07',
#   'https://app.compli.fi',
#   'ETH'],
#  ['ETHx5-USDC-1Jun21-LP',
#   '',
#   '3847.21',
#   '54257.43',
#   'https://app.compli.fi',
#   'ETH'],
#  ['ETHx5-USDC-1Jun21-UP',
#   '',
#   '14324.85',
#   '7285.93',
#   'https://app.compli.fi',
#   'ETH'],
#  ['ETHx5-USDC-1Jun21-DOWN',
#   '',
#   '9466.05',
#   '11025.69',
#   'https://app.compli.fi',
#   'ETH'],
#  ['LINKx5-USDC-1Jun21-LP', '', '0.00', 0, 'https://app.compli.fi', 'ETH'],
#  ['LINKx5-USDC-1Jun21-UP',
#   '',
#   '3305.44',
#   '31575.20',
#   'https://app.compli.fi',
#   'ETH'],
#  ['LINKx5-USDC-1Jun21-DOWN', '', '0.00', 0, 'https://app.compli.fi', 'ETH'],
#  ['UNIx5-USDC-1Jun21-LP', '', '0.00', 0, 'https://app.compli.fi', 'ETH'],
#  ['UNIx5-USDC-1Jun21-UP',
#   '',
#   '10889.58',
#   '9584.37',
#   'https://app.compli.fi',
#   'ETH'],
#  ['UNIx5-USDC-1Jun21-DOWN',
#   '',
#   '5616.70',
#   '18582.05',
#   'https://app.compli.fi',
#   'ETH'],
#  ['COMFI', 'WETH', '682911.50', '25473.41', 'https://app.compli.fi', 'ETH'],
#  ['YT-aUSDC-29DEC2022',
#   'USDC',
#   '2756775.92',
#   '309.89',
#   'https://app.pendle.finance/',
#   'ETH'],
#  ['YT-cDAI-29DEC2022',
#   'USDC',
#   '2564286.54',
#   '330.53',
#   'https://app.pendle.finance/',
#   'ETH'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['USDC',
#   'QUICK',
#   '8353002.50',
#   '50.28',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'QUICK',
#   '11483316.88',
#   '57.30',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['USDC',
#   'DAI',
#   '54642073.33',
#   '3.93',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'TEL',
#   '2320430.19',
#   '77.24',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['stkGHST-QUICK',
#   '',
#   '0.00',
#   0,
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'WISE',
#   '5384601.62',
#   '15.06',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'CEL',
#   '4731185.99',
#   '30.74',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'TEL',
#   '4122465.65',
#   '39.90',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['DEFI5',
#   'WETH',
#   '4037125.84',
#   '11.99',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['Krill',
#   'QUICK',
#   '60558.22',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'WISE',
#   '1466085.95',
#   '66.12',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'PolyDoge',
#   '704893.91',
#   '93.20',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['QUICK',
#   'EMON',
#   '81504.35',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'SX',
#   '1829184.14',
#   '20.13',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['stkGHST-USDC',
#   '',
#   '0.00',
#   0,
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC',
#   'WOLF',
#   '664505.46',
#   '48.52',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['LINK',
#   'QUICK',
#   '1287204.01',
#   '50.39',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['AGA',
#   'AGAr',
#   '127124.30',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'UNI',
#   '1880951.53',
#   '60.78',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['DAI',
#   'USDT',
#   '12880102.63',
#   '5.07',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC',
#   'PolyDoge',
#   '363452.62',
#   '127.79',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC',
#   'EMON',
#   '105231.00',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['FRAX',
#   'FXS',
#   '403962.13',
#   '12.29',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'DEGEN',
#   '561135.06',
#   '57.56',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'GAME',
#   '511762.49',
#   '62.84',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'DEGEN',
#   '522165.75',
#   '63.05',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['ARIA20',
#   'WETH',
#   '272100.36',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'CC10',
#   '974263.87',
#   '42.20',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['VISION',
#   'WETH',
#   '612468.20',
#   '26.60',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['DEFI5',
#   'QUICK',
#   '592921.85',
#   '67.80',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['$DG',
#   'WETH',
#   '575396.91',
#   '83.81',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'CEL',
#   '502830.00',
#   '64.15',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'CC10',
#   '437663.55',
#   '73.45',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'UBT',
#   '1656262.66',
#   '29.27',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC',
#   'mOCEAN',
#   '1462784.76',
#   '30.75',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['SWAP',
#   'QUICK',
#   '197245.89',
#   '65.77',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['SX',
#   'DAI',
#   '547416.07',
#   '12.04',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'miFARM',
#   '402513.87',
#   '20.01',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['UBT',
#   'QUICK',
#   '198841.79',
#   '85.43',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'SUPER',
#   '115072.79',
#   '70.70',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'AGAr',
#   '2790.64',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['ANY',
#   'QUICK',
#   '323545.38',
#   '74.74',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WETH',
#   'SUPER',
#   '214864.71',
#   '38.53',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['FRAX',
#   'QUICK',
#   '291679.36',
#   '56.38',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['VISION',
#   'QUICK',
#   '49660.92',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['HEX',
#   'QUICK',
#   '340559.21',
#   '55.23',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'xMARK',
#   '11453.62',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['$DG',
#   'QUICK',
#   '172671.26',
#   '70.04',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['AGA',
#   'QUICK',
#   '3394.03',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'IGG',
#   '158252.44',
#   '51.11',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'BTU',
#   '24.63',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['FSN',
#   'QUICK',
#   '129.03',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['ARIA20',
#   'QUICK',
#   '75124.19',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'NFTP',
#   '10811.94',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'PLOT',
#   '87596.03',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'DRC',
#   '6700.51',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK', 'SX', '538.58', 0, 'https://quickswap.exchange/#/quick', 'MATIC'],
#  ['mOCEAN',
#   'QUICK',
#   '3762.62',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['CTSI',
#   'QUICK',
#   '40098.03',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'WOLF',
#   '5139.02',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['GFARM2',
#   'QUICK',
#   '2.24',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['ELET',
#   'QUICK',
#   '1823.95',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'DMT',
#   '13216.19',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['QUICK',
#   'DSLA',
#   '119930.51',
#   '0.00',
#   'https://quickswap.exchange/#/quick',
#   'MATIC'],
#  ['WMATIC', 'WETH', '534109.24', 0, 'https://swap.cometh.io/#/stake', 'MATIC'],
#  ['LADZ',
#   'WETH',
#   '23820.13',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['LADZ', 'MUST', '12994.18', 0, 'https://swap.cometh.io/#/stake', 'MATIC'],
#  ['MUST',
#   'pBTC',
#   '14927.94',
#   '47.32',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WBTC',
#   'pBTC',
#   '31580.04',
#   '11.14',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['BND',
#   'WETH',
#   '344492.95',
#   '10.28',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'pBTC',
#   '1770.85',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['BND',
#   'MUST',
#   '34988.39',
#   '120.98',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['KIF', 'MUST', '9974.48', '0.00', 'https://swap.cometh.io/#/stake', 'MATIC'],
#  ['DAI',
#   'USDT',
#   '23611.41',
#   '15.01',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'DAI',
#   '32810.58',
#   '10.81',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'USDT',
#   '28456.53',
#   '12.55',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['PICKLE',
#   'MUST',
#   '66386.05',
#   '106.91',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WBTC',
#   'WETH',
#   '1186509.80',
#   '14.82',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['bBADGER',
#   'MUST',
#   '5314.14',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'bDIGG',
#   '6766.17',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['SDT',
#   'xSDT',
#   '236652.77',
#   '3.01',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['xSDT',
#   'sdcrvRenWSBTC',
#   '885.73',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'MUST',
#   '109926.34',
#   '98.46',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WBTC',
#   'MUST',
#   '34988.09',
#   '153.11',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['JULIEN',
#   'MUST',
#   '275604.44',
#   '1.29',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['SDT',
#   'MUST',
#   '13861.03',
#   '29.37',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WBTC',
#   'sdcrvRenWSBTC',
#   '741.28',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['maUSDC',
#   'MUST',
#   '774.56',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['GHST',
#   'MUST',
#   '99425.36',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'AAVE',
#   '7283.01',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['SUSHI',
#   'MUST',
#   '6373.16',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC',
#   'WETH',
#   '394021.89',
#   '22.51',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WETH',
#   'MUST',
#   '371620.51',
#   '138.55',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WMATIC',
#   'MUST',
#   '725408.43',
#   '116.82',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['DOKI',
#   'WETH',
#   '282866.61',
#   '63.13',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['DOKI',
#   'MUST',
#   '83037.82',
#   '42.89',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['AZUKI',
#   'MUST',
#   '97132.74',
#   '187.40',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['AZUKI',
#   'WETH',
#   '270197.16',
#   '145.82',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'STR',
#   '11235.74',
#   '95.85',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'NDR',
#   '28644.67',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['ELET',
#   'MUST',
#   '20281.62',
#   '34.74',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['VBTC',
#   'WETH',
#   '4999.74',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['VBTC',
#   'MUST',
#   '7231.69',
#   '48.85',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['VBTC',
#   'WBTC',
#   '15164.35',
#   '23.27',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['ELET',
#   'WMATIC',
#   '38521.97',
#   '18.31',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   '$TRDL',
#   '2384.73',
#   '0.00',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['SDT',
#   'WETH',
#   '244018.66',
#   '43.92',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MM',
#   'MUST',
#   '59166.26',
#   '83.41',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'mWETH',
#   '44375.77',
#   '95.29',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['mWBTC',
#   'MUST',
#   '38133.13',
#   '111.14',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['WETH',
#   'RAZOR',
#   '67739.96',
#   '23.26',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['MUST',
#   'RAZOR',
#   '21393.37',
#   '66.82',
#   'https://swap.cometh.io/#/stake',
#   'MATIC'],
#  ['USDC', 'NIOX', '459424.41', '97.27', 'https://swap.smartdex.app', 'MATIC'],
#  ['WMATIC',
#   'USDC',
#   '92611.40',
#   '123.02',
#   'https://swap.smartdex.app',
#   'MATIC'],
#  ['USDC', 'WETH', '185594.75', '62.86', 'https://swap.smartdex.app', 'MATIC'],
#  ['AGI', 'NIOX', '1721.25', '0.00', 'https://swap.smartdex.app', 'MATIC'],
#  ['GLQ', 'WETH', '1.96', '0.00', 'https://swap.smartdex.app', 'MATIC'],
#  ['ALOHA', 'NIOX', '28233.20', '0.00', 'https://swap.smartdex.app', 'MATIC'],
#  ['USDC', 'pBTC', '122641.89', '66.19', 'https://swap.smartdex.app', 'MATIC'],
#  ['WMATIC', 'ELK', '364900.89', '136.74', 'https://app.elk.finance', 'MATIC'],
#  ['USDT', 'ELK', '75321.15', '165.30', 'https://app.elk.finance', 'MATIC'],
#  ['USDC', 'ELK', '94845.40', '131.01', 'https://app.elk.finance', 'MATIC'],
#  ['WETH', 'ELK', '59184.12', '157.39', 'https://app.elk.finance', 'MATIC'],
#  ['WBTC', 'ELK', '19047.61', '260.94', 'https://app.elk.finance', 'MATIC'],
#  ['LINK', 'ELK', '28830.31', '172.34', 'https://app.elk.finance', 'MATIC'],
#  ['DAI', 'ELK', '49519.31', '150.47', 'https://app.elk.finance', 'MATIC'],
#  ['QUICK', 'ELK', '13201.29', '235.37', 'https://app.elk.finance', 'MATIC'],
#  ['AAVE', 'ELK', '21282.12', '233.50', 'https://app.elk.finance', 'MATIC'],
#  ['GHST', 'ELK', '3954.61', '315.27', 'https://app.elk.finance', 'MATIC'],
#  ['MUST', 'ELK', '12459.04', '400.70', 'https://app.elk.finance', 'MATIC'],
#  ['DEFI5', 'ELK', '3286.88', '379.54', 'https://app.elk.finance', 'MATIC'],
#  ['CC10', 'ELK', '5116.01', '243.43', 'https://app.elk.finance', 'MATIC'],
#  ['Krill', 'ELK', '5308.57', '469.69', 'https://app.elk.finance', 'MATIC'],
#  ['MANA', 'ELK', '9305.10', '270.53', 'https://app.elk.finance', 'MATIC'],
#  ['ELK', 'CXO', '15124.63', '82.16', 'https://app.elk.finance', 'MATIC'],
#  ['AZUKI', 'ELK', '7885.66', '157.75', 'https://app.elk.finance', 'MATIC'],
#  ['Krill', '', '122121.53', '0.00', 'https://polywhale.finance', 'MATIC'],
#  ['Mint', '', '0.00', 0, 'https://polywhale.finance', 'MATIC'],
#  ['USDC', 'FOX', '9233.80', '700.38', 'https://polyfox.finance', 'MATIC'],
#  ['WMATIC', '', '10043.55', '62.71', 'https://polyfox.finance', 'MATIC'],
#  ['WBTC', '', '13633.21', '46.20', 'https://polyfox.finance', 'MATIC'],
#  ['WETH', '', '3084.54', '408.35', 'https://polyfox.finance', 'MATIC'],
#  ['QUICK', '', '4263.06', '295.46', 'https://polyfox.finance', 'MATIC'],
#  ['Krill', '', '112.88', '2789.73', 'https://polyfox.finance', 'MATIC'],
#  ['USDT', '', '19796.67', '38.18', 'https://polyfox.finance', 'MATIC'],
#  ['USDC', '', '17501.93', '43.18', 'https://polyfox.finance', 'MATIC'],
#  ['DAI', '', '3952.31', '191.22', 'https://polyfox.finance', 'MATIC'],
#  ['FOX', '', '12723.01', '123.75', 'https://polyfox.finance', 'MATIC'],
#  ['HAWK', 'WETH', '7333.37', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['WMATIC', '', '20335.47', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['WETH', '', '1404.85', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['WBTC', '', '81.33', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['DAI', '', '10457.07', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['USDC', '', '32295.80', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['USDT', '', '4350.08', '0.00', 'https://hawkdex.com', 'MATIC'],
#  ['USDC', 'FIRE', '153544.46', '227.56', 'https://polydragon.io', 'MATIC'],
#  ['FIRE', '', '180464.01', '184.59', 'https://polydragon.io', 'MATIC'],
#  ['WMATIC', 'FIRE', '281688.26', '220.04', 'https://polydragon.io', 'MATIC'],
#  ['WETH', 'FIRE', '25744.56', '180.75', 'https://polydragon.io', 'MATIC'],
#  ['miMATIC', 'FIRE', '2193.21', '176.74', 'https://polydragon.io', 'MATIC'],
#  ['HEX', 'FIRE', '2788.84', '166.69', 'https://polydragon.io', 'MATIC'],
#  ['STARTER',
#   'WMATIC',
#   '1372.37',
#   '988.08',
#   'https://www.polystarter.fi',
#   'MATIC'],
#  ['WMATIC', '', '14972.40', '8.43', 'https://www.polystarter.fi', 'MATIC'],
#  ['QUICK', '', '989.65', '127.54', 'https://www.polystarter.fi', 'MATIC'],
#  ['MUST', '', '0.00', 0, 'https://www.polystarter.fi', 'MATIC'],
#  ['Krill', '', '83.15', '505.96', 'https://www.polystarter.fi', 'MATIC'],
#  ['WBTC', '', '350.46', '120.05', 'https://www.polystarter.fi', 'MATIC'],
#  ['WETH', '', '610.61', '68.90', 'https://www.polystarter.fi', 'MATIC'],
#  ['DAI', '', '1070.49', '39.30', 'https://www.polystarter.fi', 'MATIC'],
#  ['USDC', '', '7046.07', '5.97', 'https://www.polystarter.fi', 'MATIC'],
#  ['USDT', '', '506.83', '83.01', 'https://www.polystarter.fi', 'MATIC'],
#  ['USDC', 'SPR', '23.50', '3305.76', 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['SPR', '', '162.84', '168.01', 'https://polyvolve.finance', 'MATIC'],
#  ['WMATIC', '', '592.22', '18.48', 'https://polyvolve.finance', 'MATIC'],
#  ['WETH', '', '129.94', '84.22', 'https://polyvolve.finance', 'MATIC'],
#  ['WBTC', '', '63.08', '60.72', 'https://polyvolve.finance', 'MATIC'],
#  ['QUICK', '', '124.07', '88.20', 'https://polyvolve.finance', 'MATIC'],
#  ['LINK', '', '47.48', '172.86', 'https://polyvolve.finance', 'MATIC'],
#  ['USDC', '', '1301.74', '4.20', 'https://polyvolve.finance', 'MATIC'],
#  ['AAVE', '', '100.36', '70.88', 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['QUICK', 'SPR', '18.43', '1223.49', 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyvolve.finance', 'MATIC'],
#  ['Krill', 'SPR', '24.25', '2736.07', 'https://polyvolve.finance', 'MATIC'],
#  ['USDC', 'GAJ', '112948.63', '425.74', 'https://polygaj.finance', 'MATIC'],
#  ['GAJ', '', '152215.85', '260.70', 'https://polygaj.finance', 'MATIC'],
#  ['WMATIC', '', '51851.05', '76.53', 'https://polygaj.finance', 'MATIC'],
#  ['WBTC', '', '83591.53', '23.74', 'https://polygaj.finance', 'MATIC'],
#  ['WETH', '', '101126.46', '39.24', 'https://polygaj.finance', 'MATIC'],
#  ['USDC', '', '43270.06', '22.93', 'https://polygaj.finance', 'MATIC'],
#  ['USDT', '', '20946.16', '47.36', 'https://polygaj.finance', 'MATIC'],
#  ['AAVE', '', '14248.43', '69.63', 'https://polygaj.finance', 'MATIC'],
#  ['WMATIC', 'GAJ', '66814.11', '622.29', 'https://polygaj.finance', 'MATIC'],
#  ['SLP', '', '0.00', 0, 'https://polygaj.finance', 'MATIC'],
#  ['SLP', '', '0.00', 0, 'https://polygaj.finance', 'MATIC'],
#  ['WMATIC', 'GAJ', '54780.99', '835.29', 'https://polygaj.finance', 'MATIC'],
#  ['USDC',
#   'STONK',
#   '318.53',
#   '297.59',
#   'https://gameswap.netlify.app/',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://gameswap.netlify.app/', 'MATIC'],
#  ['WMATIC', '', '267.03', '30.43', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['WBTC', '', '216.75', '18.75', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['WETH', '', '12.39', '1312.29', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['QUICK', '', '34.38', '543.62', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['YLD', '', '3.69', '1102.65', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['USDT', '', '86.52', '140.89', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['USDC', '', '1548.06', '7.87', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['STONK', '', '137.55', '177.24', 'https://gameswap.netlify.app/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://gameswap.netlify.app/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://gameswap.netlify.app/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://gameswap.netlify.app/', 'MATIC'],
#  ['AURORA',
#   'USDC',
#   '40397.95',
#   '287.59',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['AURORA',
#   '',
#   '36883.78',
#   '156.95',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['WMATIC',
#   '',
#   '199883.94',
#   '23.17',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['WBTC', '', '153002.86', '7.57', 'https://www.blackswap.finance', 'MATIC'],
#  ['WETH', '', '222236.90', '20.84', 'https://www.blackswap.finance', 'MATIC'],
#  ['USDT', '', '127179.59', '27.31', 'https://www.blackswap.finance', 'MATIC'],
#  ['USDC', '', '109075.35', '31.84', 'https://www.blackswap.finance', 'MATIC'],
#  ['DAI', '', '200395.34', '11.56', 'https://www.blackswap.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.blackswap.finance', 'MATIC'],
#  ['AURORA',
#   'WMATIC',
#   '21277.35',
#   '332.01',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['AURORA',
#   'USDC',
#   '14808.57',
#   '476.45',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['USDC',
#   'NEBULA',
#   '11840.06',
#   '1031.64',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['IRON', '', '0.00', 0, 'https://www.blackswap.finance', 'MATIC'],
#  ['AURORA',
#   'WMATIC',
#   '9790.71',
#   '604.77',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['PolyZap-LP', '', '0.00', 0, 'https://www.blackswap.finance', 'MATIC'],
#  ['WMATIC',
#   'SOLAR',
#   '17831.36',
#   '516.82',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['SOLAR', '', '9216.99', '311.46', 'https://www.blackswap.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.blackswap.finance', 'MATIC'],
#  ['NEBULA', '', '2028.31', '566.12', 'https://www.blackswap.finance', 'MATIC'],
#  ['WMATIC', '', '87745.21', '19.63', 'https://www.blackswap.finance', 'MATIC'],
#  ['WBTC', '', '50911.92', '13.16', 'https://www.blackswap.finance', 'MATIC'],
#  ['WETH', '', '24219.27', '39.51', 'https://www.blackswap.finance', 'MATIC'],
#  ['USDT', '', '47106.21', '20.31', 'https://www.blackswap.finance', 'MATIC'],
#  ['USDC', '', '48506.23', '19.73', 'https://www.blackswap.finance', 'MATIC'],
#  ['DAI', '', '21043.92', '36.38', 'https://www.blackswap.finance', 'MATIC'],
#  ['WMATIC',
#   'SOLAR',
#   '7025.30',
#   '682.08',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['USDC',
#   'NEBULA',
#   '11840.06',
#   '667.00',
#   'https://www.blackswap.finance',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['PCAKE', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['WMATIC', '', '9264.49', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['WBTC', '', '7848.13', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['WETH', '', '2557.24', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['USDC', '', '6911.22', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['USDT', '', '2998.83', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['DAI', '', '11032.79', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['QUICK', '', '1010.51', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['LINK', '', '7506.93', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['AAVE', '', '2984.94', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['PolyMoon', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['ELK', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['miMATIC', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['gNFT', '', '0.00', 0, 'https://www.polycake.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['RANGER', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['WMATIC', '', '214.52', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['WETH', '', '112.67', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['WBTC', '', '39.29', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['QUICK', '', '82.72', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['LINK', '', '47.98', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['USDC', '', '215.49', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['AAVE', '', '32.72', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['FOX', '', '0.00', 0, 'https://polyrangers.finance', 'MATIC'],
#  ['WMATIC', 'WETH', '66307705.78', '22.84', 'https://app.sushi.com', 'MATIC'],
#  ['USDC', 'WETH', '82275925.57', '14.83', 'https://app.sushi.com', 'MATIC'],
# ...
#  ['USDC', 'ACORN', '158.45', '732.67', 'https://lumberjack.finance', 'MATIC'],
#  ['USDC', 'PPNK', '98.95', '1039.04', 'https://polypunk.finance', 'MATIC'],
#  ['WETH', '', '171.21', '117.92', 'https://polypunk.finance', 'MATIC'],
#  ['USDC', '', '817.63', '24.69', 'https://polypunk.finance', 'MATIC'],
#  ['QUICK', '', '40.44', '374.39', 'https://polypunk.finance', 'MATIC'],
#  ['WMATIC', '', '1119.25', '18.04', 'https://polypunk.finance', 'MATIC'],
#  ['DAI', '', '970.29', '15.61', 'https://polypunk.finance', 'MATIC'],
#  ['Steak', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['WMATIC',
#   'Steak',
#   '211.36',
#   '1316.25',
#   'https://steakhouse.finance',
#   'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['Lv1', '', '0.00', 0, 'https://steakhouse.finance', 'MATIC'],
#  ['MONKE',
#   'USDC',
#   '148.39',
#   '703.02',
#   'https://www.monkefarm.finance',
#   'MATIC'],
#  ['MONKE', '', '133.12', '198.57', 'https://www.monkefarm.finance', 'MATIC'],
#  ['WMATIC', '', '53.64', '246.41', 'https://www.monkefarm.finance', 'MATIC'],
#  ['WETH', '', '50.68', '521.62', 'https://www.monkefarm.finance', 'MATIC'],
#  ['WBTC', '', '24.10', '1096.99', 'https://www.monkefarm.finance', 'MATIC'],
#  ['USDC', '', '97.41', '271.35', 'https://www.monkefarm.finance', 'MATIC'],
#  ['USDT', '', '75.88', '348.34', 'https://www.monkefarm.finance', 'MATIC'],
#  ['QUICK', '', '14.95', '884.28', 'https://www.monkefarm.finance', 'MATIC'],
#  ['NAN', '', '0.00', 0, 'https://www.monkefarm.finance', 'MATIC'],
#  ['USDC', 'NAN', '119.40', '446.43', 'https://www.monkefarm.finance', 'MATIC'],
#  ['LION', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['WETH', '', '21453.24', 0, 'https://polylion.exchange', 'MATIC'],
#  ['USDC', '', '11079.30', 0, 'https://polylion.exchange', 'MATIC'],
#  ['WMATIC', '', '24315.53', 0, 'https://polylion.exchange', 'MATIC'],
#  ['QUICK', '', '5677.95', 0, 'https://polylion.exchange', 'MATIC'],
#  ['USDT', '', '6286.49', 0, 'https://polylion.exchange', 'MATIC'],
#  ['WBTC', '', '12147.20', 0, 'https://polylion.exchange', 'MATIC'],
#  ['DAI', '', '5240.91', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['USDC', 'QUICK', '8352537.21', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polylion.exchange', 'MATIC'],
#  ['AAVE', '', '2450.57', 0, 'https://polylion.exchange', 'MATIC'],
#  ['LINK', '', '6810.39', 0, 'https://polylion.exchange', 'MATIC'],
#  ['PolyDoge', '', '13835.15', 0, 'https://polylion.exchange', 'MATIC'],
#  ['SUSHI', '', '4783.92', 0, 'https://polylion.exchange', 'MATIC'],
#  ['DAI', 'USDT', '12879678.63', 0, 'https://polylion.exchange', 'MATIC'],
#  ['BULL', 'USDC', '7200.37', '1223.95', 'https://polybull.finance', 'MATIC'],
#  ['WBTC', '', '11525.87', '69.02', 'https://polybull.finance', 'MATIC'],
#  ['WETH', '', '1642.63', '484.33', 'https://polybull.finance', 'MATIC'],
#  ['QUICK', '', '3567.76', '222.99', 'https://polybull.finance', 'MATIC'],
#  ['WMATIC', '', '55546.87', '40.10', 'https://polybull.finance', 'MATIC'],
#  ['USDC', '', '8275.56', '96.14', 'https://polybull.finance', 'MATIC'],
#  ['USDT', '', '3541.63', '224.63', 'https://polybull.finance', 'MATIC'],
#  ['DAI', '', '11796.62', '67.44', 'https://polybull.finance', 'MATIC'],
#  ['BULL', '', '7027.09', '452.86', 'https://polybull.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybull.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybull.finance', 'MATIC'],
#  ['WMATIC', 'BULL', '4570.47', '1955.40', 'https://polybull.finance', 'MATIC'],
#  ['BULL', 'QUICK', '1965.58', '1622.12', 'https://polybull.finance', 'MATIC'],
#  ['WMATIC',
#   'ORCA',
#   '1224.85',
#   '249.78',
#   'https://www.orcinuslabs.ca',
#   'MATIC'],
#  ['USDC', 'ORCA', '1315.84', '231.30', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['USDT', 'ORCA', '1033.96', '308.30', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['ORCA', '', '3181.44', '90.62', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['USDC', '', '1302.77', '55.33', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['WMATIC', '', '845.73', '85.23', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['USDT', '', '3809.85', '13.24', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['WBTC', '', '1875.44', '38.43', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['WETH', '', '868.13', '83.03', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['SUSHI', '', '757.90', '114.12', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['LINK', '', '1289.22', '67.09', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['AAVE', '', '1557.07', '55.55', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['FISH', '', '0.00', 0, 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['Krill', '', '168.15', '514.37', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['ZERO', 'ORCA', '276.45', '1076.48', 'https://www.orcinuslabs.ca', 'MATIC'],
#  ['APE',
#   'USDC',
#   '24.34',
#   '4889.64',
#   'https://www.polyapefinance.com',
#   'MATIC'],
#  ['WMATIC',
#   '',
#   '0.00',
#   '456621706.12',
#   'https://www.polyapefinance.com',
#   'MATIC'],
#  ['WETH', '', '0.00', 0, 'https://www.polyapefinance.com', 'MATIC'],
#  ['APE', '', '10.87', '648.58', 'https://www.polyapefinance.com', 'MATIC'],
#  ['WBTC', '', '0.00', 0, 'https://www.polyapefinance.com', 'MATIC'],
#  ['USDT', '', '10.56', '166.95', 'https://www.polyapefinance.com', 'MATIC'],
#  ['QUICK', '', '0.00', 0, 'https://www.polyapefinance.com', 'MATIC'],
#  ['USDC', '', '19.74', '89.30', 'https://www.polyapefinance.com', 'MATIC'],
#  ['DAI', '', '0.96', '1836.41', 'https://www.polyapefinance.com', 'MATIC'],
#  ['WMATIC', '', '411.30', '171.42', 'https://polywolf.finance', 'MATIC'],
#  ['WBTC', '', '104.62', '673.93', 'https://polywolf.finance', 'MATIC'],
#  ['WETH', '', '53.22', '1324.77', 'https://polywolf.finance', 'MATIC'],
#  ['USDT', '', '995.18', '70.85', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', '', '821.48', '85.83', 'https://polywolf.finance', 'MATIC'],
#  ['DAI', '', '1149.64', '61.33', 'https://polywolf.finance', 'MATIC'],
#  ['AAVE', '', '1087.81', '12.96', 'https://polywolf.finance', 'MATIC'],
#  ['QUICK', '', '473.49', '29.78', 'https://polywolf.finance', 'MATIC'],
#  ['Krill', '', '166.27', '84.81', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'WOLF', '1474.46', '1820.80', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'WOLF', '813.32', '1960.23', 'https://polywolf.finance', 'MATIC'],
#  ['WBTC', 'WOLF', '189.05', '1879.59', 'https://polywolf.finance', 'MATIC'],
#  ['WETH', 'WOLF', '225.60', '1581.23', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'USDC', '17781.58', '35.69', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'WETH', '13339.64', '31.72', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'QUICK', '1242.36', '57.10', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'DAI', '20700.13', '7.35', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'USDT', '2050.08', '221.28', 'https://polywolf.finance', 'MATIC'],
#  ['SUSHI', 'WETH', '2831.91', '50.03', 'https://polywolf.finance', 'MATIC'],
#  ['SUSHI', 'USDC', '1550.42', '136.43', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'WETH', '1543.44', '138.60', 'https://polywolf.finance', 'MATIC'],
#  ['WETH', 'USDT', '1979.36', '343.90', 'https://polywolf.finance', 'MATIC'],
#  ['WMATIC', 'WBTC', '1086.03', '194.76', 'https://polywolf.finance', 'MATIC'],
#  ['WOLF', '', '3302.63', '256.17', 'https://polywolf.finance', 'MATIC'],
#  ['USDC', 'STACK', '88119.52', '132.38', 'https://stacker.vc', 'MATIC'],
#  ['USDC', 'Goat', '16.79', '1638.61', 'https://www.polygoat.finance', 'MATIC'],
#  ['WMATIC',
#   'Goat',
#   '12.41',
#   '3320.67',
#   'https://www.polygoat.finance',
#   'MATIC'],
#  ['Goat', '', '76.58', '422.65', 'https://www.polygoat.finance', 'MATIC'],
#  ['WMATIC', '', '994.76', '21.69', 'https://www.polygoat.finance', 'MATIC'],
#  ['QUICK', '', '30.98', '348.27', 'https://www.polygoat.finance', 'MATIC'],
#  ['WETH', '', '19.43', '555.20', 'https://www.polygoat.finance', 'MATIC'],
#  ['WBTC', '', '9.47', '1139.80', 'https://www.polygoat.finance', 'MATIC'],
#  ['USDT', '', '39.04', '276.35', 'https://www.polygoat.finance', 'MATIC'],
#  ['AAVE', '', '46.39', '232.58', 'https://www.polygoat.finance', 'MATIC'],
#  ['LINK', '', '18.66', '578.26', 'https://www.polygoat.finance', 'MATIC'],
#  ['Krill', '', '1.36', '7919.80', 'https://www.polygoat.finance', 'MATIC'],
#  ['Snake', '', '0.00', 0, 'https://www.polysnake.finance', 'MATIC'],
#  ['WETH', '', '6.64', '104.67', 'https://www.polysnake.finance', 'MATIC'],
#  ['WBTC', '', '18.29', '25.34', 'https://www.polysnake.finance', 'MATIC'],
#  ['WMATIC', '', '46.30', '10.01', 'https://www.polysnake.finance', 'MATIC'],
#  ['USDC',
#   'Snake',
#   '10.62',
#   '335.68',
#   'https://www.polysnake.finance',
#   'MATIC'],
#  ['USDT', '', '0.00', 0, 'https://www.polysnake.finance', 'MATIC'],
#  ['QUICK', '', '0.00', 0, 'https://www.polysnake.finance', 'MATIC'],
#  ['USDT', '', '22.41', '20.68', 'https://www.polysnake.finance', 'MATIC'],
#  ['Krill', '', '0.52', '892.74', 'https://www.polysnake.finance', 'MATIC'],
#  ['DAI', '', '6.45', '71.88', 'https://www.polysnake.finance', 'MATIC'],
#  ['WOLF', '', '633565.59', '153.24', 'https://www.moonwolf.io', 'MATIC'],
#  ['MOON', '', '87152.37', '101.28', 'https://www.moonwolf.io', 'MATIC'],
#  ['USDC', 'MOON', '113077.01', '197.13', 'https://www.moonwolf.io', 'MATIC'],
#  ['USDC', 'WOLF', '148338.79', '284.39', 'https://www.moonwolf.io', 'MATIC'],
#  ['LINK', '', '37548.12', '62.68', 'https://www.moonwolf.io', 'MATIC'],
#  ['AAVE', '', '6550.72', '269.48', 'https://www.moonwolf.io', 'MATIC'],
#  ['CEL', '', '0.00', 0, 'https://www.moonwolf.io', 'MATIC'],
#  ['USDC', 'WOLF', '99116.71', '218.78', 'https://www.moonwolf.io', 'MATIC'],
#  ['WMATIC',
#   'TITAN',
#   '21309.25',
#   '0.09',
#   'https://polygon.iron.finance',
#   'MATIC'],
#  ['USDC',
#   'IRON',
#   '910628.03',
#   '0.01',
#   'https://polygon.iron.finance',
#   'MATIC'],
#  ['USDC',
#   'IRON',
#   '525773.02',
#   '0.01',
#   'https://polygon.iron.finance',
#   'MATIC'],
#  ['TITAN', 'IRON', '2307.06', '0.62', 'https://polygon.iron.finance', 'MATIC'],
#  ['TITAN', '', '78892.24', '0.00', 'https://polygon.iron.finance', 'MATIC'],
#  ['WMATIC',
#   'ALCH',
#   '2800.49',
#   '350.31',
#   'https://polygon.alchemydao.com',
#   'MATIC'],
#  ['ALCH', '', '730.73', '0.00', 'https://polygon.alchemydao.com', 'MATIC'],
#  ['WMATIC', 'CRAB', '205.20', '0.00', 'https://polycrab.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['USDC', 'QUICK', '8351039.33', 0, 'https://polycrab.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['USDC', 'DAI', '54640249.29', '0.00', 'https://polycrab.finance', 'MATIC'],
#  ['USDC', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['USDT', '', '1.63', '0.00', 'https://polycrab.finance', 'MATIC'],
#  ['AAVE', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['QUICK', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['miFARM', '', '0.00', 0, 'https://polycrab.finance', 'MATIC'],
#  ['DAI', '', '23.47', '0.00', 'https://polycrab.finance', 'MATIC'],
#  ['USDC', 'BEAR', '523.14', '95.22', 'https://polybear.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybear.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybear.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybear.exchange', 'MATIC'],
#  ['BEAR', '', '201.22', '112.01', 'https://polybear.exchange', 'MATIC'],
#  ['WETH', '', '2978.02', '1.89', 'https://polybear.exchange', 'MATIC'],
#  ['DAI', '', '537.60', '10.48', 'https://polybear.exchange', 'MATIC'],
#  ['AAVE', '', '66.71', '84.47', 'https://polybear.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybear.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybear.exchange', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybear.exchange', 'MATIC'],
#  ['USDC', 'QUICK', '8351039.33', '7.99', 'https://polybear.exchange', 'MATIC'],
#  ['USDC',
#   'DAI',
#   '54640249.29',
#   '150.72',
#   'https://polybear.exchange',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://polybear.exchange', 'MATIC'],
#  ['WMATIC', '', '894.92', '9.44', 'https://polybear.exchange', 'MATIC'],
#  ['QUICK', '', '270.40', '20.84', 'https://polybear.exchange', 'MATIC'],
#  ['USDC', 'STONKX', '154.40', '886.80', 'https://stonk.farm/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://stonk.farm/', 'MATIC'],
#  ['WMATIC', '', '26.28', '481.45', 'https://stonk.farm/', 'MATIC'],
#  ['WBTC', '', '2258.17', '11.21', 'https://stonk.farm/', 'MATIC'],
#  ['WETH', '', '949.87', '26.64', 'https://stonk.farm/', 'MATIC'],
#  ['QUICK', '', '221.26', '131.51', 'https://stonk.farm/', 'MATIC'],
#  ['YLD', '', '884.03', '7.16', 'https://stonk.farm/', 'MATIC'],
#  ['USDT', '', '210.96', '89.96', 'https://stonk.farm/', 'MATIC'],
#  ['USDC', '', '220.70', '85.99', 'https://stonk.farm/', 'MATIC'],
#  ['STONKX', '', '153.47', '412.17', 'https://stonk.farm/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://stonk.farm/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://stonk.farm/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://stonk.farm/', 'MATIC'],
#  ['WMATIC', 'STONKX', '145.16', '917.52', 'https://stonk.farm/', 'MATIC'],
#  ['FISH', '', '0.00', 0, 'https://stonk.farm/', 'MATIC'],
#  ['IRON', '', '0.00', 0, 'https://stonk.farm/', 'MATIC'],
#  ['PolyDoge', '', '280.33', '45.13', 'https://stonk.farm/', 'MATIC'],
#  ['PLX', '', '22849.62', '0.00', 'https://polydex.fi', 'MATIC'],
#  ['PLX', 'WETH', '10423.36', '0.00', 'https://polydex.fi', 'MATIC'],
#  ['WMATIC', 'WETH', '322.09', '0.00', 'https://polydex.fi', 'MATIC'],
#  ['WBTC', 'WETH', '347.92', '0.00', 'https://polydex.fi', 'MATIC'],
#  ['USDC', 'USDT', '2827.26', '0.00', 'https://polydex.fi', 'MATIC'],
#  ['WETH', 'USDT', '168.38', '0.00', 'https://polydex.fi', 'MATIC'],
#  ['POLY-LP', '', '0.00', 0, 'https://polydex.fi', 'MATIC'],
#  ['WMATIC', 'PLX', '4259.33', '0.00', 'https://polydex.fi', 'MATIC'],
#  ['USDC', 'SDS', '134363.01', '0.00', 'https://polydex.fi', 'MATIC'],
#  ['MAPLE', '', '23807.13', '456.09', 'https://www.polymaple.com/', 'MATIC'],
#  ['USDC', '', '40827.54', '88.65', 'https://www.polymaple.com/', 'MATIC'],
#  ['WMATIC', '', '47273.96', '76.56', 'https://www.polymaple.com/', 'MATIC'],
#  ['WETH', '', '35052.14', '103.26', 'https://www.polymaple.com/', 'MATIC'],
#  ['WBTC', '', '23586.00', '153.45', 'https://www.polymaple.com/', 'MATIC'],
#  ['WMATIC',
#   'MAPLE',
#   '36495.81',
#   '802.62',
#   'https://www.polymaple.com/',
#   'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polymaple.com/', 'MATIC'],
#  ['UNI-V2', '', '0.00', 0, 'https://www.polymaple.com/', 'MATIC'],
#  ['Listing',
#   '',
#   '261937.40',
#   '216.33',
#   'https://gravityfinance.io/app/#farms',
#   'MATIC'],
#  ...]

# %%
pair_df = pair_df.drop(pair_df[pair_df['pair1'] == ''].index)

# %%
pair_df[pair_df['pair1'] == '']
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, tvl, apr, where, network, apy]
# Index: []

# %%
pair_df[pair_df['network'] == 'Alternate']['network'] = 'ETH'

# %%
sheet_pairs_df = pd.DataFrame([])
eth_sheet_pairs_df = pd.read_csv('Alternate.csv')
# eth_sheet_pairs_df.columns=['pair1', 'pair2', 'tvl', 'where', 'apr']
eth_sheet_pairs_df['apy'] = np.nan
eth_sheet_pairs_df['network'] = 'ETH'
sheet_pairs_df = sheet_pairs_df.append(eth_sheet_pairs_df)
sheet_pairs_df['pair2'] = sheet_pairs_df['pair2'].fillna('')

# %%
sheet_pairs_df
# Out:
#        pair1 pair2           tvl  where    qpr network  apy
# 0       WETH  USDT  2.561025e+08  SUSHI  12.77     ETH  NaN
# 1       USDC  WETH  3.524253e+08  SUSHI  11.60     ETH  NaN
# 2        DAI  WETH  2.129356e+08  SUSHI  17.03     ETH  NaN
# 3       sUSD  WETH  9.492397e+06  SUSHI  18.06     ETH  NaN
# 4       COMP  WETH  2.215105e+07  SUSHI   8.81     ETH  NaN
# ..       ...   ...           ...    ...    ...     ...  ...
# 200     BOND  WETH  1.098984e+05  SUSHI  59.99     ETH  NaN
# 201  bb_cDAI   DAI  1.853689e+05  SUSHI  35.57     ETH  NaN
# 202     WETH  FOLD  1.983405e+05  SUSHI  33.24     ETH  NaN
# 203      NDX  WETH  1.819949e+05  SUSHI  36.23     ETH  NaN
# 204    DEGEN  WETH  1.633722e+05  SUSHI  40.36     ETH  NaN
#
# [205 rows x 7 columns]

# %%
def update_apr(apr):
    apr = f"{apr}".replace("%", "")
    if len(apr) == 0 or "nan" == apr:
        return np.nan
    else:
        return apr

# %%
def get_symbol_mapping(pair):
    if pair is not None:
        return sm[pair.strip()] if pair.strip() in sm else pair.strip()
    else:
        return ""

# %%
pair_df = pair_df.append(sheet_pairs_df).reset_index(drop=True)
pair_df['type_of_agriculture'] = 'FARM'
pair_df = pair_df.append(df).reset_index(drop=True)

# %%
pair_df['apr'] = pair_df['apr'].apply(lambda x: update_apr(x))
pair_df['pair1'] = pair_df['pair1'].apply(lambda x: sm[x.strip()] if x.strip() in sm else x.strip())
pair_df['pair2'] = pair_df['pair2'].apply(lambda x: get_symbol_mapping(x))

# %%
pair_df['pair2'].unique()
# Out:
# array(['ETH', 'AVAX', 'LINK', ..., 'POLS', '89SA', 'OHM'], dtype=object)

# %%
pair_df
# Out:
#      pair1 pair2          tvl            apr  \
# 0     AVAX   ETH  46841802.37          14.74
# 1      BTC  AVAX   9766912.08          44.25
# 2     AVAX  LINK  10475554.12          13.04
# 3      PNG  AVAX  45373170.50         130.55
# 4     AVAX  USDT   3783645.05          13.32
# ...    ...   ...          ...            ...
# 9762   ETH  0xMR     4.643715     3.61462812
# 9763   ETH   CHZ    43.953063      9.1260504
# 9764   ETH  POLS  4576.782058     5.57622636
# 9765   ETH  89SA     3.998762     5.15366652
# 9766   ETH   OHM     4.764878  1982.39031264
#
#                                     where network  apy  qpr  \
# 0     https://app.pangolin.exchange/#/png    AVAX  NaN  NaN
# 1     https://app.pangolin.exchange/#/png    AVAX  NaN  NaN
# 2     https://app.pangolin.exchange/#/png    AVAX  NaN  NaN
# 3     https://app.pangolin.exchange/#/png    AVAX  NaN  NaN
# 4     https://app.pangolin.exchange/#/png    AVAX  NaN  NaN
# ...                                   ...     ...  ...  ...
# 9762                              Uniswap     ETH  NaN  NaN
# 9763                              Uniswap     ETH  NaN  NaN
# 9764                              Uniswap     ETH  NaN  NaN
# 9765                                Sushi     ETH  NaN  NaN
# 9766                                Sushi     ETH  NaN  NaN
#
#      type_of_agriculture
# 0                   FARM
# 1                   FARM
# 2                   FARM
# 3                   FARM
# 4                   FARM
# ...                  ...
# 9762                POOL
# 9763                POOL
# 9764                POOL
# 9765                POOL
# 9766                POOL
#
# [9767 rows x 9 columns]

# %%
# pair_df['apr'].unique().tolist()

# %%
def convert_apr_to_apy(pair_df):
    tmp_df = pair_df[pair_df['apy'].isna()]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apr = row['apr']
        if pd.isnull( apr):
            return
        if apr is not None and len(apr.strip()):
            apr = float(apr.replace(',',''))
        else:
            apr = 0
        try:
            pair_df.loc[index, 'apy'] = ((1+(apr/100)/365)**365-1)*100
        except:
            pair_df.loc[index, 'apy'] = np.nan
    return
            
def convert_apy_to_apr(pair_df):
    tmp_df = pair_df[(pair_df['apr'].isnull())]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apy = row['apy']
        if pd.isnull( apy):
            return
        if apy is not None and len(apy.strip()):
            apy = float(apy.replace(',',''))
        else:
            apy = 0
        try:
            pair_df.loc[index, 'apr'] = (((1+(apy/100))**(1/365)-1)*365)*100
        except:
            pair_df.loc[index, 'apr'] = np.nan
    return


convert_apr_to_apy(pair_df)
convert_apy_to_apr(pair_df)
# Out:
# (9767, 9)
# (205, 9)

# %%
pair_df[pair_df['apy'].isna()]
# Out:
#        pair1   pair2          tvl            apr  \
# 864   WMATIC                 0.00   456621706.12
# 1136    USDC  POLLEN        11.41     4316709.81
# 1138  WMATIC                 0.00  8896293631.46
# 1142    USDC                 0.00  1627730583.13
# 1812    USDC     RDT    104168.73     4458828.10
# ...      ...     ...          ...            ...
# 9762     ETH    0xMR     4.643715     3.61462812
# 9763     ETH     CHZ    43.953063      9.1260504
# 9764     ETH    POLS  4576.782058     5.57622636
# 9765     ETH    89SA     3.998762     5.15366652
# 9766     ETH     OHM     4.764878  1982.39031264
#
#                                where network  apy  qpr type_of_agriculture
# 864   https://www.polyapefinance.com   MATIC  NaN  NaN                FARM
# 1136   https://polybutterfly.finance   MATIC  NaN  NaN                FARM
# 1138   https://polybutterfly.finance   MATIC  NaN  NaN                FARM
# 1142   https://polybutterfly.finance   MATIC  NaN  NaN                FARM
# 1812         https://rediant.finance   MATIC  NaN  NaN                FARM
# ...                              ...     ...  ...  ...                 ...
# 9762                         Uniswap     ETH  NaN  NaN                POOL
# 9763                         Uniswap     ETH  NaN  NaN                POOL
# 9764                         Uniswap     ETH  NaN  NaN                POOL
# 9765                           Sushi     ETH  NaN  NaN                POOL
# 9766                           Sushi     ETH  NaN  NaN                POOL
#
# [1850 rows x 9 columns]

# %%
pair_df[pair_df['apr'].isna()]
# Out:
#         pair1 pair2          tvl  apr  where network  apy    qpr  \
# 8014      ETH  USDT  256102490.5  NaN  SUSHI     ETH  NaN  12.77
# 8015     USDC   ETH  352425256.3  NaN  SUSHI     ETH  NaN  11.60
# 8016      DAI   ETH  212935570.6  NaN  SUSHI     ETH  NaN  17.03
# 8017     sUSD   ETH   9492397.29  NaN  SUSHI     ETH  NaN  18.06
# 8018     COMP   ETH  22151051.62  NaN  SUSHI     ETH  NaN   8.81
# ...       ...   ...          ...  ...    ...     ...  ...    ...
# 8214     BOND   ETH    109898.41  NaN  SUSHI     ETH  NaN  59.99
# 8215  bb_cDAI   DAI    185368.94  NaN  SUSHI     ETH  NaN  35.57
# 8216      ETH  FOLD    198340.45  NaN  SUSHI     ETH  NaN  33.24
# 8217      NDX   ETH    181994.87  NaN  SUSHI     ETH  NaN  36.23
# 8218    DEGEN   ETH    163372.24  NaN  SUSHI     ETH  NaN  40.36
#
#      type_of_agriculture
# 8014                FARM
# 8015                FARM
# 8016                FARM
# 8017                FARM
# 8018                FARM
# ...                  ...
# 8214                FARM
# 8215                FARM
# 8216                FARM
# 8217                FARM
# 8218                FARM
#
# [205 rows x 9 columns]

# %%
pair_df = pair_df.drop_duplicates()

# %%
single_piar_df = pair_df[pair_df['pair2'] == ""].copy()
double_coin_pair_df = pair_df[pair_df['pair2'] != ""].copy()
tmp_df = double_coin_pair_df.copy()

# %%
single_piar_df
# Out:
#                 pair1 pair2        tvl        apr  \
# 46         sBAMBOO-V2             0.00          0
# 59               BURN             0.00          0
# 85              OLIVE         88583.54      77.73
# 99               AVAX           822.35     167.47
# 101               BAG        168593.07      72.19
# ...               ...   ...        ...        ...
# 8040           REDUCE              0.0        NaN
# 8075      SAFFRONCHEF              0.0        NaN
# 8191  MASTERCHEFDUMMY              0.0        NaN
# 8707               Xi              0.0        0.0
# 8779             RUNE         2.290009  0.3244302
#
#                               where network         apy  qpr  \
# 46       https://pandaswap.exchange    AVAX    0.000000  NaN
# 59       https://pandaswap.exchange    AVAX    0.000000  NaN
# 85          https://avax.olive.cash    AVAX  117.379287  NaN
# 99          https://avax.olive.cash    AVAX  431.679015  NaN
# 101   https://app.baguette.exchange    AVAX  105.687337  NaN
# ...                             ...     ...         ...  ...
# 8040                          SUSHI     ETH         NaN  NaN
# 8075                          SUSHI     ETH         NaN  NaN
# 8191                          SUSHI     ETH         NaN  NaN
# 8707                          Sushi     ETH         NaN  NaN
# 8779                          Sushi     ETH         NaN  NaN
#
#      type_of_agriculture
# 46                  FARM
# 59                  FARM
# 85                  FARM
# 99                  FARM
# 101                 FARM
# ...                  ...
# 8040                FARM
# 8075                FARM
# 8191                FARM
# 8707                POOL
# 8779                POOL
#
# [2825 rows x 9 columns]

# %%
double_coin_pair_df
# Out:
#      pair1 pair2          tvl            apr  \
# 0     AVAX   ETH  46841802.37          14.74
# 1      BTC  AVAX   9766912.08          44.25
# 2     AVAX  LINK  10475554.12          13.04
# 3      PNG  AVAX  45373170.50         130.55
# 4     AVAX  USDT   3783645.05          13.32
# ...    ...   ...          ...            ...
# 9762   ETH  0xMR     4.643715     3.61462812
# 9763   ETH   CHZ    43.953063      9.1260504
# 9764   ETH  POLS  4576.782058     5.57622636
# 9765   ETH  89SA     3.998762     5.15366652
# 9766   ETH   OHM     4.764878  1982.39031264
#
#                                     where network         apy  qpr  \
# 0     https://app.pangolin.exchange/#/png    AVAX   15.878292  NaN
# 1     https://app.pangolin.exchange/#/png    AVAX   55.617671  NaN
# 2     https://app.pangolin.exchange/#/png    AVAX   13.925747  NaN
# 3     https://app.pangolin.exchange/#/png    AVAX  268.094993  NaN
# 4     https://app.pangolin.exchange/#/png    AVAX   14.245071  NaN
# ...                                   ...     ...         ...  ...
# 9762                              Uniswap     ETH         NaN  NaN
# 9763                              Uniswap     ETH         NaN  NaN
# 9764                              Uniswap     ETH         NaN  NaN
# 9765                                Sushi     ETH         NaN  NaN
# 9766                                Sushi     ETH         NaN  NaN
#
#      type_of_agriculture
# 0                   FARM
# 1                   FARM
# 2                   FARM
# 3                   FARM
# 4                   FARM
# ...                  ...
# 9762                POOL
# 9763                POOL
# 9764                POOL
# 9765                POOL
# 9766                POOL
#
# [6678 rows x 9 columns]

# %%
tmp_df
# Out:
#      pair1 pair2          tvl            apr  \
# 0     AVAX   ETH  46841802.37          14.74
# 1      BTC  AVAX   9766912.08          44.25
# 2     AVAX  LINK  10475554.12          13.04
# 3      PNG  AVAX  45373170.50         130.55
# 4     AVAX  USDT   3783645.05          13.32
# ...    ...   ...          ...            ...
# 9762   ETH  0xMR     4.643715     3.61462812
# 9763   ETH   CHZ    43.953063      9.1260504
# 9764   ETH  POLS  4576.782058     5.57622636
# 9765   ETH  89SA     3.998762     5.15366652
# 9766   ETH   OHM     4.764878  1982.39031264
#
#                                     where network         apy  qpr  \
# 0     https://app.pangolin.exchange/#/png    AVAX   15.878292  NaN
# 1     https://app.pangolin.exchange/#/png    AVAX   55.617671  NaN
# 2     https://app.pangolin.exchange/#/png    AVAX   13.925747  NaN
# 3     https://app.pangolin.exchange/#/png    AVAX  268.094993  NaN
# 4     https://app.pangolin.exchange/#/png    AVAX   14.245071  NaN
# ...                                   ...     ...         ...  ...
# 9762                              Uniswap     ETH         NaN  NaN
# 9763                              Uniswap     ETH         NaN  NaN
# 9764                              Uniswap     ETH         NaN  NaN
# 9765                                Sushi     ETH         NaN  NaN
# 9766                                Sushi     ETH         NaN  NaN
#
#      type_of_agriculture
# 0                   FARM
# 1                   FARM
# 2                   FARM
# 3                   FARM
# 4                   FARM
# ...                  ...
# 9762                POOL
# 9763                POOL
# 9764                POOL
# 9765                POOL
# 9766                POOL
#
# [6678 rows x 9 columns]

# %%
tmp_df['tmp'] = tmp_df['pair1']
tmp_df['pair1'] = tmp_df['pair2']
tmp_df['pair2'] = tmp_df['tmp']
del tmp_df['tmp']

# %%
double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
# Out:
#         pair1 pair2         tvl          apr  \
# 0               sil         0.0          0.0
# 1      $BASED   ETH   12.357646  11.29263312
# 2      $BASED  SUSD   15.617854   5.28389172
# 3         $DG   BNB  1763242.43       221.00
# 4         $DG   ETH   575396.91        83.81
# ...       ...   ...         ...          ...
# 13351    zLOT   ETH   19.928978   1.21804908
# 13352  zSUSHI  ZERO    29324.30         0.00
# 13353    zUNI  ZERO    10661.79         0.00
# 13354   zUSDC  ZERO    22295.57         0.00
# 13355   zUSDT  ZERO    40639.52         0.00
#
#                                     where network         apy  qpr  \
# 0                                   Sushi     ETH         NaN  NaN
# 1                                 Uniswap     ETH         NaN  NaN
# 2                                 Uniswap     ETH         NaN  NaN
# 3             https://pancakeswap.finance     BSC  805.517427  NaN
# 4      https://quickswap.exchange/#/quick   MATIC  130.974993  NaN
# ...                                   ...     ...         ...  ...
# 13351                               Sushi     ETH         NaN  NaN
# 13352              https://app.0.exchange    AVAX    0.000000  NaN
# 13353              https://app.0.exchange    AVAX    0.000000  NaN
# 13354              https://app.0.exchange    AVAX    0.000000  NaN
# 13355              https://app.0.exchange    AVAX    0.000000  NaN
#
#       type_of_agriculture
# 0                    POOL
# 1                    POOL
# 2                    POOL
# 3                    FARM
# 4                    FARM
# ...                   ...
# 13351                POOL
# 13352                FARM
# 13353                FARM
# 13354                FARM
# 13355                FARM
#
# [13356 rows x 9 columns]

# %%
summary = {
    "total_pairs": pair_df.shape[0],
"single_coin_pairs": single_piar_df.shape[0],
"double_coin_piars": double_coin_pair_df.shape[0],
"after_switching_coins_total_double_coin_pairs": double_coin_pair_df.shape[0] * 2,
"total_pairs_in_sheet": double_coin_pair_df.shape[0] * 2 + single_piar_df.shape[0]
}

# %%
summary
# Out:
# {'total_pairs': 9503,
#  'single_coin_pairs': 2825,
#  'double_coin_piars': 6678,
#  'after_switching_coins_total_double_coin_pairs': 13356,
#  'total_pairs_in_sheet': 16181}

# %%
pair_df = double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
pair_df = single_piar_df.append(pair_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)

# %%
pair_df
# Out:
#           pair1 pair2         tvl          apr  \
# 0                 sil         0.0          0.0
# 1        $BASED   ETH   12.357646  11.29263312
# 2        $BASED  SUSD   15.617854   5.28389172
# 3           $DG   BNB  1763242.43       221.00
# 4           $DG   ETH   575396.91        83.81
# ...         ...   ...         ...          ...
# 16176  zs-XUSD2              0.00            0
# 16177  zs-tsBTC              0.00            0
# 16178      τBTC            131.17       258.49
# 16179         🌾          49549.51     26108.80
# 16180         🚜          64997.36        19.14
#
#                                     where network           apy  qpr  \
# 0                                   Sushi     ETH           NaN  NaN
# 1                                 Uniswap     ETH           NaN  NaN
# 2                                 Uniswap     ETH           NaN  NaN
# 3             https://pancakeswap.finance     BSC  8.055174e+02  NaN
# 4      https://quickswap.exchange/#/quick   MATIC  1.309750e+02  NaN
# ...                                   ...     ...           ...  ...
# 16176  https://www.stabilize.finance/app/     ETH  0.000000e+00  NaN
# 16177  https://www.stabilize.finance/app/     ETH  0.000000e+00  NaN
# 16178          https://www.elixir-swap.io     BSC  1.214169e+03  NaN
# 16179               https://harvester.app     ETH  3.427821e+87  NaN
# 16180        https://www.honestwork.farm/   MATIC  2.108830e+01  NaN
#
#       type_of_agriculture
# 0                    POOL
# 1                    POOL
# 2                    POOL
# 3                    FARM
# 4                    FARM
# ...                   ...
# 16176                FARM
# 16177                FARM
# 16178                FARM
# 16179                FARM
# 16180                FARM
#
# [16181 rows x 9 columns]

# %%
pair_df['dex'] = pair_df['where']
pair_df['date'] = date 
del pair_df['where']

# %%
# pair_df.to_csv('yield_data_2021_06_21.csv')

# %%
pair_df['dex'].unique().tolist()
# Out:
# ['Sushi',
#  'Uniswap',
#  'https://pancakeswap.finance',
#  'https://quickswap.exchange/#/quick',
#  'https://strudel.finance',
#  'https://swap.cometh.io/#/stake',
#  'https://caramelswap.finance',
#  'https://absorber.finance',
#  'https://icecreamswap.finance',
#  'http://mangofarm.finance',
#  'https://brussels.worldswap.finance',
#  'https://berlin.worldswap.finance',
#  'https://1inch.exchange/#/dao/farming',
#  'SUSHI',
#  'https://www.convexfinance.com',
#  'https://app.swamp.finance',
#  'https://ellipsis.finance',
#  'https://app.firebird.finance',
#  'https://frozenyogurt.finance',
#  'https://nerve.fi',
#  'https://autofarm.network',
#  'https://beta.belt.fi',
#  'https://blue.planetfinance.io',
#  'https://glacierswap.org/farms/',
#  'https://8ballfinance.io',
#  'https://dollar.supra.finance',
#  'https://polycat.finance',
#  'https://harvester.app',
#  'https://polyvolve.finance',
#  'https://polygaj.finance',
#  'https://www.polycake.finance',
#  'https://polyrangers.finance',
#  'https://polyvalent.finance',
#  'https://polyfi.io',
#  'https://polylion.exchange',
#  'https://www.orcinuslabs.ca',
#  'https://polywolf.finance',
#  'https://www.polygoat.finance',
#  'https://www.moonwolf.io',
#  'https://polycrab.finance',
#  'https://polybear.exchange',
#  'https://www.smellycat.finance',
#  'https://polygold.finance',
#  'https://www.polyswan.finance',
#  'https://polypingu.finance',
#  'https://polygon.prismfinance.net',
#  'https://dinosaurfinance.vercel.app',
#  'https://polymouse.finance',
#  'https://www.polytiger.com/',
#  'https://polydeer.finance',
#  'https://avengers.exchange',
#  'https://polypup.finance',
#  'https://polygon.space-defi.com/',
#  'https://polysnow.farm',
#  'https://polycafe.finance',
#  'https://polycomet.com',
#  'https://bali.worldswap.finance',
#  'https://polycuban.finance',
#  'https://www.bigdataprotocol.com/datavault',
#  'https://dao.universe.xyz/yield-farming',
#  'https://klingftm.borgswap.exchange',
#  'https://app.pangolin.exchange/#/png',
#  'https://apeswap.finance',
#  'https://app.gametoken.finance',
#  'https://berserkfinance.com',
#  'https://app.elk.finance',
#  'https://app.wault.finance/polygon',
#  'https://polycrystal.finance',
#  'https://spookyswap.finance',
#  'https://frankenstein.finance',
#  'https://waka.finance',
#  'https://www.operaswap.finance',
#  'https://exchange.dfyn.network',
#  'https://www.liquiddriver.finance',
#  'https://farm.polyzap.finance',
#  'https://abrakadabra.tech',
#  'https://lumberjack.finance',
#  'https://app.acryptos.com',
#  'https://mdex.com',
#  'https://swipe.org/farm',
#  'https://iron.finance/',
#  'https://xwin.finance',
#  'https://www.goosedefi.com',
#  'http://slime.finance',
#  'https://koaladefi.finance/',
#  'https://brickchain.finance',
#  'https://app.hyruleswap.com',
#  'https://www.jiggly.finance',
#  'http://shitz.lol',
#  'https://mooncakeswap.finance',
#  'https://app.comos.finance/',
#  'https://farm.borgswap.exchange',
#  'https://bitblocks.finance',
#  'https://lokum.finance',
#  'https://limeswap.io',
#  'https://tapswap.finance',
#  'https://app.barbecueswapfinance.com',
#  'https://vanillacake.farm',
#  'https://garudaswap.finance',
#  'https://www.elixir-swap.io',
#  'https://www.grizzlyswap.com',
#  'https://gocerberus.finance',
#  'https://ketchupfinance.com',
#  'https://mayoswap.com',
#  'https://www.andromedadefi.com',
#  'https://thunderbird.finance/',
#  'https://www.venomswap.net',
#  'https://www.blacksheepdefi.com',
#  'https://krustykrab.finance',
#  'https://www.meatchfinance.com/',
#  'https://www.carnageswap.net',
#  'https://thoreum.finance',
#  'https://app.seedmoneyfinance.com',
#  'https://whalefarm.finance',
#  'https://fusionfinance.farm/',
#  'https://pandayield.com',
#  'https://pool.mochiswap.io',
#  'https://pumpy.farm',
#  'https://mouse.farm',
#  'https://thelab.finance',
#  'https://app.apache.finance/',
#  'https://farms.pandaswap.xyz',
#  'https://pantherswap.com',
#  'https://jaguarswap.com',
#  'https://zombie-farm.com',
#  'https://degentoken.finance',
#  'https://coinswap.space/',
#  'https://gatorswap.xyz',
#  'https://dumplingdefi.finance',
#  'https://satis.finance',
#  'https://dinopark.finance',
#  'https://ten.finance',
#  'https://biswap.org',
#  'https://antswap.fi',
#  'https://lavacake.finance',
#  'https://qiswap.finance',
#  'https://zeusfarmsdefi.com',
#  'https://www.faxe.farmwiki.xyz',
#  'https://www.halvar.farmwiki.xyz',
#  'https://tomahawk.farm/',
#  'https://supermanion.com',
#  'https://app.wault.finance',
#  'https://money-pocket.dollaremon.fi',
#  'https://kesef.finance',
#  'https://manyswap.io',
#  'https://mozartfinance.io',
#  'https://app.treedefi.com',
#  'https://www.unownswap.com',
#  'https://app.sushi.com',
#  'https://augury.finance',
#  'https://swap.smartdex.app',
#  'https://dogen.finance',
#  'https://gamestop.finance',
#  'https://polygon.alchemydao.com',
#  'https://alchemydao.com',
#  'https://app.alchemix.fi/farms',
#  'https://pickle.finance/farms',
#  'Raydium',
#  'https://aliendefi.com',
#  'https://app.vlad.finance',
#  'https://farm.hyperjump.fi',
#  'https://app.sponge.finance',
#  'https://apoyield.com',
#  'https://aluna.social/farm',
#  'https://aloeswap.com',
#  'https://hyfi.pro',
#  'https://longdrink.finance',
#  'https://app.alpacafinance.org',
#  'hhttps://taco.finance/',
#  'https://alpha.parthenon.finance',
#  'https://antdefi.io',
#  'https://app.spiritswap.finance',
#  'https://www.polyapefinance.com',
#  'https://memefarm.io',
#  'https://www.polyape.online/',
#  'https://olive.cash/farms',
#  'https://farm.unicrypt.network',
#  'https://elk.finance',
#  'https://armor.fi',
#  'https://www.arthcoin.com',
#  'https://fanaticsfinance.com',
#  'https://cafeswap.finance',
#  'CHAD',
#  'https://www.blackswap.finance',
#  'https://ftm.borgswap.exchange',
#  'https://hyperjump.fi',
#  'https://www.alchemistdefi.com',
#  'https://bobadefi.com',
#  'https://toad.farm',
#  'https://fullsail.finance',
#  'https://muscle.finance',
#  'https://snek.farm',
#  'https://www.bakeryswap.org',
#  'https://squirrel.finance',
#  'https://tripswap.finance',
#  'https://www.coralfarm.finance/',
#  'https://avax.olive.cash',
#  'https://app.baguette.exchange',
#  'https://app.canary.exchange/',
#  'https://avme.io',
#  'https://pandaswap.exchange',
#  'https://birdy.finance',
#  'https://avax.complus.exchange',
#  'https://www.lydia.finance',
#  'https://bsc.complus.exchange',
#  'https://exchange.yetiswap.app',
#  'https://penguinfinance.org',
#  'https://app.gondola.finance',
#  'https://farm.avalaunch.app',
#  'https://app.0.exchange',
#  'https://b2xtoken.io/farm',
#  'https://harvest.finance/',
#  'https://basis.cash',
#  'https://app.thisistheway.finance/#/stake',
#  'https://bondappetit.io',
#  'https://cheesecakeswap.com',
#  'https://neonic.finance',
#  'https://www.ybearswap.finance',
#  'https://mars.cosmos.farm',
#  'https://www.mocktailswap.finance',
#  'https://percent.finance/',
#  'https://app.bami.money',
#  'https://polyyeld.finance',
#  'https://polyyield.finance',
#  'https://www.zexswap.finance',
#  'https://app.blueswap.finance',
#  'https://farmhero.io',
#  'https://yieldfields.finance',
#  'https://takodefi.com',
#  'https://bscrunner.com',
#  'https://floatprotocol.com/#/stake',
#  'https://basketdao.org',
#  'https://nft20.io',
#  'https://benswap.finance/',
#  'https://www.piedao.org',
#  'https://biscuitfarm.finance',
#  'https://carrotcake.fi',
#  'https://lazymint.finance',
#  'https://kimochi.finance',
#  'https://www.saltswap.finance/',
#  'https://pizzafinance.app',
#  'https://shrimpswap.finance',
#  'https://marmelade.finance',
#  'https://fulcrum.trade',
#  'https://julswap.com',
#  'https://www.wardenswap.finance',
#  'https://kebabfinance.com',
#  'https://veganswap.finance',
#  'https://sakeswap.finance',
#  'https://www.billhwangdefi.co',
#  'https://nu.parthenon.finance',
#  'https://blizzard.money',
#  'https://rediant.finance',
#  'https://donutdefi.com',
#  'https://app.polarisdefi.io',
#  'https://finance.zcore.network',
#  'https://farm.space',
#  'https://app.uranium.finance',
#  'https://dragonballfinance.org',
#  'https://marshmallowdefi.com',
#  'https://sojudefi.com',
#  'https://thefarmingden.com',
#  'https://thunderswap.finance',
#  'https://bourbondefi.com',
#  'https://app.pepr.finance',
#  'https://evodefi.com',
#  'https://dungeonswap.app',
#  'https://plumcake.finance',
#  'https://www.pulsar.farm',
#  'https://farms.tinville.finance',
#  'https://app.pancakefork.finance',
#  'https://bsc.prismfinance.net',
#  'https://app.tea-swap.finance/',
#  'https://werewolf.farm',
#  'https://siberianswap.finance',
#  'https://app.elephantswap.finance',
#  'https://mu.parthenon.finance',
#  'https://cottonfarm.app',
#  'https://www.bsc.space-defi.com',
#  'https://legofarming.club',
#  'https://www.frozencake.finance',
#  'https://app.rasta.finance',
#  'https://venus.cosmos.farm',
#  'https://tsuki.finance',
#  'https://berrydata.co/',
#  'https://yieldbay.finance',
#  'https://yumcha.finance',
#  'https://goatswap.finance',
#  'https://oni.exchange',
#  'https://pantyswap.yieldpanty.finance',
#  'https://ramenswap.finance',
#  'https://yieldnyan.com',
#  'https://app.stakd.finance',
#  'https://llamaswap.finance',
#  'https://jazzdefi.com',
#  'https://www.pureswap.finance',
#  'https://friction.finance',
#  'https://www.robinhoodswap.finance',
#  'https://cookiebake.finance',
#  'https://cdo.finance',
#  'http://djinn.gold',
#  'https://eggplant.fi',
#  'https://eleven.finance',
#  'https://app.feeder.finance',
#  'https://fishswap.app',
#  'https://fluity.finance',
#  'https://paintswap.finance',
#  'https://shadowswap.app',
#  'https://wheat.growthdefi.com',
#  'https://guessit.app',
#  'https://www.helmet.insure',
#  'https://popsicle.finance',
#  'https://www.knightsdefi.com',
#  'https://www.mythic.finance',
#  'https://mushrooms.finance',
#  'https://pearldefi.com',
#  'https://farms.polispay.org',
#  'https://privacyswap.finance',
#  'https://ricefarm.fi',
#  'https://bsc.sashimi.cool/',
#  'https://smoothy.finance',
#  'https://soups.finance',
#  'https://swirl.cash/mining',
#  'https://bsc.wasabix.finance/#/app/pool',
#  'https://farm.wsbdapp.com',
#  'https://farms.apwars.farm',
#  'https://www.polypulsar.farm',
#  'https://mushrooms.finance/farms',
#  'https://app.spoon.finance',
#  'https://piratedice.xyz',
#  'https://basis.gold',
#  'https://polyfox.finance',
#  'https://hawkdex.com',
#  'https://www.polystarter.fi',
#  'https://gameswap.netlify.app/',
#  'https://www.polyshark.finance',
#  'https://polypanda.finance',
#  'https://www.jurassicfarm.app',
#  'https://polyce.io',
#  'https://www.monkefarm.finance',
#  'https://polybull.finance',
#  'https://www.polysnake.finance',
#  'https://stonk.farm/',
#  'https://www.polymaple.com/',
#  'https://www.polyion.net',
#  'https://farms.goldenbull.finance',
#  'https://defi.polyakita.com',
#  'https://polybutterfly.finance',
#  'https://southpark.finance/',
#  'https://polycash.finance',
#  'https://www.glockswap.com',
#  'https://polyvertex.finance/farms',
#  'https://polymax.club',
#  'https://polywoof.finance',
#  'https://stonky.farm/',
#  'PolyMeme V2',
#  'https://carouselswap.com',
#  'https://stonkz.farm/',
#  'https://polymeryield.finance',
#  'https://app.sirenmarkets.com/stake',
#  'https://polydex.fi',
#  'https://klondike.finance',
#  'https://app.lift.kitchen',
#  'https://mordorswap.finance',
#  'https://ichi.farm/',
#  'https://bsc.farms.yogi.fi',
#  'https://app.compli.fi',
#  'https://docs.xbull.finance',
#  'https://bsc.lever.network/Staking',
#  'https://www.polycarrot.finance',
#  'https://v0.dfx.finance',
#  'https://yorocoon.com',
#  'https://indexed.finance',
#  'https://cntr.finance',
#  'https://convx.conv.finance',
#  'https://polygon.cosmicswap.finance',
#  'https://cvi.finance',
#  'https://app.cryptex.finance',
#  'https://cyclone.xyz/eth',
#  'https://polypunk.finance',
#  'https://www.polysa.finance',
#  'https://www.polyharvest.finance',
#  'https://www.rocketfarming.finance',
#  'https://fairyfarming.world/',
#  'https://debaseonomics.io/',
#  'https://www.stabilize.finance/app/',
#  'http://stake.kineko.io',
#  'https://morph.finance/',
#  'https://olympusdao.eth.link/',
#  'https://onecash.finance',
#  'https://www.proofofhumanity.id',
#  'https://slowpoke.space',
#  'https://www.honestwork.farm/',
#  'https://legofarming-polygon.club',
#  'https://app.elena.finance',
#  'https://valueset.finance/',
#  'https://xusd.money/',
#  'https://kitten.finance/',
#  'https://monopolyfinance.xyz',
#  'https://inverse.finance',
#  'https://don-key.finance',
#  'https://defimagic.io',
#  'https://stakedao.org',
#  'https://ethernity.io',
#  'https://ester.finance',
#  'PolyZero',
#  'https://polyroll.org',
#  'https://pop.town',
#  'https://polydragon.io',
#  'https://forcedao.com/',
#  'https://exchange.futureswap.com',
#  'https://fuse.io',
#  'https://www.dollarprotocol.com/#/stake',
#  'https://defiville.finance/',
#  'https://dashboard.keep.network/liquidity',
#  'https://kine.finance',
#  'https://lever.network',
#  'https://staking.launchpool.xyz',
#  'https://app.playludus.io',
#  'https://launchpad.benchmarkprotocol.finance/pools',
#  'https://stake.publicmint.com',
#  'https://museumofcryptoart.com',
#  'https://incentives.epns.io',
#  'https://app.optionroom.finance',
#  'https://staking.sandbox.game',
#  'https://www.sharedstake.org/earn',
#  'https://app.xsigma.fi',
#  'https://abracadabra.money',
#  'https://gemstones.finance',
#  'https://stake.myswarm.app',
#  'https://app.tornado.cash',
#  'https://app.truefi.io/farm',
#  'https://farm.umbria.network',
#  'https://www.app.unic.ly/#/farm',
#  'https://app.unslashed.finance/',
#  'https://wasabix.finance/#/app/pool',
#  'https://wild.credit',
#  'https://app.wolvesofwallstreet.finance',
#  'https://xtoken.cafe/app/dashboard',
#  'https://yaxis.io/farms',
#  'https://yflusd.linkswap.app',
#  'https://fei.money',
#  'https://www.theghost.finance',
#  'https://tomb.finance',
#  'https://governordao.org',
#  'https://gambit.financial/earn',
#  'https://polygon.iron.finance',
#  'https://polygame.finance',
#  'https://kogefarm.io',
#  'https://polywhale.finance',
#  'https://gravityfinance.io/app/#farms',
#  'https://steakhouse.finance',
#  'https://mith.cash',
#  'https://narwhale.finance',
#  'https://nya.cash',
#  'https://mimo.capital/mining',
#  'https://pegs.cash',
#  'https://polygon.fulcrum.trade',
#  'https://polkacash.finance',
#  'https://app.polyquity.org',
#  'https://www.mai.finance',
#  'https://app.rulerprotocol.com/app/farms',
#  'https://stacker.vc',
#  'https://penguinswap.eth.link',
#  'https://app.pendle.finance/',
#  'http://app.eurxb.finance',
#  'https://xdollar.mcn.ventures',
#  'https://staking.synthetix.io']

# %%
pair_df[pair_df['pair1'] == 'ETH']
# Out:
#      pair1   pair2          tvl         apr network           apy    qpr  \
# 7058   ETH          16598724.64       49.75     ETH  6.440476e+01    NaN
# 7059   ETH            482122.36           0     ETH  0.000000e+00    NaN
# 7060   ETH            114447.52    11303.68     ETH  5.841039e+44    NaN
# 7061   ETH              3084.54      408.35   MATIC  5.702225e+03    NaN
# 7062   ETH              1404.85        0.00   MATIC  0.000000e+00    NaN
# ...    ...     ...          ...         ...     ...           ...    ...
# 9087   ETH  zHEGIC     2.068828   0.8876808     ETH           NaN    NaN
# 9088   ETH  zHEGIC     0.019139         0.0     ETH           NaN    NaN
# 9089   ETH    zLOT     0.011083  1.02232608     ETH           NaN    NaN
# 9090   ETH    zLOT    19.928978  1.21804908     ETH           NaN    NaN
# 9091   ETH    zLOT     37946.24         NaN     ETH           NaN  34.75
#
#      type_of_agriculture                      dex       date
# 7058                FARM  https://polycat.finance 2021-06-28
# 7059                FARM  https://polycat.finance 2021-06-28
# 7060                FARM    https://harvester.app 2021-06-28
# 7061                FARM  https://polyfox.finance 2021-06-28
# 7062                FARM      https://hawkdex.com 2021-06-28
# ...                  ...                      ...        ...
# 9087                POOL                  Uniswap 2021-06-28
# 9088                POOL                    Sushi 2021-06-28
# 9089                POOL                  Uniswap 2021-06-28
# 9090                POOL                    Sushi 2021-06-28
# 9091                FARM                    SUSHI 2021-06-28
#
# [2034 rows x 10 columns]

# %%
pair_df['apr'].unique().tolist()
# Out:
# ['0.0',
#  '11.29263312',
#  '5.28389172',
#  '221.00',
#  '83.81',
#  '23.89966308',
#  '70.04',
#  '1.694274',
#  '146.48',
#  '4.68032904',
#  '5.22454692',
#  '0.00',
#  '29.23453428',
#  '4.9600000799999995',
#  '3.61462812',
#  '0.18444143999999998',
#  '0',
#  '258.23',
#  '742.86',
#  '15929.71',
#  '15.17',
#  '20.96813076',
#  '5.41394916',
#  '0.40344696',
#  nan,
#  '1.40943996',
#  '0.5265770399999999',
#  '2.15423844',
#  '1.51039296',
#  '2.4262336799999997',
#  '0.0035435999999999996',
#  '16.41',
#  '3.79',
#  '19.09',
#  '6.09',
#  '24.42',
#  '3.82',
#  '0.08386212000000001',
#  '1030.08',
#  '0.07637052',
#  '0.09764616000000001',
#  '5.15366652',
#  '1546.35',
#  '2955.12',
#  '4418.81',
#  '2.80',
#  '0.37990164000000004',
#  '21182.46',
#  '70.88',
#  '69.63',
#  '176.20',
#  '117.21',
#  '55.55',
#  '12.96',
#  '232.58',
#  '269.48',
#  '84.47',
#  '239.98',
#  '113.41',
#  '55.44',
#  '207.97',
#  '831.54',
#  '63.36',
#  '735.74',
#  '2207.23',
#  '5885.95',
#  '344.87',
#  '680.49',
#  '50.67',
#  '15.77',
#  '163.61',
#  '681.15',
#  '3092.08',
#  '65.36',
#  '19.43',
#  '14.46',
#  '95.37',
#  '12.98',
#  '51.10',
#  '157.65',
#  '1200.55',
#  '233.50',
#  '249.32',
#  '19.27',
#  '163.43',
#  '10.297034640000001',
#  '13.24635516',
#  '76.56',
#  '9.10',
#  '17.86',
#  '164.19',
#  '38.96',
#  '228.43',
#  '71.10',
#  '88.34',
#  '69.46',
#  '547.53',
#  '186.79',
#  '251.64',
#  '321.73',
#  '586.11',
#  '54.55',
#  '0.95327736',
#  '2.25288096',
#  '0.02306028',
#  '732.67',
#  '69.55',
#  '0.45',
#  '92.67',
#  '15.20060016',
#  '16.67',
#  '289.49',
#  '35.32',
#  '175.23',
#  '10.15',
#  '42.82',
#  '368.75',
#  '30.12',
#  '73.59',
#  '20.74',
#  '27.74',
#  '51.01',
#  '22.61',
#  '2.23',
#  '115.88',
#  '69.97',
#  '13.38',
#  '15.69',
#  '1582.56',
#  '1.00',
#  '435.74',
#  '37.67',
#  '7.61',
#  '9.96',
#  '56.10',
#  '327586.60',
#  '264129.00',
#  '2761.60',
#  '10344510.96',
#  '180.33',
#  '213.92',
#  '18.64',
#  '28.90',
#  '6.69',
#  '225.31',
#  '88.86',
#  '488.62',
#  '11.32',
#  '1.23',
#  '6.70',
#  '27.72',
#  '64.87',
#  '64.49',
#  '98.17',
#  '161.07',
#  '53.45',
#  '65.15',
#  '12.11',
#  '145.58',
#  '72.74',
#  '40.71',
#  '85.37',
#  '82.81',
#  '42.11',
#  '78.13',
#  '86.79',
#  '166.89',
#  '89.97',
#  '98.91',
#  '169.29',
#  '5822.78',
#  '182.75',
#  '33.83',
#  '17.00',
#  '36.84',
#  '49.60',
#  '392.41',
#  '299.23',
#  '2360.95',
#  '5.07',
#  '14.91',
#  '113.27',
#  '301.02',
#  '69.72',
#  '115.38',
#  '68.09',
#  '33.58',
#  '33.93',
#  '37.61',
#  '30.29',
#  '134.95',
#  '497729.41',
#  '665591.49',
#  '52.04',
#  '351.36',
#  '73094819.43',
#  '16.92',
#  '13.77',
#  '59.88',
#  '161.55',
#  '1510.35',
#  '220.40',
#  '15.96',
#  '2.56',
#  '12.51',
#  '796.60',
#  '167.78',
#  '89.04',
#  '352.90',
#  '282.07',
#  '27.24',
#  '1867.15',
#  '237.76',
#  '3312.59',
#  '7.11',
#  '11.34',
#  '14.74',
#  '42.83',
#  '115.76',
#  '198.60',
#  '5.52648468',
#  '1044.70',
#  '3138.86',
#  '5356.31',
#  '0.19591248',
#  '5.4495730799999995',
#  '11.90017608',
#  '0.10633236000000001',
#  '4.20665952',
#  '0.0163032',
#  '1.2029924399999998',
#  '0.04285560000000001',
#  '20.584758',
#  '0.03203988',
#  '15.32513328',
#  '7.984094279999999',
#  '6.57234756',
#  '13.03813284',
#  '18.50236812',
#  '20.61010548',
#  '610.96',
#  '0.05168772',
#  '350.31',
#  '108.52',
#  '4.77',
#  '132.63',
#  '2.64980364',
#  '22.63163496',
#  '0.03186',
#  '15.33415944',
#  '1.35',
#  '0.25067004',
#  '76.94',
#  '2.46',
#  '31.91',
#  '16.49',
#  '419.19',
#  '2938.73',
#  '40580.61',
#  '16538.80',
#  '104.62',
#  '209.25',
#  '261.56',
#  '4.78038072',
#  '89.30',
#  '384.25',
#  '236.44',
#  '235.92',
#  '190.40',
#  '353.14',
#  '280.13',
#  '190.97',
#  '249.24',
#  '224.05',
#  '288.38',
#  '146.20',
#  '180.68',
#  '380.31',
#  '520.20',
#  '323.47',
#  '574.11',
#  '333.08',
#  '88.26',
#  '218.96',
#  '265.18',
#  '218.41',
#  '376.96',
#  '323.38',
#  '128.27',
#  '502.97',
#  '64.88',
#  '240.28',
#  '278.15',
#  '793.07',
#  '218.72',
#  '195.40',
#  '295.48',
#  '176.93',
#  '114.21',
#  '371.72',
#  '250.25',
#  '370.29',
#  '649.86',
#  '501.68',
#  '777.71',
#  '454.51',
#  '102.88',
#  '96.38',
#  '84713774344.18',
#  '393.62',
#  '20361694.91',
#  '157.64',
#  '58.30',
#  '26.66',
#  '60.59',
#  '797.03',
#  '0.9660545999999999',
#  '14309.62',
#  '77.51',
#  '42.43',
#  '570.16',
#  '59.85',
#  '45.76',
#  '37.63',
#  '248.90',
#  '340.73',
#  '130.78',
#  '194.31',
#  '73.25',
#  '224.91',
#  '68.66',
#  '21.15',
#  '9.25',
#  '648.50',
#  '514.22',
#  '88.36',
#  '157.56',
#  '101.60',
#  '515.11',
#  '20.260810799999998',
#  '15.546259200000001',
#  '3.3397006799999995',
#  '2.1194958',
#  '3.6573757199999997',
#  '0.0703434',
#  '0.02546772',
#  '0.83894124',
#  '56.71742808',
#  '49.246060560000004',
#  '147.89',
#  '0.07113252',
#  '11.636904600000001',
#  '5.59673604',
#  '105068.12',
#  '189.99',
#  '0.43995660000000003',
#  '2.28989856',
#  '53.33',
#  '20.2970754',
#  '276.89',
#  '203.81',
#  '912.05',
#  '800.37',
#  '1407.04',
#  '1286.00',
#  '794.88',
#  '1074.61',
#  '9.918534959999999',
#  '12.419550120000002',
#  '0.5472970800000001',
#  '1747.84',
#  '975.04',
#  '0.436638',
#  '369.93',
#  '5.1091788',
#  '73.33',
#  '73.08',
#  '247.31',
#  '74.74',
#  '120.15',
#  '502.95',
#  '363.37',
#  '665.79',
#  '648.58',
#  '36.85',
#  '54.90',
#  '20.52',
#  '15.55',
#  '15.63',
#  '644.75',
#  '4889.64',
#  '1147.80',
#  '0.07600092',
#  '236.13',
#  '257.86',
#  '63.77480316',
#  '22.140417480000004',
#  '0.68084412',
#  '9.3366768',
#  '95.15',
#  '27.27',
#  '58.11',
#  '12.544546200000001',
#  '5.29',
#  '420.60',
#  '445.10',
#  '124.60',
#  '8.305083119999999',
#  '8.64861852',
#  '31.51',
#  '302.09',
#  '20.00233764',
#  '74.76',
#  '101.26',
#  '112.11',
#  '1.95652716',
#  '85.13',
#  '83.45',
#  '104.57',
#  '4.8272292',
#  '4.9772256',
#  '87.73',
#  '94.19',
#  '93.83',
#  '3.86204976',
#  '5.12751012',
#  '1.01800764',
#  '25.57',
#  '49.36',
#  '129.04',
#  '16.26',
#  '109.70',
#  '212.75',
#  '984.68',
#  '1.2031133999999999',
#  '201.08',
#  '4.595136',
#  '609.23',
#  '3.5717744400000004',
#  '2.976981',
#  '0.47017344',
#  '147.13',
#  '300.78',
#  '645.82',
#  '216.65',
#  '35.03',
#  '4.17',
#  '55.70',
#  '52.01',
#  '75.63',
#  '63.78',
#  '606.55',
#  '32.84818524',
#  '5.98',
#  '3.9144918000000004',
#  '0.37852284',
#  '11.254648320000001',
#  '156.95',
#  '3648.63',
#  '819.58',
#  '277.72',
#  '149.65',
#  '1820.57',
#  '287.59',
#  '476.45',
#  '332.01',
#  '604.77',
#  '433.13',
#  '240.98',
#  '127.05',
#  '447.94',
#  '436.60',
#  '353.42',
#  '382.03',
#  '11.678629560000001',
#  '9.49',
#  '7.29',
#  '2.94',
#  '1177.55',
#  '264.66',
#  '176.72',
#  '57.73',
#  '516.83',
#  '469.50',
#  '77.31',
#  '3533.57',
#  '426.99',
#  '320.68',
#  '210.17',
#  '1120.89',
#  '71.23',
#  '139.26',
#  '174.33',
#  '373.48',
#  '65.06',
#  '72.92',
#  '90.00',
#  '21.99',
#  '78.08',
#  '166.85',
#  '25.42',
#  '164.36',
#  '575.60',
#  '12.48',
#  '30.43',
#  '96.92',
#  '29.35',
#  '32.81',
#  '52.35',
#  '73.16',
#  '1897.60',
#  '476.46',
#  '278.91',
#  '35.91',
#  '0.13603776',
#  '1.3754083200000002',
#  '2.79969588',
#  '167.47',
#  '6.28',
#  '239.02',
#  '276.68',
#  '115.08',
#  '237.22',
#  '81.09',
#  '2456.95',
#  '56.99',
#  '95.34',
#  '44.25',
#  '57.51',
#  '43.42',
#  '19.13',
#  '23.39',
#  '455.61',
#  '30.48',
#  '150.96',
#  '249.61',
#  '13.11',
#  '15.43',
#  '122.35',
#  '13.24',
#  '34.55',
#  '28.46',
#  '12.69',
#  '43.33',
#  '16.40',
#  '20.47',
#  '16.22',
#  '244.87',
#  '74.71',
#  '13.04',
#  '26.39',
#  '28.12',
#  '289.93',
#  '186.07',
#  '71.69',
#  '193.82',
#  '91.65',
#  '4353.52',
#  '130.55',
#  '39.69',
#  '285.86',
#  '125.17',
#  '21.00',
#  '47.37',
#  '13.01',
#  '38.24',
#  '25.99',
#  '13.13',
#  '13.32',
#  '10.38',
#  '43.14',
#  '58.50',
#  '18.70',
#  '27.10',
#  '24.63',
#  '172.41',
#  '149.33',
#  '81.02',
#  '175.52',
#  '107.43',
#  '165.79',
#  '106.13',
#  '0.08971847999999999',
#  '0.0296892',
#  '0.00070764',
#  '2.03370444',
#  '16.534254',
#  '12.20111592',
#  '157.75',
#  '145.82',
#  '0.28236264',
#  '2.29483344',
#  '187.40',
#  '0.04876116',
#  '0.12686112000000002',
#  '57.93',
#  '710.02',
#  '810.74',
#  '4.17195012',
#  '28.30',
#  '5.907244919999999',
#  '52.78530972',
#  '0.28884864',
#  '10.39779312',
#  '12.54969864',
#  '0.00766476',
#  '85.00318824',
#  '61.11',
#  '34.51',
#  '1.38488532',
#  '72.19',
#  '283.16',
#  '258.25',
#  '243.04',
#  '178.25',
#  '16.44',
#  '7.26',
#  '85.59',
#  '55.72',
#  '93.11',
#  '397.70',
#  '45.53',
#  '3403.87',
#  '455.50',
#  '1967.86',
#  '14.17',
#  '120.71',
#  '79.42',
#  '53.03',
#  '24.38',
#  '72.65',
#  '179.37',
#  '3.07',
#  '214.79',
#  '7.59',
#  '95.89',
#  '98740.29',
#  '126.52',
#  '126.73',
#  '91.42',
#  '1139.86',
#  '1146.52',
#  '167.13',
#  '55.91',
#  '219.02',
#  '417.26',
#  '417.93',
#  '378.68',
#  '119.02',
#  '245.79',
#  '7679.76',
#  '0.13882860000000002',
#  '6.337377479999999',
#  '187.75',
#  '380.83',
#  '179.13',
#  '389.05',
#  '68.74',
#  '39.73',
#  '412.46',
#  '207.75',
#  '122.68',
#  '8.61',
#  '21.42',
#  '365.36',
#  '30.68',
#  '161.84',
#  '10.55',
#  '275.94',
#  '28.34',
#  '265.65',
#  '16.01',
#  '43.81',
#  '263.38',
#  '236.52',
#  '144.74',
#  '18.16',
#  '14.23',
#  '1359.02',
#  '0.56',
#  '121.77',
#  '122.29',
#  '242.95',
#  '263.20',
#  '622.68',
#  '457.99',
#  '178.20',
#  '463.24',
#  '85.03',
#  '355.32',
#  '56.20',
#  '14.90',
#  '12.94',
#  '77.15',
#  '81.18',
#  '47.27',
#  '6.83775804',
#  '10.57679808',
#  '98.45',
#  '14.55',
#  '41.60',
#  '35.72',
#  '14.0850606',
#  '2.4393716399999996',
#  '121.10',
#  '2.61253716',
#  '4.27356624',
#  '6.35442168',
#  '3.14061948',
#  '4.14691632',
#  '2.75513604',
#  '194.82',
#  '1.0930944',
#  '1371.21',
#  '3.9115328399999996',
#  '1.35211992',
#  '4.54936932',
#  '105.66',
#  '3.38600076',
#  '59.34',
#  '136.28',
#  '39.84',
#  '41.75',
#  '3.46',
#  '36.05',
#  '1.1846082',
#  '7.85608476',
#  '407.44',
#  '283.32',
#  '271.96',
#  '228.24',
#  '231.16',
#  '212.21',
#  '156.13',
#  '200.88',
#  '211.87',
#  '138.17',
#  '210.41',
#  '112.12',
#  '174.13',
#  '113.37',
#  '354.62',
#  '96.79',
#  '331.73',
#  '342.23',
#  '122.94',
#  '264.02',
#  '318.02',
#  '273.20',
#  '360.54',
#  '389.10',
#  '426.97',
#  '1.00047',
#  '18.41',
#  '61.09',
#  '37.22',
#  '57.29',
#  '1.3956588',
#  '32.62',
#  '1.04455716',
#  '0.29484299999999997',
#  '7247.62',
#  '2386.13',
#  '7.591422720000001',
#  '6.91',
#  '40.78',
#  '101.85',
#  '358.75',
#  '325.77',
#  '25.49',
#  '2.3998947600000005',
#  '112.01',
#  '95.22',
#  '70.90',
#  '4.34',
#  '81.48',
#  '7.52697012',
#  '131.51',
#  '7.58',
#  '117.60',
#  '18.65',
#  '110.53',
#  '175.73',
#  '140.51',
#  '195.36',
#  '15.19711272',
#  '150995.75',
#  '166915.85',
#  '111053.52',
#  '163.91',
#  '55.71',
#  '55.86',
#  '51.14',
#  '1.38',
#  '40.47',
#  '5.26',
#  '23.52',
#  '0.50',
#  '110.33',
#  '228.21',
#  '241.04',
#  '12.92',
#  '375.69',
#  '225.94',
#  '27.112507199999996',
#  '1.9287049200000002',
#  '275.14',
#  '213.83',
#  '306.92',
#  '419.34',
#  '12.04',
#  '1340.80',
#  '26.55',
#  '1.4961319199999998',
#  '15.78',
#  '19.01',
#  '107.50',
#  '31.86',
#  '13.06',
#  '18.585781439999998',
#  '0.31152335999999997',
#  '109.76',
#  '12.57',
#  '110.41',
#  '18.27',
#  '49.66',
#  '71.11',
#  '65.98',
#  '63.77',
#  '49.59',
#  '21.85',
#  '368.59',
#  '136.60',
#  '138.42',
#  '123.38',
#  '67.10',
#  '745.21',
#  '103.63',
#  '454.34',
#  '51.17',
#  '215.28',
#  '270.22',
#  '61.37',
#  '7.81',
#  '295.57',
#  '826.14',
#  '798.49',
#  '874.15',
#  '785.06',
#  '1.89800508',
#  '2753.73',
#  '5.72141064',
#  '1047.52',
#  '2033.30',
#  '1832.00',
#  '13.214591639999998',
#  '4.07',
#  '3.25265292',
#  '400.55',
#  '17.31836424',
#  '0.65549256',
#  '2.5149011999999997',
#  '368.54',
#  '106.88',
#  '391.74',
#  '4.00886436',
#  '10.06903152',
#  '17.10',
#  '1134957.30',
#  '52.86',
#  '7699812077067595776.00',
#  '28.32',
#  '33.10',
#  '2999.57',
#  '145.25',
#  '24.00',
#  '201.79',
#  '21.36',
#  '291.44',
#  '26.47',
#  '389.84',
#  '47.69',
#  '11634.77',
#  '17.89',
#  '33.91',
#  '23.20',
#  '76.06',
#  '42.89',
#  '97.54',
#  '187.22',
#  '71.70',
#  '3269.36',
#  '31.30',
#  '684.06',
#  '302.84',
#  '29.07',
#  '28.19',
#  '0.38',
#  '13.90',
#  '3.62',
#  '185.71',
#  '124.15',
#  '68.87',
#  '302.73',
#  '2003.86',
#  '59.27',
#  '61.54',
#  '442.30',
#  '159.59',
#  '59.16',
#  '18.17',
#  '209.79',
#  '46.24',
#  '18.77',
#  '45.47',
#  '10.35',
#  '14.53',
#  '74.25',
#  '164.74',
#  '22.09',
#  '148.61',
#  '168.22',
#  '2290.45',
#  '81.26',
#  '356.63',
#  '43.80',
#  '16.36',
#  '11.86',
#  '107.07',
#  '379.55',
#  '223.74',
#  '80.74',
#  '108.26',
#  '29.00',
#  '13.03',
#  '19.67',
#  '141.81',
#  '139.98',
#  '35.23',
#  '6.42',
#  '75.51',
#  '136.72',
#  '27.05',
#  '13.87',
#  '58.42',
#  '33.35',
#  '73.41',
#  '78.77',
#  '69.09',
#  '56.02',
#  '48.05',
#  '986.96',
#  '71.98',
#  '355.22',
#  '20.59',
#  '7.76',
#  '8.20',
#  '35.45',
#  '58.53',
#  '481.98',
#  '280.32',
#  '110715.49',
#  '400811.54',
#  '37.70',
#  '158246.30',
#  '3477.02',
#  '38.59',
#  '164.43',
#  '10181.02',
#  '36616027.78',
#  '108.50',
#  '70.66',
#  '2766.42',
#  '311.58',
#  '369.17',
#  '265.36',
#  '113.77',
#  '2.67',
#  '266.12',
#  '45.54',
#  '97.90',
#  '245.01',
#  '199.40',
#  '373.74',
#  '174.18',
#  '271.91',
#  '273.81',
#  '80992.26',
#  '38.45',
#  '5.17',
#  '1465.12',
#  '89.18',
#  '186.01',
#  '323.60',
#  '15.94',
#  '56.63',
#  '12.38',
#  '1452.66',
#  '218.20',
#  '47.35',
#  ...]

# %%
pair_df
# Out:
#           pair1 pair2         tvl          apr network           apy  qpr  \
# 0                 sil         0.0          0.0     ETH           NaN  NaN
# 1        $BASED   ETH   12.357646  11.29263312     ETH           NaN  NaN
# 2        $BASED  SUSD   15.617854   5.28389172     ETH           NaN  NaN
# 3           $DG   BNB  1763242.43       221.00     BSC  8.055174e+02  NaN
# 4           $DG   ETH   575396.91        83.81   MATIC  1.309750e+02  NaN
# ...         ...   ...         ...          ...     ...           ...  ...
# 16176  zs-XUSD2              0.00            0     ETH  0.000000e+00  NaN
# 16177  zs-tsBTC              0.00            0     ETH  0.000000e+00  NaN
# 16178      τBTC            131.17       258.49     BSC  1.214169e+03  NaN
# 16179         🌾          49549.51     26108.80     ETH  3.427821e+87  NaN
# 16180         🚜          64997.36        19.14   MATIC  2.108830e+01  NaN
#
#       type_of_agriculture                                 dex       date
# 0                    POOL                               Sushi 2021-06-28
# 1                    POOL                             Uniswap 2021-06-28
# 2                    POOL                             Uniswap 2021-06-28
# 3                    FARM         https://pancakeswap.finance 2021-06-28
# 4                    FARM  https://quickswap.exchange/#/quick 2021-06-28
# ...                   ...                                 ...        ...
# 16176                FARM  https://www.stabilize.finance/app/ 2021-06-28
# 16177                FARM  https://www.stabilize.finance/app/ 2021-06-28
# 16178                FARM          https://www.elixir-swap.io 2021-06-28
# 16179                FARM               https://harvester.app 2021-06-28
# 16180                FARM        https://www.honestwork.farm/ 2021-06-28
#
# [16181 rows x 10 columns]

# %%
pair_df[pair_df['pair1'] == 'CRV']
# Out:
#      pair1   pair2          tvl                 apr network           apy  \
# 5474   CRV             59324.78            10903.36     ETH  2.712911e+43
# 5475   CRV              5422.68                0.00     ETH  0.000000e+00
# 5476   CRV          69831055.18               36.44     ETH  4.393883e+01
# 5477   CRV                69.90              102.11  FANTOM  1.772292e+02
# 5478   CRV     CRV  21140304.75               57.76     ETH  7.809438e+01
# 5479   CRV     CRV  21140304.75               57.76     ETH  7.809438e+01
# 5480   CRV     ETH   7504222.50                   0     ETH  0.000000e+00
# 5481   CRV     ETH   7503424.03               10.55   MATIC  1.112492e+01
# 5482   CRV     ETH    930605.44              311.17   MATIC  2.116492e+03
# 5483   CRV     ETH   1124623.89              236.94   MATIC  9.609424e+02
# 5484   CRV     ETH  13763283.34                 NaN     ETH           NaN
# 5485   CRV     ETH  1249.805466  38.616780840000004     ETH           NaN
# 5486   CRV     ETH  6722.096332  26.660868120000004     ETH           NaN
# 5487   CRV     FTM    601357.34               75.05  FANTOM  1.116427e+02
# 5488   CRV     FTM   1040376.17               57.89  FANTOM  7.832569e+01
# 5489   CRV     FTM     34641.32               78.76  FANTOM  1.196250e+02
# 5490   CRV     FTM   1047740.55                2.32  FANTOM  2.347046e+00
# 5491   CRV     FTM     19549.80              117.65  FANTOM  2.236874e+02
# 5492   CRV     FTM     34716.31               84.61  FANTOM  1.328259e+02
# 5493   CRV     FTM     34775.91              215.39  FANTOM  7.564020e+02
# 5494   CRV   MILK2     0.819927          0.27383808     ETH           NaN
# 5495   CRV  WMATIC   1069641.92              250.67   MATIC  1.115975e+03
# 5496   CRV     sil          0.0                 0.0     ETH           NaN
#
#         qpr type_of_agriculture                                 dex       date
# 5474    NaN                FARM               https://harvester.app 2021-06-28
# 5475    NaN                FARM            https://gamestop.finance 2021-06-28
# 5476    NaN                FARM       https://www.convexfinance.com 2021-06-28
# 5477    NaN                FARM  https://klingftm.borgswap.exchange 2021-06-28
# 5478    NaN                FARM       https://www.convexfinance.com 2021-06-28
# 5479    NaN                FARM       https://www.convexfinance.com 2021-06-28
# 5480    NaN                FARM             https://polycat.finance 2021-06-28
# 5481    NaN                FARM               https://app.sushi.com 2021-06-28
# 5482    NaN                FARM       https://exchange.dfyn.network 2021-06-28
# 5483    NaN                FARM         https://polycrystal.finance 2021-06-28
# 5484  14.37                FARM                               SUSHI 2021-06-28
# 5485    NaN                POOL                             Uniswap 2021-06-28
# 5486    NaN                POOL                               Sushi 2021-06-28
# 5487    NaN                FARM          https://spookyswap.finance 2021-06-28
# 5488    NaN                FARM      https://app.spiritswap.finance 2021-06-28
# 5489    NaN                FARM    https://www.liquiddriver.finance 2021-06-28
# 5490    NaN                FARM        https://frankenstein.finance 2021-06-28
# 5491    NaN                FARM                https://waka.finance 2021-06-28
# 5492    NaN                FARM  https://klingftm.borgswap.exchange 2021-06-28
# 5493    NaN                FARM       https://www.operaswap.finance 2021-06-28
# 5494    NaN                POOL                             Uniswap 2021-06-28
# 5495    NaN                FARM         https://polycrystal.finance 2021-06-28
# 5496    NaN                POOL                               Sushi 2021-06-28

# %%
pair_df = pair_df.drop_duplicates()

# %%
df['pair1'].unique().tolist()
# Out:
# ['ALEPH',
#  'APYS',
#  'BLD',
#  'BOLE',
#  'BOP',
#  'BTC',
#  'CATO',
#  'CCAI',
#  'CHAD',
#  'CHEEMS',
#  'COPE',
#  'ETH',
#  'FAB',
#  'FIDA',
#  'FROG',
#  'FTR',
#  'FTT',
#  'GÜ',
#  'JOKE',
#  'KEEP',
#  'KEKW',
#  'KERMIT',
#  'KIN',
#  'LINK',
#  'LIQ',
#  'LUA',
#  'MAPS',
#  'MEDIA',
#  'MER',
#  'MOLA',
#  'OXS',
#  'OXY',
#  'PARTI',
#  'RAY',
#  'ROPE',
#  'SAIL',
#  'SAMO',
#  'SBFC',
#  'SDOGE',
#  'SHBL',
#  'SKEM',
#  'SLIM',
#  'SOL',
#  'SOLAPE',
#  'SOLPAD',
#  'SRM',
#  'STEP',
#  'SUSHI',
#  'TOMO',
#  'TULIP',
#  'TYNA',
#  'unknown',
#  'USDC',
#  'USDT',
#  'VCC',
#  'WOOF',
#  'xCOPE',
#  'YFI',
#  'WBTC',
#  'FRONT',
#  'DGCL',
#  'UNI',
#  'stZEN',
#  'YUNO',
#  'DAI',
#  'MIS',
#  'QDAO',
#  'BAO',
#  'REN',
#  'DATA',
#  'crDAI',
#  'sUSD',
#  'CRO',
#  'MIS3',
#  'AXIE',
#  'cDAI',
#  'xSUSHI',
#  'BNS',
#  'SASHIMI',
#  'MKR',
#  'silv2',
#  'FORTH',
#  'WAN',
#  'KP3R',
#  'VXC',
#  'OOKS',
#  'ALBT',
#  'MIC',
#  'KITTY',
#  'jEUR',
#  'sil',
#  'EASY',
#  'KAIJU',
#  'LEND',
#  'PROS',
#  'MASK',
#  'FOMC',
#  'BNT',
#  'OHM',
#  'ARTH',
#  'yveCRV',
#  'CURA',
#  'RUNE',
#  'ibETH',
#  'WOLF',
#  'Xi',
#  'SAKE',
#  'RAI',
#  'TUSD',
#  'NAMI',
#  'oneLINK',
#  'XOR',
#  'HEGIC',
#  'FARM',
#  'HBTC',
#  'BUSD',
#  'wCOINBASE',
#  'Mars',
#  'plDai',
#  'TSD',
#  'LON',
#  'ELE',
#  '1INCH',
#  'ARMOR',
#  'oneVBTC',
#  'NFTX',
#  'MAGGOT',
#  'DUCK',
#  'ANT',
#  'BLZ',
#  'BOND',
#  'BID',
#  'eXRD',
#  'BAT',
#  'mUSO',
#  '',
#  'XPR',
#  'PAXG',
#  'BPF',
#  'WZEC',
#  'XBE',
#  'jGBP',
#  'SOLVE',
#  'REVV',
#  '2GT',
#  'XAI',
#  'LEASH',
#  'BLOODY',
#  'MARK',
#  'UNCL',
#  'DAWN',
#  'POT',
#  'DEA',
#  'MOV',
#  'CORE',
#  'SPDR',
#  'YLA',
#  'BAC',
#  'MIR',
#  'CREAM',
#  'ESD',
#  'PLAY',
#  'BACON',
#  'RFI',
#  'PUNK',
#  'pONT',
#  'NMBL',
#  'DEUS',
#  'PICKLE',
#  'FRAX',
#  '$TRDL',
#  'AKRO',
#  'FEI',
#  '88MPH',
#  'PIB',
#  'FLEX',
#  'TEL',
#  'stDASH',
#  'DERI',
#  'y3Crv',
#  'XIO',
#  'AfroX',
#  'STA',
#  'SUSD',
#  'RARE',
#  'HAKKA',
#  'DUSD',
#  'WHALE',
#  'AVASTR',
#  'jCHF',
#  'OXT',
#  'stFIRO',
#  'SALT',
#  'YAM',
#  'GRAIN',
#  'ITALIA',
#  'HEX',
#  'WOO',
#  'PPAY',
#  'TBTC',
#  'SPICE',
#  'DTR',
#  'FXS',
#  'DDX',
#  'XYO',
#  'OPT',
#  'NICE',
#  'SGT',
#  'DIA',
#  'LIGHT',
#  'PHOON',
#  'POND',
#  'RBC',
#  'MIB',
#  'OCC',
#  'YFV',
#  'BONDLY',
#  'WFIL',
#  'TWT',
#  'MILK2',
#  'PASG',
#  'OUSD',
#  'REB2',
#  'oneWING',
#  'FUN',
#  'BEL',
#  'CELL',
#  'HKMT',
#  'ETH2POS',
#  'ALPHA',
#  'HGET',
#  'CVC',
#  'MIS2',
#  'RC_WBTC_25000_DAI_2021_3_31',
#  'LCS',
#  'USDP']

# %% [markdown]
# ## Farm Risk

# %%
# # farms_risks_df = pd.read_excel("~/notebooks/vfat_tool_data/Farm_risk.xlsx", sheet_name='BSC')
# farm_risk_df = pd.read_csv('~/notebooks/vfat_tool_data/farm_risks_analysis.csv')

# %%
# farm_risk_df.columns = ['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', 'rugdoc_url', 'network']
# farm_risk_df

# %%
# pairs_farm_risk_df = pd.merge(pair_df, farm_risk_df, how='left', left_on=['dex', 'network'], right_on=['Farm Url', 'network'])
# pairs_farm_risk_df.to_csv('farm_risk_yield_data_2021_06_14.csv')
# pairs_farm_risk_df

# %%
# farms_df = pair_df[['dex', 'network']].drop_duplicates().reset_index(drop=True)

# %%
# farms_df

# %%
# new_farm_risk_df = pd.merge(farms_df, farm_risk_df, how='left', left_on=['dex', 'network'], right_on=['Farm Url', 'network'])
# new_farm_risk_df['Farm Url'] = new_farm_risk_df['dex']
# del new_farm_risk_df['dex']
# new_farm_risk_df = new_farm_risk_df[['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', 'rugdoc_url', 'network']]

# # new_farm_risk_df.columns = ['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', 'rugdoc_url', 'network']

# %%
# new_farm_risk_df.to_csv('Farm_risk_06_14.csv', index=False)

# %%
excel_file = '~/notebooks/vfat_tool_data/Farm_risk_20210616.xlsx'

# %%
bsc_risks_df = pd.read_excel(excel_file, sheet_name='BSC')
bsc_risks_df.columns = ['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2', '3']
bsc_risks_df['rugdoc_url'] = bsc_risks_df['1'].fillna('') + bsc_risks_df['2'].fillna('') + bsc_risks_df['3'].fillna('')
del bsc_risks_df['1']
del bsc_risks_df['2']
del bsc_risks_df['3']
bsc_risks_df['network'] = 'BSC'
bsc_risks_df
# Out:
#           #  Indiv. Assesment  Audit Score RugDoc   Farm Name Farm Symbol  \
# 0         x               NaN          NaN  least     Pancake        CAKE
# 1       NaN               NaN          NaN   some     Apeswap      BANANA
# 2       NaN               NaN          NaN    NaN    Autofarm    AUTOFARM
# 3         x               9.0          NaN    NaN        Bake        BAKE
# 4         x               NaN         86.0    NaN        Brew        BREW
# ..      ...               ...          ...    ...         ...         ...
# 324     NaN               NaN          NaN    low   VenomSwap       VENOM
# 325     NaN               NaN          NaN    low    Elephant    ELEPHANT
# 326  No TLV               NaN          NaN    NaN   Bloodmoon   BLOODMOON
# 327     NaN               NaN          NaN    low  Blacksheep  BLACKSHEEP
# 328     NaN               NaN          NaN    NaN        Rice        RICE
#
#                              Farm Url  \
# 0         https://pancakeswap.finance
# 1             https://apeswap.finance
# 2            https://autofarm.network
# 3          https://www.bakeryswap.org
# 4            https://cafeswap.finance
# ..                                ...
# 324         https://www.venomswap.net
# 325  https://app.elephantswap.finance
# 326   https://bloodmoon.werewolf.farm
# 327    https://www.blacksheepdefi.com
# 328               https://ricefarm.fi
#
#                                         rugdoc_url network
# 0           https://rugdoc.io/project/pancakeswap/     BSC
# 1               https://rugdoc.io/project/apeswap/     BSC
# 2                                                      BSC
# 3                                                      BSC
# 4         https://www.certik.org/projects/cafeswap     BSC
# ..                                             ...     ...
# 324          https://rugdoc.io/project/venom-swap/     BSC
# 325       https://rugdoc.io/project/elephant-swap/     BSC
# 326                                                    BSC
# 327  https://rugdoc.io/project/blacksheep-finance/     BSC
# 328                                                    BSC
#
# [329 rows x 9 columns]

# %%
matic_risks_df = pd.read_excel(excel_file, sheet_name='MATIC')
matic_risks_df.columns = ['#', 'Indiv. Assesment', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2']
matic_risks_df['Audit Score'] = np.nan
matic_risks_df['rugdoc_url'] = matic_risks_df['1'].fillna('') + matic_risks_df['2'].fillna('')
del matic_risks_df['1']
del matic_risks_df['2']
matic_risks_df['network'] = 'MATIC'
matic_risks_df
# Out:
#          # Indiv. Assesment RugDoc     Farm Name Farm Symbol  \
# 0        x              low    NaN   Quickswap *       QUICK
# 1        x             some    NaN        Cometh        MUST
# 2   No TLV              NaN    NaN          Dark          DB
# 3      NaN              NaN    NaN      Smartdex        NIOX
# 4        x             high    NaN           Elk         ELK
# ..     ...              ...    ...           ...         ...
# 85  No TLV              NaN    NaN      PolyZero        ZERO
# 86     NaN              NaN    low       PolyMax         MAX
# 87     NaN              NaN    low  PolySnowFarm        SNOW
# 88     NaN              NaN    low      Polyyeld        YELD
# 89     NaN              NaN    low        Polysa        DUFF
#
#                               Farm Url  Audit Score  \
# 0   https://quickswap.exchange/#/quick          NaN
# 1       https://swap.cometh.io/#/stake          NaN
# 2               https://www.dark.build          NaN
# 3            https://swap.smartdex.app          NaN
# 4              https://app.elk.finance          NaN
# ..                                 ...          ...
# 85                                 NaN          NaN
# 86                https://polymax.club          NaN
# 87               https://polysnow.farm          NaN
# 88            https://polyyeld.finance          NaN
# 89          https://www.polysa.finance          NaN
#
#                                      rugdoc_url network
# 0                                                 MATIC
# 1                                                 MATIC
# 2                                                 MATIC
# 3                                                 MATIC
# 4                                                 MATIC
# ..                                          ...     ...
# 85                                                MATIC
# 86           https://rugdoc.io/project/polymax/   MATIC
# 87     https://rugdoc.io/project/polysnow-farm/   MATIC
# 88  https://rugdoc.io/project/polyyeld-finance/   MATIC
# 89    https://rugdoc.io/project/polysa-finance/   MATIC
#
# [90 rows x 9 columns]

# %%
avax_risks_df = pd.read_excel(excel_file, sheet_name='AVAX')
avax_risks_df.columns = ['#', 'Indiv. Assesment', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2']
avax_risks_df['Audit Score'] = np.nan
avax_risks_df['rugdoc_url'] = avax_risks_df['1'].fillna('') + avax_risks_df['2'].fillna('')
del avax_risks_df['1']
del avax_risks_df['2']
avax_risks_df['network'] = 'AVAX'
avax_risks_df
# Out:
#          # Indiv. Assesment RugDoc  Farm Name Farm Symbol  \
# 0        x              low    NaN   Pangolin         PNG
# 1        x              low    NaN    Complus         COM
# 2      NaN              NaN    NaN       Zero        ZERO
# 3      NaN              NaN    NaN       Yeti         YTS
# 4        x              NaN    low  Pandaswap      BAMBOO
# 5        x             some    NaN       Pefi        PEFI
# 6        x             high    NaN      Elk *         ELK
# 7   No TLV              NaN    NaN   Snowball        SNOB
# 8        x             some    NaN      Olive       OLIVE
# 9        x              NaN   some      Lydia         LYD
# 10     NaN              NaN    NaN   Baguette         BAG
# 11     NaN              NaN    NaN    Gondola         GDL
# 12       x              NaN   HIGH      Birdy        BIRD
# 13       x             some    NaN     Canary         CNR
# 14     NaN              NaN    NaN  Avalaunch        XAVA
# 15       x             some    NaN       Avme        AVME
#
#                                Farm Url  Audit Score  \
# 0   https://app.pangolin.exchange/#/png          NaN
# 1         https://avax.complus.exchange          NaN
# 2                https://app.0.exchange          NaN
# 3         https://exchange.yetiswap.app          NaN
# 4            https://pandaswap.exchange          NaN
# 5            https://penguinfinance.org          NaN
# 6                   https://elk.finance          NaN
# 7         https://snowball.network/earn          NaN
# 8               https://avax.olive.cash          NaN
# 9             https://www.lydia.finance          NaN
# 10        https://app.baguette.exchange          NaN
# 11          https://app.gondola.finance          NaN
# 12                https://birdy.finance          NaN
# 13          https://app.canary.exchange          NaN
# 14           https://farm.avalaunch.app          NaN
# 15                      https://avme.io          NaN
#
#                                     rugdoc_url network
# 0                                                 AVAX
# 1                                                 AVAX
# 2                                                 AVAX
# 3                                                 AVAX
# 4   https://rugdoc.io/project/panda-swap-defi/    AVAX
# 5                                                 AVAX
# 6                                                 AVAX
# 7                                                 AVAX
# 8                                                 AVAX
# 9        https://rugdoc.io/project/lydia-avax/    AVAX
# 10                                                AVAX
# 11                                                AVAX
# 12  https://rugdoc.io/project/birdy-avalanche/    AVAX
# 13                                                AVAX
# 14                                                AVAX
# 15                                                AVAX

# %%
fantom_risks_df = pd.read_excel(excel_file, sheet_name='FANTOM')
fantom_risks_df.columns = ['#', 'Indiv. Assesment', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2']
fantom_risks_df['Audit Score'] = np.nan
fantom_risks_df['rugdoc_url'] = fantom_risks_df['1'].fillna('') + fantom_risks_df['2'].fillna('')
del fantom_risks_df['1']
del fantom_risks_df['2']
fantom_risks_df['network'] = 'FANTOM'
fantom_risks_df
# Out:
#          # Indiv. Assesment RugDoc      Farm Name Farm Symbol  \
# 0      NaN              NaN    NaN       Popsicle         ICE
# 1        x              NaN    low         Spooky         boo
# 2        x              NaN   some         Spirit      SPIRIT
# 3        x              NaN    low           Borg         SON
# 4        x              NaN    low      Hyperjump         ORI
# 5        x              NaN    low          Ester         EST
# 6        x             high    NaN          Froyo       FROYO
# 7      NaN              NaN    NaN          Ghost       GHOST
# 8   No TLV              NaN    low          Beefy     Various
# 9        x             some    NaN  Liquid Driver        LQDR
# 10     NaN              NaN    NaN     Standard *        STRD
# 11     NaN              NaN    NaN      Mushrooms          MM
# 12       x             high    NaN     Greenhouse        SEED
# 13     NaN              NaN   high    Stake Steak       STEAK
# 14     NaN              NaN   high   Frankenstein       FRANK
# 15       x              NaN   high           Waka        WAKA
# 16       x             some    NaN            Elk         ELK
# 17      xx              NaN   high      Paintswap       BRUSH
# 18      xx              NaN    low           Tomb     Various
# 19     NaN              NaN   high         Shadow     Various
# 20     NaN              NaN    low       Borgswap       KLING
# 21     NaN              NaN   some          Opera       OPERA
#
#                               Farm Url  Audit Score  \
# 0             https://popsicle.finance          NaN
# 1           https://spookyswap.finance          NaN
# 2       https://app.spiritswap.finance          NaN
# 3        https://ftm.borgswap.exchange          NaN
# 4                 https://hyperjump.fi          NaN
# 5                https://ester.finance          NaN
# 6         https://frozenyogurt.finance          NaN
# 7         https://www.theghost.finance          NaN
# 8         https://fantom.beefy.finance          NaN
# 9     https://www.liquiddriver.finance          NaN
# 10                https://strd.finance          NaN
# 11     https://mushrooms.finance/farms          NaN
# 12       https://thegreenhouse.finance          NaN
# 13              https://stakesteak.com          NaN
# 14        https://frankenstein.finance          NaN
# 15                https://waka.finance          NaN
# 16             https://app.elk.finance          NaN
# 17           https://paintswap.finance          NaN
# 18                https://tomb.finance          NaN
# 19              https://shadowswap.app          NaN
# 20  https://klingftm.borgswap.exchange          NaN
# 21       https://www.operaswap.finance          NaN
#
#                                        rugdoc_url network
# 0                                                  FANTOM
# 1           https://rugdoc.io/project/spookyswap/  FANTOM
# 2           https://rugdoc.io/project/spiritswap/  FANTOM
# 3       https://rugdoc.io/project/borgswap-kling/  FANTOM
# 4         https://rugdoc.io/project/hyperjump-fi/  FANTOM
# 5        https://rugdoc.io/project/ester-finance/  FANTOM
# 6                                                  FANTOM
# 7                                                  FANTOM
# 8        https://rugdoc.io/project/beefy-finance/  FANTOM
# 9                                                  FANTOM
# 10                                                 FANTOM
# 11                                                 FANTOM
# 12                                                 FANTOM
# 13          https://rugdoc.io/project/stakesteak/  FANTOM
# 14        https://rugdoc.io/project/frankenstein/  FANTOM
# 15            https://rugdoc.io/project/waka-ftm/  FANTOM
# 16                                                 FANTOM
# 17           https://rugdoc.io/project/paintswap/  FANTOM
# 18        https://rugdoc.io/project/tomb-finance/  FANTOM
# 19  https://rugdoc.io/project/shadowswap-finance/  FANTOM
# 20      https://rugdoc.io/project/borgswap-kling/  FANTOM
# 21   https://rugdoc.io/project/operaswap-finance/  FANTOM

# %%
risk_df = bsc_risks_df.append(matic_risks_df)
risk_df = risk_df.append(avax_risks_df)
risk_df = risk_df.append(fantom_risks_df)
risk_df = risk_df[risk_df['rugdoc_url'] != '']
risk_df
# Out:
#       # Indiv. Assesment  Audit Score RugDoc  Farm Name Farm Symbol  \
# 0     x              NaN          NaN  least    Pancake        CAKE
# 1   NaN              NaN          NaN   some    Apeswap      BANANA
# 4     x              NaN         86.0    NaN       Brew        BREW
# 5   NaN              NaN          NaN   some      Donut       DONUT
# 7   NaN              NaN          NaN    NaN      Goose       GOOSE
# ..  ...              ...          ...    ...        ...         ...
# 17   xx              NaN          NaN   high  Paintswap       BRUSH
# 18   xx              NaN          NaN    low       Tomb     Various
# 19  NaN              NaN          NaN   high     Shadow     Various
# 20  NaN              NaN          NaN    low   Borgswap       KLING
# 21  NaN              NaN          NaN   some      Opera       OPERA
#
#                               Farm Url  \
# 0          https://pancakeswap.finance
# 1              https://apeswap.finance
# 4             https://cafeswap.finance
# 5                https://donutdefi.com
# 7            https://www.goosedefi.com
# ..                                 ...
# 17           https://paintswap.finance
# 18                https://tomb.finance
# 19              https://shadowswap.app
# 20  https://klingftm.borgswap.exchange
# 21       https://www.operaswap.finance
#
#                                        rugdoc_url network
# 0          https://rugdoc.io/project/pancakeswap/     BSC
# 1              https://rugdoc.io/project/apeswap/     BSC
# 4        https://www.certik.org/projects/cafeswap     BSC
# 5           https://rugdoc.io/project/donutswapp/     BSC
# 7       https://www.certik.org/projects/ramenswap     BSC
# ..                                            ...     ...
# 17           https://rugdoc.io/project/paintswap/  FANTOM
# 18        https://rugdoc.io/project/tomb-finance/  FANTOM
# 19  https://rugdoc.io/project/shadowswap-finance/  FANTOM
# 20      https://rugdoc.io/project/borgswap-kling/  FANTOM
# 21   https://rugdoc.io/project/operaswap-finance/  FANTOM
#
# [218 rows x 9 columns]

# %%
pairs_farm_risk_df = pd.merge(pair_df, risk_df, how='left', left_on=['dex', 'network'], right_on=['Farm Url', 'network'])
pairs_farm_risk_df.to_csv('farm_risk_yield_data_2021_06_28.csv')
pairs_farm_risk_df
# Out:
#           pair1 pair2         tvl          apr network           apy  qpr  \
# 0                 sil         0.0          0.0     ETH           NaN  NaN
# 1        $BASED   ETH   12.357646  11.29263312     ETH           NaN  NaN
# 2        $BASED  SUSD   15.617854   5.28389172     ETH           NaN  NaN
# 3           $DG   BNB  1763242.43       221.00     BSC  8.055174e+02  NaN
# 4           $DG   ETH   575396.91        83.81   MATIC  1.309750e+02  NaN
# ...         ...   ...         ...          ...     ...           ...  ...
# 16172  zs-XUSD2              0.00            0     ETH  0.000000e+00  NaN
# 16173  zs-tsBTC              0.00            0     ETH  0.000000e+00  NaN
# 16174      τBTC            131.17       258.49     BSC  1.214169e+03  NaN
# 16175         🌾          49549.51     26108.80     ETH  3.427821e+87  NaN
# 16176         🚜          64997.36        19.14   MATIC  2.108830e+01  NaN
#
#       type_of_agriculture                                 dex       date    #  \
# 0                    POOL                               Sushi 2021-06-28  NaN
# 1                    POOL                             Uniswap 2021-06-28  NaN
# 2                    POOL                             Uniswap 2021-06-28  NaN
# 3                    FARM         https://pancakeswap.finance 2021-06-28    x
# 4                    FARM  https://quickswap.exchange/#/quick 2021-06-28  NaN
# ...                   ...                                 ...        ...  ...
# 16172                FARM  https://www.stabilize.finance/app/ 2021-06-28  NaN
# 16173                FARM  https://www.stabilize.finance/app/ 2021-06-28  NaN
# 16174                FARM          https://www.elixir-swap.io 2021-06-28  NaN
# 16175                FARM               https://harvester.app 2021-06-28  NaN
# 16176                FARM        https://www.honestwork.farm/ 2021-06-28  NaN
#
#       Indiv. Assesment  Audit Score RugDoc Farm Name Farm Symbol  \
# 0                  NaN          NaN    NaN       NaN         NaN
# 1                  NaN          NaN    NaN       NaN         NaN
# 2                  NaN          NaN    NaN       NaN         NaN
# 3                  NaN          NaN  least   Pancake        CAKE
# 4                  NaN          NaN    NaN       NaN         NaN
# ...                ...          ...    ...       ...         ...
# 16172              NaN          NaN    NaN       NaN         NaN
# 16173              NaN          NaN    NaN       NaN         NaN
# 16174              NaN          NaN   high    Elixir        ELXR
# 16175              NaN          NaN    NaN       NaN         NaN
# 16176              NaN          NaN    NaN       NaN         NaN
#
#                           Farm Url                              rugdoc_url
# 0                              NaN                                     NaN
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3      https://pancakeswap.finance  https://rugdoc.io/project/pancakeswap/
# 4                              NaN                                     NaN
# ...                            ...                                     ...
# 16172                          NaN                                     NaN
# 16173                          NaN                                     NaN
# 16174   https://www.elixir-swap.io  https://rugdoc.io/project/elixir-swap/
# 16175                          NaN                                     NaN
# 16176                          NaN                                     NaN
#
# [16177 rows x 18 columns]
