# %%
import re
import os
import pandas as pd
import numpy as np
import traceback2
from datetime import datetime
import pymysql
import numpy as np

where_map = {}
# pairs regexp: "\[([a-zA-z0-9$\-+τ\.%]*)\]-", "-\[([a-zA-z0-9$\-+τ]*)\]"
ignorable_files = ["farm_risk_yield_data_2021_06_14.csv", "Farm_risk_06_14.csv", "yield_data_2021_06_14.csv","Alternate.csv","vfat_tools_data_2021_06_14.csv",'.ipynb_checkpoints', "Manual Farm Yield 6:14.xlsx", "crash_parser.ipynb", "yieldFarm_6-14.csv"]

# %%
def __connect__():
    db_user = 'coin'
    db_password = 'dragonstone#123'
    db_name = 'master_data'
    db_host = 'localhost'
    return pymysql.connect(
        unix_socket=None,
        host=db_host,
        user=db_user,
        password=db_password,
        db=db_name,
        charset='latin1',
        cursorclass=pymysql.cursors.DictCursor)


def get_cursor(connection):
    if connection is None:
        connection = __connect__()
    connection.ping(reconnect=True)
    return connection.cursor()

# %%
def get_raydium_data(date):
    sql = f'select * from raydium_farm_pool_data where timestamp_dt = FROM_UNIXTIME({date});'
    data = pd.read_sql_query(sql, __connect__())
    data['apr'] = data['pool_rate']
    data['network'] = 'SOL'
    data['type_of_agriculture'] = data['farm_payment'].apply(lambda x : 'FARM' if x is not None else 'POOL')
    return data[['pair1', 'pair2', 'apr', 'tvl', 'where', 'network', 'type_of_agriculture']]

def get_liquidityfolio_pool_data(date):
    sql = f'select * from liquidityfolio_pool where timestamp_dt = FROM_UNIXTIME({date}) and `where` != "balancer";'
    data = pd.read_sql_query(sql, __connect__())
    data['apr'] = data['pool_rate'] * 100 * 12
    data['type_of_agriculture'] = data['farm_payment'].apply(lambda x : 'FARM' if x is not None else 'POOL')
    data['network'] = 'ETH'
    return data[['pair1', 'pair2', 'apr', 'tvl', 'where', 'network', 'type_of_agriculture']]

# %%
date = datetime(2021, 6, 16)
dt = date.timestamp()

# %%
df = get_raydium_data(dt)
df = df.append(get_liquidityfolio_pool_data(dt))
df[df['where'] == 'Sushi']
# Out:
#      pair1    pair2       apr          tvl  where network type_of_agriculture
# 0      ETH      UMA  5.984138  3667.577108  Sushi     ETH                POOL
# 1      ETH      UWL  2.463383    53.551732  Sushi     ETH                POOL
# 4      ETH    LIGHT  0.206812     1.948623  Sushi     ETH                POOL
# 9     DGCL     ACXT  7.781073    11.161577  Sushi     ETH                POOL
# 11     UNI   xSUSHI  5.109741     0.011464  Sushi     ETH                POOL
# ...    ...      ...       ...          ...    ...     ...                 ...
# 1442   ETH  AMALGAM  0.087070     0.172533  Sushi     ETH                POOL
# 1443  USDP     DUCK  2.729615    94.412030  Sushi     ETH                POOL
# 1444   DAI      RDM  0.000000     1.513494  Sushi     ETH                POOL
# 1449   ETH     89SA  5.153667     3.998762  Sushi     ETH                POOL
# 1450   ETH      OHM  3.846595     3.494265  Sushi     ETH                POOL
#
# [563 rows x 7 columns]

# %%
sm = {
    "WBTC" : "BTC",
    "WETH" : "ETH",
    "WBNB" : "BNB",
    "WFTM" : "FTM",
    "WAVAX" : "AVAX",
}

# %%
dex_map = {
    "SUSHI" : "https://app.sushi.com"
    
}

# %%
def pair1(line):
#     print(line)
    try:
        is_3_pairs = line.split("]-[")
        if len(is_3_pairs) > 2:
            return None
        s_index = line.index("[") + 1
        s = line[s_index: line.index("]", s_index)]
        if all(ord(c) < 128 for c in s):
            return s
        else:
            print(line)
            return None
    except:
        return ''

def pair2(line):
    print(line)
    s_index = line.index("-[") + 2
    s = line[s_index: line.index("]", s_index)]
#     print(s)
    if all(ord(c) < 128 for c in s):
        return s
    else:
        print(line)
        return ''

# %%
def apr(line):
    apr = "Year [0-9\,\.]+\%"
    x = re.findall(apr, line)
    return x[0].replace("Year ", "").replace("%", "").strip() if len(x) else 0

# %%
def tvl(line):
    tvl = "TVL: \$[0-9\.\,]+"
    x = re.findall(tvl, line)
    return x[0].replace("TVL: $", "").replace("%", "").replace(",","").strip()

# %%
def where(line):
    if 'INFO' in line:
        return line.replace("INFO", "").replace('\n', '').replace(":", "").replace("//", "://").replace('*', '').strip()
    return None

# %%
def get_single_pair(line):
    exp = "\d* *.*Price:"
    x = re.findall(exp, line)
    if not len(x):
#         print(">>>>>>>>>>>",line)
        return
    pair = x[0].replace(" Price:", "")
    return pair[pair.rindex(" "):].strip() if " " in pair else pair

def get_single_tvl(line):
    exp = "\([0-9\,\.$]+\)"
    x = re.findall(exp, line)
    return x[0].replace("(", "").replace(")", "").replace("$", "").replace(",","").strip()

# %%
get_single_pair("3 - WBNB Price: $370.13 Market Cap: $2,556,471,438.97 [%]")
# Out:
# 'WBNB'

# %%
def is_end_of_block(line):
    print(line)
    return line == "" or len(re.findall("INFO[ ]+: ", line))

def read_block(lines, start_index):
    block = []
    while start_index < len(lines):
        line = lines[start_index]
        start_index = start_index + 1
        if not is_end_of_block(line):
            block.append(line)
        else:
            return [block, start_index]
    return

def read_blocks_from_files(file):
    f = open(file)
    lines = f.readlines()
    blocks = []
    block = []
    block_start_line_no = []
    line_no = 0
    start_index = 0
    while start_index < len(lines):
        if !is_end_of_block(lines[start_index]):
            block_and_index = read_block(lines, start_index)
            print(block_and_index)
            if block_and_index is not None:
                block_start_line_no.append(start_index)
                start_index = block_and_index[1]
                blocks.append(block_and_index[0])
            else:
                start_index = start_index + 1
        else:
            start_index = start_index + 1
    return [blocks, block_start_line_no]

def read_blocks_from_files_qw(file):
    f = open(file)
    lines = f.readlines()
    blocks = []
    block = []
    block_start_line_no = []
    line_no = 0
    for line in lines:
        line_no = line_no + 1
        line = line.strip()
        if line == "" or len(re.findall("INFO[ ]+: ", line)):
            blocks.append(block)
            block_start_line_no.append(line_no)
            if len(line):
                blocks.append([line])
                block_start_line_no.append(line_no + 1)
            block = []
        else:
            block.append(line)
            
    blocks.append(block)
    return [blocks, block_start_line_no]

def get_pair_info_from_block(block, wh, network):
    tvl_index = 0
    if network == 'BSC':
        tvl_index = 3
    if len(block) == 1:
        if 'INFO' in block[0]:
            return [where(block[0])]
        else:
            return [wh]
    if len(block) and pair1(block[0]) and not get_single_pair(block[0]):
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        return [pair1(block[0]), pair2(block[0]), get_single_tvl(block[tvl_index]) if tvl_index > 0 else tvl(block[tvl_index]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
    elif len(block) > 2 and get_single_pair(block[0]):
        print('singel')
        if network == 'BSC':
            tvl_index = 1
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        return [get_single_pair(block[0]), "", get_single_tvl(block[1]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
    return None


def get_pairs(blocks, network, block_start_line_no):
    where = ""
    pairs = []
    index = -1
    for block in blocks:
        index = index + 1
        print("Block Start Line No.: ", block_start_line_no[index] if index < len(block_start_line_no) else -1)
        try:
            pair = get_pair_info_from_block(block, where, network)
            print(pair)
            if len(where) == 0 and pair and len(pair) > 2:
                print(block, network)
            if pair:
                if len(pair) == 1 and pair[0] and len(pair[0]):
                    where = pair[0]
                else:
                    pairs.append(pair)
        except Exception as e:
            print("Exception",e)
            print(block[0])
    return pairs
# Out:
#   File "<ipython-input-101-7f9b43d6c786>", line 24
#     if !is_end_of_block(lines[start_index]):
#        ^
# SyntaxError: invalid syntax

# %%
block = [["5 - BUSD Price: $1.00 Market Cap: $4,201,000,000.00 [%]",
"Staked: 169656.1666 BUSD ($169,656.17)",
"CERBERUS Per Week: 114253.33 ($756.29)",
"APR: Day 0.06% Week 0.45% Year 23.18%",
"You are staking 0.00 BUSD ($0.00), 0.00% of the pool.",
"Stake 0.00 BUSD - Fee 4%",
"Unstake 0.00 BUSD",
"Claim 0.00 CERBERUS ($0.00)",
"Staking or unstaking also claims rewards."]]
# get_pairs(block, "BSC", [1])

# %%
data_dir = './'
def conver_files_to_one_df(data_dir):
    all_pairs = []
    files = os.listdir(data_dir)
    for file_name in files:
        if file_name in ignorable_files:
            continue
        network = file_name[0:file_name.index(" ")]
        if 'Alternate' == network:
            network = 'ETH'
        if 'BSC' != network:
            continue
        print(file_name)
        blocks = read_blocks_from_files(f"{data_dir}{file_name}")
        block_start_line_no = blocks[1]
        blocks = blocks[0]
        pairs = get_pairs(blocks, network, block_start_line_no)
        all_pairs.extend(pairs)
    return all_pairs

# %%
pairs = conver_files_to_one_df(data_dir)
# Out:
# BSC Yields 6_14.crash
# [['BSC Yields 6/14\n', '\n', '\n'], 4]
# [['****************************************************************************************\n', '\n', '0 - Cake Price: $17.39 Market Cap: $5,809,554,616.19 [%]\n', 'Staked: 137920325.6699 Cake ($2,398,434,463.40)\n', 'CAKE Per Week: 2016000.00 ($35,058,240.00)\n', 'APR: Day 0.21% Week 1.46% Year 76.01%\n', 'You are staking 0.00 Cake ($0.00), 0.00% of the pool.\n', 'Stake 0.00 Cake\n', 'Unstake 0.00 Cake\n', 'Claim 0.00 CAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '137 - LOTTO Price: $0.00 Market Cap: $0.00 \n', 'Staked: 0.1000 LOTTO ($0.00)\n', 'CAKE Per Week: 363144.10 ($6,315,075.98)\n', 'APR: Day NaN% Week NaN% Year NaN%\n', 'You are staking 0.00 LOTTO ($0.00), NaN% of the pool.\n', 'Stake 0.00 LOTTO\n', 'Unstake 0.00 LOTTO\n', 'Claim 0.00 CAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '138 - BURN Price: $0.00 Market Cap: $0.00 \n', 'Staked: 0.1000 BURN ($0.00)\n', 'CAKE Per Week: 4071615.72 ($70,805,397.38)\n', 'APR: Day NaN% Week NaN% Year NaN%\n', 'You are staking 0.00 BURN ($0.00), NaN% of the pool.\n', 'Stake 0.00 BURN\n', 'Unstake 0.00 BURN\n', 'Claim 0.00 CAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '251 - [Cake]-[WBNB] Cake LP [+] [-] [<=>] Price: $163.10 TVL: $714,623,820.26\n', 'Cake Price: $17.39\n', 'WBNB Price: $370.45\n', 'Staked: 4356287.7809 Cake-LP ($710,516,179.22)\n', 'CAKE Per Week: 440174.67 ($7,654,637.55)\n', 'APR: Day 0.15% Week 1.08% Year 56.02%\n', 'You are staking 0.00 [Cake]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [Cake]-[WBNB] Cake LP\n', 'Unstake 0.00 [Cake]-[WBNB] Cake LP\n', 'Claim 0.00 CAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '252 - [WBNB]-[BUSD] Cake LP [+] [-] [<=>] Price: $42.54 TVL: $355,872,033.18\n', 'WBNB Price: $370.45\n', 'BUSD Price: $1.01\n', 'Staked: 8065825.4166 Cake-LP ($343,090,156.18)\n', 'CAKE Per Week: 88034.93 ($1,530,927.51)\n', 'APR: Day 0.06% Week 0.45% Year 23.20%\n', 'You are staking 0.00 [WBNB]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BUSD] Cake LP\n', 'Unstake 0.00 [WBNB]-[BUSD] Cake LP\n', 'Claim 0.00 CAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '253 - [ADA]-[WBNB] Cake LP [+] [-] [<=>] Price: $49.70 TVL: $23,146,025.09\n', 'ADA Price: $1.57\n', 'WBNB Price: $370.45\n', 'Staked: 448278.7681 Cake-LP ($22,279,911.85)\n', 'CAKE Per Week: 5502.18 ($95,682.97)\n', 'APR: Day 0.06% Week 0.43% Year 22.33%\n', 'You are staking 0.00 [ADA]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [ADA]-[WBNB] Cake LP\n', 'Unstake 0.00 [ADA]-[WBNB] Cake LP\n', 'Claim 0.00 CAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '254 - [BAND]-[WBNB] Cake LP [+] [-] [<=>] Price: $104.29 TVL: $8,753,143.72\n', 'BAND Price: $7.21\n', 'WBNB Price: $370.45\n', 'Staked: 83910.2128 Cake-LP ($8,750,869.58)\n', 'CAKE Per Week: 5502.18 ($95,682.97)\n', 'APR: Day 0.16% Week 1.09% Year 56.86%\n', 'You are staking 0.00 [BAND]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BAND]-[WBNB] Cake LP\n', 'Unstake 0.00 [BAND]-[WBNB] Cake LP\n', 'Claim 0.00 CAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '255 - [DOT]-[WBNB] Cake LP [+] [-] [<=>] Price: $195.89 TVL: $40,979,644.95\n', 'DOT Price: $24.77\n', 'WBNB Price: $370.45\n', 'Staked: 200935.9786 Cake-LP ($39,361,668.03)\n', 'CAKE Per Week: 11004.37 ($191,365.94)\n', 'APR: Day 0.07% Week 0.49% Year 25.28%\n', 'You are staking 0.00 [DOT]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DOT]-[WBNB] Cake LP\n', 'Unstake 0.00 [DOT]-[WBNB] Cake LP\n', 'Claim 0.00 CAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '256 - [EOS]-[WBNB] Cake LP [+] [-] [<=>] Price: $89.89 TVL: $3,395,152.61\n', 'EOS Price: $5.23\n', 'WBNB Price: $370.45\n', 'Staked: 36728.4544 Cake-LP ($3,301,654.14)\n', 'CAKE Per Week: 1100.44 ($19,136.59)\n', 'APR: Day 0.08% Week 0.58% Year 30.14%\n', 'You are staking 0.00 [EOS]-[WBNB] Cak ...
# [['*********************************************************************************\n', '\n', '0 - BANANA Price: $2.11 Market Cap: $87,623,797.31 [%]\n', 'Staked: 21716488.0488 BANANA ($45,770,987.86)\n', 'BANANA Per Week: 503968.17 ($1,062,193.89)\n', 'APR: Day 0.33% Week 2.32% Year 120.67%\n', 'You are staking 0.00 BANANA ($0.00), 0.00% of the pool.\n', 'Stake 0.00 BANANA\n', 'Unstake 0.00 BANANA\n', 'Claim 0.00 BANANA ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - [BANANA]-[WBNB] Uni LP [+] [-] [<=>] Price: $61.74 TVL: $31,489,996.97\n', 'BANANA Price: $2.11\n', 'WBNB Price: $370.45\n', 'Staked: 506557.2226 APE-LP ($31,275,372.02)\n', 'BANANA Per Week: 509315.99 ($1,073,465.27)\n', 'APR: Day 0.49% Week 3.43% Year 178.48%\n', 'You are staking 0.00 [BANANA]-[WBNB] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BANANA]-[WBNB] Uni LP\n', 'Unstake 0.00 [BANANA]-[WBNB] Uni LP\n', 'Claim 0.00 BANANA ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '2 - [BANANA]-[BUSD] Uni LP [+] [-] [<=>] Price: $3.37 TVL: $12,242,685.69\n', 'BANANA Price: $2.11\n', 'BUSD Price: $1.01\n', 'Staked: 3604223.2307 APE-LP ($12,138,341.48)\n', 'BANANA Per Week: 190993.49 ($402,549.48)\n', 'APR: Day 0.47% Week 3.32% Year 172.45%\n', 'You are staking 0.00 [BANANA]-[BUSD] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BANANA]-[BUSD] Uni LP\n', 'Unstake 0.00 [BANANA]-[BUSD] Uni LP\n', 'Claim 0.00 BANANA ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '3 - [WBNB]-[BUSD] Uni LP [+] [-] [<=>] Price: $44.81 TVL: $10,631,592.78\n', 'WBNB Price: $370.45\n', 'BUSD Price: $1.01\n', 'Staked: 230835.9244 APE-LP ($10,344,842.95)\n', 'BANANA Per Week: 50931.60 ($107,346.53)\n', 'APR: Day 0.15% Week 1.04% Year 53.96%\n', 'You are staking 0.00 [WBNB]-[BUSD] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BUSD] Uni LP\n', 'Unstake 0.00 [WBNB]-[BUSD] Uni LP\n', 'Claim 0.00 BANANA ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '4 - [BTCB]-[WBNB] Uni LP [+] [-] [<=>] Price: $7,938.33 TVL: $5,002,771.36\n', 'BTCB Price: $40,490.00\n', 'WBNB Price: $370.45\n', 'Staked: 625.7251 APE-LP ($4,967,211.71)\n', 'BANANA Per Week: 12732.90 ($26,836.63)\n', 'APR: Day 0.08% Week 0.54% Year 28.09%\n', 'You are staking 0.00 [BTCB]-[WBNB] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BTCB]-[WBNB] Uni LP\n', 'Unstake 0.00 [BTCB]-[WBNB] Uni LP\n', 'Claim 0.00 BANANA ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '5 - [ETH]-[WBNB] Uni LP [+] [-] [<=>] Price: $2,019.67 TVL: $6,899,886.31\n', 'ETH Price: $2,582.76\n', 'WBNB Price: $370.45\n', 'Staked: 3353.8317 APE-LP ($6,773,643.45)\n', 'BANANA Per Week: 22282.57 ($46,964.11)\n', 'APR: Day 0.10% Week 0.69% Year 36.05%\n', 'You are staking 0.00 [ETH]-[WBNB] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [ETH]-[WBNB] Uni LP\n', 'Unstake 0.00 [ETH]-[WBNB] Uni LP\n', 'Claim 0.00 BANANA ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '8 - [USDC]-[BUSD] Uni LP [+] [-] [<=>] Price: $2.02 TVL: $13,515,747.80\n', 'USDC Price: $1.00\n', 'BUSD Price: $1.01\n', 'Staked: 6079397.7367 APE-LP ($12,298,781.11)\n', 'BANANA Per Week: 19099.35 ($40,254.95)\n', 'APR: Day 0.05% Week 0.33% Year 17.02%\n', 'You are staking 0.00 [USDC]-[BUSD] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [USDC]-[BUSD] Uni LP\n', 'Unstake 0.00 [USDC]-[BUSD] Uni LP\n', 'Claim 0.00 BANANA ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '11 - [WBNB]-[BIFI] Uni LP [+] [-] [<=>] Price: $1,632.10 TVL: $2,092,217.71\n', 'WBNB Price: $370.45\n', 'BIFI Price: $1,647.26\n', 'Staked: 1279.0390 APE-LP ($2,087,513.87)\n', 'BANANA Per Week: 12732.90 ($26,836.63)\n', 'APR: Day 0.18% Week 1.29% Year 66.85%\n', 'You are staking 0.00 [WBNB]-[BIFI] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BIFI] Uni LP\n', 'Unstake 0.00 [WBNB]-[BIFI] Uni LP\n', 'Claim 0.00 BANANA ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n',  ...
# [['*************************************************************************************\n', '\n', '6 - [AUTO]-[WBNB] Cake LP [+] [-] [<=>] Price: $1,352.60 TVL: $19,271,635.38\n', 'AUTO Price: $1,135.30\n', 'WBNB Price: $370.30\n', 'Staked: 14180.8142 Cake-LP ($19,180,982.39)\n', 'AUTO Per Week: 322.82 ($366,495.56)\n', 'APR: Day 0.27% Week 1.91% Year 99.36%\n', 'You are staking 0.00 [AUTO]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [AUTO]-[WBNB] Cake LP\n', 'Unstake 0.00 [AUTO]-[WBNB] Cake LP\n', 'Claim 0.00 AUTO ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '7 - Cake Price: $17.29 Market Cap: $5,776,227,778.20 [%]\n', 'Staked: 4740908.0212 Cake ($81,970,299.69)\n', 'AUTO Per Week: 32.28 ($36,649.56)\n', 'APR: Day 0.01% Week 0.04% Year 2.32%\n', 'You are staking 0.00 Cake ($0.00), 0.00% of the pool.\n', 'Stake 0.00 Cake\n', 'Unstake 0.00 Cake\n', 'Claim 0.00 AUTO ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '73 - [BUSD]-[EGG] Cake LP [+] [-] [<=>] Price: $3.46 TVL: $3,109,263.32\n', 'BUSD Price: $1.00\n', 'EGG Price: $2.42\n', 'Staked: 534766.0865 Cake-LP ($1,849,638.35)\n', 'AUTO Per Week: 0.65 ($732.99)\n', 'APR: Day 0.01% Week 0.04% Year 2.06%\n', 'You are staking 0.00 [BUSD]-[EGG] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BUSD]-[EGG] Cake LP\n', 'Unstake 0.00 [BUSD]-[EGG] Cake LP\n', 'Claim 0.00 AUTO ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '74 - [WBNB]-[EGG] Cake LP [+] [-] [<=>] Price: $66.32 TVL: $3,218,198.82\n', 'WBNB Price: $370.30\n', 'EGG Price: $2.42\n', 'Staked: 34311.4205 Cake-LP ($2,275,525.26)\n', 'AUTO Per Week: 0.65 ($732.99)\n', 'APR: Day 0.00% Week 0.03% Year 1.68%\n', 'You are staking 0.00 [WBNB]-[EGG] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[EGG] Cake LP\n', 'Unstake 0.00 [WBNB]-[EGG] Cake LP\n', 'Claim 0.00 AUTO ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '96 - [AUTO]-[WBNB] BLP [+] [-] [<=>] Price: $1,329.46 TVL: $806,232.08\n', 'AUTO Price: $1,135.30\n', 'WBNB Price: $370.30\n', 'Staked: 567.2347 BLP ($754,115.87)\n', 'AUTO Per Week: 1.94 ($2,198.97)\n', 'APR: Day 0.04% Week 0.29% Year 15.16%\n', 'You are staking 0.00 [AUTO]-[WBNB] BLP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [AUTO]-[WBNB] BLP\n', 'Unstake 0.00 [AUTO]-[WBNB] BLP\n', 'Claim 0.00 AUTO ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '97 - [WBNB]-[BAKE] BLP [+] [-] [<=>] Price: $100.87 TVL: $57,226,135.28\n', 'WBNB Price: $370.30\n', 'BAKE Price: $3.31\n', 'Staked: 11239.8386 BLP ($1,133,741.44)\n', 'AUTO Per Week: 3.23 ($3,664.96)\n', 'APR: Day 0.05% Week 0.32% Year 16.81%\n', 'You are staking 0.00 [WBNB]-[BAKE] BLP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BAKE] BLP\n', 'Unstake 0.00 [WBNB]-[BAKE] BLP\n', 'Claim 0.00 AUTO ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '98 - [BTCB]-[WBNB] BLP [+] [-] [<=>] Price: $8,060.60 TVL: $70,203,401.17\n', 'BTCB Price: $39,910.00\n', 'WBNB Price: $370.30\n', 'Staked: 2094.4495 BLP ($16,882,510.30)\n', 'AUTO Per Week: 3.23 ($3,664.96)\n', 'APR: Day 0.00% Week 0.02% Year 1.13%\n', 'You are staking 0.00 [BTCB]-[WBNB] BLP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BTCB]-[WBNB] BLP\n', 'Unstake 0.00 [BTCB]-[WBNB] BLP\n', 'Claim 0.00 AUTO ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '127 - [MDX]-[WBNB] Uni LP [+] [-] [<=>] Price: $54.20 TVL: $15,948,314.06\n', 'MDX Price: $1.98\n', 'WBNB Price: $370.30\n', 'Staked: 168062.0198 MDEX LP ($9,109,701.90)\n', 'AUTO Per Week: 6.46 ($7,329.91)\n', 'APR: Day 0.01% Week 0.08% Year 4.18%\n', 'You are staking 0.00 [MDX]-[WBNB] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [MDX]-[WBNB] Uni LP\n', 'Unstake 0.00 [MDX]-[WBNB] Uni LP\n', 'Claim 0.00 AUTO ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '128 - [USDT]-[MDX] Uni LP [+] [-] [<=>] Price: $2.82 TVL: $5,331,634.06\n', 'USDT Price: $1.00\n', 'MDX Price: $1.98\n', 'Staked: 224130.6207 MDEX LP ...
# [['*******************************************************************************\n', '\n', '0 - [WBNB]-[BAKE] BLP [+] [-] [<=>] Price: $100.87 TVL: $57,226,121.49\n', 'WBNB Price: $370.30\n', 'BAKE Price: $3.31\n', 'Staked: 481922.3724 BLP ($48,610,594.33)\n', 'BAKE Per Week: 226800.00 ($750,708.00)\n', 'APR: Day 0.22% Week 1.54% Year 80.31%\n', 'You are staking 0.00 [WBNB]-[BAKE] BLP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BAKE] BLP\n', 'Unstake 0.00 [WBNB]-[BAKE] BLP\n', 'Claim 0.00 BAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - [WBNB]-[BUSD] BLP [+] [-] [<=>] Price: $52.16 TVL: $7,411,631.47\n', 'WBNB Price: $370.30\n', 'BUSD Price: $1.00\n', 'Staked: 137713.5682 BLP ($7,183,804.97)\n', 'BAKE Per Week: 22680.00 ($75,070.80)\n', 'APR: Day 0.15% Week 1.05% Year 54.34%\n', 'You are staking 0.00 [WBNB]-[BUSD] BLP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BUSD] BLP\n', 'Unstake 0.00 [WBNB]-[BUSD] BLP\n', 'Claim 0.00 BAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '2 - [ETH]-[WBNB] BLP [+] [-] [<=>] Price: $2,107.61 TVL: $2,067,859.32\n', 'ETH Price: $2,580.14\n', 'WBNB Price: $370.30\n', 'Staked: 977.6403 BLP ($2,060,479.95)\n', 'BAKE Per Week: 7560.00 ($25,023.60)\n', 'APR: Day 0.17% Week 1.21% Year 63.15%\n', 'You are staking 0.00 [ETH]-[WBNB] BLP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [ETH]-[WBNB] BLP\n', 'Unstake 0.00 [ETH]-[WBNB] BLP\n', 'Claim 0.00 BAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '3 - [BTCB]-[WBNB] BLP [+] [-] [<=>] Price: $8,060.60 TVL: $70,203,401.17\n', 'BTCB Price: $39,910.00\n', 'WBNB Price: $370.30\n', 'Staked: 8708.0591 BLP ($70,192,141.30)\n', 'BAKE Per Week: 264600.00 ($875,826.00)\n', 'APR: Day 0.18% Week 1.25% Year 64.88%\n', 'You are staking 0.00 [BTCB]-[WBNB] BLP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BTCB]-[WBNB] BLP\n', 'Unstake 0.00 [BTCB]-[WBNB] BLP\n', 'Claim 0.00 BAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '7 - BAKE Price: $3.31 Market Cap: $2,301,647,767.51 [%]\n', 'Staked: 50431824.7258 BAKE ($166,929,339.84)\n', 'BAKE Per Week: 158760.00 ($525,495.60)\n', 'APR: Day 0.04% Week 0.31% Year 16.37%\n', 'You are staking 0.00 BAKE ($0.00), 0.00% of the pool.\n', 'Stake 0.00 BAKE\n', 'Unstake 0.00 BAKE\n', 'Claim 0.00 BAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '8 - [BAKE]-[BUSD] BLP [+] [-] [<=>] Price: $5.14 TVL: $9,266,017.22\n', 'BAKE Price: $3.31\n', 'BUSD Price: $1.00\n', 'Staked: 1750734.1882 BLP ($9,003,332.30)\n', 'BAKE Per Week: 60480.00 ($200,188.80)\n', 'APR: Day 0.32% Week 2.22% Year 115.62%\n', 'You are staking 0.00 [BAKE]-[BUSD] BLP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BAKE]-[BUSD] BLP\n', 'Unstake 0.00 [BAKE]-[BUSD] BLP\n', 'Claim 0.00 BAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '11 - [USDT]-[BUSD] BLP [+] [-] [<=>] Price: $2.03 TVL: $8,437,197.50\n', 'USDT Price: $1.00\n', 'BUSD Price: $1.00\n', 'Staked: 4154417.8001 BLP ($8,422,753.44)\n', 'BAKE Per Week: 15120.00 ($50,047.20)\n', 'APR: Day 0.08% Week 0.59% Year 30.90%\n', 'You are staking 0.00 [USDT]-[BUSD] BLP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [USDT]-[BUSD] BLP\n', 'Unstake 0.00 [USDT]-[BUSD] BLP\n', 'Claim 0.00 BAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '12 - DSPT Price: $0.00 Market Cap: $0.00 \n', 'Staked: 30635753.3247 DSPT ($0.00)\n', 'BAKE Per Week: 189000.00 ($625,590.00)\n', 'APR: Day NaN% Week NaN% Year NaN%\n', 'You are staking 0.00 DSPT ($0.00), NaN% of the pool.\n', 'Stake 0.00 DSPT\n', 'Unstake 0.00 DSPT\n', 'Claim 0.00 BAKE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '14 - [PET]-[BAKE] BLP [+] [-] [<=>] Price: $2.72 TVL: $1,488,174.31\n', 'PET Price: $0.44\n', 'BAKE Price: $3.31\n', 'Staked: 455625.4454 BLP ($1,237,943.80)\n', 'BAKE Per Week: 7560.00 ($25,023.60)\n', 'APR: Day 0.29% Week 2.02% Year 105.11%\n', 'You are staking 0.00 [PET]-[BAKE] BLP ($0.00), 0.00%  ...
# [['*************************************************************************************\n', '\n', '0 - BREW Price: $2.78 Market Cap: $11,303,544.24 [%]\n', 'Staked: 1555072.3172 BREW ($4,321,474.63)\n', 'BREW Per Week: 50397.85 ($140,053.32)\n', 'APR: Day 0.46% Week 3.24% Year 168.53%\n', 'You are staking 0.00 BREW ($0.00), 0.00% of the pool.\n', 'Stake 0.00 BREW\n', 'Unstake 0.00 BREW\n', 'Claim 0.00 BREW ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '13 - [BANANA]-[BREW] Uni LP [+] [-] [<=>] Price: $4.99 TVL: $251,822.90\n', 'BANANA Price: $2.11\n', 'BREW Price: $2.78\n', 'Staked: 48853.9880 APE-LP ($244,023.69)\n', 'BREW Per Week: 3438.37 ($9,555.06)\n', 'APR: Day 0.56% Week 3.92% Year 203.61%\n', 'You are staking 0.00 [BANANA]-[BREW] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BANANA]-[BREW] Uni LP\n', 'Unstake 0.00 [BANANA]-[BREW] Uni LP\n', 'Claim 0.00 BREW ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '14 - [BREW]-[WBNB] Uni LP [+] [-] [<=>] Price: $66.09 TVL: $3,319,280.85\n', 'BREW Price: $2.78\n', 'WBNB Price: $370.30\n', 'Staked: 49382.7623 Cafe-LP ($3,263,510.18)\n', 'BREW Per Week: 42979.58 ($119,438.27)\n', 'APR: Day 0.52% Week 3.66% Year 190.31%\n', 'You are staking 0.00 [BREW]-[WBNB] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BREW]-[WBNB] Uni LP\n', 'Unstake 0.00 [BREW]-[WBNB] Uni LP\n', 'Claim 0.00 BREW ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '15 - [BREW]-[BUSD] Uni LP [+] [-] [<=>] Price: $3.50 TVL: $1,579,966.51\n', 'BREW Price: $2.78\n', 'BUSD Price: $1.00\n', 'Staked: 445932.9115 Cafe-LP ($1,560,722.65)\n', 'BREW Per Week: 21489.79 ($59,719.14)\n', 'APR: Day 0.55% Week 3.83% Year 198.97%\n', 'You are staking 0.00 [BREW]-[BUSD] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BREW]-[BUSD] Uni LP\n', 'Unstake 0.00 [BREW]-[BUSD] Uni LP\n', 'Claim 0.00 BREW ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '16 - [Cake]-[BREW] Uni LP [+] [-] [<=>] Price: $14.11 TVL: $1,333,807.83\n', 'Cake Price: $17.35\n', 'BREW Price: $2.78\n', 'Staked: 94167.4747 Cafe-LP ($1,328,493.14)\n', 'BREW Per Week: 17191.83 ($47,775.31)\n', 'APR: Day 0.51% Week 3.60% Year 187.00%\n', 'You are staking 0.00 [Cake]-[BREW] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [Cake]-[BREW] Uni LP\n', 'Unstake 0.00 [Cake]-[BREW] Uni LP\n', 'Claim 0.00 BREW ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '17 - [ETH]-[BREW] Uni LP [+] [-] [<=>] Price: $171.21 TVL: $1,305,335.49\n', 'ETH Price: $2,580.14\n', 'BREW Price: $2.78\n', 'Staked: 7606.5538 Cafe-LP ($1,302,313.16)\n', 'BREW Per Week: 17191.83 ($47,775.31)\n', 'APR: Day 0.52% Week 3.67% Year 190.76%\n', 'You are staking 0.00 [ETH]-[BREW] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [ETH]-[BREW] Uni LP\n', 'Unstake 0.00 [ETH]-[BREW] Uni LP\n', 'Claim 0.00 BREW ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '18 - [DOT]-[BREW] Uni LP [+] [-] [<=>] Price: $16.89 TVL: $1,378,919.28\n', 'DOT Price: $25.00\n', 'BREW Price: $2.78\n', 'Staked: 81193.0252 Cafe-LP ($1,371,127.32)\n', 'BREW Per Week: 17191.83 ($47,775.31)\n', 'APR: Day 0.50% Week 3.48% Year 181.19%\n', 'You are staking 0.00 [DOT]-[BREW] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DOT]-[BREW] Uni LP\n', 'Unstake 0.00 [DOT]-[BREW] Uni LP\n', 'Claim 0.00 BREW ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '19 - [BTCB]-[WBNB] Uni LP [+] [-] [<=>] Price: $7,763.13 TVL: $173,807.50\n', 'BTCB Price: $39,910.00\n', 'WBNB Price: $370.30\n', 'Staked: 14.1630 Cafe-LP ($109,948.92)\n', 'BREW Per Week: 343.84 ($955.51)\n', 'APR: Day 0.12% Week 0.87% Year 45.19%\n', 'You are staking 0.00 [BTCB]-[WBNB] Uni LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BTCB]-[WBNB] Uni LP\n', 'Unstake 0.00 [BTCB]-[WBNB] Uni LP\n', 'Claim 0.00 BREW ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '20 - [TWT]-[WBNB] Uni LP [+] [-] [<=>] Price: $23.87 TVL: $107,898.75\n', 'TWT Price: $0 ...
# [['**********************************************************************************\n', '\n', '0 - [DONUT]-[BUSD] Cake LP [+] [-] [<=>] Price: $0.11 TVL: $2,575.36\n', 'DONUT Price: $0.002525\n', 'BUSD Price: $1.00\n', 'Staked: 23004.0958 Cake-LP ($2,476.85)\n', 'DONUT Per Week: 62511.63 ($157.83)\n', 'APR: Day 0.91% Week 6.37% Year 331.36%\n', 'You are staking 0.00 [DONUT]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DONUT]-[BUSD] Cake LP\n', 'Unstake 0.00 [DONUT]-[BUSD] Cake LP\n', 'Claim 0.00 DONUT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - [DONUT]-[WBNB] Cake LP [+] [-] [<=>] Price: $2.11 TVL: $3,197.44\n', 'DONUT Price: $0.002525\n', 'WBNB Price: $370.30\n', 'Staked: 482.7470 Cake-LP ($1,018.23)\n', 'DONUT Per Week: 37506.98 ($94.70)\n', 'APR: Day 1.33% Week 9.30% Year 483.62%\n', 'You are staking 0.00 [DONUT]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DONUT]-[WBNB] Cake LP\n', 'Unstake 0.00 [DONUT]-[WBNB] Cake LP\n', 'Claim 0.00 DONUT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '2 - [WBNB]-[BUSD] Cake LP [+] [-] [<=>] Price: $53.30 TVL: $7,242,035.65\n', 'WBNB Price: $370.30\n', 'BUSD Price: $1.00\n', 'Staked: 7.4370 Cake-LP ($396.40)\n', 'DONUT Per Week: 7813.95 ($19.73)\n', 'APR: Day 0.71% Week 4.98% Year 258.80%\n', 'You are staking 0.00 [WBNB]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BUSD] Cake LP - Fee 4%\n', 'Unstake 0.00 [WBNB]-[BUSD] Cake LP\n', 'Claim 0.00 DONUT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '3 - [USDT]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.12 TVL: $6,722,434.56\n', 'USDT Price: $1.00\n', 'BUSD Price: $1.00\n', 'Staked: 454.9171 Cake-LP ($965.64)\n', 'DONUT Per Week: 6251.16 ($15.78)\n', 'APR: Day 0.23% Week 1.63% Year 84.99%\n', 'You are staking 0.00 [USDT]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [USDT]-[BUSD] Cake LP - Fee 4%\n', 'Unstake 0.00 [USDT]-[BUSD] Cake LP\n', 'Claim 0.00 DONUT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '4 - [BTCB]-[WBNB] Cake LP [+] [-] [<=>] Price: $8,436.01 TVL: $3,131,515.31\n', 'BTCB Price: $39,910.00\n', 'WBNB Price: $370.30\n', 'Staked: 0.1136 Cake-LP ($958.66)\n', 'DONUT Per Week: 9376.74 ($23.67)\n', 'APR: Day 0.35% Week 2.47% Year 128.42%\n', 'You are staking 0.00 [BTCB]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BTCB]-[WBNB] Cake LP - Fee 4%\n', 'Unstake 0.00 [BTCB]-[WBNB] Cake LP\n', 'Claim 0.00 DONUT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '5 - [ETH]-[WBNB] Cake LP [+] [-] [<=>] Price: $2,183.22 TVL: $3,864,531.35\n', 'ETH Price: $2,580.14\n', 'WBNB Price: $370.30\n', 'Staked: 0.2629 Cake-LP ($574.02)\n', 'DONUT Per Week: 9376.74 ($23.67)\n', 'APR: Day 0.59% Week 4.12% Year 214.47%\n', 'You are staking 0.00 [ETH]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [ETH]-[WBNB] Cake LP - Fee 4%\n', 'Unstake 0.00 [ETH]-[WBNB] Cake LP\n', 'Claim 0.00 DONUT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '6 - [DAI]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.05 TVL: $5,739,485.01\n', 'DAI Price: $1.01\n', 'BUSD Price: $1.00\n', 'Staked: 209.4851 Cake-LP ($430.49)\n', 'DONUT Per Week: 6251.16 ($15.78)\n', 'APR: Day 0.52% Week 3.67% Year 190.65%\n', 'You are staking 0.00 [DAI]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DAI]-[BUSD] Cake LP - Fee 4%\n', 'Unstake 0.00 [DAI]-[BUSD] Cake LP\n', 'Claim 0.00 DONUT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '7 - [USDC]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.24 TVL: $2,597,966.13\n', 'USDC Price: $1.00\n', 'BUSD Price: $1.00\n', 'Staked: 120.7452 Cake-LP ($270.92)\n', 'DONUT Per Week: 6251.16 ($15.78)\n', 'APR: Day 0.83% Week 5.83% Year 302.94%\n', 'You are staking 0.00 [USDC]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [USDC]-[BUSD] Cake LP - Fee 4%\n', 'Unstake 0.00 [USDC]-[BUSD] Cake LP\n', 'Claim 0.00 DONUT ($0.00)\n', 'Staking or unstaki ...
# [['*************************************************************************************\n', '\n', '0 - Ramen Price: $0.39 Market Cap: $1,468,313.14 [%]\n', 'Staked: 2101485.8315 Ramen ($821,877.53)\n', 'RAMEN Per Week: 50400.00 ($19,711.11)\n', 'APR: Day 0.34% Week 2.40% Year 124.71%\n', 'You are staking 0.00 Ramen ($0.00), 0.00% of the pool.\n', 'Stake 0.00 Ramen\n', 'Unstake 0.00 Ramen\n', 'Claim 0.00 RAMEN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - [Ramen]-[WBNB] Cake LP [+] [-] [<=>] Price: $27.25 TVL: $452,850.93\n', 'Ramen Price: $0.39\n', 'WBNB Price: $370.30\n', 'Staked: 16057.4311 Cake-LP ($437,616.26)\n', 'RAMEN Per Week: 78750.00 ($30,798.62)\n', 'APR: Day 1.01% Week 7.04% Year 365.97%\n', 'You are staking 0.00 [Ramen]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [Ramen]-[WBNB] Cake LP\n', 'Unstake 0.00 [Ramen]-[WBNB] Cake LP\n', 'Claim 0.00 RAMEN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '2 - [WBNB]-[BUSD] Cake LP [+] [-] [<=>] Price: $53.30 TVL: $7,242,036.94\n', 'WBNB Price: $370.30\n', 'BUSD Price: $1.00\n', 'Staked: 30092.4075 Cake-LP ($1,603,951.43)\n', 'RAMEN Per Week: 9450.00 ($3,695.83)\n', 'APR: Day 0.03% Week 0.23% Year 11.98%\n', 'You are staking 0.00 [WBNB]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BUSD] Cake LP\n', 'Unstake 0.00 [WBNB]-[BUSD] Cake LP\n', 'Claim 0.00 RAMEN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '3 - [Ramen]-[BUSD] Cake LP [+] [-] [<=>] Price: $1.36 TVL: $359,071.82\n', 'Ramen Price: $0.39\n', 'BUSD Price: $1.00\n', 'Staked: 256557.4609 Cake-LP ($349,807.02)\n', 'RAMEN Per Week: 63000.00 ($24,638.89)\n', 'APR: Day 1.01% Week 7.04% Year 366.27%\n', 'You are staking 0.00 [Ramen]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [Ramen]-[BUSD] Cake LP\n', 'Unstake 0.00 [Ramen]-[BUSD] Cake LP\n', 'Claim 0.00 RAMEN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', 'Total Staked: $3,213,252.25\n', '\n', '\n'], 5488]
# [['**********************************************************************************\n', '\n', '0 - [BUSD]-[EGG] Cake LP [+] [-] [<=>] Price: $3.46 TVL: $3,109,263.32\n', 'BUSD Price: $1.00\n', 'EGG Price: $2.42\n', 'Staked: 881705.1846 Cake-LP ($3,049,624.44)\n', 'EGG Per Week: 45522.58 ($110,164.65)\n', 'APR: Day 0.52% Week 3.61% Year 187.84%\n', 'You are staking 0.00 [BUSD]-[EGG] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BUSD]-[EGG] Cake LP\n', 'Unstake 0.00 [BUSD]-[EGG] Cake LP\n', 'Claim 0.00 EGG ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - [WBNB]-[EGG] Cake LP [+] [-] [<=>] Price: $66.32 TVL: $3,219,478.39\n', 'WBNB Price: $370.30\n', 'EGG Price: $2.42\n', 'Staked: 47961.4396 Cake-LP ($3,180,782.38)\n', 'EGG Per Week: 45522.58 ($110,164.65)\n', 'APR: Day 0.49% Week 3.46% Year 180.10%\n', 'You are staking 0.00 [WBNB]-[EGG] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[EGG] Cake LP\n', 'Unstake 0.00 [WBNB]-[EGG] Cake LP\n', 'Claim 0.00 EGG ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '2 - [WBNB]-[BUSD] Cake LP [+] [-] [<=>] Price: $53.30 TVL: $7,242,036.78\n', 'WBNB Price: $370.30\n', 'BUSD Price: $1.00\n', 'Staked: 15937.9140 Cake-LP ($849,504.63)\n', 'EGG Per Week: 3793.55 ($9,180.39)\n', 'APR: Day 0.15% Week 1.08% Year 56.20%\n', 'You are staking 0.00 [WBNB]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BUSD] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [WBNB]-[BUSD] Cake LP\n', 'Claim 0.00 EGG ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '3 - [USDT]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.12 TVL: $6,722,434.56\n', 'USDT Price: $1.00\n', 'BUSD Price: $1.00\n', 'Staked: 885224.2002 Cake-LP ($1,879,043.75)\n', 'EGG Per Week: 3034.84 ($7,344.31)\n', 'APR: Day 0.06% Week 0.39% Year 20.32%\n', 'You are staking 0.00 [USDT]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [USDT]-[BUSD] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [USDT]-[BUSD] Cake LP\n', 'Claim 0.00 EGG ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '4 - [BTCB]-[WBNB] Cake LP [+] [-] [<=>] Price: $8,436.01 TVL: $3,131,515.31\n', 'BTCB Price: $39,910.00\n', 'WBNB Price: $370.30\n', 'Staked: 236.5663 Cake-LP ($1,995,674.52)\n', 'EGG Per Week: 4552.26 ($11,016.46)\n', 'APR: Day 0.08% Week 0.55% Year 28.70%\n', 'You are staking 0.00 [BTCB]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BTCB]-[WBNB] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [BTCB]-[WBNB] Cake LP\n', 'Claim 0.00 EGG ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '5 - [ETH]-[WBNB] Cake LP [+] [-] [<=>] Price: $2,183.24 TVL: $3,831,340.83\n', 'ETH Price: $2,580.18\n', 'WBNB Price: $370.30\n', 'Staked: 1289.1989 Cake-LP ($2,814,626.19)\n', 'EGG Per Week: 4552.26 ($11,016.46)\n', 'APR: Day 0.06% Week 0.39% Year 20.35%\n', 'You are staking 0.00 [ETH]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [ETH]-[WBNB] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [ETH]-[WBNB] Cake LP\n', 'Claim 0.00 EGG ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '6 - [DAI]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.05 TVL: $5,739,485.01\n', 'DAI Price: $1.01\n', 'BUSD Price: $1.00\n', 'Staked: 827746.9368 Cake-LP ($1,701,002.82)\n', 'EGG Per Week: 3034.84 ($7,344.31)\n', 'APR: Day 0.06% Week 0.43% Year 22.45%\n', 'You are staking 0.00 [DAI]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DAI]-[BUSD] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [DAI]-[BUSD] Cake LP\n', 'Claim 0.00 EGG ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '7 - [USDC]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.24 TVL: $2,597,966.13\n', 'USDC Price: $1.00\n', 'BUSD Price: $1.00\n', 'Staked: 754777.7378 Cake-LP ($1,693,538.02)\n', 'EGG Per Week: 3034.84 ($7,344.31)\n', 'APR: Day 0.06% Week 0.43% Year 22.55%\n', 'You are staking 0.00 [USDC]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [USDC]-[BUSD] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [USDC]-[BUSD] Cake LP\n', ...
# [['*************************************************************************************\n', '\n', '0 - SALT Price: $0.08 Market Cap: $220,952.62 [%]\n', 'Staked: 989243.6266 SALT ($75,436.34)\n', 'SALT Per Week: 15750.00 ($1,201.04)\n', 'APR: Day 0.23% Week 1.59% Year 82.79%\n', 'You are staking 0.00 SALT ($0.00), 0.00% of the pool.\n', 'Stake 0.00 SALT\n', 'Unstake 0.00 SALT\n', 'Claim 0.00 SALT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - [SALT]-[BUSD] Cake LP [+] [-] [<=>] Price: $0.62 TVL: $108,039.63\n', 'SALT Price: $0.08\n', 'BUSD Price: $1.00\n', 'Staked: 168849.1362 Cake-LP ($104,668.19)\n', 'SALT Per Week: 63000.00 ($4,804.16)\n', 'APR: Day 0.66% Week 4.59% Year 238.67%\n', 'You are staking 0.00 [SALT]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [SALT]-[BUSD] Cake LP\n', 'Unstake 0.00 [SALT]-[BUSD] Cake LP\n', 'Claim 0.00 SALT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '2 - [SALT]-[WBNB] Cake LP [+] [-] [<=>] Price: $11.76 TVL: $64,188.69\n', 'SALT Price: $0.08\n', 'WBNB Price: $370.30\n', 'Staked: 5327.8275 Cake-LP ($62,681.64)\n', 'SALT Per Week: 37800.00 ($2,882.50)\n', 'APR: Day 0.66% Week 4.60% Year 239.13%\n', 'You are staking 0.00 [SALT]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [SALT]-[WBNB] Cake LP\n', 'Unstake 0.00 [SALT]-[WBNB] Cake LP\n', 'Claim 0.00 SALT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '3 - [WBNB]-[BUSD] Cake LP [+] [-] [<=>] Price: $53.30 TVL: $7,242,037.10\n', 'WBNB Price: $370.30\n', 'BUSD Price: $1.00\n', 'Staked: 627.7080 Cake-LP ($33,457.38)\n', 'SALT Per Week: 7875.00 ($600.52)\n', 'APR: Day 0.26% Week 1.79% Year 93.33%\n', 'You are staking 0.00 [WBNB]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BUSD] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [WBNB]-[BUSD] Cake LP\n', 'Claim 0.00 SALT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '4 - [DAI]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.05 TVL: $5,739,485.53\n', 'DAI Price: $1.01\n', 'BUSD Price: $1.00\n', 'Staked: 62635.0394 Cake-LP ($128,713.72)\n', 'SALT Per Week: 6300.00 ($480.42)\n', 'APR: Day 0.05% Week 0.37% Year 19.41%\n', 'You are staking 0.00 [DAI]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DAI]-[BUSD] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [DAI]-[BUSD] Cake LP\n', 'Claim 0.00 SALT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '5 - [ETH]-[BETH] Cake LP [+] [-] [<=>] Price: $5,030.99 TVL: $34,591,455.29\n', 'ETH Price: $2,579.97\n', 'BETH Price: $2,413.48\n', 'Staked: 9.6332 Cake-LP ($48,464.41)\n', 'SALT Per Week: 6300.00 ($480.42)\n', 'APR: Day 0.14% Week 0.99% Year 51.55%\n', 'You are staking 0.00 [ETH]-[BETH] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [ETH]-[BETH] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [ETH]-[BETH] Cake LP\n', 'Claim 0.00 SALT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '6 - [Cake]-[BUSD] Cake LP [+] [-] [<=>] Price: $12.84 TVL: $411,826.23\n', 'Cake Price: $17.35\n', 'BUSD Price: $1.00\n', 'Staked: 1967.1641 Cake-LP ($25,253.55)\n', 'SALT Per Week: 6300.00 ($480.42)\n', 'APR: Day 0.27% Week 1.90% Year 98.92%\n', 'You are staking 0.00 [Cake]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [Cake]-[BUSD] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [Cake]-[BUSD] Cake LP\n', 'Claim 0.00 SALT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '7 - [Cake]-[WBNB] Cake LP [+] [-] [<=>] Price: $188.61 TVL: $6,752,594.12\n', 'Cake Price: $17.35\n', 'WBNB Price: $370.30\n', 'Staked: 52.0167 Cake-LP ($9,810.81)\n', 'SALT Per Week: 3150.00 ($240.21)\n', 'APR: Day 0.35% Week 2.45% Year 127.32%\n', 'You are staking 0.00 [Cake]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [Cake]-[WBNB] Cake LP - Fee 1.5%\n', 'Unstake 0.00 [Cake]-[WBNB] Cake LP\n', 'Claim 0.00 SALT ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '8 - BUSD Price: $1.00 Market Cap: $4,201,000,000.00 [%]\n', 'Staked: 93462 ...
# [['*********************************************************************************\n', '\n', '0 - [SOUP]-[WBNB] Cake LP [+] [-] [<=>] Price: $71.05 TVL: $38,538.38\n', 'SOUP Price: $3.06\n', 'WBNB Price: $370.30\n', 'Staked: 463.3730 Cake-LP ($32,921.23)\n', 'SOUPS Per Week: 612.86 ($881.04)\n', 'APR: Day 0.38% Week 2.68% Year 139.16%\n', 'You are staking 0.00 [SOUP]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [SOUP]-[WBNB] Cake LP\n', 'Unstake 0.00 [SOUP]-[WBNB] Cake LP\n', 'Claim 0.00 SOUPS ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - [SOUPS]-[WBNB] Cake LP [+] [-] [<=>] Price: $52.06 TVL: $12,492.67\n', 'SOUPS Price: $1.44\n', 'WBNB Price: $370.30\n', 'Staked: 230.4307 Cake-LP ($11,995.64)\n', 'SOUPS Per Week: 193.54 ($278.22)\n', 'APR: Day 0.33% Week 2.32% Year 120.61%\n', 'You are staking 0.00 [SOUPS]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [SOUPS]-[WBNB] Cake LP\n', 'Unstake 0.00 [SOUPS]-[WBNB] Cake LP\n', 'Claim 0.00 SOUPS ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '\n'], 6538]
# [['**********************************************************************************\n', '\n', '0 - KEBAB Price: $0.42 Market Cap: $1,972,667.81 [%]\n', 'Staked: 2319386.0378 KEBAB ($973,242.79)\n', 'KEBAB Per Week: 50355.52 ($21,129.79)\n', 'APR: Day 0.31% Week 2.17% Year 112.90%\n', 'You are staking 0.00 KEBAB ($0.00), 0.00% of the pool.\n', 'Stake 0.00 KEBAB\n', 'Unstake 0.00 KEBAB\n', 'Claim 0.00 KEBAB ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - [KEBAB]-[BUSD] Cake LP [+] [-] [<=>] Price: $1.49 TVL: $482,700.76\n', 'KEBAB Price: $0.42\n', 'BUSD Price: $1.00\n', 'Staked: 316090.3947 Cake-LP ($472,013.66)\n', 'KEBAB Per Week: 35586.94 ($14,932.71)\n', 'APR: Day 0.45% Week 3.16% Year 164.51%\n', 'You are staking 0.00 [KEBAB]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [KEBAB]-[BUSD] Cake LP\n', 'Unstake 0.00 [KEBAB]-[BUSD] Cake LP\n', 'Claim 0.00 KEBAB ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '2 - [WBNB]-[BUSD] Cake LP [+] [-] [<=>] Price: $53.31 TVL: $7,242,733.55\n', 'WBNB Price: $370.37\n', 'BUSD Price: $1.00\n', 'Staked: 30315.1900 Cake-LP ($1,615,981.36)\n', 'KEBAB Per Week: 5338.04 ($2,239.91)\n', 'APR: Day 0.02% Week 0.14% Year 7.21%\n', 'You are staking 0.00 [WBNB]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[BUSD] Cake LP\n', 'Unstake 0.00 [WBNB]-[BUSD] Cake LP\n', 'Claim 0.00 KEBAB ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '3 - [USDT]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.12 TVL: $6,722,434.56\n', 'USDT Price: $1.00\n', 'BUSD Price: $1.00\n', 'Staked: 110777.3745 Cake-LP ($235,144.42)\n', 'KEBAB Per Week: 1779.35 ($746.64)\n', 'APR: Day 0.05% Week 0.32% Year 16.51%\n', 'You are staking 0.00 [USDT]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [USDT]-[BUSD] Cake LP\n', 'Unstake 0.00 [USDT]-[BUSD] Cake LP\n', 'Claim 0.00 KEBAB ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '4 - [BTCB]-[BUSD] Cake LP [+] [-] [<=>] Price: $439.67 TVL: $330,879.56\n', 'BTCB Price: $39,910.00\n', 'BUSD Price: $1.00\n', 'Staked: 728.9125 Cake-LP ($320,477.81)\n', 'KEBAB Per Week: 8896.73 ($3,733.18)\n', 'APR: Day 0.17% Week 1.16% Year 60.57%\n', 'You are staking 0.00 [BTCB]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [BTCB]-[BUSD] Cake LP\n', 'Unstake 0.00 [BTCB]-[BUSD] Cake LP\n', 'Claim 0.00 KEBAB ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '5 - [KEBAB]-[WBNB] Cake LP [+] [-] [<=>] Price: $28.13 TVL: $284,662.91\n', 'KEBAB Price: $0.42\n', 'WBNB Price: $370.37\n', 'Staked: 9756.9680 Cake-LP ($274,481.58)\n', 'KEBAB Per Week: 21352.16 ($8,959.63)\n', 'APR: Day 0.47% Week 3.26% Year 169.74%\n', 'You are staking 0.00 [KEBAB]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [KEBAB]-[WBNB] Cake LP\n', 'Unstake 0.00 [KEBAB]-[WBNB] Cake LP\n', 'Claim 0.00 KEBAB ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '7 - [DOT]-[BUSD] Cake LP [+] [-] [<=>] Price: $10.89 TVL: $202,990.91\n', 'DOT Price: $25.05\n', 'BUSD Price: $1.00\n', 'Staked: 18126.1982 Cake-LP ($197,383.56)\n', 'KEBAB Per Week: 3558.69 ($1,493.27)\n', 'APR: Day 0.11% Week 0.76% Year 39.34%\n', 'You are staking 0.00 [DOT]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DOT]-[BUSD] Cake LP\n', 'Unstake 0.00 [DOT]-[BUSD] Cake LP\n', 'Claim 0.00 KEBAB ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '8 - [DAI]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.05 TVL: $5,739,485.53\n', 'DAI Price: $1.01\n', 'BUSD Price: $1.00\n', 'Staked: 100876.2640 Cake-LP ($207,298.65)\n', 'KEBAB Per Week: 1779.35 ($746.64)\n', 'APR: Day 0.05% Week 0.36% Year 18.73%\n', 'You are staking 0.00 [DAI]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DAI]-[BUSD] Cake LP\n', 'Unstake 0.00 [DAI]-[BUSD] Cake LP\n', 'Claim 0.00 KEBAB ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '9 - [USDC]-[BUSD] Cake LP [+] [-] [<=>] Price: $2.25 TVL: $2,610,947.86\n', 'USDC Pr ...
# [['************************************************************************************\n', '\n', '[KIMOCHI]-[WBNB] Cake LP [+] [-] [<=>] Price: $6.82 TVL: $26,243.52\n', 'KIMOCHI Price: $0.02\n', 'WBNB Price: $370.37\n', 'Staked: 3769.3093 Cake-LP ($25,691.34)\n', 'KIMOCHI Per Week: 175304.35 ($3,547.90)\n', 'APR: Day 1.97% Week 13.81% Year 718.11%\n', 'You are staking 0.00 [KIMOCHI]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [KIMOCHI]-[WBNB] Cake LP\n', 'Unstake 0.00 [KIMOCHI]-[WBNB] Cake LP\n', 'Claim 0.00 KIMOCHI ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '[KIMOCHI]-[BUSD] Cake LP [+] [-] [<=>] Price: $0.36 TVL: $25,955.66\n', 'KIMOCHI Price: $0.02\n', 'BUSD Price: $1.00\n', 'Staked: 57701.9036 Cake-LP ($20,601.27)\n', 'KIMOCHI Per Week: 175304.35 ($3,547.90)\n', 'APR: Day 2.46% Week 17.22% Year 895.53%\n', 'You are staking 0.00 [KIMOCHI]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [KIMOCHI]-[BUSD] Cake LP\n', 'Unstake 0.00 [KIMOCHI]-[BUSD] Cake LP\n', 'Claim 0.00 KIMOCHI ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', 'USDT Price: $1.00 Market Cap: $2,979,997,922.18 [%]\n', 'Staked: 100066.2617 USDT ($100,066.26)\n', 'KIMOCHI Per Week: 8765.22 ($177.40)\n', 'APR: Day 0.03% Week 0.18% Year 9.22%\n', 'You are staking 0.00 USDT ($0.00), 0.00% of the pool.\n', 'Stake 0.00 USDT\n', 'Unstake 0.00 USDT\n', 'Claim 0.00 KIMOCHI ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', 'Cake Price: $17.35 Market Cap: $5,796,307,133.22 [%]\n', 'Staked: 253.9147 Cake ($4,405.42)\n', 'KIMOCHI Per Week: 8765.22 ($177.40)\n', 'APR: Day 0.58% Week 4.03% Year 209.39%\n', 'You are staking 0.00 Cake ($0.00), 0.00% of the pool.\n', 'Stake 0.00 Cake\n', 'Unstake 0.00 Cake\n', 'Claim 0.00 KIMOCHI ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', 'BTCB Price: $39,910.00 Market Cap: $3,212,794,910.00 [%]\n', 'Staked: 0.0518 BTCB ($2,066.44)\n', 'KIMOCHI Per Week: 8765.22 ($177.40)\n', 'APR: Day 1.23% Week 8.58% Year 446.40%\n', 'You are staking 0.00 BTCB ($0.00), 0.00% of the pool.\n', 'Stake 0.00 BTCB\n', 'Unstake 0.00 BTCB\n', 'Claim 0.00 KIMOCHI ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', 'ETH Price: $2,580.46 Market Cap: $3,367,500,300.00 [%]\n', 'Staked: 3.1831 ETH ($8,213.81)\n', 'KIMOCHI Per Week: 8765.22 ($177.40)\n', 'APR: Day 0.31% Week 2.16% Year 112.31%\n', 'You are staking 0.00 ETH ($0.00), 0.00% of the pool.\n', 'Stake 0.00 ETH\n', 'Unstake 0.00 ETH\n', 'Claim 0.00 KIMOCHI ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', 'BSCX Price: $2.81 Market Cap: $28,053,342.76 [%]\n', 'Staked: 1236.2720 BSCX ($3,473.92)\n', 'KIMOCHI Per Week: 8765.22 ($177.40)\n', 'APR: Day 0.73% Week 5.11% Year 265.54%\n', 'You are staking 0.00 BSCX ($0.00), 0.00% of the pool.\n', 'Stake 0.00 BSCX\n', 'Unstake 0.00 BSCX\n', 'Claim 0.00 KIMOCHI ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', 'BETH Price: $2,413.48 Market Cap: $241,348,000,000.00 [%]\n', 'Staked: 1.6512 BETH ($3,985.20)\n', 'KIMOCHI Per Week: 8765.22 ($177.40)\n', 'APR: Day 0.64% Week 4.45% Year 231.47%\n', 'You are staking 0.00 BETH ($0.00), 0.00% of the pool.\n', 'Stake 0.00 BETH\n', 'Unstake 0.00 BETH\n', 'Claim 0.00 KIMOCHI ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '\n'], 6834]
# [['******************************************************************************\n', '\n', '0 - NYAN Price: $0.003986 Market Cap: $15,278.95 [%]\n', 'Staked: 1317970.3670 NYAN ($5,252.84)\n', 'NYAN Per Week: 49745.45 ($198.26)\n', 'APR: Day 0.54% Week 3.77% Year 196.27%\n', 'You are staking 0.00 NYAN ($0.00), 0.00% of the pool.\n', 'Stake 0.00 NYAN\n', 'Unstake 0.00 NYAN\n', 'Claim 0.00 NYAN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - [NYAN]-[WBNB] Cake LP [+] [-] [<=>] Price: $2.90 TVL: $2,571.10\n', 'NYAN Price: $0.003986\n', 'WBNB Price: $370.37\n', 'Staked: 825.6649 Cake-LP ($2,393.80)\n', 'NYAN Per Week: 32727.27 ($130.44)\n', 'APR: Day 0.78% Week 5.45% Year 283.34%\n', 'You are staking 0.00 [NYAN]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [NYAN]-[WBNB] Cake LP\n', 'Unstake 0.00 [NYAN]-[WBNB] Cake LP\n', 'Claim 0.00 NYAN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '2 - [NYAN]-[BUSD] Cake LP [+] [-] [<=>] Price: $0.14 TVL: $671.01\n', 'NYAN Price: $0.003986\n', 'BUSD Price: $1.00\n', 'Staked: 4785.2127 Cake-LP ($648.08)\n', 'NYAN Per Week: 15709.09 ($62.61)\n', 'APR: Day 1.38% Week 9.66% Year 502.36%\n', 'You are staking 0.00 [NYAN]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [NYAN]-[BUSD] Cake LP\n', 'Unstake 0.00 [NYAN]-[BUSD] Cake LP\n', 'Claim 0.00 NYAN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '3 - [NYAN]-[BTCB] Cake LP [+] [-] [<=>] Price: $26.46 TVL: $1,286.88\n', 'NYAN Price: $0.003986\n', 'BTCB Price: $39,910.00\n', 'Staked: 42.1595 Cake-LP ($1,115.35)\n', 'NYAN Per Week: 26181.82 ($104.35)\n', 'APR: Day 1.34% Week 9.36% Year 486.50%\n', 'You are staking 0.00 [NYAN]-[BTCB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [NYAN]-[BTCB] Cake LP\n', 'Unstake 0.00 [NYAN]-[BTCB] Cake LP\n', 'Claim 0.00 NYAN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '4 - [DAI]-[NYAN] Cake LP [+] [-] [<=>] Price: $0.13 TVL: $578.86\n', 'DAI Price: $1.01\n', 'NYAN Price: $0.003986\n', 'Staked: 4186.7443 Cake-LP ($551.10)\n', 'NYAN Per Week: 15709.09 ($62.61)\n', 'APR: Day 1.62% Week 11.36% Year 590.76%\n', 'You are staking 0.00 [DAI]-[NYAN] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [DAI]-[NYAN] Cake LP\n', 'Unstake 0.00 [DAI]-[NYAN] Cake LP\n', 'Claim 0.00 NYAN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '5 - [ETH]-[NYAN] Cake LP [+] [-] [<=>] Price: $6.66 TVL: $637.86\n', 'ETH Price: $2,580.34\n', 'NYAN Price: $0.003986\n', 'Staked: 93.7150 Cake-LP ($623.89)\n', 'NYAN Per Week: 19636.36 ($78.26)\n', 'APR: Day 1.79% Week 12.54% Year 652.29%\n', 'You are staking 0.00 [ETH]-[NYAN] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [ETH]-[NYAN] Cake LP\n', 'Unstake 0.00 [ETH]-[NYAN] Cake LP\n', 'Claim 0.00 NYAN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '6 - [NYAN]-[DOT] Cake LP [+] [-] [<=>] Price: $0.66 TVL: $1,191.15\n', 'NYAN Price: $0.003986\n', 'DOT Price: $25.02\n', 'Staked: 1490.7417 Cake-LP ($982.51)\n', 'NYAN Per Week: 19636.36 ($78.26)\n', 'APR: Day 1.14% Week 7.97% Year 414.21%\n', 'You are staking 0.00 [NYAN]-[DOT] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [NYAN]-[DOT] Cake LP\n', 'Unstake 0.00 [NYAN]-[DOT] Cake LP\n', 'Claim 0.00 NYAN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '7 - [NYAN]-[EOS] Cake LP [+] [-] [<=>] Price: $0.30 TVL: $525.84\n', 'NYAN Price: $0.003986\n', 'EOS Price: $5.26\n', 'Staked: 1639.9777 Cake-LP ($490.05)\n', 'NYAN Per Week: 13090.91 ($52.17)\n', 'APR: Day 1.52% Week 10.65% Year 553.63%\n', 'You are staking 0.00 [NYAN]-[EOS] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [NYAN]-[EOS] Cake LP\n', 'Unstake 0.00 [NYAN]-[EOS] Cake LP\n', 'Claim 0.00 NYAN ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '8 - [WBNB]-[BUSD] Cake LP [+] [-] [<=>] Price: $53.31 TVL: $7,242,758.93\n', 'WBNB Price: $370.37\n', 'BUSD Price: $1.00\n', 'Staked: 17.7599 Cake-LP ($946.71)\n', 'NYAN Per W ...
# ...
# [['**************************************************************************************\n', '\n', '0 - RICE Price: $0.74 Market Cap: $9,405,650.70 [%]\n', 'Staked: 2227481.6356 RICE ($1,637,716.45)\n', 'RICE Per Week: 604800.00 ($444,668.50)\n', 'APR: Day 3.88% Week 27.15% Year 1411.89%\n', 'You are staking 0.00 RICE ($0.00), 0.00% of the pool.\n', 'Stake 0.00 RICE\n', 'Unstake 0.00 RICE\n', 'Claim 0.00 RICE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '1 - TeslaSafe Price: $0.0000000144 Market Cap: $14,447,606.15 [%]\n', 'Staked: 114340490373340.3438 TeslaSafe ($1,651,946.37)\n', 'RICE Per Week: 403200.00 ($296,445.66)\n', 'APR: Day 2.56% Week 17.95% Year 933.15%\n', 'You are staking 0.00 TeslaSafe ($0.00), 0.00% of the pool.\n', 'Stake 0.00 TeslaSafe\n', 'Unstake 0.00 TeslaSafe\n', 'Claim 0.00 RICE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '2 - [WBNB]-[RICE] Cake LP [+] [-] [<=>] Price: $50.20 TVL: $519,434.87\n', 'WBNB Price: $365.53\n', 'RICE Price: $0.74\n', 'Staked: 10275.7464 Cake-LP ($515,806.04)\n', 'RICE Per Week: 1260000.00 ($926,392.70)\n', 'APR: Day 25.66% Week 179.60% Year 9339.25%\n', 'You are staking 0.00 [WBNB]-[RICE] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [WBNB]-[RICE] Cake LP\n', 'Unstake 0.00 [WBNB]-[RICE] Cake LP\n', 'Claim 0.00 RICE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '3 - [TeslaSafe]-[WBNB] Cake LP [+] [-] [<=>] Price: $168.04 TVL: $1,298,824.16\n', 'TeslaSafe Price: $0.0000000144\n', 'WBNB Price: $365.53\n', 'Staked: 3790.7595 Cake-LP ($636,996.07)\n', 'RICE Per Week: 1512000.00 ($1,111,671.24)\n', 'APR: Day 24.93% Week 174.52% Year 9074.92%\n', 'You are staking 0.00 [TeslaSafe]-[WBNB] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [TeslaSafe]-[WBNB] Cake LP\n', 'Unstake 0.00 [TeslaSafe]-[WBNB] Cake LP\n', 'Claim 0.00 RICE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', '4 - [RICE]-[BUSD] Cake LP [+] [-] [<=>] Price: $1.73 TVL: $528,098.32\n', 'RICE Price: $0.74\n', 'BUSD Price: $1.00\n', 'Staked: 304496.2656 Cake-LP ($527,153.03)\n', 'RICE Per Week: 1260000.00 ($926,392.70)\n', 'APR: Day 25.11% Week 175.74% Year 9138.22%\n', 'You are staking 0.00 [RICE]-[BUSD] Cake LP ($0.00), 0.00% of the pool.\n', 'Stake 0.00 [RICE]-[BUSD] Cake LP\n', 'Unstake 0.00 [RICE]-[BUSD] Cake LP\n', 'Claim 0.00 RICE ($0.00)\n', 'Staking or unstaking also claims rewards.\n', '\n', 'Total Staked: $4,969,617.95\n', '\n', '\n', '\n'], 47059]
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Block Start Line No.:  1
# None
# Block Start Line No.:  0
# None
# Block Start Line No.:  4
# None
# Block Start Line No.:  1744
# None
# Block Start Line No.:  2480
# None
# Block Start Line No.:  4480
# None
# Block Start Line No.:  4812
# None
# Block Start Line No.:  5188
# None
# Block Start Line No.:  5436
# None
# Block Start Line No.:  5488
# None
# Block Start Line No.:  6390
# None
# Block Start Line No.:  6510
# None
# Block Start Line No.:  6538
# None
# Block Start Line No.:  6746
# None
# Block Start Line No.:  6834
# None
# Block Start Line No.:  6970
# None
# Block Start Line No.:  7106
# None
# Block Start Line No.:  7302
# None
# Block Start Line No.:  7750
# None
# Block Start Line No.:  7862
# None
# Block Start Line No.:  8010
# None
# Block Start Line No.:  8066
# None
# Block Start Line No.:  8628
# None
# Block Start Line No.:  8877
# None
# Block Start Line No.:  8977
# None
# Block Start Line No.:  9235
# None
# Block Start Line No.:  9373
# None
# Block Start Line No.:  9621
# None
# Block Start Line No.:  10131
# None
# Block Start Line No.:  10257
# None
# Block Start Line No.:  10345
# None
# Block Start Line No.:  10937
# None
# Block Start Line No.:  10956
# None
# Block Start Line No.:  11030
# None
# Block Start Line No.:  11629
# None
# Block Start Line No.:  11819
# None
# Block Start Line No.:  12179
# None
# Block Start Line No.:  12357
# None
# Block Start Line No.:  12647
# None
# Block Start Line No.:  12761
# None
# Block Start Line No.:  12807
# None
# Block Start Line No.:  13255
# None
# Block Start Line No.:  13549
# None
# Block Start Line No.:  13699
# None
# Block Start Line No.:  15539
# None
# Block Start Line No.:  15740
# None
# Block Start Line No.:  15848
# None
# Block Start Line No.:  16320
# None
# Block Start Line No.:  16642
# None
# Block Start Line No.:  17253
# None
# Block Start Line No.:  17405
# None
# Block Start Line No.:  17679
# None
# Block Start Line No.:  18041
# None
# Block Start Line No.:  18189
# None
# Block Start Line No.:  18263
# None
# Block Start Line No.:  18469
# None
# Block Start Line No.:  18497
# None
# Block Start Line No.:  18693
# None
# Block Start Line No.:  18781
# None
# Block Start Line No.:  18847
# None
# Block Start Line No.:  18921
# None
# Block Start Line No.:  19387
# None
# Block Start Line No.:  19455
# None
# Block Start Line No.:  19555
# None
# Block Start Line No.:  19805
# None
# Block Start Line No.:  19935
# None
# Block Start Line No.:  19963
# None
# Block Start Line No.:  20208
# None
# Block Start Line No.:  20288
# None
# Block Start Line No.:  20483
# None
# Block Start Line No.:  20802
# None
# Block Start Line No.:  20950
# None
# Block Start Line No.:  21204
# None
# Block Start Line No.:  21629
# None
# Block Start Line No.:  21657
# None
# Block Start Line No.:  21818
# None
# Block Start Line No.:  21922
# None
# Block Start Line No.:  22192
# None
# Block Start Line No.:  22250
# None
# Block Start Line No.:  22481
# None
# Block Start Line No.:  22515
# None
# Block Start Line No.:  22629
# None
# Block Start Line No.:  22854
# None
# Block Start Line No.:  22982
# None
# Block Start Line No.:  23373
# None
# Block Start Line No.:  23413
# None
# Block Start Line No.:  23699
# None
# Block Start Line No.:  24079
# None
# Block Start Line No.:  24277
# None
# Block Start Line No.:  24473
# None
# Block Start Line No.:  24613
# None
# Block Start Line No.:  24857
# None
# Block Start Line No.:  25381
# None
# Block Start Line No.:  25503
# None
# Block Start Line No.:  26065
# None
# Block Start Line No.:  26173
# None
# Block Start Line No.:  26364
# None
# Block Start Line No.:  26728
# None
# Block Start Line No.:  26919
# None
# Block Start Line No.:  27191
# None
# Block Start Line No.:  27309
# None
# Block Start Line No.:  27501
# None
# Block Start Line No.:  27891
# None
# Block Start Line No.:  28125
# None
# Block Start Line No.:  28437
# None
# Block Start Line No.:  28701
# None
# Block Start Line No.:  28915
# None
# Block Start Line No.:  29213
# None
# Block Start Line No.:  29445
# None
# Block Start Line No.:  29619
# None
# Block Start Line No.:  29884
# None
# Block Start Line No.:  30210
# None
# Block Start Line No.:  30670
# None
# Block Start Line No.:  30830
# None
# Block Start Line No.:  31048
# None
# Block Start Line No.:  31186
# None
# Block Start Line No.:  31617
# None
# Block Start Line No.:  31787
# None
# Block Start Line No.:  32022
# None
# Block Start Line No.:  32110
# None
# Block Start Line No.:  33252
# None
# Block Start Line No.:  33666
# None
# Block Start Line No.:  33725
# None
# Block Start Line No.:  34193
# None
# Block Start Line No.:  34443
# None
# Block Start Line No.:  34483
# None
# Block Start Line No.:  34511
# None
# Block Start Line No.:  34905
# None
# Block Start Line No.:  35065
# None
# Block Start Line No.:  35115
# None
# Block Start Line No.:  35779
# None
# Block Start Line No.:  35892
# None
# Block Start Line No.:  36332
# None
# Block Start Line No.:  36480
# None
# Block Start Line No.:  36592
# None
# Block Start Line No.:  36678
# None
# Block Start Line No.:  36838
# None
# Block Start Line No.:  36952
# None
# Block Start Line No.:  37113
# None
# Block Start Line No.:  37327
# None
# Block Start Line No.:  37687
# None
# Block Start Line No.:  38241
# None
# Block Start Line No.:  38269
# None
# Block Start Line No.:  38379
# None
# Block Start Line No.:  38947
# None
# Block Start Line No.:  38976
# None
# Block Start Line No.:  39262
# None
# Block Start Line No.:  39362
# None
# Block Start Line No.:  39400
# None
# Block Start Line No.:  39464
# None
# Block Start Line No.:  39730
# None
# Block Start Line No.:  39778
# None
# Block Start Line No.:  39962
# None
# Block Start Line No.:  39982
# None
# Block Start Line No.:  40230
# None
# Block Start Line No.:  40284
# None
# Block Start Line No.:  40304
# None
# Block Start Line No.:  40548
# None
# Block Start Line No.:  40756
# None
# Block Start Line No.:  41060
# None
# Block Start Line No.:  41154
# None
# Block Start Line No.:  41470
# None
# Block Start Line No.:  41502
# None
# Block Start Line No.:  41653
# None
# Block Start Line No.:  41819
# None
# Block Start Line No.:  42355
# None
# Block Start Line No.:  42419
# None
# Block Start Line No.:  42670
# None
# Block Start Line No.:  42816
# None
# Block Start Line No.:  42972
# None
# Block Start Line No.:  43086
# None
# Block Start Line No.:  43138
# None
# Block Start Line No.:  43410
# None
# Block Start Line No.:  43732
# None
# Block Start Line No.:  43822
# None
# Block Start Line No.:  44042
# None
# Block Start Line No.:  44118
# None
# Block Start Line No.:  44382
# None
# Block Start Line No.:  44422
# None
# Block Start Line No.:  44683
# None
# Block Start Line No.:  44738
# None
# Block Start Line No.:  44920
# None
# Block Start Line No.:  44948
# None
# Block Start Line No.:  45156
# None
# Block Start Line No.:  45284
# None
# Block Start Line No.:  45486
# None
# Block Start Line No.:  45784
# None
# Block Start Line No.:  46032
# None
# Block Start Line No.:  46262
# None
# Block Start Line No.:  46510
# None
# Block Start Line No.:  46727
# None

# %%
pair_df = pd.DataFrame(pairs, columns=['pair1', 'pair2', 'tvl', 'apr', 'where', 'network'])
pair_df['apy'] = np.nan

# %%
pairs
# Out:
# []

# %%
pair_df = pair_df.drop(pair_df[pair_df['pair1'] == ''].index)

# %%
pair_df
# Out:
#        pair1 pair2            tvl      apr                        where  \
# 1       Cake        2398434463.40    76.01  https://pancakeswap.finance
# 2      LOTTO                 0.00        0  https://pancakeswap.finance
# 3       BURN                 0.00        0  https://pancakeswap.finance
# 4     BANANA          45770987.86   120.67      https://apeswap.finance
# 5       Cake          81970299.69     2.32     https://autofarm.network
# ...      ...   ...            ...      ...                          ...
# 1343    AUTO             10073.60   195.20   https://gocerberus.finance
# 1344    SHIB             61220.23    32.12   https://gocerberus.finance
# 1345    BAKE             93357.25    31.59   https://gocerberus.finance
# 1346   MATIC                 0.00        0   https://gocerberus.finance
# 1347    BIFI              4820.61  1019.76   https://gocerberus.finance
#
#      network  apy
# 1        BSC  NaN
# 2        BSC  NaN
# 3        BSC  NaN
# 4        BSC  NaN
# 5        BSC  NaN
# ...      ...  ...
# 1343     BSC  NaN
# 1344     BSC  NaN
# 1345     BSC  NaN
# 1346     BSC  NaN
# 1347     BSC  NaN
#
# [1347 rows x 7 columns]

# %%
pair_df[pair_df['network'] == 'Alternate']['network'] = 'ETH'

# %%
sheet_pairs_df = pd.read_csv('yieldFarm_6-14.csv')
eth_sheet_pairs_df = pd.read_csv('Alternate.csv')
# eth_sheet_pairs_df.columns=['pair1', 'pair2', 'tvl', 'where', 'apr']
eth_sheet_pairs_df['apy'] = np.nan
eth_sheet_pairs_df['network'] = 'ETH'
sheet_pairs_df = sheet_pairs_df.append(eth_sheet_pairs_df)
sheet_pairs_df['pair2'] = sheet_pairs_df['pair2'].fillna('')

# %%
sheet_pairs_df
# Out:
#         pair1  pair2       apr  apy      tvl                 where network
# 0    MEATBALL  BUSD   3,998.26  NaN      150  https://swedefi.com/     BSC
# 1    MEATBALL   BNB   3,381.76  NaN      156  https://swedefi.com/     BSC
# 2         BNB  BUSD      54.58  NaN    1,378  https://swedefi.com/     BSC
# 3        CAKE   BNB     127.92  NaN      588  https://swedefi.com/     BSC
# 4        USDT  BUSD     103.82  NaN      290  https://swedefi.com/     BSC
# ..        ...    ...       ...  ...      ...                   ...     ...
# 200      BOND   WETH    104.65  NaN   78,859                 SUSHI     ETH
# 201   bb_cDAI    DAI     59.45  NaN  138,810                 SUSHI     ETH
# 202      WETH   FOLD     90.43  NaN   91,256                 SUSHI     ETH
# 203       NDX   WETH     55.22  NaN  149,455                 SUSHI     ETH
# 204     DEGEN   WETH     37.07  NaN  222,592                 SUSHI     ETH
#
# [279 rows x 7 columns]

# %%
def update_apr(apr):
    apr = f"{apr}".replace("%", "")
    if len(apr) == 0 or "nan" == apr:
        return np.nan
    else:
        return apr

# %%
def get_symbol_mapping(pair):
    if pair is not None:
        return sm[pair.strip()] if pair.strip() in sm else pair.strip()
    else:
        return ""

# %%
pair_df = pair_df.append(sheet_pairs_df).reset_index(drop=True)
pair_df['type_of_agriculture'] = 'FARM'
pair_df = pair_df.append(df).reset_index(drop=True)

# %%
pair_df['apr'] = pair_df['apr'].apply(lambda x: update_apr(x))
pair_df['pair1'] = pair_df['pair1'].apply(lambda x: sm[x.strip()] if x.strip() in sm else x.strip())
pair_df['pair2'] = pair_df['pair2'].apply(lambda x: get_symbol_mapping(x))

# %%
pair_df['pair2'].unique()
# Out:
# array(['', 'BUSD', 'BNB', 'USDT', 'ETH', 'CRV', 'OMG', 'AMP', 'RARI',
#        'SEEN', 'INJ', 'BADGER', 'UWL', 'BCP', 'USDC', 'FRONT', 'UOP',
#        'CRETH2', 'DIGG', 'pWING', 'RGT', 'ASSY', 'YLD', 'GRT', 'ANY',
#        'ZRX', 'DUCK', 'ROOK', 'DAI', '1INCH', 'AAVE', 'ALPHA', 'BZRX',
#        'COMP', 'COVER', 'CREAM', 'HEGIC', 'LINK', 'REN', 'SRM', 'SUSHI',
#        'UNI', 'wNXM', 'YFI', 'sUSD', 'ibBTC', 'DG', 'UST', 'TUSD',
#        'WOOFY', 'MLN', 'SAK3', 'FOLD', 'RAY', 'SOL', 'oDOP', 'unknown',
#        'UMA', 'LIGHT', 'BPF', 'BFC', 'XOR', 'ACXT', 'LMY', 'xSUSHI',
#        'EQMT', 'PUNK', 'renBTC', 'SPANK', 'LGO', 'RARE', 'ZEON', 'REAL',
#        'YAX', 'TESTPRESALE', 'SUSD', 'AZUKI', 'COMBO', 'ICAP', 'NU',
#        'YFP', 'SDARK', 'PIPT', 'COL', 'TKN', 'DGX', 'FUN', '$TRDL', 'GEM',
#        'ST', 'POLK', 'RFUEL', 'HOPE', 'ONX', 'CONV', 'NBT', 'BNSD',
#        'USDQ', 'DANK', 'NFTI', 'YFTE', 'AMPL', 'WAIFU', 'MINT', 'TRIPS',
#        'QSP', 'bBADGER', 'SNC', 'OVR', 'sil', 'uTVL', 'ORIGIN', 'CRO',
#        'SURF', 'VISR', 'NCT', 'QNT', 'NUTS', 'TORN', 'XYO', 'VXV', 'MTA',
#        'AXN', 'SOCKS', 'SALT', 'BCC', 'FTM', 'DEP', 'LON', 'BAO', 'ICE',
#        'IDLE', 'TVK', 'YAM', 'GRID', 'BID', 'TST', 'TXL', 'ANJ',
#        'yCREDIT', 'DC', 'GLCH', 'wMBX', 'yveCRV', 'MCB', 'RBC', 'NDR',
#        'MYFI', 'MANA', 'ESH', 'CVC', 'XKW', 'CVP', 'CHAI', 'VSP', 'wDGLD',
#        'erowan', 'NFY', 'DELTA', 'CARD', 'MUST', 'MEL', 'ELF', 'SRK',
#        'DONUT', 'KNC', 'GNYerc20', 'Xi', 'WLEO', 'OKB', 'XCUR', 'ARMOR',
#        'MEME', 'ETHMNY', 'oneVBTC', 'ETHBN', 'BLES', 'MM', 'SHARE',
#        'WWGR', 'NSBT', 'TRAC', 'CER', 'EASY', 'PLG', 'YGEM', 'WSTA',
#        'DEC', 'COT', 'PAMP', 'DXD', 'DOKI', 'YFL', 'GSWAP', 'GOVI',
#        'KBTC', 'BEZOGE', 'CUTE', 'DOLA', 'cUNI', 'ANT', 'yyDAI+y...',
#        'MFT', 'GRO', 'L2', 'MUSE', 'WCK', 'BCPT', 'WISE', 'HOUSE', 'AceD',
#        'SDT', 'XBASE', 'STMX', 'ZETA', 'SFI', 'SIG', 'TRIB', '88MPH',
#        'AXS', 'SHIB', 'ITS', 'SUPER', 'SHUF', 'NEXO', 'NFTX', 'CHE',
#        'GEN', 'GET', 'PICKLE', 'TEN', 'DSD', 'CC10', 'DRC', 'GST2',
#        'FLUX', 'zHEGIC', 'SYNC', 'GARD', 'TEL', 'ALEPH', 'ODDZ', 'SYLO',
#        'LIT', 'CTX', 'RDM', 'AVVP', 'OLY', 'JRT', 'XFT', 'VGT', 'SNX',
#        'GEEQ', 'NICE', 'SLP', 'BLT', 'ROBOT', 'KTON', 'LABS', 'ALIS',
#        'NEC', 'JUP', 'aDAI', 'aETHB', 'LPOOL', 'SI', 'MATH', 'FXC', 'OAK',
#        'OCTO', 'XRT', 'FLASH', 'ISLA', 'ZAI', 'INV', 'CORE', 'CHAIN',
#        'MBC', 'PNK', 'INDEX', 'DPI', 'BASK', 'MET', 'WET', 'IGG', 'GT',
#        'DEAFBEEF', 'AMIS', 'RAUX', 'AKRO', 'PRQ', 'CFi', 'VETH', 'TRND',
#        'ROBO', 'DEXT', 'VRA', 'FOUR', 'LIEN', 'LINA', 'DDIM', 'GHOST',
#        'ROT', 'TCORE', 'BSP', 'DAO', 'OMX', 'SASHIMI', 'EBASE', 'STAKE',
#        'CAPY', 'MCO', 'FREE', 'POWR', 'USDN', 'AGI', 'VOX', 'GUP', 'PERP',
#        'SAND', 'GNO', 'CEL', 'eXRD', 'SOUL', 'WBCD', 'BNT', 'stETH',
#        'CWS', 'VTX', 'ZERO', 'L3P', 'fUSDC', 'DEV', 'CAVO', 'MAPS',
#        'RFOX', 'METH', 'UOS', 'SAN', 'AKITA', 'arNXM', 'SNT', 'WSCRT',
#        'VEGETA', 'UFR', 'ASTRO', 'ARCH', 'DAM', '$DG', 'BOR', 'ART',
#        'VAI', 'LDO', 'CRU', 'NDX', 'FOX', 'PAINT', 'MFG', 'buidl', 'XED',
#        'zLOT', 'FIN', 'YFRB', 'PATHFINDER', 'MTHD', 'CDSD', 'REQ', 'UTK',
#        'NMBL', 'TGBP', 'IMTY', 'RDN', 'FUSE', 'MVI', 'BLANK', 'MASK',
#        'MPH', 'DEUS', 'DIA', 'API3', 'TBB', 'LOTTO', 'AUDIO', 'DRGN',
#        'TMC', 'VAL', 'WHALE', 'Seal', 'IND', 'PLT', 'ETHV', 'AERGO',
#        '69C', 'cDAI', 'BEPRO', 'ANTISEAL', 'LCX', 'YIELDX', 'MITx',
#        'ANKR', 'NORD', 'Dap', 'IOU', 'MORK', 'oBTC', 'TAP', 'Mars', 'EYE',
#        'RC_COVER_250_DAI_2021_3_31', 'OIN', '$BASED', 'REM', 'HEX',
#        'yDAI+y...', 'SNM', 'CZZ', 'RFI', 'GLM', 'ERN', 'KOMET', 'POOL',
#        'MIR', 'KCAL', 'BNS', 'AMN', 'SBREE', 'sETH', 'PAX', 'BANK',
#        'JULIEN', 'STA', 'TACO', 'GHST', 'VBTC', 'PKG', 'MCHC', 'DYT',
#        'AVASTR', 'R34P', 'TOMOE', 'NRGT', 'SPDR', 'BCIO', 'MIS', 'SX',
#        'LEND', 'UNC', 'FNT', 'WOZX', 'GYSR', 'YPIE', 'XSP', 'RIO',
#        'ABYSS', 'RCC', 'WDOGE', 'stXYM', 'AFDLT', 'CRBN', 'GUSD',
#        'ankrETH', 'UNIFI', 'XVIX', 'FXS', 'EVNY', 'KEN', 'XSUc25', 'ASKO',
#        '2KEY', 'ANTS', 'PROS', 'BOND', 'AC', 'TAUD', 'LOL', 'PROPS',
#        'ZAIv2', 'ADX', '$ROPE', '0xBTC', 'VXC', 'doki20', 'DOGY', 'FARM',
#        'ILV', 'DJ15', 'UBXT', 'WOO', 'PAR', 'WORLD', 'PPDEX', 'arte',
#        'XAMP', 'MTL', 'MATTER', 'ORN', 'GLYPH', 'RLC', 'BIRD', 'ROYA',
#        'YFFI', 'FL', 'PPAY', 'MARK', 'RSR', 'APYS', 'POOLZ', 'RPL',
#        'COTI', 'REVV', 'OGN', 'KLON', 'INXT', 'PAID', 'ENK', 'PHOON',
#        'KIN', 'VGX', 'CELR', 'LPT', 'KEY', 'EURS', 'ID', 'PNT',
#        'FTX Token', 'POLY', 'TE', 'UNISTAKE', 'REEF', 'PVY', 'EWTB',
#        'ELON', 'PARETO', 'eRSDL', 'MOON', 'DGVC', 'TRIBE', 'SHROOM',
#        'ZZZ', 'GLQ', 'VAMP', 'UNN', 'KICK', 'UNCX', 'MATIC', 'BLO', 'BDP',
#        'TRYB', 'TRU', 'DMG', 'uDOO', 'MNFT', 'XIOT', 'BCUG', 'DEFI+L',
#        'ORBI', 'DARK', 'Yf', 'ALCH', 'TBTC', 'FEG', 'DPR', 'ENRH',
#        'FANNY', 'TOL', 'YFIII', 'LEASH', 'RC_WETH_750_DAI_2021_3_31',
#        'HH', 'BAB', 'PLU', 'KP3R', 'LUNA', 'PHA', 'RUNE', 'LRC', 'FST',
#        '0XMON', 'YFII', 'REPv2', 'BUIDL', 'LOOM', 'RAI', 'AAH', 'ACG',
#        'ROOM', 'SEFI', 'DHT', 'DUSD', 'SDX', 'UTU', 'stZEN', 'tfTUSD',
#        'bDPI', 'FXF', 'CHSB', 'ERC223', 'DEFI5', 'AVINOC', 'ZCRT', 'LIQ',
#        'SHAKE', 'WASABI', 'PLR', 'MINDS', 'ORAI', 'BASIC', 'UNO', 'FORTH',
#        'SOTA', 'FRM', 'LFETH', 'OOKS', 'ORBS', 'DEA', 'ROUTE', 'aETH',
#        'SCIFI', 'JUL', 'PREMIA', 'ARUK', 'ALEX', 'MSP', 'HGET', 'yvBOOST',
#        'PPBLZ', 'XCM', 'HUE', 'TIDAL', 'MEMED', 'AUSCM', 'YAMv2', 'CHART',
#        'BREE', 'LPL', 'BGANPUNK', 'NFTP', 'oneETH', 'DOUGH', 'BTSG',
#        '1ONE', 'BAT', 'YIELD', 'OM', 'HARVEST', 'SAFE', 'UFT', 'GRUMPY',
#        'TANGO', 'DENT', 'OXT', 'OCEAN', 'BAL', 'CELL', 'PAXG', 'HAKKA',
#        'MARSH', 'UPR', 'XZAR', 'UDT', 'NOODLE', 'ICHI', 'LTO', 'CHI',
#        'IQ', 'PLOT', 'BONDLY', 'UNDB', 'pBTC', 'BAEPAY', 'ZCN', 'vBZRX',
#        'DNT', 'VISION', 'RING', 'GTC', 'pONT', 'WARP', 'BENTO', 'IHF',
#        'EWO', 'MTLX', 'BAND', 'ELX', 'METRIC', 'FYZ', 'TCAP', 'ENOL',
#        'BMI', 'FNX', 'MASK20', 'HYDRO', 'UDO', 'YCO', 'SNTVT', 'xETH',
#        'CLVA', 'CREED', 'SXP', 'PRIA', 'SKM', 'ADEL', 'TXT', 'FOTO',
#        'TRST', 'SWAG', 'SQUIG', 'STORJ', 'PUSH', 'CROWN', 'USDP', 'SBTC',
#        'PUNKBODY', 'DFD', 'LQTY', 'ETHIX', 'LAYER', 'UMB', 'RULER',
#        'WAIF', 'UBT', 'RANK', 'MILK2', 'GTH', 'EILN', 'renDOGE', 'CRD',
#        'ERC20', 'PTF', 'LAGER', 'LQD', 'HOLY', 'eMax', 'URANIUM', 'wOMI',
#        'MIC', 'NMR', 'KATANA', 'SAKE', 'FMT', 'UniFi', 'YFIP', 'MRPH',
#        'NOIA', 'PIE', 'C20', 'MKR', 'CORN', 'BTC', 'CP3R', 'WHEY', 'APE$',
#        'CRT', 'GALA', 'IDRT', 'DFX', 'ETHY', 'PMON', 'BLOODY', 'AUC',
#        'MAHA', 'YETI', 'RNDR', 'SWRV', 'CAP', 'POP!', 'wanWASP', 'FRAX',
#        'xTRND', 'SAV3', 'SOLOS', 'PRQBOOST', 'ALCX', 'iFARM', 'ATRI',
#        'KIMCHI', 'REB2', '1337', 'DICE', 'DZAR', 'DOCK', 'KYL', 'DOPL.',
#        'SGT', 'NOAHP', 'bALPHA', 'DNA', 'vETH2', 'EGT', 'LID', 'ZOMBIE',
#        'CGG', 'ZAG', 'ZKS', 'WZEC', 'ALPA', 'AST', 'LOCK', 'LAND',
#        'CUDOS', 'YFV', 'BIST', 'TWERKY', 'BRAP', 'EMONT', 'TEND', '10SET',
#        'SHR', 'DSLA', 'FORCE', 'DVG', 'OXY', 'AVA', 'oneBTC', 'TRADE',
#        'PIXL', 'XNK', 'WSCOIN', 'DEXTF', 'LYXe', 'DATA', 'YOP', 'FLX',
#        'DSCPL', 'TCAD', 'UVU', 'HEZ', 'DELTA rLP', 'OPIUM', 'BASE', 'OPT',
#        'SWAP', 'TLN', 'MXC', 'HEDG', 'DOS', 'HNY', 'ARCHETYPE', 'STBZ',
#        'PRT', 'KITTY', 'QUICK', 'OHM', 'DOGEBEAR', 'ROOBEE', 'GEAR',
#        'ARIA20', 'FWB', 'ZAP', 'DIP', 'FCL', 'SYN', 'SS', 'LGCY', 'ESD',
#        'XIO', 'FWT', 'WTF', 'SENT', 'FSW', 'DFT', 'SLINK', 'PAS', 'SWISS',
#        'HIPPO', 'SPI', 'AGIX', 'SNOW', 'HXRO', 'ENJ', 'ALBT', 'REB',
#        'mbBASED', 'UBI', 'silv2', 'MONA', 'KEEP', 'INFI', 'ZPR', 'SHIT',
#        'WZCR', 'aBLOCK', 'BOSON', 'BART', 'COMFI', 'COIL', 'BABES',
#        'AfroX', 'APPLE', 'EPAN', 'BNF', 'ENB', 'REP', 'CHADS', 'RAMP',
#        'Nsure', 'YFBETA', 'HEX2T', 'SEED', 'WBOMB', 'Alpaca', 'VIDT',
#        'STAK', 'APY', 'DOGES', 'RCN', 'YAXIS', 'THKD', 'WQT', 'VERI',
#        'SKL', 'DRT', 'NAMI', 'RAD', 'CATE', 'Skey', 'ESS', 'KEL', '1UP',
#        'DGTX', 'MUSH', 'mBTC', 'HOT', 'DAOfi', 'wCRES', 'ibETHv2',
#        'KISHU', 'HVN', 'FLOW', 'FORS', 'MYM', 'ETH2x', 'bDIGG', 'AIOZ',
#        'MBTC', 'BAC', 'DEGEN', 'BSOV', 'POW', 'SHIP', 'GWEI', 'VLDY',
#        'DEGOV', 'MOD', 'TRXC', 'AMALGAM', 'DHC', '0xMR', 'CHZ', 'POLS',
#        '89SA'], dtype=object)

# %%
pair_df
# Out:
#        pair1 pair2            tvl                 apr  \
# 0       Cake        2398434463.40               76.01
# 1      LOTTO                 0.00                   0
# 2       BURN                 0.00                   0
# 3     BANANA          45770987.86              120.67
# 4       Cake          81970299.69                2.32
# ...      ...   ...            ...                 ...
# 3152     ETH  0xMR       6.393288         24.30591528
# 3153     ETH   CHZ      40.560723   56.11707960000001
# 3154     ETH  POLS    4868.881122  4.3867717200000005
# 3155     ETH  89SA       3.998762          5.15366652
# 3156     ETH   OHM       3.494265          3.84659496
#
#                             where network  apy type_of_agriculture
# 0     https://pancakeswap.finance     BSC  NaN                FARM
# 1     https://pancakeswap.finance     BSC  NaN                FARM
# 2     https://pancakeswap.finance     BSC  NaN                FARM
# 3         https://apeswap.finance     BSC  NaN                FARM
# 4        https://autofarm.network     BSC  NaN                FARM
# ...                           ...     ...  ...                 ...
# 3152                      Uniswap     ETH  NaN                POOL
# 3153                      Uniswap     ETH  NaN                POOL
# 3154                      Uniswap     ETH  NaN                POOL
# 3155                        Sushi     ETH  NaN                POOL
# 3156                        Sushi     ETH  NaN                POOL
#
# [3157 rows x 8 columns]

# %%
# pair_df['apr'].unique().tolist()

# %%
def convert_apr_to_apy(pair_df):
    tmp_df = pair_df[pair_df['apy'].isna()]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apr = row['apr']
        if pd.isnull( apr):
            return
        if apr is not None and len(apr.strip()):
            apr = float(apr.replace(',',''))
        else:
            apr = 0
        try:
            pair_df.loc[index, 'apy'] = ((1+(apr/100)/365)**365-1)*100
        except:
            pair_df.loc[index, 'apy'] = np.nan
    return
            
def convert_apy_to_apr(pair_df):
    tmp_df = pair_df[(pair_df['apr'].isnull())]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apy = row['apy']
        if pd.isnull( apy):
            return
        if apy is not None and len(apy.strip()):
            apy = float(apy.replace(',',''))
        else:
            apy = 0
        try:
            pair_df.loc[index, 'apr'] = (((1+(apy/100))**(1/365)-1)*365)*100
        except:
            pair_df.loc[index, 'apr'] = np.nan
    return


convert_apr_to_apy(pair_df)
convert_apy_to_apr(pair_df)
# Out:
# (3157, 8)
# (55, 8)

# %%
pair_df[pair_df['apy'].isna()]
# Out:
#      pair1 pair2          tvl                     apr  \
# 18     BNB               0.00  7719871081259625472.00
# 988   Cake              90.00              1581214.48
# 1202  BUSD          242821.79               384332.83
# 1203   BNB          392271.70               356861.28
# 1204  USDT          144894.86               322041.74
# ...    ...   ...          ...                     ...
# 3152   ETH  0xMR     6.393288             24.30591528
# 3153   ETH   CHZ    40.560723       56.11707960000001
# 3154   ETH  POLS  4868.881122      4.3867717200000005
# 3155   ETH  89SA     3.998762              5.15366652
# 3156   ETH   OHM     3.494265              3.84659496
#
#                               where network  apy type_of_agriculture
# 18         https://autofarm.network     BSC  NaN                FARM
# 988   https://blue.planetfinance.io     BSC  NaN                FARM
# 1202       https://lavacake.finance     BSC  NaN                FARM
# 1203       https://lavacake.finance     BSC  NaN                FARM
# 1204       https://lavacake.finance     BSC  NaN                FARM
# ...                             ...     ...  ...                 ...
# 3152                        Uniswap     ETH  NaN                POOL
# 3153                        Uniswap     ETH  NaN                POOL
# 3154                        Uniswap     ETH  NaN                POOL
# 3155                          Sushi     ETH  NaN                POOL
# 3156                          Sushi     ETH  NaN                POOL
#
# [1732 rows x 8 columns]

# %%
pair_df[pair_df['apr'].isna()]
# Out:
#                 pair1   pair2   tvl  apr  where network  apy  \
# 1447           REDUCE             0  NaN  SUSHI     ETH  NaN
# 1482      SAFFRONCHEF             0  NaN  SUSHI     ETH  NaN
# 1539           kmWETH    USDT     0  NaN  SUSHI     ETH  NaN
# 1540           kmWETH    USDC     0  NaN  SUSHI     ETH  NaN
# 1541           kmWETH     DAI     0  NaN  SUSHI     ETH  NaN
# 1542           kmWBTC    USDT     0  NaN  SUSHI     ETH  NaN
# 1543           kmWBTC     DAI     0  NaN  SUSHI     ETH  NaN
# 1544           kmWBTC    USDC     0  NaN  SUSHI     ETH  NaN
# 1545           kmLINK    USDT     0  NaN  SUSHI     ETH  NaN
# 1546           kmLINK     DAI     0  NaN  SUSHI     ETH  NaN
# 1547           kmLINK    USDC     0  NaN  SUSHI     ETH  NaN
# 1548           kmUSDC   1INCH     0  NaN  SUSHI     ETH  NaN
# 1549           kmUSDC    AAVE     0  NaN  SUSHI     ETH  NaN
# 1550           kmUSDC  BADGER     0  NaN  SUSHI     ETH  NaN
# 1551           kmUSDC   ALPHA     0  NaN  SUSHI     ETH  NaN
# 1552           kmUSDC    BZRX     0  NaN  SUSHI     ETH  NaN
# 1553           kmUSDC    COMP     0  NaN  SUSHI     ETH  NaN
# 1554           kmUSDC   COVER     0  NaN  SUSHI     ETH  NaN
# 1555           kmUSDC   CREAM     0  NaN  SUSHI     ETH  NaN
# 1556           kmUSDC     GRT     0  NaN  SUSHI     ETH  NaN
# 1557           kmUSDC   HEGIC     0  NaN  SUSHI     ETH  NaN
# 1558           kmUSDC    LINK     0  NaN  SUSHI     ETH  NaN
# 1559           kmUSDC     REN     0  NaN  SUSHI     ETH  NaN
# 1560           kmUSDC     SRM     0  NaN  SUSHI     ETH  NaN
# 1561           kmUSDC   SUSHI     0  NaN  SUSHI     ETH  NaN
# 1562           kmUSDC     UNI     0  NaN  SUSHI     ETH  NaN
# 1563           kmUSDC    wNXM  0.00  NaN  SUSHI     ETH  NaN
# 1564           kmUSDC     YFI     0  NaN  SUSHI     ETH  NaN
# 1565          kmSUSHI     UNI  0.00  NaN  SUSHI     ETH  NaN
# 1566            kmUNI   SUSHI     0  NaN  SUSHI     ETH  NaN
# 1567          kmSUSHI    USDC     0  NaN  SUSHI     ETH  NaN
# 1568          kmSUSHI    USDT     0  NaN  SUSHI     ETH  NaN
# 1569          kmSUSHI     DAI     0  NaN  SUSHI     ETH  NaN
# 1570           kmWETH   1INCH     0  NaN  SUSHI     ETH  NaN
# 1571            kmYFI    USDC     0  NaN  SUSHI     ETH  NaN
# 1572           kmAAVE    USDC     0  NaN  SUSHI     ETH  NaN
# 1573          kmALPHA    USDC     0  NaN  SUSHI     ETH  NaN
# 1574         kmBADGER    USDC     0  NaN  SUSHI     ETH  NaN
# 1575           kmRUNE    USDT     0  NaN  SUSHI     ETH  NaN
# 1576            kmUMA     DAI     0  NaN  SUSHI     ETH  NaN
# 1577            kmDAI     CRV     0  NaN  SUSHI     ETH  NaN
# 1578            kmDPI    sUSD     0  NaN  SUSHI     ETH  NaN
# 1593         kmxSUSHI     UST     0  NaN  SUSHI     ETH  NaN
# 1594         kmxSUSHI     DAI     0  NaN  SUSHI     ETH  NaN
# 1595         kmxSUSHI    USDC     0  NaN  SUSHI     ETH  NaN
# 1596         kmxSUSHI    TUSD     0  NaN  SUSHI     ETH  NaN
# 1597         kmxSUSHI    USDT     0  NaN  SUSHI     ETH  NaN
# 1598  MASTERCHEFDUMMY          1.00  NaN  SUSHI     ETH  NaN
# 1609           kmCOMP    USDC     0  NaN  SUSHI     ETH  NaN
# 1610            kmFTM    USDC     0  NaN  SUSHI     ETH  NaN
# 1611            kmSNX    USDC     0  NaN  SUSHI     ETH  NaN
# 1612           kmRUNE    sUSD     0  NaN  SUSHI     ETH  NaN
# 1613            kmREN    USDC     0  NaN  SUSHI     ETH  NaN
# 1614           kmAAVE     DAI     0  NaN  SUSHI     ETH  NaN
# 1615            kmUNI     DAI     0  NaN  SUSHI     ETH  NaN
#
#      type_of_agriculture
# 1447                FARM
# 1482                FARM
# 1539                FARM
# 1540                FARM
# 1541                FARM
# 1542                FARM
# 1543                FARM
# 1544                FARM
# 1545                FARM
# 1546                FARM
# 1547                FARM
# 1548                FARM
# 1549                FARM
# 1550                FARM
# 1551                FARM
# 1552                FARM
# 1553                FARM
# 1554                FARM
# 1555                FARM
# 1556                FARM
# 1557                FARM
# 1558                FARM
# 1559                FARM
# 1560                FARM
# 1561                FARM
# 1562                FARM
# 1563                FARM
# 1564                FARM
# 1565                FARM
# 1566                FARM
# 1567                FARM
# 1568                FARM
# 1569                FARM
# 1570                FARM
# 1571                FARM
# 1572                FARM
# 1573                FARM
# 1574                FARM
# 1575                FARM
# 1576                FARM
# 1577                FARM
# 1578                FARM
# 1593                FARM
# 1594                FARM
# 1595                FARM
# 1596                FARM
# 1597                FARM
# 1598                FARM
# 1609                FARM
# 1610                FARM
# 1611                FARM
# 1612                FARM
# 1613                FARM
# 1614                FARM
# 1615                FARM

# %%
pair_df = pair_df.drop_duplicates()

# %%
single_piar_df = pair_df[pair_df['pair2'] == ""].copy()
double_coin_pair_df = pair_df[pair_df['pair2'] != ""].copy()
tmp_df = double_coin_pair_df.copy()

# %%
single_piar_df
# Out:
#                 pair1 pair2            tvl         apr  \
# 0                Cake        2398434463.40       76.01
# 1               LOTTO                 0.00           0
# 2                BURN                 0.00           0
# 3              BANANA          45770987.86      120.67
# 4                Cake          81970299.69        2.32
# ...               ...   ...            ...         ...
# 1447           REDUCE                    0         NaN
# 1482      SAFFRONCHEF                    0         NaN
# 1598  MASTERCHEFDUMMY                 1.00         NaN
# 2101               Xi                  0.0         0.0
# 2172             RUNE             2.570675  0.33424824
#
#                             where network         apy type_of_agriculture
# 0     https://pancakeswap.finance     BSC  113.680058                FARM
# 1     https://pancakeswap.finance     BSC    0.000000                FARM
# 2     https://pancakeswap.finance     BSC    0.000000                FARM
# 3         https://apeswap.finance     BSC  233.579054                FARM
# 4        https://autofarm.network     BSC    2.347046                FARM
# ...                           ...     ...         ...                 ...
# 1447                        SUSHI     ETH         NaN                FARM
# 1482                        SUSHI     ETH         NaN                FARM
# 1598                        SUSHI     ETH         NaN                FARM
# 2101                        Sushi     ETH         NaN                POOL
# 2172                        Sushi     ETH         NaN                POOL
#
# [1300 rows x 8 columns]

# %%
double_coin_pair_df
# Out:
#          pair1 pair2          tvl                 apr                 where  \
# 1347  MEATBALL  BUSD          150            3,998.26  https://swedefi.com/
# 1348  MEATBALL   BNB          156            3,381.76  https://swedefi.com/
# 1349       BNB  BUSD        1,378               54.58  https://swedefi.com/
# 1350      CAKE   BNB          588              127.92  https://swedefi.com/
# 1351      USDT  BUSD          290              103.82  https://swedefi.com/
# ...        ...   ...          ...                 ...                   ...
# 3152       ETH  0xMR     6.393288         24.30591528               Uniswap
# 3153       ETH   CHZ    40.560723   56.11707960000001               Uniswap
# 3154       ETH  POLS  4868.881122  4.3867717200000005               Uniswap
# 3155       ETH  89SA     3.998762          5.15366652                 Sushi
# 3156       ETH   OHM     3.494265          3.84659496                 Sushi
#
#      network           apy type_of_agriculture
# 1347     BSC  3.001770e+18                FARM
# 1348     BSC  1.111040e+16                FARM
# 1349     BSC  7.252851e+01                FARM
# 1350     BSC  2.585736e+02                FARM
# 1351     BSC  1.819970e+02                FARM
# ...      ...           ...                 ...
# 3152     ETH           NaN                POOL
# 3153     ETH           NaN                POOL
# 3154     ETH           NaN                POOL
# 3155     ETH           NaN                POOL
# 3156     ETH           NaN                POOL
#
# [1794 rows x 8 columns]

# %%
tmp_df
# Out:
#          pair1 pair2          tvl                 apr                 where  \
# 1347  MEATBALL  BUSD          150            3,998.26  https://swedefi.com/
# 1348  MEATBALL   BNB          156            3,381.76  https://swedefi.com/
# 1349       BNB  BUSD        1,378               54.58  https://swedefi.com/
# 1350      CAKE   BNB          588              127.92  https://swedefi.com/
# 1351      USDT  BUSD          290              103.82  https://swedefi.com/
# ...        ...   ...          ...                 ...                   ...
# 3152       ETH  0xMR     6.393288         24.30591528               Uniswap
# 3153       ETH   CHZ    40.560723   56.11707960000001               Uniswap
# 3154       ETH  POLS  4868.881122  4.3867717200000005               Uniswap
# 3155       ETH  89SA     3.998762          5.15366652                 Sushi
# 3156       ETH   OHM     3.494265          3.84659496                 Sushi
#
#      network           apy type_of_agriculture
# 1347     BSC  3.001770e+18                FARM
# 1348     BSC  1.111040e+16                FARM
# 1349     BSC  7.252851e+01                FARM
# 1350     BSC  2.585736e+02                FARM
# 1351     BSC  1.819970e+02                FARM
# ...      ...           ...                 ...
# 3152     ETH           NaN                POOL
# 3153     ETH           NaN                POOL
# 3154     ETH           NaN                POOL
# 3155     ETH           NaN                POOL
# 3156     ETH           NaN                POOL
#
# [1794 rows x 8 columns]

# %%
tmp_df['tmp'] = tmp_df['pair1']
tmp_df['pair1'] = tmp_df['pair2']
tmp_df['pair2'] = tmp_df['tmp']
del tmp_df['tmp']

# %%
double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
# Out:
#        pair1   pair2         tvl                  apr    where network  apy  \
# 0                sil         0.0                  0.0    Sushi     ETH  NaN
# 1             xSUSHI         0.0                  0.0    Sushi     ETH  NaN
# 2     $BASED     ETH   12.640678    8.808390119999999  Uniswap     ETH  NaN
# 3     $BASED    SUSD   13.117297           5.72888256  Uniswap     ETH  NaN
# 4        $DG     ETH  783.776032   5.9177233199999995  Uniswap     ETH  NaN
# ...      ...     ...         ...                  ...      ...     ...  ...
# 3583  zHEGIC   HEGIC   32.737022  0.29695799999999994  Uniswap     ETH  NaN
# 3584    zLOT     DAI    0.094383  0.11465700000000001  Uniswap     ETH  NaN
# 3585    zLOT     ETH      46,317                35.63    SUSHI     ETH  NaN
# 3586    zLOT     ETH    0.550745   1.1481439199999999  Uniswap     ETH  NaN
# 3587    zLOT     ETH   19.316181           2.16014808    Sushi     ETH  NaN
#
#      type_of_agriculture
# 0                   POOL
# 1                   POOL
# 2                   POOL
# 3                   POOL
# 4                   POOL
# ...                  ...
# 3583                POOL
# 3584                POOL
# 3585                FARM
# 3586                POOL
# 3587                POOL
#
# [3588 rows x 8 columns]

# %%
summary = {
    "total_pairs": pair_df.shape[0],
"single_coin_pairs": single_piar_df.shape[0],
"double_coin_piars": double_coin_pair_df.shape[0],
"after_switching_coins_total_double_coin_pairs": double_coin_pair_df.shape[0] * 2,
"total_pairs_in_sheet": double_coin_pair_df.shape[0] * 2 + single_piar_df.shape[0]
}

# %%
summary
# Out:
# {'total_pairs': 3094,
#  'single_coin_pairs': 1300,
#  'double_coin_piars': 1794,
#  'after_switching_coins_total_double_coin_pairs': 3588,
#  'total_pairs_in_sheet': 4888}

# %%
pair_df = double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
pair_df = single_piar_df.append(pair_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)

# %%
pair_df
# Out:
#        pair1   pair2         tvl                  apr  \
# 0                sil         0.0                  0.0
# 1             xSUSHI         0.0                  0.0
# 2     $BASED     ETH   12.640678    8.808390119999999
# 3     $BASED    SUSD   13.117297           5.72888256
# 4        $DG     ETH  783.776032   5.9177233199999995
# ...      ...     ...         ...                  ...
# 4883    zLOT     DAI    0.094383  0.11465700000000001
# 4884    zLOT     ETH      46,317                35.63
# 4885    zLOT     ETH    0.550745   1.1481439199999999
# 4886    zLOT     ETH   19.316181           2.16014808
# 4887    τBTC              259.33               310.95
#
#                            where network          apy type_of_agriculture
# 0                          Sushi     ETH          NaN                POOL
# 1                          Sushi     ETH          NaN                POOL
# 2                        Uniswap     ETH          NaN                POOL
# 3                        Uniswap     ETH          NaN                POOL
# 4                        Uniswap     ETH          NaN                POOL
# ...                          ...     ...          ...                 ...
# 4883                     Uniswap     ETH          NaN                POOL
# 4884                       SUSHI     ETH          NaN                FARM
# 4885                     Uniswap     ETH          NaN                POOL
# 4886                       Sushi     ETH          NaN                POOL
# 4887  https://www.elixir-swap.io     BSC  2111.662429                FARM
#
# [4888 rows x 8 columns]

# %%
pair_df['dex'] = pair_df['where']
pair_df['date'] = date 
del pair_df['where']

# %%
pair_df.to_csv('yield_data_2021_06_14.csv')

# %%
pair_df['dex'].unique().tolist()
# Out:
# ['Sushi',
#  'Uniswap',
#  'https://caramelswap.finance',
#  'https://babyswap.finance/ilo',
#  'SUSHI',
#  'https://app.swamp.finance',
#  'https://ellipsis.finance',
#  'https://nerve.fi',
#  'https://autofarm.network',
#  'https://beta.belt.fi',
#  'https://blue.planetfinance.io',
#  'https://abrakadabra.tech',
#  'https://absorber.finance',
#  'https://iron.finance/',
#  'https://xwin.finance',
#  'https://www.goosedefi.com',
#  'http://slime.finance',
#  'https://koaladefi.finance/',
#  'https://brickchain.finance',
#  'https://www.jiggly.finance',
#  'https://app.hyruleswap.com',
#  'https://biscuitfarm.finance',
#  'https://mooncakeswap.finance',
#  'https://app.comos.finance/',
#  'https://farm.borgswap.exchange',
#  'https://lokum.finance',
#  'https://limeswap.io',
#  'https://degentoken.finance',
#  'https://app.barbecueswapfinance.com',
#  'https://vanillacake.farm',
#  'https://garudaswap.finance',
#  'https://www.elixir-swap.io',
#  'https://www.grizzlyswap.com',
#  'https://mayoswap.com',
#  'https://pearldefi.com',
#  'https://www.andromedadefi.com',
#  'https://www.venomswap.net',
#  'https://www.blacksheepdefi.com',
#  'https://gocerberus.finance',
#  'https://rushmoon.finance/farms',
#  'Raydium',
#  'https://farm.hyperjump.fi',
#  'https://dollar.supra.finance',
#  'https://aloeswap.com',
#  'https://hyfi.pro',
#  'hhttps://taco.finance/',
#  'https://alpha.parthenon.finance',
#  'https://antswap.fi',
#  'https://antdefi.io',
#  'https://app.apache.finance/',
#  'https://cougarswap.io',
#  'https://www.alchemistdefi.com',
#  'https://toad.farm',
#  'https://fullsail.finance',
#  'https://muscle.finance',
#  'https://snek.farm',
#  'https://mouse.farm',
#  'https://thelab.finance',
#  'https://app.gametoken.finance',
#  'https://jaguarswap.com',
#  'https://kesef.finance',
#  'https://b2xtoken.io/farm',
#  'https://www.bakeryswap.org',
#  'https://cheesecakeswap.com',
#  'https://neonic.finance',
#  'https://www.ybearswap.finance',
#  'https://gatorswap.xyz',
#  'https://app.bami.money',
#  'https://apeswap.finance',
#  'https://www.zexswap.finance',
#  'https://bitblocks.finance',
#  'https://pandayield.com',
#  'https://carrotcake.fi',
#  'https://kimochi.finance',
#  'https://fulcrum.trade',
#  'https://www.billhwangdefi.co',
#  'https://app.blueswap.finance',
#  'https://blizzard.money',
#  'https://donutdefi.com',
#  'https://www.saltswap.finance/',
#  'https://www.coralfarm.finance/',
#  'https://app.polarisdefi.io',
#  'https://finance.zcore.network',
#  'https://bscrunner.com',
#  'https://farm.space',
#  'https://app.treedefi.com',
#  'https://app.uranium.finance',
#  'https://dragonballfinance.org',
#  'https://marshmallowdefi.com',
#  'https://tripswap.finance',
#  'https://sojudefi.com',
#  'https://veganswap.finance',
#  'https://thefarmingden.com',
#  'https://thunderswap.finance',
#  'https://bourbondefi.com',
#  'https://evodefi.com',
#  'https://shrimpswap.finance',
#  'https://farms.pandaswap.xyz',
#  'https://pantherswap.com',
#  'https://dungeonswap.app',
#  'https://plumcake.finance',
#  'https://www.pulsar.farm',
#  'https://dumplingdefi.finance',
#  'https://dinopark.finance',
#  'https://farms.tinville.finance',
#  'https://benswap.finance/',
#  'https://mars.cosmos.farm',
#  'https://bsc.prismfinance.net',
#  'https://tea-swap-app.finance',
#  'https://lazymint.finance',
#  'https://werewolf.farm',
#  'https://lavacake.finance',
#  'https://siberianswap.finance',
#  'https://kiyomi.finance',
#  'https://thunderbird.finance/',
#  'https://app.elephantswap.finance',
#  'https://swedefi.com/',
#  'https://cafeswap.finance',
#  'https://cubdefi.com',
#  'https://dogen.finance',
#  'https://squirrel.finance',
#  'https://pancakeswap.finance',
#  'https://privacyswap.finance',
#  'https://coinswap.space/',
#  'https://pumpy.farm',
#  'https://llamaswap.finance',
#  'http://djinn.gold',
#  'https://www.helmet.insure',
#  'https://apoyield.com',
#  'https://eleven.finance',
#  'https://eggplant.fi',
#  'https://app.pancakefork.finance',
#  'https://fishswap.app',
#  'https://fluity.finance',
#  'https://yieldfields.finance',
#  'https://icecreamswap.finance',
#  'https://galaxydefi.finance',
#  'https://fanaticsfinance.com',
#  'https://goatswap.finance',
#  'https://farmhero.io',
#  'https://glacierswap.org/farms/',
#  'https://jazzdefi.com',
#  'https://julswap.com',
#  'https://kebabfinance.com',
#  'https://www.knightsdefi.com',
#  'https://app.vlad.finance',
#  'https://app.acryptos.com',
#  'https://www.mythic.finance',
#  'http://mangofarm.finance',
#  'https://manyswap.io',
#  'https://mushrooms.finance',
#  'https://pool.mochiswap.io',
#  'https://www.mocktailswap.finance',
#  'https://www.wardenswap.finance',
#  'https://yieldnyan.com',
#  'https://olive.cash/farms',
#  'https://yieldbay.finance',
#  'https://pastafinance.com',
#  'https://mozartfinance.io',
#  'https://pizzafinance.app',
#  'https://farms.polispay.org',
#  'https://www.pureswap.finance',
#  'https://ricefarm.fi',
#  'https://ramenswap.finance',
#  'https://app.sponge.finance',
#  'https://swirl.cash/mining',
#  'https://ten.finance',
#  'https://tsuki.finance',
#  'https://gambit.financial/earn',
#  'https://app.wault.finance',
#  'https://bsc.wasabix.finance/#/app/pool',
#  'https://wheat.growthdefi.com',
#  'https://farm.wsbdapp.com',
#  'https://zombie-farm.com',
#  'https://app.alpacafinance.org',
#  'https://cdo.finance',
#  'https://bsc.sashimi.cool/',
#  'https://app.feeder.finance',
#  'https://smoothy.finance',
#  'https://satis.finance',
#  'https://yumcha.finance']

# %%
pair_df[pair_df['pair1'] == 'ETH']
# Out:
#      pair1   pair2        tvl                 apr network         apy  \
# 1315   ETH             851.92               48.17     BSC   61.831005
# 1316   ETH             596.58                0.00     BSC    0.000000
# 1317   ETH           97045.99                   0     BSC    0.000000
# 1318   ETH            8213.81              112.31     BSC  206.907329
# 1319   ETH           74348.35                0.00     BSC    0.000000
# ...    ...     ...        ...                 ...     ...         ...
# 2623   ETH  zHEGIC   2.229828          1.31204424     ETH         NaN
# 2624   ETH  zHEGIC   0.019139                 0.0     ETH         NaN
# 2625   ETH    zLOT   0.550745  1.1481439199999999     ETH         NaN
# 2626   ETH    zLOT  19.316181          2.16014808     ETH         NaN
# 2627   ETH    zLOT     46,317               35.63     ETH         NaN
#
#      type_of_agriculture                        dex       date
# 1315                FARM      https://donutdefi.com 2021-06-16
# 1316                FARM  https://www.goosedefi.com 2021-06-16
# 1317                FARM  https://www.goosedefi.com 2021-06-16
# 1318                FARM    https://kimochi.finance 2021-06-16
# 1319                FARM       http://slime.finance 2021-06-16
# ...                  ...                        ...        ...
# 2623                POOL                    Uniswap 2021-06-16
# 2624                POOL                      Sushi 2021-06-16
# 2625                POOL                    Uniswap 2021-06-16
# 2626                POOL                      Sushi 2021-06-16
# 2627                FARM                      SUSHI 2021-06-16
#
# [1313 rows x 9 columns]

# %%
pair_df['apr'].unique().tolist()
# Out:
# ['0.0',
#  '8.808390119999999',
#  '5.72888256',
#  '5.9177233199999995',
#  '5.7588788399999995',
#  '3.30166308',
#  '5.99870484',
#  '11.60412132',
#  '2.30547576',
#  '24.30591528',
#  '0.18127031999999998',
#  '0.49014192',
#  '0',
#  '21.187301399999996',
#  '13.0237212',
#  '0.38033039999999996',
#  '107.61',
#  nan,
#  '1.2397871999999999',
#  '0.27431196',
#  '1.12040016',
#  '1.348821',
#  '0.9954314400000001',
#  '0.0035435999999999996',
#  '23.47',
#  '15.77',
#  '5.42',
#  '0.08908811999999999',
#  '0.07637052',
#  '2.78224632',
#  '5.15366652',
#  '7.85103612',
#  '10.31',
#  '1.9611871200000004',
#  '3.49063812',
#  '149.65',
#  '180.58',
#  '0.00',
#  '1.5390722399999999',
#  '0.90627804',
#  '0.02306028',
#  '104.78',
#  '7.78107348',
#  '28.56',
#  '306.47',
#  '202.31',
#  '25.86',
#  '20.61',
#  '234.66',
#  '366.93',
#  '38.02',
#  '20.89',
#  '16.80',
#  '76.23',
#  '46.11',
#  '68.66',
#  '98.21',
#  '15.62',
#  '46.48',
#  '3.87',
#  '531084.57',
#  '106.72',
#  '126.00',
#  '13588.37',
#  '126.82',
#  '13.76',
#  '93.13',
#  '142.26',
#  '68.50695683999999',
#  '6591.04',
#  '0.17828855999999998',
#  '1.83354852',
#  '5.70296964',
#  '87.77',
#  '0.09510792000000001',
#  '5.70646248',
#  '0.01380528',
#  '0.05398788',
#  '855.6907395600001',
#  '0.017728679999999997',
#  '83.69921904',
#  '0.02353416',
#  '17.54151348',
#  '29.22',
#  '10.750945080000001',
#  '8.0420028',
#  '9.63131832',
#  '15.84229788',
#  '8.636777519999999',
#  '0.08593212',
#  '4.707874800000001',
#  '50.36',
#  '11.91057024',
#  '0.14977764',
#  '4.6974211200000004',
#  '1.55',
#  '0.51780768',
#  '0.77157516',
#  '96.47',
#  '1611.24',
#  '1.6114333199999997',
#  '32.61',
#  '265.01',
#  '35.83',
#  '65.50457843999999',
#  '22.842391680000002',
#  '7.33524264',
#  '2.1529621199999998',
#  '1.91384616',
#  '0.08707008000000001',
#  '4.36839732',
#  '12.83',
#  '104.47179924000001',
#  '82.61977932',
#  '0.10277148',
#  '5.50171932',
#  '6.851877720000001',
#  '0.36414564',
#  '17.99643348',
#  '4.26874668',
#  '1290.32',
#  '984.67',
#  '5.14',
#  '3.26263212',
#  '6.820353120000001',
#  '9.18795888',
#  '0.043934640000000004',
#  '0.32306495999999996',
#  '1.97',
#  '2.8124834400000003',
#  '144.09',
#  '3.0536930399999997',
#  '14.06',
#  '49.7610684',
#  '24.21349464',
#  '0.658101',
#  '2.9957184',
#  '4.69155204',
#  '3.69',
#  '17.06',
#  '5.088996960000001',
#  '4.648161720000001',
#  '2.39138376',
#  '1.9734710400000002',
#  '2.44916892',
#  '2.59152876',
#  '42.91',
#  '3.6506046',
#  '3.5901642',
#  '1.5201978',
#  '0.50659836',
#  '0.15004140000000002',
#  '39.95',
#  '6.00545868',
#  '5.2266936',
#  '0.9435625200000001',
#  '369.44',
#  '39.98379864',
#  '1.8622271999999997',
#  '0.5189623200000001',
#  '13.811808',
#  '367.59',
#  '150.97',
#  '21.9965472',
#  '224.28',
#  '172.90',
#  '77.33',
#  '576.78',
#  '619.69',
#  '97.15',
#  '874.33',
#  '425.81',
#  '376.39',
#  '280.89',
#  '152.28',
#  '340.52',
#  '351.74',
#  '1355.01',
#  '312.74',
#  '396.07',
#  '195.20',
#  '0.59357784',
#  '3.35752164',
#  '3.8877435599999997',
#  '146.31',
#  '0.10514844000000001',
#  '0.02791164',
#  '5.798743320000001',
#  '18.61',
#  '19.82877792',
#  '10.192796040000001',
#  '0.32380104',
#  '0.7490288399999999',
#  '0.04876116',
#  '0.86720928',
#  '54.61',
#  '2.102526',
#  '0.46165980000000006',
#  '590.83',
#  '429.05',
#  '1.02440676',
#  '232.59',
#  '14.70243936',
#  '0.40444416',
#  '18.15',
#  '3.09584088',
#  '3.16152792',
#  '0.0987738',
#  '16.96949136',
#  '1.95158532',
#  '16.37',
#  '107.03',
#  '49.27',
#  '79.35',
#  '48.50',
#  '315.35',
#  '267.39',
#  '211.42',
#  '415.39',
#  '276.08',
#  '2076483.55',
#  '31.59',
#  '114.18',
#  '0.12990588',
#  '7.640275320000001',
#  '120.67',
#  '8.90',
#  '190.26',
#  '286.49',
#  '26.92',
#  '5.21912964',
#  '5.64445596',
#  '151.17',
#  '48.57',
#  '5.2993051200000005',
#  '2.17763268',
#  '1.4277552',
#  '3.08224848',
#  '6.001819319999999',
#  '2.14006224',
#  '1.7777504399999997',
#  '1.0325465999999999',
#  '0.33890760000000003',
#  '71.39955804',
#  '1.54204176',
#  '0.60655188',
#  '140.52',
#  '1.2585078',
#  '1.4835760800000002',
#  '3.8340476400000005',
#  '116.69',
#  '2.55355308',
#  '1.37170272',
#  '14.42',
#  '0.42660348',
#  '0.24896112000000004',
#  '7.27907736',
#  '101.03',
#  '3.40925484',
#  '2.88277932',
#  '8.71800012',
#  '231.47',
#  '67.24',
#  '83.70',
#  '38.87603088',
#  '1.3066252799999998',
#  '1.75845612',
#  '7.85',
#  '9.09411744',
#  '0.40402932',
#  '20.38',
#  '278.03',
#  '27.99',
#  '1019.76',
#  '513.49',
#  '2.70369288',
#  '17.20292472',
#  '11555.78',
#  '26.2547256',
#  '6.96438624',
#  '27.53',
#  '2.13744192',
#  '0.7818408',
#  '0.8577636',
#  '2.3319781199999996',
#  '9.838956959999999',
#  '7719871081259625472.00',
#  '37.61',
#  '31.77',
#  '79.79',
#  '35.78',
#  '1.19',
#  '24.63',
#  '321.22',
#  '509.63',
#  '32.27',
#  '51.36',
#  '13238.07',
#  '21.01',
#  '37.87',
#  '19.01',
#  '86.46',
#  '53.85',
#  '117.23',
#  '223.52',
#  '92.13',
#  '156.51',
#  '48.70',
#  '729.61',
#  '222.59',
#  '50.72',
#  '61.62',
#  '0.35',
#  '10.92',
#  '4.26',
#  '196.05',
#  '159.76',
#  '83.62',
#  '84.11',
#  '81.22',
#  '40.71',
#  '76.92',
#  '102.10',
#  '658.42',
#  '89.39',
#  '26.97',
#  '5.04',
#  '136.02',
#  '229.88',
#  '72.39',
#  '46.66',
#  '117.26',
#  '32.14',
#  '25.77',
#  '126.61',
#  '68.31',
#  '14.39',
#  '106.43',
#  '9.09',
#  '215.22',
#  '54.98',
#  '239.60',
#  '230.64',
#  '47.04',
#  '54.55',
#  '137.09',
#  '29.93',
#  '260.14',
#  '105.61',
#  '465.80',
#  '172.63',
#  '44.08',
#  '309.97',
#  '88.24',
#  '356861.28',
#  '242608.82',
#  '2968.32',
#  '225.88',
#  '293.90',
#  '677.48',
#  '154.49',
#  '33328.84',
#  '10153.70',
#  '105.28',
#  '129.30',
#  '10.65',
#  '1,303.86',
#  '421.49',
#  '240',
#  '54.58',
#  '859.38',
#  '127.92',
#  '200.51',
#  '753.26',
#  '70.77',
#  '131.02',
#  '80.07',
#  '0.48577764',
#  '125.35',
#  '3,381.76',
#  '528.25',
#  '2,603.85',
#  '924.35',
#  '3,606.33',
#  '74.18',
#  '59.14',
#  '2,649.33',
#  '1.43618376',
#  '0.5140572',
#  '14.91734676',
#  '0.07456896',
#  '1.67303904',
#  '0.61157136',
#  '0.0099036',
#  '17.630249759999998',
#  '153.29',
#  '104.65',
#  '2.2600144799999997',
#  '7.71064632',
#  '12.276222720000002',
#  '39.81773988',
#  '38.568462479999994',
#  '5.26',
#  '249.45',
#  '10.79',
#  '6.53774856',
#  '80.29839708',
#  '0.1785252',
#  '217.87',
#  '11.031696120000001',
#  '168.53',
#  '45.50',
#  '65.40',
#  '254.04',
#  '306.62',
#  '265.54',
#  '253.77',
#  '178.66',
#  '278.33',
#  '3775.70',
#  '256.31',
#  '138.62',
#  '100.16',
#  '6.5165181599999995',
#  '1.22372688',
#  '4.03456308',
#  '26.54',
#  '0.5342930399999999',
#  '0.34247172',
#  '0.0063324',
#  '7.56',
#  '4.05760056',
#  '2.55647292',
#  '3.8058400800000003',
#  '0.02207628',
#  '44.00818776',
#  '0.8023090800000001',
#  '0.32',
#  '7.26',
#  '7.46741124',
#  '197.99',
#  '4.76',
#  '2.98',
#  '2.03306856',
#  '1.5973807199999999',
#  '0.03786563999999999',
#  '0.0434736',
#  '1.5550715999999998',
#  '86.83',
#  '446.40',
#  '98.18',
#  '30.35',
#  '3.29',
#  '34.00',
#  '108.67',
#  '225.92',
#  '37.34',
#  '41.53',
#  '6158.54',
#  '88.92',
#  '19.84',
#  '39.44',
#  '3941.23',
#  '17.66',
#  '96.97',
#  '68.30',
#  '1811.60',
#  '62.48',
#  '2993.24',
#  '102.39',
#  '41.22',
#  '163.08',
#  '109.09',
#  '25.28',
#  '76.00',
#  '157.88',
#  '11.84',
#  '34.41',
#  '450.92',
#  '46.17',
#  '6.59',
#  '99.60',
#  '41.16',
#  '157.26',
#  '30.91',
#  '13.45',
#  '78.85',
#  '1.06',
#  '26.87',
#  '4.58',
#  '30.33',
#  '12731.65',
#  '170.73',
#  '46.71',
#  '17.53',
#  '270.98',
#  '30.18',
#  '851.01',
#  '16.92',
#  '32.20',
#  '117.92',
#  '493554.52',
#  '612759.82',
#  '3561.34',
#  '93.65',
#  '158.06',
#  '509.53',
#  '166.95',
#  '19948.52',
#  '10186.26',
#  '87.39',
#  '84.94',
#  '6.45',
#  '585.44',
#  '1.11565572',
#  '0.062126759999999996',
#  '0.79',
#  '160.91',
#  '260.41',
#  '86.14',
#  '179.67',
#  '203.26',
#  '165.43',
#  '111.77',
#  '1572982.68',
#  '280.06',
#  '79.88',
#  '125.40',
#  '13.36',
#  '179.55',
#  '30.79',
#  '166.97',
#  '47.41',
#  '1.64',
#  '126.71',
#  '35.96',
#  '35.14',
#  '14693.77',
#  '94.96',
#  '56.39',
#  '1603.52',
#  '121.74',
#  '27.73',
#  '1.75',
#  '65.17',
#  '55.74',
#  '2241.98',
#  '98.43',
#  '45.85',
#  '4.74',
#  '125.86',
#  '22.57',
#  '48.16',
#  '97.57',
#  '75.33',
#  '237.88',
#  '10.84',
#  '33.00',
#  '42.69',
#  '72.46',
#  '161.21',
#  '1.12',
#  '97.75',
#  '31.04',
#  '2.44',
#  '66.38',
#  '49.76',
#  '20.24',
#  '116.93',
#  '89.67',
#  '51.24',
#  '46.36',
#  '64.77',
#  '3.62',
#  '36.42',
#  '3.38',
#  '21.28',
#  '151.74',
#  '40.47',
#  '75.00',
#  '52.97',
#  '91.15',
#  '15.43',
#  '102.37',
#  '37.47',
#  '427.79',
#  '99.39',
#  '32.23',
#  '84.38',
#  '384332.83',
#  '194385.44',
#  '3233.66',
#  '70.66',
#  '266.78',
#  '566.73',
#  '948.79',
#  '48028.57',
#  '8818.05',
#  '127.68',
#  '315.36',
#  '23.18',
#  '72.56',
#  '993.97',
#  '117.35',
#  '8.6',
#  '0.04285464',
#  '3,998.26',
#  '2,595.76',
#  '1,356',
#  '4.82715288',
#  '3,135.75',
#  '13.77',
#  '623,892.44',
#  '19.6',
#  '103.82',
#  '50.33',
#  '91.59',
#  '6.93',
#  '15.3653862',
#  '13.90158456',
#  '0.15176099999999998',
#  '1.7521543199999998',
#  '317.76',
#  '17,051,720.86',
#  '156.96',
#  '1331.0011587599997',
#  '0.32507364',
#  '169.68',
#  '21.32497236',
#  '1.44072264',
#  '4.19924484',
#  '0.29556456',
#  '15.17751792',
#  '0.07110948',
#  '24.78126684',
#  '7.050510240000001',
#  '24.44966784',
#  '96.70',
#  '2.63502228',
#  '44.59500023999999',
#  '196.01',
#  '0.13965636',
#  '1.5464064000000002',
#  '0.7625684400000001',
#  '12.250895279999998',
#  '1.66742904',
#  '135.097395',
#  '5.34499104',
#  '56.11707960000001',
#  '12.926617799999999',
#  '0.11326008',
#  '0.24733512',
#  '0.26433612',
#  '0.62351208',
#  '419.5471218',
#  '2.2255224',
#  '19.76',
#  '0.09656712',
#  '9.17',
#  '7.63206276',
#  '14.94810504',
#  '20.570289119999998',
#  '5.73',
#  '0.0360828',
#  '1.70846928',
#  '2.1833928',
#  '1.5452782799999998',
#  '1.2130618800000001',
#  '19.72496988',
#  '32.03002848',
#  '27.19',
#  '0.06360732',
#  '10.23028464',
#  '0.15892008',
#  '0.13825476',
#  '1.5746914799999998',
#  '0.14855532',
#  '24.22',
#  '16.503809760000003',
#  '25.58922168',
#  '0.0887034',
#  '0.20913192000000003',
#  '0.13056876',
#  '2.86',
#  '0.76943484',
#  '72.90',
#  '0.14032356',
#  '0.08212668000000001',
#  '0.34888476',
#  '0.12312827999999999',
#  '8.92259424',
#  '18.89',
#  '28.7656908',
#  '31.641578400000004',
#  '0.36042252',
#  '146.85',
#  '234.82',
#  '1.45950768',
#  '60.08',
#  '34.9163892',
#  '0.12255528',
#  '0.01686444',
#  '5.02609572',
#  '46.8',
#  '1.83041172',
#  '1.14317784',
#  '3.97515636',
#  '1.54426884',
#  '76.01',
#  '2.32',
#  '166.21',
#  '209.39',
#  '103.84',
#  '70.34',
#  '65.94',
#  '2.16',
#  '429.07',
#  '107.02',
#  '4.01',
#  '6.33',
#  '132.22',
#  '579.65',
#  '19.80',
#  '86.04',
#  '245.37',
#  '63.37',
#  '12.32',
#  '99.16',
#  '163.03',
#  '103.31',
#  '87.09',
#  '95.49',
#  '114.97',
#  '125.01',
#  '64.11',
#  '157.96',
#  '160.34',
#  '372.37',
#  '118.59',
#  '11.31',
#  '224.86',
#  '89.62',
#  '90.10',
#  '82.09',
#  '35.40',
#  '146.56',
#  '81.37',
#  '1251.99',
#  '122.53',
#  '134.10',
#  '278.91',
#  '30.04',
#  '66.77',
#  '206.72',
#  '1581214.48',
#  '519.66',
#  '94.42',
#  '24.85',
#  '4.50',
#  '378.32',
#  '88.41',
#  '100.00',
#  '45.37',
#  '62.96',
#  '19.37',
#  '245.74',
#  '136.41',
#  '426.65',
#  '77.64',
#  '87.74',
#  '276.37',
#  '142.83',
#  '116564.53',
#  '174475.12',
#  '3411.85',
#  '196.34',
#  '283.99',
#  '359.19',
#  '228.89',
#  '99841.40',
#  '24376.05',
#  '287.92',
#  '125.25',
#  '31.87',
#  '16.66',
#  '92.55',
#  '394.37',
#  '88.85',
#  '464.30',
#  '43.49',
#  '186.60',
#  '65.42',
#  '29.11',
#  '44.57',
#  '37.02',
#  '83.69',
#  '1193.12',
#  '49.04',
#  '20.67',
#  '76.45',
#  '124.16',
#  '61.43',
#  '81.41',
#  '3.02',
#  '15.37',
#  '111.13',
#  '105.26',
#  '39.19',
#  '50.75',
#  '65.93',
#  '92.03',
#  '154.65',
#  '8.40',
#  '356.35',
#  '70.64',
#  '26.88',
#  '157.66',
#  '458.01',
#  '47.43',
#  '335406.80',
#  '387559.29',
#  '232.01',
#  '349.71',
#  '7460.10',
#  '72032.25',
#  '22712.45',
#  '110.95',
#  '28.92',
#  '559.94',
#  '0.7463435999999999',
#  '0.02496396',
#  '19.56',
#  '5.58786012',
#  '8.48193552',
#  '5.7476574000000005',
#  '0.42819635999999994',
#  '0.22752624000000002',
#  '0.91856988',
#  '4.800423',
#  '1.3571399999999998',
#  '0.32392763999999996',
#  '0.00227232',
#  '124.33',
#  '19.983466200000002',
#  '0.14017632',
#  '2.7610046400000003',
#  '0.09150672',
#  '0.07081608',
#  '0.220044',
#  '0.28311443999999997',
#  '2.34836976',
#  '2.1522802800000003',
#  '3.24402132',
#  '1.1772976800000001',
#  '27.26',
#  '0.36232188',
#  '0.55605312',
#  '3.203031',
#  '59.45',
#  '0.057253319999999996',
#  '0.010979880000000001',
#  '2.3581800000000004',
#  '0.98380212',
#  '2.83756512',
#  '0.11465700000000001',
#  '0.1917678',
#  '20.7',
#  '6.484286879999999',
#  '3.82647264',
#  '1.67993688',
#  '0.16351824',
#  '121.52232048',
#  '6.0219382800000005',
#  '146.57',
#  '0.11013852000000002',
#  '0.8983836',
#  '7.1234762400000005',
#  '10.88',
#  '24.939532919999998',
#  '2.39513712',
#  '6.813520440000001',
#  '11.16418536',
#  '0.7507836000000001',
#  '13.41',
#  '3.7324879199999996',
#  '4.25422776',
#  '37.07',
#  '92.40450288',
#  '5.3755158000000005',
#  '0.08606892',
#  '112.75524107999999',
#  '29.362357319999997',
#  '0.3710814',
#  '6.3',
#  '1.1890297200000002',
#  '3.38097492',
#  '2.2938240000000003',
#  '3.7979425200000003',
#  '5.5068018',
#  '327.90418752',
#  '4.09',
#  '2.86134816',
#  '0.51804636',
#  '44.54',
#  '21.311682840000003',
#  '75.11',
#  '99.92',
#  '3.14417628',
#  '0.20756304',
#  '0.33256152',
#  '0.56340468',
#  '6.70969044',
#  '3.7467554400000003',
#  '3.44999988',
#  '1.99383348',
#  '35.17766208',
#  '0.29449596',
#  '248.95',
#  '6.57779364',
#  '0.06650544',
#  '6.174327',
#  '0.8532832799999999',
#  '0.06669732',
#  '126.87',
#  '10.54',
#  '0.77120436',
#  '3.08301048',
#  '1.52315736',
#  '190.44',
#  '598.99',
#  '166.35',
#  '21.14',
#  '36.96',
#  '13.62',
#  '167.22',
#  '37.22',
#  '81.76',
#  '141.59',
#  '108415.72',
#  '14.60',
#  '102.56',
#  '0.9350471999999999',
#  '19.157702280000002',
#  '0.42673584',
#  '0.051853439999999994',
#  '15.418328039999999',
#  '0.20981423999999999',
#  '0.25371228',
#  '17.76189012',
#  '50.76',
#  '1.0400496000000001',
#  '0.02016588',
#  '3.2276368800000004',
#  '72.72',
#  '53.29',
#  '28.44',
#  '194.79',
#  '161.58',
#  '35.87',
#  '34.15',
#  '47.73',
#  '708.13',
#  '509.79',
#  '51.22',
#  '63.39',
#  '2539.52',
#  '105.13',
#  '158.90',
#  '251.51',
#  '70.36',
#  '369.65',
#  '24.53',
#  '21.16',
#  '112.07',
#  '87.12',
#  '158.33',
#  '46.35',
#  '1.36',
#  '66.94',
#  '13.32',
#  '89.27',
#  '2.54',
#  '25.80',
#  '206.86',
#  '55.52',
#  '439035.94',
#  '621258.72',
#  '573.54',
#  '120.03',
#  '17913.66',
#  '135.27',
#  '23.81',
#  '63.14',
#  '93.2',
#  '3.38413872',
#  '2.00505552',
#  '10.73',
#  '3.3569600399999997',
#  '4.26090612',
#  '10.94784432',
#  ...]

# %%
pair_df
# Out:
#        pair1   pair2         tvl                  apr network          apy  \
# 0                sil         0.0                  0.0     ETH          NaN
# 1             xSUSHI         0.0                  0.0     ETH          NaN
# 2     $BASED     ETH   12.640678    8.808390119999999     ETH          NaN
# 3     $BASED    SUSD   13.117297           5.72888256     ETH          NaN
# 4        $DG     ETH  783.776032   5.9177233199999995     ETH          NaN
# ...      ...     ...         ...                  ...     ...          ...
# 4883    zLOT     DAI    0.094383  0.11465700000000001     ETH          NaN
# 4884    zLOT     ETH      46,317                35.63     ETH          NaN
# 4885    zLOT     ETH    0.550745   1.1481439199999999     ETH          NaN
# 4886    zLOT     ETH   19.316181           2.16014808     ETH          NaN
# 4887    τBTC              259.33               310.95     BSC  2111.662429
#
#      type_of_agriculture                         dex       date
# 0                   POOL                       Sushi 2021-06-16
# 1                   POOL                       Sushi 2021-06-16
# 2                   POOL                     Uniswap 2021-06-16
# 3                   POOL                     Uniswap 2021-06-16
# 4                   POOL                     Uniswap 2021-06-16
# ...                  ...                         ...        ...
# 4883                POOL                     Uniswap 2021-06-16
# 4884                FARM                       SUSHI 2021-06-16
# 4885                POOL                     Uniswap 2021-06-16
# 4886                POOL                       Sushi 2021-06-16
# 4887                FARM  https://www.elixir-swap.io 2021-06-16
#
# [4888 rows x 9 columns]

# %%
pair_df[pair_df['pair1'] == 'ADA']
# Out:
#    pair1 pair2        tvl        apr network           apy  \
# 55   ADA         10350.40       0.00     BSC  0.000000e+00
# 56   ADA        182381.64          0     BSC  0.000000e+00
# 57   ADA          2704.61       0.00     BSC  0.000000e+00
# 58   ADA        333221.90      28.56     BSC  3.304115e+01
# 59   ADA          4724.61     306.47     BSC  2.015561e+03
# 60   ADA           134.79     202.31     BSC  6.519607e+02
# 61   ADA         96366.08      25.86     BSC  2.949971e+01
# 62   ADA          2704.61       0.00     BSC  0.000000e+00
# 63   ADA          4199.00      20.61     BSC  2.288046e+01
# 64   ADA           187.16     234.66     BSC  9.371783e+02
# 65   ADA           149.47     366.93     BSC  3.751236e+03
# 66   ADA            66.36      38.02     BSC  4.622877e+01
# 67   ADA          6521.86      20.89     BSC  2.322481e+01
# 68   ADA         16628.72      16.80     BSC  1.828909e+01
# 69   ADA        168398.20      76.23     BSC  1.141497e+02
# 70   ADA          6109.72      46.11     BSC  5.853560e+01
# 71   ADA        507310.94      68.66     BSC  9.856673e+01
# 72   ADA          3831.23      98.21     BSC  1.666538e+02
# 73   ADA         82257.25      15.62     BSC  1.690209e+01
# 74   ADA          1734.76      46.48     BSC  5.912252e+01
# 75   ADA          7658.31       3.87     BSC  3.945647e+00
# 76   ADA          3884.86  531084.57     BSC           NaN
# 77   ADA          6540.81     106.72     BSC  1.902704e+02
# 78   ADA         17485.13     126.00     BSC  2.517780e+02
# 79   ADA         31708.00   13588.37     BSC  1.469172e+52
# 80   ADA         25163.17     126.82     BSC  2.546644e+02
# 81   ADA        285896.58      13.76     BSC  1.474867e+01
# 82   ADA   BNB      9,074      93.13     BSC  1.534798e+02
# 83   ADA  USDT    183,725     142.26     BSC  3.136437e+02
#
#    type_of_agriculture                                  dex       date
# 55                FARM            https://www.goosedefi.com 2021-06-16
# 56                FARM            https://www.goosedefi.com 2021-06-16
# 57                FARM                 http://slime.finance 2021-06-16
# 58                FARM           https://koaladefi.finance/ 2021-06-16
# 59                FARM           https://brickchain.finance 2021-06-16
# 60                FARM           https://www.jiggly.finance 2021-06-16
# 61                FARM           https://app.hyruleswap.com 2021-06-16
# 62                FARM          https://biscuitfarm.finance 2021-06-16
# 63                FARM         https://mooncakeswap.finance 2021-06-16
# 64                FARM           https://app.comos.finance/ 2021-06-16
# 65                FARM             https://abrakadabra.tech 2021-06-16
# 66                FARM       https://farm.borgswap.exchange 2021-06-16
# 67                FARM                https://lokum.finance 2021-06-16
# 68                FARM                  https://limeswap.io 2021-06-16
# 69                FARM          https://caramelswap.finance 2021-06-16
# 70                FARM           https://degentoken.finance 2021-06-16
# 71                FARM  https://app.barbecueswapfinance.com 2021-06-16
# 72                FARM             https://vanillacake.farm 2021-06-16
# 73                FARM           https://garudaswap.finance 2021-06-16
# 74                FARM           https://www.elixir-swap.io 2021-06-16
# 75                FARM          https://www.grizzlyswap.com 2021-06-16
# 76                FARM                 https://mayoswap.com 2021-06-16
# 77                FARM                https://pearldefi.com 2021-06-16
# 78                FARM        https://www.andromedadefi.com 2021-06-16
# 79                FARM            https://www.venomswap.net 2021-06-16
# 80                FARM       https://www.blacksheepdefi.com 2021-06-16
# 81                FARM           https://gocerberus.finance 2021-06-16
# 82                FARM       https://rushmoon.finance/farms 2021-06-16
# 83                FARM         https://babyswap.finance/ilo 2021-06-16

# %%
df['pair1'].unique().tolist()
# Out:
# ['ALEPH',
#  'APYS',
#  'BOLE',
#  'BOP',
#  'BTC',
#  'CHAD',
#  'CHEEMS',
#  'COPE',
#  'ETH',
#  'FIDA',
#  'FROG',
#  'FTR',
#  'FTT',
#  'KEEP',
#  'KERMIT',
#  'KIN',
#  'LINK',
#  'LUA',
#  'MAPS',
#  'MEDIA',
#  'MER',
#  'MOLA',
#  'OXY',
#  'RAY',
#  'ROPE',
#  'SAMO',
#  'SBFC',
#  'SDOGE',
#  'SHBL',
#  'SKEM',
#  'SLIM',
#  'SOL',
#  'SOLAPE',
#  'SOLPAD',
#  'SRM',
#  'STEP',
#  'SUSHI',
#  'TOMO',
#  'TULIP',
#  'TYNA',
#  'unknown',
#  'USDC',
#  'USDT',
#  'WOOF',
#  'xCOPE',
#  'YFI',
#  'WBTC',
#  'WHALE',
#  'FRONT',
#  'DGCL',
#  'UNI',
#  'YUNO',
#  'DAI',
#  'MIS',
#  'QDAO',
#  'BAO',
#  'REN',
#  'DATA',
#  'sUSD',
#  'CRO',
#  'MIS3',
#  'AXIE',
#  'cDAI',
#  'xSUSHI',
#  'BNS',
#  'SASHIMI',
#  'MKR',
#  'silv2',
#  'FORTH',
#  'WAN',
#  'KP3R',
#  'VXC',
#  'OOKS',
#  'ALBT',
#  'KITTY',
#  'jEUR',
#  'sil',
#  'EASY',
#  'KAIJU',
#  'LEND',
#  'PROS',
#  'MASK',
#  'FOMC',
#  'BNT',
#  'OHM',
#  'ARTH',
#  'ANT',
#  'DIA',
#  'yveCRV',
#  'CURA',
#  'RUNE',
#  'ibETH',
#  'WOLF',
#  'Xi',
#  'SAKE',
#  'RAI',
#  'TUSD',
#  'NAMI',
#  'oneLINK',
#  'XOR',
#  'HEGIC',
#  'FARM',
#  'HBTC',
#  'BUSD',
#  'wCOINBASE',
#  'Mars',
#  'plDai',
#  'TSD',
#  'LON',
#  'ELE',
#  '1INCH',
#  'ARMOR',
#  'oneVBTC',
#  'NFTX',
#  'MAGGOT',
#  'DUCK',
#  'BLZ',
#  'BOND',
#  'BID',
#  'eXRD',
#  'BAT',
#  'FTM',
#  'mUSO',
#  '',
#  'XPR',
#  'PAXG',
#  'BPF',
#  'WZEC',
#  'XBE',
#  'MIC',
#  'jGBP',
#  'SOLVE',
#  'REVV',
#  '2GT',
#  'XAI',
#  'LEASH',
#  'BLOODY',
#  'MARK',
#  'UNCL',
#  'DAWN',
#  'POT',
#  'DEA',
#  'MOV',
#  'CORE',
#  'SPDR',
#  'YLA',
#  'BAC',
#  'MIR',
#  'CREAM',
#  'ESD',
#  'PLAY',
#  'BACON',
#  'RFI',
#  'PUNK',
#  'pONT',
#  'NMBL',
#  'DEUS',
#  'FRAX',
#  '$TRDL',
#  'AKRO',
#  'FEI',
#  '88MPH',
#  'PIB',
#  'TEL',
#  'DERI',
#  'y3Crv',
#  'AfroX',
#  'STA',
#  'SUSD',
#  'nTrump',
#  'RARE',
#  'HAKKA',
#  'DUSD',
#  'AVASTR',
#  'jCHF',
#  'OXT',
#  'SALT',
#  'YAM',
#  'GRAIN',
#  'ITALIA',
#  'HEX',
#  'WOO',
#  'PPAY',
#  'TBTC',
#  'SPICE',
#  'DTR',
#  'FXS',
#  'DDX',
#  'XYO',
#  'OPT',
#  'NICE',
#  'SGT',
#  'RC_DAI_0.25_TRIBE_2021_4_30',
#  'LIGHT',
#  'PHOON',
#  'POND',
#  'RBC',
#  'OCC',
#  'YFV',
#  'BONDLY',
#  'alphaOHM',
#  'WFIL',
#  'TWT',
#  'MILK2',
#  'PASG',
#  'OUSD',
#  'REB2',
#  'oneWING',
#  'LTO',
#  'BEL',
#  'CELL',
#  'HKMT',
#  'ETH2POS',
#  'ALPHA',
#  'CVC',
#  'MIS2',
#  'RC_WBTC_25000_DAI_2021_3_31',
#  'LCS',
#  'USDP']

# %% [markdown]
# ## Farm Risk

# %%
# # farms_risks_df = pd.read_excel("~/notebooks/vfat_tool_data/Farm_risk.xlsx", sheet_name='BSC')
# farm_risk_df = pd.read_csv('~/notebooks/vfat_tool_data/farm_risks_analysis.csv')

# %%
# farm_risk_df.columns = ['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', 'rugdoc_url', 'network']
# farm_risk_df

# %%
# pairs_farm_risk_df = pd.merge(pair_df, farm_risk_df, how='left', left_on=['dex', 'network'], right_on=['Farm Url', 'network'])
# pairs_farm_risk_df.to_csv('farm_risk_yield_data_2021_06_14.csv')
# pairs_farm_risk_df

# %%
# farms_df = pair_df[['dex', 'network']].drop_duplicates().reset_index(drop=True)

# %%
# farms_df

# %%
# new_farm_risk_df = pd.merge(farms_df, farm_risk_df, how='left', left_on=['dex', 'network'], right_on=['Farm Url', 'network'])
# new_farm_risk_df['Farm Url'] = new_farm_risk_df['dex']
# del new_farm_risk_df['dex']
# new_farm_risk_df = new_farm_risk_df[['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', 'rugdoc_url', 'network']]

# # new_farm_risk_df.columns = ['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', 'rugdoc_url', 'network']

# %%
# new_farm_risk_df.to_csv('Farm_risk_06_14.csv', index=False)

# %%
excel_file = '~/notebooks/vfat_tool_data/Farm_risk_20210616.xlsx'

# %%
bsc_risks_df = pd.read_excel(excel_file, sheet_name='BSC')
bsc_risks_df.columns = ['#', 'Indiv. Assesment', 'Audit Score', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2', '3']
bsc_risks_df['rugdoc_url'] = bsc_risks_df['1'].fillna('') + bsc_risks_df['2'].fillna('') + bsc_risks_df['3'].fillna('')
del bsc_risks_df['1']
del bsc_risks_df['2']
del bsc_risks_df['3']
bsc_risks_df['network'] = 'BSC'
bsc_risks_df
# Out:
#           #  Indiv. Assesment  Audit Score RugDoc   Farm Name Farm Symbol  \
# 0         x               NaN          NaN  least     Pancake        CAKE
# 1       NaN               NaN          NaN   some     Apeswap      BANANA
# 2       NaN               NaN          NaN    NaN    Autofarm    AUTOFARM
# 3         x               9.0          NaN    NaN        Bake        BAKE
# 4         x               NaN         86.0    NaN        Brew        BREW
# ..      ...               ...          ...    ...         ...         ...
# 324     NaN               NaN          NaN    low   VenomSwap       VENOM
# 325     NaN               NaN          NaN    low    Elephant    ELEPHANT
# 326  No TLV               NaN          NaN    NaN   Bloodmoon   BLOODMOON
# 327     NaN               NaN          NaN    low  Blacksheep  BLACKSHEEP
# 328     NaN               NaN          NaN    NaN        Rice        RICE
#
#                              Farm Url  \
# 0         https://pancakeswap.finance
# 1             https://apeswap.finance
# 2            https://autofarm.network
# 3          https://www.bakeryswap.org
# 4            https://cafeswap.finance
# ..                                ...
# 324         https://www.venomswap.net
# 325  https://app.elephantswap.finance
# 326   https://bloodmoon.werewolf.farm
# 327    https://www.blacksheepdefi.com
# 328               https://ricefarm.fi
#
#                                         rugdoc_url network
# 0           https://rugdoc.io/project/pancakeswap/     BSC
# 1               https://rugdoc.io/project/apeswap/     BSC
# 2                                                      BSC
# 3                                                      BSC
# 4         https://www.certik.org/projects/cafeswap     BSC
# ..                                             ...     ...
# 324          https://rugdoc.io/project/venom-swap/     BSC
# 325       https://rugdoc.io/project/elephant-swap/     BSC
# 326                                                    BSC
# 327  https://rugdoc.io/project/blacksheep-finance/     BSC
# 328                                                    BSC
#
# [329 rows x 9 columns]

# %%
matic_risks_df = pd.read_excel(excel_file, sheet_name='MATIC')
matic_risks_df.columns = ['#', 'Indiv. Assesment', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2']
matic_risks_df['Audit Score'] = np.nan
matic_risks_df['rugdoc_url'] = matic_risks_df['1'].fillna('') + matic_risks_df['2'].fillna('')
del matic_risks_df['1']
del matic_risks_df['2']
matic_risks_df['network'] = 'MATIC'
matic_risks_df
# Out:
#          # Indiv. Assesment RugDoc     Farm Name Farm Symbol  \
# 0        x              low    NaN   Quickswap *       QUICK
# 1        x             some    NaN        Cometh        MUST
# 2   No TLV              NaN    NaN          Dark          DB
# 3      NaN              NaN    NaN      Smartdex        NIOX
# 4        x             high    NaN           Elk         ELK
# ..     ...              ...    ...           ...         ...
# 85  No TLV              NaN    NaN      PolyZero        ZERO
# 86     NaN              NaN    low       PolyMax         MAX
# 87     NaN              NaN    low  PolySnowFarm        SNOW
# 88     NaN              NaN    low      Polyyeld        YELD
# 89     NaN              NaN    low        Polysa        DUFF
#
#                               Farm Url  Audit Score  \
# 0   https://quickswap.exchange/#/quick          NaN
# 1       https://swap.cometh.io/#/stake          NaN
# 2               https://www.dark.build          NaN
# 3            https://swap.smartdex.app          NaN
# 4              https://app.elk.finance          NaN
# ..                                 ...          ...
# 85                                 NaN          NaN
# 86                https://polymax.club          NaN
# 87               https://polysnow.farm          NaN
# 88            https://polyyeld.finance          NaN
# 89          https://www.polysa.finance          NaN
#
#                                      rugdoc_url network
# 0                                                 MATIC
# 1                                                 MATIC
# 2                                                 MATIC
# 3                                                 MATIC
# 4                                                 MATIC
# ..                                          ...     ...
# 85                                                MATIC
# 86           https://rugdoc.io/project/polymax/   MATIC
# 87     https://rugdoc.io/project/polysnow-farm/   MATIC
# 88  https://rugdoc.io/project/polyyeld-finance/   MATIC
# 89    https://rugdoc.io/project/polysa-finance/   MATIC
#
# [90 rows x 9 columns]

# %%
avax_risks_df = pd.read_excel(excel_file, sheet_name='AVAX')
avax_risks_df.columns = ['#', 'Indiv. Assesment', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2']
avax_risks_df['Audit Score'] = np.nan
avax_risks_df['rugdoc_url'] = avax_risks_df['1'].fillna('') + avax_risks_df['2'].fillna('')
del avax_risks_df['1']
del avax_risks_df['2']
avax_risks_df['network'] = 'AVAX'
avax_risks_df
# Out:
#          # Indiv. Assesment RugDoc  Farm Name Farm Symbol  \
# 0        x              low    NaN   Pangolin         PNG
# 1        x              low    NaN    Complus         COM
# 2      NaN              NaN    NaN       Zero        ZERO
# 3      NaN              NaN    NaN       Yeti         YTS
# 4        x              NaN    low  Pandaswap      BAMBOO
# 5        x             some    NaN       Pefi        PEFI
# 6        x             high    NaN      Elk *         ELK
# 7   No TLV              NaN    NaN   Snowball        SNOB
# 8        x             some    NaN      Olive       OLIVE
# 9        x              NaN   some      Lydia         LYD
# 10     NaN              NaN    NaN   Baguette         BAG
# 11     NaN              NaN    NaN    Gondola         GDL
# 12       x              NaN   HIGH      Birdy        BIRD
# 13       x             some    NaN     Canary         CNR
# 14     NaN              NaN    NaN  Avalaunch        XAVA
# 15       x             some    NaN       Avme        AVME
#
#                                Farm Url  Audit Score  \
# 0   https://app.pangolin.exchange/#/png          NaN
# 1         https://avax.complus.exchange          NaN
# 2                https://app.0.exchange          NaN
# 3         https://exchange.yetiswap.app          NaN
# 4            https://pandaswap.exchange          NaN
# 5            https://penguinfinance.org          NaN
# 6                   https://elk.finance          NaN
# 7         https://snowball.network/earn          NaN
# 8               https://avax.olive.cash          NaN
# 9             https://www.lydia.finance          NaN
# 10        https://app.baguette.exchange          NaN
# 11          https://app.gondola.finance          NaN
# 12                https://birdy.finance          NaN
# 13          https://app.canary.exchange          NaN
# 14           https://farm.avalaunch.app          NaN
# 15                      https://avme.io          NaN
#
#                                     rugdoc_url network
# 0                                                 AVAX
# 1                                                 AVAX
# 2                                                 AVAX
# 3                                                 AVAX
# 4   https://rugdoc.io/project/panda-swap-defi/    AVAX
# 5                                                 AVAX
# 6                                                 AVAX
# 7                                                 AVAX
# 8                                                 AVAX
# 9        https://rugdoc.io/project/lydia-avax/    AVAX
# 10                                                AVAX
# 11                                                AVAX
# 12  https://rugdoc.io/project/birdy-avalanche/    AVAX
# 13                                                AVAX
# 14                                                AVAX
# 15                                                AVAX

# %%
fantom_risks_df = pd.read_excel(excel_file, sheet_name='FANTOM')
fantom_risks_df.columns = ['#', 'Indiv. Assesment', 'RugDoc', 'Farm Name', 'Farm Symbol', 'Farm Url', '1', '2']
fantom_risks_df['Audit Score'] = np.nan
fantom_risks_df['rugdoc_url'] = fantom_risks_df['1'].fillna('') + fantom_risks_df['2'].fillna('')
del fantom_risks_df['1']
del fantom_risks_df['2']
fantom_risks_df['network'] = 'FANTOM'
fantom_risks_df
# Out:
#          # Indiv. Assesment RugDoc      Farm Name Farm Symbol  \
# 0      NaN              NaN    NaN       Popsicle         ICE
# 1        x              NaN    low         Spooky         boo
# 2        x              NaN   some         Spirit      SPIRIT
# 3        x              NaN    low           Borg         SON
# 4        x              NaN    low      Hyperjump         ORI
# 5        x              NaN    low          Ester         EST
# 6        x             high    NaN          Froyo       FROYO
# 7      NaN              NaN    NaN          Ghost       GHOST
# 8   No TLV              NaN    low          Beefy     Various
# 9        x             some    NaN  Liquid Driver        LQDR
# 10     NaN              NaN    NaN     Standard *        STRD
# 11     NaN              NaN    NaN      Mushrooms          MM
# 12       x             high    NaN     Greenhouse        SEED
# 13     NaN              NaN   high    Stake Steak       STEAK
# 14     NaN              NaN   high   Frankenstein       FRANK
# 15       x              NaN   high           Waka        WAKA
# 16       x             some    NaN            Elk         ELK
# 17      xx              NaN   high      Paintswap       BRUSH
# 18      xx              NaN    low           Tomb     Various
# 19     NaN              NaN   high         Shadow     Various
# 20     NaN              NaN    low       Borgswap       KLING
# 21     NaN              NaN   some          Opera       OPERA
#
#                               Farm Url  Audit Score  \
# 0             https://popsicle.finance          NaN
# 1           https://spookyswap.finance          NaN
# 2       https://app.spiritswap.finance          NaN
# 3        https://ftm.borgswap.exchange          NaN
# 4                 https://hyperjump.fi          NaN
# 5                https://ester.finance          NaN
# 6         https://frozenyogurt.finance          NaN
# 7         https://www.theghost.finance          NaN
# 8         https://fantom.beefy.finance          NaN
# 9     https://www.liquiddriver.finance          NaN
# 10                https://strd.finance          NaN
# 11     https://mushrooms.finance/farms          NaN
# 12       https://thegreenhouse.finance          NaN
# 13              https://stakesteak.com          NaN
# 14        https://frankenstein.finance          NaN
# 15                https://waka.finance          NaN
# 16             https://app.elk.finance          NaN
# 17           https://paintswap.finance          NaN
# 18                https://tomb.finance          NaN
# 19              https://shadowswap.app          NaN
# 20  https://klingftm.borgswap.exchange          NaN
# 21       https://www.operaswap.finance          NaN
#
#                                        rugdoc_url network
# 0                                                  FANTOM
# 1           https://rugdoc.io/project/spookyswap/  FANTOM
# 2           https://rugdoc.io/project/spiritswap/  FANTOM
# 3       https://rugdoc.io/project/borgswap-kling/  FANTOM
# 4         https://rugdoc.io/project/hyperjump-fi/  FANTOM
# 5        https://rugdoc.io/project/ester-finance/  FANTOM
# 6                                                  FANTOM
# 7                                                  FANTOM
# 8        https://rugdoc.io/project/beefy-finance/  FANTOM
# 9                                                  FANTOM
# 10                                                 FANTOM
# 11                                                 FANTOM
# 12                                                 FANTOM
# 13          https://rugdoc.io/project/stakesteak/  FANTOM
# 14        https://rugdoc.io/project/frankenstein/  FANTOM
# 15            https://rugdoc.io/project/waka-ftm/  FANTOM
# 16                                                 FANTOM
# 17           https://rugdoc.io/project/paintswap/  FANTOM
# 18        https://rugdoc.io/project/tomb-finance/  FANTOM
# 19  https://rugdoc.io/project/shadowswap-finance/  FANTOM
# 20      https://rugdoc.io/project/borgswap-kling/  FANTOM
# 21   https://rugdoc.io/project/operaswap-finance/  FANTOM

# %%
risk_df = bsc_risks_df.append(matic_risks_df)
risk_df = risk_df.append(avax_risks_df)
risk_df = risk_df.append(fantom_risks_df)
risk_df = risk_df[risk_df['rugdoc_url'] != '']
risk_df
# Out:
#       # Indiv. Assesment  Audit Score RugDoc  Farm Name Farm Symbol  \
# 0     x              NaN          NaN  least    Pancake        CAKE
# 1   NaN              NaN          NaN   some    Apeswap      BANANA
# 4     x              NaN         86.0    NaN       Brew        BREW
# 5   NaN              NaN          NaN   some      Donut       DONUT
# 7   NaN              NaN          NaN    NaN      Goose       GOOSE
# ..  ...              ...          ...    ...        ...         ...
# 17   xx              NaN          NaN   high  Paintswap       BRUSH
# 18   xx              NaN          NaN    low       Tomb     Various
# 19  NaN              NaN          NaN   high     Shadow     Various
# 20  NaN              NaN          NaN    low   Borgswap       KLING
# 21  NaN              NaN          NaN   some      Opera       OPERA
#
#                               Farm Url  \
# 0          https://pancakeswap.finance
# 1              https://apeswap.finance
# 4             https://cafeswap.finance
# 5                https://donutdefi.com
# 7            https://www.goosedefi.com
# ..                                 ...
# 17           https://paintswap.finance
# 18                https://tomb.finance
# 19              https://shadowswap.app
# 20  https://klingftm.borgswap.exchange
# 21       https://www.operaswap.finance
#
#                                        rugdoc_url network
# 0          https://rugdoc.io/project/pancakeswap/     BSC
# 1              https://rugdoc.io/project/apeswap/     BSC
# 4        https://www.certik.org/projects/cafeswap     BSC
# 5           https://rugdoc.io/project/donutswapp/     BSC
# 7       https://www.certik.org/projects/ramenswap     BSC
# ..                                            ...     ...
# 17           https://rugdoc.io/project/paintswap/  FANTOM
# 18        https://rugdoc.io/project/tomb-finance/  FANTOM
# 19  https://rugdoc.io/project/shadowswap-finance/  FANTOM
# 20      https://rugdoc.io/project/borgswap-kling/  FANTOM
# 21   https://rugdoc.io/project/operaswap-finance/  FANTOM
#
# [218 rows x 9 columns]

# %%
pairs_farm_risk_df = pd.merge(pair_df, risk_df, how='left', left_on=['dex', 'network'], right_on=['Farm Url', 'network'])
pairs_farm_risk_df.to_csv('farm_risk_yield_data_2021_06_14.csv')
pairs_farm_risk_df
# Out:
#        pair1   pair2         tvl                  apr network          apy  \
# 0                sil         0.0                  0.0     ETH          NaN
# 1             xSUSHI         0.0                  0.0     ETH          NaN
# 2     $BASED     ETH   12.640678    8.808390119999999     ETH          NaN
# 3     $BASED    SUSD   13.117297           5.72888256     ETH          NaN
# 4        $DG     ETH  783.776032   5.9177233199999995     ETH          NaN
# ...      ...     ...         ...                  ...     ...          ...
# 4883    zLOT     DAI    0.094383  0.11465700000000001     ETH          NaN
# 4884    zLOT     ETH      46,317                35.63     ETH          NaN
# 4885    zLOT     ETH    0.550745   1.1481439199999999     ETH          NaN
# 4886    zLOT     ETH   19.316181           2.16014808     ETH          NaN
# 4887    τBTC              259.33               310.95     BSC  2111.662429
#
#      type_of_agriculture                         dex       date    #  \
# 0                   POOL                       Sushi 2021-06-16  NaN
# 1                   POOL                       Sushi 2021-06-16  NaN
# 2                   POOL                     Uniswap 2021-06-16  NaN
# 3                   POOL                     Uniswap 2021-06-16  NaN
# 4                   POOL                     Uniswap 2021-06-16  NaN
# ...                  ...                         ...        ...  ...
# 4883                POOL                     Uniswap 2021-06-16  NaN
# 4884                FARM                       SUSHI 2021-06-16  NaN
# 4885                POOL                     Uniswap 2021-06-16  NaN
# 4886                POOL                       Sushi 2021-06-16  NaN
# 4887                FARM  https://www.elixir-swap.io 2021-06-16  NaN
#
#      Indiv. Assesment  Audit Score RugDoc Farm Name Farm Symbol  \
# 0                 NaN          NaN    NaN       NaN         NaN
# 1                 NaN          NaN    NaN       NaN         NaN
# 2                 NaN          NaN    NaN       NaN         NaN
# 3                 NaN          NaN    NaN       NaN         NaN
# 4                 NaN          NaN    NaN       NaN         NaN
# ...               ...          ...    ...       ...         ...
# 4883              NaN          NaN    NaN       NaN         NaN
# 4884              NaN          NaN    NaN       NaN         NaN
# 4885              NaN          NaN    NaN       NaN         NaN
# 4886              NaN          NaN    NaN       NaN         NaN
# 4887              NaN          NaN   high    Elixir        ELXR
#
#                         Farm Url                              rugdoc_url
# 0                            NaN                                     NaN
# 1                            NaN                                     NaN
# 2                            NaN                                     NaN
# 3                            NaN                                     NaN
# 4                            NaN                                     NaN
# ...                          ...                                     ...
# 4883                         NaN                                     NaN
# 4884                         NaN                                     NaN
# 4885                         NaN                                     NaN
# 4886                         NaN                                     NaN
# 4887  https://www.elixir-swap.io  https://rugdoc.io/project/elixir-swap/
#
# [4888 rows x 17 columns]
