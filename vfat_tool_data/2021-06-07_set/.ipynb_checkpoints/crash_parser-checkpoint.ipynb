# %%
import re
import os
import pandas as pd
import numpy as np
import traceback2

where_map = {}
# pairs regexp: "\[([a-zA-z0-9$\-+τ\.%]*)\]-", "-\[([a-zA-z0-9$\-+τ]*)\]"

# %%
sm = {
    "WBTC" : "BTC",
    "WETH" : "ETH",
    "WBNB" : "BNB",
    "WFTM" : "FTM",
    "WAVAX" : "AVAX",
}

# %%
def pair1(line):
    try:
        is_3_pairs = line.split("]-[")
        if len(is_3_pairs) > 2:
            return None
        s_index = line.index("[") + 1
        s = line[s_index: line.index("]", s_index)]
        if all(ord(c) < 128 for c in s):
            return s
        else:
            print(line)
            return None
    except:
        return ''

def pair2(line):
    s_index = line.index("-[") + 3
    s = line[s_index: line.index("]", s_index)]
    if all(ord(c) < 128 for c in s):
        return s
    else:
        print(line)
        return ''

# %%
def apr(line):
    apr = "Year [0-9\,\.]+\%"
    x = re.findall(apr, line)
    return x[0].replace("Year ", "").replace("%", "").strip() if len(x) else 0

# %%
def tvl(line):
    tvl = "TVL: \$[0-9\.\,]+"
    x = re.findall(tvl, line)
    return x[0].replace("TVL: $", "").replace("%", "").replace(",","").strip()

# %%
def where(line):
    if 'INFO' in line:
        return line.replace("INFO", "").replace('\n', '').replace(":", "").replace("//", "://").strip()
    return None

# %%
def get_single_pair(line):
    exp = "\d* *.*Price:"
    x = re.findall(exp, line)
    if not len(x):
#         print(">>>>>>>>>>>",line)
        return
    pair = x[0].replace(" Price:", "")
    return pair[pair.rindex(" "):].strip() if " " in pair else pair

def get_single_tvl(line):
    exp = "\([0-9\,\.$]+\)"
    x = re.findall(exp, line)
    return x[0].replace("(", "").replace(")", "").replace("$", "").replace(",","").strip()

# %%
def read_blocks_from_files(file):
    f = open(file)
    lines = f.readlines()
    blocks = []
    block = []
    for line in lines:
        line = line.strip()
        if line == "" or len(re.findall("INFO[ ]+: ", line)):
            blocks.append(block)
            if len(line):
                blocks.append([line])
            block = []
        else:
            block.append(line)
    blocks.append(block)
    return blocks

def get_pair_info_from_block(block, wh, network):
    if len(block) == 1:
        if 'INFO' in block[0]:
            return [where(block[0])]
        else:
            return [wh]
    if len(block) and pair1(block[0]):
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        return [pair1(block[0]), pair2(block[0]), tvl(block[0]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
    elif len(block) > 2 and get_single_pair(block[0]):
        apr_index = -1
        for index in range(1, len(block)):
            if 'APR: ' in block[index]:
                apr_index = index
                break
        return [get_single_pair(block[0]), "", get_single_tvl(block[1]), apr(block[apr_index]) if apr_index > 1 else 0, where_map[wh] if wh in where_map else wh, network]
        
    return None


def get_pairs(blocks, network):
    where = ""
    pairs = []
    for block in blocks:
        try:
            pair = get_pair_info_from_block(block, where, network)
            if len(where) == 0 and pair and len(pair) > 2:
                print(block, network)
            if pair:
                if len(pair) == 1 and pair[0] and len(pair[0]):
                    where = pair[0]
                else:
                    pairs.append(pair)
        except Exception:
            print(block[0])
    return pairs

# %%
data_dir = './'
ignorable_files = ["Alternate.csv","vfat_tools_data.csv",'.ipynb_checkpoints', "Yield Farm Manual 6:7 New .xlsx", "crash_parser.ipynb", "yieldFarm_6-7.csv"]
def conver_files_to_one_df(data_dir):
    all_pairs = []
    files = os.listdir(data_dir)
    print(files)
    for file_name in files:
        if file_name in ignorable_files:
            continue
        print(file_name)
        network = file_name[0:file_name.index(" ")]
        blocks = read_blocks_from_files(f"{data_dir}{file_name}")
        pairs = get_pairs(blocks, network)
        all_pairs.extend(pairs)
    return all_pairs

# %%
pairs = conver_files_to_one_df(data_dir)
# Out:
# ['Alternate.csv', '.ipynb_checkpoints', 'vfat_tools_data.csv', 'FATOM 6:7 Yields.crash', 'Yield Farm Manual 6:7 New .xlsx', 'crash_parser.ipynb', 'AVAX 6:7 Yields.crash', 'BSC 6:7 Yields.crash', 'Alternate Yield Farm Formats 6:7.crash', 'MATIC 6:7 Yields.crash', 'yieldFarm_6-7.csv', 'ETH 6:7 Yields.crash']
# FATOM 6:7 Yields.crash
# AVAX 6:7 Yields.crash
# BSC 6:7 Yields.crash
# 361 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $2,176,958,332.12 TVL: $20,716,037.36
# 361 - [τBTC]-[BTCB] Cake LP [+] [-] [<=>] Price: $2,176,958,332.12 TVL: $20,716,037.36
# Alternate Yield Farm Formats 6:7.crash
# [🐟]-[WETH] Uni LP [+] [-] [<=>] Price: $502.31 TVL: $179,862.69
# [🐟]-[WETH] Uni LP [+] [-] [<=>] Price: $502.31 TVL: $179,862.69
# [🐟]-[USDC] Uni LP [+] [-] [<=>] Price: $152,963,650.25 TVL: $49,697.90
# [🐟]-[USDC] Uni LP [+] [-] [<=>] Price: $152,963,650.25 TVL: $49,697.90
# [⛩️]-[🐟] Uni LP [+] [-] [<=>] Price: $5.77 TVL: $40,624.01
# [⛩️]-[🐟] Uni LP [+] [-] [<=>] Price: $5.77 TVL: $40,624.01
# MATIC 6:7 Yields.crash
# GFI-USDC Quick LP [+] [-] [<=>] Price: $264,258.12 TVL: $1,049,812.23
# GFI-WETH Quick LP [+] [-] [<=>] Price: $14.02 TVL: $1,030,086.51
# ETH 6:7 Yields.crash
# [DAI 40%]-[BAL 57.99999999999999%]-[TRU 2%] BPT Price: $1.54 TVL: $16,770.44
# [SNX 25%]-[WETH 25%]-[xSNXa 50%] BPT Price: $0.02 TVL: $81,910.26
# [WETH 25%]-[AAVE 25%]-[xAAVEa 50%] BPT Price: $3.37 TVL: $4,015,435.29
# [AAVE 25%]-[WETH 25%]-[xAAVEb 50%] BPT Price: $3.64 TVL: $5,243,088.60
# 0 - [XDEX 36%]-[DAI 32%]-[WETH 32%] BPT Price: $5.16 TVL: $278,685.77
# 3 - [XDEX 4%]-[DAI 32%]-[ZKS 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 9 - [XDEX 4%]-[UNI 32%]-[DAI 32%]-[WETH 32%] BPT Price: $9.35 TVL: $2,379.14
# 10 - [XDEX 4%]-[DAI 32%]-[ZRX 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 11 - [XDEX 4%]-[DAI 32%]-[CRV 32%]-[WETH 32%] BPT Price: $10.00 TVL: $20,419.15
# 12 - [XDEX 4%]-[DAI 32%]-[BAL 32%]-[WETH 32%] BPT Price: $8.58 TVL: $629.68
# 14 - [XDEX 4%]-[DAI 32%]-[SUSHI 32%]-[WETH 32%] BPT Price: $8.75 TVL: $1,120.87
# 17 - [XDEX 4%]-[DAI 32%]-[USDT 32%]-[WETH 32%] BPT Price: $10.47 TVL: $47,039.83
# 18 - [XDEX 4%]-[DAI 32%]-[MEME 32%]-[WETH 32%] BPT Price: $6.10 TVL: $11,590.27
# 19 - [XDEX 4%]-[DAI 32%]-[USDC 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 21 - [XDEX 4%]-[DAI 32%]-[MKR 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 23 - [XDEX 4%]-[WBTC 32%]-[DAI 32%]-[WETH 32%] BPT Price: $17.69 TVL: $9,311.97
# 28 - [XDEX 4%]-[DAI 32%]-[COMP 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 29 - [XDEX 4%]-[YFI 32%]-[DAI 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 30 - [XDEX 4%]-[CELR 32%]-[DAI 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 31 - [XDEX 4%]-[REN 32%]-[DAI 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 32 - [XDEX 4%]-[DAI 32%]-[MFT 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 33 - [XDEX 4%]-[DAI 32%]-[CRO 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 36 - [XDEX 4%]-[DAI 32%]-[ANKR 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 40 - [XDEX 4%]-[SAND 32%]-[DAI 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 43 - [XDEX 4%]-[DAI 32%]-[WETH 32%]-[AXS 32%] BPT Price: $0.00 TVL: $0.00
# 45 - [XDEX 4%]-[DAI 32%]-[TVK 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 46 - [XDEX 4%]-[FXS 32%]-[FRAX 32%]-[WETH 32%] BPT Price: $6.62 TVL: $661.96
# 47 - [XDEX 4%]-[sUSD 32%]-[SNX 32%]-[WETH 32%] BPT Price: $0.00 TVL: $0.00
# 48 - [XDEX 4%]-[USDC 48%]-[DORA 48%] BPT Price: $221.94 TVL: $22,194.39
# 49 - [XDEX 4%]-[DAI 32%]-[WETH 64%] BPT Price: $10.75 TVL: $2,149.34

# %%
pair_df = pd.DataFrame(pairs, columns=['pair1', 'pair2', 'tvl', 'apr', 'where', 'network'])
pair_df['apy'] = np.nan

# %%
pairs
# Out:
# [['WFTM', 'CE', '3425040.24', '219.04', 'https://popsicle.finance', 'FATOM'],
#  ['WFTM', 'CE', '3032060.91', '239.93', 'https://popsicle.finance', 'FATOM'],
#  ['ICE', '', '155258.78', '0.00', 'https://popsicle.finance', 'FATOM'],
#  ['WFTM', 'CE', '3425040.24', '0.00', 'https://popsicle.finance', 'FATOM'],
#  ['fUSDT+DAI+USDC',
#   '',
#   '27704.13',
#   '0.00',
#   'https://popsicle.finance',
#   'FATOM'],
#  ['WFTM',
#   'OO',
#   '10163940.14',
#   '200.84',
#   'https://spookyswap.finance',
#   'FATOM'],
#  ['fUSDT',
#   'FTM',
#   '3371622.58',
#   '95.02',
#   'https://spookyswap.finance',
#   'FATOM'],
#  ['USDC', 'FTM', '4037212.83', '79.57', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM', 'AI', '3240635.33', '99.27', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM', 'TC', '3221214.10', '79.44', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM', 'TH', '4336543.18', '61.47', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM', 'INK', '1850222.03', '69.01', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM', 'AVE', '1801239.05', '73.35', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM', 'NX', '1512730.63', '84.35', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM',
#   'USHI',
#   '1829934.95',
#   '69.77',
#   'https://spookyswap.finance',
#   'FATOM'],
#  ['WFTM', 'AND', '445919.05', '86.43', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM',
#   'REAM',
#   '389320.81',
#   '163.87',
#   'https://spookyswap.finance',
#   'FATOM'],
#  ['CRV', 'FTM', '762864.40', '85.02', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM', 'OVER', '297635.44', '85.85', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM',
#   'ADGER',
#   '494919.23',
#   '90.88',
#   'https://spookyswap.finance',
#   'FATOM'],
#  ['WFTM', 'CE', '3036247.77', '117.63', 'https://spookyswap.finance', 'FATOM'],
#  ['ZOO', 'FTM', '1478839.40', '43.17', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM', 'NB', '2135433.52', '74.73', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM',
#   'OOFY',
#   '1065588.61',
#   '121.36',
#   'https://spookyswap.finance',
#   'FATOM'],
#  ['WFTM', 'NY', '798247.54', '79.97', 'https://spookyswap.finance', 'FATOM'],
#  ['WFTM', 'IFI', '374027.25', '119.44', 'https://spookyswap.finance', 'FATOM'],
#  ['BOO', '', '6500141.14', '173.58', 'https://spookyswap.finance', 'FATOM'],
#  ['SPIRIT',
#   '',
#   '5042230.23',
#   '78.69',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'PIRIT',
#   '9822529.27',
#   '123.23',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'TC',
#   '3656152.77',
#   '54.44',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'TH',
#   '5995241.95',
#   '33.91',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['USDC',
#   'FTM',
#   '3254862.37',
#   '64.31',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['ZOO',
#   'FTM',
#   '2993841.38',
#   '33.46',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'CE',
#   '827902.29',
#   '60.40',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'USHI',
#   '2644170.89',
#   '37.60',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'REAM',
#   '468573.85',
#   '106.48',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['CRV',
#   'FTM',
#   '1688701.00',
#   '58.96',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'INK',
#   '1708812.90',
#   '58.33',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'OVER',
#   '317699.05',
#   '62.77',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'FI',
#   '1852876.57',
#   '53.69',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'RAX',
#   '1306805.22',
#   '76.77',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['FXS',
#   'RAX',
#   '1200538.70',
#   '83.51',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['fUSDT',
#   'FTM',
#   '1496930.70',
#   '66.78',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'NY',
#   '1797988.94',
#   '55.23',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['SPIRIT',
#   'ITB',
#   '67192.40',
#   '147.89',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['SPIRIT',
#   'zTears',
#   '43240.61',
#   '249.17',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'NB',
#   '2919459.95',
#   '68.09',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['SPIRIT',
#   'NB',
#   '331170.32',
#   '150.10',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['YFI',
#   'OOFY',
#   '2769462.85',
#   '17.91',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'UPRA',
#   '71204.72',
#   '139.68',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['SPIRIT',
#   'AI',
#   '1016895.70',
#   '196.51',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['WFTM',
#   'M',
#   '89494.80',
#   '120.44',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['fUSDT',
#   'USD',
#   '2018658.97',
#   '24.69',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['USDC',
#   'TON',
#   '352332.33',
#   '46.77',
#   'https://app.spiritswap.finance',
#   'FATOM'],
#  ['DAI', 'ON', '689.65', '1294.84', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['USDC', 'ON', '1617.40', '641.84', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['WFTM', 'ON', '1878.15', '698.34', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['BTC', 'ON', '6846.05', '248.11', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['ETH', 'ON', '536.12', '2226.87', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['BORGDAI',
#   'ON',
#   '585.90',
#   '1388.68',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['SON', 'ORG', '1005.99', '550.20', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['SON',
#   'URORA',
#   '296.74',
#   '1820.38',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['SON', '', '17306.81', '195.10', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['WFTM',
#   'AI',
#   '313215.65',
#   '537.96',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['USDC',
#   'FTM',
#   '473483.23',
#   '344.23',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['WFTM',
#   'TC',
#   '164806.27',
#   '124.54',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['WFTM',
#   'TH',
#   '262000.94',
#   '110.72',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['USDC',
#   'AI',
#   '954805.18',
#   '330.49',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['WFTM', '', '1411.79', '81.54', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['ETH', '', '1065.21', '108.07', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['YFI', '', '258.38', '445.51', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['FUSD', '', '2760.81', '41.70', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['ICE', '', '252.39', '456.09', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['LINK', '', '764.85', '150.50', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['CREAM',
#   '',
#   '0.00',
#   '26607271.15',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['DAI', '', '1502.35', '76.62', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['OPE', '', '0.00', 0, 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['AURORA', '', '2895.85', '39.75', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['YFI', 'ON', '1637.16', '1826.77', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['WFTM',
#   'ORG',
#   '1564.38',
#   '288.58',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['WFTM',
#   'ORGDAI',
#   '854.06',
#   '582.81',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['BOO', '', '215.44', '534.32', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['SPIRIT', '', '0.00', 0, 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['SON', 'USD', '529.28', '1551.44', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['ZOO', 'ON', '1072.60', '513.10', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['fUSDT',
#   'ON',
#   '539.49',
#   '1549.28',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['SON', 'CE', '600.29', '896.86', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['SON', 'PE', '75.38', '7166.39', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['BORGDAI',
#   'URORA',
#   '293.67',
#   '2334.93',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['BORGDAI',
#   'AI',
#   '965.49',
#   '627.58',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['fUSDT',
#   'ORGDAI',
#   '2448.44',
#   '260.32',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['SNX', '', '0.00', 0, 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['SON', 'INK', '611.82', '1948.40', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['CREAM',
#   'ON',
#   '774.70',
#   '1047.24',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['SON',
#   'USHI',
#   '199.22',
#   '4065.68',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['SON', 'BI', '70.54', '3922.05', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['AURORA',
#   'ORG',
#   '120.49',
#   '3670.70',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['SUSHI', '', '171.64', '670.68', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['WFTM',
#   'URORA',
#   '922563.48',
#   '840.94',
#   'https://ftm.borgswap.exchange',
#   'FATOM'],
#  ['ORI', 'ON', '420.76', '1003.98', 'https://ftm.borgswap.exchange', 'FATOM'],
#  ['ORI', '', '810051.43', '408.27', 'https://hyperjump.fi', 'FATOM'],
#  ['ORI', 'FTM', '1103994.50', '628.61', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'URORA', '938855.63', '233.24', 'https://hyperjump.fi', 'FATOM'],
#  ['USDC', 'FTM', '474672.86', '77.33', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'TH', '262884.46', '66.51', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'TC', '165324.88', '106.43', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'INK', '263489.58', '65.34', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'AI', '314000.25', '56.02', 'https://hyperjump.fi', 'FATOM'],
#  ['USDC', 'RI', '109037.70', '649.74', 'https://hyperjump.fi', 'FATOM'],
#  ['USDC', 'AI', '954805.18', '18.77', 'https://hyperjump.fi', 'FATOM'],
#  ['ORI', 'TH', '78542.13', '443.76', 'https://hyperjump.fi', 'FATOM'],
#  ['ORI', 'TC', '67595.58', '511.13', 'https://hyperjump.fi', 'FATOM'],
#  ['ORI', 'INK', '61673.46', '561.56', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'USHI', '196684.89', '87.67', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'FI', '212850.84', '80.85', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'NX', '450936.49', '130.10', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'NB', '254950.25', '135.34', 'https://hyperjump.fi', 'FATOM'],
#  ['ZOO', 'FTM', '183725.35', '119.82', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'CE', '85339.01', '205.05', 'https://hyperjump.fi', 'FATOM'],
#  ['WFTM', 'SWAP', '33447.01', '662.06', 'https://hyperjump.fi', 'FATOM'],
#  ['ORI', 'SWAP', '34251.02', '1043.58', 'https://hyperjump.fi', 'FATOM'],
#  ['EST', 'FTM', '187422.30', '298.76', 'https://ester.finance', 'FATOM'],
#  ['EST', '', '34510.00', '159.76', 'https://ester.finance', 'FATOM'],
#  ['WFTM',
#   'ROYO',
#   '28656.37',
#   '277.09',
#   'https://frozenyogurt.finance',
#   'FATOM'],
#  ['3FROYO', '', '671667.78', '57.79', 'https://frozenyogurt.finance', 'FATOM'],
#  ['WFTM',
#   'HOST',
#   '23559.68',
#   '8294.38',
#   'https://www.theghost.finance',
#   'FATOM'],
#  ['WFTM',
#   'HOST',
#   '20122.79',
#   '10145.04',
#   'https://www.theghost.finance',
#   'FATOM'],
#  ['WFTM',
#   'HOST',
#   '19892.45',
#   '10754.68',
#   'https://www.theghost.finance',
#   'FATOM'],
#  ['WFTM',
#   'HOST',
#   '12123.13',
#   '10612.12',
#   'https://www.theghost.finance',
#   'FATOM'],
#  ['WFTM',
#   'FI',
#   '339602.59',
#   '80.31',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['WFTM',
#   'AI',
#   '336552.58',
#   '86.91',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['WFTM',
#   'INK',
#   '204836.90',
#   '157.35',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['WFTM',
#   'TH',
#   '330024.64',
#   '83.14',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['fUSDT',
#   'FTM',
#   '217343.79',
#   '125.65',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['WFTM',
#   'TC',
#   '276046.67',
#   '108.69',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['WFTM',
#   'USHI',
#   '499119.95',
#   '67.32',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['WFTM',
#   'REAM',
#   '88650.13',
#   '262.13',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['USDC',
#   'AVE',
#   '117104.36',
#   '101.31',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['WFTM',
#   'NX',
#   '145446.73',
#   '87.60',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['WFTM',
#   'CE',
#   '3437048.60',
#   '118.79',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['WFTM',
#   'OVER',
#   '69169.70',
#   '179.09',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['ZOO',
#   'FTM',
#   '374207.81',
#   '44.66',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['CRV',
#   'FTM',
#   '76410.48',
#   '67.96',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['fUSDT',
#   'RAX',
#   '272727.69',
#   '38.11',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['fUSDT',
#   'QDR',
#   '225199.23',
#   '418.16',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['LQDR',
#   'FTM',
#   '290625.02',
#   '319.88',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['LQDR',
#   '',
#   '249403.48',
#   '163.46',
#   'https://www.liquiddriver.finance',
#   'FATOM'],
#  ['SEED', '', '2852.18', '170.75', 'https://thegreenhouse.finance', 'FATOM'],
#  ['SEED',
#   'FTM',
#   '10921.36',
#   '334.01',
#   'https://thegreenhouse.finance',
#   'FATOM'],
#  ['USDC',
#   'FTM',
#   '4057984.94',
#   '66.23',
#   'https://thegreenhouse.finance',
#   'FATOM'],
#  ['WFTM',
#   'TC',
#   '3249090.19',
#   '25.58',
#   'https://thegreenhouse.finance',
#   'FATOM'],
#  ['WFTM',
#   'TH',
#   '4368435.24',
#   '992.29',
#   'https://thegreenhouse.finance',
#   'FATOM'],
#  ['WFTM',
#   'INK',
#   '1864874.67',
#   '423.53',
#   'https://thegreenhouse.finance',
#   'FATOM'],
#  ['fUSDT',
#   'FTM',
#   '3386217.87',
#   '562.51',
#   'https://thegreenhouse.finance',
#   'FATOM'],
#  ['WFTM',
#   'NB',
#   '2148170.22',
#   '124.23',
#   'https://thegreenhouse.finance',
#   'FATOM'],
#  ['USDC', '', '187.87', '518.47', 'https://thegreenhouse.finance', 'FATOM'],
#  ['WFTM', '', '6995.75', '20.88', 'https://thegreenhouse.finance', 'FATOM'],
#  ['BTC', '', '554.56', '175.64', 'https://thegreenhouse.finance', 'FATOM'],
#  ['ETH', '', '175.06', '556.41', 'https://thegreenhouse.finance', 'FATOM'],
#  ['WFTM', 'AKA', '2637544.80', '708.25', 'https://waka.finance', 'FATOM'],
#  ['fUSDT', 'FTM', '1452141.28', '97.97', 'https://waka.finance', 'FATOM'],
#  ['USDC', 'FTM', '1241234.46', '117.87', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'TC', '1247627.98', '83.13', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'TH', '1193159.82', '89.39', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'TRI', '4668165.49', '57.11', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'AI', '517582.97', '68.29', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'FI', '362383.43', '94.68', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'USHI', '362080.44', '95.28', 'https://waka.finance', 'FATOM'],
#  ['ZOO', 'FTM', '628591.60', '54.58', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'ADGER', '296229.88', '115.67', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'AVE', '370321.16', '92.62', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'CE', '301864.58', '117.22', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'NX', '325403.36', '105.31', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'REAM', '174333.70', '196.61', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'OVER', '289161.27', '118.53', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'INK', '387491.50', '88.66', 'https://waka.finance', 'FATOM'],
#  ['CRV', 'FTM', '331269.34', '103.54', 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'AND', '260426.11', '131.74', 'https://waka.finance', 'FATOM'],
#  ['pWaka', '', '0.00', 0, 'https://waka.finance', 'FATOM'],
#  ['WFTM', 'LK', '104909.59', '81.08', 'https://app.elk.finance', 'FATOM'],
#  ['fUSDT', 'LK', '15459.71', '180.65', 'https://app.elk.finance', 'FATOM'],
#  ['USDC', 'LK', '16627.19', '164.98', 'https://app.elk.finance', 'FATOM'],
#  ['DAI', 'LK', '13800.91', '197.24', 'https://app.elk.finance', 'FATOM'],
#  ['ETH', 'LK', '14747.68', '184.46', 'https://app.elk.finance', 'FATOM'],
#  ['BTC', 'LK', '11796.63', '230.79', 'https://app.elk.finance', 'FATOM'],
#  ['BOO', 'LK', '4721.79', '209.17', 'https://app.elk.finance', 'FATOM'],
#  ['SPIRIT', 'LK', '4731.76', '225.24', 'https://app.elk.finance', 'FATOM'],
#  ['BNB', 'LK', '4417.72', '205.12', 'https://app.elk.finance', 'FATOM'],
#  ['LINK', 'LK', '7560.15', '119.84', 'https://app.elk.finance', 'FATOM'],
#  ['ZOO', 'LK', '4436.04', '204.56', 'https://app.elk.finance', 'FATOM'],
#  ['CREAM', 'LK', '2702.77', '335.26', 'https://app.elk.finance', 'FATOM'],
#  ['ELK', 'CE', '3589.26', '287.98', 'https://app.elk.finance', 'FATOM'],
#  ['YFI', 'LK', '5662.77', '160.01', 'https://app.elk.finance', 'FATOM'],
#  ['AAVE', 'LK', '8683.33', '104.34', 'https://app.elk.finance', 'FATOM'],
#  ['SUSHI', 'LK', '4689.56', '194.00', 'https://app.elk.finance', 'FATOM'],
#  ['ELK', 'STEIN', '3087.06', '370.61', 'https://app.elk.finance', 'FATOM'],
#  ['Shiba', 'LK', '6644.66', '232.36', 'https://app.elk.finance', 'FATOM'],
#  ['BRUSH', '', '58859.88', '439.75', 'https://paintswap.finance', 'FATOM'],
#  ['WFTM', 'RUSH', '138247.76', '945.49', 'https://paintswap.finance', 'FATOM'],
#  ['USDC', 'RUSH', '42558.68', '608.58', 'https://paintswap.finance', 'FATOM'],
#  ['USDC', 'FTM', '77787.56', '410.38', 'https://paintswap.finance', 'FATOM'],
#  ['WFTM', 'NB', '51263.61', '649.64', 'https://paintswap.finance', 'FATOM'],
#  ['WFTM', 'TH', '80369.49', '450.66', 'https://paintswap.finance', 'FATOM'],
#  ['WFTM', 'TC', '65931.61', '646.95', 'https://paintswap.finance', 'FATOM'],
#  ['ZOO', 'RUSH', '11706.87', '1105.82', 'https://paintswap.finance', 'FATOM'],
#  ['BRUSH', 'CE', '9106.34', '1421.19', 'https://paintswap.finance', 'FATOM'],
#  ['SPIRIT',
#   'RUSH',
#   '9133.65',
#   '1417.72',
#   'https://paintswap.finance',
#   'FATOM'],
#  ['BOO', 'RUSH', '9339.12', '1385.76', 'https://paintswap.finance', 'FATOM'],
#  ['WFTM', 'OMB', '1900241.30', '13758.96', 'https://tomb.finance', 'FATOM'],
#  ['WFTM', 'OMB', '1900241.30', '14983.13', 'https://tomb.finance', 'FATOM'],
#  ['WFTM', 'SHARE', '649769.27', '24395.72', 'https://tomb.finance', 'FATOM'],
#  ['WAVAX',
#   'TH',
#   '74923103.40',
#   '35.61',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WBTC',
#   'AVAX',
#   '12797084.56',
#   '30.66',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WAVAX',
#   'INK',
#   '16367727.31',
#   '30.57',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'AVAX',
#   '40274641.83',
#   '92.95',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WAVAX',
#   'SDT',
#   '5346810.96',
#   '30.20',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['SUSHI',
#   'AVAX',
#   '7795581.54',
#   '30.64',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WAVAX',
#   'AI',
#   '5362425.99',
#   '30.68',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['AAVE',
#   'AVAX',
#   '3864339.02',
#   '30.54',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WAVAX',
#   'NI',
#   '1742325.89',
#   '30.79',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['YFI',
#   'AVAX',
#   '510725.58',
#   '30.76',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'TH',
#   '7656286.67',
#   '92.05',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['WBTC',
#   'NG',
#   '295536.03',
#   '100.37',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'INK',
#   '3698331.89',
#   '91.49',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'SDT',
#   '1056940.38',
#   '97.57',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['SUSHI',
#   'NG',
#   '191861.05',
#   '94.22',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'AI',
#   '213826.23',
#   '96.46',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'AVE',
#   '236780.03',
#   '95.40',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'NI',
#   '190039.52',
#   '95.47',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['PNG',
#   'FI',
#   '59254.00',
#   '92.15',
#   'https://app.pangolin.exchange/#/png',
#   'AVAX'],
#  ['YTS',
#   'AVAX',
#   '71177.35',
#   '201.99',
#   'https://exchange.yetiswap.app',
#   'AVAX'],
#  ['WAVAX',
#   'TH',
#   '149798.09',
#   '33.65',
#   'https://exchange.yetiswap.app',
#   'AVAX'],
#  ['WAVAX',
#   'SDT',
#   '106532.13',
#   '66.00',
#   'https://exchange.yetiswap.app',
#   'AVAX'],
#  ['YTS', 'TH', '445.33', '171.76', 'https://exchange.yetiswap.app', 'AVAX'],
#  ['YTS', 'SDT', '1140.08', '168.89', 'https://exchange.yetiswap.app', 'AVAX'],
#  ['YTS', 'NG', '29853.45', '246.11', 'https://exchange.yetiswap.app', 'AVAX'],
#  ['sBAMBOO-V2', '', '0.00', 0, 'https://pandaswap.exchange', 'AVAX'],
#  ['BAMBOO-V2',
#   'AVAX',
#   '4589.38',
#   '236.78',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'AVAX',
#   '17667.88',
#   '101.40',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'TH',
#   '5594.49',
#   '362.66',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['WBTC',
#   'AMBOO-V2',
#   '1945.65',
#   '561.56',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'INK',
#   '12401.68',
#   '87.91',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['SUSHI',
#   'AMBOO-V2',
#   '2976.32',
#   '372.96',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'NOB',
#   '19509.74',
#   '55.82',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['WAVAX', 'TH', '31595.71', '26.84', 'https://pandaswap.exchange', 'AVAX'],
#  ['WAVAX', 'SDT', '1116.61', '339.68', 'https://pandaswap.exchange', 'AVAX'],
#  ['WBTC', 'AVAX', '4115.68', '35.40', 'https://pandaswap.exchange', 'AVAX'],
#  ['BAMBOO-V2',
#   'SDT',
#   '8682.61',
#   '244.59',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BAMBOO-V2',
#   'AI',
#   '4018.15',
#   '287.91',
#   'https://pandaswap.exchange',
#   'AVAX'],
#  ['BURN', '', '0.00', 0, 'https://pandaswap.exchange', 'AVAX'],
#  ['WAVAX',
#   'EFI',
#   '1337320.28',
#   '109.40',
#   'https://penguinfinance.org',
#   'AVAX'],
#  ['WAVAX', 'TH', '74592823.19', '9.92', 'https://penguinfinance.org', 'AVAX'],
#  ['PNG', 'EFI', '811139.88', '149.90', 'https://penguinfinance.org', 'AVAX'],
#  ['SNOB', 'EFI', '636065.69', '191.06', 'https://penguinfinance.org', 'AVAX'],
#  ['SUSHI', 'EFI', '675702.39', '176.38', 'https://penguinfinance.org', 'AVAX'],
#  ['DAI', 'EFI', '784965.24', '148.48', 'https://penguinfinance.org', 'AVAX'],
#  ['LINK', 'EFI', '690433.07', '168.67', 'https://penguinfinance.org', 'AVAX'],
#  ['WAVAX', 'LK', '259051.45', '118.10', 'https://elk.finance', 'AVAX'],
#  ['USDT', 'LK', '81734.10', '119.10', 'https://elk.finance', 'AVAX'],
#  ['ELK', 'TH', '47103.32', '60.00', 'https://elk.finance', 'AVAX'],
#  ['WBTC', 'LK', '26784.85', '71.09', 'https://elk.finance', 'AVAX'],
#  ['LINK', 'LK', '24816.43', '76.27', 'https://elk.finance', 'AVAX'],
#  ['DAI', 'LK', '27554.22', '130.99', 'https://elk.finance', 'AVAX'],
#  ['PNG', 'LK', '11740.80', '99.80', 'https://elk.finance', 'AVAX'],
#  ['YTS', 'LK', '3936.28', '165.55', 'https://elk.finance', 'AVAX'],
#  ['OLIVE', 'LK', '6230.92', '96.98', 'https://elk.finance', 'AVAX'],
#  ['ELK', 'EFI', '5738.48', '161.54', 'https://elk.finance', 'AVAX'],
#  ['SPORE', 'LK', '30805.66', '152.26', 'https://elk.finance', 'AVAX'],
#  ['SUSHI', 'LK', '7401.17', '60.63', 'https://elk.finance', 'AVAX'],
#  ['SFI', 'LK', '5933.10', '142.43', 'https://elk.finance', 'AVAX'],
#  ['SL3', 'LK', '2849.48', '173.17', 'https://elk.finance', 'AVAX'],
#  ['ARFV2', 'LK', '2078.97', '215.01', 'https://elk.finance', 'AVAX'],
#  ['SNOB', 'LK', '6906.23', '134.25', 'https://elk.finance', 'AVAX'],
#  ['OLIVE', '', '191197.73', '88.36', 'https://avax.olive.cash', 'AVAX'],
#  ['OLIVE', 'AVAX', '233288.92', '292.45', 'https://avax.olive.cash', 'AVAX'],
#  ['OLIVE', 'SDT', '195880.02', '69.10', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'SDT', '91127.96', '37.08', 'https://avax.olive.cash', 'AVAX'],
#  ['SUSHI', 'AVAX', '157562.76', '21.44', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'TH', '56144.72', '60.18', 'https://avax.olive.cash', 'AVAX'],
#  ['WBTC', 'AVAX', '102148.61', '33.08', 'https://avax.olive.cash', 'AVAX'],
#  ['PNG', 'AVAX', '25207.99', '33.51', 'https://avax.olive.cash', 'AVAX'],
#  ['DAI', 'SDT', '519953.31', '3.25', 'https://avax.olive.cash', 'AVAX'],
#  ['SPORE', 'AVAX', '133424.99', '63.37', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'LK', '3224.36', '104.79', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'NOB', '4317.21', '195.66', 'https://avax.olive.cash', 'AVAX'],
#  ['LYD', 'AVAX', '2031.78', '166.30', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'DL', '2035.07', '166.03', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'KC', '2682.74', '318.68', 'https://avax.olive.cash', 'AVAX'],
#  ['COM', 'AVAX', '1182.03', '142.92', 'https://avax.olive.cash', 'AVAX'],
#  ['SFI', 'AVAX', '1922.34', '87.92', 'https://avax.olive.cash', 'AVAX'],
#  ['SL3', 'AVAX', '2813.71', '60.72', 'https://avax.olive.cash', 'AVAX'],
#  ['HUSKY', 'AVAX', '39185.46', '172.45', 'https://avax.olive.cash', 'AVAX'],
#  ['ZERO', 'AVAX', '9580.32', '36.39', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'EKO', '8629.64', '97.88', 'https://avax.olive.cash', 'AVAX'],
#  ['WAVAX', 'AVA', '15257.79', '110.73', 'https://avax.olive.cash', 'AVAX'],
#  ['LYD', '', '941571.64', '455.73', 'https://www.lydia.finance', 'AVAX'],
#  ['WAVAX', 'SDT', '446709.15', '61.60', 'https://www.lydia.finance', 'AVAX'],
#  ['WAVAX', 'TH', '1094851.10', '33.37', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'SDT', '755435.27', '491.41', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'AVAX', '889965.96', '412.51', 'https://www.lydia.finance', 'AVAX'],
#  ['SUSHI', 'AVAX', '413557.48', '44.17', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'NG', '410741.35', '445.70', 'https://www.lydia.finance', 'AVAX'],
#  ['WBTC', 'AVAX', '369735.48', '49.41', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'TH', '397894.86', '459.54', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'NOB', '103870.35', '441.18', 'https://www.lydia.finance', 'AVAX'],
#  ['LYD', 'AVA', '99403.92', '459.37', 'https://www.lydia.finance', 'AVAX'],
#  ['gondolaETHPool',
#   '',
#   '3218719.87',
#   '25.99',
#   'https://app.gondola.finance',
#   'AVAX'],
#  ['gondolaUSDTPool',
#   '',
#   '1934048.97',
#   '25.95',
#   'https://app.gondola.finance',
#   'AVAX'],
#  ['ZERO', 'DL', '350664.15', '572.53', 'https://app.gondola.finance', 'AVAX'],
#  ['GDL', '', '705594.66', '189.66', 'https://app.gondola.finance', 'AVAX'],
#  ['WAVAX', 'DL', '386591.12', '519.96', 'https://app.gondola.finance', 'AVAX'],
#  ['WAVAX', 'TH', '335083.78', '89.76', 'https://app.canary.exchange/', 'AVAX'],
#  ['CNR',
#   'AVAX',
#   '89408.10',
#   '1015.51',
#   'https://app.canary.exchange/',
#   'AVAX'],
#  ['WAVAX', 'SDT', '137397.92', 0, 'https://app.canary.exchange/', 'AVAX'],
#  ['WAVAX',
#   'INK',
#   '165476.36',
#   '181.76',
#   'https://app.canary.exchange/',
#   'AVAX'],
#  ['PNG',
#   'AVAX',
#   '137331.19',
#   '219.04',
#   'https://app.canary.exchange/',
#   'AVAX'],
#  ['CNR', 'SDT', '64825.15', '1526.71', 'https://app.canary.exchange/', 'AVAX'],
#  ['CNR', 'TH', '73206.44', '1232.63', 'https://app.canary.exchange/', 'AVAX'],
#  ['CNR', 'INK', '69139.49', '1308.00', 'https://app.canary.exchange/', 'AVAX'],
#  ['PNG', 'NR', '77286.66', '1183.28', 'https://app.canary.exchange/', 'AVAX'],
#  ['CNR', '', '0.00', 0, 'https://app.canary.exchange/', 'AVAX'],
#  ['WAVAX', '', '699302.22', 0, 'https://app.canary.exchange/', 'AVAX'],
#  ['AVME', 'AVAX', '215035.58', '712.17', 'https://avme.io', 'AVAX'],
#  ['Cake', '', '2457658111.57', '81.68', 'https://pancakeswap.finance', 'BSC'],
#  ['LOTTO', '', '0.00', 0, 'https://pancakeswap.finance', 'BSC'],
#  ['BURN', '', '0.00', 0, 'https://pancakeswap.finance', 'BSC'],
#  ['Cake',
#   'BNB',
#   '769408494.56',
#   '58.10',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['WBNB',
#   'USD',
#   '330304472.54',
#   '28.15',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['ADA', 'BNB', '26095415.39', '22.36', 'https://pancakeswap.finance', 'BSC'],
#  ['BAND', 'BNB', '8808421.50', '63.02', 'https://pancakeswap.finance', 'BSC'],
#  ['DOT', 'BNB', '34676582.11', '33.78', 'https://pancakeswap.finance', 'BSC'],
#  ['EOS', 'BNB', '3503152.28', '32.93', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'INK', '29406142.65', '38.52', 'https://pancakeswap.finance', 'BSC'],
#  ['USDT', 'USD', '295137928.73', '7.78', 'https://pancakeswap.finance', 'BSC'],
#  ['TWT', 'BNB', '12356900.96', '90.08', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'VS', '19929985.53', '56.11', 'https://pancakeswap.finance', 'BSC'],
#  ['ETH', 'BNB', '188014470.43', '12.11', 'https://pancakeswap.finance', 'BSC'],
#  ['BTCB',
#   'BNB',
#   '131246426.03',
#   '17.37',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['ALPHA',
#   'BNB',
#   '17337837.30',
#   '64.03',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['USDT',
#   'BNB',
#   '135790247.30',
#   '16.51',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['XRP', 'BNB', '27706176.30', '40.82', 'https://pancakeswap.finance', 'BSC'],
#  ['ATOM', 'BNB', '3741511.71', '29.72', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'NI', '32930161.31', '34.39', 'https://pancakeswap.finance', 'BSC'],
#  ['INJ', 'BNB', '9834426.37', '56.53', 'https://pancakeswap.finance', 'BSC'],
#  ['SXP', 'BNB', '13371482.74', '41.82', 'https://pancakeswap.finance', 'BSC'],
#  ['CTK', 'BNB', '2583288.95', '43.06', 'https://pancakeswap.finance', 'BSC'],
#  ['blink',
#   'BNB',
#   '1021479.43',
#   '108.73',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['VAI', 'USD', '36805812.50', '15.29', 'https://pancakeswap.finance', 'BSC'],
#  ['DITTO', 'BNB', '1198335.16', '92.67', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'EEF', '15335269.58', '72.83', 'https://pancakeswap.finance', 'BSC'],
#  ['BSCX', 'BNB', '3513955.32', '31.81', 'https://pancakeswap.finance', 'BSC'],
#  ['DAI', 'USD', '60588864.82', '9.55', 'https://pancakeswap.finance', 'BSC'],
#  ['USDC', 'USD', '72527034.08', '8.01', 'https://pancakeswap.finance', 'BSC'],
#  ['LTC', 'BNB', '9650194.31', '12.25', 'https://pancakeswap.finance', 'BSC'],
#  ['BTCST',
#   'BNB',
#   '8625471.26',
#   '130.15',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['Helmet',
#   'BNB',
#   '12121990.45',
#   '45.89',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['FRONT',
#   'BNB',
#   '4929846.11',
#   '132.46',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['UST', 'USD', '31494494.33', '17.86', 'https://pancakeswap.finance', 'BSC'],
#  ['BDO', 'BNB', '1101046.20', '101.02', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'GET', '2649268.08', '210.36', 'https://pancakeswap.finance', 'BSC'],
#  ['LIT', 'BNB', '7704308.95', '72.12', 'https://pancakeswap.finance', 'BSC'],
#  ['LINA', 'USD', '5843718.89', '96.38', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'FP', '23305514.53', '23.92', 'https://pancakeswap.finance', 'BSC'],
#  ['ETH', 'OMP', '4138105.07', '26.97', 'https://pancakeswap.finance', 'BSC'],
#  ['ZEE', 'BNB', '3650200.56', '165.83', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'RY', '5792957.33', '139.76', 'https://pancakeswap.finance', 'BSC'],
#  ['SWINGBY',
#   'BNB',
#   '7835898.80',
#   '70.89',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['DODO', 'BNB', '8495495.51', '65.42', 'https://pancakeswap.finance', 'BSC'],
#  ['ETH', 'USHI', '14003827.59', '24.01', 'https://pancakeswap.finance', 'BSC'],
#  ['IOTX', 'USD', '5522341.41', '100.53', 'https://pancakeswap.finance', 'BSC'],
#  ['bMXX', 'BNB', '5218216.48', '213.99', 'https://pancakeswap.finance', 'BSC'],
#  ['xMARK',
#   'USD',
#   '6116093.51',
#   '181.57',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['WATCH', 'BNB', '6576371.09', '85.07', 'https://pancakeswap.finance', 'BSC'],
#  ['BUSD', 'PT', '15575541.74', '35.64', 'https://pancakeswap.finance', 'BSC'],
#  ['BEL', 'BNB', '4989941.23', '111.42', 'https://pancakeswap.finance', 'BSC'],
#  ['DEXE', 'USD', '1331524.70', '83.42', 'https://pancakeswap.finance', 'BSC'],
#  ['BFI', 'BNB', '1166627.96', '95.38', 'https://pancakeswap.finance', 'BSC'],
#  ['RAMP', 'USD', '5694905.43', '97.58', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB',
#   'ELT',
#   '87335157.62',
#   '157.16',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['NULS', 'USD', '7082536.02', '78.37', 'https://pancakeswap.finance', 'BSC'],
#  ['BUX', 'BNB', '1742816.77', '63.74', 'https://pancakeswap.finance', 'BSC'],
#  ['FOR', 'USD', '5659148.01', '98.12', 'https://pancakeswap.finance', 'BSC'],
#  ['ALICE', 'BNB', '6016754.17', '98.36', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB',
#   'UNNY',
#   '25911274.95',
#   '43.61',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['COS', 'BNB', '2559183.33', '45.24', 'https://pancakeswap.finance', 'BSC'],
#  ['TXL', 'USD', '2017974.51', '55.05', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'IFI', '9585699.54', '58.06', 'https://pancakeswap.finance', 'BSC'],
#  ['DUSK', 'BNB', '1908011.18', '58.26', 'https://pancakeswap.finance', 'BSC'],
#  ['TRADE', 'BNB', '1383294.38', '81.31', 'https://pancakeswap.finance', 'BSC'],
#  ['UST', 'IR', '2502642.35', '44.79', 'https://pancakeswap.finance', 'BSC'],
#  ['LTO', 'BNB', '4741643.81', '117.08', 'https://pancakeswap.finance', 'BSC'],
#  ['bDIGG', 'TCB', '3266518.71', '34.68', 'https://pancakeswap.finance', 'BSC'],
#  ['bBADGER',
#   'TCB',
#   '5298097.70',
#   '21.18',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['WBNB', 'CWS', '4803708.90', '115.58', 'https://pancakeswap.finance', 'BSC'],
#  ['ZIL', 'BNB', '12788884.39', '43.44', 'https://pancakeswap.finance', 'BSC'],
#  ['LIEN', 'BNB', '4638306.89', '239.65', 'https://pancakeswap.finance', 'BSC'],
#  ['SWTH', 'BNB', '2149663.44', '51.71', 'https://pancakeswap.finance', 'BSC'],
#  ['DFT', 'BNB', '2537034.29', '108.09', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'BTC', '9512573.78', '58.59', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'UM', '2803613.53', '208.55', 'https://pancakeswap.finance', 'BSC'],
#  ['DEGO', 'BNB', '5153403.50', '107.83', 'https://pancakeswap.finance', 'BSC'],
#  ['NRV', 'BNB', '5440079.06', '204.53', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'DDZ', '1861797.52', '85.55', 'https://pancakeswap.finance', 'BSC'],
#  ['HOO', 'USD', '4293905.36', '129.30', 'https://pancakeswap.finance', 'BSC'],
#  ['APYS', 'BNB', '2604153.59', '213.66', 'https://pancakeswap.finance', 'BSC'],
#  ['TKO', 'BNB', '17630808.84', '63.05', 'https://pancakeswap.finance', 'BSC'],
#  ['BONDLY',
#   'BNB',
#   '5839187.31',
#   '102.07',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['ITAM', 'BNB', '2912312.82', '190.66', 'https://pancakeswap.finance', 'BSC'],
#  ['ARPA', 'BNB', '4199912.45', '132.59', 'https://pancakeswap.finance', 'BSC'],
#  ['EPS', 'BNB', '5720748.04', '197.32', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'GN', '5116523.07', '217.17', 'https://pancakeswap.finance', 'BSC'],
#  ['TLM', 'BNB', '4701141.27', '118.26', 'https://pancakeswap.finance', 'BSC'],
#  ['PERL', 'BNB', '4404791.92', '126.31', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'LPA', '5111962.94', '226.44', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'ZN', '4844306.79', '140.57', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB',
#   'ROOBEE',
#   '3142001.89',
#   '176.95',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['Suter',
#   'BNB',
#   '5028047.18',
#   '221.50',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['CGG', 'BNB', '4845770.39', '230.46', 'https://pancakeswap.finance', 'BSC'],
#  ['HAKKA',
#   'USD',
#   '5512862.70',
#   '201.45',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['XED', 'BNB', '5292037.15', '210.09', 'https://pancakeswap.finance', 'BSC'],
#  ['ALPACA',
#   'USD',
#   '28997527.30',
#   '38.36',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['DFD', 'USD', '4853368.77', '228.90', 'https://pancakeswap.finance', 'BSC'],
#  ['LMT', 'BNB', '4635473.81', '240.76', 'https://pancakeswap.finance', 'BSC'],
#  ['BTCB', 'USD', '60840582.85', '18.40', 'https://pancakeswap.finance', 'BSC'],
#  ['PNT', 'BTC', '7714613.34', '145.47', 'https://pancakeswap.finance', 'BSC'],
#  ['BTT', 'BNB', '14521070.36', '76.50', 'https://pancakeswap.finance', 'BSC'],
#  ['TRX', 'BNB', '19056088.88', '58.97', 'https://pancakeswap.finance', 'BSC'],
#  ['WIN', 'BNB', '10784726.40', '103.16', 'https://pancakeswap.finance', 'BSC'],
#  ['UST', 'COIN', '6810055.41', '83.02', 'https://pancakeswap.finance', 'BSC'],
#  ['BUSD', 'ATH', '7137546.95', '155.85', 'https://pancakeswap.finance', 'BSC'],
#  ['KUN', 'USD', '2812929.19', '197.77', 'https://pancakeswap.finance', 'BSC'],
#  ['HYFI', 'BNB', '4622795.34', '246.67', 'https://pancakeswap.finance', 'BSC'],
#  ['OIN', 'USD', '4080785.67', '272.37', 'https://pancakeswap.finance', 'BSC'],
#  ['DOGE', 'BNB', '12529339.04', '47.19', 'https://pancakeswap.finance', 'BSC'],
#  ['FINE', 'BNB', '9790098.43', '169.31', 'https://pancakeswap.finance', 'BSC'],
#  ['ONE', 'USD', '4845340.28', '229.15', 'https://pancakeswap.finance', 'BSC'],
#  ['PMON', 'USD', '2448563.45', '226.74', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB',
#   'DOGE',
#   '4526643.55',
#   '246.83',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['BTR', 'USD', '4366327.66', '264.77', 'https://pancakeswap.finance', 'BSC'],
#  ['UBXT', 'USD', '2708280.21', '204.96', 'https://pancakeswap.finance', 'BSC'],
#  ['WMASS',
#   'USD',
#   '1984115.08',
#   '280.29',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['RFOX', 'BNB', '4257942.93', '261.14', 'https://pancakeswap.finance', 'BSC'],
#  ['HOTCROSS',
#   'BNB',
#   '10743917.99',
#   '238.19',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['XEND', 'BNB', '5301348.99', '223.49', 'https://pancakeswap.finance', 'BSC'],
#  ['CYC', 'BNB', '5218903.36', '226.76', 'https://pancakeswap.finance', 'BSC'],
#  ['Cake', 'USD', '32353285.63', '69.89', 'https://pancakeswap.finance', 'BSC'],
#  ['BUSD', 'HR', '7840078.66', '153.61', 'https://pancakeswap.finance', 'BSC'],
#  ['DERI', 'USD', '1953786.86', '286.70', 'https://pancakeswap.finance', 'BSC'],
#  ['BUSD', 'ELL', '2441934.17', '227.40', 'https://pancakeswap.finance', 'BSC'],
#  ['pOPEN',
#   'BNB',
#   '3814313.99',
#   '158.42',
#   'https://pancakeswap.finance',
#   'BSC'],
#  ['KALM', 'BNB', '4682404.76', '238.03', 'https://pancakeswap.finance', 'BSC'],
#  ['EZ', 'BNB', '2341075.38', '238.18', 'https://pancakeswap.finance', 'BSC'],
#  ['VRT', 'BNB', '8294038.03', '134.22', 'https://pancakeswap.finance', 'BSC'],
#  ['TUSD', 'USD', '62420906.17', '17.94', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'WG', '427606.98', '278.81', 'https://pancakeswap.finance', 'BSC'],
#  ['MTRG', 'USD', '1855682.64', '300.34', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'TN', '2027724.26', '275.20', 'https://pancakeswap.finance', 'BSC'],
#  ['QKC', 'USD', '4864230.51', '228.86', 'https://pancakeswap.finance', 'BSC'],
#  ['bCFX', 'USD', '8706795.66', '127.63', 'https://pancakeswap.finance', 'BSC'],
#  ['MX', 'USD', '8624154.74', '128.79', 'https://pancakeswap.finance', 'BSC'],
#  ['ATA', 'BNB', '5581742.01', '427.07', 'https://pancakeswap.finance', 'BSC'],
#  ['WBNB', 'AKE', '61310249.85', '83.20', 'https://www.bakeryswap.org', 'BSC'],
#  ['WBNB', 'USD', '6614052.36', '65.93', 'https://www.bakeryswap.org', 'BSC'],
#  ['ETH', 'BNB', '2738485.58', '52.82', 'https://www.bakeryswap.org', 'BSC'],
#  ['BTCB', 'BNB', '67753893.11', '74.54', 'https://www.bakeryswap.org', 'BSC'],
#  ['BAKE', '', '176166854.39', '17.20', 'https://www.bakeryswap.org', 'BSC'],
#  ['BAKE', 'USD', '9149657.32', '130.06', 'https://www.bakeryswap.org', 'BSC'],
#  ['USDT', 'USD', '10466040.49', '27.59', 'https://www.bakeryswap.org', 'BSC'],
#  ['DSPT', '', '0.00', 0, 'https://www.bakeryswap.org', 'BSC'],
#  ['PET', 'AKE', '1593803.21', '108.07', 'https://www.bakeryswap.org', 'BSC'],
#  ['DOGE', 'AKE', '2084112.18', '71.75', 'https://www.bakeryswap.org', 'BSC'],
#  ['BAKEActivity', '', '0.00', 0, 'https://www.bakeryswap.org', 'BSC'],
#  ['BAKEReserve', '', '0.00', 0, 'https://www.bakeryswap.org', 'BSC'],
#  ['USDC', 'USD', '82508928.35', '61.20', 'https://www.bakeryswap.org', 'BSC'],
#  ['BAT', 'AKE', '1383606.17', '104.41', 'https://www.bakeryswap.org', 'BSC'],
#  ['AUTO', 'BNB', '915549.59', '157.68', 'https://www.bakeryswap.org', 'BSC'],
#  ['SOCCER', '', '0.00', 0, 'https://www.bakeryswap.org', 'BSC'],
#  ['SOCCER', 'AKE', '602491.02', '241.95', 'https://www.bakeryswap.org', 'BSC'],
#  ['BakerySoccerStakingPower',
#   '',
#   '0.00',
#   0,
#   'https://www.bakeryswap.org',
#   'BSC'],
#  ['TCT', 'USD', '1198244.61', '120.46', 'https://www.bakeryswap.org', 'BSC'],
#  ['POKER', 'BNB', '556285.47', '263.28', 'https://www.bakeryswap.org', 'BSC'],
#  ['POKER', '', '933676.15', '154.52', 'https://www.bakeryswap.org', 'BSC'],
#  ['CAR', 'BNB', '571054.54', '254.55', 'https://www.bakeryswap.org', 'BSC'],
#  ['CAR', '', '957164.70', '150.73', 'https://www.bakeryswap.org', 'BSC'],
#  ['CarNFTStakingPowerToken',
#   '',
#   '0.00',
#   0,
#   'https://www.bakeryswap.org',
#   'BSC'],
#  ['DOGGY', 'BNB', '6302679.73', '184.12', 'https://www.bakeryswap.org', 'BSC'],
#  ['DoggyNFTStakingPower', '', '0.00', 0, 'https://www.bakeryswap.org', 'BSC'],
#  ['DOGGY', 'ARK', '6670305.68', '216.41', 'https://www.bakeryswap.org', 'BSC'],
#  ['BarkingNFTStakingPower',
#   '',
#   '0.00',
#   0,
#   'https://www.bakeryswap.org',
#   'BSC'],
#  ['WBNB', 'OKAU', '826655.80', '214.53', 'https://www.bakeryswap.org', 'BSC'],
#  ['BREW', '', '4652592.55', '177.89', 'https://cafeswap.finance', 'BSC'],
#  ['BANANA', 'REW', '266757.30', '222.64', 'https://cafeswap.finance', 'BSC'],
#  ['BREW', 'BNB', '3432980.71', '209.30', 'https://cafeswap.finance', 'BSC'],
#  ['BREW', 'USD', '1622152.80', '220.21', 'https://cafeswap.finance', 'BSC'],
#  ['Cake', 'REW', '1426715.73', '198.67', 'https://cafeswap.finance', 'BSC'],
#  ['ETH', 'REW', '1348359.67', '209.88', 'https://cafeswap.finance', 'BSC'],
#  ['DOT', 'REW', '1422253.68', '199.51', 'https://cafeswap.finance', 'BSC'],
#  ['BTCB', 'BNB', '89044.55', '67.37', 'https://cafeswap.finance', 'BSC'],
#  ['TWT', 'BNB', '119384.26', '119.16', 'https://cafeswap.finance', 'BSC'],
#  ['ITAM', 'REW', '114564.54', '263.34', 'https://cafeswap.finance', 'BSC'],
#  ['ITAM', 'BNB', '73960.24', '219.41', 'https://cafeswap.finance', 'BSC'],
#  ['CCC', 'BNB', '12003.04', '472.42', 'https://cafeswap.finance', 'BSC'],
#  ['NAUT', 'BNB', '46931.45', '324.52', 'https://cafeswap.finance', 'BSC'],
#  ['MIST', 'BNB', '81405.01', '178.35', 'https://cafeswap.finance', 'BSC'],
#  ['XDITTO', 'BNB', '37545.00', '188.24', 'https://cafeswap.finance', 'BSC'],
#  ['WBNB', 'IFI', '53301.54', '106.47', 'https://cafeswap.finance', 'BSC'],
#  ['BREW', 'LP', '61184.86', '461.99', 'https://cafeswap.finance', 'BSC'],
#  ['SAFEP', 'BNB', '32683.68', '434.05', 'https://cafeswap.finance', 'BSC'],
#  ['MOCHA', 'BNB', '485139.18', '296.80', 'https://cafeswap.finance', 'BSC'],
#  ['DOT', 'BNB', '160869.07', '87.89', 'https://cafeswap.finance', 'BSC'],
#  ['ATOM', 'BNB', '168630.58', '83.78', 'https://cafeswap.finance', 'BSC'],
#  ['WBNB', 'USD', '158699.81', '93.62', 'https://cafeswap.finance', 'BSC'],
#  ['USDT', 'USD', '1005190.22', '14.05', 'https://cafeswap.finance', 'BSC'],
#  ['WBNB', 'NT', '234351.45', '120.73', 'https://cafeswap.finance', 'BSC'],
#  ['ELCZ', 'BNB', '7065.78', '404.92', 'https://cafeswap.finance', 'BSC'],
#  ['BREW', 'OCHA', '448961.19', '158.15', 'https://cafeswap.finance', 'BSC'],
#  ['PACOCA', 'BNB', '896734.80', '94.65', 'https://cafeswap.finance', 'BSC'],
#  ['wIQ', 'BNB', '24014.02', '666.03', 'https://cafeswap.finance', 'BSC'],
#  ['KETCHUP', 'BNB', '418971.43', '1157.10', 'https://cafeswap.finance', 'BSC'],
#  ['Cake', 'BNB', '44613.70', '992.20', 'https://cafeswap.finance', 'BSC'],
#  ['ETH', 'BNB', '67116.22', '551.90', 'https://cafeswap.finance', 'BSC'],
#  ['Ramen', '', '1024952.44', '128.39', 'https://ramenswap.finance', 'BSC'],
#  ['Ramen', 'BNB', '503209.53', '420.05', 'https://ramenswap.finance', 'BSC'],
#  ['WBNB', 'USD', '7832758.92', '15.19', 'https://ramenswap.finance', 'BSC'],
#  ['Ramen', 'USD', '400627.64', '422.38', 'https://ramenswap.finance', 'BSC'],
#  ['SALT', '', '98202.82', '94.94', 'https://www.saltswap.finance/', 'BSC'],
#  ['SALT',
#   'USD',
#   '138065.66',
#   '278.45',
#   'https://www.saltswap.finance/',
#   'BSC'],
#  ['SALT', 'BNB', '95793.97', '238.16', 'https://www.saltswap.finance/', 'BSC'],
#  ['WBNB',
#   'USD',
#   '7832754.54',
#   '168.72',
#   'https://www.saltswap.finance/',
#   'BSC'],
#  ['DAI', 'USD', '6121096.00', '29.11', 'https://www.saltswap.finance/', 'BSC'],
#  ['ETH',
#   'ETH',
#   '43551053.17',
#   '72.50',
#   'https://www.saltswap.finance/',
#   'BSC'],
#  ['Cake',
#   'USD',
#   '599908.52',
#   '114.35',
#   'https://www.saltswap.finance/',
#   'BSC'],
#  ['Cake',
#   'BNB',
#   '7661672.30',
#   '118.66',
#   'https://www.saltswap.finance/',
#   'BSC'],
#  ['BUSD', '', '93993.67', '19.84', 'https://www.saltswap.finance/', 'BSC'],
#  ['WBNB', '', '20744.34', '44.94', 'https://www.saltswap.finance/', 'BSC'],
#  ['SOUP', 'BNB', '47927.67', '130.49', 'https://soups.finance', 'BSC'],
#  ['SOUPS', 'BNB', '14193.19', '131.83', 'https://soups.finance', 'BSC'],
#  ['GLTO', '', '183204.41', '135.73', 'https://icecreamswap.finance', 'BSC'],
#  ['GLTO', 'BNB', '104064.50', '412.15', 'https://icecreamswap.finance', 'BSC'],
#  ['GLTO', 'USD', '67878.06', '397.85', 'https://icecreamswap.finance', 'BSC'],
#  ['WBNB', 'USD', '16330.78', '224.08', 'https://icecreamswap.finance', 'BSC'],
#  ['BTCB', 'BNB', '2886.68', '394.84', 'https://icecreamswap.finance', 'BSC'],
#  ['WBNB', 'INK', '4987.39', '146.77', 'https://icecreamswap.finance', 'BSC'],
#  ['Cake', 'BNB', '9833.05', '339.00', 'https://icecreamswap.finance', 'BSC'],
#  ['ETH', 'BNB', '2151.50', '340.14', 'https://icecreamswap.finance', 'BSC'],
#  ['USDT', 'USD', '16164.32', '97.24', 'https://icecreamswap.finance', 'BSC'],
#  ['1INCH', 'BNB', '1989.49', '345.67', 'https://icecreamswap.finance', 'BSC'],
#  ['ADA', 'BNB', '3669.33', '184.18', 'https://icecreamswap.finance', 'BSC'],
#  ['MOCHI', 'BNB', '26013.19', '241.36', 'https://pool.mochiswap.io', 'BSC'],
#  ['MOCHI', 'USD', '27939.58', '234.69', 'https://pool.mochiswap.io', 'BSC'],
#  ['MOCHI', 'OGE', '31472.96', '200.54', 'https://pool.mochiswap.io', 'BSC'],
#  ['MOCHI', '', '146293.39', '6.29', 'https://pool.mochiswap.io', 'BSC'],
#  ['MOCHI', 'BNB', '60575.42', '128.35', 'https://pool.mochiswap.io', 'BSC'],
#  ['MOCHI', 'USD', '84499.06', '92.00', 'https://pool.mochiswap.io', 'BSC'],
#  ['MOCHI', 'OGE', '45069.62', '199.81', 'https://pool.mochiswap.io', 'BSC'],
#  ['WBNB', 'USD', '59231.41', '90.94', 'https://pool.mochiswap.io', 'BSC'],
#  ['ADA', 'BNB', '47781.99', '112.54', 'https://pool.mochiswap.io', 'BSC'],
#  ['DOT', 'BNB', '72071.81', '75.95', 'https://pool.mochiswap.io', 'BSC'],
#  ['ETH', 'BNB', '44082.64', '121.96', 'https://pool.mochiswap.io', 'BSC'],
#  ['BTCB', 'BNB', '44151.04', '121.79', 'https://pool.mochiswap.io', 'BSC'],
#  ['DOGE', 'BNB', '37006.72', '124.55', 'https://pool.mochiswap.io', 'BSC'],
#  ['MOCHI', 'PESOX', '58815.51', '168.69', 'https://pool.mochiswap.io', 'BSC'],
#  ['APESOX', 'BNB', '51132.86', '168.80', 'https://pool.mochiswap.io', 'BSC'],
#  ['USDT', 'BNB', '46009.15', '120.37', 'https://pool.mochiswap.io', 'BSC'],
#  ['W', '', '0.00', 0, 'https://app.wault.finance', 'BSC'],
#  ['WEX', 'BNB', '5797326.19', '460.42', 'https://app.wault.finance', 'BSC'],
#  ['WEX', 'BNB', '53583311.18', '476.01', 'https://app.wault.finance', 'BSC'],
#  ['WEX', '', '36842065.40', '158.85', 'https://app.wault.finance', 'BSC'],
#  ['WAULTx',
#   'BNB',
#   '10648621.14',
#   '298.06',
#   'https://app.wault.finance',
#   'BSC'],
#  ['WAULTx', 'BNB', '1746057.71', '427.56', 'https://app.wault.finance', 'BSC'],
#  ['WBNB', 'USD', '41028690.39', '71.34', 'https://app.wault.finance', 'BSC'],
#  ['Cake', 'BNB', '10398015.42', '70.48', 'https://app.wault.finance', 'BSC'],
#  ['BTCB', 'USD', '58529460.15', '41.66', 'https://app.wault.finance', 'BSC'],
#  ['BTCB', 'BNB', '20514366.11', '35.66', 'https://app.wault.finance', 'BSC'],
#  ['ETH', 'BNB', '22856678.82', '32.01', 'https://app.wault.finance', 'BSC'],
#  ['ETH', 'USD', '26806561.48', '36.39', 'https://app.wault.finance', 'BSC'],
#  ['VAI', 'BNB', '2267648.00', '107.54', 'https://app.wault.finance', 'BSC'],
#  ['USDT', 'BNB', '10323902.82', '70.87', 'https://app.wault.finance', 'BSC'],
#  ['USDT', 'USD', '81265890.91', '18.01', 'https://app.wault.finance', 'BSC'],
#  ['DAI', 'USD', '21618204.37', '22.56', 'https://app.wault.finance', 'BSC'],
#  ['USDC', 'BNB', '2794221.38', '87.28', 'https://app.wault.finance', 'BSC'],
#  ['DOT', 'BNB', '6353917.89', '53.73', 'https://app.wault.finance', 'BSC'],
#  ['XVS', 'USD', '1678998.51', '117.72', 'https://app.wault.finance', 'BSC'],
#  ['WBNB', 'INK', '4335510.76', '56.61', 'https://app.wault.finance', 'BSC'],
#  ['LTC', 'USD', '3652065.18', '66.77', 'https://app.wault.finance', 'BSC'],
#  ['XRP', 'USD', '3325267.89', '73.34', 'https://app.wault.finance', 'BSC'],
#  ['ADA', 'USD', '3453590.09', '70.76', 'https://app.wault.finance', 'BSC'],
#  ['DOGE', 'BNB', '2487693.19', '59.01', 'https://app.wault.finance', 'BSC'],
#  ['SWIRL', 'BNB', '785301.39', '317.19', 'https://app.wault.finance', 'BSC'],
#  ['WAULTx', '', '5766108.83', '42.29', 'https://app.wault.finance', 'BSC'],
#  ['EULER', 'BNB', '924416.90', '213.94', 'https://app.wault.finance', 'BSC'],
#  ['ELE', 'BNB', '798820.42', '305.59', 'https://app.wault.finance', 'BSC'],
#  ['ORAI', 'BNB', '680992.64', '394.56', 'https://app.wault.finance', 'BSC'],
# ...
#  ['CRX', '', '7909.59', '173.62', 'https://farm.space', 'BSC'],
#  ['SPACE', '', '120005.08', '114.44', 'https://farm.space', 'BSC'],
#  ['USDC', '', '35331.74', '77.74', 'https://farm.space', 'BSC'],
#  ['USDT', '', '34091.90', '80.56', 'https://farm.space', 'BSC'],
#  ['BTCB', 'BNB', '3856291.11', '462.37', 'https://farm.space', 'BSC'],
#  ['ETH', 'BNB', '5035690.66', '326.44', 'https://farm.space', 'BSC'],
#  ['DAI', '', '33273.25', '82.55', 'https://farm.space', 'BSC'],
#  ['DOT', '', '40880.40', '67.19', 'https://farm.space', 'BSC'],
#  ['SPACEB', '', '0.00', 0, 'https://farm.space', 'BSC'],
#  ['EPS', 'BNB', '15591267.37', '367.59', 'https://ellipsis.finance', 'BSC'],
#  ['3EPS', '', '337375473.08', '17.91', 'https://ellipsis.finance', 'BSC'],
#  ['fusdt3EPS', '', '4359664.38', '18.15', 'https://ellipsis.finance', 'BSC'],
#  ['btcEPS', '', '57382536.13', '0.00', 'https://ellipsis.finance', 'BSC'],
#  ['dai3EPS', '', '2750319.98', '18.29', 'https://ellipsis.finance', 'BSC'],
#  ['tusd3EPS', '', '1230121490.55', '18.24', 'https://ellipsis.finance', 'BSC'],
#  ['ABS', 'BNB', '48129.74', '0.00', 'https://absorber.finance', 'BSC'],
#  ['ABS', 'USD', '5881.96', '0.00', 'https://absorber.finance', 'BSC'],
#  ['Cake', 'BS', '1791.67', '0.00', 'https://absorber.finance', 'BSC'],
#  ['ABS', '', '419666.63', '0.00', 'https://absorber.finance', 'BSC'],
#  ['1INCH', 'BS', '694.60', '0.00', 'https://absorber.finance', 'BSC'],
#  ['E11', '', '0.00', 0, 'https://eleven.finance', 'BSC'],
#  ['bfBNB', '', '0.00', 0, 'https://eleven.finance', 'BSC'],
#  ['DUMMY', '', '0.00', 0, 'https://eleven.finance', 'BSC'],
#  ['ELE', 'BNB', '1375228.91', '74.90', 'https://eleven.finance', 'BSC'],
#  ['DUMMY', '', '0.00', 0, 'https://eleven.finance', 'BSC'],
#  ['DUMMY', '', '0.00', 0, 'https://eleven.finance', 'BSC'],
#  ['yumcha', '', '0.00', 0, 'https://yumcha.finance', 'BSC'],
#  ['yumcha', 'USD', '58290.00', '863.91', 'https://yumcha.finance', 'BSC'],
#  ['ycVT', 'USD', '223972.15', '223.81', 'https://yumcha.finance', 'BSC'],
#  ['WBNB', 'umcha', '10999.31', '911.35', 'https://yumcha.finance', 'BSC'],
#  ['ycVT', 'umcha', '13424.62', '746.51', 'https://yumcha.finance', 'BSC'],
#  ['MUSCLE', 'USD', '29327.99', '675.88', 'https://muscle.finance', 'BSC'],
#  ['MUSCLE', 'BNB', '12250.77', '671.46', 'https://muscle.finance', 'BSC'],
#  ['WBNB', 'USD', '7868608.06', '43.48', 'https://muscle.finance', 'BSC'],
#  ['USDT', 'USD', '6937784.41', '36.65', 'https://muscle.finance', 'BSC'],
#  ['BTCB', 'BNB', '3861749.79', '67.35', 'https://muscle.finance', 'BSC'],
#  ['ETH', 'BNB', '5046605.78', '78.64', 'https://muscle.finance', 'BSC'],
#  ['DAI', 'USD', '6137108.29', '40.71', 'https://muscle.finance', 'BSC'],
#  ['USDC', 'USD', '2896173.36', '39.13', 'https://muscle.finance', 'BSC'],
#  ['DOT', 'BNB', '2888692.72', '46.00', 'https://muscle.finance', 'BSC'],
#  ['MUSCLE', '', '21901.63', '247.36', 'https://muscle.finance', 'BSC'],
#  ['BUSD', '', '11529.60', '37.59', 'https://muscle.finance', 'BSC'],
#  ['WBNB', '', '9394.72', '69.20', 'https://muscle.finance', 'BSC'],
#  ['USDT', '', '4381.46', '49.46', 'https://muscle.finance', 'BSC'],
#  ['BTCB', '', '6877.31', '31.51', 'https://muscle.finance', 'BSC'],
#  ['ETH', '', '5014.56', '43.21', 'https://muscle.finance', 'BSC'],
#  ['DAI', '', '4317.44', '50.19', 'https://muscle.finance', 'BSC'],
#  ['USDC', '', '5101.57', '42.48', 'https://muscle.finance', 'BSC'],
#  ['DOT', '', '3015.03', '71.87', 'https://muscle.finance', 'BSC'],
#  ['Cake', '', '1408.13', '76.95', 'https://muscle.finance', 'BSC'],
#  ['EGG', '', '346.38', '156.40', 'https://muscle.finance', 'BSC'],
#  ['AUTO', '', '894.91', '121.07', 'https://muscle.finance', 'BSC'],
#  ['MUSCLEVIP', '', '0.00', 0, 'https://muscle.finance', 'BSC'],
#  ['MIST', 'USD', '33339.18', '502.82', 'https://www.alchemistdefi.com', 'BSC'],
#  ['MIST', 'BNB', '54614.10', '406.04', 'https://www.alchemistdefi.com', 'BSC'],
#  ['WBNB',
#   'USD',
#   '7868505.43',
#   '195.05',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['BTCB',
#   'BNB',
#   '3861700.25',
#   '233.77',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['DOT',
#   'BNB',
#   '2888061.24',
#   '217.64',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['Cake',
#   'BNB',
#   '7706529.27',
#   '260.87',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['MIST', '', '34418.10', '239.72', 'https://www.alchemistdefi.com', 'BSC'],
#  ['WBNB', '', '5817.05', '170.21', 'https://www.alchemistdefi.com', 'BSC'],
#  ['USDT', '', '5358.77', '61.59', 'https://www.alchemistdefi.com', 'BSC'],
#  ['BTCB', '', '6183.49', '160.12', 'https://www.alchemistdefi.com', 'BSC'],
#  ['ETH', '', '7492.05', '88.10', 'https://www.alchemistdefi.com', 'BSC'],
#  ['Cake', '', '2810.39', '117.43', 'https://www.alchemistdefi.com', 'BSC'],
#  ['AURUM',
#   'IST',
#   '109808.34',
#   '430.94',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['AURUM',
#   'USD',
#   '43512.26',
#   '467.97',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['AURUM', '', '35867.35', '368.06', 'https://www.alchemistdefi.com', 'BSC'],
#  ['MIST',
#   'SCDOG',
#   '4723.83',
#   '350.14',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['BSCDOG',
#   'BNB',
#   '29091.92',
#   '86.69',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['AURUM',
#   'USD',
#   '43512.26',
#   '563.64',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['MIST', 'USD', '33339.18', '555.91', 'https://www.alchemistdefi.com', 'BSC'],
#  ['KNIGHT',
#   'IST',
#   '3247.29',
#   '447.89',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['MIST', '', '16998.51', '426.54', 'https://www.alchemistdefi.com', 'BSC'],
#  ['AURUM', '', '21967.74', '132.02', 'https://www.alchemistdefi.com', 'BSC'],
#  ['WBNB', '', '898.45', '322.80', 'https://www.alchemistdefi.com', 'BSC'],
#  ['Cake', '', '880.96', '329.21', 'https://www.alchemistdefi.com', 'BSC'],
#  ['AURUM',
#   'IST',
#   '109808.34',
#   '455.67',
#   'https://www.alchemistdefi.com',
#   'BSC'],
#  ['MIST', 'BNB', '54614.10', '561.92', 'https://www.alchemistdefi.com', 'BSC'],
#  ['SEED', 'BNB', '968024.52', '372.91', 'https://app.treedefi.com', 'BSC'],
#  ['SEED', 'USD', '2462818.83', '387.67', 'https://app.treedefi.com', 'BSC'],
#  ['WBNB', 'USD', '7868580.57', '191.36', 'https://app.treedefi.com', 'BSC'],
#  ['DAI', 'USD', '6137108.29', '64.98', 'https://app.treedefi.com', 'BSC'],
#  ['SEED', '', '3889004.61', '150.24', 'https://app.treedefi.com', 'BSC'],
#  ['WBNB', '', '652617.28', '71.63', 'https://app.treedefi.com', 'BSC'],
#  ['BTCB', '', '399463.86', '58.51', 'https://app.treedefi.com', 'BSC'],
#  ['USDT', '', '134868.32', '43.32', 'https://app.treedefi.com', 'BSC'],
#  ['DAI', '', '133140.61', '43.89', 'https://app.treedefi.com', 'BSC'],
#  ['BUSD', '', '142366.22', '41.04', 'https://app.treedefi.com', 'BSC'],
#  ['BUSD', 'REE', '4424.23', '180.22', 'https://app.treedefi.com', 'BSC'],
#  ['TREE', '', '2178875.55', '134.08', 'https://app.treedefi.com', 'BSC'],
#  ['SEED', 'REE', '2332967.23', '257.47', 'https://app.treedefi.com', 'BSC'],
#  ['WBNB', 'REE', '1578985.13', '360.82', 'https://app.treedefi.com', 'BSC'],
#  ['Cake', 'EED', '534569.18', '310.01', 'https://app.treedefi.com', 'BSC'],
#  ['GREEN', 'REE', '128993.47', '505.53', 'https://app.treedefi.com', 'BSC'],
#  ['SEED', 'UNNY', '382954.09', '449.99', 'https://app.treedefi.com', 'BSC'],
#  ['ADA', 'EED', '535156.58', '309.88', 'https://app.treedefi.com', 'BSC'],
#  ['SEED', 'IU', '66674.13', '552.56', 'https://app.treedefi.com', 'BSC'],
#  ['SLIME', 'EED', '54315.77', '485.74', 'https://app.treedefi.com', 'BSC'],
#  ['SLIME', 'REE', '53467.03', '493.29', 'https://app.treedefi.com', 'BSC'],
#  ['SEED', '', '3889004.61', '210.34', 'https://app.treedefi.com', 'BSC'],
#  ['SWIRL', '', '192249.34', '0.00', 'https://swirl.cash/mining', 'BSC'],
#  ['SWIRL', 'BNB', '705960.06', '0.00', 'https://swirl.cash/mining', 'BSC'],
#  ['NUTS', 'BNB', '1725388.82', '234.05', 'https://squirrel.finance', 'BSC'],
#  ['NUTS', 'USD', '746950.84', '144.42', 'https://squirrel.finance', 'BSC'],
#  ['Cake', '', '1476540.21', 0, 'https://squirrel.finance', 'BSC'],
#  ['BANANA', '', '148444.98', 0, 'https://squirrel.finance', 'BSC'],
#  ['KEBAB', '', '206127.18', 0, 'https://squirrel.finance', 'BSC'],
#  ['EGG', '', '152254.17', 0, 'https://squirrel.finance', 'BSC'],
#  ['AUTO', 'BNB', '21502289.02', 0, 'https://squirrel.finance', 'BSC'],
#  ['WBNB', 'AKE', '61669093.00', 0, 'https://squirrel.finance', 'BSC'],
#  ['DAI', 'USD', '21666151.22', 0, 'https://squirrel.finance', 'BSC'],
#  ['Cake', '', '1291817.58', 0, 'https://squirrel.finance', 'BSC'],
#  ['WBNB', '', '14938117.47', 0, 'https://squirrel.finance', 'BSC'],
#  ['DBALL', '', '74759.08', '86.12', 'https://dragonballfinance.org', 'BSC'],
#  ['WBNB', '', '16735.77', '76.94', 'https://dragonballfinance.org', 'BSC'],
#  ['SENZU', '', '0.00', 0, 'https://dragonballfinance.org', 'BSC'],
#  ['DBALL',
#   'USD',
#   '25630.70',
#   '512.39',
#   'https://dragonballfinance.org',
#   'BSC'],
#  ['WBNB',
#   'BALL',
#   '23309.80',
#   '553.61',
#   'https://dragonballfinance.org',
#   'BSC'],
#  ['SENZU',
#   'BALL',
#   '39268.83',
#   '196.87',
#   'https://dragonballfinance.org',
#   'BSC'],
#  ['USDT', 'BALL', '6195.31', '539.47', 'https://dragonballfinance.org', 'BSC'],
#  ['BTCB', 'BALL', '3738.65', '861.07', 'https://dragonballfinance.org', 'BSC'],
#  ['ETH', 'BALL', '4034.13', '805.98', 'https://dragonballfinance.org', 'BSC'],
#  ['WBNB', 'ENZU', '6869.09', '234.33', 'https://dragonballfinance.org', 'BSC'],
#  ['Cake', 'BNB', '4460.93', '144.33', 'https://dragonballfinance.org', 'BSC'],
#  ['WBNB', 'USD', '3054.08', '210.82', 'https://dragonballfinance.org', 'BSC'],
#  ['USDT', 'USD', '10540.57', '31.13', 'https://dragonballfinance.org', 'BSC'],
#  ['ETH', 'BNB', '121.27', '1327.26', 'https://dragonballfinance.org', 'BSC'],
#  ['BTCB', 'BNB', '1672.62', '96.23', 'https://dragonballfinance.org', 'BSC'],
#  ['Cake', '', '6734.27', '191.22', 'https://dragonballfinance.org', 'BSC'],
#  ['BTCB', '', '3493.43', '184.30', 'https://dragonballfinance.org', 'BSC'],
#  ['ETH', '', '6183.90', '104.12', 'https://dragonballfinance.org', 'BSC'],
#  ['iBNB', '', '5879036.82', '24.59', 'https://fulcrum.trade', 'BSC'],
#  ['iBUSD', '', '8281778.46', '17.45', 'https://fulcrum.trade', 'BSC'],
#  ['iETH', '', '2435686.93', '2.97', 'https://fulcrum.trade', 'BSC'],
#  ['iUSDT', '', '7730713.32', '18.70', 'https://fulcrum.trade', 'BSC'],
#  ['iBTC', '', '2036626.00', '3.55', 'https://fulcrum.trade', 'BSC'],
#  ['iBZRX', '', '0.00', 0, 'https://fulcrum.trade', 'BSC'],
#  ['BGOV', '', '0.00', 0, 'https://fulcrum.trade', 'BSC'],
#  ['iLINK', '', '0.00', 0, 'https://fulcrum.trade', 'BSC'],
#  ['WBNB', 'GOV', '8461032.44', '41.13', 'https://fulcrum.trade', 'BSC'],
#  ['iAUTO', '', '0.00', 0, 'https://fulcrum.trade', 'BSC'],
#  ['iCAKE', '', '0.00', 0, 'https://fulcrum.trade', 'BSC'],
#  ['iDOGE', '', '0.00', 0, 'https://fulcrum.trade', 'BSC'],
#  ['MASH', 'USD', '120987.88', '151.57', 'https://marshmallowdefi.com', 'BSC'],
#  ['MASH', 'BNB', '85020.55', '217.86', 'https://marshmallowdefi.com', 'BSC'],
#  ['WBNB', 'USD', '7859860.43', '114.13', 'https://marshmallowdefi.com', 'BSC'],
#  ['BTCB', 'BNB', '3857023.74', '52.57', 'https://marshmallowdefi.com', 'BSC'],
#  ['MASH', '', '80806.63', '131.16', 'https://marshmallowdefi.com', 'BSC'],
#  ['Cake', '', '22198.67', '159.14', 'https://marshmallowdefi.com', 'BSC'],
#  ['BUNNY', '', '0.00', 0, 'https://marshmallowdefi.com', 'BSC'],
#  ['BUNNY', '', '0.00', 0, 'https://marshmallowdefi.com', 'BSC'],
#  ['XVS', '', '43467.96', '81.27', 'https://marshmallowdefi.com', 'BSC'],
#  ['VAULT', '', '0.00', 0, 'https://marshmallowdefi.com', 'BSC'],
#  ['WBNB', '', '124772.84', '28.31', 'https://marshmallowdefi.com', 'BSC'],
#  ['BUSD', '', '33574.23', '52.61', 'https://marshmallowdefi.com', 'BSC'],
#  ['BTCB', '', '52687.64', '67.05', 'https://marshmallowdefi.com', 'BSC'],
#  ['BTCB', 'ASH', '37759.07', '133.13', 'https://marshmallowdefi.com', 'BSC'],
#  ['MASH', 'AULT', '2887.87', '1227.68', 'https://marshmallowdefi.com', 'BSC'],
#  ['Cake', 'ASH', '27198.05', '162.30', 'https://marshmallowdefi.com', 'BSC'],
#  ['ENV', '', '0.00', 0, 'https://marshmallowdefi.com', 'BSC'],
#  ['USDC', 'USD', '2896180.17', '33.14', 'https://marshmallowdefi.com', 'BSC'],
#  ['USDT', 'USD', '6937784.36', '29.66', 'https://marshmallowdefi.com', 'BSC'],
#  ['DOGE', 'USD', '97763.44', '148.78', 'https://marshmallowdefi.com', 'BSC'],
#  ['MASH', 'LUM', '12282.36', '1601.68', 'https://marshmallowdefi.com', 'BSC'],
#  ['SLIME', 'ASH', '12392.57', '2007.00', 'https://marshmallowdefi.com', 'BSC'],
#  ['TAKO', 'ASH', '11284.60', '2101.28', 'https://marshmallowdefi.com', 'BSC'],
#  ['ETH', 'USD', '275557.46', '373.11', 'https://marshmallowdefi.com', 'BSC'],
#  ['DOT', 'BNB', '2882461.85', '255.20', 'https://marshmallowdefi.com', 'BSC'],
#  ['PASTA', 'USD', '97564.15', '282.63', 'https://pastafinance.com', 'BSC'],
#  ['PASTA', 'BNB', '55276.65', '304.33', 'https://pastafinance.com', 'BSC'],
#  ['WBNB', 'USD', '7859670.93', '114.57', 'https://pastafinance.com', 'BSC'],
#  ['Cake', 'USD', '602937.04', '363.37', 'https://pastafinance.com', 'BSC'],
#  ['Cake', 'BNB', '7683721.37', '306.88', 'https://pastafinance.com', 'BSC'],
#  ['PASTA', '', '209435.37', '32.36', 'https://pastafinance.com', 'BSC'],
#  ['DODO', 'BNB', '46862.42', '92.69', 'https://pastafinance.com', 'BSC'],
#  ['WBNB', 'EEF', '111467.57', '131.34', 'https://pastafinance.com', 'BSC'],
#  ['WBNB', 'VS', '60591.31', '248.95', 'https://pastafinance.com', 'BSC'],
#  ['WBNB', 'ARD', '23698.92', '137.63', 'https://pastafinance.com', 'BSC'],
#  ['DODO', 'ASTA', '7791.41', '2122.57', 'https://pastafinance.com', 'BSC'],
#  ['Cake', 'ASTA', '5012.72', '1711.93', 'https://pastafinance.com', 'BSC'],
#  ['DOT', 'ASTA', '3963.54', '1739.91', 'https://pastafinance.com', 'BSC'],
#  ['PASTA', 'NI', '3419.28', '2429.57', 'https://pastafinance.com', 'BSC'],
#  ['SUSHI', 'ASTA', '3026.07', '2729.25', 'https://pastafinance.com', 'BSC'],
#  ['PASTA', 'AKE', '7166.70', '1143.26', 'https://pastafinance.com', 'BSC'],
#  ['PIZZA', '', '0.00', 0, 'https://pizzafinance.app', 'BSC'],
#  ['PIZZA', 'BNB', '36190.71', '126.87', 'https://pizzafinance.app', 'BSC'],
#  ['PIZZA', 'USD', '5067.09', '565.71', 'https://pizzafinance.app', 'BSC'],
#  ['PIZZA', 'HS', '6742.37', '424.92', 'https://pizzafinance.app', 'BSC'],
#  ['CHS', 'BNB', '52976.28', '52.51', 'https://pizzafinance.app', 'BSC'],
#  ['WBNB', 'USD', '27070.37', '44.19', 'https://pizzafinance.app', 'BSC'],
#  ['USDT', 'BNB', '24973.49', '16.67', 'https://pizzafinance.app', 'BSC'],
#  ['ETH', 'USD', '7897.41', '39.89', 'https://pizzafinance.app', 'BSC'],
#  ['DAI', 'BNB', '7750.85', '47.25', 'https://pizzafinance.app', 'BSC'],
#  ['USDC', 'BNB', '7300.22', '42.17', 'https://pizzafinance.app', 'BSC'],
#  ['KP3RB', 'BNB', '13685.56', '201.21', 'https://pizzafinance.app', 'BSC'],
#  ['PIZZA', 'SDT', '17777.17', '204.04', 'https://pizzafinance.app', 'BSC'],
#  ['Cake', 'BNB', '4472.24', '38.71', 'https://pizzafinance.app', 'BSC'],
#  ['PIZZA', 'SDC', '10034.55', '297.80', 'https://pizzafinance.app', 'BSC'],
#  ['DAI', 'IZZA', '4024.63', '713.32', 'https://pizzafinance.app', 'BSC'],
#  ['ETH', 'ETH', '175586.24', '0.87', 'https://pizzafinance.app', 'BSC'],
#  ['BETH', 'IZZA', '5653.14', '254.44', 'https://pizzafinance.app', 'BSC'],
#  ['Cake', 'IZZA', '1608.70', '183.30', 'https://pizzafinance.app', 'BSC'],
#  ['WBNB', 'ake-LP', '13704.72', '157.27', 'https://pizzafinance.app', 'BSC'],
#  ['ETH', 'IZZA', '4802.34', '322.17', 'https://pizzafinance.app', 'BSC'],
#  ['TNDR', '', '0.00', 0, 'https://thunderswap.finance', 'BSC'],
#  ['TNDR', 'USD', '10666.37', '230.22', 'https://thunderswap.finance', 'BSC'],
#  ['TNDR', 'BNB', '6340.55', '238.93', 'https://thunderswap.finance', 'BSC'],
#  ['BUSD', '', '54592.12', '20.28', 'https://thunderswap.finance', 'BSC'],
#  ['WBNB', '', '11532.37', '143.97', 'https://thunderswap.finance', 'BSC'],
#  ['TLPT', '', '0.00', 0, 'https://thunderswap.finance', 'BSC'],
#  ['TNDR', 'BNB', '80469.40', '275.26', 'https://thunderswap.finance', 'BSC'],
#  ['TNDR', 'USD', '59221.84', '280.96', 'https://thunderswap.finance', 'BSC'],
#  ['WBNB', 'USD', '17401.40', '136.69', 'https://thunderswap.finance', 'BSC'],
#  ['USDT', 'USD', '60056.92', '13.82', 'https://thunderswap.finance', 'BSC'],
#  ['LABO', '', '0.00', 0, 'https://thelab.finance', 'BSC'],
#  ...]

# %%
pair_df
# Out:
#                pair1 pair2          tvl      apr                      where  \
# 0               WFTM    CE   3425040.24   219.04   https://popsicle.finance
# 1               WFTM    CE   3032060.91   239.93   https://popsicle.finance
# 2                ICE          155258.78     0.00   https://popsicle.finance
# 3               WFTM    CE   3425040.24     0.00   https://popsicle.finance
# 4     fUSDT+DAI+USDC           27704.13     0.00   https://popsicle.finance
# ...              ...   ...          ...      ...                        ...
# 2563            FUSE   SDC     78652.58   279.02            https://fuse.io
# 2564            FUSE   ETH   1025341.98   129.89            https://fuse.io
# 2565            WILD   ETH    895056.11  1700.00        https://wild.credit
# 2566           SPELL   ETH  12514487.48   195.06  https://abracadabra.money
# 2567   MIM-3LP3CRV-f        91396707.50    49.48  https://abracadabra.money
#
#      network  apy
# 0      FATOM  NaN
# 1      FATOM  NaN
# 2      FATOM  NaN
# 3      FATOM  NaN
# 4      FATOM  NaN
# ...      ...  ...
# 2563     ETH  NaN
# 2564     ETH  NaN
# 2565     ETH  NaN
# 2566     ETH  NaN
# 2567     ETH  NaN
#
# [2568 rows x 7 columns]

# %%
pair_df[pair_df['pair2'].isna()]
# Out:
# Empty DataFrame
# Columns: [pair1, pair2, tvl, apr, where, network, apy]
# Index: []

# %%
sheet_pairs_df = pd.read_csv('yieldFarm_6-7.csv')
eth_sheet_pairs_df = pd.read_csv('Alternate.csv')
# eth_sheet_pairs_df.columns=['pair1', 'pair2', 'tvl', 'where', 'apr']
eth_sheet_pairs_df['apy'] = np.nan
# eth_sheet_pairs_df['network'] = 'ETH'
sheet_pairs_df = sheet_pairs_df.append(eth_sheet_pairs_df)
sheet_pairs_df['pair2'] = sheet_pairs_df['pair2'].fillna('')

# %%
sheet_pairs_df
# Out:
#         pair1 pair2        apr  apy        tvl    where    network
# 0    MEATBALL  BUSD  12,573.73  NaN  51500.00%  Swedefi  YieldFarm
# 1    MEATBALL   BNB   6,924.99  NaN  81800.00%  Swedefi  YieldFarm
# 2         BNB  BUSD     338.72  NaN      2,389  Swedefi  YieldFarm
# 3        CAKE   BNB     214.74  NaN      3,768  Swedefi  YieldFarm
# 4        USDT  BUSD   1,116.39  NaN  29000.00%  Swedefi  YieldFarm
# ..        ...   ...        ...  ...        ...      ...        ...
# 190     kmSNX  USDC        NaN  NaN        0.0    SUSHI  Alternate
# 191    kmRUNE  sUSD        NaN  NaN        0.0    SUSHI  Alternate
# 192     kmREN  USDC        NaN  NaN        0.0    SUSHI  Alternate
# 193    kmAAVE   DAI        NaN  NaN        0.0    SUSHI  Alternate
# 194     kmUNI   DAI        NaN  NaN        0.0    SUSHI  Alternate
#
# [369 rows x 7 columns]

# %%
def update_apr(apr):
    apr = f"{apr}".replace("%", "")
    if len(apr) == 0 or "nan" == apr:
        return np.nan
    else:
        return apr

# %%
pair_df = pair_df.append(sheet_pairs_df).reset_index(drop=True)
pair_df['apr'] = pair_df['apr'].apply(lambda x: update_apr(x))
pair_df['pair1'] = pair_df['pair1'].apply(lambda x: sm[x.strip()] if x.strip() in sm else x.strip())
pair_df['pair2'] = pair_df['pair2'].apply(lambda x: sm[x.strip()] if x.strip() in sm else x.strip())

# %%
pair_df['pair2'].unique()
# Out:
# array(['CE', '', 'OO', 'FTM', 'AI', 'TC', 'TH', 'INK', 'AVE', 'NX',
#        'USHI', 'AND', 'REAM', 'OVER', 'ADGER', 'NB', 'OOFY', 'NY', 'IFI',
#        'PIRIT', 'FI', 'RAX', 'ITB', 'zTears', 'UPRA', 'M', 'USD', 'TON',
#        'ON', 'ORG', 'URORA', 'ORGDAI', 'PE', 'BI', 'RI', 'SWAP', 'ROYO',
#        'HOST', 'QDR', 'AKA', 'TRI', 'LK', 'STEIN', 'RUSH', 'OMB', 'SHARE',
#        'AVAX', 'SDT', 'NI', 'NG', 'AMBOO-V2', 'NOB', 'EFI', 'DL', 'KC',
#        'EKO', 'AVA', 'NR', 'BNB', 'VS', 'EEF', 'GET', 'FP', 'OMP', 'RY',
#        'PT', 'ELT', 'UNNY', 'IR', 'TCB', 'CWS', 'BTC', 'UM', 'DDZ', 'GN',
#        'LPA', 'ZN', 'ROOBEE', 'COIN', 'ATH', 'DOGE', 'HR', 'ELL', 'WG',
#        'TN', 'AKE', 'ARK', 'OKAU', 'REW', 'LP', 'NT', 'OCHA', 'ETH',
#        'OGE', 'PESOX', 'EX', 'LPACA', 'ATIC', 'BNB 50%', 'EE 50%',
#        'ASHIMI', 'LF', 'OT', 'YPTUS', 'ACO', 'RL', 'GG', 'RUPEE', 'OM+',
#        'T', 'XP', 'ABLE', 'EGEND', 'BT', 'IST', 'BS', 'umcha', 'SCDOG',
#        'REE', 'EED', 'IU', 'BALL', 'ENZU', 'GOV', 'ASH', 'AULT', 'LUM',
#        'ARD', 'ASTA', 'HS', 'SDC', 'IZZA', 'ake-LP', 'ROOT', 'IME',
#        'BEAR', 'PACHE', 'ANGO', 'IWI', 'AMI', 'NDC', 'EL', 'RX', 'ombie',
#        'hantom', 'OAK', 'OAL', 'ARUDA', 'SAT', 'MTY', 'X', 'FTFY', 'GGP',
#        'ENFI', 'ield', 'BBP', 'RANK', 'WAMP', 'OTA', 'DA', 'MDX', 'DX',
#        'OPEN', 'INVS', 'INV', 'SW', 'ERBERUS', 'ETCHUP', 'EV', 'ARS',
#        'ISH', 'AZY', 'EREWOLF', 'iMATIC', 'ULL', 'UICK', 'ISE', 'olyDoge',
#        'MON', 'OLF', 'GAr', 'EGEN', 'AME', 'C10', 'OCEAN', 'iFARM',
#        'UPER', 'MARK', 'TU', 'FTP', 'LOT', 'RC', 'MT', 'SLA', 'UST',
#        'DIGG', 'dcrvRenWSBTC', 'TR', 'DR', 'MATIC', 'TRDL', 'AZOR', 'AJ',
#        'XS', 'ZAP', 'AUTO', 'FYN', 'TACK', 'OON', 'ITAN', 'RON', 'OOTY',
#        'INGU', 'BULL', 'RISM', 'ENNY', 'RMOR', 'ETH 2%', 'RMOR 2%',
#        'rNXM', 'EFI5', 'RCL5', 'RROR', 'EGS', 'fTUSD', 'ETH2', 'LCX',
#        'INCHa', 'INCHb', 'DP', 'I', 'ETH 20%', 'SDC 20%', 'aia', 'ASK20',
#        'PUNKS20', 'CAT20', 'lonX', 'RIBE', 'OUGH', 'OUGH 80%', 'ETH 30%',
#        'HEY', 'USH', 'FBTC', 'FETH', 'IFT', 'RV', 'BEEPLE', 'GONE',
#        'GLYPH', 'ARTBLOCKS', 'BUSD', 'Pools', 'USDC', 'USDT', 'BTCB',
#        'CAKE', 'DOT', 'US', 'DAI', 'U', 'TUSD', 'CRV', 'OMG', 'AMP',
#        'RARI', 'SEEN', 'INJ', 'BADGER', 'UWL', 'BCP', 'FRONT', 'UOP',
#        'CRETH2', 'pWING', 'RGT', 'ASSY', 'YLD', 'GRT', 'ANY', 'ZRX',
#        'DUCK', 'ROOK', '1INCH', 'AAVE', 'ALPHA', 'BZRX', 'COMP', 'COVER',
#        'CREAM', 'HEGIC', 'LINK', 'REN', 'SRM', 'SUSHI', 'UNI', 'wNXM',
#        'YFI', 'sUSD', 'ibBTC', 'DG', 'WOOFY', 'MLN'], dtype=object)

# %%
pair_df
# Out:
#                pair1 pair2         tvl     apr                     where  \
# 0                FTM    CE  3425040.24  219.04  https://popsicle.finance
# 1                FTM    CE  3032060.91  239.93  https://popsicle.finance
# 2                ICE         155258.78    0.00  https://popsicle.finance
# 3                FTM    CE  3425040.24    0.00  https://popsicle.finance
# 4     fUSDT+DAI+USDC          27704.13    0.00  https://popsicle.finance
# ...              ...   ...         ...     ...                       ...
# 2932           kmSNX  USDC         0.0     NaN                     SUSHI
# 2933          kmRUNE  sUSD         0.0     NaN                     SUSHI
# 2934           kmREN  USDC         0.0     NaN                     SUSHI
# 2935          kmAAVE   DAI         0.0     NaN                     SUSHI
# 2936           kmUNI   DAI         0.0     NaN                     SUSHI
#
#         network  apy
# 0         FATOM  NaN
# 1         FATOM  NaN
# 2         FATOM  NaN
# 3         FATOM  NaN
# 4         FATOM  NaN
# ...         ...  ...
# 2932  Alternate  NaN
# 2933  Alternate  NaN
# 2934  Alternate  NaN
# 2935  Alternate  NaN
# 2936  Alternate  NaN
#
# [2937 rows x 7 columns]

# %%
# pair_df['apr'].unique().tolist()

# %%
def convert_apr_to_apy(pair_df):
    tmp_df = pair_df[pair_df['apy'].isna()]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apr = row['apr']
        if pd.isnull( apr):
            return
        if apr:
            apr = float(apr.replace(',',''))
        else:
            apr = 0
        try:
            pair_df.loc[index, 'apy'] = ((1+(apr/100)/365)**365-1)*100
        except:
            pair_df.loc[index, 'apy'] = np.nan
    return
            
def convert_apy_to_apr(pair_df):
    tmp_df = pair_df[(pair_df['apr'].isnull())]
    print(tmp_df.shape)
    for index, row in tmp_df.iterrows():
        apy = row['apy']
        if pd.isnull( apy):
            return
        if apy:
            apy = float(apy.replace(',',''))
        else:
            apy = 0
        try:
            pair_df.loc[index, 'apr'] = (((1+(apy/100))**(1/365)-1)*365)*100
        except:
            pair_df.loc[index, 'apr'] = np.nan
    return


convert_apr_to_apy(pair_df)
convert_apy_to_apr(pair_df)
# Out:
# (2933, 7)
# (55, 7)

# %%
pair_df[pair_df['apy'].isna()]
# Out:
#          pair1 pair2      tvl             apr  \
# 74       CREAM           0.00     26607271.15
# 1120  MOONTREE  BEAR    35.21  60083983518.52
# 2405      USDT        7279.01       602183.35
# 2406      USDC        1022.71      4285970.71
# 2422      USDC          49.89      4006328.11
# ...        ...   ...      ...             ...
# 2932     kmSNX  USDC      0.0             NaN
# 2933    kmRUNE  sUSD      0.0             NaN
# 2934     kmREN  USDC      0.0             NaN
# 2935    kmAAVE   DAI      0.0             NaN
# 2936     kmUNI   DAI      0.0             NaN
#
#                                           where    network  apy
# 74                https://ftm.borgswap.exchange      FATOM  NaN
# 1120              https://www.ybearswap.finance        BSC  NaN
# 2405  https://www.bigdataprotocol.com/datavault        ETH  NaN
# 2406  https://www.bigdataprotocol.com/datavault        ETH  NaN
# 2422         https://app.sirenmarkets.com/stake        ETH  NaN
# ...                                         ...        ...  ...
# 2932                                      SUSHI  Alternate  NaN
# 2933                                      SUSHI  Alternate  NaN
# 2934                                      SUSHI  Alternate  NaN
# 2935                                      SUSHI  Alternate  NaN
# 2936                                      SUSHI  Alternate  NaN
#
# [174 rows x 7 columns]

# %%
pair_df[pair_df['apr'].isna()]
# Out:
#                 pair1   pair2  tvl  apr  where    network  apy
# 2768           REDUCE          0.0  NaN  SUSHI  Alternate  NaN
# 2803      SAFFRONCHEF          0.0  NaN  SUSHI  Alternate  NaN
# 2860           kmWETH    USDT  0.0  NaN  SUSHI  Alternate  NaN
# 2861           kmWETH    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2862           kmWETH     DAI  0.0  NaN  SUSHI  Alternate  NaN
# 2863           kmWBTC    USDT  0.0  NaN  SUSHI  Alternate  NaN
# 2864           kmWBTC     DAI  0.0  NaN  SUSHI  Alternate  NaN
# 2865           kmWBTC    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2866           kmLINK    USDT  0.0  NaN  SUSHI  Alternate  NaN
# 2867           kmLINK     DAI  0.0  NaN  SUSHI  Alternate  NaN
# 2868           kmLINK    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2869           kmUSDC   1INCH  0.0  NaN  SUSHI  Alternate  NaN
# 2870           kmUSDC    AAVE  0.0  NaN  SUSHI  Alternate  NaN
# 2871           kmUSDC  BADGER  0.0  NaN  SUSHI  Alternate  NaN
# 2872           kmUSDC   ALPHA  0.0  NaN  SUSHI  Alternate  NaN
# 2873           kmUSDC    BZRX  0.0  NaN  SUSHI  Alternate  NaN
# 2874           kmUSDC    COMP  0.0  NaN  SUSHI  Alternate  NaN
# 2875           kmUSDC   COVER  0.0  NaN  SUSHI  Alternate  NaN
# 2876           kmUSDC   CREAM  0.0  NaN  SUSHI  Alternate  NaN
# 2877           kmUSDC     GRT  0.0  NaN  SUSHI  Alternate  NaN
# 2878           kmUSDC   HEGIC  0.0  NaN  SUSHI  Alternate  NaN
# 2879           kmUSDC    LINK  0.0  NaN  SUSHI  Alternate  NaN
# 2880           kmUSDC     REN  0.0  NaN  SUSHI  Alternate  NaN
# 2881           kmUSDC     SRM  0.0  NaN  SUSHI  Alternate  NaN
# 2882           kmUSDC   SUSHI  0.0  NaN  SUSHI  Alternate  NaN
# 2883           kmUSDC     UNI  0.0  NaN  SUSHI  Alternate  NaN
# 2884           kmUSDC    wNXM  0.0  NaN  SUSHI  Alternate  NaN
# 2885           kmUSDC     YFI  0.0  NaN  SUSHI  Alternate  NaN
# 2886          kmSUSHI     UNI  0.0  NaN  SUSHI  Alternate  NaN
# 2887            kmUNI   SUSHI  0.0  NaN  SUSHI  Alternate  NaN
# 2888          kmSUSHI    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2889          kmSUSHI    USDT  0.0  NaN  SUSHI  Alternate  NaN
# 2890          kmSUSHI     DAI  0.0  NaN  SUSHI  Alternate  NaN
# 2891           kmWETH   1INCH  0.0  NaN  SUSHI  Alternate  NaN
# 2892            kmYFI    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2893           kmAAVE    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2894          kmALPHA    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2895         kmBADGER    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2896           kmRUNE    USDT  0.0  NaN  SUSHI  Alternate  NaN
# 2897            kmUMA     DAI  0.0  NaN  SUSHI  Alternate  NaN
# 2898            kmDAI     CRV  0.0  NaN  SUSHI  Alternate  NaN
# 2899            kmDPI    sUSD  0.0  NaN  SUSHI  Alternate  NaN
# 2914         kmxSUSHI     UST  0.0  NaN  SUSHI  Alternate  NaN
# 2915         kmxSUSHI     DAI  0.0  NaN  SUSHI  Alternate  NaN
# 2916         kmxSUSHI    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2917         kmxSUSHI    TUSD  0.0  NaN  SUSHI  Alternate  NaN
# 2918         kmxSUSHI    USDT  0.0  NaN  SUSHI  Alternate  NaN
# 2919  MASTERCHEFDUMMY          0.0  NaN  SUSHI  Alternate  NaN
# 2930           kmCOMP    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2931            kmFTM    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2932            kmSNX    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2933           kmRUNE    sUSD  0.0  NaN  SUSHI  Alternate  NaN
# 2934            kmREN    USDC  0.0  NaN  SUSHI  Alternate  NaN
# 2935           kmAAVE     DAI  0.0  NaN  SUSHI  Alternate  NaN
# 2936            kmUNI     DAI  0.0  NaN  SUSHI  Alternate  NaN

# %%
single_piar_df = pair_df[pair_df['pair2'] == ""].copy()
double_coin_pair_df = pair_df[pair_df['pair2'] != ""].copy()
tmp_df = double_coin_pair_df.copy()

# %%
single_piar_df
# Out:
#                 pair1 pair2         tvl     apr  \
# 2                 ICE         155258.78    0.00
# 4      fUSDT+DAI+USDC          27704.13    0.00
# 26                BOO        6500141.14  173.58
# 27             SPIRIT        5042230.23   78.69
# 62                SON          17306.81  195.10
# ...               ...   ...         ...     ...
# 2692             BUSD          2,737.91   51.65
# 2693             wBNB             1.196   77.87
# 2768           REDUCE               0.0     NaN
# 2803      SAFFRONCHEF               0.0     NaN
# 2919  MASTERCHEFDUMMY               0.0     NaN
#
#                                where    network         apy
# 2           https://popsicle.finance      FATOM         0.0
# 4           https://popsicle.finance      FATOM         0.0
# 26        https://spookyswap.finance      FATOM  465.017004
# 27    https://app.spiritswap.finance      FATOM  119.471672
# 62     https://ftm.borgswap.exchange      FATOM  599.925881
# ...                              ...        ...         ...
# 2692                       PantySwap  YieldFarm     67.5539
# 2693                       PantySwap  YieldFarm  117.683183
# 2768                           SUSHI  Alternate         NaN
# 2803                           SUSHI  Alternate         NaN
# 2919                           SUSHI  Alternate         NaN
#
# [815 rows x 7 columns]

# %%
double_coin_pair_df
# Out:
#        pair1 pair2          tvl     apr                       where  \
# 0        FTM    CE   3425040.24  219.04    https://popsicle.finance
# 1        FTM    CE   3032060.91  239.93    https://popsicle.finance
# 3        FTM    CE   3425040.24    0.00    https://popsicle.finance
# 5        FTM    OO  10163940.14  200.84  https://spookyswap.finance
# 6      fUSDT   FTM   3371622.58   95.02  https://spookyswap.finance
# ...      ...   ...          ...     ...                         ...
# 2932   kmSNX  USDC          0.0     NaN                       SUSHI
# 2933  kmRUNE  sUSD          0.0     NaN                       SUSHI
# 2934   kmREN  USDC          0.0     NaN                       SUSHI
# 2935  kmAAVE   DAI          0.0     NaN                       SUSHI
# 2936   kmUNI   DAI          0.0     NaN                       SUSHI
#
#         network         apy
# 0         FATOM  788.046372
# 1         FATOM  992.931446
# 3         FATOM         0.0
# 5         FATOM  641.047552
# 6         FATOM  158.303566
# ...         ...         ...
# 2932  Alternate         NaN
# 2933  Alternate         NaN
# 2934  Alternate         NaN
# 2935  Alternate         NaN
# 2936  Alternate         NaN
#
# [2122 rows x 7 columns]

# %%
tmp_df
# Out:
#        pair1 pair2          tvl     apr                       where  \
# 0        FTM    CE   3425040.24  219.04    https://popsicle.finance
# 1        FTM    CE   3032060.91  239.93    https://popsicle.finance
# 3        FTM    CE   3425040.24    0.00    https://popsicle.finance
# 5        FTM    OO  10163940.14  200.84  https://spookyswap.finance
# 6      fUSDT   FTM   3371622.58   95.02  https://spookyswap.finance
# ...      ...   ...          ...     ...                         ...
# 2932   kmSNX  USDC          0.0     NaN                       SUSHI
# 2933  kmRUNE  sUSD          0.0     NaN                       SUSHI
# 2934   kmREN  USDC          0.0     NaN                       SUSHI
# 2935  kmAAVE   DAI          0.0     NaN                       SUSHI
# 2936   kmUNI   DAI          0.0     NaN                       SUSHI
#
#         network         apy
# 0         FATOM  788.046372
# 1         FATOM  992.931446
# 3         FATOM         0.0
# 5         FATOM  641.047552
# 6         FATOM  158.303566
# ...         ...         ...
# 2932  Alternate         NaN
# 2933  Alternate         NaN
# 2934  Alternate         NaN
# 2935  Alternate         NaN
# 2936  Alternate         NaN
#
# [2122 rows x 7 columns]

# %%
tmp_df['tmp'] = tmp_df['pair1']
tmp_df['pair1'] = tmp_df['pair2']
tmp_df['pair2'] = tmp_df['tmp']
del tmp_df['tmp']

# %%
double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
# Out:
#         pair1   pair2         tvl     apr                               where  \
# 0         $DG     ETH   738323.48   95.76  https://quickswap.exchange/#/quick
# 1         $DG    UICK   308739.68   84.77  https://quickswap.exchange/#/quick
# 2       1INCH     BNB     1989.49  345.67        https://icecreamswap.finance
# 3       1INCH     BNB    12710.23  291.04            http://mangofarm.finance
# 4       1INCH      BS      694.60    0.00            https://absorber.finance
# ...       ...     ...         ...     ...                                 ...
# 4239     ycVT   umcha    13424.62  746.51              https://yumcha.finance
# 4240   yumcha     USD    58290.00  863.91              https://yumcha.finance
# 4241  yvBOOST     ETH  25943222.8   29.89                               SUSHI
# 4242     zLOT     ETH    47651.84   40.69                               SUSHI
# 4243   zTears  SPIRIT    43240.61  249.17      https://app.spiritswap.finance
#
#         network            apy
# 0         MATIC     160.217083
# 1         MATIC     133.197872
# 2           BSC    3020.050963
# 3           BSC    1715.340213
# 4           BSC            0.0
# ...         ...            ...
# 4239        BSC  161835.925603
# 4240        BSC   510640.49136
# 4241  Alternate            NaN
# 4242  Alternate            NaN
# 4243      FATOM    1097.994043
#
# [4244 rows x 7 columns]

# %%
pair_df = double_coin_pair_df.append(tmp_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)
pair_df = single_piar_df.append(pair_df).sort_values(['pair1', 'pair2']).reset_index(drop=True)

# %%
pair_df
# Out:
#         pair1   pair2         tvl     apr                               where  \
# 0         $DG     ETH   738323.48   95.76  https://quickswap.exchange/#/quick
# 1         $DG    UICK   308739.68   84.77  https://quickswap.exchange/#/quick
# 2       1INCH                0.00       0         https://caramelswap.finance
# 3       1INCH     BNB     1989.49  345.67        https://icecreamswap.finance
# 4       1INCH     BNB    12710.23  291.04            http://mangofarm.finance
# ...       ...     ...         ...     ...                                 ...
# 5054   yumcha                0.00       0              https://yumcha.finance
# 5055   yumcha     USD    58290.00  863.91              https://yumcha.finance
# 5056  yvBOOST     ETH  25943222.8   29.89                               SUSHI
# 5057     zLOT     ETH    47651.84   40.69                               SUSHI
# 5058   zTears  SPIRIT    43240.61  249.17      https://app.spiritswap.finance
#
#         network           apy
# 0         MATIC    160.217083
# 1         MATIC    133.197872
# 2           BSC           0.0
# 3           BSC   3020.050963
# 4           BSC   1715.340213
# ...         ...           ...
# 5054        BSC           0.0
# 5055        BSC  510640.49136
# 5056  Alternate           NaN
# 5057  Alternate           NaN
# 5058      FATOM   1097.994043
#
# [5059 rows x 7 columns]

# %%
pair_df = pair_df.drop_duplicates()

# %%
pair_df['dex'] = pair_df['where']
del pair_df['where']
# Out:
# <ipython-input-34-2bf09cd45164>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pair_df['dex'] = pair_df['where']

# %%
pair_df.to_csv('vfat_tools_data_2021_06_07.csv')

# %%
pair_df['dex'].unique().tolist()
# Out:
# ['https://quickswap.exchange/#/quick',
#  'https://caramelswap.finance',
#  'https://icecreamswap.finance',
#  'http://mangofarm.finance',
#  'https://absorber.finance',
#  'BabySwap',
#  'SUSHI',
#  'https://www.convexfinance.com',
#  'https://ellipsis.finance',
#  'https://frozenyogurt.finance',
#  'https://beta.belt.fi',
#  'https://blue.planetfinance.io',
#  'https://polygaj.finance',
#  'https://www.polycake.finance',
#  'https://polylion.exchange',
#  'https://www.moonwolf.io',
#  'https://polygold.finance',
#  'https://polypingu.finance',
#  'https://polygon.prismfinance.net',
#  'https://www.bigdataprotocol.com/datavault',
#  'https://app.pangolin.exchange/#/png',
#  'https://app.elk.finance',
#  'https://www.knightsdefi.com',
#  'hhttps://taco.finance/',
#  'https://swipe.org/farm',
#  'https://koaladefi.finance/',
#  'https://app.hyruleswap.com',
#  'https://limeswap.io',
#  'https://vanillacake.farm',
#  'https://garudaswap.finance',
#  'https://gocerberus.finance',
#  'https://ketchupfinance.com',
#  'https://TheKongFinance.com',
#  'https://pancakeswap.finance',
#  'https://pool.mochiswap.io',
#  'https://thelab.finance',
#  'https://app.apache.finance/',
#  'https://zombie-farm.com',
#  'https://coinswap.space/',
#  'https://gatorswap.xyz',
#  'https://ten.finance',
#  'https://frankenstein.finance',
#  'MachoSwap',
#  'RushMoon',
#  'Cerberus',
#  'https://app.treedefi.com',
#  'https://app.wault.finance',
#  'https://spookyswap.finance',
#  'https://waka.finance',
#  'https://polycat.finance',
#  'Polycat',
#  'https://armor.fi',
#  'https://pandaswap.exchange',
#  'https://ftm.borgswap.exchange',
#  'https://hyperjump.fi',
#  'https://www.liquiddriver.finance',
#  'https://klondike.finance',
#  'https://olympusdao.eth.link/',
#  'https://app.spiritswap.finance',
#  'https://swap.cometh.io/#/stake',
#  'https://app.sushi.com',
#  'https://farm.polyzap.finance',
#  'https://southpark.finance/',
#  'https://www.bakeryswap.org',
#  'https://squirrel.finance',
#  'https://www.ybearswap.finance',
#  'https://mars.cosmos.farm',
#  'https://pastafinance.com',
#  'https://app.alchemix.fi/farms',
#  'https://app.sponge.finance',
#  'https://aluna.social/farm',
#  'https://app.bami.money',
#  'https://farm.unicrypt.network',
#  'https://elk.finance',
#  'https://www.app.unic.ly/#/farm',
#  'https://marshmallowdefi.com',
#  'https://bsc.sashimi.cool/',
#  'https://nft20.io',
#  'https://fanaticsfinance.com',
#  'https://cafeswap.finance',
#  'https://www.alchemistdefi.com',
#  'https://muscle.finance',
#  'https://www.coralfarm.finance/',
#  'https://avax.olive.cash',
#  'https://www.lydia.finance',
#  'https://app.canary.exchange/',
#  'https://avme.io',
#  'https://app.gondola.finance',
#  'https://penguinfinance.org',
#  'https://bsc.complus.exchange',
#  'https://exchange.yetiswap.app',
#  'https://lazymint.finance',
#  'https://dragonballfinance.org',
#  'https://yieldfields.finance',
#  'https://floatprotocol.com/#/stake',
#  'https://app.lift.kitchen',
#  'https://www.piedao.org',
#  'https://bundledao.org',
#  'https://wantanmee.finance',
#  'https://pizzafinance.app',
#  'https://longdrink.finance',
#  'https://fulcrum.trade',
#  'https://www.proofofhumanity.id',
#  'https://www.wardenswap.finance',
#  'https://www.saltswap.finance/',
#  'https://farm.space',
#  'https://thunderswap.finance',
#  'https://plumcake.finance',
#  'https://farms.tinville.finance',
#  'https://bsc.prismfinance.net',
#  'https://tea-swap-app.finance',
#  'https://werewolf.farm',
#  'https://tsuki.finance',
#  'https://biswap.org',
#  'FarmHero',
#  'https://satis.finance',
#  'https://www.pinkswap.finance',
#  'Swedefi',
#  'PantySwap',
#  'https://privacyswap.finance',
#  'https://friction.finance',
#  'https://eggplant.fi',
#  'https://eleven.finance',
#  'https://app.feeder.finance',
#  'https://fluity.finance',
#  'https://nftfy.org',
#  'https://wheat.growthdefi.com',
#  'https://fishswap.app',
#  'https://smoothy.finance',
#  'https://www.pureswap.finance',
#  'https://berrydata.co/',
#  'https://ramenswap.finance',
#  'https://soups.finance',
#  'https://swirl.cash/mining',
#  'https://farm.wsbdapp.com',
#  'https://yumcha.finance',
#  'https://paintswap.finance',
#  'https://piratedice.xyz',
#  'https://thegreenhouse.finance',
#  'https://polywhale.finance',
#  'https://polybull.finance',
#  'https://farms.goldenbull.finance',
#  'https://app.sirenmarkets.com/stake',
#  'https://app.compli.fi',
#  'https://indexed.finance',
#  'https://popsicle.finance',
#  'https://cntr.finance',
#  'https://app.cryptex.finance',
#  'https://cyclone.xyz/eth',
#  'http://stake.kineko.io',
#  'https://exchange.dfyn.network',
#  'https://pegs.cash',
#  'https://ester.finance',
#  'PolyDragon',
#  'https://fuse.io',
#  'https://xtoken.cafe/app/dashboard',
#  'https://lever.network',
#  'https://launchpad.benchmarkprotocol.finance/pools',
#  'https://stake.publicmint.com',
#  'https://mochi.market',
#  'https://www.sharedstake.org/earn',
#  'https://www.dollarprotocol.com/#/stake',
#  'https://app.xsigma.fi',
#  'https://abracadabra.money',
#  'https://app.truefi.io/farm',
#  'https://farm.umbria.network',
#  'https://incentives.epns.io',
#  'https://wasabix.finance/#/app/pool',
#  'https://wild.credit',
#  'https://app.wolvesofwallstreet.finance',
#  'https://yaxis.io/farms',
#  'https://fei.money',
#  'https://www.theghost.finance',
#  'https://tomb.finance',
#  'https://polygon.iron.finance',
#  'https://bsc.lever.network/Staking',
#  'https://gravityfinance.io/app/#farms',
#  'https://mith.cash',
#  'https://www.mai.finance',
#  'https://stacker.vc',
#  'https://penguinswap.eth.link']

# %%
pair_df[pair_df['pair1'] == 'ETH']
# Out:
#      pair1    pair2         tvl       apr    network  \
# 1975   ETH              1065.21    108.07      FATOM
# 1976   ETH               175.06    556.41      FATOM
# 1977   ETH                 6.37  77847.71        BSC
# 1978   ETH            520768.24     28.23        BSC
# 1979   ETH            167226.10     46.56        BSC
# ...    ...      ...         ...       ...        ...
# 2362   ETH    xKNCa     7245.58      0.00        ETH
# 2363   ETH    xKNCb     7218.95      0.00        ETH
# 2364   ETH   xSUSHI  40479500.8     16.76  Alternate
# 2365   ETH  yvBOOST  25943222.8     29.89  Alternate
# 2366   ETH     zLOT    47651.84     40.69  Alternate
#
#                                                     apy  \
# 1975                                         194.204015
# 1976                                       24916.388851
# 1977  1037842848943826568478985412663639458915456380...
# 1978                                          32.603182
# 1979                                           59.24971
# ...                                                 ...
# 2362                                                0.0
# 2363                                                0.0
# 2364                                          18.241805
# 2365                                                NaN
# 2366                                                NaN
#
#                                     dex
# 1975      https://ftm.borgswap.exchange
# 1976      https://thegreenhouse.finance
# 1977          https://wantanmee.finance
# 1978         https://koaladefi.finance/
# 1979         https://app.hyruleswap.com
# ...                                 ...
# 2362  https://xtoken.cafe/app/dashboard
# 2363  https://xtoken.cafe/app/dashboard
# 2364                              SUSHI
# 2365                              SUSHI
# 2366                              SUSHI
#
# [390 rows x 7 columns]

# %%
pair_df['apr'].unique().tolist()
# Out:
# ['95.76',
#  '84.77',
#  '0',
#  '345.67',
#  '291.04',
#  '0.00',
#  '29.46',
#  '486.39',
#  nan,
#  '17.91',
#  '57.79',
#  '76.66',
#  '85.81',
#  '568.48',
#  '340.14',
#  '560.05',
#  '166350.20',
#  '30.54',
#  '11.17',
#  '104.34',
#  '236.66',
#  '200.06',
#  '392.75',
#  '517.04',
#  '160.27',
#  '562.23',
#  '518.53',
#  '0.31',
#  '37.94',
#  '36.49',
#  '26.31',
#  '178.68',
#  '155.71',
#  '29.12',
#  '106.17',
#  '343.82',
#  '52.13',
#  '22.36',
#  '184.18',
#  '112.54',
#  '3.48',
#  '80.31',
#  '332.97',
#  '117.66',
#  '199.03',
#  '105.83',
#  '100.57',
#  '231.19',
#  '553.52',
#  '46.18',
#  '173.50',
#  '79.55',
#  '49.04',
#  '507.18',
#  '153.72',
#  '265.80',
#  '1,302.20',
#  '143.72',
#  '157.18',
#  '309.88',
#  '261.58',
#  '454.42',
#  '167.15',
#  '70.76',
#  '525.65',
#  '90.88',
#  '115.67',
#  '39.96',
#  '40.24',
#  '181.85',
#  '61.02',
#  '197.87',
#  '92.24',
#  '98.12',
#  '111.21',
#  '30.68',
#  '287.91',
#  '627.58',
#  '99.27',
#  '537.96',
#  '56.02',
#  '86.91',
#  '68.29',
#  '37.82',
#  '380.75',
#  '96.46',
#  '196.51',
#  '42.66',
#  '330.49',
#  '18.77',
#  '12.14',
#  '18.72',
#  '12.29',
#  '64.42',
#  '198.09',
#  '663.71',
#  '672.23',
#  '708.25',
#  '104.41',
#  '83.20',
#  '683.87',
#  '254.84',
#  '177.04',
#  '132.81',
#  '820.05',
#  '71.75',
#  '1703.67',
#  '1143.26',
#  '108.07',
#  '241.95',
#  '32.56',
#  '132.24',
#  '52.89',
#  '98.36',
#  '29.26',
#  '281.67',
#  '368.20',
#  '98.55',
#  '1071.18',
#  '157.70',
#  '1,710.29',
#  '38.36',
#  '69.00',
#  '1663.47',
#  '64.03',
#  '24.43',
#  '35.0',
#  '561.56',
#  '372.96',
#  '94.77',
#  '17.49',
#  '86.43',
#  '131.74',
#  '42.07',
#  '89.25',
#  '429.70',
#  '5.37',
#  '2.11',
#  '68.60',
#  '161.31',
#  '935.31',
#  '873.85',
#  '31.58',
#  '168.80',
#  '14.83',
#  '213.66',
#  '442.88',
#  '607.03',
#  '808.66',
#  '15.99',
#  '27.47',
#  '51.72',
#  '137.63',
#  '215.01',
#  '216.41',
#  '94.38',
#  '124.06',
#  '92.11',
#  '82.10',
#  '81.77',
#  '44.86',
#  '69.72',
#  '132.59',
#  '862.11',
#  '246.33',
#  '856.06',
#  '8554.10',
#  '7633.05',
#  '726.08',
#  '773.34',
#  '439.25',
#  '133.13',
#  '162.30',
#  '2007.00',
#  '2101.28',
#  '140.95',
#  '156.50',
#  '102.65',
#  '669.19',
#  '42.04',
#  '1711.93',
#  '2122.57',
#  '1739.91',
#  '2729.25',
#  '427.07',
#  '155.85',
#  '15.49',
#  '328.97',
#  '172.54',
#  '727.98',
#  '29.72',
#  '83.78',
#  '1227.68',
#  '39.75',
#  '3670.70',
#  '368.06',
#  '132.02',
#  '430.94',
#  '455.67',
#  '467.97',
#  '563.64',
#  '250.15',
#  '121.07',
#  '286.00',
#  '157.68',
#  '72.81',
#  '1154.63',
#  '794.36',
#  '152.26',
#  '110.73',
#  '459.37',
#  '712.17',
#  '236.78',
#  '101.40',
#  '30.66',
#  '35.40',
#  '33.08',
#  '49.41',
#  '1015.51',
#  '142.92',
#  '166.03',
#  '519.96',
#  '109.40',
#  '97.88',
#  '172.45',
#  '30.57',
#  '181.76',
#  '318.68',
#  '118.10',
#  '104.79',
#  '166.30',
#  '412.51',
#  '30.79',
#  '195.66',
#  '292.45',
#  '319.70',
#  '92.95',
#  '33.51',
#  '219.04',
#  '30.20',
#  '66.00',
#  '339.68',
#  '37.08',
#  '61.60',
#  '87.92',
#  '60.72',
#  '63.37',
#  '30.64',
#  '21.44',
#  '44.17',
#  '35.61',
#  '33.65',
#  '26.84',
#  '9.92',
#  '60.18',
#  '33.37',
#  '89.76',
#  '898.98',
#  '30.76',
#  '201.99',
#  '36.39',
#  '73.35',
#  '92.62',
#  '4.79',
#  '95.40',
#  '101.31',
#  '90.26',
#  '21.7',
#  '17.34',
#  '76.86',
#  '155.51',
#  '187.52',
#  '4717.56',
#  '4682.37',
#  '640.48',
#  '1,108.44',
#  '191.28',
#  '21.88',
#  '17.20',
#  '125.69',
#  '272.95',
#  '478.44',
#  '490.98',
#  '48.70',
#  '1130.55',
#  '130.06',
#  '1066.03',
#  '390.38',
#  '553.61',
#  '861.07',
#  '805.98',
#  '196.87',
#  '539.47',
#  '87.91',
#  '55.82',
#  '244.59',
#  '362.66',
#  '10.45',
#  '41.34',
#  '276.66',
#  '222.64',
#  '351.45',
#  '9.57',
#  '430.98',
#  '329.67',
#  '63.02',
#  '13.17',
#  '28.34',
#  '50.16',
#  '69.81',
#  '141.72',
#  '137.58',
#  '73.68',
#  '52.65',
#  '168.35',
#  '734.45',
#  '696.40',
#  '46.47',
#  '16.2',
#  '28.35',
#  '8636.73',
#  '66756.97',
#  '101.02',
#  '20.41',
#  '598.14',
#  '60083983518.52',
#  '978.73',
#  '1270.36',
#  '1130.15',
#  '1536.32',
#  '1345.97',
#  '3008.48',
#  '701.49',
#  '562.56',
#  '111.42',
#  '169.33',
#  '101942.03',
#  '151.63',
#  '254.44',
#  '97.78',
#  '192.75',
#  '95.38',
#  '108.18',
#  '110.01',
#  '102.27',
#  '3922.05',
#  '208.19',
#  '120.25',
#  '32.33',
#  '494.38',
#  '44.94',
#  '47.83',
#  '1.31',
#  '48.52',
#  '44.42',
#  '69.20',
#  '170.21',
#  '322.80',
#  '71.63',
#  '76.94',
#  '28.31',
#  '143.97',
#  '73.88',
#  '42.85',
#  '180.35',
#  '278.79',
#  '38.62',
#  '156.34',
#  '20.38',
#  '6.20',
#  '74.84',
#  '384.88',
#  '58.35',
#  '16.94',
#  '292.68',
#  '87.01',
#  '136.94',
#  '74.49',
#  '130.67',
#  '102.07',
#  '102.60',
#  '209.30',
#  '86.69',
#  '31.81',
#  '1439.43',
#  '58.59',
#  '82.45',
#  '103.92',
#  '89.38',
#  '17.37',
#  '74.54',
#  '67.37',
#  '394.84',
#  '121.79',
#  '35.66',
#  '365.15',
#  '413.64',
#  '293.24',
#  '55.07',
#  '16.48',
#  '462.37',
#  '67.35',
#  '233.77',
#  '96.23',
#  '52.57',
#  '150.27',
#  '56.49',
#  '1080.65',
#  '313.92',
#  '266.15',
#  '270.10',
#  '158.43',
#  '227.04',
#  '52.31',
#  '94.33',
#  '246.65',
#  '194.45',
#  '47.97',
#  '75.73',
#  '31.00',
#  '88.63',
#  '66.93',
#  '246.47',
#  '624.20',
#  '149.81',
#  '177.34',
#  '489.33',
#  '181.34',
#  '3088.65',
#  '200.36',
#  '1052.05',
#  '92.04',
#  '148.67',
#  '127.74',
#  '66.99',
#  '796.70',
#  '1,556.13',
#  '181.43',
#  '130.15',
#  '19.60',
#  '76.50',
#  '81.70',
#  '1,850.40',
#  '445.63',
#  '338.72',
#  '113.32',
#  '942.79',
#  '251.99',
#  '284.84',
#  '1,276.67',
#  '63.74',
#  '27.88',
#  '214.74',
#  '92.92',
#  '956.06',
#  '2,750.41',
#  '1165.94',
#  '202.55',
#  '254.55',
#  '472.42',
#  '792.97',
#  '799.57',
#  '230.46',
#  '19.86',
#  '52.51',
#  '65.83',
#  '79.56',
#  '108.82',
#  '45.24',
#  '43.06',
#  '115.58',
#  '226.76',
#  '58.10',
#  '992.20',
#  '118.66',
#  '339.00',
#  '70.48',
#  '88.57',
#  '192.22',
#  '204.48',
#  '115.35',
#  '260.87',
#  '144.33',
#  '306.88',
#  '38.71',
#  '412.11',
#  '82.56',
#  '750.80',
#  '175.91',
#  '253.53',
#  '371.35',
#  '90.73',
#  '152.54',
#  '113.70',
#  '79.20',
#  '183.83',
#  '96.22',
#  '256.80',
#  '234.74',
#  '163.31',
#  '269.90',
#  '59.21',
#  '238.02',
#  '39.44',
#  '203.80',
#  '195.82',
#  '218.78',
#  '300.36',
#  '1140.11',
#  '384.82',
#  '189.61',
#  '96.37',
#  '377.94',
#  '125.64',
#  '47.25',
#  '85.55',
#  '107.83',
#  '108.09',
#  '93.45',
#  '92.67',
#  '65.42',
#  '92.69',
#  '243.14',
#  '249.60',
#  '33.07',
#  '246.83',
#  '101.64',
#  '239.69',
#  '47.19',
#  '124.55',
#  '59.01',
#  '648.08',
#  '114.88',
#  '9.55',
#  '250.92',
#  '830.53',
#  '229.21',
#  '258.38',
#  '184.12',
#  '33.78',
#  '87.89',
#  '75.95',
#  '53.73',
#  '241.94',
#  '1665.53',
#  '527.27',
#  '6.23',
#  '46.00',
#  '217.64',
#  '255.20',
#  '179.26',
#  '176.74',
#  '259.92',
#  '469.49',
#  '60.68',
#  '127.20',
#  '106.87',
#  '78.60',
#  '269.83',
#  '57.61',
#  '31.21',
#  '320.73',
#  '65.53',
#  '24.78',
#  '220.66',
#  '42.47',
#  '145.23',
#  '103.52',
#  '76.48',
#  '1,098.33',
#  '122.74',
#  '223.87',
#  '58.26',
#  '72.83',
#  '131.34',
#  '115.06',
#  '765.73',
#  '404.92',
#  '305.59',
#  '74.90',
#  '157.16',
#  '154.22',
#  '190.23',
#  '20.61',
#  '423.61',
#  '234.33',
#  '32.93',
#  '925.82',
#  '197.32',
#  '367.59',
#  '12.11',
#  '52.82',
#  '551.90',
#  '121.96',
#  '32.01',
#  '211.11',
#  '561.77',
#  '350.48',
#  '46.70',
#  '143.84',
#  '2.51',
#  '326.44',
#  '78.64',
#  '1327.26',
#  '86.48',
#  '1006.68',
#  '271.96',
#  '279.66',
#  '374.54',
#  '44.49',
#  '121.52',
#  '99.62',
#  '44.63',
#  '204.45',
#  '168.12',
#  '175.41',
#  '6.81',
#  '45.10',
#  '76.14',
#  '64.56',
#  '172.63',
#  '22.88',
#  '66.74',
#  '170.16',
#  '587.99',
#  '100.14',
#  '483.93',
#  '243.18',
#  '81.56',
#  '244.60',
#  '103.98',
#  '60.08',
#  '118.65',
#  '61.53',
#  '36.34',
#  '1,079.03',
#  '347.81',
#  '1,616.13',
#  '173.64',
#  '213.94',
#  '404.78',
#  '238.18',
#  '502.68',
#  '169.31',
#  '211.98',
#  '23.92',
#  '570.30',
#  '1071.44',
#  '132.46',
#  '209.84',
#  '536.62',
#  '703.86',
#  '3892.92',
#  '210.36',
#  '19.95',
#  '412.15',
#  '217.17',
#  '41.13',
#  '41.31',
#  '74.00',
#  '6,001.38',
#  '238.19',
#  '246.67',
#  '418.24',
#  '45.89',
#  '58.06',
#  '106.47',
#  '77.51',
#  '404.24',
#  '56.53',
#  '60.16',
#  '38.52',
#  '146.77',
#  '56.61',
#  '251.79',
#  '45.34',
#  '248.06',
#  '120.26',
#  '18.03',
#  '287.25',
#  '23.50',
#  '80.77',
#  '748.57',
#  '1431.82',
#  '190.66',
#  '219.41',
#  '436.06',
#  '81.69',
#  '18,688.05',
#  '238.03',
#  '1157.10',
#  '2897.31',
#  '18.90',
#  '348.83',
#  '336.45',
#  '4641.21',
#  '201.21',
#  '257.48',
#  '351.58',
#  '239.65',
#  '292.17',
#  '72.12',
#  '65.10',
#  '205.12',
#  '240.76',
#  '2027.91',
#  '226.44',
#  '34.62',
#  '12.25',
#  '187.77',
#  '12.67',
#  '280.87',
#  '648.27',
#  '344.23',
#  '287.42',
#  '117.08',
#  '30.46',
#  '200.71',
#  '410.29',
#  '16,134.23',
#  '749.17',
#  '217.86',
#  '6,924.99',
#  '464.31',
#  '1,204.39',
#  '178.35',
#  '406.04',
#  '561.92',
#  '296.80',
#  '241.36',
#  '128.35',
#  '169.16',
#  '671.46',
#  '49.47',
#  '923.90',
#  '1462.85',
#  '324.52',
#  '79.60',
#  '34.39',
#  '133.12',
#  '120.79',
#  '166.58',
#  '377.66',
#  '98.89',
#  '382.99',
#  '625.71',
#  '204.53',
#  '226.97',
#  '120.73',
#  '28.39',
#  '234.05',
#  '31.51',
#  '567.95',
#  '214.53',
#  '126.23',
#  '394.56',
#  '40.11',
#  '94.65',
#  '223.82',
#  '2,431.38',
#  '304.33',
#  '126.31',
#  '126.87',
#  '9.11',
#  '263.28',
#  '5715.50',
#  '476.62',
#  '246.71',
#  '325.29',
#  '334.36',
#  '221.94',
#  '564.48',
#  '360.82',
#  '261.14',
#  '47.10',
#  '225.68',
#  '5,652.68',
#  '176.95',
#  '76.36',
#  '234.53',
#  '2,546.70',
#  '139.76',
#  '1654.39',
#  '172.69',
#  '20.71',
#  '420.05',
#  '434.05',
#  '238.16',
#  '372.91',
#  '579.97',
#  '143.41',
#  '314.02',
#  '130.49',
#  '131.83',
#  '174.90',
#  '14.40',
#  '103.26',
#  '252.43',
#  '236.95',
#  '215.29',
#  '1875.88',
#  '21.11',
#  '105.33',
#  '52.80',
#  '70.89',
#  '0.58',
#  '317.19',
#  '51.71',
#  '41.82',
#  '1.57',
#  '517.75',
#  '529.57',
#  '221.50',
#  '163.47',
#  '399.83',
#  '63.05',
#  '18.54',
#  '118.26',
#  '275.20',
#  '238.93',
#  '275.26',
#  '81.31',
#  '58.97',
#  '33.31',
#  '138.74',
#  '63.46',
#  '329.58',
#  '341.55',
#  '481.72',
#  '90.08',
#  '119.16',
#  '3.26',
#  '208.55',
#  '136.96',
#  '1,552.87',
#  '159.23',
#  '390.79',
#  '43.61',
#  '285.71',
#  '328.67',
#  '451.41',
#  '28.15',
#  '65.93',
#  '93.62',
#  '15.19',
#  '168.72',
#  '224.08',
#  '90.94',
#  '71.34',
#  '74.36',
#  '2025.00',
#  '327.96',
#  '73.27',
#  '12.70',
#  '103.04',
#  '43.48',
#  '195.05',
#  '191.36',
#  '210.82',
#  '114.13',
#  '114.57',
#  '44.19',
#  '136.69',
#  '61.68',
#  '297.37',
#  '970.25',
#  '364.91',
#  '209.09',
#  '24.77',
#  '408.60',
#  '60.73',
#  '123.58',
#  '132.32',
#  '144.90',
#  '225.83',
#  '243.43',
#  '181.45',
#  '18.53',
#  '39.62',
#  '165.56',
#  '75.37',
#  '112.96',
#  '111.02',
#  '60.91',
#  '118.36',
#  '281.61',
#  '100.01',
#  '89.20',
#  '66.40',
#  '219.55',
#  '194.47',
#  '277.72',
#  '785.91',
#  '130.66',
#  '645.56',
#  '555.26',
#  '1878.63',
#  '249.04',
#  '181.22',
#  '194.88',
#  '187.11',
#  '110.55',
#  '87.28',
#  '129.65',
#  '42.17',
#  '236.83',
#  '145.50',
#  '16.51',
#  '120.37',
#  '70.87',
#  '108.42',
#  '112.97',
#  '2.35',
#  '16.67',
#  '6.54',
#  '52.58',
#  '103.85',
#  '1409.21',
#  '132.07',
#  '35.18',
#  '200.00',
#  '214.51',
#  '172.61',
#  '194.49',
#  '306.12',
#  '1,466.24',
#  '220.38',
#  '107.54',
#  '13.68',
#  '352.99',
#  '134.22',
#  '56.11',
#  '16.47',
#  '248.95',
#  '220.90',
#  '439.39',
#  '35.46',
#  '85.07',
#  '11.43',
#  '35.38',
#  '298.06',
#  '427.56',
#  '3951.22',
#  '460.42',
#  '476.01',
#  '278.81',
#  '103.16',
#  '97.52',
#  '344.38',
#  '295.19',
#  '256.79',
#  '189.54',
#  '188.24',
#  '210.09',
#  '42.78',
#  '223.49',
#  '176.69',
#  '40.82',
#  '467.42',
#  '98.18',
#  '22.95',
#  '95.16',
#  '20.88',
#  '270.27',
#  '80.18',
#  '174.94',
#  '277.45',
#  '448.40',
#  '165.83',
#  '43.44',
#  '140.57',
#  '129.60',
#  '959.55',
#  '1230.17',
#  '926.09',
#  '157.27',
#  '213.99',
#  '318.05',
#  '108.73',
#  '1605.19',
#  '1037.24',
#  '158.42',
#  '241.34',
#  '911.35',
#  '572.04',
#  '353.55',
#  '666.03',
#  '173.22',
#  '63.07',
#  '48.01',
#  '62.23',
#  '340.10',
#  '284.85',
#  '355.03',
#  '1888.22',
#  '618.69',
#  '2215.54',
#  '683.19',
#  '212809.61',
#  '21.29',
#  ...]

# %%
pair_df
# Out:
#         pair1   pair2         tvl     apr    network           apy  \
# 0         $DG     ETH   738323.48   95.76      MATIC    160.217083
# 1         $DG    UICK   308739.68   84.77      MATIC    133.197872
# 2       1INCH                0.00       0        BSC           0.0
# 3       1INCH     BNB     1989.49  345.67        BSC   3020.050963
# 4       1INCH     BNB    12710.23  291.04        BSC   1715.340213
# ...       ...     ...         ...     ...        ...           ...
# 5054   yumcha                0.00       0        BSC           0.0
# 5055   yumcha     USD    58290.00  863.91        BSC  510640.49136
# 5056  yvBOOST     ETH  25943222.8   29.89  Alternate           NaN
# 5057     zLOT     ETH    47651.84   40.69  Alternate           NaN
# 5058   zTears  SPIRIT    43240.61  249.17      FATOM   1097.994043
#
#                                      dex
# 0     https://quickswap.exchange/#/quick
# 1     https://quickswap.exchange/#/quick
# 2            https://caramelswap.finance
# 3           https://icecreamswap.finance
# 4               http://mangofarm.finance
# ...                                  ...
# 5054              https://yumcha.finance
# 5055              https://yumcha.finance
# 5056                               SUSHI
# 5057                               SUSHI
# 5058      https://app.spiritswap.finance
#
# [4996 rows x 7 columns]
